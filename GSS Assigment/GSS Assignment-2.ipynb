# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from collections import Counter

# %%
df = pd.read_csv("bar_data.csv")

# %%
df.head()
# Out:
#    Responder_id                          LanguagesWorkedWith
# 0             1              HTML/CSS;Java;JavaScript;Python
# 1             2                          C++;HTML/CSS;Python
# 2             3                                     HTML/CSS
# 3             4                          C;C++;C#;Python;SQL
# 4             5  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA

# %%
df.LanguagesWorkedWith.head()
# Out:
# 0                HTML/CSS;Java;JavaScript;Python
# 1                            C++;HTML/CSS;Python
# 2                                       HTML/CSS
# 3                            C;C++;C#;Python;SQL
# 4    C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# Name: LanguagesWorkedWith, dtype: object

# %%
df.iloc[0]["LanguagesWorkedWith"]
# Out:
# 'HTML/CSS;Java;JavaScript;Python'

# %%
df.LanguagesWorkedWith.iloc[0]
# Out:
# 'HTML/CSS;Java;JavaScript;Python'

# %%
df.LanguagesWorkedWith.iloc[0].split(";")
# Out:
# ['HTML/CSS', 'Java', 'JavaScript', 'Python']

# %%
a = 0
df.LanguagesWorkedWith.iloc[a].split(";")
# Out:
# ['HTML/CSS', 'Java', 'JavaScript', 'Python']

# %%
a = 5
df.LanguagesWorkedWith.iloc[a].split(";")
# Out:
# ['Java', 'R', 'SQL']

# %%
df.LanguagesWorkedWith.iloc[0].split(";") + df.LanguagesWorkedWith.iloc[1].split(";")
# Out:
# ['HTML/CSS', 'Java', 'JavaScript', 'Python', 'C++', 'HTML/CSS', 'Python']

# %%
single_row = []
for i in df.LanguagesWorkedWith.iloc[0].split(";"): # Selected 1 row
    single_row.append(i)

# %%
single_row
# Out:
# ['HTML/CSS', 'Java', 'JavaScript', 'Python']

# %%
len(df.LanguagesWorkedWith)
# Out:
# 87569

# %%
multi_values = []
for i in range(len(df.LanguagesWorkedWith)):
    multi_values = multi_values+(df.LanguagesWorkedWith.iloc[i].split(";")) # Selected all row

# %%
multi_values
# Out:
# ['HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'C++',
#  'HTML/CSS',
#  'Python',
#  'HTML/CSS',
#  'C',
#  'C++',
#  'C#',
#  'Python',
#  'SQL',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'VBA',
#  'Java',
#  'R',
#  'SQL',
#  'HTML/CSS',
#  'JavaScript',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'C#',
#  'HTML/CSS',
#  'JavaScript',
#  'Python',
#  'Ruby',
#  'Rust',
#  'SQL',
#  'TypeScript',
#  'WebAssembly',
#  'Other(s):',
#  'C#',
#  'Go',
#  'JavaScript',
#  'Python',
#  'R',
#  'SQL',
#  'Other(s):',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'Java',
#  'Python',
#  'R',
#  'SQL',
#  'Bash/Shell/PowerShell',
#  'HTML/CSS',
#  'JavaScript',
#  'PHP',
#  'SQL',
#  'TypeScript',
#  'C++',
#  'Assembly',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C++',
#  'HTML/CSS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'SQL',
# ...

# %%
new = Counter(multi_values)

# %%
new_list = pd.Series(new)

# %%
new_list
# Out:
# HTML/CSS                 55466
# Java                     35917
# JavaScript               59219
# Python                   36443
# C++                      20524
# C                        18017
# C#                       27097
# SQL                      47544
# VBA                       4781
# R                         5048
# Bash/Shell/PowerShell    31991
# Ruby                      7331
# Rust                      2794
# TypeScript               18523
# WebAssembly               1015
# Other(s):                 7920
# Go                        7201
# PHP                      23030
# Assembly                  5833
# Kotlin                    5620
# Swift                     5744
# Objective-C               4191
# Elixir                    1260
# Erlang                     777
# Clojure                   1254
# F#                         973
# Scala                     3309
# Dart                      1683
# dtype: int64

# %%
new_list.sort_values(ascending=False)
# Out:
# JavaScript               59219
# HTML/CSS                 55466
# SQL                      47544
# Python                   36443
# Java                     35917
# Bash/Shell/PowerShell    31991
# C#                       27097
# PHP                      23030
# C++                      20524
# TypeScript               18523
# C                        18017
# Other(s):                 7920
# Ruby                      7331
# Go                        7201
# Assembly                  5833
# Swift                     5744
# Kotlin                    5620
# R                         5048
# VBA                       4781
# Objective-C               4191
# Scala                     3309
# Rust                      2794
# Dart                      1683
# Elixir                    1260
# Clojure                   1254
# WebAssembly               1015
# F#                         973
# Erlang                     777
# dtype: int64

# %%
new_list.sort_values(ascending=False).index
# Out:
# Index(['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java',
#        'Bash/Shell/PowerShell', 'C#', 'PHP', 'C++', 'TypeScript', 'C',
#        'Other(s):', 'Ruby', 'Go', 'Assembly', 'Swift', 'Kotlin', 'R', 'VBA',
#        'Objective-C', 'Scala', 'Rust', 'Dart', 'Elixir', 'Clojure',
#        'WebAssembly', 'F#', 'Erlang'],
#       dtype='object')

# %%
labels = new_list.sort_values(ascending=False).index
fig, ax = plt.subplots(figsize=(16,9),dpi=100)
ax.plot(new_list.sort_values(ascending=False))
ax.set_xlabel("Skills")
ax.set_ylabel("Number")
ax.set_xticks(labels)
ax.set_xticklabels(labels,rotation=90);

# %%
labels = new_list.sort_values(ascending=False).index
fig, ax = plt.subplots(figsize=(16,9),dpi=100)
ax.bar(new_list.sort_values(ascending=False).index,new_list.sort_values(ascending=False))
ax.set_xlabel("Skills")
ax.set_ylabel("Number")
ax.set_xticks(labels)
ax.set_xticklabels(labels,rotation=90);

# %%
fig, ax = plt.subplots(figsize=(16,9),dpi=100)
sns.barplot(x=new_list.sort_values(ascending=False).index,y=new_list.sort_values(ascending=False), ax=ax)
plt.xlabel("Skills")
plt.ylabel("Number")
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(16,9),dpi=100)
sns.barplot(x=new_list.sort_values(ascending=False).index,y=new_list.sort_values(ascending=False))
plt.xlabel("Skills")
plt.ylabel("Number")
plt.xticks(rotation=90);
