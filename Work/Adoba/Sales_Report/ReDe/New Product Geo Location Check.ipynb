# %% [markdown]
# ### Product And Location

# %%
# pip install geopy

# %%
import unicodedata
import datetime as dt
import os
import sys
import re
import numpy as np
import pandas as pd
import math
from pathlib import Path
import nltk
from nltk import word_tokenize 
import shutil
from os.path import isfile, join
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import locale
from locale import atof
from geopy.geocoders import Nominatim
from geopy.point import Point
from geopy.exc import GeocoderTimedOut
from functools import reduce

# %% [markdown]
# ##### Functions

# %%
# custom character alphabet for word
tr = re.compile(r"[abcçdefgğhıijklmnoöprsştuüvyzqxw]+", re.IGNORECASE|re.UNICODE) # Turkish filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n0123456789'
en = re.compile(r"[abcdefghıijklmnopqrstxuvwyz]+", re.IGNORECASE|re.UNICODE) # English
nl = re.compile(r"[abcdefghıijklmnopqrstxuvwyzāăēĕīĭōŏūŭ]+", re.IGNORECASE|re.UNICODE) # Dutch (Flemenk)
fr = re.compile(r"[abcçdefghıijklmnopqrstxuvwyzàâæèéêëîïôœùûüÿ]+", re.IGNORECASE|re.UNICODE) # French
de = re.compile(r"[abcdefghıijklmnopqrstxuvwyzäöüß]+", re.IGNORECASE|re.UNICODE) # German
es = re.compile(r"[abcdefghıijklmnopqrstxuvwyzñáéíóú]+", re.IGNORECASE|re.UNICODE) # Spanish (¿¡)
pt = re.compile(r"[abcçdefghıijklmnopqrstxuvwyzàáâãéêíóôõú]+", re.IGNORECASE|re.UNICODE) # Portuguese
it = re.compile(r"[abcdefghıijklmnopqrstxuvwyzàéèìòùî]+", re.IGNORECASE|re.UNICODE) # Italian
ar = re.compile(r"[ٿصؼۤڳڲؿڎػڠجڿ٬ٸؽؒؓطۄڀۂؘؔتٚڛےٝڜؖڦ٫ډ۰زۇٖۀ،لۓعٮێڔ۶ؚۧۜڤۏإٞٷؗۖ؈ژۣؕؑٴأۻڸۺگاڴڹۯ؉ْڌ؍ي؟ـٟړۅؐڶُىڽېًۢؠضۚڄٛڏٱۦ٩س٦ڼڂٔۘ٠ښٌٍ۬ٳ۾ٲږذۋٵٜ٘ڞڅںٗهڣۿپڒۥۗڋیؙم؞ثۨٹڵڪظٶۭ١ڭەڨحٕ؎ٺڷٰ۪۫ڻڥۛڑڟټآڡغګ؊ّٯڧڮ؏ۮ؋ؤ٪ؾڗۼق۟دکوِڰڐۃ۽ہفرڇچڝ۴بۈٽڕۡھةٓڃئ؛ڬٙڙڢڱۊَۆۉځ۠ۍۑۙڊنءڈٻشڍ؇۵كخ\ا]+", re.IGNORECASE|re.UNICODE) # Arabic

# %%
def convert_one_character_letter(text):
    '''This function converts two byte occupy of letter to one byte unicode character without any visual change \n
    like as Turkish character ç,ş,ö,ğ. \n
    convert_one_character_letter(text): text is any string word or sentence.
    '''
    new_text = unicodedata.normalize('NFC', f"{text}")
    return new_text

# %%
def clean_text(text, custom_alp=tr): # for only string in specific language
    '''This function extract custom_alp character from string \n
    clean_text(text, custom_alp): text is any string word or sentence and custom_alp is specific alphabet.
    '''
    # text_clean = re.findall(custom_alp, text)
    text_result_list = []
    text_list = re.findall(r'\S+', text)
    for text_var in text_list:
        text_clean = re.findall(custom_alp, str(text_var))
        text_result_var = "".join(text_clean)
        text_result_list.append(text_result_var)
    text_result = " ".join(text_result_list)
    return text_result

# %%
def lower_func(text):
    '''This function convert string character to lowercase. \n
    lower_func(text=str): text is any string word or sentence
    '''
    string_lower = str.lower(text)
    return string_lower

# %%
def upper_func(text):
    '''This function convert string character to uppercase. \n
    upper_func(text=str): text is any string word or sentence
    '''
    string_upper = str.upper(text)
    return string_upper

# %%
def capitalize_func(text):
    '''This function convert string character to capitalize case. \n
    capitalize_func(text=str): text is any string word or sentence
    '''
    string_capitalize = str.capitalize(text)
    return string_capitalize

# %%
def title_func(text):
    '''This function convert string character to title as each word start with capital letter. \n
    title_func(text=str): text is any string word or sentence
    '''
    string_title = str.title(text)
    return string_title

# %%
def character_clean_lower_text(text, custom_alp=tr): # for only string in specific language
    '''This function converts two byte occupy of letter to one byte unicode character without any visual change \n
    like as Turkish character ç,ş,ö,ğ. And also extract custom_alp character from string and convert to lowercase. \n
    character_clean_lower_text(text, custom_alp): text is any string word or sentence and custom_alp is specific alphabet.  
    '''
    new_text = unicodedata.normalize('NFC', f"{text}")
    text_result_list = []
    text_list = re.findall(r'\S+', new_text)  # like as word tokenize
    for text_var in text_list:
        text_clean = re.findall(custom_alp, str(text_var))
        text_result_var = "".join(text_clean)
        text_result_list.append(text_result_var)
    text_join = " ".join(text_result_list)
    text_result = str.lower(text_join)
    return text_result

# %%
def convert_to_float(value):
    '''This function convert string numeric value to float type. Like as 1.200,15
    convert_to_float(value): value is a string numeric value
    '''
    value = value.replace(".","").replace(",",".")
    return float(value)

# %%
def whitespace_del(text):
    '''This function provides removing left right white space.\n
    whitespace_del(text): text is a string value as word or sentence.
    '''
    text_var = str(text)
    text_var = text_var.strip()  # rstrip lstrip
    return text_var

# %% [markdown]
# #### Read Data Analysis

# %%
variable_date = "01.04.2024-05.09.2024"
input_path = fr"C:\Users\user\Desktop\Data Analysis\Adoba\Sales_Report\Data\Entegra\Sales\{variable_date}"
output_path = fr"C:\Users\user\Downloads"

data_file = fr"Entegra_Sales_List ({variable_date})"

# %%
#df_entegra = pd.read_csv(fr"{input_path}\{data_file}.csv", low_memory=False)
df_entegra = pd.read_excel(fr"{input_path}\{data_file}.xlsx")
df_entegra
# Out:
#            id order_number platform_reference_no  invoice_number  \
# 0      201036   2383110310            9465795799             NaN
# 1      201035   2383102583            9465789564             NaN
# 2      201033   2383091113            9465777317             NaN
# 3      201025   2383085464            9465772854             NaN
# 4      201027   2383076067            9465764076             NaN
# ...       ...          ...                   ...             ...
# 92975  107816   2036971893            9080057915             NaN
# 92976  107817   2036970386            9080056913             NaN
# 92977  107815   0888556689            0888556689             NaN
# 92978  107812   2036956451            9080042398             NaN
# 92979  107813   2036952678            9080038299             NaN
#
#                  datetime            date_add  entegration  supplier  status  \
# 0     2024-09-05 10:54:27 2024-09-05 10:57:15     trendyol  trendyol       2
# 1     2024-09-05 10:50:42 2024-09-05 10:51:14     trendyol  trendyol       2
# 2     2024-09-05 10:43:15 2024-09-05 10:45:03     trendyol  trendyol       2
# 3     2024-09-05 10:40:26 2024-09-05 10:42:12     trendyol  trendyol       2
# 4     2024-09-05 10:34:55 2024-09-05 10:42:15     trendyol  trendyol       2
# ...                   ...                 ...          ...       ...     ...
# 92975 2024-03-01 00:16:54 2024-03-01 00:17:34     trendyol  trendyol       2
# 92976 2024-03-01 00:16:07 2024-03-01 00:17:35     trendyol  trendyol       2
# 92977 2024-03-01 00:14:02 2024-03-01 00:15:22  HepsiBurada        hb       2
# 92978 2024-03-01 00:05:22 2024-03-01 00:06:28     trendyol  trendyol       2
# 92979 2024-03-01 00:02:25 2024-03-01 00:06:28     trendyol  trendyol       2
#
#       status_name  ...   pov_productCode payment_type total_product  \
# 0       Onaylandı  ...               NaN     Trendyol             1
# 1       Onaylandı  ...               NaN     Trendyol             5
# 2       Onaylandı  ...               NaN     Trendyol             1
# 3       Onaylandı  ...               NaN     Trendyol             2
# 4       Onaylandı  ...      220647971025     Trendyol             1
# ...           ...  ...               ...          ...           ...
# 92975   Onaylandı  ...               NaN     Trendyol             1
# 92976   Onaylandı  ...               NaN     Trendyol             1
# 92977   Onaylandı  ...               NaN  HepsiBurada             1
# 92978   Onaylandı  ...  yatak54896513739     Trendyol             1
# 92979   Onaylandı  ...               NaN     Trendyol             1
#
#       PazaryerindenGelenOdemeTutar total_product_quantity     delivery_method  \
# 0                                0                      1    Aynı gün kargoda
# 1                                0                      7    Aynı gün kargoda
# 2                                0                      1    Aynı gün kargoda
# 3                                0                      2    Aynı gün kargoda
# 4                                0                      1    Aynı gün kargoda
# ...                            ...                    ...                 ...
# 92975                            0                      1  Ertesi Gün Kargoda
# 92976                            0                      1  Ertesi Gün Kargoda
# 92977                            0                      1                 NaN
# 92978                            0                      1                 NaN
# 92979                            0                      1  Ertesi Gün Kargoda
#
#              fatura_tarihi  invoice_url  invoice_type  FaturaTipiAdi
# 0                      NaN          NaN             0        Seciniz
# 1                      NaN          NaN             0        Seciniz
# 2                      NaN          NaN             0        Seciniz
# 3                      NaN          NaN             0        Seciniz
# 4                      NaN          NaN             0        Seciniz
# ...                    ...          ...           ...            ...
# 92975  03/01/2024 10:59:38          NaN             0        Seciniz
# 92976  03/01/2024 09:21:47          NaN             0        Seciniz
# 92977  03/01/2024 09:53:35          NaN             0        Seciniz
# 92978  03/01/2024 10:59:38          NaN             0        Seciniz
# 92979  03/01/2024 09:21:47          NaN             0        Seciniz
#
# [92980 rows x 59 columns]

# %%
df_entegra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92980 entries, 0 to 92979
# Data columns (total 59 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            92980 non-null  int64
#  1   order_number                  92980 non-null  object
#  2   platform_reference_no         92980 non-null  object
#  3   invoice_number                0 non-null      float64
#  4   datetime                      92980 non-null  datetime64[ns]
#  5   date_add                      92980 non-null  datetime64[ns]
#  6   entegration                   92980 non-null  object
#  7   supplier                      92980 non-null  object
#  8   status                        92980 non-null  int64
#  9   status_name                   92980 non-null  object
#  10  company                       92979 non-null  object
#  11  cargo_code                    91159 non-null  object
#  12  invoice_country               2725 non-null   object
#  13  invoice_city                  92979 non-null  object
#  14  tax_office                    1893 non-null   object
#  15  tax_number                    1887 non-null   object
#  16  tc_id                         74871 non-null  float64
#  17  total                         92980 non-null  float64
#  18  tax                           92980 non-null  float64
#  19  grand_total                   92980 non-null  float64
#  20  sync                          92980 non-null  int64
#  21  erp_order_number              0 non-null      float64
#  22  erp_message                   92980 non-null  object
#  23  store_order_status            91159 non-null  float64
#  24  store_order_status_name       92980 non-null  object
#  25  order_process                 92980 non-null  int64
#  26  note                          2708 non-null   object
#  27  supplier1                     92980 non-null  object
#  28  supplier_id                   92980 non-null  object
#  29  cargo_sync                    92980 non-null  int64
#  30  cargo_company                 91043 non-null  object
#  31  cargo_code2                   0 non-null      float64
#  32  cargo_follow_url              0 non-null      float64
#  33  cargo_finally_statu           0 non-null      float64
#  34  cargo_error_message           0 non-null      float64
#  35  einvoice_error_message        0 non-null      float64
#  36  invoice_print_name            92980 non-null  object
#  37  ship_print_name               92980 non-null  object
#  38  sevk_tarihi                   0 non-null      float64
#  39  ship_country                  1820 non-null   object
#  40  customer_code                 92980 non-null  object
#  41  cargo_fee_type_name           92979 non-null  object
#  42  cargo_packet_type             92980 non-null  object
#  43  cargo_packet_quantity         92980 non-null  int64
#  44  grand_total_desi              92980 non-null  int64
#  45  model                         92979 non-null  object
#  46  product_name                  92979 non-null  object
#  47  store_product_name            92979 non-null  object
#  48  invoice_name                  92979 non-null  object
#  49  pov_productCode               28412 non-null  object
#  50  payment_type                  92979 non-null  object
#  51  total_product                 92980 non-null  int64
#  52  PazaryerindenGelenOdemeTutar  92980 non-null  int64
#  53  total_product_quantity        92980 non-null  int64
#  54  delivery_method               49191 non-null  object
#  55  fatura_tarihi                 90065 non-null  object
#  56  invoice_url                   0 non-null      float64
#  57  invoice_type                  92980 non-null  int64
#  58  FaturaTipiAdi                 92980 non-null  object
# dtypes: datetime64[ns](2), float64(14), int64(11), object(32)
# memory usage: 41.9+ MB

# %%
df_entegra.columns = [x.lower() for x in df_entegra.columns]
df_entegra.columns = [x.strip() for x in df_entegra.columns]
df_entegra
# Out:
#            id order_number platform_reference_no  invoice_number  \
# 0      201036   2383110310            9465795799             NaN
# 1      201035   2383102583            9465789564             NaN
# 2      201033   2383091113            9465777317             NaN
# 3      201025   2383085464            9465772854             NaN
# 4      201027   2383076067            9465764076             NaN
# ...       ...          ...                   ...             ...
# 92975  107816   2036971893            9080057915             NaN
# 92976  107817   2036970386            9080056913             NaN
# 92977  107815   0888556689            0888556689             NaN
# 92978  107812   2036956451            9080042398             NaN
# 92979  107813   2036952678            9080038299             NaN
#
#                  datetime            date_add  entegration  supplier  status  \
# 0     2024-09-05 10:54:27 2024-09-05 10:57:15     trendyol  trendyol       2
# 1     2024-09-05 10:50:42 2024-09-05 10:51:14     trendyol  trendyol       2
# 2     2024-09-05 10:43:15 2024-09-05 10:45:03     trendyol  trendyol       2
# 3     2024-09-05 10:40:26 2024-09-05 10:42:12     trendyol  trendyol       2
# 4     2024-09-05 10:34:55 2024-09-05 10:42:15     trendyol  trendyol       2
# ...                   ...                 ...          ...       ...     ...
# 92975 2024-03-01 00:16:54 2024-03-01 00:17:34     trendyol  trendyol       2
# 92976 2024-03-01 00:16:07 2024-03-01 00:17:35     trendyol  trendyol       2
# 92977 2024-03-01 00:14:02 2024-03-01 00:15:22  HepsiBurada        hb       2
# 92978 2024-03-01 00:05:22 2024-03-01 00:06:28     trendyol  trendyol       2
# 92979 2024-03-01 00:02:25 2024-03-01 00:06:28     trendyol  trendyol       2
#
#       status_name  ...   pov_productcode payment_type total_product  \
# 0       Onaylandı  ...               NaN     Trendyol             1
# 1       Onaylandı  ...               NaN     Trendyol             5
# 2       Onaylandı  ...               NaN     Trendyol             1
# 3       Onaylandı  ...               NaN     Trendyol             2
# 4       Onaylandı  ...      220647971025     Trendyol             1
# ...           ...  ...               ...          ...           ...
# 92975   Onaylandı  ...               NaN     Trendyol             1
# 92976   Onaylandı  ...               NaN     Trendyol             1
# 92977   Onaylandı  ...               NaN  HepsiBurada             1
# 92978   Onaylandı  ...  yatak54896513739     Trendyol             1
# 92979   Onaylandı  ...               NaN     Trendyol             1
#
#       pazaryerindengelenodemetutar total_product_quantity     delivery_method  \
# 0                                0                      1    Aynı gün kargoda
# 1                                0                      7    Aynı gün kargoda
# 2                                0                      1    Aynı gün kargoda
# 3                                0                      2    Aynı gün kargoda
# 4                                0                      1    Aynı gün kargoda
# ...                            ...                    ...                 ...
# 92975                            0                      1  Ertesi Gün Kargoda
# 92976                            0                      1  Ertesi Gün Kargoda
# 92977                            0                      1                 NaN
# 92978                            0                      1                 NaN
# 92979                            0                      1  Ertesi Gün Kargoda
#
#              fatura_tarihi  invoice_url  invoice_type  faturatipiadi
# 0                      NaN          NaN             0        Seciniz
# 1                      NaN          NaN             0        Seciniz
# 2                      NaN          NaN             0        Seciniz
# 3                      NaN          NaN             0        Seciniz
# 4                      NaN          NaN             0        Seciniz
# ...                    ...          ...           ...            ...
# 92975  03/01/2024 10:59:38          NaN             0        Seciniz
# 92976  03/01/2024 09:21:47          NaN             0        Seciniz
# 92977  03/01/2024 09:53:35          NaN             0        Seciniz
# 92978  03/01/2024 10:59:38          NaN             0        Seciniz
# 92979  03/01/2024 09:21:47          NaN             0        Seciniz
#
# [92980 rows x 59 columns]

# %%
df_entegra_select_var = df_entegra[["order_number","model","pov_productcode","product_name","datetime","total_product_quantity","entegration",\
    "invoice_city","invoice_country","total","tax","grand_total","company","cargo_company","status_name"]]
df_entegra_select_var
# Out:
#       order_number   model   pov_productcode  \
# 0       2383110310  003362               NaN
# 1       2383102583  004382               NaN
# 2       2383091113  001602               NaN
# 3       2383085464  001602               NaN
# 4       2383076067  002583      220647971025
# ...            ...     ...               ...
# 92975   2036971893  001603               NaN
# 92976   2036970386  002429               NaN
# 92977   0888556689  002369               NaN
# 92978   2036956451  002284  yatak54896513739
# 92979   2036952678  003418               NaN
#
#                                             product_name            datetime  \
# 0      6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö... 2024-09-05 10:54:27
# 1      Çok Amaçlı Multi İnce Temizlik Fırçası Derz Ar... 2024-09-05 10:50:42
# 2      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:43:15
# 3      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:40:26
# 4      Portatif Katlanabilir Masa, Piknik Masası, Kam... 2024-09-05 10:34:55
# ...                                                  ...                 ...
# 92975  Pikas Ahşap Özel İsim Baskılı, Kare Kedi Köpek... 2024-03-01 00:16:54
# 92976           BTS3 Boyama Tuval Sayılı Set 25x35 Yunus 2024-03-01 00:16:07
# 92977  Küçük Çelik Uçlu Kedi Köpek Evcil Hayvan Tırna... 2024-03-01 00:14:02
# 92978  Kalorifer Petek Radyatör Yatağı Kedi Geniş Ked... 2024-03-01 00:05:22
# 92979   Merinos Modern Line 3 Parça Battaniye Seti - Bej 2024-03-01 00:02:25
#
#        total_product_quantity  entegration invoice_city invoice_country  \
# 0                           1     trendyol     İstanbul             NaN
# 1                           7     trendyol     İstanbul             NaN
# 2                           1     trendyol       Ankara             NaN
# 3                           2     trendyol     İstanbul             NaN
# 4                           1     trendyol        Sivas             NaN
# ...                       ...          ...          ...             ...
# 92975                       1     trendyol       Samsun             NaN
# 92976                       1     trendyol        Çorum             NaN
# 92977                       1  HepsiBurada        İzmir             NaN
# 92978                       1     trendyol        Konya             NaN
# 92979                       1     trendyol     İstanbul             NaN
#
#          total     tax  grand_total          company     cargo_company  \
# 0      391.670  78.330       470.00      ali özdemir  trendyolekspress
# 1      395.530  48.470       444.00      Tuğba Sayar  trendyolekspress
# 2      165.830  33.170       199.00        Tuba Koca  trendyolekspress
# 3      215.830  43.170       259.00       Doğa Özkan  trendyolekspress
# 4      181.820  18.180       200.00      Damla Beşer  trendyolekspress
# ...        ...     ...          ...              ...               ...
# 92975  133.330  26.670       160.00     Gülizar Sarı  trendyolekspress
# 92976  154.170  30.830       185.00  zübeyde DEMİREL  trendyolekspress
# 92977   33.325   6.665        39.99       İrem Erbey          hepsijet
# 92978  142.500  28.500       171.00    Esma Söylemez  trendyolekspress
# 92979  772.730  77.270       850.00    ayse muhammed  trendyolekspress
#
#       status_name
# 0       Onaylandı
# 1       Onaylandı
# 2       Onaylandı
# 3       Onaylandı
# 4       Onaylandı
# ...           ...
# 92975   Onaylandı
# 92976   Onaylandı
# 92977   Onaylandı
# 92978   Onaylandı
# 92979   Onaylandı
#
# [92980 rows x 15 columns]

# %%
df_entegra_select_var.loc[:,"cargo_company"] = df_entegra_select_var.loc[:,"cargo_company"].fillna("diger")
df_entegra_select_var
# Out:
#       order_number   model   pov_productcode  \
# 0       2383110310  003362               NaN
# 1       2383102583  004382               NaN
# 2       2383091113  001602               NaN
# 3       2383085464  001602               NaN
# 4       2383076067  002583      220647971025
# ...            ...     ...               ...
# 92975   2036971893  001603               NaN
# 92976   2036970386  002429               NaN
# 92977   0888556689  002369               NaN
# 92978   2036956451  002284  yatak54896513739
# 92979   2036952678  003418               NaN
#
#                                             product_name            datetime  \
# 0      6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö... 2024-09-05 10:54:27
# 1      Çok Amaçlı Multi İnce Temizlik Fırçası Derz Ar... 2024-09-05 10:50:42
# 2      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:43:15
# 3      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:40:26
# 4      Portatif Katlanabilir Masa, Piknik Masası, Kam... 2024-09-05 10:34:55
# ...                                                  ...                 ...
# 92975  Pikas Ahşap Özel İsim Baskılı, Kare Kedi Köpek... 2024-03-01 00:16:54
# 92976           BTS3 Boyama Tuval Sayılı Set 25x35 Yunus 2024-03-01 00:16:07
# 92977  Küçük Çelik Uçlu Kedi Köpek Evcil Hayvan Tırna... 2024-03-01 00:14:02
# 92978  Kalorifer Petek Radyatör Yatağı Kedi Geniş Ked... 2024-03-01 00:05:22
# 92979   Merinos Modern Line 3 Parça Battaniye Seti - Bej 2024-03-01 00:02:25
#
#        total_product_quantity  entegration invoice_city invoice_country  \
# 0                           1     trendyol     İstanbul             NaN
# 1                           7     trendyol     İstanbul             NaN
# 2                           1     trendyol       Ankara             NaN
# 3                           2     trendyol     İstanbul             NaN
# 4                           1     trendyol        Sivas             NaN
# ...                       ...          ...          ...             ...
# 92975                       1     trendyol       Samsun             NaN
# 92976                       1     trendyol        Çorum             NaN
# 92977                       1  HepsiBurada        İzmir             NaN
# 92978                       1     trendyol        Konya             NaN
# 92979                       1     trendyol     İstanbul             NaN
#
#          total     tax  grand_total          company     cargo_company  \
# 0      391.670  78.330       470.00      ali özdemir  trendyolekspress
# 1      395.530  48.470       444.00      Tuğba Sayar  trendyolekspress
# 2      165.830  33.170       199.00        Tuba Koca  trendyolekspress
# 3      215.830  43.170       259.00       Doğa Özkan  trendyolekspress
# 4      181.820  18.180       200.00      Damla Beşer  trendyolekspress
# ...        ...     ...          ...              ...               ...
# 92975  133.330  26.670       160.00     Gülizar Sarı  trendyolekspress
# 92976  154.170  30.830       185.00  zübeyde DEMİREL  trendyolekspress
# 92977   33.325   6.665        39.99       İrem Erbey          hepsijet
# 92978  142.500  28.500       171.00    Esma Söylemez  trendyolekspress
# 92979  772.730  77.270       850.00    ayse muhammed  trendyolekspress
#
#       status_name
# 0       Onaylandı
# 1       Onaylandı
# 2       Onaylandı
# 3       Onaylandı
# 4       Onaylandı
# ...           ...
# 92975   Onaylandı
# 92976   Onaylandı
# 92977   Onaylandı
# 92978   Onaylandı
# 92979   Onaylandı
#
# [92980 rows x 15 columns]

# %%
df_entegra_select_var.loc[:,"cargo_company"] = df_entegra_select_var.loc[:,"cargo_company"].fillna("diger")
df_entegra_select_var
# Out:
#       order_number   model   pov_productcode  \
# 0       2383110310  003362               NaN
# 1       2383102583  004382               NaN
# 2       2383091113  001602               NaN
# 3       2383085464  001602               NaN
# 4       2383076067  002583      220647971025
# ...            ...     ...               ...
# 92975   2036971893  001603               NaN
# 92976   2036970386  002429               NaN
# 92977   0888556689  002369               NaN
# 92978   2036956451  002284  yatak54896513739
# 92979   2036952678  003418               NaN
#
#                                             product_name            datetime  \
# 0      6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö... 2024-09-05 10:54:27
# 1      Çok Amaçlı Multi İnce Temizlik Fırçası Derz Ar... 2024-09-05 10:50:42
# 2      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:43:15
# 3      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:40:26
# 4      Portatif Katlanabilir Masa, Piknik Masası, Kam... 2024-09-05 10:34:55
# ...                                                  ...                 ...
# 92975  Pikas Ahşap Özel İsim Baskılı, Kare Kedi Köpek... 2024-03-01 00:16:54
# 92976           BTS3 Boyama Tuval Sayılı Set 25x35 Yunus 2024-03-01 00:16:07
# 92977  Küçük Çelik Uçlu Kedi Köpek Evcil Hayvan Tırna... 2024-03-01 00:14:02
# 92978  Kalorifer Petek Radyatör Yatağı Kedi Geniş Ked... 2024-03-01 00:05:22
# 92979   Merinos Modern Line 3 Parça Battaniye Seti - Bej 2024-03-01 00:02:25
#
#        total_product_quantity  entegration invoice_city invoice_country  \
# 0                           1     trendyol     İstanbul             NaN
# 1                           7     trendyol     İstanbul             NaN
# 2                           1     trendyol       Ankara             NaN
# 3                           2     trendyol     İstanbul             NaN
# 4                           1     trendyol        Sivas             NaN
# ...                       ...          ...          ...             ...
# 92975                       1     trendyol       Samsun             NaN
# 92976                       1     trendyol        Çorum             NaN
# 92977                       1  HepsiBurada        İzmir             NaN
# 92978                       1     trendyol        Konya             NaN
# 92979                       1     trendyol     İstanbul             NaN
#
#          total     tax  grand_total          company     cargo_company  \
# 0      391.670  78.330       470.00      ali özdemir  trendyolekspress
# 1      395.530  48.470       444.00      Tuğba Sayar  trendyolekspress
# 2      165.830  33.170       199.00        Tuba Koca  trendyolekspress
# 3      215.830  43.170       259.00       Doğa Özkan  trendyolekspress
# 4      181.820  18.180       200.00      Damla Beşer  trendyolekspress
# ...        ...     ...          ...              ...               ...
# 92975  133.330  26.670       160.00     Gülizar Sarı  trendyolekspress
# 92976  154.170  30.830       185.00  zübeyde DEMİREL  trendyolekspress
# 92977   33.325   6.665        39.99       İrem Erbey          hepsijet
# 92978  142.500  28.500       171.00    Esma Söylemez  trendyolekspress
# 92979  772.730  77.270       850.00    ayse muhammed  trendyolekspress
#
#       status_name
# 0       Onaylandı
# 1       Onaylandı
# 2       Onaylandı
# 3       Onaylandı
# 4       Onaylandı
# ...           ...
# 92975   Onaylandı
# 92976   Onaylandı
# 92977   Onaylandı
# 92978   Onaylandı
# 92979   Onaylandı
#
# [92980 rows x 15 columns]

# %%
df_entegra_select_var = df_entegra_select_var.sort_values(["datetime","total_product_quantity"], ascending=False)
df_entegra_select_var.reset_index(drop=True, inplace=True)
df_entegra_select_var
# Out:
#       order_number   model   pov_productcode  \
# 0       2383110310  003362               NaN
# 1       2383102583  004382               NaN
# 2       2383091113  001602               NaN
# 3       2383085464  001602               NaN
# 4       2383076067  002583      220647971025
# ...            ...     ...               ...
# 92975   2036971893  001603               NaN
# 92976   2036970386  002429               NaN
# 92977   0888556689  002369               NaN
# 92978   2036956451  002284  yatak54896513739
# 92979   2036952678  003418               NaN
#
#                                             product_name            datetime  \
# 0      6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö... 2024-09-05 10:54:27
# 1      Çok Amaçlı Multi İnce Temizlik Fırçası Derz Ar... 2024-09-05 10:50:42
# 2      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:43:15
# 3      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:40:26
# 4      Portatif Katlanabilir Masa, Piknik Masası, Kam... 2024-09-05 10:34:55
# ...                                                  ...                 ...
# 92975  Pikas Ahşap Özel İsim Baskılı, Kare Kedi Köpek... 2024-03-01 00:16:54
# 92976           BTS3 Boyama Tuval Sayılı Set 25x35 Yunus 2024-03-01 00:16:07
# 92977  Küçük Çelik Uçlu Kedi Köpek Evcil Hayvan Tırna... 2024-03-01 00:14:02
# 92978  Kalorifer Petek Radyatör Yatağı Kedi Geniş Ked... 2024-03-01 00:05:22
# 92979   Merinos Modern Line 3 Parça Battaniye Seti - Bej 2024-03-01 00:02:25
#
#        total_product_quantity  entegration invoice_city invoice_country  \
# 0                           1     trendyol     İstanbul             NaN
# 1                           7     trendyol     İstanbul             NaN
# 2                           1     trendyol       Ankara             NaN
# 3                           2     trendyol     İstanbul             NaN
# 4                           1     trendyol        Sivas             NaN
# ...                       ...          ...          ...             ...
# 92975                       1     trendyol       Samsun             NaN
# 92976                       1     trendyol        Çorum             NaN
# 92977                       1  HepsiBurada        İzmir             NaN
# 92978                       1     trendyol        Konya             NaN
# 92979                       1     trendyol     İstanbul             NaN
#
#          total     tax  grand_total          company     cargo_company  \
# 0      391.670  78.330       470.00      ali özdemir  trendyolekspress
# 1      395.530  48.470       444.00      Tuğba Sayar  trendyolekspress
# 2      165.830  33.170       199.00        Tuba Koca  trendyolekspress
# 3      215.830  43.170       259.00       Doğa Özkan  trendyolekspress
# 4      181.820  18.180       200.00      Damla Beşer  trendyolekspress
# ...        ...     ...          ...              ...               ...
# 92975  133.330  26.670       160.00     Gülizar Sarı  trendyolekspress
# 92976  154.170  30.830       185.00  zübeyde DEMİREL  trendyolekspress
# 92977   33.325   6.665        39.99       İrem Erbey          hepsijet
# 92978  142.500  28.500       171.00    Esma Söylemez  trendyolekspress
# 92979  772.730  77.270       850.00    ayse muhammed  trendyolekspress
#
#       status_name
# 0       Onaylandı
# 1       Onaylandı
# 2       Onaylandı
# 3       Onaylandı
# 4       Onaylandı
# ...           ...
# 92975   Onaylandı
# 92976   Onaylandı
# 92977   Onaylandı
# 92978   Onaylandı
# 92979   Onaylandı
#
# [92980 rows x 15 columns]

# %%
df_entegra_select_var = df_entegra_select_var.drop_duplicates(subset="order_number", keep="first")
df_entegra_select_var = df_entegra_select_var.reset_index(drop=True)
df_entegra_select_var
# Out:
#       order_number   model   pov_productcode  \
# 0       2383110310  003362               NaN
# 1       2383102583  004382               NaN
# 2       2383091113  001602               NaN
# 3       2383085464  001602               NaN
# 4       2383076067  002583      220647971025
# ...            ...     ...               ...
# 92285   2036971893  001603               NaN
# 92286   2036970386  002429               NaN
# 92287   0888556689  002369               NaN
# 92288   2036956451  002284  yatak54896513739
# 92289   2036952678  003418               NaN
#
#                                             product_name            datetime  \
# 0      6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö... 2024-09-05 10:54:27
# 1      Çok Amaçlı Multi İnce Temizlik Fırçası Derz Ar... 2024-09-05 10:50:42
# 2      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:43:15
# 3      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:40:26
# 4      Portatif Katlanabilir Masa, Piknik Masası, Kam... 2024-09-05 10:34:55
# ...                                                  ...                 ...
# 92285  Pikas Ahşap Özel İsim Baskılı, Kare Kedi Köpek... 2024-03-01 00:16:54
# 92286           BTS3 Boyama Tuval Sayılı Set 25x35 Yunus 2024-03-01 00:16:07
# 92287  Küçük Çelik Uçlu Kedi Köpek Evcil Hayvan Tırna... 2024-03-01 00:14:02
# 92288  Kalorifer Petek Radyatör Yatağı Kedi Geniş Ked... 2024-03-01 00:05:22
# 92289   Merinos Modern Line 3 Parça Battaniye Seti - Bej 2024-03-01 00:02:25
#
#        total_product_quantity  entegration invoice_city invoice_country  \
# 0                           1     trendyol     İstanbul             NaN
# 1                           7     trendyol     İstanbul             NaN
# 2                           1     trendyol       Ankara             NaN
# 3                           2     trendyol     İstanbul             NaN
# 4                           1     trendyol        Sivas             NaN
# ...                       ...          ...          ...             ...
# 92285                       1     trendyol       Samsun             NaN
# 92286                       1     trendyol        Çorum             NaN
# 92287                       1  HepsiBurada        İzmir             NaN
# 92288                       1     trendyol        Konya             NaN
# 92289                       1     trendyol     İstanbul             NaN
#
#          total     tax  grand_total          company     cargo_company  \
# 0      391.670  78.330       470.00      ali özdemir  trendyolekspress
# 1      395.530  48.470       444.00      Tuğba Sayar  trendyolekspress
# 2      165.830  33.170       199.00        Tuba Koca  trendyolekspress
# 3      215.830  43.170       259.00       Doğa Özkan  trendyolekspress
# 4      181.820  18.180       200.00      Damla Beşer  trendyolekspress
# ...        ...     ...          ...              ...               ...
# 92285  133.330  26.670       160.00     Gülizar Sarı  trendyolekspress
# 92286  154.170  30.830       185.00  zübeyde DEMİREL  trendyolekspress
# 92287   33.325   6.665        39.99       İrem Erbey          hepsijet
# 92288  142.500  28.500       171.00    Esma Söylemez  trendyolekspress
# 92289  772.730  77.270       850.00    ayse muhammed  trendyolekspress
#
#       status_name
# 0       Onaylandı
# 1       Onaylandı
# 2       Onaylandı
# 3       Onaylandı
# 4       Onaylandı
# ...           ...
# 92285   Onaylandı
# 92286   Onaylandı
# 92287   Onaylandı
# 92288   Onaylandı
# 92289   Onaylandı
#
# [92290 rows x 15 columns]

# %%
df_entegra_select_var.loc[:,'datetime'] = pd.to_datetime(df_entegra_select_var.loc[:,'datetime'], format='%Y-%m-%d %H:%M:%S')
df_entegra_select_var.head(5)
# Out:
#   order_number   model pov_productcode  \
# 0   2383110310  003362             NaN
# 1   2383102583  004382             NaN
# 2   2383091113  001602             NaN
# 3   2383085464  001602             NaN
# 4   2383076067  002583    220647971025
#
#                                         product_name            datetime  \
# 0  6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö... 2024-09-05 10:54:27
# 1  Çok Amaçlı Multi İnce Temizlik Fırçası Derz Ar... 2024-09-05 10:50:42
# 2  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:43:15
# 3  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:40:26
# 4  Portatif Katlanabilir Masa, Piknik Masası, Kam... 2024-09-05 10:34:55
#
#    total_product_quantity entegration invoice_city invoice_country   total  \
# 0                       1    trendyol     İstanbul             NaN  391.67
# 1                       7    trendyol     İstanbul             NaN  395.53
# 2                       1    trendyol       Ankara             NaN  165.83
# 3                       2    trendyol     İstanbul             NaN  215.83
# 4                       1    trendyol        Sivas             NaN  181.82
#
#      tax  grand_total      company     cargo_company status_name
# 0  78.33        470.0  ali özdemir  trendyolekspress   Onaylandı
# 1  48.47        444.0  Tuğba Sayar  trendyolekspress   Onaylandı
# 2  33.17        199.0    Tuba Koca  trendyolekspress   Onaylandı
# 3  43.17        259.0   Doğa Özkan  trendyolekspress   Onaylandı
# 4  18.18        200.0  Damla Beşer  trendyolekspress   Onaylandı

# %%
df_entegra_select_var.insert(3,"date",pd.to_datetime(df_entegra_select_var["datetime"]).dt.date)
df_entegra_select_var.insert(4,"time",pd.to_datetime(df_entegra_select_var["datetime"]).dt.time)
df_entegra_select_var.head(5)
# Out:
#   order_number   model pov_productcode        date      time  \
# 0   2383110310  003362             NaN  2024-09-05  10:54:27
# 1   2383102583  004382             NaN  2024-09-05  10:50:42
# 2   2383091113  001602             NaN  2024-09-05  10:43:15
# 3   2383085464  001602             NaN  2024-09-05  10:40:26
# 4   2383076067  002583    220647971025  2024-09-05  10:34:55
#
#                                         product_name            datetime  \
# 0  6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö... 2024-09-05 10:54:27
# 1  Çok Amaçlı Multi İnce Temizlik Fırçası Derz Ar... 2024-09-05 10:50:42
# 2  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:43:15
# 3  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:40:26
# 4  Portatif Katlanabilir Masa, Piknik Masası, Kam... 2024-09-05 10:34:55
#
#    total_product_quantity entegration invoice_city invoice_country   total  \
# 0                       1    trendyol     İstanbul             NaN  391.67
# 1                       7    trendyol     İstanbul             NaN  395.53
# 2                       1    trendyol       Ankara             NaN  165.83
# 3                       2    trendyol     İstanbul             NaN  215.83
# 4                       1    trendyol        Sivas             NaN  181.82
#
#      tax  grand_total      company     cargo_company status_name
# 0  78.33        470.0  ali özdemir  trendyolekspress   Onaylandı
# 1  48.47        444.0  Tuğba Sayar  trendyolekspress   Onaylandı
# 2  33.17        199.0    Tuba Koca  trendyolekspress   Onaylandı
# 3  43.17        259.0   Doğa Özkan  trendyolekspress   Onaylandı
# 4  18.18        200.0  Damla Beşer  trendyolekspress   Onaylandı

# %%
object_columns = df_entegra_select_var.select_dtypes(include='object')
object_columns
# Out:
#       order_number   model   pov_productcode        date      time  \
# 0       2383110310  003362               NaN  2024-09-05  10:54:27
# 1       2383102583  004382               NaN  2024-09-05  10:50:42
# 2       2383091113  001602               NaN  2024-09-05  10:43:15
# 3       2383085464  001602               NaN  2024-09-05  10:40:26
# 4       2383076067  002583      220647971025  2024-09-05  10:34:55
# ...            ...     ...               ...         ...       ...
# 92285   2036971893  001603               NaN  2024-03-01  00:16:54
# 92286   2036970386  002429               NaN  2024-03-01  00:16:07
# 92287   0888556689  002369               NaN  2024-03-01  00:14:02
# 92288   2036956451  002284  yatak54896513739  2024-03-01  00:05:22
# 92289   2036952678  003418               NaN  2024-03-01  00:02:25
#
#                                             product_name  entegration  \
# 0      6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö...     trendyol
# 1      Çok Amaçlı Multi İnce Temizlik Fırçası Derz Ar...     trendyol
# 2      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ...     trendyol
# 3      Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ...     trendyol
# 4      Portatif Katlanabilir Masa, Piknik Masası, Kam...     trendyol
# ...                                                  ...          ...
# 92285  Pikas Ahşap Özel İsim Baskılı, Kare Kedi Köpek...     trendyol
# 92286           BTS3 Boyama Tuval Sayılı Set 25x35 Yunus     trendyol
# 92287  Küçük Çelik Uçlu Kedi Köpek Evcil Hayvan Tırna...  HepsiBurada
# 92288  Kalorifer Petek Radyatör Yatağı Kedi Geniş Ked...     trendyol
# 92289   Merinos Modern Line 3 Parça Battaniye Seti - Bej     trendyol
#
#       invoice_city invoice_country          company     cargo_company  \
# 0         İstanbul             NaN      ali özdemir  trendyolekspress
# 1         İstanbul             NaN      Tuğba Sayar  trendyolekspress
# 2           Ankara             NaN        Tuba Koca  trendyolekspress
# 3         İstanbul             NaN       Doğa Özkan  trendyolekspress
# 4            Sivas             NaN      Damla Beşer  trendyolekspress
# ...            ...             ...              ...               ...
# 92285       Samsun             NaN     Gülizar Sarı  trendyolekspress
# 92286        Çorum             NaN  zübeyde DEMİREL  trendyolekspress
# 92287        İzmir             NaN       İrem Erbey          hepsijet
# 92288        Konya             NaN    Esma Söylemez  trendyolekspress
# 92289     İstanbul             NaN    ayse muhammed  trendyolekspress
#
#       status_name
# 0       Onaylandı
# 1       Onaylandı
# 2       Onaylandı
# 3       Onaylandı
# 4       Onaylandı
# ...           ...
# 92285   Onaylandı
# 92286   Onaylandı
# 92287   Onaylandı
# 92288   Onaylandı
# 92289   Onaylandı
#
# [92290 rows x 12 columns]

# %%
for column in object_columns.columns:
    df_entegra_select_var.loc[:,f"{column}"] = df_entegra_select_var.loc[:,f"{column}"].apply(lambda x: convert_one_character_letter(x))
    df_entegra_select_var.loc[:,f"{column}"] = df_entegra_select_var.loc[:,f"{column}"].apply(lambda x: whitespace_del(x))
    df_entegra_select_var.loc[:,f"{column}"] = df_entegra_select_var.loc[:,f"{column}"].apply(lambda x: title_func(x))
    
df_entegra_select_var.head(10)
# Out:
#   order_number   model       pov_productcode        date      time  \
# 0   2383110310  003362                   Nan  2024-09-05  10:54:27
# 1   2383102583  004382                   Nan  2024-09-05  10:50:42
# 2   2383091113  001602                   Nan  2024-09-05  10:43:15
# 3   2383085464  001602                   Nan  2024-09-05  10:40:26
# 4   2383076067  002583          220647971025  2024-09-05  10:34:55
# 5   2383074871  001602                   Nan  2024-09-05  10:34:41
# 6   2383069120  002643          290894121988  2024-09-05  10:30:18
# 7   2383066275  002263  Ayk8683372407015Çkmk  2024-09-05  10:29:26
# 8   4575428431  003548                   Nan  2024-09-05  10:28:49
# 9   2383064808  004159                   Nan  2024-09-05  10:28:11
#
#                                         product_name            datetime  \
# 0  6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö... 2024-09-05 10:54:27
# 1  Çok Amaçlı Multi İnce Temizlik Fırçası Derz Ar... 2024-09-05 10:50:42
# 2  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:43:15
# 3  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:40:26
# 4  Portatif Katlanabilir Masa, Piknik Masası, Kam... 2024-09-05 10:34:55
# 5  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ... 2024-09-05 10:34:41
# 6        Kaymaz Taban Tekli Post Peluş Banyo Paspası 2024-09-05 10:30:18
# 7  İksa Devrilmez Ayaklı Portatif Kamp Ocağı, Pik... 2024-09-05 10:29:26
# 8  Yüzük Zikirmatik Karışık Renk, Yeni Nesil Ziki... 2024-09-05 10:28:49
# 9  Spider Örümcek Oyun Çadırı Çift Yönlü Giriş Çı... 2024-09-05 10:28:11
#
#    total_product_quantity  entegration invoice_city invoice_country     total  \
# 0                       1     Trendyol     İstanbul             Nan  391.6700
# 1                       7     Trendyol     İstanbul             Nan  395.5300
# 2                       1     Trendyol       Ankara             Nan  165.8300
# 3                       2     Trendyol     İstanbul             Nan  215.8300
# 4                       1     Trendyol        Sivas             Nan  181.8200
# 5                       1     Trendyol      Denizli             Nan  165.8300
# 6                       1     Trendyol        Bursa             Nan   90.0000
# 7                       1     Trendyol       Ankara             Nan  304.1700
# 8                       2  Hepsiburada       Samsun             Nan   49.9833
# 9                       1     Trendyol       Mersin             Nan  329.1700
#
#        tax  grand_total               company     cargo_company status_name
# 0  78.3300       470.00           Ali Özdemir  Trendyolekspress   Onaylandı
# 1  48.4700       444.00           Tuğba Sayar  Trendyolekspress   Onaylandı
# 2  33.1700       199.00             Tuba Koca  Trendyolekspress   Onaylandı
# 3  43.1700       259.00            Doğa Özkan  Trendyolekspress   Onaylandı
# 4  18.1800       200.00           Damla Beşer  Trendyolekspress   Onaylandı
# 5  33.1700       199.00        Sare Hacer Var  Trendyolekspress   Onaylandı
# 6   9.0000        99.00          Safinaz Dinç  Trendyolekspress   Onaylandı
# 7  60.8300       365.00         Şeyma Ödemi̇ş               Mng   Onaylandı
# 8   9.9967        59.98  Zeynep Rana Karaağaç          Hepsijet   Onaylandı
# 9  65.8300       395.00           Senem Cekli  Trendyolekspress   Onaylandı

# %% [markdown]
# ##### Entegra Products

# %%
df_product_master = pd.read_excel(r"C:\Users\user\Desktop\Data Analysis\Adoba\Sales_Report\Data\Entegra\Product Name\Master\Entegra Model Product Name Update (19.09.2024).xlsx")
df_product_master
# Out:
#        model                                       product_name
# 0     003362  6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö...
# 1     001602  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ...
# 2     003954                   Awox Barmix Çubuk Blender 1000 W
# 3     004286  Awox Orbit Gizli Rezistanslı Su Isıtıcı Kettle...
# 4     002656    Sprey Başlıklı Amber Cam 10 Ml Boş - Yedek Şişe
# ...      ...                                                ...
# 1258  003249  Merinos Relax Çift Kişilik  Battaniye Color Li...
# 1259  004303  Procli̇s Deve Dikeni Yağı %100 Doğal Bitkisel ...
# 1260  003060  Merinos Eternity Fitilli Peluş Çift Kişilik Ne...
# 1261  003593  Zirkon Taşlı Çelik Dünya Gezegen Gold Kolye, K...
# 1262  004005  Led Aplik Aydınlatma Çift Taraflı Led Dekorati...
#
# [1263 rows x 2 columns]

# %%
# df_entegra_select_product = df_entegra_select_var[["model","pov_productcode","product_name"]]
df_entegra_select_product = df_entegra_select_var[["model","product_name"]]
df_entegra_select_product
# Out:
#         model                                       product_name
# 0      003362  6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö...
# 1      004382  Çok Amaçlı Multi İnce Temizlik Fırçası Derz Ar...
# 2      001602  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ...
# 3      001602  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ...
# 4      002583  Portatif Katlanabilir Masa, Piknik Masası, Kam...
# ...       ...                                                ...
# 92285  001603  Pikas Ahşap Özel İsim Baskılı, Kare Kedi Köpek...
# 92286  002429           Bts3 Boyama Tuval Sayılı Set 25X35 Yunus
# 92287  002369  Küçük Çelik Uçlu Kedi Köpek Evcil Hayvan Tırna...
# 92288  002284  Kalorifer Petek Radyatör Yatağı Kedi Geniş Ked...
# 92289  003418   Merinos Modern Line 3 Parça Battaniye Seti - Bej
#
# [92290 rows x 2 columns]

# %%
df_entegra_select_product["model"].nunique()
# Out:
# 975

# %%
df_entegra_select_product["product_name"].nunique()
# Out:
# 993

# %%
df_entegra_select_product[df_entegra_select_product.duplicated()]
# Out:
#         model                                       product_name
# 3      001602  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ...
# 5      001602  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ...
# 10     002583  Portatif Katlanabilir Masa, Piknik Masası, Kam...
# 11     003548  Yüzük Zikirmatik Karışık Renk, Yeni Nesil Ziki...
# 12     001602  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ...
# ...       ...                                                ...
# 92285  001603  Pikas Ahşap Özel İsim Baskılı, Kare Kedi Köpek...
# 92286  002429           Bts3 Boyama Tuval Sayılı Set 25X35 Yunus
# 92287  002369  Küçük Çelik Uçlu Kedi Köpek Evcil Hayvan Tırna...
# 92288  002284  Kalorifer Petek Radyatör Yatağı Kedi Geniş Ked...
# 92289  003418   Merinos Modern Line 3 Parça Battaniye Seti - Bej
#
# [91290 rows x 2 columns]

# %%
df_entegra_select_product = df_entegra_select_product.drop_duplicates()
df_entegra_select_product
# Out:
#         model                                       product_name
# 0      003362  6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, 6 Gö...
# 1      004382  Çok Amaçlı Multi İnce Temizlik Fırçası Derz Ar...
# 2      001602  Ahşap Özel İsim Baskılı, Oval Kedi Köpek Mama ...
# 4      002583  Portatif Katlanabilir Masa, Piknik Masası, Kam...
# 6      002643        Kaymaz Taban Tekli Post Peluş Banyo Paspası
# ...       ...                                                ...
# 91758  001656      Guard Mat Siyah Klasik Deri Erkek Cüzdanı 171
# 91791  003412  Levi Çift Kişilik Keten Yatak Örtüsü, Çift Kiş...
# 91838  004034                           Kadın Erkek Desenli 4034
# 91903  002586                Bts20 Boyama Tuval Sayılı Set 25X35
# 92266  001718  Pikas Sesli Home Pamuklu Erkek Çocuk Bebek Bat...
#
# [1000 rows x 2 columns]

# %%
master_model = set(df_product_master["model"])
new_model = set(df_entegra_select_product["model"])

# %%
new_model_list = list(new_model.difference(master_model))

# %%
df_entegra_select_new_product = df_entegra_select_product[df_entegra_select_product["model"].isin(new_model_list)]
df_entegra_select_new_product.reset_index(drop=True, inplace=True)
df_entegra_select_new_product
# Out:
# Empty DataFrame
# Columns: [model, product_name]
# Index: []

# %%
# df_entegra_select_new_product.to_excel(fr"{output_path}\Entegra Model New Product Name ({variable_date}).xlsx", index=False)  # Adoba..Data Folder

# %% [markdown]
# #### Location

# %%
def reverse_geocoding(lat, lon):
    '''This function is used for giving city or country name from longitude latitude value \n
    reverse_geocoding(lat, lon): lat is geographical lattitude and lon is geographical longitude \n
    ex. \n
    df['address'] = np.vectorize(reverse_geocoding)(df['Latitude'], df['Longitude'])'''
    try:
        location = geolocator.reverse(Point(lat, lon))
        return location.raw['display_name']
    except:
        return None

# %%
def findGeocode(city):
    '''This function is used for giving latitude and longitude values from city or country name \n
    findGeocode(city): city is a city or country \n
    ex. \n
    loc = findGeocode(i) \n 
    lat = loc.latitude \n
    lon = loc.longitude''' 
       
    # try and catch is used to overcome 
    # the exception thrown by geolocator 
    # using geocodertimedout   
    try: 
          
        # Specify the user_agent as your 
        # app name it should not be none 
        geolocator = Nominatim(user_agent="tesst") 
          
        return geolocator.geocode(city) 
      
    except GeocoderTimedOut: 
          
        return findGeocode(city)

# %%
df_city_location_master = pd.read_excel(r"C:\Users\user\Desktop\Data Analysis\Adoba\Sales_Report\Data\Geo Location\Master\Entegra City Location.xlsx")
df_city_location_master.drop("id", axis=1, inplace=True)
df_city_location_master
# Out:
#                city       country    invoice_city   latitude  longitude
# 0             Adana        Turkey           Adana  37.143800  35.498409
# 1          Adiyaman        Turkey        Adıyaman  37.763750  38.276348
# 2          Adiyaman        Turkey        Adiyaman  37.763750  38.276348
# 3    Afyonkarahisar        Turkey  Afyonkarahisar  38.685273  30.642741
# 4    Afyonkarahisar        Turkey           Afyon  38.685273  30.642741
# ..              ...           ...             ...        ...        ...
# 262           Yanbu  Saudi Arabia           Yanbu  24.094893  38.070525
# 263        Az Zulfi  Saudi Arabia           Zulfi  26.311619  44.832951
# 264        Qairawan       Tunisia        Qairawan  35.673549  10.098636
# 265        Al Khodh          Oman        Al Khodh  23.565997  58.118169
# 266      Almaabilah          Oman      Almaabilah  23.648131  58.146199
#
# [267 rows x 5 columns]

# %%
df_entegra_select_var["invoice_city"].nunique()
# Out:
# 267

# %%
df_entegra_select_var[df_entegra_select_var["invoice_city"] == "Nan"]
# Out:
#       order_number model pov_productcode        date      time product_name  \
# 42703        48014   Nan             Nan  2024-06-03  22:00:13          Nan
#
#                  datetime  total_product_quantity  entegration invoice_city  \
# 42703 2024-06-03 22:00:13                       0  Woocommerce          Nan
#
#       invoice_country  total  tax  grand_total company cargo_company  \
# 42703             Nan    0.0  0.0          0.0     Nan         Diger
#
#         status_name
# 42703  Yeni Siparis

# %%
nan_index = df_entegra_select_var[df_entegra_select_var["invoice_city"] == "Nan"].index[0]
nan_index
# Out:
# 42703

# %%
new_city = set(df_entegra_select_var["invoice_city"])
master_city = set(df_city_location_master["invoice_city"])
new_city_list = list(new_city.difference(master_city))
# new_city_list

# %%
df_entegra_city_select = df_entegra_select_var[df_entegra_select_var["invoice_city"].isin(new_city_list)]
df_entegra_city_select = df_entegra_city_select[["invoice_city", "invoice_country"]]
df_entegra_city_select = df_entegra_city_select.drop_duplicates(subset="invoice_city")
df_entegra_city_select = df_entegra_city_select.reset_index(drop=True)
df_entegra_city_select
# Out:
#                                          invoice_city  invoice_country
# 0                                          Dumbrăvița          Romanya
# 1                                          Bratislava         Slovakya
# 2                                           Sabirabad       Azerbaycan
# 3                                         Cluj-Napoca          Romanya
# 4                                      Ramnicu Valcea          Romanya
# 5                                       Oyoon Al Jawa  Suudi Arabistan
# 6                                               Cadca         Slovakya
# 7                                                Anak  Suudi Arabistan
# 8                                               Zalau          Romanya
# 9                                             Qurayat  Suudi Arabistan
# 10                                            Hawally           Kuveyt
# 11                                           Sanpetru          Romanya
# 12                                              Izmir              Nan
# 13                                            Slatina          Romanya
# 14                                        Târgu Mureș          Romanya
# 15                                           Ümraniye              Nan
# 16                                            Ciuslea          Romanya
# 17                                            Suceava          Romanya
# 18                                             Catina          Romanya
# 19                                             Düziçi              Nan
# 20                                            Arifiye              Nan
# 21                                              Kepez              Nan
# 22                                             Caklov         Slovakya
# 23                                            Bornova              Nan
# 24                                              Tovuz       Azerbaycan
# 25                                           Ataşehir              Nan
# 26                                             Pendik              Nan
# 27                                            Oyaynah  Suudi Arabistan
# 28                                             Muscat            Umman
# 29                                         Biljurashi  Suudi Arabistan
# 30  Necip Fazıl Mah. Dilektaşı Sk. No:1 Evidea Sit...              Nan
# 31                                    Darica Kocaeli̇              Nan
# 32                                          Bukeiriah  Suudi Arabistan
# 33                                           Al Wajba            Katar
# 34                                          Sharourah  Suudi Arabistan
# 35                                           Atasehir              Nan
# 36                                               İçel          Türkiye

# %%
# df_entegra_city_select.to_excel(fr"{output_path}\Entegra New City ({variable_date}).xlsx", index=False)

# %%
df_entegra_new_city_select = pd.read_excel(fr"{output_path}\Entegra New City Edit (01.04.2024-05.09.2024).xlsx")
df_entegra_new_city_select
# Out:
#       invoice_city  invoice_country
# 0       Dumbrăvița          Romanya
# 1       Bratislava         Slovakya
# 2        Sabirabad       Azerbaycan
# 3      Cluj-Napoca          Romanya
# 4   Ramnicu Valcea          Romanya
# 5    Oyoon Al Jawa  Suudi Arabistan
# 6            Cadca         Slovakya
# 7             Anak  Suudi Arabistan
# 8            Zalau          Romanya
# 9          Qurayat  Suudi Arabistan
# 10         Hawally           Kuveyt
# 11        Sanpetru          Romanya
# 12         Slatina          Romanya
# 13     Târgu Mureș          Romanya
# 14         Ciuslea          Romanya
# 15         Suceava          Romanya
# 16          Catina          Romanya
# 17          Caklov         Slovakya
# 18           Tovuz       Azerbaycan
# 19         Oyaynah  Suudi Arabistan
# 20          Muscat            Umman
# 21      Biljurashi  Suudi Arabistan
# 22       Bukeiriah  Suudi Arabistan
# 23        Al Wajba            Katar
# 24       Sharourah  Suudi Arabistan

# %%
new_city_list = list(df_entegra_new_city_select["invoice_city"])

# %%
geolocator = Nominatim(user_agent="test")

# each value from city column 
# will be fetched and sent to 
# function find_geocode  
city = [] 
latitude = [] 
longitude = []

# for i in (df_entegra_city_select["invoice_city"]):
for i in new_city_list: 
      
    if findGeocode(i) != None: 
           
        loc = findGeocode(i) 
          
        # coordinates returned from  
        # function is stored into 
        # two separate list 
        city.append(i)
        latitude.append(loc.latitude) 
        longitude.append(loc.longitude) 
       
    # if coordinate for a city not 
    # found, insert "NaN" indicating  
    # missing value  
    else:
        city.append(np.nan) 
        latitude.append(np.nan) 
        longitude.append(np.nan)

# %%
df_entegra_new_city_select["latitude"] = latitude
df_entegra_new_city_select["longitude"] = longitude 
df_entegra_new_city_select
# Out:
#       invoice_city  invoice_country   latitude   longitude
# 0       Dumbrăvița          Romanya  45.801876   21.247858
# 1       Bratislava         Slovakya  48.159260   17.139659
# 2        Sabirabad       Azerbaycan  39.889001   48.795703
# 3      Cluj-Napoca          Romanya  46.769379   23.589954
# 4   Ramnicu Valcea          Romanya  45.103173   24.364721
# 5    Oyoon Al Jawa  Suudi Arabistan        NaN         NaN
# 6            Cadca         Slovakya  49.437515   18.789604
# 7             Anak  Suudi Arabistan  16.223299  121.657201
# 8            Zalau          Romanya  10.392447    9.012325
# 9          Qurayat  Suudi Arabistan  23.261044   58.920269
# 10         Hawally           Kuveyt  29.327117   48.025982
# 11        Sanpetru          Romanya  45.706642   25.632262
# 12         Slatina          Romanya  44.428062   24.367630
# 13     Târgu Mureș          Romanya  46.544625   24.561196
# 14         Ciuslea          Romanya  45.786369   27.311497
# 15         Suceava          Romanya  47.532653   25.834594
# 16          Catina          Romanya  37.502361   15.087372
# 17          Caklov         Slovakya  48.897998   21.614496
# 18           Tovuz       Azerbaycan  40.992505   45.615943
# 19         Oyaynah  Suudi Arabistan  26.375524   50.184079
# 20          Muscat            Umman  23.588202   58.382945
# 21      Biljurashi  Suudi Arabistan  19.859444   41.557222
# 22       Bukeiriah  Suudi Arabistan        NaN         NaN
# 23        Al Wajba            Katar  25.282517   51.500305
# 24       Sharourah  Suudi Arabistan        NaN         NaN

# %%
# df_entegra_new_city_select.to_excel(fr"{output_path}\Entegra New City Location ({variable_date}).xlsx", index=False)  # Adoba..Data Folder
