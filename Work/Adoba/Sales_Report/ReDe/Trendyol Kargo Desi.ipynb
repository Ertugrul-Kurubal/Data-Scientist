# %% [markdown]
# ### Trendyol Kargo Desi

# %%
# pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
df_kargo = pd.read_excel(r"C:\Users\user\Downloads\trendyol kargo.xlsx")
df_kargo
# Out:
#                   Barkod    Paket No                 Kargo Firması  \
# 0      97815659247966334  1935755636  Trendyol Express Marketplace
# 1          ALS3463102806  1935764998  Trendyol Express Marketplace
# 2           604808214197  1935781088         MNG Kargo Marketplace
# 3         ÇG742305202381  1935783700         MNG Kargo Marketplace
# 4           868407600769  1935789958         MNG Kargo Marketplace
# ...                  ...         ...                           ...
# 88791       003548003548  2306175520  Trendyol Express Marketplace
# 88792      8680998014047  2306177666  Trendyol Express Marketplace
# 88793     78541216497852  2306187379  Trendyol Express Marketplace
# 88794       604808214180  2306187379  Trendyol Express Marketplace
# 88795      6965447810015  2306194062                           NaN
#
#        Sipariş Numarası        İl       İlçe  \
# 0            8061482665     Aydın  Germencik
# 1            2424519644  Adıyaman    Gölbaşı
# 2            8061494292  İstanbul   Çekmeköy
# 3            2424528751  İstanbul    Kadıköy
# 4            8061497847  İstanbul   Ümraniye
# ...                 ...       ...        ...
# 88791        9381935071  Tekirdağ  Çerkezköy
# 88792        9381935705    Bitlis  Adilcevaz
# 88793        9381946692  İstanbul     Pendik
# 88794        9381946692  İstanbul     Pendik
# 88795        9381952726   Malatya  Yeşilyurt
#
#                                                 Ürün Adı  Komisyon Oranı  \
# 0      6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, Sakl...           20.34
# 1      3'lü Çok Amaçlı Kutu Mega Çizgili Kahverengi 6...           16.20
# 2      Ahşap Özel İsim Baskılı, Kare Kedi Köpek Mama ...           18.31
# 3      Çg74 Ahşap Çocuk Makyaj Masası Tabureli,unicor...           16.27
# 4      Çömlek Ayaklı Sırlı Seramik Kedi Maması Kabı 2...           18.31
# ...                                                  ...             ...
# 88791  Yüzük Zikirmatik Karışık Renk, Yeni Nesil Ziki...           22.50
# 88792    Rosegold Kafija Kahve Makinesi KAFİJA, one size           11.00
# 88793  Aralıklı Plastik kedi Kumu Küreği,Temizleme El...             NaN
# 88794  Ahşap Özel Isim Baskılı, Oval Kedi Köpek Mama ...             NaN
# 88795  Sprey Mop Deterjan Hazneli 4 Adet Moplu Spreyl...             NaN
#
#           Marka  Adet  Birim Fiyatı  Satış Tutarı  İndirim Tutarı  \
# 0       ALİTECH     1        375.00        375.00             0.0
# 1          ALAS     1        350.00        350.00             0.0
# 2       GOBYPET     1        149.00        149.00             0.0
# 3      ROZİTOYS     1       1200.00       1200.00             0.0
# 4       GOBYPET     1        160.00        160.00             0.0
# ...         ...   ...           ...           ...             ...
# 88791     Pikas     1         29.99         29.99             0.0
# 88792      AWOX     1        740.00        740.00             0.0
# 88793   GOBYPET     1         31.00         31.00             2.7
# 88794   GOBYPET     1        199.00        199.00            17.3
# 88795     Pikas     1        300.00        300.00             0.0
#
#        Trendyol İndirim Tutarı  Faturalanacak Tutar  Kargodan alınan desi  \
# 0                          0.0               375.00                   9.0
# 1                          0.0               350.00                  10.0
# 2                          0.0               149.00                   2.0
# 3                          0.0              1200.00                  10.0
# 4                          0.0               160.00                   4.0
# ...                        ...                  ...                   ...
# 88791                      0.0                29.99                   NaN
# 88792                      0.0               740.00                   NaN
# 88793                      0.0                28.30                   NaN
# 88794                      0.0               181.70                   NaN
# 88795                      0.0               300.00                   NaN
#
#           Faturalanan Kargo Tutarı
# 0                            97.62
# 1                           103.37
# 2                            35.49
# 3                           112.79
# 4                            71.99
# ...                            ...
# 88791  Henüz fatura kesilmemiştir.
# 88792  Henüz fatura kesilmemiştir.
# 88793  Henüz fatura kesilmemiştir.
# 88794  Henüz fatura kesilmemiştir.
# 88795  Henüz fatura kesilmemiştir.
#
# [88796 rows x 17 columns]

# %%
df_kargo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88796 entries, 0 to 88795
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Barkod                    88796 non-null  object
#  1   Paket No                  88796 non-null  int64
#  2   Kargo Firması             88795 non-null  object
#  3   Sipariş Numarası          88796 non-null  int64
#  4   İl                        88796 non-null  object
#  5   İlçe                      88796 non-null  object
#  6   Ürün Adı                  88796 non-null  object
#  7   Komisyon Oranı            88792 non-null  float64
#  8   Marka                     88678 non-null  object
#  9   Adet                      88796 non-null  int64
#  10  Birim Fiyatı              88796 non-null  float64
#  11  Satış Tutarı              88796 non-null  float64
#  12  İndirim Tutarı            88796 non-null  float64
#  13  Trendyol İndirim Tutarı   88796 non-null  float64
#  14  Faturalanacak Tutar       88796 non-null  float64
#  15  Kargodan alınan desi      84972 non-null  float64
#  16  Faturalanan Kargo Tutarı  88796 non-null  object
# dtypes: float64(7), int64(3), object(7)
# memory usage: 11.5+ MB

# %%
df_kargo.columns
# Out:
# Index(['Barkod', 'Paket No', 'Kargo Firması', 'Sipariş Numarası', 'İl', 'İlçe',
#        'Ürün Adı', 'Komisyon Oranı', 'Marka', 'Adet', 'Birim Fiyatı',
#        'Satış Tutarı', 'İndirim Tutarı', 'Trendyol İndirim Tutarı',
#        'Faturalanacak Tutar', 'Kargodan alınan desi',
#        'Faturalanan Kargo Tutarı'],
#       dtype='object')

# %%
df_kargo2 = df_kargo.drop_duplicates(subset="Paket No")
df_kargo2 = df_kargo2.reset_index(drop=True)
df_kargo2
# Out:
#                   Barkod    Paket No                 Kargo Firması  \
# 0      97815659247966334  1935755636  Trendyol Express Marketplace
# 1          ALS3463102806  1935764998  Trendyol Express Marketplace
# 2           604808214197  1935781088         MNG Kargo Marketplace
# 3         ÇG742305202381  1935783700         MNG Kargo Marketplace
# 4           868407600769  1935789958         MNG Kargo Marketplace
# ...                  ...         ...                           ...
# 80164       220647971025  2306162294  Trendyol Express Marketplace
# 80165       003548003548  2306175520  Trendyol Express Marketplace
# 80166      8680998014047  2306177666  Trendyol Express Marketplace
# 80167     78541216497852  2306187379  Trendyol Express Marketplace
# 80168      6965447810015  2306194062                           NaN
#
#        Sipariş Numarası        İl       İlçe  \
# 0            8061482665     Aydın  Germencik
# 1            2424519644  Adıyaman    Gölbaşı
# 2            8061494292  İstanbul   Çekmeköy
# 3            2424528751  İstanbul    Kadıköy
# 4            8061497847  İstanbul   Ümraniye
# ...                 ...       ...        ...
# 80164        9381922979   Kütahya   Tavşanlı
# 80165        9381935071  Tekirdağ  Çerkezköy
# 80166        9381935705    Bitlis  Adilcevaz
# 80167        9381946692  İstanbul     Pendik
# 80168        9381952726   Malatya  Yeşilyurt
#
#                                                 Ürün Adı  Komisyon Oranı  \
# 0      6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, Sakl...           20.34
# 1      3'lü Çok Amaçlı Kutu Mega Çizgili Kahverengi 6...           16.20
# 2      Ahşap Özel İsim Baskılı, Kare Kedi Köpek Mama ...           18.31
# 3      Çg74 Ahşap Çocuk Makyaj Masası Tabureli,unicor...           16.27
# 4      Çömlek Ayaklı Sırlı Seramik Kedi Maması Kabı 2...           18.31
# ...                                                  ...             ...
# 80164  Portatif Katlanabilir Masa, Piknik Masası, Kam...           12.50
# 80165  Yüzük Zikirmatik Karışık Renk, Yeni Nesil Ziki...           22.50
# 80166    Rosegold Kafija Kahve Makinesi KAFİJA, one size           11.00
# 80167  Aralıklı Plastik kedi Kumu Küreği,Temizleme El...             NaN
# 80168  Sprey Mop Deterjan Hazneli 4 Adet Moplu Spreyl...             NaN
#
#           Marka  Adet  Birim Fiyatı  Satış Tutarı  İndirim Tutarı  \
# 0       ALİTECH     1        375.00        375.00             0.0
# 1          ALAS     1        350.00        350.00             0.0
# 2       GOBYPET     1        149.00        149.00             0.0
# 3      ROZİTOYS     1       1200.00       1200.00             0.0
# 4       GOBYPET     1        160.00        160.00             0.0
# ...         ...   ...           ...           ...             ...
# 80164     Pikas     1        200.00        200.00             0.0
# 80165     Pikas     1         29.99         29.99             0.0
# 80166      AWOX     1        740.00        740.00             0.0
# 80167   GOBYPET     1         31.00         31.00             2.7
# 80168     Pikas     1        300.00        300.00             0.0
#
#        Trendyol İndirim Tutarı  Faturalanacak Tutar  Kargodan alınan desi  \
# 0                          0.0               375.00                   9.0
# 1                          0.0               350.00                  10.0
# 2                          0.0               149.00                   2.0
# 3                          0.0              1200.00                  10.0
# 4                          0.0               160.00                   4.0
# ...                        ...                  ...                   ...
# 80164                      0.0               200.00                   NaN
# 80165                      0.0                29.99                   NaN
# 80166                      0.0               740.00                   NaN
# 80167                      0.0                28.30                   NaN
# 80168                      0.0               300.00                   NaN
#
#           Faturalanan Kargo Tutarı
# 0                            97.62
# 1                           103.37
# 2                            35.49
# 3                           112.79
# 4                            71.99
# ...                            ...
# 80164  Henüz fatura kesilmemiştir.
# 80165  Henüz fatura kesilmemiştir.
# 80166  Henüz fatura kesilmemiştir.
# 80167  Henüz fatura kesilmemiştir.
# 80168  Henüz fatura kesilmemiştir.
#
# [80169 rows x 17 columns]

# %% [markdown]
# #### Duplicated

# %%
df_prod_barkod = df_kargo2[["Barkod","Ürün Adı"]]
df_prod_barkod = df_prod_barkod.drop_duplicates()
df_prod_barkod = df_prod_barkod.reset_index(drop=True)
df_prod_barkod
# Out:
#                     Barkod                                           Ürün Adı
# 0        97815659247966334  6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, Sakl...
# 1            ALS3463102806  3'lü Çok Amaçlı Kutu Mega Çizgili Kahverengi 6...
# 2             604808214197  Ahşap Özel İsim Baskılı, Kare Kedi Köpek Mama ...
# 3           ÇG742305202381  Çg74 Ahşap Çocuk Makyaj Masası Tabureli,unicor...
# 4             868407600769  Çömlek Ayaklı Sırlı Seramik Kedi Maması Kabı 2...
# ...                    ...                                                ...
# 1681          868407601703  Makaralı Otomatik 5 Metre Geri Çekilebilen Ked...
# 1682  AYK8683372407015ÇKMK  İksa Devrilmez Ayaklı Portatif Kamp Ocağı, Pik...
# 1683    TYBE094QYA434T8008  Orijinal Sayaçlı El Yayı 60 Kg - 5 Kg Ayarlana...
# 1684          004263164634  Motivasyonel Su Matarası Su Şişesi Suluk 900 m...
# 1685         8787543541093  Gökkuşağı Kedi- Köpek Göğüs Tasması+gezdirme 0...
#
# [1686 rows x 2 columns]

# %%
df_prod_barkod["Ürün Adı"].nunique()
# Out:
# 1470

# %%
df_barkod_sort = df_prod_barkod.sort_values(by="Barkod")
df_barkod_sort = df_barkod_sort.reset_index(drop=True)
df_barkod_sort
# Out:
#                     Barkod                                           Ürün Adı
# 0             000416648254  Pembe Ahşap Kaydıraklı Oyun Evi, Ahşap Oyun Ev...
# 1             000437943412  Çamaşır Kurutma Makinası İçin Uçucu Yağlar Set...
# 2         0006941057446691  Hayvanlı Kumsuz Hacıyatmaz Kaplan 98 Cm X 44 C...
# 3             002154600346  Dekoratif Salyangoz Jüt Dokuma Bardak Altlığı,...
# 4            0021547145646  Su Sıvı Geçirmez Yıkanabilir Hasta Yaşlı Bakım...
# ...                    ...                                                ...
# 1681        ÇG842302202341  Çg84 Yeşil Ahşap Ledli Çocuk Mutfağı Pembe, Ah...
# 1682        ÇG912305202332  Çg91 Pembe Ahşap Ledli Çocuk Mutfağı Pembe, Ah...
# 1683        ÇG912305202332  Çg91 Pembe Ahşap Ledli Çocuk Mutfağı Pembe, Ah...
# 1684  ÇakmakGazı11042023-4  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 3'lü Se...
# 1685  ÇakmakGazı11042023-6  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 5'li Se...
#
# [1686 rows x 2 columns]

# %%
df_barkod_sort.to_excel(r"C:\Users\user\Downloads\Trendyol Kargo Ürün Barkod.xlsx", index=False)

# %%
df_barkod_sort_dup =  df_barkod_sort[df_barkod_sort["Barkod"].duplicated(keep=False)]
# df_barkod_sort_dup = df_barkod_sort[df_barkod_sort["Barkod"].duplicated()]
df_barkod_sort_dup
# Out:
#               Barkod                                           Ürün Adı
# 31     003084gri8400  Pencereli Kazak Hurcu 45x40x30 Gri 003084, one...
# 32     003084gri8400  Pencereli Kazak Hurcu Gri 45x40x30 - Kahvereng...
# 70    00341894644531  Modern Line 3 Parça Battaniye Seti - Bej 00341...
# 71    00341894644531  Modern Line 3 Parça Battaniye Seti - Bej 86825...
# 112     003562479456  Sole 750 W Mini Tost Makinesi, Seramik Kaplama...
# ...              ...                                                ...
# 1679  ÇG832305202312  Çg83 Pembe Ahşap Çocuk Mutfağı Pembe, Ahşap Mu...
# 1680  ÇG842302202341  Çg84 Yeşil Ahşap Ledli Çocuk Mutfağı Pembe, Ah...
# 1681  ÇG842302202341  Çg84 Yeşil Ahşap Ledli Çocuk Mutfağı Pembe, Ah...
# 1682  ÇG912305202332  Çg91 Pembe Ahşap Ledli Çocuk Mutfağı Pembe, Ah...
# 1683  ÇG912305202332  Çg91 Pembe Ahşap Ledli Çocuk Mutfağı Pembe, Ah...
#
# [408 rows x 2 columns]

# %%
df_barkod_sort_dup.to_excel(r"C:\Users\user\Downloads\Trendyol Kargo Barkod Tekrar.xlsx", index=False)

# %%
df_prod_sort = df_prod_barkod.sort_values(by="Ürün Adı")
df_prod_sort = df_prod_sort.reset_index(drop=True)
df_prod_sort
# Out:
#                   Barkod                                           Ürün Adı
# 0        yüz487514280114  %100 Doğal Keçi Kılı Yüz Bakım Fırçası, Yüz Ba...
# 1          8684076009987  %100 Doğal Sarı Kantaron Yağı 50 ml TYCCV4VKIN...
# 2          8684076000083  %100 Doğal Soğuk Sıkım Sabit Çörekotu Yağı, Bl...
# 3          8684076000076  %100 Doğal Çam Terebentin Yağı, Pine Turpentin...
# 4          2997778555322  0-3 Yaş Zeka Kartları Dokun Hisset Tanı Eğitim...
# ...                  ...                                                ...
# 1681           985524140  Şişme Tabanlı 3 Boğumlu Sunset Havuz 114x25 cm...
# 1682  TYBHIT32Q6PE8REX10  Şişme Tabanlı 3 Boğumlu Sunset Havuz 114x25 cm...
# 1683      EDOT-0572-0016  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...
# 1684      EDOT-0572-0030  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...
# 1685      EDOT-0572-0007  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...
#
# [1686 rows x 2 columns]

# %%
df_prod_sort_dup = df_prod_sort[df_prod_sort["Ürün Adı"].duplicated(keep=False)]
# df_prod_sort_dup = df_prod_sort[df_prod_sort["Ürün Adı"].duplicated()]
df_prod_sort_dup
# Out:
#                    Barkod                                           Ürün Adı
# 67      8699243467620-LY3  3 Gözlü-bölmeli Çekmece Yeni Sezon Nano Teknol...
# 68      8699243467620-LY1  3 Gözlü-bölmeli Çekmece Yeni Sezon Nano Teknol...
# 69      8699243467620-LY1  3 Gözlü-bölmeli Çekmece Yeni Sezon Nano Teknol...
# 70      8699243467620-LY3  3 Gözlü-bölmeli Çekmece Yeni Sezon Nano Teknol...
# 78    3-8699243469945-LY1  3 Lü Çok Amaçlı Baza Kutusu Seti Yeni Sezon Su...
# ...                   ...                                                ...
# 1639          19369763297  Çömlek Ayaklı Sırlı Seramik Kedi Maması Kabı 0...
# 1663      798421352688941  İsme Özel, Yıkanabilir Kedi, Köpek Çadırı, Kol...
# 1664       11442012345647  İsme Özel, Yıkanabilir Kedi, Köpek Çadırı, Kol...
# 1665       11442012345647  İsme Özel, Yıkanabilir Kedi, Köpek Çadırı, Kol...
# 1666      798421352688941  İsme Özel, Yıkanabilir Kedi, Köpek Çadırı, Kol...
#
# [313 rows x 2 columns]

# %%
df_prod_sort_dup.to_excel(r"C:\Users\user\Downloads\Trendyol Kargo Ürün Tekrar.xlsx", index=False)

# %% [markdown]
# #### 1 Adet

# %%
df_kargo3 = df_kargo2[df_kargo2["Adet"] == 1]
df_kargo3 = df_kargo3.reset_index(drop=True)
df_kargo3
# Out:
#                   Barkod    Paket No                 Kargo Firması  \
# 0      97815659247966334  1935755636  Trendyol Express Marketplace
# 1          ALS3463102806  1935764998  Trendyol Express Marketplace
# 2           604808214197  1935781088         MNG Kargo Marketplace
# 3         ÇG742305202381  1935783700         MNG Kargo Marketplace
# 4           868407600769  1935789958         MNG Kargo Marketplace
# ...                  ...         ...                           ...
# 72465       220647971025  2306162294  Trendyol Express Marketplace
# 72466       003548003548  2306175520  Trendyol Express Marketplace
# 72467      8680998014047  2306177666  Trendyol Express Marketplace
# 72468     78541216497852  2306187379  Trendyol Express Marketplace
# 72469      6965447810015  2306194062                           NaN
#
#        Sipariş Numarası        İl       İlçe  \
# 0            8061482665     Aydın  Germencik
# 1            2424519644  Adıyaman    Gölbaşı
# 2            8061494292  İstanbul   Çekmeköy
# 3            2424528751  İstanbul    Kadıköy
# 4            8061497847  İstanbul   Ümraniye
# ...                 ...       ...        ...
# 72465        9381922979   Kütahya   Tavşanlı
# 72466        9381935071  Tekirdağ  Çerkezköy
# 72467        9381935705    Bitlis  Adilcevaz
# 72468        9381946692  İstanbul     Pendik
# 72469        9381952726   Malatya  Yeşilyurt
#
#                                                 Ürün Adı  Komisyon Oranı  \
# 0      6 Kg Kapatsiteli Styles Gıda Ve Bakliyat, Sakl...           20.34
# 1      3'lü Çok Amaçlı Kutu Mega Çizgili Kahverengi 6...           16.20
# 2      Ahşap Özel İsim Baskılı, Kare Kedi Köpek Mama ...           18.31
# 3      Çg74 Ahşap Çocuk Makyaj Masası Tabureli,unicor...           16.27
# 4      Çömlek Ayaklı Sırlı Seramik Kedi Maması Kabı 2...           18.31
# ...                                                  ...             ...
# 72465  Portatif Katlanabilir Masa, Piknik Masası, Kam...           12.50
# 72466  Yüzük Zikirmatik Karışık Renk, Yeni Nesil Ziki...           22.50
# 72467    Rosegold Kafija Kahve Makinesi KAFİJA, one size           11.00
# 72468  Aralıklı Plastik kedi Kumu Küreği,Temizleme El...             NaN
# 72469  Sprey Mop Deterjan Hazneli 4 Adet Moplu Spreyl...             NaN
#
#           Marka  Adet  Birim Fiyatı  Satış Tutarı  İndirim Tutarı  \
# 0       ALİTECH     1        375.00        375.00             0.0
# 1          ALAS     1        350.00        350.00             0.0
# 2       GOBYPET     1        149.00        149.00             0.0
# 3      ROZİTOYS     1       1200.00       1200.00             0.0
# 4       GOBYPET     1        160.00        160.00             0.0
# ...         ...   ...           ...           ...             ...
# 72465     Pikas     1        200.00        200.00             0.0
# 72466     Pikas     1         29.99         29.99             0.0
# 72467      AWOX     1        740.00        740.00             0.0
# 72468   GOBYPET     1         31.00         31.00             2.7
# 72469     Pikas     1        300.00        300.00             0.0
#
#        Trendyol İndirim Tutarı  Faturalanacak Tutar  Kargodan alınan desi  \
# 0                          0.0               375.00                   9.0
# 1                          0.0               350.00                  10.0
# 2                          0.0               149.00                   2.0
# 3                          0.0              1200.00                  10.0
# 4                          0.0               160.00                   4.0
# ...                        ...                  ...                   ...
# 72465                      0.0               200.00                   NaN
# 72466                      0.0                29.99                   NaN
# 72467                      0.0               740.00                   NaN
# 72468                      0.0                28.30                   NaN
# 72469                      0.0               300.00                   NaN
#
#           Faturalanan Kargo Tutarı
# 0                            97.62
# 1                           103.37
# 2                            35.49
# 3                           112.79
# 4                            71.99
# ...                            ...
# 72465  Henüz fatura kesilmemiştir.
# 72466  Henüz fatura kesilmemiştir.
# 72467  Henüz fatura kesilmemiştir.
# 72468  Henüz fatura kesilmemiştir.
# 72469  Henüz fatura kesilmemiştir.
#
# [72470 rows x 17 columns]

# %%
df_kargo3["Ürün Adı"].nunique()
# Out:
# 1437

# %%
df_kargo3["Barkod"].nunique()
# Out:
# 1425

# %%
df_kargo3.columns
# Out:
# Index(['Barkod', 'Paket No', 'Kargo Firması', 'Sipariş Numarası', 'İl', 'İlçe',
#        'Ürün Adı', 'Komisyon Oranı', 'Marka', 'Adet', 'Birim Fiyatı',
#        'Satış Tutarı', 'İndirim Tutarı', 'Trendyol İndirim Tutarı',
#        'Faturalanacak Tutar', 'Kargodan alınan desi',
#        'Faturalanan Kargo Tutarı'],
#       dtype='object')

# %% [markdown]
# #### Groupby

# %%
df_kargo_mean = df_kargo3.groupby("Ürün Adı")[["Kargodan alınan desi"]].mean()
df_kargo_mean.reset_index(inplace=True)
df_kargo_mean.rename(columns={"Kargodan alınan desi":"kargo desi ortalama"}, inplace=True)
df_kargo_mean["kargo desi ortalama"] = df_kargo_mean["kargo desi ortalama"].apply(lambda x: round(x,1))
df_kargo_mean
# Out:
#                                                Ürün Adı  kargo desi ortalama
# 0     %100 Doğal Keçi Kılı Yüz Bakım Fırçası, Yüz Ba...                  2.2
# 1     %100 Doğal Sarı Kantaron Yağı 50 ml TYCCV4VKIN...                  4.3
# 2     %100 Doğal Soğuk Sıkım Sabit Çörekotu Yağı, Bl...                  1.0
# 3     %100 Doğal Çam Terebentin Yağı, Pine Turpentin...                  2.0
# 4     0-3 Yaş Zeka Kartları Dokun Hisset Tanı Eğitim...                  4.0
# ...                                                 ...                  ...
# 1432  Şişme Tabanlı 3 Boğumlu Sunset Havuz 114x25 cm...                  2.2
# 1433  Şişme Tabanlı 3 Boğumlu Sunset Havuz 114x25 cm...                  2.0
# 1434  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...                  3.0
# 1435  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...                 10.0
# 1436  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...                  4.4
#
# [1437 rows x 2 columns]

# %%
df_kargo_max = df_kargo3.groupby("Ürün Adı")[["Kargodan alınan desi"]].max()
df_kargo_max.reset_index(inplace=True)
df_kargo_max.rename(columns={"Kargodan alınan desi":"kargo desi max"}, inplace=True)
df_kargo_max
# Out:
#                                                Ürün Adı  kargo desi max
# 0     %100 Doğal Keçi Kılı Yüz Bakım Fırçası, Yüz Ba...             5.0
# 1     %100 Doğal Sarı Kantaron Yağı 50 ml TYCCV4VKIN...             9.0
# 2     %100 Doğal Soğuk Sıkım Sabit Çörekotu Yağı, Bl...             1.0
# 3     %100 Doğal Çam Terebentin Yağı, Pine Turpentin...             2.0
# 4     0-3 Yaş Zeka Kartları Dokun Hisset Tanı Eğitim...            12.0
# ...                                                 ...             ...
# 1432  Şişme Tabanlı 3 Boğumlu Sunset Havuz 114x25 cm...             9.0
# 1433  Şişme Tabanlı 3 Boğumlu Sunset Havuz 114x25 cm...             2.0
# 1434  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...             3.0
# 1435  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...            10.0
# 1436  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...             6.0
#
# [1437 rows x 2 columns]

# %%
df_kargo_min = df_kargo3.groupby("Ürün Adı")[["Kargodan alınan desi"]].min()
df_kargo_min.reset_index(inplace=True)
df_kargo_min.rename(columns={"Kargodan alınan desi":"kargo desi min"}, inplace=True)
df_kargo_min
# Out:
#                                                Ürün Adı  kargo desi min
# 0     %100 Doğal Keçi Kılı Yüz Bakım Fırçası, Yüz Ba...             1.0
# 1     %100 Doğal Sarı Kantaron Yağı 50 ml TYCCV4VKIN...             2.0
# 2     %100 Doğal Soğuk Sıkım Sabit Çörekotu Yağı, Bl...             1.0
# 3     %100 Doğal Çam Terebentin Yağı, Pine Turpentin...             2.0
# 4     0-3 Yaş Zeka Kartları Dokun Hisset Tanı Eğitim...             1.0
# ...                                                 ...             ...
# 1432  Şişme Tabanlı 3 Boğumlu Sunset Havuz 114x25 cm...             1.0
# 1433  Şişme Tabanlı 3 Boğumlu Sunset Havuz 114x25 cm...             2.0
# 1434  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...             3.0
# 1435  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...            10.0
# 1436  Şönil Kilim Desenli Modern Halı (MAKİNADA YIKA...             3.0
#
# [1437 rows x 2 columns]

# %%
df_kargo4 = df_kargo3.sort_values(by="Barkod")
df_kargo4 = df_kargo4.reset_index(drop=True)
df_kargo4.head(5)
# Out:
#          Barkod    Paket No                 Kargo Firması  Sipariş Numarası  \
# 0  000416648254  2217440987  Trendyol Express Marketplace        9280609988
# 1  000416648254  2166714797  Trendyol Express Marketplace        9223437644
# 2  000416648254  2260600250  Trendyol Express Marketplace        9330452457
# 3  000416648254  2200142600  Trendyol Express Marketplace        9261352113
# 4  000416648254  2227011001  Trendyol Express Marketplace        9291384695
#
#          İl          İlçe                                           Ürün Adı  \
# 0  İstanbul  Küçükçekmece  Pembe Ahşap Kaydıraklı Oyun Evi, Ahşap Oyun Ev...
# 1  İstanbul         Fatih  Pembe Ahşap Kaydıraklı Oyun Evi, Ahşap Oyun Ev...
# 2  Osmaniye        Merkez  Pembe Ahşap Kaydıraklı Oyun Evi, Ahşap Oyun Ev...
# 3   Denizli  Merkezefendi  Pembe Ahşap Kaydıraklı Oyun Evi, Ahşap Oyun Ev...
# 4  İstanbul  Küçükçekmece  Pembe Ahşap Kaydıraklı Oyun Evi, Ahşap Oyun Ev...
#
#    Komisyon Oranı     Marka  Adet  Birim Fiyatı  Satış Tutarı  İndirim Tutarı  \
# 0            11.3  ROZİTOYS     1        1800.0        1800.0           100.0
# 1            13.5  ROZİTOYS     1        1850.0        1850.0             0.0
# 2            13.5  ROZİTOYS     1        1850.0        1850.0             0.0
# 3            13.5  ROZİTOYS     1        1900.0        1900.0             0.0
# 4            11.3  ROZİTOYS     1        1800.0        1800.0             0.0
#
#    Trendyol İndirim Tutarı  Faturalanacak Tutar  Kargodan alınan desi  \
# 0                      0.0               1700.0                  27.0
# 1                      0.0               1850.0                  26.0
# 2                      0.0               1850.0                  26.0
# 3                      0.0               1900.0                  10.0
# 4                      0.0               1800.0                  27.0
#
#   Faturalanan Kargo Tutarı
# 0                   206.58
# 1                   200.40
# 2                   200.40
# 3                   103.37
# 4                   206.58

# %%
df_kargo4 = df_kargo4.drop_duplicates(subset=["Barkod","Ürün Adı","Kargo Firması"])
df_kargo4.reset_index(drop=True, inplace=True)
df_kargo4
# Out:
#                     Barkod    Paket No                 Kargo Firması  \
# 0             000416648254  2217440987  Trendyol Express Marketplace
# 1             000437943412  2219946411  Trendyol Express Marketplace
# 2         0006941057446691  2134127003  Trendyol Express Marketplace
# 3         0006941057446691  2176825666         MNG Kargo Marketplace
# 4             002154600346  2116926027  Trendyol Express Marketplace
# ...                    ...         ...                           ...
# 2525  ÇakmakGazı11042023-4  2056764571         PTT Kargo Marketplace
# 2526  ÇakmakGazı11042023-4  2042258625         MNG Kargo Marketplace
# 2527  ÇakmakGazı11042023-6  2052439303         PTT Kargo Marketplace
# 2528  ÇakmakGazı11042023-6  2253264174     Yurtiçi Kargo Marketplace
# 2529  ÇakmakGazı11042023-6  2150698717         MNG Kargo Marketplace
#
#       Sipariş Numarası         İl          İlçe  \
# 0           9280609988   İstanbul  Küçükçekmece
# 1           9283284388   İstanbul      Bakırköy
# 2           9186967173   İstanbul    Başakşehir
# 3           9234601826  Eskişehir          Alpu
# 4           9167602070   İstanbul    Başakşehir
# ...                ...        ...           ...
# 2525        9103239074   Tekirdağ       Kapaklı
# 2526        9086468292  Çanakkale        Merkez
# 2527        9098432861      Niğde        Merkez
# 2528        9322073689   İstanbul    Beylikdüzü
# 2529        9206236310   İstanbul  Bahçelievler
#
#                                                Ürün Adı  Komisyon Oranı  \
# 0     Pembe Ahşap Kaydıraklı Oyun Evi, Ahşap Oyun Ev...           11.30
# 1     Çamaşır Kurutma Makinası İçin Uçucu Yağlar Set...           12.20
# 2     Hayvanlı Kumsuz Hacıyatmaz Kaplan 98 Cm X 44 C...           13.73
# 3     Hayvanlı Kumsuz Hacıyatmaz Kaplan 98 Cm X 44 C...           13.73
# 4     Dekoratif Salyangoz Jüt Dokuma Bardak Altlığı,...           19.32
# ...                                                 ...             ...
# 2525  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 3'lü Se...           16.27
# 2526  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 3'lü Se...           16.27
# 2527  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 5'li Se...           16.27
# 2528  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 5'li Se...           16.27
# 2529  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 5'li Se...           16.27
#
#          Marka  Adet  Birim Fiyatı  Satış Tutarı  İndirim Tutarı  \
# 0     ROZİTOYS     1       1800.00       1800.00           100.0
# 1      proclis     1        270.00        270.00             0.0
# 2        Intex     1        285.00        285.00             0.0
# 3        Intex     1        285.00        285.00             0.0
# 4        Pikas     1        249.99        249.99             0.0
# ...        ...   ...           ...           ...             ...
# 2525     Flash     1         86.43         86.43             0.0
# 2526     Flash     1         86.43         86.43             0.0
# 2527     Flash     1        162.70        162.70             0.0
# 2528     Flash     1        289.00        289.00             0.0
# 2529     Flash     1        289.00        289.00             0.0
#
#       Trendyol İndirim Tutarı  Faturalanacak Tutar  Kargodan alınan desi  \
# 0                         0.0              1700.00                  27.0
# 1                         0.0               270.00                   1.0
# 2                         0.0               285.00                   1.0
# 3                         0.0               285.00                   2.0
# 4                         0.0               249.99                   8.0
# ...                       ...                  ...                   ...
# 2525                      0.0                86.43                   2.0
# 2526                      0.0                86.43                   3.0
# 2527                      0.0               162.70                   2.0
# 2528                      0.0               289.00                   2.0
# 2529                      0.0               289.00                   3.0
#
#          Faturalanan Kargo Tutarı
# 0                          206.58
# 1                           53.34
# 2                           53.34
# 3                           58.79
# 4                           94.06
# ...                           ...
# 2525                        23.49
# 2526                        30.99
# 2527                        44.99
# 2528  Henüz fatura kesilmemiştir.
# 2529                        65.99
#
# [2530 rows x 17 columns]

# %%
df_kargo_min_merge = pd.merge(df_kargo4, df_kargo_min, how="left", on="Ürün Adı")
df_kargo_min_merge
# Out:
#                     Barkod    Paket No                 Kargo Firması  \
# 0             000416648254  2217440987  Trendyol Express Marketplace
# 1             000437943412  2219946411  Trendyol Express Marketplace
# 2         0006941057446691  2134127003  Trendyol Express Marketplace
# 3         0006941057446691  2176825666         MNG Kargo Marketplace
# 4             002154600346  2116926027  Trendyol Express Marketplace
# ...                    ...         ...                           ...
# 2525  ÇakmakGazı11042023-4  2056764571         PTT Kargo Marketplace
# 2526  ÇakmakGazı11042023-4  2042258625         MNG Kargo Marketplace
# 2527  ÇakmakGazı11042023-6  2052439303         PTT Kargo Marketplace
# 2528  ÇakmakGazı11042023-6  2253264174     Yurtiçi Kargo Marketplace
# 2529  ÇakmakGazı11042023-6  2150698717         MNG Kargo Marketplace
#
#       Sipariş Numarası         İl          İlçe  \
# 0           9280609988   İstanbul  Küçükçekmece
# 1           9283284388   İstanbul      Bakırköy
# 2           9186967173   İstanbul    Başakşehir
# 3           9234601826  Eskişehir          Alpu
# 4           9167602070   İstanbul    Başakşehir
# ...                ...        ...           ...
# 2525        9103239074   Tekirdağ       Kapaklı
# 2526        9086468292  Çanakkale        Merkez
# 2527        9098432861      Niğde        Merkez
# 2528        9322073689   İstanbul    Beylikdüzü
# 2529        9206236310   İstanbul  Bahçelievler
#
#                                                Ürün Adı  Komisyon Oranı  \
# 0     Pembe Ahşap Kaydıraklı Oyun Evi, Ahşap Oyun Ev...           11.30
# 1     Çamaşır Kurutma Makinası İçin Uçucu Yağlar Set...           12.20
# 2     Hayvanlı Kumsuz Hacıyatmaz Kaplan 98 Cm X 44 C...           13.73
# 3     Hayvanlı Kumsuz Hacıyatmaz Kaplan 98 Cm X 44 C...           13.73
# 4     Dekoratif Salyangoz Jüt Dokuma Bardak Altlığı,...           19.32
# ...                                                 ...             ...
# 2525  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 3'lü Se...           16.27
# 2526  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 3'lü Se...           16.27
# 2527  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 5'li Se...           16.27
# 2528  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 5'li Se...           16.27
# 2529  Çakmak Gazı 270 Ml. Parlı Kırmızı Kutu 5'li Se...           16.27
#
#          Marka  Adet  Birim Fiyatı  Satış Tutarı  İndirim Tutarı  \
# 0     ROZİTOYS     1       1800.00       1800.00           100.0
# 1      proclis     1        270.00        270.00             0.0
# 2        Intex     1        285.00        285.00             0.0
# 3        Intex     1        285.00        285.00             0.0
# 4        Pikas     1        249.99        249.99             0.0
# ...        ...   ...           ...           ...             ...
# 2525     Flash     1         86.43         86.43             0.0
# 2526     Flash     1         86.43         86.43             0.0
# 2527     Flash     1        162.70        162.70             0.0
# 2528     Flash     1        289.00        289.00             0.0
# 2529     Flash     1        289.00        289.00             0.0
#
#       Trendyol İndirim Tutarı  Faturalanacak Tutar  Kargodan alınan desi  \
# 0                         0.0              1700.00                  27.0
# 1                         0.0               270.00                   1.0
# 2                         0.0               285.00                   1.0
# 3                         0.0               285.00                   2.0
# 4                         0.0               249.99                   8.0
# ...                       ...                  ...                   ...
# 2525                      0.0                86.43                   2.0
# 2526                      0.0                86.43                   3.0
# 2527                      0.0               162.70                   2.0
# 2528                      0.0               289.00                   2.0
# 2529                      0.0               289.00                   3.0
#
#          Faturalanan Kargo Tutarı  kargo desi min
# 0                          206.58             9.0
# 1                           53.34             1.0
# 2                           53.34             1.0
# 3                           58.79             1.0
# 4                           94.06             8.0
# ...                           ...             ...
# 2525                        23.49             2.0
# 2526                        30.99             2.0
# 2527                        44.99             1.0
# 2528  Henüz fatura kesilmemiştir.             1.0
# 2529                        65.99             1.0
#
# [2530 rows x 18 columns]

# %%
df_kargo_min_max_merge = pd.merge(df_kargo_min_merge, df_kargo_max, how="left", on="Ürün Adı")
df_kargo_min_max_merge

# %%
df_kargo_min_max_mean_merge = pd.merge(df_kargo_min_max_merge, df_kargo_mean, how="left", on="Ürün Adı")
df_kargo_min_max_mean_merge

# %%
# df_kargo_min_max_mean_merge.to_excel(r"C:\Users\user\Downloads\Trendyol Kargo Desi Min Max Ortalama.xlsx", index=False)
