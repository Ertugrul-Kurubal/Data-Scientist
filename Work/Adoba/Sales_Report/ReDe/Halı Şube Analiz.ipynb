# %% [markdown]
# ### Halı Şube Satış Analiz

# %%
import unicodedata
import datetime as dt
import os
import sys
import re
import numpy as np
import pandas as pd
import math
from pathlib import Path
import nltk
from nltk import word_tokenize 
import shutil
from os.path import isfile, join
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import locale
from locale import atof
from geopy.geocoders import Nominatim
from geopy.point import Point
from geopy.exc import GeocoderTimedOut
from functools import reduce

# %%
df1 = pd.read_excel(r"C:\Users\user\Downloads\A 08.08.23-08.11.23.xlsx")
df1
# Out:
#       S.Kodu  Ü.Kodu   Cari Kodu          Firma       Adı ve Soyadı  \
# 0       2769   11380         NaN   Orhan Eroğlu        Adem ŞENTÜRK
# 1       2769   11379         NaN   Orhan Eroğlu        Adem ŞENTÜRK
# 2       2769   11378         NaN   Orhan Eroğlu        Adem ŞENTÜRK
# 3       2768   11377         NaN   Orhan Eroğlu         Halil YİĞİT
# 4       2768   11376         NaN   Orhan Eroğlu         Halil YİĞİT
# ...      ...     ...         ...            ...                 ...
# 9386     299     916  120.01.344  Hakan Nefesli       MEDİNE PAZARI
# 9387     299     915  120.01.344  Hakan Nefesli       MEDİNE PAZARI
# 9388     299     914  120.01.344  Hakan Nefesli       MEDİNE PAZARI
# 9389    1199     611         NaN    Ümmet Ercan         Ufuk Güvenç
# 9390     107     437         NaN  B2B - İbrahim  İbrahim TANRISEVEN
#
#          S.Tar.    Ürün       Kesim   G.EN     EN  ...    M2    Fiyat  \
# 0    2023-11-07  Neptün  Dikdörtgen   70.0   80.0  ...  2.00   580.00
# 1    2023-11-07  Neptün  Dikdörtgen   70.0   80.0  ...  0.86   248.24
# 2    2023-11-07  Neptün  Dikdörtgen   75.0   80.0  ...  0.80   232.00
# 3    2023-11-07  Orkide  Dikdörtgen  160.0  160.0  ...  3.68  1232.80
# 4    2023-11-07  Orkide  Dikdörtgen  160.0  160.0  ...  3.68  1232.80
# ...         ...     ...         ...    ...    ...  ...   ...      ...
# 9386 2023-08-08  Mimoza  Dikdörtgen   80.0   80.0  ...  0.32    42.24
# 9387 2023-08-08  Mimoza  Dikdörtgen  110.0  120.0  ...  0.84   110.88
# 9388 2023-08-08  Mimoza  Dikdörtgen  110.0  120.0  ...  0.84   110.88
# 9389 2023-09-28    Roma  Dikdörtgen  120.0  120.0  ...  1.92   556.80
# 9390 2023-08-09    Roma  Dikdörtgen  160.0  160.0  ...  3.76   906.16
#
#          İnd. % İnd.     KDV    Toplam            Durum  \
# 0       0.000    0.0   0.000   580.000  Kargoya Verildi
# 1       0.000    0.0   0.000   248.240  Kargoya Verildi
# 2       0.000    0.0   0.000   232.000  Kargoya Verildi
# 3     123.280   10.0   0.000  1109.520  Kargoya Verildi
# 4     123.280   10.0   0.000  1109.520  Kargoya Verildi
# ...       ...    ...     ...       ...              ...
# 9386    0.000    0.0   4.224    46.464  Kargoya Verildi
# 9387    0.000    0.0  11.088   121.968  Kargoya Verildi
# 9388    0.000    0.0  11.088   121.968  Kargoya Verildi
# 9389   38.976    7.0   0.000   517.824  Kargoya Verildi
# 9390  135.924   15.0   0.000   770.236  Kargoya Verildi
#
#                                                Açıklama  Fatura  İşlem
# 0                                                   NaN    Cari  Detay
# 1                                                   NaN    Cari  Detay
# 2                                                   NaN    Cari  Detay
# 3                                                   NaN    Cari  Detay
# 4                                                   NaN    Cari  Detay
# ...                                                 ...     ...    ...
# 9386                                                NaN  Fatura  Detay
# 9387                                                NaN  Fatura  Detay
# 9388                                                NaN  Fatura  Detay
# 9389  ( 218 Nolu Siparişin Bölünmüş Hali ) Muhaseben...    Cari  Detay
# 9390                     %10 DEFO İNDİRİMİ UYGULANACAK.    Cari  Detay
#
# [9391 rows x 25 columns]

# %%
df2 = pd.read_excel(r"C:\Users\user\Downloads\B 08.11.23-08.02.24.xlsx")
df2
# Out:
#        S.Kodu  Ü.Kodu    Cari Kodu          Firma             Adı ve Soyadı  \
# 0        7416   26368          NaN  Hasan Geylani  SONGÜL GÜRBÜZ-BEYZA HALI
# 1        7415   26365          NaN  Bayram Arslan             Sema bahtiyar
# 2        7415   26364          NaN  Bayram Arslan             Sema bahtiyar
# 3        7414   26363          NaN  Bayram Arslan            Ramazan Gürgen
# 4        7413   26362  120.02.0080    Ümmet Ercan                Hedya home
# ...       ...     ...          ...            ...                       ...
# 14008    1565    6257          NaN      Recep ŞEN             Ergeldi Aydos
# 14009    1565    6256          NaN      Recep ŞEN             Ergeldi Aydos
# 14010    1322    5085          NaN   Ali Yıldırım              Ali YILDIRIM
# 14011    1322    5084          NaN   Ali Yıldırım              Ali YILDIRIM
# 14012    1322    5083          NaN   Ali Yıldırım              Ali YILDIRIM
#
#           S.Tar.    Ürün       Kesim   G.EN     EN  ...    M2   Fiyat    İnd.  \
# 0     2024-02-07  Havana  Dikdörtgen   80.0   80.0  ...  2.40  1548.0  154.80
# 1     2024-02-07  Mimoza  Dikdörtgen   80.0   80.0  ...  0.40    64.0    6.40
# 2     2024-02-07  Mimoza  Dikdörtgen  110.0  120.0  ...  0.72   115.2   11.52
# 3     2024-02-07  Mimoza  Dikdörtgen   80.0   80.0  ...  0.40    64.0    6.40
# 4     2024-02-07    Luna  Dikdörtgen  160.0  160.0  ...  3.68  1343.2  134.32
# ...          ...     ...         ...    ...    ...  ...   ...     ...     ...
# 14008 2023-11-23  Mimoza  Dikdörtgen   80.0   80.0  ...  4.80   600.0    0.00
# 14009 2023-11-23  Mimoza  Dikdörtgen   80.0   80.0  ...  4.80   600.0    0.00
# 14010 2023-11-16    Roma  Dikdörtgen  120.0  120.0  ...  4.20  1218.0  243.60
# 14011 2023-11-16    Roma  Dikdörtgen  160.0  160.0  ...  4.48  1299.2  259.84
# 14012 2023-11-16    Roma  Dikdörtgen   80.0   80.0  ...  2.24   649.6  129.92
#
#       % İnd.     KDV    Toplam            Durum  \
# 0         10   0.000  1393.200  Kargoya Verildi
# 1         10   5.760    63.360  Kargoya Verildi
# 2         10  10.368   114.048  Kargoya Verildi
# 3         10   5.760    63.360  Kargoya Verildi
# 4         10   0.000  1208.880  Kargoya Verildi
# ...      ...     ...       ...              ...
# 14008      0   0.000   600.000  Kargoya Verildi
# 14009      0   0.000   600.000  Kargoya Verildi
# 14010     20   0.000   974.400  Kargoya Verildi
# 14011     20   0.000  1039.360  Kargoya Verildi
# 14012     20   0.000   519.680  Kargoya Verildi
#
#                                                 Açıklama  Fatura  İşlem
# 0                                        Faturalı olacak    Cari  Detay
# 1                                        KARGO EKLENECEK  Fatura  Detay
# 2                                        KARGO EKLENECEK  Fatura  Detay
# 3            Yeniden üretilecek, cariye yansıtılmayacak.  Fatura  Detay
# 4      Bu sipariş ürünün yanlış anlaşılması sonucu ia...    Cari  Detay
# ...                                                  ...     ...    ...
# 14008                                                NaN    Cari  Detay
# 14009                                                NaN    Cari  Detay
# 14010  Kargo biriminin dikkatine  Sipariş Alıcı : Nur...    Cari  Detay
# 14011  Kargo biriminin dikkatine  Sipariş Alıcı : Nur...    Cari  Detay
# 14012  Kargo biriminin dikkatine  Sipariş Alıcı : Nur...    Cari  Detay
#
# [14013 rows x 25 columns]

# %%
df3 = pd.read_excel(r"C:\Users\user\Downloads\C 08.02.24-08.05.24.xlsx")
df3
# Out:
#        S.Kodu  Ü.Kodu    Cari Kodu         Firma  \
# 0       11541   37828  120.02.0111   Ümmet Ercan
# 1       11539   37826   120.01.805  Rifat Arslan
# 2       11539   37825   120.01.805  Rifat Arslan
# 3       11539   37824   120.01.805  Rifat Arslan
# 4       11538   37823   120.01.572  Rifat Arslan
# ...       ...     ...          ...           ...
# 10989    2411    9950          NaN     Novo Home
# 10990    2411    9949          NaN     Novo Home
# 10991    2411    9902          NaN     Novo Home
# 10992    2411    9896          NaN     Novo Home
# 10993    2411    9895          NaN     Novo Home
#
#                             Adı ve Soyadı     S.Tar.    Ürün       Kesim  \
# 0                        Elit halı sarayı 2024-05-07  Havana  Dikdörtgen
# 1                       MEYDAN MANİFATURA 2024-05-07  Angora  Dikdörtgen
# 2                       MEYDAN MANİFATURA 2024-05-07  Angora  Dikdörtgen
# 3                       MEYDAN MANİFATURA 2024-05-07  Angora  Dikdörtgen
# 4      HALİL YİĞİT-MİMARSİNAN HALI PAZARI 2024-05-07  Orkide  Dikdörtgen
# ...                                   ...        ...     ...         ...
# 10989                           NOVO HOME 2024-04-29    Roma  Dikdörtgen
# 10990                           NOVO HOME 2024-04-29    Roma  Dikdörtgen
# 10991                           NOVO HOME 2024-04-29  Berlin  Dikdörtgen
# 10992                           NOVO HOME 2024-04-29    Roma  Dikdörtgen
# 10993                           NOVO HOME 2024-04-29    Roma  Dikdörtgen
#
#         G.EN     EN  ...    M2    Fiyat    İnd. % İnd.     KDV   Toplam  \
# 0      120.0  120.0  ...  1.80  1321.92  132.19   10.0    0.00  1189.73
# 1       80.0   90.0  ...  3.51  2491.12  249.11   10.0  224.20  2466.21
# 2      120.0  120.0  ...  1.92  1362.66  136.27   10.0  122.64  1349.03
# 3      160.0  185.0  ...  1.22   866.57   86.66   10.0   77.99   857.90
# 4       80.0   80.0  ...  3.04  1464.67  146.47   10.0    0.00  1318.20
# ...      ...    ...  ...   ...      ...     ...    ...     ...      ...
# 10989   80.0   80.0  ...  2.64  1089.00    0.00    NaN    0.00  1089.00
# 10990   80.0   80.0  ...  4.80  1980.00    0.00    NaN    0.00  1980.00
# 10991   80.0   80.0  ...  0.80   297.44    0.00    NaN    0.00   297.44
# 10992  100.0  100.0  ...  0.75   309.38    0.00    NaN    0.00   309.38
# 10993   80.0   80.0  ...  0.32   132.00    0.00    NaN    0.00   132.00
#
#                  Durum               Açıklama     Fatura  İşlem
# 0      Kargoya Verildi  Elden teslim alacağım       Cari  Detay
# 1      Kargoya Verildi                    NaN     Fatura  Detay
# 2      Kargoya Verildi                    NaN     Fatura  Detay
# 3      Kargoya Verildi                    NaN     Fatura  Detay
# 4      Kargoya Verildi                    NaN       Cari  Detay
# ...                ...                    ...        ...    ...
# 10989  Kargoya Verildi  30.10.2023-04.11.2023  Depo Fire  Detay
# 10990  Kargoya Verildi  30.10.2023-04.11.2023  Depo Fire  Detay
# 10991  Kargoya Verildi  30.10.2023-04.11.2023  Depo Fire  Detay
# 10992  Kargoya Verildi  30.10.2023-04.11.2023  Depo Fire  Detay
# 10993  Kargoya Verildi  30.10.2023-04.11.2023  Depo Fire  Detay
#
# [10994 rows x 25 columns]

# %%
df4 = pd.read_excel(r"C:\Users\user\Downloads\D 08.05.24-08.08.24.xlsx")
df4
# Out:
#        S.Kodu  Ü.Kodu    Cari Kodu          Firma  \
# 0       16517   51400  120.02.0131    İsmail Kurt
# 1       16518   51399   120.01.007    Brilla Home
# 2       16518   51398   120.01.007    Brilla Home
# 3       16518   51397   120.01.007    Brilla Home
# 4       16517   51396  120.02.0131    İsmail Kurt
# ...       ...     ...          ...            ...
# 13082   11450   37574   120.01.785      Musa Kurt
# 13083   11450   37573   120.01.785      Musa Kurt
# 13084   11450   37572   120.01.785      Musa Kurt
# 13085   10956   37508   120.01.970  Hakan Nefesli
# 13086   11276   37113   120.01.774   Rifat Arslan
#
#                           Adı ve Soyadı     S.Tar.           Ürün       Kesim  \
# 0          HASAN KOÇAK- İPEK MEKİK HALI 2024-08-08  Hizmet Bedeli  Dikdörtgen
# 1                                 Adoba 2024-08-08         Mimoza  Dikdörtgen
# 2                                 Adoba 2024-08-08         Mimoza  Dikdörtgen
# 3                                 Adoba 2024-08-08         Mimoza  Dikdörtgen
# 4          HASAN KOÇAK- İPEK MEKİK HALI 2024-08-08           Roma  Dikdörtgen
# ...                                 ...        ...            ...         ...
# 13082                         SENA HALI 2024-05-12         Nergis  Dikdörtgen
# 13083                         SENA HALI 2024-05-12         Nergis  Dikdörtgen
# 13084                         SENA HALI 2024-05-12         Nergis  Dikdörtgen
# 13085   ERARSLANLAR HALI VE EV TEKSTİLİ 2024-05-23         Nergis  Dikdörtgen
# 13086  ENES TÜRKERİ -TÜRKERİ HALİ PERDE 2024-05-21         Nergis  Dikdörtgen
#
#         G.EN     EN  ...     M2     Fiyat     İnd. % İnd.    KDV    Toplam  \
# 0      100.0  100.0  ...   1.00    100.00    10.00   10.0    0.0     90.00
# 1       80.0   80.0  ...  12.00   2062.80   515.70   25.0  154.7   1701.80
# 2      160.0  160.0  ...  73.60  12651.80  3163.00   25.0  948.8  10437.60
# 3      180.0  180.0  ...  46.80   8045.00  2011.20   25.0  603.4   6637.20
# 4      120.0  120.0  ...   3.60   1361.52   136.15   10.0    0.0   1225.37
# ...      ...    ...  ...    ...       ...      ...    ...    ...       ...
# 13082  160.0  160.0  ...   3.92   1195.21   119.52   10.0    0.0   1075.69
# 13083  160.0  160.0  ...   4.40   1341.56   134.16   10.0    0.0   1207.40
# 13084  200.0  200.0  ...   4.96   1512.30   151.23   10.0    0.0   1361.07
# 13085  160.0  160.0  ...   3.68   1122.03   112.20   10.0    0.0   1009.83
# 13086  160.0  160.0  ...   3.68   1122.03   112.20   10.0    0.0   1009.83
#
#                  Durum                               Açıklama  Fatura  İşlem
# 0      Dijital Baskıda                                    NaN     NaN  Detay
# 1      Dijital Baskıda                                    NaN     NaN  Detay
# 2      Dijital Baskıda                                    NaN     NaN  Detay
# 3      Dijital Baskıda                                    NaN     NaN  Detay
# 4      Dijital Baskıda                                    NaN     NaN  Detay
# ...                ...                                    ...     ...    ...
# 13082  Kargoya Verildi  Renk tonu aynı olacak. Müşteri kargo.    Cari  Detay
# 13083  Kargoya Verildi  Renk tonu aynı olacak. Müşteri kargo.    Cari  Detay
# 13084  Kargoya Verildi  Renk tonu aynı olacak. Müşteri kargo.    Cari  Detay
# 13085  Kargoya Verildi                                    NaN    Cari  Detay
# 13086  Kargoya Verildi         KDV Li olarak hesaplanacaktır.  Fatura  Detay
#
# [13087 rows x 25 columns]

# %%
df_all = pd.concat([df1,df2,df3,df4], axis=0)
df_all
# Out:
#        S.Kodu  Ü.Kodu   Cari Kodu          Firma  \
# 0        2769   11380         NaN   Orhan Eroğlu
# 1        2769   11379         NaN   Orhan Eroğlu
# 2        2769   11378         NaN   Orhan Eroğlu
# 3        2768   11377         NaN   Orhan Eroğlu
# 4        2768   11376         NaN   Orhan Eroğlu
# ...       ...     ...         ...            ...
# 13082   11450   37574  120.01.785      Musa Kurt
# 13083   11450   37573  120.01.785      Musa Kurt
# 13084   11450   37572  120.01.785      Musa Kurt
# 13085   10956   37508  120.01.970  Hakan Nefesli
# 13086   11276   37113  120.01.774   Rifat Arslan
#
#                           Adı ve Soyadı     S.Tar.    Ürün       Kesim   G.EN  \
# 0                          Adem ŞENTÜRK 2023-11-07  Neptün  Dikdörtgen   70.0
# 1                          Adem ŞENTÜRK 2023-11-07  Neptün  Dikdörtgen   70.0
# 2                          Adem ŞENTÜRK 2023-11-07  Neptün  Dikdörtgen   75.0
# 3                           Halil YİĞİT 2023-11-07  Orkide  Dikdörtgen  160.0
# 4                           Halil YİĞİT 2023-11-07  Orkide  Dikdörtgen  160.0
# ...                                 ...        ...     ...         ...    ...
# 13082                         SENA HALI 2024-05-12  Nergis  Dikdörtgen  160.0
# 13083                         SENA HALI 2024-05-12  Nergis  Dikdörtgen  160.0
# 13084                         SENA HALI 2024-05-12  Nergis  Dikdörtgen  200.0
# 13085   ERARSLANLAR HALI VE EV TEKSTİLİ 2024-05-23  Nergis  Dikdörtgen  160.0
# 13086  ENES TÜRKERİ -TÜRKERİ HALİ PERDE 2024-05-21  Nergis  Dikdörtgen  160.0
#
#           EN  ...    M2    Fiyat    İnd. % İnd.  KDV   Toplam  \
# 0       80.0  ...  2.00   580.00    0.00    0.0  0.0   580.00
# 1       80.0  ...  0.86   248.24    0.00    0.0  0.0   248.24
# 2       80.0  ...  0.80   232.00    0.00    0.0  0.0   232.00
# 3      160.0  ...  3.68  1232.80  123.28   10.0  0.0  1109.52
# 4      160.0  ...  3.68  1232.80  123.28   10.0  0.0  1109.52
# ...      ...  ...   ...      ...     ...    ...  ...      ...
# 13082  160.0  ...  3.92  1195.21  119.52   10.0  0.0  1075.69
# 13083  160.0  ...  4.40  1341.56  134.16   10.0  0.0  1207.40
# 13084  200.0  ...  4.96  1512.30  151.23   10.0  0.0  1361.07
# 13085  160.0  ...  3.68  1122.03  112.20   10.0  0.0  1009.83
# 13086  160.0  ...  3.68  1122.03  112.20   10.0  0.0  1009.83
#
#                  Durum                               Açıklama  Fatura  İşlem
# 0      Kargoya Verildi                                    NaN    Cari  Detay
# 1      Kargoya Verildi                                    NaN    Cari  Detay
# 2      Kargoya Verildi                                    NaN    Cari  Detay
# 3      Kargoya Verildi                                    NaN    Cari  Detay
# 4      Kargoya Verildi                                    NaN    Cari  Detay
# ...                ...                                    ...     ...    ...
# 13082  Kargoya Verildi  Renk tonu aynı olacak. Müşteri kargo.    Cari  Detay
# 13083  Kargoya Verildi  Renk tonu aynı olacak. Müşteri kargo.    Cari  Detay
# 13084  Kargoya Verildi  Renk tonu aynı olacak. Müşteri kargo.    Cari  Detay
# 13085  Kargoya Verildi                                    NaN    Cari  Detay
# 13086  Kargoya Verildi         KDV Li olarak hesaplanacaktır.  Fatura  Detay
#
# [47485 rows x 25 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47485 entries, 0 to 13086
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   S.Kodu         47485 non-null  int64
#  1   Ü.Kodu         47485 non-null  int64
#  2   Cari Kodu      31593 non-null  object
#  3   Firma          47485 non-null  object
#  4   Adı ve Soyadı  47485 non-null  object
#  5   S.Tar.         47485 non-null  datetime64[ns]
#  6   Ürün           47481 non-null  object
#  7   Kesim          47485 non-null  object
#  8   G.EN           46829 non-null  float64
#  9   EN             46829 non-null  float64
#  10  BOY            46829 non-null  float64
#  11  ÇAP            656 non-null    float64
#  12  Saçak          47485 non-null  object
#  13  Desen          47296 non-null  object
#  14  Adet           47484 non-null  float64
#  15  M2             47485 non-null  float64
#  16  Fiyat          47485 non-null  float64
#  17  İnd.           47485 non-null  float64
#  18  % İnd.         47257 non-null  float64
#  19  KDV            47485 non-null  float64
#  20  Toplam         47485 non-null  float64
#  21  Durum          47485 non-null  object
#  22  Açıklama       12600 non-null  object
#  23  Fatura         47182 non-null  object
#  24  İşlem          47485 non-null  object
# dtypes: datetime64[ns](1), float64(11), int64(2), object(11)
# memory usage: 9.4+ MB

# %%
df_all["S.Kodu"].nunique()
# Out:
# 15623

# %%
df_all["Adı ve Soyadı"].nunique()
# Out:
# 1835

# %%
df_all.to_excel(r"C:\Users\user\Downloads\Halı Şube Satış.xlsx", index=False)
