# %%
# pip install ipykernel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install -r requirements.txt
# Out:
# ...
#
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.0.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached regex-2024.5.15-cp312-cp312-win_amd64.whl.metadata (41 kB)
# ...
#   Using cached openpyxl-3.1.4-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached pillow-10.3.0-cp312-cp312-win_amd64.whl.metadata (9.4 kB)
# ...
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached Scrapy-2.11.2-py2.py3-none-any.whl.metadata (5.3 kB)
# ...
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached matplotlib-3.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached scikit_learn-1.5.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached scipy-1.14.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- ------------------
# aext-assistant                    4.0.15
# aext-assistant-server             4.0.15
# aext-core                         4.0.15
# aext-core-server                  4.0.15
# aext-panels                       4.0.15
# aext-panels-server                4.0.15
# aext-share-notebook               4.0.15
# aext-share-notebook-server        4.0.15
# aext-shared                       4.0.15
# aiobotocore                       2.12.3
# aiohttp                           3.9.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# altair                            5.0.1
# anaconda-anon-usage               0.4.4
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.5.1
# anaconda-navigator                2.6.0
# anaconda-project                  0.11.1
# ...

# %%
pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.7 MB 3.4 MB/s eta 0:00:03
#     --------------------------------------- 0.2/8.7 MB 3.0 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/8.7 MB 2.8 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/8.7 MB 3.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/8.7 MB 4.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.7 MB 3.8 MB/s eta 0:00:03
#    -------- ------------------------------- 1.9/8.7 MB 6.1 MB/s eta 0:00:02
#    --------- ------------------------------ 2.2/8.7 MB 6.0 MB/s eta 0:00:02
#    -------------- ------------------------- 3.1/8.7 MB 7.5 MB/s eta 0:00:01
#    --------------- ------------------------ 3.4/8.7 MB 7.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.9/8.7 MB 7.5 MB/s eta 0:00:01
# ...

# %%
pip install pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
