# %% [markdown]
# #### File Editing

# %%
import pandas as pd
import numpy as np
import glob

# %%
df_born_date = pd.read_excel(fr"C:\Users\ertugrul.kurubal\Desktop\Data Analysis\Adoba\Files\Personel Rehberi 22.09.2025.xlsx", sheet_name="ADOBA DIŞ TİCARET A.Ş")
df_born_date
# Out:
#                 AD    SOYAD           ADI SOYADI         DOĞUM TARİHİ  \
# 0            AHMET   ANARAT         AHMET ANARAT  1973-08-01 00:00:00
# 1           MEHMET  ÇALIŞIR       MEHMET ÇALIŞIR  1975-08-22 00:00:00
# 2    MUSTAFA MURAT    DEMİR  MUSTAFA MURAT DEMİR  1994-08-07 00:00:00
# 3             AYŞE     GENÇ            AYŞE GENÇ  1980-08-12 00:00:00
# 4           İSMAİL     KURT          İSMAİL KURT  1978-08-20 00:00:00
# ..             ...      ...                  ...                  ...
# 135          YAVUZ   GÜNDÜZ         YAVUZ GÜNDÜZ  1987-07-11 00:00:00
# 136         GÖKHAN   ÖZTÜRK        GÖKHAN ÖZTÜRK  1992-07-01 00:00:00
# 137          YAHYA    TANŞU          YAHYA TANŞU  1984-07-24 00:00:00
# 138         RIDVAN     UÇAR          RIDVAN UÇAR  1990-07-03 00:00:00
# 139          ERCAN   YEKTAŞ         ERCAN YEKTAŞ  1984-07-07 00:00:00
#
#         TELEFON          GÖREVİ  GÜN       AY
# 0    5055247135  ADOBA-GÜVENLİK    1  Ağustos
# ...

# %%
files = glob.glob(r"C:\Users\ertugrul.kurubal\Desktop\Data Analysis\Adoba\Files\*Yıllık İzin Raporu.xlsx")
files
# Out:
# ['C:\\Users\\ertugrul.kurubal\\Desktop\\Data Analysis\\Adoba\\Files\\Adoba Personel Yıllık İzin Raporu.xlsx',
#  'C:\\Users\\ertugrul.kurubal\\Desktop\\Data Analysis\\Adoba\\Files\\Pena Personel Yıllık İzin Raporu.xlsx',
#  'C:\\Users\\ertugrul.kurubal\\Desktop\\Data Analysis\\Adoba\\Files\\Pikas Personel Yıllık İzin Raporu.xlsx']
