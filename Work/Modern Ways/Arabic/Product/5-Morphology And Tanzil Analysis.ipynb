# %% [markdown]
# ### Morphology And Tanzil Analysis

# %%
#!pip install lang-trans
#!pip install camel-tools

# %%
import pandas as pd
import numpy as np
import re
from camel_tools.utils.charmap import CharMapper
from lang_trans.arabic import buckwalter
import nltk
from nltk import word_tokenize
from nltk import ngrams

# %%
df_tanzil_word = pd.read_excel("Arabic_And_Buckwalter_Word_Tanzil_Simple.xlsx")
df_tanzil_word
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_simple  \
# 0          1      1      1                       بسم
# 1          1      1      2                      الله
# 2          1      1      3                    الرحمن
# 3          1      1      4                    الرحيم
# 4          1      2      1                     الحمد
# ...      ...    ...    ...                       ...
# 78243    114      5      4                      صدور
# 78244    114      5      5                     الناس
# 78245    114      6      1                        من
# 78246    114      6      2                     الجنة
# 78247    114      6      3                    والناس
#
#       buckwalter_word_tanzil_simple
# 0                               bsm
# 1                              Allh
# 2                            AlrHmn
# 3                            AlrHym
# 4                             AlHmd
# ...                             ...
# 78243                          Sdwr
# 78244                         AlnAs
# 78245                            mn
# 78246                         Aljnp
# 78247                        wAlnAs
#
# [78248 rows x 5 columns]

# %%
df_morp_word = pd.read_excel("Arabic_And_Buckwalter_Word_Morphology.xlsx")
df_morp_word
# Out:
#        num_1  num_2  num_3 arabic_word_morphology buckwalter_word_morphology
# 0          1      1      1                 بِسْمِ                     bisomi
# 1          1      1      2                ٱللَّهِ                    {ll~ahi
# 2          1      1      3           ٱلرَّحْمَٰنِ               {lr~aHoma`ni
# 3          1      1      4             ٱلرَّحِيمِ                 {lr~aHiymi
# 4          1      2      1              ٱلْحَمْدُ                  {loHamodu
# ...      ...    ...    ...                    ...                        ...
# 77424    114      5      4                صُدُورِ                    Suduwri
# 77425    114      5      5               ٱلنَّاسِ                   {ln~aAsi
# 77426    114      6      1                   مِنَ                       mina
# 77427    114      6      2             ٱلْجِنَّةِ                 {lojin~api
# 77428    114      6      3             وَٱلنَّاسِ                 wa{ln~aAsi
#
# [77429 rows x 5 columns]

# %%
df_tanzil_morp_word_merge = pd.merge(df_tanzil_word,df_morp_word, how="left", on=["num_1","num_2","num_3"])
df_tanzil_morp_word_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_simple  \
# 0          1      1      1                       بسم
# 1          1      1      2                      الله
# 2          1      1      3                    الرحمن
# 3          1      1      4                    الرحيم
# 4          1      2      1                     الحمد
# ...      ...    ...    ...                       ...
# 78243    114      5      4                      صدور
# 78244    114      5      5                     الناس
# 78245    114      6      1                        من
# 78246    114      6      2                     الجنة
# 78247    114      6      3                    والناس
#
#       buckwalter_word_tanzil_simple arabic_word_morphology  \
# 0                               bsm                 بِسْمِ
# 1                              Allh                ٱللَّهِ
# 2                            AlrHmn           ٱلرَّحْمَٰنِ
# 3                            AlrHym             ٱلرَّحِيمِ
# 4                             AlHmd              ٱلْحَمْدُ
# ...                             ...                    ...
# 78243                          Sdwr                صُدُورِ
# 78244                         AlnAs               ٱلنَّاسِ
# 78245                            mn                   مِنَ
# 78246                         Aljnp             ٱلْجِنَّةِ
# 78247                        wAlnAs             وَٱلنَّاسِ
#
#       buckwalter_word_morphology
# 0                         bisomi
# 1                        {ll~ahi
# 2                   {lr~aHoma`ni
# 3                     {lr~aHiymi
# 4                      {loHamodu
# ...                          ...
# 78243                    Suduwri
# 78244                   {ln~aAsi
# 78245                       mina
# 78246                 {lojin~api
# 78247                 wa{ln~aAsi
#
# [78248 rows x 7 columns]

# %%
df_tanzil_sent = pd.read_excel("Arabic_And_Buckwalter_Sent_Tanzil_Simple.xlsx")
df_tanzil_sent
# Out:
#       num_1  num_2 arabic_sent_tanzil_simple buckwalter_sent_tanzil_simple
# 0         1      1    بسم الله الرحمن الرحيم        bsm Allh AlrHmn AlrHym
# 1         1      2     الحمد لله رب العالمين         AlHmd llh rb AlEAlmyn
# 2         1      3             الرحمن الرحيم                 AlrHmn AlrHym
# 3         1      4            مالك يوم الدين                mAlk ywm Aldyn
# 4         1      5    إياك نعبد وإياك نستعين        <yAk nEbd w<yAk nstEyn
# ...     ...    ...                       ...                           ...
# 6231    114      2                 ملك الناس                     mlk AlnAs
# 6232    114      3                 إله الناس                     <lh AlnAs
# 6233    114      4      من شر الوسواس الخناس          mn $r AlwswAs AlxnAs
# 6234    114      5  الذي يوسوس في صدور الناس      Al*y ywsws fy Sdwr AlnAs
# 6235    114      6           من الجنة والناس               mn Aljnp wAlnAs
#
# [6236 rows x 4 columns]

# %%
df_morp_sent = pd.read_excel("Arabic_And_Buckwalter_Sent_Morphology.xlsx")
df_morp_sent
# Out:
#       num_1  num_2                    arabic_sent_morphology  \
# 0         1      1    بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1         1      2     ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2         1      3                   ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3         1      4                   مَٰلِكِ يَوْمِ ٱلدِّينِ
# 4         1      5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# ...     ...    ...                                       ...
# 6231    114      2                           مَلِكِ ٱلنَّاسِ
# 6232    114      3                          إِلَٰهِ ٱلنَّاسِ
# 6233    114      4        مِن شَرِّ ٱلْوَسْوَاسِ ٱلْخَنَّاسِ
# 6234    114      5   ٱلَّذِى يُوَسْوِسُ فِى صُدُورِ ٱلنَّاسِ
# 6235    114      6                مِنَ ٱلْجِنَّةِ وَٱلنَّاسِ
#
#                     buckwalter_sent_morphology
# 0       bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi
# 1        {loHamodu lil~ahi rab~i {loEa`lamiyna
# 2                      {lr~aHoma`ni {lr~aHiymi
# 3                      ma`liki yawomi {ld~iyni
# 4     <iy~aAka naEobudu wa<iy~aAka nasotaEiynu
# ...                                        ...
# 6231                           maliki {ln~aAsi
# 6232                          <ila`hi {ln~aAsi
# 6233        min $ar~i {lowasowaAsi {loxan~aAsi
# 6234   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi
# 6235                mina {lojin~api wa{ln~aAsi
#
# [6236 rows x 4 columns]

# %%
df_tanzil_morp_sent_merge = pd.merge(df_tanzil_sent,df_morp_sent, how="inner", on=["num_1","num_2"])
df_tanzil_morp_sent_merge
# Out:
#       num_1  num_2 arabic_sent_tanzil_simple buckwalter_sent_tanzil_simple  \
# 0         1      1    بسم الله الرحمن الرحيم        bsm Allh AlrHmn AlrHym
# 1         1      2     الحمد لله رب العالمين         AlHmd llh rb AlEAlmyn
# 2         1      3             الرحمن الرحيم                 AlrHmn AlrHym
# 3         1      4            مالك يوم الدين                mAlk ywm Aldyn
# 4         1      5    إياك نعبد وإياك نستعين        <yAk nEbd w<yAk nstEyn
# ...     ...    ...                       ...                           ...
# 6231    114      2                 ملك الناس                     mlk AlnAs
# 6232    114      3                 إله الناس                     <lh AlnAs
# 6233    114      4      من شر الوسواس الخناس          mn $r AlwswAs AlxnAs
# 6234    114      5  الذي يوسوس في صدور الناس      Al*y ywsws fy Sdwr AlnAs
# 6235    114      6           من الجنة والناس               mn Aljnp wAlnAs
#
#                         arabic_sent_morphology  \
# 0       بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1        ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2                      ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3                      مَٰلِكِ يَوْمِ ٱلدِّينِ
# 4     إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# ...                                        ...
# 6231                           مَلِكِ ٱلنَّاسِ
# 6232                          إِلَٰهِ ٱلنَّاسِ
# 6233        مِن شَرِّ ٱلْوَسْوَاسِ ٱلْخَنَّاسِ
# 6234   ٱلَّذِى يُوَسْوِسُ فِى صُدُورِ ٱلنَّاسِ
# 6235                مِنَ ٱلْجِنَّةِ وَٱلنَّاسِ
#
#                     buckwalter_sent_morphology
# 0       bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi
# 1        {loHamodu lil~ahi rab~i {loEa`lamiyna
# 2                      {lr~aHoma`ni {lr~aHiymi
# 3                      ma`liki yawomi {ld~iyni
# 4     <iy~aAka naEobudu wa<iy~aAka nasotaEiynu
# ...                                        ...
# 6231                           maliki {ln~aAsi
# 6232                          <ila`hi {ln~aAsi
# 6233        min $ar~i {lowasowaAsi {loxan~aAsi
# 6234   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi
# 6235                mina {lojin~api wa{ln~aAsi
#
# [6236 rows x 6 columns]
