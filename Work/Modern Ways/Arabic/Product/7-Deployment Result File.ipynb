# %% [markdown]
# ### Deployment Result

# %%
import pandas as pd
import numpy as np
import re
from camel_tools.utils.charmap import CharMapper
from lang_trans.arabic import buckwalter
import nltk
from nltk import word_tokenize
from nltk import ngrams
import json

# %%
df_word_merge = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Text/Result/6-Morphology And Tanzil/Arabic_Buckwalter_Clean_Plain_Word_Merge_Tanzil.xlsx")
df_word_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78243    114      5      4                     صدور
# 78244    114      5      5                    الناس
# 78245    114      6      1                       من
# 78246    114      6      2                    الجنة
# 78247    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# ...

# %%
df_select_word = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Text/Result/5-Tanzil Analysis/Arabic_Buckwalter_100_Word_Frequency_Tanzil_Clean.xlsx")
df_select_word
# Out:
#    arabic_word_tanzil_clean buckwalter_word_tanzil_clean  frequency
# 0                        من                           mn       2763
# 1                      الله                         Allh       2265
# 2                        في                           fy       1185
# 3                        ما                           mA       1013
# 4                        إن                           <n        966
# ..                      ...                          ...        ...
# 95                     عليم                         Elym        106
# 96                     ربنا                         rbnA        106
# 97                     ربكم                         rbkm        102
# 98                    النار                        AlnAr        102
# 99                     فلما                         flmA        101
#
# [100 rows x 3 columns]

# %%
df_select_word.frequency.sum()
# Out:
# 29643

# %%
select_word_list = df_select_word.iloc[:,0].to_list()
select_word_list
# Out:
# ['من',
#  'الله',
#  'في',
#  'ما',
#  'إن',
#  'لا',
#  'الذين',
#  'على',
#  'إلا',
#  'ولا',
#  'وما',
#  'أن',
#  'قال',
#  'إلى',
#  'لهم',
#  'يا',
#  'ومن',
#  'ثم',
#  'لكم',
#  'به',
#  'كان',
#  'بما',
#  'قل',
#  'الأرض',
#  'ذلك',
#  'أو',
#  'له',
#  'الذي',
#  'هو',
#  'آمنوا',
#  'هم',
#  'وإن',
#  'قالوا',
#  'كل',
#  'فيها',
#  'والله',
#  'كانوا',
#  'عن',
#  'إذا',
#  'ربك',
#  'يوم',
#  'عليهم',
#  'هذا',
#  'شيء',
#  'كفروا',
#  'كنتم',
#  'الناس',
#  'السماوات',
#  'لم',
#  'وهو',
#  'فإن',
#  'إذ',
#  'والذين',
#  'عليكم',
#  'الكتاب',
#  'والأرض',
#  'الرحمن',
#  'فلا',
#  'إنا',
#  'منهم',
#  'أيها',
#  'عذاب',
#  'بعد',
#  'إنه',
#  'عليه',
#  'الرحيم',
#  'حتى',
#  'بالله',
#  'وهم',
#  'وإذا',
#  'أولئك',
#  'إني',
#  'أم',
#  'رب',
#  'ولقد',
#  'موسى',
#  'فيه',
#  'بل',
#  'قد',
#  'قوم',
#  'عند',
#  'قبل',
#  'خير',
#  'لله',
#  'يشاء',
#  'الدنيا',
#  'بسم',
#  'إنما',
#  'ولكن',
#  'ولو',
#  'ربهم',
#  'مما',
#  'الحق',
#  'السماء',
#  'منكم',
# ...

# %%
select_word_text = " ".join(select_word_list)

# %%
# 1 Way
def compare_word_text(word, word_text):
    if re.search(fr"(?:\s|^){word}(?:\s|$)", word_text):
        return 1
    else:
        return 0

# %%
df_word_merge.iloc[:,3].apply(lambda x: compare_word_text(x, select_word_text))
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 78243    0
# 78244    1
# 78245    1
# 78246    0
# 78247    0
# Name: arabic_word_tanzil_clean, Length: 78248, dtype: int64

# %%
## 2 Way
#def compare_word_list(word, word_list):
#    for i in word_list:
#        if re.search(fr"(?:\s|^){i}(?:\s|$)", word):
#            return 1

# %%
#df_word_merge.iloc[:,3].apply(lambda x: compare_word_list(x, select_word_list))

# %%
#df_word_merge["color"] = df_word_merge.iloc[:,3].apply(lambda x: compare_word_list(x, select_word_list))
#df_word_merge

# %%
#df_word_merge.color = df_word_merge.color.fillna(0)
#df_word_merge

# %%
#df_word_merge.color.sum()

# %%
df_word_merge["color"] = df_word_merge.iloc[:,3].apply(lambda x: compare_word_text(x, select_word_text))
df_word_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78243    114      5      4                     صدور
# 78244    114      5      5                    الناس
# 78245    114      6      1                       من
# 78246    114      6      2                    الجنة
# 78247    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# ...

# %%
df_word_merge.color.sum()
# Out:
# 29643

# %%
df_root = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Text/Result/2-Morphology Root Analysis/Arabic_Buckwalter_Form_Root_Morphology.xlsx")
df_root
# Out:
#        num_1  num_2  num_3  num_4        form  tag  root root_arabic
# 0          1      1      1      2        somi    N   smw         سمو
# 1          1      1      2      1     {ll~ahi   PN   Alh         اله
# 2          1      1      3      2  r~aHoma`ni  ADJ   rHm         رحم
# 3          1      1      4      2    r~aHiymi  ADJ   rHm         رحم
# 4          1      2      1      2      Hamodu    N   Hmd         حمد
# ...      ...    ...    ...    ...         ...  ...   ...         ...
# 49963    114      5      2      1  yuwasowisu    V  wsws        وسوس
# 49964    114      5      4      1     Suduwri    N   Sdr         صدر
# 49965    114      5      5      2      n~aAsi    N   nws         نوس
# 49966    114      6      2      2     jin~api    N   jnn         جنن
# 49967    114      6      3      3      n~aAsi    N   nws         نوس
#
# [49968 rows x 8 columns]

# %%
df_word_root_merge = pd.merge(df_word_merge,df_root, how="left", on=["num_1","num_2","num_3"])
df_word_root_merge = df_word_root_merge.iloc[:,[0,1,2,3,4,5,6,7,9,11,12,10]]
df_word_root_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78244    114      5      4                     صدور
# 78245    114      5      5                    الناس
# 78246    114      6      1                       من
# 78247    114      6      2                    الجنة
# 78248    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# ...

# %%
df_word_root_merge.drop_duplicates(inplace=True)

# %%
df_word_root_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78244    114      5      4                     صدور
# 78245    114      5      5                    الناس
# 78246    114      6      1                       من
# 78247    114      6      2                    الجنة
# 78248    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# ...

# %%
df_word_root_merge.color.sum()
# Out:
# 29644

# %%
#a = set(df_word_root_merge.iloc[:,6])
#b = set(df_word_merge.iloc[:,6])
#a.difference(b)

# %%
#df_word_root_merge.to_excel("Arabic_Buckwalter_Word_Root_Color.xlsx",index=False)

# %% [markdown]
# #### Read Json

# %%
df_json = pd.read_json("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Speech To Text/Result/abdul-basit-murattal-036.json")
df_json
# Out:
#                                               results
# 0   {'alternatives': [{'confidence': 0.79057527, '...
# 1   {'alternatives': [{'confidence': 0.83871365, '...
# 2   {'alternatives': [{'confidence': 0.79364455, '...
# 3   {'alternatives': [{'confidence': 0.92682546, '...
# 4   {'alternatives': [{'confidence': 0.86820089999...
# 5   {'alternatives': [{'confidence': 0.86440098, '...
# 6   {'alternatives': [{'confidence': 0.70769668, '...
# 7   {'alternatives': [{'confidence': 0.834773, 'tr...
# 8   {'alternatives': [{'confidence': 0.84761965000...
# 9   {'alternatives': [{'confidence': 0.89591819000...
# 10  {'alternatives': [{'confidence': 0.79134327, '...
# 11  {'alternatives': [{'confidence': 0.90494591, '...
# 12  {'alternatives': [{'confidence': 0.89137703, '...
# 13  {'alternatives': [{'confidence': 0.72065663, '...
# 14  {'alternatives': [{'confidence': 0.92282492, '...
# 15  {'alternatives': [{'confidence': 0.7775175, 't...
# ...

# %%
df_json.results.values.tolist()
# Out:
# [{'alternatives': [{'confidence': 0.79057527,
#     'transcript': 'الله الرحمن الرحيم ياسين والقران الحكيم انك لمن المرسلين على صراط المستقيم تنزيل العزيز الرحيم لما انظر ابائهم',
#     'words': [{'endTime': '0.900s', 'startTime': '0s', 'word': 'الله'},
#      {'endTime': '1.600s', 'startTime': '0.900s', 'word': 'الرحمن'},
#      {'endTime': '2s', 'startTime': '1.600s', 'word': 'الرحيم'},
#      {'endTime': '5.200s', 'startTime': '2s', 'word': 'ياسين'},
#      {'endTime': '8.700s', 'startTime': '5.200s', 'word': 'والقران'},
#      {'endTime': '9.200s', 'startTime': '8.700s', 'word': 'الحكيم'},
#      {'endTime': '12.400s', 'startTime': '9.200s', 'word': 'انك'},
#      {'endTime': '12.800s', 'startTime': '12.400s', 'word': 'لمن'},
#      {'endTime': '13.700s', 'startTime': '12.800s', 'word': 'المرسلين'},
#      {'endTime': '15.500s', 'startTime': '13.700s', 'word': 'على'},
#      {'endTime': '16.100s', 'startTime': '15.500s', 'word': 'صراط'},
# ...

# %%
df_json2 = pd.DataFrame(df_json.results.tolist())["alternatives"]
df_json2
# Out:
# 0     [{'confidence': 0.79057527, 'transcript': 'الل...
# 1     [{'confidence': 0.83871365, 'transcript': 'علا...
# 2     [{'confidence': 0.79364455, 'transcript': ' وج...
# 3     [{'confidence': 0.92682546, 'transcript': ' مش...
# 4     [{'confidence': 0.8682008999999999, 'transcrip...
# 5     [{'confidence': 0.86440098, 'transcript': ' ال...
# 6     [{'confidence': 0.70769668, 'transcript': ' طا...
# 7     [{'confidence': 0.834773, 'transcript': ' ومن ...
# 8     [{'confidence': 0.8476196500000001, 'transcrip...
# 9     [{'confidence': 0.8959181900000001, 'transcrip...
# 10    [{'confidence': 0.79134327, 'transcript': ' سب...
# 11    [{'confidence': 0.90494591, 'transcript': ' وا...
# 12    [{'confidence': 0.89137703, 'transcript': ' وا...
# 13    [{'confidence': 0.72065663, 'transcript': ' وا...
# 14    [{'confidence': 0.92282492, 'transcript': ' وا...
# 15    [{'confidence': 0.7775175, 'transcript': ' الذ...
# 16    [{'confidence': 0.88015044, 'transcript': ' وم...
# ...

# %%
with open("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Speech To Text/Result/abdul-basit-murattal-036.json", "r", encoding="utf8") as file:
    json_data = json.loads(file.read())

# %%
json_data
# Out:
# {'results': [{'alternatives': [{'confidence': 0.79057527,
#      'transcript': 'الله الرحمن الرحيم ياسين والقران الحكيم انك لمن المرسلين على صراط المستقيم تنزيل العزيز الرحيم لما انظر ابائهم',
#      'words': [{'endTime': '0.900s', 'startTime': '0s', 'word': 'الله'},
#       {'endTime': '1.600s', 'startTime': '0.900s', 'word': 'الرحمن'},
#       {'endTime': '2s', 'startTime': '1.600s', 'word': 'الرحيم'},
#       {'endTime': '5.200s', 'startTime': '2s', 'word': 'ياسين'},
#       {'endTime': '8.700s', 'startTime': '5.200s', 'word': 'والقران'},
#       {'endTime': '9.200s', 'startTime': '8.700s', 'word': 'الحكيم'},
#       {'endTime': '12.400s', 'startTime': '9.200s', 'word': 'انك'},
#       {'endTime': '12.800s', 'startTime': '12.400s', 'word': 'لمن'},
#       {'endTime': '13.700s', 'startTime': '12.800s', 'word': 'المرسلين'},
#       {'endTime': '15.500s', 'startTime': '13.700s', 'word': 'على'},
#       {'endTime': '16.100s', 'startTime': '15.500s', 'word': 'صراط'},
# ...

# %%
#result_data = json_data["results"]
#result_data
# Out:
# [{'alternatives': [{'confidence': 0.79057527,
#     'transcript': 'الله الرحمن الرحيم ياسين والقران الحكيم انك لمن المرسلين على صراط المستقيم تنزيل العزيز الرحيم لما انظر ابائهم',
#     'words': [{'endTime': '0.900s', 'startTime': '0s', 'word': 'الله'},
#      {'endTime': '1.600s', 'startTime': '0.900s', 'word': 'الرحمن'},
#      {'endTime': '2s', 'startTime': '1.600s', 'word': 'الرحيم'},
#      {'endTime': '5.200s', 'startTime': '2s', 'word': 'ياسين'},
#      {'endTime': '8.700s', 'startTime': '5.200s', 'word': 'والقران'},
#      {'endTime': '9.200s', 'startTime': '8.700s', 'word': 'الحكيم'},
#      {'endTime': '12.400s', 'startTime': '9.200s', 'word': 'انك'},
#      {'endTime': '12.800s', 'startTime': '12.400s', 'word': 'لمن'},
#      {'endTime': '13.700s', 'startTime': '12.800s', 'word': 'المرسلين'},
#      {'endTime': '15.500s', 'startTime': '13.700s', 'word': 'على'},
#      {'endTime': '16.100s', 'startTime': '15.500s', 'word': 'صراط'},
# ...

# %%
df_nested_list = pd.json_normalize(json_data,record_path=["results"], record_prefix=["alternatives"], meta_prefix=["transcript"] # record_path, meta, meta_prefix, record_prefix
df_nested_list
# Out:
#   File "<ipython-input-33-e6e7124b38db>", line 2
#     df_nested_list
#     ^
# SyntaxError: invalid syntax

# %%
json_object = json.dumps(result_data, indent = 4)
json_object

# %%
re.findall(r'(["endTime":](\w+.)', json_object)
