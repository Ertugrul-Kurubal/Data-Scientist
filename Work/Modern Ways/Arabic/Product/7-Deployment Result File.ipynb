# %% [markdown]
# ### Deployment Result

# %%
import pandas as pd
import numpy as np
import re
from camel_tools.utils.charmap import CharMapper
from lang_trans.arabic import buckwalter
import nltk
from nltk import word_tokenize
from nltk import ngrams
import json
import re

# %%
df_word_merge = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Text/Result/6-Morphology And Tanzil/Arabic_Buckwalter_Clean_Plain_Word_Merge_Tanzil.xlsx")
df_word_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78243    114      5      4                     صدور
# 78244    114      5      5                    الناس
# 78245    114      6      1                       من
# 78246    114      6      2                    الجنة
# 78247    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# 4                            AlHmd                الْحَمْدُ
# ...                            ...                      ...
# 78243                         Sdwr                  صُدُورِ
# 78244                        AlnAs                 النَّاسِ
# 78245                           mn                     مِنَ
# 78246                        Aljnp               الْجِنَّةِ
# 78247                       wAlnAs               وَالنَّاسِ
#
#       buckwalter_word_tanzil_plain
# 0                           bisomi
# 1                          All~ahi
# 2                     Alr~aHoma`ni
# 3                       Alr~aHiymi
# 4                        AloHamodu
# ...                            ...
# 78243                      Suduwri
# 78244                     Aln~aAsi
# 78245                         mina
# 78246                   Alojin~api
# 78247                   waAln~aAsi
#
# [78248 rows x 7 columns]

# %%
df_select_word = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Text/Result/5-Tanzil Analysis/Arabic_Buckwalter_100_Word_Frequency_Tanzil_Clean.xlsx")
df_select_word
# Out:
#    arabic_word_tanzil_clean buckwalter_word_tanzil_clean  frequency
# 0                        من                           mn       2763
# 1                      الله                         Allh       2265
# 2                        في                           fy       1185
# 3                        ما                           mA       1013
# 4                        إن                           <n        966
# ..                      ...                          ...        ...
# 95                     عليم                         Elym        106
# 96                     ربنا                         rbnA        106
# 97                     ربكم                         rbkm        102
# 98                    النار                        AlnAr        102
# 99                     فلما                         flmA        101
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Adding Color Column

# %%
select_word_list = df_select_word.iloc[:,0].to_list()
#select_word_list

# %%
select_word_text = " ".join(select_word_list)

# %%
# 1 Way
def compare_word_text(word, word_text):
    if re.search(fr"(?:\s|^){word}(?:\s|$)", word_text):
        return 1
    else:
        return 0

# %%
df_word_merge.iloc[:,3].apply(lambda x: compare_word_text(x, select_word_text))
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 78243    0
# 78244    1
# 78245    1
# 78246    0
# 78247    0
# Name: arabic_word_tanzil_clean, Length: 78248, dtype: int64

# %%
## 2 Way
#def compare_word_list(word, word_list):
#    for i in word_list:
#        if re.search(fr"(?:\s|^){i}(?:\s|$)", word):
#            return 1

# %%
#df_word_merge.iloc[:,3].apply(lambda x: compare_word_list(x, select_word_list))

# %%
#df_word_merge["color"] = df_word_merge.iloc[:,3].apply(lambda x: compare_word_list(x, select_word_list))
#df_word_merge

# %%
#df_word_merge.color = df_word_merge.color.fillna(0)
#df_word_merge

# %%
#df_word_merge.color.sum()

# %%
df_word_merge["color"] = df_word_merge.iloc[:,3].apply(lambda x: compare_word_text(x, select_word_text))
df_word_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78243    114      5      4                     صدور
# 78244    114      5      5                    الناس
# 78245    114      6      1                       من
# 78246    114      6      2                    الجنة
# 78247    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# 4                            AlHmd                الْحَمْدُ
# ...                            ...                      ...
# 78243                         Sdwr                  صُدُورِ
# 78244                        AlnAs                 النَّاسِ
# 78245                           mn                     مِنَ
# 78246                        Aljnp               الْجِنَّةِ
# 78247                       wAlnAs               وَالنَّاسِ
#
#       buckwalter_word_tanzil_plain  color
# 0                           bisomi      1
# 1                          All~ahi      1
# 2                     Alr~aHoma`ni      1
# 3                       Alr~aHiymi      1
# 4                        AloHamodu      0
# ...                            ...    ...
# 78243                      Suduwri      0
# 78244                     Aln~aAsi      1
# 78245                         mina      1
# 78246                   Alojin~api      0
# 78247                   waAln~aAsi      0
#
# [78248 rows x 8 columns]

# %%
df_word_merge.color.sum()
# Out:
# 29643

# %%
df_root = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Text/Result/2-Morphology Root Analysis/Arabic_Buckwalter_Form_Root_Morphology.xlsx")
df_root
# Out:
#        num_1  num_2  num_3  num_4        form  tag  root root_arabic
# 0          1      1      1      2        somi    N   smw         سمو
# 1          1      1      2      1     {ll~ahi   PN   Alh         اله
# 2          1      1      3      2  r~aHoma`ni  ADJ   rHm         رحم
# 3          1      1      4      2    r~aHiymi  ADJ   rHm         رحم
# 4          1      2      1      2      Hamodu    N   Hmd         حمد
# ...      ...    ...    ...    ...         ...  ...   ...         ...
# 49963    114      5      2      1  yuwasowisu    V  wsws        وسوس
# 49964    114      5      4      1     Suduwri    N   Sdr         صدر
# 49965    114      5      5      2      n~aAsi    N   nws         نوس
# 49966    114      6      2      2     jin~api    N   jnn         جنن
# 49967    114      6      3      3      n~aAsi    N   nws         نوس
#
# [49968 rows x 8 columns]

# %%
df_word_root_merge = pd.merge(df_word_merge,df_root, how="left", on=["num_1","num_2","num_3"])
df_word_root_merge = df_word_root_merge.iloc[:,[0,1,2,3,4,5,6,7,9,11,12,10]]
df_word_root_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78244    114      5      4                     صدور
# 78245    114      5      5                    الناس
# 78246    114      6      1                       من
# 78247    114      6      2                    الجنة
# 78248    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# 4                            AlHmd                الْحَمْدُ
# ...                            ...                      ...
# 78244                         Sdwr                  صُدُورِ
# 78245                        AlnAs                 النَّاسِ
# 78246                           mn                     مِنَ
# 78247                        Aljnp               الْجِنَّةِ
# 78248                       wAlnAs               وَالنَّاسِ
#
#       buckwalter_word_tanzil_plain  color        form root root_arabic  tag
# 0                           bisomi      1        somi  smw         سمو    N
# 1                          All~ahi      1     {ll~ahi  Alh         اله   PN
# 2                     Alr~aHoma`ni      1  r~aHoma`ni  rHm         رحم  ADJ
# 3                       Alr~aHiymi      1    r~aHiymi  rHm         رحم  ADJ
# 4                        AloHamodu      0      Hamodu  Hmd         حمد    N
# ...                            ...    ...         ...  ...         ...  ...
# 78244                      Suduwri      0     Suduwri  Sdr         صدر    N
# 78245                     Aln~aAsi      1      n~aAsi  nws         نوس    N
# 78246                         mina      1         NaN  NaN         NaN  NaN
# 78247                   Alojin~api      0     jin~api  jnn         جنن    N
# 78248                   waAln~aAsi      0      n~aAsi  nws         نوس    N
#
# [78249 rows x 12 columns]

# %%
df_word_root_merge.drop_duplicates(inplace=True)

# %%
df_word_root_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78244    114      5      4                     صدور
# 78245    114      5      5                    الناس
# 78246    114      6      1                       من
# 78247    114      6      2                    الجنة
# 78248    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# 4                            AlHmd                الْحَمْدُ
# ...                            ...                      ...
# 78244                         Sdwr                  صُدُورِ
# 78245                        AlnAs                 النَّاسِ
# 78246                           mn                     مِنَ
# 78247                        Aljnp               الْجِنَّةِ
# 78248                       wAlnAs               وَالنَّاسِ
#
#       buckwalter_word_tanzil_plain  color        form root root_arabic  tag
# 0                           bisomi      1        somi  smw         سمو    N
# 1                          All~ahi      1     {ll~ahi  Alh         اله   PN
# 2                     Alr~aHoma`ni      1  r~aHoma`ni  rHm         رحم  ADJ
# 3                       Alr~aHiymi      1    r~aHiymi  rHm         رحم  ADJ
# 4                        AloHamodu      0      Hamodu  Hmd         حمد    N
# ...                            ...    ...         ...  ...         ...  ...
# 78244                      Suduwri      0     Suduwri  Sdr         صدر    N
# 78245                     Aln~aAsi      1      n~aAsi  nws         نوس    N
# 78246                         mina      1         NaN  NaN         NaN  NaN
# 78247                   Alojin~api      0     jin~api  jnn         جنن    N
# 78248                   waAln~aAsi      0      n~aAsi  nws         نوس    N
#
# [78249 rows x 12 columns]

# %%
df_word_root_merge.color.sum()
# Out:
# 29644

# %%
#a = set(df_word_root_merge.iloc[:,6])
#b = set(df_word_merge.iloc[:,6])
#a.difference(b)

# %%
#df_word_root_merge.to_excel("Arabic_Buckwalter_Word_Root_Color.xlsx",index=False)

# %% [markdown]
# #### Adding Juz Surah Name Word Count And Letter Count

# %%
df_verse = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Text/Data/Dataset-Verse-by-Verse.xlsx")
df_verse = df_verse.iloc[:,[4,10,1,5,6,14,15]]
df_verse.rename(columns={"SurahNo":"num_1","AyahNo":"num_2"}, inplace=True)
df_verse
# Out:
#       num_1  num_2  Juz SurahNameArabic SurahNameEnglish  ArabicWordCount  \
# 0         1      1    1         الفاتحة        Al-Fatiha                4
# 1         1      2    1         الفاتحة        Al-Fatiha                4
# 2         1      3    1         الفاتحة        Al-Fatiha                2
# 3         1      4    1         الفاتحة        Al-Fatiha                3
# 4         1      5    1         الفاتحة        Al-Fatiha                4
# ...     ...    ...  ...             ...              ...              ...
# 6231    114      2   30           الناس           An-Nas                2
# 6232    114      3   30           الناس           An-Nas                2
# 6233    114      4   30           الناس           An-Nas                4
# 6234    114      5   30           الناس           An-Nas                5
# 6235    114      6   30           الناس           An-Nas                3
#
#       ArabicLetterCount
# 0                    19
# 1                    18
# 2                    12
# 3                    12
# 4                    19
# ...                 ...
# 6231                  8
# 6232                  8
# 6233                 17
# 6234                 20
# 6235                 13
#
# [6236 rows x 7 columns]

# %%
df_verse.ArabicWordCount.sum()
# Out:
# 82176

# %%
df_word_root_juz_name_merge = pd.merge(df_word_root_merge, df_verse, how="left", on=["num_1","num_2"])
df_word_root_juz_name_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78244    114      5      4                     صدور
# 78245    114      5      5                    الناس
# 78246    114      6      1                       من
# 78247    114      6      2                    الجنة
# 78248    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# 4                            AlHmd                الْحَمْدُ
# ...                            ...                      ...
# 78244                         Sdwr                  صُدُورِ
# 78245                        AlnAs                 النَّاسِ
# 78246                           mn                     مِنَ
# 78247                        Aljnp               الْجِنَّةِ
# 78248                       wAlnAs               وَالنَّاسِ
#
#       buckwalter_word_tanzil_plain  color        form root root_arabic  tag  \
# 0                           bisomi      1        somi  smw         سمو    N
# 1                          All~ahi      1     {ll~ahi  Alh         اله   PN
# 2                     Alr~aHoma`ni      1  r~aHoma`ni  rHm         رحم  ADJ
# 3                       Alr~aHiymi      1    r~aHiymi  rHm         رحم  ADJ
# 4                        AloHamodu      0      Hamodu  Hmd         حمد    N
# ...                            ...    ...         ...  ...         ...  ...
# 78244                      Suduwri      0     Suduwri  Sdr         صدر    N
# 78245                     Aln~aAsi      1      n~aAsi  nws         نوس    N
# 78246                         mina      1         NaN  NaN         NaN  NaN
# 78247                   Alojin~api      0     jin~api  jnn         جنن    N
# 78248                   waAln~aAsi      0      n~aAsi  nws         نوس    N
#
#        Juz SurahNameArabic SurahNameEnglish  ArabicWordCount  \
# 0        1         الفاتحة        Al-Fatiha                4
# 1        1         الفاتحة        Al-Fatiha                4
# 2        1         الفاتحة        Al-Fatiha                4
# 3        1         الفاتحة        Al-Fatiha                4
# 4        1         الفاتحة        Al-Fatiha                4
# ...    ...             ...              ...              ...
# 78244   30           الناس           An-Nas                5
# 78245   30           الناس           An-Nas                5
# 78246   30           الناس           An-Nas                3
# 78247   30           الناس           An-Nas                3
# 78248   30           الناس           An-Nas                3
#
#        ArabicLetterCount
# 0                     19
# 1                     19
# 2                     19
# 3                     19
# 4                     18
# ...                  ...
# 78244                 20
# 78245                 20
# 78246                 13
# 78247                 13
# 78248                 13
#
# [78249 rows x 17 columns]

# %%
#df_word_root_juz_name_merge.to_excel("Arabic_Buckwalter_Word_Root_Color_Juz_Name.xlsx",index=False)

# %%
# # Color Order Func
# for i in range(len(df_word_root_juz_name_merge)):
#     if df_word_root_juz_name_merge.loc[i,"color"] == 1:
#         word = df_word_root_juz_name_merge.loc[i,"arabic_word_tanzil_clean"]
#         freq = df_select_word[df_select_word.buckwalter_word_tanzil_clean.str.contains(fr"(?:\s|^){word}(?:\s|$)", na=True)]["frequency"]
#         if freq >= 2000:
#             df_word_root_juz_name_merge.loc[i,"color"] == 5
#         elif freq >= 1500:
#             df_word_root_juz_name_merge.loc[i,"color"] == 4
#         elif freq >= 1000:
#             df_word_root_juz_name_merge.loc[i,"color"] == 3
#         elif freq >= 500:
#             df_word_root_juz_name_merge.loc[i,"color"] == 2
#         else:
#             df_word_root_juz_name_merge.loc[i,"color"] == 1
#     else:
#         df_word_root_juz_name_merge.loc[i,"color"] == 0

# %% [markdown]
# #### Adding Page Number

# %%
df_page = pd.read_json("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Text/Data/pages.json")
df_page
# Out:
#                                           0  \
# 0        {'surah': 1, 'start': 1, 'end': 7}
# 1        {'surah': 2, 'start': 1, 'end': 5}
# 2       {'surah': 2, 'start': 6, 'end': 16}
# 3      {'surah': 2, 'start': 17, 'end': 24}
# 4      {'surah': 2, 'start': 25, 'end': 29}
# ..                                      ...
# 599  {'surah': 100, 'start': 10, 'end': 10}
# 600    {'surah': 103, 'start': 1, 'end': 1}
# 601    {'surah': 106, 'start': 1, 'end': 1}
# 602    {'surah': 109, 'start': 1, 'end': 1}
# 603    {'surah': 112, 'start': 1, 'end': 1}
#
#                                         1  \
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ..                                    ...
# 599  {'surah': 101, 'start': 1, 'end': 1}
# 600  {'surah': 104, 'start': 1, 'end': 1}
# 601  {'surah': 107, 'start': 1, 'end': 1}
# 602  {'surah': 110, 'start': 1, 'end': 1}
# 603  {'surah': 113, 'start': 1, 'end': 1}
#
#                                         2
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ..                                    ...
# 599  {'surah': 102, 'start': 1, 'end': 1}
# 600  {'surah': 105, 'start': 1, 'end': 1}
# 601  {'surah': 108, 'start': 1, 'end': 1}
# 602  {'surah': 111, 'start': 1, 'end': 1}
# 603  {'surah': 114, 'start': 1, 'end': 1}
#
# [604 rows x 3 columns]

# %%
df_page2 = pd.DataFrame(df_page.iloc[:,0])
df_page2
# Out:
#                                           0
# 0        {'surah': 1, 'start': 1, 'end': 7}
# 1        {'surah': 2, 'start': 1, 'end': 5}
# 2       {'surah': 2, 'start': 6, 'end': 16}
# 3      {'surah': 2, 'start': 17, 'end': 24}
# 4      {'surah': 2, 'start': 25, 'end': 29}
# ..                                      ...
# 599  {'surah': 100, 'start': 10, 'end': 10}
# 600    {'surah': 103, 'start': 1, 'end': 1}
# 601    {'surah': 106, 'start': 1, 'end': 1}
# 602    {'surah': 109, 'start': 1, 'end': 1}
# 603    {'surah': 112, 'start': 1, 'end': 1}
#
# [604 rows x 1 columns]

# %%
page_list = []
for i in df_page2.iloc[:,0]:
    surah = i["surah"]
    start = i["start"]
    end = i["end"]
    page_list.append((surah,start,end))
#page_list

# %%
df_page_new = pd.DataFrame(page_list)
df_page_new.reset_index(inplace=True)
df_page_new.rename(columns={0:"surah",1:"start",2:"end","index":"page"}, inplace=True)
df_page_new = df_page_new.iloc[:,[1,2,3,0]]
df_page_new["page"] = df_page_new["page"].apply(lambda x: x+1)
df_page_new
# Out:
#      surah  start  end  page
# 0        1      1    7     1
# 1        2      1    5     2
# 2        2      6   16     3
# 3        2     17   24     4
# 4        2     25   29     5
# ..     ...    ...  ...   ...
# 599    100     10   10   600
# 600    103      1    1   601
# 601    106      1    1   602
# 602    109      1    1   603
# 603    112      1    1   604
#
# [604 rows x 4 columns]

# %%
#df_page_new.to_excel("Quran_Page_Num_Loc.xlsx", index=False)

# %%
df_word_root_juz_name_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78244    114      5      4                     صدور
# 78245    114      5      5                    الناس
# 78246    114      6      1                       من
# 78247    114      6      2                    الجنة
# 78248    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# 4                            AlHmd                الْحَمْدُ
# ...                            ...                      ...
# 78244                         Sdwr                  صُدُورِ
# 78245                        AlnAs                 النَّاسِ
# 78246                           mn                     مِنَ
# 78247                        Aljnp               الْجِنَّةِ
# 78248                       wAlnAs               وَالنَّاسِ
#
#       buckwalter_word_tanzil_plain  color        form root root_arabic  tag  \
# 0                           bisomi      1        somi  smw         سمو    N
# 1                          All~ahi      1     {ll~ahi  Alh         اله   PN
# 2                     Alr~aHoma`ni      1  r~aHoma`ni  rHm         رحم  ADJ
# 3                       Alr~aHiymi      1    r~aHiymi  rHm         رحم  ADJ
# 4                        AloHamodu      0      Hamodu  Hmd         حمد    N
# ...                            ...    ...         ...  ...         ...  ...
# 78244                      Suduwri      0     Suduwri  Sdr         صدر    N
# 78245                     Aln~aAsi      1      n~aAsi  nws         نوس    N
# 78246                         mina      1         NaN  NaN         NaN  NaN
# 78247                   Alojin~api      0     jin~api  jnn         جنن    N
# 78248                   waAln~aAsi      0      n~aAsi  nws         نوس    N
#
#        Juz SurahNameArabic SurahNameEnglish  ArabicWordCount  \
# 0        1         الفاتحة        Al-Fatiha                4
# 1        1         الفاتحة        Al-Fatiha                4
# 2        1         الفاتحة        Al-Fatiha                4
# 3        1         الفاتحة        Al-Fatiha                4
# 4        1         الفاتحة        Al-Fatiha                4
# ...    ...             ...              ...              ...
# 78244   30           الناس           An-Nas                5
# 78245   30           الناس           An-Nas                5
# 78246   30           الناس           An-Nas                3
# 78247   30           الناس           An-Nas                3
# 78248   30           الناس           An-Nas                3
#
#        ArabicLetterCount
# 0                     19
# 1                     19
# 2                     19
# 3                     19
# 4                     18
# ...                  ...
# 78244                 20
# 78245                 20
# 78246                 13
# 78247                 13
# 78248                 13
#
# [78249 rows x 17 columns]

# %%
for i in range(len(df_page_new)):
    surah = df_page_new.loc[i,"surah"]
    start = df_page_new.loc[i,"start"]
    end = df_page_new.loc[i,"end"]
    page = df_page_new.loc[i,"page"]
    for j in range(len(df_word_root_juz_name_merge)):
        if (df_word_root_juz_name_merge.loc[j,"num_1"] == surah and df_word_root_juz_name_merge.loc[j,"num_2"] >= start and df_word_root_juz_name_merge.loc[j,"num_2"] <= end):
            df_word_root_juz_name_merge.loc[j,"page"] = page
        else:
            pass

# %%
df_word_root_juz_name_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78244    114      5      4                     صدور
# 78245    114      5      5                    الناس
# 78246    114      6      1                       من
# 78247    114      6      2                    الجنة
# 78248    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# 4                            AlHmd                الْحَمْدُ
# ...                            ...                      ...
# 78244                         Sdwr                  صُدُورِ
# 78245                        AlnAs                 النَّاسِ
# 78246                           mn                     مِنَ
# 78247                        Aljnp               الْجِنَّةِ
# 78248                       wAlnAs               وَالنَّاسِ
#
#       buckwalter_word_tanzil_plain  color        form root root_arabic  tag  \
# 0                           bisomi      1        somi  smw         سمو    N
# 1                          All~ahi      1     {ll~ahi  Alh         اله   PN
# 2                     Alr~aHoma`ni      1  r~aHoma`ni  rHm         رحم  ADJ
# 3                       Alr~aHiymi      1    r~aHiymi  rHm         رحم  ADJ
# 4                        AloHamodu      0      Hamodu  Hmd         حمد    N
# ...                            ...    ...         ...  ...         ...  ...
# 78244                      Suduwri      0     Suduwri  Sdr         صدر    N
# 78245                     Aln~aAsi      1      n~aAsi  nws         نوس    N
# 78246                         mina      1         NaN  NaN         NaN  NaN
# 78247                   Alojin~api      0     jin~api  jnn         جنن    N
# 78248                   waAln~aAsi      0      n~aAsi  nws         نوس    N
#
#        Juz SurahNameArabic SurahNameEnglish  ArabicWordCount  \
# 0        1         الفاتحة        Al-Fatiha                4
# 1        1         الفاتحة        Al-Fatiha                4
# 2        1         الفاتحة        Al-Fatiha                4
# 3        1         الفاتحة        Al-Fatiha                4
# 4        1         الفاتحة        Al-Fatiha                4
# ...    ...             ...              ...              ...
# 78244   30           الناس           An-Nas                5
# 78245   30           الناس           An-Nas                5
# 78246   30           الناس           An-Nas                3
# 78247   30           الناس           An-Nas                3
# 78248   30           الناس           An-Nas                3
#
#        ArabicLetterCount  page
# 0                     19   1.0
# 1                     19   1.0
# 2                     19   1.0
# 3                     19   1.0
# 4                     18   1.0
# ...                  ...   ...
# 78244                 20   NaN
# 78245                 20   NaN
# 78246                 13   NaN
# 78247                 13   NaN
# 78248                 13   NaN
#
# [78249 rows x 18 columns]

# %%
df_word_root_juz_name_merge["page"].fillna(method='ffill', inplace=True) # 'ffill'forward filling method as fill with first previous value, 'bfill'backward filling method

# %%
df_word_root_juz_name_merge
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          1      1      1                      بسم
# 1          1      1      2                     الله
# 2          1      1      3                   الرحمن
# 3          1      1      4                   الرحيم
# 4          1      2      1                    الحمد
# ...      ...    ...    ...                      ...
# 78244    114      5      4                     صدور
# 78245    114      5      5                    الناس
# 78246    114      6      1                       من
# 78247    114      6      2                    الجنة
# 78248    114      6      3                   والناس
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 0                              bsm                   بِسْمِ
# 1                             Allh                  اللَّهِ
# 2                           AlrHmn             الرَّحْمَٰنِ
# 3                           AlrHym               الرَّحِيمِ
# 4                            AlHmd                الْحَمْدُ
# ...                            ...                      ...
# 78244                         Sdwr                  صُدُورِ
# 78245                        AlnAs                 النَّاسِ
# 78246                           mn                     مِنَ
# 78247                        Aljnp               الْجِنَّةِ
# 78248                       wAlnAs               وَالنَّاسِ
#
#       buckwalter_word_tanzil_plain  color        form root root_arabic  tag  \
# 0                           bisomi      1        somi  smw         سمو    N
# 1                          All~ahi      1     {ll~ahi  Alh         اله   PN
# 2                     Alr~aHoma`ni      1  r~aHoma`ni  rHm         رحم  ADJ
# 3                       Alr~aHiymi      1    r~aHiymi  rHm         رحم  ADJ
# 4                        AloHamodu      0      Hamodu  Hmd         حمد    N
# ...                            ...    ...         ...  ...         ...  ...
# 78244                      Suduwri      0     Suduwri  Sdr         صدر    N
# 78245                     Aln~aAsi      1      n~aAsi  nws         نوس    N
# 78246                         mina      1         NaN  NaN         NaN  NaN
# 78247                   Alojin~api      0     jin~api  jnn         جنن    N
# 78248                   waAln~aAsi      0      n~aAsi  nws         نوس    N
#
#        Juz SurahNameArabic SurahNameEnglish  ArabicWordCount  \
# 0        1         الفاتحة        Al-Fatiha                4
# 1        1         الفاتحة        Al-Fatiha                4
# 2        1         الفاتحة        Al-Fatiha                4
# 3        1         الفاتحة        Al-Fatiha                4
# 4        1         الفاتحة        Al-Fatiha                4
# ...    ...             ...              ...              ...
# 78244   30           الناس           An-Nas                5
# 78245   30           الناس           An-Nas                5
# 78246   30           الناس           An-Nas                3
# 78247   30           الناس           An-Nas                3
# 78248   30           الناس           An-Nas                3
#
#        ArabicLetterCount   page
# 0                     19    1.0
# 1                     19    1.0
# 2                     19    1.0
# 3                     19    1.0
# 4                     18    1.0
# ...                  ...    ...
# 78244                 20  604.0
# 78245                 20  604.0
# 78246                 13  604.0
# 78247                 13  604.0
# 78248                 13  604.0
#
# [78249 rows x 18 columns]

# %%
#df_word_root_juz_name_merge.to_excel("Arabic_Buckwalter_Word_Root_Color_Juz_Name_Page.xlsx",index=False)

# %% [markdown]
# #### Adding N Gram Flag

# %%
n_gram_num = 100
df_twogram = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Text/Result/4-N Gram/Arabic_Clean_Twogram_Frequency_From_DataFrame_Tanzil.xlsx")
df_twogram = df_twogram.head(n_gram_num)
df_twogram
# Out:
#           twogram buckwalter_twogram  frequency
# 0         إن الله            <n Allh        205
# 1     الذين آمنوا        Al*yn |mnwA        184
# 2        في الأرض           fy Al>rD        176
# 3         يا أيها            yA >yhA        142
# 4     الذين كفروا        Al*yn kfrwA        134
# ..            ...                ...        ...
# 95       بما كنتم           bmA kntm         29
# 96       الله كان           Allh kAn         29
# 97  العزيز الحكيم      AlEzyz AlHkym         29
# 98   خلق السماوات       xlq AlsmAwAt         29
# 99          ما لا              mA lA         29
#
# [100 rows x 3 columns]

# %%
df_sent = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Text/Result/5-Tanzil Analysis/Arabic_Buckwalter_Sent_Tanzil_Clean.xlsx")
df_sent
# Out:
#       num_1  num_2  arabic_sent_tanzil_clean buckwalter_sent_tanzil_clean
# 0         1      1    بسم الله الرحمن الرحيم       bsm Allh AlrHmn AlrHym
# 1         1      2     الحمد لله رب العالمين        AlHmd llh rb AlEAlmyn
# 2         1      3             الرحمن الرحيم                AlrHmn AlrHym
# 3         1      4            مالك يوم الدين               mAlk ywm Aldyn
# 4         1      5    إياك نعبد وإياك نستعين       <yAk nEbd w<yAk nstEyn
# ...     ...    ...                       ...                          ...
# 6231    114      2                 ملك الناس                    mlk AlnAs
# 6232    114      3                 إله الناس                    <lh AlnAs
# 6233    114      4      من شر الوسواس الخناس         mn $r AlwswAs AlxnAs
# 6234    114      5  الذي يوسوس في صدور الناس     Al*y ywsws fy Sdwr AlnAs
# 6235    114      6           من الجنة والناس              mn Aljnp wAlnAs
#
# [6236 rows x 4 columns]

# %%
# Two Gram
df_sent_twogram_result = pd.DataFrame()
for i in df_twogram.iloc[:,0]:
    try:
        sent_in_video = df_sent[df_sent.arabic_sent_tanzil_clean.str.contains(fr"(^|\s){i}(\s|$)", regex=True)]
        #sent_in_video = df_sent[df_sent.arabic_sent_tanzil_clean.str.contains(fr"(^|\s){i}(\s|$)")].sample(10)
    except:
        sent_in_video = df_sent[df_sent.arabic_sent_tanzil_clean.str.contains(fr"(^|\s){i}(\s|$)", regex=True)] 
        #sent_in_video = df_sent[df_sent.arabic_sent_tanzil_clean.str.contains(fr"(^|\s){i}(\s|$)")].head(10) 
    sent_in_video.insert(0,"twogram",i)
    df_sent_twogram_result = pd.concat([df_sent_twogram_result,sent_in_video], axis=0)
df_sent_twogram_result.reset_index(drop=True, inplace=True)
df_sent_twogram_result
# Out:
# <ipython-input-8-40e6f74a9873>:5: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   sent_in_video = df_sent[df_sent.arabic_sent_tanzil_clean.str.contains(fr"(^|\s){i}(\s|$)", regex=True)]
#       twogram  num_1  num_2  \
# 0     إن الله      2     20
# 1     إن الله      2     26
# 2     إن الله      2     67
# 3     إن الله      2    109
# 4     إن الله      2    110
# ...       ...    ...    ...
# 5432    ما لا     25     55
# 5433    ما لا     26    226
# 5434    ما لا     56     61
# 5435    ما لا     61      2
# 5436    ما لا     61      3
#
#                                arabic_sent_tanzil_clean  \
# 0     يكاد البرق يخطف أبصارهم كلما أضاء لهم مشوا فيه...
# 1     إن الله لا يستحيي أن يضرب مثلا ما بعوضة فما فو...
# 2     وإذ قال موسى لقومه إن الله يأمركم أن تذبحوا بق...
# 3     ود كثير من أهل الكتاب لو يردونكم من بعد إيمانك...
# 4     وأقيموا الصلاة وآتوا الزكاة وما تقدموا لأنفسكم...
# ...                                                 ...
# 5432  ويعبدون من دون الله ما لا ينفعهم ولا يضرهم وكا...
# 5433                          وأنهم يقولون ما لا يفعلون
# 5434        على أن نبدل أمثالكم وننشئكم في ما لا تعلمون
# 5435         يا أيها الذين آمنوا لم تقولون ما لا تفعلون
# 5436           كبر مقتا عند الله أن تقولوا ما لا تفعلون
#
#                            buckwalter_sent_tanzil_clean
# 0     ykAd Albrq yxTf >bSArhm klmA >DA' lhm m$wA fyh...
# 1     <n Allh lA ystHyy >n yDrb mvlA mA bEwDp fmA fw...
# 2     w<* qAl mwsY lqwmh <n Allh y>mrkm >n t*bHwA bq...
# 3     wd kvyr mn >hl AlktAb lw yrdwnkm mn bEd <ymAnk...
# 4     w>qymwA AlSlAp w|twA AlzkAp wmA tqdmwA l>nfskm...
# ...                                                 ...
# 5432  wyEbdwn mn dwn Allh mA lA ynfEhm wlA yDrhm wkA...
# 5433                          w>nhm yqwlwn mA lA yfElwn
# 5434        ElY >n nbdl >mvAlkm wnn$}km fy mA lA tElmwn
# 5435         yA >yhA Al*yn |mnwA lm tqwlwn mA lA tfElwn
# 5436           kbr mqtA End Allh >n tqwlwA mA lA tfElwn
#
# [5437 rows x 5 columns]

# %%
# ngram_loc_list = []
# for i in range(len(df_sent_ngram_result)):
#     num_1 = df_sent_ngram_result.loc[i,"num_1"]
#     num_2 = df_sent_ngram_result.loc[i,"num_2"]
#     sent = df_sent_ngram_result.loc[i,"arabic_sent_tanzil_clean"]
#     ngram = df_sent_ngram_result.loc[i,"ngram"]
#     sent_token = word_tokenize(sent)
#     ngram_token = word_tokenize(ngram)
#     for j in ngram_token:
#         for k in range(len(sent_token)):
#             if j == sent_token[k]:
#                 num_3 = k+1
#                 ngram_loc_list.append((num_1,num_2,num_3,j,sent))
#                 
# df_ngram_loc = pd.DataFrame(ngram_loc_list)
# df_ngram_loc.rename(columns={0:"num_1",1:"num_2",2:"num_3",3:"ngram_word",4:"arabic_sent_tanzil_clean"},inplace=True)
# df_ngram_loc

# %%
# Two Gram
twogram_loc_list = []
for i in range(len(df_sent_twogram_result)):
    num_1 = df_sent_twogram_result.loc[i,"num_1"]
    num_2 = df_sent_twogram_result.loc[i,"num_2"]
    sent = df_sent_twogram_result.loc[i,"arabic_sent_tanzil_clean"]
    ngram = df_sent_twogram_result.loc[i,"twogram"]
    sent_token = word_tokenize(sent)
    ngram_token = word_tokenize(ngram)    
    for j in range(len(ngram_token)):        
        for k in range(len(sent_token)):
            if ngram_token[j] == sent_token[k]:
                try:
                    if ngram_token[j+1] == sent_token[k+1]:
                        num_3 = k+1
                        twogram_loc_list.append((num_1,num_2,num_3,ngram_token[j],sent))
                        twogram_loc_list.append((num_1,num_2,num_3+1,ngram_token[j+1],sent))
                except:
                    pass
                
df_twogram_loc = pd.DataFrame(twogram_loc_list)
df_twogram_loc.rename(columns={0:"num_1",1:"num_2",2:"num_3",3:"arabic_word_tanzil_clean",4:"arabic_sent_tanzil_clean"},inplace=True)
df_twogram_loc["two_flag"] = 1
df_twogram_loc
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0          2     20     20                       إن
# 1          2     20     21                     الله
# 2          2     26      1                       إن
# 3          2     26      2                     الله
# 4          2     67      5                       إن
# ...      ...    ...    ...                      ...
# 11033     56     61      8                       لا
# 11034     61      2      7                       ما
# 11035     61      2      8                       لا
# 11036     61      3      7                       ما
# 11037     61      3      8                       لا
#
#                                 arabic_sent_tanzil_clean  two_flag
# 0      يكاد البرق يخطف أبصارهم كلما أضاء لهم مشوا فيه...         1
# 1      يكاد البرق يخطف أبصارهم كلما أضاء لهم مشوا فيه...         1
# 2      إن الله لا يستحيي أن يضرب مثلا ما بعوضة فما فو...         1
# 3      إن الله لا يستحيي أن يضرب مثلا ما بعوضة فما فو...         1
# 4      وإذ قال موسى لقومه إن الله يأمركم أن تذبحوا بق...         1
# ...                                                  ...       ...
# 11033        على أن نبدل أمثالكم وننشئكم في ما لا تعلمون         1
# 11034         يا أيها الذين آمنوا لم تقولون ما لا تفعلون         1
# 11035         يا أيها الذين آمنوا لم تقولون ما لا تفعلون         1
# 11036           كبر مقتا عند الله أن تقولوا ما لا تفعلون         1
# 11037           كبر مقتا عند الله أن تقولوا ما لا تفعلون         1
#
# [11038 rows x 6 columns]

# %%
df_twogram_loc.to_excel("Arabic_Twogram_Loc_With_Sent.xlsx",index=False)

# %%
n_gram_num = 100
df_threegram = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Text/Result/4-N Gram/Arabic_Clean_Threegram_Frequency_From_DataFrame_Tanzil.xlsx")
df_threegram = df_threegram.head(n_gram_num)
df_threegram
# Out:
#              threegram buckwalter_threegram  frequency
# 0      بسم الله الرحمن      bsm Allh AlrHmn        114
# 1   الله الرحمن الرحيم   Allh AlrHmn AlrHym        114
# 2        يا أيها الذين        yA >yhA Al*yn         92
# 3     أيها الذين آمنوا     >yhA Al*yn |mnwA         89
# 4          من دون الله          mn dwn Allh         71
# ..                 ...                  ...        ...
# 95    عليم بذات الصدور     Elym b*At AlSdwr         12
# 96        والله على كل         wAllh ElY kl         12
# 97        وما أدراك ما         wmA >drAk mA         12
# 98     واعلموا أن الله      wAElmwA >n Allh         12
# 99        تر إلى الذين         tr <lY Al*yn         12
#
# [100 rows x 3 columns]

# %%
# Three Gram
df_sent_threegram_result = pd.DataFrame()
for i in df_threegram.iloc[:,0]:
    try:
        sent_in_video = df_sent[df_sent.arabic_sent_tanzil_clean.str.contains(fr"(^|\s){i}(\s|$)", regex=True)]
        #sent_in_video = df_sent[df_sent.arabic_sent_tanzil_clean.str.contains(fr"(^|\s){i}(\s|$)")].sample(10)
    except:
        sent_in_video = df_sent[df_sent.arabic_sent_tanzil_clean.str.contains(fr"(^|\s){i}(\s|$)", regex=True)] 
        #sent_in_video = df_sent[df_sent.arabic_sent_tanzil_clean.str.contains(fr"(^|\s){i}(\s|$)")].head(10) 
    sent_in_video.insert(0,"threegram",i)
    df_sent_threegram_result = pd.concat([df_sent_threegram_result,sent_in_video], axis=0)
df_sent_threegram_result.reset_index(drop=True, inplace=True)
df_sent_threegram_result
# Out:
# <ipython-input-16-4b5e989fca7f>:5: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   sent_in_video = df_sent[df_sent.arabic_sent_tanzil_clean.str.contains(fr"(^|\s){i}(\s|$)", regex=True)]
#             threegram  num_1  num_2  \
# 0     بسم الله الرحمن      1      1
# 1     بسم الله الرحمن      2      1
# 2     بسم الله الرحمن      3      1
# 3     بسم الله الرحمن      4      1
# 4     بسم الله الرحمن      5      1
# ...               ...    ...    ...
# 2389     تر إلى الذين     14     28
# 2390     تر إلى الذين     40     69
# 2391     تر إلى الذين     58      8
# 2392     تر إلى الذين     58     14
# 2393     تر إلى الذين     59     11
#
#                                arabic_sent_tanzil_clean  \
# 0                                بسم الله الرحمن الرحيم
# 1                            بسم الله الرحمن الرحيم الم
# 2                            بسم الله الرحمن الرحيم الم
# 3     بسم الله الرحمن الرحيم يا أيها الناس اتقوا ربك...
# 4     بسم الله الرحمن الرحيم يا أيها الذين آمنوا أوف...
# ...                                                 ...
# 2389  ألم تر إلى الذين بدلوا نعمت الله كفرا وأحلوا ق...
# 2390   ألم تر إلى الذين يجادلون في آيات الله أنى يصرفون
# 2391  ألم تر إلى الذين نهوا عن النجوى ثم يعودون لما ...
# 2392  ألم تر إلى الذين تولوا قوما غضب الله عليهم ما ...
# 2393  ألم تر إلى الذين نافقوا يقولون لإخوانهم الذين ...
#
#                            buckwalter_sent_tanzil_clean
# 0                                bsm Allh AlrHmn AlrHym
# 1                            bsm Allh AlrHmn AlrHym Alm
# 2                            bsm Allh AlrHmn AlrHym Alm
# 3     bsm Allh AlrHmn AlrHym yA >yhA AlnAs AtqwA rbk...
# 4     bsm Allh AlrHmn AlrHym yA >yhA Al*yn |mnwA >wf...
# ...                                                 ...
# 2389  >lm tr <lY Al*yn bdlwA nEmt Allh kfrA w>HlwA q...
# 2390   >lm tr <lY Al*yn yjAdlwn fy |yAt Allh >nY ySrfwn
# 2391  >lm tr <lY Al*yn nhwA En AlnjwY vm yEwdwn lmA ...
# 2392  >lm tr <lY Al*yn twlwA qwmA gDb Allh Elyhm mA ...
# 2393  >lm tr <lY Al*yn nAfqwA yqwlwn l<xwAnhm Al*yn ...
#
# [2394 rows x 5 columns]

# %%
# Three Gram
threegram_loc_list = []
for i in range(len(df_sent_threegram_result)):
    num_1 = df_sent_threegram_result.loc[i,"num_1"]
    num_2 = df_sent_threegram_result.loc[i,"num_2"]
    sent = df_sent_threegram_result.loc[i,"arabic_sent_tanzil_clean"]
    ngram = df_sent_threegram_result.loc[i,"threegram"]
    sent_token = word_tokenize(sent)
    ngram_token = word_tokenize(ngram)    
    for j in range(len(ngram_token)):        
        for k in range(len(sent_token)):
            if ngram_token[j] == sent_token[k]:
                try:
                    if ngram_token[j+1] == sent_token[k+1]:
                        if ngram_token[j+2] == sent_token[k+2]:
                            num_3 = k+1
                            threegram_loc_list.append((num_1,num_2,num_3,ngram_token[j],sent))
                            threegram_loc_list.append((num_1,num_2,num_3+1,ngram_token[j+1],sent))
                            threegram_loc_list.append((num_1,num_2,num_3+2,ngram_token[j+2],sent))
                except:
                    pass
                
df_threegram_loc = pd.DataFrame(threegram_loc_list)
df_threegram_loc.rename(columns={0:"num_1",1:"num_2",2:"num_3",3:"arabic_word_tanzil_clean",4:"arabic_sent_tanzil_clean"},inplace=True)
df_threegram_loc["three_flag"] = 1
df_threegram_loc
# Out:
#       num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 0         1      1      1                      بسم
# 1         1      1      2                     الله
# 2         1      1      3                   الرحمن
# 3         2      1      1                      بسم
# 4         2      1      2                     الله
# ...     ...    ...    ...                      ...
# 7225     58     14      3                      إلى
# 7226     58     14      4                    الذين
# 7227     59     11      2                       تر
# 7228     59     11      3                      إلى
# 7229     59     11      4                    الذين
#
#                                arabic_sent_tanzil_clean  three_flag
# 0                                بسم الله الرحمن الرحيم           1
# 1                                بسم الله الرحمن الرحيم           1
# 2                                بسم الله الرحمن الرحيم           1
# 3                            بسم الله الرحمن الرحيم الم           1
# 4                            بسم الله الرحمن الرحيم الم           1
# ...                                                 ...         ...
# 7225  ألم تر إلى الذين تولوا قوما غضب الله عليهم ما ...           1
# 7226  ألم تر إلى الذين تولوا قوما غضب الله عليهم ما ...           1
# 7227  ألم تر إلى الذين نافقوا يقولون لإخوانهم الذين ...           1
# 7228  ألم تر إلى الذين نافقوا يقولون لإخوانهم الذين ...           1
# 7229  ألم تر إلى الذين نافقوا يقولون لإخوانهم الذين ...           1
#
# [7230 rows x 6 columns]

# %%
df_threegram_loc.to_excel("Arabic_Threegram_Loc_With_Sent.xlsx",index=False)

# %% [markdown]
# #### Custom Page Unique Words

# %%
df_441 = df_word_root_juz_name_merge[df_word_root_juz_name_merge.page == 441]
df_441
# Out:
#        num_1  num_2  num_3 arabic_word_tanzil_clean  \
# 57185     36     13      1                    واضرب
# 57186     36     13      2                      لهم
# 57187     36     13      3                     مثلا
# 57188     36     13      4                    أصحاب
# 57189     36     13      5                   القرية
# ...      ...    ...    ...                      ...
# 57311     36     27      3                       لي
# 57312     36     27      4                      ربي
# 57313     36     27      5                   وجعلني
# 57314     36     27      6                       من
# 57315     36     27      7                 المكرمين
#
#       buckwalter_word_tanzil_clean arabic_word_tanzil_plain  \
# 57185                        wADrb                وَاضْرِبْ
# 57186                          lhm                   لَهُمْ
# 57187                         mvlA                  مَثَلًا
# 57188                        >SHAb                أَصْحَابَ
# 57189                       Alqryp              الْقَرْيَةِ
# ...                            ...                      ...
# 57311                           ly                      لِي
# 57312                          rby                   رَبِّي
# 57313                       wjElny              وَجَعَلَنِي
# 57314                           mn                     مِنَ
# 57315                     Almkrmyn           الْمُكْرَمِينَ
#
#       buckwalter_word_tanzil_plain  color         form root root_arabic  tag  \
# 57185                    waADoribo      0      {Doribo  Drb         ضرب    V
# 57186                       lahumo      1          NaN  NaN         NaN  NaN
# 57187                      mavalFA      0     m~avalFA  mvl         مثل    N
# 57188                    >aSoHaAba      0    >aSoHa`ba  SHb         صحب    N
# 57189                  Aloqaroyapi      0     qaroyapi  qry         قري    N
# ...                            ...    ...          ...  ...         ...  ...
# 57311                          liy      0          NaN  NaN         NaN  NaN
# 57312                       rab~iy      0        rab~i  rbb         ربب    N
# 57313                  wajaEalaniy      0       jaEala  jEl         جعل    V
# 57314                         mina      1          NaN  NaN         NaN  NaN
# 57315               Alomukoramiyna      0  mukoramiyna  krm         كرم    N
#
#        Juz SurahNameArabic SurahNameEnglish  ArabicWordCount  \
# 57185   22              يس          Ya Seen                8
# 57186   22              يس          Ya Seen                8
# 57187   22              يس          Ya Seen                8
# 57188   22              يس          Ya Seen                8
# 57189   22              يس          Ya Seen                8
# ...    ...             ...              ...              ...
# 57311   22              يس          Ya Seen                7
# 57312   22              يس          Ya Seen                7
# 57313   22              يس          Ya Seen                7
# 57314   22              يس          Ya Seen                7
# 57315   22              يس          Ya Seen                7
#
#        ArabicLetterCount   page
# 57185                 39  441.0
# 57186                 39  441.0
# 57187                 39  441.0
# 57188                 39  441.0
# 57189                 39  441.0
# ...                  ...    ...
# 57311                 27  441.0
# 57312                 27  441.0
# 57313                 27  441.0
# 57314                 27  441.0
# 57315                 27  441.0
#
# [131 rows x 18 columns]

# %%
df_441_count = pd.DataFrame(df_441.groupby("arabic_word_tanzil_clean")["arabic_word_tanzil_clean"].count())
df_441_count.rename(columns={"arabic_word_tanzil_clean":"frequency"}, inplace=True)
df_441_count.reset_index(inplace=True)
df_441_count.sort_values(by="frequency", ascending=False, inplace=True)
df_441_count
# Out:
#     arabic_word_tanzil_clean  frequency
# 86                        من          5
# 66                     قالوا          4
# 71                        لا          3
# 18                       إنا          3
# 95                       وما          3
# ..                       ...        ...
# 38                        بل          1
# 37                       بكم          1
# 36                       بضر          1
# 35                       بشر          1
# 103                   ينقذون          1
#
# [104 rows x 2 columns]

# %%
#df_441_count.to_excel("Quran_Page_441_Word_And_Frequency.xlsx",index=False)

# %% [markdown]
# #### Read Json

# %%
df_json = pd.read_json("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Speech To Text/Result/abdul-basit-murattal-036.json")
df_json

# %%
df_json.results.values.tolist()

# %%
df_json2 = pd.DataFrame(df_json.results.tolist())["alternatives"]
df_json2

# %%
with open("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Speech To Text/Result/abdul-basit-murattal-036.json", "r", encoding="utf8") as file:
    json_data = json.loads(file.read())

# %%
json_data # json file and like as dict

# %%
result_data = json_data["results"] # results selected from json_data is json file
result_data  # this data is list data

# %%
df_nested_list = pd.json_normalize(result_data,record_path=["alternatives"]) # read list data
df_nested_list

# %%
result_data # data is list

# %%
result_data[0] # data is dict as json file

# %%
result_data[0]["alternatives"] # data is list

# %%
alternatives_data = result_data[0]["alternatives"]
alternatives_data  # data is list

# %%
df_nested_list2 = pd.json_normalize(alternatives_data,record_path=["words"]) # record_path, meta, meta_prefix, record_prefix 
df_nested_list2

# %%
alternatives_data2 = result_data[1]["alternatives"]
alternatives_data2  # data is list

# %%
df_nested_list3 = pd.json_normalize(alternatives_data2,record_path=["words"]) # record_path, meta, meta_prefix, record_prefix 
df_nested_list3

# %%
len(result_data)

# %%
df_word = pd.DataFrame()
for i in range(len(result_data)):
    data = result_data[i]["alternatives"]
    df_data = pd.json_normalize(data,record_path=["words"])
    df_word = pd.concat([df_word,df_data], axis=0) # attention df_word,df_data must be for ascending time 
df_word.reset_index(drop=True, inplace=True)
df_word

# %%
json_object = json.dumps(result_data, indent = 4)
json_object
