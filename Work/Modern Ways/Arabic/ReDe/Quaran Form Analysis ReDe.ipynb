# %% [markdown]
# ### Quaran Form Analysis

# %%
#!pip install lang-trans

# %%
import pandas as pd
import numpy as np
import re
from camel_tools.utils.charmap import CharMapper
from lang_trans.arabic import buckwalter

# %%
with open("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Data/Quranic Corpus Morphology.txt", "r", encoding="utf8") as file:
    text = file.read()

# %% [markdown]
# #### Form Tag

# %%
form_tag_list = re.findall("[\(\d*:\d*:\d*:\d*\)][\t](\D*)[\t][\D*]", text)

# %%
form_tag_num = re.findall("(\d*:\d*:\d*:\d*)", text)

# %%
df_word = pd.DataFrame(form_tag_num)
df_word.rename(columns={0:"loc_num"}, inplace=True)
df_word
# Out:
#           loc_num
# 0         1:1:1:1
# 1         1:1:1:2
# 2         1:1:2:1
# 3         1:1:3:1
# 4         1:1:3:2
# ...           ...
# 128214  114:6:2:1
# 128215  114:6:2:2
# 128216  114:6:3:1
# 128217  114:6:3:2
# 128218  114:6:3:3
#
# [128219 rows x 1 columns]

# %%
df_word = df_word["loc_num"].str.split(":", n=-1, expand=True)
df_word.rename(columns={0:"num_1", 1:"num_2", 2:"num_3", 3:"num_4"}, inplace=True)
df_word
# Out:
#        num_1 num_2 num_3 num_4
# 0          1     1     1     1
# 1          1     1     1     2
# 2          1     1     2     1
# 3          1     1     3     1
# 4          1     1     3     2
# ...      ...   ...   ...   ...
# 128214   114     6     2     1
# 128215   114     6     2     2
# 128216   114     6     3     1
# 128217   114     6     3     2
# 128218   114     6     3     3
#
# [128219 rows x 4 columns]

# %%
df_word["form_tag"] = pd.DataFrame(form_tag_list)
df_word
# Out:
#        num_1 num_2 num_3 num_4         form_tag
# 0          1     1     1     1            bi\tP
# 1          1     1     1     2          somi\tN
# 2          1     1     2     1      {ll~ahi\tPN
# 3          1     1     3     1          {l\tDET
# 4          1     1     3     2  r~aHoma`ni\tADJ
# ...      ...   ...   ...   ...              ...
# 128214   114     6     2     1         {lo\tDET
# 128215   114     6     2     2       jin~api\tN
# 128216   114     6     3     1         wa\tCONJ
# 128217   114     6     3     2          {l\tDET
# 128218   114     6     3     3        n~aAsi\tN
#
# [128219 rows x 5 columns]

# %%
df_word[["form","tag"]] = df_word["form_tag"].str.split("\t", n=-1, expand=True)
df_word
# Out:
#        num_1 num_2 num_3 num_4         form_tag        form   tag
# 0          1     1     1     1            bi\tP          bi     P
# 1          1     1     1     2          somi\tN        somi     N
# 2          1     1     2     1      {ll~ahi\tPN     {ll~ahi    PN
# 3          1     1     3     1          {l\tDET          {l   DET
# 4          1     1     3     2  r~aHoma`ni\tADJ  r~aHoma`ni   ADJ
# ...      ...   ...   ...   ...              ...         ...   ...
# 128214   114     6     2     1         {lo\tDET         {lo   DET
# 128215   114     6     2     2       jin~api\tN     jin~api     N
# 128216   114     6     3     1         wa\tCONJ          wa  CONJ
# 128217   114     6     3     2          {l\tDET          {l   DET
# 128218   114     6     3     3        n~aAsi\tN      n~aAsi     N
#
# [128219 rows x 7 columns]

# %%
df_word.drop(["form_tag"], axis=1, inplace=True)

# %%
df_word.drop_duplicates(inplace=True)
df_word.reset_index(drop=True, inplace=True)
df_word
# Out:
#        num_1 num_2 num_3 num_4        form   tag
# 0          1     1     1     1          bi     P
# 1          1     1     1     2        somi     N
# 2          1     1     2     1     {ll~ahi    PN
# 3          1     1     3     1          {l   DET
# 4          1     1     3     2  r~aHoma`ni   ADJ
# ...      ...   ...   ...   ...         ...   ...
# 128214   114     6     2     1         {lo   DET
# 128215   114     6     2     2     jin~api     N
# 128216   114     6     3     1          wa  CONJ
# 128217   114     6     3     2          {l   DET
# 128218   114     6     3     3      n~aAsi     N
#
# [128219 rows x 6 columns]

# %%
#df_word.to_excel("Buckwalter_Form_Tag.xlsx", sheet_name="Form_Tag", index=False)

# %%
df_word_concat = pd.DataFrame(df_word.groupby(["num_1","num_2","num_3"])["form"].sum())
df_word_concat.reset_index(inplace=True)
df_word_concat
# Out:
#       num_1 num_2 num_3          form
# 0         1     1     1        bisomi
# 1         1     1     2       {ll~ahi
# 2         1     1     3  {lr~aHoma`ni
# 3         1     1     4    {lr~aHiymi
# 4         1     2     1     {loHamodu
# ...     ...   ...   ...           ...
# 77424    99     8     2      yaEomalo
# 77425    99     8     3     mivoqaAla
# 77426    99     8     4       *ar~apK
# 77427    99     8     5        $ar~FA
# 77428    99     8     6       yarahu,
#
# [77429 rows x 4 columns]

# %%
#df_word_concat.to_excel("Buckwalter_Form_Concat.xlsx", sheet_name="Concat_Form", index=False)

# %% [markdown]
# #### Buckwalter Text

# %%
#df_word_concat = pd.read_excel("Buckwalter_Form_Concat.xlsx")

# %%
df_word_concat
# Out:
#       num_1 num_2 num_3          form
# 0         1     1     1        bisomi
# 1         1     1     2       {ll~ahi
# 2         1     1     3  {lr~aHoma`ni
# 3         1     1     4    {lr~aHiymi
# 4         1     2     1     {loHamodu
# ...     ...   ...   ...           ...
# 77424    99     8     2      yaEomalo
# 77425    99     8     3     mivoqaAla
# 77426    99     8     4       *ar~apK
# 77427    99     8     5        $ar~FA
# 77428    99     8     6       yarahu,
#
# [77429 rows x 4 columns]

# %%
#concat_list = df_word_concat.iloc[:,3].to_list()

# %%
concat_list = df_word_concat.iloc[:,3].head(500).to_list()
#concat_list = df_word_concat.iloc[:,3].to_list()

# %%
#concat_list

# %%
buckwalter_text = " ".join(concat_list)
#buckwalter_text

# %% [markdown]
# #### Arabic Text

# %%
# 1 Way camel_tools.utils.charmap
bw2ar = CharMapper.builtin_mapper('bw2ar')

# %%
#bw2ar = CharMapper.builtin_mapper('safebw2ar')

# %%
#bw2ar = CharMapper.builtin_mapper('hsb2ar')

# %%
arabic_text = bw2ar(buckwalter_text)

# %%
#arabic_text

# %%
with open("Arabic.txt", "w", encoding="utf8") as file:
    file.write(arabic_text)

# %%
# 2 Way lang_trans.arabic
arabic_text2 = buckwalter.untransliterate(arabic_text)

# %%
arabic_text2
# Out:
# 'بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ مَٰلِكِ يَوْمِ ٱلدِّينِ إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
ِى ٱلْأَرْضِ سُبْحَٰنَهُ, وَتَعَٰلَىٰ عَمَّا يُشْرِكُونَ دُونِ ٱللَّهِ مَا لَا يَضُرُّهُمْ وَلَا يَنفَعُهُمْ وَمَا سَبَقَتْ مِن رَّبِّكَ لَقُضِىَ بَيْنَهُمْ فِيمَا فِيهِ يَخْتَلِفُونَ كَانَ ٱلنَّاسُ إِلَّا^ أُمَّةً وَٰحِدَةً فَٱخْتَلَفُوا@ وَلَوْلَا كَلِمَةٌ أَكَانَ أَنذِرِ ٱلنَّاسَ وَبَشِّرِ ٱلَّذِينَ ءَامَنُو^ا@ أَنَّ لَهُمْ قَدَمَ صِدْقٍ عِندَ لِلنَّاسِ رَبِّهِمْ قَالَ ٱلْكَٰفِرُونَ إِنَّ هَٰذَا لَسَٰحِرٌ مُّبِينٌ عَجَبًا أَنْ أَوْحَيْنَا^ إِلَىٰ رَجُلٍ مِّنْهُمْ أَنْ وَيَقُولُونَ ٱلْغَيْبُ لِلَّهِ فَٱنتَظِرُو^ا@ إِنِّى مَعَكُم مِّنَ ٱلْمُنتَظِرِينَ لَوْلَا^ أُنزِلَ عَلَيْهِ ءَايَةٌ مِّن رَّبِّهِ. فَقُلْ إِنَّمَا وَإِذَا^ لَهُم مَّكْرٌ فِى^ ءَايَاتِنَا قُلِ ٱللَّهُ أَسْرَعُ مَكْرًا إِنَّ رُسُلَنَا أَذَقْنَا يَكْتُبُونَ مَا تَمْكُرُونَ ٱلنَّاسَ رَحْمَةً مِّن[ بَعْدِ ضَرَّا ...

# %%
tex = "{lD~aA^l~iyna Al^r tiloka \'aAya`tu {lokita`bi {loHakiymi daEowaY`humo >ani"

# %%
bw2ar(tex)
# Out:
# 'ٱلضَّا^لِّينَ ال^ر تِلْكَ ءَايَٰتُ ٱلْكِتَٰبِ ٱلْحَكِيمِ دَعْوَىٰهُمْ أَنِ'

# %%
# 1-Way Encoding
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2uni = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "}": u"\u0626", # hamza-on-yaa'
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "F": u"\u064B", # fatHatayn
            "N": u"\u064C", # Dammatayn
            "K": u"\u064D", # kasratayn
            "a": u"\u064E", # fatHa
            "u": u"\u064F", # Damma
            "i": u"\u0650", # kasra
            "~": u"\u0651", # shaddah
            "o": u"\u0652", # sukuun
            "`": u"\u0670", # dagger 'alif
            "{": u"\u0671", # waSla
}

def transString(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2uni.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
print(transString(u'مرحبا'))
# Out:
# mrHbA

# %%
print(transString('mrHbA', 1))
# Out:
# مرحبا

# %%
transString("{lD~aA^l~iyna Al^r tiloka \'aAya`tu {lokita`bi {loHakiymi daEowaY`humo >ani",1)
# Out:
# 'ٱلضَّا^لِّينَ ال^ر تِلْكَ ءَايَٰتُ ٱلْكِتَٰبِ ٱلْحَكِيمِ دَعْوَىٰهُمْ أَنِ'

# %%
# 2-Way Encoding Extended
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2uni = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "}": u"\u0626", # hamza-on-yaa'
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "F": u"\u064B", # fatHatayn
            "N": u"\u064C", # Dammatayn
            "K": u"\u064D", # kasratayn
            "a": u"\u064E", # fatHa
            "u": u"\u064F", # Damma
            "i": u"\u0650", # kasra
            "~": u"\u0651", # shaddah
            "o": u"\u0652", # sukuun
            "^": u"\u0653", # maddah
            "#": u"\u0654", # hamzaabove            
            "`": u"\u0670", # dagger 'alif
            "{": u"\u0671", # waSla
            ":": u"\u06DC", # smallhighseen
            "@": u"\u06DF", # smallhighroundedzero
            "\"": u"\u06E0", # smallhighuprightrectangularzero
            "[": u"\u06E2", # smallhighmeemisolatedform
            ";": u"\u06E3", # smalllowseen
            ",": u"\u06E5", # smallwaw
            ".": u"\u06E6", # smallya
            "!": u"\u06E8", # smallhighnoon
            "-": u"\u06EA", # emptycentrelowstop
            "+": u"\u06EB", # emptycentrehighstop
            "%": u"\u06EC", # roundedhighstopwithfilledcentre
            "]": u"\u06ED", # smalllowmeem
}

def transString2(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2uni.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
test = transString2(buckwalter_text, 1)
test
# Out:
# 'بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ مَٰلِكِ يَوْمِ ٱلدِّينِ إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ ٱهْدِنَا ٱلصِّرَٰطَ ٱلْمُسْتَقِيمَ صِرَٰطَ ٱلَّذِينَ أَنْعَمْتَ عَلَيْهِمْ غَيْرِ ٱلْمَغْضُوبِ عَلَيْهِمْ وَلَا ٱلضَّآلِّينَ الٓر تِلْكَ ءَايَٰتُ ٱلْكِتَٰبِ ٱلْحَكِيمِ دَعْوَىٰهُمْ أَنِ ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ فِيهَا سُبْحَٰنَكَ ٱللَّهُمَّ وَتَحِيَّتُهُمْ فِيهَا سَلَٰمٌ وَءَاخِرُ دَعْوَىٰهُمْ وَمَا ٱلرِّجْسَ عَلَى ٱلَّذِينَ لَا يَعْقِلُونَ كَانَ لِنَفْسٍ أَن تُؤْمِنَ إِلَّا بِإِذْنِ ٱللَّهِ وَيَجْعَلُ قُلِ وَٱلنُّذُرُ عَن قَوْمٍ لَّا يُؤْمِنُونَ ٱنظُرُوا۟ مَاذَا فِى ٱلسَّمَٰوَٰتِ وَٱلْأَرْضِ وَمَا تُغْنِى ٱلْءَايَٰتُ فَهَلْ قُلْ فَٱنتَظِرُوٓا۟ إِنِّى مَعَكُم مِّنَ ٱلْمُنتَظِرِينَ يَنتَظِرُونَ إِلَّا مِثْلَ أَيَّامِ ٱلَّذِينَ خَلَوْا۟ مِن قَبْلِهِمْ ثُمَّ ٱلْمُؤْمِنِينَ نُنَجِّى رُسُلَنَا وَٱلَّذِينَ ءَامَنُوا۟ كَذَٰلِكَ حَقًّا عَلَيْنَا نُنجِ قُلْ فَلَآ أَعْبُدُ ٱلَّذِينَ تَعْبُدُونَ مِن دُونِ ٱللَّهِ وَلَٰكِنْ أَعْبُدُ ٱللَّهَ يَٰٓأَيُّهَا ٱلَّذِى يَتَوَفَّىٰكُمْ وَأُمِرْتُ أَنْ أَكُونَ مِنَ ٱلْمُؤْمِنِينَ ٱلنَّاسُ إِن كُنتُمْ فِى شَكٍّ مِّن دِينِى وَأَنْ أَقِمْ وَجْهَكَ لِلدِّينِ حَنِيفًا وَلَا تَكُونَنَّ مِنَ ٱلْمُشْرِكِينَ وَلَا يَضُرُّكَ فَإِن فَعَلْتَ فَإِنَّكَ إِذًا مِّنَ ٱلظَّٰلِمِينَ تَدْعُ مِن دُونِ ٱللَّهِ مَا لَا يَنفَعُكَ وَلَا وَإِن وَإِن يُرِدْكَ بِخَيْرٍ فَلَا رَآدَّ لِفَضْلِهِۦ يُصِيبُ بِهِۦ مَن يَشَآءُ يَمْسَسْكَ مِنْ عِبَادِهِۦ وَهُوَ ٱلْغَفُورُ ٱلرَّحِيمُ ٱللَّهُ بِضُرٍّ فَلَا كَاشِفَ لَهُۥٓ إِلَّا هُوَ قُلْ ٱهْتَدَىٰ فَإِنَّمَا يَهْتَدِى لِنَفْسِهِۦ وَمَن ضَلَّ فَإِنَّمَا يَضِلُّ عَلَيْهَا وَمَآ يَٰٓأَيُّهَا أَنَا۠ عَلَيْكُم بِوَكِيلٍ ٱلنَّاسُ قَدْ جَآءَكُمُ ٱلْحَقُّ مِن رَّبِّكُمْ فَمَنِ وَٱتَّبِعْ خَيْرُ ٱلْحَٰكِمِينَ مَا يُوحَىٰٓ إِلَيْكَ وَٱصْبِرْ حَتَّىٰ يَحْكُمَ ٱللَّهُ وَهُوَ وَلَوْ أَجَلُهُمْ فَنَذَرُ ٱلَّذِينَ لَا يَرْجُونَ لِقَآءَنَا فِى طُغْيَٰنِهِمْ يَعْمَهُونَ يُعَجِّلُ ٱللَّهُ لِلنَّاسِ ٱلشَّرَّ ٱسْتِعْجَالَهُم بِٱلْخَيْرِ لَقُضِىَ إِلَيْهِمْ وَإِذَا قَآئِمًا فَلَمَّا كَشَفْنَا عَنْهُ ضُرَّهُۥ مَرَّ كَأَن لَّمْ يَدْعُنَآ إِلَىٰ مَسَّ ضُرٍّ مَّسَّهُۥ كَذَٰلِكَ زُيِّنَ لِلْمُسْرِفِينَ مَا كَانُوا۟ يَعْمَلُونَ ٱلْإِنسَٰنَ ٱلضُّرُّ دَعَانَا لِجَنۢبِهِۦٓ أَوْ قَاعِدًا أَوْ وَلَقَدْ بِٱلْبَيِّنَٰتِ وَمَا كَانُوا۟ لِيُؤْمِنُوا۟ كَذَٰلِكَ نَجْزِى ٱلْقَوْمَ ٱلْمُجْرِمِينَ أَهْلَكْنَا ٱلْقُرُونَ مِن قَبْلِكُمْ لَمَّا ظَلَمُوا۟ وَجَآءَتْهُمْ رُسُلُهُم ثُمَّ تَعْمَلُونَ جَعَلْنَٰكُمْ خَلَٰٓئِفَ فِى ٱلْأَرْضِ مِنۢ بَعْدِهِمْ لِنَنظُرَ كَيْفَ وَإِذَا لِقَآءَنَا ٱئْتِ بِقُرْءَانٍ غَيْرِ هَٰذَآ أَوْ بَدِّلْهُ قُلْ مَا يَكُونُ تُتْلَىٰ لِىٓ أَنْ أُبَدِّلَهُۥ مِن تِلْقَآئِ نَفْسِىٓ إِنْ أَتَّبِعُ إِلَّا مَا عَلَيْهِمْ يُوحَىٰٓ إِلَىَّ إِنِّىٓ أَخَافُ إِنْ عَصَيْتُ رَبِّى عَذَابَ يَوْمٍ عَظِيمٍ ءَايَاتُنَا بَيِّنَٰتٍ قَالَ ٱلَّذِينَ لَا يَرْجُونَ قُل بِهِۦ فَقَدْ لَبِثْتُ فِيكُمْ عُمُرًا مِّن قَبْلِهِۦٓ أَفَلَا تَعْقِلُونَ لَّوْ شَآءَ ٱللَّهُ مَا تَلَوْتُهُۥ عَلَيْكُمْ وَلَآ أَدْرَىٰكُم فَمَنْ بِـَٔايَٰتِهِۦٓ إِنَّهُۥ لَا يُفْلِحُ ٱلْمُجْرِمُونَ أَظْلَمُ مِمَّنِ ٱفْتَرَىٰ عَلَى ٱللَّهِ كَذِبًا أَوْ كَذَّبَ وَيَعْبُدُونَ وَيَقُولُونَ هَٰٓؤُلَآءِ شُفَعَٰٓؤُنَا عِندَ ٱللَّهِ قُلْ أَتُنَبِّـُٔونَ ٱللَّهَ بِمَا لَا مِن يَعْلَمُ فِى ٱلسَّمَٰوَٰتِ وَلَا فِى ٱلْأَرْضِ سُبْحَٰنَهُۥ وَتَعَٰلَىٰ عَمَّا يُشْرِكُونَ دُونِ ٱللَّهِ مَا لَا يَضُرُّهُمْ وَلَا يَنفَعُهُمْ وَمَا سَبَقَتْ مِن رَّبِّكَ لَقُضِىَ بَيْنَهُمْ فِيمَا فِيهِ يَخْتَلِفُونَ كَانَ ٱلنَّاسُ إِلَّآ أُمَّةً وَٰحِدَةً فَٱخْتَلَفُوا۟ وَلَوْلَا كَلِمَةٌ أَكَانَ أَنذِرِ ٱلنَّاسَ وَبَشِّرِ ٱلَّذِينَ ءَامَنُوٓا۟ أَنَّ لَهُمْ قَدَمَ صِدْقٍ عِندَ لِلنَّاسِ رَبِّهِمْ قَالَ ٱلْكَٰفِرُونَ إِنَّ هَٰذَا لَسَٰحِرٌ مُّبِينٌ عَجَبًا أَنْ أَوْحَيْنَآ إِلَىٰ رَجُلٍ مِّنْهُمْ أَنْ وَيَقُولُونَ ٱلْغَيْبُ لِلَّهِ فَٱنتَظِرُوٓا۟ إِنِّى مَعَكُم مِّنَ ٱلْمُنتَظِرِينَ لَوْلَآ أُنزِلَ عَلَيْهِ ءَايَةٌ مِّن رَّبِّهِۦ فَقُلْ إِنَّمَا وَإِذَآ لَهُم مَّكْرٌ فِىٓ ءَايَاتِنَا قُلِ ٱللَّهُ أَسْرَعُ مَكْرًا إِنَّ رُسُلَنَا أَذَقْنَا يَكْتُبُونَ مَا تَمْكُرُونَ ٱلنَّاسَ رَحْمَةً مِّنۢ بَعْدِ ضَرَّا ...

# %%
with open("Arabic2.txt", "w", encoding="utf8") as file:
    file.write(test)
