# %% [markdown]
# ### Quaran Form Analysis

# %%
#!pip install lang-trans

# %%
import pandas as pd
import numpy as np
import re
from camel_tools.utils.charmap import CharMapper
from lang_trans.arabic import buckwalter

# %%
with open("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Data/Quranic Corpus Morphology.txt", "r", encoding="utf8") as file:
    text = file.read()

# %% [markdown]
# #### Form Tag

# %%
form_tag_list = re.findall("[\(\d*:\d*:\d*:\d*\)][\t](\D*)[\t][\D*]", text)

# %%
form_tag_num = re.findall("(\d*:\d*:\d*:\d*)", text)

# %%
df_stem = pd.DataFrame(form_tag_num)
df_stem.rename(columns={0:"loc_num"}, inplace=True)
df_stem
# Out:
#           loc_num
# 0         1:1:1:1
# 1         1:1:1:2
# 2         1:1:2:1
# 3         1:1:3:1
# 4         1:1:3:2
# ...           ...
# 128214  114:6:2:1
# 128215  114:6:2:2
# 128216  114:6:3:1
# 128217  114:6:3:2
# 128218  114:6:3:3
#
# [128219 rows x 1 columns]

# %%
df_stem = df_stem["loc_num"].str.split(":", n=-1, expand=True)
df_stem.rename(columns={0:"num_1", 1:"num_2", 2:"num_3", 3:"num_4"}, inplace=True)
df_stem
# Out:
#        num_1 num_2 num_3 num_4
# 0          1     1     1     1
# 1          1     1     1     2
# 2          1     1     2     1
# 3          1     1     3     1
# 4          1     1     3     2
# ...      ...   ...   ...   ...
# 128214   114     6     2     1
# 128215   114     6     2     2
# 128216   114     6     3     1
# 128217   114     6     3     2
# 128218   114     6     3     3
#
# [128219 rows x 4 columns]

# %%
df_stem['num_1'] = df_stem['num_1'].astype(int)
df_stem['num_2'] = df_stem['num_2'].astype(int)
df_stem['num_3'] = df_stem['num_3'].astype(int)
df_stem['num_4'] = df_stem['num_4'].astype(int)

# %%
df_stem["form_tag"] = pd.DataFrame(form_tag_list)
df_stem
# Out:
#         num_1  num_2  num_3  num_4         form_tag
# 0           1      1      1      1            bi\tP
# 1           1      1      1      2          somi\tN
# 2           1      1      2      1      {ll~ahi\tPN
# 3           1      1      3      1          {l\tDET
# 4           1      1      3      2  r~aHoma`ni\tADJ
# ...       ...    ...    ...    ...              ...
# 128214    114      6      2      1         {lo\tDET
# 128215    114      6      2      2       jin~api\tN
# 128216    114      6      3      1         wa\tCONJ
# 128217    114      6      3      2          {l\tDET
# 128218    114      6      3      3        n~aAsi\tN
#
# [128219 rows x 5 columns]

# %%
df_stem[["form","tag"]] = df_stem["form_tag"].str.split("\t", n=-1, expand=True)
df_stem.drop(["form_tag"], axis=1, inplace=True)
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag
# 0           1      1      1      1          bi     P
# 1           1      1      1      2        somi     N
# 2           1      1      2      1     {ll~ahi    PN
# 3           1      1      3      1          {l   DET
# 4           1      1      3      2  r~aHoma`ni   ADJ
# ...       ...    ...    ...    ...         ...   ...
# 128214    114      6      2      1         {lo   DET
# 128215    114      6      2      2     jin~api     N
# 128216    114      6      3      1          wa  CONJ
# 128217    114      6      3      2          {l   DET
# 128218    114      6      3      3      n~aAsi     N
#
# [128219 rows x 6 columns]

# %%
df_stem.drop_duplicates(inplace=True)
df_stem.reset_index(drop=True, inplace=True)
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag
# 0           1      1      1      1          bi     P
# 1           1      1      1      2        somi     N
# 2           1      1      2      1     {ll~ahi    PN
# 3           1      1      3      1          {l   DET
# 4           1      1      3      2  r~aHoma`ni   ADJ
# ...       ...    ...    ...    ...         ...   ...
# 128214    114      6      2      1         {lo   DET
# 128215    114      6      2      2     jin~api     N
# 128216    114      6      3      1          wa  CONJ
# 128217    114      6      3      2          {l   DET
# 128218    114      6      3      3      n~aAsi     N
#
# [128219 rows x 6 columns]

# %%
#df_stem.to_excel("Buckwalter_Form_Tag.xlsx", sheet_name="Form_Tag", index=False)

# %%
df_word = pd.DataFrame(df_stem.groupby(["num_1","num_2","num_3"])["form"].sum())
df_word.rename(columns={"form":"form_concat"}, inplace=True)
df_word.reset_index(inplace=True)
df_word
# Out:
#        num_1  num_2  num_3   form_concat
# 0          1      1      1        bisomi
# 1          1      1      2       {ll~ahi
# 2          1      1      3  {lr~aHoma`ni
# 3          1      1      4    {lr~aHiymi
# 4          1      2      1     {loHamodu
# ...      ...    ...    ...           ...
# 77424    114      5      4       Suduwri
# 77425    114      5      5      {ln~aAsi
# 77426    114      6      1          mina
# 77427    114      6      2    {lojin~api
# 77428    114      6      3    wa{ln~aAsi
#
# [77429 rows x 4 columns]

# %%
#df_word.to_excel("Buckwalter_Form_Concat.xlsx", sheet_name="Concat_Form", index=False)

# %% [markdown]
# #### Buckwalter Text

# %%
#df_word = pd.read_excel("Buckwalter_Form_Concat.xlsx")

# %%
df_word
# Out:
#        num_1  num_2  num_3   form_concat
# 0          1      1      1        bisomi
# 1          1      1      2       {ll~ahi
# 2          1      1      3  {lr~aHoma`ni
# 3          1      1      4    {lr~aHiymi
# 4          1      2      1     {loHamodu
# ...      ...    ...    ...           ...
# 77424    114      5      4       Suduwri
# 77425    114      5      5      {ln~aAsi
# 77426    114      6      1          mina
# 77427    114      6      2    {lojin~api
# 77428    114      6      3    wa{ln~aAsi
#
# [77429 rows x 4 columns]

# %%
concat_list = df_word.iloc[:,3].to_list()
#concat_list = df_word_concat.iloc[:,3].head(500).to_list()

# %%
buckwalter_text = " ".join(concat_list)
#buckwalter_text

# %%
#with open("Buckwalter_Form_Concat.txt", "w", encoding="utf8") as file:
#    file.write(buckwalter_text)

# %% [markdown]
# #### Arabic Text

# %%
#with open("Buckwalter_Form_Concat.txt", "r", encoding="utf8") as file:
#    buckwalter_text = file.read()

# %%
# buckwalter text clean for simple before transString
def clean_ex(text):
    arabic_text2 = re.sub(r'''([PJVG\.:;,!\+\^\]\[@#FNKauio}`~"%-])''', "", text) # difference from clean
    return arabic_text2

# %%
# buckwalter text clean for simple before transString
def clean_ex2(text):
    arabic_text2 = re.sub(r"`", "A", text)
    arabic_text3 = re.sub(r"{", "A", arabic_text2)
    arabic_text4 = re.sub(r'''([PJVG\.:;,!\+\^\]\[@#FNKauio`~"%-])''', "", arabic_text3) # difference from clean
    return arabic_text4

# %%
# Fail
## buckwalter text clean for simple before transString
#def clean_ex(text):
#    arabic_text2 = re.sub(r"\[", "", text)
#    arabic_text3 = re.sub(r"\]", "", arabic_text2)
#    arabic_text4 = re.sub(r'''([@#:;,.!-+%"FNKaui~o`}PJVG])''', "", arabic_text3, re.UNICODE)
#    arabic_text5 = re.sub(r"\^", "", arabic_text4) # difference from clean
#    return arabic_text5

# %%
# Arabic Encoding Extended
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2uni = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "}": u"\u0626", # hamza-on-yaa'
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "F": u"\u064B", # fatHatayn
            "N": u"\u064C", # Dammatayn
            "K": u"\u064D", # kasratayn
            "a": u"\u064E", # fatHa
            "u": u"\u064F", # Damma
            "i": u"\u0650", # kasra
            "~": u"\u0651", # shaddah
            "o": u"\u0652", # sukuun
            "^": u"\u0653", # maddah
            "#": u"\u0654", # hamzaabove            
            "`": u"\u0670", # dagger 'alif
            "{": u"\u0671", # waSla
            "P": u"\u067E", # arabicletterpeh
            "J": u"\u0686", 
            "V": u"\u06A4", # arabicletterveh
            "G": u"\u06AF", # arabiclettergaf
            ":": u"\u06DC", # smallhighseen
            "@": u"\u06DF", # smallhighroundedzero
            "\"": u"\u06E0", # smallhighuprightrectangularzero
            "[": u"\u06E2", # smallhighmeemisolatedform
            ";": u"\u06E3", # smalllowseen
            ",": u"\u06E5", # smallwaw
            ".": u"\u06E6", # smallya
            "!": u"\u06E8", # smallhighnoon
            "-": u"\u06EA", # emptycentrelowstop
            "+": u"\u06EB", # emptycentrehighstop
            "%": u"\u06EC", # roundedhighstopwithfilledcentre
            "]": u"\u06ED", # smalllowmeem           
}

def transString(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2uni.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
# Simple Encoding Technique
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2unisimple = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "{": u"\u0671", # waSla         
}

def transStringSimple(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2unisimple.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
# character clean for simple after transStringSimple 
def clean(text):
    arabic_text2 = re.sub(r'''([PJVG\.:;,!\+\]\[@#FNKauio}`~"%-])''', "", text) # .$^*+
    arabic_text3 = re.sub(r"\^", " ", arabic_text2)
    return arabic_text3

# %%
# character clean for simple after transStringSimple 
def clean2(text):
    arabic_text2 = re.sub(r"`", "A", text)
    arabic_text3 = re.sub(r"{", "A", arabic_text2)
    arabic_text4 = re.sub(r'''([PJVG\.:;,!\+\]\[@#FNKauio`~"%-])''', "", arabic_text3) # .$^*+
    arabic_text5 = re.sub(r"\^", " ", arabic_text4)
    return arabic_text5

# %%
# Fail
## character clean for simple after transStringSimple 
#def clean(text):
#    arabic_text2 = re.sub(r"\[", "", text)
#    arabic_text3 = re.sub(r"\]", "", arabic_text2)
#    arabic_text4 = re.sub(r'''([@#:;,\.!-\+%"FNKaui~o`}PJVG])''', "", arabic_text3) # .$^*+
#    arabic_text5 = re.sub(r"\^", " ", arabic_text4)
#    return arabic_text5

# %%
test = '@SrAT# A-l*yn >nE!mt (Ely.hm gy|r A`lm^gD.wb) Pkl~JAVLGi El:yo,hm; wlA ["+Al+DAly}n,"] $ Pa`t ^wel? a%l+ya'''

# %%
re.sub(r'''([PJVGFNKauio@#:;,!\.\+\^\]\[}`~"%-])''', "", test, re.UNICODE) # %- must be end for accurancy
# Out:
# 'SrAT Al*yn >nEmt (Elyhm gy|r AlmgDwb) klAL Elyhm wlA AlDAlyn $ t wel? l+ya'

# %%
re.sub(r'''([PJVG\.:;,!\+@#FNKauio}`~"%-])''', "", test) # %"-
# Out:
# 'SrAT Al*yn >nEmt (Elyhm gy|r Alm^gDwb) klAL Elyhm wlA [AlDAlyn] $ t ^wel? ly'

# %%
test2 = "Sira`Ta {l~a*iyna >anoEamota Ealayohimo gayori {lomagoDuwbi Ealayohimo walaA {lD~aA^l~iyna"

# %%
clean_ex(test2)
# Out:
# 'SrT {l*yn >nEmt Elyhm gyr {lmgDwb Elyhm wlA {lDAlyn'

# %%
clean(test2)
# Out:
# 'SrT {l*yn >nEmt Elyhm gyr {lmgDwb Elyhm wlA {lDA lyn'

# %%
re.sub(r'''([PJVGFNKauio@#:;,!\.\+\^\]\[}`~"%-])''', "", test2)
# Out:
# 'SrT {l*yn >nEmt Elyhm gyr {lmgDwb Elyhm wlA {lDAlyn'

# %%
re.sub(r'''([PJVG\.:;,!\+\^\]\[@#FNKauio}`~"%-])''', "", test2)
# Out:
# 'SrT {l*yn >nEmt Elyhm gyr {lmgDwb Elyhm wlA {lDAlyn'

# %%
transString(test2, 1)
# Out:
# 'صِرَٰطَ ٱلَّذِينَ أَنْعَمْتَ عَلَيْهِمْ غَيْرِ ٱلْمَغْضُوبِ عَلَيْهِمْ وَلَا ٱلضَّآلِّينَ'

# %%
transStringSimple(test2, 1)
# Out:
# 'صiرa`طa ٱل~aذiينa أaنoعaمoتa عaلaيoهiمo غaيoرi ٱلoمaغoضuوبi عaلaيoهiمo وaلaا ٱلض~aا^ل~iينa'

# %%
arabic_func_text = transString(buckwalter_text, 1)
#arabic_func_text

# %%
with open("Arabic_Converted_Extended_Characters.txt", "w", encoding="utf8") as file:
    file.write(arabic_func_text)

# %% [markdown]
# ##### DF Form Word Concat Convert Arabic

# %%
#df_word = pd.read_excel("Buckwalter_Form_Concat.xlsx")

# %%
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag
# 0           1      1      1      1          bi     P
# 1           1      1      1      2        somi     N
# 2           1      1      2      1     {ll~ahi    PN
# 3           1      1      3      1          {l   DET
# 4           1      1      3      2  r~aHoma`ni   ADJ
# ...       ...    ...    ...    ...         ...   ...
# 128214    114      6      2      1         {lo   DET
# 128215    114      6      2      2     jin~api     N
# 128216    114      6      3      1          wa  CONJ
# 128217    114      6      3      2          {l   DET
# 128218    114      6      3      3      n~aAsi     N
#
# [128219 rows x 6 columns]

# %%
df_stem["arabic_form"] = df_stem.iloc[:,4].apply(lambda x: transString(x, 1))
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag arabic_form
# 0           1      1      1      1          bi     P          بِ
# 1           1      1      1      2        somi     N        سْمِ
# 2           1      1      2      1     {ll~ahi    PN     ٱللَّهِ
# 3           1      1      3      1          {l   DET          ٱل
# 4           1      1      3      2  r~aHoma`ni   ADJ  رَّحْمَٰنِ
# ...       ...    ...    ...    ...         ...   ...         ...
# 128214    114      6      2      1         {lo   DET         ٱلْ
# 128215    114      6      2      2     jin~api     N     جِنَّةِ
# 128216    114      6      3      1          wa  CONJ          وَ
# 128217    114      6      3      2          {l   DET          ٱل
# 128218    114      6      3      3      n~aAsi     N      نَّاسِ
#
# [128219 rows x 7 columns]

# %%
# 1 Way
df_stem["arabic_form_simple"] = df_stem.iloc[:,4].apply(lambda x: clean_ex2(x))
df_stem["arabic_form_simple"] = df_stem.iloc[:,7].apply(lambda x: transString(x, 1))
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag arabic_form  \
# 0           1      1      1      1          bi     P          بِ
# 1           1      1      1      2        somi     N        سْمِ
# 2           1      1      2      1     {ll~ahi    PN     ٱللَّهِ
# 3           1      1      3      1          {l   DET          ٱل
# 4           1      1      3      2  r~aHoma`ni   ADJ  رَّحْمَٰنِ
# ...       ...    ...    ...    ...         ...   ...         ...
# 128214    114      6      2      1         {lo   DET         ٱلْ
# 128215    114      6      2      2     jin~api     N     جِنَّةِ
# 128216    114      6      3      1          wa  CONJ          وَ
# 128217    114      6      3      2          {l   DET          ٱل
# 128218    114      6      3      3      n~aAsi     N      نَّاسِ
#
#        arabic_form_simple
# 0                       ب
# 1                      سم
# 2                    الله
# 3                      ال
# 4                   رحمان
# ...                   ...
# 128214                 ال
# 128215                جنة
# 128216                  و
# 128217                 ال
# 128218                ناس
#
# [128219 rows x 8 columns]

# %%
## 2 Way
#df_stem["arabic_form_simple"] = df_stem.iloc[:,4].apply(lambda x: transStringSimple(x, 1))
#df_stem["arabic_form_simple"] = df_stem.iloc[:,7].apply(lambda x: clean(x))
#df_stem

# %%
# 1 Way
df_stem["form_simple"] = df_stem.iloc[:,4].apply(lambda x: clean_ex2(x))
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag arabic_form  \
# 0           1      1      1      1          bi     P          بِ
# 1           1      1      1      2        somi     N        سْمِ
# 2           1      1      2      1     {ll~ahi    PN     ٱللَّهِ
# 3           1      1      3      1          {l   DET          ٱل
# 4           1      1      3      2  r~aHoma`ni   ADJ  رَّحْمَٰنِ
# ...       ...    ...    ...    ...         ...   ...         ...
# 128214    114      6      2      1         {lo   DET         ٱلْ
# 128215    114      6      2      2     jin~api     N     جِنَّةِ
# 128216    114      6      3      1          wa  CONJ          وَ
# 128217    114      6      3      2          {l   DET          ٱل
# 128218    114      6      3      3      n~aAsi     N      نَّاسِ
#
#        arabic_form_simple form_simple
# 0                       ب           b
# 1                      سم          sm
# 2                    الله        Allh
# 3                      ال          Al
# 4                   رحمان       rHmAn
# ...                   ...         ...
# 128214                 ال          Al
# 128215                جنة         jnp
# 128216                  و           w
# 128217                 ال          Al
# 128218                ناس         nAs
#
# [128219 rows x 9 columns]

# %%
## 2 Way
##df_stem["form_simple"] = df_stem.iloc[:,7].apply(lambda x: transString(x, 0))
#df_stem["form_simple"] = df_stem.iloc[:,7].apply(lambda x: transStringSimple(x, 0))
#df_stem["form_simple"] = df_stem.iloc[:,8].apply(lambda x: clean(x))
#df_stem

# %%
df_stem = df_stem[["num_1","num_2","num_3","num_4","arabic_form_simple","form_simple","arabic_form","form","tag"]]
df_stem.rename(columns={"form_simple":"buckwalter_simple", "form":"buckwalter"}, inplace=True)
df_stem
# Out:
#         num_1  num_2  num_3  num_4 arabic_form_simple buckwalter_simple  \
# 0           1      1      1      1                  ب                 b
# 1           1      1      1      2                 سم                sm
# 2           1      1      2      1               الله              Allh
# 3           1      1      3      1                 ال                Al
# 4           1      1      3      2              رحمان             rHmAn
# ...       ...    ...    ...    ...                ...               ...
# 128214    114      6      2      1                 ال                Al
# 128215    114      6      2      2                جنة               jnp
# 128216    114      6      3      1                  و                 w
# 128217    114      6      3      2                 ال                Al
# 128218    114      6      3      3                ناس               nAs
#
#        arabic_form  buckwalter   tag
# 0               بِ          bi     P
# 1             سْمِ        somi     N
# 2          ٱللَّهِ     {ll~ahi    PN
# 3               ٱل          {l   DET
# 4       رَّحْمَٰنِ  r~aHoma`ni   ADJ
# ...            ...         ...   ...
# 128214         ٱلْ         {lo   DET
# 128215     جِنَّةِ     jin~api     N
# 128216          وَ          wa  CONJ
# 128217          ٱل          {l   DET
# 128218      نَّاسِ      n~aAsi     N
#
# [128219 rows x 9 columns]

# %%
df_stem.to_excel("Arabic_And_Simple_Form.xlsx", sheet_name="Arabic_And_Simple_Form", index=False, encoding="utf-8")

# %%
df_word
# Out:
#        num_1  num_2  num_3   form_concat
# 0          1      1      1        bisomi
# 1          1      1      2       {ll~ahi
# 2          1      1      3  {lr~aHoma`ni
# 3          1      1      4    {lr~aHiymi
# 4          1      2      1     {loHamodu
# ...      ...    ...    ...           ...
# 77424    114      5      4       Suduwri
# 77425    114      5      5      {ln~aAsi
# 77426    114      6      1          mina
# 77427    114      6      2    {lojin~api
# 77428    114      6      3    wa{ln~aAsi
#
# [77429 rows x 4 columns]

# %%
df_word["arabic"] = df_word.iloc[:,3].apply(lambda x: transString(x, 1))
df_word
# Out:
#        num_1  num_2  num_3   form_concat        arabic
# 0          1      1      1        bisomi        بِسْمِ
# 1          1      1      2       {ll~ahi       ٱللَّهِ
# 2          1      1      3  {lr~aHoma`ni  ٱلرَّحْمَٰنِ
# 3          1      1      4    {lr~aHiymi    ٱلرَّحِيمِ
# 4          1      2      1     {loHamodu     ٱلْحَمْدُ
# ...      ...    ...    ...           ...           ...
# 77424    114      5      4       Suduwri       صُدُورِ
# 77425    114      5      5      {ln~aAsi      ٱلنَّاسِ
# 77426    114      6      1          mina          مِنَ
# 77427    114      6      2    {lojin~api    ٱلْجِنَّةِ
# 77428    114      6      3    wa{ln~aAsi    وَٱلنَّاسِ
#
# [77429 rows x 5 columns]

# %%
# 1 Way
df_word["arabic_simple"] = df_word.iloc[:,3].apply(lambda x : clean_ex2(x))
df_word["arabic_simple"] = df_word.iloc[:,5].apply(lambda x : transString(x, 1))
df_word
# Out:
#        num_1  num_2  num_3   form_concat        arabic arabic_simple
# 0          1      1      1        bisomi        بِسْمِ           بسم
# 1          1      1      2       {ll~ahi       ٱللَّهِ          الله
# 2          1      1      3  {lr~aHoma`ni  ٱلرَّحْمَٰنِ       الرحمان
# 3          1      1      4    {lr~aHiymi    ٱلرَّحِيمِ        الرحيم
# 4          1      2      1     {loHamodu     ٱلْحَمْدُ         الحمد
# ...      ...    ...    ...           ...           ...           ...
# 77424    114      5      4       Suduwri       صُدُورِ          صدور
# 77425    114      5      5      {ln~aAsi      ٱلنَّاسِ         الناس
# 77426    114      6      1          mina          مِنَ            من
# 77427    114      6      2    {lojin~api    ٱلْجِنَّةِ         الجنة
# 77428    114      6      3    wa{ln~aAsi    وَٱلنَّاسِ        والناس
#
# [77429 rows x 6 columns]

# %%
## 2 Way
#df_word["arabic_simple"] = df_word.iloc[:,3].apply(lambda x : transStringSimple(x, 1))
#df_word["arabic_simple"] = df_word.iloc[:,5].apply(lambda x : clean(x))
#df_word

# %%
df_word["form_concat_simple"] = df_word.iloc[:,3].apply(lambda x: clean_ex2(x))
df_word
# Out:
#        num_1  num_2  num_3   form_concat        arabic arabic_simple  \
# 0          1      1      1        bisomi        بِسْمِ           بسم
# 1          1      1      2       {ll~ahi       ٱللَّهِ          الله
# 2          1      1      3  {lr~aHoma`ni  ٱلرَّحْمَٰنِ       الرحمان
# 3          1      1      4    {lr~aHiymi    ٱلرَّحِيمِ        الرحيم
# 4          1      2      1     {loHamodu     ٱلْحَمْدُ         الحمد
# ...      ...    ...    ...           ...           ...           ...
# 77424    114      5      4       Suduwri       صُدُورِ          صدور
# 77425    114      5      5      {ln~aAsi      ٱلنَّاسِ         الناس
# 77426    114      6      1          mina          مِنَ            من
# 77427    114      6      2    {lojin~api    ٱلْجِنَّةِ         الجنة
# 77428    114      6      3    wa{ln~aAsi    وَٱلنَّاسِ        والناس
#
#       form_concat_simple
# 0                    bsm
# 1                   Allh
# 2                AlrHmAn
# 3                 AlrHym
# 4                  AlHmd
# ...                  ...
# 77424               Sdwr
# 77425              AlnAs
# 77426                 mn
# 77427              Aljnp
# 77428             wAlnAs
#
# [77429 rows x 7 columns]

# %%
## 2 Way
##df_word["form_concat_simple"] = df_word.iloc[:,5].apply(lambda x: transString(x, 0))
#df_word["form_concat_simple"] = df_word.iloc[:,5].apply(lambda x: transStringSimple(x, 0))
#df_word["form_concat_simple"] = df_word.iloc[:,6].apply(lambda x: clean(x))
#df_word

# %%
df_word = df_word[["num_1","num_2","num_3","arabic_simple","form_concat_simple","arabic","form_concat"]]
df_word.rename(columns={"form_concat":"buckwalter","form_concat_simple":"buckwalter_simple"}, inplace=True)
df_word
# Out:
#        num_1  num_2  num_3 arabic_simple buckwalter_simple        arabic  \
# 0          1      1      1           بسم               bsm        بِسْمِ
# 1          1      1      2          الله              Allh       ٱللَّهِ
# 2          1      1      3       الرحمان           AlrHmAn  ٱلرَّحْمَٰنِ
# 3          1      1      4        الرحيم            AlrHym    ٱلرَّحِيمِ
# 4          1      2      1         الحمد             AlHmd     ٱلْحَمْدُ
# ...      ...    ...    ...           ...               ...           ...
# 77424    114      5      4          صدور              Sdwr       صُدُورِ
# 77425    114      5      5         الناس             AlnAs      ٱلنَّاسِ
# 77426    114      6      1            من                mn          مِنَ
# 77427    114      6      2         الجنة             Aljnp    ٱلْجِنَّةِ
# 77428    114      6      3        والناس            wAlnAs    وَٱلنَّاسِ
#
#          buckwalter
# 0            bisomi
# 1           {ll~ahi
# 2      {lr~aHoma`ni
# 3        {lr~aHiymi
# 4         {loHamodu
# ...             ...
# 77424       Suduwri
# 77425      {ln~aAsi
# 77426          mina
# 77427    {lojin~api
# 77428    wa{ln~aAsi
#
# [77429 rows x 7 columns]

# %%
df_word.iloc[27,:]
# Out:
# num_1                    1
# num_2                    7
# num_3                    8
# arabic_simple          ولا
# buckwalter_simple      wlA
# arabic               وَلَا
# buckwalter           walaA
# Name: 27, dtype: object

# %%
df_word.to_excel("Arabic_And_Simple_Word.xlsx", sheet_name="Arabic_And_Simple", index=False, encoding="utf-8")

# %%
df_buckwalter = df_word.iloc[:,[0,1,2,6]]
df_buckwalter
# Out:
#        num_1  num_2  num_3    buckwalter
# 0          1      1      1        bisomi
# 1          1      1      2       {ll~ahi
# 2          1      1      3  {lr~aHoma`ni
# 3          1      1      4    {lr~aHiymi
# 4          1      2      1     {loHamodu
# ...      ...    ...    ...           ...
# 77424    114      5      4       Suduwri
# 77425    114      5      5      {ln~aAsi
# 77426    114      6      1          mina
# 77427    114      6      2    {lojin~api
# 77428    114      6      3    wa{ln~aAsi
#
# [77429 rows x 4 columns]

# %%
df_buckwalter_concat = df_buckwalter.groupby(["num_1","num_2"])["buckwalter"].apply(" ".join).reset_index()
df_buckwalter_concat
# Out:
#       num_1  num_2                                buckwalter
# 0         1      1    bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi
# 1         1      2     {loHamodu lil~ahi rab~i {loEa`lamiyna
# 2         1      3                   {lr~aHoma`ni {lr~aHiymi
# 3         1      4                   ma`liki yawomi {ld~iyni
# 4         1      5  <iy~aAka naEobudu wa<iy~aAka nasotaEiynu
# ...     ...    ...                                       ...
# 6231    114      2                           maliki {ln~aAsi
# 6232    114      3                          <ila`hi {ln~aAsi
# 6233    114      4        min $ar~i {lowasowaAsi {loxan~aAsi
# 6234    114      5   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi
# 6235    114      6                mina {lojin~api wa{ln~aAsi
#
# [6236 rows x 3 columns]

# %%
df_buckwalter_concat["arabic"] = df_buckwalter_concat.iloc[:,2].apply(lambda x: transString(x, 1)) # Convert Arabic Extended
df_buckwalter_concat
# Out:
#       num_1  num_2                                buckwalter  \
# 0         1      1    bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi
# 1         1      2     {loHamodu lil~ahi rab~i {loEa`lamiyna
# 2         1      3                   {lr~aHoma`ni {lr~aHiymi
# 3         1      4                   ma`liki yawomi {ld~iyni
# 4         1      5  <iy~aAka naEobudu wa<iy~aAka nasotaEiynu
# ...     ...    ...                                       ...
# 6231    114      2                           maliki {ln~aAsi
# 6232    114      3                          <ila`hi {ln~aAsi
# 6233    114      4        min $ar~i {lowasowaAsi {loxan~aAsi
# 6234    114      5   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi
# 6235    114      6                mina {lojin~api wa{ln~aAsi
#
#                                         arabic
# 0       بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1        ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2                      ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3                      مَٰلِكِ يَوْمِ ٱلدِّينِ
# 4     إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# ...                                        ...
# 6231                           مَلِكِ ٱلنَّاسِ
# 6232                          إِلَٰهِ ٱلنَّاسِ
# 6233        مِن شَرِّ ٱلْوَسْوَاسِ ٱلْخَنَّاسِ
# 6234   ٱلَّذِى يُوَسْوِسُ فِى صُدُورِ ٱلنَّاسِ
# 6235                مِنَ ٱلْجِنَّةِ وَٱلنَّاسِ
#
# [6236 rows x 4 columns]

# %%
df_buckwalter_concat["arabic_simple"] = df_buckwalter_concat.iloc[:,2].apply(lambda x : clean_ex2(x))
df_buckwalter_concat["arabic_simple"] = df_buckwalter_concat.iloc[:,4].apply(lambda x : transString(x, 1)) # Convert Arabic Simple
df_buckwalter_concat
# Out:
#       num_1  num_2                                buckwalter  \
# 0         1      1    bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi
# 1         1      2     {loHamodu lil~ahi rab~i {loEa`lamiyna
# 2         1      3                   {lr~aHoma`ni {lr~aHiymi
# 3         1      4                   ma`liki yawomi {ld~iyni
# 4         1      5  <iy~aAka naEobudu wa<iy~aAka nasotaEiynu
# ...     ...    ...                                       ...
# 6231    114      2                           maliki {ln~aAsi
# 6232    114      3                          <ila`hi {ln~aAsi
# 6233    114      4        min $ar~i {lowasowaAsi {loxan~aAsi
# 6234    114      5   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi
# 6235    114      6                mina {lojin~api wa{ln~aAsi
#
#                                         arabic             arabic_simple
# 0       بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ   بسم الله الرحمان الرحيم
# 1        ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ     الحمد لله رب العالمين
# 2                      ٱلرَّحْمَٰنِ ٱلرَّحِيمِ            الرحمان الرحيم
# 3                      مَٰلِكِ يَوْمِ ٱلدِّينِ            مالك يوم الدين
# 4     إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ    إياك نعبد وإياك نستعين
# ...                                        ...                       ...
# 6231                           مَلِكِ ٱلنَّاسِ                 ملك الناس
# 6232                          إِلَٰهِ ٱلنَّاسِ                إلاه الناس
# 6233        مِن شَرِّ ٱلْوَسْوَاسِ ٱلْخَنَّاسِ      من شر الوسواس الخناس
# 6234   ٱلَّذِى يُوَسْوِسُ فِى صُدُورِ ٱلنَّاسِ  الذى يوسوس فى صدور الناس
# 6235                مِنَ ٱلْجِنَّةِ وَٱلنَّاسِ           من الجنة والناس
#
# [6236 rows x 5 columns]

# %%
## 2 Way
#df_buckwalter_concat["arabic_simple"] = df_buckwalter_concat.iloc[:,2].apply(lambda x : transStringSimple(x, 1)) # Convert Arabic Simple
#df_buckwalter_concat["arabic_simple"] = df_buckwalter_concat.iloc[:,4].apply(lambda x : clean(x))
#df_buckwalter_concat

# %%
df_buckwalter_concat = df_buckwalter_concat[["num_1","num_2","arabic","buckwalter","arabic_simple"]]
df_buckwalter_concat
# Out:
#       num_1  num_2                                    arabic  \
# 0         1      1    بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1         1      2     ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2         1      3                   ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3         1      4                   مَٰلِكِ يَوْمِ ٱلدِّينِ
# 4         1      5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# ...     ...    ...                                       ...
# 6231    114      2                           مَلِكِ ٱلنَّاسِ
# 6232    114      3                          إِلَٰهِ ٱلنَّاسِ
# 6233    114      4        مِن شَرِّ ٱلْوَسْوَاسِ ٱلْخَنَّاسِ
# 6234    114      5   ٱلَّذِى يُوَسْوِسُ فِى صُدُورِ ٱلنَّاسِ
# 6235    114      6                مِنَ ٱلْجِنَّةِ وَٱلنَّاسِ
#
#                                     buckwalter             arabic_simple
# 0       bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi   بسم الله الرحمان الرحيم
# 1        {loHamodu lil~ahi rab~i {loEa`lamiyna     الحمد لله رب العالمين
# 2                      {lr~aHoma`ni {lr~aHiymi            الرحمان الرحيم
# 3                      ma`liki yawomi {ld~iyni            مالك يوم الدين
# 4     <iy~aAka naEobudu wa<iy~aAka nasotaEiynu    إياك نعبد وإياك نستعين
# ...                                        ...                       ...
# 6231                           maliki {ln~aAsi                 ملك الناس
# 6232                          <ila`hi {ln~aAsi                إلاه الناس
# 6233        min $ar~i {lowasowaAsi {loxan~aAsi      من شر الوسواس الخناس
# 6234   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi  الذى يوسوس فى صدور الناس
# 6235                mina {lojin~api wa{ln~aAsi           من الجنة والناس
#
# [6236 rows x 5 columns]

# %%
# 1 Way
df_buckwalter_concat["buckwalter_simple"] = df_buckwalter_concat.iloc[:,3].apply(lambda x : clean_ex2(x)) # Convert Arabic Simple
df_buckwalter_concat
# Out:
# <ipython-input-65-9cfb42f5b149>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_buckwalter_concat["buckwalter_simple"] = df_buckwalter_concat.iloc[:,3].apply(lambda x : clean_ex2(x)) # Convert Arabic Simple
#       num_1  num_2                                    arabic  \
# 0         1      1    بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1         1      2     ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2         1      3                   ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3         1      4                   مَٰلِكِ يَوْمِ ٱلدِّينِ
# 4         1      5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# ...     ...    ...                                       ...
# 6231    114      2                           مَلِكِ ٱلنَّاسِ
# 6232    114      3                          إِلَٰهِ ٱلنَّاسِ
# 6233    114      4        مِن شَرِّ ٱلْوَسْوَاسِ ٱلْخَنَّاسِ
# 6234    114      5   ٱلَّذِى يُوَسْوِسُ فِى صُدُورِ ٱلنَّاسِ
# 6235    114      6                مِنَ ٱلْجِنَّةِ وَٱلنَّاسِ
#
#                                     buckwalter             arabic_simple  \
# 0       bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi   بسم الله الرحمان الرحيم
# 1        {loHamodu lil~ahi rab~i {loEa`lamiyna     الحمد لله رب العالمين
# 2                      {lr~aHoma`ni {lr~aHiymi            الرحمان الرحيم
# 3                      ma`liki yawomi {ld~iyni            مالك يوم الدين
# 4     <iy~aAka naEobudu wa<iy~aAka nasotaEiynu    إياك نعبد وإياك نستعين
# ...                                        ...                       ...
# 6231                           maliki {ln~aAsi                 ملك الناس
# 6232                          <ila`hi {ln~aAsi                إلاه الناس
# 6233        min $ar~i {lowasowaAsi {loxan~aAsi      من شر الوسواس الخناس
# 6234   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi  الذى يوسوس فى صدور الناس
# 6235                mina {lojin~api wa{ln~aAsi           من الجنة والناس
#
#              buckwalter_simple
# 0      bsm Allh AlrHmAn AlrHym
# 1        AlHmd llh rb AlEAlmyn
# 2               AlrHmAn AlrHym
# 3               mAlk ywm Aldyn
# 4       <yAk nEbd w<yAk nstEyn
# ...                        ...
# 6231                 mlk AlnAs
# 6232                <lAh AlnAs
# 6233      mn $r AlwswAs AlxnAs
# 6234  Al*Y ywsws fY Sdwr AlnAs
# 6235           mn Aljnp wAlnAs
#
# [6236 rows x 6 columns]

# %%
## 2 Way
##df_buckwalter_concat["buckwalter_simple"] = df_buckwalter_concat.iloc[:,4].apply(lambda x : transString(x, 0))
#df_buckwalter_concat["buckwalter_simple"] = df_buckwalter_concat.iloc[:,4].apply(lambda x : transStringSimple(x, 0)) # Convert Arabic Simple
#df_buckwalter_concat["buckwalter_simple"] = df_buckwalter_concat.iloc[:,5].apply(lambda x : clean(x))
#df_buckwalter_concat

# %%
df_buckwalter_concat.to_excel("Arabic_And_Simple_Sentence.xlsx", sheet_name="Arabic_Simple_Sentence", index=False)

# %% [markdown]
# ##### Arabic Frequency

# %%
#df_stem = pd.read_excel("Arabic_And_Simple_Form.xlsx")

# %%
df_arabic_form_count = pd.DataFrame(df_stem.iloc[:,6].value_counts(ascending=False))
df_arabic_form_count.reset_index(inplace=True)
df_arabic_form_count.rename(columns={"index":"arabic_form","arabic_form":"frequency"}, inplace=True)
df_arabic_form_count

# %%
#df_arabic_form_count.to_excel("Arabic_Form_Frequency_From_Morphology.xlsx", sheet_name="Arabic_Form_Frequency", index=False)

# %%
df_arabic_form_simple_count = pd.DataFrame(df_stem.iloc[:,4].value_counts(ascending=False))
df_arabic_form_simple_count.reset_index(inplace=True)
df_arabic_form_simple_count.rename(columns={"index":"arabic_form_simple","arabic_form_simple":"frequency"}, inplace=True)
df_arabic_form_simple_count

# %%
#df_arabic_form_simple_count.to_excel("Arabic_Form_Simple_Frequency_From_Morphology.xlsx", sheet_name="Arabic_Form_Simple_Frequency", index=False)

# %%
#df_word = pd.read_excel("Arabic_And_Simple_Word.xlsx")

# %%
df_arabic_count = pd.DataFrame(df_word.iloc[:,5].value_counts(ascending=False))
df_arabic_count.reset_index(inplace=True)
df_arabic_count.rename(columns={"index":"arabic","arabic":"frequency"}, inplace=True)
df_arabic_count

# %%
#df_arabic_count.to_excel("Arabic_Frequency_From_Morphology.xlsx", sheet_name="Arabic_Frequency", index=False)

# %%
df_arabic_simple_count = pd.DataFrame(df_word.iloc[:,3].value_counts(ascending=False))
df_arabic_simple_count.reset_index(inplace=True)
df_arabic_simple_count.rename(columns={"index":"arabic_simple","arabic_simple":"frequency"}, inplace=True)
df_arabic_simple_count

# %%
#df_arabic_simple_count.to_excel("Arabic_Simple_Frequency_From_Morphology.xlsx", sheet_name="Arabic_Simple_Frequency", index=False)

# %% [markdown]
# ##### Arabic Simple Frequency Nav

# %%
df_arabic_simple_select = df_arabic_simple_count.head(1000)
df_arabic_simple_select

# %%
df_arabic_simple_count_merge = pd.merge(df_arabic_simple_select, df_word, how="inner", on="arabic_simple")
df_arabic_simple_count_merge

# %%
df_arabic_simple_count_merge = df_arabic_simple_count_merge[["num_1","num_2","num_3","arabic_simple","buckwalter_simple","frequency","arabic","buckwalter"]]
df_arabic_simple_count_merge

# %%
df_arabic_simple_count_merge["nav"] = df_arabic_simple_count_merge["num_1"].astype("str")+":"+df_arabic_simple_count_merge["num_2"].astype("str")+":"+df_arabic_simple_count_merge["num_3"].astype("str")
df_arabic_simple_count_merge

# %%
#df_arabic_simple_count_merge.to_excel("Arabic_Simple_Navigation.xlsx", sheet_name="Arabic_Simple_Navigation", index=False)

# %%
df_arabic_simple_nav = df_arabic_simple_count_merge.groupby(["arabic_simple","buckwalter_simple","frequency"])["nav"].apply(", ".join).reset_index().sort_values(by="frequency", ascending=False)
df_arabic_simple_nav.reset_index(drop=True, inplace=True)
df_arabic_simple_nav

# %%
#df_arabic_simple_nav.to_excel("Arabic_Simple_Frequency_Navigation.xlsx", sheet_name="Arabic_Simple_Frequency", index=False)

# %%
df_a = df_buckwalter_concat.iloc[:,[5,4]]
df_a
# Out:
#              buckwalter_simple             arabic_simple
# 0      bsm Allh AlrHmAn AlrHym   بسم الله الرحمان الرحيم
# 1        AlHmd llh rb AlEAlmyn     الحمد لله رب العالمين
# 2               AlrHmAn AlrHym            الرحمان الرحيم
# 3               mAlk ywm Aldyn            مالك يوم الدين
# 4       <yAk nEbd w<yAk nstEyn    إياك نعبد وإياك نستعين
# ...                        ...                       ...
# 6231                 mlk AlnAs                 ملك الناس
# 6232                <lAh AlnAs                إلاه الناس
# 6233      mn $r AlwswAs AlxnAs      من شر الوسواس الخناس
# 6234  Al*Y ywsws fY Sdwr AlnAs  الذى يوسوس فى صدور الناس
# 6235           mn Aljnp wAlnAs           من الجنة والناس
#
# [6236 rows x 2 columns]

# %%
set_a = set(df_a.iloc[:,0])
set_a
# Out:
# {"w<n kAn TA}fp mnkm 'AmnwA bAl*Y >rslt bh wTA}fp lm y&mnwA fASbrwA HtYA yHkm Allh bynnA whw xyr AlHAkmyn",
#  "lqd kAn fY ywsf w<xwth 'AyAt llsA}lyn",
#  'wAl>rD mddnAhA w>lqynA fyhA rwAsY w>nbtnA fyhA mn kl zwj bhyj',
#  'AdxlwA >bwAb jhnm xAldyn fyhA fb}s mvwY Almtkbryn',
#  "qAl yAbnY lA tqSS r'yAk ElYA <xwtk fykydwA lk kydA <n Al$yTAn ll<nsAn Edw mbyn",
#  'w<n kAnwA mn qbl >n ynzl Elyhm mn qblh lmblsyn',
#  'wydxlhm Aljnp ErfhA lhm',
#  "wAl*yn hAjrwA fY Allh mn bEd mA ZlmwA lnbw}nhm fY AldnyA Hsnp wl>jr Al'Axrp >kbr lw kAnwA yElmwn",
#  'wlw trYA <* wqfwA ElY AlnAr fqAlwA yAlytnA nrd wlA nk*b b_AyAt rbnA wnkwn mn Alm&mnyn',
#  'wAlyl wmA wsq',
#  'fqtl kyf qdr',
#  'flA tTE Almk*byn',
#  "Al*Y jEl lkm Al>rD frA$A wAlsmA' bnA' w>nzl mn AlsmA' mA' f>xrj bh mn AlvmrAt rzqA lkm flA tjElwA llh >ndAdA w>ntm tElmwn",
#  'wAlqmr <*A Atsq',
#  'wlqd k*b Al*yn mn qblhm fkyf kAn nkyr',
#  'qAlwA tAllh tft&A t*kr ywsf HtYA tkwn HrDA >w tkwn mn AlhAlkyn',
#  "qAlwA mA >ntm <lA b$r mvlnA wmA >nzl AlrHmAn mn $Y' <n >ntm <lA tk*bwn",
#  'mhTEyn <lY AldAE yqwl AlkAfrwn hA*A ywm Esr',
#  "fmn AbtgYA wrA' *Alk f>wlA}k hm AlEAdwn",
#  "Al*yn ySdwn En sbyl Allh wybgwnhA EwjA whm bAl'Axrp hm kAfrwn",
#  'wt*rwn mA xlq lkm rbkm mn >zwAjkm bl >ntm qwm EAdwn',
#  'ln ystnkf AlmsyH >n ykwn EbdA llh wlA AlmlA}kp Almqrbwn wmn ystnkf En EbAdth wystkbr fsyH$rhm <lyh jmyEA',
#  'f*rhm HtYA ylAqwA ywmhm Al*Y fyh ySEqwn',
#  'vm ArjE AlbSr krtyn ynqlb <lyk AlbSr xAs}A whw Hsyr',
#  ">w tsqT AlsmA' kmA zEmt ElynA ksfA >w t>tY bAllh wAlmlA}kp qbylA",
#  "wmn >Zlm mmn mnE msAjd Allh >n y*kr fyhA Asmh wsEYA fY xrAbhA >wlA}k mA kAn lhm >n ydxlwhA <lA xA}fyn lhm fY AldnyA xzY wlhm fY Al'Axrp E*Ab EZym",
#  'flA >qsm bAlxns',
#  '*Alk wmn yEZm $EA}r Allh f<nhA mn tqwY Alqlwb',
#  "ql <n rbY ybsT Alrzq lmn y$A' mn EbAdh wyqdr lh wmA >nfqtm mn $Y' fhw yxlfh whw xyr AlrAzqyn",
#  '<n Allh hw AlrzAq *w Alqwp Almtyn',
#  'snlqY fY qlwb Al*yn kfrwA AlrEb bmA >$rkwA bAllh mA lm ynzl bh slTAnA wm>wYAhm AlnAr wb}s mvwY AlZAlmyn',
#  'fmA yk*bk bEd bAldyn',
#  'wAlsAbqwn AlsAbqwn',
#  'wfAkhp kvyrp',
#  '<n Allh mE Al*yn AtqwA wAl*yn hm mHsnwn',
#  "<n tbdwA xyrA >w txfwh >w tEfwA En sw' f<n Allh kAn EfwA qdyrA",
#  '>lm tr kyf fEl rbk bEAd',
#  'w*kr Asm rbh fSlYA',
#  'wwSYA bhA <brAhm bnyh wyEqwb yAbnY <n Allh ASTfYA lkm Aldyn flA tmwtn <lA w>ntm mslmwn',
#  'wywm yErD Al*yn kfrwA ElY AlnAr >*hbtm TybAtkm fY HyAtkm AldnyA wAstmtEtm bhA fAlywm tjzwn E*Ab Alhwn bmA kntm tstkbrwn fY Al>rD bgyr AlHq wbmA kntm tfsqwn',
#  'wAl*yn yjtnbwn kbA}r Al<vm wAlfwAH$ w<*A mA gDbwA hm ygfrwn',
#  'ql AdEwA Al*yn zEmtm mn dwnh flA ymlkwn k$f AlDr Enkm wlA tHwylA',
#  ">xrj mnhA mA'hA wmrEYAhA",
#  'wmn rHmth jEl lkm Alyl wAlnhAr ltsknwA fyh wltbtgwA mn fDlh wlElkm t$krwn',
#  'wlA ySdnkm Al$yTAn <nh lkm Edw mbyn',
#  'wmn AlnAs mn yjAdl fY Allh bgyr Elm wlA hdY wlA ktAb mnyr',
#  "<lA Al*yn 'AmnwA wEmlwA AlSAlHAt w*krwA Allh kvyrA wAntSrwA mn bEd mA ZlmwA wsyElm Al*yn ZlmwA >Y mnqlb ynqlbwn",
#  'f<n lm tjdwA fyhA >HdA flA tdxlwhA HtYA y&*n lkm w<n qyl lkm ArjEwA fArjEwA hw >zkYA lkm wAllh bmA tEmlwn Elym',
#  'vm bEvnA mn bEdhm mwsYA b_AyAtnA <lYA frEwn wml<yh fZlmwA bhA fAnZr kyf kAn EAqbp Almfsdyn',
#  "wk*Alk >wHynA <lyk rwHA mn >mrnA mA knt tdrY mA AlktAb wlA Al<ymAn wlAkn jElnAh nwrA nhdY bh mn n$A' mn EbAdnA w<nk lthdY <lYA SrAT mstqym",
#  'f>wHYA <lYA Ebdh mA >wHYA',
#  "wlqd 'AtynA mwsY AlhdYA w>wrvnA bnY <srA'yl AlktAb",
#  'wmnhm mn ylmzk fY AlSdqAt f<n >ETwA mnhA rDwA w<n lm yETwA mnhA <*A hm ysxTwn',
#  ">m Hsb Al*yn AjtrHwA Alsy_At >n njElhm kAl*yn 'AmnwA wEmlwA AlSAlHAt swA' mHyAhm wmmAthm sA' mA yHkmwn",
#  'ttjAfYA jnwbhm En AlmDAjE ydEwn rbhm xwfA wTmEA wmmA rzqnAhm ynfqwn',
#  'w>rAdwA bh kydA fjElnAhm Al>xsryn',
#  'w<n tEdwA nEmp Allh lA tHSwhA <n Allh lgfwr rHym',
#  'wbrA bwAldtY wlm yjElnY jbArA $qyA',
#  "wlA tqwlwA lmn yqtl fY sbyl Allh >mwAt bl >HyA' wlAkn lA t$Erwn",
#  'wlA ynfqwn nfqp Sgyrp wlA kbyrp wlA yqTEwn wAdyA <lA ktb lhm lyjzyhm Allh >Hsn mA kAnwA yEmlwn',
#  "wlw kAnwA y&mnwn bAllh wAlnbY wmA >nzl <lyh mA Atx*whm >wlyA' wlAkn kvyrA mnhm fAsqwn",
#  "qAlwA >j}tnA ltlftnA EmA wjdnA Elyh 'AbA'nA wtkwn lkmA AlkbryA' fY Al>rD wmA nHn lkmA bm&mnyn",
#  'wysqwn fyhA k>sA kAn mzAjhA znjbylA',
#  "wywm ynfx fY AlSwr ffzE mn fY AlsmAwAt wmn fY Al>rD <lA mn $A' Allh wkl >twh dAxryn",
#  '>lm y>thm nb> Al*yn mn qblhm qwm nwH wEAd wvmwd wqwm <brAhym w>SHAb mdyn wAlm&tfkAt >tthm rslhm bAlbynAt fmA kAn Allh lyZlmhm wlAkn kAnwA >nfshm yZlmwn',
#  'qd frD Allh lkm tHlp >ymAnkm wAllh mwlYAkm whw AlElym AlHkym',
#  "wlqd njynA bnY <srA'yl mn AlE*Ab Almhyn",
#  'qlnA lA txf <nk >nt Al>ElYA',
#  'mA Atx* Allh mn wld wmA kAn mEh mn <lAh <*A l*hb kl <lAh bmA xlq wlElA bEDhm ElYA bED sbHAn Allh EmA ySfwn',
#  'wtHsbhm >yqAZA whm rqwd wnqlbhm *At Alymyn w*At Al$mAl wklbhm bAsT *rAEyh bAlwSyd lw ATlEt Elyhm lwlyt mnhm frArA wlml}t mnhm rEbA',
#  "lAkn Alrswl wAl*yn 'AmnwA mEh jAhdwA b>mwAlhm w>nfshm w>wlA}k lhm AlxyrAt w>wlA}k hm AlmflHwn",
#  "wqAlt Alyhwd lyst AlnSArYA ElYA $Y' wqAlt AlnSArYA lyst Alyhwd ElYA $Y' whm ytlwn AlktAb k*Alk qAl Al*yn lA yElmwn mvl qwlhm fAllh yHkm bynhm ywm AlqyAmp fymA kAnwA fyh yxtlfwn",
#  "wlqd >rslnA mn qblk rslA <lYA qwmhm fjA'whm bAlbynAt fAntqmnA mn Al*yn >jrmwA wkAn HqA ElynA nSr Alm&mnyn",
#  "ywm ybEvhm Allh jmyEA fyHlfwn lh kmA yHlfwn lkm wyHsbwn >nhm ElYA $Y' >lA <nhm hm AlkA*bwn",
#  'wk>sA dhAqA',
#  "wA*krwA <* jElkm xlfA' mn bEd EAd wbw>km fY Al>rD ttx*wn mn shwlhA qSwrA wtnHtwn AljbAl bywtA fA*krwA 'AlA' Allh wlA tEvwA fY Al>rD mfsdyn",
#  '<n Al*yn kfrwA mn >hl AlktAb wAlm$rkyn fY nAr jhnm xAldyn fyhA >wlA}k hm $r Albryp',
#  'ywm ynfx fY AlSwr wnH$r Almjrmyn ywm}* zrqA',
#  '>lhYAkm AltkAvr',
#  "hw Al>wl wAl'Axr wAlZAhr wAlbATn whw bkl $Y' Elym",
#  'wl}n >TEtm b$rA mvlkm <nkm <*A lxAsrwn',
#  ">r'yt Al*Y yk*b bAldyn",
#  'qAlwA rbnA yElm <nA <lykm lmrslwn',
#  'wlwlA <* smEtmwh qltm mA ykwn lnA >n ntklm bhA*A sbHAnk hA*A bhtAn EZym',
#  'wEAdA wvmwdA w>SHAb Alrs wqrwnA byn *Alk kvyrA',
#  'Aqtrb llnAs HsAbhm whm fY gflp mErDwn',
#  "wAl*yn kfrwA >EmAlhm ksrAb bqyEp yHsbh AlZm_An mA' HtYA <*A jA'h lm yjdh $y_A wwjd Allh Endh fwfYAh HsAbh wAllh sryE AlHsAb",
#  "w<* qAl Allh yAEysY Abn mrym '>nt qlt llnAs Atx*wnY w>mY <lAhyn mn dwn Allh qAl sbHAnk mA ykwn lY >n >qwl mA lys lY bHq <n knt qlth fqd Elmth tElm mA fY nfsY wlA >Elm mA fY nfsk <nk >nt ElAm Algywb",
#  "yA>xt hArwn mA kAn >bwk Amr> sw' wmA kAnt >mk bgyA",
#  "wAllh fDl bEDkm ElYA bED fY Alrzq fmA Al*yn fDlwA brAdY rzqhm ElYA mA mlkt >ymAnhm fhm fyh swA' >fbnEmp Allh yjHdwn",
#  'w*llnAhA lhm fmnhA rkwbhm wmnhA y>klwn',
#  '>wmn yn$&A fY AlHlyp whw fY AlxSAm gyr mbyn',
#  'lA y&mnwn bh wqd xlt snp Al>wlyn',
#  'fEAl lmA yryd',
#  'mn kAn EdwA llh wmlA}kth wrslh wjbryl wmykYAl f<n Allh Edw llkAfryn',
#  '<nA qd >wHY <lynA >n AlE*Ab ElYA mn k*b wtwlYA',
#  'wAtl mA >wHY <lyk mn ktAb rbk lA mbdl lklmAth wln tjd mn dwnh mltHdA',
#  'vm bEvnAkm mn bEd mwtkm lElkm t$krwn',
#  'wAl*yn k*bwA b_AyAtnA ymshm AlE*Ab bmA kAnwA yfsqwn',
#  '>f lkm wlmA tEbdwn mn dwn Allh >flA tEqlwn',
#  'ql lmn mA fY AlsmAwAt wAl>rD ql llh ktb ElYA nfsh AlrHmp lyjmEnkm <lYA ywm AlqyAmp lA ryb fyh Al*yn xsrwA >nfshm fhm lA y&mnwn',
#  "hw Al*Y jEl Al$ms DyA' wAlqmr nwrA wqdrh mnAzl ltElmwA Edd Alsnyn wAlHsAb mA xlq Allh *Alk <lA bAlHq yfSl Al'AyAt lqwm yElmwn",
#  'qAl bl swlt lkm >nfskm >mrA fSbr jmyl EsY Allh >n y>tynY bhm jmyEA <nh hw AlElym AlHkym',
#  'blYA mn >slm wjhh llh whw mHsn flh >jrh End rbh wlA xwf Elyhm wlA hm yHznwn',
#  "<nmA yst_*nk Al*yn lA y&mnwn bAllh wAlywm Al'Axr wArtAbt qlwbhm fhm fY rybhm ytrddwn",
#  'HtYA >tYAnA Alyqyn',
#  'vm twlwA Enh wqAlwA mElm mjnwn',
#  'lqd j}tm $y_A <dA',
#  'wk*Alk nrY <brAhym mlkwt AlsmAwAt wAl>rD wlykwn mn Almwqnyn',
#  "<nk lA tsmE AlmwtYA wlA tsmE AlSm AldEA' <*A wlwA mdbryn",
#  'qAl >nA xyr mnh xlqtnY mn nAr wxlqth mn Tyn',
#  "ql yA>hl AlktAb lm tSdwn En sbyl Allh mn 'Amn tbgwnhA EwjA w>ntm $hdA' wmA Allh bgAfl EmA tEmlwn",
#  '>m ll<nsAn mA tmnYA',
#  'fY smwm wHmym',
#  'wlh mn fY AlsmAwAt wAl>rD kl lh qAntwn',
#  'wxlq AljAn mn mArj mn nAr',
#  'qAlwA >n&mn lk wAtbEk Al>r*lwn',
#  'wkm >hlknA qblhm mn qrn hl tHs mnhm mn >Hd >w tsmE lhm rkzA',
#  'wmn >hl AlktAb mn <n t>mnh bqnTAr y&dh <lyk wmnhm mn <n t>mnh bdynAr lA y&dh <lyk <lA mA dmt Elyh qA}mA *Alk b>nhm qAlwA lys ElynA fY Al>myn sbyl wyqwlwn ElY Allh Alk*b whm yElmwn',
#  'wk>yn mn dAbp lA tHml rzqhA Allh yrzqhA w<yAkm whw AlsmyE AlElym',
#  'hl ynZrwn <lA AlsAEp >n t>tyhm bgtp whm lA y$Erwn',
#  "wAlsmA' rfEhA wwDE AlmyzAn",
#  "yASYAHbY Alsjn >mA >HdkmA fysqY rbh xmrA w>mA Al'Axr fySlb ft>kl AlTyr mn r>sh qDY Al>mr Al*Y fyh tstftyAn",
#  'wlbvwA fY khfhm vlAv mA}p snyn wAzdAdwA tsEA',
#  'ftwlYA brknh wqAl sAHr >w mjnwn',
#  'f>twA b_AbA}nA <n kntm SAdqyn',
#  'mswmp End rbk llmsrfyn',
#  "<nY twklt ElY Allh rbY wrbkm mA mn dAbp <lA hw 'Ax* bnASythA <n rbY ElYA SrAT mstqym",
#  "w<*A Almw'dp s}lt",
#  'wlA ys_l Hmym HmymA',
#  "wllh gyb AlsmAwAt wAl>rD wmA >mr AlsAEp <lA klmH AlbSr >w hw >qrb <n Allh ElYA kl $Y' qdyr",
#  'ymnwn Elyk >n >slmwA ql lA tmnwA ElY <slAmkm bl Allh ymn Elykm >n hdYAkm ll<ymAn <n kntm SAdqyn',
#  "wlA thnwA fY AbtgA' Alqwm <n tkwnwA t>lmwn f<nhm y>lmwn kmA t>lmwn wtrjwn mn Allh mA lA yrjwn wkAn Allh ElymA HkymA",
#  'xAldyn fyhA lA ybgwn EnhA HwlA',
#  'w>nA Axtrtk fAstmE lmA ywHYA',
#  '*Alk bmA qdmt ydAk w>n Allh lys bZlAm llEbyd',
#  'AdE <lYA sbyl rbk bAlHkmp wAlmwEZp AlHsnp wjAdlhm bAltY hY >Hsn <n rbk hw >Elm bmn Dl En sbylh whw >Elm bAlmhtdyn',
#  'rb <nhn >Dlln kvyrA mn AlnAs fmn tbEnY f<nh mnY wmn ESAnY f<nk gfwr rHym',
#  "hw Al*Y yrykm 'AyAth wynzl lkm mn AlsmA' rzqA wmA yt*kr <lA mn ynyb",
#  'qAlwA yAmwsYA <mA >n tlqY w<mA >n nkwn >wl mn >lqYA',
#  "wAlsmA' *At Albrwj",
#  "w>SbH Al*yn tmnwA mkAnh bAl>ms yqwlwn wyk>n Allh ybsT Alrzq lmn y$A' mn EbAdh wyqdr lwlA >n mn Allh ElynA lxsf bnA wyk>nh lA yflH AlkAfrwn",
#  'wlA >qsm bAlnfs AllwAmp',
#  "<nA >wHynA <lyk kmA >wHynA <lYA nwH wAlnbyn mn bEdh w>wHynA <lYA <brAhym w<smAEyl w<sHAq wyEqwb wAl>sbAT wEysYA w>ywb wywns whArwn wslymAn w'AtynA dAwd zbwrA",
#  'qAlwA bl lm tkwnwA m&mnyn',
#  "<n Allh ydxl Al*yn 'AmnwA wEmlwA AlSAlHAt jnAt tjrY mn tHthA Al>nhAr <n Allh yfEl mA yryd",
#  'wlA ElY Al*yn <*A mA >twk ltHmlhm qlt lA >jd mA >Hmlkm Elyh twlwA w>Eynhm tfyD mn AldmE HznA >lA yjdwA mA ynfqwn',
#  'w<* AEtzltmwhm wmA yEbdwn <lA Allh f>wA <lY Alkhf yn$r lkm rbkm mn rHmth wyhy} lkm mn >mrkm mrfqA',
#  '<n y$> y*hbkm wy>t bxlq jdyd',
#  "wqAlwA ljlwdhm lm $hdtm ElynA qAlwA >nTqnA Allh Al*Y >nTq kl $Y' whw xlqkm >wl mrp w<lyh trjEwn",
#  'w>qymwA Alwzn bAlqsT wlA txsrwA AlmyzAn',
#  'whdynAh Alnjdyn',
#  'w<lYA vmwd >xAhm SAlHA qAl yAqwm AEbdwA Allh mA lkm mn <lAh gyrh hw >n$>km mn Al>rD wAstEmrkm fyhA fAstgfrwh vm twbwA <lyh <n rbY qryb mjyb',
#  'ntlwA Elyk mn nb< mwsYA wfrEwn bAlHq lqwm y&mnwn',
#  "Al*yn ybxlwn wy>mrwn AlnAs bAlbxl wyktmwn mA 'AtYAhm Allh mn fDlh w>EtdnA llkAfryn E*AbA mhynA",
#  'wk*b bh qwmk whw AlHq ql lst Elykm bwkyl',
#  'qAl qA}l mnhm <nY kAn lY qryn',
#  'Al*Y yrYAk Hyn tqwm',
#  'hnAlk AlwlAyp llh AlHq hw xyr vwAbA wxyr EqbA',
#  '>wlA}k Al*yn yElm Allh mA fY qlwbhm f>ErD Enhm wEZhm wql lhm fY >nfshm qwlA blygA',
#  'wqAlwA >sATyr Al>wlyn AkttbhA fhY tmlYA Elyh bkrp w>SylA',
#  'wqAl Al*yn fY AlnAr lxznp jhnm AdEwA rbkm yxff EnA ywmA mn AlE*Ab',
#  'wmgAnm kvyrp y>x*wnhA wkAn Allh EzyzA HkymA',
#  'wAl*yn <*A fElwA fAH$p >w ZlmwA >nfshm *krwA Allh fAstgfrwA l*nwbhm wmn ygfr Al*nwb <lA Allh wlm ySrwA ElYA mA fElwA whm yElmwn',
#  "wlmA jA't rslnA lwTA sY' bhm wDAq bhm *rEA wqAl hA*A ywm ESyb",
#  "<n Al*yn 'AmnwA wAl*yn hAdwA wAlSAb_yn wAlnSArYA wAlmjws wAl*yn >$rkwA <n Allh yfSl bynhm ywm AlqyAmp <n Allh ElYA kl $Y' $hyd",
#  "ywm tkwn AlsmA' kAlmhl",
#  ">w'AbA&nA Al>wlwn",
#  "wjAY' ywm}* bjhnm ywm}* yt*kr Al<nsAn w>nYA lh Al*krYA",
#  'yA>yhA AlnAs AEbdwA rbkm Al*Y xlqkm wAl*yn mn qblkm lElkm ttqwn',
#  "rbnA 'AmnA bmA >nzlt wAtbEnA Alrswl fAktbnA mE Al$Ahdyn",
#  'fswf ydEwA vbwrA',
#  'fkyf ttqwn <n kfrtm ywmA yjEl AlwldAn $ybA',
#  '>Endh Elm Algyb fhw yrYA',
#  'mn AhtdYA f<nmA yhtdY lnfsh wmn Dl f<nmA yDl ElyhA wlA tzr wAzrp wzr >xrYA wmA knA mE*byn HtYA nbEv rswlA',
#  "flmA jA'hA nwdY >n bwrk mn fY AlnAr wmn HwlhA wsbHAn Allh rb AlEAlmyn",
#  'nzl Elyk AlktAb bAlHq mSdqA lmA byn ydyh w>nzl AltwrYAp wAl<njyl',
#  "yA>yhA Al*yn 'AmnwA qwA >nfskm w>hlykm nArA wqwdhA AlnAs wAlHjArp ElyhA mlA}kp glAZ $dAd lA yESwn Allh mA >mrhm wyfElwn mA y&mrwn",
#  'lyjEl mA ylqY Al$yTAn ftnp ll*yn fY qlwbhm mrD wAlqAsyp qlwbhm w<n AlZAlmyn lfY $qAq bEyd',
#  "mn jA' bAlHsnp flh xyr mnhA whm mn fzE ywm}* 'Amnwn",
#  'w>kyd kydA',
#  "'AmnwA bAllh wrswlh w>nfqwA mmA jElkm mstxlfyn fyh fAl*yn 'AmnwA mnkm w>nfqwA lhm >jr kbyr",
#  '<nA >rslnA <lykm rswlA $AhdA Elykm kmA >rslnA <lYA frEwn rswlA',
#  'wmA ydryk lElh yzkYA',
#  'nAr Allh Almwqdp',
#  ">wlA}k y&twn >jrhm mrtyn bmA SbrwA wydr'wn bAlHsnp Alsy}p wmmA rzqnAhm ynfqwn",
#  'ql <nY >mrt >n >Ebd Allh mxlSA lh Aldyn',
#  "<n Allh lA ygfr >n y$rk bh wygfr mA dwn *Alk lmn y$A' wmn y$rk bAllh fqd Dl DlAlA bEydA",
#  'wxsf Alqmr',
#  "<lA Al*yn 'AmnwA wEmlwA AlSAlHAt wtwASwA bAlHq wtwASwA bAlSbr",
#  'ln tnfEkm >rHAmkm wlA >wlAdkm ywm AlqyAmp yfSl bynkm wAllh bmA tEmlwn bSyr',
#  "wybyn Allh lkm Al'AyAt wAllh Elym Hkym",
#  '<n hA*A lhw AlblA&A Almbyn',
#  'f>yn t*hbwn',
#  '<n AlmSdqyn wAlmSdqAt w>qrDwA Allh qrDA HsnA yDAEf lhm wlhm >jr krym',
#  "rbnA <nk tElm mA nxfY wmA nEln wmA yxfYA ElY Allh mn $Y' fY Al>rD wlA fY AlsmA'",
#  "Al*yn ytbEwn Alrswl AlnbY Al>mY Al*Y yjdwnh mktwbA Endhm fY AltwrYAp wAl<njyl y>mrhm bAlmErwf wynhYAhm En Almnkr wyHl lhm AlTybAt wyHrm Elyhm AlxbA}v wyDE Enhm <Srhm wAl>glAl AltY kAnt Elyhm fAl*yn 'AmnwA bh wEzrwh wnSrwh wAtbEwA Alnwr Al*Y >nzl mEh >wlA}k hm AlmflHwn",
#  '>wlA}k Almqrbwn',
#  'AdxlwA Aljnp >ntm w>zwAjkm tHbrwn',
#  "wlqd >twA ElY Alqryp AltY >mTrt mTr Alsw' >flm ykwnwA yrwnhA bl kAnwA lA yrjwn n$wrA",
#  'wHsbwA >lA tkwn ftnp fEmwA wSmwA vm tAb Allh Elyhm vm EmwA wSmwA kvyr mnhm wAllh bSyr bmA yEmlwn',
#  'wAlwzn ywm}* AlHq fmn vqlt mwAzynh f>wlA}k hm AlmflHwn',
#  'fmn yEml mn AlSAlHAt whw m&mn flA kfrAn lsEyh w<nA lh kAtbwn',
#  'wfY mwsYA <* >rslnAh <lYA frEwn bslTAn mbyn',
#  '>smE bhm w>bSr ywm y>twnnA lAkn AlZAlmwn Alywm fY DlAl mbyn',
#  'wAllh yElm mA tsrwn wmA tElnwn',
#  "<n Al*yn y&*wn Allh wrswlh lEnhm Allh fY AldnyA wAl'Axrp w>Ed lhm E*AbA mhynA",
#  'rbnA <nk mn tdxl AlnAr fqd >xzyth wmA llZAlmyn mn >nSAr',
#  '<nmA twEdwn lSAdq',
#  'wnAdwA yAmAlk lyqD ElynA rbk qAl <nkm mAkvwn',
#  '<nh mn y>t rbh mjrmA f<n lh jhnm lA ymwt fyhA wlA yHyYA',
#  'whw Al*Y yHY wymyt wlh AxtlAf Alyl wAlnhAr >flA tEqlwn',
#  ">lhm >rjl ym$wn bhA >m lhm >yd ybT$wn bhA >m lhm >Eyn ybSrwn bhA >m lhm 'A*An ysmEwn bhA ql AdEwA $rkA'km vm kydwn flA tnZrwn",
#  'klA snktb mA yqwl wnmd lh mn AlE*Ab mdA',
#  'lqd kfr Al*yn qAlwA <n Allh vAlv vlAvp wmA mn <lAh <lA <lAh wAHd w<n lm ynthwA EmA yqwlwn lymsn Al*yn kfrwA mnhm E*Ab >lym',
#  "hm Al*yn kfrwA wSdwkm En Almsjd AlHrAm wAlhdY mEkwfA >n yblg mHlh wlwlA rjAl m&mnwn wnsA' m&mnAt lm tElmwhm >n tT_whm ftSybkm mnhm mErp bgyr Elm lydxl Allh fY rHmth mn y$A' lw tzylwA lE*bnA Al*yn kfrwA mnhm E*AbA >lymA",
#  '*Alk b>nh kAnt t>tyhm rslhm bAlbynAt fqAlwA >b$r yhdwnnA fkfrwA wtwlwA wAstgnY Allh wAllh gnY Hmyd',
#  "wmn kAn fY hA*h >EmYA fhw fY Al'Axrp >EmYA w>Dl sbylA",
#  "f>mA Al*yn 'AmnwA wEmlwA AlSAlHAt fhm fY rwDp yHbrwn",
#  "wtrYAhm yErDwn ElyhA xA$Eyn mn Al*l ynZrwn mn Trf xfY wqAl Al*yn 'AmnwA <n AlxAsryn Al*yn xsrwA >nfshm w>hlyhm ywm AlqyAmp >lA <n AlZAlmyn fY E*Ab mqym",
#  "f<n HAjwk fql >slmt wjhY llh wmn AtbEn wql ll*yn >wtwA AlktAb wAl>myn '>slmtm f<n >slmwA fqd AhtdwA w<n twlwA f<nmA Elyk AlblAg wAllh bSyr bAlEbAd",
#  'wqDYA rbk >lA tEbdwA <lA <yAh wbAlwAldyn <HsAnA <mA yblgn Endk Alkbr >HdhmA >w klAhmA flA tql lhmA >f wlA tnhrhmA wql lhmA qwlA krymA',
#  "yA>yhA Al*yn 'AmnwA A*krwA nEmp Allh Elykm <* jA'tkm jnwd f>rslnA Elyhm ryHA wjnwdA lm trwhA wkAn Allh bmA tEmlwn bSyrA",
#  'fqrbh <lyhm qAl >lA t>klwn',
#  "ql mA >s_lkm Elyh mn >jr <lA mn $A' >n ytx* <lYA rbh sbylA",
#  "ywm ybEvhm Allh jmyEA fynb}hm bmA EmlwA >HSYAh Allh wnswh wAllh ElYA kl $Y' $hyd",
#  'ql Allhm fATr AlsmAwAt wAl>rD EAlm Algyb wAl$hAdp >nt tHkm byn EbAdk fY mA kAnwA fyh yxtlfwn',
#  'ql >}nkm ltkfrwn bAl*Y xlq Al>rD fY ywmyn wtjElwn lh >ndAdA *Alk rb AlEAlmyn',
#  'mn dwn Allh hl ynSrwnkm >w yntSrwn',
#  "wlA tnkHwA Alm$rkAt HtYA y&mn wl>mp m&mnp xyr mn m$rkp wlw >Ejbtkm wlA tnkHwA Alm$rkyn HtYA y&mnwA wlEbd m&mn xyr mn m$rk wlw >Ejbkm >wlA}k ydEwn <lY AlnAr wAllh ydEwA <lY Aljnp wAlmgfrp b<*nh wybyn 'AyAth llnAs lElhm yt*krwn",
#  'wk*Alk jElnA fY kl qryp >kAbr mjrmyhA lymkrwA fyhA wmA ymkrwn <lA b>nfshm wmA y$Erwn',
#  'w>rsl Elyhm TyrA >bAbyl',
#  "mn >jl *Alk ktbnA ElYA bnY <srA'yl >nh mn qtl nfsA bgyr nfs >w fsAd fY Al>rD fk>nmA qtl AlnAs jmyEA wmn >HyAhA fk>nmA >HyA AlnAs jmyEA wlqd jA'thm rslnA bAlbynAt vm <n kvyrA mnhm bEd *Alk fY Al>rD lmsrfwn",
#  ">flm yhd lhm km >hlknA qblhm mn Alqrwn ym$wn fY msAknhm <n fY *Alk l'AyAt l>wlY AlnhYA",
#  '<* ErD Elyh bAlE$Y AlSAfnAt AljyAd',
#  'lA yftr Enhm whm fyh mblswn',
#  'Elmt nfs mA qdmt w>xrt',
#  'rbnA lA tzg qlwbnA bEd <* hdytnA whb lnA mn ldnk rHmp <nk >nt AlwhAb',
#  "fArtqb ywm t>tY AlsmA' bdxAn mbyn",
#  '<n Al*yn kfrwA wSdwA En sbyl Allh vm mAtwA whm kfAr fln ygfr Allh lhm',
#  'fjElhm j*A*A <lA kbyrA lhm lElhm <lyh yrjEwn',
#  'yxrj mn byn AlSlb wAltrA}b',
#  "wlqd Sdqkm Allh wEdh <* tHswnhm b<*nh HtYA <*A f$ltm wtnAzEtm fY Al>mr wESytm mn bEd mA >rYAkm mA tHbwn mnkm mn yryd AldnyA wmnkm mn yryd Al'Axrp vm Srfkm Enhm lybtlykm wlqd EfA Enkm wAllh *w fDl ElY Alm&mnyn",
#  "<n Al*yn kfrwA bAl*kr lmA jA'hm w<nh lktAb Ezyz",
#  'f>Eqbhm nfAqA fY qlwbhm <lYA ywm ylqwnh bmA >xlfwA Allh mA wEdwh wbmA kAnwA yk*bwn',
#  'fmn vqlt mwAzynh f>wlA}k hm AlmflHwn',
#  'hw Al*Y yrykm Albrq xwfA wTmEA wyn$} AlsHAb AlvqAl',
#  'mlEwnyn >ynmA vqfwA >x*wA wqtlwA tqtylA',
#  "mA yfEl Allh bE*Abkm <n $krtm w'Amntm wkAn Allh $AkrA ElymA",
#  "Hqyq ElYA >n lA >qwl ElY Allh <lA AlHq qd j}tkm bbynp mn rbkm f>rsl mEY bnY <srA'yl",
#  "<nh kAn fryq mn EbAdY yqwlwn rbnA 'AmnA fAgfr lnA wArHmnA w>nt xyr AlrAHmyn",
#  ">lm tr >n Allh ysjd lh mn fY AlsmAwAt wmn fY Al>rD wAl$ms wAlqmr wAlnjwm wAljbAl wAl$jr wAldwAb wkvyr mn AlnAs wkvyr Hq Elyh AlE*Ab wmn yhn Allh fmA lh mn mkrm <n Allh yfEl mA y$A'",
#  'wkm >rslnA mn nbY fY Al>wlyn',
#  '<* qAl lhm >xwhm lwT >lA ttqwn',
#  "<n Al*yn 'AmnwA wEmlwA AlSAlHAt >wlA}k hm xyr Albryp",
#  'qAl rb <nY Zlmt nfsY fAgfr lY fgfr lh <nh hw Algfwr AlrHym',
#  'ql mn ykl&km bAlyl wAlnhAr mn AlrHmAn bl hm En *kr rbhm mErDwn',
#  "wlqd 'AtynA mwsYA tsE 'AyAt bynAt fs_l bnY <srA'yl <* jA'hm fqAl lh frEwn <nY l>Znk yAmwsYA msHwrA",
#  'f<n twlwA f<nmA Elyk AlblAg Almbyn',
#  "wkm mn qryp >hlknAhA fjA'hA b>snA byAtA >w hm qA}lwn",
#  'wtrYA kvyrA mnhm ysArEwn fY Al<vm wAlEdwAn w>klhm AlsHt lb}s mA kAnwA yEmlwn',
#  'wmkrwA mkrA kbArA',
#  "Al*yn 'AmnwA wEmlwA AlSAlHAt TwbYA lhm wHsn m_Ab",
#  'kmA >nzlnA ElY Almqtsmyn',
#  'w<n jnHwA llslm fAjnH lhA wtwkl ElY Allh <nh hw AlsmyE AlElym',
#  "wAlbld AlTyb yxrj nbAth b<*n rbh wAl*Y xbv lA yxrj <lA nkdA k*Alk nSrf Al'AyAt lqwm y$krwn",
#  'wlA Sdyq Hmym',
#  'wElY Al*yn hAdwA HrmnA mA qSSnA Elyk mn qbl wmA ZlmnAhm wlAkn kAnwA >nfshm yZlmwn',
#  'lA >Ebd mA tEbdwn',
#  'whl >tYAk Hdyv mwsYA',
#  'sbHAn rb AlsmAwAt wAl>rD rb AlEr$ EmA ySfwn',
#  'f>tyA frEwn fqwlA <nA rswl rb AlEAlmyn',
#  'klA lynb*n fY AlHTmp',
#  'fwqYAhm Allh $r *Alk Alywm wlqYAhm nDrp wsrwrA',
#  'qAtlwhm yE*bhm Allh b>ydykm wyxzhm wynSrkm Elyhm wy$f Sdwr qwm m&mnyn',
#  "ql AnZrwA mA*A fY AlsmAwAt wAl>rD wmA tgnY Al'AyAt wAln*r En qwm lA y&mnwn",
#  '<rm *At AlEmAd',
#  "wlA trknwA <lY Al*yn ZlmwA ftmskm AlnAr wmA lkm mn dwn Allh mn >wlyA' vm lA tnSrwn",
#  'vm AjtbAh rbh ftAb Elyh whdYA',
#  "w<*A >nEmnA ElY Al<nsAn >ErD wn_A bjAnbh w<*A msh Al$r f*w dEA' EryD",
#  "qAlwA >j}tnA lt>fknA En 'AlhtnA f>tnA bmA tEdnA <n knt mn AlSAdqyn",
#  'wkAn lh vmr fqAl lSAHbh whw yHAwrh >nA >kvr mnk mAlA w>Ez nfrA',
#  'yA>hl AlktAb lm tkfrwn b_AyAt Allh w>ntm t$hdwn',
#  'sbHAn Allh EmA ySfwn',
#  'fklwA mmA rzqkm Allh HlAlA TybA wA$krwA nEmt Allh <n kntm <yAh tEbdwn',
#  'hw Al*Y xlqkm mn trAb vm mn nTfp vm mn Elqp vm yxrjkm TflA vm ltblgwA >$dkm vm ltkwnwA $ywxA wmnkm mn ytwfYA mn qbl wltblgwA >jlA msmY wlElkm tEqlwn',
#  'ql hl nnb}km bAl>xsryn >EmAlA',
#  'w<*A Alnjwm Ankdrt',
#  '<nh yElm Aljhr mn Alqwl wyElm mA tktmwn',
#  'Al*yn TgwA fY AlblAd',
#  'qtl AlxrASwn',
#  'fASbr lHkm rbk wlA tkn kSAHb AlHwt <* nAdYA whw mkZwm',
#  'wk*bwA b_AyAtnA k*AbA',
#  "<n Al*yn 'AmnwA whAjrwA wjAhdwA b>mwAlhm w>nfshm fY sbyl Allh wAl*yn 'AwwA wnSrwA >wlA}k bEDhm >wlyA' bED wAl*yn 'AmnwA wlm yhAjrwA mA lkm mn wlAythm mn $Y' HtYA yhAjrwA w<n AstnSrwkm fY Aldyn fElykm AlnSr <lA ElYA qwm bynkm wbynhm myvAq wAllh bmA tEmlwn bSyr",
#  'wmn xft mwAzynh f>wlA}k Al*yn xsrwA >nfshm bmA kAnwA b_AyAtnA yZlmwn',
#  'wx* bydk DgvA fADrb bh wlA tHnv <nA wjdnAh SAbrA nEm AlEbd <nh >wAb',
#  'E*rA >w n*rA',
#  'whw Al*Y yqbl Altwbp En EbAdh wyEfwA En Alsy_At wyElm mA tfElwn',
#  '*Alk b>nhm $AqwA Allh wrswlh wmn y$Aqq Allh wrswlh f<n Allh $dyd AlEqAb',
#  'wAlxyl wAlbgAl wAlHmyr ltrkbwhA wzynp wyxlq mA lA tElmwn',
#  '>wlm yr Al<nsAn >nA xlqnAh mn nTfp f<*A hw xSym mbyn',
#  'wAlAtY y>tyn AlfAH$p mn nsA}km fAst$hdwA Elyhn >rbEp mnkm f<n $hdwA f>mskwhn fY Albywt HtYA ytwfYAhn Almwt >w yjEl Allh lhn sbylA',
#  'w<n jhnm lmwEdhm >jmEyn',
#  "wjA' mn >qSA Almdynp rjl ysEYA qAl yAqwm AtbEwA Almrslyn",
#  'mn yTE Alrswl fqd >TAE Allh wmn twlYA fmA >rslnAk Elyhm HfyZA',
#  '<lA mn rHm Allh <nh hw AlEzyz AlrHym',
#  "Allh Al*Y yrsl AlryAH ftvyr sHAbA fybsTh fY AlsmA' kyf y$A' wyjElh ksfA ftrY Alwdq yxrj mn xlAlh f<*A >SAb bh mn y$A' mn EbAdh <*A hm ystb$rwn",
#  'lA tqm fyh >bdA lmsjd >ss ElY AltqwYA mn >wl ywm >Hq >n tqwm fyh fyh rjAl yHbwn >n ytThrwA wAllh yHb AlmThryn',
#  'qAl Alml> Al*yn kfrwA mn qwmh <nA lnrYAk fY sfAhp w<nA lnZnk mn AlkA*byn',
#  'f<n xftm frjAlA >w rkbAnA f<*A >mntm fA*krwA Allh kmA Elmkm mA lm tkwnwA tElmwn',
#  ">wlm yElmwA >n Allh ybsT Alrzq lmn y$A' wyqdr <n fY *Alk l'AyAt lqwm y&mnwn",
#  'slAm hY HtYA mTlE Alfjr',
#  'yA>yhA AlnAs Drb mvl fAstmEwA lh <n Al*yn tdEwn mn dwn Allh ln yxlqwA *bAbA wlw AjtmEwA lh w<n yslbhm Al*bAb $y_A lA ystnq*wh mnh DEf AlTAlb wAlmTlwb',
#  'qAl bSrt bmA lm ybSrwA bh fqbDt qbDp mn >vr Alrswl fnb*thA wk*Alk swlt lY nfsY',
#  'wlA tfsdwA fY Al>rD bEd <SlAHhA wAdEwh xwfA wTmEA <n rHmt Allh qryb mn AlmHsnyn',
#  'yA>yhA Almdvr',
#  "f>mA Al*yn kfrwA f>E*bhm E*AbA $dydA fY AldnyA wAl'Axrp wmA lhm mn nASryn",
#  'rDwA b>n ykwnwA mE AlxwAlf wTbE ElYA qlwbhm fhm lA yfqhwn',
#  'wqAl frEwn A}twnY bkl sAHr Elym',
#  'wqAlwA lwlA y>tynA b_Ayp mn rbh >wlm t>thm bynp mA fY AlSHf Al>wlYA',
#  "<n fY *Alk l'AyAt w<n knA lmbtlyn",
#  '<n fY *Alk l*krYA lmn kAn lh qlb >w >lqY AlsmE whw $hyd',
#  "wlwlA >n ktb Allh Elyhm AljlA' lE*bhm fY AldnyA wlhm fY Al'Axrp E*Ab AlnAr",
#  "ywm lA ynfE AlZAlmyn mE*rthm wlhm AllEnp wlhm sw' AldAr",
#  'w<*A mrwA bhm ytgAmzwn',
#  "yA>yhA Al*yn 'AmnwA >TyEwA Allh wrswlh wlA twlwA Enh w>ntm tsmEwn",
#  'qAl yAnwH <nh lys mn >hlk <nh Eml gyr SAlH flA ts_ln mA lys lk bh Elm <nY >EZk >n tkwn mn AljAhlyn',
#  'ywm yg$YAhm AlE*Ab mn fwqhm wmn tHt >rjlhm wyqwl *wqwA mA kntm tEmlwn',
#  'wsyjnbhA Al>tqY',
#  '<n Al*yn kfrwA ln tgnY Enhm >mwAlhm wlA >wlAdhm mn Allh $y_A w>wlA}k >SHAb AlnAr hm fyhA xAldwn',
#  'hw Al*Y jElkm xlA}f fY Al>rD fmn kfr fElyh kfrh wlA yzyd AlkAfryn kfrhm End rbhm <lA mqtA wlA yzyd AlkAfryn kfrhm <lA xsArA',
#  "wAtx*wA mn dwn Allh 'Alhp lElhm ynSrwn",
#  'qAl k*Alk qAl rbk hw ElY hyn wqd xlqtk mn qbl wlm tk $y_A',
#  "w<* qlnA llmlA}kp AsjdwA l'Adm fsjdwA <lA <blys >bYA",
#  'AstjybwA lrbkm mn qbl >n y>tY ywm lA mrd lh mn Allh mA lkm mn mlj< ywm}* wmA lkm mn nkyr',
#  'qAl EmA qlyl lySbHn nAdmyn',
#  "wlw n$A' l>rynAkhm flErfthm bsymAhm wltErfnhm fY lHn Alqwl wAllh yElm >EmAlkm",
#  "wlw >nA >hlknAhm bE*Ab mn qblh lqAlwA rbnA lwlA >rslt <lynA rswlA fntbE 'AyAtk mn qbl >n n*l wnxzYA",
#  'ql ytwfYAkm mlk Almwt Al*Y wkl bkm vm <lYA rbkm trjEwn',
#  "w<*A r>wA 'Ayp ystsxrwn",
#  'Al*yn yk*bwn bywm Aldyn',
#  "ysbH llh mA fY AlsmAwAt wmA fY Al>rD lh Almlk wlh AlHmd whw ElYA kl $Y' qdyr",
#  "vm dmrnA Al'Axryn",
#  'rHmp mn rbk <nh hw AlsmyE AlElym',
#  "Em ytsA'lwn",
#  'Al*yn k*bwA bAlktAb wbmA >rslnA bh rslnA fswf yElmwn',
#  'f<mA n*hbn bk f<nA mnhm mntqmwn',
#  "f<n zlltm mn bEd mA jA'tkm AlbynAt fAElmwA >n Allh Ezyz Hkym",
#  "mA yjAdl fY 'AyAt Allh <lA Al*yn kfrwA flA ygrrk tqlbhm fY AlblAd",
#  ">wlm ykn lhm 'Ayp >n yElmh ElmA&A bnY <srA'yl",
#  'klwA mn TybAt mA rzqnAkm wlA tTgwA fyh fyHl Elykm gDbY wmn yHll Elyh gDbY fqd hwYA',
#  "AlHmd llh fATr AlsmAwAt wAl>rD jAEl AlmlA}kp rslA >wlY >jnHp mvnYA wvlAv wrbAE yzyd fY Alxlq mA y$A' <n Allh ElYA kl $Y' qdyr",
#  "<n rbk ybsT Alrzq lmn y$A' wyqdr <nh kAn bEbAdh xbyrA bSyrA",
#  'kglY AlHmym',
#  "<n hA*A Alqr'An yqS ElYA bnY <srA'yl >kvr Al*Y hm fyh yxtlfwn",
#  'qAl hl >ntm mTlEwn',
#  "ql mn rb AlsmAwAt wAl>rD ql Allh ql >fAtx*tm mn dwnh >wlyA' lA ymlkwn l>nfshm nfEA wlA DrA ql hl ystwY Al>EmYA wAlbSyr >m hl tstwY AlZlmAt wAlnwr >m jElwA llh $rkA' xlqwA kxlqh ft$Abh Alxlq Elyhm ql Allh xAlq kl $Y' whw AlwAHd AlqhAr",
#  'qAl bl fElh kbyrhm hA*A fs_lwhm <n kAnwA ynTqwn',
#  "Al*yn 'AmnwA wkAnwA ytqwn",
#  'wyEbdwn mn dwn Allh mA lA ymlk lhm rzqA mn AlsmAwAt wAl>rD $y_A wlA ystTyEwn',
#  "<n kl mn fY AlsmAwAt wAl>rD <lA 'AtY AlrHmAn EbdA",
#  'wnAdynAh >n yA<brAhym',
#  'wlswf yETyk rbk ftrDYA',
#  'bmA gfr lY rbY wjElnY mn Almkrmyn',
#  '*Alk bmA qdmt >ydykm w>n Allh lys bZlAm llEbyd',
#  '<n hA*A lrzqnA mA lh mn nfAd',
#  "<n hA&lA' lyqwlwn",
#  "flmA jA'hm b_AyAtnA <*A hm mnhA yDHkwn",
#  'w<* qAl rbk llmlA}kp <nY xAlq b$rA mn SlSAl mn Hm< msnwn',
#  '<lYA ywm Alwqt AlmElwm',
#  '<n Al*yn yktmwn mA >nzlnA mn AlbynAt wAlhdYA mn bEd mA bynAh llnAs fY AlktAb >wlA}k ylEnhm Allh wylEnhm AllAEnwn',
#  'AlHmd llh Al*Y >nzl ElYA Ebdh AlktAb wlm yjEl lh EwjA',
#  "lw >nzlnA hA*A Alqr'An ElYA jbl lr>yth xA$EA mtSdEA mn x$yp Allh wtlk Al>mvAl nDrbhA llnAs lElhm ytfkrwn",
#  "wkyf tkfrwn w>ntm ttlYA Elykm 'AyAt Allh wfykm rswlh wmn yEtSm bAllh fqd hdY <lYA SrAT mstqym",
#  '<nY Znnt >nY mlAq HsAbyh',
#  'ywm ynfx fY AlSwr ft>twn >fwAjA',
#  "wlwTA 'AtynAh HkmA wElmA wnjynAh mn Alqryp AltY kAnt tEml AlxbA}v <nhm kAnwA qwm sw' fAsqyn",
#  'ql lmn Al>rD wmn fyhA <n kntm tElmwn',
#  'nHn >Elm bmA ystmEwn bh <* ystmEwn <lyk w<* hm njwYA <* yqwl AlZAlmwn <n ttbEwn <lA rjlA msHwrA',
#  'Allh Al*Y jEl lkm Al>nEAm ltrkbwA mnhA wmnhA t>klwn',
#  'wl}n msthm nfHp mn E*Ab rbk lyqwln yAwylnA <nA knA ZAlmyn',
#  "wlmA rjE mwsYA <lYA qwmh gDbAn >sfA qAl b}smA xlftmwnY mn bEdY >Ejltm >mr rbkm w>lqY Al>lwAH w>x* br>s >xyh yjrh <lyh qAl Abn >m <n Alqwm AstDEfwnY wkAdwA yqtlwnnY flA t$mt bY Al>EdA' wlA tjElnY mE Alqwm AlZAlmyn",
#  "wAl*yn ySlwn mA >mr Allh bh >n ywSl wyx$wn rbhm wyxAfwn sw' AlHsAb",
#  'wmn AlnAs mn yjAdl fY Allh bgyr Elm wytbE kl $yTAn mryd',
#  'wnAdYA frEwn fY qwmh qAl yAqwm >lys lY mlk mSr whA*h Al>nhAr tjrY mn tHtY >flA tbSrwn',
#  "lw kAn fyhmA 'Alhp <lA Allh lfsdtA fsbHAn Allh rb AlEr$ EmA ySfwn",
#  ">fr'ytm mA tmnwn",
#  "wyAqwm AstgfrwA rbkm vm twbwA <lyh yrsl AlsmA' Elykm mdrArA wyzdkm qwp <lYA qwtkm wlA ttwlwA mjrmyn",
#  'kyf w<n yZhrwA Elykm lA yrqbwA fykm <lA wlA *mp yrDwnkm b>fwAhhm wt>bYA qlwbhm w>kvrhm fAsqwn',
#  "wlqd mknAhm fymA <n mknAkm fyh wjElnA lhm smEA w>bSArA w>f_dp fmA >gnYA Enhm smEhm wlA >bSArhm wlA >f_dthm mn $Y' <* kAnwA yjHdwn b_AyAt Allh wHAq bhm mA kAnwA bh ysthz'wn",
#  "<lyh mrjEkm jmyEA wEd Allh HqA <nh ybd&A Alxlq vm yEydh lyjzY Al*yn 'AmnwA wEmlwA AlSAlHAt bAlqsT wAl*yn kfrwA lhm $rAb mn Hmym wE*Ab >lym bmA kAnwA ykfrwn",
#  "wqyDnA lhm qrnA' fzynwA lhm mA byn >ydyhm wmA xlfhm wHq Elyhm Alqwl fY >mm qd xlt mn qblhm mn Aljn wAl<ns <nhm kAnwA xAsryn",
#  "yA>yhA Al*yn 'AmnwA lA tkwnwA kAl*yn kfrwA wqAlwA l<xwAnhm <*A DrbwA fY Al>rD >w kAnwA gzY lw kAnwA EndnA mA mAtwA wmA qtlwA lyjEl Allh *Alk Hsrp fY qlwbhm wAllh yHY wymyt wAllh bmA tEmlwn bSyr",
#  "qAl yAqwm >r'ytm <n knt ElYA bynp mn rbY w'AtYAnY mnh rHmp fmn ynSrnY mn Allh <n ESyth fmA tzydwnnY gyr txsyr",
#  'tnzE AlnAs k>nhm >EjAz nxl mnqEr',
#  '*Alk b>nhm krhwA mA >nzl Allh f>HbT >EmAlhm',
#  "zyn ll*yn kfrwA AlHywAp AldnyA wysxrwn mn Al*yn 'AmnwA wAl*yn AtqwA fwqhm ywm AlqyAmp wAllh yrzq mn y$A' bgyr HsAb",
#  'HtYA <*A blg mTlE Al$ms wjdhA tTlE ElYA qwm lm njEl lhm mn dwnhA strA',
#  'wqyl mn rAq',
#  'w>xrjt Al>rD >vqAlhA',
#  'w>gT$ lylhA w>xrj DHYAhA',
#  'fqdrnA fnEm AlqAdrwn',
#  'wmA >s_lkm Elyh mn >jr <n >jrY <lA ElYA rb AlEAlmyn',
#  '<lA mn ArtDYA mn rswl f<nh yslk mn byn ydyh wmn xlfh rSdA',
#  "mvl Aljnp AltY wEd Almtqwn fyhA >nhAr mn mA' gyr 'Asn w>nhAr mn lbn lm ytgyr TEmh w>nhAr mn xmr l*p ll$Arbyn w>nhAr mn Esl mSfY wlhm fyhA mn kl AlvmrAt wmgfrp mn rbhm kmn hw xAld fY AlnAr wsqwA mA' HmymA fqTE >mEA'hm",
#  "wfY Al>rD qTE mtjAwrAt wjnAt mn >EnAb wzrE wnxyl SnwAn wgyr SnwAn ysqYA bmA' wAHd wnfDl bEDhA ElYA bED fY Al>kl <n fY *Alk l'AyAt lqwm yEqlwn",
#  'mn dwn Allh fAhdwhm <lYA SrAT AljHym',
#  "wjElnA Alyl wAlnhAr 'Aytyn fmHwnA 'Ayp Alyl wjElnA 'Ayp AlnhAr mbSrp ltbtgwA fDlA mn rbkm wltElmwA Edd Alsnyn wAlHsAb wkl $Y' fSlnAh tfSylA",
#  '<nmA ynhYAkm Allh En Al*yn qAtlwkm fY Aldyn w>xrjwkm mn dyArkm wZAhrwA ElYA <xrAjkm >n twlwhm wmn ytwlhm f>wlA}k hm AlZAlmwn',
#  "ql l}n AjtmEt Al<ns wAljn ElYA >n y>twA bmvl hA*A Alqr'An lA y>twn bmvlh wlw kAn bEDhm lbED ZhyrA",
#  "<n Allh lA yxfYA Elyh $Y' fY Al>rD wlA fY AlsmA'",
#  'Hwr mqSwrAt fY AlxyAm',
#  'yElmwn mA tfElwn',
#  'hA*A n*yr mn Aln*r Al>wlYA',
#  "w<*A ttlYA Elyhm 'AyAtnA bynAt tErf fY wjwh Al*yn kfrwA Almnkr ykAdwn ysTwn bAl*yn ytlwn Elyhm 'AyAtnA ql >f>nb}km b$r mn *Alkm AlnAr wEdhA Allh Al*yn kfrwA wb}s AlmSyr",
#  'bl qAlwA mvl mA qAl Al>wlwn',
#  'fyhA srr mrfwEp',
#  'rdwhA ElY fTfq msHA bAlswq wAl>EnAq',
#  'ywm nH$r Almtqyn <lY AlrHmAn wfdA',
#  "kd>b 'Al frEwn wAl*yn mn qblhm k*bwA b_AyAtnA f>x*hm Allh b*nwbhm wAllh $dyd AlEqAb",
#  'lys ElY Al>EmYA Hrj wlA ElY Al>Erj Hrj wlA ElY AlmryD Hrj wmn yTE Allh wrswlh ydxlh jnAt tjrY mn tHthA Al>nhAr wmn ytwl yE*bh E*AbA >lymA',
#  'vm yqAl hA*A Al*Y kntm bh tk*bwn',
#  'whA*A *kr mbArk >nzlnAh >f>ntm lh mnkrwn',
#  'lyn*r mn kAn HyA wyHq Alqwl ElY AlkAfryn',
#  'hl >tYAk Hdyv Aljnwd',
#  'AltY lm yxlq mvlhA fY AlblAd',
#  'wl}n s>lthm mn xlq AlsmAwAt wAl>rD lyqwln Allh ql AlHmd llh bl >kvrhm lA yElmwn',
#  'yHlfwn bAllh lkm lyrDwkm wAllh wrswlh >Hq >n yrDwh <n kAnwA m&mnyn',
#  'Allh Al*Y jEl lkm Alyl ltsknwA fyh wAlnhAr mbSrA <n Allh l*w fDl ElY AlnAs wlAkn >kvr AlnAs lA y$krwn',
#  ">wlm ysyrwA fY Al>rD fynZrwA kyf kAn EAqbp Al*yn mn qblhm kAnwA >$d mnhm qwp w>vArwA Al>rD wEmrwhA >kvr mmA EmrwhA wjA'thm rslhm bAlbynAt fmA kAn Allh lyZlmhm wlAkn kAnwA >nfshm yZlmwn",
#  'f<n Aljnp hY Alm>wYA',
#  "wAl*yn EmlwA Alsy_At vm tAbwA mn bEdhA w'AmnwA <n rbk mn bEdhA lgfwr rHym",
#  "f<*A An$qt AlsmA' fkAnt wrdp kAldhAn",
#  "tsqYA mn Eyn 'Anyp",
#  'w>lqYA fY Al>rD rwAsY >n tmyd bkm w>nhArA wsblA lElkm thtdwn',
#  "<n Al*yn 'AmnwA wEmlwA AlSAlHAt w>qAmwA AlSlwAp w'AtwA AlzkwAp lhm >jrhm End rbhm wlA xwf Elyhm wlA hm yHznwn",
#  '>fmn $rH Allh Sdrh ll<slAm fhw ElYA nwr mn rbh fwyl llqAsyp qlwbhm mn *kr Allh >wlA}k fY DlAl mbyn',
#  "sl bnY <srA'yl km 'AtynAhm mn 'Ayp bynp wmn ybdl nEmp Allh mn bEd mA jA'th f<n Allh $dyd AlEqAb",
#  'w<* qyl lhm AsknwA hA*h Alqryp wklwA mnhA Hyv $}tm wqwlwA HTp wAdxlwA AlbAb sjdA ngfr lkm xTy_Atkm snzyd AlmHsnyn',
#  "lA yst_*nk Al*yn y&mnwn bAllh wAlywm Al'Axr >n yjAhdwA b>mwAlhm w>nfshm wAllh Elym bAlmtqyn",
#  'wlA tqrbwA mAl Alytym <lA bAltY hY >Hsn HtYA yblg >$dh w>wfwA Alkyl wAlmyzAn bAlqsT lA nklf nfsA <lA wsEhA w<*A qltm fAEdlwA wlw kAn *A qrbYA wbEhd Allh >wfwA *Alkm wSYAkm bh lElkm t*krwn',
#  "wlqd 'AtynA mwsY AlktAb fAxtlf fyh wlwlA klmp sbqt mn rbk lqDY bynhm w<nhm lfY $k mnh mryb",
#  'wln*yqnhm mn AlE*Ab Al>dnYA dwn AlE*Ab Al>kbr lElhm yrjEwn',
#  "*Alk Alywm AlHq fmn $A' Atx* <lYA rbh m_AbA",
#  "wAl>nEAm xlqhA lkm fyhA df' wmnAfE wmnhA t>klwn",
#  'fqwlA lh qwlA lynA lElh yt*kr >w yx$YA',
#  'bsm Allh AlrHmAn AlrHym',
#  'wAllh >nbtkm mn Al>rD nbAtA',
#  'hw Al*Y >xrj Al*yn kfrwA mn >hl AlktAb mn dyArhm l>wl AlH$r mA Znntm >n yxrjwA wZnwA >nhm mAnEthm HSwnhm mn Allh f>tYAhm Allh mn Hyv lm yHtsbwA wq*f fY qlwbhm AlrEb yxrbwn bywthm b>ydyhm w>ydY Alm&mnyn fAEtbrwA yA>wlY Al>bSAr',
#  'qAlwA ln nbrH Elyh EAkfyn HtYA yrjE <lynA mwsYA',
#  "vm ntbEhm Al'Axryn",
#  "wlmA dxlwA ElYA ywsf 'AwYA <lyh >xAh qAl <nY >nA >xwk flA tbt}s bmA kAnwA yEmlwn",
#  'lA $ryk lh wb*Alk >mrt w>nA >wl Almslmyn',
#  'yTAf Elyhm bk>s mn mEyn',
#  '>wlm ytfkrwA mA bSAHbhm mn jnp <n hw <lA n*yr mbyn',
#  'w<nh lHq Alyqyn',
#  "yA>hl AlktAb qd jA'km rswlnA ybyn lkm kvyrA mmA kntm txfwn mn AlktAb wyEfwA En kvyr qd jA'km mn Allh nwr wktAb mbyn",
#  ">mn yjyb AlmDTr <*A dEAh wyk$f Alsw' wyjElkm xlfA' Al>rD >'lAh mE Allh qlylA mA t*krwn",
#  'wmA >drYAk mA ywm Aldyn',
#  'fmA tnfEhm $fAEp Al$AfEyn',
#  "lyHmlwA >wzArhm kAmlp ywm AlqyAmp wmn >wzAr Al*yn yDlwnhm bgyr Elm >lA sA' mA yzrwn",
#  "fwjdA EbdA mn EbAdnA 'AtynAh rHmp mn EndnA wElmnAh mn ldnA ElmA",
#  "fbEv Allh grAbA ybHv fY Al>rD lyryh kyf ywArY sw'p >xyh qAl yAwyltYA >Ejzt >n >kwn mvl hA*A AlgrAb f>wArY sw'p >xY f>SbH mn AlnAdmyn",
#  "w<lYA mdyn >xAhm $EybA fqAl yAqwm AEbdwA Allh wArjwA Alywm Al'Axr wlA tEvwA fY Al>rD mfsdyn",
#  'wmA l>Hd Endh mn nEmp tjzYA',
#  'wjElnA *ryth hm AlbAqyn',
#  'wqAl Allh lA ttx*wA <lAhyn Avnyn <nmA hw <lAh wAHd f<yAY fArhbwn',
#  'wqlnA yA_Adm Askn >nt wzwjk Aljnp wklA mnhA rgdA Hyv $}tmA wlA tqrbA hA*h Al$jrp ftkwnA mn AlZAlmyn',
#  'wmA tjzwn <lA mA kntm tEmlwn',
#  "kAl*yn mn qblkm kAnwA >$d mnkm qwp w>kvr >mwAlA w>wlAdA fAstmtEwA bxlAqhm fAstmtEtm bxlAqkm kmA AstmtE Al*yn mn qblkm bxlAqhm wxDtm kAl*Y xADwA >wlA}k HbTt >EmAlhm fY AldnyA wAl'Axrp w>wlA}k hm AlxAsrwn",
#  'llsA}l wAlmHrwm',
#  '<lYA frEwn whAmAn wqArwn fqAlwA sAHr k*Ab',
#  "wmA >nzlnA ElYA qwmh mn bEdh mn jnd mn AlsmA' wmA knA mnzlyn",
#  'tlk Aljnp AltY nwrv mn EbAdnA mn kAn tqyA',
#  "nHn >Elm bmA yqwlwn wmA >nt Elyhm bjbAr f*kr bAlqr'An mn yxAf wEyd",
#  'Almlk ywm}* AlHq llrHmAn wkAn ywmA ElY AlkAfryn EsyrA',
#  'ql syrwA fY Al>rD fAnZrwA kyf kAn EAqbp Almjrmyn',
#  '>m lkm ktAb fyh tdrswn',
#  '<n kAnt <lA SyHp wAHdp f<*A hm jmyE ldynA mHDrwn',
#  'frjEwA <lYA >nfshm fqAlwA <nkm >ntm AlZAlmwn',
#  "bl mtEt hA&lA' w'AbA'hm HtYA jA'hm AlHq wrswl mbyn",
#  'lA ysmEwn fyhA lgwA wlA t>vymA',
#  "tlk 'AyAt Allh ntlwhA Elyk bAlHq wmA Allh yryd ZlmA llEAlmyn",
#  "f>vAbhm Allh bmA qAlwA jnAt tjrY mn tHthA Al>nhAr xAldyn fyhA w*Alk jzA' AlmHsnyn",
#  "wlqd >x*nA 'Al frEwn bAlsnyn wnqS mn AlvmrAt lElhm y*krwn",
#  'yA>hl AlktAb lm tlbswn AlHq bAlbATl wtktmwn AlHq w>ntm tElmwn',
#  "wlqd DrbnA llnAs fY hA*A Alqr'An mn kl mvl wl}n j}thm b_Ayp lyqwln Al*yn kfrwA <n >ntm <lA mbTlwn",
#  'wyTAf Elyhm b_Anyp mn fDp w>kwAb kAnt qwAryrA',
#  "w'Axr mn $klh >zwAj",
#  "yA>yhA Al*yn 'AmnwA <n ttqwA Allh yjEl lkm frqAnA wykfr Enkm sy_Atkm wygfr lkm wAllh *w AlfDl AlEZym",
#  'flns_ln Al*yn >rsl <lyhm wlns_ln Almrslyn',
#  "w>mA Al*yn sEdwA ffY Aljnp xAldyn fyhA mA dAmt AlsmAwAt wAl>rD <lA mA $A' rbk ETA' gyr mj*w*",
#  'wkl <nsAn >lzmnAh TA}rh fY Enqh wnxrj lh ywm AlqyAmp ktAbA ylqYAh mn$wrA',
#  'w<*A g$yhm mwj kAlZll dEwA Allh mxlSyn lh Aldyn flmA njYAhm <lY Albr fmnhm mqtSd wmA yjHd b_AyAtnA <lA kl xtAr kfwr',
#  "yElmwn ZAhrA mn AlHywAp AldnyA whm En Al'Axrp hm gAflwn",
#  'fsnysrh llEsrYA',
#  "w>qbl bEDhm ElYA bED ytsA'lwn",
#  ">jEl Al'Alhp <lAhA wAHdA <n hA*A l$Y' EjAb",
#  'qwAryrA mn fDp qdrwhA tqdyrA',
#  "wyAqwm >wfwA AlmkyAl wAlmyzAn bAlqsT wlA tbxswA AlnAs >$yA'hm wlA tEvwA fY Al>rD mfsdyn",
#  'wmA kAn lm&mn >n yqtl m&mnA <lA xT_A wmn qtl m&mnA xT_A ftHryr rqbp m&mnp wdyp mslmp <lYA >hlh <lA >n ySdqwA f<n kAn mn qwm Edw lkm whw m&mn ftHryr rqbp m&mnp w<n kAn mn qwm bynkm wbynhm myvAq fdyp mslmp <lYA >hlh wtHryr rqbp m&mnp fmn lm yjd fSyAm $hryn mttAbEyn twbp mn Allh wkAn Allh ElymA HkymA',
#  'qAlwA <nA <lYA rbnA mnqlbwn',
#  'qAlwA yAmwsYA <n fyhA qwmA jbAryn w<nA ln ndxlhA HtYA yxrjwA mnhA f<n yxrjwA mnhA f<nA dAxlwn',
#  'kyf tkfrwn bAllh wkntm >mwAtA f>HyAkm vm ymytkm vm yHyykm vm <lyh trjEwn',
#  'wwAld wmA wld',
#  "ql <n rbY ybsT Alrzq lmn y$A' wyqdr wlAkn >kvr AlnAs lA yElmwn",
#  '>lA ttbEn >fESyt >mrY',
#  'wlh AlHmd fY AlsmAwAt wAl>rD wE$yA wHyn tZhrwn',
#  "rjAl lA tlhyhm tjArp wlA byE En *kr Allh w<qAm AlSlwAp w<ytA' AlzkwAp yxAfwn ywmA ttqlb fyh Alqlwb wAl>bSAr",
#  "qAl <nmA y>tykm bh Allh <n $A' wmA >ntm bmEjzyn",
#  'HtYA <*A ftHt y>jwj wm>jwj whm mn kl Hdb ynslwn',
#  'vm <n ElynA HsAbhm',
#  'wmn >Hsn dynA mmn >slm wjhh llh whw mHsn wAtbE mlp <brAhym HnyfA wAtx* Allh <brAhym xlylA',
#  'wllh gyb AlsmAwAt wAl>rD w<lyh yrjE Al>mr klh fAEbdh wtwkl Elyh wmA rbk bgAfl EmA tEmlwn',
#  'whw Al*Y xlq Alyl wAlnhAr wAl$ms wAlqmr kl fY flk ysbHwn',
#  'lA ygrnk tqlb Al*yn kfrwA fY AlblAd',
#  'qAlwA k*Alk qAl rbk <nh hw AlHkym AlElym',
#  'yrydwn >n yxrjwA mn AlnAr wmA hm bxArjyn mnhA wlhm E*Ab mqym',
#  'w>qsmwA bAllh jhd >ymAnhm l}n >mrthm lyxrjn ql lA tqsmwA TAEp mErwfp <n Allh xbyr bmA tEmlwn',
#  'x* mn >mwAlhm Sdqp tThrhm wtzkyhm bhA wSl Elyhm <n SlwAtk skn lhm wAllh smyE Elym',
#  'fqAl <nY >Hbbt Hb Alxyr En *kr rbY HtYA twArt bAlHjAb',
#  'mA ElY Alrswl <lA AlblAg wAllh yElm mA tbdwn wmA tktmwn',
#  'wAlbdn jElnAhA lkm mn $EA}r Allh lkm fyhA xyr fA*krwA Asm Allh ElyhA SwAf f<*A wjbt jnwbhA fklwA mnhA w>TEmwA AlqAnE wAlmEtr k*Alk sxrnAhA lkm lElkm t$krwn',
#  "wAl*yn 'AmnwA wEmlwA AlSAlHAt lndxlnhm fY AlSAlHyn",
#  "wmn ywlhm ywm}* dbrh <lA mtHrfA lqtAl >w mtHyzA <lYA f}p fqd bA' bgDb mn Allh wm>wYAh jhnm wb}s AlmSyr",
#  "flmA r'A >ydyhm lA tSl <lyh nkrhm w>wjs mnhm xyfp qAlwA lA txf <nA >rslnA <lYA qwm lwT",
#  'lA trkDwA wArjEwA <lYA mA >trftm fyh wmsAknkm lElkm ts_lwn',
#  ">fr'yt Al*Y kfr b_AyAtnA wqAl l>wtyn mAlA wwldA",
#  ">wlA}k lm ykwnwA mEjzyn fY Al>rD wmA kAn lhm mn dwn Allh mn >wlyA' yDAEf lhm AlE*Ab mA kAnwA ystTyEwn AlsmE wmA kAnwA ybSrwn",
#  'bl t&vrwn AlHywAp AldnyA',
#  'w<n kAnwA lyqwlwn',
#  'hnAlk AbtlY Alm&mnwn wzlzlwA zlzAlA $dydA',
#  "mA AlmsyH Abn mrym <lA rswl qd xlt mn qblh Alrsl w>mh Sdyqp kAnA y>klAn AlTEAm AnZr kyf nbyn lhm Al'AyAt vm AnZr >nYA y&fkwn",
#  "yA>yhA Al*yn 'AmnwA AtqwA Allh Hq tqAth wlA tmwtn <lA w>ntm mslmwn",
#  "xAldyn fyhA mA dAmt AlsmAwAt wAl>rD <lA mA $A' rbk <n rbk fEAl lmA yryd",
#  'wAlrjz fAhjr',
#  'fkAn qAb qwsyn >w >dnYA',
#  "yA>yhA Al*yn 'AmnwA <*A lqytm f}p fAvbtwA wA*krwA Allh kvyrA lElkm tflHwn",
#  'w>ywb <* nAdYA rbh >nY msnY AlDr w>nt >rHm AlrAHmyn',
#  'ql >nzlh Al*Y yElm Alsr fY AlsmAwAt wAl>rD <nh kAn gfwrA rHymA',
#  "yA>yhA Al*yn 'AmnwA mA lkm <*A qyl lkm AnfrwA fY sbyl Allh AvAqltm <lY Al>rD >rDytm bAlHywAp AldnyA mn Al'Axrp fmA mtAE AlHywAp AldnyA fY Al'Axrp <lA qlyl",
#  "f<n k*bwk fqd k*b rsl mn qblk jA'w bAlbynAt wAlzbr wAlktAb Almnyr",
#  "<nmA wlykm Allh wrswlh wAl*yn 'AmnwA Al*yn yqymwn AlSlwAp wy&twn AlzkwAp whm rAkEwn",
#  'wltElmn nb>h bEd Hyn',
#  'EynA y$rb bhA EbAd Allh yfjrwnhA tfjyrA',
#  "qd kAnt lkm >swp Hsnp fY <brAhym wAl*yn mEh <* qAlwA lqwmhm <nA br'A&A mnkm wmmA tEbdwn mn dwn Allh kfrnA bkm wbdA bynnA wbynkm AlEdAwp wAlbgDA' >bdA HtYA t&mnwA bAllh wHdh <lA qwl <brAhym l>byh l>stgfrn lk wmA >mlk lk mn Allh mn $Y' rbnA Elyk twklnA w<lyk >nbnA w<lyk AlmSyr",
#  'ywm lA ygnY Enhm kydhm $y_A wlA hm ynSrwn',
#  "wqAlwA mhmA t>tnA bh mn 'Ayp ltsHrnA bhA fmA nHn lk bm&mnyn",
#  "wlqd DrbnA llnAs fY hA*A Alqr'An mn kl mvl lElhm yt*krwn",
#  'wql rb >Ew* bk mn hmzAt Al$yATyn',
#  "lyElm >n qd >blgwA rsAlAt rbhm w>HAT bmA ldyhm w>HSYA kl $Y' EddA",
#  "wqAl mwsYA yAqwm <n kntm 'Amntm bAllh fElyh twklwA <n kntm mslmyn",
#  'wlA tkwnwA kAl*yn qAlwA smEnA whm lA ysmEwn',
#  'f>n$>nA lkm bh jnAt mn nxyl w>EnAb lkm fyhA fwAkh kvyrp wmnhA t>klwn',
#  '>wlys Al*Y xlq AlsmAwAt wAl>rD bqAdr ElYA >n yxlq mvlhm blYA whw AlxlAq AlElym',
#  'wAtqwA Al*Y xlqkm wAljblp Al>wlyn',
#  'w<n tk*bwA fqd k*b >mm mn qblkm wmA ElY Alrswl <lA AlblAg Almbyn',
#  'hl >tYAk Hdyv Dyf <brAhym Almkrmyn',
#  "wlkm nSf mA trk >zwAjkm <n lm ykn lhn wld f<n kAn lhn wld flkm AlrbE mmA trkn mn bEd wSyp ywSyn bhA >w dyn wlhn AlrbE mmA trktm <n lm ykn lkm wld f<n kAn lkm wld flhn Alvmn mmA trktm mn bEd wSyp twSwn bhA >w dyn w<n kAn rjl ywrv klAlp >w Amr>p wlh >x >w >xt flkl wAHd mnhmA Alsds f<n kAnwA >kvr mn *Alk fhm $rkA' fY Alvlv mn bEd wSyp ywSYA bhA >w dyn gyr mDAr wSyp mn Allh wAllh Elym Hlym",
#  '>lm tr >nhm fY kl wAd yhymwn',
#  "hw Al*Y bEv fY Al>myn rswlA mnhm ytlwA Elyhm 'AyAth wyzkyhm wyElmhm AlktAb wAlHkmp w<n kAnwA mn qbl lfY DlAl mbyn",
#  'wmmn xlqnA >mp yhdwn bAlHq wbh yEdlwn',
#  "lqd kAn fY qSShm Ebrp l>wlY Al>lbAb mA kAn HdyvA yftrYA wlAkn tSdyq Al*Y byn ydyh wtfSyl kl $Y' whdY wrHmp lqwm y&mnwn",
#  'bl hm Alywm mstslmwn',
#  'wlw nzlnA Elyk ktAbA fY qrTAs flmswh b>ydyhm lqAl Al*yn kfrwA <n hA*A <lA sHr mbyn',
#  "w>wHY <lYA nwH >nh ln y&mn mn qwmk <lA mn qd 'Amn flA tbt}s bmA kAnwA yfElwn",
#  ">wlA}k Al*yn A$trwA AlHywAp AldnyA bAl'Axrp flA yxff Enhm AlE*Ab wlA hm ynSrwn",
#  'vm twlytm mn bEd *Alk flwlA fDl Allh Elykm wrHmth lkntm mn AlxAsryn',
#  "<lA mn tAb w'Amn wEml EmlA SAlHA f>wlA}k ybdl Allh sy_Athm HsnAt wkAn Allh gfwrA rHymA",
#  'w<n Amr>p xAft mn bElhA n$wzA >w <ErADA flA jnAH ElyhmA >n ySlHA bynhmA SlHA wAlSlH xyr w>HDrt Al>nfs Al$H w<n tHsnwA wttqwA f<n Allh kAn bmA tEmlwn xbyrA',
#  'mA AlHAqp',
#  'wAllh xlqkm mn trAb vm mn nTfp vm jElkm >zwAjA wmA tHml mn >nvYA wlA tDE <lA bElmh wmA yEmr mn mEmr wlA ynqS mn Emrh <lA fY ktAb <n *Alk ElY Allh ysyr',
#  "wmA nrsl Almrslyn <lA mb$ryn wmn*ryn wyjAdl Al*yn kfrwA bAlbATl lydHDwA bh AlHq wAtx*wA 'AyAtY wmA >n*rwA hzwA",
#  'fhl yntZrwn <lA mvl >yAm Al*yn xlwA mn qblhm ql fAntZrwA <nY mEkm mn AlmntZryn',
#  '>wlA}k yjzwn Algrfp bmA SbrwA wylqwn fyhA tHyp wslAmA',
#  'wAllh xlqkm vm ytwfYAkm wmnkm mn yrd <lYA >r*l AlEmr lkY lA yElm bEd Elm $y_A <n Allh Elym qdyr',
#  'wjElwA llh >ndAdA lyDlwA En sbylh ql tmtEwA f<n mSyrkm <lY AlnAr',
#  'w>nA mnA Almslmwn wmnA AlqAsTwn fmn >slm f>wlA}k tHrwA r$dA',
#  'Al*Y hm fyh mxtlfwn',
#  "w<nY lgfAr lmn tAb w'Amn wEml SAlHA vm AhtdYA",
#  'wmn AlnAs mn y$trY lhw AlHdyv lyDl En sbyl Allh bgyr Elm wytx*hA hzwA >wlA}k lhm E*Ab mhyn',
#  "<n Allh lA ystHY >n yDrb mvlA mA bEwDp fmA fwqhA f>mA Al*yn 'AmnwA fyElmwn >nh AlHq mn rbhm w>mA Al*yn kfrwA fyqwlwn mA*A >rAd Allh bhA*A mvlA yDl bh kvyrA wyhdY bh kvyrA wmA yDl bh <lA AlfAsqyn",
#  'rb AlsmAwAt wAl>rD wmA bynhmA wrb Alm$Arq',
#  'wfAkhp w>bA',
#  'AlnAr *At Alwqwd',
#  "wmA y*krwn <lA >n y$A' Allh hw >hl AltqwYA w>hl Almgfrp",
#  'f>lqYA ESAh f<*A hY vEbAn mbyn',
#  "f<n twlwA fqd >blgtkm mA >rslt bh <lykm wystxlf rbY qwmA gyrkm wlA tDrwnh $y_A <n rbY ElYA kl $Y' HfyZ",
#  "wmA ElmnAh Al$Er wmA ynbgY lh <n hw <lA *kr wqr'An mbyn",
#  'wlmA brzwA ljAlwt wjnwdh qAlwA rbnA >frg ElynA SbrA wvbt >qdAmnA wAnSrnA ElY Alqwm AlkAfryn',
#  'k>nh jmAlt Sfr',
#  ">lm tr >n Allh yzjY sHAbA vm y&lf bynh vm yjElh rkAmA ftrY Alwdq yxrj mn xlAlh wynzl mn AlsmA' mn jbAl fyhA mn brd fySyb bh mn y$A' wySrfh En mn y$A' ykAd snA brqh y*hb bAl>bSAr",
#  "lA ytx* Alm&mnwn AlkAfryn >wlyA' mn dwn Alm&mnyn wmn yfEl *Alk flys mn Allh fY $Y' <lA >n ttqwA mnhm tqYAp wyH*rkm Allh nfsh w<lY Allh AlmSyr",
#  "*Alk mn >nbA' Algyb nwHyh <lyk wmA knt ldyhm <* ylqwn >qlAmhm >yhm ykfl mrym wmA knt ldyhm <* yxtSmwn",
#  "yA>yhA AlnAs <n kntm fY ryb mn AlbEv f<nA xlqnAkm mn trAb vm mn nTfp vm mn Elqp vm mn mDgp mxlqp wgyr mxlqp lnbyn lkm wnqr fY Al>rHAm mA n$A' <lYA >jl msmY vm nxrjkm TflA vm ltblgwA >$dkm wmnkm mn ytwfYA wmnkm mn yrd <lYA >r*l AlEmr lkylA yElm mn bEd Elm $y_A wtrY Al>rD hAmdp f<*A >nzlnA ElyhA AlmA' Ahtzt wrbt w>nbtt mn kl zwj bhyj",
#  "wklhm 'Atyh ywm AlqyAmp frdA",
#  '<nY >xAf Elykm E*Ab ywm EZym',
#  "w<*A qyl lhm AtbEwA mA >nzl Allh qAlwA bl ntbE mA >lfynA Elyh 'AbA'nA >wlw kAn 'AbA&hm lA yEqlwn $y_A wlA yhtdwn",
#  'AlrHmAn',
#  'lywfyhm >jwrhm wyzydhm mn fDlh <nh gfwr $kwr',
#  'Hkmp bAlgp fmA tgn Aln*r',
#  'wjnAt wEywn',
#  'vAnY ETfh lyDl En sbyl Allh lh fY AldnyA xzY wn*yqh ywm AlqyAmp E*Ab AlHryq',
#  'lylp Alqdr xyr mn >lf $hr',
#  "wsxr lkm mA fY AlsmAwAt wmA fY Al>rD jmyEA mnh <n fY *Alk l'AyAt lqwm ytfkrwn",
#  "Al*yn lA y&twn AlzkwAp whm bAl'Axrp hm kAfrwn",
#  "f_AtYAhm Allh vwAb AldnyA wHsn vwAb Al'Axrp wAllh yHb AlmHsnyn",
#  '>f>mnwA mkr Allh flA y>mn mkr Allh <lA Alqwm AlxAsrwn',
#  'ywm tbdl Al>rD gyr Al>rD wAlsmAwAt wbrzwA llh AlwAHd AlqhAr',
#  '<n Almjrmyn fY DlAl wsEr',
#  ">w tqwlwA <nmA >$rk 'AbA&nA mn qbl wknA *ryp mn bEdhm >fthlknA bmA fEl AlmbTlwn",
#  'lh mA fY AlsmAwAt wmA fY Al>rD whw AlElY AlEZym',
#  "kltA Aljntyn 'Att >klhA wlm tZlm mnh $y_A wfjrnA xlAlhmA nhrA",
#  'fmn >Zlm mmn AftrYA ElY Allh k*bA >w k*b b_AyAth <nh lA yflH Almjrmwn',
#  'wElyhA wElY Alflk tHmlwn',
#  "wlmA dxlwA mn Hyv >mrhm >bwhm mA kAn ygnY Enhm mn Allh mn $Y' <lA HAjp fY nfs yEqwb qDYAhA w<nh l*w Elm lmA ElmnAh wlAkn >kvr AlnAs lA yElmwn",
#  "wDrb Allh mvlA rjlyn >HdhmA >bkm lA yqdr ElYA $Y' whw kl ElYA mwlYAh >ynmA ywjhh lA y>t bxyr hl ystwY hw wmn y>mr bAlEdl whw ElYA SrAT mstqym",
#  "wqDynA <lYA bnY <srA'yl fY AlktAb ltfsdn fY Al>rD mrtyn wltEln ElwA kbyrA",
#  'w>mA <*A mA AbtlYAh fqdr Elyh rzqh fyqwl rbY >hAnn',
#  "mn wrA}hm jhnm wlA ygnY Enhm mA ksbwA $y_A wlA mA Atx*wA mn dwn Allh >wlyA' wlhm E*Ab EZym",
#  "mA ywd Al*yn kfrwA mn >hl AlktAb wlA Alm$rkyn >n ynzl Elykm mn xyr mn rbkm wAllh yxtS brHmth mn y$A' wAllh *w AlfDl AlEZym",
#  '*Alk EAlm Algyb wAl$hAdp AlEzyz AlrHym',
#  "fxlf mn bEdhm xlf wrvwA AlktAb y>x*wn ErD hA*A Al>dnYA wyqwlwn sygfr lnA w<n y>thm ErD mvlh y>x*wh >lm y&x* Elyhm myvAq AlktAb >n lA yqwlwA ElY Allh <lA AlHq wdrswA mA fyh wAldAr Al'Axrp xyr ll*yn ytqwn >flA tEqlwn",
#  '>fY qlwbhm mrD >m ArtAbwA >m yxAfwn >n yHyf Allh Elyhm wrswlh bl >wlA}k hm AlZAlmwn',
#  'w<*A AljbAl syrt',
#  'wlyAl E$r',
#  '<n bT$ rbk l$dyd',
#  ">wlm yrwA >n Allh ybsT Alrzq lmn y$A' wyqdr <n fY *Alk l'AyAt lqwm y&mnwn",
#  ">m yqwlwn AftrYAh ql <n Aftryth fElY <jrAmY w>nA brY' mmA tjrmwn",
#  'Elm Al<nsAn mA lm yElm',
#  'fqAl <n hA*A <lA sHr y&vr',
#  '<lA Al*yn SbrwA wEmlwA AlSAlHAt >wlA}k lhm mgfrp w>jr kbyr',
#  'wZllnA Elykm AlgmAm w>nzlnA Elykm Almn wAlslwYA klwA mn TybAt mA rzqnAkm wmA ZlmwnA wlAkn kAnwA >nfshm yZlmwn',
#  'ql >ndEwA mn dwn Allh mA lA ynfEnA wlA yDrnA wnrd ElYA >EqAbnA bEd <* hdYAnA Allh kAl*Y Asthwth Al$yATyn fY Al>rD HyrAn lh >SHAb ydEwnh <lY AlhdY A}tnA ql <n hdY Allh hw AlhdYA w>mrnA lnslm lrb AlEAlmyn',
#  'wlA ystTyEwn lhm nSrA wlA >nfshm ynSrwn',
#  'wlm nk nTEm Almskyn',
#  'wlA tmdn Eynyk <lYA mA mtEnA bh >zwAjA mnhm zhrp AlHywAp AldnyA lnftnhm fyh wrzq rbk xyr w>bqYA',
#  "wk*Alk >nzlnAh HkmA ErbyA wl}n AtbEt >hwA'hm bEdmA jA'k mn AlElm mA lk mn Allh mn wlY wlA wAq",
#  "lqd >nzlnA 'AyAt mbynAt wAllh yhdY mn y$A' <lYA SrAT mstqym",
#  'ywm}* tErDwn lA txfYA mnkm xAfyp',
#  'flmA *hbwA bh w>jmEwA >n yjElwh fY gyAbt Aljb w>wHynA <lyh ltnb}nhm b>mrhm hA*A whm lA y$Erwn',
#  "lqd smE Allh qwl Al*yn qAlwA <n Allh fqyr wnHn >gnyA' snktb mA qAlwA wqtlhm Al>nbyA' bgyr Hq wnqwl *wqwA E*Ab AlHryq",
#  'fTAf ElyhA TA}f mn rbk whm nA}mwn',
#  'wAl*Y >wHynA <lyk mn AlktAb hw AlHq mSdqA lmA byn ydyh <n Allh bEbAdh lxbyr bSyr',
#  '<n Al*yn kfrwA wmAtwA whm kfAr >wlA}k Elyhm lEnp Allh wAlmlA}kp wAlnAs >jmEyn',
#  'wtlk Aljnp AltY >wrvtmwhA bmA kntm tEmlwn',
#  '>wlA}k m>wYAhm jhnm wlA yjdwn EnhA mHySA',
#  'sbHAnh wtEAlYA EmA yqwlwn ElwA kbyrA',
#  'ql lA >qwl lkm EndY xzA}n Allh wlA >Elm Algyb wlA >qwl lkm <nY mlk <n >tbE <lA mA ywHYA <lY ql hl ystwY Al>EmYA wAlbSyr >flA ttfkrwn',
#  '<lYA frEwn wml<yh fAtbEwA >mr frEwn wmA >mr frEwn br$yd',
#  ">'nzl Elyh Al*kr mn bynnA bl hm fY $k mn *krY bl lmA y*wqwA E*Ab",
#  "<* qAl Allh yAEysY Abn mrym A*kr nEmtY Elyk wElYA wAldtk <* >ydtk brwH Alqds tklm AlnAs fY Almhd wkhlA w<* Elmtk AlktAb wAlHkmp wAltwrYAp wAl<njyl w<* txlq mn AlTyn khy_p AlTyr b<*nY ftnfx fyhA ftkwn TyrA b<*nY wtbr} Al>kmh wAl>brS b<*nY w<* txrj AlmwtYA b<*nY w<* kfft bnY <srA'yl Enk <* j}thm bAlbynAt fqAl Al*yn kfrwA mnhm <n hA*A <lA sHr mbyn",
#  "<n hA*A kAn lkm jzA' wkAn sEykm m$kwrA",
#  'AdEwA rbkm tDrEA wxfyp <nh lA yHb AlmEtdyn',
#  "wlmA jA' >mrnA njynA $EybA wAl*yn 'AmnwA mEh brHmp mnA w>x*t Al*yn ZlmwA AlSyHp f>SbHwA fY dyArhm jAvmyn",
#  "ql lEbAdY Al*yn 'AmnwA yqymwA AlSlwAp wynfqwA mmA rzqnAhm srA wElAnyp mn qbl >n y>tY ywm lA byE fyh wlA xlAl",
#  "ytwArYA mn Alqwm mn sw' mA b$r bh >ymskh ElYA hwn >m ydsh fY AltrAb >lA sA' mA yHkmwn",
#  "hl ynZrwn <lA t>wylh ywm y>tY t>wylh yqwl Al*yn nswh mn qbl qd jA't rsl rbnA bAlHq fhl lnA mn $fEA' fy$fEwA lnA >w nrd fnEml gyr Al*Y knA nEml qd xsrwA >nfshm wDl Enhm mA kAnwA yftrwn",
#  'ql lw kAn AlbHr mdAdA lklmAt rbY lnfd AlbHr qbl >n tnfd klmAt rbY wlw j}nA bmvlh mddA',
#  'qAl snnZr >Sdqt >m knt mn AlkA*byn',
#  'mswmp End rbk wmA hY mn AlZAlmyn bbEyd',
#  'wAlyl <*A EsEs',
#  "whw Al*Y >n$>km mn nfs wAHdp fmstqr wmstwdE qd fSlnA Al'AyAt lqwm yfqhwn",
#  'wtkwn AljbAl kAlEhn Almnfw$',
#  "flwlA kAnt qryp 'Amnt fnfEhA <ymAnhA <lA qwm ywns lmA 'AmnwA k$fnA Enhm E*Ab AlxzY fY AlHywAp AldnyA wmtEnAhm <lYA Hyn",
# ...
#  '<lA AlmSlyn',
#  'jnAt Edn ydxlwnhA yHlwn fyhA mn >sAwr mn *hb wl&l&A wlbAshm fyhA Hryr',
#  '<n Allh ymsk AlsmAwAt wAl>rD >n tzwlA wl}n zAltA <n >mskhmA mn >Hd mn bEdh <nh kAn HlymA gfwrA',
#  "ql <nY nhyt >n >Ebd Al*yn tdEwn mn dwn Allh lmA jA'nY AlbynAt mn rbY w>mrt >n >slm lrb AlEAlmyn",
#  '<lA <blys >bYA >n ykwn mE AlsAjdyn',
#  'w>mA Al*yn AbyDt wjwhhm ffY rHmp Allh hm fyhA xAldwn',
#  '<* tSEdwn wlA tlwn ElYA >Hd wAlrswl ydEwkm fY >xrYAkm f>vAbkm gmA bgm lkylA tHznwA ElYA mA fAtkm wlA mA >SAbkm wAllh xbyr bmA tEmlwn',
#  'ywm yqwm AlnAs lrb AlEAlmyn',
#  "wlqd trknAhA 'Ayp fhl mn mdkr",
#  'fAnTlqA HtYA <*A lqyA glAmA fqtlh qAl >qtlt nfsA zkyp bgyr nfs lqd j}t $y_A nkrA',
#  "wlqd jA'hm mn Al>nbA' mA fyh mzdjr",
#  'flA ystTyEwn twSyp wlA <lYA >hlhm yrjEwn',
#  'syhzm AljmE wywlwn Aldbr',
#  'wywm nH$rhm jmyEA vm nqwl ll*yn >$rkwA mkAnkm >ntm w$rkA&km fzylnA bynhm wqAl $rkA&hm mA kntm <yAnA tEbdwn',
#  'flwlA kAn mn Alqrwn mn qblkm >wlwA bqyp ynhwn En AlfsAd fY Al>rD <lA qlylA mmn >njynA mnhm wAtbE Al*yn ZlmwA mA >trfwA fyh wkAnwA mjrmyn',
#  'ql hw nb&A EZym',
#  "wAlsArq wAlsArqp fAqTEwA >ydyhmA jzA' bmA ksbA nkAlA mn Allh wAllh Ezyz Hkym",
#  'wnqlb >f_dthm w>bSArhm kmA lm y&mnwA bh >wl mrp wn*rhm fY TgyAnhm yEmhwn',
#  'fmA AsTAEwA >n yZhrwh wmA AstTAEwA lh nqbA',
#  '*Alk b>n Allh lm yk mgyrA nEmp >nEmhA ElYA qwm HtYA ygyrwA mA b>nfshm w>n Allh smyE Elym',
#  '<nmA kAn qwl Alm&mnyn <*A dEwA <lY Allh wrswlh lyHkm bynhm >n yqwlwA smEnA w>TEnA w>wlA}k hm AlmflHwn',
#  'wyl lkl hmzp lmzp',
#  'w>mA bnEmp rbk fHdv',
#  "lA jrm >nmA tdEwnnY <lyh lys lh dEwp fY AldnyA wlA fY Al'Axrp w>n mrdnA <lY Allh w>n Almsrfyn hm >SHAb AlnAr",
#  'wmA mnEhm >n tqbl mnhm nfqAthm <lA >nhm kfrwA bAllh wbrswlh wlA y>twn AlSlwAp <lA whm ksAlYA wlA ynfqwn <lA whm kArhwn',
#  "w<*A H$r AlnAs kAnwA lhm >EdA' wkAnwA bEbAdthm kAfryn",
#  "*Alk jzA' >EdA' Allh AlnAr lhm fyhA dAr Alxld jzA' bmA kAnwA b_AyAtnA yjHdwn",
#  'wlqd SbHhm bkrp E*Ab mstqr',
#  "w>mA mn 'Amn wEml SAlHA flh jzA' AlHsnYA wsnqwl lh mn >mrnA ysrA",
#  ">wlm yhd lhm km >hlknA mn qblhm mn Alqrwn ym$wn fY msAknhm <n fY *Alk l'AyAt >flA ysmEwn",
#  "Atx*wA >ymAnhm jnp fSdwA En sbyl Allh <nhm sA' mA kAnwA yEmlwn",
#  "trjY mn t$A' mnhn wt_wY <lyk mn t$A' wmn Abtgyt mmn Ezlt flA jnAH Elyk *Alk >dnYA >n tqr >Eynhn wlA yHzn wyrDyn bmA 'Atythn klhn wAllh yElm mA fY qlwbkm wkAn Allh ElymA HlymA",
#  '<* nAdYAh rbh bAlwAd Almqds TwY',
#  'yA>yhA AlnAs <nA xlqnAkm mn *kr w>nvYA wjElnAkm $EwbA wqbA}l ltEArfwA <n >krmkm End Allh >tqYAkm <n Allh Elym xbyr',
#  "qd xsr Al*yn qtlwA >wlAdhm sfhA bgyr Elm wHrmwA mA rzqhm Allh AftrA' ElY Allh qd DlwA wmA kAnwA mhtdyn",
#  'Al$hr AlHrAm bAl$hr AlHrAm wAlHrmAt qSAS fmn AEtdYA Elykm fAEtdwA Elyh bmvl mA AEtdYA Elykm wAtqwA Allh wAElmwA >n Allh mE Almtqyn',
#  "wAlm&mnwn wAlm&mnAt bEDhm >wlyA' bED y>mrwn bAlmErwf wynhwn En Almnkr wyqymwn AlSlwAp wy&twn AlzkwAp wyTyEwn Allh wrswlh >wlA}k syrHmhm Allh <n Allh Ezyz Hkym",
#  'A*hbA <lYA frEwn <nh TgYA',
#  'w<lAhkm <lAh wAHd lA <lAh <lA hw AlrHmAn AlrHym',
#  "AElmwA >nmA AlHywAp AldnyA lEb wlhw wzynp wtfAxr bynkm wtkAvr fY Al>mwAl wAl>wlAd kmvl gyv >Ejb AlkfAr nbAth vm yhyj ftrYAh mSfrA vm ykwn HTAmA wfY Al'Axrp E*Ab $dyd wmgfrp mn Allh wrDwAn wmA AlHywAp AldnyA <lA mtAE Algrwr",
#  ">fmn AtbE rDwAn Allh kmn bA' bsxT mn Allh wm>wYAh jhnm wb}s AlmSyr",
#  'w<nkm ltmrwn Elyhm mSbHyn',
#  'f>x*nAh wjnwdh fnb*nAhm fY Alym fAnZr kyf kAn EAqbp AlZAlmyn',
#  '$AkrA l>nEmh AjtbYAh whdYAh <lYA SrAT mstqym',
#  'wAstmE ywm ynAd AlmnAd mn mkAn qryb',
#  '>tx*nAhm sxryA >m zAgt Enhm Al>bSAr',
#  "wnzEnA mA fY Sdwrhm mn gl tjrY mn tHthm Al>nhAr wqAlwA AlHmd llh Al*Y hdYAnA lhA*A wmA knA lnhtdY lwlA >n hdYAnA Allh lqd jA't rsl rbnA bAlHq wnwdwA >n tlkm Aljnp >wrvtmwhA bmA kntm tEmlwn",
#  'fAjtbAh rbh fjElh mn AlSAlHyn',
#  "ql hw AlrHmAn 'AmnA bh wElyh twklnA fstElmwn mn hw fY DlAl mbyn",
#  'vm klA swf tElmwn',
#  "wnb}hm >n AlmA' qsmp bynhm kl $rb mHtDr",
#  'wAlbyt AlmEmwr',
#  'rfE smkhA fswYAhA',
#  'w<nY mrslp <lyhm bhdyp fnAZrp bm yrjE Almrslwn',
#  'fym >nt mn *krYAhA',
#  "wqAlwA >'*A knA EZAmA wrfAtA >'nA lmbEwvwn xlqA jdydA",
#  "hw Al*Y >nzl Elyk AlktAb mnh 'AyAt mHkmAt hn >m AlktAb w>xr mt$AbhAt f>mA Al*yn fY qlwbhm zyg fytbEwn mA t$Abh mnh AbtgA' Alftnp wAbtgA' t>wylh wmA yElm t>wylh <lA Allh wAlrAsxwn fY AlElm yqwlwn 'AmnA bh kl mn End rbnA wmA y*kr <lA >wlwA Al>lbAb",
#  'wlkm fyhA mnAfE wltblgwA ElyhA HAjp fY Sdwrkm wElyhA wElY Alflk tHmlwn',
#  'w<*A AlSHf n$rt',
#  'qAlwA <nA knA qbl fY >hlnA m$fqyn',
#  "fAnqlbwA bnEmp mn Allh wfDl lm ymsshm sw' wAtbEwA rDwAn Allh wAllh *w fDl EZym",
#  '>blgkm rsAlAt rbY w>nA lkm nASH >myn',
#  'qAl <nmA >wtyth ElYA Elm EndY >wlm yElm >n Allh qd >hlk mn qblh mn Alqrwn mn hw >$d mnh qwp w>kvr jmEA wlA ys_l En *nwbhm Almjrmwn',
#  "AlsmA' mnfTr bh kAn wEdh mfEwlA",
#  '<* qAl l>byh wqwmh mA tEbdwn',
#  'hl >tYA ElY Al<nsAn Hyn mn Aldhr lm ykn $y_A m*kwrA',
#  "wlw ftHnA Elyhm bAbA mn AlsmA' fZlwA fyh yErjwn",
#  'wmn yhd Allh fmA lh mn mDl >lys Allh bEzyz *Y AntqAm',
#  'qAl rb Agfr lY whb lY mlkA lA ynbgY l>Hd mn bEdY <nk >nt AlwhAb',
#  'flnqSn Elyhm bElm wmA knA gA}byn',
#  'mA >SAb mn mSybp fY Al>rD wlA fY >nfskm <lA fY ktAb mn qbl >n nbr>hA <n *Alk ElY Allh ysyr',
#  'l>E*bnh E*AbA $dydA >w l>A*bHnh >w ly>tynY bslTAn mbyn',
#  'qAl Al*yn AstkbrwA <nA kl fyhA <n Allh qd Hkm byn AlEbAd',
#  'xAfDp rAfEp',
#  "w'AmnwA bmA >nzlt mSdqA lmA mEkm wlA tkwnwA >wl kAfr bh wlA t$trwA b_AyAtY vmnA qlylA w<yAY fAtqwn",
#  'wlqd kntm tmnwn Almwt mn qbl >n tlqwh fqd r>ytmwh w>ntm tnZrwn',
#  'wlA tlbswA AlHq bAlbATl wtktmwA AlHq w>ntm tElmwn',
#  'wqAtlwhm HtYA lA tkwn ftnp wykwn Aldyn klh llh f<n AnthwA f<n Allh bmA yEmlwn bSyr',
#  "*Alk jzA&hm b>nhm kfrwA b_AyAtnA wqAlwA >'*A knA EZAmA wrfAtA >'nA lmbEwvwn xlqA jdydA",
#  "yA>yhA Al*yn 'AmnwA <*A qmtm <lY AlSlwAp fAgslwA wjwhkm w>ydykm <lY AlmrAfq wAmsHwA br'wskm w>rjlkm <lY AlkEbyn w<n kntm jnbA fAThrwA w<n kntm mrDYA >w ElYA sfr >w jA' >Hd mnkm mn AlgA}T >w lAmstm AlnsA' flm tjdwA mA' ftymmwA SEydA TybA fAmsHwA bwjwhkm w>ydykm mnh mA yryd Allh lyjEl Elykm mn Hrj wlAkn yryd lyThrkm wlytm nEmth Elykm lElkm t$krwn",
#  'ywm ydEwkm ftstjybwn bHmdh wtZnwn <n lbvtm <lA qlylA',
#  "f>mA mn >wtY ktAbh bymynh fyqwl hA&m Aqr'wA ktAbyh",
#  "wlqd zynA AlsmA' AldnyA bmSAbyH wjElnAhA rjwmA ll$yATyn w>EtdnA lhm E*Ab AlsEyr",
#  "wjElwA lh mn EbAdh jz'A <n Al<nsAn lkfwr mbyn",
#  'xlq AlsmAwAt wAl>rD bAlHq wSwrkm f>Hsn Swrkm w<lyh AlmSyr',
#  "wlw $A' Allh ljElkm >mp wAHdp wlAkn yDl mn y$A' wyhdY mn y$A' wlts_ln EmA kntm tEmlwn",
#  "yA>yhA Al*yn 'AmnwA <*A nAjytm Alrswl fqdmwA byn ydY njwYAkm Sdqp *Alk xyr lkm w>Thr f<n lm tjdwA f<n Allh gfwr rHym",
#  "f<n lm ystjybwA lk fAElm >nmA ytbEwn >hwA'hm wmn >Dl mmn AtbE hwYAh bgyr hdY mn Allh <n Allh lA yhdY Alqwm AlZAlmyn",
#  "<n Al*yn k*bwA b_AyAtnA wAstkbrwA EnhA lA tftH lhm >bwAb AlsmA' wlA ydxlwn Aljnp HtYA ylj Aljml fY sm AlxyAT wk*Alk njzY Almjrmyn",
#  'wqTEnAhm fY Al>rD >mmA mnhm AlSAlHwn wmnhm dwn *Alk wblwnAhm bAlHsnAt wAlsy_At lElhm yrjEwn',
#  'wtfqd AlTyr fqAl mA lY lA >rY Alhdhd >m kAn mn AlgA}byn',
#  "<n fY *Alk l'Ayp llm&mnyn",
#  'lA ySlYAhA <lA Al>$qY',
#  '>wklmA EAhdwA EhdA nb*h fryq mnhm bl >kvrhm lA y&mnwn',
#  'w<*A >*qnA AlnAs rHmp frHwA bhA w<n tSbhm sy}p bmA qdmt >ydyhm <*A hm yqnTwn',
#  "Al*yn yjAdlwn fY 'AyAt Allh bgyr slTAn >tYAhm kbr mqtA End Allh wEnd Al*yn 'AmnwA k*Alk yTbE Allh ElYA kl qlb mtkbr jbAr",
#  "yA>yhA Al*yn 'AmnwA kwnwA qwAmyn bAlqsT $hdA' llh wlw ElYA >nfskm >w AlwAldyn wAl>qrbyn <n ykn gnyA >w fqyrA fAllh >wlYA bhmA flA ttbEwA AlhwYA >n tEdlwA w<n tlwA >w tErDwA f<n Allh kAn bmA tEmlwn xbyrA",
#  'wmn Alyl fsbHh w<dbAr Alnjwm',
#  'lqd Hq Alqwl ElYA >kvrhm fhm lA y&mnwn',
#  "wqAlwA 'AmnA bh w>nYA lhm AltnAw$ mn mkAn bEyd",
#  "wk*Alk mknA lywsf fY Al>rD ytbw> mnhA Hyv y$A' nSyb brHmtnA mn n$A' wlA nDyE >jr AlmHsnyn",
#  ">r'yt Al*Y ynhYA",
#  'wywm yErD Al*yn kfrwA ElY AlnAr >lys hA*A bAlHq qAlwA blYA wrbnA qAl f*wqwA AlE*Ab bmA kntm tkfrwn',
#  "wAl*yn tbw'w AldAr wAl<ymAn mn qblhm yHbwn mn hAjr <lyhm wlA yjdwn fY Sdwrhm HAjp mmA >wtwA wy&vrwn ElYA >nfshm wlw kAn bhm xSASp wmn ywq $H nfsh f>wlA}k hm AlmflHwn",
#  'wlA yHD ElYA TEAm Almskyn',
#  "Al*Y lh mlk AlsmAwAt wAl>rD wAllh ElYA kl $Y' $hyd",
#  'Al*Y xlqk fswYAk fEdlk',
#  '<n E*Ab rbhm gyr m>mwn',
#  '<nA sxrnA AljbAl mEh ysbHn bAlE$Y wAl<$rAq',
#  'wyDyq SdrY wlA ynTlq lsAnY f>rsl <lYA hArwn',
#  "wllh ysjd mn fY AlsmAwAt wAl>rD TwEA wkrhA wZlAlhm bAlgdw wAl'ASAl",
#  'l>ml>n jhnm mnk wmmn tbEk mnhm >jmEyn',
#  "w'AtYAkm mn kl mA s>ltmwh w<n tEdwA nEmt Allh lA tHSwhA <n Al<nsAn lZlwm kfAr",
#  "wk*Alk zyn lkvyr mn Alm$rkyn qtl >wlAdhm $rkA&hm lyrdwhm wlylbswA Elyhm dynhm wlw $A' Allh mA fElwh f*rhm wmA yftrwn",
#  'wqwm nwH mn qbl <nhm kAnwA qwmA fAsqyn',
#  'k*b >SHAb l_ykp Almrslyn',
#  'ly$hdwA mnAfE lhm wy*krwA Asm Allh fY >yAm mElwmAt ElYA mA rzqhm mn bhymp Al>nEAm fklwA mnhA w>TEmwA AlbA}s Alfqyr',
#  'wlA tqtlwA >wlAdkm x$yp <mlAq nHn nrzqhm w<yAkm <n qtlhm kAn xT_A kbyrA',
#  "wl}n >*qnAh rHmp mnA mn bEd DrA' msth lyqwln hA*A lY wmA >Zn AlsAEp qA}mp wl}n rjEt <lYA rbY <n lY Endh llHsnYA flnnb}n Al*yn kfrwA bmA EmlwA wln*yqnhm mn E*Ab glyZ",
#  "qAl Al*yn AstkbrwA <nA bAl*Y 'Amntm bh kAfrwn",
#  'wnAdYA >SHAb Aljnp >SHAb AlnAr >n qd wjdnA mA wEdnA rbnA HqA fhl wjdtm mA wEd rbkm HqA qAlwA nEm f>*n m&*n bynhm >n lEnp Allh ElY AlZAlmyn',
#  "Al*Y jEl lkm Al>rD mhdA wslk lkm fyhA sblA w>nzl mn AlsmA' mA' f>xrjnA bh >zwAjA mn nbAt $tYA",
#  'qAl f<nhA mHrmp Elyhm >rbEyn snp ytyhwn fY Al>rD flA t>s ElY Alqwm AlfAsqyn',
#  'rbnA >xrjnA mnhA f<n EdnA f<nA ZAlmwn',
#  '>m xlqwA AlsmAwAt wAl>rD bl lA ywqnwn',
#  "wlqd Asthz} brsl mn qblk fHAq bAl*yn sxrwA mnhm mA kAnwA bh ysthz'wn",
#  'lA tdrkh Al>bSAr whw ydrk Al>bSAr whw AllTyf Alxbyr',
#  'wzrwE wmqAm krym',
#  "wdxl mEh Alsjn ftyAn qAl >HdhmA <nY >rYAnY >ESr xmrA wqAl Al'Axr <nY >rYAnY >Hml fwq r>sY xbzA t>kl AlTyr mnh nb}nA bt>wylh <nA nrYAk mn AlmHsnyn",
#  '<* qAlt Amr>t EmrAn rb <nY n*rt lk mA fY bTnY mHrrA ftqbl mnY <nk >nt AlsmyE AlElym',
#  "yA>yhA Al*yn 'AmnwA >wfwA bAlEqwd >Hlt lkm bhymp Al>nEAm <lA mA ytlYA Elykm gyr mHlY AlSyd w>ntm Hrm <n Allh yHkm mA yryd",
#  'qAl *Alk bynY wbynk >ymA Al>jlyn qDyt flA EdwAn ElY wAllh ElYA mA nqwl wkyl',
#  '<n hA*h >mtkm >mp wAHdp w>nA rbkm fAEbdwn',
#  "ql fllh AlHjp AlbAlgp flw $A' lhdYAkm >jmEyn",
#  'vm >mAth f>qbrh',
#  'wmA qdrwA Allh Hq qdrh wAl>rD jmyEA qbDth ywm AlqyAmp wAlsmAwAt mTwyAt bymynh sbHAnh wtEAlYA EmA y$rkwn',
#  'wqAl Almlk A}twnY bh >stxlSh lnfsY flmA klmh qAl <nk Alywm ldynA mkyn >myn',
#  'vm jElnAkm xlA}f fY Al>rD mn bEdhm lnnZr kyf tEmlwn',
#  "'>tx* mn dwnh 'Alhp <n yrdn AlrHmAn bDr lA tgn EnY $fAEthm $y_A wlA ynq*wn",
#  'wwDEnA Enk wzrk',
#  '>m Atx* mmA yxlq bnAt w>SfYAkm bAlbnyn',
#  "f<*A blgn >jlhn f>mskwhn bmErwf >w fArqwhn bmErwf w>$hdwA *wY Edl mnkm w>qymwA Al$hAdp llh *Alkm ywEZ bh mn kAn y&mn bAllh wAlywm Al'Axr wmn ytq Allh yjEl lh mxrjA",
#  'tnzl ElYA kl >fAk >vym',
#  '<n rbk hw yfSl bynhm ywm AlqyAmp fymA kAnwA fyh yxtlfwn',
#  '<nmA Hrm Elykm Almytp wAldm wlHm Alxnzyr wmA >hl lgyr Allh bh fmn ADTr gyr bAg wlA EAd f<n Allh gfwr rHym',
#  'wAxfD lhmA jnAH Al*l mn AlrHmp wql rb ArHmhmA kmA rbyAnY SgyrA',
#  "<nhm ln ygnwA Enk mn Allh $y_A w<n AlZAlmyn bEDhm >wlyA' bED wAllh wlY Almtqyn",
#  '<nA nHn nrv Al>rD wmn ElyhA w<lynA yrjEwn',
#  "yA>yhA Al*yn 'AmnwA <n tTyEwA fryqA mn Al*yn >wtwA AlktAb yrdwkm bEd <ymAnkm kAfryn",
#  '<n Al<nsAn lrbh lknwd',
#  'rslA mb$ryn wmn*ryn l}lA ykwn llnAs ElY Allh Hjp bEd Alrsl wkAn Allh EzyzA HkymA',
#  ">wlA}k Al*yn lys lhm fY Al'Axrp <lA AlnAr wHbT mA SnEwA fyhA wbATl mA kAnwA yEmlwn",
#  'wAl*yn kfrwA wk*bwA b_AyAtnA >wlA}k >SHAb AlnAr xAldyn fyhA wb}s AlmSyr',
#  ">m >mntm mn fY AlsmA' >n yrsl Elykm HASbA fstElmwn kyf n*yr",
#  "Al*yn 'AmnwA b_AyAtnA wkAnwA mslmyn",
#  "yA>yhA Al*yn 'AmnwA AstEynwA bAlSbr wAlSlwAp <n Allh mE AlSAbryn",
#  'wmn yksb <vmA f<nmA yksbh ElYA nfsh wkAn Allh ElymA HkymA',
#  'fsbH bHmd rbk wkn mn AlsAjdyn',
#  'w<nh lHsrp ElY AlkAfryn',
#  "lqd >DlnY En Al*kr bEd <* jA'nY wkAn Al$yTAn ll<nsAn x*wlA",
#  'wklA DrbnA lh Al>mvAl wklA tbrnA ttbyrA',
#  'whw Allh fY AlsmAwAt wfY Al>rD yElm srkm wjhrkm wyElm mA tksbwn',
#  "wmA >mwAlkm wlA >wlAdkm bAltY tqrbkm EndnA zlfYA <lA mn 'Amn wEml SAlHA f>wlA}k lhm jzA' AlDEf bmA EmlwA whm fY AlgrfAt 'Amnwn",
#  "w<*A r'A Al*yn >$rkwA $rkA'hm qAlwA rbnA hA&lA' $rkA&nA Al*yn knA ndEwA mn dwnk f>lqwA <lyhm Alqwl <nkm lkA*bwn",
#  "wmA kAn SlAthm End Albyt <lA mkA' wtSdyp f*wqwA AlE*Ab bmA kntm tkfrwn",
#  "<nmA Alm&mnwn Al*yn 'AmnwA bAllh wrswlh w<*A kAnwA mEh ElYA >mr jAmE lm y*hbwA HtYA yst_*nwh <n Al*yn yst_*nwnk >wlA}k Al*yn y&mnwn bAllh wrswlh f<*A Ast_*nwk lbED $>nhm f>*n lmn $}t mnhm wAstgfr lhm Allh <n Allh gfwr rHym",
#  "mA lhm bh mn Elm wlA l'AbA}hm kbrt klmp txrj mn >fwAhhm <n yqwlwn <lA k*bA",
#  "yxAdEwn Allh wAl*yn 'AmnwA wmA yxdEwn <lA >nfshm wmA y$Erwn",
#  'k*Alk yTbE Allh ElYA qlwb Al*yn lA yElmwn',
#  "<lA Al*yn ySlwn <lYA qwm bynkm wbynhm myvAq >w jA'wkm HSrt Sdwrhm >n yqAtlwkm >w yqAtlwA qwmhm wlw $A' Allh lslThm Elykm flqAtlwkm f<n AEtzlwkm flm yqAtlwkm w>lqwA <lykm Alslm fmA jEl Allh lkm Elyhm sbylA",
#  "ql syrwA fY Al>rD fAnZrwA kyf bd> Alxlq vm Allh yn$} Aln$>p Al'Axrp <n Allh ElYA kl $Y' qdyr",
#  'vm EfwnA Enkm mn bEd *Alk lElkm t$krwn',
#  "yA>yhA Al*yn 'AmnwA AdxlwA fY Alslm kAfp wlA ttbEwA xTwAt Al$yTAn <nh lkm Edw mbyn",
#  'fwAkh whm mkrmwn',
#  "lys b>mAnykm wlA >mAnY >hl AlktAb mn yEml sw'A yjz bh wlA yjd lh mn dwn Allh wlyA wlA nSyrA",
#  "wAl*yn 'AmnwA wEmlwA AlSAlHAt sndxlhm jnAt tjrY mn tHthA Al>nhAr xAldyn fyhA >bdA lhm fyhA >zwAj mThrp wndxlhm ZlA ZlylA",
#  'mtk_yn ElYA rfrf xDr wEbqrY HsAn',
#  'wyjElwn llh mA ykrhwn wtSf >lsnthm Alk*b >n lhm AlHsnYA lA jrm >n lhm AlnAr w>nhm mfrTwn',
#  "'>ntm >nzltmwh mn Almzn >m nHn Almnzlwn",
#  'ql <nY ln yjyrnY mn Allh >Hd wln >jd mn dwnh mltHdA',
#  "f>*Aqhm Allh AlxzY fY AlHywAp AldnyA wlE*Ab Al'Axrp >kbr lw kAnwA yElmwn",
#  'w<*A HDr Alqsmp >wlwA AlqrbYA wAlytAmYA wAlmsAkyn fArzqwhm mnh wqwlwA lhm qwlA mErwfA',
#  "Drb Allh mvlA EbdA mmlwkA lA yqdr ElYA $Y' wmn rzqnAh mnA rzqA HsnA fhw ynfq mnh srA wjhrA hl ystwn AlHmd llh bl >kvrhm lA yElmwn",
#  "ql >r'ytkm <n >tYAkm E*Ab Allh >w >ttkm AlsAEp >gyr Allh tdEwn <n kntm SAdqyn",
#  "w<*A Tlqtm AlnsA' fblgn >jlhn flA tEDlwhn >n ynkHn >zwAjhn <*A trADwA bynhm bAlmErwf *Alk ywEZ bh mn kAn mnkm y&mn bAllh wAlywm Al'Axr *Alkm >zkYA lkm w>Thr wAllh yElm w>ntm lA tElmwn",
#  'mn *A Al*Y yqrD Allh qrDA HsnA fyDAEfh lh >DEAfA kvyrp wAllh yqbD wybST w<lyh trjEwn',
#  "wAtbEt mlp 'AbA'Y <brAhym w<sHAq wyEqwb mA kAn lnA >n n$rk bAllh mn $Y' *Alk mn fDl Allh ElynA wElY AlnAs wlAkn >kvr AlnAs lA y$krwn",
#  '>wlA}k Al*yn lEnhm Allh f>Smhm w>EmYA >bSArhm',
#  '<nhA trmY b$rr kAlqSr',
#  'AdxlwhA bslAm *Alk ywm Alxlwd',
#  'wlA AlZlmAt wlA Alnwr',
#  'hl vwb AlkfAr mA kAnwA yfElwn',
#  "yqwl >'nk lmn AlmSdqyn",
#  "fAlywm Al*yn 'AmnwA mn AlkfAr yDHkwn",
#  'bynhmA brzx lA ybgyAn',
#  'fAxtlf Al>HzAb mn bynhm fwyl ll*yn ZlmwA mn E*Ab ywm >lym',
#  'k*bt qwm nwH Almrslyn',
#  'wnDE AlmwAzyn AlqsT lywm AlqyAmp flA tZlm nfs $y_A w<n kAn mvqAl Hbp mn xrdl >tynA bhA wkfYA bnA HAsbyn',
#  "yAEbAdY Al*yn 'AmnwA <n >rDY wAsEp f<yAY fAEbdwn",
#  "f<nk lA tsmE AlmwtYA wlA tsmE AlSm AldEA' <*A wlwA mdbryn",
#  "w<*A >*qnA AlnAs rHmp mn bEd DrA' msthm <*A lhm mkr fY 'AyAtnA ql Allh >srE mkrA <n rslnA yktbwn mA tmkrwn",
#  "<nA >nzlnAh qr'AnA ErbyA lElkm tEqlwn",
#  'rbnA Ak$f EnA AlE*Ab <nA m&mnwn',
#  'tdEwA mn >dbr wtwlYA',
#  "wmA tfrqwA <lA mn bEd mA jA'hm AlElm bgyA bynhm wlwlA klmp sbqt mn rbk <lYA >jl msmY lqDY bynhm w<n Al*yn >wrvwA AlktAb mn bEdhm lfY $k mnh mryb",
#  'wAl*yn jAhdwA fynA lnhdynhm sblnA w<n Allh lmE AlmHsnyn',
#  'ElYA srr mtqAblyn',
#  'Allh Al*Y sxr lkm AlbHr ltjrY Alflk fyh b>mrh wltbtgwA mn fDlh wlElkm t$krwn',
#  "wmn AlnAs mn ytx* mn dwn Allh >ndAdA yHbwnhm kHb Allh wAl*yn 'AmnwA >$d HbA llh wlw yrY Al*yn ZlmwA <* yrwn AlE*Ab >n Alqwp llh jmyEA w>n Allh $dyd AlE*Ab",
#  ">flm ydbrwA Alqwl >m jA'hm mA lm y>t 'AbA'hm Al>wlyn",
#  "Allh xAlq kl $Y' whw ElYA kl $Y' wkyl",
#  'AlHAqp',
#  'wmkrwA wmkr Allh wAllh xyr AlmAkryn',
#  '>lqyA fY jhnm kl kfAr Enyd',
#  'w<nk ltdEwhm <lYA SrAT mstqym',
#  "wmn AlnAs mn yqwl 'AmnA bAllh f<*A >w*Y fY Allh jEl ftnp AlnAs kE*Ab Allh wl}n jA' nSr mn rbk lyqwln <nA knA mEkm >wlys Allh b>Elm bmA fY Sdwr AlEAlmyn",
#  ...}

# %%
df_b = pd.read_excel("/media/kurubal/SSD/Data Scientist/Data Science/Data-Scientist/Work/Modern Ways/Arabic/ReDe/Tanzil_Simple_Buckwalter_And_Arabic.xlsx")
df_b
# Out:
#              buckwalter_simple             arabic_simple
# 0       bsm Allh AlrHmn AlrHym    بسم الله الرحمن الرحيم
# 1        AlHmd llh rb AlEAlmyn     الحمد لله رب العالمين
# 2                AlrHmn AlrHym             الرحمن الرحيم
# 3               mAlk ywm Aldyn            مالك يوم الدين
# 4       <yAk nEbd w<yAk nstEyn    إياك نعبد وإياك نستعين
# ...                        ...                       ...
# 6231                 mlk AlnAs                 ملك الناس
# 6232                 <lh AlnAs                 إله الناس
# 6233      mn $r AlwswAs AlxnAs      من شر الوسواس الخناس
# 6234  Al*y ywsws fy Sdwr AlnAs  الذي يوسوس في صدور الناس
# 6235         mn Aljnp wAlnAs\n         من الجنة والناس\n
#
# [6236 rows x 2 columns]

# %%
set_b = set(df_b.iloc[:,0])
set_b
# Out:
# {'AdxlwA >bwAb jhnm xAldyn fyhA fb}s mvwY Almtkbryn',
#  'wSdq bAlHsnY',
#  'bsm Allh AlrHmn AlrHym yA >yhA Al*yn |mnwA >wfwA bAlEqwd >Hlt lkm bhymp Al>nEAm <lA mA ytlY Elykm gyr mHly AlSyd w>ntm Hrm <n Allh yHkm mA yryd',
#  'qAl lA txAfA <nny mEkmA >smE w>rY',
#  'w<n kAnwA mn qbl >n ynzl Elyhm mn qblh lmblsyn',
#  "w<* qAlt AlmlA}kp yA mrym <n Allh ASTfAk wThrk wASTfAk ElY nsA' AlEAlmyn",
#  'fyh |yAt bynAt mqAm <brAhym wmn dxlh kAn |mnA wllh ElY AlnAs Hj Albyt mn AstTAE <lyh sbylA wmn kfr f<n Allh gny En AlEAlmyn',
#  'wydxlhm Aljnp ErfhA lhm',
#  'wl}n s>lthm mn xlqhm lyqwln Allh f>nY y&fkwn',
#  "bsm Allh AlrHmn AlrHym tbArk Al*y bydh Almlk whw ElY kl $y' qdyr",
#  'fqtl kyf qdr',
#  '<n Al*yn yjAdlwn fy |yAt Allh bgyr slTAn >tAhm <n fy Sdwrhm <lA kbr mA hm bbAlgyh fAstE* bAllh <nh hw AlsmyE AlbSyr',
#  'flA tTE Almk*byn',
#  'wAlqmr <*A Atsq',
#  'qAl yA <blys mA lk >lA tkwn mE AlsAjdyn',
#  "lyswA swA' mn >hl AlktAb >mp qA}mp ytlwn |yAt Allh |nA' Allyl whm ysjdwn",
#  'wlqd k*b Al*yn mn qblhm fkyf kAn nkyr',
#  "*lkm Allh rbkm lA <lh <lA hw xAlq kl $y' fAEbdwh whw ElY kl $y' wkyl",
#  "wlw y&Ax* Allh AlnAs bZlmhm mA trk ElyhA mn dAbp wlkn y&xrhm <lY >jl msmY f<*A jA' >jlhm lA yst>xrwn sAEp wlA ystqdmwn",
#  'wt*rwn mA xlq lkm rbkm mn >zwAjkm bl >ntm qwm EAdwn',
#  "<nA nHn nHyy AlmwtY wnktb mA qdmwA w|vArhm wkl $y' >HSynAh fy <mAm mbyn",
#  'ql h*h sbyly >dEw <lY Allh ElY bSyrp >nA wmn AtbEny wsbHAn Allh wmA >nA mn Alm$rkyn',
#  'ln ystnkf AlmsyH >n ykwn EbdA llh wlA AlmlA}kp Almqrbwn wmn ystnkf En EbAdth wystkbr fsyH$rhm <lyh jmyEA',
#  'qd >flH mn tzkY',
#  "<n >Hsntm >Hsntm l>nfskm w<n >s>tm flhA f<*A jA' wEd Al|xrp lysw'wA wjwhkm wlydxlwA Almsjd kmA dxlwh >wl mrp wlytbrwA mA ElwA ttbyrA",
#  'vm ArjE AlbSr krtyn ynqlb <lyk AlbSr xAs}A whw Hsyr',
#  '><*A knA EZAmA nxrp',
#  'ql EsY >n ykwn rdf lkm bED Al*y tstEjlwn',
#  '>wlA y*kr Al<nsAn >nA xlqnAh mn qbl wlm yk $y}A',
#  '>smE bhm w>bSr ywm y>twnnA lkn AlZAlmwn Alywm fy DlAl mbyn',
#  'flA >qsm bAlxns',
#  "wmA >nzlnA ElY qwmh mn bEdh mn jnd mn AlsmA' wmA knA mnzlyn",
#  '<n Allh hw AlrzAq *w Alqwp Almtyn',
#  'fmA yk*bk bEd bAldyn',
#  'wAlsAbqwn AlsAbqwn',
#  'wfAkhp kvyrp',
#  "<n Allh y>mr bAlEdl wAl<HsAn w<ytA' *y AlqrbY wynhY En AlfH$A' wAlmnkr wAlbgy yEZkm lElkm t*krwn",
#  '<n Allh mE Al*yn AtqwA wAl*yn hm mHsnwn',
#  "<n tbdwA xyrA >w txfwh >w tEfwA En sw' f<n Allh kAn EfwA qdyrA",
#  '>lm tr kyf fEl rbk bEAd',
#  "w>qsmwA bAllh jhd >ymAnhm l}n jA'thm |yp ly&mnn bhA ql <nmA Al|yAt End Allh wmA y$Erkm >nhA <*A jA't lA y&mnwn",
#  'wAl*yn hm ElY SlwAthm yHAfZwn',
#  '<n fy h*A lblAgA lqwm EAbdyn',
#  'wAl*yn lA ydEwn mE Allh <lhA |xr wlA yqtlwn Alnfs Alty Hrm Allh <lA bAlHq wlA yznwn wmn yfEl *lk ylq >vAmA',
#  'ql mn yrzqkm mn AlsmAwAt wAl>rD ql Allh w<nA >w <yAkm lElY hdY >w fy DlAl mbyn',
#  'wyrykm |yAth f>y |yAt Allh tnkrwn',
#  'Alty lm yxlq mvlhA fy AlblAd',
#  'wAl*yn yjtnbwn kbA}r Al<vm wAlfwAH$ w<*A mA gDbwA hm ygfrwn',
#  'wmA >rslnA mn qblk mn rswl <lA nwHy <lyh >nh lA <lh <lA >nA fAEbdwn',
#  'qr|nA ErbyA gyr *y Ewj lElhm ytqwn',
#  'ql AdEwA Al*yn zEmtm mn dwnh flA ymlkwn k$f AlDr Enkm wlA tHwylA',
#  'qAl <nmA >wtyth ElY Elm Endy >wlm yElm >n Allh qd >hlk mn qblh mn Alqrwn mn hw >$d mnh qwp w>kvr jmEA wlA ys>l En *nwbhm Almjrmwn',
#  "w<* qlnA llmlA}kp AsjdwA l|dm fsjdwA <lA <blys kAn mn Aljn ffsq En >mr rbh >fttx*wnh w*ryth >wlyA' mn dwny whm lkm Edw b}s llZAlmyn bdlA",
#  'wlA ySdnkm Al$yTAn <nh lkm Edw mbyn',
#  'Al$hr AlHrAm bAl$hr AlHrAm wAlHrmAt qSAS fmn AEtdY Elykm fAEtdwA Elyh bmvl mA AEtdY Elykm wAtqwA Allh wAElmwA >n Allh mE Almtqyn',
#  'hl ynZrwn <lA >n y>tyhm Allh fy Zll mn AlgmAm wAlmlA}kp wqDy Al>mr w<lY Allh trjE Al>mwr',
#  'hw Allh Al*y lA <lh <lA hw EAlm Algyb wAl$hAdp hw AlrHmn AlrHym',
#  'k*b >SHAb Al>ykp Almrslyn',
#  'wl>jr Al|xrp xyr ll*yn |mnwA wkAnwA ytqwn',
#  'wqAlwA mA hy <lA HyAtnA AldnyA nmwt wnHyA wmA yhlknA <lA Aldhr wmA lhm b*lk mn Elm <n hm <lA yZnwn',
#  'wmn yql mnhm <ny <lh mn dwnh f*lk njzyh jhnm k*lk njzy AlZAlmyn',
#  '>m t>mrhm >HlAmhm bh*A >m hm qwm TAgwn',
#  "Al*y lh mlk AlsmAwAt wAl>rD wAllh ElY kl $y' $hyd",
#  'vm >n$>nA mn bEdhm qrnA |xryn',
#  'w>rAdwA bh kydA fjElnAhm Al>xsryn',
#  'w<n tEdwA nEmp Allh lA tHSwhA <n Allh lgfwr rHym',
#  'bsm Allh AlrHmn AlrHym AlHmd llh Al*y lh mA fy AlsmAwAt wmA fy Al>rD wlh AlHmd fy Al|xrp whw AlHkym Alxbyr',
#  'wlqd >rslnA mwsY b|yAtnA <lY frEwn wml}h fqAl <ny rswl rb AlEAlmyn',
#  'qwAryr mn fDp qdrwhA tqdyrA',
#  'wlA ynfqwn nfqp Sgyrp wlA kbyrp wlA yqTEwn wAdyA <lA ktb lhm lyjzyhm Allh >Hsn mA kAnwA yEmlwn',
#  'wysqwn fyhA k>sA kAn mzAjhA znjbylA',
#  "kyf yhdy Allh qwmA kfrwA bEd <ymAnhm w$hdwA >n Alrswl Hq wjA'hm AlbynAt wAllh lA yhdy Alqwm AlZAlmyn",
#  'fAlywm lA ymlk bEDkm lbED nfEA wlA DrA wnqwl ll*yn ZlmwA *wqwA E*Ab AlnAr Alty kntm bhA tk*bwn',
#  '<n Allh ydxl Al*yn |mnwA wEmlwA AlSAlHAt jnAt tjry mn tHthA Al>nhAr <n Allh yfEl mA yryd',
#  'wtHsbhm >yqAZA whm rqwd wnqlbhm *At Alymyn w*At Al$mAl wklbhm bAsT *rAEyh bAlwSyd lw ATlEt Elyhm lwlyt mnhm frArA wlml}t mnhm rEbA',
#  '<lA Al*yn |mnwA wEmlwA AlSAlHAt flhm >jr gyr mmnwn',
#  'ywm ynfx fy AlSwr ft>twn >fwAjA',
#  "qAl Al*yn AstkbrwA ll*yn AstDEfwA >nHn SddnAkm En AlhdY bEd <* jA'km bl kntm mjrmyn",
#  'wk>sA dhAqA',
#  "ql lw kAn fy Al>rD mlA}kp ym$wn mTm}nyn lnzlnA Elyhm mn AlsmA' mlkA rswlA",
#  'qAl >r>ytk h*A Al*y krmt Ely l}n >xrtn <lY ywm AlqyAmp l>Htnkn *ryth <lA qlylA',
#  '<ny lkm rswl >myn',
#  'wl}n >TEtm b$rA mvlkm <nkm <*A lxAsrwn',
#  'bdyE AlsmAwAt wAl>rD w<*A qDY >mrA f<nmA yqwl lh kn fykwn',
#  '<lyh yrd Elm AlsAEp wmA txrj mn vmrAt mn >kmAmhA wmA tHml mn >nvY wlA tDE <lA bElmh wywm ynAdyhm >yn $rkA}y qAlwA |*nAk mA mnA mn $hyd',
#  'w<* frqnA bkm AlbHr f>njynAkm w>grqnA |l frEwn w>ntm tnZrwn',
#  'yEt*rwn <lykm <*A rjEtm <lyhm ql lA tEt*rwA ln n&mn lkm qd nb>nA Allh mn >xbArkm wsyrY Allh Emlkm wrswlh vm trdwn <lY EAlm Algyb wAl$hAdp fynb}km bmA kntm tEmlwn',
#  'qAlwA rbnA yElm <nA <lykm lmrslwn',
#  "qAl mA xTbkn <* rAwdtn ywsf En nfsh qln HA$ llh mA ElmnA Elyh mn sw' qAlt Amr>t AlEzyz Al|n HSHS AlHq >nA rAwdth En nfsh w<nh lmn AlSAdqyn",
#  "w>qbl bEDhm ElY bED ytsA'lwn",
#  "mn y$fE $fAEp Hsnp ykn lh nSyb mnhA wmn y$fE $fAEp sy}p ykn lh kfl mnhA wkAn Allh ElY kl $y' mqytA",
#  "HtY <*A jA'wA qAl >k*btm b|yAty wlm tHyTwA bhA ElmA >mA*A kntm tEmlwn",
#  'w*llnAhA lhm fmnhA rkwbhm wmnhA y>klwn',
#  '*lk b>n Allh hw AlHq w>n mA ydEwn mn dwnh AlbATl w>n Allh hw AlEly Alkbyr',
#  'f<*A qDytm AlSlAp fA*krwA Allh qyAmA wqEwdA wElY jnwbkm f<*A ATm>nntm f>qymwA AlSlAp <n AlSlAp kAnt ElY Alm&mnyn ktAbA mwqwtA',
#  '<lY rbk ywm}* Almstqr',
#  "wyqwl Al*yn kfrwA lwlA >nzl Elyh |yp mn rbh ql <n Allh yDl mn y$A' wyhdy <lyh mn >nAb",
#  'lA y&mnwn bh wqd xlt snp Al>wlyn',
#  'wmA knt bjAnb AlTwr <* nAdynA wlkn rHmp mn rbk ltn*r qwmA mA >tAhm mn n*yr mn qblk lElhm yt*krwn',
#  'fEAl lmA yryd',
#  'vm kAn mn Al*yn |mnwA wtwASwA bAlSbr wtwASwA bAlmrHmp',
#  'vm <ny >Elnt lhm w>srrt lhm <srArA',
#  'kAnwA qlylA mn Allyl mA yhjEwn',
#  'w<*A qyl lhm lA tfsdwA fy Al>rD qAlwA <nmA nHn mSlHwn',
#  '<lA Al*yn EAhdtm mn Alm$rkyn vm lm ynqSwkm $y}A wlm yZAhrwA Elykm >HdA f>tmwA <lyhm Ehdhm <lY mdthm <n Allh yHb Almtqyn',
#  'f<nhm l|klwn mnhA fmAl}wn mnhA AlbTwn',
#  'wmrym Abnt EmrAn Alty >HSnt frjhA fnfxnA fyh mn rwHnA wSdqt bklmAt rbhA wktbh wkAnt mn AlqAntyn',
#  'vm bEvnAkm mn bEd mwtkm lElkm t$krwn',
#  'Al*yn yfsdwn fy Al>rD wlA ySlHwn',
#  "ql <n rby ybsT Alrzq lmn y$A' wyqdr wlkn >kvr AlnAs lA yElmwn",
#  'tlk |yAt Allh ntlwhA Elyk bAlHq w<nk lmn Almrslyn',
#  '>f lkm wlmA tEbdwn mn dwn Allh >flA tEqlwn',
#  'b>ydy sfrp',
#  '>wl}k Al*yn A$trwA AlDlAlp bAlhdY fmA rbHt tjArthm wmA kAnwA mhtdyn',
#  'vm >grqnA Al|xryn',
#  'wlmA sqT fy >ydyhm wr>wA >nhm qd DlwA qAlwA l}n lm yrHmnA rbnA wygfr lnA lnkwnn mn AlxAsryn',
#  'qAl lA t&Ax*ny bmA nsyt wlA trhqny mn >mry EsrA',
#  'f>rslnA fyhm rswlA mnhm >n AEbdwA Allh mA lkm mn <lh gyrh >flA ttqwn',
#  'wlqd r|h nzlp >xrY',
#  'hnAlk tblw kl nfs mA >slft wrdwA <lY Allh mwlAhm AlHq wDl Enhm mA kAnwA yftrwn',
#  'vm lnnzEn mn kl $yEp >yhm >$d ElY AlrHmn EtyA',
#  "Allh ybsT Alrzq lmn y$A' mn EbAdh wyqdr lh <n Allh bkl $y' Elym",
#  'k*lk nfEl bAlmjrmyn',
#  'vm twlwA Enh wqAlwA mElm mjnwn',
#  'w<n mnhm lfryqA ylwwn >lsnthm bAlktAb ltHsbwh mn AlktAb wmA hw mn AlktAb wyqwlwn hw mn End Allh wmA hw mn End Allh wyqwlwn ElY Allh Alk*b whm yElmwn',
#  'fEqrwhA fqAl tmtEwA fy dArkm vlAvp >yAm *lk wEd gyr mk*wb',
#  'nHn >wlyA&km fy AlHyAp AldnyA wfy Al|xrp wlkm fyhA mA t$thy >nfskm wlkm fyhA mA tdEwn',
#  'w<lY rbk fArgb',
#  'mn qbl hdY llnAs w>nzl AlfrqAn <n Al*yn kfrwA b|yAt Allh lhm E*Ab $dyd wAllh Ezyz *w AntqAm',
#  'wxlq AljAn mn mArj mn nAr',
#  'qAlwA >n&mn lk wAtbEk Al>r*lwn',
#  'Al|n xff Allh Enkm wElm >n fykm DEfA f<n ykn mnkm mA}p SAbrp yglbwA mA}tyn w<n ykn mnkm >lf yglbwA >lfyn b<*n Allh wAllh mE AlSAbryn',
#  'wkm >hlknA qblhm mn qrn hl tHs mnhm mn >Hd >w tsmE lhm rkzA',
#  'wk>yn mn dAbp lA tHml rzqhA Allh yrzqhA w<yAkm whw AlsmyE AlElym',
#  "flmA blg mEh AlsEy qAl yA bny <ny >rY fy AlmnAm >ny >*bHk fAnZr mA*A trY qAl yA >bt AfEl mA t&mr stjdny <n $A' Allh mn AlSAbryn",
#  "wAlsmA' rfEhA wwDE AlmyzAn",
#  'hl ynZrwn <lA AlsAEp >n t>tyhm bgtp whm lA y$Erwn',
#  "wlqd SrfnA fy h*A Alqr|n llnAs mn kl mvl wkAn Al<nsAn >kvr $y' jdlA",
#  'wAl*yn k*bwA b|yAtnA ymshm AlE*Ab bmA kAnwA yfsqwn',
#  'f>njynAh wmn mEh fy Alflk Alm$Hwn',
#  'mswmp End rbk llmsrfyn',
#  'w>ywb <* nAdY rbh >ny msny AlDr w>nt >rHm AlrAHmyn',
#  "mHmd rswl Allh wAl*yn mEh >$dA' ElY AlkfAr rHmA' bynhm trAhm rkEA sjdA ybtgwn fDlA mn Allh wrDwAnA symAhm fy wjwhhm mn >vr Alsjwd *lk mvlhm fy AltwrAp wmvlhm fy Al<njyl kzrE >xrj $T>h f|zrh fAstglZ fAstwY ElY swqh yEjb AlzrAE lygyZ bhm AlkfAr wEd Allh Al*yn |mnwA wEmlwA AlSAlHAt mnhm mgfrp w>jrA EZymA",
#  '>mn h*A Al*y yrzqkm <n >msk rzqh bl ljwA fy Etw wnfwr',
#  'w>lf byn qlwbhm lw >nfqt mA fy Al>rD jmyEA mA >lft byn qlwbhm wlkn Allh >lf bynhm <nh Ezyz Hkym',
#  "vm >nzl Allh skynth ElY rswlh wElY Alm&mnyn w>nzl jnwdA lm trwhA wE*b Al*yn kfrwA w*lk jzA' AlkAfryn",
#  ">mn hw qAnt |nA' Allyl sAjdA wqA}mA yH*r Al|xrp wyrjw rHmp rbh ql hl ystwy Al*yn yElmwn wAl*yn lA yElmwn <nmA yt*kr >wlw Al>lbAb",
#  'wAllyl <* >dbr',
#  '<lY frEwn wml}h fAstkbrwA wkAnwA qwmA EAlyn',
#  'wystjyb Al*yn |mnwA wEmlwA AlSAlHAt wyzydhm mn fDlh wAlkAfrwn lhm E*Ab $dyd',
#  'flmA >lqwA qAl mwsY mA j}tm bh AlsHr <n Allh sybTlh <n Allh lA ySlH Eml Almfsdyn',
#  "qAlwA >wlm tk t>tykm rslkm bAlbynAt qAlwA blY qAlwA fAdEwA wmA dEA' AlkAfryn <lA fy DlAl",
#  'xAldyn fyhA lA ybgwn EnhA HwlA',
#  '>Endh Elm Algyb fhw yrY',
#  "w>n lw AstqAmwA ElY AlTryqp l>sqynAhm mA' gdqA",
#  'w<*A r|k Al*yn kfrwA <n ytx*wnk <lA hzwA >h*A Al*y y*kr |lhtkm whm b*kr AlrHmn hm kAfrwn',
#  "hm Al*yn kfrwA wSdwkm En Almsjd AlHrAm wAlhdy mEkwfA >n yblg mHlh wlwlA rjAl m&mnwn wnsA' m&mnAt lm tElmwhm >n tT}whm ftSybkm mnhm mErp bgyr Elm lydxl Allh fy rHmth mn y$A' lw tzylwA lE*bnA Al*yn kfrwA mnhm E*AbA >lymA",
#  'ql ll*yn kfrwA stglbwn wtH$rwn <lY jhnm wb}s AlmhAd',
#  '*lk bmA qdmt >ydykm w>n Allh lys bZlAm llEbyd',
#  'k*bt EAd fkyf kAn E*Aby wn*r',
#  "mA nnsx mn |yp >w nnshA n>t bxyr mnhA >w mvlhA >lm tElm >n Allh ElY kl $y' qdyr",
#  "hw Al*y >nzl mn AlsmA' mA' lkm mnh $rAb wmnh $jr fyh tsymwn",
#  'wAl*y >xrj AlmrEY',
#  "w>SbH Al*yn tmnwA mkAnh bAl>ms yqwlwn wyk>n Allh ybsT Alrzq lmn y$A' mn EbAdh wyqdr lwlA >n mn Allh ElynA lxsf bnA wyk>nh lA yflH AlkAfrwn",
#  'wlA >qsm bAlnfs AllwAmp',
#  'qAlwA bl lm tkwnwA m&mnyn',
#  'wqAl qrynh h*A mA ldy Etyd',
#  'wlA ElY Al*yn <*A mA >twk ltHmlhm qlt lA >jd mA >Hmlkm Elyh twlwA w>Eynhm tfyD mn AldmE HznA >lA yjdwA mA ynfqwn',
#  "HnfA' llh gyr m$rkyn bh wmn y$rk bAllh fk>nmA xr mn AlsmA' ftxTfh AlTyr >w thwy bh AlryH fy mkAn sHyq",
#  '<n y$> y*hbkm wy>t bxlq jdyd',
#  'w>qymwA Alwzn bAlqsT wlA txsrwA AlmyzAn',
#  'whw Al*y xlq AlsmAwAt wAl>rD bAlHq wywm yqwl kn fykwn qwlh AlHq wlh Almlk ywm ynfx fy AlSwr EAlm Algyb wAl$hAdp whw AlHkym Alxbyr',
#  'whdynAh Alnjdyn',
#  'wdxl Almdynp ElY Hyn gflp mn >hlhA fwjd fyhA rjlyn yqttlAn h*A mn $yEth wh*A mn Edwh fAstgAvh Al*y mn $yEth ElY Al*y mn Edwh fwkzh mwsY fqDY Elyh qAl h*A mn Eml Al$yTAn <nh Edw mDl mbyn',
#  'wk*b bh qwmk whw AlHq ql lst Elykm bwkyl',
#  'wlqd nElm >nhm yqwlwn <nmA yElmh b$r lsAn Al*y ylHdwn <lyh >Ejmy wh*A lsAn Erby mbyn',
#  '>m Atx*wA mn dwnh |lhp ql hAtwA brhAnkm h*A *kr mn mEy w*kr mn qbly bl >kvrhm lA yElmwn AlHq fhm mErDwn',
#  'hnAlk AlwlAyp llh AlHq hw xyr vwAbA wxyr EqbA',
#  'wmn >Zlm mmn *kr b|yAt rbh vm >ErD EnhA <nA mn Almjrmyn mntqmwn',
#  "vm >rslnA rslnA ttrY kl mA jA' >mp rswlhA k*bwh f>tbEnA bEDhm bEDA wjElnAhm >HAdyv fbEdA lqwm lA y&mnwn",
#  'wAlqr|n AlHkym',
#  'AtbEwA mn lA ys>lkm >jrA whm mhtdwn',
#  "wAl*yn k*bwA b|yAtnA wlqA' Al|xrp HbTt >EmAlhm hl yjzwn <lA mA kAnwA yEmlwn",
#  'wyA qwm <ny >xAf Elykm ywm AltnAd',
#  'ywm ysHbwn fy AlnAr ElY wjwhhm *wqwA ms sqr',
#  'wmA >drAk mA AlHTmp',
#  'wqAtlwA fy sbyl Allh Al*yn yqAtlwnkm wlA tEtdwA <n Allh lA yHb AlmEtdyn',
#  '<* r>Y nArA fqAl l>hlh AmkvwA <ny |nst nArA lEly |tykm mnhA bqbs >w >jd ElY AlnAr hdY',
#  'wmgAnm kvyrp y>x*wnhA wkAn Allh EzyzA HkymA',
#  "ywm tkwn AlsmA' kAlmhl",
#  'w<lY EAd >xAhm hwdA qAl yA qwm AEbdwA Allh mA lkm mn <lh gyrh <n >ntm <lA mftrwn',
#  'wAl*yn fy >mwAlhm Hq mElwm',
#  'mtk}yn fyhA ElY Al>rA}k lA yrwn fyhA $msA wlA zmhryrA',
#  "wAl*yn kfrwA >EmAlhm ksrAb bqyEp yHsbh AlZm|n mA' HtY <*A jA'h lm yjdh $y}A wwjd Allh Endh fwfAh HsAbh wAllh sryE AlHsAb",
#  'ys>lwnk En AlsAEp >yAn mrsAhA',
#  'fy qlwbhm mrD fzAdhm Allh mrDA wlhm E*Ab >lym bmA kAnwA yk*bwn',
#  'yA >yhA Al*yn |mnwA AtqwA Allh wqwlwA qwlA sdydA',
#  'f<n tAbwA w>qAmwA AlSlAp w|twA AlzkAp f<xwAnkm fy Aldyn wnfSl Al|yAt lqwm yElmwn',
#  'qAl rb <ny whn AlEZm mny wA$tEl Alr>s $ybA wlm >kn bdEA}k rb $qyA',
#  'wnryd >n nmn ElY Al*yn AstDEfwA fy Al>rD wnjElhm >}mp wnjElhm AlwArvyn',
#  'fkyf ttqwn <n kfrtm ywmA yjEl AlwldAn $ybA',
#  "wqAlwA ljlwdhm lm $hdtm ElynA qAlwA >nTqnA Allh Al*y >nTq kl $y' whw xlqkm >wl mrp w<lyh trjEwn",
#  '>wlm ysyrwA fy Al>rD fynZrwA kyf kAn EAqbp Al*yn kAnwA mn qblhm kAnwA hm >$d mnhm qwp w|vArA fy Al>rD f>x*hm Allh b*nwbhm wmA kAn lhm mn Allh mn wAq',
#  "wAllh >nzl mn AlsmA' mA' f>HyA bh Al>rD bEd mwthA <n fy *lk l|yp lqwm ysmEwn",
#  ">lA <nhm fy mryp mn lqA' rbhm >lA <nh bkl $y' mHyT",
#  'tsqY mn Eyn |nyp',
#  'w>kyd kydA',
#  'wqAl frEwn yA hAmAn Abn ly SrHA lEly >blg Al>sbAb',
#  'ttjAfY jnwbhm En AlmDAjE ydEwn rbhm xwfA wTmEA wmmA rzqnAhm ynfqwn',
#  'wmA mnEnA >n nrsl bAl|yAt <lA >n k*b bhA Al>wlwn w|tynA vmwd AlnAqp mbSrp fZlmwA bhA wmA nrsl bAl|yAt <lA txwyfA',
#  ">wlm yrwA <lY mA xlq Allh mn $y' ytfy> ZlAlh En Alymyn wAl$mA}l sjdA llh whm dAxrwn",
#  'w<lY mdyn >xAhm $EybA qAl yA qwm AEbdwA Allh mA lkm mn <lh gyrh wlA tnqSwA AlmkyAl wAlmyzAn <ny >rAkm bxyr w<ny >xAf Elykm E*Ab ywm mHyT',
#  'hdY w*krY l>wly Al>lbAb',
#  'nAr Allh Almwqdp',
#  'lyjzy Al*yn |mnwA wEmlwA AlSAlHAt mn fDlh <nh lA yHb AlkAfryn',
#  'wxsf Alqmr',
#  '>wl}k lhm rzq mElwm',
#  'ln tnfEkm >rHAmkm wlA >wlAdkm ywm AlqyAmp yfSl bynkm wAllh bmA tEmlwn bSyr',
#  'f>yn t*hbwn',
#  '<n AlmSdqyn wAlmSdqAt w>qrDwA Allh qrDA HsnA yDAEf lhm wlhm >jr krym',
#  'lqd >rslnA nwHA <lY qwmh fqAl yA qwm AEbdwA Allh mA lkm mn <lh gyrh <ny >xAf Elykm E*Ab ywm EZym',
#  '<* >ntm bAlEdwp AldnyA whm bAlEdwp AlqSwY wAlrkb >sfl mnkm wlw twAEdtm lAxtlftm fy AlmyEAd wlkn lyqDy Allh >mrA kAn mfEwlA lyhlk mn hlk En bynp wyHyY mn Hy En bynp w<n Allh lsmyE Elym',
#  'AdxlwA Aljnp >ntm w>zwAjkm tHbrwn',
#  "yA qwm lkm Almlk Alywm ZAhryn fy Al>rD fmn ynSrnA mn b>s Allh <n jA'nA qAl frEwn mA >rykm <lA mA >rY wmA >hdykm <lA sbyl Alr$Ad",
#  'fklwA mmA *kr Asm Allh Elyh <n kntm b|yAth m&mnyn',
#  'wyA qwm mA ly >dEwkm <lY AlnjAp wtdEwnny <lY AlnAr',
#  'wHsbwA >lA tkwn ftnp fEmwA wSmwA vm tAb Allh Elyhm vm EmwA wSmwA kvyr mnhm wAllh bSyr bmA yEmlwn',
#  'wtwkl ElY AlHy Al*y lA ymwt wsbH bHmdh wkfY bh b*nwb EbAdh xbyrA',
#  'fmn yEml mn AlSAlHAt whw m&mn flA kfrAn lsEyh w<nA lh kAtbwn',
#  'wwSY bhA <brAhym bnyh wyEqwb yA bny <n Allh ASTfY lkm Aldyn flA tmwtn <lA w>ntm mslmwn',
#  'wywm yErD Al*yn kfrwA ElY AlnAr >*hbtm TybAtkm fy HyAtkm AldnyA wAstmtEtm bhA fAlywm tjzwn E*Ab Alhwn bmA kntm tstkbrwn fy Al>rD bgyr AlHq wbmA kntm tfsqwn',
#  'y&mnwn bAllh wAlywm Al|xr wy>mrwn bAlmErwf wynhwn En Almnkr wysArEwn fy AlxyrAt w>wl}k mn AlSAlHyn',
#  'yA >bt <ny >xAf >n ymsk E*Ab mn AlrHmn ftkwn ll$yTAn wlyA',
#  'wAllh yElm mA tsrwn wmA tElnwn',
#  '<n Al<nsAn lfy xsr',
#  'fln*yqn Al*yn kfrwA E*AbA $dydA wlnjzynhm >sw> Al*y kAnwA yEmlwn',
#  'yqwl yA lytny qdmt lHyAty',
#  "wmn yTE Allh wAlrswl f>wl}k mE Al*yn >nEm Allh Elyhm mn Alnbyyn wAlSdyqyn wAl$hdA' wAlSAlHyn wHsn >wl}k rfyqA",
#  "Atl mA >wHy <lyk mn AlktAb w>qm AlSlAp <n AlSlAp tnhY En AlfH$A' wAlmnkr wl*kr Allh >kbr wAllh yElm mA tSnEwn",
#  'rbnA <nk mn tdxl AlnAr fqd >xzyth wmA llZAlmyn mn >nSAr',
#  'fmA >gnY Enhm mA kAnwA yksbwn',
#  '<nmA twEdwn lSAdq',
#  "qd nrY tqlb wjhk fy AlsmA' flnwlynk qblp trDAhA fwl wjhk $Tr Almsjd AlHrAm wHyv mA kntm fwlwA wjwhkm $Trh w<n Al*yn >wtwA AlktAb lyElmwn >nh AlHq mn rbhm wmA Allh bgAfl EmA yEmlwn",
#  "lyElm >n qd >blgwA rsAlAt rbhm w>HAT bmA ldyhm w>HSY kl $y' EddA",
#  'wyEbdwn mn dwn Allh mA lA ynfEhm wlA yDrhm wkAn AlkAfr ElY rbh ZhyrA',
#  'Al*yn |tynAhm AlktAb ytlwnh Hq tlAwth >wl}k y&mnwn bh wmn ykfr bh f>wl}k hm AlxAsrwn',
#  'w>nybwA <lY rbkm w>slmwA lh mn qbl >n y>tykm AlE*Ab vm lA tnSrwn',
#  ">fmn AtbE rDwAn Allh kmn bA' bsxT mn Allh wm>wAh jhnm wb}s AlmSyr",
#  'fESY frEwn Alrswl f>x*nAh >x*A wbylA',
#  'klA snktb mA yqwl wnmd lh mn AlE*Ab mdA',
#  'gAfr Al*nb wqAbl Altwb $dyd AlEqAb *y AlTwl lA <lh <lA hw <lyh AlmSyr',
#  'wyTEmwn AlTEAm ElY Hbh mskynA wytymA w>syrA',
#  'hlk Eny slTAnyh',
#  '>fr>ytm mA tHrvwn',
#  "qAl <n s>ltk En $y' bEdhA flA tSAHbny qd blgt mn ldny E*rA",
#  'f>rdnA >n ybdlhmA rbhmA xyrA mnh zkAp w>qrb rHmA',
#  'fqrbh <lyhm qAl >lA t>klwn',
#  ">wlm yrwA <lY AlTyr fwqhm SAfAt wyqbDn mA ymskhn <lA AlrHmn <nh bkl $y' bSyr",
#  'wtrY kvyrA mnhm ysArEwn fy Al<vm wAlEdwAn w>klhm AlsHt lb}s mA kAnwA yEmlwn',
#  'wlswf yETyk rbk ftrDY',
#  'w>mA <*A mA AbtlAh fqdr Elyh rzqh fyqwl rby >hAnn',
#  'ql |mnwA bh >w lA t&mnwA <n Al*yn >wtwA AlElm mn qblh <*A ytlY Elyhm yxrwn ll>*qAn sjdA',
#  'fqAl <n h*A <lA sHr y&vr',
#  'mn dwn Allh hl ynSrwnkm >w yntSrwn',
#  'qAlwA k*lk qAl rbk <nh hw AlHkym AlElym',
#  'w>rsl Elyhm TyrA >bAbyl',
#  'fsnysrh llEsrY',
#  "lA tjd qwmA y&mnwn bAllh wAlywm Al|xr ywAdwn mn HAd Allh wrswlh wlw kAnwA |bA'hm >w >bnA'hm >w <xwAnhm >w E$yrthm >wl}k ktb fy qlwbhm Al<ymAn w>ydhm brwH mnh wydxlhm jnAt tjry mn tHthA Al>nhAr xAldyn fyhA rDy Allh Enhm wrDwA Enh >wl}k Hzb Allh >lA <n Hzb Allh hm AlmflHwn",
#  "wmA >rslnA mn rswl <lA blsAn qwmh lybyn lhm fyDl Allh mn y$A' wyhdy mn y$A' whw AlEzyz AlHkym",
#  'lA yftr Enhm whm fyh mblswn',
#  'Elmt nfs mA qdmt w>xrt',
#  'lykfrwA bmA |tynAhm wlytmtEwA fswf yElmwn',
#  'rbnA lA tzg qlwbnA bEd <* hdytnA whb lnA mn ldnk rHmp <nk >nt AlwhAb',
#  '>fr>yt mn Atx* <lhh hwAh w>Dlh Allh ElY Elm wxtm ElY smEh wqlbh wjEl ElY bSrh g$Awp fmn yhdyh mn bEd Allh >flA t*krwn',
#  '>fr>yt Al*y kfr b|yAtnA wqAl l>wtyn mAlA wwldA',
#  '<n Al*yn kfrwA wSdwA En sbyl Allh vm mAtwA whm kfAr fln ygfr Allh lhm',
#  'fjElhm j*A*A <lA kbyrA lhm lElhm <lyh yrjEwn',
#  'yxrj mn byn AlSlb wAltrA}b',
#  "<n Al*yn kfrwA bAl*kr lmA jA'hm w<nh lktAb Ezyz",
#  'bsm Allh AlrHmn AlrHym swrp >nzlnAhA wfrDnAhA w>nzlnA fyhA |yAt bynAt lElkm t*krwn',
#  "flmA jA'hm AlHq mn EndnA qAlwA <n h*A lsHr mbyn",
#  'mlEwnyn >ynmA vqfwA >x*wA wqtlwA tqtylA',
#  'wk*lk nfSl Al|yAt wlElhm yrjEwn',
#  '<lY ywm Alwqt AlmElwm',
#  'wlhm Ely *nb f>xAf >n yqtlwn',
#  'l}n lm ynth AlmnAfqwn wAl*yn fy qlwbhm mrD wAlmrjfwn fy Almdynp lngrynk bhm vm lA yjAwrwnk fyhA <lA qlylA',
#  'wdxl jnth whw ZAlm lnfsh qAl mA >Zn >n tbyd h*h >bdA',
#  '<* qAl lhm >xwhm lwT >lA ttqwn',
#  'f<n twlwA f<nmA Elyk AlblAg Almbyn',
#  "wkm mn qryp >hlknAhA fjA'hA b>snA byAtA >w hm qA}lwn",
#  '<n Al*yn kfrwA ln tgny Enhm >mwAlhm wlA >wlAdhm mn Allh $y}A w>wl}k hm wqwd AlnAr',
#  "swA' mnkm mn >sr Alqwl wmn jhr bh wmn hw mstxf bAllyl wsArb bAlnhAr",
#  'wqd xAb mn dsAhA',
#  'wmkrwA mkrA kbArA',
#  'kmA >nzlnA ElY Almqtsmyn',
#  'wAl*yn k*bwA b|yAtnA wAstkbrwA EnhA >wl}k >SHAb AlnAr hm fyhA xAldwn',
#  'w<n jnHwA llslm fAjnH lhA wtwkl ElY Allh <nh hw AlsmyE AlElym',
#  'f<n twlytm fmA s>ltkm mn >jr <n >jry <lA ElY Allh w>mrt >n >kwn mn Almslmyn',
#  "qAlwA yA $Eyb >SlAtk t>mrk >n ntrk mA yEbd |bA&nA >w >n nfEl fy >mwAlnA mA n$A' <nk l>nt AlHlym Alr$yd",
#  'wlA Sdyq Hmym',
#  '*lk >dnY >n y>twA bAl$hAdp ElY wjhhA >w yxAfwA >n trd >ymAn bEd >ymAnhm wAtqwA Allh wAsmEwA wAllh lA yhdy Alqwm AlfAsqyn',
#  'fmn twlY bEd *lk f>wl}k hm AlfAsqwn',
#  'lA >Ebd mA tEbdwn',
#  "wmvl Al*yn kfrwA kmvl Al*y ynEq bmA lA ysmE <lA dEA' wndA' Sm bkm Emy fhm lA yEqlwn",
#  'wlw rHmnAhm wk$fnA mA bhm mn Dr lljwA fy TgyAnhm yEmhwn',
#  'wl}n >*qnA Al<nsAn mnA rHmp vm nzEnAhA mnh <nh ly}ws kfwr',
#  "wAl*yn ynfqwn >mwAlhm r}A' AlnAs wlA y&mnwn bAllh wlA bAlywm Al|xr wmn ykn Al$yTAn lh qrynA fsA' qrynA",
#  'flmA >tAhA nwdy yA mwsY',
#  'wAlsAbqwn Al>wlwn mn AlmhAjryn wAl>nSAr wAl*yn AtbEwhm b<HsAn rDy Allh Enhm wrDwA Enh w>Ed lhm jnAt tjry tHthA Al>nhAr xAldyn fyhA >bdA *lk Alfwz AlEZym',
#  'sbHAn rb AlsmAwAt wAl>rD rb AlEr$ EmA ySfwn',
#  'ql lA yElm mn fy AlsmAwAt wAl>rD Algyb <lA Allh wmA y$Erwn >yAn ybEvwn',
#  'f>tyA frEwn fqwlA <nA rswl rb AlEAlmyn',
#  'bsm Allh AlrHmn AlrHym yA >yhA Alnby Atq Allh wlA tTE AlkAfryn wAlmnAfqyn <n Allh kAn ElymA HkymA',
#  '<lA mn tAb w|mn wEml EmlA SAlHA f>wl}k ybdl Allh sy}Athm HsnAt wkAn Allh gfwrA rHymA',
#  '>>lqy Al*kr Elyh mn bynnA bl hw k*Ab >$r',
#  'qAtlwhm yE*bhm Allh b>ydykm wyxzhm wynSrkm Elyhm wy$f Sdwr qwm m&mnyn',
#  '<rm *At AlEmAd',
#  "wlA trknwA <lY Al*yn ZlmwA ftmskm AlnAr wmA lkm mn dwn Allh mn >wlyA' vm lA tnSrwn",
#  'wmA >rslnA qblk <lA rjAlA nwHy <lyhm fAs>lwA >hl Al*kr <n kntm lA tElmwn',
#  'klA lynb*n fy AlHTmp',
#  '*lk ntlwh Elyk mn Al|yAt wAl*kr AlHkym',
#  'wkAn lh vmr fqAl lSAHbh whw yHAwrh >nA >kvr mnk mAlA w>Ez nfrA',
#  "qAl stjdny <n $A' Allh SAbrA wlA >ESy lk >mrA",
#  'sbHAn Allh EmA ySfwn',
#  'fklwA mmA rzqkm Allh HlAlA TybA wA$krwA nEmt Allh <n kntm <yAh tEbdwn',
#  'ftrY Al*yn fy qlwbhm mrD ysArEwn fyhm yqwlwn nx$Y >n tSybnA dA}rp fEsY Allh >n y>ty bAlftH >w >mr mn Endh fySbHwA ElY mA >srwA fy >nfshm nAdmyn',
#  'ql hl nnb}km bAl>xsryn >EmAlA',
#  'yA >yhA Al*yn |mnwA <n tTyEwA fryqA mn Al*yn >wtwA AlktAb yrdwkm bEd <ymAnkm kAfryn',
#  'w<*A Alnjwm Ankdrt',
#  'tErf fy wjwhhm nDrp AlnEym',
#  '<nh yElm Aljhr mn Alqwl wyElm mA tktmwn',
#  "*lk fDl Allh y&tyh mn y$A' wAllh *w AlfDl AlEZym",
#  'qtl AlxrASwn',
#  'fmn AftrY ElY Allh Alk*b mn bEd *lk f>wl}k hm AlZAlmwn',
#  "w<n xftm >lA tqsTwA fy AlytAmY fAnkHwA mA TAb lkm mn AlnsA' mvnY wvlAv wrbAE f<n xftm >lA tEdlwA fwAHdp >w mA mlkt >ymAnkm *lk >dnY >lA tEwlwA",
#  "<* nAdY rbh ndA' xfyA",
#  'wx* bydk DgvA fADrb bh wlA tHnv <nA wjdnAh SAbrA nEm AlEbd <nh >wAb',
#  'qAl <nmA AlElm End Allh w>blgkm mA >rslt bh wlkny >rAkm qwmA tjhlwn',
#  'E*rA >w n*rA',
#  'w<*A qyl lhm AsjdwA llrHmn qAlwA wmA AlrHmn >nsjd lmA t>mrnA wzAdhm nfwrA',
#  'wAlxyl wAlbgAl wAlHmyr ltrkbwhA wzynp wyxlq mA lA tElmwn',
#  '>wlm yr Al<nsAn >nA xlqnAh mn nTfp f<*A hw xSym mbyn',
#  'w<n jhnm lmwEdhm >jmEyn',
#  'wmA ynbgy lhm wmA ystTyEwn',
#  '<lA mn rHm Allh <nh hw AlEzyz AlrHym',
#  "w<*A jA'thm |yp qAlwA ln n&mn HtY n&tY mvl mA >wty rsl Allh Allh >Elm Hyv yjEl rsAlth sySyb Al*yn >jrmwA SgAr End Allh wE*Ab $dyd bmA kAnwA ymkrwn",
#  'wqAl Allh lA ttx*wA <lhyn Avnyn <nmA hw <lh wAHd f<yAy fArhbwn',
#  'w<* qlnA lk <n rbk >HAT bAlnAs wmA jElnA Alr&yA Alty >rynAk <lA ftnp llnAs wAl$jrp AlmlEwnp fy Alqr|n wnxwfhm fmA yzydhm <lA TgyAnA kbyrA',
#  'mswmp End rbk wmA hy mn AlZAlmyn bbEyd',
#  'ql yA qwm AEmlwA ElY mkAntkm <ny EAml fswf tElmwn',
#  'bsm Allh AlrHmn AlrHym Alr ktAb >nzlnAh <lyk ltxrj AlnAs mn AlZlmAt <lY Alnwr b<*n rbhm <lY SrAT AlEzyz AlHmyd',
#  'w<* nAdY rbk mwsY >n A}t Alqwm AlZAlmyn',
#  '<n Allh Endh Elm AlsAEp wynzl Algyv wyElm mA fy Al>rHAm wmA tdry nfs mA*A tksb gdA wmA tdry nfs b>y >rD tmwt <n Allh Elym xbyr',
#  'f<n xftm frjAlA >w rkbAnA f<*A >mntm fA*krwA Allh kmA Elmkm mA lm tkwnwA tElmwn',
#  'wqAtlwA fy sbyl Allh wAElmwA >n Allh smyE Elym',
#  '<n tjtnbwA kbA}r mA tnhwn Enh nkfr Enkm sy}Atkm wndxlkm mdxlA krymA',
#  'qAl qA}l mnhm lA tqtlwA ywsf w>lqwh fy gyAbt Aljb yltqTh bED AlsyArp <n kntm fAElyn',
#  'wA*kr rbk fy nfsk tDrEA wxyfp wdwn Aljhr mn Alqwl bAlgdw wAl|SAl wlA tkn mn AlgAflyn',
#  ">n jA'h Al>EmY",
#  'wlqd trknA mnhA |yp bynp lqwm yEqlwn',
#  'Al*yn kfrwA lhm E*Ab $dyd wAl*yn |mnwA wEmlwA AlSAlHAt lhm mgfrp w>jr kbyr',
#  "flmA jA' slymAn qAl >tmdwnn bmAl fmA |tAny Allh xyr mmA |tAkm bl >ntm bhdytkm tfrHwn",
#  "ywm lA ynfE AlZAlmyn mE*rthm wlhm AllEnp wlhm sw' AldAr",
#  'w<*A mrwA bhm ytgAmzwn',
#  'wbynhmA HjAb wElY Al>ErAf rjAl yErfwn klA bsymAhm wnAdwA >SHAb Aljnp >n slAm Elykm lm ydxlwhA whm yTmEwn',
#  "wAl*yn |mnwA bAllh wrslh >wl}k hm AlSdyqwn wAl$hdA' End rbhm lhm >jrhm wnwrhm wAl*yn kfrwA wk*bwA b|yAtnA >wl}k >SHAb AljHym",
#  'ql <nmA >nA mn*r wmA mn <lh <lA Allh AlwAHd AlqhAr',
#  'wys>lwnk En AlrwH ql AlrwH mn >mr rby wmA >wtytm mn AlElm <lA qlylA',
#  'wlqd mnnA Elyk mrp >xrY',
#  'whw Al*y >HyAkm vm ymytkm vm yHyykm <n Al<nsAn lkfwr',
#  'hl >tAk Hdyv Dyf <brAhym Almkrmyn',
#  'wsyjnbhA Al>tqY',
#  'Al*y xlq fswY',
#  "wnAdY >SHAb AlnAr >SHAb Aljnp >n >fyDwA ElynA mn AlmA' >w mmA rzqkm Allh qAlwA <n Allh HrmhmA ElY AlkAfryn",
#  '>wlys Al*y xlq AlsmAwAt wAl>rD bqAdr ElY >n yxlq mvlhm blY whw AlxlAq AlElym',
#  'vm jElnAh nTfp fy qrAr mkyn',
#  'qAl EmA qlyl lySbHn nAdmyn',
#  'ywm t$qq Al>rD Enhm srAEA *lk H$r ElynA ysyr',
#  'f>rslnA Elyhm AlTwfAn wAljrAd wAlqml wAlDfAdE wAldm |yAt mfSlAt fAstkbrwA wkAnwA qwmA mjrmyn',
#  'Al*yn yk*bwn bywm Aldyn',
#  'rHmp mn rbk <nh hw AlsmyE AlElym',
#  'qAl yA qwm >r>ytm <n knt ElY bynp mn rby wrzqny mnh rzqA HsnA wmA >ryd >n >xAlfkm <lY mA >nhAkm Enh <n >ryd <lA Al<SlAH mA AstTEt wmA twfyqy <lA bAllh Elyh twklt w<lyh >nyb',
#  'wjElnA Abn mrym w>mh |yp w|wynAhmA <lY rbwp *At qrAr wmEyn',
#  'wqAlwA yA wylnA h*A ywm Aldyn',
#  'Al*yn k*bwA bAlktAb wbmA >rslnA bh rslnA fswf yElmwn',
#  "wmA ynZr h&lA' <lA SyHp wAHdp mA lhA mn fwAq",
#  'f<mA n*hbn bk f<nA mnhm mntqmwn',
#  'wmn vmrAt Alnxyl wAl>EnAb ttx*wn mnh skrA wrzqA HsnA <n fy *lk l|yp lqwm yEqlwn',
#  'wmA >rslnA qblk mn Almrslyn <lA <nhm ly>klwn AlTEAm wym$wn fy Al>swAq wjElnA bEDkm lbED ftnp >tSbrwn wkAn rbk bSyrA',
#  "f<n zlltm mn bEd mA jA'tkm AlbynAt fAElmwA >n Allh Ezyz Hkym",
#  '>>ntm >nzltmwh mn Almzn >m nHn Almnzlwn',
#  "<n rbk ybsT Alrzq lmn y$A' wyqdr <nh kAn bEbAdh xbyrA bSyrA",
#  'lkn AlrAsxwn fy AlElm mnhm wAlm&mnwn y&mnwn bmA >nzl <lyk wmA >nzl mn qblk wAlmqymyn AlSlAp wAlm&twn AlzkAp wAlm&mnwn bAllh wAlywm Al|xr >wl}k sn&tyhm >jrA EZymA',
#  'qAl hl >ntm mTlEwn',
#  'wqAl Almlk <ny >rY sbE bqrAt smAn y>klhn sbE EjAf wsbE snblAt xDr w>xr yAbsAt yA >yhA Alml> >ftwny fy r&yAy <n kntm llr&yA tEbrwn',
#  'flmA r>wA b>snA qAlwA |mnA bAllh wHdh wkfrnA bmA knA bh m$rkyn',
#  'wAl*y hw yTEmny wysqyn',
#  'ymHq Allh AlrbA wyrby AlSdqAt wAllh lA yHb kl kfAr >vym',
#  'ql mn Hrm zynp Allh Alty >xrj lEbAdh wAlTybAt mn Alrzq ql hy ll*yn |mnwA fy AlHyAp AldnyA xAlSp ywm AlqyAmp k*lk nfSl Al|yAt lqwm yElmwn',
#  "Allh nzl >Hsn AlHdyv ktAbA mt$AbhA mvAny tq$Er mnh jlwd Al*yn yx$wn rbhm vm tlyn jlwdhm wqlwbhm <lY *kr Allh *lk hdY Allh yhdy bh mn y$A' wmn yDll Allh fmA lh mn hAd",
#  "flmA nswA mA *krwA bh >njynA Al*yn ynhwn En Alsw' w>x*nA Al*yn ZlmwA bE*Ab b}ys bmA kAnwA yfsqwn",
#  "wqAl rjl m&mn mn |l frEwn yktm <ymAnh >tqtlwn rjlA >n yqwl rby Allh wqd jA'km bAlbynAt mn rbkm w<n yk kA*bA fElyh k*bh w<n yk SAdqA ySbkm bED Al*y yEdkm <n Allh lA yhdy mn hw msrf k*Ab",
#  "bsm Allh AlrHmn AlrHym <*A AlsmA' AnfTrt",
#  "flwlA >lqy Elyh >swrp mn *hb >w jA' mEh AlmlA}kp mqtrnyn",
#  'ql lmn Al>rD wmn fyhA <n kntm tElmwn',
#  "wkl $y' fElwh fy Alzbr",
#  'fqAlwA >b$rA mnA wAHdA ntbEh <nA <*A lfy DlAl wsEr',
#  'wqAl mwsY yA frEwn <ny rswl mn rb AlEAlmyn',
#  "wAl*yn ySlwn mA >mr Allh bh >n ywSl wyx$wn rbhm wyxAfwn sw' AlHsAb",
#  "fryqA hdY wfryqA Hq Elyhm AlDlAlp <nhm Atx*wA Al$yATyn >wlyA' mn dwn Allh wyHsbwn >nhm mhtdwn",
#  "yA >yhA Al*yn |mnwA lyst>*nkm Al*yn mlkt >ymAnkm wAl*yn lm yblgwA AlHlm mnkm vlAv mrAt mn qbl SlAp Alfjr wHyn tDEwn vyAbkm mn AlZhyrp wmn bEd SlAp AlE$A' vlAv EwrAt lkm lys Elykm wlA Elyhm jnAH bEdhn TwAfwn Elykm bEDkm ElY bED k*lk ybyn Allh lkm Al|yAt wAllh Elym Hkym",
#  '<nmA Alm&mnwn Al*yn |mnwA bAllh wrswlh vm lm yrtAbwA wjAhdwA b>mwAlhm w>nfshm fy sbyl Allh >wl}k hm AlSAdqwn',
#  "wynjy Allh Al*yn AtqwA bmfAzthm lA ymshm Alsw' wlA hm yHznwn",
#  'lqd r>Y mn |yAt rbh AlkbrY',
#  'w<* >x* rbk mn bny |dm mn Zhwrhm *rythm w>$hdhm ElY >nfshm >lst brbkm qAlwA blY $hdnA >n tqwlwA ywm AlqyAmp <nA knA En h*A gAflyn',
#  "ywSykm Allh fy >wlAdkm ll*kr mvl HZ Al>nvyyn f<n kn nsA' fwq Avntyn flhn vlvA mA trk w<n kAnt wAHdp flhA AlnSf wl>bwyh lkl wAHd mnhmA Alsds mmA trk <n kAn lh wld f<n lm ykn lh wld wwrvh >bwAh fl>mh Alvlv f<n kAn lh <xwp fl>mh Alsds mn bEd wSyp ywSy bhA >w dyn |bA&km w>bnA&km lA tdrwn >yhm >qrb lkm nfEA fryDp mn Allh <n Allh kAn ElymA HkymA",
#  "ql lA >mlk lnfsy DrA wlA nfEA <lA mA $A' Allh lkl >mp >jl <*A jA' >jlhm flA yst>xrwn sAEp wlA ystqdmwn",
#  'fqlnA ADrbwh bbEDhA k*lk yHyy Allh AlmwtY wyrykm |yAth lElkm tEqlwn',
#  'wA*krwA nEmp Allh Elykm wmyvAqh Al*y wAvqkm bh <* qltm smEnA w>TEnA wAtqwA Allh <n Allh Elym b*At AlSdwr',
#  '*krY wmA knA ZAlmyn',
#  'fy rq mn$wr',
#  'tnzE AlnAs k>nhm >EjAz nxl mnqEr',
#  'wAllyl <*A ysr',
#  "wjElnAhm >}mp yhdwn b>mrnA w>wHynA <lyhm fEl AlxyrAt w<qAm AlSlAp w<ytA' AlzkAp wkAnwA lnA EAbdyn",
#  'wlw >nhm |mnwA wAtqwA lmvwbp mn End Allh xyr lw kAnwA yElmwn',
#  'lqd xlqnA Al<nsAn fy >Hsn tqwym',
#  "yElm mA ylj fy Al>rD wmA yxrj mnhA wmA ynzl mn AlsmA' wmA yErj fyhA whw AlrHym Algfwr",
#  'wmn yTE Allh wrswlh wyx$ Allh wytqh f>wl}k hm AlfA}zwn',
#  'mn Aljnp wAlnAs\n',
#  'wqyl mn rAq',
#  'w>xrjt Al>rD >vqAlhA',
#  '>fmn ym$y mkbA ElY wjhh >hdY >mn ym$y swyA ElY SrAT mstqym',
#  '>wlm yrwA >nA jElnA HrmA |mnA wytxTf AlnAs mn Hwlhm >fbAlbATl y&mnwn wbnEmp Allh ykfrwn',
#  'tnzl ElY kl >fAk >vym',
#  'fqdrnA fnEm AlqAdrwn',
#  'flmA |tAhm mn fDlh bxlwA bh wtwlwA whm mErDwn',
#  'xlq Al<nsAn mn Ejl s>rykm |yAty flA tstEjlwn',
#  '>lm tr <lY Al*y HAj <brAhym fy rbh >n |tAh Allh Almlk <* qAl <brAhym rby Al*y yHyy wymyt qAl >nA >Hyy w>myt qAl <brAhym f<n Allh y>ty bAl$ms mn Alm$rq f>t bhA mn Almgrb fbht Al*y kfr wAllh lA yhdy Alqwm AlZAlmyn',
#  '<n Al*yn kfrwA wSdwA En sbyl Allh w$AqwA Alrswl mn bEd mA tbyn lhm AlhdY ln yDrwA Allh $y}A wsyHbT >EmAlhm',
#  'fDlA mn rbk *lk hw Alfwz AlEZym',
#  'ql >r>ytkm <n >tAkm E*Ab Allh bgtp >w jhrp hl yhlk <lA Alqwm AlZAlmwn',
#  'bsm Allh AlrHmn AlrHym AlrHmn',
#  'wkyf >xAf mA >$rktm wlA txAfwn >nkm >$rktm bAllh mA lm ynzl bh Elykm slTAnA f>y Alfryqyn >Hq bAl>mn <n kntm tElmwn',
#  'yElmwn mA tfElwn',
#  'Hqyq ElY >n lA >qwl ElY Allh <lA AlHq qd j}tkm bbynp mn rbkm f>rsl mEy bny <srA}yl',
#  "wl}n >*qnAh rHmp mnA mn bEd DrA' msth lyqwln h*A ly wmA >Zn AlsAEp qA}mp wl}n rjEt <lY rby <n ly Endh llHsnY flnnb}n Al*yn kfrwA bmA EmlwA wln*yqnhm mn E*Ab glyZ",
#  '<n Al*yn |mnwA wEmlwA AlSAlHAt lhm jnAt AlnEym',
#  'ygfr lkm *nwbkm wydxlkm jnAt tjry mn tHthA Al>nhAr wmsAkn Tybp fy jnAt Edn *lk Alfwz AlEZym',
#  'bl qAlwA mvl mA qAl Al>wlwn',
#  'qAlA rbnA <nnA nxAf >n yfrT ElynA >w >n yTgY',
#  'fyhA srr mrfwEp',
#  'fH$r fnAdY',
#  'f>*Aqhm Allh Alxzy fy AlHyAp AldnyA wlE*Ab Al|xrp >kbr lw kAnwA yElmwn',
#  "flmA jA't qyl >hk*A Er$k qAlt k>nh hw w>wtynA AlElm mn qblhA wknA mslmyn",
#  'ly$hdwA mnAfE lhm wy*krwA Asm Allh fy >yAm mElwmAt ElY mA rzqhm mn bhymp Al>nEAm fklwA mnhA w>TEmwA AlbA}s Alfqyr',
#  '<* AnbEv >$qAhA',
#  'wqAl ArkbwA fyhA bsm Allh mjrAhA wmrsAhA <n rby lgfwr rHym',
#  'hArwn >xy',
#  '<n Al*yn y$trwn bEhd Allh w>ymAnhm vmnA qlylA >wl}k lA xlAq lhm fy Al|xrp wlA yklmhm Allh wlA ynZr <lyhm ywm AlqyAmp wlA yzkyhm wlhm E*Ab >lym',
#  "ll*yn y&lwn mn nsA}hm trbS >rbEp >$hr f<n fA'wA f<n Allh gfwr rHym",
#  'lyn*r mn kAn HyA wyHq Alqwl ElY AlkAfryn',
#  "wAlsmA' wmA bnAhA",
#  'ql Allh >Elm bmA lbvwA lh gyb AlsmAwAt wAl>rD >bSr bh w>smE mA lhm mn dwnh mn wly wlA y$rk fy Hkmh >HdA',
#  'wl}n s>lthm mn xlq AlsmAwAt wAl>rD lyqwln Allh ql AlHmd llh bl >kvrhm lA yElmwn',
#  'yHlfwn bAllh lkm lyrDwkm wAllh wrswlh >Hq >n yrDwh <n kAnwA m&mnyn',
#  "wAqtlwhm Hyv vqftmwhm w>xrjwhm mn Hyv >xrjwkm wAlftnp >$d mn Alqtl wlA tqAtlwhm End Almsjd AlHrAm HtY yqAtlwkm fyh f<n qAtlwkm fAqtlwhm k*lk jzA' AlkAfryn",
#  "wtlk HjtnA |tynAhA <brAhym ElY qwmh nrfE drjAt mn n$A' <n rbk Hkym Elym",
#  ">lhm >rjl ym$wn bhA >m lhm >yd ybT$wn bhA >m lhm >Eyn ybSrwn bhA >m lhm |*An ysmEwn bhA ql AdEwA $rkA'km vm kydwn flA tnZrwn",
#  "f<*A An$qt AlsmA' fkAnt wrdp kAldhAn",
#  'flmA k$fnA Enhm Alrjz <lY >jl hm bAlgwh <*A hm ynkvwn',
#  'bsm Allh AlrHmn AlrHym wAlnjm <*A hwY',
#  'yA >yhA Al*yn |mnwA lA txwnwA Allh wAlrswl wtxwnwA >mAnAtkm w>ntm tElmwn',
#  'qAl bl rbkm rb AlsmAwAt wAl>rD Al*y fTrhn w>nA ElY *lkm mn Al$Ahdyn',
#  'wqAl Al*yn lA yElmwn lwlA yklmnA Allh >w t>tynA |yp k*lk qAl Al*yn mn qblhm mvl qwlhm t$Abht qlwbhm qd bynA Al|yAt lqwm ywqnwn',
#  'wtrY AlmlA}kp HAfyn mn Hwl AlEr$ ysbHwn bHmd rbhm wqDy bynhm bAlHq wqyl AlHmd llh rb AlEAlmyn',
#  'bl AlsAEp mwEdhm wAlsAEp >dhY w>mr',
#  "<lA mA $A' Allh <nh yElm Aljhr wmA yxfY",
#  "wmA >br} nfsy <n Alnfs l>mArp bAlsw' <lA mA rHm rby <n rby gfwr rHym",
#  "wmA mn dAbp fy Al>rD wlA TA}r yTyr bjnAHyh <lA >mm >mvAlkm mA frTnA fy AlktAb mn $y' vm <lY rbhm yH$rwn",
#  "wAl>nEAm xlqhA lkm fyhA df' wmnAfE wmnhA t>klwn",
#  'wlyElmn Allh Al*yn |mnwA wlyElmn AlmnAfqyn',
#  'wAllh >nbtkm mn Al>rD nbAtA',
#  '<n Al*yn ygDwn >SwAthm End rswl Allh >wl}k Al*yn AmtHn Allh qlwbhm lltqwY lhm mgfrp w>jr EZym',
#  "wlw yEjl Allh llnAs Al$r AstEjAlhm bAlxyr lqDy <lyhm >jlhm fn*r Al*yn lA yrjwn lqA'nA fy TgyAnhm yEmhwn",
#  "lys Albr >n twlwA wjwhkm qbl Alm$rq wAlmgrb wlkn Albr mn |mn bAllh wAlywm Al|xr wAlmlA}kp wAlktAb wAlnbyyn w|tY AlmAl ElY Hbh *wy AlqrbY wAlytAmY wAlmsAkyn wAbn Alsbyl wAlsA}lyn wfy AlrqAb w>qAm AlSlAp w|tY AlzkAp wAlmwfwn bEhdhm <*A EAhdwA wAlSAbryn fy Alb>sA' wAlDrA' wHyn Alb>s >wl}k Al*yn SdqwA w>wl}k hm Almtqwn",
#  'wr>yt AlnAs ydxlwn fy dyn Allh >fwAjA',
#  '<lA Al*yn tAbwA w>SlHwA wbynwA f>wl}k >twb Elyhm w>nA AltwAb AlrHym',
#  'yTAf Elyhm bk>s mn mEyn',
#  'wlA tqtlwA Alnfs Alty Hrm Allh <lA bAlHq wmn qtl mZlwmA fqd jElnA lwlyh slTAnA flA ysrf fy Alqtl <nh kAn mnSwrA',
#  '<nA >rslnA Elyhm ryHA SrSrA fy ywm nHs mstmr',
#  '>wlm ytfkrwA mA bSAHbhm mn jnp <n hw <lA n*yr mbyn',
#  'w<nh lHq Alyqyn',
#  "wADrb lhm mvl AlHyAp AldnyA kmA' >nzlnAh mn AlsmA' fAxtlT bh nbAt Al>rD f>SbH h$ymA t*rwh AlryAH wkAn Allh ElY kl $y' mqtdrA",
#  'wl}n qtltm fy sbyl Allh >w mtm lmgfrp mn Allh wrHmp xyr mmA yjmEwn',
#  'wlA tkwnwA kAlty nqDt gzlhA mn bEd qwp >nkAvA ttx*wn >ymAnkm dxlA bynkm >n tkwn >mp hy >rbY mn >mp <nmA yblwkm Allh bh wlybynn lkm ywm AlqyAmp mA kntm fyh txtlfwn',
#  'w<*A b$r >Hdhm bmA Drb llrHmn mvlA Zl wjhh mswdA whw kZym',
#  'lkylA t>swA ElY mA fAtkm wlA tfrHwA bmA |tAkm wAllh lA yHb kl mxtAl fxwr',
#  'fmA tnfEhm $fAEp Al$AfEyn',
#  'bsm Allh AlrHmn AlrHym Tsm',
#  'wmA *r> lkm fy Al>rD mxtlfA >lwAnh <n fy *lk l|yp lqwm y*krwn',
#  "w<*A >nEmnA ElY Al<nsAn >ErD wn>Y bjAnbh w<*A msh Al$r f*w dEA' EryD",
#  "lyHmlwA >wzArhm kAmlp ywm AlqyAmp wmn >wzAr Al*yn yDlwnhm bgyr Elm >lA sA' mA yzrwn",
#  'h*A ywm AlfSl jmEnAkm wAl>wlyn',
#  'wbdA lhm sy}At mA EmlwA wHAq bhm mA kAnwA bh ysthz}wn',
#  "kAn AlnAs >mp wAHdp fbEv Allh Alnbyyn mb$ryn wmn*ryn w>nzl mEhm AlktAb bAlHq lyHkm byn AlnAs fymA AxtlfwA fyh wmA Axtlf fyh <lA Al*yn >wtwh mn bEd mA jA'thm AlbynAt bgyA bynhm fhdY Allh Al*yn |mnwA lmA AxtlfwA fyh mn AlHq b<*nh wAllh yhdy mn y$A' <lY SrAT mstqym",
#  "Al*yn |mnwA yqAtlwn fy sbyl Allh wAl*yn kfrwA yqAtlwn fy sbyl AlTAgwt fqAtlwA >wlyA' Al$yTAn <n kyd Al$yTAn kAn DEyfA",
#  "fl*lk fAdE wAstqm kmA >mrt wlA ttbE >hwA'hm wql |mnt bmA >nzl Allh mn ktAb w>mrt l>Edl bynkm Allh rbnA wrbkm lnA >EmAlnA wlkm >EmAlkm lA Hjp bynnA wbynkm Allh yjmE bynnA w<lyh AlmSyr",
#  'w<*A Elm mn |yAtnA $y}A Atx*hA hzwA >wl}k lhm E*Ab mhyn',
#  'wAl*y qAl lwAldyh >f lkmA >tEdAnny >n >xrj wqd xlt Alqrwn mn qbly whmA ystgyvAn Allh wylk |mn <n wEd Allh Hq fyqwl mA h*A <lA >sATyr Al>wlyn',
#  'ql AnZrwA mA*A fy AlsmAwAt wAl>rD wmA tgny Al|yAt wAln*r En qwm lA y&mnwn',
#  'wjElnA *ryth hm AlbAqyn',
#  'qAl lh SAHbh whw yHAwrh >kfrt bAl*y xlqk mn trAb vm mn nTfp vm swAk rjlA',
#  'f>nt lh tSdY',
#  ">w tqwlwA lw >nA >nzl ElynA AlktAb lknA >hdY mnhm fqd jA'km bynp mn rbkm whdY wrHmp fmn >Zlm mmn k*b b|yAt Allh wSdf EnhA snjzy Al*yn ySdfwn En |yAtnA sw' AlE*Ab bmA kAnwA ySdfwn",
#  "mn wrA}hm jhnm wlA ygny Enhm mA ksbwA $y}A wlA mA Atx*wA mn dwn Allh >wlyA' wlhm E*Ab EZym",
#  'wmA tjzwn <lA mA kntm tEmlwn',
#  "wysbH AlrEd bHmdh wAlmlA}kp mn xyfth wyrsl AlSwAEq fySyb bhA mn y$A' whm yjAdlwn fy Allh whw $dyd AlmHAl",
#  'mn ySrf Enh ywm}* fqd rHmh w*lk Alfwz Almbyn',
#  '*lk lyElm >ny lm >xnh bAlgyb w>n Allh lA yhdy kyd AlxA}nyn',
#  'wmn xft mwAzynh f>wl}k Al*yn xsrwA >nfshm bmA kAnwA b|yAtnA yZlmwn',
#  'llsA}l wAlmHrwm',
#  "<nmA Alsbyl ElY Al*yn yst>*nwnk whm >gnyA' rDwA b>n ykwnwA mE AlxwAlf wTbE Allh ElY qlwbhm fhm lA yElmwn",
#  'w<*A ttlY Elyhm |yAtnA bynAt qAl Al*yn kfrwA ll*yn |mnwA >y Alfryqyn xyr mqAmA w>Hsn ndyA',
#  'wmnhm mn yqwl rbnA |tnA fy AldnyA Hsnp wfy Al|xrp Hsnp wqnA E*Ab AlnAr',
#  '>m lkm ktAb fyh tdrswn',
#  '<n kAnt <lA SyHp wAHdp f<*A hm jmyE ldynA mHDrwn',
#  'wqAlt TA}fp mn >hl AlktAb |mnwA bAl*y >nzl ElY Al*yn |mnwA wjh AlnhAr wAkfrwA |xrh lElhm yrjEwn',
#  'Al*yn |mnwA wlm ylbswA <ymAnhm bZlm >wl}k lhm Al>mn whm mhtdwn',
#  'lA ysmEwn fyhA lgwA wlA t>vymA',
#  'tkAd tmyz mn AlgyZ klmA >lqy fyhA fwj s>lhm xznthA >lm y>tkm n*yr',
#  "vm ywm AlqyAmp yxzyhm wyqwl >yn $rkA}y Al*yn kntm t$Aqwn fyhm qAl Al*yn >wtwA AlElm <n Alxzy Alywm wAlsw' ElY AlkAfryn",
#  'bsm Allh AlrHmn AlrHym >lm tr kyf fEl rbk b>SHAb Alfyl',
#  "wjA' rjl mn >qSY Almdynp ysEY qAl yA mwsY <n Alml> y>tmrwn bk lyqtlwk fAxrj <ny lk mn AlnASHyn",
#  '*lk b>nhm $AqwA Allh wrswlh wmn y$Aqq Allh wrswlh f<n Allh $dyd AlEqAb',
#  'qAl lhm mwsY >lqwA mA >ntm mlqwn',
#  'lw kAn ErDA qrybA wsfrA qASdA lAtbEwk wlkn bEdt Elyhm Al$qp wsyHlfwn bAllh lw AstTEnA lxrjnA mEkm yhlkwn >nfshm wAllh yElm <nhm lkA*bwn',
#  'mn dwn Allh fAhdwhm <lY SrAT AljHym',
#  'wqAlwA qlwbnA fy >knp mmA tdEwnA <lyh wfy |*AnnA wqr wmn bynnA wbynk HjAb fAEml <nnA EAmlwn',
#  'wmA ZlmnAhm wlkn kAnwA hm AlZAlmyn',
#  'wqAl lftyAnh AjElwA bDAEthm fy rHAlhm lElhm yErfwnhA <*A AnqlbwA <lY >hlhm lElhm yrjEwn',
#  'w>n h*A SrATy mstqymA fAtbEwh wlA ttbEwA Alsbl ftfrq bkm En sbylh *lkm wSAkm bh lElkm ttqwn',
#  "<* yg$ykm AlnEAs >mnp mnh wynzl Elykm mn AlsmA' mA' lyThrkm bh wy*hb Enkm rjz Al$yTAn wlyrbT ElY qlwbkm wyvbt bh Al>qdAm",
#  'fwrbk lns>lnhm >jmEyn',
#  '<n Al*yn lA y&mnwn bAl|xrp zynA lhm >EmAlhm fhm yEmhwn',
#  'qAlwA yA nwH qd jAdltnA f>kvrt jdAlnA f>tnA bmA tEdnA <n knt mn AlSAdqyn',
#  'mA >gnY Enhm mA kAnwA ymtEwn',
#  'wA*krwA Allh fy >yAm mEdwdAt fmn tEjl fy ywmyn flA <vm Elyh wmn t>xr flA <vm Elyh lmn AtqY wAtqwA Allh wAElmwA >nkm <lyh tH$rwn',
#  '>m |tynAhm ktAbA mn qblh fhm bh mstmskwn',
#  "w>mA mn |mn wEml SAlHA flh jzA' AlHsnY wsnqwl lh mn >mrnA ysrA",
#  'ywm nH$r Almtqyn <lY AlrHmn wfdA',
#  'lqd kAn fy ywsf w<xwth |yAt llsA}lyn',
#  'kyf tkfrwn bAllh wkntm >mwAtA f>HyAkm vm ymytkm vm yHyykm vm <lyh trjEwn',
#  'w<* qAlt TA}fp mnhm yA >hl yvrb lA mqAm lkm fArjEwA wyst>*n fryq mnhm Alnby yqwlwn <n bywtnA Ewrp wmA hy bEwrp <n yrydwn <lA frArA',
#  'ql yA >yhA AlnAs <nmA >nA lkm n*yr mbyn',
#  'wwAld wmA wld',
#  '>>ntm tzrEwnh >m nHn AlzArEwn',
#  'wyqwl Al*yn kfrwA lst mrslA ql kfY bAllh $hydA byny wbynkm wmn Endh Elm AlktAb',
#  'bsm Allh AlrHmn AlrHym <nA ftHnA lk ftHA mbynA',
#  'fqAl <ny >Hbbt Hb Alxyr En *kr rby HtY twArt bAlHjAb',
#  'f<*A nfx fy AlSwr nfxp wAHdp',
#  "qAl <nmA y>tykm bh Allh <n $A' wmA >ntm bmEjzyn",
#  'ywm nbT$ AlbT$p AlkbrY <nA mntqmwn',
#  'klA bl lA yxAfwn Al|xrp',
#  'fAlywm nnjyk bbdnk ltkwn lmn xlfk |yp w<n kvyrA mn AlnAs En |yAtnA lgAflwn',
#  "wk*lk jElnAkm >mp wsTA ltkwnwA $hdA' ElY AlnAs wykwn Alrswl Elykm $hydA wmA jElnA Alqblp Alty knt ElyhA <lA lnElm mn ytbE Alrswl mmn ynqlb ElY Eqbyh w<n kAnt lkbyrp <lA ElY Al*yn hdY Allh wmA kAn Allh lyDyE <ymAnkm <n Allh bAlnAs lr'wf rHym",
#  'vm <n ElynA HsAbhm',
#  'wsxr lkm Al$ms wAlqmr dA}byn wsxr lkm Allyl wAlnhAr',
#  'wmn >Hsn dynA mmn >slm wjhh llh whw mHsn wAtbE mlp <brAhym HnyfA wAtx* Allh <brAhym xlylA',
#  'wllh gyb AlsmAwAt wAl>rD w<lyh yrjE Al>mr klh fAEbdh wtwkl Elyh wmA rbk bgAfl EmA tEmlwn',
#  "hw Al*y ysyrkm fy Albr wAlbHr HtY <*A kntm fy Alflk wjryn bhm bryH Tybp wfrHwA bhA jA'thA ryH EASf wjA'hm Almwj mn kl mkAn wZnwA >nhm >HyT bhm dEwA Allh mxlSyn lh Aldyn l}n >njytnA mn h*h lnkwnn mn Al$Akryn",
#  'wlA t>klwA mmA lm y*kr Asm Allh Elyh w<nh lfsq w<n Al$yATyn lywHwn <lY >wlyA}hm lyjAdlwkm w<n >TEtmwhm <nkm lm$rkwn',
#  '<n Al*yn |mnwA wAl*yn hAjrwA wjAhdwA fy sbyl Allh >wl}k yrjwn rHmt Allh wAllh gfwr rHym',
#  "lqd tAb Allh ElY Alnby wAlmhAjryn wAl>nSAr Al*yn AtbEwh fy sAEp AlEsrp mn bEd mA kAd yzyg qlwb fryq mnhm vm tAb Elyhm <nh bhm r'wf rHym",
#  'yrydwn >n yxrjwA mn AlnAr wmA hm bxArjyn mnhA wlhm E*Ab mqym',
#  'w>qsmwA bAllh jhd >ymAnhm l}n >mrthm lyxrjn ql lA tqsmwA TAEp mErwfp <n Allh xbyr bmA tEmlwn',
#  'mA ElY Alrswl <lA AlblAg wAllh yElm mA tbdwn wmA tktmwn',
#  'yA >yhA Al*yn |mnwA AtqwA Allh Hq tqAth wlA tmwtn <lA w>ntm mslmwn',
#  'wlqd *r>nA ljhnm kvyrA mn Aljn wAl<ns lhm qlwb lA yfqhwn bhA wlhm >Eyn lA ybSrwn bhA wlhm |*An lA ysmEwn bhA >wl}k kAl>nEAm bl hm >Dl >wl}k hm AlgAflwn',
#  'w>dxl Al*yn |mnwA wEmlwA AlSAlHAt jnAt tjry mn tHthA Al>nhAr xAldyn fyhA b<*n rbhm tHythm fyhA slAm',
#  'w<n kAnwA lyqwlwn',
#  'yA qwmnA >jybwA dAEy Allh w|mnwA bh ygfr lkm mn *nwbkm wyjrkm mn E*Ab >lym',
#  'w<* AstsqY mwsY lqwmh fqlnA ADrb bESAk AlHjr fAnfjrt mnh AvntA E$rp EynA qd Elm kl >nAs m$rbhm klwA wA$rbwA mn rzq Allh wlA tEvwA fy Al>rD mfsdyn',
#  "xAldyn fyhA mA dAmt AlsmAwAt wAl>rD <lA mA $A' rbk <n rbk fEAl lmA yryd",
#  'ql yA qwm AEmlwA ElY mkAntkm <ny EAml fswf tElmwn mn tkwn lh EAqbp AldAr <nh lA yflH AlZAlmwn',
#  'wAlrjz fAhjr',
#  'f<n AljHym hy Alm>wY',
#  'wydr> EnhA AlE*Ab >n t$hd >rbE $hAdAt bAllh <nh lmn AlkA*byn',
#  "<n n$> nnzl Elyhm mn AlsmA' |yp fZlt >EnAqhm lhA xADEyn",
#  'qAlwA >w*ynA mn qbl >n t>tynA wmn bEd mA j}tnA qAl EsY rbkm >n yhlk Edwkm wystxlfkm fy Al>rD fynZr kyf tEmlwn',
#  'wltElmn nb>h bEd Hyn',
#  'EynA y$rb bhA EbAd Allh yfjrwnhA tfjyrA',
#  'wlqd DrbnA llnAs fy h*A Alqr|n mn kl mvl lElhm yt*krwn',
#  ">lA llh Aldyn AlxAlS wAl*yn Atx*wA mn dwnh >wlyA' mA nEbdhm <lA lyqrbwnA <lY Allh zlfY <n Allh yHkm bynhm fy mA hm fyh yxtlfwn <n Allh lA yhdy mn hw kA*b kfAr",
#  'wql rb >Ew* bk mn hmzAt Al$yATyn',
#  '<nA >rslnAk bAlHq b$yrA wn*yrA wlA ts>l En >SHAb AljHym',
#  'wlA tkwnwA kAl*yn qAlwA smEnA whm lA ysmEwn',
#  'f>n$>nA lkm bh jnAt mn nxyl w>EnAb lkm fyhA fwAkh kvyrp wmnhA t>klwn',
#  'whw Al*y jEl lkm Alnjwm lthtdwA bhA fy ZlmAt Albr wAlbHr qd fSlnA Al|yAt lqwm yElmwn',
#  'w<n tk*bwA fqd k*b >mm mn qblkm wmA ElY Alrswl <lA AlblAg Almbyn',
#  'w>nh hw >gnY w>qnY',
#  'kntm xyr >mp >xrjt llnAs t>mrwn bAlmErwf wtnhwn En Almnkr wt&mnwn bAllh wlw |mn >hl AlktAb lkAn xyrA lhm mnhm Alm&mnwn w>kvrhm AlfAsqwn',
#  "<n h&lA' yHbwn AlEAjlp wy*rwn wrA'hm ywmA vqylA",
#  "wlw kAnwA y&mnwn bAllh wAlnby wmA >nzl <lyh mA Atx*whm >wlyA' wlkn kvyrA mnhm fAsqwn",
#  'ql mA knt bdEA mn Alrsl wmA >dry mA yfEl by wlA bkm <n >tbE <lA mA ywHY <ly wmA >nA <lA n*yr mbyn',
#  "zyn ll*yn kfrwA AlHyAp AldnyA wysxrwn mn Al*yn |mnwA wAl*yn AtqwA fwqhm ywm AlqyAmp wAllh yrzq mn y$A' bgyr HsAb",
#  'wyA qwm AEmlwA ElY mkAntkm <ny EAml swf tElmwn mn y>tyh E*Ab yxzyh wmn hw kA*b wArtqbwA <ny mEkm rqyb',
#  'wmmn xlqnA >mp yhdwn bAlHq wbh yEdlwn',
#  'bl hm Alywm mstslmwn',
#  'wlA tmdn Eynyk <lY mA mtEnA bh >zwAjA mnhm zhrp AlHyAp AldnyA lnftnhm fyh wrzq rbk xyr w>bqY',
#  'w<*A b$r >Hdhm bAl>nvY Zl wjhh mswdA whw kZym',
#  'w<n Amr>p xAft mn bElhA n$wzA >w <ErADA flA jnAH ElyhmA >n ySlHA bynhmA SlHA wAlSlH xyr w>HDrt Al>nfs Al$H w<n tHsnwA wttqwA f<n Allh kAn bmA tEmlwn xbyrA',
#  'qAlwA mA >xlfnA mwEdk bmlknA wlknA HmlnA >wzArA mn zynp Alqwm fq*fnAhA fk*lk >lqY AlsAmry',
#  'wlqd ysrnA Alqr|n ll*kr fhl mn mdkr',
#  'mA AlHAqp',
#  "qAlt yA wyltY >>ld w>nA Ejwz wh*A bEly $yxA <n h*A l$y' Ejyb",
#  "*lkm Allh rbkm xAlq kl $y' lA <lh <lA hw f>nY t&fkwn",
#  'wyqwlwn TAEp f<*A brzwA mn Endk byt TA}fp mnhm gyr Al*y tqwl wAllh yktb mA ybytwn f>ErD Enhm wtwkl ElY Allh wkfY bAllh wkylA',
#  'qAl yA hArwn mA mnEk <* r>ythm DlwA',
#  'wjElwA llh >ndAdA lyDlwA En sbylh ql tmtEwA f<n mSyrkm <lY AlnAr',
#  "qAl >wlw j}tkm b>hdY mmA wjdtm Elyh |bA'km qAlwA <nA bmA >rsltm bh kAfrwn",
#  'fmA |mn lmwsY <lA *ryp mn qwmh ElY xwf mn frEwn wml}hm >n yftnhm w<n frEwn lEAl fy Al>rD w<nh lmn Almsrfyn',
#  'w>mA mn xAf mqAm rbh wnhY Alnfs En AlhwY',
#  "trY AlZAlmyn m$fqyn mmA ksbwA whw wAqE bhm wAl*yn |mnwA wEmlwA AlSAlHAt fy rwDAt AljnAt lhm mA y$A'wn End rbhm *lk hw AlfDl Alkbyr",
#  "fsxrnA lh AlryH tjry b>mrh rxA' Hyv >SAb",
#  's>Srf En |yAty Al*yn ytkbrwn fy Al>rD bgyr AlHq w<n yrwA kl |yp lA y&mnwA bhA w<n yrwA sbyl Alr$d lA ytx*wh sbylA w<n yrwA sbyl Algy ytx*wh sbylA *lk b>nhm k*bwA b|yAtnA wkAnwA EnhA gAflyn',
#  'f|mnwA bAllh wrswlh wAlnwr Al*y >nzlnA wAllh bmA tEmlwn xbyr',
#  'rb AlsmAwAt wAl>rD wmA bynhmA wrb Alm$Arq',
#  "flmA |tAhmA SAlHA jElA lh $rkA' fymA |tAhmA ftEAlY Allh EmA y$rkwn",
#  'wfAkhp w>bA',
#  'AlnAr *At Alwqwd',
#  'whw Al*y >n$>km mn nfs wAHdp fmstqr wmstwdE qd fSlnA Al|yAt lqwm yfqhwn',
#  'wmA mnEhm >n tqbl mnhm nfqAthm <lA >nhm kfrwA bAllh wbrswlh wlA y>twn AlSlAp <lA whm ksAlY wlA ynfqwn <lA whm kArhwn',
#  'wlmA brzwA ljAlwt wjnwdh qAlwA rbnA >frg ElynA SbrA wvbt >qdAmnA wAnSrnA ElY Alqwm AlkAfryn',
#  '<lhkm <lh wAHd fAl*yn lA y&mnwn bAl|xrp qlwbhm mnkrp whm mstkbrwn',
#  '>f>mn Al*yn mkrwA Alsy}At >n yxsf Allh bhm Al>rD >w y>tyhm AlE*Ab mn Hyv lA y$Erwn',
#  'k>nh jmAlt Sfr',
#  'wjzAhm bmA SbrwA jnp wHryrA',
#  'lywfyhm >jwrhm wyzydhm mn fDlh <nh gfwr $kwr',
#  'Hkmp bAlgp fmA tgn Aln*r',
#  'wjnAt wEywn',
#  '<n Al*yn kfrwA b|yAtnA swf nSlyhm nArA klmA nDjt jlwdhm bdlnAhm jlwdA gyrhA ly*wqwA AlE*Ab <n Allh kAn EzyzA HkymA',
#  'lylp Alqdr xyr mn >lf $hr',
#  '<* qAl mwsY l>hlh <ny |nst nArA s|tykm mnhA bxbr >w |tykm b$hAb qbs lElkm tSTlwn',
#  'qAlwA Hrqwh wAnSrwA |lhtkm <n kntm fAElyn',
#  "wlA t&mnwA <lA lmn tbE dynkm ql <n AlhdY hdY Allh >n y&tY >Hd mvl mA >wtytm >w yHAjwkm End rbkm ql <n AlfDl byd Allh y&tyh mn y$A' wAllh wAsE Elym",
#  'fy smwm wHmym',
#  '>f>mnwA mkr Allh flA y>mn mkr Allh <lA Alqwm AlxAsrwn',
#  'ywm tbdl Al>rD gyr Al>rD wAlsmAwAt wbrzwA llh AlwAHd AlqhAr',
#  "ql mA >s>lkm Elyh mn >jr <lA mn $A' >n ytx* <lY rbh sbylA",
#  'qAl frEwn |mntm bh qbl >n |*n lkm <n h*A lmkr mkrtmwh fy Almdynp ltxrjwA mnhA >hlhA fswf tElmwn',
#  'w<n >Hd mn Alm$rkyn AstjArk f>jrh HtY ysmE klAm Allh vm >blgh m>mnh *lk b>nhm qwm lA yElmwn',
#  'wElyhA wElY Alflk tHmlwn',
#  'wk*lk >EvrnA Elyhm lyElmwA >n wEd Allh Hq w>n AlsAEp lA ryb fyhA <* ytnAzEwn bynhm >mrhm fqAlwA AbnwA Elyhm bnyAnA rbhm >Elm bhm qAl Al*yn glbwA ElY >mrhm lntx*n Elyhm msjdA',
#  '<n tkfrwA f<n Allh gny Enkm wlA yrDY lEbAdh Alkfr w<n t$krwA yrDh lkm wlA tzr wAzrp wzr >xrY vm <lY rbkm mrjEkm fynb}km bmA kntm tEmlwn <nh Elym b*At AlSdwr',
#  "mA ywd Al*yn kfrwA mn >hl AlktAb wlA Alm$rkyn >n ynzl Elykm mn xyr mn rbkm wAllh yxtS brHmth mn y$A' wAllh *w AlfDl AlEZym",
#  '>lm y>thm nb> Al*yn mn qblhm qwm nwH wEAd wvmwd wqwm <brAhym w>SHAb mdyn wAlm&tfkAt >tthm rslhm bAlbynAt fmA kAn Allh lyZlmhm wlkn kAnwA >nfshm yZlmwn',
#  'w<*A AljbAl syrt',
#  "yA >yhA Al*yn |mnwA <*A tdAyntm bdyn <lY >jl msmY fAktbwh wlyktb bynkm kAtb bAlEdl wlA y>b kAtb >n yktb kmA Elmh Allh flyktb wlymll Al*y Elyh AlHq wlytq Allh rbh wlA ybxs mnh $y}A f<n kAn Al*y Elyh AlHq sfyhA >w DEyfA >w lA ystTyE >n yml hw flymll wlyh bAlEdl wAst$hdwA $hydyn mn rjAlkm f<n lm ykwnA rjlyn frjl wAmr>tAn mmn trDwn mn Al$hdA' >n tDl <HdAhmA ft*kr <HdAhmA Al>xrY wlA y>b Al$hdA' <*A mA dEwA wlA ts>mwA >n tktbwh SgyrA >w kbyrA <lY >jlh *lkm >qsT End Allh w>qwm ll$hAdp w>dnY >lA trtAbwA <lA >n tkwn tjArp HADrp tdyrwnhA bynkm flys Elykm jnAH >lA tktbwhA w>$hdwA <*A tbAyEtm wlA yDAr kAtb wlA $hyd w<n tfElwA f<nh fswq bkm wAtqwA Allh wyElmkm Allh wAllh bkl $y' Elym",
#  'wlyAl E$r',
#  "vm AstwY <lY AlsmA' why dxAn fqAl lhA wll>rD A}tyA TwEA >w krhA qAltA >tynA TA}Eyn",
#  ">flm ydbrwA Alqwl >m jA'hm mA lm y>t |bA'hm Al>wlyn",
#  '<n bT$ rbk l$dyd',
#  "qAl AdxlwA fy >mm qd xlt mn qblkm mn Aljn wAl<ns fy AlnAr klmA dxlt >mp lEnt >xthA HtY <*A AdArkwA fyhA jmyEA qAlt >xrAhm l>wlAhm rbnA h&lA' >DlwnA f|thm E*AbA DEfA mn AlnAr qAl lkl DEf wlkn lA tElmwn",
#  '<n ywHY <ly <lA >nmA >nA n*yr mbyn',
#  'Elm Al<nsAn mA lm yElm',
#  'w|tAkm mn kl mA s>ltmwh w<n tEdwA nEmt Allh lA tHSwhA <n Al<nsAn lZlwm kfAr',
#  "flm tqtlwhm wlkn Allh qtlhm wmA rmyt <* rmyt wlkn Allh rmY wlybly Alm&mnyn mnh blA' HsnA <n Allh smyE Elym",
#  '>lys *lk bqAdr ElY >n yHyy AlmwtY',
# ...
#  'x* AlEfw w>mr bAlErf w>ErD En AljAhlyn',
#  'bsm Allh AlrHmn AlrHym lA >qsm bywm AlqyAmp',
#  'wAl$ms tjry lmstqr lhA *lk tqdyr AlEzyz AlElym',
#  'ql ln ySybnA <lA mA ktb Allh lnA hw mwlAnA wElY Allh flytwkl Alm&mnwn',
#  '>flm yhd lhm km >hlknA qblhm mn Alqrwn ym$wn fy msAknhm <n fy *lk l|yAt l>wly AlnhY',
#  'w<*A >nzlt swrp >n |mnwA bAllh wjAhdwA mE rswlh Ast>*nk >wlw AlTwl mnhm wqAlwA *rnA nkn mE AlqAEdyn',
#  "wmn |yAth >nk trY Al>rD xA$Ep f<*A >nzlnA ElyhA AlmA' Ahtzt wrbt <n Al*y >HyAhA lmHyy AlmwtY <nh ElY kl $y' qdyr",
#  '<lA AlmSlyn',
#  'jnAt Edn ydxlwnhA yHlwn fyhA mn >sAwr mn *hb wl&l&A wlbAshm fyhA Hryr',
#  '<ny |mnt brbkm fAsmEwn',
#  '<n Allh ymsk AlsmAwAt wAl>rD >n tzwlA wl}n zAltA <n >mskhmA mn >Hd mn bEdh <nh kAn HlymA gfwrA',
#  'wlqd >rslnA nwHA <lY qwmh flbv fyhm >lf snp <lA xmsyn EAmA f>x*hm AlTwfAn whm ZAlmwn',
#  'fwyl ll*yn kfrwA mn ywmhm Al*y ywEdwn',
#  'wAtqwA ywmA lA tjzy nfs En nfs $y}A wlA yqbl mnhA Edl wlA tnfEhA $fAEp wlA hm ynSrwn',
#  'ywm yqwm AlnAs lrb AlEAlmyn',
#  'yA >bt lA tEbd Al$yTAn <n Al$yTAn kAn llrHmn ESyA',
#  "wlqd jA'hm mn Al>nbA' mA fyh mzdjr",
#  'syhzm AljmE wywlwn Aldbr',
#  'qwl mErwf wmgfrp xyr mn Sdqp ytbEhA >*Y wAllh gny Hlym',
#  '>wl}k Elyhm SlwAt mn rbhm wrHmp w>wl}k hm Almhtdwn',
#  'wAllh jEl lkm mn bywtkm sknA wjEl lkm mn jlwd Al>nEAm bywtA tstxfwnhA ywm ZEnkm wywm <qAmtkm wmn >SwAfhA w>wbArhA w>$EArhA >vAvA wmtAEA <lY Hyn',
#  'w>lqy AlsHrp sAjdyn',
#  'wywm nH$rhm jmyEA vm nqwl ll*yn >$rkwA mkAnkm >ntm w$rkA&km fzylnA bynhm wqAl $rkA&hm mA kntm <yAnA tEbdwn',
#  'mtk}yn ElY srr mSfwfp wzwjnAhm bHwr Eyn',
#  'ql kfY bAllh $hydA byny wbynkm <nh kAn bEbAdh xbyrA bSyrA',
#  'yA >yhA Al*yn |mnwA mA lkm <*A qyl lkm AnfrwA fy sbyl Allh AvAqltm <lY Al>rD >rDytm bAlHyAp AldnyA mn Al|xrp fmA mtAE AlHyAp AldnyA fy Al|xrp <lA qlyl',
#  "wAlsArq wAlsArqp fAqTEwA >ydyhmA jzA' bmA ksbA nkAlA mn Allh wAllh Ezyz Hkym",
#  'rb <nhn >Dlln kvyrA mn AlnAs fmn tbEny f<nh mny wmn ESAny f<nk gfwr rHym',
#  'yA >yhA Al*yn |mnwA >nfqwA mn TybAt mA ksbtm wmmA >xrjnA lkm mn Al>rD wlA tymmwA Alxbyv mnh tnfqwn wlstm b|x*yh <lA >n tgmDwA fyh wAElmwA >n Allh gny Hmyd',
#  'wql lEbAdy yqwlwA Alty hy >Hsn <n Al$yTAn ynzg bynhm <n Al$yTAn kAn ll<nsAn EdwA mbynA',
#  'fmA AsTAEwA >n yZhrwh wmA AstTAEwA lh nqbA',
#  'qAlwA <nA <lY rbnA mnqlbwn',
#  'qAl f<nA qd ftnA qwmk mn bEdk w>Dlhm AlsAmry',
#  'w|twA AlytAmY >mwAlhm wlA ttbdlwA Alxbyv bAlTyb wlA t>klwA >mwAlhm <lY >mwAlkm <nh kAn HwbA kbyrA',
#  'fbmA rHmp mn Allh lnt lhm wlw knt fZA glyZ Alqlb lAnfDwA mn Hwlk fAEf Enhm wAstgfr lhm w$Awrhm fy Al>mr f<*A Ezmt ftwkl ElY Allh <n Allh yHb Almtwklyn',
#  'mn kfr bAllh mn bEd <ymAnh <lA mn >krh wqlbh mTm}n bAl<ymAn wlkn mn $rH bAlkfr SdrA fElyhm gDb mn Allh wlhm E*Ab EZym',
#  'wkm qSmnA mn qryp kAnt ZAlmp w>n$>nA bEdhA qwmA |xryn',
#  'yg$Y AlnAs h*A E*Ab >lym',
#  'w>mA bnEmp rbk fHdv',
#  'wqAlwA <n h*A <lA sHr mbyn',
#  'wtrknA bEDhm ywm}* ymwj fy bED wnfx fy AlSwr fjmEnAhm jmEA',
#  'h*A *kr w<n llmtqyn lHsn m|b',
#  '>lA tEbdwA <lA Allh <nny lkm mnh n*yr wb$yr',
#  "<n ymsskm qrH fqd ms Alqwm qrH mvlh wtlk Al>yAm ndAwlhA byn AlnAs wlyElm Allh Al*yn |mnwA wytx* mnkm $hdA' wAllh lA yHb AlZAlmyn",
#  'tlk |yAt Allh ntlwhA Elyk bAlHq wmA Allh yryd ZlmA llEAlmyn',
#  'fmn lm yjd fSyAm $hryn mttAbEyn mn qbl >n ytmAsA fmn lm ystTE f<TEAm styn mskynA *lk lt&mnwA bAllh wrswlh wtlk Hdwd Allh wllkAfryn E*Ab >lym',
#  "w<*A H$r AlnAs kAnwA lhm >EdA' wkAnwA bEbAdthm kAfryn",
#  'qAl Alml> Al*yn AstkbrwA mn qwmh lnxrjnk yA $Eyb wAl*yn |mnwA mEk mn qrytnA >w ltEwdn fy mltnA qAl >wlw knA kArhyn',
#  'ql syrwA fy Al>rD fAnZrwA kyf kAn EAqbp Al*yn mn qbl kAn >kvrhm m$rkyn',
#  'wqAlt Amr>t frEwn qrt Eyn ly wlk lA tqtlwh EsY >n ynfEnA >w ntx*h wldA whm lA y$Erwn',
#  '>wl}k yjzwn Algrfp bmA SbrwA wylqwn fyhA tHyp wslAmA',
#  '<n mA twEdwn l|t wmA >ntm bmEjzyn',
#  'wlqd SbHhm bkrp E*Ab mstqr',
#  'wqAlt >wlAhm l>xrAhm fmA kAn lkm ElynA mn fDl f*wqwA AlE*Ab bmA kntm tksbwn',
#  'slAm ElY <l yAsyn',
#  "wmA y*krwn <lA >n y$A' Allh hw >hl AltqwY w>hl Almgfrp",
#  "w<*A r>whm qAlwA <n h&lA' lDAlwn",
#  "Atx*wA >ymAnhm jnp fSdwA En sbyl Allh <nhm sA' mA kAnwA yEmlwn",
#  'qAl yA qwm lys by DlAlp wlkny rswl mn rb AlEAlmyn',
#  "fkyf <*A j}nA mn kl >mp b$hyd wj}nA bk ElY h&lA' $hydA",
#  "qd xsr Al*yn qtlwA >wlAdhm sfhA bgyr Elm wHrmwA mA rzqhm Allh AftrA' ElY Allh qd DlwA wmA kAnwA mhtdyn",
#  "qAl rbnA Al*y >ETY kl $y' xlqh vm hdY",
#  'ql mn ynjykm mn ZlmAt Albr wAlbHr tdEwnh tDrEA wxfyp l}n >njAnA mn h*h lnkwnn mn Al$Akryn',
#  "w<*A qyl lhm >nfqwA mmA rzqkm Allh qAl Al*yn kfrwA ll*yn |mnwA >nTEm mn lw y$A' Allh >TEmh <n >ntm <lA fy DlAl mbyn",
#  '>wl}k fy jnAt mkrmwn',
#  'w<nkm ltmrwn Elyhm mSbHyn',
#  '<n kl mn fy AlsmAwAt wAl>rD <lA |ty AlrHmn EbdA',
#  'qAl *lk mA knA nbg fArtdA ElY |vArhmA qSSA',
#  'mn kAn yryd AlEzp fllh AlEzp jmyEA <lyh ySEd Alklm AlTyb wAlEml AlSAlH yrfEh wAl*yn ymkrwn Alsy}At lhm E*Ab $dyd wmkr >wl}k hw ybwr',
#  'ftlqY |dm mn rbh klmAt ftAb Elyh <nh hw AltwAb AlrHym',
#  'wAstmE ywm ynAd AlmnAd mn mkAn qryb',
#  'ql hw AlqAdr ElY >n ybEv Elykm E*AbA mn fwqkm >w mn tHt >rjlkm >w ylbskm $yEA wy*yq bEDkm b>s bED AnZr kyf nSrf Al|yAt lElhm yfqhwn',
#  'bsm Allh AlrHmn AlrHym >tY >mr Allh flA tstEjlwh sbHAnh wtEAlY EmA y$rkwn',
#  '>tx*nAhm sxryA >m zAgt Enhm Al>bSAr',
#  'w<lhkm <lh wAHd lA <lh <lA hw AlrHmn AlrHym',
#  'fAjtbAh rbh fjElh mn AlSAlHyn',
#  'wlqd Sdqkm Allh wEdh <* tHswnhm b<*nh HtY <*A f$ltm wtnAzEtm fy Al>mr wESytm mn bEd mA >rAkm mA tHbwn mnkm mn yryd AldnyA wmnkm mn yryd Al|xrp vm Srfkm Enhm lybtlykm wlqd EfA Enkm wAllh *w fDl ElY Alm&mnyn',
#  '>n tqwl nfs yA HsrtY ElY mA frTt fy jnb Allh w<n knt lmn AlsAxryn',
#  'vm klA swf tElmwn',
#  'wsxr lkm Allyl wAlnhAr wAl$ms wAlqmr wAlnjwm msxrAt b>mrh <n fy *lk l|yAt lqwm yEqlwn',
#  "wnb}hm >n AlmA' qsmp bynhm kl $rb mHtDr",
#  'wAlbyt AlmEmwr',
#  'w<* jElnA Albyt mvAbp llnAs w>mnA wAtx*wA mn mqAm <brAhym mSlY wEhdnA <lY <brAhym w<smAEyl >n ThrA byty llTA}fyn wAlEAkfyn wAlrkE Alsjwd',
#  "wjA'wA >bAhm E$A' ybkwn",
#  'qAlwA mn fEl h*A b|lhtnA <nh lmn AlZAlmyn',
#  'w<*A AlSHf n$rt',
#  'wAl>rD bEd *lk dHAhA',
#  'wqAlwA kwnwA hwdA >w nSArY thtdwA ql bl mlp <brAhym HnyfA wmA kAn mn Alm$rkyn',
#  "<nhm ln ygnwA Enk mn Allh $y}A w<n AlZAlmyn bEDhm >wlyA' bED wAllh wly Almtqyn",
#  '>Hsb AlnAs >n ytrkwA >n yqwlwA |mnA whm lA yftnwn',
#  "fAnqlbwA bnEmp mn Allh wfDl lm ymsshm sw' wAtbEwA rDwAn Allh wAllh *w fDl EZym",
#  ">m Hsb Al*yn yEmlwn Alsy}At >n ysbqwnA sA' mA yHkmwn",
#  'bsm Allh AlrHmn AlrHym sbH Asm rbk Al>ElY',
#  "AlsmA' mnfTr bh kAn wEdh mfEwlA",
#  '<* qAl l>byh wqwmh mA tEbdwn',
#  'f>x*h Allh nkAl Al|xrp wAl>wlY',
#  'w<nh lfy zbr Al>wlyn',
#  "wlw ftHnA Elyhm bAbA mn AlsmA' fZlwA fyh yErjwn",
#  'wlkm fy AlqSAS HyAp yA >wly Al>lbAb lElkm ttqwn',
#  '*lk b>nhm |mnwA vm kfrwA fTbE ElY qlwbhm fhm lA yfqhwn',
#  "f<*A lqytm Al*yn kfrwA fDrb AlrqAb HtY <*A >vxntmwhm f$dwA AlwvAq f<mA mnA bEd w<mA fdA' HtY tDE AlHrb >wzArhA *lk wlw y$A' Allh lAntSr mnhm wlkn lyblw bEDkm bbED wAl*yn qtlwA fy sbyl Allh fln yDl >EmAlhm",
#  'qAlwA >rjh w>xAh w>rsl fy AlmdA}n HA$ryn',
#  'w<ny klmA dEwthm ltgfr lhm jElwA >SAbEhm fy |*Anhm wAstg$wA vyAbhm w>SrwA wAstkbrwA AstkbArA',
#  'flnqSn Elyhm bElm wmA knA gA}byn',
#  'qAl Al*yn AstkbrwA <nA kl fyhA <n Allh qd Hkm byn AlEbAd',
#  "ql <n rby ybsT Alrzq lmn y$A' mn EbAdh wyqdr lh wmA >nfqtm mn $y' fhw yxlfh whw xyr AlrAzqyn",
#  'xAfDp rAfEp',
#  'f>lqY mwsY ESAh f<*A hy tlqf mA y>fkwn',
#  'wlqd kntm tmnwn Almwt mn qbl >n tlqwh fqd r>ytmwh w>ntm tnZrwn',
#  "tbArk Al*y jEl fy AlsmA' brwjA wjEl fyhA srAjA wqmrA mnyrA",
#  'wlA tlbswA AlHq bAlbATl wtktmwA AlHq w>ntm tElmwn',
#  'wElY AlvlAvp Al*yn xlfwA HtY <*A DAqt Elyhm Al>rD bmA rHbt wDAqt Elyhm >nfshm wZnwA >n lA mlj> mn Allh <lA <lyh vm tAb Elyhm lytwbwA <n Allh hw AltwAb AlrHym',
#  'wyqwlwn mtY h*A AlwEd <n kntm SAdqyn',
#  'ywm ydEwkm ftstjybwn bHmdh wtZnwn <n lbvtm <lA qlylA',
#  "wlqd zynA AlsmA' AldnyA bmSAbyH wjElnAhA rjwmA ll$yATyn w>EtdnA lhm E*Ab AlsEyr",
#  "wjElwA lh mn EbAdh jz'A <n Al<nsAn lkfwr mbyn",
#  'xlq AlsmAwAt wAl>rD bAlHq wSwrkm f>Hsn Swrkm w<lyh AlmSyr',
#  'ys>lwnk En Alxmr wAlmysr ql fyhmA <vm kbyr wmnAfE llnAs w<vmhmA >kbr mn nfEhmA wys>lwnk mA*A ynfqwn ql AlEfw k*lk ybyn Allh lkm Al|yAt lElkm ttfkrwn',
#  'yA >yhA Al*yn |mnwA <n ttqwA Allh yjEl lkm frqAnA wykfr Enkm sy}Atkm wygfr lkm wAllh *w AlfDl AlEZym',
#  'lA ys>l EmA yfEl whm ys>lwn',
#  "Al*y lh mlk AlsmAwAt wAl>rD wlm ytx* wldA wlm ykn lh $ryk fy Almlk wxlq kl $y' fqdrh tqdyrA",
#  '<n Al*yn ytlwn ktAb Allh w>qAmwA AlSlAp w>nfqwA mmA rzqnAhm srA wElAnyp yrjwn tjArp ln tbwr',
#  'wvmwd fmA >bqY',
#  'frddnAh <lY >mh ky tqr EynhA wlA tHzn wltElm >n wEd Allh Hq wlkn >kvrhm lA yElmwn',
#  '>fmn wEdnAh wEdA HsnA fhw lAqyh kmn mtEnAh mtAE AlHyAp AldnyA vm hw ywm AlqyAmp mn AlmHDryn',
#  'f*rhm HtY ylAqwA ywmhm Al*y fyh ySEqwn',
#  'lA tbqy wlA t*r',
#  'yA >yhA Alrswl blg mA >nzl <lyk mn rbk w<n lm tfEl fmA blgt rsAlth wAllh yESmk mn AlnAs <n Allh lA yhdy Alqwm AlkAfryn',
#  'wmA y>tyhm mn rswl <lA kAnwA bh ysthz}wn',
#  '>wklmA EAhdwA EhdA nb*h fryq mnhm bl >kvrhm lA y&mnwn',
#  'w<*A >*qnA AlnAs rHmp frHwA bhA w<n tSbhm sy}p bmA qdmt >ydyhm <*A hm yqnTwn',
#  'ql <n kAnt lkm AldAr Al|xrp End Allh xAlSp mn dwn AlnAs ftmnwA Almwt <n kntm SAdqyn',
#  'ql <nmA >dEw rby wlA >$rk bh >HdA',
#  'lqd rDy Allh En Alm&mnyn <* ybAyEwnk tHt Al$jrp fElm mA fy qlwbhm f>nzl Alskynp Elyhm w>vAbhm ftHA qrybA',
#  'fAstmsk bAl*y >wHy <lyk <nk ElY SrAT mstqym',
#  "w|tynAhm bynAt mn Al>mr fmA AxtlfwA <lA mn bEd mA jA'hm AlElm bgyA bynhm <n rbk yqDy bynhm ywm AlqyAmp fymA kAnwA fyh yxtlfwn",
#  "mvl Aljnp Alty wEd Almtqwn fyhA >nhAr mn mA' gyr |sn w>nhAr mn lbn lm ytgyr TEmh w>nhAr mn xmr l*p ll$Arbyn w>nhAr mn Esl mSfY wlhm fyhA mn kl AlvmrAt wmgfrp mn rbhm kmn hw xAld fy AlnAr wsqwA mA' HmymA fqTE >mEA'hm",
#  "lh mlk AlsmAwAt wAl>rD yHyy wymyt whw ElY kl $y' qdyr",
#  '>fmn kAn ElY bynp mn rbh wytlwh $Ahd mnh wmn qblh ktAb mwsY <mAmA wrHmp >wl}k y&mnwn bh wmn ykfr bh mn Al>HzAb fAlnAr mwEdh flA tk fy mryp mnh <nh AlHq mn rbk wlkn >kvr AlnAs lA y&mnwn',
#  "trjy mn t$A' mnhn wt&wy <lyk mn t$A' wmn Abtgyt mmn Ezlt flA jnAH Elyk *lk >dnY >n tqr >Eynhn wlA yHzn wyrDyn bmA |tythn klhn wAllh yElm mA fy qlwbkm wkAn Allh ElymA HlymA",
#  'bl yryd kl Amr} mnhm >n y&tY SHfA mn$rp',
#  "Al*yn kAnt >Eynhm fy gTA' En *kry wkAnwA lA ystTyEwn smEA",
#  'wqAl lhm nbyhm <n |yp mlkh >n y>tykm AltAbwt fyh skynp mn rbkm wbqyp mmA trk |l mwsY w|l hArwn tHmlh AlmlA}kp <n fy *lk l|yp lkm <n kntm m&mnyn',
#  'wrbk >Elm bmn fy AlsmAwAt wAl>rD wlqd fDlnA bED Alnbyyn ElY bED w|tynA dAwwd zbwrA',
#  '<n E*Ab rbhm gyr m>mwn',
#  'Allh ySTfy mn AlmlA}kp rslA wmn AlnAs <n Allh smyE bSyr',
#  'l>ml>n jhnm mnk wmmn tbEk mnhm >jmEyn',
#  'qd xlt mn qblkm snn fsyrwA fy Al>rD fAnZrwA kyf kAn EAqbp Almk*byn',
#  'wqwm nwH mn qbl <nhm kAnwA qwmA fAsqyn',
#  'w<n yrwA |yp yErDwA wyqwlwA sHr mstmr',
#  "yA >yhA Al*yn |mnwA lA ttx*wA bTAnp mn dwnkm lA y>lwnkm xbAlA wdwA mA Entm qd bdt AlbgDA' mn >fwAhhm wmA txfy Sdwrhm >kbr qd bynA lkm Al|yAt <n kntm tEqlwn",
#  '<lY rbk ywm}* AlmsAq',
#  'mn Alm&mnyn rjAl SdqwA mA EAhdwA Allh Elyh fmnhm mn qDY nHbh wmnhm mn yntZr wmA bdlwA tbdylA',
#  'wmn Al$yATyn mn ygwSwn lh wyEmlwn EmlA dwn *lk wknA lhm HAfZyn',
#  'ywm trY Alm&mnyn wAlm&mnAt ysEY nwrhm byn >ydyhm wb>ymAnhm b$rAkm Alywm jnAt tjry mn tHthA Al>nhAr xAldyn fyhA *lk hw Alfwz AlEZym',
#  "w<*A jA'k Al*yn y&mnwn b|yAtnA fql slAm Elykm ktb rbkm ElY nfsh AlrHmp >nh mn Eml mnkm sw'A bjhAlp vm tAb mn bEdh w>SlH f>nh gfwr rHym",
#  "qAl h*A rHmp mn rby f<*A jA' wEd rby jElh dkA' wkAn wEd rby HqA",
#  'f<*A qr>t Alqr|n fAstE* bAllh mn Al$yTAn Alrjym',
#  ">wlm yr Al*yn kfrwA >n AlsmAwAt wAl>rD kAntA rtqA fftqnAhmA wjElnA mn AlmA' kl $y' Hy >flA y&mnwn",
#  'fkyf kAn E*Aby wn*r',
#  "w<* qAlwA Allhm <n kAn h*A hw AlHq mn Endk f>mTr ElynA HjArp mn AlsmA' >w A}tnA bE*Ab >lym",
#  'wqAl frEwn *rwny >qtl mwsY wlydE rbh <ny >xAf >n ybdl dynkm >w >n yZhr fy Al>rD AlfsAd',
#  'w<n Tlqtmwhn mn qbl >n tmswhn wqd frDtm lhn fryDp fnSf mA frDtm <lA >n yEfwn >w yEfw Al*y bydh Eqdp AlnkAH w>n tEfwA >qrb lltqwY wlA tnswA AlfDl bynkm <n Allh bmA tEmlwn bSyr',
#  'wlmA skt En mwsY AlgDb >x* Al>lwAH wfy nsxthA hdY wrHmp ll*yn hm lrbhm yrhbwn',
#  'mn kAn yryd Hrv Al|xrp nzd lh fy Hrvh wmn kAn yryd Hrv AldnyA n&th mnhA wmA lh fy Al|xrp mn nSyb',
#  'rbnA >xrjnA mnhA f<n EdnA f<nA ZAlmwn',
#  'yA qwm AdxlwA Al>rD Almqdsp Alty ktb Allh lkm wlA trtdwA ElY >dbArkm ftnqlbwA xAsryn',
#  '>m xlqwA AlsmAwAt wAl>rD bl lA ywqnwn',
#  'yA >yhA Al*yn |mnwA AtqwA Allh wltnZr nfs mA qdmt lgd wAtqwA Allh <n Allh xbyr bmA tEmlwn',
#  'w>nzl Al*yn ZAhrwhm mn >hl AlktAb mn SyASyhm wq*f fy qlwbhm AlrEb fryqA tqtlwn wt>srwn fryqA',
#  'lA tdrkh Al>bSAr whw ydrk Al>bSAr whw AllTyf Alxbyr',
#  'wzrwE wmqAm krym',
#  '<n hw <lA rjl AftrY ElY Allh k*bA wmA nHn lh bm&mnyn',
#  'yhdy bh Allh mn AtbE rDwAnh sbl AlslAm wyxrjhm mn AlZlmAt <lY Alnwr b<*nh wyhdyhm <lY SrAT mstqym',
#  'ys>lwnk En Al>hlp ql hy mwAqyt llnAs wAlHj wlys Albr b>n t>twA Albywt mn ZhwrhA wlkn Albr mn AtqY w>twA Albywt mn >bwAbhA wAtqwA Allh lElkm tflHwn',
#  'f>x*nAh wjnwdh fnb*nAhm fy Alym fAnZr kyf kAn EAqbp AlZAlmyn',
#  'vm >mAth f>qbrh',
#  "hw Allh AlxAlq AlbAr} AlmSwr lh Al>smA' AlHsnY ysbH lh mA fy AlsmAwAt wAl>rD whw AlEzyz AlHkym",
#  "<n rbk yElm >nk tqwm >dnY mn vlvy Allyl wnSfh wvlvh wTA}fp mn Al*yn mEk wAllh yqdr Allyl wAlnhAr Elm >n ln tHSwh ftAb Elykm fAqr'wA mA tysr mn Alqr|n Elm >n sykwn mnkm mrDY w|xrwn yDrbwn fy Al>rD ybtgwn mn fDl Allh w|xrwn yqAtlwn fy sbyl Allh fAqr'wA mA tysr mnh w>qymwA AlSlAp w|twA AlzkAp w>qrDwA Allh qrDA HsnA wmA tqdmwA l>nfskm mn xyr tjdwh End Allh hw xyrA w>EZm >jrA wAstgfrwA Allh <n Allh gfwr rHym",
#  'fASbr kmA Sbr >wlw AlEzm mn Alrsl wlA tstEjl lhm k>nhm ywm yrwn mA ywEdwn lm ylbvwA <lA sAEp mn nhAr blAg fhl yhlk <lA Alqwm AlfAsqwn',
#  'k*lk AlE*Ab wlE*Ab Al|xrp >kbr lw kAnwA yElmwn',
#  'ql AdEwA Al*yn zEmtm mn dwn Allh lA ymlkwn mvqAl *rp fy AlsmAwAt wlA fy Al>rD wmA lhm fyhmA mn $rk wmA lh mnhm mn Zhyr',
#  'wwDEnA Enk wzrk',
#  "wdwA lw tkfrwn kmA kfrwA ftkwnwn swA' flA ttx*wA mnhm >wlyA' HtY yhAjrwA fy sbyl Allh f<n twlwA fx*whm wAqtlwhm Hyv wjdtmwhm wlA ttx*wA mnhm wlyA wlA nSyrA",
#  'fy AlHmym vm fy AlnAr ysjrwn',
#  '<n rbk hw yfSl bynhm ywm AlqyAmp fymA kAnwA fyh yxtlfwn',
#  '<nmA Hrm Elykm Almytp wAldm wlHm Alxnzyr wmA >hl lgyr Allh bh fmn ADTr gyr bAg wlA EAd f<n Allh gfwr rHym',
#  'f*lk Al*y ydE Alytym',
#  '<nA nHn nrv Al>rD wmn ElyhA w<lynA yrjEwn',
#  "wlA tnkHwA mA nkH |bA&km mn AlnsA' <lA mA qd slf <nh kAn fAH$p wmqtA wsA' sbylA",
#  '<n Al<nsAn lrbh lknwd',
#  'rslA mb$ryn wmn*ryn l}lA ykwn llnAs ElY Allh Hjp bEd Alrsl wkAn Allh EzyzA HkymA',
#  '<n fy *lk l|yp wmA kAn >kvrhm m&mnyn',
#  'wAl*yn hm b|yAt rbhm y&mnwn',
#  "w<n TA}ftAn mn Alm&mnyn AqttlwA f>SlHwA bynhmA f<n bgt <HdAhmA ElY Al>xrY fqAtlwA Alty tbgy HtY tfy' <lY >mr Allh f<n fA't f>SlHwA bynhmA bAlEdl w>qsTwA <n Allh yHb AlmqsTyn",
#  'fsbH bHmd rbk wkn mn AlsAjdyn',
#  'w<nh lHsrp ElY AlkAfryn',
#  'wklA DrbnA lh Al>mvAl wklA tbrnA ttbyrA',
#  '*lkm bmA kntm tfrHwn fy Al>rD bgyr AlHq wbmA kntm tmrHwn',
#  'wlw >n lkl nfs Zlmt mA fy Al>rD lAftdt bh w>srwA AlndAmp lmA r>wA AlE*Ab wqDy bynhm bAlqsT whm lA yZlmwn',
#  "qAl qd wqE Elykm mn rbkm rjs wgDb >tjAdlwnny fy >smA' smytmwhA >ntm w|bA&km mA nzl Allh bhA mn slTAn fAntZrwA <ny mEkm mn AlmntZryn",
#  "wmA kAn SlAthm End Albyt <lA mkA' wtSdyp f*wqwA AlE*Ab bmA kntm tkfrwn",
#  'yA bny <nhA <n tk mvqAl Hbp mn xrdl ftkn fy Sxrp >w fy AlsmAwAt >w fy Al>rD y>t bhA Allh <n Allh lTyf xbyr',
#  'w<*A *kr Allh wHdh A$m>zt qlwb Al*yn lA y&mnwn bAl|xrp w<*A *kr Al*yn mn dwnh <*A hm ystb$rwn',
#  'wAl*yn <*A >SAbhm Albgy hm yntSrwn',
#  "wAl$ErA' ytbEhm AlgAwwn",
#  'wh*A *kr mbArk >nzlnAh >f>ntm lh mnkrwn',
#  "wjElnA Allyl wAlnhAr |ytyn fmHwnA |yp Allyl wjElnA |yp AlnhAr mbSrp ltbtgwA fDlA mn rbkm wltElmwA Edd Alsnyn wAlHsAb wkl $y' fSlnAh tfSylA",
#  'w<*A ms Al<nsAn Dr dEA rbh mnybA <lyh vm <*A xwlh nEmp mnh nsy mA kAn ydEw <lyh mn qbl wjEl llh >ndAdA lyDl En sbylh ql tmtE bkfrk qlylA <nk mn >SHAb AlnAr',
#  'wAl*yn ysEwn fy |yAtnA mEAjzyn >wl}k fy AlE*Ab mHDrwn',
#  "w>qsmwA bAllh jhd >ymAnhm l}n jA'hm n*yr lykwnn >hdY mn <HdY Al>mm flmA jA'hm n*yr mA zAdhm <lA nfwrA",
#  'qAl rb >nY ykwn ly glAm wkAnt Amr>ty EAqrA wqd blgt mn Alkbr EtyA',
#  ...}

# %%
df_set_a = pd.DataFrame(set_a.difference(set_b))
df_set_a.rename(columns={0:"buckwalter_simple"}, inplace=True)
df_set_a
# Out:
#                                       buckwalter_simple
# 0     w<n kAn TA}fp mnkm 'AmnwA bAl*Y >rslt bh wTA}f...
# 1                 lqd kAn fY ywsf w<xwth 'AyAt llsA}lyn
# 2     wAl>rD mddnAhA w>lqynA fyhA rwAsY w>nbtnA fyhA...
# 3                        wmA ynbgY llrHmAn >n ytx* wldA
# 4     qAl ln >rslh mEkm HtYA t&twn mwvqA mn Allh lt>...
# ...                                                 ...
# 4249  ql ll*yn 'AmnwA ygfrwA ll*yn lA yrjwn >yAm All...
# 4250  lm ykn Al*yn kfrwA mn >hl AlktAb wAlm$rkyn mnf...
# 4251  wrswlA <lYA bnY <srA'yl >nY qd j}tkm b_Ayp mn ...
# 4252  wlA t&mnwA <lA lmn tbE dynkm ql <n AlhdYA hdY ...
# 4253  <n Al*yn ylHdwn fY 'AyAtnA lA yxfwn ElynA >fmn...
#
# [4254 rows x 1 columns]

# %%
df_a_merge = pd.merge(df_set_a, df_a, how="right", on="buckwalter_simple")
df_a_merge.drop_duplicates(inplace=True)
df_a_merge
# Out:
#              buckwalter_simple             arabic_simple
# 0      bsm Allh AlrHmAn AlrHym   بسم الله الرحمان الرحيم
# 1        AlHmd llh rb AlEAlmyn     الحمد لله رب العالمين
# 2               AlrHmAn AlrHym            الرحمان الرحيم
# 3               mAlk ywm Aldyn            مالك يوم الدين
# 4       <yAk nEbd w<yAk nstEyn    إياك نعبد وإياك نستعين
# ...                        ...                       ...
# 6231                 mlk AlnAs                 ملك الناس
# 6232                <lAh AlnAs                إلاه الناس
# 6233      mn $r AlwswAs AlxnAs      من شر الوسواس الخناس
# 6234  Al*Y ywsws fY Sdwr AlnAs  الذى يوسوس فى صدور الناس
# 6235           mn Aljnp wAlnAs           من الجنة والناس
#
# [6054 rows x 2 columns]

# %%
df_set_b = pd.DataFrame(set_b.difference(set_a))
df_set_b.rename(columns={0:"buckwalter_simple"}, inplace=True)
df_set_b
# Out:
#                                       buckwalter_simple
# 0                    yA >yhA Al<nsAn mA grk brbk Alkrym
# 1                                 vm kAn Elqp fxlq fswY
# 2                                          wSdq bAlHsnY
# 3     bsm Allh AlrHmn AlrHym yA >yhA Al*yn |mnwA >wf...
# 4     snlqy fy qlwb Al*yn kfrwA AlrEb bmA >$rkwA bAl...
# ...                                                 ...
# 4250  wlqd k*bt rsl mn qblk fSbrwA ElY mA k*bwA w>w*...
# 4251               wmn nEmrh nnksh fy Alxlq >flA yEqlwn
# 4252                                        kgly AlHmym
# 4253  yA bny |dm lA yftnnkm Al$yTAn kmA >xrj >bwykm ...
# 4254                               slAm ElY mwsY whArwn
#
# [4255 rows x 1 columns]

# %%
df_b_merge = pd.merge(df_set_b, df_b, how="right", on="buckwalter_simple")
df_b_merge.drop_duplicates(inplace=True)
df_b_merge
# Out:
#              buckwalter_simple             arabic_simple
# 0       bsm Allh AlrHmn AlrHym    بسم الله الرحمن الرحيم
# 1        AlHmd llh rb AlEAlmyn     الحمد لله رب العالمين
# 2                AlrHmn AlrHym             الرحمن الرحيم
# 3               mAlk ywm Aldyn            مالك يوم الدين
# 4       <yAk nEbd w<yAk nstEyn    إياك نعبد وإياك نستعين
# ...                        ...                       ...
# 6231                 mlk AlnAs                 ملك الناس
# 6232                 <lh AlnAs                 إله الناس
# 6233      mn $r AlwswAs AlxnAs      من شر الوسواس الخناس
# 6234  Al*y ywsws fy Sdwr AlnAs  الذي يوسوس في صدور الناس
# 6235         mn Aljnp wAlnAs\n         من الجنة والناس\n
#
# [6055 rows x 2 columns]
