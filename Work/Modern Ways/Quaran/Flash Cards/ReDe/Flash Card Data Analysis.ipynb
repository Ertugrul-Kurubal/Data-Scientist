# %% [markdown]
# ### Flash Cards Data Analysis

# %%
import pandas as pd
import numpy as np
import re
from functools import reduce
from camel_tools.utils.charmap import CharMapper
from lang_trans.arabic import buckwalter

# %%
# buckwalter text clean for simple before transString
def clean_ex(text):
    buckwalter_out = re.sub(r'''([PJVG\.:;,!\+\^\]\[@#FNKauio`~"%-])''', "", text) # difference from clean
    return buckwalter_out

# %%
# Arabic Encoding Extended
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2uni = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "}": u"\u0626", # hamza-on-yaa'
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "F": u"\u064B", # fatHatayn
            "N": u"\u064C", # Dammatayn
            "K": u"\u064D", # kasratayn
            "a": u"\u064E", # fatHa
            "u": u"\u064F", # Damma
            "i": u"\u0650", # kasra
            "~": u"\u0651", # shaddah
            "o": u"\u0652", # sukuun
            "^": u"\u0653", # maddah
            "#": u"\u0654", # hamzaabove            
            "`": u"\u0670", # dagger 'alif
            "{": u"\u0671", # waSla
            "P": u"\u067E", # arabicletterpeh
            "J": u"\u0686", 
            "V": u"\u06A4", # arabicletterveh
            "G": u"\u06AF", # arabiclettergaf
            ":": u"\u06DC", # smallhighseen
            "@": u"\u06DF", # smallhighroundedzero
            "\"": u"\u06E0", # smallhighuprightrectangularzero
            "[": u"\u06E2", # smallhighmeemisolatedform
            ";": u"\u06E3", # smalllowseen
            ",": u"\u06E5", # smallwaw
            ".": u"\u06E6", # smallya
            "!": u"\u06E8", # smallhighnoon
            "-": u"\u06EA", # emptycentrelowstop
            "+": u"\u06EB", # emptycentrehighstop
            "%": u"\u06EC", # roundedhighstopwithfilledcentre
            "]": u"\u06ED", # smalllowmeem           
}

def transString(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2uni.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
# Simple Technique
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2unisimple = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "{": u"\u0671", # waSla         
}

def transStringSimple(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2unisimple.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
# character clean for simple after transStringSimple 
def clean(text):
    arabic_out = re.sub(r'''([PJVG\.:;,!\+\]\[@#FNKauio`~"%-])''', "", text) # .$^*+
    arabic_out2 = re.sub(r"\^", " ", arabic_out)
    return arabic_out2

# %% [markdown]
# #### Arabic Word Select

# %%
df_arabic_translate = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Flash Cards/Data/Quran_All_Translate_Fill_Asterisks.xlsx")
#df_arabic_translate = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Flash Cards/Data/All_Surah_Translate_File_Concat.xlsx")
df_arabic_translate
# Out:
#        surah surah latin        arabic transliterate       translate_english  \
# 0          1   Al-Fatiha        بِسۡمِ        bis'mi           In (the) name
# 1          1   Al-Fatiha       ٱللَّهِ       al-lahi              (of) Allah
# 2          1   Al-Fatiha  ٱلرَّحۡمَٰنِ    al-rahmani       the Most Gracious
# 3          1   Al-Fatiha    ٱلرَّحِيمِ     al-rahimi       the Most Merciful
# 4          1   Al-Fatiha     ٱلۡحَمۡدُ      al-hamdu  All praises and thanks
# ...      ...         ...           ...           ...                     ...
# 77424    114      An-Nas       صُدُورِ        suduri           (the) breasts
# 77425    114      An-Nas      ٱلنَّاسِ       al-nasi            (of) mankind
# 77426    114      An-Nas          مِنَ          mina                    From
# 77427    114      An-Nas    ٱلۡجِنَّةِ     al-jinati                the jinn
# 77428    114      An-Nas    وَٱلنَّاسِ      wal-nasi                 and men
#
#                    translate_urdu          translate_hindi  \
# 0                        ساتھ نام                 साथ नाम
# 1                         اللہ کے                अल्लाह के
# 2              جو بے حد مہربان ہے         जो बहुत मेहरबान
# 3      بار بار رحم فرمانے والا ہے  निहायत रहम करने वाला है
# 4                        سب تعریف                सब तारीफ़
# ...                           ...                      ...
# 77424                       سینوں                सीनों में
# 77425                  انسانوں کے                लोगों के
# 77426                          سے                        *
# 77427                    جنوں میں          जिन्नों में से
# 77428             اور انسانوں میں       और इन्सानों में से
#
#       translate_indonesian translate_bangla  translate_turkish  \
# 0              dengan nama             নামে             adıyla
# 1                    Allah       আল্লাহ (র)           Allah'ın
# 2            Maha Pengasih      পরম করুণাময়             Rahman
# 3           Maha Penyayang       অসীম দয়ালু              Rahim
# 4                   pujian      সকল প্রশংসা          hamdolsun
# ...                    ...              ...                ...
# 77424                 dada      অন্তরসমূহের                  *
# 77425              manusia          মানুষের         insanların
# 77426                 dari         মধ্য হতে          cinlerden
# 77427                  jin            জিনের                  *
# 77428          dan manusia        ও মানুষের  ve insanlar(dan);
#
#          translate_russian  index
# 0                 С именем      0
# 1                  Аллаха,      1
# 2             Милостивого,      2
# 3            Милосердного!      3
# 4                    Хвала      4
# ...                    ...    ...
# 77424               грудях  78244
# 77425               людей,  78245
# 77426  (будучи) из (числа)  78246
# 77427              джиннов  78247
# 77428            и людей».  78248
#
# [77429 rows x 12 columns]

# %%
df_arabic_word_count = df_arabic_translate["arabic"].value_counts(ascending=False).reset_index()
df_arabic_word_count.rename(columns={"index":"arabic","arabic":"arabic_frequency"}, inplace=True)
#df_arabic_word_count = df_arabic_word_count.head(300)
df_arabic_word_count
# Out:
#               arabic  arabic_frequency
# 0                فِي              1096
# 1          ٱلَّذِينَ               810
# 2                مِن               728
# 3                مَا               709
# 4            ٱللَّهِ               667
# ...              ...               ...
# 21304       ٱلۡجُبِّ                 1
# 21305   يَلۡتَقِطۡهُ                 1
# 21306  ٱلسَّيَّارَةِ                 1
# 21307    تَأۡمَ۬نَّا                 1
# 21308     يُوَسۡوِسُ                 1
#
# [21309 rows x 2 columns]

# %%
df_word_translate_select = df_arabic_translate.iloc[:,[2,3,4,5,6,7,8,9,10]]
df_word_translate_select.drop_duplicates(inplace=True)
df_word_translate_select
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#              arabic transliterate       translate_english  \
# 0            بِسۡمِ        bis'mi           In (the) name
# 1           ٱللَّهِ       al-lahi              (of) Allah
# 2      ٱلرَّحۡمَٰنِ    al-rahmani       the Most Gracious
# 3        ٱلرَّحِيمِ     al-rahimi       the Most Merciful
# 4         ٱلۡحَمۡدُ      al-hamdu  All praises and thanks
# ...             ...           ...                     ...
# 77424       صُدُورِ        suduri           (the) breasts
# 77425      ٱلنَّاسِ       al-nasi            (of) mankind
# 77426          مِنَ          mina                    From
# 77427    ٱلۡجِنَّةِ     al-jinati                the jinn
# 77428    وَٱلنَّاسِ      wal-nasi                 and men
#
#                    translate_urdu          translate_hindi  \
# 0                        ساتھ نام                 साथ नाम
# 1                         اللہ کے                अल्लाह के
# 2              جو بے حد مہربان ہے         जो बहुत मेहरबान
# 3      بار بار رحم فرمانے والا ہے  निहायत रहम करने वाला है
# 4                        سب تعریف                सब तारीफ़
# ...                           ...                      ...
# 77424                       سینوں                सीनों में
# 77425                  انسانوں کے                लोगों के
# 77426                          سے                        *
# 77427                    جنوں میں          जिन्नों में से
# 77428             اور انسانوں میں       और इन्सानों में से
#
#       translate_indonesian translate_bangla  translate_turkish  \
# 0              dengan nama             নামে             adıyla
# 1                    Allah       আল্লাহ (র)           Allah'ın
# 2            Maha Pengasih      পরম করুণাময়             Rahman
# 3           Maha Penyayang       অসীম দয়ালু              Rahim
# 4                   pujian      সকল প্রশংসা          hamdolsun
# ...                    ...              ...                ...
# 77424                 dada      অন্তরসমূহের                  *
# 77425              manusia          মানুষের         insanların
# 77426                 dari         মধ্য হতে          cinlerden
# 77427                  jin            জিনের                  *
# 77428          dan manusia        ও মানুষের  ve insanlar(dan);
#
#          translate_russian
# 0                 С именем
# 1                  Аллаха,
# 2             Милостивого,
# 3            Милосердного!
# 4                    Хвала
# ...                    ...
# 77424               грудях
# 77425               людей,
# 77426  (будучи) из (числа)
# 77427              джиннов
# 77428            и людей».
#
# [69910 rows x 9 columns]

# %%
df_arabic_count_translate_merge = pd.merge(df_arabic_word_count, df_word_translate_select, how="left", on="arabic")
df_arabic_count_translate_merge.drop_duplicates(inplace=True)
df_arabic_count_translate_merge
# Out:
#               arabic  arabic_frequency transliterate translate_english  \
# 0                فِي              1096            fi                In
# 1                فِي              1096            fi                in
# 2                فِي              1096            fi                in
# 3                فِي              1096            fi                in
# 4                فِي              1096            fi                in
# ...              ...               ...           ...               ...
# 69905       ٱلۡجُبِّ                 1       al-jubi     (of) the well
# 69906   يَلۡتَقِطۡهُ                 1   yaltaqit'hu     will pick him
# 69907  ٱلسَّيَّارَةِ                 1   al-sayarati     [the] caravan
# 69908    تَأۡمَ۬نَّا                 1       tamanna          trust us
# 69909     يُوَسۡوِسُ                 1     yuwaswisu          whispers
#
#                          translate_urdu           translate_hindi  \
# 0                                   میں                         *
# 1                                   میں                         *
# 2                                 ان کی                         *
# 3                                   میں                         *
# 4                                   میں                         *
# ...                                 ...                       ...
# 69905  کنوئیں میں۔ کنوئیں کی گہرائی میں                   कुएँ की
# 69906                  اٹھا لے گا اس کو              उठा लेगा उसे
# 69907                             قافلہ                  क़ाफ़िला
# 69908                 آپ بھروسہ کرتے ہم  नहीं आप भरोसा करते हम पर
# 69909                    وسوسہ ڈالتا ہے           वसवसा डालता है
#
#             translate_indonesian     translate_bangla   translate_turkish  \
# 0                       di dalam            মধ্যে আছে  onların kablerinde
# 1                             di                মধ্যে          yeryüzünde
# 2                          dalam                মধ্যে              içinde
# 3                          dalam                মধ্যে              içinde
# 4                          dalam                মধ্যে              içinde
# ...                          ...                  ...                 ...
# 69905                      sumur                কূপের             kuyunun
# 69906                 menemuinya       তাকে তুলে নিবে   onu (görüp) alsın
# 69907  orang-orang yang berjalan         পথযাত্রীদলের        kervanlardan
# 69908      kamu mempercayai kami  আমাদের বিশ্বাস করেন                   *
# 69909           membisik-bisikan      কুমন্ত্রণা দেয়            fısıldar
#
#       translate_russian
# 0                     В
# 1                    на
# 2                     в
# 3                    во
# 4                     в
# ...                 ...
# 69905         колодца,–
# 69906      подберёт его
# 69907          караван,
# 69908  доверяешь ты нам
# 69909           наущает
#
# [69910 rows x 10 columns]

# %%
#df_arabic_count_translate_merge.to_excel("Quran_Arabic_Word_Translate_Selected.xlsx", index=False)

# %%
#df_arabic_count_translate_merge["buckwalter"] = df_arabic_count_translate_merge.loc[:,"arabic"].apply(lambda x : transString(x,0))
#df_arabic_count_translate_merge

# %%
#df_arabic_count_translate_merge["buckwalter_simple"] = df_arabic_count_translate_merge.loc[:,"buckwalter"].apply(lambda x : clean_ex(x))
#df_arabic_count_translate_merge

# %%
#df_arabic_count_translate_merge["arabic_simple"] = df_arabic_count_translate_merge.loc[:,"buckwalter_simple"].apply(lambda x : transString(x,1))
#df_arabic_count_translate_merge

# %%
df_arabic_count_translate_merge["buckwalter"] = df_arabic_count_translate_merge.loc[:,"arabic"].apply(lambda x : transString(x,0))
df_arabic_count_translate_merge["buckwalter_simple"] = df_arabic_count_translate_merge.loc[:,"buckwalter"].apply(lambda x : clean_ex(x))# Convert Arabic Simple
df_arabic_count_translate_merge["arabic_simple"] = df_arabic_count_translate_merge.loc[:,"buckwalter_simple"].apply(lambda x : transString(x,1))
df_arabic_count_translate_merge.drop(["buckwalter","buckwalter_simple"], axis=1, inplace=True)
df_arabic_count_translate_merge = df_arabic_count_translate_merge.iloc[:,[0,10,1,2,3,4,5,6,7,8,9]]
df_arabic_count_translate_merge
# Out:
#               arabic arabic_simple  arabic_frequency transliterate  \
# 0                فِي            في              1096            fi
# 1                فِي            في              1096            fi
# 2                فِي            في              1096            fi
# 3                فِي            في              1096            fi
# 4                فِي            في              1096            fi
# ...              ...           ...               ...           ...
# 69905       ٱلۡجُبِّ         ٱلۡجب                 1       al-jubi
# 69906   يَلۡتَقِطۡهُ      يلۡتقطۡه                 1   yaltaqit'hu
# 69907  ٱلسَّيَّارَةِ       ٱلسيارة                 1   al-sayarati
# 69908    تَأۡمَ۬نَّا        تأۡمنا                 1       tamanna
# 69909     يُوَسۡوِسُ        يوسۡوس                 1     yuwaswisu
#
#       translate_english                    translate_urdu  \
# 0                    In                               میں
# 1                    in                               میں
# 2                    in                             ان کی
# 3                    in                               میں
# 4                    in                               میں
# ...                 ...                               ...
# 69905     (of) the well  کنوئیں میں۔ کنوئیں کی گہرائی میں
# 69906     will pick him                  اٹھا لے گا اس کو
# 69907     [the] caravan                             قافلہ
# 69908          trust us                 آپ بھروسہ کرتے ہم
# 69909          whispers                    وسوسہ ڈالتا ہے
#
#                 translate_hindi       translate_indonesian  \
# 0                             *                   di dalam
# 1                             *                         di
# 2                             *                      dalam
# 3                             *                      dalam
# 4                             *                      dalam
# ...                         ...                        ...
# 69905                   कुएँ की                      sumur
# 69906              उठा लेगा उसे                 menemuinya
# 69907                  क़ाफ़िला  orang-orang yang berjalan
# 69908  नहीं आप भरोसा करते हम पर      kamu mempercayai kami
# 69909           वसवसा डालता है            membisik-bisikan
#
#           translate_bangla   translate_turkish translate_russian
# 0                মধ্যে আছে  onların kablerinde                 В
# 1                    মধ্যে          yeryüzünde                на
# 2                    মধ্যে              içinde                 в
# 3                    মধ্যে              içinde                во
# 4                    মধ্যে              içinde                 в
# ...                    ...                 ...               ...
# 69905                কূপের             kuyunun         колодца,–
# 69906       তাকে তুলে নিবে   onu (görüp) alsın      подберёт его
# 69907         পথযাত্রীদলের        kervanlardan          караван,
# 69908  আমাদের বিশ্বাস করেন                   *  доверяешь ты нам
# 69909      কুমন্ত্রণা দেয়            fısıldar           наущает
#
# [69910 rows x 11 columns]

# %%
df_select_english = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency","transliterate"]).apply(lambda x: x['translate_english'].value_counts(ascending=False).index[0]))
df_select_english.rename(columns={0:"translate_english"}, inplace=True)
df_select_english.reset_index(inplace=True)
df_select_english.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_english.reset_index(drop=True, inplace=True)
df_select_english
# Out:
#             arabic arabic_simple  arabic_frequency transliterate  \
# 0              فِي            في              1096            fi
# 1        ٱلَّذِينَ         ٱلذين               810     alladhina
# 2              مِن            من               728           min
# 3              مَا            ما               709            ma
# 4          ٱللَّهِ          ٱلله               667       al-lahi
# ...            ...           ...               ...           ...
# 21306        فَذُو           فذو                 1         fadhu
# 21307   فَذُوقُوهُ        فذوقوه                 1     fadhuquhu
# 21308   فَرَأَوۡهُ        فرأوۡه                 1     fara-awhu
# 21309  فَرَبُّكُمۡ        فربكمۡ                 1    farabbukum
# 21310    لَعَلِيٌّ          لعلي                 1    la'aliyyun
#
#        translate_english
# 0                     in
# 1              those who
# 2                   from
# 3                   what
# 4                  Allah
# ...                  ...
# 21306  then (he is) full
# 21307        So taste it
# 21308    and they see it
# 21309      but your Lord
# 21310     surely exalted
#
# [21311 rows x 5 columns]

# %%
df_select_urdu = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency","transliterate"]).apply(lambda x: x['translate_urdu'].value_counts(ascending=False).index[0]))
df_select_urdu.rename(columns={0:"translate_urdu"}, inplace=True)
df_select_urdu.reset_index(inplace=True)
df_select_urdu.reset_index(drop=True, inplace=True)
df_select_urdu
# Out:
#                 arabic arabic_simple  arabic_frequency transliterate  \
# 0          ءَأَتَّخِذُ         ءأتخذ                 1  a-attakhidhu
# 1          ءَأَرۡبَابٞ      ءأرۡبابٞ                 1     a-arbabun
# 2           ءَأَسۡجُدُ        ءأسۡجد                 1      a-asjudu
# 3      ءَأَسۡلَمۡتُمۡۚ   ءأسۡلمۡتمۡۚ                 1    a-aslamtum
# 4       ءَأَشۡفَقۡتُمۡ    ءأشۡفقۡتمۡ                 1   a-ashfaqtum
# ...                ...           ...               ...           ...
# 21306   ۞يَـٰٓأَيُّهَا       ۞يـأيها                 8      yaayyuha
# 21307          ۞يَوۡمَ         ۞يوۡم                 2         yawma
# 21308       ۞يَٰبَنِيٓ         ۞يبني                 1        yabani
# 21309      ۞ٱحۡشُرُواْ      ۞ٱحۡشروا                 1      uh'shuru
# 21310         ۞ٱللَّهُ         ۞ٱلله                 3       al-lahu
#
#                         translate_urdu
# 0                       کیا میں بنالوں
# 1                        کیا بہت سے رب
# 2                    کیا میں سجدہ کروں
# 3      اسلام لائے تم۔ سپرد کردیا تم نے
# 4                        کیا ڈر گئے تم
# ...                                ...
# 21306                               اے
# 21307                            جس دن
# 21308                           اے بنی
# 21309                         گھیر لاؤ
# 21310                             اللہ
#
# [21311 rows x 5 columns]

# %%
df_select_hindi = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency","transliterate"]).apply(lambda x: x['translate_hindi'].value_counts(ascending=False).index[0]))
df_select_hindi.rename(columns={0:"translate_hindi"}, inplace=True)
df_select_hindi.reset_index(inplace=True)
df_select_hindi.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_hindi.reset_index(drop=True, inplace=True)
df_select_hindi
# Out:
#             arabic arabic_simple  arabic_frequency transliterate  \
# 0              فِي            في              1096            fi
# 1        ٱلَّذِينَ         ٱلذين               810     alladhina
# 2              مِن            من               728           min
# 3              مَا            ما               709            ma
# 4          ٱللَّهِ          ٱلله               667       al-lahi
# ...            ...           ...               ...           ...
# 21306        فَذُو           فذو                 1         fadhu
# 21307   فَذُوقُوهُ        فذوقوه                 1     fadhuquhu
# 21308   فَرَأَوۡهُ        فرأوۡه                 1     fara-awhu
# 21309  فَرَبُّكُمۡ        فربكمۡ                 1    farabbukum
# 21310    لَعَلِيٌّ          لعلي                 1    la'aliyyun
#
#                   translate_hindi
# 0                               *
# 1                           वो जो
# 2                               *
# 3                              जो
# 4                       अल्लाह के
# ...                           ...
# 21306                           *
# 21307                 पस चख़ो इसे
# 21308  फिर वो देखें उस (खेती) को
# 21309              तो रब तुम्हारा
# 21310      अलबत्ता बहुत बुलन्द है
#
# [21311 rows x 5 columns]

# %%
df_select_indonesian = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency","transliterate"]).apply(lambda x: x['translate_indonesian'].value_counts(ascending=False).index[0]))
df_select_indonesian.rename(columns={0:"translate_indonesian"}, inplace=True)
df_select_indonesian.reset_index(inplace=True)
df_select_indonesian.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_indonesian.reset_index(drop=True, inplace=True)
df_select_indonesian
# Out:
#             arabic arabic_simple  arabic_frequency transliterate  \
# 0              فِي            في              1096            fi
# 1        ٱلَّذِينَ         ٱلذين               810     alladhina
# 2              مِن            من               728           min
# 3              مَا            ما               709            ma
# 4          ٱللَّهِ          ٱلله               667       al-lahi
# ...            ...           ...               ...           ...
# 21306        فَذُو           فذو                 1         fadhu
# 21307   فَذُوقُوهُ        فذوقوه                 1     fadhuquhu
# 21308   فَرَأَوۡهُ        فرأوۡه                 1     fara-awhu
# 21309  فَرَبُّكُمۡ        فربكمۡ                 1    farabbukum
# 21310    لَعَلِيٌّ          لعلي                 1    la'aliyyun
#
#          translate_indonesian
# 0                       dalam
# 1            orang-orang yang
# 2                        dari
# 3                         apa
# 4                       Allah
# ...                       ...
# 21306       maka ia mempunyai
# 21307      maka rasakanlah ia
# 21308  maka mereka melihatnya
# 21309            maka Tuhanmu
# 21310      benar-benar tinggi
#
# [21311 rows x 5 columns]

# %%
df_select_bangla = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency","transliterate"]).apply(lambda x: x['translate_bangla'].value_counts(ascending=False).index[0]))
df_select_bangla.rename(columns={0:"translate_bangla"}, inplace=True)
df_select_bangla.reset_index(inplace=True)
df_select_bangla.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_bangla.reset_index(drop=True, inplace=True)
df_select_bangla
# Out:
#             arabic arabic_simple  arabic_frequency transliterate  \
# 0              فِي            في              1096            fi
# 1        ٱلَّذِينَ         ٱلذين               810     alladhina
# 2              مِن            من               728           min
# 3              مَا            ما               709            ma
# 4          ٱللَّهِ          ٱلله               667       al-lahi
# ...            ...           ...               ...           ...
# 21306        فَذُو           فذو                 1         fadhu
# 21307   فَذُوقُوهُ        فذوقوه                 1     fadhuquhu
# 21308   فَرَأَوۡهُ        فرأوۡه                 1     fara-awhu
# 21309  فَرَبُّكُمۡ        فربكمۡ                 1    farabbukum
# 21310    لَعَلِيٌّ          لعلي                 1    la'aliyyun
#
#                 translate_bangla
# 0                          মধ্যে
# 1                           যারা
# 2                           থেকে
# 3                             যা
# 4                        আল্লাহর
# ...                          ...
# 21306                        তখন
# 21307  "তাই তোমরা স্বাদ নাও তার"
# 21308           ফলে তারা দেখে তা
# 21309          অতঃপর তোমাদের রবই
# 21310         অতীব উচ্চ মর্যাদার
#
# [21311 rows x 5 columns]

# %%
df_select_turkish = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency","transliterate"]).apply(lambda x: x['translate_turkish'].value_counts(ascending=False).index[0]))
df_select_turkish.rename(columns={0:"translate_turkish"}, inplace=True)
df_select_turkish.reset_index(inplace=True)
df_select_turkish.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_turkish.reset_index(drop=True, inplace=True)
df_select_turkish
# Out:
#             arabic arabic_simple  arabic_frequency transliterate  \
# 0              فِي            في              1096            fi
# 1        ٱلَّذِينَ         ٱلذين               810     alladhina
# 2              مِن            من               728           min
# 3              مَا            ما               709            ma
# 4          ٱللَّهِ          ٱلله               667       al-lahi
# ...            ...           ...               ...           ...
# 21306        فَذُو           فذو                 1         fadhu
# 21307   فَذُوقُوهُ        فذوقوه                 1     fadhuquhu
# 21308   فَرَأَوۡهُ        فرأوۡه                 1     fara-awhu
# 21309  فَرَبُّكُمۡ        فربكمۡ                 1    farabbukum
# 21310    لَعَلِيٌّ          لعلي                 1    la'aliyyun
#
#          translate_turkish
# 0                   içinde
# 1                 kimseler
# 2                   hiçbir
# 3                  şeyleri
# 4                 Allah'ın
# ...                    ...
# 21306                hemen
# 21307      şimdi tadın onu
# 21308  ve (ekini) görseler
# 21309             Rabbiniz
# 21310      elbette yücedir
#
# [21311 rows x 5 columns]

# %%
df_select_russian = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency","transliterate"]).apply(lambda x: x['translate_russian'].value_counts(ascending=False).index[0]))
df_select_russian.rename(columns={0:"translate_russian"}, inplace=True)
df_select_russian.reset_index(inplace=True)
df_select_russian.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_russian.reset_index(drop=True, inplace=True)
df_select_russian
# Out:
#             arabic arabic_simple  arabic_frequency transliterate  \
# 0              فِي            في              1096            fi
# 1        ٱلَّذِينَ         ٱلذين               810     alladhina
# 2              مِن            من               728           min
# 3              مَا            ما               709            ma
# 4          ٱللَّهِ          ٱلله               667       al-lahi
# ...            ...           ...               ...           ...
# 21306        فَذُو           فذو                 1         fadhu
# 21307   فَذُوقُوهُ        فذوقوه                 1     fadhuquhu
# 21308   فَرَأَوۡهُ        فرأوۡه                 1     fara-awhu
# 21309  فَرَبُّكُمۡ        فربكمۡ                 1    farabbukum
# 21310    لَعَلِيٌّ          لعلي                 1    la'aliyyun
#
#                     translate_russian
# 0                                   в
# 1                        тех, которые
# 2                                  из
# 3                             то, что
# 4                              Аллаха
# ...                               ...
# 21306  то (становится он) обладателем
# 21307                  Вкусите же его
# 21308                и они увидят это
# 21309                   а Господь ваш
# 21310         однозначно, возвышенный
#
# [21311 rows x 5 columns]

# %%
dfs = [df_select_english,df_select_urdu,df_select_hindi,df_select_indonesian,df_select_bangla,df_select_turkish,df_select_russian]

# %%
df_select_translate_all = reduce(lambda  left,right: pd.merge(left,right, on=['arabic','arabic_simple','arabic_frequency','transliterate'], how='inner'), dfs)  # left,right make left to right merge
#df_select_translate_all = reduce(lambda  right,left: pd.merge(left,right, on=['word'], how='outer'), dfs)  # right,left make right to left merge
df_select_translate_all.drop_duplicates(inplace=True)
df_select_translate_all
# Out:
#             arabic arabic_simple  arabic_frequency transliterate  \
# 0              فِي            في              1096            fi
# 1        ٱلَّذِينَ         ٱلذين               810     alladhina
# 2              مِن            من               728           min
# 3              مَا            ما               709            ma
# 4          ٱللَّهِ          ٱلله               667       al-lahi
# ...            ...           ...               ...           ...
# 21306        فَذُو           فذو                 1         fadhu
# 21307   فَذُوقُوهُ        فذوقوه                 1     fadhuquhu
# 21308   فَرَأَوۡهُ        فرأوۡه                 1     fara-awhu
# 21309  فَرَبُّكُمۡ        فربكمۡ                 1    farabbukum
# 21310    لَعَلِيٌّ          لعلي                 1    la'aliyyun
#
#        translate_english        translate_urdu             translate_hindi  \
# 0                     in                   میں                           *
# 1              those who                وہ لوگ                       वो जो
# 2                   from                    سے                           *
# 3                   what                    جو                          जो
# 4                  Allah               اللہ کے                   अल्लाह के
# ...                  ...                   ...                         ...
# 21306  then (he is) full  تو کرنے والا ہوتا ہے                           *
# 21307        So taste it         پس چکھو اس کو                 पस चख़ो इसे
# 21308    and they see it   پھر وہ دیکھیں اس کو  फिर वो देखें उस (खेती) को
# 21309      but your Lord          تو رب تمہارا              तो रब तुम्हारा
# 21310     surely exalted        البتہ بلند ہے،      अलबत्ता बहुत बुलन्द है
#
#          translate_indonesian           translate_bangla    translate_turkish  \
# 0                       dalam                      মধ্যে               içinde
# 1            orang-orang yang                       যারা             kimseler
# 2                        dari                       থেকে               hiçbir
# 3                         apa                         যা              şeyleri
# 4                       Allah                    আল্লাহর             Allah'ın
# ...                       ...                        ...                  ...
# 21306       maka ia mempunyai                        তখন                hemen
# 21307      maka rasakanlah ia  "তাই তোমরা স্বাদ নাও তার"      şimdi tadın onu
# 21308  maka mereka melihatnya           ফলে তারা দেখে তা  ve (ekini) görseler
# 21309            maka Tuhanmu          অতঃপর তোমাদের রবই             Rabbiniz
# 21310      benar-benar tinggi         অতীব উচ্চ মর্যাদার      elbette yücedir
#
#                     translate_russian
# 0                                   в
# 1                        тех, которые
# 2                                  из
# 3                             то, что
# 4                              Аллаха
# ...                               ...
# 21306  то (становится он) обладателем
# 21307                  Вкусите же его
# 21308                и они увидят это
# 21309                   а Господь ваш
# 21310         однозначно, возвышенный
#
# [21311 rows x 11 columns]

# %%
#df_arabic_count_translate_merge.to_excel("Quran_Arabic_Word_Translate_Selected2.xlsx", index=False)

# %% [markdown]
# #### Arabic Root With Related Arabic Word

# %%
df_master = pd.read_excel("")  # read master file
