# %% [markdown]
# ### Flash Cards Data Analysis

# %%
import pandas as pd
import numpy as np
import re
from functools import reduce
from camel_tools.utils.charmap import CharMapper
from lang_trans.arabic import buckwalter
from pathlib import Path
import shutil

# %%
path = f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Flash Cards/Result"

Path(path).mkdir(parents=True, exist_ok=True)

# %%
# buckwalter text clean for simple before transString
def clean_ex(text):
    buckwalter_out = re.sub(r'''([PJVG\.:;,!\+\^\]\[@#FNKauio`~"%-])''', "", text) # difference from clean
    return buckwalter_out

# %%
# Arabic Encoding Extended
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2uni = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "}": u"\u0626", # hamza-on-yaa'
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "F": u"\u064B", # fatHatayn
            "N": u"\u064C", # Dammatayn
            "K": u"\u064D", # kasratayn
            "a": u"\u064E", # fatHa
            "u": u"\u064F", # Damma
            "i": u"\u0650", # kasra
            "~": u"\u0651", # shaddah
            "o": u"\u0652", # sukuun
            "^": u"\u0653", # maddah
            "#": u"\u0654", # hamzaabove            
            "`": u"\u0670", # dagger 'alif
            "{": u"\u0671", # waSla
            "P": u"\u067E", # arabicletterpeh
            "J": u"\u0686", 
            "V": u"\u06A4", # arabicletterveh
            "G": u"\u06AF", # arabiclettergaf
            ":": u"\u06DC", # smallhighseen
            "@": u"\u06DF", # smallhighroundedzero
            "\"": u"\u06E0", # smallhighuprightrectangularzero
            "[": u"\u06E2", # smallhighmeemisolatedform
            ";": u"\u06E3", # smalllowseen
            ",": u"\u06E5", # smallwaw
            ".": u"\u06E6", # smallya
            "!": u"\u06E8", # smallhighnoon
            "-": u"\u06EA", # emptycentrelowstop
            "+": u"\u06EB", # emptycentrehighstop
            "%": u"\u06EC", # roundedhighstopwithfilledcentre
            "]": u"\u06ED", # smalllowmeem           
}

def transString(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2uni.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
# Simple Technique
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2unisimple = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "{": u"\u0671", # waSla         
}

def transStringSimple(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2unisimple.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
# character clean for simple after transStringSimple 
def clean(text):
    arabic_out = re.sub(r'''([PJVG\.:;,!\+\]\[@#FNKauio`~"%-])''', "", text) # .$^*+
    arabic_out2 = re.sub(r"\^", " ", arabic_out)
    return arabic_out2

# %% [markdown]
# #### Quaran Word Translate Select

# %%
#df_arabic_translate = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Flash Cards/Data/All_Surah_Translate_File_Concat.xlsx")  # with asterisk
#df_arabic_translate  # it needs transString(x,0), clean_ex(text), transString(x,1) funcs

# %%
df_quaran_master = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Flash Cards/Data/Master 17052022.xlsx")
df_all_word_translate = df_quaran_master.loc[:,["surah","surah latin","tanzil_clean","tanzil_plain","arabic","translate_english","translate_urdu","translate_hindi","translate_indonesian","translate_bangla","translate_turkish","translate_russian"]]
df_all_word_translate
# Out:
#        surah surah latin tanzil_clean  tanzil_plain        arabic  \
# 0          1   Al-Fatiha          بسم        بِسْمِ        بِسۡمِ
# 1          1   Al-Fatiha         الله       اللَّهِ       ٱللَّهِ
# 2          1   Al-Fatiha       الرحمن  الرَّحْمَٰنِ  ٱلرَّحۡمَٰنِ
# 3          1   Al-Fatiha       الرحيم    الرَّحِيمِ    ٱلرَّحِيمِ
# 4          1   Al-Fatiha        الحمد     الْحَمْدُ     ٱلۡحَمۡدُ
# ...      ...         ...          ...           ...           ...
# 78242    114      An-Nas         صدور       صُدُورِ       صُدُورِ
# 78243    114      An-Nas        الناس      النَّاسِ      ٱلنَّاسِ
# 78244    114      An-Nas           من          مِنَ          مِنَ
# 78245    114      An-Nas        الجنة    الْجِنَّةِ    ٱلۡجِنَّةِ
# 78246    114      An-Nas       والناس    وَالنَّاسِ    وَٱلنَّاسِ
#
#             translate_english              translate_urdu  \
# 0               In (the) name                    ساتھ نام
# 1                  (of) Allah                     اللہ کے
# 2           the Most Gracious          جو بے حد مہربان ہے
# 3           the Most Merciful  بار بار رحم فرمانے والا ہے
# 4      All praises and thanks                    سب تعریف
# ...                       ...                         ...
# 78242           (the) breasts                       سینوں
# 78243            (of) mankind                  انسانوں کے
# 78244                    From                          سے
# 78245                the jinn                    جنوں میں
# 78246                 and men             اور انسانوں میں
#
#                translate_hindi translate_indonesian translate_bangla  \
# 0                     साथ नाम           dengan nama             নামে
# 1                    अल्लाह के                Allah       আল্লাহ (র)
# 2             जो बहुत मेहरबान         Maha Pengasih      পরম করুণাময়
# 3      निहायत रहम करने वाला है       Maha Penyayang       অসীম দয়ালু
# 4                    सब तारीफ़               pujian      সকল প্রশংসা
# ...                        ...                  ...              ...
# 78242                सीनों में                 dada      অন্তরসমূহের
# 78243                लोगों के               manusia          মানুষের
# 78244          जिन्नों में से                  dari         মধ্য হতে
# 78245          जिन्नों में से                   jin            জিনের
# 78246       और इन्सानों में से          dan manusia        ও মানুষের
#
#        translate_turkish    translate_russian
# 0                 adıyla             С именем
# 1               Allah'ın              Аллаха,
# 2                 Rahman         Милостивого,
# 3                  Rahim        Милосердного!
# 4              hamdolsun                Хвала
# ...                  ...                  ...
# 78242        göğüslerine               грудях
# 78243         insanların               людей,
# 78244          cinlerden  (будучи) из (числа)
# 78245          cinlerden              джиннов
# 78246  ve insanlar(dan);            и людей».
#
# [78247 rows x 12 columns]

# %%
df_all_word_translate = df_all_word_translate[~df_all_word_translate["arabic"].isnull()]
df_all_word_translate
# Out:
#        surah surah latin tanzil_clean  tanzil_plain        arabic  \
# 0          1   Al-Fatiha          بسم        بِسْمِ        بِسۡمِ
# 1          1   Al-Fatiha         الله       اللَّهِ       ٱللَّهِ
# 2          1   Al-Fatiha       الرحمن  الرَّحْمَٰنِ  ٱلرَّحۡمَٰنِ
# 3          1   Al-Fatiha       الرحيم    الرَّحِيمِ    ٱلرَّحِيمِ
# 4          1   Al-Fatiha        الحمد     الْحَمْدُ     ٱلۡحَمۡدُ
# ...      ...         ...          ...           ...           ...
# 78242    114      An-Nas         صدور       صُدُورِ       صُدُورِ
# 78243    114      An-Nas        الناس      النَّاسِ      ٱلنَّاسِ
# 78244    114      An-Nas           من          مِنَ          مِنَ
# 78245    114      An-Nas        الجنة    الْجِنَّةِ    ٱلۡجِنَّةِ
# 78246    114      An-Nas       والناس    وَالنَّاسِ    وَٱلنَّاسِ
#
#             translate_english              translate_urdu  \
# 0               In (the) name                    ساتھ نام
# 1                  (of) Allah                     اللہ کے
# 2           the Most Gracious          جو بے حد مہربان ہے
# 3           the Most Merciful  بار بار رحم فرمانے والا ہے
# 4      All praises and thanks                    سب تعریف
# ...                       ...                         ...
# 78242           (the) breasts                       سینوں
# 78243            (of) mankind                  انسانوں کے
# 78244                    From                          سے
# 78245                the jinn                    جنوں میں
# 78246                 and men             اور انسانوں میں
#
#                translate_hindi translate_indonesian translate_bangla  \
# 0                     साथ नाम           dengan nama             নামে
# 1                    अल्लाह के                Allah       আল্লাহ (র)
# 2             जो बहुत मेहरबान         Maha Pengasih      পরম করুণাময়
# 3      निहायत रहम करने वाला है       Maha Penyayang       অসীম দয়ালু
# 4                    सब तारीफ़               pujian      সকল প্রশংসা
# ...                        ...                  ...              ...
# 78242                सीनों में                 dada      অন্তরসমূহের
# 78243                लोगों के               manusia          মানুষের
# 78244          जिन्नों में से                  dari         মধ্য হতে
# 78245          जिन्नों में से                   jin            জিনের
# 78246       और इन्सानों में से          dan manusia        ও মানুষের
#
#        translate_turkish    translate_russian
# 0                 adıyla             С именем
# 1               Allah'ın              Аллаха,
# 2                 Rahman         Милостивого,
# 3                  Rahim        Милосердного!
# 4              hamdolsun                Хвала
# ...                  ...                  ...
# 78242        göğüslerine               грудях
# 78243         insanların               людей,
# 78244          cinlerden  (будучи) из (числа)
# 78245          cinlerden              джиннов
# 78246  ve insanlar(dan);            и людей».
#
# [77799 rows x 12 columns]

# %%
df_all_word_translate.drop("arabic", axis=1, inplace=True)
df_all_word_translate.rename(columns={"tanzil_plain":"arabic","tanzil_clean":"arabic_simple"}, inplace=True)
df_all_word_translate
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#        surah surah latin arabic_simple        arabic       translate_english  \
# 0          1   Al-Fatiha           بسم        بِسْمِ           In (the) name
# 1          1   Al-Fatiha          الله       اللَّهِ              (of) Allah
# 2          1   Al-Fatiha        الرحمن  الرَّحْمَٰنِ       the Most Gracious
# 3          1   Al-Fatiha        الرحيم    الرَّحِيمِ       the Most Merciful
# 4          1   Al-Fatiha         الحمد     الْحَمْدُ  All praises and thanks
# ...      ...         ...           ...           ...                     ...
# 78242    114      An-Nas          صدور       صُدُورِ           (the) breasts
# 78243    114      An-Nas         الناس      النَّاسِ            (of) mankind
# 78244    114      An-Nas            من          مِنَ                    From
# 78245    114      An-Nas         الجنة    الْجِنَّةِ                the jinn
# 78246    114      An-Nas        والناس    وَالنَّاسِ                 and men
#
#                    translate_urdu          translate_hindi  \
# 0                        ساتھ نام                 साथ नाम
# 1                         اللہ کے                अल्लाह के
# 2              جو بے حد مہربان ہے         जो बहुत मेहरबान
# 3      بار بار رحم فرمانے والا ہے  निहायत रहम करने वाला है
# 4                        سب تعریف                सब तारीफ़
# ...                           ...                      ...
# 78242                       سینوں                सीनों में
# 78243                  انسانوں کے                लोगों के
# 78244                          سے          जिन्नों में से
# 78245                    جنوں میں          जिन्नों में से
# 78246             اور انسانوں میں       और इन्सानों में से
#
#       translate_indonesian translate_bangla  translate_turkish  \
# 0              dengan nama             নামে             adıyla
# 1                    Allah       আল্লাহ (র)           Allah'ın
# 2            Maha Pengasih      পরম করুণাময়             Rahman
# 3           Maha Penyayang       অসীম দয়ালু              Rahim
# 4                   pujian      সকল প্রশংসা          hamdolsun
# ...                    ...              ...                ...
# 78242                 dada      অন্তরসমূহের        göğüslerine
# 78243              manusia          মানুষের         insanların
# 78244                 dari         মধ্য হতে          cinlerden
# 78245                  jin            জিনের          cinlerden
# 78246          dan manusia        ও মানুষের  ve insanlar(dan);
#
#          translate_russian
# 0                 С именем
# 1                  Аллаха,
# 2             Милостивого,
# 3            Милосердного!
# 4                    Хвала
# ...                    ...
# 78242               грудях
# 78243               людей,
# 78244  (будучи) из (числа)
# 78245              джиннов
# 78246            и людей».
#
# [77799 rows x 11 columns]

# %%
df_arabic_word_count = df_all_word_translate["arabic"].value_counts(ascending=False).reset_index()
df_arabic_word_count.rename(columns={"index":"arabic","arabic":"arabic_frequency"}, inplace=True)
#df_arabic_word_count = df_arabic_word_count.head(300)
df_arabic_word_count
# Out:
#            arabic  arabic_frequency
# 0            مِنْ              1673
# 1             فِي              1185
# 2             مَا              1013
# 3         اللَّهِ               828
# 4             لَا               812
# ...           ...               ...
# 17611  بِصَوْتِكَ                 1
# 17612  وَأَجْلِبْ                 1
# 17613  بِخَيْلِكَ                 1
# 17614  وَرَجِلِكَ                 1
# 17615  يُوَسْوِسُ                 1
#
# [17616 rows x 2 columns]

# %%
df_word_translate_select = df_all_word_translate.iloc[:,[2,3,4,5,6,7,8,9,10]]
df_word_translate_select.drop_duplicates(inplace=True)
df_word_translate_select
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#       arabic_simple        arabic       translate_english  \
# 0               بسم        بِسْمِ           In (the) name
# 1              الله       اللَّهِ              (of) Allah
# 2            الرحمن  الرَّحْمَٰنِ       the Most Gracious
# 3            الرحيم    الرَّحِيمِ       the Most Merciful
# 4             الحمد     الْحَمْدُ  All praises and thanks
# ...             ...           ...                     ...
# 78242          صدور       صُدُورِ           (the) breasts
# 78243         الناس      النَّاسِ            (of) mankind
# 78244            من          مِنَ                    From
# 78245         الجنة    الْجِنَّةِ                the jinn
# 78246        والناس    وَالنَّاسِ                 and men
#
#                    translate_urdu          translate_hindi  \
# 0                        ساتھ نام                 साथ नाम
# 1                         اللہ کے                अल्लाह के
# 2              جو بے حد مہربان ہے         जो बहुत मेहरबान
# 3      بار بار رحم فرمانے والا ہے  निहायत रहम करने वाला है
# 4                        سب تعریف                सब तारीफ़
# ...                           ...                      ...
# 78242                       سینوں                सीनों में
# 78243                  انسانوں کے                लोगों के
# 78244                          سے          जिन्नों में से
# 78245                    جنوں میں          जिन्नों में से
# 78246             اور انسانوں میں       और इन्सानों में से
#
#       translate_indonesian translate_bangla  translate_turkish  \
# 0              dengan nama             নামে             adıyla
# 1                    Allah       আল্লাহ (র)           Allah'ın
# 2            Maha Pengasih      পরম করুণাময়             Rahman
# 3           Maha Penyayang       অসীম দয়ালু              Rahim
# 4                   pujian      সকল প্রশংসা          hamdolsun
# ...                    ...              ...                ...
# 78242                 dada      অন্তরসমূহের        göğüslerine
# 78243              manusia          মানুষের         insanların
# 78244                 dari         মধ্য হতে          cinlerden
# 78245                  jin            জিনের          cinlerden
# 78246          dan manusia        ও মানুষের  ve insanlar(dan);
#
#          translate_russian
# 0                 С именем
# 1                  Аллаха,
# 2             Милостивого,
# 3            Милосердного!
# 4                    Хвала
# ...                    ...
# 78242               грудях
# 78243               людей,
# 78244  (будучи) из (числа)
# 78245              джиннов
# 78246            и людей».
#
# [70092 rows x 9 columns]

# %%
df_arabic_count_translate_merge = pd.merge(df_arabic_word_count, df_word_translate_select, how="left", on="arabic")
df_arabic_count_translate_merge.drop_duplicates(inplace=True)
df_arabic_count_translate_merge
# Out:
#            arabic  arabic_frequency arabic_simple  translate_english  \
# 0            مِنْ              1673            من               from
# 1            مِنْ              1673            من               from
# 2            مِنْ              1673            من               from
# 3            مِنْ              1673            من               [of]
# 4            مِنْ              1673            من               from
# ...           ...               ...           ...                ...
# 70087  بِصَوْتِكَ                 1         بصوتك    with your voice
# 70088  وَأَجْلِبْ                 1         وأجلب        and assault
# 70089  بِخَيْلِكَ                 1         بخيلك  with your cavalry
# 70090  وَرَجِلِكَ                 1         ورجلك       and infantry
# 70091  يُوَسْوِسُ                 1         يوسوس           whispers
#
#           translate_urdu     translate_hindi  \
# 0                     سے           आपसे पहले
# 1                     سے  अपने रब की तरफ़ से
# 2                     سے       तुमसे पहले थे
# 3                     اس             इस जैसी
# 4                     سے               सिवाय
# ...                  ...                 ...
# 70087  اپنی آواز کے ساتھ   साथ अपनी आवाज़ के
# 70088        اور چڑھا لا          और चढ़ा ला
# 70089          سوار اپنے           सवार अपने
# 70090     اور پیادے اپنے      और प्यादे अपने
# 70091     وسوسہ ڈالتا ہے     वसवसा डालता है
#
#                    translate_indonesian             translate_bangla  \
# 0                                  dari                         থেকে
# 1                                  dari                     পক্ষ হতে
# 2                                  dari                         থেকে
# 3                                  dari                     মধ্য হতে
# 4                                  dari                         দিয়ে
# ...                                 ...                          ...
# 70087                    dengan suaramu          দিয়ে তোমার কন্ঠস্বর
# 70088                   dan kerahkanlah                    ও চড়াও হও
# 70089             dengan pasukan kudamu  নিয়ে তোমার অশ্বারোহী বাহিনী
# 70090  dan pasukanmu yang berjalan kaki        ও তোমার পদাতিক বাহিনী
# 70091                  membisik-bisikan              কুমন্ত্রণা দেয়
#
#        translate_turkish translate_russian
# 0            senden önce           до тебя
# 1            Rablerinden                от
# 2      sizden öncekileri            до вас
# 3              onun gibi                из
# 4               başkadan            помимо
# ...                  ...               ...
# 70087            sesinle     своим голосом
# 70088   ve yaygarayı bas         и собирай
# 70089        atlılarınla      твою конницу
# 70090     ve yayalarınla    и пехоту твою,
# 70091           fısıldar           наущает
#
# [70092 rows x 10 columns]

# %%
#df_arabic_count_translate_merge.to_excel("Quran_Arabic_Word_Translate_Selected.xlsx", index=False)

# %%
#df_arabic_count_translate_merge["buckwalter"] = df_arabic_count_translate_merge.loc[:,"arabic"].apply(lambda x : transString(x,0))
#df_arabic_count_translate_merge

# %%
#df_arabic_count_translate_merge["buckwalter_simple"] = df_arabic_count_translate_merge.loc[:,"buckwalter"].apply(lambda x : clean_ex(x))
#df_arabic_count_translate_merge

# %%
#df_arabic_count_translate_merge["arabic_simple"] = df_arabic_count_translate_merge.loc[:,"buckwalter_simple"].apply(lambda x : transString(x,1))
#df_arabic_count_translate_merge

# %%
## It is for first file
#df_arabic_count_translate_merge["buckwalter"] = df_arabic_count_translate_merge.loc[:,"arabic"].apply(lambda x : transString(x,0))
#df_arabic_count_translate_merge["buckwalter_simple"] = df_arabic_count_translate_merge.loc[:,"buckwalter"].apply(lambda x : clean_ex(x))# Convert Arabic Simple
#df_arabic_count_translate_merge["arabic_simple"] = df_arabic_count_translate_merge.loc[:,"buckwalter_simple"].apply(lambda x : transString(x,1))
#df_arabic_count_translate_merge.drop(["buckwalter","buckwalter_simple"], axis=1, inplace=True)
#df_arabic_count_translate_merge = df_arabic_count_translate_merge.iloc[:,[0,10,1,2,3,4,5,6,7,8,9]]
#df_arabic_count_translate_merge

# %%
df_select_english = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_english'].value_counts(ascending=False).index[0]))
df_select_english.rename(columns={0:"translate_english"}, inplace=True)
df_select_english.reset_index(inplace=True)
df_select_english.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_english.reset_index(drop=True, inplace=True)
df_select_english
# Out:
#             arabic arabic_simple  arabic_frequency      translate_english
# 0             مِنْ            من              1673                   from
# 1              فِي            في              1185                     in
# 2              مَا            ما              1013                   what
# 3          اللَّهِ          الله               828                  Allah
# 4              لَا            لا               812                    not
# ...            ...           ...               ...                    ...
# 17611      شَاعِرٍ          شاعر                 1           (of) a poet;
# 17612   شَافِعِينَ        شافعين                 1           intercessors
# 17613      شَاكِرٌ          شاكر                 1  (is) All-Appreciative
# 17614   شَاكِرُونَ        شاكرون                 1          (be) grateful
# 17615  يُوَلِّهِمْ         يولهم                 1          turns to them
#
# [17616 rows x 4 columns]

# %%
df_select_urdu = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_urdu'].value_counts(ascending=False).index[0]))
df_select_urdu.rename(columns={0:"translate_urdu"}, inplace=True)
df_select_urdu.reset_index(inplace=True)
df_select_urdu.reset_index(drop=True, inplace=True)
df_select_urdu
# Out:
#              arabic arabic_simple  arabic_frequency           translate_urdu
# 0        آبَاءَكُمْ        آباءكم                 3         اپنے باپ دادا کو
# 1         آبَاءَنَا        آباءنا                10       اپنے آباؤ اجداد کو
# 2        آبَاءَهُمُ        آباءهم                 1  ان کے آباؤ اجداد کے پاس
# 3        آبَاءَهُمْ        آباءهم                 3           ان کے باپوں کو
# 4            آبَاءِ          آباء                 1                    باپوں
# ...             ...           ...               ...                      ...
# 17611     يُوَفِّقِ          يوفق                 1       موافقت پیدا کرے گا
# 17612  يُوَفِّيهِمُ        يوفيهم                 1    پورا پورا دے گا ان کو
# 17613  يُوَلُّوكُمُ        يولوكم                 1     وہ پھیر دیں گے تم سے
# 17614    يُوَلُّونَ         يولون                 1             وہ پھیریں گے
# 17615   يُوَلِّهِمْ         يولهم                 1           پھیرے گا ان سے
#
# [17616 rows x 4 columns]

# %%
df_select_hindi = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_hindi'].value_counts(ascending=False).index[0]))
df_select_hindi.rename(columns={0:"translate_hindi"}, inplace=True)
df_select_hindi.reset_index(inplace=True)
df_select_hindi.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_hindi.reset_index(drop=True, inplace=True)
df_select_hindi
# Out:
#             arabic arabic_simple  arabic_frequency          translate_hindi
# 0             مِنْ            من              1673                इससे पहले
# 1              فِي            في              1185               ज़मीन में
# 2              مَا            ما              1013                       जो
# 3          اللَّهِ          الله               828                अल्लाह के
# 4              لَا            لا               812                     नहीं
# ...            ...           ...               ...                      ...
# 17611      شَاعِرٍ          شاعر                 1            किसी शायर का
# 17612   شَافِعِينَ        شافعين                 1  कोई सिफ़ारिशियों में से
# 17613      شَاكِرٌ          شاكر                 1              क़द्रदान है
# 17614   شَاكِرُونَ        شاكرون                 1          शुक्र गुज़ार हो
# 17615  يُوَلِّهِمْ         يولهم                 1              फेरेगा उनसे
#
# [17616 rows x 4 columns]

# %%
df_select_indonesian = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_indonesian'].value_counts(ascending=False).index[0]))
df_select_indonesian.rename(columns={0:"translate_indonesian"}, inplace=True)
df_select_indonesian.reset_index(inplace=True)
df_select_indonesian.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_indonesian.reset_index(drop=True, inplace=True)
df_select_indonesian
# Out:
#             arabic arabic_simple  arabic_frequency  \
# 0             مِنْ            من              1673
# 1              فِي            في              1185
# 2              مَا            ما              1013
# 3          اللَّهِ          الله               828
# 4              لَا            لا               812
# ...            ...           ...               ...
# 17611      شَاعِرٍ          شاعر                 1
# 17612   شَافِعِينَ        شافعين                 1
# 17613      شَاكِرٌ          شاكر                 1
# 17614   شَاكِرُونَ        شاكرون                 1
# 17615  يُوَلِّهِمْ         يولهم                 1
#
#                    translate_indonesian
# 0                                  dari
# 1                                 dalam
# 2                                   apa
# 3                                 Allah
# 4                                 tidak
# ...                                 ...
# 17611                   seorang penyair
# 17612                  pemberi syafa'at
# 17613                   Maha Mensyukuri
# 17614  orang-orang yang berterima kasih
# 17615             berpaling dari mereka
#
# [17616 rows x 4 columns]

# %%
df_select_bangla = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_bangla'].value_counts(ascending=False).index[0]))
df_select_bangla.rename(columns={0:"translate_bangla"}, inplace=True)
df_select_bangla.reset_index(inplace=True)
df_select_bangla.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_bangla.reset_index(drop=True, inplace=True)
df_select_bangla
# Out:
#             arabic arabic_simple  arabic_frequency    translate_bangla
# 0             مِنْ            من              1673                থেকে
# 1              فِي            في              1185               মধ্যে
# 2              مَا            ما              1013                  যা
# 3          اللَّهِ          الله               828             আল্লাহর
# 4              لَا            لا               812                  না
# ...            ...           ...               ...                 ...
# 17611      شَاعِرٍ          شاعر                 1                কবির
# 17612   شَافِعِينَ        شافعين                 1      সুপারিশকারীদের
# 17613      شَاكِرٌ          شاكر                 1  (তার) মূল্যদানকারী
# 17614   شَاكِرُونَ        شاكرون                 1          কৃতজ্ঞ হবে
# 17615  يُوَلِّهِمْ         يولهم                 1   দিকে ফিরাবে তাদের
#
# [17616 rows x 4 columns]

# %%
df_select_turkish = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_turkish'].value_counts(ascending=False).index[0]))
df_select_turkish.rename(columns={0:"translate_turkish"}, inplace=True)
df_select_turkish.reset_index(inplace=True)
df_select_turkish.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_turkish.reset_index(drop=True, inplace=True)
df_select_turkish
# Out:
#             arabic arabic_simple  arabic_frequency  translate_turkish
# 0             مِنْ            من              1673             hiçbir
# 1              فِي            في              1185             içinde
# 2              مَا            ما              1013            şeyleri
# 3          اللَّهِ          الله               828           Allah'ın
# 4              لَا            لا               812             yoktur
# ...            ...           ...               ...                ...
# 17611      شَاعِرٍ          شاعر                 1        bir şa'irin
# 17612   شَافِعِينَ        شافعين                 1   şefa'atçilerimiz
# 17613      شَاكِرٌ          شاكر                 1  karşılığını verir
# 17614   شَاكِرُونَ        شاكرون                 1     şükredenlerden
# 17615  يُوَلِّهِمْ         يولهم                 1     döner(kaçar)sa
#
# [17616 rows x 4 columns]

# %%
df_select_russian = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_russian'].value_counts(ascending=False).index[0]))
df_select_russian.rename(columns={0:"translate_russian"}, inplace=True)
df_select_russian.reset_index(inplace=True)
df_select_russian.sort_values(by="arabic_frequency", ascending=False, inplace=True)
df_select_russian.reset_index(drop=True, inplace=True)
df_select_russian
# Out:
#             arabic arabic_simple  arabic_frequency     translate_russian
# 0             مِنْ            من              1673                    из
# 1              فِي            في              1185                     в
# 2              مَا            ما              1013               то, что
# 3          اللَّهِ          الله               828                Аллаха
# 4              لَا            لا               812                    не
# ...            ...           ...               ...                   ...
# 17611      شَاعِرٍ          شاعر                 1  (какого-либо) поэта!
# 17612   شَافِعِينَ        شافعين                 1           заступников
# 17613      شَاكِرٌ          شاكر                 1          благодарный,
# 17614   شَاكِرُونَ        شاكرون                 1         благодарными?
# 17615  يُوَلِّهِمْ         يولهم                 1        повернёт к ним
#
# [17616 rows x 4 columns]

# %%
dfs = [df_select_english,df_select_urdu,df_select_hindi,df_select_indonesian,df_select_bangla,df_select_turkish,df_select_russian]

# %%
df_all_translate_merge = reduce(lambda  left,right: pd.merge(left,right, on=['arabic','arabic_simple','arabic_frequency'], how='inner'), dfs)  # left,right make left to right merge
#df_all_translate_merge = reduce(lambda  right,left: pd.merge(left,right, on=['word'], how='outer'), dfs)  # right,left make right to left merge
df_all_translate_merge.drop_duplicates(inplace=True)
df_all_translate_merge
# Out:
#             arabic arabic_simple  arabic_frequency      translate_english  \
# 0             مِنْ            من              1673                   from
# 1              فِي            في              1185                     in
# 2              مَا            ما              1013                   what
# 3          اللَّهِ          الله               828                  Allah
# 4              لَا            لا               812                    not
# ...            ...           ...               ...                    ...
# 17611      شَاعِرٍ          شاعر                 1           (of) a poet;
# 17612   شَافِعِينَ        شافعين                 1           intercessors
# 17613      شَاكِرٌ          شاكر                 1  (is) All-Appreciative
# 17614   شَاكِرُونَ        شاكرون                 1          (be) grateful
# 17615  يُوَلِّهِمْ         يولهم                 1          turns to them
#
#        translate_urdu          translate_hindi  \
# 0                  سے                इससे पहले
# 1                 میں               ज़मीन में
# 2                  جو                       जो
# 3             اللہ کے                अल्लाह के
# 4                نہیں                     नहीं
# ...               ...                      ...
# 17611         شاعر کا            किसी शायर का
# 17612        سفارشیوں  कोई सिफ़ारिशियों में से
# 17613      قدر دان ہے              क़द्रदान है
# 17614     شکر گزار ہو          शुक्र गुज़ार हो
# 17615  پھیرے گا ان سے              फेरेगा उनसे
#
#                    translate_indonesian    translate_bangla  \
# 0                                  dari                থেকে
# 1                                 dalam               মধ্যে
# 2                                   apa                  যা
# 3                                 Allah             আল্লাহর
# 4                                 tidak                  না
# ...                                 ...                 ...
# 17611                   seorang penyair                কবির
# 17612                  pemberi syafa'at      সুপারিশকারীদের
# 17613                   Maha Mensyukuri  (তার) মূল্যদানকারী
# 17614  orang-orang yang berterima kasih          কৃতজ্ঞ হবে
# 17615             berpaling dari mereka   দিকে ফিরাবে তাদের
#
#        translate_turkish     translate_russian
# 0                 hiçbir                    из
# 1                 içinde                     в
# 2                şeyleri               то, что
# 3               Allah'ın                Аллаха
# 4                 yoktur                    не
# ...                  ...                   ...
# 17611        bir şa'irin  (какого-либо) поэта!
# 17612   şefa'atçilerimiz           заступников
# 17613  karşılığını verir          благодарный,
# 17614     şükredenlerden         благодарными?
# 17615     döner(kaçar)sa        повернёт к ним
#
# [17616 rows x 10 columns]

# %%
df_all_translate_merge.to_excel("Quran_Word_Translate_All.xlsx", index=False)

# %% [markdown]
# #### Quaran Root With Related Arabic Word

# %%
df_all_translate_merge

# %%
df_master_root_data = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Flash Cards/Data/Master 17052022.xlsx")
df_master_root_data = df_master_root_data.loc[:,["surah","ayah","word rank","surah latin","tanzil_clean","tanzil_plain","root_arabic","root"]]
df_master_root_data
# Out:
#        surah  ayah  word rank surah latin tanzil_clean  tanzil_plain  \
# 0          1     1          1   Al-Fatiha          بسم        بِسْمِ
# 1          1     1          2   Al-Fatiha         الله       اللَّهِ
# 2          1     1          3   Al-Fatiha       الرحمن  الرَّحْمَٰنِ
# 3          1     1          4   Al-Fatiha       الرحيم    الرَّحِيمِ
# 4          1     2          1   Al-Fatiha        الحمد     الْحَمْدُ
# ...      ...   ...        ...         ...          ...           ...
# 78242    114     5          4      An-Nas         صدور       صُدُورِ
# 78243    114     5          5      An-Nas        الناس      النَّاسِ
# 78244    114     6          1      An-Nas           من          مِنَ
# 78245    114     6          2      An-Nas        الجنة    الْجِنَّةِ
# 78246    114     6          3      An-Nas       والناس    وَالنَّاسِ
#
#       root_arabic root
# 0             سمو  smw
# 1             اله  Alh
# 2             رحم  rHm
# 3             رحم  rHm
# 4             حمد  Hmd
# ...           ...  ...
# 78242         صدر  Sdr
# 78243         نوس  nws
# 78244         NaN  NaN
# 78245         جنن  jnn
# 78246         نوس  nws
#
# [78247 rows x 8 columns]

# %%
df_arabic_root_count = df_master_root_data["root_arabic"].value_counts(ascending=False).reset_index()
df_arabic_root_count.rename(columns={"index":"root_arabic","root_arabic":"root_arabic_frequency"}, inplace=True)
df_arabic_root_count = df_arabic_root_count.head(99)
df_arabic_root_count
# Out:
#    root_arabic  root_arabic_frequency
# 0          اله                   2851
# 1          قول                   1722
# 2          كون                   1390
# 3          ربب                    980
# 4          امن                    879
# ..         ...                    ...
# 94         يدي                    120
# 95         عزز                    119
# 96         امم                    119
# 97         جزي                    118
# 98         ابو                    117
#
# [99 rows x 2 columns]

# %%
df_root_data_merge = pd.merge(df_arabic_root_count, df_master_root_data, how="left", on=["root_arabic"])
df_root_data_merge.rename(columns={"tanzil_plain":"arabic","tanzil_clean":"arabic_simple"}, inplace=True)
#df_root_data_merge.drop_duplicates(inplace=True)
df_root_data_merge = df_root_data_merge.iloc[:,[0,8,1,2,3,4,5,6,7]]
df_root_data_merge
# Out:
#       root_arabic root  root_arabic_frequency  surah  ayah  word rank  \
# 0             اله  Alh                   2851      1     1          2
# 1             اله  Alh                   2851      1     2          2
# 2             اله  Alh                   2851      2     7          2
# 3             اله  Alh                   2851      2     8          6
# 4             اله  Alh                   2851      2     9          2
# ...           ...  ...                    ...    ...   ...        ...
# 30110         ابو  Abw                    117     56    48          1
# 30111         ابو  Abw                    117     58    22         15
# 30112         ابو  Abw                    117     60     4         36
# 30113         ابو  Abw                    117     80    35          2
# 30114         ابو  Abw                    117    111     1          3
#
#         surah latin arabic_simple         arabic
# 0         Al-Fatiha          الله        اللَّهِ
# 1         Al-Fatiha           لله        لِلَّهِ
# 2         Al-Baqara          الله        اللَّهُ
# 3         Al-Baqara         بالله      بِاللَّهِ
# 4         Al-Baqara          الله        اللَّهَ
# ...             ...           ...            ...
# 30110     Al-Waqi'a      أوآباؤنا  أَوَآبَاؤُنَا
# 30111   Al-Mujadila        آباءهم     آبَاءَهُمْ
# 30112  Al-Mumtahina         لأبيه      لِأَبِيهِ
# 30113         Abasa         وأبيه      وَأَبِيهِ
# 30114      Al-Masad           أبي          أَبِي
#
# [30115 rows x 9 columns]

# %%
df_root_translate_merge = pd.merge(df_root_data_merge, df_all_translate_merge, how="left", on=["arabic_simple","arabic"])
df_root_translate_merge.drop_duplicates(inplace=True)
df_root_translate_merge
# Out:
#       root_arabic root  root_arabic_frequency  surah  ayah  word rank  \
# 0             اله  Alh                   2851      1     1          2
# 1             اله  Alh                   2851      1     2          2
# 2             اله  Alh                   2851      2     7          2
# 3             اله  Alh                   2851      2     8          6
# 4             اله  Alh                   2851      2     9          2
# ...           ...  ...                    ...    ...   ...        ...
# 30110         ابو  Abw                    117     56    48          1
# 30111         ابو  Abw                    117     58    22         15
# 30112         ابو  Abw                    117     60     4         36
# 30113         ابو  Abw                    117     80    35          2
# 30114         ابو  Abw                    117    111     1          3
#
#         surah latin arabic_simple         arabic  arabic_frequency  \
# 0         Al-Fatiha          الله        اللَّهِ               828
# 1         Al-Fatiha           لله        لِلَّهِ               116
# 2         Al-Baqara          الله        اللَّهُ               733
# 3         Al-Baqara         بالله      بِاللَّهِ               139
# 4         Al-Baqara          الله        اللَّهَ               592
# ...             ...           ...            ...               ...
# 30110     Al-Waqi'a      أوآباؤنا  أَوَآبَاؤُنَا                 2
# 30111   Al-Mujadila        آباءهم     آبَاءَهُمْ                 3
# 30112  Al-Mumtahina         لأبيه      لِأَبِيهِ                 9
# 30113         Abasa         وأبيه      وَأَبِيهِ                 1
# 30114      Al-Masad           أبي          أَبِي                 4
#
#       translate_english             translate_urdu  \
# 0                 Allah                    اللہ کے
# 1              to Allah                اللہ کے لیے
# 2                 Allah                       اللہ
# 3              in Allah                    اللہ پر
# 4                 Allah                    اللہ سے
# ...                 ...                        ...
# 30110    Or our fathers  کیا بھلا ہمارے آباؤ اجداد
# 30111     their fathers             ان کے باپوں کو
# 30112     to his father                اپنے باپ سے
# 30113    and his father            اور اپنے باپ سے
# 30114         my father                   میرا باپ
#
#                    translate_hindi   translate_indonesian  \
# 0                        अल्लाह के                  Allah
# 1                    अल्लाह के लिए             bagi Allah
# 2                           अल्लाह                  Allah
# 3                        अल्लाह पर           kepada Allah
# 4                           अल्लाह                  Allah
# ...                            ...                    ...
# 30110  क्या भला आबा ओ अजदाद हमारे   atau bapak-bapak kami
# 30111               उनके बापों को      bapak-bapak mereka
# 30112                 अपने बाप से         kepada bapaknya
# 30113              और अपने बाप से            dan bapaknya
# 30114                   मेरा वालिद                 ayahku
#
#                                 translate_bangla  translate_turkish  \
# 0                                        আল্লাহর           Allah'ın
# 1                                  জন্যে আল্লাহর            Allah'a
# 2                                         আল্লাহ              Allah
# 3                                        আল্লাহই            Allah'a
# 4                                       আল্লাহকে              Allah
# ...                                          ...                ...
# 30110  এবং কি (উঠানো হবে) আমাদের পিতৃপুরুষদেরকেও  atalarımız da mı?
# 30111                       পিতাদের তাদের(পরিচয়)         babalarını
# 30112                                 তার পিতাকে           babasına
# 30113                            ও তার বাপ (হতে)    ve babası(ndan)
# 30114                                  আমার পিতা              babam
#
#       translate_russian
# 0                Аллаха
# 1               Аллаху,
# 2                 Аллах
# 3              в Аллаха
# 4                 Аллах
# ...                 ...
# 30110               Или
# 30111         их отцов,
# 30112       своему отцу
# 30113    и отца своего,
# 30114          отец мой
#
# [30115 rows x 17 columns]

# %%
df_root_translate_merge.to_excel("Quran_Root_Word_Translate_All.xlsx", index=False)

# %% [markdown]
# #### Quaran Ayah Frequency
