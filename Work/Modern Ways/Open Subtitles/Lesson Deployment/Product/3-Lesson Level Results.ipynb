# %% [markdown]
# ### Level Results

# %%
import pandas as pd
import numpy as np
import re
import glob
import nltk
from nltk import word_tokenize

# %%
word_num = 28

# %%
df_word = pd.read_excel(f"Word_{word_num}.xlsx")
df_word = pd.DataFrame(df_word.iloc[:,0])
df_word
# Out:
#      word
# 0     bir
# 1      bu
# 2      ne
# 3      ve
# 4    için
# 5      mi
# 6     ben
# 7      de
# 8     çok
# 9     ama
# 10    var
# 11   evet
# 12     mı
# 13  değil
# 14     da
# 15    şey
# 16  hayır
# 17   daha
# 18    sen
# 19  kadar
# 20   bana
# 21    yok
# 22    onu
# 23   seni
# 24   beni
# 25   bunu
# 26   gibi
# 27    iyi

# %%
twogram_file = glob.glob(f"Twogram_And*")
twogram_file
# Out:
# ['Twogram_And_Sentence_123_With_28_Word.xlsx']

# %%
df_twogram = pd.read_excel(f"{twogram_file[0]}")
df_twogram = pd.DataFrame(df_twogram.iloc[:,0])
df_twogram
# Out:
#          twogram
# 0        bir şey
# 1       değil mi
# 2         ben de
# 3         var mı
# 4    hayır hayır
# ..           ...
# 118      ama şey
# 119   hayır evet
# 120     ne değil
# 121    hayır şey
# 122      ama var
#
# [123 rows x 1 columns]

# %%
threegram_file = glob.glob(f"Threegram_And*")
threegram_file
# Out:
# ['Threegram_And_Sentence_92_With_28_Word.xlsx']

# %%
df_threegram = pd.read_excel(f"{threegram_file[0]}")
df_threegram = pd.DataFrame(df_threegram.iloc[:,0])
df_threegram
# Out:
#             threegram
# 0         bir şey yok
# 1         bir şey var
# 2            bu da ne
# 3   hayır hayır hayır
# 4       bir şey değil
# ..                ...
# 87         ne için mi
# 88          ne ben mi
# 89    hayır iyi değil
# 90      yok yok hayır
# 91          ne var mı
#
# [92 rows x 1 columns]

# %%
fourgram_file = glob.glob(f"Fourgram_And*")
fourgram_file
# Out:
# ['Fourgram_And_Sentence_61_With_28_Word.xlsx']

# %%
df_fourgram = pd.read_excel(f"{fourgram_file[0]}")
df_fourgram = pd.DataFrame(df_fourgram.iloc[:,0])
df_fourgram
# Out:
#                    fourgram
# 0            bir şey var mı
# 1          bir şey daha var
# 2   hayır hayır hayır hayır
# 3            bir şey mi var
# 4             ne var ne yok
# ..                      ...
# 56         evet bir şey yok
# 57       hayır bu iyi değil
# 58            bu iyi bu iyi
# 59            ben mi sen mi
# 60        ne kadar daha var
#
# [61 rows x 1 columns]

# %%
fivegram_file = glob.glob(f"Fivegram_And*")
fivegram_file
# Out:
# ['Fivegram_And_Sentence_28_With_28_Word.xlsx']

# %%
df_fivegram = pd.read_excel(f"{fivegram_file[0]}")
df_fivegram = pd.DataFrame(df_fivegram.iloc[:,0])
df_fivegram
# Out:
#                          fivegram
# 0   hayır hayır hayır hayır hayır
# 1            bu iyi bir şey değil
# 2               bu iyi bir şey mi
# 3            bir şey yok değil mi
# 4        evet evet evet evet evet
# 5            ama bir şey daha var
# 6             ve bir şey daha var
# 7               bu da iyi bir şey
# 8                  da da da da da
# 9              ama bu iyi bir şey
# 10              ve bu iyi bir şey
# 11           bu daha iyi değil mi
# 12               bu da bir şey mi
# 13          bu daha bir şey değil
# 14               ne sen ne de ben
# 15           hayır bu iyi bir şey
# 16            bana bir şey var mı
# 17            bu çok iyi değil mi
# 18               ve bir de bu var
# 19             sen sen sen ve sen
# 20             bu çok iyi bir şey
# 21        hayır hayır bir şey yok
# 22          ne kadar iyi değil mi
# 23            bu evet mi hayır mı
# 24          evet bir şey daha var
# 25          bu iyi değil değil mi
# 26            bu bir şey değil mi
# 27          daha iyi çok daha iyi

# %%
twogram_other_file = glob.glob(f"Twogram_*_Include*")
twogram_other_file
# Out:
# ['Twogram_193_Include_Arabic_With_28_Word.xlsx']

# %%
df_twogram_other = pd.read_excel(f"{twogram_other_file[0]}")
df_twogram_other = pd.DataFrame(df_twogram_other.iloc[:,0])
df_twogram_other
# Out:
#         twogram
# 0       bir şey
# 1      ne kadar
# 2      bu kadar
# 3       şey yok
# 4       şey var
# ..          ...
# 188      şey da
# 189      ama mı
# 190  evet kadar
# 191  gibi kadar
# 192   yok kadar
#
# [193 rows x 1 columns]

# %%
def word_count(df, bigger_than): # df is dataframe, bigger_than is integer
    list_all = []
    for i in df.columns:
        var_list = df[f"{i}"].dropna().tolist()
        for j in var_list:
            list_all.append(j)
    text = " ".join(list_all)
    word_list = re.findall(r"\w+",text, re.UNICODE)
    df_word_list = pd.DataFrame(word_list)
    df_word_list.rename(columns={0:"word"}, inplace=True)
    df_word_count = pd.DataFrame(df_word_list.value_counts())
    df_word_count.reset_index(inplace=True)
    df_word_count.rename(columns={0:"count"}, inplace=True)
    
    return  df_word_count["count"][df_word_count.loc[:,"count"] > bigger_than].any()

# %%
twogram_num = 30
threegram_num = 30
fourgram_num = 30
fivegram_num = 30
twogram_other_num = 30

# %%
df_lesson_result = pd.DataFrame(columns=["twogram","twogram_other","threegram","fourgram","fivegram"])
word_thresh_num = 9
a = 0
b = 0
c = 0
d = 0
e = 0
for i in range(len(df_word)):
    try:
        var1 = df_twogram.iloc[a,0]
        if len(df_lesson_result["twogram"]) < twogram_num and not(word_count(df_lesson_result, word_thresh_num)):
            df_lesson_result.loc[i,"twogram"] = var1
            while word_count(df_lesson_result, word_thresh_num): # word count result                
                a += 1
                var1 = df_twogram.iloc[a,0]
                df_lesson_result.loc[i,"twogram"] = var1
            else:
                pass
        else:
            pass
    except:
        pass
    a += 1

    try:
        var2 = df_twogram_other.iloc[b,0]
        if len(df_lesson_result["twogram_other"]) < twogram_other_num and not(word_count(df_lesson_result, word_thresh_num)):
            df_lesson_result.loc[i,"twogram_other"] = var2
            while word_count(df_lesson_result, word_thresh_num): # word count result                
                b += 1
                var2 = df_twogram_other.iloc[b,0]
                df_lesson_result.loc[i,"twogram_other"] = var2
            else:
                pass
        else:
            pass
    except:
        pass
    b += 1

    try:
        var3 = df_threegram.iloc[c,0]
        if len(df_lesson_result["threegram"]) < threegram_num and not(word_count(df_lesson_result, word_thresh_num)):
            df_lesson_result.loc[i,"threegram"] = var3
            while word_count(df_lesson_result, word_thresh_num): # word count result                
                c += 1
                var3 = df_threegram.iloc[c,0]
                df_lesson_result.loc[i,"threegram"] = var3
            else:
                pass
        else:
            pass
    except:
        pass
    c += 1

    try:
        var4 = df_fourgram.iloc[d,0]
        if len(df_lesson_result["fourgram"]) < fourgram_num and not(word_count(df_lesson_result, word_thresh_num)):
            df_lesson_result.loc[i,"fourgram"] = var4
            while word_count(df_lesson_result, word_thresh_num): # word count result                
                d += 1
                var4 = df_fourgram.iloc[d,0]
                df_lesson_result.loc[i,"fourgram"] = var4
            else:
                pass
        else:
            pass
    except:
        pass
    d += 1

    try:
        var5 = df_fivegram.iloc[e,0]
        if len(df_lesson_result["fivegram"]) < fivegram_num and not(word_count(df_lesson_result, word_thresh_num)):
            df_lesson_result.loc[i,"fivegram"] = var5
            while word_count(df_lesson_result, word_thresh_num):                
                e += 1
                var5 = df_fivegram.iloc[e,0]
                df_lesson_result.loc[i,"fivegram"] = var5
            else:
                pass
        else:
            pass
    except:
        pass
    e += 1

# %%
d
# Out:
# 40

# %%
e
# Out:
# 48

# %%
b
# Out:
# 33

# %%
df_lesson_result
# Out:
#     twogram twogram_other     threegram                 fourgram  \
# 0   bir şey       bir şey   bir şey yok           bir şey var mı
# 1  değil mi      ne kadar   bir şey var         bir şey daha var
# 2    ben de      bu kadar      bu da ne  hayır hayır hayır hayır
# 3    var mı       şey yok   ben de seni            ne var ne yok
# 4  ne kadar        ama bu    sen ve ben        daha iyi değil mi
# 5  bu kadar        ve ben   bu kadar mı      evet evet evet evet
# 6     bu da       ama ben     ve ben de        daha ne kadar var
# 7    sen de        ve bir  yok değil mi         çok iyi değil mi
# 8    ne var        sen ve  çok daha iyi          çok iyi çok iyi
#
#                         fivegram
# 0  hayır hayır hayır hayır hayır
# 1           bu iyi bir şey değil
# 2              bu iyi bir şey mi
# 3       evet evet evet evet evet
# 4                 da da da da da
# 5           bu daha iyi değil mi
# 6               ne sen ne de ben
# 7             sen sen sen ve sen
# 8          daha iyi çok daha iyi

# %%
def word_count_result(df): # df is dataframe, bigger_than is integer
    list_all = []
    for i in df.columns:
        var_list = df[f"{i}"].dropna().tolist()
        for j in var_list:
            list_all.append(j)
    text = " ".join(list_all)
    word_list = re.findall(r"\w+",text, re.UNICODE)
    df_word_list = pd.DataFrame(word_list)
    df_word_list.rename(columns={0:"word"}, inplace=True)
    df_word_count = pd.DataFrame(df_word_list.value_counts())
    df_word_count.reset_index(inplace=True)
    df_word_count.rename(columns={0:"count"}, inplace=True)
    
    return  df_word_count

# %%
word_count_result(df_lesson_result)
# Out:
#      word  count
# 0     iyi     10
# 1     şey      9
# 2      ne      9
# 3     bir      9
# 4      bu      9
# 5    evet      9
# 6   hayır      9
# 7     sen      8
# 8      da      7
# 9    daha      7
# 10    var      7
# 11    ben      7
# 12     ve      6
# 13  kadar      6
# 14     mi      6
# 15  değil      6
# 16     de      5
# 17    çok      5
# 18    yok      4
# 19     mı      3
# 20    ama      2
# 21   seni      1
