# %% [markdown]
# ### Youtube Sentence Adjust Word List Ratio

# %%
#!pip install modin[ray]

# %%
#import ray  # ayrı olarak çalıştırılmalı
#ray.init()

# %%
#import modin.pandas as pd

# %%
import pandas as pd
import numpy as np
import re
import glob

# %%
folder_name = "Turkish"
word_num = 28

# %% [markdown]
# #### Calculate Sentence Ratio By Word

# %%
df_adjust_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{folder_name.lower().capitalize()}/Deployment/Result/Level 1/Opus/Word_{word_num}.xlsx")
df_adjust_word
# Out:
#      word  frequency
# 0     bir   18835735
# 1      bu   11062659
# 2      ne    8025880
# 3      ve    7766036
# 4    için    5484109
# 5      mi    5362714
# 6     ben    4908913
# 7      de    4880315
# 8     çok    4852169
# 9     ama    4661966
# 10    var    4389551
# 11   evet    4324786
# 12     mı    4001316
# 13  değil    3883885
# 14     da    3610161
# 15    şey    3602024
# 16  hayır    3406992
# 17   daha    3317577
# 18    sen    3283654
# 19  kadar    2697900
# 20   bana    2659182
# 21    yok    2491685
# 22    onu    2486889
# 23   seni    2454988
# 24   beni    2446696
# 25   bunu    2445337
# 26   gibi    2427957
# 27    iyi    2383224

# %%
df_youtube_sentence = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Youtube/Result/{folder_name.lower().capitalize()}/Sentence Clean Merge/Clean_Youtube_Sentence_Merge_Result.csv")
df_youtube_sentence = df_youtube_sentence.head(40000)
df_youtube_sentence
# Out:
#          start_time      end_time                                  sentence  \
# 0      00:00:06.680  00:00:07.340                           sen kimsin peki
# 1      00:00:07.340  00:00:08.600                            parolayı söyle
# 2      00:00:09.440  00:00:11.060                       ya ben kim olacağım
# 3      00:00:11.060  00:00:11.860                               keloğlan ım
# 4      00:00:13.380  00:00:13.880                                        ey
# ...             ...           ...                                       ...
# 39995  00:10:47.348  00:10:48.955                   o yüzden geri çıkıyoruz
# 39996  00:10:48.955  00:10:50.809               haliyle buraya gelecekseniz
# 39997  00:10:50.809  00:10:53.841  sabah erken saatlerde gelmenizi öneririm
# 39998  00:10:53.841  00:10:56.070             çünkü yer sınırlı olduğu için
# 39999  00:10:56.070  00:10:58.615   zaman zaman oturacak yer bulamıyorsunuz
#
#           video_id
# 0      JR7nKXxUVtM
# 1      JR7nKXxUVtM
# 2      JR7nKXxUVtM
# 3      JR7nKXxUVtM
# 4      JR7nKXxUVtM
# ...            ...
# 39995  rUafZNR1GxY
# 39996  rUafZNR1GxY
# 39997  rUafZNR1GxY
# 39998  rUafZNR1GxY
# 39999  rUafZNR1GxY
#
# [40000 rows x 4 columns]

# %%
#def sentence_word_ratio(df_word, df_sentence, word_column_name, sentence_column_name, word_num): # df_word and df_sentence are dataframe, word_column_name and sentence_column_name are string, word_num is an integer
#    word_set = set(df_word[f"{word_column_name}"].to_list())
#    for i in range(len(df_sentence)):
#        sentence = df_sentence.loc[i,f"{sentence_column_name}"]
#        sent_word = re.findall(r"\w+", sentence, re.UNICODE)
#        sent_word_set = set(sent_word)
#        intersect_word = word_set.intersection(sent_word_set)
#        different_word = sent_word_set.difference(word_set)
#        df_sentence.loc[i,f"{word_num}_word_ratio"] = (len(intersect_word)/len(sent_word)+0.001)*100
#        df_sentence.loc[i,"different_word"] = [different_word]
#        df_sentence.loc[i,"intersect_word"] = [intersect_word]
#
#    df_sentence.reset_index(inplace=True)    
#    return df_sentence

# %%
def sentence_word_ratio(df_word, df_sentence, word_column_name, sentence_column_name, word_num): # df_word and df_sentence are dataframe, word_column_name and sentence_column_name are string, word_num is an integer
    word_set = set(df_word[f"{word_column_name}"].to_list())
    for i in range(len(df_sentence)):
        sentence = df_sentence.loc[i,f"{sentence_column_name}"]
        sent_word = re.findall(r"\w+", sentence, re.UNICODE)
        sent_word_set = set(sent_word)
        intersect_word = list(word_set.intersection(sent_word_set))
        different_word = list(sent_word_set.difference(word_set))
        df_sentence.loc[i,f"{word_num}_word_ratio"] = (len(intersect_word)/len(sent_word)+0.001)*100
        df_sentence.loc[i,"different_word"] = ", ".join(different_word)
        df_sentence.loc[i,"intersect_word"] = ", ".join(intersect_word)

    df_sentence.reset_index(inplace=True)    
    return df_sentence

# %%
df_sentence_ratio_result = sentence_word_ratio(df_adjust_word, df_youtube_sentence, "word", "sentence", 28)
df_sentence_ratio_result
# Out:
#        index    start_time      end_time  \
# 0          0  00:00:06.680  00:00:07.340
# 1          1  00:00:07.340  00:00:08.600
# 2          2  00:00:09.440  00:00:11.060
# 3          3  00:00:11.060  00:00:11.860
# 4          4  00:00:13.380  00:00:13.880
# ...      ...           ...           ...
# 39995  39995  00:10:47.348  00:10:48.955
# 39996  39996  00:10:48.955  00:10:50.809
# 39997  39997  00:10:50.809  00:10:53.841
# 39998  39998  00:10:53.841  00:10:56.070
# 39999  39999  00:10:56.070  00:10:58.615
#
#                                        sentence     video_id  28_word_ratio  \
# 0                               sen kimsin peki  JR7nKXxUVtM      33.433333
# 1                                parolayı söyle  JR7nKXxUVtM       0.100000
# 2                           ya ben kim olacağım  JR7nKXxUVtM      25.100000
# 3                                   keloğlan ım  JR7nKXxUVtM       0.100000
# 4                                            ey  JR7nKXxUVtM       0.100000
# ...                                         ...          ...            ...
# 39995                   o yüzden geri çıkıyoruz  rUafZNR1GxY       0.100000
# 39996               haliyle buraya gelecekseniz  rUafZNR1GxY       0.100000
# 39997  sabah erken saatlerde gelmenizi öneririm  rUafZNR1GxY       0.100000
# 39998             çünkü yer sınırlı olduğu için  rUafZNR1GxY      20.100000
# 39999   zaman zaman oturacak yer bulamıyorsunuz  rUafZNR1GxY       0.100000
#
#                                      different_word intersect_word
# 0                                      kimsin, peki            sen
# 1                                   parolayı, söyle
# 2                                 ya, kim, olacağım            ben
# 3                                      keloğlan, ım
# 4                                                ey
# ...                                             ...            ...
# 39995                    geri, çıkıyoruz, o, yüzden
# 39996                 gelecekseniz, buraya, haliyle
# 39997  saatlerde, erken, öneririm, sabah, gelmenizi
# 39998                   olduğu, yer, sınırlı, çünkü           için
# 39999          zaman, bulamıyorsunuz, oturacak, yer
#
# [40000 rows x 8 columns]

# %%
df_sentence_ratio_result["different_word"] = df_sentence_ratio_result["different_word"].apply(lambda x: np.nan if x == "" else x)
df_sentence_ratio_result["intersect_word"] = df_sentence_ratio_result["intersect_word"].apply(lambda x: np.nan if x == "" else x)
df_sentence_ratio_result
# Out:
#       index    start_time      end_time  \
# 0         0  00:00:06.680  00:00:07.340
# 1         1  00:00:07.340  00:00:08.600
# 2         2  00:00:09.440  00:00:11.060
# 3         3  00:00:11.060  00:00:11.860
# 4         4  00:00:13.380  00:00:13.880
# ...     ...           ...           ...
# 4995   4995  00:03:26.780  00:03:28.160
# 4996   4996  00:03:28.260  00:03:30.540
# 4997   4997  00:03:30.540  00:03:34.840
# 4998   4998  00:03:34.840  00:03:37.060
# 4999   4999  00:03:37.060  00:03:39.380
#
#                                                sentence     video_id  \
# 0                                       sen kimsin peki  JR7nKXxUVtM
# 1                                        parolayı söyle  JR7nKXxUVtM
# 2                                   ya ben kim olacağım  JR7nKXxUVtM
# 3                                           keloğlan ım  JR7nKXxUVtM
# 4                                                    ey  JR7nKXxUVtM
# ...                                                 ...          ...
# 4995                             böyle bile yiyebiliriz  cQjX9DzXTw0
# 4996                   kıvama geldiğinde artık tamamdır  cQjX9DzXTw0
# 4997  böyle ağzınıza böyle çıtır çıtır şeker tadı da...  cQjX9DzXTw0
# 4998  şimdi bundan sonra artık çırpıcı ile devam ede...  cQjX9DzXTw0
# 4999           yumurtaları tek tek kırıp karıştıracağım  cQjX9DzXTw0
#
#       28_word_ratio                                     different_word  \
# 0         33.433333                                       kimsin, peki
# 1          0.100000                                    parolayı, söyle
# 2         25.100000                                  ya, olacağım, kim
# 3          0.100000                                       keloğlan, ım
# 4          0.100000                                                 ey
# ...             ...                                                ...
# 4995       0.100000                           böyle, yiyebiliriz, bile
# 4996       0.100000                kıvama, tamamdır, artık, geldiğinde
# 4997       7.792308  önemli, tadı, lazım, çıtır, gelmemesi, ağzınız...
# 4998       0.100000  sonra, bundan, şimdi, artık, devam, ile, edece...
# 4999       0.100000            yumurtaları, kırıp, karıştıracağım, tek
#
#      intersect_word
# 0               sen
# 1               NaN
# 2               ben
# 3               NaN
# 4               NaN
# ...             ...
# 4995            NaN
# 4996            NaN
# 4997             da
# 4998            NaN
# 4999            NaN
#
# [5000 rows x 8 columns]

# %%
#df_sentence_ratio_result.to_excel(f"Youtube_Sentence_{word_num}_Word_Ratio_Result.xlsx", index=False)

# %% [markdown]
# #### Calculate Videoid Ratio By Word

# %%
#df_adjust_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{folder_name.lower().capitalize()}/Deployment/Result/Level 1/Opus/Word_{word_num}.xlsx")
#df_adjust_word

# %%
#df_youtube_sentence = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Youtube/Result/{folder_name.lower().capitalize()}/Sentence Clean Merge/Clean_Youtube_Sentence_Merge_Result.csv")
#df_youtube_sentence = df_youtube_sentence.head(5000)
#df_youtube_sentence

# %%
df_videoid_sentence = df_youtube_sentence.groupby("video_id")["sentence"].apply(" ".join).reset_index()
df_videoid_sentence
# Out:
#        video_id                                           sentence
# 0   23c9nwRm01o  arkadaşlar merhaba uzun zamandır video çekmiyo...
# 1   3jq75SKokNQ  asi döner alabilir miyim buyrun ne kadar hızlı...
# 2   4Ncsac3ywv0  intro çalıyor aman of of of of gidiyom gidemiy...
# 3   8V9tq1pe8eI  özgür bunlar normalde kamyon daha büyük araçla...
# 4   96Fw6H0ZG84  hiçbir şey yapmayacağım damlalarını vereceğim ...
# 5   CU7tcdhf02I  kar yağar kar üstüne derdim var dert üstüne ce...
# 6   DKTAB8HgIwc  dam başında sarı çiçek oy oy dam başında sarı ...
# 7   DgtKLrT9_GI  behey ala gözlü dilber dilber vaktin geçer dem...
# 8   DjrAJH4bjpE  eser rüzgar dağıtmaz efkarımı ben yarından umu...
# 9   EttVyq4DHYk  ve keten tohumu jeli ve kremi yapıyoruz sarkma...
# 10  GWsDgpOaPH8  ama bana var dediler var dendi hoş geldiniz uz...
# 11  JR7nKXxUVtM  sen kimsin peki parolayı söyle ya ben kim olac...
# 12  Jxky2g9BjKE  dert kervanı dizi dizi olsun efkar bastı hepim...
# 13  KkV_TmKSsp4  bir şehir sanki karşında hatıraların arkanda k...
# 14  LQuW_6iiyfk  dandini dandini dastana danalar girmiş bostana...
# 15  Lq03XCr1Eq0  giydiğim atlas iğneler batmaz yar bensiz yatma...
# 16  Q2HeV1M20Vo  kısırlaştırmanın seni sakinleştirmesi gerekiyo...
# 17  Rpz3oiCcgSg  yanımda olamasan da sesini duyamasam da sen be...
# 18  UDDfBEUGY60  erkin koray sana bir şeyler olmuş çalıyor çok ...
# 19  UVUk31HSHKw  a spec ppv bu aşamaya nasıl mı geldik izlemeye...
# 20  XAunIuGLdUk  evet çılgın bir kedimiz var yıllık aşılarını o...
# 21  ZcTP1fmOFFI  iddada kaybetmiş olabilirim ama o sonuç olarak...
# 22  __ZGmCkB58I  on dört bin yıl gezdim pervanelikte sıdkı ismi...
# 23  bZSx8_IZxX8  hi everyone i m in ağva _while i was walking w...
# 24  c1QvY3X64qM  bugünüm sensiz geçti cehennemde bir asırdı san...
# 25  cQjX9DzXTw0  san sebastian cheesecake i evde lezzetli bir ş...
# 26  cm40e1ChozE  nasıl gidiyor millet ben enes ve istanbul türk...
# 27  dYLeqJdv6PM  ah yoruldum hayatan ah nerde beni anlayan ah k...
# 28  g84ZNC2LyaE                                     hab v sbv vsiv
# 29  i6wonoiNr2o  bilirim her şey zaman geçer unutulur her günün...
# 30  iXAdoyurn18  karpuz adam şip şap şop burnu uzun lü lü lü sa...
# 31  kZf8nCwvaKk  yine kara gözlerin fikrime bilmece göğsüme taş...
# 32  nQJtsnUdXdg  koşuyorum yolda çünkü topum kaçtı kenara almak...
# 33  qnyDewp1vTE  ben şimdi burada böyle tek başıma dikerken sök...
# 34  sTCG43meXBg  ya sefa ya vallaha ayıp oluyor ya ya bırak ben...
# 35  tCadoXCM31Y  hoşgeldiniz abi buyrun gardaş hangi masaya alı...
# 36  tUNXI8BQGGg  dış parazitimiz var tırnak kesimi nasıl saplad...
# 37  uUeVFNLALK0  seni düşünüp yazmaktan kendi kuyumu kazmaktan ...
# 38  yL0lDvr1AsI  gün gidende ay gelende gel oğlum cihan yanar s...

# %%
def videoid_word_ratio(df_word, df_videoid_sentence, word_column_name, videoid_sentence_column_name, word_num):
    word_set = set(df_word[f"{word_column_name}"].to_list())
    for i in range(len(df_videoid_sentence)):
        text = df_videoid_sentence.loc[i,f"{videoid_sentence_column_name}"]
        text_word = re.findall(r"\w+", text, re.UNICODE)
        text_word_set = set(text_word)
        intersect_word = list(word_set.intersection(text_word_set))
        different_word = list(text_word_set.difference(word_set))
        df_videoid_sentence.loc[i,f"{word_num}_word_ratio"] = (len(intersect_word)/len(text_word)+0.001)*100
        df_videoid_sentence.loc[i,"different_word"] = ", ".join(different_word)
        df_videoid_sentence.loc[i,"intersect_word"] = ", ".join(intersect_word)
        
    return df_videoid_sentence

# %%
df_text_ratio_result = videoid_word_ratio(df_adjust_word, df_videoid_sentence, "word", "sentence", 28)
df_text_ratio_result
# Out:
#        video_id                                           sentence  \
# 0   23c9nwRm01o  arkadaşlar merhaba uzun zamandır video çekmiyo...
# 1   3jq75SKokNQ  asi döner alabilir miyim buyrun ne kadar hızlı...
# 2   4Ncsac3ywv0  intro çalıyor aman of of of of gidiyom gidemiy...
# 3   8V9tq1pe8eI  özgür bunlar normalde kamyon daha büyük araçla...
# 4   96Fw6H0ZG84  hiçbir şey yapmayacağım damlalarını vereceğim ...
# 5   CU7tcdhf02I  kar yağar kar üstüne derdim var dert üstüne ce...
# 6   DKTAB8HgIwc  dam başında sarı çiçek oy oy dam başında sarı ...
# 7   DgtKLrT9_GI  behey ala gözlü dilber dilber vaktin geçer dem...
# 8   DjrAJH4bjpE  eser rüzgar dağıtmaz efkarımı ben yarından umu...
# 9   EttVyq4DHYk  ve keten tohumu jeli ve kremi yapıyoruz sarkma...
# 10  GWsDgpOaPH8  ama bana var dediler var dendi hoş geldiniz uz...
# 11  JR7nKXxUVtM  sen kimsin peki parolayı söyle ya ben kim olac...
# 12  Jxky2g9BjKE  dert kervanı dizi dizi olsun efkar bastı hepim...
# 13  KkV_TmKSsp4  bir şehir sanki karşında hatıraların arkanda k...
# 14  LQuW_6iiyfk  dandini dandini dastana danalar girmiş bostana...
# 15  Lq03XCr1Eq0  giydiğim atlas iğneler batmaz yar bensiz yatma...
# 16  Q2HeV1M20Vo  kısırlaştırmanın seni sakinleştirmesi gerekiyo...
# 17  Rpz3oiCcgSg  yanımda olamasan da sesini duyamasam da sen be...
# 18  UDDfBEUGY60  erkin koray sana bir şeyler olmuş çalıyor çok ...
# 19  UVUk31HSHKw  a spec ppv bu aşamaya nasıl mı geldik izlemeye...
# 20  XAunIuGLdUk  evet çılgın bir kedimiz var yıllık aşılarını o...
# 21  ZcTP1fmOFFI  iddada kaybetmiş olabilirim ama o sonuç olarak...
# 22  __ZGmCkB58I  on dört bin yıl gezdim pervanelikte sıdkı ismi...
# 23  bZSx8_IZxX8  hi everyone i m in ağva _while i was walking w...
# 24  c1QvY3X64qM  bugünüm sensiz geçti cehennemde bir asırdı san...
# 25  cQjX9DzXTw0  san sebastian cheesecake i evde lezzetli bir ş...
# 26  cm40e1ChozE  nasıl gidiyor millet ben enes ve istanbul türk...
# 27  dYLeqJdv6PM  ah yoruldum hayatan ah nerde beni anlayan ah k...
# 28  g84ZNC2LyaE                                     hab v sbv vsiv
# 29  i6wonoiNr2o  bilirim her şey zaman geçer unutulur her günün...
# 30  iXAdoyurn18  karpuz adam şip şap şop burnu uzun lü lü lü sa...
# 31  kZf8nCwvaKk  yine kara gözlerin fikrime bilmece göğsüme taş...
# 32  nQJtsnUdXdg  koşuyorum yolda çünkü topum kaçtı kenara almak...
# 33  qnyDewp1vTE  ben şimdi burada böyle tek başıma dikerken sök...
# 34  sTCG43meXBg  ya sefa ya vallaha ayıp oluyor ya ya bırak ben...
# 35  tCadoXCM31Y  hoşgeldiniz abi buyrun gardaş hangi masaya alı...
# 36  tUNXI8BQGGg  dış parazitimiz var tırnak kesimi nasıl saplad...
# 37  uUeVFNLALK0  seni düşünüp yazmaktan kendi kuyumu kazmaktan ...
# 38  yL0lDvr1AsI  gün gidende ay gelende gel oğlum cihan yanar s...
#
#     28_word_ratio                                     different_word  \
# 0        6.160606  ozaman, biraz, uzun, bütün, ile, panjur, anlam...
# 1        5.933333  afiyet, pisliği, hızlısı, hemen, nasıl, sakin,...
# 2        4.751163  gidemiyom, gitar, anasına, kalmaz, aman, çalıy...
# 3        1.562317  içerde, kurt, sigaranla, karın, sıcak, durmuşu...
# 4        3.983495  hissediyorum, havluyu, sorunları, karar, üzeri...
# 5        4.645455  zaman, yağar, halım, arpa, sevmem, gelin, cell...
# 6        1.549275  başında, düşte, ürgüp, burdan, sarı, gör, kese...
# 7        0.637634  keser, harami, geçer, dilber, lerin, gözlü, be...
# 8        3.325806  yazık, baharımı, çaldılar, kuşlar, verip, böyl...
# 9        3.098236  jelimizin, çatlaklara, yağı, sıcak, arta, sıvı...
# 10       0.818870  sonraeaoğğğ, bacı, yapiyon, sıcak, programına,...
# 11       4.805882  güzel, uyan, vermişim, hem, kel, parolayı, sev...
# 12       4.100000  kara, girersin, bilinir, hakkına, bak, düştük,...
# 13       2.647771  evim, şeye, kaçmadan, mahallem, gelmemiş, için...
# 14       1.570588  doyunca, saraylı, onaylık, yürüsün, on, doğmuş...
# 15       1.276471  canıma, sarı, yatmaz, çamura, hacı, şişeleeeee...
# 16       3.728447  nişan, dokunmak, tutmaya, baktı, içinde, boks,...
# 17       4.021569  olsa, isn, gitmiş, my, bone, home, ihanet, hay...
# 18       0.518974  telefonumu, yaşıyoruz, bulacak, kalkalım, kaça...
# 19       3.919444  motorları, emeği, merceğin, güzel, ilk, ibares...
# 20       6.136745  havluyu, güzel, diliyorum, bakalım, biraz, ger...
# 21       2.220441  çekici, bakin, sonuç, olmamasi, sat, alamaz, s...
# 22       3.433333  sıdkı, duydum, divanelikte, zaman, alkış, dara...
# 23       1.824138  in, grooming, was, and, m, this, knows, my, be...
# 24       2.390076  kara, asırdı, dön, sevgine, gelip, gözlüm, ben...
# 25       3.679952  bisküvili, ilk, saklama, devam, dünya, ağzında...
# 26       0.659747  odalarımızı, eşyalar, genişletiyorlar, ınız, y...
# 27       5.694406  evim, ona, evini, kaderime, kıyma, bey, tüm, a...
# 28       0.100000                                  hab, vsiv, sbv, v
# 29       3.897468  gideceğim, güzel, gör, biteceğim, henüz, gücüm...
# 30       0.100000  burnu, çilek, vu, şip, uzun, vah, davul, güm, ...
# 31       3.803704  kara, özledim, günde, zaman, düşersen, gölgele...
# 32       4.894521  sesi, yoktu, güzel, düşüncelere, şeyler, içind...
# 33       4.954369  tarafın, dramdır, yoktur, üstü, yol, uzun, elb...
# 34       2.072243  ömrüm, videolar, düşecek, sıkacağım, saatdir, ...
# 35      10.327273  parası, yicem, afiyet, yiyebilecek, çocuğa, iz...
# 36       4.363566  ayıp, yoktu, ilk, devam, metin, oo, sıcaklık, ...
# 37       5.982353  kendi, sevdim, gitme, koydum, deli, hatır, yaz...
# 38       1.262791  in, yana, kol, öl, sonsuzluğa, yol, gezen, şer...
#
#                                        intersect_word
# 0                          bir, var, bu, ama, ve, çok
# 1                    de, bir, bu, ben, var, ne, kadar
# 2                         sen, bu, ben, ama, bana, ve
# 3   sen, şey, evet, yok, bana, var, bunu, daha, be...
# 4   sen, şey, yok, bana, var, bunu, daha, beni, bi...
# 5                                           var, seni
# 6                                             bir, de
# 7                                                  mi
# 8                                   ben, mı, ne, için
# 9   daha, iyi, ve, için, bir, de, yok, bu, ben, da...
# 10  sen, şey, evet, yok, bana, var, bunu, daha, be...
# 11                                ben, bir, sen, seni
# 12                      bir, bu, ama, bana, ne, kadar
# 13             ve, beni, bir, seni, bu, ama, var, çok
# 14                                        bir, da, de
# 15                                            mı, sen
# 16  sen, şey, evet, yok, bana, var, daha, beni, bi...
# 17                                 bir, da, sen, seni
# 18  sen, şey, evet, yok, bana, var, bunu, daha, be...
# 19  daha, ve, değil, bir, bu, da, var, mı, de, içi...
# 20  sen, şey, evet, yok, bana, var, daha, beni, bi...
# 21  sen, şey, evet, yok, bana, var, bunu, daha, be...
# 22                                     bir, için, çok
# 23                                                 ve
# 24                                      ben, bir, sen
# 25  daha, ve, şey, onu, de, bir, yok, bu, da, gibi...
# 26  şey, evet, bana, var, bunu, daha, bir, bu, ve,...
# 27           sen, onu, beni, yok, ben, ama, bana, çok
# 28
# 29                       daha, şey, bir, bu, ama, çok
# 30
# 31                      de, bir, seni, gibi, ne, için
# 32  şey, onu, bir, evet, yok, bu, ben, da, ama, gi...
# 33    sen, değil, de, bir, bu, ben, da, mi, var, bunu
# 34  sen, şey, yok, bana, var, bunu, daha, beni, bi...
# 35         beni, de, yok, bu, ben, var, mı, ne, kadar
# 36  sen, şey, evet, yok, bana, var, bunu, daha, bi...
# 37                       sen, seni, yok, bu, ben, çok
# 38                                     bana, bir, sen

# %%
#df_text_ratio_result.to_excel(f"Youtube_Videoid_Text_{word_num}_Word_Ratio_Result.xlsx", index=False)

# %% [markdown]
# #### Select Adjust Sentence Ratio Result

# %%
#df_sentence_ratio_result = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{folder_name}/Deployment/Result/Level 1/Youtube/Youtube_Sentence_28_Word_Ratio_Result.xlsx")
#df_sentence_ratio_result

# %%
adjust_word_ratio = 100
df_adjust_ratio = df_sentence_ratio_result[df_sentence_ratio_result[f"{word_num}_word_ratio"] >= adjust_word_ratio]
df_adjust_ratio
# Out:
#       index    start_time      end_time       sentence     video_id  \
# 59       59  00:00:15.780  00:00:16.600             ne  3jq75SKokNQ
# 162     162  00:00:20.980  00:00:21.480            var  tCadoXCM31Y
# 164     164  00:00:23.280  00:00:24.060            var  tCadoXCM31Y
# 342     342  00:04:18.495  00:04:19.495            yok  UDDfBEUGY60
# 350     350  00:04:45.747  00:04:46.747             ne  UDDfBEUGY60
# 351     351  00:04:47.900  00:04:48.900             ne  UDDfBEUGY60
# 400     400  00:07:35.246  00:07:36.278  değil mi evet  UDDfBEUGY60
# 419     419  00:09:15.573  00:09:17.263     ben de çok  UDDfBEUGY60
# 549     549  00:21:32.301  00:21:33.545         sen de  UDDfBEUGY60
# 564     564  00:23:33.434  00:23:34.434           evet  UDDfBEUGY60
# 613     613  00:27:36.886  00:27:37.886           evet  UDDfBEUGY60
# 644     644  00:30:04.337  00:30:05.337             ne  UDDfBEUGY60
# 672     672  00:33:52.721  00:33:55.147             ve  UDDfBEUGY60
# 718     718  00:36:23.293  00:36:24.741           evet  UDDfBEUGY60
# 754     754  00:39:00.825  00:39:03.070           evet  UDDfBEUGY60
# 793     793  00:41:21.888  00:41:22.888           evet  UDDfBEUGY60
# 947     947  00:54:52.643  00:54:54.063          bu ne  UDDfBEUGY60
# 961     961  00:55:59.572  00:56:00.746           evet  UDDfBEUGY60
# 1006   1006  00:58:22.613  00:58:23.906          bu ne  UDDfBEUGY60
# 1110   1110  01:06:09.908  01:06:11.202           evet  UDDfBEUGY60
# 1152   1152  01:08:58.219  01:08:59.417         sen de  UDDfBEUGY60
# 1372   1372  01:32:27.417  01:32:28.549           evet  UDDfBEUGY60
# 1407   1407  01:35:05.270  01:35:06.334            ben  UDDfBEUGY60
# 1437   1437  01:37:58.058  01:37:59.185            ama  UDDfBEUGY60
# 1480   1480  01:41:03.369  01:41:04.369           evet  UDDfBEUGY60
# 1501   1501  01:43:00.174  01:43:01.690           evet  UDDfBEUGY60
# 1504   1504  01:43:14.006  01:43:15.006       değil mi  UDDfBEUGY60
# 1519   1519  01:45:03.389  01:45:04.389           evet  UDDfBEUGY60
# 1653   1653  01:57:54.175  01:57:55.175          hayır  UDDfBEUGY60
# 1735   1735  00:01:00.400  00:01:02.800           seni  Rpz3oiCcgSg
# 2338   2338  00:16:19.520  00:16:21.560            ama  GWsDgpOaPH8
# 2566   2566  00:29:17.180  00:29:19.700         ben de  GWsDgpOaPH8
# 2580   2580  00:30:05.560  00:30:06.800          bu ne  GWsDgpOaPH8
# 2641   2641  00:33:46.500  00:33:47.500             ne  GWsDgpOaPH8
# 3153   3153  00:12:59.720  00:13:00.720           evet  ZcTP1fmOFFI
# 3338   3338  00:03:37.529  00:03:38.583           evet  tUNXI8BQGGg
# 3347   3347  00:04:09.673  00:04:10.789        çok iyi  tUNXI8BQGGg
# 3371   3371  00:05:10.989  00:05:12.100          hayır  tUNXI8BQGGg
# 3372   3372  00:05:12.145  00:05:12.791          hayır  tUNXI8BQGGg
# 3394   3394  00:06:09.832  00:06:10.465           evet  tUNXI8BQGGg
# 3398   3398  00:06:20.754  00:06:21.418            şey  tUNXI8BQGGg
# 3407   3407  00:00:00.000  00:00:00.760             ve  EttVyq4DHYk
# 3433   3433  00:02:04.050  00:02:04.660             bu  EttVyq4DHYk
# 3444   3444  00:03:03.810  00:03:04.660             ve  EttVyq4DHYk
# 3456   3456  00:03:56.130  00:03:57.070             bu  EttVyq4DHYk
# 3477   3477  00:05:32.980  00:05:34.070             ve  EttVyq4DHYk
# 3973   3973  00:27:46.048  00:27:46.560           evet  8V9tq1pe8eI
# 4475   4475  00:15:31.140  00:15:34.580             ve  cm40e1ChozE
# 4494   4494  00:16:12.380  00:16:13.213           evet  cm40e1ChozE
# 4520   4520  00:17:16.050  00:17:21.050             ve  cm40e1ChozE
# 4614   4614  00:21:07.310  00:21:08.880             bu  cm40e1ChozE
# 4625   4625  00:21:30.750  00:21:32.610            ama  cm40e1ChozE
#
#       28_word_ratio different_word   intersect_word
# 59            100.1            NaN               ne
# 162           100.1            NaN              var
# 164           100.1            NaN              var
# 342           100.1            NaN              yok
# 350           100.1            NaN               ne
# 351           100.1            NaN               ne
# 400           100.1            NaN  değil, mi, evet
# 419           100.1            NaN     ben, de, çok
# 549           100.1            NaN          sen, de
# 564           100.1            NaN             evet
# 613           100.1            NaN             evet
# 644           100.1            NaN               ne
# 672           100.1            NaN               ve
# 718           100.1            NaN             evet
# 754           100.1            NaN             evet
# 793           100.1            NaN             evet
# 947           100.1            NaN           bu, ne
# 961           100.1            NaN             evet
# 1006          100.1            NaN           bu, ne
# 1110          100.1            NaN             evet
# 1152          100.1            NaN          sen, de
# 1372          100.1            NaN             evet
# 1407          100.1            NaN              ben
# 1437          100.1            NaN              ama
# 1480          100.1            NaN             evet
# 1501          100.1            NaN             evet
# 1504          100.1            NaN        mi, değil
# 1519          100.1            NaN             evet
# 1653          100.1            NaN            hayır
# 1735          100.1            NaN             seni
# 2338          100.1            NaN              ama
# 2566          100.1            NaN          ben, de
# 2580          100.1            NaN           bu, ne
# 2641          100.1            NaN               ne
# 3153          100.1            NaN             evet
# 3338          100.1            NaN             evet
# 3347          100.1            NaN         iyi, çok
# 3371          100.1            NaN            hayır
# 3372          100.1            NaN            hayır
# 3394          100.1            NaN             evet
# 3398          100.1            NaN              şey
# 3407          100.1            NaN               ve
# 3433          100.1            NaN               bu
# 3444          100.1            NaN               ve
# 3456          100.1            NaN               bu
# 3477          100.1            NaN               ve
# 3973          100.1            NaN             evet
# 4475          100.1            NaN               ve
# 4494          100.1            NaN             evet
# 4520          100.1            NaN               ve
# 4614          100.1            NaN               bu
# 4625          100.1            NaN              ama

# %%
#df_adjust_ratio.to_excel(f"Youtube_Sentence_{word_num}_Word_{word_ratio}_Ratio_Sentences.xlsx", index=False)

# %% [markdown]
# #### Calculate Sequential Sentence Length Of Adjust Ratio Result

# %%
df_adjust_ratio["with_word"] = 1
df_adjust_ratio
# Out:
# <ipython-input-22-3eb37270623c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adjust_ratio["with_word"] = 1
#       index    start_time      end_time       sentence     video_id  \
# 59       59  00:00:15.780  00:00:16.600             ne  3jq75SKokNQ
# 162     162  00:00:20.980  00:00:21.480            var  tCadoXCM31Y
# 164     164  00:00:23.280  00:00:24.060            var  tCadoXCM31Y
# 342     342  00:04:18.495  00:04:19.495            yok  UDDfBEUGY60
# 350     350  00:04:45.747  00:04:46.747             ne  UDDfBEUGY60
# 351     351  00:04:47.900  00:04:48.900             ne  UDDfBEUGY60
# 400     400  00:07:35.246  00:07:36.278  değil mi evet  UDDfBEUGY60
# 419     419  00:09:15.573  00:09:17.263     ben de çok  UDDfBEUGY60
# 549     549  00:21:32.301  00:21:33.545         sen de  UDDfBEUGY60
# 564     564  00:23:33.434  00:23:34.434           evet  UDDfBEUGY60
# 613     613  00:27:36.886  00:27:37.886           evet  UDDfBEUGY60
# 644     644  00:30:04.337  00:30:05.337             ne  UDDfBEUGY60
# 672     672  00:33:52.721  00:33:55.147             ve  UDDfBEUGY60
# 718     718  00:36:23.293  00:36:24.741           evet  UDDfBEUGY60
# 754     754  00:39:00.825  00:39:03.070           evet  UDDfBEUGY60
# 793     793  00:41:21.888  00:41:22.888           evet  UDDfBEUGY60
# 947     947  00:54:52.643  00:54:54.063          bu ne  UDDfBEUGY60
# 961     961  00:55:59.572  00:56:00.746           evet  UDDfBEUGY60
# 1006   1006  00:58:22.613  00:58:23.906          bu ne  UDDfBEUGY60
# 1110   1110  01:06:09.908  01:06:11.202           evet  UDDfBEUGY60
# 1152   1152  01:08:58.219  01:08:59.417         sen de  UDDfBEUGY60
# 1372   1372  01:32:27.417  01:32:28.549           evet  UDDfBEUGY60
# 1407   1407  01:35:05.270  01:35:06.334            ben  UDDfBEUGY60
# 1437   1437  01:37:58.058  01:37:59.185            ama  UDDfBEUGY60
# 1480   1480  01:41:03.369  01:41:04.369           evet  UDDfBEUGY60
# 1501   1501  01:43:00.174  01:43:01.690           evet  UDDfBEUGY60
# 1504   1504  01:43:14.006  01:43:15.006       değil mi  UDDfBEUGY60
# 1519   1519  01:45:03.389  01:45:04.389           evet  UDDfBEUGY60
# 1653   1653  01:57:54.175  01:57:55.175          hayır  UDDfBEUGY60
# 1735   1735  00:01:00.400  00:01:02.800           seni  Rpz3oiCcgSg
# 2338   2338  00:16:19.520  00:16:21.560            ama  GWsDgpOaPH8
# 2566   2566  00:29:17.180  00:29:19.700         ben de  GWsDgpOaPH8
# 2580   2580  00:30:05.560  00:30:06.800          bu ne  GWsDgpOaPH8
# 2641   2641  00:33:46.500  00:33:47.500             ne  GWsDgpOaPH8
# 3153   3153  00:12:59.720  00:13:00.720           evet  ZcTP1fmOFFI
# 3338   3338  00:03:37.529  00:03:38.583           evet  tUNXI8BQGGg
# 3347   3347  00:04:09.673  00:04:10.789        çok iyi  tUNXI8BQGGg
# 3371   3371  00:05:10.989  00:05:12.100          hayır  tUNXI8BQGGg
# 3372   3372  00:05:12.145  00:05:12.791          hayır  tUNXI8BQGGg
# 3394   3394  00:06:09.832  00:06:10.465           evet  tUNXI8BQGGg
# 3398   3398  00:06:20.754  00:06:21.418            şey  tUNXI8BQGGg
# 3407   3407  00:00:00.000  00:00:00.760             ve  EttVyq4DHYk
# 3433   3433  00:02:04.050  00:02:04.660             bu  EttVyq4DHYk
# 3444   3444  00:03:03.810  00:03:04.660             ve  EttVyq4DHYk
# 3456   3456  00:03:56.130  00:03:57.070             bu  EttVyq4DHYk
# 3477   3477  00:05:32.980  00:05:34.070             ve  EttVyq4DHYk
# 3973   3973  00:27:46.048  00:27:46.560           evet  8V9tq1pe8eI
# 4475   4475  00:15:31.140  00:15:34.580             ve  cm40e1ChozE
# 4494   4494  00:16:12.380  00:16:13.213           evet  cm40e1ChozE
# 4520   4520  00:17:16.050  00:17:21.050             ve  cm40e1ChozE
# 4614   4614  00:21:07.310  00:21:08.880             bu  cm40e1ChozE
# 4625   4625  00:21:30.750  00:21:32.610            ama  cm40e1ChozE
#
#       28_word_ratio different_word   intersect_word  with_word
# 59            100.1            NaN               ne          1
# 162           100.1            NaN              var          1
# 164           100.1            NaN              var          1
# 342           100.1            NaN              yok          1
# 350           100.1            NaN               ne          1
# 351           100.1            NaN               ne          1
# 400           100.1            NaN  değil, mi, evet          1
# 419           100.1            NaN     ben, de, çok          1
# 549           100.1            NaN          sen, de          1
# 564           100.1            NaN             evet          1
# 613           100.1            NaN             evet          1
# 644           100.1            NaN               ne          1
# 672           100.1            NaN               ve          1
# 718           100.1            NaN             evet          1
# 754           100.1            NaN             evet          1
# 793           100.1            NaN             evet          1
# 947           100.1            NaN           bu, ne          1
# 961           100.1            NaN             evet          1
# 1006          100.1            NaN           bu, ne          1
# 1110          100.1            NaN             evet          1
# 1152          100.1            NaN          sen, de          1
# 1372          100.1            NaN             evet          1
# 1407          100.1            NaN              ben          1
# 1437          100.1            NaN              ama          1
# 1480          100.1            NaN             evet          1
# 1501          100.1            NaN             evet          1
# 1504          100.1            NaN        mi, değil          1
# 1519          100.1            NaN             evet          1
# 1653          100.1            NaN            hayır          1
# 1735          100.1            NaN             seni          1
# 2338          100.1            NaN              ama          1
# 2566          100.1            NaN          ben, de          1
# 2580          100.1            NaN           bu, ne          1
# 2641          100.1            NaN               ne          1
# 3153          100.1            NaN             evet          1
# 3338          100.1            NaN             evet          1
# 3347          100.1            NaN         iyi, çok          1
# 3371          100.1            NaN            hayır          1
# 3372          100.1            NaN            hayır          1
# 3394          100.1            NaN             evet          1
# 3398          100.1            NaN              şey          1
# 3407          100.1            NaN               ve          1
# 3433          100.1            NaN               bu          1
# 3444          100.1            NaN               ve          1
# 3456          100.1            NaN               bu          1
# 3477          100.1            NaN               ve          1
# 3973          100.1            NaN             evet          1
# 4475          100.1            NaN               ve          1
# 4494          100.1            NaN             evet          1
# 4520          100.1            NaN               ve          1
# 4614          100.1            NaN               bu          1
# 4625          100.1            NaN              ama          1

# %%
df_adjust_ratio_flag = pd.merge(df_youtube_sentence, df_adjust_ratio, how="left", on=["index","sentence","start_time","end_time","video_id",f"{word_num}_word_ratio","different_word","intersect_word"])
df_adjust_ratio_flag["with_word"].fillna(0, inplace=True)
df_adjust_ratio_flag
# Out:
#       index    start_time      end_time  \
# 0         0  00:00:06.680  00:00:07.340
# 1         1  00:00:07.340  00:00:08.600
# 2         2  00:00:09.440  00:00:11.060
# 3         3  00:00:11.060  00:00:11.860
# 4         4  00:00:13.380  00:00:13.880
# ...     ...           ...           ...
# 4995   4995  00:03:26.780  00:03:28.160
# 4996   4996  00:03:28.260  00:03:30.540
# 4997   4997  00:03:30.540  00:03:34.840
# 4998   4998  00:03:34.840  00:03:37.060
# 4999   4999  00:03:37.060  00:03:39.380
#
#                                                sentence     video_id  \
# 0                                       sen kimsin peki  JR7nKXxUVtM
# 1                                        parolayı söyle  JR7nKXxUVtM
# 2                                   ya ben kim olacağım  JR7nKXxUVtM
# 3                                           keloğlan ım  JR7nKXxUVtM
# 4                                                    ey  JR7nKXxUVtM
# ...                                                 ...          ...
# 4995                             böyle bile yiyebiliriz  cQjX9DzXTw0
# 4996                   kıvama geldiğinde artık tamamdır  cQjX9DzXTw0
# 4997  böyle ağzınıza böyle çıtır çıtır şeker tadı da...  cQjX9DzXTw0
# 4998  şimdi bundan sonra artık çırpıcı ile devam ede...  cQjX9DzXTw0
# 4999           yumurtaları tek tek kırıp karıştıracağım  cQjX9DzXTw0
#
#       28_word_ratio                                     different_word  \
# 0         33.433333                                       kimsin, peki
# 1          0.100000                                    parolayı, söyle
# 2         25.100000                                  ya, olacağım, kim
# 3          0.100000                                       keloğlan, ım
# 4          0.100000                                                 ey
# ...             ...                                                ...
# 4995       0.100000                           böyle, yiyebiliriz, bile
# 4996       0.100000                kıvama, tamamdır, artık, geldiğinde
# 4997       7.792308  önemli, tadı, lazım, çıtır, gelmemesi, ağzınız...
# 4998       0.100000  sonra, bundan, şimdi, artık, devam, ile, edece...
# 4999       0.100000            yumurtaları, kırıp, karıştıracağım, tek
#
#      intersect_word  with_word
# 0               sen        0.0
# 1               NaN        0.0
# 2               ben        0.0
# 3               NaN        0.0
# 4               NaN        0.0
# ...             ...        ...
# 4995            NaN        0.0
# 4996            NaN        0.0
# 4997             da        0.0
# 4998            NaN        0.0
# 4999            NaN        0.0
#
# [5000 rows x 9 columns]

# %%
df_adjust_ratio_flag.with_word.value_counts()
# Out:
# 0.0    4948
# 1.0      52
# Name: with_word, dtype: int64

# %%
# Code Running For Video_id Sentence
zeros = []
ones = []
zero_list = []
one_list = []
for i in range(len(df_adjust_ratio_flag)):
    videoid = df_adjust_ratio_flag.loc[i,"video_id"]    
    if df_adjust_ratio_flag.loc[i,"with_word"] == 0:
        zeros.append(i)
        try:
            one_list.append((ones[0],len(ones)))
        except:
            pass
        ones = []
    else:
        ones.append(i)
        try:
            zero_list.append((zeros[0],len(zeros)))
        except:
            pass
        zeros = []

    try:
        if df_adjust_ratio_flag.loc[i+1,"video_id"] != videoid:
            try:
                one_list.append((ones[0],len(ones)))
                ones = []
            except:
                pass
            try:
                zero_list.append((zeros[0],len(zeros)))
                zeros = []
            except:
                pass
        else:
            pass
    except:
        pass

try:
    one_list.append((ones[0],len(ones)))
except:
    pass
try:
    zero_list.append((zeros[0],len(zeros)))
except:
    pass

# %%
df_one = pd.DataFrame(one_list)
df_one.rename(columns={0:"index",1:"length"}, inplace=True)
df_one.drop_duplicates(inplace=True)
df_one.sort_values(by="length", ascending=False, inplace=True)
df_one.reset_index(drop=True, inplace=True)
df_one
# Out:
#     index  length
# 0     350       2
# 1    3371       2
# 2      59       1
# 3    3398       1
# 4    1735       1
# 5    2338       1
# 6    2566       1
# 7    2580       1
# 8    2641       1
# 9    3153       1
# 10   3338       1
# 11   3347       1
# 12   3394       1
# 13   3407       1
# 14   1519       1
# 15   3433       1
# 16   3444       1
# 17   3456       1
# 18   3477       1
# 19   3973       1
# 20   4475       1
# 21   4494       1
# 22   4520       1
# 23   4614       1
# 24   1653       1
# 25   1504       1
# 26    162       1
# 27   1501       1
# 28    164       1
# 29    342       1
# 30    400       1
# 31    419       1
# 32    549       1
# 33    564       1
# 34    613       1
# 35    644       1
# 36    672       1
# 37    718       1
# 38    754       1
# 39    793       1
# 40    947       1
# 41    961       1
# 42   1006       1
# 43   1110       1
# 44   1152       1
# 45   1372       1
# 46   1407       1
# 47   1437       1
# 48   1480       1
# 49   4625       1

# %%
df_one_all = pd.DataFrame()
for i in range(len(df_one)):
    index = df_one.loc[i,"index"]
    length = df_one.loc[i,"length"]
    start_index = index
    end_index = index+length
    df_video = df_adjust_ratio_flag.iloc[start_index:end_index,]
    df_one_all = pd.concat([df_one_all, df_video],axis=0)
df_one_all.reset_index(inplace=True, drop=True)
df_one_all
# Out:
#     index    start_time      end_time       sentence     video_id  \
# 0     350  00:04:45.747  00:04:46.747             ne  UDDfBEUGY60
# 1     351  00:04:47.900  00:04:48.900             ne  UDDfBEUGY60
# 2    3371  00:05:10.989  00:05:12.100          hayır  tUNXI8BQGGg
# 3    3372  00:05:12.145  00:05:12.791          hayır  tUNXI8BQGGg
# 4      59  00:00:15.780  00:00:16.600             ne  3jq75SKokNQ
# 5    3398  00:06:20.754  00:06:21.418            şey  tUNXI8BQGGg
# 6    1735  00:01:00.400  00:01:02.800           seni  Rpz3oiCcgSg
# 7    2338  00:16:19.520  00:16:21.560            ama  GWsDgpOaPH8
# 8    2566  00:29:17.180  00:29:19.700         ben de  GWsDgpOaPH8
# 9    2580  00:30:05.560  00:30:06.800          bu ne  GWsDgpOaPH8
# 10   2641  00:33:46.500  00:33:47.500             ne  GWsDgpOaPH8
# 11   3153  00:12:59.720  00:13:00.720           evet  ZcTP1fmOFFI
# 12   3338  00:03:37.529  00:03:38.583           evet  tUNXI8BQGGg
# 13   3347  00:04:09.673  00:04:10.789        çok iyi  tUNXI8BQGGg
# 14   3394  00:06:09.832  00:06:10.465           evet  tUNXI8BQGGg
# 15   3407  00:00:00.000  00:00:00.760             ve  EttVyq4DHYk
# 16   1519  01:45:03.389  01:45:04.389           evet  UDDfBEUGY60
# 17   3433  00:02:04.050  00:02:04.660             bu  EttVyq4DHYk
# 18   3444  00:03:03.810  00:03:04.660             ve  EttVyq4DHYk
# 19   3456  00:03:56.130  00:03:57.070             bu  EttVyq4DHYk
# 20   3477  00:05:32.980  00:05:34.070             ve  EttVyq4DHYk
# 21   3973  00:27:46.048  00:27:46.560           evet  8V9tq1pe8eI
# 22   4475  00:15:31.140  00:15:34.580             ve  cm40e1ChozE
# 23   4494  00:16:12.380  00:16:13.213           evet  cm40e1ChozE
# 24   4520  00:17:16.050  00:17:21.050             ve  cm40e1ChozE
# 25   4614  00:21:07.310  00:21:08.880             bu  cm40e1ChozE
# 26   1653  01:57:54.175  01:57:55.175          hayır  UDDfBEUGY60
# 27   1504  01:43:14.006  01:43:15.006       değil mi  UDDfBEUGY60
# 28    162  00:00:20.980  00:00:21.480            var  tCadoXCM31Y
# 29   1501  01:43:00.174  01:43:01.690           evet  UDDfBEUGY60
# 30    164  00:00:23.280  00:00:24.060            var  tCadoXCM31Y
# 31    342  00:04:18.495  00:04:19.495            yok  UDDfBEUGY60
# 32    400  00:07:35.246  00:07:36.278  değil mi evet  UDDfBEUGY60
# 33    419  00:09:15.573  00:09:17.263     ben de çok  UDDfBEUGY60
# 34    549  00:21:32.301  00:21:33.545         sen de  UDDfBEUGY60
# 35    564  00:23:33.434  00:23:34.434           evet  UDDfBEUGY60
# 36    613  00:27:36.886  00:27:37.886           evet  UDDfBEUGY60
# 37    644  00:30:04.337  00:30:05.337             ne  UDDfBEUGY60
# 38    672  00:33:52.721  00:33:55.147             ve  UDDfBEUGY60
# 39    718  00:36:23.293  00:36:24.741           evet  UDDfBEUGY60
# 40    754  00:39:00.825  00:39:03.070           evet  UDDfBEUGY60
# 41    793  00:41:21.888  00:41:22.888           evet  UDDfBEUGY60
# 42    947  00:54:52.643  00:54:54.063          bu ne  UDDfBEUGY60
# 43    961  00:55:59.572  00:56:00.746           evet  UDDfBEUGY60
# 44   1006  00:58:22.613  00:58:23.906          bu ne  UDDfBEUGY60
# 45   1110  01:06:09.908  01:06:11.202           evet  UDDfBEUGY60
# 46   1152  01:08:58.219  01:08:59.417         sen de  UDDfBEUGY60
# 47   1372  01:32:27.417  01:32:28.549           evet  UDDfBEUGY60
# 48   1407  01:35:05.270  01:35:06.334            ben  UDDfBEUGY60
# 49   1437  01:37:58.058  01:37:59.185            ama  UDDfBEUGY60
# 50   1480  01:41:03.369  01:41:04.369           evet  UDDfBEUGY60
# 51   4625  00:21:30.750  00:21:32.610            ama  cm40e1ChozE
#
#     28_word_ratio different_word   intersect_word  with_word
# 0           100.1            NaN               ne        1.0
# 1           100.1            NaN               ne        1.0
# 2           100.1            NaN            hayır        1.0
# 3           100.1            NaN            hayır        1.0
# 4           100.1            NaN               ne        1.0
# 5           100.1            NaN              şey        1.0
# 6           100.1            NaN             seni        1.0
# 7           100.1            NaN              ama        1.0
# 8           100.1            NaN          ben, de        1.0
# 9           100.1            NaN           bu, ne        1.0
# 10          100.1            NaN               ne        1.0
# 11          100.1            NaN             evet        1.0
# 12          100.1            NaN             evet        1.0
# 13          100.1            NaN         iyi, çok        1.0
# 14          100.1            NaN             evet        1.0
# 15          100.1            NaN               ve        1.0
# 16          100.1            NaN             evet        1.0
# 17          100.1            NaN               bu        1.0
# 18          100.1            NaN               ve        1.0
# 19          100.1            NaN               bu        1.0
# 20          100.1            NaN               ve        1.0
# 21          100.1            NaN             evet        1.0
# 22          100.1            NaN               ve        1.0
# 23          100.1            NaN             evet        1.0
# 24          100.1            NaN               ve        1.0
# 25          100.1            NaN               bu        1.0
# 26          100.1            NaN            hayır        1.0
# 27          100.1            NaN        mi, değil        1.0
# 28          100.1            NaN              var        1.0
# 29          100.1            NaN             evet        1.0
# 30          100.1            NaN              var        1.0
# 31          100.1            NaN              yok        1.0
# 32          100.1            NaN  değil, mi, evet        1.0
# 33          100.1            NaN     ben, de, çok        1.0
# 34          100.1            NaN          sen, de        1.0
# 35          100.1            NaN             evet        1.0
# 36          100.1            NaN             evet        1.0
# 37          100.1            NaN               ne        1.0
# 38          100.1            NaN               ve        1.0
# 39          100.1            NaN             evet        1.0
# 40          100.1            NaN             evet        1.0
# 41          100.1            NaN             evet        1.0
# 42          100.1            NaN           bu, ne        1.0
# 43          100.1            NaN             evet        1.0
# 44          100.1            NaN           bu, ne        1.0
# 45          100.1            NaN             evet        1.0
# 46          100.1            NaN          sen, de        1.0
# 47          100.1            NaN             evet        1.0
# 48          100.1            NaN              ben        1.0
# 49          100.1            NaN              ama        1.0
# 50          100.1            NaN             evet        1.0
# 51          100.1            NaN              ama        1.0

# %%
#df_one_all.to_excel(f"Youtube_Sentence_{word_num}_Word_{word_ratio}_Ratio_Sequential_Sentences_And_Others.xlsx", index=False)

# %%
# Only Sequential Sentences
df_one_sequential = df_one[df_one.length > 1]
df_one_sequential
# Out:
#    index  length
# 0    350       2
# 1   3371       2

# %%
df_one_sequential_all = pd.DataFrame()
for i in range(len(df_one_sequential)):
    index = df_one_sequential.loc[i,"index"]
    length = df_one_sequential.loc[i,"length"]
    start_index = index
    end_index = index+length
    df_video = df_adjust_ratio_flag.iloc[start_index:end_index,]
    df_one_sequential_all = pd.concat([df_one_sequential_all, df_video],axis=0)
df_one_sequential_all.reset_index(inplace=True, drop=True)
df_one_sequential_all
# Out:
#    index    start_time      end_time sentence     video_id  28_word_ratio  \
# 0    350  00:04:45.747  00:04:46.747       ne  UDDfBEUGY60          100.1
# 1    351  00:04:47.900  00:04:48.900       ne  UDDfBEUGY60          100.1
# 2   3371  00:05:10.989  00:05:12.100    hayır  tUNXI8BQGGg          100.1
# 3   3372  00:05:12.145  00:05:12.791    hayır  tUNXI8BQGGg          100.1
#
#   different_word intersect_word  with_word
# 0            NaN             ne        1.0
# 1            NaN             ne        1.0
# 2            NaN          hayır        1.0
# 3            NaN          hayır        1.0

# %%
#df_one_sequential_all.to_excel(f"Youtube_Sentence_{word_num}_Word_{word_ratio}_Ratio_Only_Sequential_Sentences.xlsx", index=False)

# %% [markdown]
# #### Count Sentence Words By Adjust Column

# %%
#df_one_sequential_all = pd.read_excel("Youtube_Sentence_{word_num}_Word_{word_ratio}_Ratio_Only_Sequential_Sentences.xlsx")
#df_one_sequential_all

# %%
def text_to_list_df(df_target, target_column): # df_target include dict value columns, target_column occurs dict
    text_value_list = []
    for i in df_target[f"{target_column}"]:
        try:
            var = re.findall(r"\w+", i)
            for j in var:
                text_value_list.append(j)
        except:
            pass
    df_alone_value = pd.DataFrame(text_value_list)
    df_alone_value.rename(columns={0:f"{target_column}_alone"}, inplace=True)
    df_unique_count = pd.DataFrame(df_alone_value.value_counts(ascending=False))
    df_unique_count.reset_index(inplace=True)
    df_unique_count.rename(columns={0:"count"}, inplace=True)
            
    return df_unique_count

# %%
df_unique_word_count = text_to_list_df(df_one_sequential_all, "intersect_word")
df_unique_word_count
# Out:
#   intersect_word_alone  count
# 0                hayır      2
# 1                   ne      2

# %%
#df_unique_word_count.to_excel(f"Youtube_Sentence_{word_num}_Word_{word_ratio}_Ratio_Sequential_Sentence_Words_Count.xlsx", index=False)

# %% [markdown]
# #### Count Adjust Sentence Ratio Result By Videoid

# %%
df_ratio_count = pd.DataFrame(df_adjust_ratio.groupby("video_id")["28_word_ratio"].count())
df_ratio_count.reset_index(inplace=True)
df_ratio_count.rename(columns={"28_word_ratio":"28_word_ratio_count"}, inplace=True)
df_ratio_count.sort_values(by="28_word_ratio_count", ascending=False, inplace=True)
df_ratio_count.reset_index(drop=True,inplace=True)
df_ratio_count
# Out:
#       video_id  28_word_ratio_count
# 0  UDDfBEUGY60                   26
# 1  tUNXI8BQGGg                    6
# 2  EttVyq4DHYk                    5
# 3  cm40e1ChozE                    5
# 4  GWsDgpOaPH8                    4
# 5  tCadoXCM31Y                    2
# 6  3jq75SKokNQ                    1
# 7  8V9tq1pe8eI                    1
# 8  Rpz3oiCcgSg                    1
# 9  ZcTP1fmOFFI                    1

# %%
#df_ratio_count.to_excel(f"Youtube_Sentence_{word_num}_Word_{word_ratio}_Ratio_Videoid_Count.xlsx", index=False)

# %% [markdown]
# #### Multi Processing

# %%
import pandas as pd
import numpy as np
import os
import multiprocessing
#import multiprocessing as mp
from multiprocessing import Process, Manager, Pool, Queue
from itertools import islice
import re
import glob

# %%
nprocs = multiprocessing.cpu_count()
print(f"Number of CPU cores: {nprocs}")
# Out:
# Number of CPU cores: 16

# %%
folder_name = "Turkish"
word_num = 28

# %%
df_adjust_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{folder_name.lower().capitalize()}/Deployment/Result/Level 1/Opus/Word_{word_num}.xlsx")
df_adjust_word
# Out:
#      word  frequency
# 0     bir   18835735
# 1      bu   11062659
# 2      ne    8025880
# 3      ve    7766036
# 4    için    5484109
# 5      mi    5362714
# 6     ben    4908913
# 7      de    4880315
# 8     çok    4852169
# 9     ama    4661966
# 10    var    4389551
# 11   evet    4324786
# 12     mı    4001316
# 13  değil    3883885
# 14     da    3610161
# 15    şey    3602024
# 16  hayır    3406992
# 17   daha    3317577
# 18    sen    3283654
# 19  kadar    2697900
# 20   bana    2659182
# 21    yok    2491685
# 22    onu    2486889
# 23   seni    2454988
# 24   beni    2446696
# 25   bunu    2445337
# 26   gibi    2427957
# 27    iyi    2383224

# %%
df_youtube_sentence = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Youtube/Result/{folder_name.lower().capitalize()}/Sentence Clean Merge/Clean_Youtube_Sentence_Merge_Result.csv")
df_youtube_sentence = df_youtube_sentence.head(40000)
df_youtube_sentence.reset_index(inplace=True)
df_youtube_sentence
# Out:
#        index    start_time      end_time  \
# 0          0  00:00:06.680  00:00:07.340
# 1          1  00:00:07.340  00:00:08.600
# 2          2  00:00:09.440  00:00:11.060
# 3          3  00:00:11.060  00:00:11.860
# 4          4  00:00:13.380  00:00:13.880
# ...      ...           ...           ...
# 39995  39995  00:10:47.348  00:10:48.955
# 39996  39996  00:10:48.955  00:10:50.809
# 39997  39997  00:10:50.809  00:10:53.841
# 39998  39998  00:10:53.841  00:10:56.070
# 39999  39999  00:10:56.070  00:10:58.615
#
#                                        sentence     video_id
# 0                               sen kimsin peki  JR7nKXxUVtM
# 1                                parolayı söyle  JR7nKXxUVtM
# 2                           ya ben kim olacağım  JR7nKXxUVtM
# 3                                   keloğlan ım  JR7nKXxUVtM
# 4                                            ey  JR7nKXxUVtM
# ...                                         ...          ...
# 39995                   o yüzden geri çıkıyoruz  rUafZNR1GxY
# 39996               haliyle buraya gelecekseniz  rUafZNR1GxY
# 39997  sabah erken saatlerde gelmenizi öneririm  rUafZNR1GxY
# 39998             çünkü yer sınırlı olduğu için  rUafZNR1GxY
# 39999   zaman zaman oturacak yer bulamıyorsunuz  rUafZNR1GxY
#
# [40000 rows x 5 columns]

# %%
# import os
# from multiprocessing import Process, Manager, Pool, Queue
manager = multiprocessing.Manager()
result_list = manager.list()
word_set = set(df_adjust_word["word"].to_list())
index_num = list(range(len(df_youtube_sentence)))

def sentence_word_ratio(index_num):
    index = df_youtube_sentence.loc[index_num,"index"]
    start = df_youtube_sentence.loc[index_num,"start_time"]
    end = df_youtube_sentence.loc[index_num,"end_time"]
    sentence = df_youtube_sentence.loc[index_num,"sentence"]
    videoid = df_youtube_sentence.loc[index_num,"video_id"]

    sent_word = re.findall(r"\w+", sentence, re.UNICODE)
    sent_word_set = set(sent_word)
    intersect_word = list(word_set.intersection(sent_word_set))
    different_word = list(sent_word_set.difference(word_set))
    word_ratio = (len(intersect_word)/len(sent_word)+0.001)*100
    different = ", ".join(different_word)
    intersect = ", ".join(intersect_word)

    result_list.append([index,start,end,sentence,videoid,word_ratio,different,intersect])  
    
   
if __name__ == '__main__':
    # with Pool(16) as p:
    with Pool(nprocs) as p: # Pool number CPU sayısına eşit olursa tüm CPU lar çalışır
        p.map(sentence_word_ratio, index_num) # zip_list fonksiyon için çoklu eleman gerekli olduğu için kullanıldı.
# Not: starmap çoklu iterable değerlere ihtiyaç duyan fonksiyonlar için kullanılıyor ve bu değerler zip veya itertools şeklinde olmalı. O yüzden burada pool.map yerine pool.starmap kullanıldı.

# %%
df_sentence_ratio_result = pd.DataFrame(list(result_list), columns=["index","start_time","end_time","sentence","video_id",f"{word_num}_word_ratio","different_word","intersect_word"])
df_sentence_ratio_result.sort_values(by="index", ascending=True, inplace=True)
df_sentence_ratio_result.reset_index(drop=True, inplace=True)
df_sentence_ratio_result
# Out:
#        index    start_time      end_time  \
# 0          0  00:00:06.680  00:00:07.340
# 1          1  00:00:07.340  00:00:08.600
# 2          2  00:00:09.440  00:00:11.060
# 3          3  00:00:11.060  00:00:11.860
# 4          4  00:00:13.380  00:00:13.880
# ...      ...           ...           ...
# 39995  39995  00:10:47.348  00:10:48.955
# 39996  39996  00:10:48.955  00:10:50.809
# 39997  39997  00:10:50.809  00:10:53.841
# 39998  39998  00:10:53.841  00:10:56.070
# 39999  39999  00:10:56.070  00:10:58.615
#
#                                        sentence     video_id  28_word_ratio  \
# 0                               sen kimsin peki  JR7nKXxUVtM      33.433333
# 1                                parolayı söyle  JR7nKXxUVtM       0.100000
# 2                           ya ben kim olacağım  JR7nKXxUVtM      25.100000
# 3                                   keloğlan ım  JR7nKXxUVtM       0.100000
# 4                                            ey  JR7nKXxUVtM       0.100000
# ...                                         ...          ...            ...
# 39995                   o yüzden geri çıkıyoruz  rUafZNR1GxY       0.100000
# 39996               haliyle buraya gelecekseniz  rUafZNR1GxY       0.100000
# 39997  sabah erken saatlerde gelmenizi öneririm  rUafZNR1GxY       0.100000
# 39998             çünkü yer sınırlı olduğu için  rUafZNR1GxY      20.100000
# 39999   zaman zaman oturacak yer bulamıyorsunuz  rUafZNR1GxY       0.100000
#
#                                      different_word intersect_word
# 0                                      kimsin, peki            sen
# 1                                   parolayı, söyle
# 2                                 olacağım, kim, ya            ben
# 3                                      keloğlan, ım
# 4                                                ey
# ...                                             ...            ...
# 39995                    o, yüzden, çıkıyoruz, geri
# 39996                 haliyle, gelecekseniz, buraya
# 39997  saatlerde, sabah, öneririm, erken, gelmenizi
# 39998                   yer, sınırlı, olduğu, çünkü           için
# 39999          oturacak, bulamıyorsunuz, yer, zaman
#
# [40000 rows x 8 columns]

# %%
df_sentence_ratio_result["different_word"] = df_sentence_ratio_result["different_word"].apply(lambda x: np.nan if x == "" else x)
df_sentence_ratio_result["intersect_word"] = df_sentence_ratio_result["intersect_word"].apply(lambda x: np.nan if x == "" else x)
df_sentence_ratio_result
# Out:
#        index    start_time      end_time  \
# 0          0  00:00:06.680  00:00:07.340
# 1          1  00:00:07.340  00:00:08.600
# 2          2  00:00:09.440  00:00:11.060
# 3          3  00:00:11.060  00:00:11.860
# 4          4  00:00:13.380  00:00:13.880
# ...      ...           ...           ...
# 39995  39995  00:10:47.348  00:10:48.955
# 39996  39996  00:10:48.955  00:10:50.809
# 39997  39997  00:10:50.809  00:10:53.841
# 39998  39998  00:10:53.841  00:10:56.070
# 39999  39999  00:10:56.070  00:10:58.615
#
#                                        sentence     video_id  28_word_ratio  \
# 0                               sen kimsin peki  JR7nKXxUVtM      33.433333
# 1                                parolayı söyle  JR7nKXxUVtM       0.100000
# 2                           ya ben kim olacağım  JR7nKXxUVtM      25.100000
# 3                                   keloğlan ım  JR7nKXxUVtM       0.100000
# 4                                            ey  JR7nKXxUVtM       0.100000
# ...                                         ...          ...            ...
# 39995                   o yüzden geri çıkıyoruz  rUafZNR1GxY       0.100000
# 39996               haliyle buraya gelecekseniz  rUafZNR1GxY       0.100000
# 39997  sabah erken saatlerde gelmenizi öneririm  rUafZNR1GxY       0.100000
# 39998             çünkü yer sınırlı olduğu için  rUafZNR1GxY      20.100000
# 39999   zaman zaman oturacak yer bulamıyorsunuz  rUafZNR1GxY       0.100000
#
#                                      different_word intersect_word
# 0                                      kimsin, peki            sen
# 1                                   parolayı, söyle            NaN
# 2                                 olacağım, kim, ya            ben
# 3                                      keloğlan, ım            NaN
# 4                                                ey            NaN
# ...                                             ...            ...
# 39995                    o, yüzden, çıkıyoruz, geri            NaN
# 39996                 haliyle, gelecekseniz, buraya            NaN
# 39997  saatlerde, sabah, öneririm, erken, gelmenizi            NaN
# 39998                   yer, sınırlı, olduğu, çünkü           için
# 39999          oturacak, bulamıyorsunuz, yer, zaman            NaN
#
# [40000 rows x 8 columns]

# %% [markdown]
# #### Find Word In Sentence Time Interval

# %%
folder_name = "Turkish"
word_num = 206
level = "level 2"

# %%
df_word_count_low = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{folder_name.lower().capitalize()}/Deployment/Result/{level.lower().capitalize()}/3-Lesson Level Result/Lesson_{level.lower().capitalize()}_Low_Count_Words.xlsx")
df_word_count_low
# Out:
#        word  count
# 0    yardım      6
# 1        ve      6
# 2        oh      6
# 3       ona      6
# 4      bize      6
# ..      ...    ...
# 116   vardı      1
# 117    size      1
# 118     tüm      1
# 119    gece      1
# 120  olarak      1
#
# [121 rows x 2 columns]

# %%
df_sent = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Youtube/Result/Turkish/Sentence Clean Merge/Clean_Youtube_Sentence_Merge_Result.csv")
df_sent
# Out:
#           start_time      end_time                               sentence  \
# 0       00:00:06.680  00:00:07.340                        sen kimsin peki
# 1       00:00:07.340  00:00:08.600                         parolayı söyle
# 2       00:00:09.440  00:00:11.060                    ya ben kim olacağım
# 3       00:00:11.060  00:00:11.860                            keloğlan ım
# 4       00:00:13.380  00:00:13.880                                     ey
# ...              ...           ...                                    ...
# 387903  00:02:11.720  00:02:14.440  gözlerin bir an bile çıkmadı aklımdan
# 387904  00:02:15.560  00:02:19.320       koynumdaysa hala o ufak bin lira
# 387905  00:02:20.320  00:02:21.200                                   sahi
# 387906  00:02:21.720  00:02:24.480                diğer eşi sende mi hala
# 387907  00:02:30.000  00:02:35.000                          ufak bin lira
#
#            video_id
# 0       JR7nKXxUVtM
# 1       JR7nKXxUVtM
# 2       JR7nKXxUVtM
# 3       JR7nKXxUVtM
# 4       JR7nKXxUVtM
# ...             ...
# 387903  7R3K6EDaBGE
# 387904  7R3K6EDaBGE
# 387905  7R3K6EDaBGE
# 387906  7R3K6EDaBGE
# 387907  7R3K6EDaBGE
#
# [387908 rows x 4 columns]

# %%
df_sent['start_time'] = pd.to_timedelta(df_sent['start_time']) # data type converted timedelta for second 
df_sent['end_time'] = pd.to_timedelta(df_sent['end_time'])

# %%
df_sent['start_time'] = df_sent['start_time'].apply(lambda x: x.total_seconds()) # convert seconds
df_sent['end_time'] = df_sent['end_time'].apply(lambda x: x.total_seconds())
df_sent
# Out:
#         start_time  end_time                               sentence  \
# 0             6.68      7.34                        sen kimsin peki
# 1             7.34      8.60                         parolayı söyle
# 2             9.44     11.06                    ya ben kim olacağım
# 3            11.06     11.86                            keloğlan ım
# 4            13.38     13.88                                     ey
# ...            ...       ...                                    ...
# 387903      131.72    134.44  gözlerin bir an bile çıkmadı aklımdan
# 387904      135.56    139.32       koynumdaysa hala o ufak bin lira
# 387905      140.32    141.20                                   sahi
# 387906      141.72    144.48                diğer eşi sende mi hala
# 387907      150.00    155.00                          ufak bin lira
#
#            video_id
# 0       JR7nKXxUVtM
# 1       JR7nKXxUVtM
# 2       JR7nKXxUVtM
# 3       JR7nKXxUVtM
# 4       JR7nKXxUVtM
# ...             ...
# 387903  7R3K6EDaBGE
# 387904  7R3K6EDaBGE
# 387905  7R3K6EDaBGE
# 387906  7R3K6EDaBGE
# 387907  7R3K6EDaBGE
#
# [387908 rows x 4 columns]

# %%
word_list = df_word_count_low.iloc[:,0].values.tolist()

# %%
df_word_result = pd.DataFrame()
for i in word_list:
    try:
        word_in_video = df_sent[df_sent.sentence.str.contains(fr"(?:\s|^){i}(?:\s|$)", na=True)].sample(1)
    except:
        word_in_video = df_sent[df_sent.sentence.str.contains(fr"(?:\s|^){i}(?:\s|$)", na=True)].head(1) 
    word_in_video.insert(0,"word",i)
    df_word_result = pd.concat([df_word_result,word_in_video], axis=0)
df_word_result.reset_index(drop=True, inplace=True)
df_word_result = df_word_result.sort_values(by=["video_id","start_time"], ascending=True)
df_word_result.reset_index(drop=True, inplace=True)
df_word_result
# Out:
#        word  start_time  end_time  \
# 0       pek      12.249    15.924
# 1    önemli     692.083   694.044
# 2      yeni    1782.048  1787.248
# 3       son     151.040   154.100
# 4    hiçbir     128.340   135.659
# ..      ...         ...       ...
# 116    beni     208.770   215.220
# 117    bunu      49.146    50.720
# 118      en     209.379   213.810
# 119   kadar      18.944    23.296
# 120   gerek     690.764   691.724
#
#                                               sentence     video_id
# 0    ilk olarak sormamız gereken soru pek tabi ki m...  0WucJZifF6w
# 1          burada emlakçıların çok önemli bir payı var  0WucJZifF6w
# 2    bir senaryo verilmiş bunun üzerinden yeni bir ...  0n3FlTxTUG8
# 3                              son yıllarda uzmanlar h  0xFmSqha4ms
# 4    hamurunuz da hiçbir şekilde kokusu ve tadı his...  1cWoQnLFMRA
# ..                                                 ...          ...
# 116  bölümüne yazarsanız videoyu beğenirseniz ve an...  yRw1Y4Rblkg
# 117                        yani bunu her sabah yapıyor  z60801HZBmQ
# 118  kendi ülkesinin ihtiyacı varken kimse başka bi...  zZ7nvW1e03M
# 119  ne kadar hiçbir aktivitede bulunmazsam hamile ...  zidlx3JojIo
# 120                       ondan bir ısırık almam gerek  zqhlxwKFJXo
#
# [121 rows x 5 columns]

# %%
word_time_loc_list = []
def word_time_loc(df):
    for i in range(len(df)):
        word = df.loc[i,"word"]
        start_time = df.loc[i,"start_time"]
        end_time = df.loc[i,"end_time"]
        sentence = df.loc[i,"sentence"]
        video_id = df.loc[i,"video_id"]
        time_length = end_time-start_time
        sentence_length = len(sentence)
        time_length_ratio = time_length/sentence_length
        loc_list = []
        for j in re.finditer(fr"(?:\s|^){word}(?:\s|$)", sentence, re.IGNORECASE|re.UNICODE):
            loc_list.append(j)
            start = loc_list[0].start()
            end = loc_list[0].end()
            start_loc = start_time+(start*time_length_ratio)
            end_loc = start_time+(end*time_length_ratio)
        word_time_loc_list.append([word,start_loc,end_loc,sentence,video_id])
    df_word_time_loc = pd.DataFrame(word_time_loc_list, columns=["word","start_time","end_time","sentence","video_id"])

    return df_word_time_loc

# %%
word_time_loc(df_word_result)
# Out:
#        word   start_time     end_time  \
# 0       pek    14.349000    14.677125
# 1    önemli   693.131907   693.496744
# 2      yeni  1785.332211  1785.879579
# 3       son   151.040000   151.572174
# 4    hiçbir   129.908357   130.953929
# ..      ...          ...          ...
# 116    beni   214.422809   214.857640
# 117    bunu    49.379185    49.728963
# 118      en   212.413932   212.656726
# 119   kadar    19.058526    19.459368
# 120   gerek   691.518286   691.724000
#
#                                               sentence     video_id
# 0    ilk olarak sormamız gereken soru pek tabi ki m...  0WucJZifF6w
# 1          burada emlakçıların çok önemli bir payı var  0WucJZifF6w
# 2    bir senaryo verilmiş bunun üzerinden yeni bir ...  0n3FlTxTUG8
# 3                              son yıllarda uzmanlar h  0xFmSqha4ms
# 4    hamurunuz da hiçbir şekilde kokusu ve tadı his...  1cWoQnLFMRA
# ..                                                 ...          ...
# 116  bölümüne yazarsanız videoyu beğenirseniz ve an...  yRw1Y4Rblkg
# 117                        yani bunu her sabah yapıyor  z60801HZBmQ
# 118  kendi ülkesinin ihtiyacı varken kimse başka bi...  zZ7nvW1e03M
# 119  ne kadar hiçbir aktivitede bulunmazsam hamile ...  zidlx3JojIo
# 120                       ondan bir ısırık almam gerek  zqhlxwKFJXo
#
# [121 rows x 5 columns]

# %%
test_text = "güneş gökyüzünde pırıl pırıl parlıyordu. Birden gökyüzünde bulutlar belirdi"

# %%
len(test_text)
# Out:
# 75

# %%
loc_list = []
for i in re.finditer(fr"(?:\s|^)gökyüzünde(?:\s|$)", test_text, re.IGNORECASE|re.UNICODE):
    loc_list.append(i)

# %%
loc_list
# Out:
# [<re.Match object; span=(5, 17), match=' gökyüzünde '>,
#  <re.Match object; span=(47, 59), match=' gökyüzünde '>]

# %%
loc_list[0]
# Out:
# <re.Match object; span=(5, 17), match=' gökyüzünde '>

# %%
loc_list[0].start()
# Out:
# 5

# %%
loc_list[0].end()
# Out:
# 17

# %%
time_length_ratio = 0.01

# %% [markdown]
# ### String In Word Group

# %%
def string_in_wordgroup(df, list_value, target_column):

    '''word_in_wordgroup(df, "word", "twogram"):
       df is dataframe, list_column and target_column are 
       dataframe column string name. list_column convert list
       values that are in target column.
    '''
    
    df_select = df[[f"{target_column}"]].dropna()
    df_search_result = pd.DataFrame()
    #for i in df[f"{list_column}"].dropna():
    for i in list_value:
        try:
            #word_in_word_cluster = df_select[df_select[f"{target_column}"].str.contains(fr"(?:\s|^){i}(?:\s|$)", na=True)].head(6)
            string_in_word_cluster = df_select[df_select[f"{target_column}"].str.contains(fr"{i}", na=True)].head(6) 
        except:
            pass        
        string_in_word_cluster.insert(0,"search_value",i)
        df_search_result = pd.concat([df_search_result,string_in_word_cluster], axis=0)
    df_search_result.reset_index(drop=True, inplace=True)

    return df_search_result

# %%
df_opus_sent = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Turkish/Result/Sentence/Merge/Sentence_Merge.csv")
df_opus_sent = df_opus_sent[["sentence","frequency"]]
df_opus_sent
# Out:
#                                                   sentence  frequency
# 0                                                     evet    1948596
# 1                                                   fikret    1533918
# 2                                                    hayır    1250401
# 3                                                    tamam     882921
# 4                                                       ne     753105
# ...                                                    ...        ...
# 2913965                hayır ben bir pikap kamyon alacağım          6
# 2913966                                 eminim uydurmuştur          6
# 2913967  hemen bir kement ile onu yakalar ve aşağı çekerim          6
# 2913968                     tabii gerçek bir profesyonel o          6
# 2913969                                       _ adı fikret          6
#
# [2913970 rows x 2 columns]

# %%
df_threegram = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Turkish/Result/N Gram/Merge/Threegram_Merge.csv")
df_threegram = df_threegram[["threegram","frequency"]]
df_threegram
# Out:
#                         threegram  frequency
# 0                     bir şey yok     113165
# 1                     bir şey var     110455
# 2                        bu da ne      89463
# 3                 her şey yolunda      75968
# 4                   başka bir şey      75193
# ...                           ...        ...
# 3009751        haydi büyük fikret          5
# 3009752     fikret caesardan beri          5
# 3009753       fikret cage kazandı          5
# 3009754      haydi bakayım fikret          5
# 3009755  şimdilik hoşçakal fikret          5
#
# [3009756 rows x 2 columns]

# %%
df_fourgram = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Turkish/Result/N Gram/Merge/Fourgram_Merge.csv")
df_fourgram = df_fourgram[["fourgram","frequency"]]
df_fourgram
# Out:
#                            fourgram  frequency
# 0                    bir şey var mı      41773
# 1                her şey yolunda mı      31126
# 2                burada ne işin var      21993
# 3                  bir sorun mu var      21423
# 4             ben de seni seviyorum      17338
# ...                             ...        ...
# 3052209    fikret miloya merhaba de          5
# 3052210      fikret millsin oğlu mu          5
# 3052211        fikret millet iyi iş          5
# 3052212  fikret millet bize bakıyor          5
# 3052213    bayan fikret hoşça kalın          5
#
# [3052214 rows x 2 columns]

# %%
df_fivegram = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Turkish/Result/N Gram/Merge/Fivegram_Merge.csv")
df_fivegram = df_fivegram[["fivegram","frequency"]]
df_fivegram
# Out:
#                                       fivegram  frequency
# 0                         başka bir şey var mı      14104
# 1                        bu da ne demek oluyor      10205
# 2                        o kadar da kötü değil       7012
# 3                       sence de öyle değil mi       6305
# 4                 sana bir şey sorabilir miyim       6224
# ...                                        ...        ...
# 1096831        peder fikret hep şöyle söylerdi          4
# 1096832  peder fikret intihar etmeye çalışıyor          4
# 1096833            fikret dolson 12 gün yaşadı          4
# 1096834             ama fikret diye biri yoktu          4
# 1096835     okumaz ve düşünmezler derdi fikret          4
#
# [1096836 rows x 2 columns]

# %%
word_list = ["numarayı kontrol", "biraz kontrolden", "sistem kontrolü", "bombanın kontrolünü", "oteli kontrol", "robot kontrol", "biraz kontrol", "makineleri kontrol", "motoru kontrol", "kontrol sistemi", "sistemleri kontrol", "telefonunu kontrol", "sistemi kontrol", "fazla kontrol", "rutin kontrol", "sistemini kontrol", "kalite kontrol", "bombayı kontrol", "metropolis kontrol", "asansörü kontrol"]

# %%
df_result_sent = string_in_wordgroup(df_opus_sent, word_list, "sentence")
df_result_sent
# Out:
#           search_value                                           sentence
# 0     numarayı kontrol         lütfen numarayı kontrol edip tekrar arayın
# 1     numarayı kontrol               numarayı kontrol edip tekrar deneyin
# 2     numarayı kontrol                       üç numarayı kontrol ettin mi
# 3     numarayı kontrol                       lütfen numarayı kontrol edin
# 4     numarayı kontrol  beni sürekli arayan şu numarayı kontrol et 555...
# ..                 ...                                                ...
# 93     bombayı kontrol  söylemeye çalıştığı general bombayı kontrol ed...
# 94  metropolis kontrol  metropolis kontrol kulesi burası n7241h kodlu ...
# 95    asansörü kontrol                         bogdan asansörü kontrol et
# 96    asansörü kontrol                                asansörü kontrol et
# 97    asansörü kontrol                              asansörü kontrol edin
#
# [98 rows x 2 columns]

# %%
df_merge_result_sent = pd.merge(df_result_sent,df_opus_sent, how="left", on="sentence")
df_merge_result_sent.drop_duplicates(inplace=True)
df_merge_result_sent.sort_values(by="frequency", ascending=False, inplace=True)
df_merge_result_sent
# Out:
#           search_value                                           sentence  \
# 32       biraz kontrol                      i̇şler biraz kontrolden çıktı
# 6     biraz kontrolden                      i̇şler biraz kontrolden çıktı
# 94  metropolis kontrol  metropolis kontrol kulesi burası n7241h kodlu ...
# 12     sistem kontrolü                                    sistem kontrolü
# 30       robot kontrol  elimizdeki pilotları yörüngedeki robot kontrol...
# ..                 ...                                                ...
# 47      motoru kontrol                                motoru kontrol edin
# 82   sistemini kontrol  onu kapatalım çalışmasını sistemini kontrol ed...
# 11    biraz kontrolden      bugün işler biraz kontrolden çıktı ve sanırım
# 42  makineleri kontrol  makineleri kontrol eden bilgisayar skynet geri...
# 10    biraz kontrolden                  evet işler biraz kontrolden çıktı
#
#     frequency
# 32         74
# 6          74
# 94         45
# 12         38
# 30         36
# ..        ...
# 47          7
# 82          7
# 11          7
# 42          7
# 10          7
#
# [98 rows x 3 columns]

# %%
df_merge_result_sent.groupby(["search_value"])[["frequency"]].sum().sort_values(by="frequency", ascending=False)
# Out:
#                      frequency
# search_value
# biraz kontrol              162
# biraz kontrolden           117
# sistem kontrolü            103
# kalite kontrol             101
# numarayı kontrol            96
# bombanın kontrolünü         87
# rutin kontrol               85
# fazla kontrol               81
# kontrol sistemi             79
# robot kontrol               72
# sistemi kontrol             71
# oteli kontrol               69
# makineleri kontrol          68
# motoru kontrol              66
# sistemleri kontrol          60
# telefonunu kontrol          58
# bombayı kontrol             50
# sistemini kontrol           46
# metropolis kontrol          45
# asansörü kontrol            38

# %%
df_result_three = string_in_wordgroup(df_threegram, word_list, "threegram")
df_result_three
# Out:
#           search_value                  threegram
# 0     numarayı kontrol    lütfen numarayı kontrol
# 1     numarayı kontrol      numarayı kontrol edip
# 2     numarayı kontrol      numarayı kontrol edin
# 3     numarayı kontrol    numarayı kontrol ediniz
# 4     numarayı kontrol        numarayı kontrol et
# ..                 ...                        ...
# 90     bombayı kontrol        ben bombayı kontrol
# 91     bombayı kontrol   bombayı kontrol ediyorum
# 92  metropolis kontrol  metropolis kontrol kulesi
# 93    asansörü kontrol        asansörü kontrol et
# 94    asansörü kontrol    bogdan asansörü kontrol
#
# [95 rows x 2 columns]

# %%
df_merge_result_three = pd.merge(df_result_three,df_threegram, how="left", on="threegram")
df_merge_result_three.drop_duplicates(inplace=True)
df_merge_result_three.sort_values(by="frequency", ascending=False, inplace=True)
df_merge_result_three
# Out:
#            search_value                   threegram  frequency
# 33        biraz kontrol      biraz kontrolden çıktı        166
# 6      biraz kontrolden      biraz kontrolden çıktı        166
# 0      numarayı kontrol     lütfen numarayı kontrol         90
# 1      numarayı kontrol       numarayı kontrol edip         87
# 66        fazla kontrol          daha fazla kontrol         84
# ..                  ...                         ...        ...
# 72        rutin kontrol      yüzbaşım rutin kontrol         11
# 74        rutin kontrol     rutin kontrol yapacağız         11
# 80    sistemini kontrol    sistemini kontrol edelim         11
# 23  bombanın kontrolünü   bombanın kontrolünü başka         10
# 17      sistem kontrolü  sistem kontrolünü başlatın         10
#
# [95 rows x 3 columns]

# %%
df_merge_result_three.groupby(["search_value"])[["frequency"]].sum().sort_values(by="frequency", ascending=False)
# Out:
#                      frequency
# search_value
# biraz kontrol              365
# biraz kontrolden           347
# numarayı kontrol           295
# fazla kontrol              179
# bombanın kontrolünü        148
# sistemleri kontrol         148
# robot kontrol              144
# sistemi kontrol            137
# sistemini kontrol          134
# kontrol sistemi            112
# makineleri kontrol         109
# kalite kontrol             100
# sistem kontrolü             93
# oteli kontrol               87
# bombayı kontrol             81
# metropolis kontrol          45
# asansörü kontrol            39
# motoru kontrol              36
# rutin kontrol               33
# telefonunu kontrol          33

# %%
df_result_four = string_in_wordgroup(df_fourgram, word_list, "fourgram")
df_result_four
# Out:
#           search_value                                fourgram
# 0     numarayı kontrol            numarayı kontrol edip tekrar
# 1     numarayı kontrol            lütfen numarayı kontrol edip
# 2     numarayı kontrol               numarayı kontrol ettin mi
# 3     numarayı kontrol               üç numarayı kontrol ettin
# 4     numarayı kontrol      lütfen aradığınız numarayı kontrol
# ..                 ...                                     ...
# 88     bombayı kontrol  general bombayı kontrol edebileceğimiz
# 89     bombayı kontrol            ben bombayı kontrol ediyorum
# 90     bombayı kontrol              bombayı kontrol ediyorum o
# 91     bombayı kontrol            yani general bombayı kontrol
# 92  metropolis kontrol        metropolis kontrol kulesi burası
#
# [93 rows x 2 columns]

# %%
df_merge_result_four = pd.merge(df_result_four,df_fourgram, how="left", on="fourgram")
df_merge_result_four.drop_duplicates(inplace=True)
df_merge_result_four.sort_values(by="frequency", ascending=False, inplace=True)
df_merge_result_four
# Out:
#            search_value                            fourgram  frequency
# 0      numarayı kontrol        numarayı kontrol edip tekrar         77
# 6      biraz kontrolden       i̇şler biraz kontrolden çıktı         74
# 35        biraz kontrol       i̇şler biraz kontrolden çıktı         74
# 18  bombanın kontrolünü  bombanın kontrolünü halktan birine         53
# 92   metropolis kontrol    metropolis kontrol kulesi burası         45
# ..                  ...                                 ...        ...
# 61      sistemi kontrol     tek sıra sistemi kontrolsüzlüğü          9
# 46   makineleri kontrol        makineleri kontrol eden oldu          9
# 75        rutin kontrol        bölgede rutin kontrol görevi          8
# 63      sistemi kontrol         çıkmak için sistemi kontrol          8
# 17      sistem kontrolü         sistem kontrolü yapın sonra          7
#
# [93 rows x 3 columns]

# %%
df_merge_result_four.groupby(["search_value"])[["frequency"]].sum().sort_values(by="frequency", ascending=False)
# Out:
#                      frequency
# search_value
# numarayı kontrol           182
# robot kontrol              180
# biraz kontrol              170
# biraz kontrolden           147
# bombanın kontrolünü        133
# sistemi kontrol            117
# kalite kontrol             102
# oteli kontrol               97
# bombayı kontrol             92
# kontrol sistemi             91
# sistemini kontrol           88
# fazla kontrol               84
# makineleri kontrol          80
# sistem kontrolü             61
# rutin kontrol               59
# metropolis kontrol          45
# sistemleri kontrol          27
# motoru kontrol              18

# %%
df_result_five = string_in_wordgroup(df_fivegram, word_list, "fivegram")
df_result_five
# Out:
#           search_value                                     fivegram
# 0     numarayı kontrol          lütfen numarayı kontrol edip tekrar
# 1     numarayı kontrol          numarayı kontrol edip tekrar arayın
# 2     numarayı kontrol         numarayı kontrol edip tekrar deneyin
# 3     numarayı kontrol                 üç numarayı kontrol ettin mi
# 4     numarayı kontrol               şu numarayı kontrol et 5554085
# ..                 ...                                          ...
# 69     bombayı kontrol    general bombayı kontrol edebileceğimiz 12
# 70     bombayı kontrol               ben bombayı kontrol ediyorum o
# 71     bombayı kontrol              bombayı kontrol ediyorum o beni
# 72     bombayı kontrol  yani general bombayı kontrol edebileceğimiz
# 73  metropolis kontrol      metropolis kontrol kulesi burası n7241h
#
# [74 rows x 2 columns]

# %%
df_merge_result_five = pd.merge(df_result_five,df_fivegram, how="left", on="fivegram")
df_merge_result_five.drop_duplicates(inplace=True)
df_merge_result_five.sort_values(by="frequency", ascending=False, inplace=True)
df_merge_result_five
# Out:
#           search_value                                         fivegram  \
# 24       robot kontrol                      bu bir robot kontrol gemisi
# 73  metropolis kontrol          metropolis kontrol kulesi burası n7241h
# 0     numarayı kontrol              lütfen numarayı kontrol edip tekrar
# 28       robot kontrol     pilotları yörüngedeki robot kontrol gemisini
# 27       robot kontrol      yörüngedeki robot kontrol gemisini devreden
# ..                 ...                                              ...
# 56       rutin kontrol             hurda teknesi yüzbaşım rutin kontrol
# 55       rutin kontrol  iraklıların kontrolündeki bölgede rutin kontrol
# 66      kalite kontrol               bir kalite kontrol testi yapacağız
# 43     kontrol sistemi        modülü reaksiyon kontrol sistemi valfleri
# 57       rutin kontrol                sadece rutin kontrol bayan fikret
#
#     frequency
# 24         72
# 73         45
# 0          44
# 28         36
# 27         36
# ..        ...
# 56         11
# 55         11
# 66         10
# 43         10
# 57          9
#
# [74 rows x 3 columns]

# %%
df_merge_result_five.groupby(["search_value"])[["frequency"]].sum().sort_values(by="frequency", ascending=False)
# Out:
#                      frequency
# search_value
# robot kontrol              216
# numarayı kontrol           136
# sistemi kontrol            116
# bombanın kontrolünü        105
# oteli kontrol               99
# kalite kontrol              94
# bombayı kontrol             92
# kontrol sistemi             87
# fazla kontrol               84
# biraz kontrol               73
# sistemini kontrol           70
# makineleri kontrol          53
# metropolis kontrol          45
# biraz kontrolden            44
# rutin kontrol               42
# sistem kontrolü             27

# %% [markdown]
# ### Selected Search In Youtube

# %%
df_youtube_sent = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Youtube/Result/Turkish/Sentence Clean Merge/Clean_Youtube_Sentence_Merge_Result.csv")
df_youtube_sent
# Out:
#            start_time      end_time  \
# 0        00:02:51.948  00:02:58.829
# 1        00:03:00.956  00:03:04.236
# 2        00:03:13.434  00:03:16.327
# 3        00:03:17.235  00:03:21.338
# 4        00:03:27.806  00:03:33.383
# ...               ...           ...
# 3036932  00:07:51.970  00:07:52.470
# 3036933  00:07:52.470  00:08:02.304
# 3036934  00:08:02.498  00:08:04.178
# 3036935  00:08:04.178  00:08:08.089
# 3036936  00:08:08.089  00:08:11.770
#
#                                                   sentence     video_id
# 0        özgür bunlar normalde kamyon daha büyük araçla...  8V9tq1pe8eI
# 1               burcu arka tarafı bağlamak kolay olmayacak  8V9tq1pe8eI
# 2                      özgür arabaya yarım tur attıracağım  8V9tq1pe8eI
# 3            burcu biraz daha devam et devam et tamam oldu  8V9tq1pe8eI
# 4        burcu şimdilik iki tekere takacağız ama kar ka...  8V9tq1pe8eI
# ...                                                    ...          ...
# 3036932  umarız ki bu büyük ve güçlü teknoloji yanlış e...  YFFJ5FyZj4Q
# 3036933  daha faydalı ve özgün kurumlarda herkesin eşit...  YFFJ5FyZj4Q
# 3036934                      i zlediğiniz için teşekkürler  YFFJ5FyZj4Q
# 3036935  yararlandığım kaynakları açıklamada link olara...  YFFJ5FyZj4Q
# 3036936  i leri düzey okuma ve araştırma yapmak isteyen...  YFFJ5FyZj4Q
#
# [3036937 rows x 4 columns]

# %%
df_youtube_sent['start_time'] = pd.to_timedelta(df_youtube_sent['start_time']) # data type converted timedelta for second 
df_youtube_sent['end_time'] = pd.to_timedelta(df_youtube_sent['end_time'])

# %%
df_youtube_sent['start_time'] = df_youtube_sent['start_time'].apply(lambda x: x.total_seconds()) # convert seconds
df_youtube_sent['end_time'] = df_youtube_sent['end_time'].apply(lambda x: x.total_seconds())
df_youtube_sent
# Out:
#          start_time  end_time  \
# 0           171.948   178.829
# 1           180.956   184.236
# 2           193.434   196.327
# 3           197.235   201.338
# 4           207.806   213.383
# ...             ...       ...
# 3036932     471.970   472.470
# 3036933     472.470   482.304
# 3036934     482.498   484.178
# 3036935     484.178   488.089
# 3036936     488.089   491.770
#
#                                                   sentence     video_id
# 0        özgür bunlar normalde kamyon daha büyük araçla...  8V9tq1pe8eI
# 1               burcu arka tarafı bağlamak kolay olmayacak  8V9tq1pe8eI
# 2                      özgür arabaya yarım tur attıracağım  8V9tq1pe8eI
# 3            burcu biraz daha devam et devam et tamam oldu  8V9tq1pe8eI
# 4        burcu şimdilik iki tekere takacağız ama kar ka...  8V9tq1pe8eI
# ...                                                    ...          ...
# 3036932  umarız ki bu büyük ve güçlü teknoloji yanlış e...  YFFJ5FyZj4Q
# 3036933  daha faydalı ve özgün kurumlarda herkesin eşit...  YFFJ5FyZj4Q
# 3036934                      i zlediğiniz için teşekkürler  YFFJ5FyZj4Q
# 3036935  yararlandığım kaynakları açıklamada link olara...  YFFJ5FyZj4Q
# 3036936  i leri düzey okuma ve araştırma yapmak isteyen...  YFFJ5FyZj4Q
#
# [3036937 rows x 4 columns]

# %%
df_test = df_youtube_sent[df_youtube_sent.sentence.str.contains(fr"(?:\s|^)bir polis(?:\s|$)", na=True)]
df_test
# Out:
#          start_time  end_time  \
# 83183      1498.670  1505.990
# 169337      152.250   159.270
# 178022       88.188    90.948
# 200440      712.663   718.743
# 365436     1464.481  1467.841
# ...             ...       ...
# 2654072     218.660   225.590
# 2656784     364.760   367.880
# 2657925    2176.080  2185.560
# 2734089    1671.870  1676.820
# 2894285    4848.730  4857.580
#
#                                                   sentence     video_id
# 83183    kolik bebekler i nsan bir polis dediğimiz bir ...  DEiWkLwHS6Y
# 169337   zamana kadar hiç bir polis çok kontör gelmedi ...  v9C2lMvuYR8
# 178022   bir polis şiddetine maruz kaldım daha sonra gö...  l7mITXdbzNw
# 200440   polis olur mu olmaz kahraman çocuklarım her gü...  LS6ra7RK6NA
# 365436   senin gibi bir polis adayına hiç yakıştıramadı...  RVaNiCkhMJg
# ...                                                    ...          ...
# 2654072  yazdım yine polar olan başkasını hidropiktir k...  osW3FxJ9VGc
# 2656784  ovidio guzman bir polis çevirmesi sırasında ya...  MZLGtMHzb_Q
# 2657925  sazan gibi atmak ondan bir projenin bağlı olac...  rKpNLCUBvks
# 2734089  kulübenin içinde gözlerini sımsıkı kapamış sak...  fA5dG8UqneU
# 2894285  deniyor bilmiyorum bir müşterimiz vardı o bize...  EyQTMdxuqSs
#
# [106 rows x 4 columns]

# %%
df_test.sort_values("sentence",key=lambda x:x.str.len())
# Out:
#          start_time  end_time  \
# 519295      825.696   827.451
# 2503647      76.605    78.615
# 1714047    5963.488  5964.976
# 1229382     412.360   413.619
# 2175924     550.870   552.403
# ...             ...       ...
# 2337853    1213.662  1224.337
# 83183      1498.670  1505.990
# 1786229     256.940   264.620
# 1935309    3105.162  3116.217
# 1783175    1110.721  1119.221
#
#                                                   sentence     video_id
# 519295                                       hem bir polis  9JVCjzcvXco
# 2503647                               bu bir polis arabası  afE_8h7b44E
# 1714047                              çünkü o iyi bir polis  y2eeFsmsNdg
# 1229382                              bu bir polis aracıydı  l6ebG583028
# 2175924                            sen bir polis memurusun  fZiaUKJSy0M
# ...                                                    ...          ...
# 2337853  çıkışta polislerle çatıştığını ve bu çatışma s...  tQRsEpIj5uo
# 83183    kolik bebekler i nsan bir polis dediğimiz bir ...  DEiWkLwHS6Y
# 1786229  en geç saatte bir her sokaktan bir polis kesin...  7WqM5Z7695s
# 1935309  meğerse kendimize damat diye sıkı bir polis de...  HjuzPWNQeP4
# 1783175  senin gözü kara bir polis olduğunu duymuştum a...  LJiP_ouvA9k
#
# [106 rows x 4 columns]

# %%
df_english_select = pd.read_excel("Turkish English Manual Selected 2 Gram Hybrids.xlsx", sheet_name= "2 gram target")
df_english_select
# Out:
#      word   twogram_1   twogram_2    twogram_3   twogram_4
# 0     bir     bir şey    bir daha       bir de     bir çok
# 1      bu    bu kadar       bu ne       bu çok    bu değil
# 2      ne    ne kadar     ne için      bana ne     ne gibi
# 3      ve       ve de     ve evet        ve ne      ve sen
# 4    için     ne için  benim için   senin için   onun için
# 5      mi    değil mi      ben mi       sen mi     evet mi
# 6       o     o kadar        o da      o değil      evet o
# 7     ben      ben de   ben değil    hayır ben      ben mi
# 8      de      sen de      bir de      beni de     beni de
# 9     çok      bu çok    daha çok      çok var     çok şey
# 10    ama      ama bu    evet ama    hayır ama     var ama
# 11    var      var mı      ne var     daha var    evet var
# 12   evet    evet ama     evet bu     evet ben      evet o
# 13     mı      var mı    hayır mı      bana mı     daha mı
# 14  değil    değil mi    bu değil  hayır değil     o değil
# 15     da       bu da        o da      daha da     bana da
# 16    şey     bir şey      bu şey        o şey    şey gibi
# 17  hayır   hayır ben    hayır mı  hayır değil   hayır yok
# 18   daha    bir daha    daha çok     daha var  daha değil
# 19    sen      sen de      sen mi    hayır sen   sen değil
# 20  kadar    ne kadar    bu kadar      o kadar  bana kadar
# 21   bana     bana ne     bana da      bana mı     bu bana
# 22    yok   hayır yok    yok gibi     evet yok       o yok
# 23    onu      ve onu      onu da     evet onu   hayır onu
# 24   seni     seni de   evet seni   hayır seni  seni değil
# 25   beni     beni mi     beni de   beni değil   evet beni
# 26   bunu  hayır bunu   evet bunu   bunu değil  bunun için
# 27   gibi     ne gibi    şey gibi     var gibi    yok gibi

# %%
df_english_select.columns[1:]
# Out:
# Index(['twogram_1', 'twogram_2', 'twogram_3', 'twogram_4'], dtype='object')

# %%
df_search_result = pd.DataFrame()
for i in range(len(df_english_select)):
    for j in df_english_select.columns[1:]:
        string = df_english_select.loc[i,j]
        df_result = df_youtube_sent[df_youtube_sent.sentence.str.contains(fr"(?:\s|^){string}(?:\s|$)", na=True)]
        df_result.sort_values("sentence",key=lambda x:x.str.len(), inplace=True)
        df_select = df_result.head(6)
        df_select.insert(0,"search_string",string)
        df_search_result = pd.concat([df_search_result,df_select], axis=0)
df_search_result
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#         search_string  start_time  end_time        sentence     video_id
# 1413678       bir şey    5604.850  5605.350         bir şey  eHtgG748qhI
# 1989437       bir şey    3672.346  3672.991         bir şey  kCf15d2KbBo
# 1871310       bir şey    5681.980  5682.820         bir şey  8c6pH98yxyA
# 1986331       bir şey     851.790   852.790         bir şey  e2UAg5xF3Ks
# 2733360       bir şey     906.660   910.650         bir şey  qJd2PBgNCwU
# ...               ...         ...       ...             ...          ...
# 1787629      yok gibi    4935.085  4936.095        yok gibi  cFBv6_tAXIo
# 2353191      yok gibi       3.919     5.101    ama yok gibi  2DzH7cHQPsE
# 2353305      yok gibi     375.819   376.921    ama yok gibi  2DzH7cHQPsE
# 2234154      yok gibi     988.533   989.515   evde yok gibi  dNbOwo0XPwE
# 377252       yok gibi    6632.940  6634.160  kimse yok gibi  TW9Ij2Lr3U4
#
# [665 rows x 5 columns]

# %%
#df_search_result.to_excel("Youtube_Search_Result_Test2.xlsx", index=False)

# %%
df_search_result["concat"] = df_search_result['start_time'].map(str)+", "+df_search_result['end_time'].map(str)+", "+df_search_result['video_id'].map(str)
df_search_result

# %%
df_word_result = pd.DataFrame()
for i in word_list:
    try:
        word_in_video = df_sent[df_sent.sentence.str.contains(fr"(?:\s|^){i}(?:\s|$)", na=True)]
    except:
        pass
    word_in_video.insert(0,"word",i)
    df_word_result = pd.concat([df_word_result,word_in_video], axis=0)
df_word_result.reset_index(drop=True, inplace=True)
df_word_result = df_word_result.sort_values(by=["video_id","start_time"], ascending=True)
df_word_result.reset_index(drop=True, inplace=True)
df_word_result
