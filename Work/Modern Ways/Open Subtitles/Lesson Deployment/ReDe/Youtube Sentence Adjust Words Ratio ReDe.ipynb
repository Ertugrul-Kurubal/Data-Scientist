# %% [markdown]
# ### Youtube Sentence Adjust Word List Ratio

# %%
import pandas as pd
import numpy as np
import re
import glob

# %%
folder_name = "Turkish"
word_num = 28

# %%
df_adjust_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{folder_name.lower().capitalize()}/Deployment/Result/Level 1/Word_{word_num}.xlsx")
df_adjust_word
# Out:
#      word  frequency
# 0     bir   18835735
# 1      bu   11062659
# 2      ne    8025880
# 3      ve    7766036
# 4    için    5484109
# 5      mi    5362714
# 6     ben    4908913
# 7      de    4880315
# 8     çok    4852169
# 9     ama    4661966
# 10    var    4389551
# 11   evet    4324786
# 12     mı    4001316
# 13  değil    3883885
# 14     da    3610161
# 15    şey    3602024
# 16  hayır    3406992
# 17   daha    3317577
# 18    sen    3283654
# 19  kadar    2697900
# 20   bana    2659182
# 21    yok    2491685
# 22    onu    2486889
# 23   seni    2454988
# 24   beni    2446696
# 25   bunu    2445337
# 26   gibi    2427957
# 27    iyi    2383224

# %%
df_youtube_sentence = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Youtube/Result/{folder_name.lower().capitalize()}/Sentence Clean Merge/Clean_Youtube_Sentence_Merge_Result.csv")
df_youtube_sentence
# Out:
#           start_time      end_time                               sentence  \
# 0       00:00:06.680  00:00:07.340                        sen kimsin peki
# 1       00:00:07.340  00:00:08.600                         parolayı söyle
# 2       00:00:09.440  00:00:11.060                    ya ben kim olacağım
# 3       00:00:11.060  00:00:11.860                            keloğlan ım
# 4       00:00:13.380  00:00:13.880                                     ey
# ...              ...           ...                                    ...
# 387903  00:02:11.720  00:02:14.440  gözlerin bir an bile çıkmadı aklımdan
# 387904  00:02:15.560  00:02:19.320       koynumdaysa hala o ufak bin lira
# 387905  00:02:20.320  00:02:21.200                                   sahi
# 387906  00:02:21.720  00:02:24.480                diğer eşi sende mi hala
# 387907  00:02:30.000  00:02:35.000                          ufak bin lira
#
#            video_id
# 0       JR7nKXxUVtM
# 1       JR7nKXxUVtM
# 2       JR7nKXxUVtM
# 3       JR7nKXxUVtM
# 4       JR7nKXxUVtM
# ...             ...
# 387903  7R3K6EDaBGE
# 387904  7R3K6EDaBGE
# 387905  7R3K6EDaBGE
# 387906  7R3K6EDaBGE
# 387907  7R3K6EDaBGE
#
# [387908 rows x 4 columns]

# %%
set(df_adjust_word["word"].to_list())
# Out:
# {'ama',
#  'bana',
#  'ben',
#  'beni',
#  'bir',
#  'bu',
#  'bunu',
#  'da',
#  'daha',
#  'de',
#  'değil',
#  'evet',
#  'gibi',
#  'hayır',
#  'iyi',
#  'için',
#  'kadar',
#  'mi',
#  'mı',
#  'ne',
#  'onu',
#  'sen',
#  'seni',
#  'var',
#  've',
#  'yok',
#  'çok',
#  'şey'}

# %%
def sentence_word_ratio(df_word,df_sentence, word_column_name, sentence_column_name, word_num): # df_word and df_sentence are dataframe, word_column_name and sentence_column_name are string
    word_set = set(df_word[f"{word_column_name}"].to_list())
    for i in range(len(df_sentence)):
        sentence = df_sentence.loc[i,f"{sentence_column_name}"]
        sent_word = re.findall(r"\w+", sentence)
        sent_word_set = set(sent_word)
        intersect_word = word_set.intersection(sent_word_set)
        different_word = sent_word_set.difference(word_set)
        df_sentence.loc[i,f"{word_num}_word_ratio"] = (len(intersect_word)/len(sent_word))*100
        df_sentence.loc[i,"different_word"] = different_word
        df_sentence.loc[i,"intersect_word"] = intersect_word
        df_sentence.reset_index(inplace=True)
    
    return df_sentence

# %%
a = ["ali, mehmet, ahmet"]

# %%
set_a = set(a)

# %%
c = ["ali", "ceylan"]

# %%
set_c = set(c)

# %%
set_c.difference(set_a)
# Out:
# {'ali', 'ceylan'}

# %%
b = set(a)

# %%
df_youtube_sentence.loc[1,"diff_word"] = b

# %%
df_youtube_sentence
# Out:
#           start_time      end_time                               sentence  \
# 0       00:00:06.680  00:00:07.340                        sen kimsin peki
# 1       00:00:07.340  00:00:08.600                         parolayı söyle
# 2       00:00:09.440  00:00:11.060                    ya ben kim olacağım
# 3       00:00:11.060  00:00:11.860                            keloğlan ım
# 4       00:00:13.380  00:00:13.880                                     ey
# ...              ...           ...                                    ...
# 387903  00:02:11.720  00:02:14.440  gözlerin bir an bile çıkmadı aklımdan
# 387904  00:02:15.560  00:02:19.320       koynumdaysa hala o ufak bin lira
# 387905  00:02:20.320  00:02:21.200                                   sahi
# 387906  00:02:21.720  00:02:24.480                diğer eşi sende mi hala
# 387907  00:02:30.000  00:02:35.000                          ufak bin lira
#
#            video_id           diff_word
# 0       JR7nKXxUVtM  ali, mehmet, ahmet
# 1       JR7nKXxUVtM  ali, mehmet, ahmet
# 2       JR7nKXxUVtM                 NaN
# 3       JR7nKXxUVtM                 NaN
# 4       JR7nKXxUVtM                 NaN
# ...             ...                 ...
# 387903  7R3K6EDaBGE                 NaN
# 387904  7R3K6EDaBGE                 NaN
# 387905  7R3K6EDaBGE                 NaN
# 387906  7R3K6EDaBGE                 NaN
# 387907  7R3K6EDaBGE                 NaN
#
# [387908 rows x 5 columns]
