# %% [markdown]
# ### Shared Word

# %% [markdown]
# This notebook is combined into a file by obtaining ngrams (2,3,4,5) in the target language by using the etymological words in the mother tongue and the target language.

# %%
import os
import multiprocessing
#import multiprocessing as mp
from multiprocessing import Process, Manager, Pool, Queue
from itertools import islice
import re
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize
from functools import reduce
from pathlib import Path
import shutil

# %%
nprocs = multiprocessing.cpu_count()
print(f"Number of CPU cores: {nprocs}")
# Out:
# Number of CPU cores: 16

# %%
# language pair
lang_folder = "Turkish"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> target language for learner
lang_pair = "English"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> native language

# adding native word to shared word
word_start = 0  # 0  # native word start index
word_end = 28  # 28  # native word end index

# word sample
word_sample = True  # True, False
word_sample_num = 20

# sentence check
twogram_sentence_check = False  # True, False
threegram_sentence_check = False
fourgram_sentence_check = False
fivegram_sentence_check = False

# shared word frequency
shared_word_frequency = True  # True, False

# prefix suffix file
prefix_suffix = False  # True, False  # True for adding prefix suffix word
native_word = True # True for adding native word
etymology_word = False  # True for adding etymology word

# adding output file extention
if (not prefix_suffix) & etymology_word & native_word:
    file_ext = "1"
elif (not prefix_suffix) & etymology_word & (not native_word):
    file_ext = "2"
elif prefix_suffix & etymology_word & native_word:
    file_ext = "3"
elif prefix_suffix & etymology_word & (not native_word):
    file_ext = "4"
elif prefix_suffix & (not etymology_word) & native_word:
    file_ext = "5"
elif (not prefix_suffix) & (not etymology_word) & native_word:
    file_ext = "6"
else:
    file_ext = "7"              
# 1 => for native word and etymology word without prefix suffix. 
# 2 => for only etymology word without prefix suffix. 
# 3 => for native word and etymology word with prefix suffix. prefix_suffix, native_word and etymology_word must be True. 
# 4 => for only etymology word with prefix suffix.
# 5 => for only native word with prefix suffix.
# 6 => for only native word without prefix suffix.

print(f"{file_ext}")
# Out:
# 6

# %%
Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Deployment/Result/4-Shared Word/{lang_folder.capitalize()} {lang_pair.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
def remove_repetition(word_group):
    '''
    remove_repetition(word_group): detect word repetion in word group 
    '''
    words = word_tokenize(word_group)
    word_unique = set(words)
    if len(word_unique) == 1:
        return "repetitive_word_group"
    else:
        return word_group

# %%
df_word_all = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.lower().capitalize()}/Deployment/Data/Word/Word_Merge_Preprocess.xlsx")
df_word_all
# Out:
#                 word  frequency
# 0                bir   18835735
# 1                 bu   11062659
# 2                 ne    8025880
# 3                 ve    7766036
# 4               için    5484109
# ...              ...        ...
# 987924     karneleme          5
# 987925       karnaya          5
# 987926   dörtlümüzün          5
# 987927  karnavalınız          5
# 987928      hurmanın          5
#
# [987929 rows x 2 columns]

# %%
df_word_select = df_word_all.iloc[word_start:word_end,]

# %%
# Option
if prefix_suffix:
    df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_folder.capitalize()}/{lang_folder.capitalize()} {lang_pair.capitalize()}/{lang_folder.capitalize()}_{lang_pair.capitalize()}_{word_end}_Word_Prefix_Suffix_Custom_Result_Manuel.xlsx")
    df_word = df_word.loc[:,["word","frequency"]]
    df_word = pd.concat([df_word,df_word_select], axis=0)
    df_word.drop_duplicates(inplace=True)    
    df_word.sort_values(by="frequency", ascending=False, inplace=True)
    df_word.reset_index(drop=True, inplace=True)
else:
    df_word = df_word_select

if native_word:
    df_word
else:
    df_word = df_word.head(0)

df_word
# Out:
#      word  frequency
# 0     bir   18835735
# 1      bu   11062659
# 2      ne    8025880
# 3      ve    7766036
# 4    için    5484109
# 5      mi    5362714
# 6       o    5013838
# 7     ben    4908913
# 8      de    4880315
# 9     çok    4852169
# 10    ama    4661966
# 11    var    4389551
# 12   evet    4324786
# 13     mı    4001316
# 14  değil    3883885
# 15     da    3610161
# 16    şey    3602024
# 17  hayır    3406992
# 18   daha    3317577
# 19    sen    3283654
# 20  kadar    2697900
# 21   bana    2659182
# 22    yok    2491685
# 23    onu    2486889
# 24   seni    2454988
# 25   beni    2446696
# 26   bunu    2445337
# 27   gibi    2427957

# %%
#lang_pair_list = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_folder.capitalize()}/{lang_folder.capitalize()}_And_{lang_pair.lower().capitalize()}*_All.xlsx")
#lang_pair_list

# %%
#df_pair = pd.read_excel(f"{lang_pair_list[0]}")
df_pair = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_folder.capitalize()}/{lang_folder.capitalize()} {lang_pair.lower().capitalize()}/{lang_folder.capitalize()}_{lang_pair.lower().capitalize()}_Shared_Vocabulary.xlsx")
#df_pair = df_pair.head()
df_pair
# Out:
#      dict_entry_main english_word
# 0             abaküs       abacus
# 1             abluka     blockade
# 2            absorbe       absorb
# 3             absürt       absurd
# 4             açelya       azalea
# ...              ...          ...
# 1773           zebra        zebra
# 1774          zikzak       zigzag
# 1775           zombi       zombie
# 1776         zooloji      zoology
# 1777             zum         zoom
#
# [1778 rows x 2 columns]

# %%
# Option
if prefix_suffix:
    df_prefix_suffix_select = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_folder.capitalize()}/{lang_folder.capitalize()} {lang_pair.capitalize()}/{lang_folder.capitalize()}_{lang_pair.capitalize()}_Shared_Word_Prefix_Suffix_Custom_Result.xlsx")
    df_prefix_suffix_select = df_prefix_suffix_select.loc[:,["search_word","word"]]
    df_prefix_suffix_select.rename(columns={"search_word":"dict_entry_main"}, inplace=True)
    df_pair = pd.merge(df_pair,df_prefix_suffix_select, how="inner", on="dict_entry_main")
    df_pair.drop_duplicates(inplace=True)
    df_pair.reset_index(drop=True, inplace=True)
    df_pair = df_pair.loc[:,["word",f"{lang_pair.lower()}_word"]]
    df_pair.rename(columns={"word":"dict_entry_main"}, inplace=True)
else:
    pass

if etymology_word:
    df_pair
else:
    df_pair = df_pair.head(0)
    
df_pair
# Out:
# Empty DataFrame
# Columns: [dict_entry_main, english_word]
# Index: []

# %%
disable_list = ["sex","seks","seksi","sexy","sexe","seksüel","sexuell","gey","gay","lezbiyen","lesbienne","eşcinsel","mastürbasyon","masturbation","erotik","érotique", \
"bikini","penis","vagina","vajina","fetish","fetiş","fetishy","erotic","erotik","sexdom","kondom","condom","dildo","fetisj","hétérosexuel","féticher","fétiche","homosexuel"\
"ereksiyon","erectie","erection","érection","homoseksüel","prezervatif","préservatif","ass","fetisch","fetiche"]

# %%
word_select = df_word["word"].values.tolist()
words = df_pair["dict_entry_main"].values.tolist()
word_select_set = set(word_select)
disable_word_set = set(disable_list)
words_set = set(words)

# %%
word_list = list((word_select_set.union(words_set)).difference(disable_word_set))

# %%
# 2 way  Not: 1 way is long and in Shared Word ReDe part 
data_kind_list = ["Two", "Three", "Four", "Five", "Sentence"]
for i in data_kind_list:
    sent_ngram_file = f"{i}" # Two, Three, Four, Five, Sentence
 
    if sent_ngram_file.lower() != "sentence":
        data_kind = f"{sent_ngram_file}gram"  # Twogram, Threegram, Fourgram, Fivegram
        folder_path = "N Gram"
    else:
        data_kind = "sentence"
        folder_path = "Sentence"

    df = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Result/{folder_path.capitalize()}/Merge/{data_kind.capitalize()}_Merge.csv")
    d_list  = df.iloc[:,0].values.tolist()

    resultlist = []
    manager = multiprocessing.Manager()
    resultlist = manager.list()
    
    def word_in_wordgroup(d_list):
        mergelist = []
        try:
            word = d_list.split()
        except:
            word = []
            #pass  disabled for non split value
        var1 = range(len(word))
        for j in var1:
            if word[j] in word_list:
                mergelist.append(word[j])
                if len(mergelist) == len(word):
                        resultlist.append(d_list)
                            
    if __name__ == '__main__':
        # with Pool(16) as p:
        with Pool(nprocs) as p: # Pool number CPU sayısına eşit olursa tüm CPU lar çalışır
            p.map(word_in_wordgroup, d_list) # string_word liste

    result_list = list(resultlist)
    df_result = pd.DataFrame(result_list, columns=[0])  # add columns parameter for empty result
    df_result = df_result.rename(columns = {0: f"{data_kind.lower()}"})
    df_merge = pd.merge(df_result, df, how="left", on=f"{data_kind.lower()}")
    df_merge_result = df_merge.sort_values(by="frequency", ascending=False)
    df_merge_result.drop_duplicates(inplace=True)
    df_merge_result[f"{data_kind.lower()}"] = df_merge_result[f"{data_kind.lower()}"].apply(lambda x: remove_repetition(x))  # added remove_repetition 
    df_merge_result = df_merge_result[df_merge_result[f"{data_kind.lower()}"] != "repetitive_word_group"]  # remove_repetition part
    df_merge_result.reset_index(drop=True, inplace=True)

    df_merge_result.to_excel(f"{lang_folder.capitalize()}_{lang_pair.capitalize()}_Shared_{data_kind.capitalize()}{file_ext}.xlsx", index=False)

# %% [markdown]
# #### Concat Result

# %%
df_word = pd.DataFrame(word_list, columns=["word"])
df_word
# Out:
#      word
# 0     ben
# 1     var
# 2     yok
# 3     bir
# 4     sen
# 5      mı
# 6      bu
# 7   değil
# 8    evet
# 9     şey
# 10   bana
# 11   gibi
# 12  kadar
# 13   bunu
# 14   için
# 15   daha
# 16    çok
# 17  hayır
# 18     mi
# 19     da
# 20   beni
# 21     ne
# 22     de
# 23      o
# 24    onu
# 25    ama
# 26   seni
# 27     ve

# %%
# Option For Frequency
if shared_word_frequency:
    df_word_all = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.lower().capitalize()}/Deployment/Data/Word/Word_Merge_Preprocess.xlsx")
    df_word = pd.merge(df_word,df_word_all, how="inner", on="word")
    df_word.drop_duplicates(inplace=True)
    df_word.sort_values(by="frequency", ascending=False, inplace=True)
    df_word.reset_index(drop=True, inplace=True)
else:
    pass

df_word
# Out:
#      word  frequency
# 0     bir   18835735
# 1      bu   11062659
# 2      ne    8025880
# 3      ve    7766036
# 4    için    5484109
# 5      mi    5362714
# 6       o    5013838
# 7     ben    4908913
# 8      de    4880315
# 9     çok    4852169
# 10    ama    4661966
# 11    var    4389551
# 12   evet    4324786
# 13     mı    4001316
# 14  değil    3883885
# 15     da    3610161
# 16    şey    3602024
# 17  hayır    3406992
# 18   daha    3317577
# 19    sen    3283654
# 20  kadar    2697900
# 21   bana    2659182
# 22    yok    2491685
# 23    onu    2486889
# 24   seni    2454988
# 25   beni    2446696
# 26   bunu    2445337
# 27   gibi    2427957

# %%
df_shared_twogram = pd.read_excel(f"{lang_folder.capitalize()}_{lang_pair.capitalize()}_Shared_Twogram{file_ext}.xlsx")
df_shared_twogram = df_shared_twogram.loc[:,["twogram","frequency"]]
df_shared_twogram.rename(columns={"frequency":"freq_twogram"}, inplace=True)
df_shared_twogram
# Out:
#         twogram  freq_twogram
# 0       bir şey        859944
# 1      değil mi        585879
# 2        ben de        377765
# 3        var mı        281902
# 4      ne kadar        237876
# ..          ...           ...
# 682      şey da             6
# 683      çok de             6
# 684  evet kadar             6
# 685   çok hayır             6
# 686  gibi kadar             6
#
# [687 rows x 2 columns]

# %%
# Option For Twogram Sentence
if twogram_sentence_check:
    df_twogram_sent = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Result/N Gram/N Gram And Sentence/Two_Gram_And_Sentence.csv")  # ext. sentence and ngram
    df_twogram_sent.rename(columns={"two_gram":"twogram"}, inplace=True)  # ext. Not: Two_Gram_And_Sentence.csv convert to Two_Gram_And_Sentence_All.csv
    df_twogram_sent = df_twogram_sent.loc[:,["twogram"]]
    df_shared_twogram = pd.merge(df_shared_twogram, df_twogram_sent, how="inner", on="twogram")
    df_shared_twogram.drop_duplicates(inplace=True)
    df_shared_twogram.reset_index(drop=True, inplace=True)
else:
    pass

df_shared_twogram
# Out:
#         twogram  freq_twogram
# 0       bir şey        859944
# 1      değil mi        585879
# 2        ben de        377765
# 3        var mı        281902
# 4      ne kadar        237876
# ..          ...           ...
# 682      şey da             6
# 683      çok de             6
# 684  evet kadar             6
# 685   çok hayır             6
# 686  gibi kadar             6
#
# [687 rows x 2 columns]

# %%
df_shared_threegram = pd.read_excel(f"{lang_folder.capitalize()}_{lang_pair.capitalize()}_Shared_Threegram{file_ext}.xlsx")
df_shared_threegram = df_shared_threegram.loc[:,["threegram","frequency"]]
df_shared_threegram.rename(columns={"frequency":"freq_threegram"}, inplace=True)
df_shared_threegram
# Out:
#           threegram  freq_threegram
# 0       bir şey yok          113165
# 1       bir şey var          110455
# 2          bu da ne           89463
# 3     bir şey değil           68498
# 4        bir şey mi           64933
# ...             ...             ...
# 4062    ve ben beni              10
# 4063    ama ben var              10
# 4064  ama bana beni              10
# 4065    ama bir sen              10
# 4066       o ne sen              10
#
# [4067 rows x 2 columns]

# %%
# Option For Threegram Sentence
if threegram_sentence_check:
    df_threegram_sent = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Result/N Gram/N Gram And Sentence/Three_Gram_And_Sentence.csv")  # ext. sentence and ngram
    df_threegram_sent.rename(columns={"three_gram":"threegram"}, inplace=True)  # ext. Not: Two_Gram_And_Sentence.csv convert to Two_Gram_And_Sentence_All.csv
    df_threegram_sent = df_threegram_sent.loc[:,["threegram"]]
    df_shared_threegram = pd.merge(df_shared_threegram, df_threegram_sent, how="inner", on="threegram")
    df_shared_threegram.drop_duplicates(inplace=True)
    df_shared_threegram.reset_index(drop=True, inplace=True)
else:
    pass

df_shared_threegram
# Out:
#           threegram  freq_threegram
# 0       bir şey yok          113165
# 1       bir şey var          110455
# 2          bu da ne           89463
# 3     bir şey değil           68498
# 4        bir şey mi           64933
# ...             ...             ...
# 4062    ve ben beni              10
# 4063    ama ben var              10
# 4064  ama bana beni              10
# 4065    ama bir sen              10
# 4066       o ne sen              10
#
# [4067 rows x 2 columns]

# %%
df_shared_fourgram = pd.read_excel(f"{lang_folder.capitalize()}_{lang_pair.capitalize()}_Shared_Fourgram{file_ext}.xlsx")
df_shared_fourgram = df_shared_fourgram.loc[:,["fourgram","frequency"]]
df_shared_fourgram.rename(columns={"frequency":"freq_fourgram"}, inplace=True)
df_shared_fourgram
# Out:
#               fourgram  freq_fourgram
# 0       bir şey var mı          41773
# 1     bir şey daha var          12185
# 2       bir şey mi var          11834
# 3        ne var ne yok           9276
# 4     bir şey değil mi           5080
# ...                ...            ...
# 2787        ne de o bu              7
# 2788        o bir o da              7
# 2789     ne var bir de              7
# 2790    ne var daha ne              7
# 2791    onu o daha bir              7
#
# [2792 rows x 2 columns]

# %%
# Option For Fourgram Sentence
if fourgram_sentence_check:
    df_fourgram_sent = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Result/N Gram/N Gram And Sentence/Four_Gram_And_Sentence.csv")  # ext. sentence and ngram
    df_fourgram_sent.rename(columns={"four_gram":"fourgram"}, inplace=True)  # ext. Not: Two_Gram_And_Sentence.csv convert to Two_Gram_And_Sentence_All.csv
    df_fourgram_sent = df_fourgram_sent.loc[:,["fourgram"]]
    df_shared_fourgram = pd.merge(df_shared_fourgram, df_fourgram_sent, how="inner", on="fourgram")
    df_shared_fourgram.drop_duplicates(inplace=True)
    df_shared_fourgram.reset_index(drop=True, inplace=True)
else:
    pass

df_shared_fourgram
# Out:
#               fourgram  freq_fourgram
# 0       bir şey var mı          41773
# 1     bir şey daha var          12185
# 2       bir şey mi var          11834
# 3        ne var ne yok           9276
# 4     bir şey değil mi           5080
# ...                ...            ...
# 2787        ne de o bu              7
# 2788        o bir o da              7
# 2789     ne var bir de              7
# 2790    ne var daha ne              7
# 2791    onu o daha bir              7
#
# [2792 rows x 2 columns]

# %%
df_shared_fivegram = pd.read_excel(f"{lang_folder.capitalize()}_{lang_pair.capitalize()}_Shared_Fivegram{file_ext}.xlsx")
df_shared_fivegram = df_shared_fivegram.loc[:,["fivegram","frequency"]]
df_shared_fivegram.rename(columns={"frequency":"freq_fivegram"}, inplace=True)
df_shared_fivegram
# Out:
#                  fivegram  freq_fivegram
# 0    bir şey yok değil mi            893
# 1     o kadar çok şey var            790
# 2     bir şey yok bir şey            490
# 3     ve bir şey daha var            393
# 4    ama bir şey daha var            393
# ..                    ...            ...
# 353     ben mi ben mi ben             10
# 354  bir şey de yok değil             10
# 355    ama sen de bir şey             10
# 356   bir sen bir ben bir             10
# 357      ve bir de ne var             10
#
# [358 rows x 2 columns]

# %%
# Option For Fivegram Sentence
if fivegram_sentence_check:
    df_fivegram_sent = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Result/N Gram/N Gram And Sentence/Five_Gram_And_Sentence.csv")  # ext. sentence and ngram
    df_fivegram_sent.rename(columns={"five_gram":"fivegram"}, inplace=True)  # ext. Not: Two_Gram_And_Sentence.csv convert to Two_Gram_And_Sentence_All.csv
    df_fivegram_sent = df_fivegram_sent.loc[:,["fivegram"]]
    df_shared_fivegram = pd.merge(df_shared_fivegram, df_fivegram_sent, how="inner", on="fivegram")
    df_shared_fivegram.drop_duplicates(inplace=True)
    df_shared_fivegram.reset_index(drop=True, inplace=True)
else:
    pass

df_shared_fivegram
# Out:
#                  fivegram  freq_fivegram
# 0    bir şey yok değil mi            893
# 1     o kadar çok şey var            790
# 2     bir şey yok bir şey            490
# 3     ve bir şey daha var            393
# 4    ama bir şey daha var            393
# ..                    ...            ...
# 353     ben mi ben mi ben             10
# 354  bir şey de yok değil             10
# 355    ama sen de bir şey             10
# 356   bir sen bir ben bir             10
# 357      ve bir de ne var             10
#
# [358 rows x 2 columns]

# %%
df_shared_sentence = pd.read_excel(f"{lang_folder.capitalize()}_{lang_pair.capitalize()}_Shared_Sentence{file_ext}.xlsx")
df_shared_sentence = df_shared_sentence.loc[:,["sentence","frequency"]]
df_shared_sentence.rename(columns={"frequency":"freq_sentence"}, inplace=True)
df_shared_sentence
# Out:
#                      sentence  freq_sentence
# 0                      ne var          62532
# 1                      ben de          59972
# 2                    değil mi          58386
# 3                    bu da ne          50098
# 4                      ben mi          33652
# ...                       ...            ...
# 1479  bir de bir şey daha var              6
# 1480            ne o kadar mı              6
# 1481         evet o kadar var              6
# 1482                 o ben mi              6
# 1483                  o bir o              6
#
# [1484 rows x 2 columns]

# %%
df_shared_all = pd.concat([df_word, df_shared_twogram, df_shared_threegram, df_shared_fourgram, df_shared_fivegram, df_shared_sentence], axis=1)
df_shared_all
# Out:
#       word   frequency   twogram  freq_twogram      threegram  freq_threegram  \
# 0      bir  18835735.0   bir şey      859944.0    bir şey yok          113165
# 1       bu  11062659.0  değil mi      585879.0    bir şey var          110455
# 2       ne   8025880.0    ben de      377765.0       bu da ne           89463
# 3       ve   7766036.0    var mı      281902.0  bir şey değil           68498
# 4     için   5484109.0  ne kadar      237876.0     bir şey mi           64933
# ...    ...         ...       ...           ...            ...             ...
# 4062   NaN         NaN       NaN           NaN    ve ben beni              10
# 4063   NaN         NaN       NaN           NaN    ama ben var              10
# 4064   NaN         NaN       NaN           NaN  ama bana beni              10
# 4065   NaN         NaN       NaN           NaN    ama bir sen              10
# 4066   NaN         NaN       NaN           NaN       o ne sen              10
#
#               fourgram  freq_fourgram              fivegram  freq_fivegram  \
# 0       bir şey var mı        41773.0  bir şey yok değil mi          893.0
# 1     bir şey daha var        12185.0   o kadar çok şey var          790.0
# 2       bir şey mi var        11834.0   bir şey yok bir şey          490.0
# 3        ne var ne yok         9276.0   ve bir şey daha var          393.0
# 4     bir şey değil mi         5080.0  ama bir şey daha var          393.0
# ...                ...            ...                   ...            ...
# 4062               NaN            NaN                   NaN            NaN
# 4063               NaN            NaN                   NaN            NaN
# 4064               NaN            NaN                   NaN            NaN
# 4065               NaN            NaN                   NaN            NaN
# 4066               NaN            NaN                   NaN            NaN
#
#       sentence  freq_sentence
# 0       ne var        62532.0
# 1       ben de        59972.0
# 2     değil mi        58386.0
# 3     bu da ne        50098.0
# 4       ben mi        33652.0
# ...        ...            ...
# 4062       NaN            NaN
# 4063       NaN            NaN
# 4064       NaN            NaN
# 4065       NaN            NaN
# 4066       NaN            NaN
#
# [4067 rows x 12 columns]

# %%
df_shared_all.to_excel(f"{lang_folder.capitalize()}_{lang_pair.capitalize()}_Shared_Result_With_Frequency{file_ext}.xlsx", index=False)

# %% [markdown]
# ##### Concat Result With Comma

# %%
def word_in_wordgroup(df, source_column, target_column):

    '''word_in_wordgroup(df, "word", "twogram"):
       df is dataframe, source_column and target_column are 
       dataframe column string name. source_column convert list
       values that are in target column.
    '''
    
    df_select = df[[f"{target_column}"]].dropna()
    df_word_result = pd.DataFrame()
    for i in df[f"{source_column}"].dropna():
        try:
            if word_sample:
                word_in_word_cluster = df_select[df_select[f"{target_column}"].str.contains(fr"(?:\s|^){i}(?:\s|$)", na=True)].head(word_sample_num)  # Option
            else:
                word_in_word_cluster = df_select[df_select[f"{target_column}"].str.contains(fr"(?:\s|^){i}(?:\s|$)", na=True)] 
        except:
            pass        
        word_in_word_cluster.insert(0,f"{source_column}",i)
        df_word_result = pd.concat([df_word_result,word_in_word_cluster], axis=0)
    df_word_result.reset_index(drop=True, inplace=True)

    return df_word_result

# %%
df_word_order_twogram = word_in_wordgroup(df_shared_all, "word", "twogram")
df_word_order_threegram = word_in_wordgroup(df_shared_all, "word", "threegram") 
df_word_order_fourgram = word_in_wordgroup(df_shared_all, "word", "fourgram") 
df_word_order_fivegram = word_in_wordgroup(df_shared_all, "word", "fivegram")
df_word_order_sentence = word_in_wordgroup(df_shared_all, "word", "sentence")

# %%
df_word_order_join_twogram = df_word_order_twogram.groupby(["word"])["twogram"].apply(", ".join).reset_index()   # df_word_order_11.groupby(["word"])[f"twogram_pair_{lang_pair.lower()}"].transform(lambda x: ','.join(x))
df_word_order_join_threegram = df_word_order_threegram.groupby(["word"])["threegram"].apply(", ".join).reset_index()
df_word_order_join_fourgram = df_word_order_fourgram.groupby(["word"])["fourgram"].apply(", ".join).reset_index()
df_word_order_join_fivegram = df_word_order_fivegram.groupby(["word"])["fivegram"].apply(", ".join).reset_index()
df_word_order_join_sentence = df_word_order_sentence.groupby(["word"])["sentence"].apply(", ".join).reset_index()

# %%
dfs = [df_word_order_join_twogram,df_word_order_join_threegram,df_word_order_join_fourgram,df_word_order_join_fivegram,df_word_order_join_sentence]

# %%
df_word_order_join_all = reduce(lambda  left,right: pd.merge(left,right, on=['word'], how='outer'), dfs)  # left,right make left to right merge
#df_word_order_join_all = reduce(lambda  right,left: pd.merge(left,right, on=['word'], how='outer'), dfs)  # right,left make right to left merge
df_word_order_join_all
# Out:
#      word                                            twogram  \
# 0     ama  ama bu, ama ben, evet ama, ama o, ama sen, ama...
# 1    bana  bana bir, bana ne, bunu bana, onu bana, bana d...
# 2     ben  ben de, ben bir, ve ben, ben mi, ama ben, hayı...
# 3    beni  beni mi, beni de, bu beni, sen beni, ve beni, ...
# 4     bir  bir şey, bu bir, bir daha, ben bir, bana bir, ...
# 5      bu  bu kadar, bu da, bu çok, bu bir, bu ne, ama bu...
# 6    bunu  bunu bana, bunu daha, bunu bir, ama bunu, bunu...
# 7      da  bu da, da ne, o da, kadar da, daha da, da bir,...
# 8    daha  bir daha, daha çok, çok daha, daha da, daha va...
# 9      de  ben de, sen de, bir de, de seni, de bir, de ço...
# 10  değil  değil mi, şey değil, bu değil, gibi değil, hay...
# 11   evet  evet ama, evet bu, evet ben, evet çok, evet o,...
# 12   gibi  gibi bir, ne gibi, gibi değil, gibi mi, şey gi...
# 13  hayır  hayır ben, hayır bu, hayır mı, hayır değil, ha...
# 14   için  için bir, için çok, ne için, için mi, için ne,...
# 15  kadar  ne kadar, bu kadar, o kadar, kadar da, kadar m...
# 16     mi  değil mi, şey mi, ben mi, için mi, sen mi, mi ...
# 17     mı  var mı, kadar mı, hayır mı, mı var, bana mı, m...
# 18     ne  ne kadar, ne var, da ne, bu ne, sen ne, ne içi...
# 19      o  o kadar, o da, o bir, bu o, o ne, ama o, o değ...
# 20    onu  onu bana, onu ben, ve onu, de onu, onu da, onu...
# 21    sen  sen de, sen ne, sen bir, sen ve, sen mi, ve se...
# 22   seni  de seni, seni çok, ben seni, bu seni, seni bir...
# 23    var  var mı, ne var, şey var, mi var, daha var, da ...
# 24     ve  ve ben, ve bu, ve bir, sen ve, ve sen, ve o, v...
# 25    yok  şey yok, yok bir, hayır yok, yok değil, ne yok...
# 26    çok  bu çok, için çok, daha çok, çok daha, çok şey,...
# 27    şey  bir şey, şey yok, şey var, şey değil, şey mi, ...
#
#                                             threegram  \
# 0   çok ama çok, ama bir şey, ama değil mi, evet a...
# 1   bana bir şey, sen de bana, bir de bana, bana b...
# 2   ben de seni, sen ve ben, ve ben de, evet ben d...
# 3   sen de beni, beni bir daha, o da beni, bu da b...
# 4   bir şey yok, bir şey var, bir şey değil, bir ş...
# 5   bu da ne, bu kadar mı, ve bu da, bu kadar çok,...
# 6   ben de bunu, bunu bir daha, bunu sen mi, bunu ...
# 7   bu da ne, o kadar da, ne kadar da, o da ne, ve...
# 8   bir şey daha, daha ne kadar, şey daha var, sen...
# 9   ben de seni, ve ben de, evet ben de, ve sen de...
# 10  bir şey değil, yok değil mi, var değil mi, değ...
# 11  evet ben de, evet ama bu, evet ama ben, evet m...
# 12  gibi bir şey, gibi değil mi, gibi ben de, ne g...
# 13  mi hayır mı, evet mi hayır, hayır hayır ben, h...
# 14  için bir şey, için ne kadar, bir şey için, içi...
# 15  o kadar da, bu kadar mı, ne kadar da, daha ne ...
# 16  bir şey mi, yok değil mi, var değil mi, şey mi...
# 17  şey var mı, bu kadar mı, o kadar mı, mi hayır ...
# 18  bu da ne, ne kadar da, o da ne, daha ne kadar,...
# 19  o kadar da, o da ne, o kadar çok, ve o da, o d...
# 20  ben de onu, onu bir daha, sen de onu, onu ne k...
# 21  sen ve ben, ve sen de, sen de mi, sen de bir, ...
# 22  ben de seni, seni bir daha, seni ne kadar, sen...
# 23  bir şey var, şey var mı, var değil mi, şey dah...
# 24  sen ve ben, ve ben de, ve sen de, ve bu da, ve...
# 25  bir şey yok, yok bir şey, yok değil mi, var ne...
# 26  o kadar çok, bu kadar çok, çok şey var, ne kad...
# 27  bir şey yok, bir şey var, bir şey değil, bir ş...
#
#                                              fourgram  \
# 0   ama o kadar da, bir şey değil ama, bir şey yok...
# 1   bana bir şey mi, ve sen de bana, evet bir de b...
# 2   ben de bir şey, sen de ben de, evet ben de sen...
# 3   ve o da beni, ve sen de beni, beni daha ne kad...
# 4   bir şey var mı, bir şey daha var, bir şey mi v...
# 5   bu şey de ne, bu o kadar da, bir şey değil bu,...
# 6   bunu daha ne kadar, ve sen de bunu, ve bunu se...
# 7   o kadar da değil, ama o kadar da, bu o kadar d...
# 8   bir şey daha var, ve bir şey daha, daha ne kad...
# 9   bu şey de ne, ben de bir şey, de bu değil mi, ...
# 10  bir şey değil mi, o kadar da değil, bir şey de...
# 11  evet mi hayır mı, evet ben de seni, evet o da ...
# 12  gibi bir şey mi, gibi bir şey bu, gibi bir şey...
# 13  evet mi hayır mı, hayır bir şey yok, hayır yok...
# 14  için bir şey var, için çok ama çok, için daha ...
# 15  o kadar da değil, o kadar çok şey, ama o kadar...
# 16  bir şey mi var, bir şey değil mi, evet mi hayı...
# 17  bir şey var mı, evet mi hayır mı, var mı bir ş...
# 18  ne var ne yok, bu şey de ne, daha ne kadar var...
# 19  o kadar da değil, o kadar çok şey, ama o kadar...
# 20  ve ben de onu, ve sen de onu, evet ben de onu,...
# 21  sen de ben de, ve sen de bunu, ne sen ne de, s...
# 22  seni ne kadar çok, evet ben de seni, ben de se...
# 23  bir şey var mı, bir şey daha var, bir şey mi v...
# 24  ve bir şey daha, ve sen de bunu, ve ben de onu...
# 25  ne var ne yok, şey yok değil mi, hayır bir şey...
# 26  o kadar çok şey, kadar çok şey var, seni ne ka...
# 27  bir şey var mı, bir şey daha var, bir şey mi v...
#
#                                              fivegram  \
# 0   ama bir şey daha var, ama o kadar da değil, am...
# 1   bana bir şey var mı, sen onu bir de bana, sen ...
# 2   ne sen ne de ben, bunu sen de ben de, ne o ne ...
# 3   ne seni ne de beni, ve bu da beni çok, ben sen...
# 4   bir şey yok değil mi, bir şey yok bir şey, ve ...
# 5   bu da bir şey mi, bu daha bir şey değil, ve bi...
# 6   bunu sen de ben de, değil ve bunu sen de, yok ...
# 7   ama o kadar da değil, o da bir şey mi, ama bir...
# 8   ve bir şey daha var, ama bir şey daha var, bu ...
# 9   ne sen ne de ben, ve bir de bu var, bunu sen d...
# 10  bir şey yok değil mi, ama o kadar da değil, bi...
# 11  bu evet mi hayır mı, evet bir şey daha var, ev...
# 12  gibi bir şey değil mi, gibi bir şey var mı, gi...
# 13  hayır o kadar da değil, hayır hayır bir şey yo...
# 14  için bir şey var mı, için bir şey mi var, için...
# 15  o kadar çok şey var, ama o kadar da değil, ama...
# 16  bir şey yok değil mi, bir şey var değil mi, o ...
# 17  için bir şey var mı, bana bir şey var mı, gibi...
# 18  ne kadar çok o kadar, ne sen ne de ben, ne o n...
# 19  o kadar çok şey var, ama o kadar da değil, o d...
# 20  sen onu bir de bana, sen onu değil o seni, ben...
# 21  ne sen ne de ben, sen sen sen ve sen, bunu sen...
# 22  ne seni ne de beni, seni bir çok şey için, ne ...
# 23  o kadar çok şey var, ve bir şey daha var, ama ...
# 24  ve bir şey daha var, ve bir o kadar da, ve bir...
# 25  bir şey yok değil mi, bir şey yok bir şey, şey...
# 26  o kadar çok şey var, ne kadar çok o kadar, o k...
# 27  bir şey yok değil mi, o kadar çok şey var, bir...
#
#                                              sentence
# 0   evet ama, ama ben, ama ne, ama bu, ama sen, ha...
# 1   bana mı, bana ne, bana da, bana değil, bu bana...
# 2   ben de, ben mi, hayır ben, evet ben de, ben de...
# 3   beni mi, beni de, beni değil, evet beni de, se...
# 4   bir şey değil, yok bir şey, bir şey yok, bir ş...
# 5   bu da ne, bu ne, bu o, bu kadar, bu kadar mı, ...
# 6   bunu da, ve bunu, ben bunu, bunu değil, ve bun...
# 7   bu da ne, o da ne, bu da, bana da, o kadar da ...
# 8   daha değil, bir şey daha var, bir daha, bir şe...
# 9   ben de, sen de, evet ben de, ben de seni, seni...
# 10  değil mi, hayır değil, bir şey değil, daha değ...
# 11  evet var, evet ama, evet ben de, evet o, evet ...
# 12  ne gibi, şey gibi, bu şey gibi, ne gibi bir şe...
# 13  hayır değil, hayır mı, hayır yok, hayır ben, y...
# 14  ne için, bu ne için, o ne için, şey için, ne i...
# 15  ne kadar, bu kadar, bu kadar mı, o kadar, o ka...
# 16  değil mi, ben mi, sen mi, evet mi, beni mi, ev...
# 17  hayır mı, bu kadar mı, bana mı, var mı, bir şe...
# 18  ne var, bu da ne, ne için, bu ne, ne kadar, ne...
# 19  bu o, o da ne, o ne, o kadar, evet o, ne o, o ...
# 20  onu değil, onu da, evet onu, ben onu, hayır on...
# 21  sen de, sen mi, sen ve ben, ve sen, evet sen, ...
# 22  ben de seni, seni de, seni mi, seni değil, ben...
# 23  ne var, evet var, bir şey daha var, ne var ne ...
# 24  sen ve ben, ve sen, ve ben, ve bu, ve ne, ve b...
# 25  yok bir şey, bir şey yok, hayır yok, ne var ne...
# 26  bu çok, çok değil, daha çok, evet çok, sen çok...
# 27  bir şey değil, yok bir şey, bir şey yok, bir ş...

# %%
# Option For Word Frequency
if shared_word_frequency:
    df_word_order_join_all = pd.merge(df_word_order_join_all,df_word_all, how="inner", on="word")
    df_word_order_join_all.drop_duplicates(inplace=True)
    df_word_order_join_all = df_word_order_join_all.loc[:,["word","frequency","twogram","threegram","fourgram","fivegram","sentence"]]
    df_word_order_join_all.sort_values(by="frequency", inplace=True, ascending=False)
    df_word_order_join_all.reset_index(drop=True, inplace=True)
else:
    pass

df_word_order_join_all
# Out:
#      word  frequency                                            twogram  \
# 0     bir   18835735  bir şey, bu bir, bir daha, ben bir, bana bir, ...
# 1      bu   11062659  bu kadar, bu da, bu çok, bu bir, bu ne, ama bu...
# 2      ne    8025880  ne kadar, ne var, da ne, bu ne, sen ne, ne içi...
# 3      ve    7766036  ve ben, ve bu, ve bir, sen ve, ve sen, ve o, v...
# 4    için    5484109  için bir, için çok, ne için, için mi, için ne,...
# 5      mi    5362714  değil mi, şey mi, ben mi, için mi, sen mi, mi ...
# 6       o    5013838  o kadar, o da, o bir, bu o, o ne, ama o, o değ...
# 7     ben    4908913  ben de, ben bir, ve ben, ben mi, ama ben, hayı...
# 8      de    4880315  ben de, sen de, bir de, de seni, de bir, de ço...
# 9     çok    4852169  bu çok, için çok, daha çok, çok daha, çok şey,...
# 10    ama    4661966  ama bu, ama ben, evet ama, ama o, ama sen, ama...
# 11    var    4389551  var mı, ne var, şey var, mi var, daha var, da ...
# 12   evet    4324786  evet ama, evet bu, evet ben, evet çok, evet o,...
# 13     mı    4001316  var mı, kadar mı, hayır mı, mı var, bana mı, m...
# 14  değil    3883885  değil mi, şey değil, bu değil, gibi değil, hay...
# 15     da    3610161  bu da, da ne, o da, kadar da, daha da, da bir,...
# 16    şey    3602024  bir şey, şey yok, şey var, şey değil, şey mi, ...
# 17  hayır    3406992  hayır ben, hayır bu, hayır mı, hayır değil, ha...
# 18   daha    3317577  bir daha, daha çok, çok daha, daha da, daha va...
# 19    sen    3283654  sen de, sen ne, sen bir, sen ve, sen mi, ve se...
# 20  kadar    2697900  ne kadar, bu kadar, o kadar, kadar da, kadar m...
# 21   bana    2659182  bana bir, bana ne, bunu bana, onu bana, bana d...
# 22    yok    2491685  şey yok, yok bir, hayır yok, yok değil, ne yok...
# 23    onu    2486889  onu bana, onu ben, ve onu, de onu, onu da, onu...
# 24   seni    2454988  de seni, seni çok, ben seni, bu seni, seni bir...
# 25   beni    2446696  beni mi, beni de, bu beni, sen beni, ve beni, ...
# 26   bunu    2445337  bunu bana, bunu daha, bunu bir, ama bunu, bunu...
# 27   gibi    2427957  gibi bir, ne gibi, gibi değil, gibi mi, şey gi...
#
#                                             threegram  \
# 0   bir şey yok, bir şey var, bir şey değil, bir ş...
# 1   bu da ne, bu kadar mı, ve bu da, bu kadar çok,...
# 2   bu da ne, ne kadar da, o da ne, daha ne kadar,...
# 3   sen ve ben, ve ben de, ve sen de, ve bu da, ve...
# 4   için bir şey, için ne kadar, bir şey için, içi...
# 5   bir şey mi, yok değil mi, var değil mi, şey mi...
# 6   o kadar da, o da ne, o kadar çok, ve o da, o d...
# 7   ben de seni, sen ve ben, ve ben de, evet ben d...
# 8   ben de seni, ve ben de, evet ben de, ve sen de...
# 9   o kadar çok, bu kadar çok, çok şey var, ne kad...
# 10  çok ama çok, ama bir şey, ama değil mi, evet a...
# 11  bir şey var, şey var mı, var değil mi, şey dah...
# 12  evet ben de, evet ama bu, evet ama ben, evet m...
# 13  şey var mı, bu kadar mı, o kadar mı, mi hayır ...
# 14  bir şey değil, yok değil mi, var değil mi, değ...
# 15  bu da ne, o kadar da, ne kadar da, o da ne, ve...
# 16  bir şey yok, bir şey var, bir şey değil, bir ş...
# 17  mi hayır mı, evet mi hayır, hayır hayır ben, h...
# 18  bir şey daha, daha ne kadar, şey daha var, sen...
# 19  sen ve ben, ve sen de, sen de mi, sen de bir, ...
# 20  o kadar da, bu kadar mı, ne kadar da, daha ne ...
# 21  bana bir şey, sen de bana, bir de bana, bana b...
# 22  bir şey yok, yok bir şey, yok değil mi, var ne...
# 23  ben de onu, onu bir daha, sen de onu, onu ne k...
# 24  ben de seni, seni bir daha, seni ne kadar, sen...
# 25  sen de beni, beni bir daha, o da beni, bu da b...
# 26  ben de bunu, bunu bir daha, bunu sen mi, bunu ...
# 27  gibi bir şey, gibi değil mi, gibi ben de, ne g...
#
#                                              fourgram  \
# 0   bir şey var mı, bir şey daha var, bir şey mi v...
# 1   bu şey de ne, bu o kadar da, bir şey değil bu,...
# 2   ne var ne yok, bu şey de ne, daha ne kadar var...
# 3   ve bir şey daha, ve sen de bunu, ve ben de onu...
# 4   için bir şey var, için çok ama çok, için daha ...
# 5   bir şey mi var, bir şey değil mi, evet mi hayı...
# 6   o kadar da değil, o kadar çok şey, ama o kadar...
# 7   ben de bir şey, sen de ben de, evet ben de sen...
# 8   bu şey de ne, ben de bir şey, de bu değil mi, ...
# 9   o kadar çok şey, kadar çok şey var, seni ne ka...
# 10  ama o kadar da, bir şey değil ama, bir şey yok...
# 11  bir şey var mı, bir şey daha var, bir şey mi v...
# 12  evet mi hayır mı, evet ben de seni, evet o da ...
# 13  bir şey var mı, evet mi hayır mı, var mı bir ş...
# 14  bir şey değil mi, o kadar da değil, bir şey de...
# 15  o kadar da değil, ama o kadar da, bu o kadar d...
# 16  bir şey var mı, bir şey daha var, bir şey mi v...
# 17  evet mi hayır mı, hayır bir şey yok, hayır yok...
# 18  bir şey daha var, ve bir şey daha, daha ne kad...
# 19  sen de ben de, ve sen de bunu, ne sen ne de, s...
# 20  o kadar da değil, o kadar çok şey, ama o kadar...
# 21  bana bir şey mi, ve sen de bana, evet bir de b...
# 22  ne var ne yok, şey yok değil mi, hayır bir şey...
# 23  ve ben de onu, ve sen de onu, evet ben de onu,...
# 24  seni ne kadar çok, evet ben de seni, ben de se...
# 25  ve o da beni, ve sen de beni, beni daha ne kad...
# 26  bunu daha ne kadar, ve sen de bunu, ve bunu se...
# 27  gibi bir şey mi, gibi bir şey bu, gibi bir şey...
#
#                                              fivegram  \
# 0   bir şey yok değil mi, bir şey yok bir şey, ve ...
# 1   bu da bir şey mi, bu daha bir şey değil, ve bi...
# 2   ne kadar çok o kadar, ne sen ne de ben, ne o n...
# 3   ve bir şey daha var, ve bir o kadar da, ve bir...
# 4   için bir şey var mı, için bir şey mi var, için...
# 5   bir şey yok değil mi, bir şey var değil mi, o ...
# 6   o kadar çok şey var, ama o kadar da değil, o d...
# 7   ne sen ne de ben, bunu sen de ben de, ne o ne ...
# 8   ne sen ne de ben, ve bir de bu var, bunu sen d...
# 9   o kadar çok şey var, ne kadar çok o kadar, o k...
# 10  ama bir şey daha var, ama o kadar da değil, am...
# 11  o kadar çok şey var, ve bir şey daha var, ama ...
# 12  bu evet mi hayır mı, evet bir şey daha var, ev...
# 13  için bir şey var mı, bana bir şey var mı, gibi...
# 14  bir şey yok değil mi, ama o kadar da değil, bi...
# 15  ama o kadar da değil, o da bir şey mi, ama bir...
# 16  bir şey yok değil mi, o kadar çok şey var, bir...
# 17  hayır o kadar da değil, hayır hayır bir şey yo...
# 18  ve bir şey daha var, ama bir şey daha var, bu ...
# 19  ne sen ne de ben, sen sen sen ve sen, bunu sen...
# 20  o kadar çok şey var, ama o kadar da değil, ama...
# 21  bana bir şey var mı, sen onu bir de bana, sen ...
# 22  bir şey yok değil mi, bir şey yok bir şey, şey...
# 23  sen onu bir de bana, sen onu değil o seni, ben...
# 24  ne seni ne de beni, seni bir çok şey için, ne ...
# 25  ne seni ne de beni, ve bu da beni çok, ben sen...
# 26  bunu sen de ben de, değil ve bunu sen de, yok ...
# 27  gibi bir şey değil mi, gibi bir şey var mı, gi...
#
#                                              sentence
# 0   bir şey değil, yok bir şey, bir şey yok, bir ş...
# 1   bu da ne, bu ne, bu o, bu kadar, bu kadar mı, ...
# 2   ne var, bu da ne, ne için, bu ne, ne kadar, ne...
# 3   sen ve ben, ve sen, ve ben, ve bu, ve ne, ve b...
# 4   ne için, bu ne için, o ne için, şey için, ne i...
# 5   değil mi, ben mi, sen mi, evet mi, beni mi, ev...
# 6   bu o, o da ne, o ne, o kadar, evet o, ne o, o ...
# 7   ben de, ben mi, hayır ben, evet ben de, ben de...
# 8   ben de, sen de, evet ben de, ben de seni, seni...
# 9   bu çok, çok değil, daha çok, evet çok, sen çok...
# 10  evet ama, ama ben, ama ne, ama bu, ama sen, ha...
# 11  ne var, evet var, bir şey daha var, ne var ne ...
# 12  evet var, evet ama, evet ben de, evet o, evet ...
# 13  hayır mı, bu kadar mı, bana mı, var mı, bir şe...
# 14  değil mi, hayır değil, bir şey değil, daha değ...
# 15  bu da ne, o da ne, bu da, bana da, o kadar da ...
# 16  bir şey değil, yok bir şey, bir şey yok, bir ş...
# 17  hayır değil, hayır mı, hayır yok, hayır ben, y...
# 18  daha değil, bir şey daha var, bir daha, bir şe...
# 19  sen de, sen mi, sen ve ben, ve sen, evet sen, ...
# 20  ne kadar, bu kadar, bu kadar mı, o kadar, o ka...
# 21  bana mı, bana ne, bana da, bana değil, bu bana...
# 22  yok bir şey, bir şey yok, hayır yok, ne var ne...
# 23  onu değil, onu da, evet onu, ben onu, hayır on...
# 24  ben de seni, seni de, seni mi, seni değil, ben...
# 25  beni mi, beni de, beni değil, evet beni de, se...
# 26  bunu da, ve bunu, ben bunu, bunu değil, ve bun...
# 27  ne gibi, şey gibi, bu şey gibi, ne gibi bir şe...

# %%
df_word_order_join_all.word.nunique()
# Out:
# 28

# %%
df_word_order_join_all.to_excel(f"{lang_folder.capitalize()}_{lang_pair.capitalize()}_Shared_Join_Result_Without_Frequency{file_ext}.xlsx", index=False)

# %% [markdown]
# #### Copy Move And Delete

# %%
output_file = glob.glob(f"{lang_folder.capitalize()}_{lang_pair.capitalize()}_Shared*{file_ext}.xlsx")
output_file
# Out:
# ['Turkish_English_Shared_Twogram6.xlsx',
#  'Turkish_English_Shared_Threegram6.xlsx',
#  'Turkish_English_Shared_Fourgram6.xlsx',
#  'Turkish_English_Shared_Fivegram6.xlsx',
#  'Turkish_English_Shared_Sentence6.xlsx',
#  'Turkish_English_Shared_Result_With_Frequency6.xlsx',
#  'Turkish_English_Shared_Join_Result_Without_Frequency6.xlsx']

# %%
for k in output_file:
    source = k # source directory
    destination = f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Deployment/Result/4-Shared Word/{lang_folder.capitalize()} {lang_pair.capitalize()}"
    shutil.copy2(source, destination)

# %%
for i in output_file:
    try:
        os.remove(i)
    except:
        pass
