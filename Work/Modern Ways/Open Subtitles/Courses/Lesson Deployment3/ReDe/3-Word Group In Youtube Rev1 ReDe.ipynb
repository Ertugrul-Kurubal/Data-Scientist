# %% [markdown]
# ### Word Group In Youtube

# %%
import os
import multiprocessing
#import multiprocessing as mp
from multiprocessing import Process, Manager, Pool, Queue
from itertools import islice
from collections import Counter
import re
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize
from functools import reduce
from pathlib import Path
import shutil

# %%
nprocs = multiprocessing.cpu_count()
print(f"Number of CPU cores: {nprocs}")
# Out:
# Number of CPU cores: 16

# %%
# language pair
lang_folder = "Turkish"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> target language for learner

# adding native word to shared word
word_start = 0  # 0  # native word start index
word_end = 1000  # native word end index 28,200,1000,5000,10000, 20000, 40000

# word ratio
if word_end == 28 or word_end == 200:
    unique_word_ratio = 70
    include_wordgroup_ratio = 70
elif word_end == 1000 or word_end == 5000:
    unique_word_ratio = 80
    include_wordgroup_ratio = 80
elif word_end == 10000:
    unique_word_ratio = 85
    include_wordgroup_ratio = 85
else:
    unique_word_ratio = 90
    include_wordgroup_ratio = 90

# word usage
if word_end == 28 or word_end == 200 or word_end == 1000 or word_end == 5000 or word_end == 10000:
    word_usage_min = 1
    word_usage_max = 30
elif word_end == 20000:
    word_usage_min = 1
    word_usage_max = 40
else:
    word_usage_min = 1
    word_usage_max = 50

# use for manuel set
#unique_word_ratio = 70  # 28,200 = 70 ; 1000,5000 = 80 ; 10000 = 85 ; 20000,40000 = 90
#include_wordgroup_ratio = 70  # 28,200 = 70 ; 1000,5000 = 80 : 10000 = 85 ; 20000,40000 = 90
#word_usage_min = 10  # 28,200,1000,5000,10000 = 10 ; 20000 = 7 ; 40000 = 5
#word_usage_max = 100


# sentence ratio and time shift
adjust_sent_word_ratio = 25  #28,200 = 15 ; 1000,5000,10000 = 25 ; 20000 = 35 ; 40000 = 45

# start end time result shift
shift = 0.3  # sentence time shift

# func select
if word_end == 28:
    sentence_word_count_number = 2
else:
    sentence_word_count_number = 5   
word_group_adjust_select = False  # True, False; True for selecting word group according to sentence_word_count_number in video_id text analysis
                                  # False for selecting word group according to max word group length 

# shared word frequency
word_frequency = True  # True, False

# prefix suffix file
prefix_suffix = False  # True, False  # True for adding prefix suffix word
native_word = True # True for adding native word

# adding output file extention
if prefix_suffix & native_word:
    file_ext = "5"
elif (not prefix_suffix) & native_word:
    file_ext = "6"
else:
    file_ext = "7"              

# 5 => for only native word with prefix suffix.
# 6 => for only native word without prefix suffix.

print(f"word_end:{word_end}\nfile_ext:{file_ext}\nunique_word_ratio:{unique_word_ratio}\n\
include_wordgroup_ratio:{include_wordgroup_ratio}\nword_usage_min:{word_usage_min}\nword_usage_max:{word_usage_max}")
# Out:
# word_end:1000
# file_ext:6
# unique_word_ratio:80
# include_wordgroup_ratio:80
# word_usage_min:1
# word_usage_max:30

# %%
path = f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/\
Deployment3/Result/3-Word Group In Youtube"

Path(path).mkdir(parents=True, exist_ok=True)

# %%
def word_usage_result(word_list, df_target, target_column, target_opt_column, word_usage_min, word_usage_max):
    '''
    word_usage_result(word_list, df_ngram_pair, "threegram", "frequency", 1, 5) \n
    word_list is a list, df_target is a dateframe, target_column is df_target dataframe target column, \n
    target_opt_column is df_target dataframe opt_target column, \n
    word_usage_min and word_usage_max word usage condition.
    '''    
    word_num_dict = {}
    for i in word_list:
        word_num_dict[f"{i}"] = 0
    
    result_list_select = []
    var_list = []
    for i in range(len(df_target)):
        target_value = df_target.loc[i,f"{target_column}"]
        opt_value = df_target.loc[i,f"{target_opt_column}"]
        words = word_tokenize(target_value)   
        temp_list = [word for word in words]
        temp_list = temp_list + var_list
        # word count for max
        dict_list_count = Counter(temp_list)
        count_list = list(dict_list_count.values())
        # word count for min
        count_list2 = list(word_num_dict.values())
    
        if any([True if i>word_usage_max else False for i in count_list]) or not(any([True if j<word_usage_min else False for j in count_list2])):
            pass
        else:
            var_list = temp_list
            result_list_select.append([target_value,opt_value]) 
    
            for item2 in dict_list_count.items(): 
                word_num_dict[item2[0]] = item2[1]        
    df_result = pd.DataFrame(result_list_select, columns=[f"{target_column}",f"{target_opt_column}"])
    df_result.sort_values(by=f"{target_opt_column}", ascending=False, inplace=True)
    df_result.reset_index(drop=True, inplace=True)
    
    return df_result

# %%
def word_usage_result2(word_list, df_target, target_column, target_opt_column, word_usage_min, word_adjust_usage_dict):
    '''
    word_usage_result(word_list, df_ngram_pair, "threegram", "frequency", 1, 5) \n
    word_list is a list, df_target is a dateframe, target_column is df_target dataframe target column, \n
    target_opt_column is df_target dataframe opt_target column, \n
    word_usage_min and word_usage_max word usage condition.
    '''    
    word_num_dict = {}
    for i in word_list:
        word_num_dict[f"{i}"] = 0
    
    result_list_select = []
    var_list = []
    for i in range(len(df_target)):
        target_value = df_target.loc[i,f"{target_column}"]
        opt_value = df_target.loc[i,f"{target_opt_column}"]
        words = word_tokenize(target_value)   
        temp_list = [word for word in words]
        temp_list = temp_list + var_list
        # word count for max
        dict_list_count = Counter(temp_list)
        #count_list = list(dict_list_count.values())
        # word count for min
        count_list2 = list(word_num_dict.values())
    
        if any(True if word_adjust_usage_dict[f"{word}"] < dict_list_count[f"{word}"] else False for word in words) or not(any([True if j<word_usage_min else False for j in count_list2])):
            pass
        else:
            var_list = temp_list
            result_list_select.append([target_value,opt_value]) 
    
            for item2 in dict_list_count.items(): 
                word_num_dict[item2[0]] = item2[1]        
    df_result = pd.DataFrame(result_list_select, columns=[f"{target_column}",f"{target_opt_column}"])
    df_result.sort_values(by=f"{target_opt_column}", ascending=False, inplace=True)
    df_result.reset_index(drop=True, inplace=True)
    
    return df_result

# %%
def exract_word_group(text, word_list):
    '''
    exract_word_group(text, word_list): \n
    text is a string sentence, word_list occurs words 
    '''
    words = re.findall(r"\w+", text, re.UNICODE)
    index_list = []
    # check words in word_list
    for i in range(len(words)):
        if words[i] in word_list:
            index_list.append(i)
        else:
            pass
    # add index plus 1 and compare with current and next index (Is it continuous or not?)
    all_index_list = []
    var_index_list = []
    for j in range(len(index_list)):
        try:
            var1 = index_list[j] + 1  
            var2 = index_list[j+1]
        except:
            var1 = index_list[j] + 1  
            var2 = index_list[-1]
        if var1 == var2:
            var3 = index_list[j]
            var_index_list.append(var3)
        else:
            var3 = index_list[j]
            var_index_list.append(var3)
            var4 = list(var_index_list)
            all_index_list.append(var4)
            var_index_list = []
    # index convert to word
    text_list = []
    for k in max(all_index_list, key=len):  # any error convert k to i
        word = words[k]
        text_list.append(word)
        if len(text_list) >= sentence_word_count_number:
            text = " ".join(text_list)
        else:
            text = f"sentencte_word_count_less_than_{sentence_word_count_number}"
    
    return text

# %%
def df_exract_word_group(df, source_text_column, opt_column, word_list, sent_len=False, sent_len_num=2):
    '''
    df_exract_word_group(df_adjust_text_ratio, sentence, video_id, word_list, sent_len=False, sent_len_num=2): \n
    df_adjust_text_ratio is a dataframe and it includes sentence and video_id columns. \n
    sentence is a string sentence. video_id is optional column value. word_list occurs words \n
    sent_len is sentence length condition. sent_len_num is sentence occurs how many word at least. 
    '''
    df.reset_index(drop=True, inplace=True)
    df_new = pd.DataFrame()
    for i in range(len(df)):
        source_text = df.loc[i,f"{source_text_column}"]
        opt_var = df.loc[i,f"{opt_column}"]
        words = re.findall(r"\w+", source_text, re.UNICODE)
        # check words in word_list
        index_list = []
        for j in range(len(words)):
            if words[j] in word_list:
                index_list.append(j)
            else:
                pass
        # add index plus 1 and compare with current and next index (Is it continuous or not?)
        all_index_list = []
        var_index_list = []
        for k in range(len(index_list)):
            try:
                var1 = index_list[k] + 1  
                var2 = index_list[k+1]
            except:
                var1 = index_list[k] + 1  
                var2 = index_list[-1]
            if var1 == var2:
                var3 = index_list[k]
                var_index_list.append(var3)
            else:
                var3 = index_list[k]
                var_index_list.append(var3)
                var4 = list(var_index_list)
                all_index_list.append(var4)
                var_index_list = []
        # index convert to word
        text_all_list = []
        for m in all_index_list:
            text_list = [] 
            for n in m:
                word = words[n]
                text_list.append(word)
                if sent_len:
                    if len(text_list) >= sent_len_num:
                        text = " ".join(text_list)
                        text_all_list.append(text)
                    else:
                        pass
                else:
                   text = " ".join(text_list)
                   text_all_list.append(text) 
        # dataframe output     
        for search_string in text_all_list:
            #df_var["index"] = i
            #df_var["search_string"] = search_string
            #df_var["sentence"] = source_text
            #df_var["video_id"] = opt_var
            df_list = []
            df_list.append([i,search_string,source_text,opt_var])
            df_var = pd.DataFrame(df_list,columns=["index","search_string",f"{source_text_column}",f"{opt_column}"])
            df_new = pd.concat([df_new, df_var], axis=0)

    return df_new

# %%
def word_group_time_loc(df, search, start_sent, end_sent, sent, sent_video_id):
    '''
    word_group_time_loc(df_search_result, "search_string", "start_time", "end_time", "sentence", "video_id")
    '''
    df.reset_index(drop=True, inplace=True)  # will test
    word_time_loc_list = []
    for i in range(len(df)):
        word = df.loc[i,f"{search}"]
        start_time = df.loc[i,f"{start_sent}"]
        end_time = df.loc[i,f"{end_sent}"]
        sentence = df.loc[i,f"{sent}"]
        video_id = df.loc[i,f"{sent_video_id}"]
        time_length = end_time-start_time
        sentence_length = len(sentence)
        time_length_ratio = time_length/sentence_length
        loc_list = []
        for j in re.finditer(fr"(?:\s|^){word}(?:\s|$)", sentence, re.IGNORECASE|re.UNICODE):
            loc_list.append(j)
            start = loc_list[0].start()
            end = loc_list[0].end()
            start_loc = start_time+(start*time_length_ratio)
            end_loc = start_time+(end*time_length_ratio)
        word_time_loc_list.append([word,start_loc,end_loc,sentence,video_id])
    df_word_time_loc = pd.DataFrame(word_time_loc_list, columns=[f"{search}",f"{start_sent}",f"{end_sent}",f"{sent}",f"{sent_video_id}"])

    return df_word_time_loc

# %%
def repetation_ratio(text):
    '''
    repetation_ratio(text) 
    text is a like as sentence and def compute repetation word ratio\n
    repetation_ratio("yok bir şey yok bir şey yok bir şey") 
    '''
    word_list = word_tokenize(text)
    word_num = len(word_list)
    word_unique_num = len(set(word_list))
    ratio = int((word_unique_num/word_num)*100)
    
    return ratio

# %%
def word_count_result(df,column_list): # df is dataframe, column_list is list value
    '''
    word_count_bool(df, column_list): df columns word count for word frequency\n
    df is dataframe, column_list is list value\n
    word_count_bool(df, ["word","twogram"]):
    '''
    list_all = []
    for i in df.loc[:,[x for x in column_list]].columns:
        var_list = df[f"{i}"].dropna().tolist()
        for j in var_list:
            list_all.append(j)
    text = " ".join(list_all)
    word_list = re.findall(r"\w+",text, re.UNICODE)
    df_word_list = pd.DataFrame(word_list, columns=["word"])
    #df_word_list.rename(columns={0:"word"}, inplace=True)
    df_word_count = pd.DataFrame(df_word_list.value_counts())
    df_word_count.reset_index(inplace=True)
    df_word_count.rename(columns={0:"word_count"}, inplace=True)
    
    return  df_word_count

# %%
def word_max_usage_limit(df, word_column_name, word_freq_column_name, min_word_usage):
    '''
    word_max_usage_limit(df, word_column_name, word_freq_column_name, min_word_usage)
    '''
    word_adjust_usage_dict = {}
    min_frequency = min(df[f"{word_freq_column_name}"])
    for word,frequency in zip(df[f"{word_column_name}"], df[f"{word_freq_column_name}"]):        
        word_usage_var = int((frequency*min_word_usage)/min_frequency)
        word_adjust_usage_dict[f"{word}"] = word_usage_var
    return word_adjust_usage_dict

# %% [markdown]
# #### Select Word

# %%
df_word_all = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.lower().capitalize()}/Deployment/Data/Word/Word_Merge_Preprocess.xlsx")
df_word_all  # word checked with picture word
# Out:
#                 word  frequency
# 0                bir   18835735
# 1                 bu   11062659
# 2                 ne    8025880
# 3                 ve    7766036
# 4               için    5484109
# ...              ...        ...
# 987890     karneleme          5
# 987891       karnaya          5
# 987892   dörtlümüzün          5
# 987893  karnavalınız          5
# 987894      hurmanın          5
#
# [987895 rows x 2 columns]

# %%
df_word_select = df_word_all.iloc[word_start:word_end,]

# %%
# Option
if prefix_suffix:
    df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_folder.capitalize()}/{lang_folder.capitalize()}/{lang_folder.capitalize()}_{word_end}_Word_Prefix_Suffix_Custom_Result_Manuel.xlsx")
    df_word = df_word.loc[:,["word","frequency"]]
    df_word = pd.concat([df_word,df_word_select], axis=0)
    df_word.drop_duplicates(inplace=True)    
    df_word.sort_values(by="frequency", ascending=False, inplace=True)
    df_word.reset_index(drop=True, inplace=True)
else:
    df_word = df_word_select

if native_word:
    df_word
else:
    df_word = df_word.head(0)

df_word
# Out:
#         word  frequency
# 0        bir   18835735
# 1         bu   11062659
# 2         ne    8025880
# 3         ve    7766036
# 4       için    5484109
# ..       ...        ...
# 995    resmi      68287
# 996  veriyor      68163
# 997     okul      68160
# 998    suçlu      68124
# 999   mesela      68096
#
# [1000 rows x 2 columns]

# %%
disable_list = ["sex","seks","seksi","sexy","sexe","seksüel","sexuell","gey","gay","lezbiyen","lesbienne","eşcinsel","mastürbasyon","masturbation","erotik","érotique", \
"bikini","penis","vagina","vajina","fetish","fetiş","fetishy","erotic","erotik","sexdom","kondom","condom","dildo","fetisj","hétérosexuel","féticher","fétiche","homosexuel"\
"ereksiyon","erectie","erection","érection","homoseksüel","prezervatif","préservatif","ass","fetisch","fetiche"]

# %%
word_select = df_word["word"].values.tolist()
word_select_set = set(word_select)
disable_word_set = set(disable_list)

# %%
word_list = list(word_select_set.difference(disable_word_set))
len(word_list)
# Out:
# 1000

# %% [markdown]
# ##### Check Word From Picture Word

# %%
image_path_folder = f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Image Audio Video/Data/1000 Words/Genome_Picture_In_Picture_Select_Rename"

# %%
file_list = os.listdir(f"{image_path_folder}")
file_list
# Out:
# ['bir.jpg',
#  'biraz.jpg',
#  'biri.jpg',
#  'birlikte.jpg',
#  'birini.jpg',
#  'birisi.jpg',
#  'birinin.jpg',
#  'birine.jpg',
#  'birden.jpg',
#  'biriyle.jpg',
#  'bu.jpg',
#  'bunu.jpg',
#  'bunun.jpg',
#  'buna.jpg',
#  'bunlar.jpg',
#  'bundan.jpg',
#  'bunları.jpg',
#  'bununla.jpg',
#  'bunların.jpg',
#  'ne.jpg',
#  'neler.jpg',
#  'nedir.jpg',
#  'neyi.jpg',
#  'neydi.jpg',
#  'neyin.jpg',
#  'neye.jpg',
#  've.jpg',
#  'için.jpg',
#  'içinde.jpg',
#  'içine.jpg',
#  'mi.jpg',
#  'misin.jpg',
#  'miyim.jpg',
#  'misiniz.jpg',
#  'miyiz.jpg',
#  'miydi.jpg',
#  'o.jpg',
#  'onu.jpg',
#  'ona.jpg',
#  'onun.jpg',
#  'onları.jpg',
#  'onlar.jpg',
#  'onunla.jpg',
#  'onlara.jpg',
#  'ondan.jpg',
#  'onların.jpg',
#  'onlardan.jpg',
#  'onlarla.jpg',
#  'ben.jpg',
#  'beni.jpg',
#  'benim.jpg',
#  'benimle.jpg',
#  'bence.jpg',
#  'benden.jpg',
#  'bende.jpg',
#  'de.jpg',
#  'demek.jpg',
#  'dedim.jpg',
#  'dedi.jpg',
#  'dersin.jpg',
#  'dedin.jpg',
#  'demektir.jpg',
#  'çok.jpg',
#  'çoktan.jpg',
#  'ama.jpg',
#  'var.jpg',
#  'vardı.jpg',
#  'vardır.jpg',
#  'varsa.jpg',
#  'varmış.jpg',
#  'evet.jpg',
#  'mı.jpg',
#  'mısın.jpg',
#  'mısınız.jpg',
#  'mıydı.jpg',
#  'değil.jpg',
#  'değilim.jpg',
#  'değildi.jpg',
#  'değilsin.jpg',
#  'değildir.jpg',
#  'değiliz.jpg',
#  'da.jpg',
#  'şey.jpg',
#  'şeyi.jpg',
#  'şeyler.jpg',
#  'şeyin.jpg',
#  'şeye.jpg',
#  'şeyleri.jpg',
#  'şeyden.jpg',
#  'hayır.jpg',
#  'daha.jpg',
#  'sen.jpg',
#  'seni.jpg',
#  'senin.jpg',
#  'seninle.jpg',
#  'senden.jpg',
#  'sence.jpg',
#  'sende.jpg',
#  'sensin.jpg',
#  'kadar.jpg',
#  'bana.jpg',
#  'yok.jpg',
#  'yoksa.jpg',
#  'yoktu.jpg',
#  'yoktur.jpg',
#  'gibi.jpg',
#  'iyi.jpg',
#  'iyiyim.jpg',
#  'iyisi.jpg',
#  'tamam.jpg',
#  'tamamen.jpg',
#  'tamamdır.jpg',
#  'her.jpg',
#  'sana.jpg',
#  'ki.jpg',
#  'neden.jpg',
#  'zaman.jpg',
#  'zamanı.jpg',
#  'zamanda.jpg',
#  'zamandır.jpg',
#  'zamanlar.jpg',
#  'sadece.jpg',
#  'burada.jpg',
#  'buradan.jpg',
#  'buradayım.jpg',
#  'buradaki.jpg',
#  'nasıl.jpg',
#  'nasılsın.jpg',
#  'olduğunu.jpg',
#  'hiç.jpg',
#  'sonra.jpg',
#  'sonraki.jpg',
#  'şimdi.jpg',
#  'şimdiye.jpg',
#  'en.jpg',
#  'ya.jpg',
#  'öyle.jpg',
#  'öyleyse.jpg',
#  'mu.jpg',
#  'musun.jpg',
#  'musunuz.jpg',
#  'şu.jpg',
#  'şunu.jpg',
#  'şuna.jpg',
#  'hadi.jpg',
#  'önce.jpg',
#  'önceki.jpg',
#  'güzel.jpg',
#  'oldu.jpg',
#  'olduğu.jpg',
#  'olduğumu.jpg',
#  'oldukça.jpg',
#  'oldum.jpg',
#  'olduğuna.jpg',
#  'olduğun.jpg',
#  'olduğum.jpg',
#  'olduğundan.jpg',
#  'oldun.jpg',
#  'böyle.jpg',
#  'böylece.jpg',
#  'lütfen.jpg',
#  'bile.jpg',
#  'bilemiyorum.jpg',
#  'yani.jpg',
#  'artık.jpg',
#  'geri.jpg',
#  'bak.jpg',
#  'bakalım.jpg',
#  'bakın.jpg',
#  'bakma.jpg',
#  'baksana.jpg',
#  'bakayım.jpg',
#  'istiyorum.jpg',
#  'peki.jpg',
#  'eğer.jpg',
#  'çünkü.jpg',
#  'biliyorum.jpg',
#  'gerçekten.jpg',
#  'başka.jpg',
#  'tek.jpg',
#  'olarak.jpg',
#  'belki.jpg',
#  'doğru.jpg',
#  'büyük.jpg',
#  'buraya.jpg',
#  'olan.jpg',
#  'olur.jpg',
#  'olursa.jpg',
#  'olurdu.jpg',
#  'adam.jpg',
#  'adamı.jpg',
#  'adamın.jpg',
#  'adamım.jpg',
#  'adamlar.jpg',
#  'adama.jpg',
#  'hey.jpg',
#  'olacak.jpg',
#  'olacaksın.jpg',
#  'hiçbir.jpg',
#  'efendim.jpg',
#  'yardım.jpg',
#  'yardımcı.jpg',
#  'biz.jpg',
#  'bize.jpg',
#  'bizi.jpg',
#  'bizim.jpg',
#  'bizimle.jpg',
#  'bizden.jpg',
#  'ile.jpg',
#  'nerede.jpg',
#  'nereden.jpg',
#  'neredeyse.jpg',
#  'sanırım.jpg',
#  'tüm.jpg',
#  'orada.jpg',
#  'oradan.jpg',
#  'bilmiyorum.jpg',
#  'gün.jpg',
#  'günü.jpg',
#  'günler.jpg',
#  'fazla.jpg',
#  'ederim.jpg',
#  'teşekkürler.jpg',
#  'yeni.jpg',
#  'yeniden.jpg',
#  'son.jpg',
#  'sonunda.jpg',
#  'sonsuza.jpg',
#  'sonu.jpg',
#  'sona.jpg',
#  'et.jpg',
#  'etmek.jpg',
#  'etti.jpg',
#  'etme.jpg',
#  'ettim.jpg',
#  'etmeye.jpg',
#  'ettin.jpg',
#  'merhaba.jpg',
#  'kötü.jpg',
#  'gece.jpg',
#  'geceler.jpg',
#  'işte.jpg',
#  'biliyor.jpg',
#  'biliyorsun.jpg',
#  'biliyordum.jpg',
#  'biliyoruz.jpg',
#  'iki.jpg',
#  'ikinci.jpg',
#  'sorun.jpg',
#  'tam.jpg',
#  'bütün.jpg',
#  'hemen.jpg',
#  'harika.jpg',
#  'olsun.jpg',
#  'gerek.jpg',
#  'gerekiyor.jpg',
#  'gereken.jpg',
#  'gerektiğini.jpg',
#  'gerekir.jpg',
#  'gerekiyordu.jpg',
#  'ol.jpg',
#  'olabilir.jpg',
#  'oluyor.jpg',
#  'olmak.jpg',
#  'olmaz.jpg',
#  'olmalı.jpg',
#  'olmuş.jpg',
#  'olması.jpg',
#  'olamaz.jpg',
#  'olsa.jpg',
#  'olun.jpg',
#  'olmadığını.jpg',
#  'olacağım.jpg',
#  'olmadan.jpg',
#  'olacağını.jpg',
#  'olmayacak.jpg',
#  'olmadı.jpg',
#  'olmayan.jpg',
#  'olup.jpg',
#  'olmalısın.jpg',
#  'olsaydı.jpg',
#  'olmasını.jpg',
#  'olası.jpg',
#  'olmaya.jpg',
#  'olma.jpg',
#  'olmasın.jpg',
#  'siz.jpg',
#  'size.jpg',
#  'sizi.jpg',
#  'sizin.jpg',
#  'sizinle.jpg',
#  'üzgünüm.jpg',
#  'diye.jpg',
#  'gel.jpg',
#  'geldi.jpg',
#  'geliyor.jpg',
#  'gelecek.jpg',
#  'geldim.jpg',
#  'gelen.jpg',
#  'geldin.jpg',
#  'gelip.jpg',
#  'geliyorum.jpg',
#  'gelmiş.jpg',
#  'geldiniz.jpg',
#  'geldik.jpg',
#  'geldiğini.jpg',
#  'gelmek.jpg',
#  'küçük.jpg',
#  'teşekkür.jpg',
#  'devam.jpg',
#  'tabii.jpg',
#  'aynı.jpg',
#  'ver.jpg',
#  'verdi.jpg',
#  'verin.jpg',
#  'verdim.jpg',
#  'veriyorum.jpg',
#  'vermek.jpg',
#  'verir.jpg',
#  'vereceğim.jpg',
#  'verici.jpg',
#  'veriyor.jpg',
#  'yüzden.jpg',
#  'kendi.jpg',
#  'kendini.jpg',
#  'kendine.jpg',
#  'kendimi.jpg',
#  'kendisi.jpg',
#  'kendim.jpg',
#  'kendime.jpg',
#  'hakkında.jpg',
#  'haydi.jpg',
#  'kız.jpg',
#  'kızı.jpg',
#  'kızlar.jpg',
#  'kızım.jpg',
#  'kızın.jpg',
#  'izin.jpg',
#  'iş.jpg',
#  'işe.jpg',
#  'işi.jpg',
#  'işin.jpg',
#  'işler.jpg',
#  'işim.jpg',
#  'işini.jpg',
#  'dur.jpg',
#  'durum.jpg',
#  'durumda.jpg',
#  'durun.jpg',
#  'durumu.jpg',
#  'git.jpg',
#  'gitti.jpg',
#  'gitmek.jpg',
#  'gitmem.jpg',
#  'gitsin.jpg',
#  'kimse.jpg',
#  'kimsenin.jpg',
#  'kimseye.jpg',
#  'asla.jpg',
#  'göre.jpg',
#  'önemli.jpg',
#  'baba.jpg',
#  'babam.jpg',
#  'baban.jpg',
#  'babası.jpg',
#  'babamın.jpg',
#  'tekrar.jpg',
#  'söyle.jpg',
#  'söyledi.jpg',
#  'söyledim.jpg',
#  'söylemek.jpg',
#  'söyledin.jpg',
#  'söylemiştim.jpg',
#  'söyleme.jpg',
#  'söyleyeyim.jpg',
#  'özür.jpg',
#  'mü.jpg',
#  'dostum.jpg',
#  'selam.jpg',
#  'yine.jpg',
#  'hala.jpg',
#  'anne.jpg',
#  'annem.jpg',
#  'annen.jpg',
#  'al.jpg',
#  'aldım.jpg',
#  'almak.jpg',
#  'aldı.jpg',
#  'alıp.jpg',
#  'aldın.jpg',
#  'alın.jpg',
#  'almaya.jpg',
#  'alabilir.jpg',
#  'alacağım.jpg',
#  'alır.jpg',
#  'bugün.jpg',
#  'üç.jpg',
#  'üçüncü.jpg',
#  'uzun.jpg',
#  'herkes.jpg',
#  'herkesin.jpg',
#  'herkese.jpg',
#  'herkesi.jpg',
#  'aslında.jpg',
#  'dakika.jpg',
#  'para.jpg',
#  'parayı.jpg',
#  'şekilde.jpg',
#  'gerçek.jpg',
#  'pekala.jpg',
#  'istiyorsun.jpg',
#  'istiyorsunuz.jpg',
#  'birkaç.jpg',
#  'zaten.jpg',
#  'ilk.jpg',
#  'lazım.jpg',
#  'saat.jpg',
#  'yapıyorsun.jpg',
#  'ister.jpg',
#  'istersen.jpg',
#  'isterim.jpg',
#  'bay.jpg',
#  'bayım.jpg',
#  'bayan.jpg',
#  'bayanlar.jpg',
#  'emin.jpg',
#  'eminim.jpg',
#  'pek.jpg',
#  'gidelim.jpg',
#  'bırak.jpg',
#  'bırakın.jpg',
#  'yer.jpg',
#  'yere.jpg',
#  'yerde.jpg',
#  'yerine.jpg',
#  'yeri.jpg',
#  'yerinde.jpg',
#  'yerini.jpg',
#  'hep.jpg',
#  'hepsi.jpg',
#  'hepimiz.jpg',
#  'hepsini.jpg',
#  'hepiniz.jpg',
#  'yıl.jpg',
#  'yıldır.jpg',
#  'çocuk.jpg',
#  'çocuklar.jpg',
#  'çocukları.jpg',
#  'eve.jpg',
#  'bekle.jpg',
#  'bekleyin.jpg',
#  'nereye.jpg',
#  'burası.jpg',
#  'dilerim.jpg',
#  'karşı.jpg',
#  'hazır.jpg',
#  'an.jpg',
#  'anda.jpg',
#  'kaç.jpg',
#  'istemiyorum.jpg',
#  'az.jpg',
#  'azından.jpg',
#  'ilgili.jpg',
#  'söz.jpg',
#  'ediyorum.jpg',
#  'eski.jpg',
#  'eskiden.jpg',
#  'dinle.jpg',
#  'dinleyin.jpg',
#  'tane.jpg',
#  'fakat.jpg',
#  'zor.jpg',
#  'zorunda.jpg',
#  'zorundayım.jpg',
#  'kesinlikle.jpg',
#  'yapmak.jpg',
#  'kişi.jpg',
#  'kadın.jpg',
#  'görmek.jpg',
#  'istiyor.jpg',
#  'istiyorsan.jpg',
#  'istiyoruz.jpg',
#  'diğer.jpg',
#  'sağ.jpg',
#  'kabul.jpg',
#  'seviyorum.jpg',
#  'niye.jpg',
#  'aman.jpg',
#  'elbette.jpg',
#  'kez.jpg',
#  'yarın.jpg',
#  'yapma.jpg',
#  'yapmaya.jpg',
#  'yapmam.jpg',
#  'edin.jpg',
#  'hem.jpg',
#  'falan.jpg',
#  'oraya.jpg',
#  'hoş.jpg',
#  'hoşça.jpg',
#  'hoşuma.jpg',
#  'gidip.jpg',
#  'yanlış.jpg',
#  'kontrol.jpg',
#  'özel.jpg',
#  'özellikle.jpg',
#  'ediyor.jpg',
#  'ediyorsun.jpg',
#  'tatlım.jpg',
#  'doktor.jpg',
#  'geç.jpg',
#  'geçen.jpg',
#  'geçti.jpg',
#  'hafta.jpg',
#  'yemek.jpg',
#  'dışarı.jpg',
#  'dışarıda.jpg',
#  'mutlu.jpg',
#  'insan.jpg',
#  'insanlar.jpg',
#  'insanların.jpg',
#  'insanları.jpg',
#  'gördüm.jpg',
#  'bazı.jpg',
#  'polis.jpg',
#  'yalnız.jpg',
#  'yalnızca.jpg',
#  'dikkat.jpg',
#  'dikkatli.jpg',
#  'sakin.jpg',
#  'çabuk.jpg',
#  'beri.jpg',
#  'merak.jpg',
#  'yalan.jpg',
#  'ihtiyacım.jpg',
#  'ihtiyacımız.jpg',
#  'gidiyor.jpg',
#  'gidiyorum.jpg',
#  'gidiyoruz.jpg',
#  'gidiyorsun.jpg',
#  'ayrıca.jpg',
#  'haber.jpg',
#  'beş.jpg',
#  'görüşürüz.jpg',
#  'dün.jpg',
#  'erkek.jpg',
#  'umarım.jpg',
#  'nefret.jpg',
#  'sanki.jpg',
#  'öldü.jpg',
#  'öldürmek.jpg',
#  'karar.jpg',
#  'veya.jpg',
#  'gördün.jpg',
#  'aptal.jpg',
#  'sabah.jpg',
#  'yeter.jpg',
#  'yeterince.jpg',
#  'yeterli.jpg',
#  'yaptım.jpg',
#  'kes.jpg',
#  'ateş.jpg',
#  'akşam.jpg',
#  'yap.jpg',
#  'yaptın.jpg',
#  'yapıyor.jpg',
#  'yaptı.jpg',
#  'yaptığını.jpg',
#  'yapacağım.jpg',
#  'yapamam.jpg',
#  'yapacağız.jpg',
#  'yapacak.jpg',
#  'yapıyorum.jpg',
#  'yapar.jpg',
#  'yapacaksın.jpg',
#  'yaparım.jpg',
#  'yapalım.jpg',
#  'yaptığı.jpg',
#  'yapan.jpg',
#  'yaptığın.jpg',
#  'yapabilirim.jpg',
#  'yapmış.jpg',
#  'yaptığım.jpg',
#  'farklı.jpg',
#  'birşey.jpg',
#  'tarafından.jpg',
#  'boyunca.jpg',
#  'su.jpg',
#  'üzerinde.jpg',
#  'dört.jpg',
#  'adı.jpg',
#  'adını.jpg',
#  'adına.jpg',
#  'fark.jpg',
#  'ay.jpg',
#  'dolar.jpg',
#  'hangi.jpg',
#  'açık.jpg',
#  'yol.jpg',
#  'yolu.jpg',
#  'yolunda.jpg',
#  'yola.jpg',
#  'istediğim.jpg',
#  'kal.jpg',
#  'kaldı.jpg',
#  'kalan.jpg',
#  'kalmak.jpg',
#  'neyse.jpg',
#  'yüzünden.jpg',
#  'bitti.jpg',
#  'ancak.jpg',
#  'başına.jpg',
#  'yanında.jpg',
#  'adım.jpg',
#  'cevap.jpg',
#  'kolay.jpg',
#  'ise.jpg',
#  'görünüyor.jpg',
#  'görünüyorsun.jpg',
#  'sahip.jpg',
#  'henüz.jpg',
#  'anlıyorum.jpg',
#  'beraber.jpg',
#  'buldum.jpg',
#  'konuşmak.jpg',
#  'bazen.jpg',
#  'takip.jpg',
#  'sakın.jpg',
#  'aç.jpg',
#  'savaş.jpg',
#  'dünya.jpg',
#  'dünyanın.jpg',
#  'dünyada.jpg',
#  'genç.jpg',
#  'eder.jpg',
#  'hızlı.jpg',
#  'içeri.jpg',
#  'on.jpg',
#  'altında.jpg',
#  'uzak.jpg',
#  'hayatta.jpg',
#  'saniye.jpg',
#  'konusunda.jpg',
#  'evde.jpg',
#  'süre.jpg',
#  'sürekli.jpg',
#  'boş.jpg',
#  'göz.jpg',
#  'oğlum.jpg',
#  'halde.jpg',
#  'ara.jpg',
#  'arada.jpg',
#  'arasında.jpg',
#  'ciddi.jpg',
#  'düşünüyorsun.jpg',
#  'sanmıyorum.jpg',
#  'duydum.jpg',
#  'mükemmel.jpg',
#  'güçlü.jpg',
#  'galiba.jpg',
#  'konuda.jpg',
#  'istedim.jpg',
#  'kan.jpg',
#  'düşündüm.jpg',
#  'tabi.jpg',
#  'çıktı.jpg',
#  'bin.jpg',
#  'herhangi.jpg',
#  'ev.jpg',
#  'evine.jpg',
#  'evi.jpg',
#  'muhtemelen.jpg',
#  'yakın.jpg',
#  'yakında.jpg',
#  'söylüyor.jpg',
#  'söylüyorum.jpg',
#  'söylüyorsun.jpg',
#  'silah.jpg',
#  'silahı.jpg',
#  'düşünüyorum.jpg',
#  'rahat.jpg',
#  'rahatsız.jpg',
#  'hayatım.jpg',
#  'anladım.jpg',
#  'kimin.jpg',
#  'alo.jpg',
#  'hayal.jpg',
#  'araba.jpg',
#  'arabayı.jpg',
#  'çocuğu.jpg',
#  'çocuğun.jpg',
#  'hava.jpg',
#  'bebeğim.jpg',
#  'evlat.jpg',
#  'çalışıyorum.jpg',
#  'acele.jpg',
#  'hareket.jpg',
#  'kesin.jpg',
#  'sürü.jpg',
#  'garip.jpg',
#  'başladı.jpg',
#  'altı.jpg',
#  'altına.jpg',
#  'herif.jpg',
#  'hayat.jpg',
#  'hayatını.jpg',
#  'ortaya.jpg',
#  'çalışıyor.jpg',
#  'çalışıyorsun.jpg',
#  'acaba.jpg',
#  'kapıyı.jpg',
#  'oyun.jpg',
#  'hatta.jpg',
#  'kardeşim.jpg',
#  'soru.jpg',
#  'canım.jpg',
#  'komik.jpg',
#  'bilirsin.jpg',
#  'gizli.jpg',
#  'el.jpg',
#  'ele.jpg',
#  'elinde.jpg',
#  'terk.jpg',
#  'zarar.jpg',
#  'gelir.jpg',
#  'beyler.jpg',
#  'kısa.jpg',
#  'üzerine.jpg',
#  'ihtiyacı.jpg',
#  'ihtiyacın.jpg',
#  'haklısın.jpg',
#  'diyorsun.jpg',
#  'ait.jpg',
#  'telefon.jpg',
#  'şaka.jpg',
#  'günaydın.jpg',
#  'bebek.jpg',
#  'olay.jpg',
#  'olayı.jpg',
#  'sanıyorsun.jpg',
#  'arkadaşım.jpg',
#  'gelin.jpg',
#  'çeviri.jpg',
#  'uygun.jpg',
#  'çıkar.jpg',
#  'aynen.jpg',
#  'dans.jpg',
#  'beyaz.jpg',
#  'memnun.jpg',
#  'dışında.jpg',
#  'ölüm.jpg',
#  'tuhaf.jpg',
#  'yüksek.jpg',
#  'korkunç.jpg',
#  'tür.jpg',
#  'yaşlı.jpg',
#  'edecek.jpg',
#  'dolu.jpg',
#  'eden.jpg',
#  'fikir.jpg',
#  'anladın.jpg',
#  'sevindim.jpg',
#  'bilmek.jpg',
#  'mümkün.jpg',
#  'kere.jpg',
#  'sanıyordum.jpg',
#  'acı.jpg',
#  'hissediyorum.jpg',
#  'tahmin.jpg',
#  'üzere.jpg',
#  'kapa.jpg',
#  'şöyle.jpg',
#  'milyon.jpg',
#  'başkan.jpg',
#  'ölü.jpg',
#  'güvenlik.jpg',
#  'çık.jpg',
#  'belli.jpg',
#  'aşağı.jpg',
#  'affedersiniz.jpg',
#  'yemin.jpg',
#  'dön.jpg',
#  'otur.jpg',
#  'anlaşıldı.jpg',
#  'dek.jpg',
#  'kaptan.jpg',
#  'at.jpg',
#  'deli.jpg',
#  'ana.jpg',
#  'çek.jpg',
#  'çekil.jpg',
#  'çekilin.jpg',
#  'hasta.jpg',
#  'sefer.jpg',
#  'berbat.jpg',
#  'istedi.jpg',
#  'istediğini.jpg',
#  'istediğin.jpg',
#  'baş.jpg',
#  'başıma.jpg',
#  'diyorum.jpg',
#  'normal.jpg',
#  'şans.jpg',
#  'güç.jpg',
#  'tatlı.jpg',
#  'dair.jpg',
#  'keşke.jpg',
#  'getir.jpg',
#  'getirdim.jpg',
#  'gidin.jpg',
#  'yukarı.jpg',
#  'yavaş.jpg',
#  'tehlikeli.jpg',
#  'bilmem.jpg',
#  'pardon.jpg',
#  'hata.jpg',
#  'aşk.jpg',
#  'aşkına.jpg',
#  'sessiz.jpg',
#  'üstüne.jpg',
#  'duydun.jpg',
#  'önünde.jpg',
#  'aile.jpg',
#  'millet.jpg',
#  'yüz.jpg',
#  'asıl.jpg',
#  'nefes.jpg',
#  'kahve.jpg',
#  'basit.jpg',
#  'diyor.jpg',
#  'bilgi.jpg',
#  'kusura.jpg',
#  'tut.jpg',
#  'görüyorum.jpg',
#  'sıcak.jpg',
#  'koca.jpg',
#  'bilmiyor.jpg',
#  'bilmiyordum.jpg',
#  'ufak.jpg',
#  'hak.jpg',
#  'haklı.jpg',
#  'edeceğim.jpg',
#  'arkadaş.jpg',
#  'arkadaşın.jpg',
#  'arkadaşı.jpg',
#  'yaşında.jpg',
#  'benziyor.jpg',
#  'tıpkı.jpg',
#  'yedi.jpg',
#  'herhalde.jpg',
#  'vakit.jpg',
#  'doğum.jpg',
#  'birçok.jpg',
#  'dalga.jpg',
#  'erken.jpg',
#  'düşünüyor.jpg',
#  'köpek.jpg',
#  'temiz.jpg',
#  'sesini.jpg',
#  'görüyor.jpg',
#  'cidden.jpg',
#  'ajan.jpg',
#  'fena.jpg',
#  'bulmak.jpg',
#  'mesaj.jpg',
#  'buldun.jpg',
#  'gayet.jpg',
#  'anlamıyorum.jpg',
#  'düşün.jpg',
#  'şarkı.jpg',
#  'bilir.jpg',
#  'konu.jpg',
#  'inanamıyorum.jpg',
#  'hatırlıyor.jpg',
#  'hatırlıyorum.jpg',
#  'muhteşem.jpg',
#  'sağol.jpg',
#  'sayın.jpg',
#  'acil.jpg',
#  'kimsin.jpg',
#  'güvenli.jpg',
#  'bekliyor.jpg',
#  'kalk.jpg',
#  'yanına.jpg',
#  'canlı.jpg',
#  'cinayet.jpg',
#  'sevgili.jpg',
#  'zavallı.jpg',
#  'rağmen.jpg',
#  'teslim.jpg',
#  'üstünde.jpg',
#  'görünüşe.jpg',
#  'kırmızı.jpg',
#  'gerçeği.jpg',
#  'içki.jpg',
#  'yürü.jpg',
#  'numara.jpg',
#  'unutma.jpg',
#  'konuşma.jpg',
#  'film.jpg',
#  'sebep.jpg',
#  'defa.jpg',
#  'uyuşturucu.jpg',
#  'bağlı.jpg',
#  'suç.jpg',
#  'suçlu.jpg',
#  'sebebi.jpg',
#  'parçası.jpg',
#  'sıkı.jpg',
#  'pislik.jpg',
#  'herşey.jpg',
#  'herşeyi.jpg',
#  'tercih.jpg',
#  'umurumda.jpg',
#  'patron.jpg',
#  'bahsediyorsun.jpg',
#  'saçma.jpg',
#  'soğuk.jpg',
#  'oda.jpg',
#  'parti.jpg',
#  'sıra.jpg',
#  'sırada.jpg',
#  'kayıp.jpg',
#  'eğlenceli.jpg',
#  'yaşıyor.jpg',
#  'burayı.jpg',
#  'anlat.jpg',
#  'ölmüş.jpg',
#  'çoğu.jpg',
#  'yemeği.jpg',
#  'burda.jpg',
#  'dedektif.jpg',
#  'dürüst.jpg',
#  'anlıyor.jpg',
#  'seviyor.jpg',
#  'dolayı.jpg',
#  'şehir.jpg',
#  'tanıyor.jpg',
#  'sert.jpg',
#  'bulduk.jpg',
#  'teklif.jpg',
#  'anlamı.jpg',
#  'anlamına.jpg',
#  'göster.jpg',
#  'alan.jpg',
#  'orası.jpg',
#  'istemiyor.jpg',
#  'ağır.jpg',
#  'tarafa.jpg',
#  'affedersin.jpg',
#  'görmedim.jpg',
#  'hanımefendi.jpg',
#  'takım.jpg',
#  'kalın.jpg',
#  'kara.jpg',
#  'karanlık.jpg',
#  'edebilir.jpg',
#  'canına.jpg',
#  'sene.jpg',
#  'davet.jpg',
#  'taraftan.jpg',
#  'görmeye.jpg',
#  'anlaşma.jpg',
#  'aşık.jpg',
#  'süper.jpg',
#  'yarım.jpg',
#  'sahibi.jpg',
#  'kapı.jpg',
#  'fikrim.jpg',
#  'duyuyor.jpg',
#  'müzik.jpg',
#  'aferin.jpg',
#  'gurur.jpg',
#  'öğrenmek.jpg',
#  'iç.jpg',
#  'vakti.jpg',
#  'yazık.jpg',
#  'serbest.jpg',
#  'siyah.jpg',
#  'görev.jpg',
#  'hale.jpg',
#  'kavga.jpg',
#  'bölüm.jpg',
#  'sık.jpg',
#  'arka.jpg',
#  'gidecek.jpg',
#  'dava.jpg',
#  'sekiz.jpg',
#  'dua.jpg',
#  'istemedim.jpg',
#  'gider.jpg',
#  'konuş.jpg',
#  'kitap.jpg',
#  'güneş.jpg',
#  'bul.jpg',
#  'edeyim.jpg',
#  'ifade.jpg',
#  'resmi.jpg',
#  'okul.jpg',
#  'mesela.jpg']

# %%
image_file_name = []
for file in file_list:
    # file and extention
    file_without_ext = os.path.splitext(file)[0]
    image_file_name.append(file_without_ext)

# %%
word_set = set(word_list)
image_file_name_set = set(image_file_name)

# %%
word_set.difference(image_file_name_set)
# Out:
# set()

# %%
image_file_name_set.difference(word_set)
# Out:
# set()

# %% [markdown]
# #### Youtube Sentence Analysis

# %%
df_youtube_sentence = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Youtube/Result/{lang_folder.capitalize()}/Sentence Clean Merge/Clean_Youtube_Sentence_Merge_Result.csv")
df_youtube_sentence
# Out:
#            start_time      end_time  \
# 0        00:00:00.294  00:00:03.294
# 1        00:00:03.375  00:00:06.375
# 2        00:00:06.462  00:00:09.462
# 3        00:00:10.267  00:00:11.394
# 4        00:00:11.835  00:00:14.061
# ...               ...           ...
# 3934202  00:10:00.240  00:10:07.818
# 3934203  00:10:07.994  00:10:13.534
# 3934204  00:10:14.745  00:10:17.924
# 3934205  00:10:18.047  00:10:22.398
# 3934206  00:10:22.734  00:10:23.633
#
#                                                   sentence     video_id
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                 sesli betimleme derneğine yaptırılmıştır  fI1BI4d5KFU
# 2                                            wwwsebederorg  fI1BI4d5KFU
# 3                                                     mumu  fI1BI4d5KFU
# 4                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# ...                                                    ...          ...
# 3934202  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3934203  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3934204  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
# 3934205  video hoşunuza gittiyse beğenmeyi ve kanalıma ...  dRssR_apbR0
# 3934206                                         hoşçakalın  dRssR_apbR0
#
# [3934207 rows x 4 columns]

# %%
df_youtube_sentence['start_time'] = pd.to_timedelta(df_youtube_sentence['start_time']) # data type converted timedelta for second 
df_youtube_sentence['end_time'] = pd.to_timedelta(df_youtube_sentence['end_time'])

# %%
df_youtube_sentence['start_time'] = df_youtube_sentence['start_time'].apply(lambda x: x.total_seconds()) # convert seconds
df_youtube_sentence['end_time'] = df_youtube_sentence['end_time'].apply(lambda x: x.total_seconds())
df_youtube_sentence.reset_index(inplace=True)  # adding index column
df_youtube_sentence
# Out:
#            index  start_time  end_time  \
# 0              0       0.294     3.294
# 1              1       3.375     6.375
# 2              2       6.462     9.462
# 3              3      10.267    11.394
# 4              4      11.835    14.061
# ...          ...         ...       ...
# 3934202  3934202     600.240   607.818
# 3934203  3934203     607.994   613.534
# 3934204  3934204     614.745   617.924
# 3934205  3934205     618.047   622.398
# 3934206  3934206     622.734   623.633
#
#                                                   sentence     video_id
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                 sesli betimleme derneğine yaptırılmıştır  fI1BI4d5KFU
# 2                                            wwwsebederorg  fI1BI4d5KFU
# 3                                                     mumu  fI1BI4d5KFU
# 4                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# ...                                                    ...          ...
# 3934202  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3934203  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3934204  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
# 3934205  video hoşunuza gittiyse beğenmeyi ve kanalıma ...  dRssR_apbR0
# 3934206                                         hoşçakalın  dRssR_apbR0
#
# [3934207 rows x 5 columns]

# %%
#df_youtube_sentence[df_youtube_sentence["index"] == 1287503]

# %%
# import os
# from multiprocessing import Process, Manager, Pool, Queue
manager = multiprocessing.Manager()
result_list = manager.list()
word_set = set(word_list)
index_num = list(range(len(df_youtube_sentence)))

def sentence_word_ratio(index_num):
    index = df_youtube_sentence.loc[index_num,"index"]
    start = df_youtube_sentence.loc[index_num,"start_time"]
    end = df_youtube_sentence.loc[index_num,"end_time"]
    sentence = df_youtube_sentence.loc[index_num,"sentence"]
    videoid = df_youtube_sentence.loc[index_num,"video_id"]

    sent_word = re.findall(r"\w+", sentence, re.UNICODE)
    sent_word_set = set(sent_word)
    intersect_word = list(word_set.intersection(sent_word_set))
    different_word = list(sent_word_set.difference(word_set))
    word_ratio = round(((len(intersect_word)/(len(sent_word)+0.001))*100),1)
    different = ", ".join(different_word)
    intersect = ", ".join(intersect_word)

    result_list.append([index,start,end,sentence,videoid,word_ratio,different,intersect])  
    
   
if __name__ == '__main__':
    # with Pool(16) as p:
    with Pool(nprocs-2) as p: # Pool number CPU sayısına eşit olursa tüm CPU lar çalışır
        p.map(sentence_word_ratio, index_num)

# %%
df_sentence_ratio_result = pd.DataFrame(list(result_list), columns=["index","start_time","end_time","sentence","video_id","word_ratio","different_word","intersect_word"])
df_sentence_ratio_result.sort_values(by="index", ascending=True, inplace=True)
df_sentence_ratio_result.reset_index(drop=True, inplace=True)
df_sentence_ratio_result.drop_duplicates(subset="sentence", inplace=True)
df_sentence_ratio_result
# Out:
#            index  start_time  end_time  \
# 0              0       0.294     3.294
# 1              1       3.375     6.375
# 2              2       6.462     9.462
# 3              3      10.267    11.394
# 4              4      11.835    14.061
# ...          ...         ...       ...
# 3934201  3934201     594.755   599.701
# 3934202  3934202     600.240   607.818
# 3934203  3934203     607.994   613.534
# 3934204  3934204     614.745   617.924
# 3934205  3934205     618.047   622.398
#
#                                                   sentence     video_id  \
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                 sesli betimleme derneğine yaptırılmıştır  fI1BI4d5KFU
# 2                                            wwwsebederorg  fI1BI4d5KFU
# 3                                                     mumu  fI1BI4d5KFU
# 4                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# ...                                                    ...          ...
# 3934201  ihtiyaç sahiplerine vermeyi tercih ediyorlar v...  dRssR_apbR0
# 3934202  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3934203  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3934204  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
# 3934205  video hoşunuza gittiyse beğenmeyi ve kanalıma ...  dRssR_apbR0
#
#          word_ratio                                     different_word  \
# 0              28.6                lm, dizinin, betimlemesi, staff, fi
# 1               0.0        derneğine, betimleme, yaptırılmıştır, sesli
# 2               0.0                                      wwwsebederorg
# 3               0.0                                               mumu
# 4              42.9                      safhada, sinir, hat, katsayım
# ...             ...                                                ...
# 3934201        50.0  iyilik, örneğidir, sahiplerine, ediyorlar, ver...
# 3934202        43.7  ülke, videoyu, engebeli, bulunmadığı, dümdüz, ...
# 3934203        30.0  nedenle, ulaşımda, bisikletle, işine, yakını, ...
# 3934204        33.3   söyleyeceklerim, şimdilik, danimarkayla, alakalı
# 3934205        11.1  abone, beğenmeyi, olmayı, unutmayın, kanalıma,...
#
#                                        intersect_word
# 0                                      bu, tarafından
# 1
# 2
# 3
# 4                                         an, bak, şu
# ...                                               ...
# 3934201               güzel, ve, bu, çok, bir, tercih
# 3934202  söylemek, isterim, da, bir, şunu, olduğu, ki
# 3934203                       gidiyor, bu, insanların
# 3934204                                     kadar, bu
# 3934205                                            ve
#
# [3128423 rows x 8 columns]

# %%
df_sentence_ratio_result["different_word"] = df_sentence_ratio_result["different_word"].apply(lambda x: np.nan if x == "" else x)
df_sentence_ratio_result["intersect_word"] = df_sentence_ratio_result["intersect_word"].apply(lambda x: np.nan if x == "" else x)
df_sentence_ratio_result
# Out:
#            index  start_time  end_time  \
# 0              0       0.294     3.294
# 1              1       3.375     6.375
# 2              2       6.462     9.462
# 3              3      10.267    11.394
# 4              4      11.835    14.061
# ...          ...         ...       ...
# 3934201  3934201     594.755   599.701
# 3934202  3934202     600.240   607.818
# 3934203  3934203     607.994   613.534
# 3934204  3934204     614.745   617.924
# 3934205  3934205     618.047   622.398
#
#                                                   sentence     video_id  \
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                 sesli betimleme derneğine yaptırılmıştır  fI1BI4d5KFU
# 2                                            wwwsebederorg  fI1BI4d5KFU
# 3                                                     mumu  fI1BI4d5KFU
# 4                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# ...                                                    ...          ...
# 3934201  ihtiyaç sahiplerine vermeyi tercih ediyorlar v...  dRssR_apbR0
# 3934202  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3934203  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3934204  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
# 3934205  video hoşunuza gittiyse beğenmeyi ve kanalıma ...  dRssR_apbR0
#
#          word_ratio                                     different_word  \
# 0              28.6                lm, dizinin, betimlemesi, staff, fi
# 1               0.0        derneğine, betimleme, yaptırılmıştır, sesli
# 2               0.0                                      wwwsebederorg
# 3               0.0                                               mumu
# 4              42.9                      safhada, sinir, hat, katsayım
# ...             ...                                                ...
# 3934201        50.0  iyilik, örneğidir, sahiplerine, ediyorlar, ver...
# 3934202        43.7  ülke, videoyu, engebeli, bulunmadığı, dümdüz, ...
# 3934203        30.0  nedenle, ulaşımda, bisikletle, işine, yakını, ...
# 3934204        33.3   söyleyeceklerim, şimdilik, danimarkayla, alakalı
# 3934205        11.1  abone, beğenmeyi, olmayı, unutmayın, kanalıma,...
#
#                                        intersect_word
# 0                                      bu, tarafından
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                         an, bak, şu
# ...                                               ...
# 3934201               güzel, ve, bu, çok, bir, tercih
# 3934202  söylemek, isterim, da, bir, şunu, olduğu, ki
# 3934203                       gidiyor, bu, insanların
# 3934204                                     kadar, bu
# 3934205                                            ve
#
# [3128423 rows x 8 columns]

# %%
df_test = df_sentence_ratio_result.sort_values(by="word_ratio", ascending=False)
df_test2 = df_test.head(100)
df_test2
# Out:
#            index  start_time  end_time                          sentence  \
# 3148967  3148967    1554.440  1555.856                canım sen nasılsın
# 2962013  2962013     686.560   688.120               şu çok güzel olduğu
# 1753271  1753271     341.740   343.940        bu da çok zor oluyor zaten
# 1095890  1095890    3364.276  3366.145          tamam oğlum sen bilirsin
# 1753285  1753285      19.300    20.680                    sadece bir gün
# ...          ...         ...       ...                               ...
# 2606314  2606314     235.423   238.979                  bir çok yerde de
# 109685    109685    1795.287  1797.247                      gördün mü ya
# 3652101  3652101     102.282   104.282              geldik bu sefer açık
# 1753775  1753775    2274.580  2275.740       olur mu öyle şey büyük anne
# 1359093  1359093    3781.040  3782.480  şey affedersiniz bir saniye evet
#
#             video_id  word_ratio different_word  \
# 3148967  ncBnb7UmEA0       100.0            NaN
# 2962013  Qhhka9zIUzI       100.0            NaN
# 1753271  sHnvEDmE3so       100.0            NaN
# 1095890  I7Q29rHYldg       100.0            NaN
# 1753285  6epcwvnSNyc       100.0            NaN
# ...              ...         ...            ...
# 2606314  YzWZZb7UdqI       100.0            NaN
# 109685   QtOjRnw10Ig       100.0            NaN
# 3652101  SvhzHz35_hU       100.0            NaN
# 1753775  6epcwvnSNyc       100.0            NaN
# 1359093  hFFskmCQkuM       100.0            NaN
#
#                                intersect_word
# 3148967                  canım, sen, nasılsın
# 2962013                güzel, şu, olduğu, çok
# 1753271       oluyor, da, bu, çok, zor, zaten
# 1095890           oğlum, tamam, sen, bilirsin
# 1753285                      sadece, gün, bir
# ...                                       ...
# 2606314                   de, yerde, çok, bir
# 109685                         ya, gördün, mü
# 3652101               sefer, geldik, açık, bu
# 1753775      olur, mu, büyük, şey, öyle, anne
# 1359093  affedersiniz, saniye, şey, bir, evet
#
# [100 rows x 8 columns]

# %%
df_test
# Out:
#            index  start_time  end_time  \
# 3148967  3148967    1554.440  1555.856
# 2962013  2962013     686.560   688.120
# 1753271  1753271     341.740   343.940
# 1095890  1095890    3364.276  3366.145
# 1753285  1753285      19.300    20.680
# ...          ...         ...       ...
# 791869    791869       8.000    18.000
# 1718492  1718492    5447.021  5449.748
# 791860    791860     458.137   470.449
# 1718493  1718493    5449.972  5453.540
# 3148964  3148964    1547.326  1548.457
#
#                                                   sentence     video_id  \
# 3148967                                 canım sen nasılsın  ncBnb7UmEA0
# 2962013                                şu çok güzel olduğu  Qhhka9zIUzI
# 1753271                         bu da çok zor oluyor zaten  sHnvEDmE3so
# 1095890                           tamam oğlum sen bilirsin  I7Q29rHYldg
# 1753285                                     sadece bir gün  6epcwvnSNyc
# ...                                                    ...          ...
# 791869   patlıcan yetiştiriciliği yapılan serada rekor ...  hM4RaERIiSQ
# 1718492                                      yüzüme gülmez  K_OWP7fPtMw
# 791860                                              günlük  cG1YFLbY1D8
# 1718493                                      zalim aynalar  K_OWP7fPtMw
# 3148964                                         uzanacağım  ncBnb7UmEA0
#
#          word_ratio                                     different_word  \
# 3148967       100.0                                                NaN
# 2962013       100.0                                                NaN
# 1753271       100.0                                                NaN
# 1095890       100.0                                                NaN
# 1753285       100.0                                                NaN
# ...             ...                                                ...
# 791869          0.0  uygulanmıştır, gübre, rekor, yetiştiriciliği, ...
# 1718492         0.0                                     yüzüme, gülmez
# 791860          0.0                                             günlük
# 1718493         0.0                                     zalim, aynalar
# 3148964         0.0                                         uzanacağım
#
#                           intersect_word
# 3148967             canım, sen, nasılsın
# 2962013           güzel, şu, olduğu, çok
# 1753271  oluyor, da, bu, çok, zor, zaten
# 1095890      oğlum, tamam, sen, bilirsin
# 1753285                 sadece, gün, bir
# ...                                  ...
# 791869                               NaN
# 1718492                              NaN
# 791860                               NaN
# 1718493                              NaN
# 3148964                              NaN
#
# [3128423 rows x 8 columns]

# %%
df_test2 = df_test2.sort_values(by="sentence", key=lambda x:x.str.len(), ascending=False)
df_test2
# Out:
#            index  start_time  end_time  \
# 1753257  1753257     272.840   277.660
# 3186685  3186685      76.680    79.760
# 1095879  1095879    3309.594  3311.438
# 2606841  2606841    1963.040  1965.600
# 1359208  1359208    4139.320  4141.360
# ...          ...         ...       ...
# 1753521  1753521    1013.340  1014.460
# 1753353  1753353     397.340   398.600
# 1753354  1753354     399.080   399.780
# 109735    109735    1940.137  1941.208
# 341472    341472    2261.701  2264.518
#
#                                                   sentence     video_id  \
# 1753257  benim burada ne işim var neden bunu yapıyorum ...  sHnvEDmE3so
# 3186685   bana bir şey olmaz ama sen söyle ne düşünüyorsun  HBxB7ytsEus
# 1095879            gerçekten sen niye merak ettin bu kadar  I7Q29rHYldg
# 2606841            ama olması gereken doğru normal olan bu  YzWZZb7UdqI
# 1359208                bu boş çıktı ya ama bunlar var yani  hFFskmCQkuM
# ...                                                    ...          ...
# 1753521                                         dua ediyor  6epcwvnSNyc
# 1753353                                          hem annem  6epcwvnSNyc
# 1753354                                          hem babam  6epcwvnSNyc
# 109735                                            ne bu ya  QtOjRnw10Ig
# 341472                                              ama şu  MuqJeFdzXgE
#
#          word_ratio different_word  \
# 1753257       100.0            NaN
# 3186685       100.0            NaN
# 1095879       100.0            NaN
# 2606841       100.0            NaN
# 1359208       100.0            NaN
# ...             ...            ...
# 1753521       100.0            NaN
# 1753353       100.0            NaN
# 1753354       100.0            NaN
# 109735        100.0            NaN
# 341472        100.0            NaN
#
#                                             intersect_word
# 1753257  nereye, işim, var, ediyor, bunu, artık, kadar,...
# 3186685  sen, şey, ama, bana, olmaz, söyle, bir, ne, dü...
# 1095879      niye, sen, gerçekten, ettin, kadar, bu, merak
# 2606841      gereken, doğru, normal, olması, ama, olan, bu
# 1359208         bunlar, var, ya, ama, boş, bu, çıktı, yani
# ...                                                    ...
# 1753521                                        ediyor, dua
# 1753353                                         annem, hem
# 1753354                                         hem, babam
# 109735                                          ne, bu, ya
# 341472                                             ama, şu
#
# [100 rows x 8 columns]

# %%
df_test.to_excel("test.xlsx", index=False)

# %%
df_adjust_sentence_ratio = df_sentence_ratio_result[(df_sentence_ratio_result["word_ratio"] >= 80) & (df_sentence_ratio_result["word_ratio"] != 100)]
df_adjust_sentence_ratio.reset_index(inplace=True, drop=True)
df_adjust_sentence_ratio
# Out:
#           index  start_time  end_time  \
# 0             8      23.921    25.737
# 1            10      30.479    31.550
# 2            24      75.854    78.412
# 3            25      81.538    84.046
# 4            36     127.661   129.605
# ...         ...         ...       ...
# 187207  3934076     489.120   492.600
# 187208  3934092     550.540   553.680
# 187209  3934101     588.220   590.620
# 187210  3934189     522.947   525.643
# 187211  3934198     581.507   583.733
#
#                                                  sentence     video_id  \
# 0                                doğru mu bu konuşsana ya  fI1BI4d5KFU
# 1                                                      ne  fI1BI4d5KFU
# 2                 bu gerçeği size nasıl söyleyeceğim diye  fI1BI4d5KFU
# 3                     demek o yüzden öyle garip davrandın  fI1BI4d5KFU
# 4                           ama her şeyi o meryem biliyor  fI1BI4d5KFU
# ...                                                   ...          ...
# 187207  olsa da bundan daha büyüğü nerede biliyor musunuz  xX6E5mQ1XP0
# 187208  çok yakında bu konuda da bilgi sahibi olabilec...  xX6E5mQ1XP0
# 187209       ve ben de tıpkı fırlatılışında yaptığım gibi  xX6E5mQ1XP0
# 187210                yani bu insanlar gerçekten mutlular  dRssR_apbR0
# 187211             bu aslında çok anormal bir durum değil  dRssR_apbR0
#
#         word_ratio  different_word  \
# 0             80.0       konuşsana
# 1             99.9             NaN
# 2             83.3    söyleyeceğim
# 3             83.3       davrandın
# 4             83.3          meryem
# ...            ...             ...
# 187207        87.5          büyüğü
# 187208        87.5    olabileceğiz
# 187209        85.7  fırlatılışında
# 187210        80.0        mutlular
# 187211        85.7         anormal
#
#                                           intersect_word
# 0                                      doğru, mu, bu, ya
# 1                                                     ne
# 2                         nasıl, size, bu, gerçeği, diye
# 3                          demek, o, yüzden, öyle, garip
# 4                             o, şeyi, ama, biliyor, her
# ...                                                  ...
# 187207  olsa, daha, nerede, da, biliyor, musunuz, bundan
# 187208       yakında, konuda, da, bilgi, bu, çok, sahibi
# 187209                ben, de, tıpkı, yaptığım, ve, gibi
# 187210                     yani, insanlar, gerçekten, bu
# 187211               değil, durum, aslında, bu, çok, bir
#
# [187212 rows x 8 columns]

# %%
df_adjust_sentence_ratio = df_adjust_sentence_ratio.sort_values(by="sentence", key=lambda x:x.str.len(), ascending=False)
df_adjust_sentence_ratio
# Out:
#           index  start_time  end_time  \
# 178278  3615498     925.955   934.224
# 137180  2610472    1456.000  1462.900
# 179228  3660900     818.880   825.605
# 166128  3143709     680.650   687.900
# 165604  3131138     529.400   538.400
# ...         ...         ...       ...
# 52728   1115812     109.842   112.537
# 82681   1633196    1027.244  1028.174
# 79          911    3186.944  3188.341
# 419        5435    1167.763  1168.579
# 5627     100281    1354.003  1357.080
#
#                                                  sentence     video_id  \
# 178278  ve senden her zaman aynı gülüşü enerjiyi hoş g...  cPoQ27hCNOU
# 137180  eminim hakkında her şey değil ama belli ki önü...  J0hq13epy2k
# 179228  ya aslında seyirci orada benim için tamamen yo...  it2FXAAbs88
# 166128  aslında istediğimiz gibi davranmadığı için ona...  PzC8LWAObVw
# 165604  senin için o benim aşkım diyor böylece onun ge...  vWCPAbFQxzE
# ...                                                   ...          ...
# 52728                                                  an  OUPHieGN4UU
# 82681                                                  iş  AgsOk1HIPag
# 79                                                     ay  fI1BI4d5KFU
# 419                                                    ve  VpRGQkSZgrU
# 5627                                                    o  JrJs2vfea4g
#
#         word_ratio                                   different_word  \
# 178278        80.0  enerjiyi, doğal, bekliyorlar, gülüşü, antrenman
# 137180        82.6   önümüzdeki, çalıştığına, edineceksiniz, yıllar
# 179228        80.9         yapısından, diyebilirim, seyirci, ateşin
# 166128        80.0        kızmak, davranmadığı, istediğimiz, diğeri
# 165604        80.9                              edenin, aşkı, aşkım
# ...            ...                                              ...
# 52728         99.9                                              NaN
# 82681         99.9                                              NaN
# 79            99.9                                              NaN
# 419           99.9                                              NaN
# 5627          99.9                                              NaN
#
#                                            intersect_word
# 178278  senden, o, olarak, bir, hep, güzel, de, zaman,...
# 137180  şey, değil, hakkında, ama, iyi, çok, umarım, b...
# 179228  çünkü, oluyor, tehlikeli, dolayı, yok, durumu,...
# 166128  zorunda, için, şey, değil, herhangi, aslında, ...
# 165604  gerçek, sen, gerçekten, için, o, onun, senin, ...
# ...                                                   ...
# 52728                                                  an
# 82681                                                  iş
# 79                                                     ay
# 419                                                    ve
# 5627                                                    o
#
# [187212 rows x 8 columns]

# %%
df_adjust_sentence_ratio = df_adjust_sentence_ratio.head(100)
df_adjust_sentence_ratio
# Out:
#           index  start_time  end_time  \
# 178278  3615498     925.955   934.224
# 137180  2610472    1456.000  1462.900
# 179228  3660900     818.880   825.605
# 166128  3143709     680.650   687.900
# 165604  3131138     529.400   538.400
# ...         ...         ...       ...
# 84900   1672885     579.340   583.780
# 180269  3698969    2194.540  2208.790
# 171317  3310354     388.090   394.510
# 42374    792229    1027.910  1035.720
# 179459  3670531     977.400   986.760
#
#                                                  sentence     video_id  \
# 178278  ve senden her zaman aynı gülüşü enerjiyi hoş g...  cPoQ27hCNOU
# 137180  eminim hakkında her şey değil ama belli ki önü...  J0hq13epy2k
# 179228  ya aslında seyirci orada benim için tamamen yo...  it2FXAAbs88
# 166128  aslında istediğimiz gibi davranmadığı için ona...  PzC8LWAObVw
# 165604  senin için o benim aşkım diyor böylece onun ge...  vWCPAbFQxzE
# ...                                                   ...          ...
# 84900   hep aynı şeyi tekrar ediyor gibi olabilirim am...  LD8neyexaPw
# 180269  sen tamam geldi sana toplayın her iki tane ama...  BOdC4NwcWHE
# 171317  bunu yaptık ya çıkıp bilmiyordum buraya böyle ...  h_zydUpJF08
# 42374   anladın mı bazı günler bu doğru şeyleri unutab...  rU3lNhDPo2U
# 179459  ben buradan böyle devam edeceğim çünkü karşıda...  dI5dWq903Po
#
#         word_ratio                                   different_word  \
# 178278        80.0  enerjiyi, doğal, bekliyorlar, gülüşü, antrenman
# 137180        82.6   önümüzdeki, çalıştığına, edineceksiniz, yıllar
# 179228        80.9         yapısından, diyebilirim, seyirci, ateşin
# 166128        80.0        kızmak, davranmadığı, istediğimiz, diğeri
# 165604        80.9                              edenin, aşkı, aşkım
# ...            ...                                              ...
# 84900         86.7                               olabilirim, durmak
# 180269        80.9                          toplayın, aramadım, lan
# 171317        86.7                                    yaptık, çıkıp
# 42374         81.2                  unutabilir, etmen, yapamıyorsan
# 179459        80.0                     kokenin, karşıdakine, ulaştı
#
#                                            intersect_word
# 178278  senden, o, olarak, bir, hep, güzel, de, zaman,...
# 137180  şey, değil, hakkında, ama, iyi, çok, umarım, b...
# 179228  çünkü, oluyor, tehlikeli, dolayı, yok, durumu,...
# 166128  zorunda, için, şey, değil, herhangi, aslında, ...
# 165604  gerçek, sen, gerçekten, için, o, onun, senin, ...
# ...                                                   ...
# 84900   ediyor, özellikle, önemli, için, aynı, istiyor...
# 180269  iki, sen, de, yok, için, gerek, tane, ya, ama,...
# 171317  nereden, bilmiyorum, bunu, değil, ya, oldu, bi...
# 42374   doğru, yapacak, bunu, şeyleri, şey, mı, günler...
# 179459  nereye, ben, çünkü, olur, devam, edeceğim, yan...
#
# [100 rows x 8 columns]

# %%
df_word1 = word_count_result(df_adjust_sentence_ratio, ["sentence"])
df_word1
# Out:
#              word  word_count
# 0             bir          63
# 1             çok          35
# 2             şey          32
# 3             ama          28
# 4              bu          27
# ..            ...         ...
# 714      bilmiyor           1
# 715   bilmiyordum           1
# 716  istiyorsunuz           1
# 717    istiyorsan           1
# 718    karışmamış           1
#
# [719 rows x 2 columns]

# %%
df_adjust_sentence_ratio2 = df_sentence_ratio_result[df_sentence_ratio_result["word_ratio"] == 100]
df_adjust_sentence_ratio2.reset_index(inplace=True, drop=True)
df_adjust_sentence_ratio2
# Out:
#           index  start_time  end_time  \
# 0            11      34.571    35.667
# 1            18      62.326    63.644
# 2            21      69.949    71.188
# 3            32     110.626   113.396
# 4            40     142.699   143.881
# ...         ...         ...       ...
# 114626  3933847     196.780   202.160
# 114627  3933950     419.131   421.108
# 114628  3933991     101.080   106.460
# 114629  3934051     382.800   385.020
# 114630  3934113      56.096    57.635
#
#                                           sentence     video_id  word_ratio  \
# 0                                        gerçek bu  fI1BI4d5KFU       100.0
# 1                                       ama olmadı  fI1BI4d5KFU       100.0
# 2                                    biliyorum zor  fI1BI4d5KFU       100.0
# 3                                        ben senin  fI1BI4d5KFU       100.0
# 4                                            bu mu  fI1BI4d5KFU       100.0
# ...                                            ...          ...         ...
# 114626                  bir anda dünyanın en büyük  biOpGkPG_Ho       100.0
# 114627           en azından ben böyle hissediyorum  RkLLlRIaea8       100.0
# 114628                            ve neredeyse tam  xX6E5mQ1XP0       100.0
# 114629  ve o yüzden de böyle siyah beyaz görünüyor  xX6E5mQ1XP0       100.0
# 114630                     ancak güzel haber şu ki  dRssR_apbR0       100.0
#
#        different_word                                     intersect_word
# 0                 NaN                                         gerçek, bu
# 1                 NaN                                        ama, olmadı
# 2                 NaN                                     biliyorum, zor
# 3                 NaN                                         ben, senin
# 4                 NaN                                             mu, bu
# ...               ...                                                ...
# 114626            NaN                     anda, en, büyük, bir, dünyanın
# 114627            NaN              ben, en, böyle, hissediyorum, azından
# 114628            NaN                                 ve, neredeyse, tam
# 114629            NaN  görünüyor, de, siyah, o, ve, böyle, yüzden, beyaz
# 114630            NaN                        güzel, haber, şu, ancak, ki
#
# [114631 rows x 8 columns]

# %%
df_adjust_sentence_ratio2 = df_adjust_sentence_ratio2.sort_values(by="sentence", key=lambda x:x.str.len(), ascending=False)
df_adjust_sentence_ratio2
# Out:
#           index  start_time  end_time  \
# 27909    807123     603.370   611.560
# 59523   1753257     272.840   277.660
# 110841  3679622     939.200   946.170
# 107859  3405153    7920.740  7927.100
# 112334  3747541    1191.790  1203.490
# ...         ...         ...       ...
# 27655    796891     648.240   659.010
# 28702    849753    4625.940  4641.810
# 4190      87160    5352.260  5353.386
# 3294      66561    2940.972  2942.249
# 111183  3699901    4639.490  4649.300
#
#                                                  sentence     video_id  \
# 27909   sıcak mı evet böyle işte tamam bir şey yok ora...  Mh3bgDLKt2o
# 59523   benim burada ne işim var neden bunu yapıyorum ...  sHnvEDmE3so
# 110841  diye gerçekten ilk kez diyorum çok teşekkür ed...  5WWjIgii2IU
# 107859  var da bu bir sorun olur mu benim için ben bun...  zgQbOmPp9pk
# 112334  birkaç gün daha böyle gitsin ben bana belli et...  sSTIfQUm18Q
# ...                                                   ...          ...
# 27655                                                o mı  nIWRjUzeG1A
# 28702                                                da o  EvVkTNm_BJY
# 4190                                                 o ne  eXhF5s8iuh8
# 3294                                                 o ev  s64U8yhvcvw
# 111183                                               ki o  6XgenY_eEro
#
#         word_ratio different_word  \
# 27909        100.0            NaN
# 59523        100.0            NaN
# 110841       100.0            NaN
# 107859       100.0            NaN
# 112334       100.0            NaN
# ...            ...            ...
# 27655        100.0            NaN
# 28702        100.0            NaN
# 4190         100.0            NaN
# 3294         100.0            NaN
# 111183       100.0            NaN
#
#                                            intersect_word
# 27909   şey, bakalım, orada, bir, ne, evet, yok, mı, v...
# 59523   nereye, işim, var, ediyor, bunu, artık, kadar,...
# 110841  kez, olur, gerçekten, diyorum, ediyorum, duydu...
# 107859  üzerine, ben, var, olur, mu, için, bunu, kendi...
# 112334  kötü, gitsin, beni, ben, birkaç, et, daha, bel...
# ...                                                   ...
# 27655                                               mı, o
# 28702                                               da, o
# 4190                                                ne, o
# 3294                                                ev, o
# 111183                                              ki, o
#
# [114631 rows x 8 columns]

# %%
df_adjust_sentence_ratio3 = df_adjust_sentence_ratio2.head(100)
df_adjust_sentence_ratio3
# Out:
#           index  start_time  end_time  \
# 27909    807123     603.370   611.560
# 59523   1753257     272.840   277.660
# 110841  3679622     939.200   946.170
# 107859  3405153    7920.740  7927.100
# 112334  3747541    1191.790  1203.490
# ...         ...         ...       ...
# 64012   1882279    6483.135  6485.240
# 33022   1066242      90.800    95.080
# 109963  3608609     181.040   185.440
# 74644   2195776     576.844   580.139
# 12987    318493     724.260   727.820
#
#                                                  sentence     video_id  \
# 27909   sıcak mı evet böyle işte tamam bir şey yok ora...  Mh3bgDLKt2o
# 59523   benim burada ne işim var neden bunu yapıyorum ...  sHnvEDmE3so
# 110841  diye gerçekten ilk kez diyorum çok teşekkür ed...  5WWjIgii2IU
# 107859  var da bu bir sorun olur mu benim için ben bun...  zgQbOmPp9pk
# 112334  birkaç gün daha böyle gitsin ben bana belli et...  sSTIfQUm18Q
# ...                                                   ...          ...
# 64012   saçma böyle bir şey olamaz ama şimdi siz ilk m...  HhrBZuxjFxM
# 33022   o iş kadar kolay mı oluyor yoksa başına başka ...  v9qRUChLss0
# 109963  yani pek fazla sorun gibi değil aslında benim ...  UGyGF6BzXTM
# 74644   bazen hatta hala insanlar şey diyor yani çok s...  gARgK8NjSDc
# 12987   o yüzden öyle bir şey yok yani gayet güzel dah...  ffR1xltvmbk
#
#         word_ratio different_word  \
# 27909        100.0            NaN
# 59523        100.0            NaN
# 110841       100.0            NaN
# 107859       100.0            NaN
# 112334       100.0            NaN
# ...            ...            ...
# 64012        100.0            NaN
# 33022        100.0            NaN
# 109963       100.0            NaN
# 74644        100.0            NaN
# 12987        100.0            NaN
#
#                                            intersect_word
# 27909   şey, bakalım, orada, bir, ne, evet, yok, mı, v...
# 59523   nereye, işim, var, ediyor, bunu, artık, kadar,...
# 110841  kez, olur, gerçekten, diyorum, ediyorum, duydu...
# 107859  üzerine, ben, var, olur, mu, için, bunu, kendi...
# 112334  kötü, gitsin, beni, ben, birkaç, et, daha, bel...
# ...                                                   ...
# 64012   şey, geldiniz, saçma, böyle, ama, olamaz, mi, ...
# 33022   oluyor, yoksa, başına, o, kolay, kadar, mı, ba...
# 109963  için, fazla, değil, oldu, aslında, sorun, ama,...
# 74644   hatta, şey, görünüyorsun, bazen, diyor, çok, s...
# 12987   güzel, yok, o, şey, daha, bence, yüzden, olmuş...
#
# [100 rows x 8 columns]

# %%
df_adjust_sentence_ratio3.to_excel("test2.xlsx", index=False)

# %%
def word_count_result(df,column_list): # df is dataframe, column_list is list value
    '''
    word_count_bool(df, column_list): df columns word count for word frequency\n
    df is dataframe, column_list is list value\n
    word_count_bool(df, ["word","twogram"]):
    '''
    list_all = []
    for i in df.loc[:,[x for x in column_list]].columns:
        var_list = df[f"{i}"].dropna().tolist()
        for j in var_list:
            list_all.append(j)
    text = " ".join(list_all)
    word_list = re.findall(r"\w+",text, re.UNICODE)
    df_word_list = pd.DataFrame(word_list, columns=["word"])
    #df_word_list.rename(columns={0:"word"}, inplace=True)
    df_word_count = pd.DataFrame(df_word_list.value_counts())
    df_word_count.reset_index(inplace=True)
    df_word_count.rename(columns={0:"word_count"}, inplace=True)
    
    return  df_word_count

# %%
df_word2 = word_count_result(df_adjust_sentence_ratio3, ["sentence"])
df_word2
# Out:
#         word  word_count
# 0        bir          44
# 1        ben          31
# 2        şey          27
# 3        çok          26
# 4        ama          22
# ..       ...         ...
# 433  bakayım           1
# 434       ev           1
# 435   olamaz           1
# 436     olan           1
# 437    şöyle           1
#
# [438 rows x 2 columns]

# %%
set2 = set(df_word2["word"])
set1 = set(df_word1["word"])

# %%
set2.difference(set1)
# Out:
# {'acele',
#  'ait',
#  'akşam',
#  'alabilir',
#  'altında',
#  'alın',
#  'ana',
#  'anlamıyorum',
#  'anlat',
#  'anlıyor',
#  'arkadaşın',
#  'aşık',
#  'baba',
#  'baban',
#  'bak',
#  'bakayım',
#  'başıma',
#  'bekliyor',
#  'benimle',
#  'biz',
#  'bizden',
#  'bizimle',
#  'boş',
#  'buldun',
#  'bulmak',
#  'bunlar',
#  'bölüm',
#  'cevap',
#  'dedin',
#  'deli',
#  'değildi',
#  'değildir',
#  'değiliz',
#  'diyorum',
#  'doktor',
#  'dün',
#  'dünya',
#  'düşündüm',
#  'düşünüyorum',
#  'dışarıda',
#  'ederim',
#  'efendim',
#  'elbette',
#  'etmek',
#  'evde',
#  'fikrim',
#  'gayet',
#  'gelir',
#  'gerekiyordu',
#  'geç',
#  'geçen',
#  'gidecek',
#  'gider',
#  'gidip',
#  'gidiyor',
#  'gidiyorum',
#  'gitmek',
#  'gitmem',
#  'gitsin',
#  'gurur',
#  'gördüm',
#  'görünüyorsun',
#  'görüşürüz',
#  'güneş',
#  'hatırlıyor',
#  'hatırlıyorum',
#  'hayır',
#  'hazır',
#  'hepsi',
#  'herhalde',
#  'herkese',
#  'herkesi',
#  'hızlı',
#  'ihtiyacım',
#  'inanamıyorum',
#  'ise',
#  'istedim',
#  'istediğim',
#  'istediğin',
#  'istemedim',
#  'istemiyorum',
#  'ister',
#  'isterim',
#  'istiyorsun',
#  'işim',
#  'işler',
#  'kahve',
#  'kalmak',
#  'kayıp',
#  'kendim',
#  'kendime',
#  'kesin',
#  'kez',
#  'koca',
#  'kolay',
#  'konuşmak',
#  'lütfen',
#  'memnun',
#  'misiniz',
#  'miyim',
#  'mümkün',
#  'nefret',
#  'neye',
#  'olacağım',
#  'olamaz',
#  'olay',
#  'olduğun',
#  'olmadı',
#  'olmayacak',
#  'olmayan',
#  'olmuş',
#  'olun',
#  'olursa',
#  'onlara',
#  'otur',
#  'oğlum',
#  'parayı',
#  'pardon',
#  'patron',
#  'pek',
#  'rahat',
#  'resmi',
#  'saçma',
#  'sizinle',
#  'sorun',
#  'soğuk',
#  'söyleme',
#  'söylemek',
#  'söz',
#  'sürekli',
#  'sürü',
#  'sıcak',
#  'tam',
#  'tarafından',
#  'tatlı',
#  'teşekkür',
#  'tuhaf',
#  'ufak',
#  'umurumda',
#  'uzak',
#  'vardır',
#  'ver',
#  'verdim',
#  'yanlış',
#  'yanında',
#  'yapabilirim',
#  'yapacaksın',
#  'yapacağım',
#  'yapan',
#  'yapma',
#  'yaptım',
#  'yardım',
#  'yardımcı',
#  'yarım',
#  'yarın',
#  'yazık',
#  'yemin',
#  'yerde',
#  'yere',
#  'yeri',
#  'yerine',
#  'yüzünden',
#  'çalışıyorsun',
#  'üzerine',
#  'üç',
#  'şaka'}

# %%
set1.difference(set2)
# Out:
# {'adamın',
#  'aklındasın',
#  'akıllı',
#  'aldım',
#  'allah',
#  'alıyorum',
#  'alışkanlık',
#  'amacımız',
#  'anda',
#  'anlamak',
#  'anlamamalısın',
#  'anlamasını',
#  'anlatmak',
#  'anlattım',
#  'anlayışsız',
#  'anlaşma',
#  'anneyim',
#  'antrenman',
#  'arabayla',
#  'aramadım',
#  'ararım',
#  'arkada',
#  'arkadaşlarını',
#  'arzusu',
#  'ateşin',
#  'atıyorum',
#  'ay',
#  'az',
#  'azından',
#  'açık',
#  'ağır',
#  'aşk',
#  'aşkı',
#  'aşkım',
#  'bahsediyordur',
#  'bakarız',
#  'bakıyor',
#  'baraj',
#  'basit',
#  'batıda',
#  'bazı',
#  'başarırken',
#  'başladı',
#  'başlangıç',
#  'başlayacağım',
#  'beklenti',
#  'bekliyorlar',
#  'bildiklerimi',
#  'bildiriminiz',
#  'bile',
#  'bilim',
#  'biliyordum',
#  'bilmem',
#  'bilmiyordum',
#  'bilsinler',
#  'birisi',
#  'biriyle',
#  'birçok',
#  'bittin',
#  'buluyorsun',
#  'buna',
#  'bunlarla',
#  'bunun',
#  'buradan',
#  'burayı',
#  'böylece',
#  'büyükşehirde',
#  'bırakamadığınız',
#  'bıraktıracaksın',
#  'bırakın',
#  'cevaplar',
#  'challenge',
#  'ciddi',
#  'cildinizi',
#  'ciğerlerini',
#  'dair',
#  'davranmadığı',
#  'davranması',
#  'dayanabildiniz',
#  'dediğinle',
#  'değer',
#  'değişikliği',
#  'değiştiriyorum',
#  'diyebilirim',
#  'diğeri',
#  'dolayı',
#  'dolduramaz',
#  'dostum',
#  'doğal',
#  'dua',
#  'durduran',
#  'durmak',
#  'durumu',
#  'duyarım',
#  'duygularım',
#  'dönüşler',
#  'dönüşü',
#  'dört',
#  'dörtlük',
#  'dünyanın',
#  'düşünen',
#  'düşünmenizden',
#  'düşünüyor',
#  'dışarıdan',
#  'dışında',
#  'edeceğim',
#  'eden',
#  'edenin',
#  'edineceksiniz',
#  'ee',
#  'egolarım',
#  'elbiseleri',
#  'eminim',
#  'eminliği',
#  'endişe',
#  'enerjiyi',
#  'erkekler',
#  'eskiden',
#  'etme',
#  'etmediğiniz',
#  'etmeleri',
#  'etmen',
#  'etmesine',
#  'etmeye',
#  'etmiyor',
#  'etmiyorum',
#  'ettin',
#  'ettiği',
#  'ettiğiniz',
#  'eşit',
#  'fakat',
#  'fark',
#  'farklı',
#  'farkındalıkları',
#  'futboluyla',
#  'gamsız',
#  'gebe',
#  'gece',
#  'geldin',
#  'gelebiliyorsa',
#  'gelip',
#  'gelirken',
#  'gelmiş',
#  'genç',
#  'gereken',
#  'gerekiyor',
#  'geri',
#  'giren',
#  'girmek',
#  'giydikten',
#  'giymezdim',
#  'gizlice',
#  'gördün',
#  'görebilirsiniz',
#  'göreceksin',
#  'görmek',
#  'görünür',
#  'görüyorum',
#  'görüşlere',
#  'götürüyor',
#  'gülüşü',
#  'günler',
#  'güven',
#  'haberlere',
#  'haberleşeceğiz',
#  'haftada',
#  'hangi',
#  'hapisten',
#  'harikayım',
#  'hatan',
#  'hayal',
#  'hayat',
#  'hayata',
#  'hayatınıza',
#  'hazırlıklar',
#  'herkesin',
#  'heyecanlıyım',
#  'hikayelerimde',
#  'hocaya',
#  'hoş',
#  'i',
#  'idare',
#  'iki',
#  'ilerlemeye',
#  'ilgilendirmiyor',
#  'ilginç',
#  'ilişki',
#  'inandırdığı',
#  'inanılmaz',
#  'inanıyorum',
#  'insan',
#  'insanların',
#  'insanım',
#  'internetten',
#  'istediğimiz',
#  'istediğiniz',
#  'istediğinize',
#  'istemediğini',
#  'istemiyorsunuz',
#  'isteyecek',
#  'istiyor',
#  'istiyorsan',
#  'istiyorsunuz',
#  'itiraf',
#  'iyisi',
#  'izin',
#  'içimden',
#  'içine',
#  'kabul',
#  'kadın',
#  'kahrediyorsun',
#  'kalbi',
#  'kaldırıyor',
#  'kalk',
#  'kalın',
#  'kalınlıkta',
#  'karar',
#  'karışmamış',
#  'karşı',
#  'karşıdakine',
#  'kasıyorsunuz',
#  'kavuşmak',
#  'kaybetmek',
#  'kaybettiğim',
#  'kaygısı',
#  'kayıtlarda',
#  'kazanabileceğimiz',
#  'kemik',
#  'kemiği',
#  'kendine',
#  'kendini',
#  'kerim',
#  'kil',
#  'kimse',
#  'kimsenin',
#  'kimseye',
#  'kişi',
#  'kokenin',
#  'kontrol',
#  'koruyor',
#  'koyacaksın',
#  'koydum',
#  'koydun',
#  'koysak',
#  'kurtarmazdım',
#  'kurtulmanız',
#  'kırıldığımı',
#  'kızmak',
#  'kızım',
#  'lan',
#  'makyajımı',
#  'mesafe',
#  'mesaj',
#  'mudur',
#  'mustafabir',
#  'musunuz',
#  'mü',
#  'müzik',
#  'namaza',
#  'nanılmaz',
#  'neler',
#  'neredeyse',
#  'neşeli',
#  'niye',
#  'odalarına',
#  'ol',
#  'olabilirim',
#  'olasılığı',
#  'oldukları',
#  'olduğum',
#  'olduğumu',
#  'olduğunda',
#  'olma',
#  'olmadığım',
#  'olmaları',
#  'olmalı',
#  'olmasın',
#  'olmasını',
#  'olmaya',
#  'olmayabilir',
#  'olmayacağız',
#  'olmayanlar',
#  'olsa',
#  'olup',
#  'onlar',
#  'onlarla',
#  'onların',
#  'oradan',
#  'oraya',
#  'ortaya',
#  'oturuyor',
#  'pahalı',
#  'papa',
#  'papaya',
#  'para',
#  'paylaşılıyor',
#  'pislik',
#  'pişmanlıkları',
#  'polis',
#  'pozisyonunda',
#  'rahatsızlık',
#  'sabah',
#  'sahip',
#  'saklayarak',
#  'sanmıyorum',
#  'sanırım',
#  'sarımsak',
#  'saygısı',
#  'saykodelik',
#  'sağ',
#  'sefer',
#  'sert',
#  'sevdirdim',
#  'sevdiğime',
#  'seversem',
#  'seveyim',
#  'seviyede',
#  'seviyorsun',
#  'seyirci',
#  'silin',
#  'sizi',
#  'sizin',
#  'son',
#  'sonu',
#  'sorabilirsin',
#  'soracağım',
#  'sorumluluk',
#  'soruyorlar',
#  'sosyallik',
#  'su',
#  'suriyeye',
#  'söyledin',
#  'söylemediğim',
#  'söylerken',
#  'söyleyebilirim',
#  'süre',
#  'süreceğim',
#  'sıra',
#  'tahmin',
#  'takibi',
#  'takip',
#  'takım',
#  'tamamen',
#  'tanıyorum',
#  'taraftanda',
#  'tarafını',
#  'tarihin',
#  'tarsustan',
#  'tarz',
#  'tarzında',
#  'tek',
#  'tekrar',
#  'tercih',
#  'terk',
#  'toplayın',
#  'trafikte',
#  'tüm',
#  'ucundan',
#  'ulaştı',
#  'umarım',
#  'umuyorum',
#  'unutabilir',
#  'uygulamayı',
#  'uzaklaştın',
#  'uzun',
#  'varsa',
#  'varım',
#  'vazoyu',
#  'verdi',
#  'verin',
#  'veririm',
#  'verirsen',
#  'veriyor',
#  'vermese',
#  'vermeyeceksin',
#  'veya',
#  'videoda',
#  'vurulduğunu',
#  'yalnız',
#  'yanına',
#  'yapabilirsiniz',
#  'yapacak',
#  'yapamıyorsan',
#  'yaparsa',
#  'yaparım',
#  'yapmalıyız',
#  'yapmazsınız',
#  'yapmıyor',
#  'yaprağı',
#  'yaptı',
#  'yaptık',
#  'yaptıklarımı',
#  'yaptın',
#  'yaptığım',
#  'yapılıyor',
#  'yapısından',
#  'yapıyorsunuz',
#  'yardımcısının',
#  'yazarlar',
#  'yaşam',
#  'yaşamak',
#  'yaşaması',
#  'yaşamış',
#  'yaşasaydım',
#  'yaşta',
#  'yaşıyor',
#  'yaşıyorum',
#  'yemiyorum',
#  'yeni',
#  'yeniden',
#  'yeterince',
#  'yolumuz',
#  'yumuşak',
#  'yıllar',
#  'zamana',
#  'zamanı',
#  'zorunda',
#  'çaldırın',
#  'çaldığını',
#  'çalıştığım',
#  'çalıştığına',
#  'çalıştığını',
#  'çağlarında',
#  'çiçekleri',
#  'çocuk',
#  'çocuklar',
#  'çoğu',
#  'çıkıp',
#  'ölmüş',
#  'önce',
#  'önemli',
#  'önümüzdeki',
#  'özgürlük',
#  'öğrenciyseniz',
#  'ülkemizde',
#  'ümitsiz',
#  'üniversiteler',
#  'üstünde',
#  'üzücü',
#  'üzüleceğimi',
#  'ın',
#  'şarkı',
#  'şekillerde',
#  'şeye',
#  'şeyin',
#  'şeyleri',
#  'şurası'}

# %%
set1.union(set2)
# Out:
# {'acaba',
#  'acele',
#  'adamın',
#  'ait',
#  'aklındasın',
#  'akıllı',
#  'akşam',
#  'alabilir',
#  'aldım',
#  'allah',
#  'almak',
#  'altında',
#  'alın',
#  'alıp',
#  'alıyorum',
#  'alışkanlık',
#  'ama',
#  'amacımız',
#  'an',
#  'ana',
#  'anda',
#  'anladım',
#  'anladın',
#  'anlamak',
#  'anlamamalısın',
#  'anlamasını',
#  'anlamına',
#  'anlamıyorum',
#  'anlat',
#  'anlatmak',
#  'anlattım',
#  'anlayışsız',
#  'anlaşma',
#  'anlıyor',
#  'anneyim',
#  'antrenman',
#  'arabayla',
#  'arada',
#  'aramadım',
#  'ararım',
#  'arkada',
#  'arkadaş',
#  'arkadaşlarını',
#  'arkadaşım',
#  'arkadaşın',
#  'artık',
#  'arzusu',
#  'asla',
#  'aslında',
#  'ateşin',
#  'atıyorum',
#  'ay',
#  'aynı',
#  'ayrıca',
#  'az',
#  'azından',
#  'açık',
#  'ağır',
#  'aşk',
#  'aşkı',
#  'aşkım',
#  'aşık',
#  'baba',
#  'baban',
#  'bahsediyordur',
#  'bak',
#  'bakalım',
#  'bakarız',
#  'bakayım',
#  'bakın',
#  'bakıyor',
#  'bana',
#  'baraj',
#  'basit',
#  'batıda',
#  'bazen',
#  'bazı',
#  'bağlı',
#  'başarırken',
#  'başka',
#  'başladı',
#  'başlangıç',
#  'başlayacağım',
#  'başıma',
#  'başına',
#  'beklenti',
#  'bekliyor',
#  'bekliyorlar',
#  'belki',
#  'belli',
#  'ben',
#  'bence',
#  'bende',
#  'benden',
#  'beni',
#  'benim',
#  'benimle',
#  'beraber',
#  'bildiklerimi',
#  'bildiriminiz',
#  'bile',
#  'bilgi',
#  'bilim',
#  'biliyor',
#  'biliyordum',
#  'biliyorsun',
#  'biliyorum',
#  'bilmek',
#  'bilmem',
#  'bilmiyor',
#  'bilmiyordum',
#  'bilmiyorum',
#  'bilsinler',
#  'bir',
#  'biraz',
#  'biri',
#  'birinin',
#  'birisi',
#  'biriyle',
#  'birkaç',
#  'birlikte',
#  'birçok',
#  'bittin',
#  'biz',
#  'bizden',
#  'bize',
#  'bizim',
#  'bizimle',
#  'boş',
#  'bu',
#  'bugün',
#  'buldun',
#  'bulmak',
#  'buluyorsun',
#  'buna',
#  'bundan',
#  'bunlar',
#  'bunlarla',
#  'bunları',
#  'bunların',
#  'bunu',
#  'bunun',
#  'bununla',
#  'burada',
#  'buradaki',
#  'buradan',
#  'burası',
#  'buraya',
#  'burayı',
#  'bölüm',
#  'böyle',
#  'böylece',
#  'bütün',
#  'büyük',
#  'büyükşehirde',
#  'bırakamadığınız',
#  'bıraktıracaksın',
#  'bırakın',
#  'canım',
#  'cevap',
#  'cevaplar',
#  'challenge',
#  'ciddi',
#  'cildinizi',
#  'ciğerlerini',
#  'da',
#  'daha',
#  'dair',
#  'davranmadığı',
#  'davranması',
#  'dayanabildiniz',
#  'de',
#  'dedi',
#  'dedim',
#  'dedin',
#  'dediğinle',
#  'defa',
#  'deli',
#  'demek',
#  'devam',
#  'değer',
#  'değil',
#  'değildi',
#  'değildir',
#  'değilim',
#  'değiliz',
#  'değişikliği',
#  'değiştiriyorum',
#  'diye',
#  'diyebilirim',
#  'diyor',
#  'diyorsun',
#  'diyorum',
#  'diğeri',
#  'doktor',
#  'dolayı',
#  'dolduramaz',
#  'dostum',
#  'doğal',
#  'doğru',
#  'dua',
#  'dur',
#  'durduran',
#  'durmak',
#  'durum',
#  'durumu',
#  'duyarım',
#  'duydum',
#  'duygularım',
#  'dönüşler',
#  'dönüşü',
#  'dört',
#  'dörtlük',
#  'dün',
#  'dünya',
#  'dünyanın',
#  'düşündüm',
#  'düşünen',
#  'düşünmenizden',
#  'düşünüyor',
#  'düşünüyorsun',
#  'düşünüyorum',
#  'dışarıda',
#  'dışarıdan',
#  'dışında',
#  'edecek',
#  'edeceğim',
#  'eden',
#  'edenin',
#  'ederim',
#  'edineceksiniz',
#  'ediyor',
#  'ediyorsun',
#  'ediyorum',
#  'ee',
#  'efendim',
#  'egolarım',
#  'elbette',
#  'elbiseleri',
#  'emin',
#  'eminim',
#  'eminliği',
#  'en',
#  'endişe',
#  'enerjiyi',
#  'erkekler',
#  'eskiden',
#  'et',
#  'etme',
#  'etmediğiniz',
#  'etmek',
#  'etmeleri',
#  'etmen',
#  'etmesine',
#  'etmeye',
#  'etmiyor',
#  'etmiyorum',
#  'ettim',
#  'ettin',
#  'ettiği',
#  'ettiğiniz',
#  'ev',
#  'evde',
#  'evet',
#  'eğer',
#  'eşit',
#  'fakat',
#  'falan',
#  'fark',
#  'farklı',
#  'farkındalıkları',
#  'fazla',
#  'fikir',
#  'fikrim',
#  'futboluyla',
#  'gamsız',
#  'gayet',
#  'gebe',
#  'gece',
#  'gel',
#  'geldi',
#  'geldim',
#  'geldin',
#  'geldiniz',
#  'gelebiliyorsa',
#  'gelecek',
#  'gelip',
#  'gelir',
#  'gelirken',
#  'geliyor',
#  'geliyorum',
#  'gelmiş',
#  'genç',
#  'gerek',
#  'gereken',
#  'gerekiyor',
#  'gerekiyordu',
#  'gerektiğini',
#  'geri',
#  'gerçek',
#  'gerçekten',
#  'geç',
#  'geçen',
#  'gibi',
#  'gidecek',
#  'gider',
#  'gidip',
#  'gidiyor',
#  'gidiyorum',
#  'giren',
#  'girmek',
#  'gitmek',
#  'gitmem',
#  'gitsin',
#  'gitti',
#  'giydikten',
#  'giymezdim',
#  'gizlice',
#  'gurur',
#  'gördüm',
#  'gördün',
#  'göre',
#  'görebilirsiniz',
#  'göreceksin',
#  'görmek',
#  'görünür',
#  'görünüyorsun',
#  'görüyorum',
#  'görüşlere',
#  'görüşürüz',
#  'götürüyor',
#  'gülüşü',
#  'gün',
#  'güneş',
#  'günler',
#  'güven',
#  'güzel',
#  'haber',
#  'haberlere',
#  'haberleşeceğiz',
#  'hadi',
#  'haftada',
#  'hak',
#  'hakkında',
#  'haklısın',
#  'hala',
#  'hangi',
#  'hapisten',
#  'hareket',
#  'harikayım',
#  'hatan',
#  'hatta',
#  'hatırlıyor',
#  'hatırlıyorum',
#  'hayal',
#  'hayat',
#  'hayata',
#  'hayatta',
#  'hayatım',
#  'hayatınıza',
#  'hayır',
#  'hazır',
#  'hazırlıklar',
#  'hemen',
#  'hep',
#  'hepsi',
#  'her',
#  'herhalde',
#  'herhangi',
#  'herkes',
#  'herkese',
#  'herkesi',
#  'herkesin',
#  'heyecanlıyım',
#  'hikayelerimde',
#  'hissediyorum',
#  'hiç',
#  'hiçbir',
#  'hocaya',
#  'hoş',
#  'hoşuma',
#  'hızlı',
#  'i',
#  'idare',
#  'ihtiyacım',
#  'ihtiyacın',
#  'iki',
#  'ilerlemeye',
#  'ilgilendirmiyor',
#  'ilgili',
#  'ilginç',
#  'ilişki',
#  'ilk',
#  'inanamıyorum',
#  'inandırdığı',
#  'inanılmaz',
#  'inanıyorum',
#  'insan',
#  'insanlar',
#  'insanların',
#  'insanım',
#  'internetten',
#  'ise',
#  'istedim',
#  'istediğim',
#  'istediğimiz',
#  'istediğin',
#  'istediğiniz',
#  'istediğinize',
#  'istemedim',
#  'istemediğini',
#  'istemiyorsunuz',
#  'istemiyorum',
#  'ister',
#  'isterim',
#  'isteyecek',
#  'istiyor',
#  'istiyorsan',
#  'istiyorsun',
#  'istiyorsunuz',
#  'istiyorum',
#  'itiraf',
#  'iyi',
#  'iyisi',
#  'izin',
#  'içimden',
#  'için',
#  'içinde',
#  'içine',
#  'iş',
#  'işe',
#  'işim',
#  'işler',
#  'işte',
#  'kabul',
#  'kadar',
#  'kadın',
#  'kahrediyorsun',
#  'kahve',
#  'kalbi',
#  'kaldırıyor',
#  'kalk',
#  'kalmak',
#  'kalın',
#  'kalınlıkta',
#  'karar',
#  'kardeşim',
#  'karışmamış',
#  'karşı',
#  'karşıdakine',
#  'kasıyorsunuz',
#  'kavuşmak',
#  'kaybetmek',
#  'kaybettiğim',
#  'kaygısı',
#  'kayıp',
#  'kayıtlarda',
#  'kazanabileceğimiz',
#  'kaç',
#  'kemik',
#  'kemiği',
#  'kendi',
#  'kendim',
#  'kendime',
#  'kendimi',
#  'kendine',
#  'kendini',
#  'kere',
#  'kerim',
#  'kesin',
#  'kesinlikle',
#  'kez',
#  'ki',
#  'kil',
#  'kimin',
#  'kimse',
#  'kimsenin',
#  'kimseye',
#  'kişi',
#  'koca',
#  'kokenin',
#  'kolay',
#  'kontrol',
#  'konu',
#  'konuda',
#  'konusunda',
#  'konuşmak',
#  'koruyor',
#  'koyacaksın',
#  'koydum',
#  'koydun',
#  'koysak',
#  'kurtarmazdım',
#  'kurtulmanız',
#  'kötü',
#  'küçük',
#  'kırıldığımı',
#  'kız',
#  'kızmak',
#  'kızım',
#  'lan',
#  'lazım',
#  'lütfen',
#  'makyajımı',
#  'memnun',
#  'merak',
#  'mesafe',
#  'mesaj',
#  'mesela',
#  'mi',
#  'misin',
#  'misiniz',
#  'miyim',
#  'mu',
#  'mudur',
#  'mustafabir',
#  'musun',
#  'musunuz',
#  'mutlu',
#  'mü',
#  'mümkün',
#  'müzik',
#  'mı',
#  'namaza',
#  'nanılmaz',
#  'nasıl',
#  'ne',
#  'neden',
#  'nefret',
#  'neler',
#  'nereden',
#  'neredeyse',
#  'nereye',
#  'neye',
#  'neyse',
#  'neşeli',
#  'niye',
#  'o',
#  'odalarına',
#  'ol',
#  'olabilir',
#  'olabilirim',
#  'olacak',
#  'olacağım',
#  'olamaz',
#  'olan',
#  'olarak',
#  'olasılığı',
#  'olay',
#  'olayı',
#  'oldu',
#  'oldukları',
#  'olduğu',
#  'olduğum',
#  'olduğumu',
#  'olduğun',
#  'olduğuna',
#  'olduğunda',
#  'olduğunu',
#  'olma',
#  'olmadı',
#  'olmadığım',
#  'olmadığını',
#  'olmak',
#  'olmaları',
#  'olmalı',
#  'olması',
#  'olmasın',
#  'olmasını',
#  'olmaya',
#  'olmayabilir',
#  'olmayacak',
#  'olmayacağız',
#  'olmayan',
#  'olmayanlar',
#  'olmaz',
#  'olmuş',
#  'olsa',
#  'olsun',
#  'olun',
#  'olup',
#  'olur',
#  'olurdu',
#  'olursa',
#  'oluyor',
#  'ona',
#  'ondan',
#  'onlar',
#  'onlara',
#  'onlardan',
#  'onlarla',
#  'onları',
#  'onların',
#  'onu',
#  'onun',
#  'onunla',
#  'orada',
#  'oradan',
#  'oraya',
#  'ortaya',
#  'otur',
#  'oturuyor',
#  'oğlum',
#  'pahalı',
#  'papa',
#  'papaya',
#  'para',
#  'parayı',
#  'pardon',
#  'patron',
#  'paylaşılıyor',
#  'pek',
#  'peki',
#  'pislik',
#  'pişmanlıkları',
#  'polis',
#  'pozisyonunda',
#  'rahat',
#  'rahatsız',
#  'rahatsızlık',
#  'resmi',
#  'sabah',
#  'sadece',
#  'sahibi',
#  'sahip',
#  'sakin',
#  'saklayarak',
#  'sana',
#  'sanki',
#  'sanmıyorum',
#  'sanırım',
#  'sarımsak',
#  'saygısı',
#  'saykodelik',
#  'saçma',
#  'sağ',
#  'sefer',
#  'sen',
#  'senden',
#  'seni',
#  'senin',
#  'seninle',
#  'sert',
#  'sevdirdim',
#  'sevdiğime',
#  'seversem',
#  'seveyim',
#  'seviyede',
#  'seviyorsun',
#  'seviyorum',
#  'seyirci',
#  'silin',
#  'siz',
#  'size',
#  'sizi',
#  'sizin',
#  'sizinle',
#  'son',
#  'sonra',
#  'sonu',
#  'sorabilirsin',
#  'soracağım',
#  'soru',
#  'sorumluluk',
#  'sorun',
#  'soruyorlar',
#  'sosyallik',
#  'soğuk',
#  'su',
#  'suriyeye',
#  'söyledi',
#  'söyledim',
#  'söyledin',
#  'söyleme',
#  'söylemediğim',
#  'söylemek',
#  'söylerken',
#  'söyleyebilirim',
#  'söyleyeyim',
#  'söylüyor',
#  'söylüyorsun',
#  'söylüyorum',
#  'söz',
#  'süre',
#  'süreceğim',
#  'sürekli',
#  'sürü',
#  'sıcak',
#  'sıra',
#  'tabi',
#  'tabii',
#  'tahmin',
#  'takibi',
#  'takip',
#  'takım',
#  'tam',
#  'tamam',
#  'tamamen',
#  'tane',
#  'tanıyorum',
#  'tarafa',
#  'taraftanda',
#  'tarafından',
#  'tarafını',
#  'tarihin',
#  'tarsustan',
#  'tarz',
#  'tarzında',
#  'tatlı',
#  'tehlikeli',
#  'tek',
#  'tekrar',
#  'tercih',
#  'terk',
#  'teslim',
#  'teşekkür',
#  'toplayın',
#  'trafikte',
#  'tuhaf',
#  'tüm',
#  'ucundan',
#  'ufak',
#  'ulaştı',
#  'umarım',
#  'umurumda',
#  'umuyorum',
#  'unutabilir',
#  'uygulamayı',
#  'uzak',
#  'uzaklaştın',
#  'uzun',
#  'var',
#  'vardır',
#  'varmış',
#  'varsa',
#  'varım',
#  'vazoyu',
#  've',
#  'ver',
#  'verdi',
#  'verdim',
#  'verin',
#  'veririm',
#  'verirsen',
#  'veriyor',
#  'veriyorum',
#  'vermek',
#  'vermese',
#  'vermeyeceksin',
#  'veya',
#  'videoda',
#  'vurulduğunu',
#  'ya',
#  'yakın',
#  'yalan',
#  'yalnız',
#  'yani',
#  'yanlış',
#  'yanına',
#  'yanında',
#  'yapabilirim',
#  'yapabilirsiniz',
#  'yapacak',
#  'yapacaksın',
#  'yapacağım',
#  'yapacağız',
#  'yapalım',
#  'yapamıyorsan',
#  'yapan',
#  'yaparsa',
#  'yaparım',
#  'yapma',
#  'yapmak',
#  'yapmalıyız',
#  'yapmam',
#  'yapmaya',
#  'yapmazsınız',
#  'yapmıyor',
#  'yaprağı',
#  'yaptı',
#  'yaptık',
#  'yaptıklarımı',
#  'yaptım',
#  'yaptın',
#  'yaptığım',
#  'yaptığın',
#  'yapılıyor',
#  'yapısından',
#  'yapıyor',
#  'yapıyorsunuz',
#  'yapıyorum',
#  'yardım',
#  'yardımcı',
#  'yardımcısının',
#  'yarım',
#  'yarın',
#  'yazarlar',
#  'yazık',
#  'yaşam',
#  'yaşamak',
#  'yaşaması',
#  'yaşamış',
#  'yaşasaydım',
#  'yaşta',
#  'yaşıyor',
#  'yaşıyorum',
#  'yemin',
#  'yemiyorum',
#  'yeni',
#  'yeniden',
#  'yerde',
#  'yere',
#  'yeri',
#  'yerine',
#  'yerini',
#  'yeter',
#  'yeterince',
#  'yine',
#  'yok',
#  'yoksa',
#  'yol',
#  'yolumuz',
#  'yumuşak',
#  'yüzden',
#  'yüzünden',
#  'yıllar',
#  'zaman',
#  'zamana',
#  'zamanda',
#  'zamanı',
#  'zarar',
#  'zaten',
#  'zor',
#  'zorunda',
#  'çaldırın',
#  'çaldığını',
#  'çalıştığım',
#  'çalıştığına',
#  'çalıştığını',
#  'çalışıyor',
#  'çalışıyorsun',
#  'çalışıyorum',
#  'çağlarında',
#  'çiçekleri',
#  'çocuk',
#  'çocuklar',
#  'çok',
#  'çoğu',
#  'çünkü',
#  'çıkar',
#  'çıktı',
#  'çıkıp',
#  'ölmüş',
#  'önce',
#  'önemli',
#  'önümüzdeki',
#  'öyle',
#  'özellikle',
#  'özgürlük',
#  'öğrenciyseniz',
#  'öğrenmek',
#  'ülkemizde',
#  'ümitsiz',
#  'üniversiteler',
#  'üstünde',
#  'üzerine',
#  'üzücü',
#  'üzüleceğimi',
#  'üç',
#  'ın',
#  'şaka',
#  'şarkı',
#  'şekilde',
#  'şekillerde',
#  'şey',
#  'şeye',
#  'şeyi',
#  'şeyin',
#  'şeyler',
#  'şeyleri',
#  'şimdi',
#  'şu',
#  'şunu',
#  'şurası',
#  'şöyle'}

# %%
df_adjust_sentence_ratio = df_sentence_ratio_result[df_sentence_ratio_result["word_ratio"] >= adjust_sent_word_ratio]
df_adjust_sentence_ratio.reset_index(inplace=True, drop=True)
df_adjust_sentence_ratio
# Out:
#            index  start_time  end_time  \
# 0              0       0.294     3.294
# 1              4      11.835    14.061
# 2              5      14.213    17.219
# 3              6      18.687    19.854
# 4              7      19.967    22.805
# ...          ...         ...       ...
# 2675734  3934200     590.325   594.700
# 2675735  3934201     594.755   599.701
# 2675736  3934202     600.240   607.818
# 2675737  3934203     607.994   613.534
# 2675738  3934204     614.745   617.924
#
#                                                   sentence     video_id  \
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# 2                 kelimelerini lütfen seçerek konuş lütfen  fI1BI4d5KFU
# 3                                       otursana bir tanem  fI1BI4d5KFU
# 4               hah oturtmaya çalıştığına göre demek doğru  fI1BI4d5KFU
# ...                                                    ...          ...
# 2675734  zira bizim insanlarımız işine yaramayan ikinci...  dRssR_apbR0
# 2675735  ihtiyaç sahiplerine vermeyi tercih ediyorlar v...  dRssR_apbR0
# 2675736  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 2675737  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 2675738  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
#
#          word_ratio                                     different_word  \
# 0              28.6                betimlemesi, staff, fi, lm, dizinin
# 1              42.9                      safhada, katsayım, hat, sinir
# 2              40.0                              kelimelerini, seçerek
# 3              33.3                                    otursana, tanem
# 4              50.0                        oturtmaya, çalıştığına, hah
# ...             ...                                                ...
# 2675734        40.0  işine, satmak, kıyafetleri, insanlarımız, yara...
# 2675735        50.0  ediyorlar, sahiplerine, örneğidir, iyilik, ver...
# 2675736        43.7  bulunmadığı, ülke, arazilerin, yolların, bitir...
# 2675737        30.0  yakını, işine, yarısına, okuluna, bisikletle, ...
# 2675738        33.3   söyleyeceklerim, alakalı, şimdilik, danimarkayla
#
#                                        intersect_word
# 0                                      tarafından, bu
# 1                                         an, bak, şu
# 2                                       lütfen, konuş
# 3                                                 bir
# 4                                  göre, demek, doğru
# ...                                               ...
# 2675734                     ikinci, bizim, yerine, el
# 2675735               ve, güzel, bu, bir, tercih, çok
# 2675736  olduğu, da, isterim, bir, ki, söylemek, şunu
# 2675737                       gidiyor, insanların, bu
# 2675738                                     kadar, bu
#
# [2675739 rows x 8 columns]

# %%
df_adjust_sentence_ratio.loc[:,"search_string"] = df_adjust_sentence_ratio.loc[:,"sentence"].map(lambda x: exract_word_group(x, word_list))
df_adjust_sentence_ratio = df_adjust_sentence_ratio[~(df_adjust_sentence_ratio["search_string"]==f"sentencte_word_count_less_than_{sentence_word_count_number}")]
#df_adjust_sentence_ratio.reset_index(drop=True, inplace=True)
df_adjust_sentence_ratio.drop_duplicates(subset="search_string", inplace=True)
df_adjust_sentence_ratio
# Out:
# <ipython-input-33-d976c66f1733>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adjust_sentence_ratio.loc[:,"search_string"] = df_adjust_sentence_ratio.loc[:,"sentence"].map(lambda x: exract_word_group(x, word_list))
# <ipython-input-33-d976c66f1733>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adjust_sentence_ratio.drop_duplicates(subset="search_string", inplace=True)
#            index  start_time  end_time  \
# 20            25      81.538    84.046
# 32            38     135.778   139.810
# 37            43     147.019   149.009
# 60            79     302.034   303.874
# 71            93     336.721   339.860
# ...          ...         ...       ...
# 2675684  3934138     187.205   192.549
# 2675731  3934197     578.076   581.389
# 2675733  3934199     583.933   590.183
# 2675735  3934201     594.755   599.701
# 2675736  3934202     600.240   607.818
#
#                                                   sentence     video_id  \
# 20                     demek o yüzden öyle garip davrandın  fI1BI4d5KFU
# 32       o deli kadın herkesin içinde beni rezil etti h...  fI1BI4d5KFU
# 37                 ama yapma böyle git dedim git karşımdan  fI1BI4d5KFU
# 60                               bana o kadar iyi geldi ki  fI1BI4d5KFU
# 71               allahım ben tamamen inanamıyorum şu an ya  fI1BI4d5KFU
# ...                                                    ...          ...
# 2675684  hatta köyleri o kadar sakin ki dışarıda insan ...  dRssR_apbR0
# 2675731  yani orada ciddi ciddi ikinci el kıyafet sektö...  dRssR_apbR0
# 2675733  fakat ülkemizde ikinci el kıyafet dükkanı görd...  dRssR_apbR0
# 2675735  ihtiyaç sahiplerine vermeyi tercih ediyorlar v...  dRssR_apbR0
# 2675736  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
#
#          word_ratio                                     different_word  \
# 20             83.3                                          davrandın
# 32             70.0                                              rezil
# 37             71.4                                          karşımdan
# 60            100.0                                                NaN
# 71             85.7                                            allahım
# ...             ...                                                ...
# 2675684        66.7            köyleri, görünce, geliyorsunuz, sevinir
# 2675731        66.7                                   sektörü, kıyafet
# 2675733        60.0  hatırlamıyorum, yapmıyordur, ülkemizde, kıyafe...
# 2675735        50.0  ediyorlar, sahiplerine, örneğidir, iyilik, ver...
# 2675736        43.7  bulunmadığı, ülke, arazilerin, yolların, bitir...
#
#                                             intersect_word  \
# 20                           demek, o, garip, yüzden, öyle
# 32            içinde, herkesin, o, kadın, deli, beni, etti
# 37                           git, ama, dedim, yapma, böyle
# 60                          o, bana, iyi, ki, kadar, geldi
# 71                  şu, tamamen, an, ben, ya, inanamıyorum
# ...                                                    ...
# 2675684  o, hatta, insan, ki, kadar, sakin, dışarıda, hale
# 2675731                var, orada, ciddi, yani, el, ikinci
# 2675733  iş, da, eğer, ikinci, bence, çok, el, fakat, v...
# 2675735                    ve, güzel, bu, bir, tercih, çok
# 2675736       olduğu, da, isterim, bir, ki, söylemek, şunu
#
#                              search_string
# 20               demek o yüzden öyle garip
# 32       o deli kadın herkesin içinde beni
# 37           ama yapma böyle git dedim git
# 60               bana o kadar iyi geldi ki
# 71       ben tamamen inanamıyorum şu an ya
# ...                                    ...
# 2675684    o kadar sakin ki dışarıda insan
# 2675731   yani orada ciddi ciddi ikinci el
# 2675733         eğer varsa da bence çok iş
# 2675735                ve bu çok güzel bir
# 2675736        şunu da söylemek isterim ki
#
# [248030 rows x 9 columns]

# %%
df_word_group_time_loc_in_sent_result = word_group_time_loc(df_adjust_sentence_ratio, "search_string", "start_time", "end_time", "sentence", "video_id")
df_word_group_time_loc_in_sent_result
# Out:
#                             search_string  start_time    end_time  \
# 0               demek o yüzden öyle garip   81.538000   83.401086
# 1       o deli kadın herkesin içinde beni  135.778000  138.062800
# 2           ama yapma böyle git dedim git  147.019000  148.549769
# 3               bana o kadar iyi geldi ki  302.034000  303.874000
# 4       ben tamamen inanamıyorum şu an ya  337.256927  339.860000
# ...                                   ...         ...         ...
# 248025    o kadar sakin ki dışarıda insan  188.084392  190.316696
# 248026   yani orada ciddi ciddi ikinci el  578.076000  580.178481
# 248027         eğer varsa da bence çok iş  587.861571  589.528238
# 248028                ve bu çok güzel bir  597.441716  598.724012
# 248029        şunu da söylemek isterim ki  601.376700  603.208050
#
#                                                  sentence     video_id
# 0                     demek o yüzden öyle garip davrandın  fI1BI4d5KFU
# 1       o deli kadın herkesin içinde beni rezil etti h...  fI1BI4d5KFU
# 2                 ama yapma böyle git dedim git karşımdan  fI1BI4d5KFU
# 3                               bana o kadar iyi geldi ki  fI1BI4d5KFU
# 4               allahım ben tamamen inanamıyorum şu an ya  fI1BI4d5KFU
# ...                                                   ...          ...
# 248025  hatta köyleri o kadar sakin ki dışarıda insan ...  dRssR_apbR0
# 248026  yani orada ciddi ciddi ikinci el kıyafet sektö...  dRssR_apbR0
# 248027  fakat ülkemizde ikinci el kıyafet dükkanı görd...  dRssR_apbR0
# 248028  ihtiyaç sahiplerine vermeyi tercih ediyorlar v...  dRssR_apbR0
# 248029  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
#
# [248030 rows x 5 columns]

# %%
df_word_group_time_loc_in_sent_result["start_time"] = df_word_group_time_loc_in_sent_result["start_time"].apply(lambda x: (x-shift))
df_word_group_time_loc_in_sent_result["end_time"] = df_word_group_time_loc_in_sent_result["end_time"].apply(lambda x: (x+shift))
df_word_group_time_loc_in_sent_result
# Out:
#                             search_string  start_time    end_time  \
# 0               demek o yüzden öyle garip   81.238000   83.701086
# 1       o deli kadın herkesin içinde beni  135.478000  138.362800
# 2           ama yapma böyle git dedim git  146.719000  148.849769
# 3               bana o kadar iyi geldi ki  301.734000  304.174000
# 4       ben tamamen inanamıyorum şu an ya  336.956927  340.160000
# ...                                   ...         ...         ...
# 248025    o kadar sakin ki dışarıda insan  187.784392  190.616696
# 248026   yani orada ciddi ciddi ikinci el  577.776000  580.478481
# 248027         eğer varsa da bence çok iş  587.561571  589.828238
# 248028                ve bu çok güzel bir  597.141716  599.024012
# 248029        şunu da söylemek isterim ki  601.076700  603.508050
#
#                                                  sentence     video_id
# 0                     demek o yüzden öyle garip davrandın  fI1BI4d5KFU
# 1       o deli kadın herkesin içinde beni rezil etti h...  fI1BI4d5KFU
# 2                 ama yapma böyle git dedim git karşımdan  fI1BI4d5KFU
# 3                               bana o kadar iyi geldi ki  fI1BI4d5KFU
# 4               allahım ben tamamen inanamıyorum şu an ya  fI1BI4d5KFU
# ...                                                   ...          ...
# 248025  hatta köyleri o kadar sakin ki dışarıda insan ...  dRssR_apbR0
# 248026  yani orada ciddi ciddi ikinci el kıyafet sektö...  dRssR_apbR0
# 248027  fakat ülkemizde ikinci el kıyafet dükkanı görd...  dRssR_apbR0
# 248028  ihtiyaç sahiplerine vermeyi tercih ediyorlar v...  dRssR_apbR0
# 248029  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
#
# [248030 rows x 5 columns]

# %%
df_word_group_time_loc_in_sent_result["start_time"] = df_word_group_time_loc_in_sent_result["start_time"].apply(lambda x: round(x))
df_word_group_time_loc_in_sent_result["end_time"] = df_word_group_time_loc_in_sent_result["end_time"].apply(lambda x: round(x))
df_word_group_time_loc_in_sent_result
# Out:
#                             search_string  start_time  end_time  \
# 0               demek o yüzden öyle garip          81        84
# 1       o deli kadın herkesin içinde beni         135       138
# 2           ama yapma böyle git dedim git         147       149
# 3               bana o kadar iyi geldi ki         302       304
# 4       ben tamamen inanamıyorum şu an ya         337       340
# ...                                   ...         ...       ...
# 248025    o kadar sakin ki dışarıda insan         188       191
# 248026   yani orada ciddi ciddi ikinci el         578       580
# 248027         eğer varsa da bence çok iş         588       590
# 248028                ve bu çok güzel bir         597       599
# 248029        şunu da söylemek isterim ki         601       604
#
#                                                  sentence     video_id
# 0                     demek o yüzden öyle garip davrandın  fI1BI4d5KFU
# 1       o deli kadın herkesin içinde beni rezil etti h...  fI1BI4d5KFU
# 2                 ama yapma böyle git dedim git karşımdan  fI1BI4d5KFU
# 3                               bana o kadar iyi geldi ki  fI1BI4d5KFU
# 4               allahım ben tamamen inanamıyorum şu an ya  fI1BI4d5KFU
# ...                                                   ...          ...
# 248025  hatta köyleri o kadar sakin ki dışarıda insan ...  dRssR_apbR0
# 248026  yani orada ciddi ciddi ikinci el kıyafet sektö...  dRssR_apbR0
# 248027  fakat ülkemizde ikinci el kıyafet dükkanı görd...  dRssR_apbR0
# 248028  ihtiyaç sahiplerine vermeyi tercih ediyorlar v...  dRssR_apbR0
# 248029  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
#
# [248030 rows x 5 columns]

# %%
df_word_group_time_loc_in_sent_result.sort_values("search_string",key=lambda x:x.str.len(), inplace=True, ascending=False)
df_word_group_time_loc_in_sent_result.reset_index(drop=True, inplace=True)
df_word_group_time_loc_in_sent_result
# Out:
#                                             search_string  start_time  \
# 0       başka biriyle herhangi bir şey yaşıyor musun k...         319
# 1       gidelim bir bakalım hep birlikte bakalım bir o...         987
# 2       nasıl olduğunu gördün zaten artık değil mi tek...        2614
# 3       bir şekilde söylüyorum ve o zaman eminim ki ço...        4774
# 4       benim kızım tamam bir şey yapmış hata yapmış o...        3090
# ...                                                   ...         ...
# 248025                                       da o o da ki          61
# 248026                                       o mu o şey o        2237
# 248027                                        o o o şey o        1183
# 248028                                        o o o o o o         697
# 248029                                          o o o o o        2264
#
#         end_time                                           sentence  \
# 0            325  başka biriyle herhangi bir şey yaşıyor musun k...
# 1            988  yerleştirmeye yumurtasını seviyoruz çok güzel ...
# 2           2620  nasıl olduğunu gördün zaten artık değil mi tek...
# 3           4781  bir şekilde söylüyorum ve o zaman eminim ki ço...
# 4           3097  benim kızım tamam bir şey yapmış hata yapmış o...
# ...          ...                                                ...
# 248025        63  bu bacağı ben uçmak istiyorum demesiydi bunun ...
# 248026      2240                                    ha o mu o şey o
# 248027      1186                                        o o o şey o
# 248028       701     olur biz saçında bir dur sevdim be o o o o o o
# 248029      2266  o o o o o alttan yazdırıyorlar abi yardım ne a...
#
#            video_id
# 0       KsZ_8oIQsv4
# 1       eqkDognLtTc
# 2       N4YDaU51lvI
# 3       cUAQrHbbpZ8
# 4       CIQ3Ave21Kw
# ...             ...
# 248025  agGOHteE2GI
# 248026  99Iaexxewq4
# 248027  _FsOnRDIJQQ
# 248028  wXAnHYWPnfw
# 248029  eYt2lCw2Z7U
#
# [248030 rows x 5 columns]

# %%
df_word_group_time_loc_in_sent_result["unique_word_ratio"] = df_word_group_time_loc_in_sent_result["search_string"].apply(lambda text: repetation_ratio(text))
df_word_group_time_loc_in_sent_result
# Out:
#                                             search_string  start_time  \
# 0       başka biriyle herhangi bir şey yaşıyor musun k...         319
# 1       gidelim bir bakalım hep birlikte bakalım bir o...         987
# 2       nasıl olduğunu gördün zaten artık değil mi tek...        2614
# 3       bir şekilde söylüyorum ve o zaman eminim ki ço...        4774
# 4       benim kızım tamam bir şey yapmış hata yapmış o...        3090
# ...                                                   ...         ...
# 248025                                       da o o da ki          61
# 248026                                       o mu o şey o        2237
# 248027                                        o o o şey o        1183
# 248028                                        o o o o o o         697
# 248029                                          o o o o o        2264
#
#         end_time                                           sentence  \
# 0            325  başka biriyle herhangi bir şey yaşıyor musun k...
# 1            988  yerleştirmeye yumurtasını seviyoruz çok güzel ...
# 2           2620  nasıl olduğunu gördün zaten artık değil mi tek...
# 3           4781  bir şekilde söylüyorum ve o zaman eminim ki ço...
# 4           3097  benim kızım tamam bir şey yapmış hata yapmış o...
# ...          ...                                                ...
# 248025        63  bu bacağı ben uçmak istiyorum demesiydi bunun ...
# 248026      2240                                    ha o mu o şey o
# 248027      1186                                        o o o şey o
# 248028       701     olur biz saçında bir dur sevdim be o o o o o o
# 248029      2266  o o o o o alttan yazdırıyorlar abi yardım ne a...
#
#            video_id  unique_word_ratio
# 0       KsZ_8oIQsv4                 93
# 1       eqkDognLtTc                 77
# 2       N4YDaU51lvI                100
# 3       cUAQrHbbpZ8                 89
# 4       CIQ3Ave21Kw                 94
# ...             ...                ...
# 248025  agGOHteE2GI                 60
# 248026  99Iaexxewq4                 60
# 248027  _FsOnRDIJQQ                 40
# 248028  wXAnHYWPnfw                 16
# 248029  eYt2lCw2Z7U                 20
#
# [248030 rows x 6 columns]

# %%
df_word_group_time_loc_in_sent_result_repeat_ratio = df_word_group_time_loc_in_sent_result[df_word_group_time_loc_in_sent_result["unique_word_ratio"] > unique_word_ratio]
df_word_group_time_loc_in_sent_result_repeat_ratio.drop_duplicates(subset=["search_string","start_time","end_time"], inplace=True)
df_word_group_time_loc_in_sent_result_repeat_ratio.reset_index(drop=True, inplace=True)
df_word_group_time_loc_in_sent_result_repeat_ratio.drop("unique_word_ratio", axis=1, inplace=True)
df_word_group_time_loc_in_sent_result_repeat_ratio
# Out:
# <ipython-input-39-d6186b820154>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_word_group_time_loc_in_sent_result_repeat_ratio.drop_duplicates(subset=["search_string","start_time","end_time"], inplace=True)
# <ipython-input-39-d6186b820154>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_word_group_time_loc_in_sent_result_repeat_ratio.drop("unique_word_ratio", axis=1, inplace=True)
#                                             search_string  start_time  \
# 0       başka biriyle herhangi bir şey yaşıyor musun k...         319
# 1       nasıl olduğunu gördün zaten artık değil mi tek...        2614
# 2       bir şekilde söylüyorum ve o zaman eminim ki ço...        4774
# 3       benim kızım tamam bir şey yapmış hata yapmış o...        3090
# 4       sıcak mı evet böyle işte tamam bir şey yok ora...         603
# ...                                                   ...         ...
# 218262                                     yok ki ya o da        7361
# 218263                                     ya o da mı yok        7065
# 218264                                     da var şu an o         366
# 218265                                     ki tek şu an o        1381
# 218266                                      ne o da şu an         273
#
#         end_time                                           sentence  \
# 0            325  başka biriyle herhangi bir şey yaşıyor musun k...
# 1           2620  nasıl olduğunu gördün zaten artık değil mi tek...
# 2           4781  bir şekilde söylüyorum ve o zaman eminim ki ço...
# 3           3097  benim kızım tamam bir şey yapmış hata yapmış o...
# 4            612  sıcak mı evet böyle işte tamam bir şey yok ora...
# ...          ...                                                ...
# 218262      7363      i lyas abinin haberi yok ki ya o da sevinecek
# 218263      7067               abi hey barmen gürkan ya o da mı yok
# 218264       376  çeksem çekmesem mi diye düşünüyorum belki oyna...
# 218265      1383  yeni nesil yazılımlar sistemler deniliyor bura...
# 218266       275  formasyonu ne o da şu an aktif hale getirdim d...
#
#            video_id
# 0       KsZ_8oIQsv4
# 1       N4YDaU51lvI
# 2       cUAQrHbbpZ8
# 3       CIQ3Ave21Kw
# 4       Mh3bgDLKt2o
# ...             ...
# 218262  XREYOwgg6Uk
# 218263  r1eZ_SdK_24
# 218264  EafHmnHMjvg
# 218265  Sa8nJcrmBp0
# 218266  HgaAaBdkWks
#
# [218267 rows x 5 columns]

# %%
df_word_group_time_loc_in_sent_result_repeat_ratio["include_string_ratio"] = df_word_group_time_loc_in_sent_result_repeat_ratio.apply(lambda x: int((len(str(x['search_string']))/len(str(x['sentence'])))*100) ,axis=1)
df_word_group_time_loc_in_sent_result_repeat_ratio
# Out:
# <ipython-input-40-e137816795b3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_word_group_time_loc_in_sent_result_repeat_ratio["include_string_ratio"] = df_word_group_time_loc_in_sent_result_repeat_ratio.apply(lambda x: int((len(str(x['search_string']))/len(str(x['sentence'])))*100) ,axis=1)
#                                             search_string  start_time  \
# 0       başka biriyle herhangi bir şey yaşıyor musun k...         319
# 1       nasıl olduğunu gördün zaten artık değil mi tek...        2614
# 2       bir şekilde söylüyorum ve o zaman eminim ki ço...        4774
# 3       benim kızım tamam bir şey yapmış hata yapmış o...        3090
# 4       sıcak mı evet böyle işte tamam bir şey yok ora...         603
# ...                                                   ...         ...
# 218262                                     yok ki ya o da        7361
# 218263                                     ya o da mı yok        7065
# 218264                                     da var şu an o         366
# 218265                                     ki tek şu an o        1381
# 218266                                      ne o da şu an         273
#
#         end_time                                           sentence  \
# 0            325  başka biriyle herhangi bir şey yaşıyor musun k...
# 1           2620  nasıl olduğunu gördün zaten artık değil mi tek...
# 2           4781  bir şekilde söylüyorum ve o zaman eminim ki ço...
# 3           3097  benim kızım tamam bir şey yapmış hata yapmış o...
# 4            612  sıcak mı evet böyle işte tamam bir şey yok ora...
# ...          ...                                                ...
# 218262      7363      i lyas abinin haberi yok ki ya o da sevinecek
# 218263      7067               abi hey barmen gürkan ya o da mı yok
# 218264       376  çeksem çekmesem mi diye düşünüyorum belki oyna...
# 218265      1383  yeni nesil yazılımlar sistemler deniliyor bura...
# 218266       275  formasyonu ne o da şu an aktif hale getirdim d...
#
#            video_id  include_string_ratio
# 0       KsZ_8oIQsv4                   100
# 1       N4YDaU51lvI                    92
# 2       cUAQrHbbpZ8                   100
# 3       CIQ3Ave21Kw                   100
# 4       Mh3bgDLKt2o                   100
# ...             ...                   ...
# 218262  XREYOwgg6Uk                    31
# 218263  r1eZ_SdK_24                    38
# 218264  EafHmnHMjvg                    16
# 218265  Sa8nJcrmBp0                    12
# 218266  HgaAaBdkWks                    15
#
# [218267 rows x 6 columns]

# %%
df_word_group_time_loc_in_sent_result_repeat_ratio.to_excel(f"{lang_folder.capitalize()}_Word_Group_Max_In_Youtube_Sentence_{word_end}_Word{file_ext}_Not_Word_Usage.xlsx", index=False)

# %%
df_word_group_time_loc_include_string_ratio = df_word_group_time_loc_in_sent_result_repeat_ratio[df_word_group_time_loc_in_sent_result_repeat_ratio["include_string_ratio"] > include_wordgroup_ratio]
df_word_group_time_loc_include_string_ratio.drop("include_string_ratio", axis=1, inplace=True)
df_word_group_time_loc_include_string_ratio.reset_index(drop=True, inplace=True)
df_word_group_time_loc_include_string_ratio
# Out:
# <ipython-input-41-ea709f90da2b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_word_group_time_loc_include_string_ratio.drop("include_string_ratio", axis=1, inplace=True)
#                                            search_string  start_time  \
# 0      başka biriyle herhangi bir şey yaşıyor musun k...         319
# 1      nasıl olduğunu gördün zaten artık değil mi tek...        2614
# 2      bir şekilde söylüyorum ve o zaman eminim ki ço...        4774
# 3      benim kızım tamam bir şey yapmış hata yapmış o...        3090
# 4      sıcak mı evet böyle işte tamam bir şey yok ora...         603
# ...                                                  ...         ...
# 48786                                    o bu ve her gün         893
# 48787                                    ne o boş ver ya        4366
# 48788                                    bu ay mı yok mu         199
# 48789                                    ya bir de o var        1286
# 48790                                    o da şu her gün         148
#
#        end_time                                           sentence  \
# 0           325  başka biriyle herhangi bir şey yaşıyor musun k...
# 1          2620  nasıl olduğunu gördün zaten artık değil mi tek...
# 2          4781  bir şekilde söylüyorum ve o zaman eminim ki ço...
# 3          3097  benim kızım tamam bir şey yapmış hata yapmış o...
# 4           612  sıcak mı evet böyle işte tamam bir şey yok ora...
# ...         ...                                                ...
# 48786       897                                    o bu ve her gün
# 48787      4369                                    ne o boş ver ya
# 48788       263                                    bu ay mı yok mu
# 48789      1288                                    ya bir de o var
# 48790       155                                    o da şu her gün
#
#           video_id
# 0      KsZ_8oIQsv4
# 1      N4YDaU51lvI
# 2      cUAQrHbbpZ8
# 3      CIQ3Ave21Kw
# 4      Mh3bgDLKt2o
# ...            ...
# 48786  IiptWs5QgDA
# 48787  BeCS4X5oyXQ
# 48788  d4hmTrjuAk0
# 48789  Wzuoaygu2dQ
# 48790  GaCiHWyWkWg
#
# [48791 rows x 5 columns]

# %% [markdown]
# ###### Search String Wordgroup Word Analysis

# %%
#search_string_word_list = []
#for sent in df_word_group_time_loc_include_string_ratio["search_string"]:
#    words = word_tokenize(sent)
#    search_string_word_list = search_string_word_list + words

# %%
#search_string_word_count = Counter(search_string_word_list)
#search_string_word_count

# %%
#df_word_copy = df_word.copy()
#df_word_copy

# %%
#word_freq_count = []
#for word in df_word_copy["word"]:
#    try:
#        freq = search_string_word_count[f"{word}"]
#    except:
#        freq = 0
#    word_freq_count.append([word,freq])
#df_search_word_freq = pd.DataFrame(word_freq_count, columns=["word","frequency"])
#df_search_word_freq["frequency"] = df_search_word_freq["frequency"].replace([0], int(df_search_word_freq["frequency"].mean()))
#df_search_word_freq.sort_values(by="frequency", inplace=True, ascending=False)
#df_search_word_freq.reset_index(drop=True, inplace=True)
#df_search_word_freq

# %%
#word_adjust_usage_dict = word_max_usage_limit(df_search_word_freq,"word","frequency", 1)
#word_adjust_usage_dict

# %%
word_adjust_usage_dict = word_max_usage_limit(df_word,"word","frequency", 3)
word_adjust_usage_dict
# Out:
# {'bir': 829,
#  'bu': 487,
#  'ne': 353,
#  've': 342,
#  'için': 241,
#  'mi': 236,
#  'o': 220,
#  'ben': 216,
#  'de': 215,
#  'çok': 213,
#  'ama': 205,
#  'var': 193,
#  'evet': 190,
#  'mı': 176,
#  'değil': 171,
#  'da': 159,
#  'şey': 158,
#  'hayır': 150,
#  'daha': 146,
#  'sen': 144,
#  'kadar': 118,
#  'bana': 117,
#  'yok': 109,
#  'onu': 109,
#  'seni': 108,
#  'beni': 107,
#  'bunu': 107,
#  'gibi': 106,
#  'iyi': 104,
#  'tamam': 102,
#  'her': 99,
#  'benim': 98,
#  'sana': 90,
#  'ki': 85,
#  'neden': 82,
#  'zaman': 79,
#  'senin': 79,
#  'sadece': 79,
#  'burada': 78,
#  'nasıl': 72,
#  'olduğunu': 71,
#  'hiç': 69,
#  'sonra': 68,
#  'şimdi': 67,
#  'en': 65,
#  'ya': 64,
#  'öyle': 63,
#  'mu': 62,
#  'şu': 60,
#  'misin': 58,
#  'hadi': 57,
#  'önce': 56,
#  'biraz': 55,
#  'musun': 53,
#  'güzel': 53,
#  'oldu': 50,
#  'böyle': 50,
#  'ona': 49,
#  'lütfen': 48,
#  'bile': 46,
#  'yani': 46,
#  'artık': 45,
#  'onun': 45,
#  'geri': 44,
#  'bak': 44,
#  'istiyorum': 43,
#  'peki': 42,
#  'eğer': 42,
#  'çünkü': 42,
#  'biliyorum': 41,
#  'gerçekten': 40,
#  'başka': 40,
#  'tek': 39,
#  'olarak': 39,
#  'belki': 39,
#  'doğru': 38,
#  'büyük': 37,
#  'buraya': 37,
#  'biri': 36,
#  'olan': 36,
#  'olur': 35,
#  'adam': 35,
#  'hey': 34,
#  'olacak': 34,
#  'hiçbir': 34,
#  'efendim': 33,
#  'demek': 33,
#  'yardım': 33,
#  'biz': 32,
#  'ile': 32,
#  'nerede': 31,
#  'sanırım': 31,
#  'tüm': 31,
#  'orada': 31,
#  'bilmiyorum': 30,
#  'gün': 30,
#  'fazla': 30,
#  'bunun': 30,
#  'ederim': 30,
#  'şeyi': 30,
#  'teşekkürler': 29,
#  'yeni': 29,
#  'son': 29,
#  'et': 29,
#  'merhaba': 28,
#  'kötü': 28,
#  'gece': 28,
#  'şeyler': 28,
#  'işte': 28,
#  'biliyor': 28,
#  'iki': 28,
#  'sorun': 27,
#  'tam': 27,
#  'bütün': 26,
#  'hemen': 26,
#  'harika': 26,
#  'olsun': 26,
#  'gerek': 26,
#  'ol': 26,
#  'siz': 26,
#  'onları': 25,
#  'size': 25,
#  'üzgünüm': 24,
#  'diye': 24,
#  'gel': 24,
#  'küçük': 24,
#  'teşekkür': 23,
#  'devam': 23,
#  'tabii': 23,
#  'olabilir': 23,
#  'aynı': 23,
#  'ver': 23,
#  'yüzden': 23,
#  'kendi': 23,
#  'bize': 23,
#  'bizi': 22,
#  'hakkında': 22,
#  'haydi': 22,
#  'kız': 22,
#  'oluyor': 22,
#  'izin': 21,
#  'sizi': 21,
#  'iş': 21,
#  'buna': 21,
#  'dur': 21,
#  'git': 20,
#  'kimse': 20,
#  'geldi': 20,
#  'bizim': 20,
#  'asla': 20,
#  'yoksa': 20,
#  'mısın': 20,
#  'göre': 19,
#  'seninle': 19,
#  'vardı': 19,
#  'değilim': 19,
#  'önemli': 19,
#  'benimle': 19,
#  'içinde': 19,
#  'baba': 19,
#  'tekrar': 19,
#  'söyle': 19,
#  'özür': 19,
#  'mü': 19,
#  'dostum': 19,
#  'selam': 19,
#  'yine': 19,
#  'hala': 19,
#  'anne': 19,
#  'al': 18,
#  'bugün': 18,
#  'üç': 18,
#  'uzun': 18,
#  'herkes': 18,
#  'aslında': 18,
#  'bakalım': 18,
#  'olmak': 18,
#  'dakika': 18,
#  'para': 18,
#  'geliyor': 18,
#  'olmaz': 18,
#  'şekilde': 18,
#  'bence': 18,
#  'gerçek': 18,
#  'biliyorsun': 18,
#  'pekala': 18,
#  'birlikte': 18,
#  'istiyorsun': 17,
#  'onlar': 17,
#  'şunu': 17,
#  'birkaç': 17,
#  'zaten': 17,
#  'ilk': 17,
#  'lazım': 17,
#  'saat': 17,
#  'onunla': 17,
#  'yapıyorsun': 17,
#  'neler': 17,
#  'ister': 17,
#  'bay': 38,
#  'bayan': 23,
#  'emin': 17,
#  'pek': 17,
#  'gidelim': 17,
#  'bırak': 17,
#  'yer': 17,
#  'miyim': 17,
#  'hep': 17,
#  'buradan': 17,
#  'yıl': 16,
#  'çocuk': 16,
#  'yere': 16,
#  'sizin': 16,
#  'söyledi': 16,
#  'nedir': 16,
#  'eve': 16,
#  'bekle': 16,
#  'nereye': 16,
#  'burası': 16,
#  'dilerim': 16,
#  'hepsi': 15,
#  'karşı': 15,
#  'hazır': 15,
#  'etmek': 15,
#  'olduğu': 15,
#  'an': 15,
#  'olmalı': 15,
#  'kaç': 15,
#  'istemiyorum': 15,
#  'az': 15,
#  'çocuklar': 15,
#  'kendini': 14,
#  'ilgili': 14,
#  'söz': 14,
#  'ediyorum': 14,
#  'eski': 14,
#  'anda': 14,
#  'dinle': 14,
#  'gerekiyor': 14,
#  'benden': 14,
#  'tane': 14,
#  'işe': 14,
#  'bunlar': 13,
#  'fakat': 13,
#  'işi': 13,
#  'zor': 13,
#  'kesinlikle': 13,
#  'yapmak': 13,
#  'kişi': 13,
#  'kadın': 13,
#  'görmek': 13,
#  'istiyor': 13,
#  'misiniz': 13,
#  'diğer': 13,
#  'sağ': 13,
#  'kabul': 12,
#  'seviyorum': 12,
#  'bundan': 12,
#  'niye': 12,
#  'onlara': 12,
#  'aman': 12,
#  'elbette': 12,
#  'kez': 12,
#  'yarın': 12,
#  'yapma': 12,
#  'edin': 12,
#  'hem': 12,
#  'falan': 12,
#  'senden': 12,
#  'oraya': 12,
#  'hoş': 12,
#  'zorunda': 12,
#  'gidip': 12,
#  'yerde': 12,
#  'yanlış': 12,
#  'kontrol': 11,
#  'özel': 11,
#  'ediyor': 11,
#  'gereken': 11,
#  'dedim': 11,
#  'tatlım': 11,
#  'doktor': 11,
#  'geç': 11,
#  'nereden': 11,
#  'hafta': 11,
#  'birini': 11,
#  'yemek': 11,
#  'bakın': 11,
#  'dışarı': 11,
#  'mutlu': 11,
#  'ondan': 11,
#  'eminim': 11,
#  'insan': 11,
#  'gördüm': 11,
#  'bazı': 10,
#  'polis': 10,
#  'yalnız': 10,
#  'gitti': 10,
#  'dikkat': 10,
#  'sakin': 10,
#  'etti': 10,
#  'musunuz': 10,
#  'çabuk': 10,
#  'beri': 10,
#  'merak': 10,
#  'yalan': 10,
#  'ihtiyacım': 10,
#  'insanlar': 10,
#  'gidiyor': 10,
#  'ayrıca': 10,
#  'değildi': 10,
#  'haber': 10,
#  'babam': 10,
#  'beş': 10,
#  'görüşürüz': 10,
#  'dün': 9,
#  'erkek': 9,
#  'umarım': 9,
#  'nefret': 9,
#  'etme': 9,
#  'yerine': 9,
#  'sanki': 9,
#  'öldü': 9,
#  'karar': 9,
#  'veya': 9,
#  'gördün': 9,
#  'değilsin': 9,
#  'aptal': 9,
#  'sabah': 9,
#  'yeter': 9,
#  'olmuş': 9,
#  'sence': 9,
#  'yaptım': 9,
#  'kes': 9,
#  'geçen': 9,
#  'ateş': 9,
#  'sonunda': 9,
#  'akşam': 9,
#  'kendine': 9,
#  'yap': 9,
#  'farklı': 9,
#  'birşey': 9,
#  'tarafından': 9,
#  'bunları': 9,
#  'olması': 8,
#  'kendimi': 8,
#  'boyunca': 8,
#  'su': 8,
#  'üzerinde': 8,
#  'dört': 8,
#  'olursa': 8,
#  'adı': 8,
#  'ettim': 8,
#  'fark': 8,
#  'olduğumu': 8,
#  'olamaz': 8,
#  'ay': 8,
#  'vardır': 8,
#  'dolar': 8,
#  'tamamen': 8,
#  'hangi': 8,
#  'açık': 8,
#  'yaptın': 8,
#  'oldukça': 8,
#  'yol': 8,
#  'adamı': 8,
#  'istediğim': 8,
#  'kal': 8,
#  'neyse': 8,
#  'yüzünden': 8,
#  'gelecek': 8,
#  'olsa': 8,
#  'bitti': 8,
#  'ancak': 8,
#  'olun': 8,
#  'başına': 8,
#  'söyledim': 8,
#  'yanında': 8,
#  'adım': 8,
#  'annem': 8,
#  'cevap': 8,
#  'kolay': 8,
#  'ise': 8,
#  'görünüyor': 8,
#  'aldım': 8,
#  'sahip': 8,
#  'dedi': 8,
#  'birisi': 8,
#  'öyleyse': 8,
#  'yolu': 8,
#  'henüz': 8,
#  'yoktu': 8,
#  'anlıyorum': 7,
#  'geldim': 7,
#  'beraber': 7,
#  'zamanı': 7,
#  'onların': 7,
#  'yapıyor': 7,
#  'durum': 7,
#  'olmadığını': 7,
#  'buldum': 7,
#  'gitmek': 7,
#  'konuşmak': 7,
#  'bazen': 7,
#  'adamın': 7,
#  'takip': 7,
#  'bende': 7,
#  'oldum': 7,
#  'sakın': 7,
#  'aç': 7,
#  'savaş': 7,
#  'dünya': 7,
#  'genç': 7,
#  'yardımcı': 7,
#  'eder': 7,
#  'yeniden': 7,
#  'almak': 7,
#  'hızlı': 7,
#  'içeri': 7,
#  'on': 7,
#  'neredeyse': 7,
#  'altında': 7,
#  'uzak': 7,
#  'hayatta': 7,
#  'yaptı': 7,
#  'saniye': 7,
#  'konusunda': 7,
#  'evde': 7,
#  'süre': 7,
#  'boş': 7,
#  'göz': 7,
#  'oğlum': 7,
#  'halde': 7,
#  'ara': 7,
#  'söylemek': 7,
#  'ciddi': 7,
#  'düşünüyorsun': 7,
#  'azından': 7,
#  'sanmıyorum': 7,
#  'duydum': 7,
#  'mükemmel': 7,
#  'kaldı': 7,
#  'güçlü': 7,
#  'işin': 7,
#  'şeyin': 7,
#  'galiba': 7,
#  'miyiz': 7,
#  'gelen': 7,
#  'konuda': 7,
#  'istedim': 7,
#  'kan': 6,
#  'günü': 6,
#  'düşündüm': 6,
#  'tabi': 6,
#  'çıktı': 6,
#  'hepimiz': 6,
#  'bin': 6,
#  'herhangi': 6,
#  'ev': 6,
#  'muhtemelen': 6,
#  'yakın': 6,
#  'söylüyor': 6,
#  'silah': 6,
#  'düşünüyorum': 6,
#  'rahat': 6,
#  'hayatım': 6,
#  'anladım': 6,
#  'gidiyorum': 6,
#  'kimin': 6,
#  'alo': 6,
#  'hayal': 6,
#  'araba': 6,
#  'çocuğu': 6,
#  'hava': 6,
#  'bebeğim': 6,
#  'dersin': 6,
#  'arada': 6,
#  'evlat': 6,
#  'olacağım': 6,
#  'çalışıyorum': 6,
#  'acele': 6,
#  'olduğuna': 6,
#  'hareket': 6,
#  'kesin': 6,
#  'sürü': 6,
#  'şeye': 6,
#  'garip': 6,
#  'başladı': 6,
#  'durumda': 6,
#  'altı': 6,
#  'adamım': 6,
#  'verdi': 6,
#  'herif': 6,
#  'hayat': 6,
#  'geldin': 6,
#  'ortaya': 6,
#  'sende': 6,
#  'çalışıyor': 6,
#  'gelip': 6,
#  'acaba': 6,
#  'yaptığını': 6,
#  'kapıyı': 6,
#  'oyun': 6,
#  'hatta': 6,
#  'kardeşim': 6,
#  'şuna': 6,
#  'gidiyoruz': 6,
#  'soru': 6,
#  'canım': 6,
#  'arasında': 6,
#  'komik': 6,
#  'verin': 6,
#  'bilirsin': 6,
#  'gizli': 6,
#  'el': 6,
#  'durun': 6,
#  'varsa': 6,
#  'hepsini': 6,
#  'terk': 6,
#  'zarar': 6,
#  'böylece': 6,
#  'gelir': 6,
#  'şeyleri': 6,
#  'beyler': 6,
#  'yeterince': 6,
#  'olmadan': 6,
#  'olacağını': 6,
#  'kısa': 6,
#  'üzerine': 5,
#  'ihtiyacı': 5,
#  'haklısın': 5,
#  'diyorsun': 5,
#  'birinin': 5,
#  'yapacağım': 5,
#  'geçti': 5,
#  'ait': 5,
#  'yolunda': 5,
#  'telefon': 5,
#  'şaka': 5,
#  'kızı': 5,
#  'günaydın': 5,
#  'bebek': 5,
#  'olay': 5,
#  'sanıyorsun': 5,
#  'etmeye': 5,
#  'arkadaşım': 5,
#  'sürekli': 5,
#  'olmayacak': 5,
#  'gelin': 5,
#  'baban': 5,
#  'çeviri': 5,
#  'uygun': 5,
#  'çıkar': 5,
#  'verdim': 5,
#  'aynen': 5,
#  'nasılsın': 5,
#  'dans': 5,
#  'beyaz': 5,
#  'gidiyorsun': 5,
#  'memnun': 5,
#  'dünyanın': 5,
#  'dışında': 5,
#  'geceler': 5,
#  'ölüm': 5,
#  'tuhaf': 5,
#  'zamanda': 5,
#  'yüksek': 5,
#  'korkunç': 5,
#  'tür': 5,
#  'yaşlı': 5,
#  'yakında': 5,
#  'veriyorum': 5,
#  'değildir': 5,
#  'edecek': 5,
#  'olmadı': 5,
#  'bırakın': 5,
#  'dolu': 5,
#  'iyiyim': 5,
#  'aldı': 5,
#  'eden': 5,
#  'fikir': 5,
#  'mısınız': 5,
#  'anladın': 5,
#  'olurdu': 5,
#  'neyi': 5,
#  'sevindim': 5,
#  'sensin': 5,
#  'bilmek': 5,
#  'neydi': 5,
#  'rahatsız': 5,
#  'mümkün': 5,
#  'kere': 5,
#  'sanıyordum': 5,
#  'parayı': 5,
#  'acı': 5,
#  'yalnızca': 5,
#  'hissediyorum': 5,
#  'dedin': 5,
#  'tahmin': 5,
#  'ediyorsun': 5,
#  'üzere': 5,
#  'yapamam': 5,
#  'içine': 5,
#  'gerektiğini': 5,
#  'yapacağız': 5,
#  'dikkatli': 5,
#  'geliyorum': 5,
#  'neyin': 5,
#  'kapa': 5,
#  'bizimle': 5,
#  'şöyle': 5,
#  'biliyordum': 5,
#  'milyon': 5,
#  'varmış': 5,
#  'başkan': 5,
#  'sizinle': 5,
#  'ölü': 5,
#  'ihtiyacımız': 5,
#  'güvenlik': 5,
#  'çık': 5,
#  'belli': 5,
#  'vermek': 5,
#  'aşağı': 5,
#  'affedersiniz': 5,
#  'yapacak': 5,
#  'yapmaya': 5,
#  'yemin': 5,
#  'dön': 5,
#  'otur': 5,
#  'ihtiyacın': 4,
#  'oradan': 4,
#  'anlaşıldı': 4,
#  'dek': 4,
#  'kaptan': 4,
#  'at': 4,
#  'deli': 4,
#  'ana': 4,
#  'çek': 4,
#  'annen': 4,
#  'olmayan': 4,
#  'dışarıda': 4,
#  'hasta': 4,
#  'birine': 4,
#  'sefer': 4,
#  'berbat': 4,
#  'istedi': 4,
#  'yapıyorum': 4,
#  'baş': 4,
#  'diyorum': 4,
#  'normal': 4,
#  'olup': 4,
#  'şans': 4,
#  'ettin': 4,
#  'istediğini': 4,
#  'insanların': 4,
#  'güç': 4,
#  'tatlı': 4,
#  'dair': 4,
#  'keşke': 4,
#  'getir': 4,
#  'gidin': 4,
#  'herkesin': 4,
#  'söyledin': 4,
#  'yukarı': 4,
#  'yavaş': 4,
#  'evine': 4,
#  'tehlikeli': 4,
#  'bilmem': 4,
#  'yeri': 4,
#  'pardon': 4,
#  'hayatını': 4,
#  'yapar': 4,
#  'ele': 4,
#  'istersen': 4,
#  'durumu': 4,
#  'hata': 4,
#  'kendisi': 4,
#  'aşk': 4,
#  'sessiz': 4,
#  'üstüne': 4,
#  'biliyoruz': 4,
#  'miydi': 4,
#  'duydun': 4,
#  'önünde': 4,
#  'hoşça': 4,
#  'yeterli': 4,
#  'aile': 4,
#  'bununla': 4,
#  'millet': 4,
#  'yüz': 4,
#  'zamandır': 4,
#  'isterim': 4,
#  'bayım': 4,
#  'asıl': 4,
#  'alıp': 4,
#  'buradayım': 4,
#  'nefes': 4,
#  'kahve': 4,
#  'basit': 4,
#  'diyor': 4,
#  'bakma': 4,
#  'bilgi': 4,
#  'kusura': 4,
#  'bunların': 4,
#  'tut': 4,
#  'görüyorum': 4,
#  'sıcak': 4,
#  'koca': 4,
#  'neye': 4,
#  'bilmiyor': 4,
#  'ufak': 4,
#  'kızlar': 4,
#  'hak': 4,
#  'edeceğim': 4,
#  'mıydı': 4,
#  'aldın': 4,
#  'arkadaş': 4,
#  'yaşında': 4,
#  'benziyor': 4,
#  'yapacaksın': 4,
#  'adını': 4,
#  'tıpkı': 4,
#  'yedi': 4,
#  'sonraki': 4,
#  'olacaksın': 4,
#  'herhalde': 4,
#  'gelmiş': 4,
#  'yıldır': 4,
#  'kızım': 4,
#  'vakit': 4,
#  'olduğun': 4,
#  'alın': 4,
#  'kimsenin': 4,
#  'doğum': 4,
#  'birçok': 4,
#  'dalga': 4,
#  'erken': 4,
#  'haklı': 4,
#  'görünüyorsun': 4,
#  'olmalısın': 4,
#  'olsaydı': 4,
#  'düşünüyor': 4,
#  'olmasını': 4,
#  'olduğum': 4,
#  'köpek': 4,
#  'temiz': 4,
#  'adına': 4,
#  'işler': 4,
#  'olası': 4,
#  'sesini': 4,
#  'görüyor': 4,
#  'cidden': 4,
#  'söylüyorum': 4,
#  'ajan': 4,
#  'fena': 4,
#  'bulmak': 4,
#  'almaya': 4,
#  'mesaj': 4,
#  'yerinde': 4,
#  'kızın': 4,
#  'buldun': 4,
#  'insanları': 4,
#  'gayet': 4,
#  'anlamıyorum': 4,
#  'söylemiştim': 4,
#  'düşün': 4,
#  'ikinci': 4,
#  'öldürmek': 4,
#  'yapmam': 4,
#  'şarkı': 4,
#  'istediğin': 4,
#  'yoktur': 3,
#  'bilir': 3,
#  'gitmem': 3,
#  'konu': 3,
#  'yerini': 3,
#  'inanamıyorum': 3,
#  'birden': 3,
#  'hatırlıyor': 3,
#  'muhteşem': 3,
#  'sağol': 3,
#  'zamanlar': 3,
#  'sayın': 3,
#  'acil': 3,
#  'çekil': 3,
#  'kimsin': 3,
#  'güvenli': 3,
#  'yaparım': 3,
#  'bilmiyordum': 3,
#  'evi': 3,
#  'bekliyor': 3,
#  'kalk': 3,
#  'yanına': 3,
#  'buradaki': 3,
#  'canlı': 3,
#  'cinayet': 3,
#  'sevgili': 3,
#  'zavallı': 3,
#  'geldiniz': 3,
#  'rağmen': 3,
#  'teslim': 3,
#  'yapalım': 3,
#  'üstünde': 3,
#  'istiyorsan': 3,
#  'alabilir': 3,
#  'söylüyorsun': 3,
#  'görünüşe': 3,
#  'söyleme': 3,
#  'kırmızı': 3,
#  'gerçeği': 3,
#  'geldik': 3,
#  'içki': 3,
#  'yürü': 3,
#  'numara': 3,
#  'olmaya': 3,
#  'sonsuza': 3,
#  'adamlar': 3,
#  'unutma': 3,
#  'baksana': 3,
#  'konuşma': 3,
#  'arkadaşın': 3,
#  'kimseye': 3,
#  'film': 3,
#  'işim': 3,
#  'özellikle': 3,
#  'sebep': 3,
#  'yaptığı': 3,
#  'şeyden': 3,
#  'defa': 3,
#  'bizden': 3,
#  'uyuşturucu': 3,
#  'bağlı': 3,
#  'işini': 3,
#  'onlardan': 3,
#  'gerekir': 3,
#  'değiliz': 3,
#  'suç': 3,
#  'sebebi': 3,
#  'çoktan': 3,
#  'bilemiyorum': 3,
#  'olduğundan': 3,
#  'parçası': 3,
#  'sıkı': 3,
#  'pislik': 3,
#  'sonu': 3,
#  'herşey': 3,
#  'tercih': 3,
#  'alacağım': 3,
#  'babası': 3,
#  'biriyle': 3,
#  'umurumda': 3,
#  'patron': 3,
#  'verir': 3,
#  'bahsediyorsun': 3,
#  'saçma': 3,
#  'soğuk': 3,
#  'oda': 3,
#  'elinde': 3,
#  'kalan': 3,
#  'parti': 3,
#  'sıra': 3,
#  'kayıp': 3,
#  'eskiden': 3,
#  'eğlenceli': 3,
#  'yapan': 3,
#  'yaşıyor': 3,
#  'burayı': 3,
#  'anlat': 3,
#  'bekleyin': 3,
#  'ölmüş': 3,
#  'onlarla': 3,
#  'babamın': 3,
#  'çoğu': 3,
#  'yemeği': 3,
#  'burda': 3,
#  'dedektif': 3,
#  'yaptığın': 3,
#  'günler': 3,
#  'gerekiyordu': 3,
#  'olma': 3,
#  'dürüst': 3,
#  'yapabilirim': 3,
#  'çocukları': 3,
#  'anlıyor': 3,
#  'seviyor': 3,
#  'dolayı': 3,
#  'yola': 3,
#  'dünyada': 3,
#  'şehir': 3,
#  'tanıyor': 3,
#  'sert': 3,
#  'çalışıyorsun': 3,
#  'olmasın': 3,
#  'iyisi': 3,
#  'bulduk': 3,
#  'aşkına': 3,
#  'teklif': 3,
#  'anlamı': 3,
#  'silahı': 3,
#  'göster': 3,
#  'alır': 3,
#  'bakayım': 3,
#  'alan': 3,
#  'gitsin': 3,
#  'orası': 3,
#  'istemiyor': 3,
#  'istiyoruz': 3,
#  'ağır': 3,
#  'adama': 3,
#  'tamamdır': 3,
#  'tarafa': 3,
#  'affedersin': 3,
#  'altına': 3,
#  'görmedim': 3,
#  'hanımefendi': 3,
#  'takım': 3,
#  'kalın': 3,
#  'kara': 3,
#  'söyleyeyim': 3,
#  'geldiğini': 3,
#  'demektir': 3,
#  'edebilir': 3,
#  'canına': 3,
#  'arkadaşı': 3,
#  'kendim': 3,
#  'sene': 3,
#  'davet': 3,
#  'taraftan': 3,
#  'kalmak': 3,
#  'görmeye': 3,
#  'anlaşma': 3,
#  'yapmış': 3,
#  'hepiniz': 3,
#  'aşık': 3,
#  'vereceğim': 3,
#  'zorundayım': 3,
#  'süper': 3,
#  'yarım': 3,
#  'sahibi': 3,
#  'kapı': 3,
#  'çocuğun': 3,
#  'fikrim': 3,
#  'duyuyor': 3,
#  'müzik': 3,
#  'aferin': 3,
#  'gurur': 3,
#  'gelmek': 3,
#  'öğrenmek': 3,
#  'kendime': 3,
#  'hatırlıyorum': 3,
#  'iç': 3,
#  'vakti': 3,
#  'herkese': 3,
#  'sona': 3,
#  'yazık': 3,
#  'serbest': 3,
#  'bayanlar': 3,
#  'yaptığım': 3,
#  'siyah': 3,
#  'şimdiye': 3,
#  'istiyorsunuz': 3,
#  'herşeyi': 3,
#  'görev': 3,
#  'getirdim': 3,
#  'dinleyin': 3,
#  'hale': 3,
#  'kavga': 3,
#  'arabayı': 3,
#  'oldun': 3,
#  'bölüm': 3,
#  'sık': 3,
#  'arka': 3,
#  'hoşuma': 3,
#  'üçüncü': 3,
#  'sırada': 3,
#  'gidecek': 3,
#  'karanlık': 3,
#  'verici': 3,
#  'dava': 3,
#  'sekiz': 3,
#  'çekilin': 3,
#  'olayı': 3,
#  'anlamına': 3,
#  'dua': 3,
#  'istemedim': 3,
#  'herkesi': 3,
#  'gider': 3,
#  'başıma': 3,
#  'konuş': 3,
#  'kitap': 3,
#  'güneş': 3,
#  'bul': 3,
#  'edeyim': 3,
#  'önceki': 3,
#  'ifade': 3,
#  'resmi': 3,
#  'veriyor': 3,
#  'okul': 3,
#  'suçlu': 3,
#  'mesela': 3}

# %%
df_youtube_word_usage = word_usage_result2(word_list, df_word_group_time_loc_include_string_ratio, "search_string", "video_id", word_usage_min, word_adjust_usage_dict)
df_youtube_word_usage.drop_duplicates(inplace=True)
df_youtube_word_usage
# Out:
#                                           search_string     video_id
# 0                             sana gerek yok burada kal  ztZMp7dpRto
# 1     gerek yok çok teşekkür ederim ben zaten birkaç...  zpfhmsZB26w
# 2     pardon ben çok sıcak bir kahve alabilir miyim ...  zoN3xOGVjbk
# 3     bilir ne güzel anne olacaksın çok sevindim bil...  zmmMNX_dDg4
# 4                      burası biraz büyük değil mi bize  zmmMNX_dDg4
# ...                                                 ...          ...
# 1363  bana ne kadar güzel bir kadın olduğumu söyledi...  0EmRyNfzWKM
# 1364                            ama küçük bir sorun var  0EmRyNfzWKM
# 1365  peki birisi için mi yaptın yoksa oyun olsun di...  0AOYUEuSiyw
# 1366          ben dün gece için senden çok özür dilerim  071PtpSHv5c
# 1367    hadi çocuklar gidelim sen de gelecek misin baba  06tktL2JVgk
#
# [1368 rows x 2 columns]

# %%
#df_youtube_word_usage = word_usage_result(word_list, df_word_group_time_loc_include_string_ratio, "search_string", "video_id", word_usage_min, word_usage_max)
#df_youtube_word_usage.drop_duplicates(inplace=True)
#df_youtube_word_usage

# %%
df_youtube_word_usage_merge = pd.merge(df_word_group_time_loc_include_string_ratio,df_youtube_word_usage,how="inner",on=["search_string","video_id"])
df_youtube_word_usage_merge.drop_duplicates(subset=["search_string","video_id"],inplace=True)
df_youtube_word_usage_merge.reset_index(drop=True, inplace=True)
df_youtube_word_usage_merge
# Out:
#                                           search_string  start_time  end_time  \
# 0     başka biriyle herhangi bir şey yaşıyor musun k...         319       325
# 1     nasıl olduğunu gördün zaten artık değil mi tek...        2614      2620
# 2     bir şekilde söylüyorum ve o zaman eminim ki ço...        4774      4781
# 3     benim kızım tamam bir şey yapmış hata yapmış o...        3090      3097
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...         603       612
# ...                                                 ...         ...       ...
# 1363                                ne var ki daha önce         130       138
# 1364                                o mu bu mu var evet          53        55
# 1365                                daha genç bir at al        2041      2043
# 1366                                cidden mi o mu evet         368       370
# 1367                                 doğru bir de o var        6472      6475
#
#                                                sentence     video_id
# 0     başka biriyle herhangi bir şey yaşıyor musun k...  KsZ_8oIQsv4
# 1     nasıl olduğunu gördün zaten artık değil mi tek...  N4YDaU51lvI
# 2     bir şekilde söylüyorum ve o zaman eminim ki ço...  cUAQrHbbpZ8
# 3     benim kızım tamam bir şey yapmış hata yapmış o...  CIQ3Ave21Kw
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...  Mh3bgDLKt2o
# ...                                                 ...          ...
# 1363                                ne var ki daha önce  _0Ozm1E1xHE
# 1364                                o mu bu mu var evet  StouY7hsuSQ
# 1365                                daha genç bir at al  W263ryKMPH0
# 1366                                cidden mi o mu evet  FythRb2U8OU
# 1367                              ha doğru bir de o var  HeXezF4VrJ8
#
# [1368 rows x 5 columns]

# %%
df_youtube_word_usage_merge.to_excel(f"{lang_folder.capitalize()}_Word_Group_Max_In_Youtube_Sentence_{word_end}_Word{file_ext}_Temp.xlsx", index=False)

# %%
df_word_count = word_count_result(df_youtube_word_usage_merge, df_youtube_word_usage_merge.columns[0:1])
df_word_count
# Out:
#               word  word_count
# 0              bir         560
# 1               bu         247
# 2              ben         216
# 3               de         215
# 4              çok         213
# ..             ...         ...
# 944           neyi           1
# 945  bahsediyorsun           1
# 946        sonsuza           1
# 947    gerektiğini           1
# 948         sessiz           1
#
# [949 rows x 2 columns]

# %%
word_set = set(word_list)
sent_result_word_set = set(df_word_count["word"])

# %%
word_set.difference(sent_result_word_set)
# Out:
# {'adını',
#  'ajan',
#  'altına',
#  'arka',
#  'aşkına',
#  'bay',
#  'bayan',
#  'bayanlar',
#  'bayım',
#  'beri',
#  'beyler',
#  'birden',
#  'burda',
#  'böylece',
#  'canına',
#  'dek',
#  'dolayı',
#  'durun',
#  'ele',
#  'evine',
#  'görev',
#  'görünüşe',
#  'güç',
#  'hangi',
#  'hayatını',
#  'hepiniz',
#  'içki',
#  'kapa',
#  'kaptan',
#  'olası',
#  'olmalı',
#  'parti',
#  'pekala',
#  'sağol',
#  'silah',
#  'sona',
#  'sıkı',
#  'tut',
#  'tür',
#  'uyuşturucu',
#  'verici',
#  'yeterince',
#  'yola',
#  'zamandır',
#  'zavallı',
#  'çekil',
#  'çekilin',
#  'çeviri',
#  'çoktan',
#  'öyleyse',
#  'üzere'}

# %%
df_youtube_word_usage_merge = pd.read_excel(f"{lang_folder.capitalize()}_Word_Group_Max_In_Youtube_Sentence_{word_end}_Word{file_ext}_Temp.xlsx")
df_youtube_word_usage_merge
# Out:
#                                           search_string  start_time  end_time  \
# 0     başka biriyle herhangi bir şey yaşıyor musun k...         319       325
# 1     nasıl olduğunu gördün zaten artık değil mi tek...        2614      2620
# 2     bir şekilde söylüyorum ve o zaman eminim ki ço...        4774      4781
# 3     benim kızım tamam bir şey yapmış hata yapmış o...        3090      3097
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...         603       612
# ...                                                 ...         ...       ...
# 1363                                ne var ki daha önce         130       138
# 1364                                o mu bu mu var evet          53        55
# 1365                                daha genç bir at al        2041      2043
# 1366                                cidden mi o mu evet         368       370
# 1367                                 doğru bir de o var        6472      6475
#
#                                                sentence     video_id
# 0     başka biriyle herhangi bir şey yaşıyor musun k...  KsZ_8oIQsv4
# 1     nasıl olduğunu gördün zaten artık değil mi tek...  N4YDaU51lvI
# 2     bir şekilde söylüyorum ve o zaman eminim ki ço...  cUAQrHbbpZ8
# 3     benim kızım tamam bir şey yapmış hata yapmış o...  CIQ3Ave21Kw
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...  Mh3bgDLKt2o
# ...                                                 ...          ...
# 1363                                ne var ki daha önce  _0Ozm1E1xHE
# 1364                                o mu bu mu var evet  StouY7hsuSQ
# 1365                                daha genç bir at al  W263ryKMPH0
# 1366                                cidden mi o mu evet  FythRb2U8OU
# 1367                              ha doğru bir de o var  HeXezF4VrJ8
#
# [1368 rows x 5 columns]

# %%
df_youtube_word_usage_merge_reassign = df_youtube_word_usage_merge.copy() # important because when it doesn't copy, main df are also change.

# %%
df_youtube_word_usage_merge_reassign["end_time"] = df_youtube_word_usage_merge_reassign["start_time"] + 1

# %%
out_path = "/home/kurubal/Downloads"

# %%
df_youtube_word_usage_merge_reassign.to_excel(f"{out_path}/{lang_folder.capitalize()}_Word_Group_Max_In_Youtube_Sentence_{word_end}_Word{file_ext}_Temp.xlsx", index=False)

# %%
df_youtube_word_usage_merge_youtube_tool = pd.read_excel(f"{out_path}/{lang_folder.capitalize()}_Word_Group_Max_In_Youtube_Sentence_{word_end}_Word{file_ext}_Temp.xlsx")  # from youtube tool
df_youtube_word_usage_merge_video_list = list(set(df_youtube_word_usage_merge_youtube_tool["video_id"]))

# %%
df_youtube_word_usage_merge_new = df_youtube_word_usage_merge[df_youtube_word_usage_merge["video_id"].isin(df_youtube_word_usage_merge_video_list)]
df_youtube_word_usage_merge_new
# Out:
#                                           search_string  start_time  end_time  \
# 0     başka biriyle herhangi bir şey yaşıyor musun k...         319       325
# 2     bir şekilde söylüyorum ve o zaman eminim ki ço...        4774      4781
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...         603       612
# 5     benim burada ne işim var neden bunu yapıyorum ...         273       278
# 6     bu işi yaparım dedim o zaman süper dedi bitti ...        5381      5389
# ...                                                 ...         ...       ...
# 1357                               iki devam bir de var          94       105
# 1361                               hızlı ol ve acele et         488       491
# 1363                                ne var ki daha önce         130       138
# 1364                                o mu bu mu var evet          53        55
# 1366                                cidden mi o mu evet         368       370
#
#                                                sentence     video_id
# 0     başka biriyle herhangi bir şey yaşıyor musun k...  KsZ_8oIQsv4
# 2     bir şekilde söylüyorum ve o zaman eminim ki ço...  cUAQrHbbpZ8
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...  Mh3bgDLKt2o
# 5     benim burada ne işim var neden bunu yapıyorum ...  sHnvEDmE3so
# 6     bu işi yaparım dedim o zaman süper dedi bitti ...  zgQbOmPp9pk
# ...                                                 ...          ...
# 1357                               iki devam bir de var  pHR9Y_R6DGQ
# 1361                               hızlı ol ve acele et  tMSvpjvsjDc
# 1363                                ne var ki daha önce  _0Ozm1E1xHE
# 1364                                o mu bu mu var evet  StouY7hsuSQ
# 1366                                cidden mi o mu evet  FythRb2U8OU
#
# [483 rows x 5 columns]

# %%
df_youtube_word_usage_merge_new["video_url"] = "https://www.youtube.com/watch?v="+df_youtube_word_usage_merge['video_id'].map(str)+"&t="+df_youtube_word_usage_merge['start_time'].map(str)+"s"
df_youtube_word_usage_merge_new
# Out:
# <ipython-input-32-c1453041db40>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_youtube_word_usage_merge_new["video_url"] = "https://www.youtube.com/watch?v="+df_youtube_word_usage_merge['video_id'].map(str)+"&t="+df_youtube_word_usage_merge['start_time'].map(str)+"s"
#                                           search_string  start_time  end_time  \
# 0     başka biriyle herhangi bir şey yaşıyor musun k...         319       325
# 2     bir şekilde söylüyorum ve o zaman eminim ki ço...        4774      4781
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...         603       612
# 5     benim burada ne işim var neden bunu yapıyorum ...         273       278
# 6     bu işi yaparım dedim o zaman süper dedi bitti ...        5381      5389
# ...                                                 ...         ...       ...
# 1357                               iki devam bir de var          94       105
# 1361                               hızlı ol ve acele et         488       491
# 1363                                ne var ki daha önce         130       138
# 1364                                o mu bu mu var evet          53        55
# 1366                                cidden mi o mu evet         368       370
#
#                                                sentence     video_id  \
# 0     başka biriyle herhangi bir şey yaşıyor musun k...  KsZ_8oIQsv4
# 2     bir şekilde söylüyorum ve o zaman eminim ki ço...  cUAQrHbbpZ8
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...  Mh3bgDLKt2o
# 5     benim burada ne işim var neden bunu yapıyorum ...  sHnvEDmE3so
# 6     bu işi yaparım dedim o zaman süper dedi bitti ...  zgQbOmPp9pk
# ...                                                 ...          ...
# 1357                               iki devam bir de var  pHR9Y_R6DGQ
# 1361                               hızlı ol ve acele et  tMSvpjvsjDc
# 1363                                ne var ki daha önce  _0Ozm1E1xHE
# 1364                                o mu bu mu var evet  StouY7hsuSQ
# 1366                                cidden mi o mu evet  FythRb2U8OU
#
#                                               video_url
# 0     https://www.youtube.com/watch?v=KsZ_8oIQsv4&t=...
# 2     https://www.youtube.com/watch?v=cUAQrHbbpZ8&t=...
# 4     https://www.youtube.com/watch?v=Mh3bgDLKt2o&t=...
# 5     https://www.youtube.com/watch?v=sHnvEDmE3so&t=...
# 6     https://www.youtube.com/watch?v=zgQbOmPp9pk&t=...
# ...                                                 ...
# 1357  https://www.youtube.com/watch?v=pHR9Y_R6DGQ&t=94s
# 1361  https://www.youtube.com/watch?v=tMSvpjvsjDc&t=...
# 1363  https://www.youtube.com/watch?v=_0Ozm1E1xHE&t=...
# 1364  https://www.youtube.com/watch?v=StouY7hsuSQ&t=53s
# 1366  https://www.youtube.com/watch?v=FythRb2U8OU&t=...
#
# [483 rows x 6 columns]

# %%
#df_youtube_word_usage_merge = df_youtube_word_usage_merge.head(700)
df_youtube_word_usage_merge_new.to_excel(f"{lang_folder.capitalize()}_Word_Group_Max_In_Youtube_Sentence_{word_end}_Word{file_ext}.xlsx", index=False)

# %%
df_youtube_word_usage_merge_new_count = word_count_result(df_youtube_word_usage_merge_new, df_youtube_word_usage_merge_new.columns[0:1])
df_youtube_word_usage_merge_new_count
# Out:
#       word  word_count
# 0      bir         214
# 1      çok         111
# 2       bu         108
# 3      ama          84
# 4       de          76
# ..     ...         ...
# 786   asıl           1
# 787  içeri           1
# 788  iyisi           1
# 789  suçlu           1
# 790    oda           1
#
# [791 rows x 2 columns]

# %% [markdown]
# #### Copy Move And Delete

# %%
output_file = glob.glob(f"{lang_folder.capitalize()}_Word_Group_Max_In_Youtube_Sentence_{word_end}_Word{file_ext}.xlsx")  # ???
output_file

# %%
for k in output_file:
    source = k # source directory
    destination = path
    shutil.copy2(source, destination)

# %%
for i in output_file:
    try:
        os.remove(i)
    except:
        pass

# %% [markdown]
# #### Manuel Select Result Word Count

# %%
df_youtube_word_usage_merge_manuel = pd.read_excel("")
df_youtube_word_usage_merge_manuel

# %%
df_word_count_manuel = word_count_result(df_youtube_word_usage_merge_manuel, df_youtube_word_usage_merge_manuel.columns[0:1])
df_word_count_manuel

# %%
word_set = set(word_list)
select_sent_result_word_set = set(df_word_count_manuel["word"])

# %%
word_set.difference(select_sent_result_word_set)

# %%
# deployment2 notebook 8 den max kelime minimum sentence alınacak

# %% [markdown]
# #### Temp

# %%
df_youtube_word_usage2 = word_usage_result2(word_list, df_word_group_time_loc_include_string_ratio, "search_string", "video_id", word_usage_min, word_adjust_usage_dict)
df_youtube_word_usage2.drop_duplicates(inplace=True)
df_youtube_word_usage2
# Out:
#                                           search_string     video_id
# 0         senin gibi birinin kızı olduğuna inanamıyorum  ztZMp7dpRto
# 1                             sana gerek yok burada kal  ztZMp7dpRto
# 2     gerek yok çok teşekkür ederim ben zaten birkaç...  zpfhmsZB26w
# 3     pardon ben çok sıcak bir kahve alabilir miyim ...  zoN3xOGVjbk
# 4                      burası biraz büyük değil mi bize  zmmMNX_dDg4
# ...                                                 ...          ...
# 1353                            ne var ne yok iyi misin  0F7lXcoPGSU
# 1354  bana ne kadar güzel bir kadın olduğumu söyledi...  0EmRyNfzWKM
# 1355                            ama küçük bir sorun var  0EmRyNfzWKM
# 1356          ben dün gece için senden çok özür dilerim  071PtpSHv5c
# 1357    hadi çocuklar gidelim sen de gelecek misin baba  06tktL2JVgk
#
# [1357 rows x 2 columns]

# %%
df_youtube_word_usage_merge2 = pd.merge(df_word_group_time_loc_include_string_ratio,df_youtube_word_usage2,how="inner",on=["search_string","video_id"])
df_youtube_word_usage_merge2.drop_duplicates(subset=["search_string","video_id"],inplace=True)
df_youtube_word_usage_merge2.reset_index(drop=True, inplace=True)
df_youtube_word_usage_merge2
# Out:
#                                           search_string  start_time  end_time  \
# 0     başka biriyle herhangi bir şey yaşıyor musun k...         319       325
# 1     nasıl olduğunu gördün zaten artık değil mi tek...        2614      2620
# 2     benim kızım tamam bir şey yapmış hata yapmış o...        3090      3097
# 3     bir şekilde söylüyorum ve o zaman eminim ki ço...        4774      4781
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...         603       612
# ...                                                 ...         ...       ...
# 1352                                tek bir de aldın mı        7903      7911
# 1353                                ve bu film için tam        2374      2377
# 1354                                cidden mi o mu evet         368       370
# 1355                                 doğru bir de o var        6472      6475
# 1356                                   al bir de bu var        2465      2467
#
#                                                sentence     video_id
# 0     başka biriyle herhangi bir şey yaşıyor musun k...  KsZ_8oIQsv4
# 1     nasıl olduğunu gördün zaten artık değil mi tek...  N4YDaU51lvI
# 2     benim kızım tamam bir şey yapmış hata yapmış o...  CIQ3Ave21Kw
# 3     bir şekilde söylüyorum ve o zaman eminim ki ço...  cUAQrHbbpZ8
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...  Mh3bgDLKt2o
# ...                                                 ...          ...
# 1352                                tek bir de aldın mı  qQUZ5d5mpWk
# 1353                                ve bu film için tam  Yr2ZLfWT0i8
# 1354                                cidden mi o mu evet  FythRb2U8OU
# 1355                              ha doğru bir de o var  HeXezF4VrJ8
# 1356                                   al bir de bu var  5e5vf1WrQYg
#
# [1357 rows x 5 columns]

# %%
df_word_count2 = word_count_result(df_youtube_word_usage_merge2, df_youtube_word_usage_merge2.columns[0:1])
df_word_count2
# Out:
#          word  word_count
# 0         bir         563
# 1          bu         243
# 2         ben         216
# 3         çok         213
# 4          de         210
# ..        ...         ...
# 940       göz           1
# 941    oradan           1
# 942   gerekir           1
# 943  dedektif           1
# 944   sonraki           1
#
# [945 rows x 2 columns]

# %%
word_set = set(word_list)
sent_result_word_set2 = set(df_word_count2["word"])

# %%
word_set.difference(sent_result_word_set2)
# Out:
# {'bayım', 'görünüşe'}
