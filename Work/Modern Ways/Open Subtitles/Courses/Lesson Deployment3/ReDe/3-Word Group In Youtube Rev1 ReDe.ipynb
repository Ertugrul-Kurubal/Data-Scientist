# %% [markdown]
# ### Word Group In Youtube

# %%
import os
import multiprocessing
#import multiprocessing as mp
from multiprocessing import Process, Manager, Pool, Queue
from itertools import islice
from collections import Counter
import re
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize
from functools import reduce
from pathlib import Path
import shutil

# %%
nprocs = multiprocessing.cpu_count()
print(f"Number of CPU cores: {nprocs}")
# Out:
# Number of CPU cores: 16

# %%
# language pair
lang_folder = "Turkish"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> target language for learner

# adding native word to shared word
word_start = 0  # 0  # native word start index
word_end = 1000  # native word end index 28,200,1000,5000,10000, 20000, 40000

# word ratio
if word_end == 28 or word_end == 200:
    unique_word_ratio = 70
    include_wordgroup_ratio = 70
elif word_end == 1000 or word_end == 5000:
    unique_word_ratio = 80
    include_wordgroup_ratio = 80
elif word_end == 10000:
    unique_word_ratio = 85
    include_wordgroup_ratio = 85
else:
    unique_word_ratio = 90
    include_wordgroup_ratio = 90

# word usage
if word_end == 28 or word_end == 200 or word_end == 1000 or word_end == 5000 or word_end == 10000:
    word_usage_min = 1
    word_usage_max = 30
elif word_end == 20000:
    word_usage_min = 7
    word_usage_max = 40
else:
    word_usage_min = 7
    word_usage_max = 50

# use for manuel set
#unique_word_ratio = 70  # 28,200 = 70 ; 1000,5000 = 80 ; 10000 = 85 ; 20000,40000 = 90
#include_wordgroup_ratio = 70  # 28,200 = 70 ; 1000,5000 = 80 : 10000 = 85 ; 20000,40000 = 90
#word_usage_min = 10  # 28,200,1000,5000,10000 = 10 ; 20000 = 7 ; 40000 = 5
#word_usage_max = 100


# sentence ratio and time shift
adjust_sent_word_ratio = 25  #28,200 = 15 ; 1000,5000,10000 = 25 ; 20000 = 35 ; 40000 = 45

# start end time result shift
shift = 0.3  # sentence time shift

# func select
if word_end == 28:
    sentence_word_count_number = 2
else:
    sentence_word_count_number = 5   
word_group_adjust_select = False  # True, False; True for selecting word group according to sentence_word_count_number in video_id text analysis
                                  # False for selecting word group according to max word group length 

# shared word frequency
word_frequency = True  # True, False

# prefix suffix file
prefix_suffix = False  # True, False  # True for adding prefix suffix word
native_word = True # True for adding native word

# adding output file extention
if prefix_suffix & native_word:
    file_ext = "5"
elif (not prefix_suffix) & native_word:
    file_ext = "6"
else:
    file_ext = "7"              

# 5 => for only native word with prefix suffix.
# 6 => for only native word without prefix suffix.

print(f"word_end:{word_end}\nfile_ext:{file_ext}\nunique_word_ratio:{unique_word_ratio}\n\
include_wordgroup_ratio:{include_wordgroup_ratio}\nword_usage_min:{word_usage_min}\nword_usage_max:{word_usage_max}")
# Out:
# word_end:1000
# file_ext:6
# unique_word_ratio:80
# include_wordgroup_ratio:80
# word_usage_min:1
# word_usage_max:30

# %%
path = f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/\
Deployment3/Result/3-Word Group In Youtube"

Path(path).mkdir(parents=True, exist_ok=True)

# %%
def word_usage_result(word_list, df_target, target_column, target_opt_column, word_usage_min, word_usage_max):
    '''
    word_usage_result(word_list, df_ngram_pair, "threegram", "frequency", 1, 5) \n
    word_list is a list, df_target is a dateframe, target_column is df_target dataframe target column, \n
    target_opt_column is df_target dataframe opt_target column, \n
    word_usage_min and word_usage_max word usage condition.
    '''    
    word_num_dict = {}
    for i in word_list:
        word_num_dict[f"{i}"] = 0
    
    result_list_select = []
    var_list = []
    for i in range(len(df_target)):
        target_value = df_target.loc[i,f"{target_column}"]
        opt_value = df_target.loc[i,f"{target_opt_column}"]
        words = word_tokenize(target_value)   
        temp_list = [word for word in words]
        temp_list = temp_list + var_list
        # word count for max
        dict_list_count = Counter(temp_list)
        count_list = list(dict_list_count.values())
        # word count for min
        count_list2 = list(word_num_dict.values())
    
        if any([True if i>word_usage_max else False for i in count_list]) or not(any([True if j<word_usage_min else False for j in count_list2])):
            pass
        else:
            var_list = temp_list
            result_list_select.append([target_value,opt_value]) 
    
            for item2 in dict_list_count.items(): 
                word_num_dict[item2[0]] = item2[1]        
    df_result = pd.DataFrame(result_list_select, columns=[f"{target_column}",f"{target_opt_column}"])
    df_result.sort_values(by=f"{target_opt_column}", ascending=False, inplace=True)
    df_result.reset_index(drop=True, inplace=True)
    
    return df_result

# %%
def word_usage_result2(word_list, df_target, target_column, target_opt_column, word_usage_min, word_usage_max):
    '''
    word_usage_result(word_list, df_ngram_pair, "threegram", "frequency", 1, 5) \n
    word_list is a list, df_target is a dateframe, target_column is df_target dataframe target column, \n
    target_opt_column is df_target dataframe opt_target column, \n
    word_usage_min and word_usage_max word usage condition.
    '''    
    word_num_dict = {}
    for i in word_list:
        word_num_dict[f"{i}"] = 0
    
    result_list_select = []
    var_list = []
    for i in range(len(df_target)):
        target_value = df_target.loc[i,f"{target_column}"]
        opt_value = df_target.loc[i,f"{target_opt_column}"]
        words = word_tokenize(target_value)   
        temp_list = [word for word in words]
        temp_list = temp_list + var_list
        # word count for max
        dict_list_count = Counter(temp_list)
        count_list = list(dict_list_count.values())
        # word count for min
        count_list2 = list(word_num_dict.values())
    
        if any([True if i>word_usage_max else False for i in count_list]) or not(any([True if j<word_usage_min else False for j in count_list2])):
            pass
        else:
            var_list = temp_list
            result_list_select.append([target_value,opt_value]) 
    
            for item2 in dict_list_count.items(): 
                word_num_dict[item2[0]] = item2[1]        
    df_result = pd.DataFrame(result_list_select, columns=[f"{target_column}",f"{target_opt_column}"])
    df_result.sort_values(by=f"{target_opt_column}", ascending=False, inplace=True)
    df_result.reset_index(drop=True, inplace=True)
    
    return df_result

# %%
def exract_word_group(text, word_list):
    '''
    exract_word_group(text, word_list): \n
    text is a string sentence, word_list occurs words 
    '''
    words = re.findall(r"\w+", text, re.UNICODE)
    index_list = []
    # check words in word_list
    for i in range(len(words)):
        if words[i] in word_list:
            index_list.append(i)
        else:
            pass
    # add index plus 1 and compare with current and next index (Is it continuous or not?)
    all_index_list = []
    var_index_list = []
    for j in range(len(index_list)):
        try:
            var1 = index_list[j] + 1  
            var2 = index_list[j+1]
        except:
            var1 = index_list[j] + 1  
            var2 = index_list[-1]
        if var1 == var2:
            var3 = index_list[j]
            var_index_list.append(var3)
        else:
            var3 = index_list[j]
            var_index_list.append(var3)
            var4 = list(var_index_list)
            all_index_list.append(var4)
            var_index_list = []
    # index convert to word
    text_list = []
    for k in max(all_index_list, key=len):  # any error convert k to i
        word = words[k]
        text_list.append(word)
        if len(text_list) >= sentence_word_count_number:
            text = " ".join(text_list)
        else:
            text = f"sentencte_word_count_less_than_{sentence_word_count_number}"
    
    return text

# %%
def df_exract_word_group(df, source_text_column, opt_column, word_list, sent_len=False, sent_len_num=2):
    '''
    df_exract_word_group(df_adjust_text_ratio, sentence, video_id, word_list, sent_len=False, sent_len_num=2): \n
    df_adjust_text_ratio is a dataframe and it includes sentence and video_id columns. \n
    sentence is a string sentence. video_id is optional column value. word_list occurs words \n
    sent_len is sentence length condition. sent_len_num is sentence occurs how many word at least. 
    '''
    df.reset_index(drop=True, inplace=True)
    df_new = pd.DataFrame()
    for i in range(len(df)):
        source_text = df.loc[i,f"{source_text_column}"]
        opt_var = df.loc[i,f"{opt_column}"]
        words = re.findall(r"\w+", source_text, re.UNICODE)
        # check words in word_list
        index_list = []
        for j in range(len(words)):
            if words[j] in word_list:
                index_list.append(j)
            else:
                pass
        # add index plus 1 and compare with current and next index (Is it continuous or not?)
        all_index_list = []
        var_index_list = []
        for k in range(len(index_list)):
            try:
                var1 = index_list[k] + 1  
                var2 = index_list[k+1]
            except:
                var1 = index_list[k] + 1  
                var2 = index_list[-1]
            if var1 == var2:
                var3 = index_list[k]
                var_index_list.append(var3)
            else:
                var3 = index_list[k]
                var_index_list.append(var3)
                var4 = list(var_index_list)
                all_index_list.append(var4)
                var_index_list = []
        # index convert to word
        text_all_list = []
        for m in all_index_list:
            text_list = [] 
            for n in m:
                word = words[n]
                text_list.append(word)
                if sent_len:
                    if len(text_list) >= sent_len_num:
                        text = " ".join(text_list)
                        text_all_list.append(text)
                    else:
                        pass
                else:
                   text = " ".join(text_list)
                   text_all_list.append(text) 
        # dataframe output     
        for search_string in text_all_list:
            #df_var["index"] = i
            #df_var["search_string"] = search_string
            #df_var["sentence"] = source_text
            #df_var["video_id"] = opt_var
            df_list = []
            df_list.append([i,search_string,source_text,opt_var])
            df_var = pd.DataFrame(df_list,columns=["index","search_string",f"{source_text_column}",f"{opt_column}"])
            df_new = pd.concat([df_new, df_var], axis=0)

    return df_new

# %%
def word_group_time_loc(df, search, start_sent, end_sent, sent, sent_video_id):
    '''
    word_group_time_loc(df_search_result, "search_string", "start_time", "end_time", "sentence", "video_id")
    '''
    df.reset_index(drop=True, inplace=True)  # will test
    word_time_loc_list = []
    for i in range(len(df)):
        word = df.loc[i,f"{search}"]
        start_time = df.loc[i,f"{start_sent}"]
        end_time = df.loc[i,f"{end_sent}"]
        sentence = df.loc[i,f"{sent}"]
        video_id = df.loc[i,f"{sent_video_id}"]
        time_length = end_time-start_time
        sentence_length = len(sentence)
        time_length_ratio = time_length/sentence_length
        loc_list = []
        for j in re.finditer(fr"(?:\s|^){word}(?:\s|$)", sentence, re.IGNORECASE|re.UNICODE):
            loc_list.append(j)
            start = loc_list[0].start()
            end = loc_list[0].end()
            start_loc = start_time+(start*time_length_ratio)
            end_loc = start_time+(end*time_length_ratio)
        word_time_loc_list.append([word,start_loc,end_loc,sentence,video_id])
    df_word_time_loc = pd.DataFrame(word_time_loc_list, columns=[f"{search}",f"{start_sent}",f"{end_sent}",f"{sent}",f"{sent_video_id}"])

    return df_word_time_loc

# %%
def repetation_ratio(text):
    '''
    repetation_ratio(text) 
    text is a like as sentence and def compute repetation word ratio\n
    repetation_ratio("yok bir şey yok bir şey yok bir şey") 
    '''
    word_list = word_tokenize(text)
    word_num = len(word_list)
    word_unique_num = len(set(word_list))
    ratio = int((word_unique_num/word_num)*100)
    
    return ratio

# %%
def word_count_result(df,column_list): # df is dataframe, column_list is list value
    '''
    word_count_bool(df, column_list): df columns word count for word frequency\n
    df is dataframe, column_list is list value\n
    word_count_bool(df, ["word","twogram"]):
    '''
    list_all = []
    for i in df.loc[:,[x for x in column_list]].columns:
        var_list = df[f"{i}"].dropna().tolist()
        for j in var_list:
            list_all.append(j)
    text = " ".join(list_all)
    word_list = re.findall(r"\w+",text, re.UNICODE)
    df_word_list = pd.DataFrame(word_list, columns=["word"])
    #df_word_list.rename(columns={0:"word"}, inplace=True)
    df_word_count = pd.DataFrame(df_word_list.value_counts())
    df_word_count.reset_index(inplace=True)
    df_word_count.rename(columns={0:"word_count"}, inplace=True)
    
    return  df_word_count

# %%
def word_max_usage_limit(df, word_column_name, word_freq_column_name, min_word_usage):
    word_adjust_usage_dict = {}
    min_frequency = min(df[f"{word_freq_column_name}"])
    for word,frequency in zip(df[f"{word_column_name}"], df[f"{word_freq_column_name}"]):        
        word_usage_var = int((frequency*min_word_usage)/min_frequency)
        word_adjust_usage_dict[f"{word}"] = word_usage_var
    return word_adjust_usage_dict

# %% [markdown]
# #### Select Word

# %%
df_word_all = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.lower().capitalize()}/Deployment/Data/Word/Word_Merge_Preprocess.xlsx")
df_word_all  # word checked with picture word
# Out:
#                 word  frequency
# 0                bir   18835735
# 1                 bu   11062659
# 2                 ne    8025880
# 3                 ve    7766036
# 4               için    5484109
# ...              ...        ...
# 987890     karneleme          5
# 987891       karnaya          5
# 987892   dörtlümüzün          5
# 987893  karnavalınız          5
# 987894      hurmanın          5
#
# [987895 rows x 2 columns]

# %%
df_word_select = df_word_all.iloc[word_start:word_end,]

# %%
# Option
if prefix_suffix:
    df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_folder.capitalize()}/{lang_folder.capitalize()}/{lang_folder.capitalize()}_{word_end}_Word_Prefix_Suffix_Custom_Result_Manuel.xlsx")
    df_word = df_word.loc[:,["word","frequency"]]
    df_word = pd.concat([df_word,df_word_select], axis=0)
    df_word.drop_duplicates(inplace=True)    
    df_word.sort_values(by="frequency", ascending=False, inplace=True)
    df_word.reset_index(drop=True, inplace=True)
else:
    df_word = df_word_select

if native_word:
    df_word
else:
    df_word = df_word.head(0)

df_word
# Out:
#         word  frequency
# 0        bir   18835735
# 1         bu   11062659
# 2         ne    8025880
# 3         ve    7766036
# 4       için    5484109
# ..       ...        ...
# 995    resmi      68287
# 996  veriyor      68163
# 997     okul      68160
# 998    suçlu      68124
# 999   mesela      68096
#
# [1000 rows x 2 columns]

# %%
disable_list = ["sex","seks","seksi","sexy","sexe","seksüel","sexuell","gey","gay","lezbiyen","lesbienne","eşcinsel","mastürbasyon","masturbation","erotik","érotique", \
"bikini","penis","vagina","vajina","fetish","fetiş","fetishy","erotic","erotik","sexdom","kondom","condom","dildo","fetisj","hétérosexuel","féticher","fétiche","homosexuel"\
"ereksiyon","erectie","erection","érection","homoseksüel","prezervatif","préservatif","ass","fetisch","fetiche"]

# %%
word_select = df_word["word"].values.tolist()
word_select_set = set(word_select)
disable_word_set = set(disable_list)

# %%
word_list = list(word_select_set.difference(disable_word_set))
len(word_list)
# Out:
# 1000

# %%
word_adjust_usage_dict = word_max_usage_limit(df_word,"word","frequency", 1)
word_adjust_usage_dict
# Out:
# {'bir': 276,
#  'bu': 162,
#  'ne': 117,
#  've': 114,
#  'için': 80,
#  'mi': 78,
#  'o': 73,
#  'ben': 72,
#  'de': 71,
#  'çok': 71,
#  'ama': 68,
#  'var': 64,
#  'evet': 63,
#  'mı': 58,
#  'değil': 57,
#  'da': 53,
#  'şey': 52,
#  'hayır': 50,
#  'daha': 48,
#  'sen': 48,
#  'kadar': 39,
#  'bana': 39,
#  'yok': 36,
#  'onu': 36,
#  'seni': 36,
#  'beni': 35,
#  'bunu': 35,
#  'gibi': 35,
#  'iyi': 34,
#  'tamam': 34,
#  'her': 33,
#  'benim': 32,
#  'sana': 30,
#  'ki': 28,
#  'neden': 27,
#  'zaman': 26,
#  'senin': 26,
#  'sadece': 26,
#  'burada': 26,
#  'nasıl': 24,
#  'olduğunu': 23,
#  'hiç': 23,
#  'sonra': 22,
#  'şimdi': 22,
#  'en': 21,
#  'ya': 21,
#  'öyle': 21,
#  'mu': 20,
#  'şu': 20,
#  'misin': 19,
#  'hadi': 19,
#  'önce': 18,
#  'biraz': 18,
#  'musun': 17,
#  'güzel': 17,
#  'oldu': 16,
#  'böyle': 16,
#  'ona': 16,
#  'lütfen': 16,
#  'bile': 15,
#  'yani': 15,
#  'artık': 15,
#  'onun': 15,
#  'geri': 14,
#  'bak': 14,
#  'istiyorum': 14,
#  'peki': 14,
#  'eğer': 14,
#  'çünkü': 14,
#  'biliyorum': 13,
#  'gerçekten': 13,
#  'başka': 13,
#  'tek': 13,
#  'olarak': 13,
#  'belki': 13,
#  'doğru': 12,
#  'büyük': 12,
#  'buraya': 12,
#  'biri': 12,
#  'olan': 12,
#  'olur': 11,
#  'adam': 11,
#  'hey': 11,
#  'olacak': 11,
#  'hiçbir': 11,
#  'efendim': 11,
#  'demek': 11,
#  'yardım': 11,
#  'biz': 10,
#  'ile': 10,
#  'nerede': 10,
#  'sanırım': 10,
#  'tüm': 10,
#  'orada': 10,
#  'bilmiyorum': 10,
#  'gün': 10,
#  'fazla': 10,
#  'bunun': 10,
#  'ederim': 10,
#  'şeyi': 10,
#  'teşekkürler': 9,
#  'yeni': 9,
#  'son': 9,
#  'et': 9,
#  'merhaba': 9,
#  'kötü': 9,
#  'gece': 9,
#  'şeyler': 9,
#  'işte': 9,
#  'biliyor': 9,
#  'iki': 9,
#  'sorun': 9,
#  'tam': 9,
#  'bütün': 8,
#  'hemen': 8,
#  'harika': 8,
#  'olsun': 8,
#  'gerek': 8,
#  'ol': 8,
#  'siz': 8,
#  'onları': 8,
#  'size': 8,
#  'üzgünüm': 8,
#  'diye': 8,
#  'gel': 8,
#  'küçük': 8,
#  'teşekkür': 7,
#  'devam': 7,
#  'tabii': 7,
#  'olabilir': 7,
#  'aynı': 7,
#  'ver': 7,
#  'yüzden': 7,
#  'kendi': 7,
#  'bize': 7,
#  'bizi': 7,
#  'hakkında': 7,
#  'haydi': 7,
#  'kız': 7,
#  'oluyor': 7,
#  'izin': 7,
#  'sizi': 7,
#  'iş': 7,
#  'buna': 7,
#  'dur': 7,
#  'git': 6,
#  'kimse': 6,
#  'geldi': 6,
#  'bizim': 6,
#  'asla': 6,
#  'yoksa': 6,
#  'mısın': 6,
#  'göre': 6,
#  'seninle': 6,
#  'vardı': 6,
#  'değilim': 6,
#  'önemli': 6,
#  'benimle': 6,
#  'içinde': 6,
#  'baba': 6,
#  'tekrar': 6,
#  'söyle': 6,
#  'özür': 6,
#  'mü': 6,
#  'dostum': 6,
#  'selam': 6,
#  'yine': 6,
#  'hala': 6,
#  'anne': 6,
#  'al': 6,
#  'bugün': 6,
#  'üç': 6,
#  'uzun': 6,
#  'herkes': 6,
#  'aslında': 6,
#  'bakalım': 6,
#  'olmak': 6,
#  'dakika': 6,
#  'para': 6,
#  'geliyor': 6,
#  'olmaz': 6,
#  'şekilde': 6,
#  'bence': 6,
#  'gerçek': 6,
#  'biliyorsun': 6,
#  'pekala': 6,
#  'birlikte': 6,
#  'istiyorsun': 5,
#  'onlar': 5,
#  'şunu': 5,
#  'birkaç': 5,
#  'zaten': 5,
#  'ilk': 5,
#  'lazım': 5,
#  'saat': 5,
#  'onunla': 5,
#  'yapıyorsun': 5,
#  'neler': 5,
#  'ister': 5,
#  'bay': 12,
#  'bayan': 7,
#  'emin': 5,
#  'pek': 5,
#  'gidelim': 5,
#  'bırak': 5,
#  'yer': 5,
#  'miyim': 5,
#  'hep': 5,
#  'buradan': 5,
#  'yıl': 5,
#  'çocuk': 5,
#  'yere': 5,
#  'sizin': 5,
#  'söyledi': 5,
#  'nedir': 5,
#  'eve': 5,
#  'bekle': 5,
#  'nereye': 5,
#  'burası': 5,
#  'dilerim': 5,
#  'hepsi': 5,
#  'karşı': 5,
#  'hazır': 5,
#  'etmek': 5,
#  'olduğu': 5,
#  'an': 5,
#  'olmalı': 5,
#  'kaç': 5,
#  'istemiyorum': 5,
#  'az': 5,
#  'çocuklar': 5,
#  'kendini': 4,
#  'ilgili': 4,
#  'söz': 4,
#  'ediyorum': 4,
#  'eski': 4,
#  'anda': 4,
#  'dinle': 4,
#  'gerekiyor': 4,
#  'benden': 4,
#  'tane': 4,
#  'işe': 4,
#  'bunlar': 4,
#  'fakat': 4,
#  'işi': 4,
#  'zor': 4,
#  'kesinlikle': 4,
#  'yapmak': 4,
#  'kişi': 4,
#  'kadın': 4,
#  'görmek': 4,
#  'istiyor': 4,
#  'misiniz': 4,
#  'diğer': 4,
#  'sağ': 4,
#  'kabul': 4,
#  'seviyorum': 4,
#  'bundan': 4,
#  'niye': 4,
#  'onlara': 4,
#  'aman': 4,
#  'elbette': 4,
#  'kez': 4,
#  'yarın': 4,
#  'yapma': 4,
#  'edin': 4,
#  'hem': 4,
#  'falan': 4,
#  'senden': 4,
#  'oraya': 4,
#  'hoş': 4,
#  'zorunda': 4,
#  'gidip': 4,
#  'yerde': 4,
#  'yanlış': 4,
#  'kontrol': 3,
#  'özel': 3,
#  'ediyor': 3,
#  'gereken': 3,
#  'dedim': 3,
#  'tatlım': 3,
#  'doktor': 3,
#  'geç': 3,
#  'nereden': 3,
#  'hafta': 3,
#  'birini': 3,
#  'yemek': 3,
#  'bakın': 3,
#  'dışarı': 3,
#  'mutlu': 3,
#  'ondan': 3,
#  'eminim': 3,
#  'insan': 3,
#  'gördüm': 3,
#  'bazı': 3,
#  'polis': 3,
#  'yalnız': 3,
#  'gitti': 3,
#  'dikkat': 3,
#  'sakin': 3,
#  'etti': 3,
#  'musunuz': 3,
#  'çabuk': 3,
#  'beri': 3,
#  'merak': 3,
#  'yalan': 3,
#  'ihtiyacım': 3,
#  'insanlar': 3,
#  'gidiyor': 3,
#  'ayrıca': 3,
#  'değildi': 3,
#  'haber': 3,
#  'babam': 3,
#  'beş': 3,
#  'görüşürüz': 3,
#  'dün': 3,
#  'erkek': 3,
#  'umarım': 3,
#  'nefret': 3,
#  'etme': 3,
#  'yerine': 3,
#  'sanki': 3,
#  'öldü': 3,
#  'karar': 3,
#  'veya': 3,
#  'gördün': 3,
#  'değilsin': 3,
#  'aptal': 3,
#  'sabah': 3,
#  'yeter': 3,
#  'olmuş': 3,
#  'sence': 3,
#  'yaptım': 3,
#  'kes': 3,
#  'geçen': 3,
#  'ateş': 3,
#  'sonunda': 3,
#  'akşam': 3,
#  'kendine': 3,
#  'yap': 3,
#  'farklı': 3,
#  'birşey': 3,
#  'tarafından': 3,
#  'bunları': 3,
#  'olması': 2,
#  'kendimi': 2,
#  'boyunca': 2,
#  'su': 2,
#  'üzerinde': 2,
#  'dört': 2,
#  'olursa': 2,
#  'adı': 2,
#  'ettim': 2,
#  'fark': 2,
#  'olduğumu': 2,
#  'olamaz': 2,
#  'ay': 2,
#  'vardır': 2,
#  'dolar': 2,
#  'tamamen': 2,
#  'hangi': 2,
#  'açık': 2,
#  'yaptın': 2,
#  'oldukça': 2,
#  'yol': 2,
#  'adamı': 2,
#  'istediğim': 2,
#  'kal': 2,
#  'neyse': 2,
#  'yüzünden': 2,
#  'gelecek': 2,
#  'olsa': 2,
#  'bitti': 2,
#  'ancak': 2,
#  'olun': 2,
#  'başına': 2,
#  'söyledim': 2,
#  'yanında': 2,
#  'adım': 2,
#  'annem': 2,
#  'cevap': 2,
#  'kolay': 2,
#  'ise': 2,
#  'görünüyor': 2,
#  'aldım': 2,
#  'sahip': 2,
#  'dedi': 2,
#  'birisi': 2,
#  'öyleyse': 2,
#  'yolu': 2,
#  'henüz': 2,
#  'yoktu': 2,
#  'anlıyorum': 2,
#  'geldim': 2,
#  'beraber': 2,
#  'zamanı': 2,
#  'onların': 2,
#  'yapıyor': 2,
#  'durum': 2,
#  'olmadığını': 2,
#  'buldum': 2,
#  'gitmek': 2,
#  'konuşmak': 2,
#  'bazen': 2,
#  'adamın': 2,
#  'takip': 2,
#  'bende': 2,
#  'oldum': 2,
#  'sakın': 2,
#  'aç': 2,
#  'savaş': 2,
#  'dünya': 2,
#  'genç': 2,
#  'yardımcı': 2,
#  'eder': 2,
#  'yeniden': 2,
#  'almak': 2,
#  'hızlı': 2,
#  'içeri': 2,
#  'on': 2,
#  'neredeyse': 2,
#  'altında': 2,
#  'uzak': 2,
#  'hayatta': 2,
#  'yaptı': 2,
#  'saniye': 2,
#  'konusunda': 2,
#  'evde': 2,
#  'süre': 2,
#  'boş': 2,
#  'göz': 2,
#  'oğlum': 2,
#  'halde': 2,
#  'ara': 2,
#  'söylemek': 2,
#  'ciddi': 2,
#  'düşünüyorsun': 2,
#  'azından': 2,
#  'sanmıyorum': 2,
#  'duydum': 2,
#  'mükemmel': 2,
#  'kaldı': 2,
#  'güçlü': 2,
#  'işin': 2,
#  'şeyin': 2,
#  'galiba': 2,
#  'miyiz': 2,
#  'gelen': 2,
#  'konuda': 2,
#  'istedim': 2,
#  'kan': 2,
#  'günü': 2,
#  'düşündüm': 2,
#  'tabi': 2,
#  'çıktı': 2,
#  'hepimiz': 2,
#  'bin': 2,
#  'herhangi': 2,
#  'ev': 2,
#  'muhtemelen': 2,
#  'yakın': 2,
#  'söylüyor': 2,
#  'silah': 2,
#  'düşünüyorum': 2,
#  'rahat': 2,
#  'hayatım': 2,
#  'anladım': 2,
#  'gidiyorum': 2,
#  'kimin': 2,
#  'alo': 2,
#  'hayal': 2,
#  'araba': 2,
#  'çocuğu': 2,
#  'hava': 2,
#  'bebeğim': 2,
#  'dersin': 2,
#  'arada': 2,
#  'evlat': 2,
#  'olacağım': 2,
#  'çalışıyorum': 2,
#  'acele': 2,
#  'olduğuna': 2,
#  'hareket': 2,
#  'kesin': 2,
#  'sürü': 2,
#  'şeye': 2,
#  'garip': 2,
#  'başladı': 2,
#  'durumda': 2,
#  'altı': 2,
#  'adamım': 2,
#  'verdi': 2,
#  'herif': 2,
#  'hayat': 2,
#  'geldin': 2,
#  'ortaya': 2,
#  'sende': 2,
#  'çalışıyor': 2,
#  'gelip': 2,
#  'acaba': 2,
#  'yaptığını': 2,
#  'kapıyı': 2,
#  'oyun': 2,
#  'hatta': 2,
#  'kardeşim': 2,
#  'şuna': 2,
#  'gidiyoruz': 2,
#  'soru': 2,
#  'canım': 2,
#  'arasında': 2,
#  'komik': 2,
#  'verin': 2,
#  'bilirsin': 2,
#  'gizli': 2,
#  'el': 2,
#  'durun': 2,
#  'varsa': 2,
#  'hepsini': 2,
#  'terk': 2,
#  'zarar': 2,
#  'böylece': 2,
#  'gelir': 2,
#  'şeyleri': 2,
#  'beyler': 2,
#  'yeterince': 2,
#  'olmadan': 2,
#  'olacağını': 2,
#  'kısa': 2,
#  'üzerine': 1,
#  'ihtiyacı': 1,
#  'haklısın': 1,
#  'diyorsun': 1,
#  'birinin': 1,
#  'yapacağım': 1,
#  'geçti': 1,
#  'ait': 1,
#  'yolunda': 1,
#  'telefon': 1,
#  'şaka': 1,
#  'kızı': 1,
#  'günaydın': 1,
#  'bebek': 1,
#  'olay': 1,
#  'sanıyorsun': 1,
#  'etmeye': 1,
#  'arkadaşım': 1,
#  'sürekli': 1,
#  'olmayacak': 1,
#  'gelin': 1,
#  'baban': 1,
#  'çeviri': 1,
#  'uygun': 1,
#  'çıkar': 1,
#  'verdim': 1,
#  'aynen': 1,
#  'nasılsın': 1,
#  'dans': 1,
#  'beyaz': 1,
#  'gidiyorsun': 1,
#  'memnun': 1,
#  'dünyanın': 1,
#  'dışında': 1,
#  'geceler': 1,
#  'ölüm': 1,
#  'tuhaf': 1,
#  'zamanda': 1,
#  'yüksek': 1,
#  'korkunç': 1,
#  'tür': 1,
#  'yaşlı': 1,
#  'yakında': 1,
#  'veriyorum': 1,
#  'değildir': 1,
#  'edecek': 1,
#  'olmadı': 1,
#  'bırakın': 1,
#  'dolu': 1,
#  'iyiyim': 1,
#  'aldı': 1,
#  'eden': 1,
#  'fikir': 1,
#  'mısınız': 1,
#  'anladın': 1,
#  'olurdu': 1,
#  'neyi': 1,
#  'sevindim': 1,
#  'sensin': 1,
#  'bilmek': 1,
#  'neydi': 1,
#  'rahatsız': 1,
#  'mümkün': 1,
#  'kere': 1,
#  'sanıyordum': 1,
#  'parayı': 1,
#  'acı': 1,
#  'yalnızca': 1,
#  'hissediyorum': 1,
#  'dedin': 1,
#  'tahmin': 1,
#  'ediyorsun': 1,
#  'üzere': 1,
#  'yapamam': 1,
#  'içine': 1,
#  'gerektiğini': 1,
#  'yapacağız': 1,
#  'dikkatli': 1,
#  'geliyorum': 1,
#  'neyin': 1,
#  'kapa': 1,
#  'bizimle': 1,
#  'şöyle': 1,
#  'biliyordum': 1,
#  'milyon': 1,
#  'varmış': 1,
#  'başkan': 1,
#  'sizinle': 1,
#  'ölü': 1,
#  'ihtiyacımız': 1,
#  'güvenlik': 1,
#  'çık': 1,
#  'belli': 1,
#  'vermek': 1,
#  'aşağı': 1,
#  'affedersiniz': 1,
#  'yapacak': 1,
#  'yapmaya': 1,
#  'yemin': 1,
#  'dön': 1,
#  'otur': 1,
#  'ihtiyacın': 1,
#  'oradan': 1,
#  'anlaşıldı': 1,
#  'dek': 1,
#  'kaptan': 1,
#  'at': 1,
#  'deli': 1,
#  'ana': 1,
#  'çek': 1,
#  'annen': 1,
#  'olmayan': 1,
#  'dışarıda': 1,
#  'hasta': 1,
#  'birine': 1,
#  'sefer': 1,
#  'berbat': 1,
#  'istedi': 1,
#  'yapıyorum': 1,
#  'baş': 1,
#  'diyorum': 1,
#  'normal': 1,
#  'olup': 1,
#  'şans': 1,
#  'ettin': 1,
#  'istediğini': 1,
#  'insanların': 1,
#  'güç': 1,
#  'tatlı': 1,
#  'dair': 1,
#  'keşke': 1,
#  'getir': 1,
#  'gidin': 1,
#  'herkesin': 1,
#  'söyledin': 1,
#  'yukarı': 1,
#  'yavaş': 1,
#  'evine': 1,
#  'tehlikeli': 1,
#  'bilmem': 1,
#  'yeri': 1,
#  'pardon': 1,
#  'hayatını': 1,
#  'yapar': 1,
#  'ele': 1,
#  'istersen': 1,
#  'durumu': 1,
#  'hata': 1,
#  'kendisi': 1,
#  'aşk': 1,
#  'sessiz': 1,
#  'üstüne': 1,
#  'biliyoruz': 1,
#  'miydi': 1,
#  'duydun': 1,
#  'önünde': 1,
#  'hoşça': 1,
#  'yeterli': 1,
#  'aile': 1,
#  'bununla': 1,
#  'millet': 1,
#  'yüz': 1,
#  'zamandır': 1,
#  'isterim': 1,
#  'bayım': 1,
#  'asıl': 1,
#  'alıp': 1,
#  'buradayım': 1,
#  'nefes': 1,
#  'kahve': 1,
#  'basit': 1,
#  'diyor': 1,
#  'bakma': 1,
#  'bilgi': 1,
#  'kusura': 1,
#  'bunların': 1,
#  'tut': 1,
#  'görüyorum': 1,
#  'sıcak': 1,
#  'koca': 1,
#  'neye': 1,
#  'bilmiyor': 1,
#  'ufak': 1,
#  'kızlar': 1,
#  'hak': 1,
#  'edeceğim': 1,
#  'mıydı': 1,
#  'aldın': 1,
#  'arkadaş': 1,
#  'yaşında': 1,
#  'benziyor': 1,
#  'yapacaksın': 1,
#  'adını': 1,
#  'tıpkı': 1,
#  'yedi': 1,
#  'sonraki': 1,
#  'olacaksın': 1,
#  'herhalde': 1,
#  'gelmiş': 1,
#  'yıldır': 1,
#  'kızım': 1,
#  'vakit': 1,
#  'olduğun': 1,
#  'alın': 1,
#  'kimsenin': 1,
#  'doğum': 1,
#  'birçok': 1,
#  'dalga': 1,
#  'erken': 1,
#  'haklı': 1,
#  'görünüyorsun': 1,
#  'olmalısın': 1,
#  'olsaydı': 1,
#  'düşünüyor': 1,
#  'olmasını': 1,
#  'olduğum': 1,
#  'köpek': 1,
#  'temiz': 1,
#  'adına': 1,
#  'işler': 1,
#  'olası': 1,
#  'sesini': 1,
#  'görüyor': 1,
#  'cidden': 1,
#  'söylüyorum': 1,
#  'ajan': 1,
#  'fena': 1,
#  'bulmak': 1,
#  'almaya': 1,
#  'mesaj': 1,
#  'yerinde': 1,
#  'kızın': 1,
#  'buldun': 1,
#  'insanları': 1,
#  'gayet': 1,
#  'anlamıyorum': 1,
#  'söylemiştim': 1,
#  'düşün': 1,
#  'ikinci': 1,
#  'öldürmek': 1,
#  'yapmam': 1,
#  'şarkı': 1,
#  'istediğin': 1,
#  'yoktur': 1,
#  'bilir': 1,
#  'gitmem': 1,
#  'konu': 1,
#  'yerini': 1,
#  'inanamıyorum': 1,
#  'birden': 1,
#  'hatırlıyor': 1,
#  'muhteşem': 1,
#  'sağol': 1,
#  'zamanlar': 1,
#  'sayın': 1,
#  'acil': 1,
#  'çekil': 1,
#  'kimsin': 1,
#  'güvenli': 1,
#  'yaparım': 1,
#  'bilmiyordum': 1,
#  'evi': 1,
#  'bekliyor': 1,
#  'kalk': 1,
#  'yanına': 1,
#  'buradaki': 1,
#  'canlı': 1,
#  'cinayet': 1,
#  'sevgili': 1,
#  'zavallı': 1,
#  'geldiniz': 1,
#  'rağmen': 1,
#  'teslim': 1,
#  'yapalım': 1,
#  'üstünde': 1,
#  'istiyorsan': 1,
#  'alabilir': 1,
#  'söylüyorsun': 1,
#  'görünüşe': 1,
#  'söyleme': 1,
#  'kırmızı': 1,
#  'gerçeği': 1,
#  'geldik': 1,
#  'içki': 1,
#  'yürü': 1,
#  'numara': 1,
#  'olmaya': 1,
#  'sonsuza': 1,
#  'adamlar': 1,
#  'unutma': 1,
#  'baksana': 1,
#  'konuşma': 1,
#  'arkadaşın': 1,
#  'kimseye': 1,
#  'film': 1,
#  'işim': 1,
#  'özellikle': 1,
#  'sebep': 1,
#  'yaptığı': 1,
#  'şeyden': 1,
#  'defa': 1,
#  'bizden': 1,
#  'uyuşturucu': 1,
#  'bağlı': 1,
#  'işini': 1,
#  'onlardan': 1,
#  'gerekir': 1,
#  'değiliz': 1,
#  'suç': 1,
#  'sebebi': 1,
#  'çoktan': 1,
#  'bilemiyorum': 1,
#  'olduğundan': 1,
#  'parçası': 1,
#  'sıkı': 1,
#  'pislik': 1,
#  'sonu': 1,
#  'herşey': 1,
#  'tercih': 1,
#  'alacağım': 1,
#  'babası': 1,
#  'biriyle': 1,
#  'umurumda': 1,
#  'patron': 1,
#  'verir': 1,
#  'bahsediyorsun': 1,
#  'saçma': 1,
#  'soğuk': 1,
#  'oda': 1,
#  'elinde': 1,
#  'kalan': 1,
#  'parti': 1,
#  'sıra': 1,
#  'kayıp': 1,
#  'eskiden': 1,
#  'eğlenceli': 1,
#  'yapan': 1,
#  'yaşıyor': 1,
#  'burayı': 1,
#  'anlat': 1,
#  'bekleyin': 1,
#  'ölmüş': 1,
#  'onlarla': 1,
#  'babamın': 1,
#  'çoğu': 1,
#  'yemeği': 1,
#  'burda': 1,
#  'dedektif': 1,
#  'yaptığın': 1,
#  'günler': 1,
#  'gerekiyordu': 1,
#  'olma': 1,
#  'dürüst': 1,
#  'yapabilirim': 1,
#  'çocukları': 1,
#  'anlıyor': 1,
#  'seviyor': 1,
#  'dolayı': 1,
#  'yola': 1,
#  'dünyada': 1,
#  'şehir': 1,
#  'tanıyor': 1,
#  'sert': 1,
#  'çalışıyorsun': 1,
#  'olmasın': 1,
#  'iyisi': 1,
#  'bulduk': 1,
#  'aşkına': 1,
#  'teklif': 1,
#  'anlamı': 1,
#  'silahı': 1,
#  'göster': 1,
#  'alır': 1,
#  'bakayım': 1,
#  'alan': 1,
#  'gitsin': 1,
#  'orası': 1,
#  'istemiyor': 1,
#  'istiyoruz': 1,
#  'ağır': 1,
#  'adama': 1,
#  'tamamdır': 1,
#  'tarafa': 1,
#  'affedersin': 1,
#  'altına': 1,
#  'görmedim': 1,
#  'hanımefendi': 1,
#  'takım': 1,
#  'kalın': 1,
#  'kara': 1,
#  'söyleyeyim': 1,
#  'geldiğini': 1,
#  'demektir': 1,
#  'edebilir': 1,
#  'canına': 1,
#  'arkadaşı': 1,
#  'kendim': 1,
#  'sene': 1,
#  'davet': 1,
#  'taraftan': 1,
#  'kalmak': 1,
#  'görmeye': 1,
#  'anlaşma': 1,
#  'yapmış': 1,
#  'hepiniz': 1,
#  'aşık': 1,
#  'vereceğim': 1,
#  'zorundayım': 1,
#  'süper': 1,
#  'yarım': 1,
#  'sahibi': 1,
#  'kapı': 1,
#  'çocuğun': 1,
#  'fikrim': 1,
#  'duyuyor': 1,
#  'müzik': 1,
#  'aferin': 1,
#  'gurur': 1,
#  'gelmek': 1,
#  'öğrenmek': 1,
#  'kendime': 1,
#  'hatırlıyorum': 1,
#  'iç': 1,
#  'vakti': 1,
#  'herkese': 1,
#  'sona': 1,
#  'yazık': 1,
#  'serbest': 1,
#  'bayanlar': 1,
#  'yaptığım': 1,
#  'siyah': 1,
#  'şimdiye': 1,
#  'istiyorsunuz': 1,
#  'herşeyi': 1,
#  'görev': 1,
#  'getirdim': 1,
#  'dinleyin': 1,
#  'hale': 1,
#  'kavga': 1,
#  'arabayı': 1,
#  'oldun': 1,
#  'bölüm': 1,
#  'sık': 1,
#  'arka': 1,
#  'hoşuma': 1,
#  'üçüncü': 1,
#  'sırada': 1,
#  'gidecek': 1,
#  'karanlık': 1,
#  'verici': 1,
#  'dava': 1,
#  'sekiz': 1,
#  'çekilin': 1,
#  'olayı': 1,
#  'anlamına': 1,
#  'dua': 1,
#  'istemedim': 1,
#  'herkesi': 1,
#  'gider': 1,
#  'başıma': 1,
#  'konuş': 1,
#  'kitap': 1,
#  'güneş': 1,
#  'bul': 1,
#  'edeyim': 1,
#  'önceki': 1,
#  'ifade': 1,
#  'resmi': 1,
#  'veriyor': 1,
#  'okul': 1,
#  'suçlu': 1,
#  'mesela': 1}

# %% [markdown]
# ##### Check Word From Picture Word

# %%
image_path_folder = f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Image Audio Video/Data/1000 Words/Genome_Picture_In_Picture_Select_Rename"

# %%
file_list = os.listdir(f"{image_path_folder}")
file_list
# Out:
# ['bir.jpg',
#  'biraz.jpg',
#  'biri.jpg',
#  'birlikte.jpg',
#  'birini.jpg',
#  'birisi.jpg',
#  'birinin.jpg',
#  'birine.jpg',
#  'birden.jpg',
#  'biriyle.jpg',
#  'bu.jpg',
#  'bunu.jpg',
#  'bunun.jpg',
#  'buna.jpg',
#  'bunlar.jpg',
#  'bundan.jpg',
#  'bunları.jpg',
#  'bununla.jpg',
#  'bunların.jpg',
#  'ne.jpg',
#  'neler.jpg',
#  'nedir.jpg',
#  'neyi.jpg',
#  'neydi.jpg',
#  'neyin.jpg',
#  'neye.jpg',
#  've.jpg',
#  'için.jpg',
#  'içinde.jpg',
#  'içine.jpg',
#  'mi.jpg',
#  'misin.jpg',
#  'miyim.jpg',
#  'misiniz.jpg',
#  'miyiz.jpg',
#  'miydi.jpg',
#  'o.jpg',
#  'onu.jpg',
#  'ona.jpg',
#  'onun.jpg',
#  'onları.jpg',
#  'onlar.jpg',
#  'onunla.jpg',
#  'onlara.jpg',
#  'ondan.jpg',
#  'onların.jpg',
#  'onlardan.jpg',
#  'onlarla.jpg',
#  'ben.jpg',
#  'beni.jpg',
#  'benim.jpg',
#  'benimle.jpg',
#  'bence.jpg',
#  'benden.jpg',
#  'bende.jpg',
#  'de.jpg',
#  'demek.jpg',
#  'dedim.jpg',
#  'dedi.jpg',
#  'dersin.jpg',
#  'dedin.jpg',
#  'demektir.jpg',
#  'çok.jpg',
#  'çoktan.jpg',
#  'ama.jpg',
#  'var.jpg',
#  'vardı.jpg',
#  'vardır.jpg',
#  'varsa.jpg',
#  'varmış.jpg',
#  'evet.jpg',
#  'mı.jpg',
#  'mısın.jpg',
#  'mısınız.jpg',
#  'mıydı.jpg',
#  'değil.jpg',
#  'değilim.jpg',
#  'değildi.jpg',
#  'değilsin.jpg',
#  'değildir.jpg',
#  'değiliz.jpg',
#  'da.jpg',
#  'şey.jpg',
#  'şeyi.jpg',
#  'şeyler.jpg',
#  'şeyin.jpg',
#  'şeye.jpg',
#  'şeyleri.jpg',
#  'şeyden.jpg',
#  'hayır.jpg',
#  'daha.jpg',
#  'sen.jpg',
#  'seni.jpg',
#  'senin.jpg',
#  'seninle.jpg',
#  'senden.jpg',
#  'sence.jpg',
#  'sende.jpg',
#  'sensin.jpg',
#  'kadar.jpg',
#  'bana.jpg',
#  'yok.jpg',
#  'yoksa.jpg',
#  'yoktu.jpg',
#  'yoktur.jpg',
#  'gibi.jpg',
#  'iyi.jpg',
#  'iyiyim.jpg',
#  'iyisi.jpg',
#  'tamam.jpg',
#  'tamamen.jpg',
#  'tamamdır.jpg',
#  'her.jpg',
#  'sana.jpg',
#  'ki.jpg',
#  'neden.jpg',
#  'zaman.jpg',
#  'zamanı.jpg',
#  'zamanda.jpg',
#  'zamandır.jpg',
#  'zamanlar.jpg',
#  'sadece.jpg',
#  'burada.jpg',
#  'buradan.jpg',
#  'buradayım.jpg',
#  'buradaki.jpg',
#  'nasıl.jpg',
#  'nasılsın.jpg',
#  'olduğunu.jpg',
#  'hiç.jpg',
#  'sonra.jpg',
#  'sonraki.jpg',
#  'şimdi.jpg',
#  'şimdiye.jpg',
#  'en.jpg',
#  'ya.jpg',
#  'öyle.jpg',
#  'öyleyse.jpg',
#  'mu.jpg',
#  'musun.jpg',
#  'musunuz.jpg',
#  'şu.jpg',
#  'şunu.jpg',
#  'şuna.jpg',
#  'hadi.jpg',
#  'önce.jpg',
#  'önceki.jpg',
#  'güzel.jpg',
#  'oldu.jpg',
#  'olduğu.jpg',
#  'olduğumu.jpg',
#  'oldukça.jpg',
#  'oldum.jpg',
#  'olduğuna.jpg',
#  'olduğun.jpg',
#  'olduğum.jpg',
#  'olduğundan.jpg',
#  'oldun.jpg',
#  'böyle.jpg',
#  'böylece.jpg',
#  'lütfen.jpg',
#  'bile.jpg',
#  'bilemiyorum.jpg',
#  'yani.jpg',
#  'artık.jpg',
#  'geri.jpg',
#  'bak.jpg',
#  'bakalım.jpg',
#  'bakın.jpg',
#  'bakma.jpg',
#  'baksana.jpg',
#  'bakayım.jpg',
#  'istiyorum.jpg',
#  'peki.jpg',
#  'eğer.jpg',
#  'çünkü.jpg',
#  'biliyorum.jpg',
#  'gerçekten.jpg',
#  'başka.jpg',
#  'tek.jpg',
#  'olarak.jpg',
#  'belki.jpg',
#  'doğru.jpg',
#  'büyük.jpg',
#  'buraya.jpg',
#  'olan.jpg',
#  'olur.jpg',
#  'olursa.jpg',
#  'olurdu.jpg',
#  'adam.jpg',
#  'adamı.jpg',
#  'adamın.jpg',
#  'adamım.jpg',
#  'adamlar.jpg',
#  'adama.jpg',
#  'hey.jpg',
#  'olacak.jpg',
#  'olacaksın.jpg',
#  'hiçbir.jpg',
#  'efendim.jpg',
#  'yardım.jpg',
#  'yardımcı.jpg',
#  'biz.jpg',
#  'bize.jpg',
#  'bizi.jpg',
#  'bizim.jpg',
#  'bizimle.jpg',
#  'bizden.jpg',
#  'ile.jpg',
#  'nerede.jpg',
#  'nereden.jpg',
#  'neredeyse.jpg',
#  'sanırım.jpg',
#  'tüm.jpg',
#  'orada.jpg',
#  'oradan.jpg',
#  'bilmiyorum.jpg',
#  'gün.jpg',
#  'günü.jpg',
#  'günler.jpg',
#  'fazla.jpg',
#  'ederim.jpg',
#  'teşekkürler.jpg',
#  'yeni.jpg',
#  'yeniden.jpg',
#  'son.jpg',
#  'sonunda.jpg',
#  'sonsuza.jpg',
#  'sonu.jpg',
#  'sona.jpg',
#  'et.jpg',
#  'etmek.jpg',
#  'etti.jpg',
#  'etme.jpg',
#  'ettim.jpg',
#  'etmeye.jpg',
#  'ettin.jpg',
#  'merhaba.jpg',
#  'kötü.jpg',
#  'gece.jpg',
#  'geceler.jpg',
#  'işte.jpg',
#  'biliyor.jpg',
#  'biliyorsun.jpg',
#  'biliyordum.jpg',
#  'biliyoruz.jpg',
#  'iki.jpg',
#  'ikinci.jpg',
#  'sorun.jpg',
#  'tam.jpg',
#  'bütün.jpg',
#  'hemen.jpg',
#  'harika.jpg',
#  'olsun.jpg',
#  'gerek.jpg',
#  'gerekiyor.jpg',
#  'gereken.jpg',
#  'gerektiğini.jpg',
#  'gerekir.jpg',
#  'gerekiyordu.jpg',
#  'ol.jpg',
#  'olabilir.jpg',
#  'oluyor.jpg',
#  'olmak.jpg',
#  'olmaz.jpg',
#  'olmalı.jpg',
#  'olmuş.jpg',
#  'olması.jpg',
#  'olamaz.jpg',
#  'olsa.jpg',
#  'olun.jpg',
#  'olmadığını.jpg',
#  'olacağım.jpg',
#  'olmadan.jpg',
#  'olacağını.jpg',
#  'olmayacak.jpg',
#  'olmadı.jpg',
#  'olmayan.jpg',
#  'olup.jpg',
#  'olmalısın.jpg',
#  'olsaydı.jpg',
#  'olmasını.jpg',
#  'olası.jpg',
#  'olmaya.jpg',
#  'olma.jpg',
#  'olmasın.jpg',
#  'siz.jpg',
#  'size.jpg',
#  'sizi.jpg',
#  'sizin.jpg',
#  'sizinle.jpg',
#  'üzgünüm.jpg',
#  'diye.jpg',
#  'gel.jpg',
#  'geldi.jpg',
#  'geliyor.jpg',
#  'gelecek.jpg',
#  'geldim.jpg',
#  'gelen.jpg',
#  'geldin.jpg',
#  'gelip.jpg',
#  'geliyorum.jpg',
#  'gelmiş.jpg',
#  'geldiniz.jpg',
#  'geldik.jpg',
#  'geldiğini.jpg',
#  'gelmek.jpg',
#  'küçük.jpg',
#  'teşekkür.jpg',
#  'devam.jpg',
#  'tabii.jpg',
#  'aynı.jpg',
#  'ver.jpg',
#  'verdi.jpg',
#  'verin.jpg',
#  'verdim.jpg',
#  'veriyorum.jpg',
#  'vermek.jpg',
#  'verir.jpg',
#  'vereceğim.jpg',
#  'verici.jpg',
#  'veriyor.jpg',
#  'yüzden.jpg',
#  'kendi.jpg',
#  'kendini.jpg',
#  'kendine.jpg',
#  'kendimi.jpg',
#  'kendisi.jpg',
#  'kendim.jpg',
#  'kendime.jpg',
#  'hakkında.jpg',
#  'haydi.jpg',
#  'kız.jpg',
#  'kızı.jpg',
#  'kızlar.jpg',
#  'kızım.jpg',
#  'kızın.jpg',
#  'izin.jpg',
#  'iş.jpg',
#  'işe.jpg',
#  'işi.jpg',
#  'işin.jpg',
#  'işler.jpg',
#  'işim.jpg',
#  'işini.jpg',
#  'dur.jpg',
#  'durum.jpg',
#  'durumda.jpg',
#  'durun.jpg',
#  'durumu.jpg',
#  'git.jpg',
#  'gitti.jpg',
#  'gitmek.jpg',
#  'gitmem.jpg',
#  'gitsin.jpg',
#  'kimse.jpg',
#  'kimsenin.jpg',
#  'kimseye.jpg',
#  'asla.jpg',
#  'göre.jpg',
#  'önemli.jpg',
#  'baba.jpg',
#  'babam.jpg',
#  'baban.jpg',
#  'babası.jpg',
#  'babamın.jpg',
#  'tekrar.jpg',
#  'söyle.jpg',
#  'söyledi.jpg',
#  'söyledim.jpg',
#  'söylemek.jpg',
#  'söyledin.jpg',
#  'söylemiştim.jpg',
#  'söyleme.jpg',
#  'söyleyeyim.jpg',
#  'özür.jpg',
#  'mü.jpg',
#  'dostum.jpg',
#  'selam.jpg',
#  'yine.jpg',
#  'hala.jpg',
#  'anne.jpg',
#  'annem.jpg',
#  'annen.jpg',
#  'al.jpg',
#  'aldım.jpg',
#  'almak.jpg',
#  'aldı.jpg',
#  'alıp.jpg',
#  'aldın.jpg',
#  'alın.jpg',
#  'almaya.jpg',
#  'alabilir.jpg',
#  'alacağım.jpg',
#  'alır.jpg',
#  'bugün.jpg',
#  'üç.jpg',
#  'üçüncü.jpg',
#  'uzun.jpg',
#  'herkes.jpg',
#  'herkesin.jpg',
#  'herkese.jpg',
#  'herkesi.jpg',
#  'aslında.jpg',
#  'dakika.jpg',
#  'para.jpg',
#  'parayı.jpg',
#  'şekilde.jpg',
#  'gerçek.jpg',
#  'pekala.jpg',
#  'istiyorsun.jpg',
#  'istiyorsunuz.jpg',
#  'birkaç.jpg',
#  'zaten.jpg',
#  'ilk.jpg',
#  'lazım.jpg',
#  'saat.jpg',
#  'yapıyorsun.jpg',
#  'ister.jpg',
#  'istersen.jpg',
#  'isterim.jpg',
#  'bay.jpg',
#  'bayım.jpg',
#  'bayan.jpg',
#  'bayanlar.jpg',
#  'emin.jpg',
#  'eminim.jpg',
#  'pek.jpg',
#  'gidelim.jpg',
#  'bırak.jpg',
#  'bırakın.jpg',
#  'yer.jpg',
#  'yere.jpg',
#  'yerde.jpg',
#  'yerine.jpg',
#  'yeri.jpg',
#  'yerinde.jpg',
#  'yerini.jpg',
#  'hep.jpg',
#  'hepsi.jpg',
#  'hepimiz.jpg',
#  'hepsini.jpg',
#  'hepiniz.jpg',
#  'yıl.jpg',
#  'yıldır.jpg',
#  'çocuk.jpg',
#  'çocuklar.jpg',
#  'çocukları.jpg',
#  'eve.jpg',
#  'bekle.jpg',
#  'bekleyin.jpg',
#  'nereye.jpg',
#  'burası.jpg',
#  'dilerim.jpg',
#  'karşı.jpg',
#  'hazır.jpg',
#  'an.jpg',
#  'anda.jpg',
#  'kaç.jpg',
#  'istemiyorum.jpg',
#  'az.jpg',
#  'azından.jpg',
#  'ilgili.jpg',
#  'söz.jpg',
#  'ediyorum.jpg',
#  'eski.jpg',
#  'eskiden.jpg',
#  'dinle.jpg',
#  'dinleyin.jpg',
#  'tane.jpg',
#  'fakat.jpg',
#  'zor.jpg',
#  'zorunda.jpg',
#  'zorundayım.jpg',
#  'kesinlikle.jpg',
#  'yapmak.jpg',
#  'kişi.jpg',
#  'kadın.jpg',
#  'görmek.jpg',
#  'istiyor.jpg',
#  'istiyorsan.jpg',
#  'istiyoruz.jpg',
#  'diğer.jpg',
#  'sağ.jpg',
#  'kabul.jpg',
#  'seviyorum.jpg',
#  'niye.jpg',
#  'aman.jpg',
#  'elbette.jpg',
#  'kez.jpg',
#  'yarın.jpg',
#  'yapma.jpg',
#  'yapmaya.jpg',
#  'yapmam.jpg',
#  'edin.jpg',
#  'hem.jpg',
#  'falan.jpg',
#  'oraya.jpg',
#  'hoş.jpg',
#  'hoşça.jpg',
#  'hoşuma.jpg',
#  'gidip.jpg',
#  'yanlış.jpg',
#  'kontrol.jpg',
#  'özel.jpg',
#  'özellikle.jpg',
#  'ediyor.jpg',
#  'ediyorsun.jpg',
#  'tatlım.jpg',
#  'doktor.jpg',
#  'geç.jpg',
#  'geçen.jpg',
#  'geçti.jpg',
#  'hafta.jpg',
#  'yemek.jpg',
#  'dışarı.jpg',
#  'dışarıda.jpg',
#  'mutlu.jpg',
#  'insan.jpg',
#  'insanlar.jpg',
#  'insanların.jpg',
#  'insanları.jpg',
#  'gördüm.jpg',
#  'bazı.jpg',
#  'polis.jpg',
#  'yalnız.jpg',
#  'yalnızca.jpg',
#  'dikkat.jpg',
#  'dikkatli.jpg',
#  'sakin.jpg',
#  'çabuk.jpg',
#  'beri.jpg',
#  'merak.jpg',
#  'yalan.jpg',
#  'ihtiyacım.jpg',
#  'ihtiyacımız.jpg',
#  'gidiyor.jpg',
#  'gidiyorum.jpg',
#  'gidiyoruz.jpg',
#  'gidiyorsun.jpg',
#  'ayrıca.jpg',
#  'haber.jpg',
#  'beş.jpg',
#  'görüşürüz.jpg',
#  'dün.jpg',
#  'erkek.jpg',
#  'umarım.jpg',
#  'nefret.jpg',
#  'sanki.jpg',
#  'öldü.jpg',
#  'öldürmek.jpg',
#  'karar.jpg',
#  'veya.jpg',
#  'gördün.jpg',
#  'aptal.jpg',
#  'sabah.jpg',
#  'yeter.jpg',
#  'yeterince.jpg',
#  'yeterli.jpg',
#  'yaptım.jpg',
#  'kes.jpg',
#  'ateş.jpg',
#  'akşam.jpg',
#  'yap.jpg',
#  'yaptın.jpg',
#  'yapıyor.jpg',
#  'yaptı.jpg',
#  'yaptığını.jpg',
#  'yapacağım.jpg',
#  'yapamam.jpg',
#  'yapacağız.jpg',
#  'yapacak.jpg',
#  'yapıyorum.jpg',
#  'yapar.jpg',
#  'yapacaksın.jpg',
#  'yaparım.jpg',
#  'yapalım.jpg',
#  'yaptığı.jpg',
#  'yapan.jpg',
#  'yaptığın.jpg',
#  'yapabilirim.jpg',
#  'yapmış.jpg',
#  'yaptığım.jpg',
#  'farklı.jpg',
#  'birşey.jpg',
#  'tarafından.jpg',
#  'boyunca.jpg',
#  'su.jpg',
#  'üzerinde.jpg',
#  'dört.jpg',
#  'adı.jpg',
#  'adını.jpg',
#  'adına.jpg',
#  'fark.jpg',
#  'ay.jpg',
#  'dolar.jpg',
#  'hangi.jpg',
#  'açık.jpg',
#  'yol.jpg',
#  'yolu.jpg',
#  'yolunda.jpg',
#  'yola.jpg',
#  'istediğim.jpg',
#  'kal.jpg',
#  'kaldı.jpg',
#  'kalan.jpg',
#  'kalmak.jpg',
#  'neyse.jpg',
#  'yüzünden.jpg',
#  'bitti.jpg',
#  'ancak.jpg',
#  'başına.jpg',
#  'yanında.jpg',
#  'adım.jpg',
#  'cevap.jpg',
#  'kolay.jpg',
#  'ise.jpg',
#  'görünüyor.jpg',
#  'görünüyorsun.jpg',
#  'sahip.jpg',
#  'henüz.jpg',
#  'anlıyorum.jpg',
#  'beraber.jpg',
#  'buldum.jpg',
#  'konuşmak.jpg',
#  'bazen.jpg',
#  'takip.jpg',
#  'sakın.jpg',
#  'aç.jpg',
#  'savaş.jpg',
#  'dünya.jpg',
#  'dünyanın.jpg',
#  'dünyada.jpg',
#  'genç.jpg',
#  'eder.jpg',
#  'hızlı.jpg',
#  'içeri.jpg',
#  'on.jpg',
#  'altında.jpg',
#  'uzak.jpg',
#  'hayatta.jpg',
#  'saniye.jpg',
#  'konusunda.jpg',
#  'evde.jpg',
#  'süre.jpg',
#  'sürekli.jpg',
#  'boş.jpg',
#  'göz.jpg',
#  'oğlum.jpg',
#  'halde.jpg',
#  'ara.jpg',
#  'arada.jpg',
#  'arasında.jpg',
#  'ciddi.jpg',
#  'düşünüyorsun.jpg',
#  'sanmıyorum.jpg',
#  'duydum.jpg',
#  'mükemmel.jpg',
#  'güçlü.jpg',
#  'galiba.jpg',
#  'konuda.jpg',
#  'istedim.jpg',
#  'kan.jpg',
#  'düşündüm.jpg',
#  'tabi.jpg',
#  'çıktı.jpg',
#  'bin.jpg',
#  'herhangi.jpg',
#  'ev.jpg',
#  'evine.jpg',
#  'evi.jpg',
#  'muhtemelen.jpg',
#  'yakın.jpg',
#  'yakında.jpg',
#  'söylüyor.jpg',
#  'söylüyorum.jpg',
#  'söylüyorsun.jpg',
#  'silah.jpg',
#  'silahı.jpg',
#  'düşünüyorum.jpg',
#  'rahat.jpg',
#  'rahatsız.jpg',
#  'hayatım.jpg',
#  'anladım.jpg',
#  'kimin.jpg',
#  'alo.jpg',
#  'hayal.jpg',
#  'araba.jpg',
#  'arabayı.jpg',
#  'çocuğu.jpg',
#  'çocuğun.jpg',
#  'hava.jpg',
#  'bebeğim.jpg',
#  'evlat.jpg',
#  'çalışıyorum.jpg',
#  'acele.jpg',
#  'hareket.jpg',
#  'kesin.jpg',
#  'sürü.jpg',
#  'garip.jpg',
#  'başladı.jpg',
#  'altı.jpg',
#  'altına.jpg',
#  'herif.jpg',
#  'hayat.jpg',
#  'hayatını.jpg',
#  'ortaya.jpg',
#  'çalışıyor.jpg',
#  'çalışıyorsun.jpg',
#  'acaba.jpg',
#  'kapıyı.jpg',
#  'oyun.jpg',
#  'hatta.jpg',
#  'kardeşim.jpg',
#  'soru.jpg',
#  'canım.jpg',
#  'komik.jpg',
#  'bilirsin.jpg',
#  'gizli.jpg',
#  'el.jpg',
#  'ele.jpg',
#  'elinde.jpg',
#  'terk.jpg',
#  'zarar.jpg',
#  'gelir.jpg',
#  'beyler.jpg',
#  'kısa.jpg',
#  'üzerine.jpg',
#  'ihtiyacı.jpg',
#  'ihtiyacın.jpg',
#  'haklısın.jpg',
#  'diyorsun.jpg',
#  'ait.jpg',
#  'telefon.jpg',
#  'şaka.jpg',
#  'günaydın.jpg',
#  'bebek.jpg',
#  'olay.jpg',
#  'olayı.jpg',
#  'sanıyorsun.jpg',
#  'arkadaşım.jpg',
#  'gelin.jpg',
#  'çeviri.jpg',
#  'uygun.jpg',
#  'çıkar.jpg',
#  'aynen.jpg',
#  'dans.jpg',
#  'beyaz.jpg',
#  'memnun.jpg',
#  'dışında.jpg',
#  'ölüm.jpg',
#  'tuhaf.jpg',
#  'yüksek.jpg',
#  'korkunç.jpg',
#  'tür.jpg',
#  'yaşlı.jpg',
#  'edecek.jpg',
#  'dolu.jpg',
#  'eden.jpg',
#  'fikir.jpg',
#  'anladın.jpg',
#  'sevindim.jpg',
#  'bilmek.jpg',
#  'mümkün.jpg',
#  'kere.jpg',
#  'sanıyordum.jpg',
#  'acı.jpg',
#  'hissediyorum.jpg',
#  'tahmin.jpg',
#  'üzere.jpg',
#  'kapa.jpg',
#  'şöyle.jpg',
#  'milyon.jpg',
#  'başkan.jpg',
#  'ölü.jpg',
#  'güvenlik.jpg',
#  'çık.jpg',
#  'belli.jpg',
#  'aşağı.jpg',
#  'affedersiniz.jpg',
#  'yemin.jpg',
#  'dön.jpg',
#  'otur.jpg',
#  'anlaşıldı.jpg',
#  'dek.jpg',
#  'kaptan.jpg',
#  'at.jpg',
#  'deli.jpg',
#  'ana.jpg',
#  'çek.jpg',
#  'çekil.jpg',
#  'çekilin.jpg',
#  'hasta.jpg',
#  'sefer.jpg',
#  'berbat.jpg',
#  'istedi.jpg',
#  'istediğini.jpg',
#  'istediğin.jpg',
#  'baş.jpg',
#  'başıma.jpg',
#  'diyorum.jpg',
#  'normal.jpg',
#  'şans.jpg',
#  'güç.jpg',
#  'tatlı.jpg',
#  'dair.jpg',
#  'keşke.jpg',
#  'getir.jpg',
#  'getirdim.jpg',
#  'gidin.jpg',
#  'yukarı.jpg',
#  'yavaş.jpg',
#  'tehlikeli.jpg',
#  'bilmem.jpg',
#  'pardon.jpg',
#  'hata.jpg',
#  'aşk.jpg',
#  'aşkına.jpg',
#  'sessiz.jpg',
#  'üstüne.jpg',
#  'duydun.jpg',
#  'önünde.jpg',
#  'aile.jpg',
#  'millet.jpg',
#  'yüz.jpg',
#  'asıl.jpg',
#  'nefes.jpg',
#  'kahve.jpg',
#  'basit.jpg',
#  'diyor.jpg',
#  'bilgi.jpg',
#  'kusura.jpg',
#  'tut.jpg',
#  'görüyorum.jpg',
#  'sıcak.jpg',
#  'koca.jpg',
#  'bilmiyor.jpg',
#  'bilmiyordum.jpg',
#  'ufak.jpg',
#  'hak.jpg',
#  'haklı.jpg',
#  'edeceğim.jpg',
#  'arkadaş.jpg',
#  'arkadaşın.jpg',
#  'arkadaşı.jpg',
#  'yaşında.jpg',
#  'benziyor.jpg',
#  'tıpkı.jpg',
#  'yedi.jpg',
#  'herhalde.jpg',
#  'vakit.jpg',
#  'doğum.jpg',
#  'birçok.jpg',
#  'dalga.jpg',
#  'erken.jpg',
#  'düşünüyor.jpg',
#  'köpek.jpg',
#  'temiz.jpg',
#  'sesini.jpg',
#  'görüyor.jpg',
#  'cidden.jpg',
#  'ajan.jpg',
#  'fena.jpg',
#  'bulmak.jpg',
#  'mesaj.jpg',
#  'buldun.jpg',
#  'gayet.jpg',
#  'anlamıyorum.jpg',
#  'düşün.jpg',
#  'şarkı.jpg',
#  'bilir.jpg',
#  'konu.jpg',
#  'inanamıyorum.jpg',
#  'hatırlıyor.jpg',
#  'hatırlıyorum.jpg',
#  'muhteşem.jpg',
#  'sağol.jpg',
#  'sayın.jpg',
#  'acil.jpg',
#  'kimsin.jpg',
#  'güvenli.jpg',
#  'bekliyor.jpg',
#  'kalk.jpg',
#  'yanına.jpg',
#  'canlı.jpg',
#  'cinayet.jpg',
#  'sevgili.jpg',
#  'zavallı.jpg',
#  'rağmen.jpg',
#  'teslim.jpg',
#  'üstünde.jpg',
#  'görünüşe.jpg',
#  'kırmızı.jpg',
#  'gerçeği.jpg',
#  'içki.jpg',
#  'yürü.jpg',
#  'numara.jpg',
#  'unutma.jpg',
#  'konuşma.jpg',
#  'film.jpg',
#  'sebep.jpg',
#  'defa.jpg',
#  'uyuşturucu.jpg',
#  'bağlı.jpg',
#  'suç.jpg',
#  'suçlu.jpg',
#  'sebebi.jpg',
#  'parçası.jpg',
#  'sıkı.jpg',
#  'pislik.jpg',
#  'herşey.jpg',
#  'herşeyi.jpg',
#  'tercih.jpg',
#  'umurumda.jpg',
#  'patron.jpg',
#  'bahsediyorsun.jpg',
#  'saçma.jpg',
#  'soğuk.jpg',
#  'oda.jpg',
#  'parti.jpg',
#  'sıra.jpg',
#  'sırada.jpg',
#  'kayıp.jpg',
#  'eğlenceli.jpg',
#  'yaşıyor.jpg',
#  'burayı.jpg',
#  'anlat.jpg',
#  'ölmüş.jpg',
#  'çoğu.jpg',
#  'yemeği.jpg',
#  'burda.jpg',
#  'dedektif.jpg',
#  'dürüst.jpg',
#  'anlıyor.jpg',
#  'seviyor.jpg',
#  'dolayı.jpg',
#  'şehir.jpg',
#  'tanıyor.jpg',
#  'sert.jpg',
#  'bulduk.jpg',
#  'teklif.jpg',
#  'anlamı.jpg',
#  'anlamına.jpg',
#  'göster.jpg',
#  'alan.jpg',
#  'orası.jpg',
#  'istemiyor.jpg',
#  'ağır.jpg',
#  'tarafa.jpg',
#  'affedersin.jpg',
#  'görmedim.jpg',
#  'hanımefendi.jpg',
#  'takım.jpg',
#  'kalın.jpg',
#  'kara.jpg',
#  'karanlık.jpg',
#  'edebilir.jpg',
#  'canına.jpg',
#  'sene.jpg',
#  'davet.jpg',
#  'taraftan.jpg',
#  'görmeye.jpg',
#  'anlaşma.jpg',
#  'aşık.jpg',
#  'süper.jpg',
#  'yarım.jpg',
#  'sahibi.jpg',
#  'kapı.jpg',
#  'fikrim.jpg',
#  'duyuyor.jpg',
#  'müzik.jpg',
#  'aferin.jpg',
#  'gurur.jpg',
#  'öğrenmek.jpg',
#  'iç.jpg',
#  'vakti.jpg',
#  'yazık.jpg',
#  'serbest.jpg',
#  'siyah.jpg',
#  'görev.jpg',
#  'hale.jpg',
#  'kavga.jpg',
#  'bölüm.jpg',
#  'sık.jpg',
#  'arka.jpg',
#  'gidecek.jpg',
#  'dava.jpg',
#  'sekiz.jpg',
#  'dua.jpg',
#  'istemedim.jpg',
#  'gider.jpg',
#  'konuş.jpg',
#  'kitap.jpg',
#  'güneş.jpg',
#  'bul.jpg',
#  'edeyim.jpg',
#  'ifade.jpg',
#  'resmi.jpg',
#  'okul.jpg',
#  'mesela.jpg']

# %%
image_file_name = []
for file in file_list:
    # file and extention
    file_without_ext = os.path.splitext(file)[0]
    image_file_name.append(file_without_ext)

# %%
word_set = set(word_list)
image_file_name_set = set(image_file_name)

# %%
word_set.difference(image_file_name_set)
# Out:
# set()

# %%
image_file_name_set.difference(word_set)
# Out:
# set()

# %% [markdown]
# #### Youtube Sentence Analysis

# %%
df_youtube_sentence = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Youtube/Result/{lang_folder.capitalize()}/Sentence Clean Merge/Clean_Youtube_Sentence_Merge_Result.csv")
df_youtube_sentence
# Out:
#            start_time      end_time  \
# 0        00:00:00.294  00:00:03.294
# 1        00:00:03.375  00:00:06.375
# 2        00:00:06.462  00:00:09.462
# 3        00:00:10.267  00:00:11.394
# 4        00:00:11.835  00:00:14.061
# ...               ...           ...
# 3934202  00:10:00.240  00:10:07.818
# 3934203  00:10:07.994  00:10:13.534
# 3934204  00:10:14.745  00:10:17.924
# 3934205  00:10:18.047  00:10:22.398
# 3934206  00:10:22.734  00:10:23.633
#
#                                                   sentence     video_id
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                 sesli betimleme derneğine yaptırılmıştır  fI1BI4d5KFU
# 2                                            wwwsebederorg  fI1BI4d5KFU
# 3                                                     mumu  fI1BI4d5KFU
# 4                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# ...                                                    ...          ...
# 3934202  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3934203  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3934204  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
# 3934205  video hoşunuza gittiyse beğenmeyi ve kanalıma ...  dRssR_apbR0
# 3934206                                         hoşçakalın  dRssR_apbR0
#
# [3934207 rows x 4 columns]

# %%
df_youtube_sentence['start_time'] = pd.to_timedelta(df_youtube_sentence['start_time']) # data type converted timedelta for second 
df_youtube_sentence['end_time'] = pd.to_timedelta(df_youtube_sentence['end_time'])

# %%
df_youtube_sentence['start_time'] = df_youtube_sentence['start_time'].apply(lambda x: x.total_seconds()) # convert seconds
df_youtube_sentence['end_time'] = df_youtube_sentence['end_time'].apply(lambda x: x.total_seconds())
df_youtube_sentence.reset_index(inplace=True)  # adding index column
df_youtube_sentence
# Out:
#            index  start_time  end_time  \
# 0              0       0.294     3.294
# 1              1       3.375     6.375
# 2              2       6.462     9.462
# 3              3      10.267    11.394
# 4              4      11.835    14.061
# ...          ...         ...       ...
# 3934202  3934202     600.240   607.818
# 3934203  3934203     607.994   613.534
# 3934204  3934204     614.745   617.924
# 3934205  3934205     618.047   622.398
# 3934206  3934206     622.734   623.633
#
#                                                   sentence     video_id
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                 sesli betimleme derneğine yaptırılmıştır  fI1BI4d5KFU
# 2                                            wwwsebederorg  fI1BI4d5KFU
# 3                                                     mumu  fI1BI4d5KFU
# 4                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# ...                                                    ...          ...
# 3934202  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3934203  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3934204  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
# 3934205  video hoşunuza gittiyse beğenmeyi ve kanalıma ...  dRssR_apbR0
# 3934206                                         hoşçakalın  dRssR_apbR0
#
# [3934207 rows x 5 columns]

# %%
#df_youtube_sentence[df_youtube_sentence["index"] == 1287503]

# %%
# import os
# from multiprocessing import Process, Manager, Pool, Queue
manager = multiprocessing.Manager()
result_list = manager.list()
word_set = set(word_list)
index_num = list(range(len(df_youtube_sentence)))

def sentence_word_ratio(index_num):
    index = df_youtube_sentence.loc[index_num,"index"]
    start = df_youtube_sentence.loc[index_num,"start_time"]
    end = df_youtube_sentence.loc[index_num,"end_time"]
    sentence = df_youtube_sentence.loc[index_num,"sentence"]
    videoid = df_youtube_sentence.loc[index_num,"video_id"]

    sent_word = re.findall(r"\w+", sentence, re.UNICODE)
    sent_word_set = set(sent_word)
    intersect_word = list(word_set.intersection(sent_word_set))
    different_word = list(sent_word_set.difference(word_set))
    word_ratio = round(((len(intersect_word)/(len(sent_word)+0.001))*100),1)
    different = ", ".join(different_word)
    intersect = ", ".join(intersect_word)

    result_list.append([index,start,end,sentence,videoid,word_ratio,different,intersect])  
    
   
if __name__ == '__main__':
    # with Pool(16) as p:
    with Pool(nprocs-2) as p: # Pool number CPU sayısına eşit olursa tüm CPU lar çalışır
        p.map(sentence_word_ratio, index_num)

# %%
df_sentence_ratio_result = pd.DataFrame(list(result_list), columns=["index","start_time","end_time","sentence","video_id","word_ratio","different_word","intersect_word"])
df_sentence_ratio_result.sort_values(by="index", ascending=True, inplace=True)
df_sentence_ratio_result.reset_index(drop=True, inplace=True)
df_sentence_ratio_result
# Out:
#            index  start_time  end_time  \
# 0              0       0.294     3.294
# 1              1       3.375     6.375
# 2              2       6.462     9.462
# 3              3      10.267    11.394
# 4              4      11.835    14.061
# ...          ...         ...       ...
# 3934202  3934202     600.240   607.818
# 3934203  3934203     607.994   613.534
# 3934204  3934204     614.745   617.924
# 3934205  3934205     618.047   622.398
# 3934206  3934206     622.734   623.633
#
#                                                   sentence     video_id  \
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                 sesli betimleme derneğine yaptırılmıştır  fI1BI4d5KFU
# 2                                            wwwsebederorg  fI1BI4d5KFU
# 3                                                     mumu  fI1BI4d5KFU
# 4                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# ...                                                    ...          ...
# 3934202  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3934203  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3934204  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
# 3934205  video hoşunuza gittiyse beğenmeyi ve kanalıma ...  dRssR_apbR0
# 3934206                                         hoşçakalın  dRssR_apbR0
#
#          word_ratio                                     different_word  \
# 0              28.6                betimlemesi, fi, dizinin, staff, lm
# 1               0.0        sesli, yaptırılmıştır, betimleme, derneğine
# 2               0.0                                      wwwsebederorg
# 3               0.0                                               mumu
# 4              42.9                      hat, katsayım, sinir, safhada
# ...             ...                                                ...
# 3934202        43.7  bulunmadığı, yolların, dümdüz, ülke, danimarka...
# 3934203        30.0  okuluna, işine, bisikletle, nedenle, yarısına,...
# 3934204        33.3   söyleyeceklerim, alakalı, danimarkayla, şimdilik
# 3934205        11.1  unutmayın, video, kanalıma, hoşunuza, gittiyse...
# 3934206         0.0                                         hoşçakalın
#
#                                        intersect_word
# 0                                      bu, tarafından
# 1
# 2
# 3
# 4                                         bak, an, şu
# ...                                               ...
# 3934202  da, olduğu, isterim, söylemek, şunu, ki, bir
# 3934203                       gidiyor, bu, insanların
# 3934204                                     bu, kadar
# 3934205                                            ve
# 3934206
#
# [3934207 rows x 8 columns]

# %%
df_sentence_ratio_result["different_word"] = df_sentence_ratio_result["different_word"].apply(lambda x: np.nan if x == "" else x)
df_sentence_ratio_result["intersect_word"] = df_sentence_ratio_result["intersect_word"].apply(lambda x: np.nan if x == "" else x)
df_sentence_ratio_result
# Out:
#            index  start_time  end_time  \
# 0              0       0.294     3.294
# 1              1       3.375     6.375
# 2              2       6.462     9.462
# 3              3      10.267    11.394
# 4              4      11.835    14.061
# ...          ...         ...       ...
# 3934202  3934202     600.240   607.818
# 3934203  3934203     607.994   613.534
# 3934204  3934204     614.745   617.924
# 3934205  3934205     618.047   622.398
# 3934206  3934206     622.734   623.633
#
#                                                   sentence     video_id  \
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                 sesli betimleme derneğine yaptırılmıştır  fI1BI4d5KFU
# 2                                            wwwsebederorg  fI1BI4d5KFU
# 3                                                     mumu  fI1BI4d5KFU
# 4                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# ...                                                    ...          ...
# 3934202  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3934203  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3934204  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
# 3934205  video hoşunuza gittiyse beğenmeyi ve kanalıma ...  dRssR_apbR0
# 3934206                                         hoşçakalın  dRssR_apbR0
#
#          word_ratio                                     different_word  \
# 0              28.6                betimlemesi, fi, dizinin, staff, lm
# 1               0.0        sesli, yaptırılmıştır, betimleme, derneğine
# 2               0.0                                      wwwsebederorg
# 3               0.0                                               mumu
# 4              42.9                      hat, katsayım, sinir, safhada
# ...             ...                                                ...
# 3934202        43.7  bulunmadığı, yolların, dümdüz, ülke, danimarka...
# 3934203        30.0  okuluna, işine, bisikletle, nedenle, yarısına,...
# 3934204        33.3   söyleyeceklerim, alakalı, danimarkayla, şimdilik
# 3934205        11.1  unutmayın, video, kanalıma, hoşunuza, gittiyse...
# 3934206         0.0                                         hoşçakalın
#
#                                        intersect_word
# 0                                      bu, tarafından
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                         bak, an, şu
# ...                                               ...
# 3934202  da, olduğu, isterim, söylemek, şunu, ki, bir
# 3934203                       gidiyor, bu, insanların
# 3934204                                     bu, kadar
# 3934205                                            ve
# 3934206                                           NaN
#
# [3934207 rows x 8 columns]

# %%
df_adjust_sentence_ratio = df_sentence_ratio_result[df_sentence_ratio_result["word_ratio"] >= adjust_sent_word_ratio]
df_adjust_sentence_ratio.reset_index(inplace=True, drop=True)
df_adjust_sentence_ratio
# Out:
#            index  start_time  end_time  \
# 0              0       0.294     3.294
# 1              4      11.835    14.061
# 2              5      14.213    17.219
# 3              6      18.687    19.854
# 4              7      19.967    22.805
# ...          ...         ...       ...
# 3236946  3934200     590.325   594.700
# 3236947  3934201     594.755   599.701
# 3236948  3934202     600.240   607.818
# 3236949  3934203     607.994   613.534
# 3236950  3934204     614.745   617.924
#
#                                                   sentence     video_id  \
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# 2                 kelimelerini lütfen seçerek konuş lütfen  fI1BI4d5KFU
# 3                                       otursana bir tanem  fI1BI4d5KFU
# 4               hah oturtmaya çalıştığına göre demek doğru  fI1BI4d5KFU
# ...                                                    ...          ...
# 3236946  zira bizim insanlarımız işine yaramayan ikinci...  dRssR_apbR0
# 3236947  ihtiyaç sahiplerine vermeyi tercih ediyorlar v...  dRssR_apbR0
# 3236948  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3236949  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3236950  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
#
#          word_ratio                                     different_word  \
# 0              28.6                betimlemesi, fi, dizinin, staff, lm
# 1              42.9                      hat, katsayım, sinir, safhada
# 2              40.0                              kelimelerini, seçerek
# 3              33.3                                    otursana, tanem
# 4              50.0                        oturtmaya, hah, çalıştığına
# ...             ...                                                ...
# 3236946        40.0  işine, kıyafetleri, satmak, yaramayan, zira, i...
# 3236947        50.0  ediyorlar, iyilik, ihtiyaç, örneğidir, sahiple...
# 3236948        43.7  bulunmadığı, yolların, dümdüz, ülke, danimarka...
# 3236949        30.0  okuluna, işine, bisikletle, nedenle, yarısına,...
# 3236950        33.3   söyleyeceklerim, alakalı, danimarkayla, şimdilik
#
#                                        intersect_word
# 0                                      bu, tarafından
# 1                                         bak, an, şu
# 2                                       konuş, lütfen
# 3                                                 bir
# 4                                  demek, doğru, göre
# ...                                               ...
# 3236946                     ikinci, el, bizim, yerine
# 3236947               ve, çok, tercih, güzel, bu, bir
# 3236948  da, olduğu, isterim, söylemek, şunu, ki, bir
# 3236949                       gidiyor, bu, insanların
# 3236950                                     bu, kadar
#
# [3236951 rows x 8 columns]

# %%
# 1 way (use more memory) will edit code for less memory ??????
# import os
# from multiprocessing import Process, Manager, Pool, Queue
manager = multiprocessing.Manager()
result_list4 = manager.list()
#index_list = manager.list()
#all_index_list = manager.list()
#var_index_list = manager.list()
#text_all_list = manager.list()  
df = df_adjust_sentence_ratio
df.reset_index(drop=True, inplace=True)
index_num = list(range(len(df)))
sentence = list((df["sentence"]))
opt_column = list((df["video_id"]))
sent_len = word_group_adjust_select
sent_len_num = sentence_word_count_number
data_zip = zip(index_num, sentence, opt_column) 

def df_exract_word_group(index_num, source_text, opt_var):    
    #source_text = df.loc[index_num,"sentence"]
    #opt_var = df.loc[index_num,"video_id"]
    words = re.findall(r"\w+", source_text, re.UNICODE)
    # check words in word_list
    index_list = []
    for j in range(len(words)):
        if words[j] in word_list:
            index_list.append(j)
        else:
            pass
    # add index plus 1 and compare with current and next index (Is it continuous or not?)
    all_index_list = []
    var_index_list = []
    for k in range(len(index_list)):
        try:
            var1 = index_list[k] + 1  
            var2 = index_list[k+1]
        except:
            var1 = index_list[k] + 1  
            var2 = index_list[-1]
        if var1 == var2:
            var3 = index_list[k]
            var_index_list.append(var3)
        else:
            var3 = index_list[k]
            var_index_list.append(var3)
            var4 = list(var_index_list)
            all_index_list.append(var4)
            var_index_list = []
    # index convert to word
    text_all_list = []
    for m in all_index_list:
        text_list = [] 
        for n in m:
            word = words[n]
            text_list.append(word)
            if sent_len:
                if len(text_list) >= sent_len_num:
                    text = " ".join(text_list)
                    text_all_list.append(text)
                else:
                    pass
            else:
               text = " ".join(text_list)
               text_all_list.append(text) 
    # result list    
    for search_string in text_all_list:
        #df_var["index"] = i
        #df_var["search_string"] = search_string
        #df_var["sentence"] = source_text
        #df_var["video_id"] = opt_var
        result_list4.append([index_num,search_string,source_text,opt_var])

if __name__ == '__main__':
    # with Pool(16) as p:
    with Pool(nprocs) as p: # Pool number CPU sayısına eşit olursa tüm CPU lar çalışır
        p.starmap(df_exract_word_group, data_zip)
# Out:
# Process ForkPoolWorker-63:
# Traceback (most recent call last):
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-59:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-ed37c04af93e> in <module>
#      74     # with Pool(16) as p:
#      75     with Pool(nprocs) as p: # Pool number CPU sayısına eşit olursa tüm CPU lar çalışır
# ---> 76         p.starmap(df_exract_word_group, data_zip)
#
# ~/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py in starmap(self, func, iterable, chunksize)
#     370         `func` and (a, b) becomes func(a, b).
#     371         '''
# --> 372         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     373
#     374     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# ~/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~/anaconda3/envs/py39/lib/python3.9/threading.py in wait(self, timeout)
#     572             signaled = self._flag
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#     576
#
# ~/anaconda3/envs/py39/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
# Traceback (most recent call last):
#   File "<string>", line 2, in append
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "<string>", line 2, in append
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
# Process ForkPoolWorker-55:
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
# Process ForkPoolWorker-56:
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "<string>", line 2, in append
#   File "<string>", line 2, in append
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
# Process ForkPoolWorker-60:
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-50:
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-58:
# Traceback (most recent call last):
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<string>", line 2, in append
# Process ForkPoolWorker-52:
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Traceback (most recent call last):
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "<string>", line 2, in append
# KeyboardInterrupt
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "<string>", line 2, in append
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
# Traceback (most recent call last):
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "<string>", line 2, in append
#   File "<string>", line 2, in append
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Process ForkPoolWorker-61:
# Process ForkPoolWorker-53:
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
# Process ForkPoolWorker-62:
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
# KeyboardInterrupt
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Process ForkPoolWorker-64:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "<string>", line 2, in append
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<string>", line 2, in append
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "<string>", line 2, in append
# KeyboardInterrupt
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
# Process ForkPoolWorker-54:
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
# Traceback (most recent call last):
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
# Traceback (most recent call last):
#   File "<string>", line 2, in append
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "<string>", line 2, in append
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "<string>", line 2, in append
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "<ipython-input-58-ed37c04af93e>", line 71, in df_exract_word_group
#     result_list4.append([index_num,search_string,source_text,opt_var])
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "<string>", line 2, in append
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/managers.py", line 809, in _callmethod
#     kind, result = conn.recv()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 255, in recv
#     buf = self._recv_bytes()
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/kurubal/anaconda3/envs/py39/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
df_adjust_sentence_ratio2 = pd.DataFrame(list(result_list4), columns=["index","search_string","sentence","video_id"])
df_adjust_sentence_ratio2.sort_values(by="index", ascending=True, inplace=True)
df_adjust_sentence_ratio2.reset_index(drop=True, inplace=True)
df_adjust_sentence_ratio2.drop(["index"], axis=1, inplace=True)
df_adjust_sentence_ratio2
# Out:
#                   search_string                 sentence     video_id
# 0                        gerçek                gerçek bu  fI1BI4d5KFU
# 1                     gerçek bu                gerçek bu  fI1BI4d5KFU
# 2                           ama               ama olmadı  fI1BI4d5KFU
# 3                    ama olmadı               ama olmadı  fI1BI4d5KFU
# 4                     biliyorum            biliyorum zor  fI1BI4d5KFU
# ...                         ...                      ...          ...
# 798660        ancak güzel haber  ancak güzel haber şu ki  dRssR_apbR0
# 798661     ancak güzel haber şu  ancak güzel haber şu ki  dRssR_apbR0
# 798662                    ancak  ancak güzel haber şu ki  dRssR_apbR0
# 798663              ancak güzel  ancak güzel haber şu ki  dRssR_apbR0
# 798664  ancak güzel haber şu ki  ancak güzel haber şu ki  dRssR_apbR0
#
# [798665 rows x 3 columns]

# %%
df_adjust_sentence_ratio2.drop_duplicates()
# Out:
#                   search_string                 sentence     video_id
# 0                        gerçek                gerçek bu  fI1BI4d5KFU
# 1                     gerçek bu                gerçek bu  fI1BI4d5KFU
# 2                    ama olmadı               ama olmadı  fI1BI4d5KFU
# 3                           ama               ama olmadı  fI1BI4d5KFU
# 4                 biliyorum zor            biliyorum zor  fI1BI4d5KFU
# ...                         ...                      ...          ...
# 798660        ancak güzel haber  ancak güzel haber şu ki  dRssR_apbR0
# 798661     ancak güzel haber şu  ancak güzel haber şu ki  dRssR_apbR0
# 798662                    ancak  ancak güzel haber şu ki  dRssR_apbR0
# 798663              ancak güzel  ancak güzel haber şu ki  dRssR_apbR0
# 798664  ancak güzel haber şu ki  ancak güzel haber şu ki  dRssR_apbR0
#
# [759976 rows x 3 columns]

# %%
df_adjust_sentence_ratio
# Out:
#           index  start_time  end_time  \
# 0            11      34.571    35.667
# 1            18      62.326    63.644
# 2            21      69.949    71.188
# 3            32     110.626   113.396
# 4            40     142.699   143.881
# ...         ...         ...       ...
# 251209  3933950     419.131   421.108
# 251210  3933991     101.080   106.460
# 251211  3934008     187.540   190.080
# 251212  3934051     382.800   385.020
# 251213  3934113      56.096    57.635
#
#                                           sentence     video_id  word_ratio  \
# 0                                        gerçek bu  fI1BI4d5KFU       100.0
# 1                                       ama olmadı  fI1BI4d5KFU       100.0
# 2                                    biliyorum zor  fI1BI4d5KFU       100.0
# 3                                        ben senin  fI1BI4d5KFU       100.0
# 4                                            bu mu  fI1BI4d5KFU       100.0
# ...                                            ...          ...         ...
# 251209           en azından ben böyle hissediyorum  RkLLlRIaea8       100.0
# 251210                            ve neredeyse tam  xX6E5mQ1XP0       100.0
# 251211                                      ve tam  xX6E5mQ1XP0       100.0
# 251212  ve o yüzden de böyle siyah beyaz görünüyor  xX6E5mQ1XP0       100.0
# 251213                     ancak güzel haber şu ki  dRssR_apbR0       100.0
#
#        different_word                                     intersect_word
# 0                 NaN                                         gerçek, bu
# 1                 NaN                                        olmadı, ama
# 2                 NaN                                     zor, biliyorum
# 3                 NaN                                         ben, senin
# 4                 NaN                                             mu, bu
# ...               ...                                                ...
# 251209            NaN              en, böyle, azından, ben, hissediyorum
# 251210            NaN                                 ve, neredeyse, tam
# 251211            NaN                                            ve, tam
# 251212            NaN  o, yüzden, ve, görünüyor, de, beyaz, siyah, böyle
# 251213            NaN                        haber, güzel, şu, ki, ancak
#
# [251214 rows x 8 columns]

# %%
# 2 way
df_adjust_sentence_ratio.loc[:,"search_string"] = df_adjust_sentence_ratio.loc[:,"sentence"].map(lambda x: exract_word_group(x, word_list))
df_adjust_sentence_ratio = df_adjust_sentence_ratio[~(df_adjust_sentence_ratio["search_string"]==f"sentencte_word_count_less_than_{sentence_word_count_number}")]
#df_adjust_sentence_ratio.reset_index(drop=True, inplace=True)
df_adjust_sentence_ratio
# Out:
# <ipython-input-110-ea0aea4442a6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adjust_sentence_ratio.loc[:,"search_string"] = df_adjust_sentence_ratio.loc[:,"sentence"].map(lambda x: exract_word_group(x, word_list))
#           index  start_time  end_time  \
# 10           79     302.034   303.874
# 14          116     412.533   414.390
# 15          125     436.730   438.867
# 16          141     537.521   540.307
# 23          226     957.180   958.965
# ...         ...         ...       ...
# 251196  3933284     240.180   243.020
# 251208  3933847     196.780   202.160
# 251209  3933950     419.131   421.108
# 251212  3934051     382.800   385.020
# 251213  3934113      56.096    57.635
#
#                                             sentence     video_id  word_ratio  \
# 10                         bana o kadar iyi geldi ki  fI1BI4d5KFU       100.0
# 14                   öyle bir şey mi dedim ben şimdi  fI1BI4d5KFU       100.0
# 15                   anne ne işin var orada ya kızım  fI1BI4d5KFU       100.0
# 16                    ne oldu ciddi bir durum mu var  fI1BI4d5KFU       100.0
# 23                     zaten hiçbir şey de olmayacak  fI1BI4d5KFU       100.0
# ...                                              ...          ...         ...
# 251196  benim bir ihtiyacım daha olduğunu fark ettim  Pa1uwQHegSA       100.0
# 251208                    bir anda dünyanın en büyük  biOpGkPG_Ho       100.0
# 251209             en azından ben böyle hissediyorum  RkLLlRIaea8       100.0
# 251212    ve o yüzden de böyle siyah beyaz görünüyor  xX6E5mQ1XP0       100.0
# 251213                       ancak güzel haber şu ki  dRssR_apbR0       100.0
#
#        different_word                                     intersect_word  \
# 10                NaN                     ki, o, bana, geldi, kadar, iyi
# 14                NaN              dedim, şey, şimdi, mi, öyle, ben, bir
# 15                NaN              anne, ya, ne, orada, var, işin, kızım
# 16                NaN               durum, ne, oldu, mu, var, ciddi, bir
# 23                NaN                  olmayacak, şey, de, hiçbir, zaten
# ...               ...                                                ...
# 251196            NaN  ettim, fark, daha, benim, ihtiyacım, olduğunu,...
# 251208            NaN                     dünyanın, en, büyük, anda, bir
# 251209            NaN              en, böyle, azından, ben, hissediyorum
# 251212            NaN  o, yüzden, ve, görünüyor, de, beyaz, siyah, böyle
# 251213            NaN                        haber, güzel, şu, ki, ancak
#
#                                        search_string
# 10                         bana o kadar iyi geldi ki
# 14                   öyle bir şey mi dedim ben şimdi
# 15                   anne ne işin var orada ya kızım
# 16                    ne oldu ciddi bir durum mu var
# 23                     zaten hiçbir şey de olmayacak
# ...                                              ...
# 251196  benim bir ihtiyacım daha olduğunu fark ettim
# 251208                    bir anda dünyanın en büyük
# 251209             en azından ben böyle hissediyorum
# 251212    ve o yüzden de böyle siyah beyaz görünüyor
# 251213                       ancak güzel haber şu ki
#
# [40597 rows x 9 columns]

# %%
df_word_group_time_loc_in_sent_result = word_group_time_loc(df_adjust_sentence_ratio, "search_string", "start_time", "end_time", "sentence", "video_id")
df_word_group_time_loc_in_sent_result
# Out:
#                             search_string  start_time    end_time  \
# 0               demek o yüzden öyle garip   81.538000   83.401086
# 1       o deli kadın herkesin içinde beni  135.778000  138.062800
# 2           ama yapma böyle git dedim git  147.019000  148.549769
# 3               bana o kadar iyi geldi ki  302.034000  303.874000
# 4       ben tamamen inanamıyorum şu an ya  337.256927  339.860000
# ...                                   ...         ...         ...
# 271442    o kadar sakin ki dışarıda insan  188.084392  190.316696
# 271443   yani orada ciddi ciddi ikinci el  578.076000  580.178481
# 271444         eğer varsa da bence çok iş  587.861571  589.528238
# 271445                ve bu çok güzel bir  597.441716  598.724012
# 271446        şunu da söylemek isterim ki  601.376700  603.208050
#
#                                                  sentence     video_id
# 0                     demek o yüzden öyle garip davrandın  fI1BI4d5KFU
# 1       o deli kadın herkesin içinde beni rezil etti h...  fI1BI4d5KFU
# 2                 ama yapma böyle git dedim git karşımdan  fI1BI4d5KFU
# 3                               bana o kadar iyi geldi ki  fI1BI4d5KFU
# 4               allahım ben tamamen inanamıyorum şu an ya  fI1BI4d5KFU
# ...                                                   ...          ...
# 271442  hatta köyleri o kadar sakin ki dışarıda insan ...  dRssR_apbR0
# 271443  yani orada ciddi ciddi ikinci el kıyafet sektö...  dRssR_apbR0
# 271444  fakat ülkemizde ikinci el kıyafet dükkanı görd...  dRssR_apbR0
# 271445  ihtiyaç sahiplerine vermeyi tercih ediyorlar v...  dRssR_apbR0
# 271446  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
#
# [271447 rows x 5 columns]

# %%
df_word_group_time_loc_in_sent_result["start_time"] = df_word_group_time_loc_in_sent_result["start_time"].apply(lambda x: (x-shift))
df_word_group_time_loc_in_sent_result["end_time"] = df_word_group_time_loc_in_sent_result["end_time"].apply(lambda x: (x+shift))
df_word_group_time_loc_in_sent_result
# Out:
#                             search_string  start_time    end_time  \
# 0               demek o yüzden öyle garip   81.238000   83.701086
# 1       o deli kadın herkesin içinde beni  135.478000  138.362800
# 2           ama yapma böyle git dedim git  146.719000  148.849769
# 3               bana o kadar iyi geldi ki  301.734000  304.174000
# 4       ben tamamen inanamıyorum şu an ya  336.956927  340.160000
# ...                                   ...         ...         ...
# 271442    o kadar sakin ki dışarıda insan  187.784392  190.616696
# 271443   yani orada ciddi ciddi ikinci el  577.776000  580.478481
# 271444         eğer varsa da bence çok iş  587.561571  589.828238
# 271445                ve bu çok güzel bir  597.141716  599.024012
# 271446        şunu da söylemek isterim ki  601.076700  603.508050
#
#                                                  sentence     video_id
# 0                     demek o yüzden öyle garip davrandın  fI1BI4d5KFU
# 1       o deli kadın herkesin içinde beni rezil etti h...  fI1BI4d5KFU
# 2                 ama yapma böyle git dedim git karşımdan  fI1BI4d5KFU
# 3                               bana o kadar iyi geldi ki  fI1BI4d5KFU
# 4               allahım ben tamamen inanamıyorum şu an ya  fI1BI4d5KFU
# ...                                                   ...          ...
# 271442  hatta köyleri o kadar sakin ki dışarıda insan ...  dRssR_apbR0
# 271443  yani orada ciddi ciddi ikinci el kıyafet sektö...  dRssR_apbR0
# 271444  fakat ülkemizde ikinci el kıyafet dükkanı görd...  dRssR_apbR0
# 271445  ihtiyaç sahiplerine vermeyi tercih ediyorlar v...  dRssR_apbR0
# 271446  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
#
# [271447 rows x 5 columns]

# %%
df_word_group_time_loc_in_sent_result["start_time"] = df_word_group_time_loc_in_sent_result["start_time"].apply(lambda x: round(x))
df_word_group_time_loc_in_sent_result["end_time"] = df_word_group_time_loc_in_sent_result["end_time"].apply(lambda x: round(x))
df_word_group_time_loc_in_sent_result
# Out:
#                             search_string  start_time  end_time  \
# 0               demek o yüzden öyle garip          81        84
# 1       o deli kadın herkesin içinde beni         135       138
# 2           ama yapma böyle git dedim git         147       149
# 3               bana o kadar iyi geldi ki         302       304
# 4       ben tamamen inanamıyorum şu an ya         337       340
# ...                                   ...         ...       ...
# 271442    o kadar sakin ki dışarıda insan         188       191
# 271443   yani orada ciddi ciddi ikinci el         578       580
# 271444         eğer varsa da bence çok iş         588       590
# 271445                ve bu çok güzel bir         597       599
# 271446        şunu da söylemek isterim ki         601       604
#
#                                                  sentence     video_id
# 0                     demek o yüzden öyle garip davrandın  fI1BI4d5KFU
# 1       o deli kadın herkesin içinde beni rezil etti h...  fI1BI4d5KFU
# 2                 ama yapma böyle git dedim git karşımdan  fI1BI4d5KFU
# 3                               bana o kadar iyi geldi ki  fI1BI4d5KFU
# 4               allahım ben tamamen inanamıyorum şu an ya  fI1BI4d5KFU
# ...                                                   ...          ...
# 271442  hatta köyleri o kadar sakin ki dışarıda insan ...  dRssR_apbR0
# 271443  yani orada ciddi ciddi ikinci el kıyafet sektö...  dRssR_apbR0
# 271444  fakat ülkemizde ikinci el kıyafet dükkanı görd...  dRssR_apbR0
# 271445  ihtiyaç sahiplerine vermeyi tercih ediyorlar v...  dRssR_apbR0
# 271446  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
#
# [271447 rows x 5 columns]

# %%
df_word_group_time_loc_in_sent_result.sort_values("search_string",key=lambda x:x.str.len(), inplace=True, ascending=False)
df_word_group_time_loc_in_sent_result.reset_index(drop=True, inplace=True)
df_word_group_time_loc_in_sent_result
# Out:
#                                             search_string  start_time  \
# 0       başka biriyle herhangi bir şey yaşıyor musun k...         319
# 1       gidelim bir bakalım hep birlikte bakalım bir o...         987
# 2       nasıl olduğunu gördün zaten artık değil mi tek...        2614
# 3       benim kızım tamam bir şey yapmış hata yapmış o...        3090
# 4       bir şekilde söylüyorum ve o zaman eminim ki ço...        4774
# ...                                                   ...         ...
# 271442                                          o o o o o         174
# 271443                                          o o o o o        1065
# 271444                                          o o o o o          60
# 271445                                          o o o o o         595
# 271446                                          o o o o o         856
#
#         end_time                                           sentence  \
# 0            325  başka biriyle herhangi bir şey yaşıyor musun k...
# 1            988  yerleştirmeye yumurtasını seviyoruz çok güzel ...
# 2           2620  nasıl olduğunu gördün zaten artık değil mi tek...
# 3           3097  benim kızım tamam bir şey yapmış hata yapmış o...
# 4           4781  bir şekilde söylüyorum ve o zaman eminim ki ço...
# ...          ...                                                ...
# 271442       177                                          o o o o o
# 271443      1067                                          o o o o o
# 271444        82                                          o o o o o
# 271445       597  o o o o o zamanlı dom dom yine yemek yapıyor n...
# 271446       871                                          o o o o o
#
#            video_id
# 0       KsZ_8oIQsv4
# 1       eqkDognLtTc
# 2       N4YDaU51lvI
# 3       CIQ3Ave21Kw
# 4       cUAQrHbbpZ8
# ...             ...
# 271442  z8rQdsakhBM
# 271443  St4YR8bvX70
# 271444  ATYZ4L0_jxQ
# 271445  1JKejQ9pQBc
# 271446  K0b_9Xzy79A
#
# [271447 rows x 5 columns]

# %%
df_word_group_time_loc_in_sent_result["unique_word_ratio"] = df_word_group_time_loc_in_sent_result["search_string"].apply(lambda text: repetation_ratio(text))
df_word_group_time_loc_in_sent_result
# Out:
#                                             search_string  start_time  \
# 0       başka biriyle herhangi bir şey yaşıyor musun k...         319
# 1       gidelim bir bakalım hep birlikte bakalım bir o...         987
# 2       nasıl olduğunu gördün zaten artık değil mi tek...        2614
# 3       benim kızım tamam bir şey yapmış hata yapmış o...        3090
# 4       bir şekilde söylüyorum ve o zaman eminim ki ço...        4774
# ...                                                   ...         ...
# 271442                                          o o o o o         174
# 271443                                          o o o o o        1065
# 271444                                          o o o o o          60
# 271445                                          o o o o o         595
# 271446                                          o o o o o         856
#
#         end_time                                           sentence  \
# 0            325  başka biriyle herhangi bir şey yaşıyor musun k...
# 1            988  yerleştirmeye yumurtasını seviyoruz çok güzel ...
# 2           2620  nasıl olduğunu gördün zaten artık değil mi tek...
# 3           3097  benim kızım tamam bir şey yapmış hata yapmış o...
# 4           4781  bir şekilde söylüyorum ve o zaman eminim ki ço...
# ...          ...                                                ...
# 271442       177                                          o o o o o
# 271443      1067                                          o o o o o
# 271444        82                                          o o o o o
# 271445       597  o o o o o zamanlı dom dom yine yemek yapıyor n...
# 271446       871                                          o o o o o
#
#            video_id  unique_word_ratio
# 0       KsZ_8oIQsv4                 93
# 1       eqkDognLtTc                 77
# 2       N4YDaU51lvI                100
# 3       CIQ3Ave21Kw                 94
# 4       cUAQrHbbpZ8                 89
# ...             ...                ...
# 271442  z8rQdsakhBM                 20
# 271443  St4YR8bvX70                 20
# 271444  ATYZ4L0_jxQ                 20
# 271445  1JKejQ9pQBc                 20
# 271446  K0b_9Xzy79A                 20
#
# [271447 rows x 6 columns]

# %%
df_word_group_time_loc_in_sent_result_repeat_ratio = df_word_group_time_loc_in_sent_result[df_word_group_time_loc_in_sent_result["unique_word_ratio"] > unique_word_ratio]
df_word_group_time_loc_in_sent_result_repeat_ratio.drop_duplicates(subset=["search_string","start_time","end_time"], inplace=True)
df_word_group_time_loc_in_sent_result_repeat_ratio.reset_index(drop=True, inplace=True)
df_word_group_time_loc_in_sent_result_repeat_ratio.drop("unique_word_ratio", axis=1, inplace=True)
df_word_group_time_loc_in_sent_result_repeat_ratio
# Out:
# <ipython-input-92-d6186b820154>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_word_group_time_loc_in_sent_result_repeat_ratio.drop_duplicates(subset=["search_string","start_time","end_time"], inplace=True)
# <ipython-input-92-d6186b820154>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_word_group_time_loc_in_sent_result_repeat_ratio.drop("unique_word_ratio", axis=1, inplace=True)
#                                             search_string  start_time  \
# 0       başka biriyle herhangi bir şey yaşıyor musun k...         319
# 1       nasıl olduğunu gördün zaten artık değil mi tek...        2614
# 2       benim kızım tamam bir şey yapmış hata yapmış o...        3090
# 3       bir şekilde söylüyorum ve o zaman eminim ki ço...        4774
# 4       sıcak mı evet böyle işte tamam bir şey yok ora...         603
# ...                                                   ...         ...
# 233235                                     de bu da en az         807
# 233236                                     ki sen o da mı        2513
# 233237                                     şu an var ya o        2539
# 233238                                     o da bir de ve         699
# 233239                                      ne o da şu an         273
#
#         end_time                                           sentence  \
# 0            325  başka biriyle herhangi bir şey yaşıyor musun k...
# 1           2620  nasıl olduğunu gördün zaten artık değil mi tek...
# 2           3097  benim kızım tamam bir şey yapmış hata yapmış o...
# 3           4781  bir şekilde söylüyorum ve o zaman eminim ki ço...
# 4            612  sıcak mı evet böyle işte tamam bir şey yok ora...
# ...          ...                                                ...
# 233235       809         üçüncüsü de bu da en az ikisi kadar önemli
# 233236      2515  ama niye gözlerini belerttin ki sen o da mı sa...
# 233237      2540                        şu an var ya o dilini böyle
# 233238       701  o da bir de ve birazcık süreceğiz gibime geliy...
# 233239       275  formasyonu ne o da şu an aktif hale getirdim d...
#
#            video_id
# 0       KsZ_8oIQsv4
# 1       N4YDaU51lvI
# 2       CIQ3Ave21Kw
# 3       cUAQrHbbpZ8
# 4       Mh3bgDLKt2o
# ...             ...
# 233235  c90800j_ED4
# 233236  XNBOk8QO8I0
# 233237  kulZ_sWzBR0
# 233238  NBJpBvOxPYI
# 233239  HgaAaBdkWks
#
# [233240 rows x 5 columns]

# %%
df_word_group_time_loc_in_sent_result_repeat_ratio["include_string_ratio"] = df_word_group_time_loc_in_sent_result_repeat_ratio.apply(lambda x: int((len(str(x['search_string']))/len(str(x['sentence'])))*100) ,axis=1)
df_word_group_time_loc_in_sent_result_repeat_ratio
# Out:
# <ipython-input-93-e137816795b3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_word_group_time_loc_in_sent_result_repeat_ratio["include_string_ratio"] = df_word_group_time_loc_in_sent_result_repeat_ratio.apply(lambda x: int((len(str(x['search_string']))/len(str(x['sentence'])))*100) ,axis=1)
#                                             search_string  start_time  \
# 0       başka biriyle herhangi bir şey yaşıyor musun k...         319
# 1       nasıl olduğunu gördün zaten artık değil mi tek...        2614
# 2       benim kızım tamam bir şey yapmış hata yapmış o...        3090
# 3       bir şekilde söylüyorum ve o zaman eminim ki ço...        4774
# 4       sıcak mı evet böyle işte tamam bir şey yok ora...         603
# ...                                                   ...         ...
# 233235                                     de bu da en az         807
# 233236                                     ki sen o da mı        2513
# 233237                                     şu an var ya o        2539
# 233238                                     o da bir de ve         699
# 233239                                      ne o da şu an         273
#
#         end_time                                           sentence  \
# 0            325  başka biriyle herhangi bir şey yaşıyor musun k...
# 1           2620  nasıl olduğunu gördün zaten artık değil mi tek...
# 2           3097  benim kızım tamam bir şey yapmış hata yapmış o...
# 3           4781  bir şekilde söylüyorum ve o zaman eminim ki ço...
# 4            612  sıcak mı evet böyle işte tamam bir şey yok ora...
# ...          ...                                                ...
# 233235       809         üçüncüsü de bu da en az ikisi kadar önemli
# 233236      2515  ama niye gözlerini belerttin ki sen o da mı sa...
# 233237      2540                        şu an var ya o dilini böyle
# 233238       701  o da bir de ve birazcık süreceğiz gibime geliy...
# 233239       275  formasyonu ne o da şu an aktif hale getirdim d...
#
#            video_id  include_string_ratio
# 0       KsZ_8oIQsv4                   100
# 1       N4YDaU51lvI                    92
# 2       CIQ3Ave21Kw                   100
# 3       cUAQrHbbpZ8                   100
# 4       Mh3bgDLKt2o                   100
# ...             ...                   ...
# 233235  c90800j_ED4                    33
# 233236  XNBOk8QO8I0                    26
# 233237  kulZ_sWzBR0                    51
# 233238  NBJpBvOxPYI                    16
# 233239  HgaAaBdkWks                    15
#
# [233240 rows x 6 columns]

# %%
df_word_group_time_loc_include_string_ratio = df_word_group_time_loc_in_sent_result_repeat_ratio[df_word_group_time_loc_in_sent_result_repeat_ratio["include_string_ratio"] > include_wordgroup_ratio]
df_word_group_time_loc_include_string_ratio.drop("include_string_ratio", axis=1, inplace=True)
df_word_group_time_loc_include_string_ratio.reset_index(drop=True, inplace=True)
df_word_group_time_loc_include_string_ratio
# Out:
# <ipython-input-94-ea709f90da2b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_word_group_time_loc_include_string_ratio.drop("include_string_ratio", axis=1, inplace=True)
#                                            search_string  start_time  \
# 0      başka biriyle herhangi bir şey yaşıyor musun k...         319
# 1      nasıl olduğunu gördün zaten artık değil mi tek...        2614
# 2      benim kızım tamam bir şey yapmış hata yapmış o...        3090
# 3      bir şekilde söylüyorum ve o zaman eminim ki ço...        4774
# 4      sıcak mı evet böyle işte tamam bir şey yok ora...         603
# ...                                                  ...         ...
# 54766                                    o da şu her gün         148
# 54767                                    o da bir şey mi        5691
# 54768                                    ay kız o ne çık        3471
# 54769                                    bu ay mı yok mu         199
# 54770                                    para mı o ne ya        6354
#
#        end_time                                           sentence  \
# 0           325  başka biriyle herhangi bir şey yaşıyor musun k...
# 1          2620  nasıl olduğunu gördün zaten artık değil mi tek...
# 2          3097  benim kızım tamam bir şey yapmış hata yapmış o...
# 3          4781  bir şekilde söylüyorum ve o zaman eminim ki ço...
# 4           612  sıcak mı evet böyle işte tamam bir şey yok ora...
# ...         ...                                                ...
# 54766       155                                    o da şu her gün
# 54767      5693                                 oo o da bir şey mi
# 54768      3475                                    ay kız o ne çık
# 54769       263                                    bu ay mı yok mu
# 54770      6357                                    para mı o ne ya
#
#           video_id
# 0      KsZ_8oIQsv4
# 1      N4YDaU51lvI
# 2      CIQ3Ave21Kw
# 3      cUAQrHbbpZ8
# 4      Mh3bgDLKt2o
# ...            ...
# 54766  GaCiHWyWkWg
# 54767  uB0TeB35l94
# 54768  p9GnFrcEy0o
# 54769  d4hmTrjuAk0
# 54770  TLv5OWfkU8U
#
# [54771 rows x 5 columns]

# %%
df_youtube_word_usage = word_usage_result(word_list, df_word_group_time_loc_include_string_ratio, "search_string", "video_id", word_usage_min, word_usage_max)
df_youtube_word_usage.drop_duplicates(inplace=True)
df_youtube_word_usage
# Out:
#                                           search_string     video_id
# 0             bunun neden böyle olduğundan emin değilim  zxznlmnXsoo
# 1     o yüzden yardım etmek lazım ona birkaç gün burada  ztZMp7dpRto
# 2         senin gibi birinin kızı olduğuna inanamıyorum  ztZMp7dpRto
# 3     gerek yok çok teşekkür ederim ben zaten birkaç...  zpfhmsZB26w
# 4                  çocuk buraya kadar geldi senden özür  zoN3xOGVjbk
# ...                                                 ...          ...
# 2984  peki birisi için mi yaptın yoksa oyun olsun di...  0AOYUEuSiyw
# 2985    anne niye öyle söylüyorsun herkes yapıyor artık  071PtpSHv5c
# 2986                        gelir misin buraya sakin ol  071PtpSHv5c
# 2987      tamam merak etme buradayım canım tamam geldim  05PK5asBrP0
# 2988                    merak etme kısa zamanda gelecek  05PK5asBrP0
#
# [2979 rows x 2 columns]

# %%
df_youtube_word_usage_merge = pd.merge(df_word_group_time_loc_include_string_ratio,df_youtube_word_usage,how="inner",on=["search_string","video_id"])
df_youtube_word_usage_merge.drop_duplicates(subset=["search_string","video_id"],inplace=True)
df_youtube_word_usage_merge.reset_index(drop=True, inplace=True)
df_youtube_word_usage_merge
# Out:
#                                           search_string  start_time  end_time  \
# 0     başka biriyle herhangi bir şey yaşıyor musun k...         319       325
# 1     nasıl olduğunu gördün zaten artık değil mi tek...        2614      2620
# 2     benim kızım tamam bir şey yapmış hata yapmış o...        3090      3097
# 3     bir şekilde söylüyorum ve o zaman eminim ki ço...        4774      4781
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...         603       612
# ...                                                 ...         ...       ...
# 2974                              üç dört beş altı yedi         246       250
# 2975                               tam on yedi yıl oldu        2505      2507
# 2976                               iki üç dört beş altı         468       477
# 2977                               sağ ol canım al şunu        6102      6104
# 2978                                ay sağ ol canım dur        6071      6073
#
#                                                sentence     video_id
# 0     başka biriyle herhangi bir şey yaşıyor musun k...  KsZ_8oIQsv4
# 1     nasıl olduğunu gördün zaten artık değil mi tek...  N4YDaU51lvI
# 2     benim kızım tamam bir şey yapmış hata yapmış o...  CIQ3Ave21Kw
# 3     bir şekilde söylüyorum ve o zaman eminim ki ço...  cUAQrHbbpZ8
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...  Mh3bgDLKt2o
# ...                                                 ...          ...
# 2974                              üç dört beş altı yedi  SApb3kjbZvs
# 2975                               tam on yedi yıl oldu  3f9swy52NkU
# 2976                               iki üç dört beş altı  7ueyRTf46No
# 2977                               sağ ol canım al şunu  GQgS2ruEJAs
# 2978                                ay sağ ol canım dur  HhxZTM_WB68
#
# [2979 rows x 5 columns]

# %%
df_word_count = word_count_result(df_youtube_word_usage_merge, df_youtube_word_usage_merge.columns[0:1])
df_word_count
# Out:
#           word  word_count
# 0           da         100
# 1        benim         100
# 2           ya         100
# 3           ve         100
# 4          var         100
# ..         ...         ...
# 963     olmalı           1
# 964      olayı           1
# 965        oda           1
# 966        ölü           1
# 967  olmalısın           1
#
# [968 rows x 2 columns]

# %%
word_set = set(word_list)
sent_result_word_set = set(df_word_count["word"])

# %%
word_set.difference(sent_result_word_set)
# Out:
# {'ajan',
#  'aldın',
#  'bayanlar',
#  'bayım',
#  'benziyor',
#  'canına',
#  'cidden',
#  'cinayet',
#  'dedektif',
#  'dek',
#  'ele',
#  'görünüşe',
#  'güvenlik',
#  'içine',
#  'kapa',
#  'kaptan',
#  'kara',
#  'olası',
#  'pekala',
#  'sanıyordum',
#  'sağol',
#  'sona',
#  'sonraki',
#  'taraftan',
#  'uyuşturucu',
#  'verici',
#  'yeterince',
#  'zavallı',
#  'çekilin',
#  'çeviri',
#  'üzerinde',
#  'şans'}

# %%
df_youtube_word_usage_merge["video_url"] = "https://www.youtube.com/watch?v="+df_youtube_word_usage_merge['video_id'].map(str)+"&t="+df_youtube_word_usage_merge['start_time'].map(str)+"s"
df_youtube_word_usage_merge
# Out:
#                                           search_string  start_time  end_time  \
# 0     başka biriyle herhangi bir şey yaşıyor musun k...         319       325
# 1     nasıl olduğunu gördün zaten artık değil mi tek...        2614      2620
# 2     benim kızım tamam bir şey yapmış hata yapmış o...        3090      3097
# 3     bir şekilde söylüyorum ve o zaman eminim ki ço...        4774      4781
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...         603       612
# ...                                                 ...         ...       ...
# 3021                               bi sakin ol gel otur         199       202
# 3022                               iki üç dört beş altı         468       477
# 3023                                on beş sene oldu be         401       403
# 3024                                i pek gibi oldum be        2091      2094
# 3025                                   e sağ ol be baba        3280      3282
#
#                                                sentence     video_id  \
# 0     başka biriyle herhangi bir şey yaşıyor musun k...  KsZ_8oIQsv4
# 1     nasıl olduğunu gördün zaten artık değil mi tek...  N4YDaU51lvI
# 2     benim kızım tamam bir şey yapmış hata yapmış o...  CIQ3Ave21Kw
# 3     bir şekilde söylüyorum ve o zaman eminim ki ço...  cUAQrHbbpZ8
# 4     sıcak mı evet böyle işte tamam bir şey yok ora...  Mh3bgDLKt2o
# ...                                                 ...          ...
# 3021                               bi sakin ol gel otur  LnoGaqALRvI
# 3022                               iki üç dört beş altı  7ueyRTf46No
# 3023                                on beş sene oldu be  vK7fxrBDlL0
# 3024                                i pek gibi oldum be  RCJjWkmMdD4
# 3025                                   e sağ ol be baba  vMxEQFO8teQ
#
#                                               video_url
# 0     https://www.youtube.com/watch?v=KsZ_8oIQsv4&t=...
# 1     https://www.youtube.com/watch?v=N4YDaU51lvI&t=...
# 2     https://www.youtube.com/watch?v=CIQ3Ave21Kw&t=...
# 3     https://www.youtube.com/watch?v=cUAQrHbbpZ8&t=...
# 4     https://www.youtube.com/watch?v=Mh3bgDLKt2o&t=...
# ...                                                 ...
# 3021  https://www.youtube.com/watch?v=LnoGaqALRvI&t=...
# 3022  https://www.youtube.com/watch?v=7ueyRTf46No&t=...
# 3023  https://www.youtube.com/watch?v=vK7fxrBDlL0&t=...
# 3024  https://www.youtube.com/watch?v=RCJjWkmMdD4&t=...
# 3025  https://www.youtube.com/watch?v=vMxEQFO8teQ&t=...
#
# [3026 rows x 6 columns]

# %%
df_youtube_word_usage_merge = df_youtube_word_usage_merge.head(2000)
df_youtube_word_usage_merge.to_csv(f"{lang_folder.capitalize()}_Word_Group_Max_In_Youtube_Sentence_{word_end}_Word{file_ext}.csv", index=False)

# %%
df_youtube_word_usage_merge = df_youtube_word_usage_merge.head(700)
df_youtube_word_usage_merge.to_excel(f"{lang_folder.capitalize()}_Word_Group_Max_In_Youtube_Sentence_{word_end}_Word{file_ext}.xlsx", index=False)

# %%
#df_word_group_time_loc_in_sent_result = df_word_group_time_loc_in_sent_result.head(1000000)
#df_word_group_time_loc_in_sent_result.to_excel(f"{lang_folder.capitalize()}_Word_Group_Max_In_Youtube_Sentence_{word_end}_Word{file_ext}.xlsx", index=False)

# %% [markdown]
# #### Copy Move And Delete

# %%
output_file = glob.glob(f"{lang_folder.capitalize()}_Word_Group*{file_ext}.*")
output_file

# %%
for k in output_file:
    source = k # source directory
    destination = path
    shutil.copy2(source, destination)

# %%
for i in output_file:
    try:
        os.remove(i)
    except:
        pass

# %% [markdown]
# #### Manuel Select Result Word Count

# %%
df_youtube_word_usage_merge_manuel = pd.read_excel("")
df_youtube_word_usage_merge_manuel

# %%
df_word_count_manuel = word_count_result(df_youtube_word_usage_merge_manuel, df_youtube_word_usage_merge_manuel.columns[0:1])
df_word_count_manuel

# %%
word_set = set(word_list)
select_sent_result_word_set = set(df_word_count_manuel["word"])

# %%
word_set.difference(select_sent_result_word_set)
