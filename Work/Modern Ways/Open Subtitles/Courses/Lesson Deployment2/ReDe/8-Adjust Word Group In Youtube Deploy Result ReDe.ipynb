# %% [markdown]
# ### Adjust Word Group In Youtube Deploy Result

# %%
import os
import multiprocessing
#import multiprocessing as mp
from multiprocessing import Process, Manager, Pool, Queue
from itertools import islice
from collections import Counter
import re
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize
from functools import reduce
from pathlib import Path
import shutil

# %%
nprocs = multiprocessing.cpu_count()
print(f"Number of CPU cores: {nprocs}")
# Out:
# Number of CPU cores: 16

# %%
# language pair
lang_folder = "Turkish"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> target language for learner
#lang_pair = "Arabic"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> native language

# source path
source_path = "/media/kurubal/SSD1/Data Scientist/Work/Modern Ways/Project/Turkish/Deployment2/Result/Deploy2 Result Manuel/Turkish"

# parameter
file = "Basics Cover the Most Master File"  # file without extention
sheets = "85 Sentence"  # 2 gram target, 2 gram hybrid
file_ext = "85 Sentence"
first_column = 2  # start column location number
end_column = 3

# native word select for Part 2 
word_start = 0  # 0  # native word start index
word_end = 200 # 28  # native word end index

# word all usage in sent
word_use_big_than = 1

# %%
def word_count_result(df,column_list): # df is dataframe, column_list is list value
    '''
    word_count_bool(df, column_list): df columns word count for word frequency\n
    df is dataframe, column_list is list value\n
    word_count_bool(df, ["word","twogram"]):
    '''
    list_all = []
    for i in df.loc[:,[x for x in column_list]].columns:
        var_list = df[f"{i}"].dropna().tolist()
        for j in var_list:
            list_all.append(j)
    text = " ".join(list_all)
    word_list = re.findall(r"\w+",text, re.UNICODE)
    df_word_list = pd.DataFrame(word_list, columns=["word"])
    #df_word_list.rename(columns={0:"word"}, inplace=True)
    df_word_count = pd.DataFrame(df_word_list.value_counts())
    df_word_count.reset_index(inplace=True)
    df_word_count.rename(columns={0:"word_count"}, inplace=True)
    
    return  df_word_count

# %%
def word_in_wordgroup(source_word_list, df_target, target_column, word_sample_num, simple=False):

    '''word_in_wordgroup(not_in_sent_word_list, df_youtube_sent_select, "search_string", 5, simple=False)\n
       source_word_list is searching word list\n
       df_target is dataframe, target_column are dataframe column string name\n
       word_sample_num is searching sample number.
       simple use for all column result or only target column result 
    '''
    if simple:
        df_select = df_target[[f"{target_column}"]].dropna()
    else:
        df_select = df_target
        
    df_result = pd.DataFrame()
    for i in source_word_list:
        try:
            word_in_word_cluster = df_select[df_select[f"{target_column}"].str.contains(fr"(?:\s|^){i}(?:\s|$)", na=True)].head(word_sample_num)    
        except:
            pass        
        word_in_word_cluster.insert(0,"word",i)
        df_result = pd.concat([df_result,word_in_word_cluster], axis=0)
    df_result.reset_index(drop=True, inplace=True)

    return df_result

# %%
path = f"/media/kurubal/SSD1/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/\
Deployment2/Result/8-Adjust Word Group In Youtube Deploy Result/{lang_folder.capitalize()}"

Path(path).mkdir(parents=True, exist_ok=True)

# %%
df_word_all = pd.read_excel(f"/media/kurubal/SSD1/Data Scientist/Work/Modern Ways/Project/{lang_folder.lower().capitalize()}/Deployment/Data/Word/Word_Merge_Preprocess.xlsx")
df_word_all
# Out:
#                 word  frequency
# 0                bir   18835735
# 1                 bu   11062659
# 2                 ne    8025880
# 3                 ve    7766036
# 4               için    5484109
# ...              ...        ...
# 987924     karneleme          5
# 987925       karnaya          5
# 987926   dörtlümüzün          5
# 987927  karnavalınız          5
# 987928      hurmanın          5
#
# [987929 rows x 2 columns]

# %%
df_word_select = df_word_all.iloc[word_start:word_end,]
df_word_select.reset_index(inplace=True)
df_word_select
# Out:
#      index        word  frequency
# 0        0         bir   18835735
# 1        1          bu   11062659
# 2        2          ne    8025880
# 3        3          ve    7766036
# 4        4        için    5484109
# ..     ...         ...        ...
# 195    195        saat     399989
# 196    196      onunla     399330
# 197    197  yapıyorsun     398274
# 198    198       neler     397377
# 199    199       ister     396177
#
# [200 rows x 3 columns]

# %%
df_file = pd.read_excel(f"{source_path}/{file}.xlsx", sheet_name=f"{sheets}")
#df_file.sort_values("search_string",key=lambda x:x.str.len(), inplace=True, ascending=True)
df_file.reset_index(drop=True, inplace=True)
df_file
# Out:
#                                         search_string  start_time  end_time  \
# 0   kendi şimdi sen mi ne oluyor biliyor musun bu ...         446       451
# 1   gerçekten uzun ve bu da benim için çok önemli ...         623       627
# 2   her zaman öyle değil herkes için de her zaman ...         559       562
# 3   çok iyi değil mi tam böyle gerçek gibi gerçek ...           3         6
# 4   nasıl bir şekilde olduğunu ve neden o şekilde ...          14        17
# ..                                                ...         ...       ...
# 80                                  en fazla iki saat         318       320
# 81                                   ol başka biri ol         281       283
# 82                                    şu adam şu adam         214       216
# 83                              bir gece çok kötü bir         822       824
# 84                     tamam peki pekala pekala tamam        1408      1410
#
#                                              sentence     video_id  \
# 0   artık hamill olması lazım altı kendi şimdi sen...  Yuu5VhJBIUg
# 1   bu tabletin şarj ömrü batarya ömrü gerçekten u...  r_9ngjGh2Ks
# 2   her zaman öyle değil herkes için de her zaman ...  cPoQ27hCNOU
# 3   çok iyi değil mi tam böyle gerçek gibi gerçek ...  OmT_BtZh8qU
# 4   şimdi apexin nasıl bir şekilde olduğunu ve ned...  owj1QZoYqFs
# ..                                                ...          ...
# 80                bu evde en fazla iki saat geçiririm  bt6fLjCmyvM
# 81                   mark zuckerberg ol başka biri ol  30Sd_IpkgK4
# 82                                    şu adam şu adam  mHkBxBLAZww
# 83  hayat mücadelesi verdiğimde bir gece çok kötü ...  eS84Pe23HMA
# 84                     tamam peki pekala pekala tamam  d9tZZGbLQMU
#
#                                             video_url  \
# 0   https://www.youtube.com/watch?v=Yuu5VhJBIUg&t=...
# 1   https://www.youtube.com/watch?v=r_9ngjGh2Ks&t=...
# 2   https://www.youtube.com/watch?v=cPoQ27hCNOU&t=...
# 3    https://www.youtube.com/watch?v=OmT_BtZh8qU&t=3s
# 4   https://www.youtube.com/watch?v=owj1QZoYqFs&t=14s
# ..                                                ...
# 80  https://www.youtube.com/watch?v=bt6fLjCmyvM&t=...
# 81  https://www.youtube.com/watch?v=30Sd_IpkgK4&t=...
# 82  https://www.youtube.com/watch?v=mHkBxBLAZww&t=...
# 83  https://www.youtube.com/watch?v=eS84Pe23HMA&t=...
# 84  https://www.youtube.com/watch?v=d9tZZGbLQMU&t=...
#
#                                       word_index_list
# 0   [133, 43, 19, 5, 2, 139, 109, 53, 1, 43, 168, ...
# 1          [70, 172, 3, 1, 15, 31, 4, 9, 156, 68, 67]
# 2         [30, 35, 46, 14, 173, 4, 8, 30, 35, 46, 14]
# 3       [9, 28, 14, 5, 112, 56, 183, 27, 183, 27, 60]
# 4                 [39, 0, 181, 40, 3, 34, 6, 181, 40]
# ..                                                ...
# 80                                 [44, 96, 110, 195]
# 81                                 [118, 71, 78, 118]
# 82                                   [48, 81, 48, 81]
# 83                                                NaN
# 84                                                NaN
#
# [85 rows x 7 columns]

# %%
df_file_count = word_count_result(df_file, df_file.columns[0:1])  # "search_string" column
df_check = df_file_count[df_file_count["word_count"] > word_use_big_than]
check_list = df_check["word"].to_list()
remove_list = []
df_file_var = df_file
for var_sent in df_file["search_string"]:
    result_list = []
    words = re.findall(r"\w+",var_sent, re.UNICODE)
    for word in words:
        if word in check_list:
            result_list.append(True)
        else:
            result_list.append(False)
    if all(result_list):
        df_file_var = df_file_var[df_file_var["search_string"] != f"{var_sent}"]
        df_file_var_count = word_count_result(df_file_var, df_file_var.columns[0:1])
        df_check = df_file_var_count[df_file_var_count["word_count"] > word_use_big_than]
        check_list = df_check["word"].to_list()
        remove_list.append(var_sent)
    else:
        pass

df_file_var.reset_index(drop=True, inplace=True)
df_file_var
# Out:
#                                         search_string  start_time  end_time  \
# 0   kendi şimdi sen mi ne oluyor biliyor musun bu ...         446       451
# 1   gerçekten uzun ve bu da benim için çok önemli ...         623       627
# 2   her zaman öyle değil herkes için de her zaman ...         559       562
# 3   bile yok bu da benim için aslında önemli bir ş...         131       134
# 4   için artık değil misin gerek yok bunun için si...          65        70
# ..                                                ...         ...       ...
# 57                                diye söyle bak hala         104       106
# 58                                lütfen ilk önce onu          21        23
# 59                                  en fazla iki saat         318       320
# 60                                   ol başka biri ol         281       283
# 61                              bir gece çok kötü bir         822       824
#
#                                              sentence     video_id  \
# 0   artık hamill olması lazım altı kendi şimdi sen...  Yuu5VhJBIUg
# 1   bu tabletin şarj ömrü batarya ömrü gerçekten u...  r_9ngjGh2Ks
# 2   her zaman öyle değil herkes için de her zaman ...  cPoQ27hCNOU
# 3   bulabilirsiniz şu an görünce bile yok bu da be...  aqQ7IUho9pA
# 4   göndermek için artık değil misin gerek yok bun...  gX77n13Qj0o
# ..                                                ...          ...
# 57  o taşlarını gecesi zor için yoğurduktan sonra ...  P5bYtFrqw68
# 58  videoyu izlemediyseniz lütfen ilk önce onu izl...  DWIzzc0OaIM
# 59                bu evde en fazla iki saat geçiririm  bt6fLjCmyvM
# 60                   mark zuckerberg ol başka biri ol  30Sd_IpkgK4
# 61  hayat mücadelesi verdiğimde bir gece çok kötü ...  eS84Pe23HMA
#
#                                             video_url  \
# 0   https://www.youtube.com/watch?v=Yuu5VhJBIUg&t=...
# 1   https://www.youtube.com/watch?v=r_9ngjGh2Ks&t=...
# 2   https://www.youtube.com/watch?v=cPoQ27hCNOU&t=...
# 3   https://www.youtube.com/watch?v=aqQ7IUho9pA&t=...
# 4   https://www.youtube.com/watch?v=gX77n13Qj0o&t=65s
# ..                                                ...
# 57  https://www.youtube.com/watch?v=P5bYtFrqw68&t=...
# 58  https://www.youtube.com/watch?v=DWIzzc0OaIM&t=21s
# 59  https://www.youtube.com/watch?v=bt6fLjCmyvM&t=...
# 60  https://www.youtube.com/watch?v=30Sd_IpkgK4&t=...
# 61  https://www.youtube.com/watch?v=eS84Pe23HMA&t=...
#
#                                       word_index_list
# 0   [133, 43, 19, 5, 2, 139, 109, 53, 1, 43, 168, ...
# 1          [70, 172, 3, 1, 15, 31, 4, 9, 156, 68, 67]
# 2         [30, 35, 46, 14, 173, 4, 8, 30, 35, 46, 14]
# 3         [59, 22, 1, 15, 31, 4, 174, 156, 0, 16, 68]
# 4             [4, 61, 14, 49, 117, 22, 97, 4, 121, 0]
# ..                                                ...
# 57                                [123, 161, 64, 167]
# 58                                  [58, 193, 51, 23]
# 59                                 [44, 96, 110, 195]
# 60                                 [118, 71, 78, 118]
# 61                                                NaN
#
# [62 rows x 7 columns]

# %%
remove_list
# Out:
# ['çok iyi değil mi tam böyle gerçek gibi gerçek gibi yani',
#  'nasıl bir şekilde olduğunu ve neden o şekilde olduğunu',
#  'burada böyle hayır öyle bir şey olabilir mi asla asla',
#  'bence çok güzel bence çok güzel senin zaten',
#  'biraz daha devam et devam et tamam oldu',
#  'kız seni gel buraya gel buraya kız gel',
#  'bakalım son olarak neler var neler',
#  'hemen ve her gün her dakika oluyor',
#  'aslında seninle birlikte orada',
#  'bakalım nasıl olacak ve buna',
#  'çünkü hiçbir zaman bana göre',
#  'ile hemen hemen aynı hiçbir',
#  'onları biliyor musun çünkü',
#  'size söyle merhaba merhaba',
#  'geldi ona kadar ona kadar',
#  'olsun ki sadece biz bize',
#  'bize lazım olacak çünkü',
#  'biri büyük biri küçük',
#  'tabii onlar tabii ona',
#  'olan oldu artık geri',
#  'tam başka en uzun',
#  'şu adam şu adam',
#  'tamam peki pekala pekala tamam']

# %%
df_result_word_count = word_count_result(df_file_var, df_file.columns[0:1])
df_result_word_count
# Out:
#         word  word_count
# 0        bir          13
# 1        çok          11
# 2      değil           7
# 3       için           7
# 4    bakalım           6
# ..       ...         ...
# 187   herkes           1
# 188    hemen           1
# 189    hayır           1
# 190    haydi           1
# 191     şunu           1
#
# [192 rows x 2 columns]

# %%
df_result_word_count["word_count"].sum()
# Out:
# 395

# %%
df_file_var.to_excel(f"{lang_folder.capitalize()}_{word_end}_Word_Group_In_Youtube_Sentence_Word_Index_List_Sample_Selected.xlsx", index=False)

# %% [markdown]
# ##### Not In Sent And Result Word Count

# %%
set_result_word_count = set(df_result_word_count["word"])
set_word_select = set(df_word_select["word"])

# %%
not_in_sent_word_list = list(set_word_select.difference(set_result_word_count))
not_in_sent_word_list
# Out:
# ['pekala', 'devam', 'adam', 'et', 'asla', 'bence', 'merhaba', 'gerçek']

# %%
df_youtube_sent_result = pd.read_excel(f"/media/kurubal/SSD1/Data Scientist/Work/Modern Ways/Project/{lang_folder.lower().capitalize()}/Deployment2/Result/\
2-Word Group In Youtube Sentence/{lang_folder.lower().capitalize()}/{lang_folder.lower().capitalize()}_Word_Group_Max_In_Youtube_Sentence_200_Word6.xlsx")
df_youtube_sent_result
# Out:
#                                             search_string  start_time  \
# 0       bilmiyorum belki hiçbir şey olmaz belki çok şe...         381
# 1       yardım yapıyorsun çok teşekkürler çok zaman he...        1222
# 2       ya böyle bir şey olabilir mi ya ama bir şey ol...         466
# 3       çok güzel bir dakika bir dakika bir dakika bir...         525
# 4       senin için önemli olan tek şey hala burada bil...          84
# ...                                                   ...         ...
# 187595                                          o da o da        7102
# 187596                                          ol o o bu         244
# 187597                                           o ne o o        3947
# 187598                                           ol o o o        2258
# 187599                                           mi o o o         419
#
#         end_time                                           sentence  \
# 0            385  bilmiyorum belki hiçbir şey olmaz belki çok şe...
# 1           1230  yardım yapıyorsun çok teşekkürler çok zaman he...
# 2            480  ya böyle bir şey olabilir mi ya ama bir şey ol...
# 3            531  çok güzel bir dakika bir dakika bir dakika bir...
# 4             88  senin için önemli olan tek şey hala burada bil...
# ...          ...                                                ...
# 187595      7103                       ha o da o da iptal peki peki
# 187596       250  abone ol o o bu çocuğumuz sünnet ettirme ne iz...
# 187597      3948            o ne o o i lyasın yanındaki ayşen mi ya
# 187598      2260                                     abone ol o o o
# 187599       428                                           mi o o o
#
#            video_id                                          video_url
# 0       L3bf7dlR5hk  https://www.youtube.com/watch?v=L3bf7dlR5hk&t=...
# 1       zgQbOmPp9pk  https://www.youtube.com/watch?v=zgQbOmPp9pk&t=...
# 2       duaQwKTmgvE  https://www.youtube.com/watch?v=duaQwKTmgvE&t=...
# 3       OZhgDD1ScBg  https://www.youtube.com/watch?v=OZhgDD1ScBg&t=...
# 4       9Wx3JJTq_Hw  https://www.youtube.com/watch?v=9Wx3JJTq_Hw&t=84s
# ...             ...                                                ...
# 187595  8DYpvzyEVg0                                                NaN
# 187596  oixYiG0tGgo                                                NaN
# 187597  D6Va3TXwFEQ                                                NaN
# 187598  K0b_9Xzy79A                                                NaN
# 187599  5ofdGcvaeZU                                                NaN
#
# [187600 rows x 6 columns]

# %%
df_not_in_sent_selected_word_list_result = word_in_wordgroup(not_in_sent_word_list, df_youtube_sent_result, "search_string", 20000, simple=False)
#df_not_in_sent_selected_word_list_result = not_in_sent_selected_word_list_result.drop(["word"], axis=1)
df_not_in_sent_selected_word_list_result
# Out:
#         word                          search_string  start_time  end_time  \
# 0     pekala  pekala pekala tamam tamam haydi kendi        2303      2306
# 1     pekala     pekala o zaman ben sizi daha fazla        4442      4445
# 2     pekala         tamam peki pekala pekala tamam        1408      1411
# 3     pekala         pekala teşekkür ederim o zaman          36        39
# 4     pekala         tamam peki pekala pekala tamam        1408      1411
# ...      ...                                    ...         ...       ...
# 6733  gerçek                        ne bu gerçek mi        5131      5132
# 6734  gerçek                        bu gerçek mi al         794       801
# 6735  gerçek                        gerçek mi ya ne        1471      1473
# 6736  gerçek                        o da gerçek bir         182       185
# 6737  gerçek                        ve gerçek şu ki          69        73
#
#                                                sentence     video_id  \
# 0     pekala pekala tamam tamam haydi kendi işlerim var  Wp7JJK2jToU
# 1         pekala o zaman ben sizi daha fazla tutmayayım  Qb80uEMXEmE
# 2                        tamam peki pekala pekala tamam  d9tZZGbLQMU
# 3     pekala teşekkür ederim o zaman youtubenin bu v...  By626Hmvvt0
# 4                        tamam peki pekala pekala tamam  GdJVLA16hUc
# ...                                                 ...          ...
# 6733                       ne bu gerçek mi anlatılanlar  6eBEz91Zwh8
# 6734                                    bu gerçek mi al  pvcitd4fH2w
# 6735                                    gerçek mi ya ne  kulZ_sWzBR0
# 6736  türküsünün yaşandığı yer o da gerçek bir hikay...  vLe62fNrI7A
# 6737                                    ve gerçek şu ki  1OfndHcbYFo
#
#                                               video_url
# 0     https://www.youtube.com/watch?v=Wp7JJK2jToU&t=...
# 1     https://www.youtube.com/watch?v=Qb80uEMXEmE&t=...
# 2     https://www.youtube.com/watch?v=d9tZZGbLQMU&t=...
# 3     https://www.youtube.com/watch?v=By626Hmvvt0&t=36s
# 4     https://www.youtube.com/watch?v=GdJVLA16hUc&t=...
# ...                                                 ...
# 6733                                                NaN
# 6734                                                NaN
# 6735                                                NaN
# 6736                                                NaN
# 6737                                                NaN
#
# [6738 rows x 7 columns]

# %%
#not_in_sent_selected_word_list_result.groupby("word")["video_id"].apply(list)

# %%
df_not_in_sent_selected_videoid_list = df_not_in_sent_selected_word_list_result.groupby("word")[["video_id"]].agg(lambda x: set(x))
df_not_in_sent_selected_videoid_list.reset_index(inplace=True)
df_not_in_sent_selected_videoid_list.sort_values(by="video_id", ascending=False, inplace=True, key=lambda x:x.str.len())
df_not_in_sent_selected_videoid_list.reset_index(drop=True, inplace=True)
df_not_in_sent_selected_videoid_list
# Out:
#       word                                           video_id
# 0    bence  {dNbOwo0XPwE, d9tZZGbLQMU, P_Fu2hIxc9o, FdcrtO...
# 1     adam  {qWG21pLc2fw, fB8Az8AuS8s, d9tZZGbLQMU, ML10ds...
# 2       et  {G_VBKWCoQTo, d9tZZGbLQMU, dXqn8xhYSr8, BFrL0j...
# 3    devam  {le2FL3oKDfE, d9tZZGbLQMU, dXqn8xhYSr8, FdcrtO...
# 4     asla  {qWG21pLc2fw, 4kk4uXOc_1Q, FdcrtOMslHI, MIzN8O...
# 5   gerçek  {dNbOwo0XPwE, mMfE4oYhLzg, uNUrvGrdsQ8, OKeOx2...
# 6  merhaba  {bTDD2nj0BYM, LQ7ispbi_6U, 9GbYnL0tvcg, 15AOCt...
# 7   pekala  {xcitAtuxPCk, d9tZZGbLQMU, hLOOwsxDBJo, qmMZmy...

# %%
videoid_list_group_list = df_not_in_sent_selected_videoid_list["video_id"].to_list()
videoid_list_group_list
# Out:
# [{'dNbOwo0XPwE',
#   'd9tZZGbLQMU',
#   'P_Fu2hIxc9o',
#   'FdcrtOMslHI',
#   'Oz7FkuxsmJU',
#   'MIzN8O6pfmA',
#   'NV_G6wX2xtQ',
#   'uNUrvGrdsQ8',
#   'lfmUF6cUFfU',
#   'ko2ksKJtphI',
#   'bwlFUCVl2d0',
#   'liPZA3Zdvig',
#   'fhCv2PjqkFw',
#   'cFeee5Tcf4s',
#   'LsdkfH4cIqM',
#   'DP3nFc6WMYY',
#   'dhZbOwKw7wg',
#   'uEH4jrxGgAk',
#   'b_y907ixB08',
#   'fcxSmwjtuAA',
#   'zzXTIIo7EvM',
#   'VjS5hmgV4qI',
#   'Uxv88I7nKXw',
#   'r4o0Vg6NQNc',
#   'IbkoW6_fesk',
#   'eypQZvq_52I',
#   '5MufL43DkcM',
#   'pcAhoVDv2Gs',
#   'lu2RFs4xRuA',
#   'yBHDgyFceSs',
#   'Hf2BNlWDDRU',
#   'CJhu53w6Zq4',
#   'h_ZbadF7tIA',
#   'BPWJGcTkw28',
#   'ixUx5MhHzvw',
#   '6NFjjfvQ7ZQ',
#   'jTa54byZKHg',
#   'Uv0cwJd6KVw',
#   'JghIp4n7Uxc',
#   '071PtpSHv5c',
#   's0zbkx_9T0M',
#   'OHoW8_47ilY',
#   'TVwC7Pb_N0s',
#   'ZJ_KUlTY7nM',
#   'ijbh9WJ6Aw0',
#   'EDJh1X6oOXk',
#   'eBNwx79Zdwc',
#   'FGjL3tQ6vN0',
#   'UctkmnbuBIA',
#   'h6K5K0Qktu8',
#   'wsWnhczse10',
#   'kolVH5PDzI0',
#   'XjIzyvw_UMA',
#   'tmPcuRQ0AVA',
#   '_JDO9FKXZ88',
#   '9uEGE4v9ROM',
#   'EO4RHGzuFsw',
#   '_Js9kaGp1tE',
#   'JrJs2vfea4g',
#   'gm9X3qR1GRI',
#   'TawfVjq0fxM',
#   'qF4qaLRHjHI',
#   'XvkQBrWnbF8',
#   'wXZVCz3WhLw',
#   '_FsOnRDIJQQ',
#   'VHQ9gRn_RpQ',
#   '_IimozO_x50',
#   'uJmiKNXgBAk',
#   'dhV8ToP5VTQ',
#   'S73oaKSsvtQ',
#   'C_IXiaaAow8',
#   'DKljy1DyRcQ',
#   'yClpnQgYCSA',
#   'kQ4Y6EPljPk',
#   'O5raFzyCm70',
#   'TSqEmpzSLYA',
#   'zaq5J5endq0',
#   'Si_Th9uzHmY',
#   'O3iT4_8jUVw',
#   'PgSFJIfd67s',
#   'QXOP9pviJ58',
#   'MXciFLdLVSY',
#   '1iByM08MvqU',
#   'Pirq9B1GIAc',
#   'iOYSx0suPrY',
#   'DjyZKZmShIc',
#   'ozaCwmUvl4A',
#   'xGee6eTzY3s',
#   'RuVVxns8wh0',
#   '5B5lpUACeBE',
#   'sZQ8tF5UHdU',
#   'g9s7UhT22Uc',
#   'fhG1ArBe_uU',
#   '0ClPSPNTOIY',
#   'OImI_S8C2vo',
#   '9J7s6l7Ob4Q',
#   'YSH2xuNak44',
#   'XKdYDel5rMI',
#   'xagFSGk8vT4',
#   'shBaEhGS1Bk',
#   'zFKMGKSS48c',
#   'JaKhDtaIyvU',
#   'bcFElYG4asM',
#   'so3c6vWInWY',
#   'ueD4RlDqxz0',
#   'JNu3JUv5ceA',
#   'fMKR_0Cqnyg',
#   '4C_h8ZyIXdc',
#   '6W0SwUSwuFg',
#   'KV8e9IvyVi4',
#   'qy1MXQn6M6k',
#   'R8kPUKlJtBk',
#   '6YWjiAAowKo',
#   '1Nc4d_tmiGY',
#   'NCSbC9Ma6ps',
#   'FUS0hsPCtMs',
#   '9eYN0BDyLFM',
#   'KC4dx3NyO_I',
#   'tn5QG7h48xU',
#   'pGgYpcKg0Gs',
#   'ocq_09p_92U',
#   'w25yutHRugA',
#   '329uDNTb33g',
#   'poaw32nV1_A',
#   'dChbp9GjGyU',
#   '2wRFVUx8IoM',
#   '6RBRUDvbHGM',
#   'AvfpnsqaWw4',
#   'Yuu5VhJBIUg',
#   'z5gne255PHY',
#   'YZtqeg5Rhjs',
#   'V9w9RE4zg7U',
#   'ne_t7rBCcDw',
#   'ps5hj273iCo',
#   'ZLTP8QiCouw',
#   '347g9fKfT6Q',
#   '9EaLkRsP3Ps',
#   'J1lq1KN0NtQ',
#   'ZOFFYeumtfA',
#   'lsciLyjICMk',
#   'le4xXuWUIoc',
#   'ANd2wYIi8oU',
#   'vA4ywYo4QbY',
#   'EFEFEcYl9es',
#   'OZEyapxyZZM',
#   'uiwgbWJfTyE',
#   'y8S06fxzhNk',
#   'JA4fcNdKTZk',
#   '9iBhLq7p_Xk',
#   'Y5ftLlQOZlo',
#   'zV5ipnhf9xs',
#   '3sqBlmCqhpY',
#   'SzFGh9iLndY',
#   'x4ioRas_9l8',
#   'um1pjcGH6XU',
#   'Wd69L0vmaOQ',
#   'od_ZPJBFYUA',
#   'pLifvTWuvHg',
#   'BaRN5FQboew',
#   'LmY6NZwmSa4',
#   'WL6Wh39Gd74',
#   'rUafZNR1GxY',
#   'SGt85ZPH1Gk',
#   'sDR1xwXjMuE',
#   'Lb1vJOrnztM',
#   '3RGVTogMjgY',
#   'EmJ8TQY5dTY',
#   'mOZyr4Z_B_k',
#   'R5Em8Z2Pfjo',
#   'fvDwiICHh0M',
#   'HqfHP96C4hU',
#   'GEbWT0HUnfw',
#   'l4QeCalIl6E',
#   '94KUKlC1rlc',
#   'p1rtR61NICs',
#   '8dOdIN_E8fo',
#   'bIH7u90sJ3Q',
#   'Eqq4fciITJw',
#   'kCf15d2KbBo',
#   'HNKY3MHRejY',
#   'zoS5vEIsOrc',
#   'XfOXG9viUEY',
#   'ffh6W9qSBOc',
#   'Kze2x40RihY',
#   'vR7Z8aQKWEs',
#   'HhLIORa1NKg',
#   'aLY7EZoOlVo',
#   'b3FkvFd0MGg',
#   'W39aHZ6Kago',
#   'nNlk_65StfQ',
#   'uLIQAbifOME',
#   'djPS3OL3xEQ',
#   'fzryjql82so',
#   'tHYbkdWVUMg',
#   'gUrC6ydtQ2c',
#   'Qhhka9zIUzI',
#   'mUqgywfJJfQ',
#   'qe8TjfIqZ8Y',
#   'l3eppPkUMbk',
#   '6HX5dmPKqWQ',
#   'a5oQSIf9isU',
#   '5T1gZdTgXPI',
#   'xSphOvstqUc',
#   'e7RXMoofC1A',
#   '4UhIXjsL79Y',
#   'ag2ISgNp8fA',
#   'L_kkRc7s_6M',
#   'UojljloKmhI',
#   '4KEKZEIs344',
#   'PZ5IZowCuRk',
#   'WMvs2VZLSBQ',
#   'h93wXNLXmYU',
#   'opSsU5jHHJw',
#   'qvYbytv5ZhI',
#   'Yr2ZLfWT0i8',
#   'twGX5mN6Mcs',
#   'jWVWwpm_IHw',
#   'pXGCTXMKs0k',
#   'OBQ4Oqmi_tc',
#   'o1BNtH2rqY0',
#   'eVrZx6gM24U',
#   'wXjCShrqs8E',
#   'BqEjGUX0Yvk',
#   'NZpTKY0bqpk',
#   'Bbaal2Neohk',
#   'hxFlyzshFaA',
#   'VTl4pJ9Fdgs',
#   'ynjLf2AW7dg',
#   'Rm6zwwnAVeA',
#   'FvvNyw0607o',
#   'luk67hdsDus',
#   'O7nYQ11gG9s',
#   'TyzfA87Zboo',
#   'HixnqAdS2YM',
#   'oD7GlhIvAlM',
#   'lcAWcDLMPJc',
#   '2com040xmrI',
#   'YN6xuSz86PA',
#   'HXB7HUg7Mks',
#   'QpjmOepR95c',
#   'K_y7fyVMht0',
#   'Y26YgIFEQcw',
#   'd_5S0x4eWi4',
#   'kWFEKLDshAg',
#   'oeObDZcQxK0',
#   'hS1Jn4JeHzs',
#   'rswMSVdJqdA',
#   'YlMvSr2W_wo',
#   'P93YSUoCMd0',
#   'WL496X8YpS0',
#   'wuF2ZxXGN8c',
#   'yMyAtgLnFzo',
#   'aAorMpDd9ok',
#   '_DDeF00hglI',
#   'KtM2vZRvxnE',
#   'TVy2hkF_G9c',
#   'tJQFiCOLO8E',
#   'kOrLi7wQWwM',
#   'XONa6eDkoZ8',
#   '1iMSdRfy0Nk',
#   '_Ya18fCiA0k',
#   'YDz1CKcddSE',
#   'hd3QRlRM6xo',
#   '0PObnwYVPLw',
#   'Ho8bmMTZKjI',
#   'earwXiKop_w',
#   'fJEqh1YLGes',
#   'zj5ynCM8vKI',
#   'pcY_LT4GbbY',
#   'EyxjFfK2GWA',
#   'KVCZbb3svSc',
#   'dHohXDBK3KI',
#   'qCQI10Hkf30',
#   'sItRQL43F6U',
#   'Aii8sJ5Uw_8',
#   '0VppXfycGc8',
#   'Oz9wJkWAEec',
#   's6XPg87do4g',
#   'KKZmPCvc98s',
#   '5Uz5LVKEYYU',
#   'NAOjsIU2Y7E',
#   'DQHN3D_W_J8',
#   'GdJVLA16hUc',
#   'XREYOwgg6Uk',
#   'kbxqTZOFsX4',
#   'Vpmg0GAshHU',
#   'vleTt0rWGw4',
#   'S3_ocI0xUEk',
#   'tm0ilmgKAww',
#   'qzLawMz8ZG4',
#   'Mh3bgDLKt2o',
#   'itmwL5TYKgs',
#   'sdw58rC22GY',
#   '5BzYdU8fqwM',
#   'g6jbONgF8IU',
#   'EoPkx6FoSRg',
#   'kOct90tfkXQ',
#   'sX7jAW0onSE',
#   'LxuQYorE1jQ',
#   'qWScoyOl7Ds',
#   'AuHMcuN82y8',
#   'PLMQWYGJuVQ',
#   'tU1Mv8UkyR4',
#   'CmoGZ3DBmr4',
#   'rkJflxmHxIE',
#   'QTY7qBMdetU',
#   'R2C3fHcNm1k',
#   'gA6hUM1qDGY',
#   'JLYu46L6sgI',
#   'Qj56ae6DwAQ',
#   'WKcMQmdFU34',
#   'UrEJ7oAhcX8',
#   'B_DJOqGf8Lw',
#   'H0QznezgnNk',
#   'mw0asrBhp0Y',
#   'ylA9LrcU9vo',
#   'G16TpbnSpFw',
#   'UoSoiAt_VQM',
#   'ofwzLS_BNw0',
#   'tGmPoySBZvQ',
#   'S7gctHEy2k0',
#   'd73g1XrUYxE',
#   'BhGXfFsxgsQ',
#   'rH5PqTOIt6Q',
#   '2bDTSTyktqE',
#   'rQhGmJxi_s4',
#   'rXq5yNXIAac',
#   'EpGPLDrpiFA',
#   'akoFjM1_p2o',
#   'gl486Y5GB0w',
#   '480nF81vFI0',
#   'X8C6vUzsIHU',
#   'DoCN8XTwZFo',
#   '_l6NM6NEKdI',
#   's0s07c3YGdk',
#   'OeHxe75lMNE',
#   'crxe2d7kvvg',
#   'L46PgskDnDQ',
#   'aHVLZEB2juA',
#   'FUH7m6tHgm0',
#   'MJtGR4MDI4M',
#   'X7D_dmahSD0',
#   '3EBHjo8rngQ',
#   'oiL9WkdhHLY',
#   'jNTZDRtKZqs',
#   'fLLBXUcWZDg',
#   'SmIaXMtgO2I',
#   'Wf1rn1FL8hY',
#   'DqJoXQHy0cU',
#   'iVtaHvUDLC4',
#   'rcuYVyP47jw',
#   '1W_hRD7WBGU',
#   'NukjvrVDkks',
#   'OEBlxyKWlh0',
#   'k94r8UG9LsU',
#   'nHe1MZ9BJyY',
#   'kYJSv6u4qHI',
#   'goOctWXJFYU',
#   'mWSkub3K_ps',
#   '5ys2TcUElHw',
#   'zxznlmnXsoo',
#   'DmRbWV_6v74',
#   '4FWxiXCnMf8',
#   'n3TXgjx0128',
#   'vLkbW6uukDU',
#   'h_FfxeLeMOc',
#   'mpg2dM5DrGg',
#   'VPBnPZol_nU',
#   'sKaz_zTOqx4',
#   'CgESCTp0UqI',
#   'SuEaiSpdlIc',
#   'CpCJuA2U3wg',
#   'JwO9OFItyzg',
#   'IF78KAsksbQ',
#   'JD98sOCBkVM',
#   'TGvJRDIey5s',
#   'uGP2vRun1Q8',
#   'hbo7XlB0FWA',
#   '_1usEcWvo8A',
#   'D_yb9_19sEo',
#   'WcRHKUhrmHQ',
#   '9Ez5806fqiw',
#   'gifDZ53zR3I',
#   'mvpMmzgcQSA',
#   'uLM3hC_A9B0',
#   'wEc24CZ97kI',
#   'lS43t9rPqmM',
#   'eS84Pe23HMA',
#   '9k02Yj8lIKM',
#   'U1b6PKLSS74',
#   'aHBaWrd09KY',
#   'TOo7_nW4dfI',
#   'P85qoxqS00Q',
#   '64YqHeWhhsc',
#   'Uc3awVv1I5Y',
#   'SUHivc0n3DE',
#   'P_Xncte6zqg',
#   '66Oih2dmURc',
#   'w_6WwWmaDsU',
#   'OPzhVWt1D9A',
#   'bt7g4VoVBoE',
#   'I3OqgGOIctw',
#   '6x8l5sLCKnc',
#   'UKVile_HpwQ',
#   '9PHCaxokNXo',
#   'BXjgkS7gsn8',
#   '2tAVAcdOhNM',
#   'V4__ydgTkaI',
#   'tjjnxvFOzig',
#   'zI2VldmdTM4',
#   'iMj5gB0XHRw',
#   'UEUJAgUgP_Q',
#   'AMdNsGoLM8w',
#   'awA8QjEncEU',
#   '9kTRJ3ULX18',
#   'NxpCRpuABsw',
#   'hWdU5vcjMxU',
#   'beemj3cm_5E',
#   '7mJCChriUjM',
#   'xUoSs0TlJVE',
#   'xai6ZoFUQxo',
#   'i4cQkYkr8Lo',
#   'r9oUL6syDB0',
#   'm3smE8dAzo4',
#   'cABj7BBhFd8',
#   'LahgXhqBM10',
#   '9QnUxnhVK8o',
#   'i_g1f4QurKs',
#   'lrLbXImf8rk',
#   'vKlNZYljG_8',
#   '1f77ar1m7Ks',
#   'dpyxmIPS1Sw',
#   'RqNXm3Vjxzc',
#   '4BBQyegIQWQ',
#   '7OkGQu0jNMM',
#   'OE8ujtE5ybI',
#   'qQUZ5d5mpWk',
#   'ggK_kABWOdw',
#   'LwmbPWjegxQ',
#   '2ZgDKJ7NS00',
#   'f69FZ66NvGU',
#   'mcLH22Uot6o',
#   '2YDi0RGGmRg',
#   'XswBqDSbWjI',
#   'jkQGssMH0Us',
#   'Odbd1stkcRk',
#   'GgZXKb2rRKc',
#   'TrgPuJHj7p8',
#   '9aO3H_YIiwY',
#   'uRvMnq_rk8k',
#   'XDqC6HwrKTg',
#   'gVOllvdKurs',
#   'TOCCUCfrz0M',
#   'bRIjl3yF01U',
#   'es2HApj6HwY',
#   'R02ljlzvh_A',
#   'smqSkXg1LXI',
#   'DOZcEJMIquY',
#   'KMmowTGPzRc',
#   'aKhqwoPQ9W8',
#   'Ip3v1Hdc65w',
#   'IC2wYIX8kx0',
#   'eoZYflUA7sQ',
#   'pTTVH1RZDp0',
#   'uB0TeB35l94',
#   'YxrdvRRPMfs',
#   'k0H95JbwIM8',
#   'I6CN51om8ZU',
#   '6KZ9VI5Yo5k',
#   'MgIFbO_BmaU',
#   'oYykJu6A7Dg',
#   'ANjeNt_WFUU',
#   'VUb5yWYww90',
#   '5e5vf1WrQYg',
#   'DcameSrKBOM',
#   '5JYPsDsH3oc',
#   '9WHt1TSQKf4',
#   'ZfzVwcLSzIk',
#   'R7WCewA1O_o',
#   'sHxCuGD9F88',
#   'RRZzlj4qGCw',
#   '_lk2xErspiE',
#   'z0ZcKLV6Hcs',
#   'HjuzPWNQeP4',
#   'ejpcV0S9ibo',
#   'ZdeFof81xKs',
#   '_fnQ4MhtREE',
#   'f694PFHVMFM',
#   'c1XcJdwSbLg',
#   '61v7xkFFvFA',
#   'P8R_Lwa33rs',
#   'jKrBnCmdlZE',
#   'Sj5vhnLGKHc',
#   'CLhbDUJgvFo',
#   'oCsHNgql560',
#   'B8Tal07cM8M',
#   '16VUS6il8qU',
#   'Xngssqf4zuw',
#   '9WyllWm0KmM',
#   'xDyuUiBsabQ',
#   'Sa8nJcrmBp0',
#   'PesN3EHzy3I',
#   'sRRlYasWUaM',
#   'HUOfxMca268',
#   'olhVVjfKC4s',
#   'mV0Za81wwU8',
#   'gRgeisH8yAA',
#   '8ZVy5PWwXis',
#   'M_XAY49dFV4',
#   'JpC4tST1ReQ',
#   'JWrpgQhFgK8',
#   '2wbsVBy9IMI',
#   'viTrbKvW7bA',
#   '5DpBItxxFws',
#   'tw5QQnxltOI',
#   'dD3A1IseY00',
#   'nMSrzqjAFfs',
#   'AjigBllg2bk',
#   'KrLItbrSnZs',
#   '4nlVqcAmMco',
#   'qKdeiL8Zrsg',
#   'gzOhOZQ8DgY',
#   'ZsXzvkDqmIk',
#   'qlD2vNmS5e4',
#   'QIkbhrCuWe4',
#   'AVsf2P0g1MU',
#   'lNwXQrpMfhM',
#   'qLl2eNRvt70',
#   'rAkxQk_SimU',
#   'oGcBTMuRqZw',
#   'j3dNiexsiRw',
#   '9gNCrNxBHt8',
#   '7pgJFwOBqaQ',
#   'BDUqLR_dd8Q',
#   'iZjzaNo_vDk',
#   'ohnzxn1P7io',
#   'tInqFBTWGoQ',
#   '9h5OFgs3BQo',
#   '9xE7220oTTk',
#   'NCYLETT8EXI',
#   'Su_bfE13oc8',
#   'zXR_pFRSE7s',
#   'narvrRi001U',
#   'ndssE4SMOaA',
#   'oiLvMET2Wrs',
#   'Ks19MD2LRUw',
#   '9K5pIUPkTmA',
#   'K5GIun0flM4',
#   'x0YH_9VSFus',
#   'H70I2mlLQFI',
#   'Qp10YEd7RyI',
#   'eQZssVr1Y64',
#   'ECMOxsNNmpY',
#   'cUChcCBmNGw',
#   '1OzBRPolzfU',
#   'sUhXp_XnXgE',
#   'D9xCnT7yFAI',
#   'UY5j2f90KaY',
#   'mQUinrfsVkM',
#   '8GCGRdwg80Y',
#   'OIS8cAZNmdI',
#   '3ogB_jaW4FI',
#   'kN1tvTnShzU',
#   'T1FQjm8T4Hw',
#   'jmB5ptZBi3c',
#   'eHtgG748qhI',
#   '0K6BSU1IqS0',
#   'elrghRMZY3I',
#   'kulZ_sWzBR0',
#   'ismSbk7x33Q',
#   '6TGH_yi9JiQ',
#   'PY5VYx2TUos',
#   'h37Xcn1BTOE',
#   'bIrJMI1eSK4',
#   '1KN8foDEwQs',
#   'XhpHvhIeSso',
#   'Gb1mMsZGb9A',
#   'Uh9XPrYJeKE',
#   'tTLcZy2D2hk',
#   '7B4IaUoAffQ',
#   'rZCZjuqkagQ',
#   'JfEl_wc7WiE',
#   'MdMDS31Mul4',
#   '8_VkxmHeMAk',
#   'g81mNCrBnO4',
#   'agAUR7SzzH0',
#   'tc6rSVC3QJs',
#   'n4dSJgjRUAM',
#   'dRssR_apbR0',
#   'L0Txo5QR7Rw',
#   '8cU1k2ylhF4',
#   '5Tr1TSSuowY',
#   'Qb80uEMXEmE',
#   '16gxQE8C1p0',
#   'Oue2H9hPYLA',
#   'yVh21IsS_JQ',
#   'tkSBNGHyksQ',
#   '1WaWFqtUsjU',
#   'fzMD9GjvcSY',
#   'mZuUdSQIrcA',
#   'SA3R1HniCoM',
#   'EyQTMdxuqSs',
#   '3uvwpm5XfNk',
#   'sFmok9tBwuc',
#   'OfK1BgCxRbE',
#   'QMEyg4HluPM',
#   'adhxDVmBAaE',
#   'aJ0j_xZxVBc',
#   '88X1K2jiCbQ',
#   '_Xtfh7OGcGM',
#   'de9wmUKoZxI',
#   'Yc1Yleb4Hz4',
#   'IbNzJFmtkZ0',
#   'Ejb6HObUkeI',
#   'Of8aDHV2A1w',
#   'wQgA2PCdg1U',
#   'SRtSBaFd8Ek',
#   'tN1putCohn4',
#   'ry0hEicwuhQ',
#   'VmFgMqSkA78',
#   'UwxskjOFO2Y',
#   'WXOpDJ78984',
#   'pLAuteGBNoc',
#   'buAn47zBd3U',
#   'zJMggnPkep8',
#   'i7RrNTLaaGE',
#   'MEW9uH5mfBQ',
#   '8vpg6d_fGv8',
#   'h43bURok9aY',
#   'u3caNTZeKqE',
#   'kRyvp9_y6Ek',
#   'b8XqeZgy9QY',
#   '_tQc8fwv7cM',
#   'KQTQdEj1JqI',
#   'EvSVykyXNGE',
#   'MOH8b4moNLo',
#   'ot0LKuAhBKk',
#   'tpAqsybia0E',
#   'qolPvF5Sq2k',
#   'YUcrsJAR3Ck',
#   'isXHFk5a63A',
#   'B3ZakJ4O5uw',
#   'nYpniobItLY',
#   'eBKS1dCabuI',
#   'yh1c1vaAiYE',
#   '3LDpq53oV0o',
#   'XcJfbADgIhs',
#   'VbFwNDsUMBU',
#   '7AW4dTcgyRk',
#   'i7bA1qFLC_E',
#   'g1Vag7OgCXw',
#   'G82kzhYUINo',
#   'eFKv8712V4w',
#   '_UFzaVIg1Gc',
#   'lgTWjX83MqQ',
#   'T3WKGqIXBnU',
#   '0BoH9Zih2vA',
#   'QyJBnfh233A',
#   '3yS8pSsVZH8',
#   'mpMUBJL01Hw',
#   'Lhb_Qerye5M',
#   '5yKRIMdIAoI',
#   'n3HmgraEOJA',
#   'H4wEbdhEyWI',
#   'T2WB3DGJsz8',
#   'bKV0xesPfJQ',
#   'AjQkYpuB6Dc',
#   'Fc4drtbgDb0',
#   'HImyOvCtNCU',
#   '_LgJMrDTOaI',
#   'pvsImT6E4yM',
#   'OXGETrqx8JE',
#   'F1EQ6xghU9E',
#   '_CjoSa2z04I',
#   'OAHJQ3_lKds',
#   'nChyKnRKHYg',
#   'osW3FxJ9VGc',
#   'qJeGtmpqLCc',
#   'MBSMO8akXno',
#   'FwO5ey02pk4',
#   'VfsC7tWp934',
#   'a2jSYC38aKg',
#   'QGIm9CqOqMM',
#   'tEAkJ8mUMdY',
#   'EvVkTNm_BJY',
#   'GZG9nDbIgXM',
#   'Q3Azp5eUgNE',
#   'nyliOKM_9J4',
#   'PmEa9xL7awE',
#   'y4sMCzeb_y0',
#   'IL3S7KRq_RE',
#   '204vg0ZpzxU',
#   'yGLNsAuSPeM',
#   'BtMlOuryRao',
#   'YHMPEDdEAaE',
#   'g7v5T4oeE4Q',
#   'JaOgnPCTw_M',
#   'gKPHum_NzX0',
#   'EFtSONw79Cc',
#   'mBim2lKo0d4',
#   'DcdoBrCvS9o',
#   'Jdchy9yuyJA',
#   'qByU2P8LhdE',
#   'RTCj8AfwTPg',
#   'yE7kCeAPpCg',
#   's0MkQMlOg1A',
#   'hSDGL1O4_2A',
#   'qD1tBFRTh3c',
#   '8DYpvzyEVg0',
#   'BtbnOuY6vOU',
#   'G084405Z9Q8',
#   '2SgmBwBSt8M',
#   'KX4oDYNXcog',
#   'nl6gIl_59GI',
#   'hfD_DBjBx7A',
#   '9uFTCtGETNw',
#   'hhVLTUla7r4',
#   'eoVDyaZPcUU',
#   '_ezYjZ5q1MQ',
#   'S0BB5SBzwPk',
#   'u01jmux78QA',
#   'NmT17RwbyQs',
#   'W2LJG6d5398',
#   'M6M7psZYUB4',
#   'rsdRmTdMetk',
#   'eYt2lCw2Z7U',
#   'g0PivPwcYPM',
#   'fgTr47WT4rI',
#   '82S9KcNuZes',
#   'UAmR7Z1wIDI',
#   'UfpByy3jOCY',
#   'vmU81I4UlzY',
#   'IkOlvVytQ3M',
#   'nQJtsnUdXdg',
#   'aZmtVidm4Tw',
#   'fXpqstfOzck',
#   'qg4rfk381aQ',
#   'z7IjzketUfY',
#   'j5XOzTRnvjg',
#   '8Yu_uR8rZrA',
#   'I5ZZcEVXIME',
#   'EnmQeHfGa7E',
#   'lmVR7QEgip0',
#   'q_WSTbal5z8',
#   'ATYZ4L0_jxQ',
#   'PQP98H0RqDQ',
#   'U2EJKZ1v_dw',
#   'sHnvEDmE3so',
#   'f332DVN3EoQ',
#   'XDLKuNMhS20',
#   '18lUWxYKgOc',
#   'E4Il4IJZh1M',
#   'tCbQEuQKW3A',
#   'ZJQH2outc0s',
#   'Ws5feMfuQ7I',
#   'nB0Q5v1_kUs',
#   '9pkAJqw5XPA',
#   'ySRy018cUIg',
#   'KFLVosHj1G0',
#   'PE61nrJJ6Gc',
#   'sA9zwxrAVlo',
#   'IqAwin7WV6E',
#   'dhc3UMrUeWU',
#   'iEbC_rRmfWE',
#   'OxCmqfD612k',
#   'P9prvFtgyCQ',
#   'tlPXUeUI4zc',
#   'NcNNTEtEVQo',
#   'IvcoZk5ZsyI',
#   '2g2eti7GnRY',
#   'mYCKzV49rx0',
#   'v1N7FhTu1ik',
#   '96DG6V_P9Yk',
#   'RvilDs1Sr18',
#   'sMUdrPFL3V8',
#   '1RGBtA_GhWI',
#   'lD3lPxiIWXI',
#   'gBI2LEk4If4',
#   'JjIsa6A_lw0',
#   'gARgK8NjSDc',
#   '8GZY83WyOf4',
#   '1K2owHA_1Oo',
#   'ZybViRe2e6o',
#   '3NOD9l9DASo',
#   'J723HmRU3QU',
#   'ckIKm_pio64',
#   'dWyhBea_0RU',
#   'rZadqwWOZiU',
#   'nUdSvPEYgsk',
#   '0b86bWr6xjk',
#   '7lNpXrFIMbE',
#   'mv7xsjK0DiM',
#   'eCxuuAz3m4I',
#   '15Ra_1BpFDM',
#   'TsieXYhREDc',
#   'FJHnWtFa3LU',
#   'KnCPTBb7yfM',
#   'MhHCQ_cb3T8',
#   'VcAH9WxXC74',
#   'reHetuCABos',
#   'GpYLnYdEvhI',
#   'dTR_db4sX9Y',
#   'W5TQ_lDKRM0',
#   'Zvm6hNb4m7Y',
#   '6SaENw39rU4',
#   'K7cO94ZHDo0',
#   'DyfM4_h4_aM',
#   'egPzPanHpXw',
#   'XPGhLx3rcf0',
#   'ADO6ez2_Bl4',
#   '_RIH7fRpJtY',
#   'ys_HDCt6xEY',
#   'OD_4GN0TCms',
#   'XENntT235g4',
#   's6vN0Sl2F1c',
#   '9NguZ1ukR5E',
#   'H1iMbqdksDE',
#   'WYcGfSiTbYY',
#   'nHs8cNkmgds',
#   'Vy29UePOx6g',
#   'urr6mfZxptw',
#   'jGY7merlB2Y',
#   'GMvQVE3_o4k',
#   '2kmLFL5OWyI',
#   'wKnBkKSY6zI',
#   '97AKmkHvvFw',
#   'z_SWahrfEEE',
#   '6sNOi4OG4sw',
#   'H1DpAES4Jng',
#   'YULqnxkESWg',
#   'TGisbPWwn5I',
#   'Vksflolj05E',
#   'vhxBEmsc8zM',
#   'TTrVFSRUGIE',
#   'khMON7k5kWk',
#   '2z9rtGpzPXU',
#   'iSrsHDQASVs',
#   'kzxUQG7yJTU',
#   'BNp8Zr5MlOg',
#   'hJzuRTfhgIc',
#   '5f6UWoANodU',
#   'EtPXddRypOs',
#   'MRTuvtkv5RQ',
#   'QmUinhGphos',
#   'oKzi2l3kk90',
#   'ifdL1WTxsXQ',
#   '7oNPVt4C5NQ',
#   'EafHmnHMjvg',
#   '4IN9QAb_l1M',
#   'ajA7uSoqpvI',
#   'bflB2XYu5rw',
#   'tP3ou_3RGVg',
#   'hIqLjwwlkqU',
#   'iCcHGzMFQYg',
#   'r82oTd2aamU',
#   'LUZkWZQU730',
#   'MUXruJEcy6I',
#   'qJd2PBgNCwU',
#   'MZXYPlXZG14',
#   'Nl0xtx9AyI0',
#   'rU3lNhDPo2U',
#   '4lfp5MhNY2k',
#   'iNBGj2q0G44',
#   'LsrRVWm2ivA',
#   'fGbeuBzH6_4',
#   'L4ed7PRsvxE',
#   'p4E0s20uabE',
#   's64U8yhvcvw',
#   '1AmQr2m98yU',
#   'wUBZ6f87Pf8',
#   'Vdv26f3rpJ8',
#   'n8sYBXvKJFo',
#   '5B0XYZjzivw',
#   'LY58Fz665UM',
#   'xcQkHqSe6FY',
#   'Hk1Fq13U7aY',
#   'b079OoXNVUA',
#   'GzF8RMV8Fss',
#   'JV6ZUdw_lXQ',
#   '2DzH7cHQPsE',
#   '5jFfRm_sGV0',
#   '2f2coPjVHO0',
#   'nxCTPu2F0fU',
#   'NudrNCdBxAE',
#   'n4NhvxPxpuw',
#   'ZjeNTjm_uo0',
#   'sQdJ76CBD48',
#   'NGI6DX_qeso',
#   '3J2b9YYf_SY',
#   '2c6JXo1iJUs',
#   'F1MsBKifzIo',
#   'qV3xntSmr1o',
#   '70daKdkwjeY',
#   'LwTkPjdrmns',
#   '7OEf12TqmBc',
#   'RVaNiCkhMJg',
#   'fZiaUKJSy0M',
#   'LFHDU8S0yFg',
#   'sHGhGFYE_0M',
#   'wyzABB_eutk',
#   'd4O2uEPSgjo',
#   'JTZmtkyF8rc',
#   'RxpiKe26bfo',
#   'kOwaqR6St2I',
#   '_LOeU9XVjr4',
#   'cPoQ27hCNOU',
#   'qgcriEYao7E',
#   '8LQvYszWb6k',
#   '8vTQ01eFJCk',
#   'q3aI7Eds5Qo',
#   'WhZxheIcNDc',
#   'Fuv6bYBPMb0',
#   'UBVqFj2mwWM',
#   'dmWSWoux4Tc',
#   '9HWVgoMjGIQ',
#   'u1x5Br5cftc',
#   'Y5pjN6z1JjU',
#   '9xy9mqEUh64',
#   'LPrMSJHDDcA',
#   'rzHB9uT9egU',
#   'ncy57YkTtdU',
#   'R6jUy13AW5w',
#   '9GbYnL0tvcg',
#   'VWHKv7pkLiE',
#   'N3oCFbrZcwE',
#   'ztZMp7dpRto',
#   'LJkfYfo2kWg',
#   'pm8vXAkcHeA',
#   'WSZVw3qGyg4',
#   '6O1Rc3Pmv2s',
#   'uUgYlA8Afko',
#   'jYnPj1Ep948',
#   'FBc2TT0UmTs',
#   '5qawyk_MkYg',
#   '4S6_h9xAe6M',
#   '1ryNlh3SRCs',
#   'UCzXULyScAU',
#   'P29oZ_e0qZw',
#   'qxa2fKVjIAM',
#   'miHysd6fjNQ',
#   'BwuZADpRtdM',
#   'Z6Yd2QM_UT8',
#   'YQt_1UnQiFU',
#   'NHFuxzAgMNc',
#   '3pahpE8TQqg',
#   '7WqM5Z7695s',
#   'gFzXi6TnQSg',
#   '2FC6qLz4W6M',
#   'yuApyHAH_lg',
#   'b2DLF8zrYZI',
#   'BNHANE6n74k',
#   'VnKWykmREO4',
#   'A4wf93zJZIQ',
#   'KuO0uITOdN4',
#   'K1UKsLlNvUo',
#   'xHuZdUGGQHg',
#   'C5lApBKCF7Q',
#   '259wx6vTLz4',
#   'agGOHteE2GI',
#   'ghv9VKgbUYo',
#   'XNBOk8QO8I0',
#   'rVhb6OMlips',
#   'pY2JYeGELcc',
#   'dSGr6OLsPls',
#   'rDo7bb0Ts4o',
#   'mdyixrMtD_8',
#   'iwfm9uNXt1A',
#   'fX9i0RBrLLk',
#   '7MOmZ5PntgU',
#   'eYZA9hehwR0',
#   'Bp9Myhl1Mps',
#   'zgQbOmPp9pk',
#   'pkRppmJjxy8',
#   'ciYaNPzUjZ0',
#   'fJ75tL1Oh9w',
#   'Kj4Sgx9HXb4',
#   'uQsxPYqkFfw',
#   'ULIc9dn1TNU',
#   'melmLHxxvw4',
#   'cUAQrHbbpZ8',
#   'Ba_ffkYzPds',
#   'DmYYZ8Dr17s',
#   'RPJg_lUfHvI',
#   'K4oWnQPSF10',
#   'DeRHaq0U7aA',
#   'y2eeFsmsNdg',
#   'Wv4GlT_G2m0',
#   'BPD9xUapILk',
#   'xgbeqTCkO_o',
#   'vPfHZc52LfY',
#   'egMVHfEPdMU',
#   'vl7mATkmpEo',
#   'HXLainKFXyU',
#   'sNJ5olvLdGs',
#   'VbUy2HOaJFw',
#   '8tprOH6SZIc',
#   '9__7BrYUOno',
#   'LVnzp2y1jgs',
#   'CULrx3yerE8',
#   'hqKV5stekqk',
#   ...},
#  {'qWG21pLc2fw',
#   'fB8Az8AuS8s',
#   'd9tZZGbLQMU',
#   'ML10ds4K1cA',
#   'Oz7FkuxsmJU',
#   'NV_G6wX2xtQ',
#   'bwlFUCVl2d0',
#   'uNUrvGrdsQ8',
#   '9Wk7pYmWt8I',
#   'liPZA3Zdvig',
#   'x8yoLCYSzVw',
#   'fcc456xMQtM',
#   '9WI1760BQK4',
#   'fhCv2PjqkFw',
#   'JuGbyzRd1oY',
#   'LsdkfH4cIqM',
#   '6_o14WcPUC8',
#   'GEbdWxkGJOc',
#   'luv56Zk_gkY',
#   'uOuJijvQ0qA',
#   'oXOeA9tU55c',
#   'VjS5hmgV4qI',
#   'pcAhoVDv2Gs',
#   'InLvuI0MAtc',
#   'VxK7lhI_2pc',
#   'r4o0Vg6NQNc',
#   'DzojdNjzSTU',
#   'r0qdOapKojk',
#   'PJlcXLLZOT0',
#   'CJhu53w6Zq4',
#   'U9cyavnOr1E',
#   '1UOatSFd_hE',
#   'RqQe0ewBrD0',
#   'im2J3GRCnGk',
#   'gxynhdL6m4k',
#   '6NFjjfvQ7ZQ',
#   'P5XTGJk6h28',
#   'jTa54byZKHg',
#   'gQg3cyWahgc',
#   '2QUV1PPNsZU',
#   '6PjRLIvmam4',
#   'FGjL3tQ6vN0',
#   'XBDHpKH8Ar0',
#   'fbsdWq7xJ7k',
#   'HlQX_Fvu7hI',
#   'XrBSrgUat6k',
#   'PzwqomOhEg0',
#   'QMUCHwM0CR4',
#   'CvWFQzp1vmk',
#   'sMEBFgBFmy8',
#   'tmPcuRQ0AVA',
#   '2Me6SuIfpSk',
#   'ZfX1iafZ0fc',
#   'dcrF0fcizRA',
#   'Jl9__Gs09BI',
#   'JU9blLfDPuo',
#   'jzbP_t9esgo',
#   '4VM8tDd6naU',
#   'gm9X3qR1GRI',
#   'qF4qaLRHjHI',
#   'fxDBy17BCqo',
#   '_FsOnRDIJQQ',
#   'wXZVCz3WhLw',
#   'XvkQBrWnbF8',
#   '_IimozO_x50',
#   'dhV8ToP5VTQ',
#   'PjtNlSBTlKg',
#   'orEhowBkuKI',
#   'AdJxPlzipw0',
#   'J1sEju6i5iQ',
#   'iqex3hSn2RU',
#   'jpW_MOekS4Q',
#   'TAHq3DYE_Rw',
#   'zaq5J5endq0',
#   '95AhWPH552E',
#   'pvwgTTH4tKw',
#   'NVTSbRgtpbk',
#   'S5bcpySWWpc',
#   'b900YUviKNw',
#   '1pWuXjJ1SUE',
#   'MXciFLdLVSY',
#   'SKs9CmsEhuw',
#   'Hb6WeHkLQGI',
#   '1iByM08MvqU',
#   'ebP0C2MSwgw',
#   'ofzGf0PwldY',
#   '_oEMIflSrow',
#   'RmZwvS0UXzU',
#   'LJiP_ouvA9k',
#   '4_80XvYI_Ek',
#   'Qe69_lVe7jE',
#   '9KRJZByi__U',
#   'OImI_S8C2vo',
#   'fhG1ArBe_uU',
#   '9J7s6l7Ob4Q',
#   'shBaEhGS1Bk',
#   'vC8HCxU34jk',
#   'JaKhDtaIyvU',
#   'VpSpwWMW5eA',
#   '2zp6o_3CRzU',
#   'fAZLO23Zdbw',
#   'mP2i9zSxYHw',
#   'nwcLl_K3I5E',
#   'fY6FOPbqQl0',
#   'HWxPjFUR2Qg',
#   'LsbRXTusV6E',
#   'GiuI0CiyMZI',
#   'r1eZ_SdK_24',
#   '1Nc4d_tmiGY',
#   'FUS0hsPCtMs',
#   'MWMmHcPKvfs',
#   'w25yutHRugA',
#   'RF56oE4gsJo',
#   '329uDNTb33g',
#   '2wRFVUx8IoM',
#   '6RBRUDvbHGM',
#   'V9w9RE4zg7U',
#   'CX2yWOhmwbg',
#   'le0BtRt794k',
#   'ANd2wYIi8oU',
#   'lsciLyjICMk',
#   'O0bEoH4WlNU',
#   'gDfzD0fJjwI',
#   '7ok3aVhT5Sc',
#   'qhI_qKtD2r4',
#   '5cf7N7oricU',
#   'OckqrD0x_r8',
#   'Id9i789lYz8',
#   'lQ2yjMzByCI',
#   'MKX0zLqY7YU',
#   '3HutEP1zOds',
#   'x4ioRas_9l8',
#   'Wd69L0vmaOQ',
#   'xIjA_1JQF8I',
#   'xDH7oMWYmRw',
#   'od_ZPJBFYUA',
#   'LmY6NZwmSa4',
#   'vWod_p2wmr4',
#   'eaO9SWnaFW4',
#   'udNdqhGlkSA',
#   'raf6rDUfiOc',
#   '4OO3M5j0lbg',
#   '3RGVTogMjgY',
#   'EmJ8TQY5dTY',
#   'R5Em8Z2Pfjo',
#   'PDTgnVrixgQ',
#   'GEbWT0HUnfw',
#   'D6Va3TXwFEQ',
#   'CiG3WbsA9fw',
#   '6eBEz91Zwh8',
#   'i26oblZnXUU',
#   'fcmIYoQtOmE',
#   '5wKh99xBLgw',
#   'L9bkiAADDIY',
#   'Lm12f30wJ1I',
#   '3n3meg4bfnI',
#   'xsuRFseeHTA',
#   'uAUhYFwY2c4',
#   'EBvJ2rWj7LM',
#   'OALASDJOKb8',
#   'HNKY3MHRejY',
#   '2O9Vje552cA',
#   'ffh6W9qSBOc',
#   '7SR0NIMSJ98',
#   'Kze2x40RihY',
#   '0H2vf25EgmA',
#   'djPS3OL3xEQ',
#   'HSushtZe0A4',
#   'UFFSiECdTLY',
#   'uLIQAbifOME',
#   'vMxEQFO8teQ',
#   'YD_MuXwW824',
#   'HhxZTM_WB68',
#   'Cojb8DSHvyU',
#   'qe8TjfIqZ8Y',
#   'jTizVpdiPa0',
#   '6HX5dmPKqWQ',
#   'OUPHieGN4UU',
#   'e7RXMoofC1A',
#   'dqSBEvKMvfY',
#   '8c6pH98yxyA',
#   '4UhIXjsL79Y',
#   'A8a9dN5U3Yo',
#   'L_kkRc7s_6M',
#   'UojljloKmhI',
#   '0O66nXhndHw',
#   'eC2wI3jh0h0',
#   '0R2LivDo2wQ',
#   'PahaNi4E0OI',
#   'v80aiuXB0W4',
#   'Yr2ZLfWT0i8',
#   'upmsYGlTLDo',
#   'twGX5mN6Mcs',
#   'nh50JjAcsuQ',
#   'jWVWwpm_IHw',
#   'FvHLgE5L4p8',
#   'V866JTz6lJ0',
#   'o1BNtH2rqY0',
#   'ioHd1Rcp5Ew',
#   'OBQ4Oqmi_tc',
#   '7pipCxfvJ20',
#   'Kwo2qcJCdGo',
#   'pXGCTXMKs0k',
#   'DzOS_wLQMsc',
#   'BqEjGUX0Yvk',
#   'FxRayyob69s',
#   'FvvNyw0607o',
#   '3U6y39uiZmw',
#   'xUCV3e1LZYw',
#   '5EsyiXMKOPs',
#   'BIA3NQUispI',
#   'y7iQAQafi9E',
#   'fA5dG8UqneU',
#   'lcAWcDLMPJc',
#   'nAB6xdjqero',
#   'JT9bt6AwEuc',
#   'r3cTVf3Ka60',
#   'YN6xuSz86PA',
#   'XWd602XfKh0',
#   'QpjmOepR95c',
#   'y0KzJDKW0WM',
#   'd9tote4cfGU',
#   'qWB9IEgfzHY',
#   'oeObDZcQxK0',
#   'Aw5ynnoQnQE',
#   'rc6JQ7NnH9Q',
#   '9dhhuPr0JyI',
#   'ft2fyDA0jY0',
#   '6parhz7LGI4',
#   'rVeWAUvBU50',
#   'HEJ6RAmVM1A',
#   'TXbhyTyHmyA',
#   '2KOeSglQU10',
#   'KtM2vZRvxnE',
#   'TSFUMTGQUWw',
#   'TVy2hkF_G9c',
#   'Sk0rAunGmlQ',
#   'HeKwkn3ByP0',
#   'CXiKad8CBF4',
#   'X4KMfjB8Erc',
#   'TyKZVXlXess',
#   '85RxQHZkluE',
#   'Ho8bmMTZKjI',
#   'pdP9mQAQnQU',
#   'zj5ynCM8vKI',
#   '5k5s_IiQzXc',
#   'fJEqh1YLGes',
#   'EyxjFfK2GWA',
#   'dHohXDBK3KI',
#   'TLv5OWfkU8U',
#   '50wYL3oH1NA',
#   'Ik61qAqcnXo',
#   'sAr8atA3tuY',
#   'Oz9wJkWAEec',
#   'veM423POiU8',
#   's6XPg87do4g',
#   'N4YDaU51lvI',
#   'iXVfXEJ8i0A',
#   'rBmOKZYKOhE',
#   'TMLCOvRyZE4',
#   'KKZmPCvc98s',
#   'GdJVLA16hUc',
#   'fO8TyCMoDP8',
#   'Vpmg0GAshHU',
#   'XREYOwgg6Uk',
#   'IiptWs5QgDA',
#   'vleTt0rWGw4',
#   'bZ5hKMRmYg4',
#   'VPeJpO2xwlQ',
#   '3Fy5tvgO5OA',
#   'MynQerUj1dM',
#   'aWAp9pXi_DI',
#   '5BzYdU8fqwM',
#   'QTY7qBMdetU',
#   'UtslpwELYvo',
#   'R2C3fHcNm1k',
#   'rkJflxmHxIE',
#   'H9RPDtJ_PKU',
#   'SPdf__1Dulw',
#   '4qhQDQu6Nfo',
#   'ehyCswv8byU',
#   'UrEJ7oAhcX8',
#   'i0gEmSZe9jc',
#   'm6k2GOeUHNI',
#   '8Kq9E5l0SPM',
#   '9Wh9FqL2Xk8',
#   'AgGbMTCYztg',
#   'YMuAdNxf40I',
#   'xEx954Qsjjc',
#   'B6APbgmIA6Q',
#   'ofwzLS_BNw0',
#   'Y6wGoA_flkM',
#   'tGmPoySBZvQ',
#   'rH5PqTOIt6Q',
#   'rQhGmJxi_s4',
#   'TVcNvuRpBYM',
#   'P58YYifsUgY',
#   'akoFjM1_p2o',
#   'ORAtNZJoCBo',
#   'gl486Y5GB0w',
#   '480nF81vFI0',
#   'hFFskmCQkuM',
#   'DoCN8XTwZFo',
#   '_l6NM6NEKdI',
#   'SffHY1Snn1Q',
#   'Jcypy2AgHMo',
#   'OeHxe75lMNE',
#   'crxe2d7kvvg',
#   'ipzZ7O0J7P0',
#   '27kv5lOOTGc',
#   'aHVLZEB2juA',
#   'X7D_dmahSD0',
#   'TYDaYcOCGho',
#   'MJtGR4MDI4M',
#   'SmIaXMtgO2I',
#   'ZMoMD8tmBZ8',
#   'HeXezF4VrJ8',
#   'M4MC5E5TFHQ',
#   'iVtaHvUDLC4',
#   'UDlsIakb9Kg',
#   'McU8mJhTRnU',
#   'HOkBohJhbPE',
#   'bIppytTQ0aI',
#   '71VzkALm1Oc',
#   'n3TXgjx0128',
#   'mpg2dM5DrGg',
#   'vLkbW6uukDU',
#   'ANayzbybVDA',
#   'IjskzwN03fc',
#   'rUyOsgYjbFI',
#   'Z0W00M3kNB0',
#   '7qB9WsTtMIQ',
#   'hbo7XlB0FWA',
#   'WcRHKUhrmHQ',
#   'D_yb9_19sEo',
#   '9Ez5806fqiw',
#   'Z477uI7POtM',
#   'FYvl3if0WiE',
#   'L3bf7dlR5hk',
#   'YtM8D8t8zZo',
#   'wEc24CZ97kI',
#   'lS43t9rPqmM',
#   'uLM3hC_A9B0',
#   'KUFEiXRXxys',
#   '9k02Yj8lIKM',
#   'PLzNBRoZRzo',
#   'OlQsFYgdzLk',
#   'iqo_4SwuZ4g',
#   'yMJXOjtvUkc',
#   'i9AZdyMTPXs',
#   'a5CrSSneht4',
#   'aHBaWrd09KY',
#   'pynAZVy5q4U',
#   'q85rmRUdgK8',
#   'l3b0_C2thD8',
#   'xziHqmASdIY',
#   'P_Xncte6zqg',
#   'KRmJLMt89b8',
#   'w_6WwWmaDsU',
#   'kPb5UUmHnHs',
#   'bt7g4VoVBoE',
#   'C3gffJgZtl0',
#   '9V_nVAdBB3g',
#   'UKVile_HpwQ',
#   '9PHCaxokNXo',
#   'BXjgkS7gsn8',
#   'aMWKWcdyYMo',
#   'qxuVGpnzmIA',
#   '6ip1mqRyI5M',
#   'lYSwby37FwQ',
#   'CIS_a5kfJUM',
#   'G7eFHY90kFs',
#   'efIAxTOX9F0',
#   'tjjnxvFOzig',
#   'iMj5gB0XHRw',
#   'tQRsEpIj5uo',
#   'UEUJAgUgP_Q',
#   'AMdNsGoLM8w',
#   'awA8QjEncEU',
#   'NxpCRpuABsw',
#   'hWdU5vcjMxU',
#   'xjjD70sa3WI',
#   'TIvZVY2CtsA',
#   'cABj7BBhFd8',
#   'FSj1fQMbu0A',
#   '9QnUxnhVK8o',
#   'CIQ3Ave21Kw',
#   'lrLbXImf8rk',
#   '6GC8ekmdngk',
#   'p_CrKSdqktA',
#   'JyzAOR0GTs4',
#   '4BBQyegIQWQ',
#   'EPA02wTaonI',
#   'RqNXm3Vjxzc',
#   'Cac_RI6qfPU',
#   'CeAyzMJJ7fw',
#   '3pquLEf8kr4',
#   'OE8ujtE5ybI',
#   'qQUZ5d5mpWk',
#   '346acKUgnOo',
#   'oE9qrxR7DpI',
#   '2YDi0RGGmRg',
#   '9aO3H_YIiwY',
#   'MCQ8KvHvalc',
#   'HOFjdBDqknQ',
#   'Odbd1stkcRk',
#   'TrgPuJHj7p8',
#   'B2BcTrXcsVE',
#   'SdycpaKESd4',
#   'X5qrIxcQEus',
#   '3k0YGdgj5vo',
#   '9JVCjzcvXco',
#   'zmmMNX_dDg4',
#   'v_ZhT1JJe4g',
#   'gVOllvdKurs',
#   'TOCCUCfrz0M',
#   'YmuBBsHttz0',
#   'b94GsLb_XKQ',
#   '6p74_Ar_qmc',
#   'RTbIN41lf9A',
#   'R02ljlzvh_A',
#   'qqIZ9MLZk0Y',
#   'FmeNmsKYwWU',
#   'uB0TeB35l94',
#   'BmTY9GRS7lo',
#   'DAh5wI1W3qw',
#   'V6xicGYXS_c',
#   'oYykJu6A7Dg',
#   'VUb5yWYww90',
#   'IGJVw1HjIHc',
#   '2YnN4oQEvnE',
#   'ZfzVwcLSzIk',
#   'kOlkuIUqd64',
#   'J435iJWU6vc',
#   'k7jaBgF3u7M',
#   '9XdPTKEdHrc',
#   'a4KrJZa3tXw',
#   'f694PFHVMFM',
#   'P8R_Lwa33rs',
#   'g_t4wXG9o_s',
#   'jKrBnCmdlZE',
#   '0ocs4QH3Mcc',
#   'Sj5vhnLGKHc',
#   'ov4ghi_kG3U',
#   'M8xUPQyG_yg',
#   'oCsHNgql560',
#   'ryJ7MtDof9Y',
#   '2lzmRcaSLRI',
#   'SIYgWgOEa8k',
#   'O5GrZxoov98',
#   'NPay3GbYxsk',
#   'EAakij0ExEc',
#   'sRRlYasWUaM',
#   'BEruWbc6ZT8',
#   'FN8jOLvssjM',
#   '5JL50W2VaNs',
#   'JWrpgQhFgK8',
#   'BeCS4X5oyXQ',
#   'Y_y4Q9w5Ijo',
#   'dD3A1IseY00',
#   'nMSrzqjAFfs',
#   'O5SvwYGbXCE',
#   '6CvnikVJQq8',
#   'yb6NCcmsSMo',
#   'lREyKzqpCjE',
#   'BZ_kP3J6XcI',
#   '4nlVqcAmMco',
#   'gzOhOZQ8DgY',
#   '6epcwvnSNyc',
#   'qKdeiL8Zrsg',
#   'QIkbhrCuWe4',
#   'lNwXQrpMfhM',
#   'qpRWi2rJYQc',
#   '2ENOaC3O_2o',
#   'SnbDtuHGdqE',
#   'tlIGISsI6Vc',
#   'Ye1BZHCeMu4',
#   'fxThU75vC38',
#   'ohnzxn1P7io',
#   'FuAkKW6NVuM',
#   'K39LN8yzimg',
#   '_d1oBbMQQGM',
#   'Su_bfE13oc8',
#   'x6aEnqpTUBo',
#   'OXCnc2IRq4k',
#   'ndssE4SMOaA',
#   'oiLvMET2Wrs',
#   'lS1fFzAWbLw',
#   'xPgddk3AnRQ',
#   '3J8rb0L1Njc',
#   '0fBkL_bj7z0',
#   'cgS9ODt4bQA',
#   'x0YH_9VSFus',
#   'Sm3Z7wqn59s',
#   'uSXzoikCu_k',
#   '8mhAWJx5YjI',
#   '7kSVE8sJbuw',
#   'K5GIun0flM4',
#   'GQgS2ruEJAs',
#   '39NJ5pDEMAo',
#   'wKZjZ0c9k4Y',
#   'UGyGF6BzXTM',
#   '8xaLfHCU2KM',
#   'SRBkkbE7Uyg',
#   'zoN3xOGVjbk',
#   'vl0psWonAwQ',
#   '8GCGRdwg80Y',
#   'mQUinrfsVkM',
#   'adh1JDl2mDk',
#   'M8azLVqwJ24',
#   '3ogB_jaW4FI',
#   'kN1tvTnShzU',
#   'H6B_nTqoq3Q',
#   'YedJhuZQqpI',
#   'b4Kw8SHF4tU',
#   'e_B2GkcUtrI',
#   'kulZ_sWzBR0',
#   'UY_PbAAy2mI',
#   'V9SkCPhO9wk',
#   '5fcCPAkAGVs',
#   'kJHnaKS0Igg',
#   'cDzt6pKCzcQ',
#   '259ZLluIkyk',
#   'OoX_zCryYCU',
#   '7qipzGB4DXM',
#   'DUGkeN87ByI',
#   'BUxpgSVmM2Y',
#   '8_VkxmHeMAk',
#   'D9BypvVyS4Y',
#   'n4dSJgjRUAM',
#   '3aUTbWogu4E',
#   'Wx6WqWXx0lU',
#   'L0Txo5QR7Rw',
#   '8cU1k2ylhF4',
#   'Qb80uEMXEmE',
#   'wlVXqhcsWyA',
#   '16gxQE8C1p0',
#   '0TgwPoPxrTo',
#   'xJMJ97AX5zE',
#   'yVh21IsS_JQ',
#   'fI1BI4d5KFU',
#   'fzMD9GjvcSY',
#   'SA3R1HniCoM',
#   'mHkBxBLAZww',
#   'EyQTMdxuqSs',
#   'GKemEDW3fao',
#   'F85pyD5KTWE',
#   'G9sYOW9SU2k',
#   'Z3Vbzpo2Bf8',
#   '6oUUkdGMYDs',
#   '6teAhXTWpsU',
#   'BWSxerD3LDc',
#   'c1izj8jr1XQ',
#   'QNlBw3sFyw8',
#   'Qmn1S9yjxB4',
#   'zaWgmcdN2JE',
#   'gHjUEWlfmOw',
#   'QLQAjiKlG5Q',
#   'de9wmUKoZxI',
#   'rqhejKh3_XE',
#   'IbNzJFmtkZ0',
#   '7jaQmQj3Wgo',
#   'SRtSBaFd8Ek',
#   'WSZVw3qGyg4',
#   'K_OWP7fPtMw',
#   'VmFgMqSkA78',
#   '72dK6BETM6Q',
#   'tN1putCohn4',
#   '31liERlX9Tg',
#   'buAn47zBd3U',
#   'kRyvp9_y6Ek',
#   'nyG7yKBfzjY',
#   'b8XqeZgy9QY',
#   'K8fgPqaaJrA',
#   'r_HaHYSEswE',
#   'KQTQdEj1JqI',
#   'EvSVykyXNGE',
#   'YUcrsJAR3Ck',
#   'MOH8b4moNLo',
#   'F65G8BhqvHc',
#   'DGymMUfRtqM',
#   'A3ZQtnTGRlU',
#   'ot0LKuAhBKk',
#   'B3ZakJ4O5uw',
#   'OSJNrfcXksc',
#   'W22CuafoISE',
#   '3LDpq53oV0o',
#   'XcJfbADgIhs',
#   'g1Vag7OgCXw',
#   'EcfG7zdjBYQ',
#   'KCHy3SxfYUA',
#   'AkNlDAXFEU8',
#   'eFKv8712V4w',
#   'HMrN12C4JwM',
#   'IRrQkwZgvB8',
#   'aaWdowfdCg0',
#   'glntkvUyUZU',
#   'T3WKGqIXBnU',
#   'QyJBnfh233A',
#   'L2u31Yt7r2w',
#   'NtoRI5nlwKw',
#   'jrpuIZdDapQ',
#   'Lhb_Qerye5M',
#   '5yKRIMdIAoI',
#   'H4wEbdhEyWI',
#   'EYvZmZv3r9I',
#   'OOF8y6PCb90',
#   'T2WB3DGJsz8',
#   'bKV0xesPfJQ',
#   'AjQkYpuB6Dc',
#   'frpPLNtClhE',
#   'HImyOvCtNCU',
#   'DUiumyUqZsQ',
#   'Fc4drtbgDb0',
#   '1m5hUp_hxTM',
#   'pvsImT6E4yM',
#   'xHEVAFJPdto',
#   'M03u4buJtug',
#   '01qjQ_KPgpY',
#   'OXGETrqx8JE',
#   'TZi6krD1RuI',
#   'w7rj5B0C46c',
#   'dRl7KrgM9JI',
#   'qxbz9rvlyRE',
#   'J9v0rMRogvk',
#   'nyliOKM_9J4',
#   'EvVkTNm_BJY',
#   'Q3Azp5eUgNE',
#   'PmEa9xL7awE',
#   'LC2QScFT5QI',
#   'cf6j1Uq7HhA',
#   'yGLNsAuSPeM',
#   'g6yvs1f4S1s',
#   '204vg0ZpzxU',
#   'q6XCsawHDTY',
#   'o5Zsr5b9DYk',
#   'S0gfKMVt7vg',
#   'wH4L9NiHHIE',
#   'MrVom7SrpJ0',
#   'JTrVtCEpYqk',
#   '2pV7DNjAHKY',
#   'HhrBZuxjFxM',
#   'DcdoBrCvS9o',
#   '_jIHwb2m320',
#   'JmxB4eyQpuY',
#   '8DYpvzyEVg0',
#   'BtbnOuY6vOU',
#   'OhnmECT23mw',
#   'HTrOki7rggk',
#   'KO_jeuest9s',
#   'pxfSojtlfAs',
#   'oe8Z354Jo94',
#   'vK7fxrBDlL0',
#   'Ssg7vpw8Zb4',
#   'eoVDyaZPcUU',
#   'LOQOS5IJtlM',
#   '_SB9TAhoZ80',
#   'rsdRmTdMetk',
#   'eYt2lCw2Z7U',
#   'g0PivPwcYPM',
#   'fgTr47WT4rI',
#   'UfpByy3jOCY',
#   'QtOjRnw10Ig',
#   'OiMTyPoKj1c',
#   'w4CQ0fKNBeU',
#   'aZmtVidm4Tw',
#   'hLOOwsxDBJo',
#   'ZSX8Onpr7Qw',
#   '0dONhQHN1Io',
#   'Tis4mhVXPHE',
#   'cFAfGfCoTLw',
#   'z7IjzketUfY',
#   'j5XOzTRnvjg',
#   'oc0K7I2qCfc',
#   'HslyuL0PeYU',
#   'zo4FIUW2ybg',
#   'apQWdtLcLM4',
#   'wCU8slQrG1U',
#   '5a0LLRhy1_U',
#   '7id4wa39DD4',
#   'eqtImn3Syzo',
#   'hQXLrPlcbeo',
#   '18lUWxYKgOc',
#   'agJgHzMHu3w',
#   'tCbQEuQKW3A',
#   '8X7NyKhJWxQ',
#   'vsDoBhQJ1hY',
#   'IqAwin7WV6E',
#   'ZkraCqiF2S8',
#   'w_F_4UwdR0A',
#   'p2NgeOyvtZs',
#   'gIgKGAFdKFI',
#   'Ri8OHAHmTJw',
#   'Wp7JJK2jToU',
#   'IvcoZk5ZsyI',
#   '11aXftLrWIc',
#   'BtMlOuryRao',
#   '1RGBtA_GhWI',
#   '98DaJnhQV9w',
#   'gBI2LEk4If4',
#   'h_FfxeLeMOc',
#   'ckIKm_pio64',
#   'hepgJ44h3WA',
#   'rZadqwWOZiU',
#   'UuqwgWoHR74',
#   'YXMgrpbXFTM',
#   '7lNpXrFIMbE',
#   'LVPw3VkNyME',
#   '1IgM8UPf68o',
#   'MhHCQ_cb3T8',
#   'iu9NydPw9yI',
#   'tdmk1MYHMs0',
#   'RT602tXUlEA',
#   'egPzPanHpXw',
#   'FVuvCrgPCP0',
#   '_RIH7fRpJtY',
#   'ys_HDCt6xEY',
#   'XENntT235g4',
#   's6vN0Sl2F1c',
#   'wdHldaeg_VE',
#   'UkpHuQqUxn4',
#   'VpRGQkSZgrU',
#   'MngysJ6Dp6A',
#   'XWpMMIj8REs',
#   'BmdvXmV5TTo',
#   '3yqs2nVoPDM',
#   'y56W71aIgd0',
#   'ob5auOJ5mS8',
#   '2kmLFL5OWyI',
#   'hoYvSh0apYI',
#   'wKnBkKSY6zI',
#   'z_SWahrfEEE',
#   'VwgAnmMsah0',
#   'w_mwpp1tfKI',
#   'vhxBEmsc8zM',
#   'Vksflolj05E',
#   'ijUj_XN506U',
#   'TTrVFSRUGIE',
#   'hJzuRTfhgIc',
#   'kzxUQG7yJTU',
#   'iSrsHDQASVs',
#   '7fc3_6Uycl0',
#   '5f6UWoANodU',
#   'QmUinhGphos',
#   'GjlduZjqHxA',
#   '0MgW9k9sUqA',
#   'xD8uW0Hj6v0',
#   'UkA5tTr8JFQ',
#   'Iw1u6ZYA4t8',
#   '7oNPVt4C5NQ',
#   '7fuvt2Q8Kgk',
#   '4IN9QAb_l1M',
#   'qFFBi8ok6NU',
#   'bflB2XYu5rw',
#   '3CzGMO93xiA',
#   'tP3ou_3RGVg',
#   'ZGerOSyXZb4',
#   '_pRpOiXW2N8',
#   'dJt7PtJobAw',
#   'iCcHGzMFQYg',
#   '8DtAfW7ig1k',
#   'UUKdaBrF4Eo',
#   'q5O7mQ957TY',
#   'rU3lNhDPo2U',
#   'iNBGj2q0G44',
#   'HSNBvFfipNs',
#   'ntMf2tcUhew',
#   'aQtPOiovlzM',
#   'i5qd1RMfkRE',
#   '_S4ZbD_6iCY',
#   'VJFduvcKW1M',
#   'wUBZ6f87Pf8',
#   'eXhF5s8iuh8',
#   'OcZJIp3KUYs',
#   'NhHThS0MDbM',
#   'HNVA4nLzkpQ',
#   'xcQkHqSe6FY',
#   'kTDnHaChCkQ',
#   'H5tCfLoE_UM',
#   'riiIV32FEuM',
#   'Eizcm0GYu_0',
#   'nxCTPu2F0fU',
#   '1EEZhYHOqvU',
#   'T7kwkA6u6ek',
#   'JV6ZUdw_lXQ',
#   '1HgNReVRvzI',
#   'FH2BgOVARVo',
#   'n4NhvxPxpuw',
#   '0EmRyNfzWKM',
#   'Prrt7mTtbeE',
#   'oXT1SXqaWno',
#   'iO6rfKBOugY',
#   '5n_ZSdhY20k',
#   '7OEf12TqmBc',
#   'lJ6ePdJnXNY',
#   '7AKxJJ64WsM',
#   'LFHDU8S0yFg',
#   'BPXIPKqx3j4',
#   'qFhfefDONtQ',
#   'W2tWECa8dlo',
#   'onT5q8NBw4w',
#   '8WIjnu3QRus',
#   'yNvfJlMv9Vg',
#   '8LQvYszWb6k',
#   'q3aI7Eds5Qo',
#   'Fuv6bYBPMb0',
#   'aMGS7vyx4Zo',
#   'QepY2n76x2w',
#   '9HWVgoMjGIQ',
#   'zLSi0My6vuQ',
#   'p4SMy2tB_ZI',
#   'Y5pjN6z1JjU',
#   '740EOWBVi5Y',
#   '4Qtvx6lDmKc',
#   'LPrMSJHDDcA',
#   'ncy57YkTtdU',
#   'fgOr3z8mSDA',
#   'hD3b4O1RSfg',
#   'eJdWTp7DDf0',
#   'VWHKv7pkLiE',
#   'LJfO12NnyFc',
#   'f57lDadHW7w',
#   'brTJMrML94o',
#   'x8WcOxvsFnU',
#   'uUgYlA8Afko',
#   '4S6_h9xAe6M',
#   'ItPqSO1qt_E',
#   'V6MpDCjC3xg',
#   'gIgCFvyyv_o',
#   'mpqBUCFMgWo',
#   'C2xtDX5qexc',
#   'BEH6RWDGy7c',
#   'cslXqrcH5qg',
#   'avv2l7778JA',
#   'BwuZADpRtdM',
#   'BLl8zyql99w',
#   'NHFuxzAgMNc',
#   '16PcuNZLnDw',
#   '2FC6qLz4W6M',
#   'R30Vm4gTdwI',
#   'xcitAtuxPCk',
#   'FkKOGn0GCw8',
#   'xHuZdUGGQHg',
#   'fpOSD8Q_bIE',
#   '259wx6vTLz4',
#   'FTDfx7DNV4M',
#   '5fqLddbpcEs',
#   'lHNtdUcq2_A',
#   'XNBOk8QO8I0',
#   'N_iPU3x6ORI',
#   'rVhb6OMlips',
#   'pY2JYeGELcc',
#   'XbnjdV8Vi5c',
#   'apceA57Aadg',
#   '2Opymc6Cbxw',
#   'iKb7UgGxpKk',
#   '0cCZkBCbZco',
#   '1Mufuvyj3wY',
#   'qRh1Qg6swPU',
#   '1yYN4FZDEGQ',
#   '9unIrJQwLNA',
#   'fX9i0RBrLLk',
#   'eYZA9hehwR0',
#   'JxcQrfHYKqI',
#   '4OwzqHqcG1c',
#   '7XVwNBlTIWs',
#   'zgQbOmPp9pk',
#   'ywHjHx8G940',
#   'HBkCeDRkIUY',
#   'uQsxPYqkFfw',
#   'ULIc9dn1TNU',
#   'Chvvzy8loOE',
#   'cFBv6_tAXIo',
#   'Ba_ffkYzPds',
#   'a2pkzoFipuI',
#   'xC2ZMFghEkw',
#   'LK2EopzNnjU',
#   'K4oWnQPSF10',
#   'RPJg_lUfHvI',
#   'y2eeFsmsNdg',
#   'EhJQE9hzIVs',
#   'ZFhqVsst0qc',
#   'ChLFgcWOdTk',
#   'C5eg7J9vCoU',
#   'LS6ra7RK6NA',
#   'jmaJhnP0l3w',
#   'Zu3E27Z3FOI',
#   'Wv4GlT_G2m0',
#   'ohTFAhx3kKo',
#   'HXLainKFXyU',
#   'vhmLncm06Wc',
#   'SXIptFh9GCM',
#   'mCkpcetMaU0',
#   'N5rqYAWRdu4',
#   '3lFAW3VoKHc',
#   'I38DAHs79gc',
#   'HN02LoRFSy8',
#   'wQqdfjkDnmQ',
#   'll04J7XfVRQ',
#   'djxTgqBL2lw',
#   'iEUzOEvInhg',
#   'v8eY_Xa5SGw',
#   'AVxYl4go_FQ',
#   'enQXZ5orGqI',
#   '4aN0e5dOzh0',
#   'AuFFdIhuqs0',
#   '0jB0w2DUB5s',
#   'Y23tsXWjMGI',
#   'dPMiNPHlbLU',
#   'pehY3S0mbRU',
#   'lKOq8sFusR8',
#   'iQwA3WKfaK8',
#   'OSPI7I2SeUo',
#   'd61_l7BtleU',
#   'NIcaM2L_6io',
#   'QIIxhOx7kKs',
#   'OuRTW3NCa90',
#   'fW1eDMJPAXI',
#   'XZXgTgxXjRE',
#   '7gw4cgfRxPM',
#   'AcjaFczpwk0',
#   'sb_iG9dSVPg',
#   'LMDr1kdX2Dk',
#   'oTkv1jJ7fkQ',
#   'he7zUu_6QzE',
#   'jbyNpe0rN9o',
#   'XraGwABUYc0',
#   'OTDkvCGQyVQ',
#   't4hQ13HMook',
#   'BA8XxfCDVvg',
#   'edGx4W9_vhg',
#   'UGhnC3f4kqw',
#   'MuqJeFdzXgE',
#   'YEEkOShrcP4',
#   'W_ofzCKTKvY',
#   'MxXpMANYQn0',
#   'oKGyj4W89P0',
#   'B8uU8Gux4og',
#   'oGiFkt681WE',
#   'XyDxdC9ioIY',
#   'axyvWKQ4MQw',
#   '16ffmJv44fA',
#   'sTCG43meXBg',
#   'qjsFh_Y8svE',
#   'ab5_089XJpQ',
#   'VQ4fb1LsG6Q',
#   'tYBwrXTUMDQ',
#   'GrHUOaNiYIo',
#   '0uQYi8A_eH4',
#   '3tNHGkbhQws',
#   'LqKrDWGup1Q',
#   'UPUYOBG2TtQ',
#   '7hf6KFdMcC0',
#   'Y5kxIA77e1E',
#   'OZhgDD1ScBg',
#   'oLX9l2VylXU',
#   'TPk3pdL6QzU',
#   'c5sL2QXeSEM',
#   'AxEi0Uy8gMQ',
#   'KGB4XuvUdlQ',
#   'El2sv50Jzyk',
#   '7USqEZWi308',
#   'pQOJvMR56fA',
#   'c_hVdvvh_gw',
#   'jluoByJbQgg',
#   'Rbm8GEIVZgE',
#   'jOVBUlR_oZE',
#   '9ISf_UoeXU4',
#   'lj4uaxT3RVE',
#   'pyW6MuLZN48',
#   'I7Q29rHYldg',
#   'EnePz8iNbJY',
#   'IxuS6zAE2Kc',
#   'fmpWBnd5VRs',
#   'qvMxJGqasUY',
#   'QIY5a9P6030',
#   'EtWqWE8gdF0',
#   'FsZpHom40xQ',
#   'lNfbZbkcVVE',
#   'n5eIuJEEdgs',
#   'WqRjVy_YAtY',
#   'mii242r0WWQ',
#   'SjVWia8J9JI',
#   'ZWJ0RSaXA1Q',
#   'v07bTdH8VwU',
#   'JvsqNlgYDFc',
#   'Ru6VfbUnhTg',
#   '6Eypw0D5r78',
#   'zSLNUwcbqqo',
#   'eFW35iYK4cw',
#   '2hcVCMNKuJ0',
#   '_dh6Yop63Qg',
#   'U_tDGkeoFXs',
#   '3nAKKZA9zlg',
#   'ZVlNJtqzXdg',
#   'Kyw_6oSQqzM',
#   'Fbce6jx5jmA',
#   'gE85fd99w44',
#   'btG7pB_pX3Y',
#   'Tw3jvq5C2KI',
#   ...},
#  {'05PK5asBrP0',
#   '0F7lXcoPGSU',
#   '0H2vf25EgmA',
#   '0I4Mxi2V3Ig',
#   '0VppXfycGc8',
#   '0cCZkBCbZco',
#   '0jB0w2DUB5s',
#   '0t1D3P6NYYM',
#   '16PcuNZLnDw',
#   '16gxQE8C1p0',
#   '18lUWxYKgOc',
#   '1HgNReVRvzI',
#   '1OLV2bjYgA0',
#   '1RGBtA_GhWI',
#   '1UOatSFd_hE',
#   '1f77ar1m7Ks',
#   '1iByM08MvqU',
#   '1iMSdRfy0Nk',
#   '1m9T1ddE5U8',
#   '1pWuXjJ1SUE',
#   '1s60RPDoaNU',
#   '1xw5ui2UOyI',
#   '204vg0ZpzxU',
#   '259wx6vTLz4',
#   '2ENOaC3O_2o',
#   '2LjAkg3c6hw',
#   '2YqbKDoFyL4',
#   '2lzmRcaSLRI',
#   '2w9UHpEiUME',
#   '2z9rtGpzPXU',
#   '3Fy5tvgO5OA',
#   '3LDpq53oV0o',
#   '3PDJDym1ZXQ',
#   '3Uh_I6rN_Hs',
#   '3ZFfL3wl1so',
#   '3k0YGdgj5vo',
#   '3lFAW3VoKHc',
#   '3mpFwkjir0A',
#   '3n3meg4bfnI',
#   '3pquLEf8kr4',
#   '3rtbPiaDIDo',
#   '3tNHGkbhQws',
#   '3wlgAGFRppU',
#   '480nF81vFI0',
#   '4ClnLLMUHM8',
#   '4RMoZo69RE8',
#   '4TTTCdfK4FE',
#   '4nlVqcAmMco',
#   '5BzYdU8fqwM',
#   '5EkKjw4mDdc',
#   '5EsyiXMKOPs',
#   '5KiRW2zXunQ',
#   '5NaAEyaQJrA',
#   '5Uz5LVKEYYU',
#   '5a0LLRhy1_U',
#   '5e5vf1WrQYg',
#   '5f6UWoANodU',
#   '5jFfRm_sGV0',
#   '5kTHtaAxtGo',
#   '5o2rhvamLBM',
#   '5tgCO0mVqxU',
#   '5u6iuXms50M',
#   '657jf2KYTfw',
#   '66Oih2dmURc',
#   '6HX5dmPKqWQ',
#   '6NFjjfvQ7ZQ',
#   '6RBRUDvbHGM',
#   '6dEyHaXpGaM',
#   '6eBEz91Zwh8',
#   '6hi5BgAaB2U',
#   '6kTSTAVyFec',
#   '6kvWn7nO9q8',
#   '6ohqeoNGpc8',
#   '6p74_Ar_qmc',
#   '6sNOi4OG4sw',
#   '6u6zU5ujaIY',
#   '72b4w0FKXiQ',
#   '78X96DCTFpc',
#   '7DTaoLcybuM',
#   '7G29Odeyqpk',
#   '7Mn1mlrNFgU',
#   '7OEf12TqmBc',
#   '7OL4fdbXK98',
#   '7OoP4lQVV48',
#   '7TB5Wu3zj0w',
#   '7VNGhuCG6ps',
#   '7XVwNBlTIWs',
#   '7fsccwLqxL8',
#   '7gw4cgfRxPM',
#   '7hf6KFdMcC0',
#   '7jaQmQj3Wgo',
#   '7lNpXrFIMbE',
#   '7pgJFwOBqaQ',
#   '7pipCxfvJ20',
#   '7qB9WsTtMIQ',
#   '7qSjHkGx6k0',
#   '832yhHXntNo',
#   '8G6vBOOtiy0',
#   '8GCGRdwg80Y',
#   '8KgIU34hVPc',
#   '8LQvYszWb6k',
#   '8V9tq1pe8eI',
#   '8WIjnu3QRus',
#   '8Yu_uR8rZrA',
#   '8_VkxmHeMAk',
#   '8d2qntjg2GQ',
#   '8l88wzheGsc',
#   '8sPhyRCJPJQ',
#   '8vpg6d_fGv8',
#   '8xaLfHCU2KM',
#   '98xXlNVvfq4',
#   '9GbYnL0tvcg',
#   '9JVCjzcvXco',
#   '9KRJZByi__U',
#   '9MgK7U5LK_A',
#   '9Wk7pYmWt8I',
#   '9dhhuPr0JyI',
#   '9vhyOOVeEBg',
#   '9vnwSP2Cw0k',
#   'A8YZM0KBQcU',
#   'ACB9OhqECtc',
#   'ACbXnJFl3tc',
#   'AHERxteoNPw',
#   'ANd2wYIi8oU',
#   'ARcj4_TQwHE',
#   'AW8szIqnqjU',
#   'AatPAzgWKdQ',
#   'AgsOk1HIPag',
#   'AhGHDceWnOk',
#   'AjQkYpuB6Dc',
#   'AkNlDAXFEU8',
#   'AvfpnsqaWw4',
#   'Aw5ynnoQnQE',
#   'AxEi0Uy8gMQ',
#   'B3ZakJ4O5uw',
#   'BA8XxfCDVvg',
#   'BEH6RWDGy7c',
#   'BFrL0jSJ_tg',
#   'BKHh_GS__Xc',
#   'BMTukOpi23I',
#   'BPXIPKqx3j4',
#   'BUxpgSVmM2Y',
#   'BWFN4M0mNuk',
#   'BWSxerD3LDc',
#   'BaRN5FQboew',
#   'Ba_ffkYzPds',
#   'Bbaal2Neohk',
#   'BeCS4X5oyXQ',
#   'BfX0BJRrRhI',
#   'Bg6idO0U7d8',
#   'BmdvXmV5TTo',
#   'Bp9Myhl1Mps',
#   'Bvr94mzYPBs',
#   'C0yg97HrglM',
#   'C2xtDX5qexc',
#   'C5eg7J9vCoU',
#   'CGcUCL07vLo',
#   'CIQ3Ave21Kw',
#   'CLhbDUJgvFo',
#   'CSr36NrNoWM',
#   'CX2yWOhmwbg',
#   'C_nsbjuAyrs',
#   'CbkPKh8ETYc',
#   'CmoGZ3DBmr4',
#   'CpCJuA2U3wg',
#   'CpUnvHn0xcI',
#   'DC5AS8u3o3c',
#   'DEK6RHxvXD4',
#   'DcdoBrCvS9o',
#   'DmYYZ8Dr17s',
#   'DoCN8XTwZFo',
#   'DzOS_wLQMsc',
#   'E0tPrAYY1qo',
#   'E7YUoWI0Qwc',
#   'EBvJ2rWj7LM',
#   'EFtSONw79Cc',
#   'EKojB84HQfg',
#   'EcfG7zdjBYQ',
#   'EhJQE9hzIVs',
#   'Eizcm0GYu_0',
#   'Ejb6HObUkeI',
#   'EqVZ1Bet5U0',
#   'EtWqWE8gdF0',
#   'Ez9tXJrcag4',
#   'F8OVbRQgLao',
#   'FH2BgOVARVo',
#   'FN8jOLvssjM',
#   'F_fkQUutMzg',
#   'FfyaQJcpnFk',
#   'FkKOGn0GCw8',
#   'Fve8VR92fek',
#   'FxRayyob69s',
#   'G7eFHY90kFs',
#   'G82kzhYUINo',
#   'GENdU9GxZ9g',
#   'GEbWT0HUnfw',
#   'GKoKWkcNojE',
#   'GQoxlTN4uc4',
#   'GWzi144zrEs',
#   'GYBLqxwKJzg',
#   'G_VBKWCoQTo',
#   'GdJVLA16hUc',
#   'H4wEbdhEyWI',
#   'H5hfCFM8KK0',
#   'H6B_nTqoq3Q',
#   'HArKPHipKx4',
#   'HEJ6RAmVM1A',
#   'HI7Js8ej53I',
#   'HN02LoRFSy8',
#   'HOkBohJhbPE',
#   'HSNBvFfipNs',
#   'HXLainKFXyU',
#   'Hc_jvVkNVJs',
#   'HlQX_Fvu7hI',
#   'I6fOELoabyU',
#   'I7Q29rHYldg',
#   'IDBLfpy15Jk',
#   'IGJVw1HjIHc',
#   'ILMtclIfRN8',
#   'IWzovfmUXWE',
#   'IbNzJFmtkZ0',
#   'IdLaynfyUOQ',
#   'Isab2NO9jlk',
#   'Iw1u6ZYA4t8',
#   'JSXEHqFCYgE',
#   'JcNIGDJMlxg',
#   'Jcypy2AgHMo',
#   'Jg_x1fbZtsY',
#   'JyzAOR0GTs4',
#   'K0Y6z7H4u50',
#   'K60W7P6cB6c',
#   'KC4dx3NyO_I',
#   'KCHy3SxfYUA',
#   'KLa6cSuvBJQ',
#   'KO_jeuest9s',
#   'Kfqr0U0FcXQ',
#   'Khfp7Hhc5Vk',
#   'Kjw9SWuqcZI',
#   'Kl_jFoATGoc',
#   'KnZuRjwzbus',
#   'Ko04pecy63Y',
#   'Ks19MD2LRUw',
#   'Kze2x40RihY',
#   'L0Txo5QR7Rw',
#   'LA0_b4COZtM',
#   'LAegzV76Aa0',
#   'LB3bJPyTVF0',
#   'LCQUAK01D90',
#   'LOQOS5IJtlM',
#   'LjQR8qT8s_s',
#   'Lm12f30wJ1I',
#   'LsbRXTusV6E',
#   'MCQ8KvHvalc',
#   'MKX0zLqY7YU',
#   'MOH8b4moNLo',
#   'MWMmHcPKvfs',
#   'MfLGxnBWVxQ',
#   'MhHCQ_cb3T8',
#   'N4YDaU51lvI',
#   'N5rqYAWRdu4',
#   'NCNKcWLA7WM',
#   'NCSbC9Ma6ps',
#   'NoeaLFiCFkc',
#   'NxpCRpuABsw',
#   'Ny0armaD5cw',
#   'O0f5ymS7z3c',
#   'O1pUs5EpWVQ',
#   'O5SvwYGbXCE',
#   'OBQ4Oqmi_tc',
#   'OIS8cAZNmdI',
#   'OImI_S8C2vo',
#   'OKeOx2sOe54',
#   'OSPI7I2SeUo',
#   'OTDkvCGQyVQ',
#   'OUPHieGN4UU',
#   'OXGETrqx8JE',
#   'OcZJIp3KUYs',
#   'OeHxe75lMNE',
#   'Oj3BQZzaXq8',
#   'OxvFKNl0CxQ',
#   'Oz7FkuxsmJU',
#   'P2zBgBTaARs',
#   'P9prvFtgyCQ',
#   'PBbgRoZhU_8',
#   'PJmTaepVp5o',
#   'PNeuhGDHGyc',
#   'PPjvKfcmY6E',
#   'PS7ekUerwGc',
#   'PTmX0CXPK7w',
#   'P_KbNZi5uUo',
#   'P_Xncte6zqg',
#   'PeQifrSZmBo',
#   'PmEa9xL7awE',
#   'PwGdpbguE4w',
#   'Q8KfV3zaCYQ',
#   'Q9bo4mKKszc',
#   'QMUCHwM0CR4',
#   'QTY7qBMdetU',
#   'QWcoSqIji_Y',
#   'QXFgitfOR2w',
#   'QXOP9pviJ58',
#   'Qb80uEMXEmE',
#   'QeJimN_cFSc',
#   'QpjmOepR95c',
#   'QtOjRnw10Ig',
#   'QtZExndP66M',
#   'R02ljlzvh_A',
#   'R2C3fHcNm1k',
#   'R2QHQxsQuDw',
#   'R7WCewA1O_o',
#   'RCJjWkmMdD4',
#   'RF56oE4gsJo',
#   'RFB43deNEQ4',
#   'RNk8WSAmmWI',
#   'RPJg_lUfHvI',
#   'RXrXXZOSLgY',
#   'RcoZ2dP5vZw',
#   'RkpKaStFYEM',
#   'RnHNLsRRo7w',
#   'RpD1D9pgpB4',
#   'RqQe0ewBrD0',
#   'SCYnEIq3mCY',
#   'SEi1aeadnXw',
#   'SKs9CmsEhuw',
#   'SRtSBaFd8Ek',
#   'SafvgsfvS2g',
#   'SdycpaKESd4',
#   'Sj5vhnLGKHc',
#   'Sk0rAunGmlQ',
#   'Sm3Z7wqn59s',
#   'Sy0AFDqBvqw',
#   'T3WKGqIXBnU',
#   'TBmiGKuo9fM',
#   'TGvJRDIey5s',
#   'TIojRu4_23s',
#   'TOCCUCfrz0M',
#   'TTrVFSRUGIE',
#   'TVy2hkF_G9c',
#   'TXmIsqvT5pc',
#   'TYDaYcOCGho',
#   'TrgPuJHj7p8',
#   'U46oxWqK7AI',
#   'U9cyavnOr1E',
#   'UD18COn9a70',
#   'UDlsIakb9Kg',
#   'UDySRbaEssc',
#   'UKVile_HpwQ',
#   'ULIc9dn1TNU',
#   'UPUYOBG2TtQ',
#   'U_tDGkeoFXs',
#   'UctkmnbuBIA',
#   'UfpByy3jOCY',
#   'UojljloKmhI',
#   'UrEJ7oAhcX8',
#   'UvF7rFqqfmc',
#   'V1_PsCPvC6o',
#   'V3_VN8NqFoA',
#   'V4I6bV6QWUA',
#   'V9LhxvG1GWg',
#   'VBdcD7hLGuo',
#   'VL5297KySxk',
#   'VWZCDkOGm1o',
#   'VcAH9WxXC74',
#   'VjS5hmgV4qI',
#   'VmFgMqSkA78',
#   'VpSpwWMW5eA',
#   'Vpmg0GAshHU',
#   'VxK7lhI_2pc',
#   'W0wawEKN78g',
#   'WQzOYp3hhpM',
#   'WSZVw3qGyg4',
#   'W_ofzCKTKvY',
#   'Wb9t801rKTg',
#   'Wd69L0vmaOQ',
#   'WhhUMO5C0SE',
#   'Ws5feMfuQ7I',
#   'WvtTKK9k34E',
#   'WyHI8VAPJzw',
#   'X1fpSLDLbFg',
#   'X48jgyzoQdE',
#   'XIVW8tVnBEk',
#   'XNBOk8QO8I0',
#   'XPGhLx3rcf0',
#   'XRG7yKuCzSc',
#   'XWd602XfKh0',
#   'XavptifouvM',
#   'XnakBVeh0n4',
#   'XvkQBrWnbF8',
#   'Xwq_TnOSn2A',
#   'Xz9hCrwDk0Y',
#   'Y5pjN6z1JjU',
#   'Y877USjPGms',
#   'YDo5YyIgPbw',
#   'YTwOrQoynA4',
#   'YbjDi_yvMmk',
#   'Yfe4hUAECCE',
#   'YgnDKgGpPio',
#   'YmZgpnyhJR8',
#   'Yr2ZLfWT0i8',
#   'YzWZZb7UdqI',
#   'Z3Vbzpo2Bf8',
#   'Z477uI7POtM',
#   'ZAlqIYFjm8Y',
#   'ZFhqVsst0qc',
#   'ZSX8Onpr7Qw',
#   'ZZXEbSw1KrI',
#   'ZfX1iafZ0fc',
#   'Zh1zuwyiiX4',
#   'ZjeNTjm_uo0',
#   'ZvpiV4iHzOE',
#   '_86qb39xPdk',
#   '_86udPds4Wg',
#   '_FsOnRDIJQQ',
#   '_IimozO_x50',
#   '_LqGQPwtH4Q',
#   '_RIH7fRpJtY',
#   '_d1oBbMQQGM',
#   '_ezYjZ5q1MQ',
#   '_l6NM6NEKdI',
#   '_lk2xErspiE',
#   '_pRpOiXW2N8',
#   '_srfsUOpKig',
#   'a4UF4C1hiB0',
#   'aFgm2xjoim8',
#   'aGQDt0mDyCU',
#   'aHBaWrd09KY',
#   'aMGS7vyx4Zo',
#   'aMRBsJyZFYc',
#   'aMWKWcdyYMo',
#   'aPwTtMXPv3o',
#   'aQtPOiovlzM',
#   'aWAp9pXi_DI',
#   'agJgHzMHu3w',
#   'avv2l7778JA',
#   'ax6mM3Rr_ws',
#   'b4mdZR5OCUA',
#   'b4wW_q5RKng',
#   'b5u_fevmt7I',
#   'b88hhCCKu4E',
#   'bG4PMwbefRE',
#   'bIH7u90sJ3Q',
#   'bIppytTQ0aI',
#   'bR8REmVupt0',
#   'bZ5hKMRmYg4',
#   'bc8xOmoiZm8',
#   'bflB2XYu5rw',
#   'buAn47zBd3U',
#   'c3prYnNzy3M',
#   'cABj7BBhFd8',
#   'cFxMpyxnJV0',
#   'cU6eEgIvz1Q',
#   'cXAaYu0JM_s',
#   'cXMr5QBndeA',
#   'c_hVdvvh_gw',
#   'cd0MpMM7vLE',
#   'ckIKm_pio64',
#   'cslXqrcH5qg',
#   'd9tZZGbLQMU',
#   'dHohXDBK3KI',
#   'dJt7PtJobAw',
#   'dPMiNPHlbLU',
#   'dWESn5qU5FY',
#   'dXqn8xhYSr8',
#   'dcrF0fcizRA',
#   'dhZbOwKw7wg',
#   'djxTgqBL2lw',
#   'dpakDRRYQPY',
#   'e0ueNDDD1qI',
#   'eBKS1dCabuI',
#   'eETQbq80d3o',
#   'eF4OaNRUvgg',
#   'eFKv8712V4w',
#   'ehyCswv8byU',
#   'es2HApj6HwY',
#   'fJEqh1YLGes',
#   'fX9i0RBrLLk',
#   'fXpqstfOzck',
#   'fcmIYoQtOmE',
#   'fcxSmwjtuAA',
#   'fgOr3z8mSDA',
#   'fgTr47WT4rI',
#   'fiMBa8W8UMo',
#   'frBM3E7xXlI',
#   'frpPLNtClhE',
#   'fxThU75vC38',
#   'fyvhMbNv0B8',
#   'fzMD9GjvcSY',
#   'fzzTqB8lB_Y',
#   'g6yvs1f4S1s',
#   'g81mNCrBnO4',
#   'g9kNoBu80r0',
#   'gBI2LEk4If4',
#   'gE85fd99w44',
#   'gEeZgnhdRmI',
#   'gIgKGAFdKFI',
#   'gKPHum_NzX0',
#   'gQg3cyWahgc',
#   'grKYOG3pTpI',
#   'guvvQcKfLvw',
#   'gvoKkcw61pA',
#   'gvxfRjCwhFQ',
#   'gzOhOZQ8DgY',
#   'h43bURok9aY',
#   'hAZVkr4f534',
#   'hBabeQT8a2w',
#   'hFFskmCQkuM',
#   'hX8S64wZSDU',
#   'h_FfxeLeMOc',
#   'i4cQkYkr8Lo',
#   'i5qd1RMfkRE',
#   'iGv7gFmM3vk',
#   'iMIQeECfdwE',
#   'iMj5gB0XHRw',
#   'iQHhtTpBD6A',
#   'iVtaHvUDLC4',
#   'igQ6Dkbqq_I',
#   'ijUj_XN506U',
#   'im2J3GRCnGk',
#   'ioHd1Rcp5Ew',
#   'ipCgTr9DwO0',
#   'jCmTFXiThTk',
#   'jNTZDRtKZqs',
#   'jOVBUlR_oZE',
#   'jTa54byZKHg',
#   'jTizVpdiPa0',
#   'jWOoeD3haY8',
#   'jZvY8BEjnys',
#   'jdpYInLk2Ow',
#   'jfBzqghHCkM',
#   'jocluVfUT48',
#   'juOuzbcmpqg',
#   'jwYlYq6oGIU',
#   'jzDmk010Ra0',
#   'k5QBkYqUIPk',
#   'kC3wiRad5TE',
#   'kHVk5bHKpWc',
#   'kNWJ3yYgYCo',
#   'kQ4Y6EPljPk',
#   'kQhE3DjhkAA',
#   'kSIzlvs8ngw',
#   'kT3mXnMeBXM',
#   'kYrGsnwOcRM',
#   'kolVH5PDzI0',
#   'kulZ_sWzBR0',
#   'kx99oKm_K_U',
#   'kzxUQG7yJTU',
#   'l24bJeUqLao',
#   'l7mITXdbzNw',
#   'lFWYh_HTYxE',
#   'lHNtdUcq2_A',
#   'lJ6ePdJnXNY',
#   'lNfbZbkcVVE',
#   'lNwXQrpMfhM',
#   'lQ2yjMzByCI',
#   'lhFIwEfjChE',
#   'liPZA3Zdvig',
#   'lj3bwmr3dp8',
#   'lnCLMrjQgis',
#   'm3Clq7uulPg',
#   'mGKo9gaXuF0',
#   'mJpS5m0AEIM',
#   'mYCKzV49rx0',
#   'mdyixrMtD_8',
#   'metH403loSY',
#   'miut7_nlyXU',
#   'mpg2dM5DrGg',
#   'nHs8cNkmgds',
#   'nMSrzqjAFfs',
#   'nXmeeUgYlGA',
#   'nhR2CoWjLZQ',
#   'njo30ReYSKg',
#   'nl6gIl_59GI',
#   'nqovdxY2Mmw',
#   'nuseh0QL7Tg',
#   'nxy6fHm96Ns',
#   'nyG7yKBfzjY',
#   'nyliOKM_9J4',
#   'o1BNtH2rqY0',
#   'o4LyycKz0wg',
#   'oCPRsBiXlf4',
#   'oCsHNgql560',
#   'oE9qrxR7DpI',
#   'oLX9l2VylXU',
#   'oRYKnD_df5M',
#   'oWyqKDfhtgo',
#   'oYykJu6A7Dg',
#   'ob5auOJ5mS8',
#   'oeG4FprNOkc',
#   'ok43drtlLz0',
#   'oobHYBDiDAc',
#   'orEhowBkuKI',
#   'ov4ghi_kG3U',
#   'p2NgeOyvtZs',
#   'p4SMy2tB_ZI',
#   'pIo6ZNDOhZo',
#   'pLifvTWuvHg',
#   'pQOJvMR56fA',
#   'pRbi4o3O038',
#   'pY2JYeGELcc',
#   'pZUgbSkK8to',
#   'pcAhoVDv2Gs',
#   'pehY3S0mbRU',
#   'pj52Pr5mUu0',
#   'pvsImT6E4yM',
#   'pvwgTTH4tKw',
#   'q85rmRUdgK8',
#   'qDbDFbNEPe8',
#   'qFFBi8ok6NU',
#   'qFhfefDONtQ',
#   'qKdeiL8Zrsg',
#   'qlD2vNmS5e4',
#   'qmMZmy8rfg0',
#   'qrnDvRIqndw',
#   'qvMxJGqasUY',
#   'qvPu7qxSnes',
#   'qxa2fKVjIAM',
#   'qxbz9rvlyRE',
#   'r3cTVf3Ka60',
#   'r6RJWuLenrU',
#   'r8IFPvdG40s',
#   'rAkxQk_SimU',
#   'rBmOKZYKOhE',
#   'rH5PqTOIt6Q',
#   'rKTXenn5XDs',
#   'rZSKHRWnfIk',
#   'rcPGxL2zLqI',
#   'rgWY9ejMESU',
#   'rqhejKh3_XE',
#   'ru2f_m_xsg4',
#   's4MqASVecXc',
#   'sAr8atA3tuY',
#   'sGPdUbK7nKQ',
#   'sRRlYasWUaM',
#   'sVg7ZFD2dyg',
#   'sg4JV3TYzs0',
#   'soJyv0EcQQo',
#   'ssd85B28W18',
#   't2_cwoQxmzE',
#   'tEAkJ8mUMdY',
#   'tIlamQpNpXg',
#   'tYBwrXTUMDQ',
#   'tdmk1MYHMs0',
#   'tn5QG7h48xU',
#   'ttL7ytiF9f0',
#   'twGX5mN6Mcs',
#   'u3sQ_lh7z1c',
#   'uAUhYFwY2c4',
#   'uB0TeB35l94',
#   'uBDsQXn1DgQ',
#   'uFqVjc0lUzc',
#   'uGnvayaksyc',
#   'uK9kCxpB6t0',
#   'uLIQAbifOME',
#   'uQNiS4UGe6E',
#   'uS7uQmzCi1w',
#   'uSmYsUnuNM0',
#   'uUgYlA8Afko',
#   'uXWqKxbROyY',
#   'udNdqhGlkSA',
#   'um1pjcGH6XU',
#   'usdTl9ddSIg',
#   'utbSnaURXfI',
#   'v80aiuXB0W4',
#   'vC8HCxU34jk',
#   'vINAdKErbJo',
#   'vMxEQFO8teQ',
#   'vPfHZc52LfY',
#   'vY7Q1i03tlg',
#   'vYQWj2HLsg4',
#   'veM423POiU8',
#   'vhxBEmsc8zM',
#   'viTrbKvW7bA',
#   'vqRJnlPbXHA',
#   'vzaDsrnirqc',
#   'w25yutHRugA',
#   'w4CQ0fKNBeU',
#   'wBjDafmCd_c',
#   'wH4L9NiHHIE',
#   'wUBZ6f87Pf8',
#   'w_F_4UwdR0A',
#   'wdHldaeg_VE',
#   'wq5MQd1Lv0c',
#   'x0YH_9VSFus',
#   'x4ioRas_9l8',
#   'xD8uW0Hj6v0',
#   'xLHg6fzOZwE',
#   'xPgddk3AnRQ',
#   'xsuRFseeHTA',
#   'y2PMMy7r840',
#   'y4sMCzeb_y0',
#   'yGMZGa090vU',
#   'yH9Ln2_GH3s',
#   'yK7iNLl2Tqo',
#   'yP0QLRg5DWc',
#   'yUPlayjTnNA',
#   'ylA9LrcU9vo',
#   'ywaY9qRQ4Ag',
#   'z0cVY9navGM',
#   'z7IjzketUfY',
#   'zJdse775slU',
#   'zLSi0My6vuQ',
#   'zaHnVJggOdQ',
#   'zfWbqwdkGTc',
#   'zgQbOmPp9pk',
#   'zku9IPj58EE',
#   'zmmMNX_dDg4'},
#  {'071PtpSHv5c',
#   '0I4Mxi2V3Ig',
#   '0R2LivDo2wQ',
#   '0_zAXK9DGd0',
#   '0ntQWNrTmDk',
#   '0t1D3P6NYYM',
#   '18lUWxYKgOc',
#   '1CStKx0DgxM',
#   '1CvWFADo2qc',
#   '1HgNReVRvzI',
#   '1LGjDfeIowk',
#   '1LSDvAXn2Ug',
#   '1SdW2lh6Ukk',
#   '1dquYfeo4BE',
#   '1iMSdRfy0Nk',
#   '1lzCmIzeSjw',
#   '1pWuXjJ1SUE',
#   '1s60RPDoaNU',
#   '259wx6vTLz4',
#   '2C9oRCAardw',
#   '2D4JD2O9X3w',
#   '2ENOaC3O_2o',
#   '2LjAkg3c6hw',
#   '2kbuzrWxBdk',
#   '2w9UHpEiUME',
#   '2wRFVUx8IoM',
#   '31aWkYp8WJE',
#   '31liERlX9Tg',
#   '39d7OyFvbcg',
#   '3LDpq53oV0o',
#   '3PDJDym1ZXQ',
#   '3SBdodj8960',
#   '3ZFfL3wl1so',
#   '3k0YGdgj5vo',
#   '3n3meg4bfnI',
#   '3nhgTd3mC1g',
#   '3ogB_jaW4FI',
#   '3sQyM32CHC8',
#   '4ClnLLMUHM8',
#   '4Qtvx6lDmKc',
#   '4mSjysXw9KE',
#   '51s31Ae5J_M',
#   '57OwgYk16_E',
#   '58xSm8LSj9M',
#   '5EsyiXMKOPs',
#   '5JYPsDsH3oc',
#   '5T1gZdTgXPI',
#   '5YZKKCxobSA',
#   '5jFfRm_sGV0',
#   '5tgCO0mVqxU',
#   '5u6iuXms50M',
#   '5wJnN4KgoaI',
#   '657jf2KYTfw',
#   '6HVBMCL7PI0',
#   '6LX94cGktSo',
#   '6NFjjfvQ7ZQ',
#   '6d9nXmIAqx0',
#   '6epcwvnSNyc',
#   '6ohqeoNGpc8',
#   '6u6zU5ujaIY',
#   '74xhLbzeNU0',
#   '7DTaoLcybuM',
#   '7G29Odeyqpk',
#   '7OoP4lQVV48',
#   '7TB5Wu3zj0w',
#   '7VNGhuCG6ps',
#   '7XVwNBlTIWs',
#   '7bYDoG7BtvE',
#   '7fsccwLqxL8',
#   '7hkjqGRP7OA',
#   '7pgJFwOBqaQ',
#   '7qB9WsTtMIQ',
#   '81OFaVpvkpM',
#   '87VSEWibVdM',
#   '8G6vBOOtiy0',
#   '8GCGRdwg80Y',
#   '8KgIU34hVPc',
#   '8L8nn4t8x3k',
#   '8LQvYszWb6k',
#   '8NPLf81Tbno',
#   '8V9tq1pe8eI',
#   '8_VkxmHeMAk',
#   '8cB6SKJGuYY',
#   '8pG5yyA3pts',
#   '8xaLfHCU2KM',
#   '9GbYnL0tvcg',
#   '9JVCjzcvXco',
#   '9KRJZByi__U',
#   '9Wh9FqL2Xk8',
#   '9vnwSP2Cw0k',
#   '9ya9jdOyiZU',
#   'A3y7gcwGWCw',
#   'A8EHhMhwoGo',
#   'A8YZM0KBQcU',
#   'ACB9OhqECtc',
#   'AKGGBc4t9xs',
#   'AMaxpmVfu3k',
#   'AatPAzgWKdQ',
#   'AjQkYpuB6Dc',
#   'AkNlDAXFEU8',
#   'Ame4Wu8KfsM',
#   'AoB889WmUsA',
#   'AxEi0Uy8gMQ',
#   'AzaTH5Fcu5k',
#   'B3ZakJ4O5uw',
#   'B6eMvq1BIug',
#   'B80Md3RbcW4',
#   'BPXIPKqx3j4',
#   'BWSxerD3LDc',
#   'BZ80_0ARk6w',
#   'Bbaal2Neohk',
#   'BeCS4X5oyXQ',
#   'BfX0BJRrRhI',
#   'BlyDLK8k04A',
#   'BmdvXmV5TTo',
#   'C3862JVMR80',
# ...
#   'CpUnvHn0xcI',
#   'CuFWV2Ts8eI',
#   'D9BypvVyS4Y',
#   'DEiWkLwHS6Y',
#   'DP3nFc6WMYY',
#   'Dk93ivXHteA',
#   'DoCN8XTwZFo',
#   'DyGPB2fan30',
#   'EBvJ2rWj7LM',
#   'EcfG7zdjBYQ',
#   'EhJQE9hzIVs',
#   'EqVZ1Bet5U0',
#   'EtWqWE8gdF0',
#   'EyQTMdxuqSs',
#   'F65G8BhqvHc',
#   'FIHRgreiagM',
#   'FR6xFQX_wGo',
#   'FSEU3O_vrcI',
#   'FUS0hsPCtMs',
#   'Fc4drtbgDb0',
#   'FcK1oTwMsFQ',
#   'FdcrtOMslHI',
#   'FmeNmsKYwWU',
#   'Fve8VR92fek',
#   'G16TpbnSpFw',
#   'G7eFHY90kFs',
#   'GE2wqxWBvYI',
#   'GWzi144zrEs',
#   'GZG9nDbIgXM',
#   'GjlduZjqHxA',
#   'Gk0ACL1WBW4',
#   'HGpG2rbfmvc',
#   'HNKY3MHRejY',
#   'HOFjdBDqknQ',
#   'HOkBohJhbPE',
#   'HXLainKFXyU',
#   'HkDdiq4c8Mg',
#   'HslyuL0PeYU',
#   'IDBLfpy15Jk',
#   'IqAwin7WV6E',
#   'IvcoZk5ZsyI',
#   'IxuS6zAE2Kc',
#   'J3ZzEixVXKs',
#   'J3lK1h2j7Lo',
#   'JV6ZUdw_lXQ',
#   'JcjWum79akI',
#   'Jcypy2AgHMo',
#   'JghIp4n7Uxc',
#   'JmUwCbGEtNM',
#   'JtV7uEMOkYk',
#   'JuGbyzRd1oY',
#   'JvsqNlgYDFc',
#   'K39LN8yzimg',
#   'K4oWnQPSF10',
#   'K5GIun0flM4',
#   'KC4dx3NyO_I',
#   'KHyLRPII8ow',
#   'KRmJLMt89b8',
#   'KcPvxkYZrEU',
#   'Kfqr0U0FcXQ',
#   'Khfp7Hhc5Vk',
#   'Ks19MD2LRUw',
#   'L0Txo5QR7Rw',
#   'L9bkiAADDIY',
#   'LJfO12NnyFc',
#   'LJiP_ouvA9k',
#   'LVPw3VkNyME',
#   'LVnzp2y1jgs',
#   'LsbRXTusV6E',
#   'M4ZBsM_a6pA',
#   'MIzN8O6pfmA',
#   'MJtGR4MDI4M',
#   'MTFBaKAeuDQ',
#   'MUXruJEcy6I',
#   'MdMDS31Mul4',
#   'MfLGxnBWVxQ',
#   'MhHCQ_cb3T8',
#   'MuqJeFdzXgE',
#   'MvEFmdxPhDo',
#   'NAkLZNlnhUs',
#   'NGI6DX_qeso',
#   'NeMTKw_SZRc',
#   'NxxWj8KR7sc',
#   'O3iT4_8jUVw',
#   'OE8ujtE5ybI',
#   'OIS8cAZNmdI',
#   'OcZJIp3KUYs',
#   'OeHxe75lMNE',
#   'Of8aDHV2A1w',
#   'OfRfGDFKKio',
#   'OqCwUFwFdsQ',
#   'OxCmqfD612k',
#   'OxvFKNl0CxQ',
#   'P5XTGJk6h28',
#   'P5m6gzHdiQI',
#   'P9prvFtgyCQ',
#   'PAoRMtCoyhA',
#   'PLDcB2en5vk',
#   'PTBPLnAAJiI',
#   'PUNCf6sid4Q',
#   'PlyZ7qY2UX0',
#   'PzC8LWAObVw',
#   'Q8KfV3zaCYQ',
#   'Q9bo4mKKszc',
#   'QIF4PAQBRS8',
#   'QepY2n76x2w',
#   'Qhhka9zIUzI',
#   'Qmn1S9yjxB4',
#   'QyJBnfh233A',
#   'R4o2jakVqNg',
#   'RCJjWkmMdD4',
#   'RRDRvwWQgVE',
#   'RUe6znlWfo0',
#   'SRBkkbE7Uyg',
#   'SRtSBaFd8Ek',
#   'SXIptFh9GCM',
#   'SaOSZykkKso',
#   'SadjmAZdRlg',
#   'SbojRKRb8NE',
#   'Sk0rAunGmlQ',
#   'SnbDtuHGdqE',
#   'Spmn5G00Lng',
#   'TTrVFSRUGIE',
#   'TXbhyTyHmyA',
#   'TYDaYcOCGho',
#   'TZi6krD1RuI',
#   'TawfVjq0fxM',
#   'TdBCP2P6yVc',
#   'TmcyXjIlSOg',
#   'To6iQZhM29g',
#   'TrgPuJHj7p8',
#   'TuienbOohV0',
#   'TyzfA87Zboo',
#   'U46oxWqK7AI',
#   'U4HIWejXzlc',
#   'UBVqFj2mwWM',
#   'UCzXULyScAU',
#   'UF43Ol2R4HQ',
#   'UKVile_HpwQ',
#   'ULIc9dn1TNU',
#   'UUKdaBrF4Eo',
#   'U_tDGkeoFXs',
#   'UyyRvYKKHf8',
#   'V2fic27Vsss',
#   'V9w9RE4zg7U',
#   'VBdcD7hLGuo',
#   'VcAH9WxXC74',
#   'Ve7bkylp4Xk',
#   'VwgAnmMsah0',
#   'VxK7lhI_2pc',
#   'WQzOYp3hhpM',
#   'WcRHKUhrmHQ',
#   'Wd69L0vmaOQ',
#   'Wxk7wlMV04I',
#   'X1fpSLDLbFg',
#   'X5qrIxcQEus',
#   'XPGhLx3rcf0',
#   'XavptifouvM',
#   'XbnjdV8Vi5c',
#   'XcJfbADgIhs',
#   'Xhf4CdRsMfg',
#   'XnakBVeh0n4',
#   'XswBqDSbWjI',
#   'Y3BpcUDDDis',
#   'YDo5YyIgPbw',
#   'YFhOILNPnB4',
#   'YN6xuSz86PA',
#   'YSH2xuNak44',
#   'YTwOrQoynA4',
#   'YXMgrpbXFTM',
#   'Yfe4hUAECCE',
#   'Yr2ZLfWT0i8',
#   'Z3c_UEvxq3U',
#   'Z477uI7POtM',
#   'ZeEfrGgvjtk',
#   'ZmahvhKmnns',
#   '_2rlddA7wXg',
#   '_A9a4Ws5dts',
#   '_JDO9FKXZ88',
#   '_RIH7fRpJtY',
#   '_Ya18fCiA0k',
#   'aAjETGq6K9M',
#   'aGQDt0mDyCU',
#   'aMWKWcdyYMo',
#   'aPwTtMXPv3o',
#   'aQtPOiovlzM',
#   'aS8D2CVcu3s',
#   'aVPfq1nS6S8',
#   'aZmtVidm4Tw',
#   'a_SoPbglmYg',
#   'aaWdowfdCg0',
#   'agAUR7SzzH0',
#   'agJgHzMHu3w',
#   'amxtLcpaawM',
#   'b11cWchguq0',
#   'bfMcpOxx1pU',
#   'bflB2XYu5rw',
#   'bt7g4VoVBoE',
#   'cABj7BBhFd8',
#   'cf6j1Uq7HhA',
#   'cgCRXHfO6Z4',
#   'cgS9ODt4bQA',
#   'cgWXbjsANe0',
#   'dBqFkaX130Q',
#   'dD3A1IseY00',
#   'dHohXDBK3KI',
#   'dMzNNYwDEx4',
#   'dPEQnpgBi5c',
#   'dWESn5qU5FY',
#   'df634Rr9A54',
#   'djxTgqBL2lw',
#   'e4s1urJLIjI',
#   'e6__HtdFr0E',
#   'eC2wI3jh0h0',
#   'eHtgG748qhI',
#   'eJrrDQe1scs',
#   'ebGaOVFUc50',
#   'enQXZ5orGqI',
#   'eoVDyaZPcUU',
#   'eqEmUZF5LQY',
#   'es2HApj6HwY',
#   'euEqygu4peU',
#   'euxnPQ3FlnM',
#   'evVtrLqloLU',
#   'f694PFHVMFM',
#   'fBy2KLLuNp4',
#   'fQF9fc7tQq4',
#   'fX9i0RBrLLk',
#   'fZiaUKJSy0M',
#   'g0PivPwcYPM',
#   'gARgK8NjSDc',
#   'gRgeisH8yAA',
#   'gl486Y5GB0w',
#   'gmMul24h0_Y',
#   'grKYOG3pTpI',
#   'gzOhOZQ8DgY',
#   'h1Nh2eS2kp4',
#   'hAZVkr4f534',
#   'hFFskmCQkuM',
#   'hJzuRTfhgIc',
#   'hX8S64wZSDU',
#   'hd3QRlRM6xo',
#   'hepgJ44h3WA',
#   'hgdY_I44Ffo',
#   'hhVLTUla7r4',
#   'hoXfbFoAsS0',
#   'i0gEmSZe9jc',
#   'i26oblZnXUU',
#   'i7bA1qFLC_E',
#   'iGv7gFmM3vk',
#   'iM7Fl2gpgPg',
#   'iMj5gB0XHRw',
#   'iSrsHDQASVs',
#   'iZr9uku31qI',
#   'iqex3hSn2RU',
#   'iu9NydPw9yI',
#   'j3dNiexsiRw',
#   'jNTZDRtKZqs',
#   'jRtlPAV5lSo',
#   'jWOoeD3haY8',
#   'jlBxbSxx5pQ',
#   'jluoByJbQgg',
#   'jzDmk010Ra0',
#   'k6DNsOhr6n0',
#   'kCf15d2KbBo',
#   'kKPqeq4IrB4',
#   'kKStk4V6HRU',
#   'kNp3Do6Ajuo',
#   'kulZ_sWzBR0',
#   'kzxUQG7yJTU',
#   'lHNtdUcq2_A',
#   'lNwXQrpMfhM',
#   'liPZA3Zdvig',
#   'll04J7XfVRQ',
#   'lsciLyjICMk',
#   'm3smE8dAzo4',
#   'mOHh9I1LdGA',
#   'mQUinrfsVkM',
#   'mcLH22Uot6o',
#   'mpg2dM5DrGg',
#   'mw0asrBhp0Y',
#   'my9iC2Nmix0',
#   'n3TXgjx0128',
#   'n4NhvxPxpuw',
#   'nG9EPbo9SNw',
#   'nyG7yKBfzjY',
#   'o1BNtH2rqY0',
#   'oD7GlhIvAlM',
#   'oTkv1jJ7fkQ',
#   'pB4QI5qwCN8',
#   'pLifvTWuvHg',
#   'pQOJvMR56fA',
#   'pcY_LT4GbbY',
#   'peM8h8O4QlY',
#   'pehY3S0mbRU',
#   'poaw32nV1_A',
#   'pvwgTTH4tKw',
#   'q0VcC5sIx8E',
#   'qD1tBFRTh3c',
#   'qKdeiL8Zrsg',
#   'qV3xntSmr1o',
#   'qWG21pLc2fw',
#   'qlD2vNmS5e4',
#   'qxbz9rvlyRE',
#   'r3cTVf3Ka60',
#   'rAaUWwcpQBw',
#   'rQhGmJxi_s4',
#   'rSuEJ7UHyLk',
#   'rU3lNhDPo2U',
#   'rWMw8x_6Exs',
#   'r_HaHYSEswE',
#   's6vN0Sl2F1c',
#   'sCASddsI__A',
#   'sDR1xwXjMuE',
#   'sZQ8tF5UHdU',
#   'saoItIJinso',
#   'sb_iG9dSVPg',
#   'seOwYSi59Pw',
#   'tCbQEuQKW3A',
#   'tP3ou_3RGVg',
#   'tUFQtSt7gNM',
#   'tYBwrXTUMDQ',
#   'tn5QG7h48xU',
#   'tsI6CFPkguQ',
#   'u2OguxxvCoY',
#   'uAUhYFwY2c4',
#   'uB0TeB35l94',
#   'uEH4jrxGgAk',
#   'uNAbrYTBS7A',
#   'uOuJijvQ0qA',
#   'uPS8SwnI1aY',
#   'uSXzoikCu_k',
#   'uUgYlA8Afko',
#   'udNdqhGlkSA',
#   'um1pjcGH6XU',
#   'usdTl9ddSIg',
#   'v80aiuXB0W4',
#   'vC8HCxU34jk',
#   'vWCPAbFQxzE',
#   'vY7Q1i03tlg',
#   'w9H42uo3WuU',
#   'wQgA2PCdg1U',
#   'wRgteEJift0',
#   'wXZVCz3WhLw',
#   'wa6FhuUXTRs',
#   'x6aEnqpTUBo',
#   'x8yoLCYSzVw',
#   'xD8uW0Hj6v0',
#   'xgbeqTCkO_o',
#   'xy9zcVGx1zA',
#   'y0KzJDKW0WM',
#   'yGMZGa090vU',
#   'yK7iNLl2Tqo',
#   'yMSzIQn7MR4',
#   'ySDBn7Cw8O8',
#   'ys_HDCt6xEY',
#   'ywf4HpQKuf0',
#   'yyYQfz7mViE',
#   'z0cVY9navGM',
#   'z2qWjf0A3UY',
#   'zSLNUwcbqqo',
#   'zV5ipnhf9xs',
#   'zoN3xOGVjbk'},
#  {'01qjQ_KPgpY',
#   '0EC2P7aCb6Y',
#   '0R2LivDo2wQ',
#   '0b86bWr6xjk',
#   '1Mufuvyj3wY',
#   '1OfndHcbYFo',
#   '1RGBtA_GhWI',
#   '1SdW2lh6Ukk',
#   '1g4suE6pDKo',
#   '1iByM08MvqU',
#   '1iMSdRfy0Nk',
#   '204vg0ZpzxU',
#   '22qdkFRqoFE',
#   '2HEJfb4zWic',
#   '2YqbKDoFyL4',
#   '2pV7DNjAHKY',
#   '2z9rtGpzPXU',
#   '3J2b9YYf_SY',
#   '3LDTgXzWKes',
#   '3LDpq53oV0o',
#   '3evkMmZdp9M',
#   '3rtbPiaDIDo',
#   '3sqBlmCqhpY',
#   '3xCLc2owEtI',
#   '4BBQyegIQWQ',
#   '4IN9QAb_l1M',
#   '4RMoZo69RE8',
#   '4S6_h9xAe6M',
#   '4ZzvROhMfjg',
#   '4nlVqcAmMco',
#   '4syqfwNfygw',
#   '4uAeQzEgTdU',
#   '5B0XYZjzivw',
#   '5T1gZdTgXPI',
#   '5WWjIgii2IU',
#   '5fqLddbpcEs',
#   '5nEJHu6DBMs',
#   '5o2rhvamLBM',
#   '64YqHeWhhsc',
#   '6GC8ekmdngk',
#   '6IICiCHsE00',
#   '6NFjjfvQ7ZQ',
#   '6TOnCfxXzyU',
#   '6WCjer_Fmsk',
#   '6aPHgbQh5MQ',
#   '6eBEz91Zwh8',
#   '6susHsajq_A',
#   '6vi6gKoS_6Y',
#   '71VzkALm1Oc',
#   '78ZiDsVOQyc',
#   '7TB5Wu3zj0w',
#   '7_PBqRebxME',
#   '7jx__UOAMuk',
#   '7lgBaKDtQqU',
#   '7oozYl45nzQ',
#   '7re2Hfhc3Ac',
#   '7yBRWI1W4jU',
#   '7zEYafr6M2c',
#   '89o7v_UmLXw',
#   '8DczVgr03BQ',
#   '8GCGRdwg80Y',
#   '8GZY83WyOf4',
#   '8cU1k2ylhF4',
#   '8hbHNROHIvA',
#   '8xaLfHCU2KM',
#   '95AhWPH552E',
#   '99Iaexxewq4',
#   '9BrGr9qsHts',
#   '9LQI4LueVMU',
#   '9Wh9FqL2Xk8',
#   '9h_0i3BhAoc',
#   '9j7bkqBSyFY',
#   '9k02Yj8lIKM',
#   '9xy9mqEUh64',
#   'AMdNsGoLM8w',
#   'Aa4WUgTzcGw',
#   'AaoZnt4E9EU',
#   'AgsOk1HIPag',
#   'AspCLE3dpdI',
#   'AxEi0Uy8gMQ',
#   'B0RA0F2h4Bg',
#   'B8Tal07cM8M',
#   'BWFN4M0mNuk',
#   'BXjgkS7gsn8',
#   'BaRN5FQboew',
#   'Ba_ffkYzPds',
#   'Bebws7jVXWE',
#   'BtFKV0ny6Lo',
#   'CF_o4ECRwiE',
#   'CGcUCL07vLo',
#   'CIEH_MRMMZg',
#   'CULrx3yerE8',
#   'CitI8UTxrQ4',
#   'DVLY3J4lgMg',
#   'D_yb9_19sEo',
#   'DbsR_Cccadg',
#   'DqjGcOKmYks',
#   'Dxh3VN6kePA',
#   'EhJQE9hzIVs',
#   'Eizcm0GYu_0',
#   'EvSVykyXNGE',
#   'EvVkTNm_BJY',
#   'ExiI4bcfcx8',
#   'EyXdQCbWujw',
#   'F1EQ6xghU9E',
#   'F7xhXPdQKxY',
#   'FHJviEdsYrk',
#   'FhMBZw8UL10',
#   'GCSbDDd7B1s',
#   'GKemEDW3fao',
#   'GQgS2ruEJAs',
#   'GWzi144zrEs',
#   'GYBLqxwKJzg',
#   'GlduEKCGLQg',
#   'H4DFz8qRaFk',
#   'HMWAITDhWjw',
#   'HNKY3MHRejY',
#   'HStCv8ixyWg',
#   'HSushtZe0A4',
#   'HTFTvfin5Es',
#   'Hf2BNlWDDRU',
#   'HhLIORa1NKg',
#   'HhrBZuxjFxM',
#   'HixnqAdS2YM',
#   'HlJjWjOzC6c',
#   'I7Q29rHYldg',
#   'IbNzJFmtkZ0',
#   'Ik61qAqcnXo',
#   'ImiL_z0UjZE',
#   'IqAwin7WV6E',
#   'Irxq4RiKY5I',
#   'Isab2NO9jlk',
#   'J0hq13epy2k',
#   'JY3uMezS7Y4',
#   'KHMNiXYbdaU',
#   'KN15Qezt3qQ',
#   'Khfp7Hhc5Vk',
#   'Kj4Sgx9HXb4',
#   'KrFEX9gLp7I',
#   'KrLItbrSnZs',
#   'L9bkiAADDIY',
#   'LC2QScFT5QI',
#   'Lll8fnbV4Ew',
#   'Ls7VLqIm3JY',
#   'LsnNflMxfWg',
#   'M4oQAlKOYLY',
#   'M8azLVqwJ24',
#   'MEW9uH5mfBQ',
#   'MKX0zLqY7YU',
#   'MSf0YD2Zwa4',
#   'MX2Tgv3o1kc',
#   'MXciFLdLVSY',
#   'MYuPdUkQUMI',
#   'MZktWieSNqI',
#   'Mh3bgDLKt2o',
#   'MhHCQ_cb3T8',
#   'MuqJeFdzXgE',
#   'MxXpMANYQn0',
#   'N5rqYAWRdu4',
#   'NBJpBvOxPYI',
#   'NS5wc3MAbWE',
#   'NTG7NZgQals',
#   'NVTSbRgtpbk',
#   'NoeaLFiCFkc',
#   'OCbeS5MVDXg',
#   'OE8ujtE5ybI',
#   'OKeOx2sOe54',
#   'ObOPCees7LI',
#   'OdgyYhCn0O0',
#   'OfK1BgCxRbE',
#   'OmT_BtZh8qU',
#   'OvLrKbkH19E',
#   'Oz9wJkWAEec',
#   'P0ARaT7Wpz0',
#   'P2zBgBTaARs',
#   'P5bYtFrqw68',
#   'P93YSUoCMd0',
#   'P9prvFtgyCQ',
#   'PeQifrSZmBo',
#   'Q2HeV1M20Vo',
#   'QGIm9CqOqMM',
#   'QIIzCgVdWSM',
#   'QXOP9pviJ58',
#   'QmUinhGphos',
#   'RortX6xPKsg',
#   'Rv9U3P69Yo8',
#   'SKs9CmsEhuw',
#   'SLgDQlAjv1s',
#   'SffHY1Snn1Q',
#   'SgYj1SsG1LQ',
#   'SnbDtuHGdqE',
#   'Su_bfE13oc8',
#   'T1FQjm8T4Hw',
#   'TIvZVY2CtsA',
#   'TMLCOvRyZE4',
#   'TNhoEE0Jgn4',
#   'TUC58iDoKN4',
#   'TW9Ij2Lr3U4',
#   'TXmIsqvT5pc',
#   'TfsCvh2fRco',
#   'TmcyXjIlSOg',
#   'TpyvA_f_Ejo',
#   'UDDfBEUGY60',
#   'UDlsIakb9Kg',
#   'UGo15RpXLRM',
#   'UKVile_HpwQ',
#   'UrEJ7oAhcX8',
#   'UtcBPDTBiko',
#   'UuqwgWoHR74',
#   'V01QdmJS_fI',
#   'V3_VN8NqFoA',
#   'VGBEhpJll7c',
#   'VWHKv7pkLiE',
#   'V_s4qiD2hAo',
#   'Ve7bkylp4Xk',
#   'VeWtn9aC7LM',
#   'VjS5hmgV4qI',
#   'VxK7lhI_2pc',
#   'VxWNvMpYujU',
#   'W39aHZ6Kago',
#   'WCaHjQI0SKc',
#   'WJOXr86lYTA',
#   'WL496X8YpS0',
#   'WORWZ342d2A',
#   'Wd69L0vmaOQ',
#   'WfXIH3HS5b4',
#   'WkFzVVx49Hw',
#   'Wz7Zct4QTgo',
#   'X3KPymO2H0k',
#   'X7kIvbEFLWE',
#   'XAsnzfjidng',
#   'XQvVq8tZ4Wc',
#   'XZXgTgxXjRE',
#   'Xl3b9kmdmoI',
#   'XlxCzSWU4t0',
#   'XswBqDSbWjI',
#   'YGTZFE7ziNc',
#   'YN6xuSz86PA',
#   'Yr9x9cNQZic',
#   'YunOhFZS4MQ',
#   'Z3Vbzpo2Bf8',
#   'ZkraCqiF2S8',
#   'Zu4kIDXVgPk',
#   '_2rlddA7wXg',
#   '_5o4ITc4MzI',
#   '_FsOnRDIJQQ',
#   '_LqGQPwtH4Q',
#   '_Rmtpkg0EvY',
#   '_dh6Yop63Qg',
#   '_ezYjZ5q1MQ',
#   '_pwjvqaqvEQ',
#   '_xV3Arrj5bo',
#   'a4KrJZa3tXw',
#   'algJRKesyLQ',
#   'b4wW_q5RKng',
#   'bNidTHjdTp4',
#   'bR8REmVupt0',
#   'batyghupR2Q',
#   'bkexA13CBPs',
#   'c90800j_ED4',
#   'cAwlRmHSdfk',
#   'cQbynkEPQqs',
#   'cUAQrHbbpZ8',
#   'cZX24tJ9OsQ',
#   'cbKv3plJQp0',
#   'crxe2d7kvvg',
#   'd4O2uEPSgjo',
#   'd7he2iI2oR0',
#   'dChbp9GjGyU',
#   'dD3A1IseY00',
#   'dNbOwo0XPwE',
#   'dhc3UMrUeWU',
#   'eFW35iYK4cw',
#   'eHtgG748qhI',
#   'eXu5nqFf_IU',
#   'eYZA9hehwR0',
#   'egPzPanHpXw',
#   'f1Y6w5LiVqU',
#   'f6kVa7kkQiI',
#   'fBy2KLLuNp4',
#   'fJEqh1YLGes',
#   'fKNtJfw1m9M',
#   'fcmIYoQtOmE',
#   'fgTr47WT4rI',
#   'frpPLNtClhE',
#   'fxDBy17BCqo',
#   'g5QNMMNsxmg',
#   'gCTKeaPFVuY',
#   'gDfzD0fJjwI',
#   'gIgjKheyn3o',
#   'gNQOnEh4JbE',
#   'gVOllvdKurs',
#   'gYoIugaLSJw',
#   'gZNcKSFTGKE',
#   'gl486Y5GB0w',
#   'gpdZhvCuMYs',
#   'gqYhnxGEPhg',
#   'guvvQcKfLvw',
#   'h7ybrIfVTRw',
#   'h93wXNLXmYU',
#   'hJJscBAgqAI',
#   'hLM07VHy0xI',
#   'hLOOwsxDBJo',
#   'hX8S64wZSDU',
#   'i26oblZnXUU',
#   'iCcHGzMFQYg',
#   'iMWJYbnaaA8',
#   'iOE1VwqgO2g',
#   'iPt9aaUUpQ4',
#   'i_fb_jHCUE8',
#   'i_g1f4QurKs',
#   'im2J3GRCnGk',
#   'io3ajc3ysBY',
#   'iqex3hSn2RU',
#   'iqo_4SwuZ4g',
#   'isXHFk5a63A',
#   'j5XOzTRnvjg',
#   'jIZvju0MUag',
#   'jzDmk010Ra0',
#   'k1oDrh3eSHQ',
#   'k7jaBgF3u7M',
#   'kC3wiRad5TE',
#   'kPb5UUmHnHs',
#   'kQ4Y6EPljPk',
#   'keZMGy3F_10',
#   'kj7bMkYgBeE',
#   'kosDbw1NUPM',
#   'kulZ_sWzBR0',
#   'kzxUQG7yJTU',
#   'l14bzgXkO08',
#   'lHNtdUcq2_A',
#   'lIrGCr2sciQ',
#   'lS43t9rPqmM',
#   'lZv1iIIOSEQ',
#   'lcAWcDLMPJc',
#   'lhms3u5T1m8',
#   'lsciLyjICMk',
#   'mMfE4oYhLzg',
#   'mcLH22Uot6o',
#   'mim72K0Q3io',
#   'mpg2dM5DrGg',
#   'my9iC2Nmix0',
#   'n3HmgraEOJA',
#   'n48GVQFJRUY',
#   'n49OnbNnFWk',
#   'nSRhszFec4Q',
#   'nU916ZJHIAI',
#   'ncy57YkTtdU',
#   'nyliOKM_9J4',
#   'o1BNtH2rqY0',
#   'o3oQATu9B9A',
#   'o5OoL2MUs3Q',
#   'oATun_RMfco',
#   'oD84wa2vojw',
#   'oKfaa43c0hA',
#   'oKzi2l3kk90',
#   'occzCWayOgo',
#   'p2NgeOyvtZs',
#   'p4afjwmtjJk',
#   'pWDdpYnobko',
#   'pY2JYeGELcc',
#   'pmOSTmw8dUc',
#   'ppBglbVONIs',
#   'pvcitd4fH2w',
#   'q4pJENhqSm8',
#   'q5O7mQ957TY',
#   'qKdeiL8Zrsg',
#   'qM0a2o6BpZM',
#   'qQUZ5d5mpWk',
#   'qaZnDHacYSk',
#   'qfa_DF23Es0',
#   'qiuh6emUCfA',
#   'qmMZmy8rfg0',
#   'r1eZ_SdK_24',
#   'r3cTVf3Ka60',
#   'r8ORBkJBD4k',
#   'r8cUlNZm2Pc',
#   'rAkxQk_SimU',
#   'rKTXenn5XDs',
#   's_PFLeOKK8U',
#   'seOwYSi59Pw',
#   'soJyv0EcQQo',
#   'tQRsEpIj5uo',
#   'tlPXUeUI4zc',
#   'tsI6CFPkguQ',
#   'twAaAXJHUcA',
#   'u2OguxxvCoY',
#   'u6s17QJeuXM',
#   'uCy3SFC9S3E',
#   'uHGFL5oUfgg',
#   'uKQAhEAIOt4',
#   'uLGuYZnrV5U',
#   'uNUrvGrdsQ8',
#   'uUVz_y8ZZ0Q',
#   'uXWqKxbROyY',
#   'uojBW7c53V4',
#   'usdTl9ddSIg',
#   'uwLBJyNHCzw',
#   'v0ts9dwzpLw',
#   'v80aiuXB0W4',
#   'vC8HCxU34jk',
#   'vKlNZYljG_8',
#   'vLe62fNrI7A',
#   'vPdqbHCijJk',
#   'vWCPAbFQxzE',
#   'vdrZQOKvsZM',
#   'viTrbKvW7bA',
#   'vl7mATkmpEo',
#   'vsDoBhQJ1hY',
#   'wKZjZ0c9k4Y',
#   'wKnBkKSY6zI',
#   'wVwP56u93jo',
#   'w_6WwWmaDsU',
#   'wlBotUlGyPg',
#   'wlVXqhcsWyA',
#   'wuF2ZxXGN8c',
#   'x4ioRas_9l8',
#   'x7uac1mes8c',
#   'xDdlyMEGh6M',
#   'xHuZdUGGQHg',
#   'xcQkHqSe6FY',
#   'xcitAtuxPCk',
#   'xpe3UXj0wCo',
#   'yNvfJlMv9Vg',
#   'yRw1Y4Rblkg',
#   'yXHOeK8xMYk',
#   'ykccgeWwdQ8',
#   'ylA9LrcU9vo',
#   'ywaY9qRQ4Ag',
#   'zLSi0My6vuQ',
#   'zaq5J5endq0',
#   'zgQbOmPp9pk',
#   'zidlx3JojIo',
#   'zjQc1oKufYg',
#   'zwJ0IGCZl_E'},
#  {'0JqaxCjCQKQ',
#   '15AOCtzI1cM',
#   '1OzBRPolzfU',
#   '1iByM08MvqU',
#   '2SgmBwBSt8M',
#   '480nF81vFI0',
#   '4lJ0vD6QO1o',
#   '5EsyiXMKOPs',
#   '5g7hQG2MQNw',
#   '6XgenY_eEro',
#   '6_o14WcPUC8',
#   '6eOnUHKbZ2g',
#   '7H4jvc3ERrc',
#   '7gw4cgfRxPM',
#   '8OjNg0Sspro',
#   '8dvpd87QV4s',
#   '94KUKlC1rlc',
#   '9GbYnL0tvcg',
#   '9JVCjzcvXco',
#   'ALQa8SjBujc',
#   'AvfpnsqaWw4',
#   'AxEi0Uy8gMQ',
#   'B8TM4eoaSk8',
#   'Bbaal2Neohk',
#   'DPMTVjWy1E4',
#   'F2iRjNS9KCk',
#   'Fc4drtbgDb0',
#   'G1WBHh_uWF4',
#   'GWsDgpOaPH8',
#   'HBxB7ytsEus',
#   'HN02LoRFSy8',
#   'HWxPjFUR2Qg',
#   'HXB7HUg7Mks',
#   'IF78KAsksbQ',
#   'J1sEju6i5iQ',
#   'JWrpgQhFgK8',
#   'JrcKPsflI5k',
#   'K0TANHoBncY',
#   'KVCZbb3svSc',
#   'Ks19MD2LRUw',
#   'Kx2GhRVfgyg',
#   'L9bkiAADDIY',
#   'LJiP_ouvA9k',
#   'LQ7ispbi_6U',
#   'M3ELr8oCr40',
#   'MWMmHcPKvfs',
#   'MgIFbO_BmaU',
#   'NbdXFQECU14',
#   'NeMTKw_SZRc',
#   'O3iT4_8jUVw',
#   'OALASDJOKb8',
#   'OPWhkKQLTmE',
#   'Oz9wJkWAEec',
#   'P_KbNZi5uUo',
#   'RUscR5_LL88',
#   'Ri8OHAHmTJw',
#   'Rm6zwwnAVeA',
#   'SA3R1HniCoM',
#   'Sscep6rpD_E',
#   'Sy0AFDqBvqw',
#   'TQhN5dJS35A',
#   'Tyx5100s0lY',
#   'UGyGF6BzXTM',
#   'ULIc9dn1TNU',
#   'UTcs6TECwV4',
#   'UtcBPDTBiko',
#   'V9SkCPhO9wk',
#   'VBdcD7hLGuo',
#   'VRPrnvtZjvg',
#   'VpSpwWMW5eA',
#   'VxK7lhI_2pc',
#   'WQ3Q58jakVQ',
#   'Wb9t801rKTg',
#   'WfXIH3HS5b4',
#   'X48jgyzoQdE',
#   'Y5kxIA77e1E',
#   'YUcrsJAR3Ck',
#   'Yuu5VhJBIUg',
#   'ZJCUwiWKfDI',
#   'Z_C_UCXorM4',
#   'aQtPOiovlzM',
#   'alV1Zu0vTM8',
#   'bRIjl3yF01U',
#   'bTDD2nj0BYM',
#   'bsQD5xMYc7o',
#   'bt7g4VoVBoE',
#   'dChbp9GjGyU',
#   'dJt7PtJobAw',
#   'e2ZLAOzUS24',
#   'e2qQY8H_2Pw',
#   'efIAxTOX9F0',
#   'eoZYflUA7sQ',
#   'fgTr47WT4rI',
#   'gOq59m1pUi4',
#   'gl486Y5GB0w',
#   'hFFskmCQkuM',
#   'hnTQ5V3N7zU',
#   'hwN1HfsFJlQ',
#   'i4JXGMaT5I4',
#   'iMj5gB0XHRw',
#   'iSrsHDQASVs',
#   'io3ajc3ysBY',
#   'jIVKspz9mf4',
#   'jgAT53lbnVI',
#   'jpW_MOekS4Q',
#   'kulZ_sWzBR0',
#   'lREyKzqpCjE',
#   'lhms3u5T1m8',
#   'nPVd4XaeM34',
#   'nzFUZlCtQVU',
#   'poaw32nV1_A',
#   'pvcitd4fH2w',
#   'pvsImT6E4yM',
#   'qqIZ9MLZk0Y',
#   'rMxxGQVkczU',
#   'rXq5yNXIAac',
#   's0pw3ELURlE',
#   'tbBnx8G1GSk',
#   'u49dzFO3Y8I',
#   'uLjYfhSIaVw',
#   'uXALR822noE',
#   'vS9Ioi6uK30',
#   'vleTt0rWGw4',
#   'wH4L9NiHHIE',
#   'wdUr23pwKzk',
#   'wq5MQd1Lv0c',
#   'wyEjwiBux8w',
#   'yrI420Xkkpc'},
#  {'23s335_laNA',
#   '4nlVqcAmMco',
#   '5fqLddbpcEs',
#   '9JqwCHP7POA',
#   'ANd2wYIi8oU',
#   'By626Hmvvt0',
#   'GdJVLA16hUc',
#   'HhrBZuxjFxM',
#   'Qb80uEMXEmE',
#   'Wp7JJK2jToU',
#   'd9tZZGbLQMU',
#   'hLOOwsxDBJo',
#   'qmMZmy8rfg0',
#   'xcitAtuxPCk'}]

# %%
set_list = []
for i in range(len(df_not_in_sent_selected_videoid_list)-2):
    var_1 = videoid_list_group_list[i]
    set_list.append(var_1)
set_intersect = set.intersection(*set_list)
list_intersect = list(set_intersect) 
list_intersect
# Out:
# ['kzxUQG7yJTU',
#  '6NFjjfvQ7ZQ',
#  '3LDpq53oV0o',
#  'kulZ_sWzBR0',
#  'MhHCQ_cb3T8',
#  'o1BNtH2rqY0',
#  '8GCGRdwg80Y']

# %%
df_intersect_result = df_not_in_sent_selected_word_list_result[df_not_in_sent_selected_word_list_result["video_id"].isin(list_intersect)]
df_intersect_result
# Out:
#         word                  search_string  start_time  end_time  \
# 71     devam  tamam tamam devam et devam et        2786      2788
# 193    devam        böyle devam et tamam mı        3273      3275
# 243    devam         biraz daha böyle devam        4397      4399
# 387    devam           öyle de devam ederim        6106      6108
# 451    devam            sen şimdi ona devam        1118      1119
# ...      ...                            ...         ...       ...
# 6620  gerçek            gerçek benim sen ve        6792      6794
# 6640  gerçek             biz gerçek bir şey        3877      3879
# 6674  gerçek             bu ne gerçek mi bu        4913      4916
# 6728  gerçek                bu gerçek mi ya        5339      5341
# 6735  gerçek                gerçek mi ya ne        1471      1473
#
#                                                sentence     video_id  \
# 71                        tamam tamam devam et devam et  kulZ_sWzBR0
# 193                             böyle devam et tamam mı  8GCGRdwg80Y
# 243   biraz daha böyle devam edersen bir şeyin var s...  3LDpq53oV0o
# 387   ben bu yaşıma kadar tek başıma geldim öyle de ...  6NFjjfvQ7ZQ
# 451   senin uzmanlık alanın tembellik sen şimdi ona ...  MhHCQ_cb3T8
# ...                                                 ...          ...
# 6620  gerçek benim sen ve yalanların bir çöpsünüz ba...  6NFjjfvQ7ZQ
# 6640                      biz gerçek bir şey yapmıyoruz  o1BNtH2rqY0
# 6674        bu ne gerçek mi bu pahalı bir şeye benziyor  3LDpq53oV0o
# 6728                               emir bu gerçek mi ya  kzxUQG7yJTU
# 6735                                    gerçek mi ya ne  kulZ_sWzBR0
#
#                                               video_url
# 71    https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...
# 193   https://www.youtube.com/watch?v=8GCGRdwg80Y&t=...
# 243   https://www.youtube.com/watch?v=3LDpq53oV0o&t=...
# 387                                                 NaN
# 451                                                 NaN
# ...                                                 ...
# 6620                                                NaN
# 6640                                                NaN
# 6674                                                NaN
# 6728                                                NaN
# 6735                                                NaN
#
# [70 rows x 7 columns]

# %%
df_intersect_result["video_url"] = "https://www.youtube.com/watch?v="+df_intersect_result['video_id'].map(str)+"&t="+df_intersect_result['start_time'].map(str)+"s"
df_intersect_result
# Out:
# <ipython-input-27-23f5f6eb5eaf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_intersect_result["video_url"] = "https://www.youtube.com/watch?v="+df_intersect_result['video_id'].map(str)+"&t="+df_intersect_result['start_time'].map(str)+"s"
#         word                  search_string  start_time  end_time  \
# 71     devam  tamam tamam devam et devam et        2786      2788
# 193    devam        böyle devam et tamam mı        3273      3275
# 243    devam         biraz daha böyle devam        4397      4399
# 387    devam           öyle de devam ederim        6106      6108
# 451    devam            sen şimdi ona devam        1118      1119
# ...      ...                            ...         ...       ...
# 6620  gerçek            gerçek benim sen ve        6792      6794
# 6640  gerçek             biz gerçek bir şey        3877      3879
# 6674  gerçek             bu ne gerçek mi bu        4913      4916
# 6728  gerçek                bu gerçek mi ya        5339      5341
# 6735  gerçek                gerçek mi ya ne        1471      1473
#
#                                                sentence     video_id  \
# 71                        tamam tamam devam et devam et  kulZ_sWzBR0
# 193                             böyle devam et tamam mı  8GCGRdwg80Y
# 243   biraz daha böyle devam edersen bir şeyin var s...  3LDpq53oV0o
# 387   ben bu yaşıma kadar tek başıma geldim öyle de ...  6NFjjfvQ7ZQ
# 451   senin uzmanlık alanın tembellik sen şimdi ona ...  MhHCQ_cb3T8
# ...                                                 ...          ...
# 6620  gerçek benim sen ve yalanların bir çöpsünüz ba...  6NFjjfvQ7ZQ
# 6640                      biz gerçek bir şey yapmıyoruz  o1BNtH2rqY0
# 6674        bu ne gerçek mi bu pahalı bir şeye benziyor  3LDpq53oV0o
# 6728                               emir bu gerçek mi ya  kzxUQG7yJTU
# 6735                                    gerçek mi ya ne  kulZ_sWzBR0
#
#                                               video_url
# 71    https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...
# 193   https://www.youtube.com/watch?v=8GCGRdwg80Y&t=...
# 243   https://www.youtube.com/watch?v=3LDpq53oV0o&t=...
# 387   https://www.youtube.com/watch?v=6NFjjfvQ7ZQ&t=...
# 451   https://www.youtube.com/watch?v=MhHCQ_cb3T8&t=...
# ...                                                 ...
# 6620  https://www.youtube.com/watch?v=6NFjjfvQ7ZQ&t=...
# 6640  https://www.youtube.com/watch?v=o1BNtH2rqY0&t=...
# 6674  https://www.youtube.com/watch?v=3LDpq53oV0o&t=...
# 6728  https://www.youtube.com/watch?v=kzxUQG7yJTU&t=...
# 6735  https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...
#
# [70 rows x 7 columns]

# %%
# Option
#df_intersect_sent_count = df_intersect_result.groupby("search_string")[["search_string"]].count()
df_intersect_sent_count = df_intersect_result.groupby(["search_string","start_time","end_time","sentence","video_id","video_url"])[["search_string"]].count()
df_intersect_sent_count.rename(columns={"search_string":"count"}, inplace=True)
df_intersect_sent_count.reset_index(inplace=True)
df_intersect_sent_count.sort_values(by="count", ascending=False, inplace=True)
df_intersect_sent_count
# Out:
#                            search_string  start_time  end_time  \
# 47                    sen böyle devam et        4747      4749
# 29                     değil mi devam et        3612      3613
# 51         tamam tamam devam et devam et        2786      2788
# 24               böyle devam et tamam mı        3273      3275
# 28                     devam et tamam mı        2334      2336
# ..                                   ...         ...       ...
# 26                   daha ne kadar devam         822       824
# 27                   daha ne kadar devam        1862      1863
# 30  değilim sana hiç değilim zaten bence        9756      9759
# 31           evet efendim tekrar merhaba        8132      8134
# 63                 şimdi bize bir şey et        4930      4931
#
#                                              sentence     video_id  \
# 47                                 sen böyle devam et  3LDpq53oV0o
# 29                                  değil mi devam et  8GCGRdwg80Y
# 51                      tamam tamam devam et devam et  kulZ_sWzBR0
# 24                            böyle devam et tamam mı  8GCGRdwg80Y
# 28        eğer sana iyi gelen buysa devam et tamam mı  kzxUQG7yJTU
# ..                                                ...          ...
# 26            daha ne kadar devam edecektin bu yalana  o1BNtH2rqY0
# 27  bakalım yalan söylemeye daha ne kadar devam ed...  o1BNtH2rqY0
# 30        şakacı değilim sana hiç değilim zaten bence  kulZ_sWzBR0
# 31                        evet efendim tekrar merhaba  kulZ_sWzBR0
# 63                         hele şimdi bize bir şey et  kulZ_sWzBR0
#
#                                             video_url  count
# 47  https://www.youtube.com/watch?v=3LDpq53oV0o&t=...      2
# 29  https://www.youtube.com/watch?v=8GCGRdwg80Y&t=...      2
# 51  https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...      2
# 24  https://www.youtube.com/watch?v=8GCGRdwg80Y&t=...      2
# 28  https://www.youtube.com/watch?v=kzxUQG7yJTU&t=...      2
# ..                                                ...    ...
# 26  https://www.youtube.com/watch?v=o1BNtH2rqY0&t=...      1
# 27  https://www.youtube.com/watch?v=o1BNtH2rqY0&t=...      1
# 30  https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...      1
# 31  https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...      1
# 63  https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...      1
#
# [64 rows x 7 columns]

# %%
df_intersect_sent_word_join = df_intersect_result.groupby(["search_string","start_time","end_time","sentence","video_id","video_url"])["word"].apply(lambda x: ','.join(x)).reset_index()
df_intersect_sent_word_join.drop_duplicates(inplace=True)
df_intersect_sent_word_join.sort_values(by="word", ascending=False, inplace=True, key=lambda x:x.str.len())
df_intersect_sent_word_join
# Out:
#                     search_string  start_time  end_time  \
# 19         bu adam asla böyle bir        3604      3606
# 47             sen böyle devam et        4747      4749
# 24        böyle devam et tamam mı        3273      3275
# 51  tamam tamam devam et devam et        2786      2788
# 29              değil mi devam et        3612      3613
# ..                            ...         ...       ...
# 58          yardım et sen de bize        7710      7712
# 12        benim et o zaman ben de        5177      5179
# 48         sen yardım et şu bizim         434       436
# 46             sen bana yardım et        4382      4384
# 63          şimdi bize bir şey et        4930      4931
#
#                                              sentence     video_id  \
# 19                bu adam asla böyle bir ifade vermez  o1BNtH2rqY0
# 47                                 sen böyle devam et  3LDpq53oV0o
# 24                            böyle devam et tamam mı  8GCGRdwg80Y
# 51                      tamam tamam devam et devam et  kulZ_sWzBR0
# 29                                  değil mi devam et  8GCGRdwg80Y
# ..                                                ...          ...
# 58                bırak çantanı yardım et sen de bize  o1BNtH2rqY0
# 12  ah canım benim et o zaman ben de salatayı hazı...  MhHCQ_cb3T8
# 48                      sen yardım et şu bizim oğlana  kulZ_sWzBR0
# 46  sanki hiç geçmeyecekmiş gibi allahım sen bana ...  6NFjjfvQ7ZQ
# 63                         hele şimdi bize bir şey et  kulZ_sWzBR0
#
#                                             video_url       word
# 19  https://www.youtube.com/watch?v=o1BNtH2rqY0&t=...  adam,asla
# 47  https://www.youtube.com/watch?v=3LDpq53oV0o&t=...   devam,et
# 24  https://www.youtube.com/watch?v=8GCGRdwg80Y&t=...   devam,et
# 51  https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...   devam,et
# 29  https://www.youtube.com/watch?v=8GCGRdwg80Y&t=...   devam,et
# ..                                                ...        ...
# 58  https://www.youtube.com/watch?v=o1BNtH2rqY0&t=...         et
# 12  https://www.youtube.com/watch?v=MhHCQ_cb3T8&t=...         et
# 48  https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...         et
# 46  https://www.youtube.com/watch?v=6NFjjfvQ7ZQ&t=...         et
# 63  https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...         et
#
# [64 rows x 7 columns]

# %%
df_intersect_sent_word_join.to_excel(f"{lang_folder.capitalize()}_{word_end}_Word_Group_In_Youtube_Sentence_Word_Index_List_Sample4.xlsx", index=False)

# %% [markdown]
# #### Remain Words

# %%
remain_word_list = ["merhaba","pekala"]

# %%
df_not_in_sent_selected_videoid_list_remain = df_not_in_sent_selected_videoid_list[df_not_in_sent_selected_videoid_list["word"].isin(remain_word_list)]
df_not_in_sent_selected_videoid_list_remain
# Out:
#       word                                           video_id
# 6  merhaba  {bTDD2nj0BYM, LQ7ispbi_6U, 9GbYnL0tvcg, 15AOCt...
# 7   pekala  {xcitAtuxPCk, d9tZZGbLQMU, hLOOwsxDBJo, qmMZmy...

# %%
videoid_list_group_list_remain = df_not_in_sent_selected_videoid_list_remain["video_id"].to_list()
videoid_list_group_list_remain
# Out:
# [{'0JqaxCjCQKQ',
#   '15AOCtzI1cM',
#   '1OzBRPolzfU',
#   '1iByM08MvqU',
#   '2SgmBwBSt8M',
#   '480nF81vFI0',
#   '4lJ0vD6QO1o',
#   '5EsyiXMKOPs',
#   '5g7hQG2MQNw',
#   '6XgenY_eEro',
#   '6_o14WcPUC8',
#   '6eOnUHKbZ2g',
#   '7H4jvc3ERrc',
#   '7gw4cgfRxPM',
#   '8OjNg0Sspro',
#   '8dvpd87QV4s',
#   '94KUKlC1rlc',
#   '9GbYnL0tvcg',
#   '9JVCjzcvXco',
#   'ALQa8SjBujc',
#   'AvfpnsqaWw4',
#   'AxEi0Uy8gMQ',
#   'B8TM4eoaSk8',
#   'Bbaal2Neohk',
#   'DPMTVjWy1E4',
#   'F2iRjNS9KCk',
#   'Fc4drtbgDb0',
#   'G1WBHh_uWF4',
#   'GWsDgpOaPH8',
#   'HBxB7ytsEus',
#   'HN02LoRFSy8',
#   'HWxPjFUR2Qg',
#   'HXB7HUg7Mks',
#   'IF78KAsksbQ',
#   'J1sEju6i5iQ',
#   'JWrpgQhFgK8',
#   'JrcKPsflI5k',
#   'K0TANHoBncY',
#   'KVCZbb3svSc',
#   'Ks19MD2LRUw',
#   'Kx2GhRVfgyg',
#   'L9bkiAADDIY',
#   'LJiP_ouvA9k',
#   'LQ7ispbi_6U',
#   'M3ELr8oCr40',
#   'MWMmHcPKvfs',
#   'MgIFbO_BmaU',
#   'NbdXFQECU14',
#   'NeMTKw_SZRc',
#   'O3iT4_8jUVw',
#   'OALASDJOKb8',
#   'OPWhkKQLTmE',
#   'Oz9wJkWAEec',
#   'P_KbNZi5uUo',
#   'RUscR5_LL88',
#   'Ri8OHAHmTJw',
#   'Rm6zwwnAVeA',
#   'SA3R1HniCoM',
#   'Sscep6rpD_E',
#   'Sy0AFDqBvqw',
#   'TQhN5dJS35A',
#   'Tyx5100s0lY',
#   'UGyGF6BzXTM',
#   'ULIc9dn1TNU',
#   'UTcs6TECwV4',
#   'UtcBPDTBiko',
#   'V9SkCPhO9wk',
#   'VBdcD7hLGuo',
#   'VRPrnvtZjvg',
#   'VpSpwWMW5eA',
#   'VxK7lhI_2pc',
#   'WQ3Q58jakVQ',
#   'Wb9t801rKTg',
#   'WfXIH3HS5b4',
#   'X48jgyzoQdE',
#   'Y5kxIA77e1E',
#   'YUcrsJAR3Ck',
#   'Yuu5VhJBIUg',
#   'ZJCUwiWKfDI',
#   'Z_C_UCXorM4',
#   'aQtPOiovlzM',
#   'alV1Zu0vTM8',
#   'bRIjl3yF01U',
#   'bTDD2nj0BYM',
#   'bsQD5xMYc7o',
#   'bt7g4VoVBoE',
#   'dChbp9GjGyU',
#   'dJt7PtJobAw',
#   'e2ZLAOzUS24',
#   'e2qQY8H_2Pw',
#   'efIAxTOX9F0',
#   'eoZYflUA7sQ',
#   'fgTr47WT4rI',
#   'gOq59m1pUi4',
#   'gl486Y5GB0w',
#   'hFFskmCQkuM',
#   'hnTQ5V3N7zU',
#   'hwN1HfsFJlQ',
#   'i4JXGMaT5I4',
#   'iMj5gB0XHRw',
#   'iSrsHDQASVs',
#   'io3ajc3ysBY',
#   'jIVKspz9mf4',
#   'jgAT53lbnVI',
#   'jpW_MOekS4Q',
#   'kulZ_sWzBR0',
#   'lREyKzqpCjE',
#   'lhms3u5T1m8',
#   'nPVd4XaeM34',
#   'nzFUZlCtQVU',
#   'poaw32nV1_A',
#   'pvcitd4fH2w',
#   'pvsImT6E4yM',
#   'qqIZ9MLZk0Y',
#   'rMxxGQVkczU',
#   'rXq5yNXIAac',
#   's0pw3ELURlE',
#   'tbBnx8G1GSk',
#   'u49dzFO3Y8I',
#   'uLjYfhSIaVw',
#   'uXALR822noE',
#   'vS9Ioi6uK30',
#   'vleTt0rWGw4',
#   'wH4L9NiHHIE',
#   'wdUr23pwKzk',
#   'wq5MQd1Lv0c',
#   'wyEjwiBux8w',
#   'yrI420Xkkpc'},
#  {'23s335_laNA',
#   '4nlVqcAmMco',
#   '5fqLddbpcEs',
#   '9JqwCHP7POA',
#   'ANd2wYIi8oU',
#   'By626Hmvvt0',
#   'GdJVLA16hUc',
#   'HhrBZuxjFxM',
#   'Qb80uEMXEmE',
#   'Wp7JJK2jToU',
#   'd9tZZGbLQMU',
#   'hLOOwsxDBJo',
#   'qmMZmy8rfg0',
#   'xcitAtuxPCk'}]

# %%
set_intersect2 = set.intersection(*videoid_list_group_list_remain)
set_intersect2
# Out:
# set()

# %%
df_not_in_sent_selected_word_remain_result = word_in_wordgroup(["merhaba","pekala"], df_youtube_sent_result, "search_string", 10, simple=False)
#df_not_in_sent_selected_word_remain_result = not_in_sent_selected_word_list_result.drop(["word"], axis=1)
df_not_in_sent_selected_word_remain_result
# Out:
#        word                                    search_string  start_time  \
# 0   merhaba  merhaba merhaba merhaba merhaba merhaba uzun ve         517
# 1   merhaba    çok güzel burada sen burada merhaba sen bizim        1887
# 2   merhaba        gel gel hadi gel hadi teşekkürler merhaba        6758
# 3   merhaba        değilim bu peki onları burada merhaba onu        2151
# 4   merhaba          var burada burada göre olabilir merhaba          99
# 5   merhaba          efendim ben de merhaba tabii ki efendim        4230
# 6   merhaba             merhaba çok teşekkür ederim bu benim        2249
# 7   merhaba               merhaba çok teşekkür ederim buraya        3275
# 8   merhaba               sadece merhaba merhaba o kadar ama        5574
# 9   merhaba                biz sadece bir merhaba demek için        5612
# 10   pekala            pekala pekala tamam tamam haydi kendi        2303
# 11   pekala               pekala o zaman ben sizi daha fazla        4442
# 12   pekala                   tamam peki pekala pekala tamam        1408
# 13   pekala                   pekala teşekkür ederim o zaman          36
# 14   pekala                   tamam peki pekala pekala tamam        1408
# 15   pekala                          pekala size o zaman bir        2003
# 16   pekala                          ki pekala pekala ama bu         414
# 17   pekala                           pekala o zaman ilk ilk        1282
# 18   pekala                           pekala ona bunu ben de        2291
# 19   pekala                            pekala ama ben onları        2336
#
#     end_time                                           sentence     video_id  \
# 0        522  dostlar merhaba merhaba merhaba merhaba merhab...  VRPrnvtZjvg
# 1       1891  uğraşıyor survivorda merhaba serman seni görme...  9GbYnL0tvcg
# 2       6760     gel gel hadi gel hadi teşekkürler merhaba jale  bt7g4VoVBoE
# 3       2155  gidişat hakkında şu an emin değilim bu peki on...  1iByM08MvqU
# 4        102  hoparlörleri deyince sınıfından kaan var burad...  JrcKPsflI5k
# 5       4233  bakabilir miyim efendim ben de merhaba tabii k...  8OjNg0Sspro
# 6       2253  hepsini değiştirir sen yemezsin ali merhaba ço...  nPVd4XaeM34
# 7       3278  merhaba tolga merhaba çok teşekkür ederim bura...  AvfpnsqaWw4
# 8       5577  arkadaşım değil büyük hanım aynı bölükteydik s...  VBdcD7hLGuo
# 9       5614           biz sadece bir merhaba demek için geldik  MWMmHcPKvfs
# 10      2306  pekala pekala tamam tamam haydi kendi işlerim var  Wp7JJK2jToU
# 11      4445      pekala o zaman ben sizi daha fazla tutmayayım  Qb80uEMXEmE
# 12      1411                     tamam peki pekala pekala tamam  d9tZZGbLQMU
# 13        39  pekala teşekkür ederim o zaman youtubenin bu v...  By626Hmvvt0
# 14      1411                     tamam peki pekala pekala tamam  GdJVLA16hUc
# 15      2005  pekala size o zaman bir kaç tane daire göstereyim  xcitAtuxPCk
# 16       417  onu önce tanımaz gibi görmüş ama süleyman ısra...  9JqwCHP7POA
# 17      1284    pekala o zaman ilk ilk soruyla hemen başlayalım  HhrBZuxjFxM
# 18      2293     pekala ona bunu ben de gösterebilirim değil mi  5fqLddbpcEs
# 19      2338             pekala ama ben onları bekleyemeyeceğim  23s335_laNA
#
#                                             video_url
# 0   https://www.youtube.com/watch?v=VRPrnvtZjvg&t=...
# 1   https://www.youtube.com/watch?v=9GbYnL0tvcg&t=...
# 2   https://www.youtube.com/watch?v=bt7g4VoVBoE&t=...
# 3   https://www.youtube.com/watch?v=1iByM08MvqU&t=...
# 4   https://www.youtube.com/watch?v=JrcKPsflI5k&t=99s
# 5   https://www.youtube.com/watch?v=8OjNg0Sspro&t=...
# 6   https://www.youtube.com/watch?v=nPVd4XaeM34&t=...
# 7   https://www.youtube.com/watch?v=AvfpnsqaWw4&t=...
# 8   https://www.youtube.com/watch?v=VBdcD7hLGuo&t=...
# 9   https://www.youtube.com/watch?v=MWMmHcPKvfs&t=...
# 10  https://www.youtube.com/watch?v=Wp7JJK2jToU&t=...
# 11  https://www.youtube.com/watch?v=Qb80uEMXEmE&t=...
# 12  https://www.youtube.com/watch?v=d9tZZGbLQMU&t=...
# 13  https://www.youtube.com/watch?v=By626Hmvvt0&t=36s
# 14  https://www.youtube.com/watch?v=GdJVLA16hUc&t=...
# 15  https://www.youtube.com/watch?v=xcitAtuxPCk&t=...
# 16  https://www.youtube.com/watch?v=9JqwCHP7POA&t=...
# 17  https://www.youtube.com/watch?v=HhrBZuxjFxM&t=...
# 18  https://www.youtube.com/watch?v=5fqLddbpcEs&t=...
# 19  https://www.youtube.com/watch?v=23s335_laNA&t=...

# %%
df_not_in_sent_selected_word_remain_result.to_excel(f"{lang_folder.capitalize()}_{word_end}_Word_Group_In_Youtube_Sentence_Word_Index_List_Sample5.xlsx", index=False)

# %% [markdown]
# #### Copy Move And Delete

# %%
output_file = glob.glob(f"{lang_folder.capitalize()}_{word_end}_Word_Group_In_Youtube_Sentence_*_Sample*.xlsx")
output_file
# Out:
# ['Turkish_200_Word_Group_In_Youtube_Sentence_Word_Index_List_Sample4.xlsx',
#  'Turkish_200_Word_Group_In_Youtube_Sentence_Word_Index_List_Sample5.xlsx',
#  'Turkish_200_Word_Group_In_Youtube_Sentence_Word_Index_List_Sample_Selected.xlsx']

# %%
for k in output_file:
    source = k # source directory
    destination = path
    shutil.copy2(source, destination)

# %%
for i in output_file:
    try:
        os.remove(i)
    except:
        pass

# %% [markdown]
# #### Deploy File Word Count

# %%
df_deploy_file = pd.read_excel(f"{source_path}/Turkish_200_Word_Group_In_69_Youtube_Sentence_Deploy.xlsx")
df_deploy_file
# Out:
#                                         search_string  start_time  end_time  \
# 0   kendi şimdi sen mi ne oluyor biliyor musun bu ...         446       451
# 1   gerçekten uzun ve bu da benim için çok önemli ...         623       627
# 2   her zaman öyle değil herkes için de her zaman ...         559       562
# 3   bile yok bu da benim için aslında önemli bir ş...         131       134
# 4   için artık değil misin gerek yok bunun için si...          65        70
# ..                                                ...         ...       ...
# 64                                    gerçek mi ya ne        1471      1473
# 65                             bence olur bence olmaz        3893      3895
# 66                              ben asla öyle bir şey        4768      4769
# 67                             bir şey yok ki ya adam        2554      2556
# 68              pekala pekala tamam tamam haydi kendi        2303      2306
#
#                                              sentence     video_id  \
# 0   artık hamill olması lazım altı kendi şimdi sen...  Yuu5VhJBIUg
# 1   bu tabletin şarj ömrü batarya ömrü gerçekten u...  r_9ngjGh2Ks
# 2   her zaman öyle değil herkes için de her zaman ...  cPoQ27hCNOU
# 3   bulabilirsiniz şu an görünce bile yok bu da be...  aqQ7IUho9pA
# 4   göndermek için artık değil misin gerek yok bun...  gX77n13Qj0o
# ..                                                ...          ...
# 64                                    gerçek mi ya ne  kulZ_sWzBR0
# 65                             bence olur bence olmaz  MhHCQ_cb3T8
# 66                     ben asla öyle bir şey yapmadım  kulZ_sWzBR0
# 67    bir şey yok ki ya adam hırsızın teki çıktı işte  MhHCQ_cb3T8
# 68  pekala pekala tamam tamam haydi kendi işlerim var  Wp7JJK2jToU
#
#                                             video_url  \
# 0   https://www.youtube.com/watch?v=Yuu5VhJBIUg&t=...
# 1   https://www.youtube.com/watch?v=r_9ngjGh2Ks&t=...
# 2   https://www.youtube.com/watch?v=cPoQ27hCNOU&t=...
# 3   https://www.youtube.com/watch?v=aqQ7IUho9pA&t=...
# 4   https://www.youtube.com/watch?v=gX77n13Qj0o&t=65s
# ..                                                ...
# 64  https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...
# 65  https://www.youtube.com/watch?v=MhHCQ_cb3T8&t=...
# 66  https://www.youtube.com/watch?v=kulZ_sWzBR0&t=...
# 67  https://www.youtube.com/watch?v=MhHCQ_cb3T8&t=...
# 68  https://www.youtube.com/watch?v=Wp7JJK2jToU&t=...
#
#                                       word_index_list
# 0   [133, 43, 19, 5, 2, 139, 109, 53, 1, 43, 168, ...
# 1          [70, 172, 3, 1, 15, 31, 4, 9, 156, 68, 67]
# 2         [30, 35, 46, 14, 173, 4, 8, 30, 35, 46, 14]
# 3         [59, 22, 1, 15, 31, 4, 174, 156, 0, 16, 68]
# 4             [4, 61, 14, 49, 117, 22, 97, 4, 121, 0]
# ..                                                ...
# 64                                             gerçek
# 65                                              bence
# 66                                               asla
# 67                                               adam
# 68                                             pekala
#
# [69 rows x 7 columns]

# %%
df_deploy_file_count = word_count_result(df_deploy_file, df_deploy_file.columns[0:1])
df_deploy_file_count.sort_values(by="word_count", ascending=False, inplace=True)
df_deploy_file_count
# Out:
#       word  word_count
# 0      bir          15
# 1      çok          11
# 2    tamam           8
# 3    değil           7
# 4      şey           7
# ..     ...         ...
# 130   sizi           1
# 129   seni           1
# 128   yeni           1
# 127  selam           1
# 199   şunu           1
#
# [200 rows x 2 columns]

# %%
df_file_count = word_count_result(df_file, df_file.columns[0:1])
df_file_count.sort_values(by="word_count", ascending=False)
df_file_count

# %%
df_check = df_file_count[df_file_count["word_count"] > 2]
df_check

# %%
check_list = df_check["word"].to_list()
check_list

# %%
len(check_list)

# %%
df_file_count = word_count_result(df_file, df_file.columns[0:1])  # "search_string" column
df_check = df_file_count[df_file_count["word_count"] > 2]
check_list = df_check["word"].to_list()
remove_list = []
for var_sent in df_file["search_string"]:
    result_list = []
    words = re.findall(r"\w+",var_sent, re.UNICODE)
    for word in words:
        if word in check_list:
            result_list.append(True)
        else:
            result_list.append(False)
    if all(result_list):
        df_file = df_file[df_file["search_string"] != f"{var_sent}"]
        df_file_count = word_count_result(df_file, df_file.columns[0:1])
        df_check = df_file_count[df_file_count["word_count"] > 2]
        check_list = df_check["word"].to_list()
        remove_list.append(var_sent)
    else:
        df_file = df_file

# %%
df_file

# %%
remove_list

# %%
word_count_result(df_file, df_file.columns[0:1])

# %%
test = ["aet","önce"]

# %%
test in check_list

# %%
df_file_count = word_count_result(df_file, df_file.columns[0:1])  # "search_string" column
df_check = df_file_count[df_file_count["word_count"] > 2]
check_list = df_check["word"].to_list()
i = 0
while i < len(df_file):
    var_sent in df_file.loc[i,"search_string"]
    result_list = []
    words = re.findall(r"\w+",var_sent, re.UNICODE)
    for word in words:
        if word in check_list:
            result_list.append(True)
        else:
            result_list.append(False)
    if all(result_list):
        df_file = df_file[df_file["search_string"] != f"{var_sent}"]
        df_file_count = word_count_result(df_file, df_file.columns[0:1])
        df_check = df_file_count[df_file_count["word_count"] > 1]
        check_list = df_check["word"].to_list()
    else:
        df_file = df_file
    i += 1

# %%
df_file

# %%
check_list

# %%
len(check_list)

# %%
while var_sent in df_file["search_string"]:
    print(var_sent)

# %%
all_list = []
for var_sent in df_file["search_string"]:
    result_list = []
    words = re.findall(r"\w+",var_sent, re.UNICODE)
    for word in words:
        if word in check_list:
            result_list.append(True)
        else:
            result_list.append(False)
    all_list.append(result_list)

# %%
all_list

# %%
test_list = []
for j in all_list:
    if all(j):
        test_list.append(j)
    else:
        pass

# %%
test_list

# %%
result_list

# %%
all(result_list)

# %%
a = []

# %%
a.append(True)

# %%
a.append(False)

# %%
a
