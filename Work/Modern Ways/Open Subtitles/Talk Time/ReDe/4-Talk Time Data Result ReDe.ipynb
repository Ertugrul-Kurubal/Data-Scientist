# %% [markdown]
# ### Talk Time

# %%
import os
import multiprocessing
#import multiprocessing as mp
from multiprocessing import Process, Manager, Pool, Queue
from itertools import islice
from collections import Counter
import re
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize
from nltk import ngrams
from functools import reduce
from pathlib import Path
import shutil

# %%
nprocs = multiprocessing.cpu_count()
print(f"Number of CPU cores: {nprocs}")
# Out:
# Number of CPU cores: 16

# %%
# language pair
lang_folder = "Dutch"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> target language for learner
#lang_pair = "Intersect"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> native language

# adding native word to shared word
word_start = 0  # 0 native word start index
word_end = 200  # 28 native word end index

# youtube read data
sample_num = 1  # 6
time_shift = 0.6

# %%
def word_in_wordgroup_simple(source_word_list, df_target, target_column, word_sample_num, simple=False):

    '''word_in_wordgroup(not_in_sent_word_list, df_youtube_sent_select, "search_string", 5, simple=False)\n
       source_word_list is searching word list\n
       df_target is dataframe, target_column are dataframe column string name\n
       word_sample_num is searching sample number.
       simple use for all column row result or only target column result 
    '''
    if simple:
        df_select = df_target[[f"{target_column}"]].dropna()
    else:
        df_select = df_target
        
    df_result = pd.DataFrame()
    for i in source_word_list:
        try:
            word_in_word_cluster = df_select[df_select[f"{target_column}"].str.contains(fr"(?:\s|^){i}(?:\s|$)", na=True)].head(word_sample_num)    
        except:
            pass        
        word_in_word_cluster.insert(0,"search_string",i)
        df_result = pd.concat([df_result,word_in_word_cluster], axis=0)
    df_result.reset_index(drop=True, inplace=True)

    return df_result

# %%
def word_group_youtube(df, search_list, target_column, sample_num):
    '''
    word_group_youtube(df_youtube_sentence, search_list, "sentence", 6)
    ''' 
    df_search_result = pd.DataFrame()
    for j in search_list:
        try:
            df_select = df[df[f"{target_column}"].str.contains(fr"(?:\s|^){j}(?:\s|$)", na=True)].sample(sample_num)
        except:
            df_select = df[df[f"{target_column}"].str.contains(fr"(?:\s|^){j}(?:\s|$)", na=True)].head(sample_num)
        #df_result = df[df[f"{target_column}"].str.contains(fr"(?:\s|^){j}(?:\s|$)", na=True)]  # sentence length part
        #df_result.sort_values(f"{target_column}",key=lambda x:x.str.len(), inplace=True)
        #df_select = df_result.head(sample_num)
        df_select.insert(0,"search_string",j)
        df_search_result = pd.concat([df_search_result,df_select], axis=0)
    df_search_result.reset_index(inplace=True, drop=True)
    
    return df_search_result

# %%
def word_group_time_loc(df, search, start_sent, end_sent, sent, sent_video_id):
    '''
    word_group_time_loc(df_search_result, "search_string", "start_time", "end_time", "sentence", "video_id")
    '''
    df.reset_index(drop=True, inplace=True)
    word_time_loc_list = []
    for i in range(len(df)):
        word = df.loc[i,f"{search}"]
        start_time = df.loc[i,f"{start_sent}"]
        end_time = df.loc[i,f"{end_sent}"]
        sentence = df.loc[i,f"{sent}"]
        video_id = df.loc[i,f"{sent_video_id}"]
        time_length = end_time-start_time
        sentence_length = len(sentence)
        time_length_ratio = time_length/sentence_length
        loc_list = []
        for j in re.finditer(fr"(?:\s|^){word}(?:\s|$)", sentence, re.IGNORECASE|re.UNICODE):
            loc_list.append(j)
            start = loc_list[0].start()
            end = loc_list[0].end()
            start_loc = start_time+(start*time_length_ratio)
            end_loc = start_time+(end*time_length_ratio)
        word_time_loc_list.append([word,start_loc,end_loc,sentence,video_id])
    df_word_time_loc = pd.DataFrame(word_time_loc_list, columns=[f"{search}",f"{start_sent}",f"{end_sent}",f"{sent}",f"{sent_video_id}"])

    return df_word_time_loc

# %%
def word_count_result(df, column_list, set_condition=False): # df is dataframe, column_list is list value
    '''
    word_count_bool(df, column_list): df columns word count for word frequency\n
    df is dataframe, column_list is list value\n
    word_count_bool(df, ["word","twogram"]):
    '''
    list_all = []
    for i in df.loc[:,[x for x in column_list]].columns:
        if set_condition:
            var_list = set(df[f"{i}"].dropna().tolist())
        else:
            var_list = df[f"{i}"].dropna().tolist()
        for j in var_list:
            list_all.append(j)
    text = " ".join(list_all)
    word_list = re.findall(r"\w+",text, re.UNICODE)
    df_word_list = pd.DataFrame(word_list, columns=["word"])
    #df_word_list.rename(columns={0:"word"}, inplace=True)
    df_word_count = pd.DataFrame(df_word_list.value_counts())
    df_word_count.reset_index(inplace=True)
    df_word_count.rename(columns={0:"word_count"}, inplace=True)
    df_word_count.sort_values("word_count", ascending=False, inplace=True)
    df_word_count.reset_index(inplace=True, drop=True)
    
    return  df_word_count

# %%
def df_col_value_join_comma(df, df_columns_list):
    '''
    df_col_value_join_comma(df_test, ["video_id","start_time","end_time"])\n
    function used for selected column value join with comma in one row
    '''
    column_value_list = []
    for column in df_columns_list:
        list_var = df[f"{column}"].to_list()
        list_var_string = [str(x) for x in list_var] 
        list_var_join = ",".join(list_var_string)
        column_value_list.append(list_var_join)

    df_result = pd.DataFrame([[column_value_list[0],column_value_list[1],column_value_list[2]]], columns=df_columns_list)

    return df_result

# %%
path = f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/\
Talk Time/Result/4-Talk Time Data Result"

Path(path).mkdir(parents=True, exist_ok=True)

# %%
df_word_all = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.lower().capitalize()}/Deployment/Data/Word/Word_Merge_Preprocess.xlsx")
df_word_all
# Out:
#                     word  frequency
# 0                     ik   22539531
# 1                     je   20769946
# 2                    het   15696161
# 3                     de   15258816
# 4                    dat   13387137
# ...                  ...        ...
# 331769  oorlogsgezichten          5
# 331770   opdrachtenlijst          5
# 331771        verlsaafde          5
# 331772    oxidatieproces          5
# 331773     nepcappuccino          5
#
# [331774 rows x 2 columns]

# %%
df_word_select = df_word_all.iloc[word_start:word_end,]

# %%
df_word_select
# Out:
#        word  frequency
# 0        ik   22539531
# 1        je   20769946
# 2       het   15696161
# 3        de   15258816
# 4       dat   13387137
# ..      ...        ...
# 195  genoeg     353128
# 196    wist     352948
# 197      oh     351988
# 198   klaar     350506
# 199    neem     348003
#
# [200 rows x 2 columns]

# %%
#df_word_select.to_excel(f"{lang_folder.capitalize()}_200_Word.xlsx", index=False)

# %%
word_list = df_word_select["word"].to_list()
len(word_list)
# Out:
# 200

# %%
df_youtube_sentence = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Youtube/Result/{lang_folder.capitalize()}/Sentence Clean Merge/Clean_Youtube_Sentence_Merge_Result.csv")
df_youtube_sentence
# Out:
#           start_time      end_time  \
# 0       00:00:00.000  00:00:02.501
# 1       00:00:04.501  00:00:05.434
# 2       00:00:08.518  00:00:13.066
# 3       00:00:13.066  00:00:14.316
# 4       00:00:14.316  00:00:15.889
# ...              ...           ...
# 252485  00:01:37.135  00:01:47.040
# 252486  00:01:47.040  00:01:49.340
# 252487  00:01:49.340  00:01:53.600
# 252488  00:01:53.600  00:01:57.914
# 252489  00:01:57.914  00:01:58.758
#
#                                                  sentence     video_id
# 0                                     dit is de pangale v  BoaYsdPtJYA
# 1                                                  unreal  BoaYsdPtJYA
# 2         dit is de eerste keer ik rijd in een supersport  BoaYsdPtJYA
# 3                           ik heb dit in mijn hele leven  BoaYsdPtJYA
# 4                                 nog nooit eerder gedaan  BoaYsdPtJYA
# ...                                                   ...          ...
# 252485  soms zitten de volwassenen met natte ogen te k...  MZUDbceIw4E
# 252486      dit ziet er al was super indrukwekkend uit en  MZUDbceIw4E
# 252487  het is nog maar een voorproefje dus kom zeker ...  MZUDbceIw4E
# 252488  tijdsblok te kiezen en zeker ook op tijd te ko...  MZUDbceIw4E
# 252489                                            tot dan  MZUDbceIw4E
#
# [252490 rows x 4 columns]

# %%
df_youtube_sentence['start_time'] = pd.to_timedelta(df_youtube_sentence['start_time']) # data type converted timedelta for second 
df_youtube_sentence['end_time'] = pd.to_timedelta(df_youtube_sentence['end_time'])

# %%
df_youtube_sentence['start_time'] = df_youtube_sentence['start_time'].apply(lambda x: x.total_seconds()) # convert seconds
df_youtube_sentence['end_time'] = df_youtube_sentence['end_time'].apply(lambda x: x.total_seconds())
df_youtube_sentence
# Out:
#         start_time  end_time  \
# 0            0.000     2.501
# 1            4.501     5.434
# 2            8.518    13.066
# 3           13.066    14.316
# 4           14.316    15.889
# ...            ...       ...
# 252485      97.135   107.040
# 252486     107.040   109.340
# 252487     109.340   113.600
# 252488     113.600   117.914
# 252489     117.914   118.758
#
#                                                  sentence     video_id
# 0                                     dit is de pangale v  BoaYsdPtJYA
# 1                                                  unreal  BoaYsdPtJYA
# 2         dit is de eerste keer ik rijd in een supersport  BoaYsdPtJYA
# 3                           ik heb dit in mijn hele leven  BoaYsdPtJYA
# 4                                 nog nooit eerder gedaan  BoaYsdPtJYA
# ...                                                   ...          ...
# 252485  soms zitten de volwassenen met natte ogen te k...  MZUDbceIw4E
# 252486      dit ziet er al was super indrukwekkend uit en  MZUDbceIw4E
# 252487  het is nog maar een voorproefje dus kom zeker ...  MZUDbceIw4E
# 252488  tijdsblok te kiezen en zeker ook op tijd te ko...  MZUDbceIw4E
# 252489                                            tot dan  MZUDbceIw4E
#
# [252490 rows x 4 columns]

# %%
# other option 
# mUf7VNqChac =>  black screen
# 0_CDMstFg7M => 10sn
# bj1JRuyYeco => 20sn
# cElhIDdGz7M => screensaver
default_video_id = "Q-8I-uMUMYA"
df_link_default = pd.DataFrame(data=[["repeat",5,7,"repeat_again",f"{default_video_id}",f"https://www.youtube.com/watch?v={default_video_id}&t=0s"]], columns=["search_string","start_time","end_time","sentence","video_id","video_url"])
df_link_default
# Out:
#   search_string  start_time  end_time      sentence     video_id  \
# 0        repeat           5         7  repeat_again  Q-8I-uMUMYA
#
#                                           video_url
# 0  https://www.youtube.com/watch?v=Q-8I-uMUMYA&t=0s

# %%
df_word_link = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Talk Time/Data/3-Talk Time Data Prepare/{lang_folder.capitalize()}_{word_end}_Word_{sample_num}_Youtube_{time_shift}s_Timeshift_For_Talk_Time_Result_Manuel.xlsx")
df_word_link
# Out:
#     search_string  start_time  end_time  \
# 0              ik          19        21
# 1              ik        2213      2214
# 2              ik         547       549
# 3              ik          38        39
# 4              ik        1057      1059
# ..            ...         ...       ...
# 995          neem        1030      1033
# 996          neem         313       315
# 997          neem         230       232
# 998          neem          48        49
# 999          neem          37        39
#
#                                               sentence     video_id  \
# 0    we zijn een tijdje geleden opgericht maar wat ...  8jmOuLksBJ0
# 1    ik zal ophouden over de oorzaak van die schaar...  QAjt9liE_a4
# 2    ik vertel het verhaal aan tom en we passen de ...  HKCKdkGrazU
# 3    ik denk dat dat de maatregelen zijn die je nie...  KgYv5wjScaM
# 4                                   ja dat denk ik wel  gFA9Q_RrOVo
# ..                                                 ...          ...
# 995                                      neem maar mee  Gj1X8jth_Bw
# 996  op stoom geholpen dus mijn advies neem de tijd...  lYKUmLypP5s
# 997                 ik neem de volgende dan ga ik deze  ZqkfywfGIIY
# 998  en neem gerust een dekentje mee extra gezellig...  ELg3rJ5NeRk
# 999  neem dan contact op met één van onze vakspecia...  QMq3mQkF6i8
#
#                                              video_url
# 0    https://www.youtube.com/watch?v=8jmOuLksBJ0&t=19s
# 1    https://www.youtube.com/watch?v=QAjt9liE_a4&t=...
# 2    https://www.youtube.com/watch?v=HKCKdkGrazU&t=...
# 3    https://www.youtube.com/watch?v=KgYv5wjScaM&t=38s
# 4    https://www.youtube.com/watch?v=gFA9Q_RrOVo&t=...
# ..                                                 ...
# 995  https://www.youtube.com/watch?v=Gj1X8jth_Bw&t=...
# 996  https://www.youtube.com/watch?v=lYKUmLypP5s&t=...
# 997  https://www.youtube.com/watch?v=ZqkfywfGIIY&t=...
# 998  https://www.youtube.com/watch?v=ELg3rJ5NeRk&t=48s
# 999  https://www.youtube.com/watch?v=QMq3mQkF6i8&t=37s
#
# [1000 rows x 6 columns]

# %%
df_word_link[df_word_link["search_string"].duplicated()]
# Out:
#     search_string  start_time  end_time  \
# 1              ik        2213      2214
# 2              ik         547       549
# 3              ik          38        39
# 4              ik        1057      1059
# 6              je       12415     12416
# ..            ...         ...       ...
# 994         klaar         478       480
# 996          neem         313       315
# 997          neem         230       232
# 998          neem          48        49
# 999          neem          37        39
#
#                                               sentence     video_id  \
# 1    ik zal ophouden over de oorzaak van die schaar...  QAjt9liE_a4
# 2    ik vertel het verhaal aan tom en we passen de ...  HKCKdkGrazU
# 3    ik denk dat dat de maatregelen zijn die je nie...  KgYv5wjScaM
# 4                                   ja dat denk ik wel  gFA9Q_RrOVo
# 6    maar het gebruik ervan dat kun je gebieden dus...  uJhEbO42qRo
# ..                                                 ...          ...
# 994  als ik klaar ben met werken dan zit ik op de b...  P9u2BkJamhg
# 996  op stoom geholpen dus mijn advies neem de tijd...  lYKUmLypP5s
# 997                 ik neem de volgende dan ga ik deze  ZqkfywfGIIY
# 998  en neem gerust een dekentje mee extra gezellig...  ELg3rJ5NeRk
# 999  neem dan contact op met één van onze vakspecia...  QMq3mQkF6i8
#
#                                              video_url
# 1    https://www.youtube.com/watch?v=QAjt9liE_a4&t=...
# 2    https://www.youtube.com/watch?v=HKCKdkGrazU&t=...
# 3    https://www.youtube.com/watch?v=KgYv5wjScaM&t=38s
# 4    https://www.youtube.com/watch?v=gFA9Q_RrOVo&t=...
# 6    https://www.youtube.com/watch?v=uJhEbO42qRo&t=...
# ..                                                 ...
# 994  https://www.youtube.com/watch?v=P9u2BkJamhg&t=...
# 996  https://www.youtube.com/watch?v=lYKUmLypP5s&t=...
# 997  https://www.youtube.com/watch?v=ZqkfywfGIIY&t=...
# 998  https://www.youtube.com/watch?v=ELg3rJ5NeRk&t=48s
# 999  https://www.youtube.com/watch?v=QMq3mQkF6i8&t=37s
#
# [800 rows x 6 columns]

# %%
df_twogram_link = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Talk Time/Data/3-Talk Time Data Prepare/{lang_folder.capitalize()}_Twogram_With_{word_end}_Word_{sample_num}_Youtube_{time_shift}s_Timeshift_For_Talk_Time_Result_Manuel.xlsx")
df_twogram_link
# Out:
#    search_string  start_time  end_time  \
# 0        weet je        1434      1436
# 1        hoe dan         137       139
# 2          ik ga        1137      1139
# 3         het is          68        70
# 4         dat is         215       216
# 5         ik ben          68        69
# 6         dit is        1381      1383
# 7        dat kan         134       136
# 8        ik denk         563       565
# 9         ik heb         129       132
# 10      het gaat         673       675
# 11        en dus        4414      4416
# 12        en dat        3774      3775
# 13     veel meer        1253      1254
# 14        je wat          57        58
# 15        ben ik         368       369
# 16        ik zou        4490      4492
# 17        is dit         146       148
# 18       nog wel         423       425
# 19        als je         242       244
# 20       je kunt          95        96
# 21       nog wat        1471      1472
# 22       hier in         852       854
# 23       je weet          76        78
# 24    gewoon weg         918       920
# 25      maar dat         237       238
# 26     ze hebben          21        22
# 27       er zijn         553       555
# 28        oh dit        1555      1557
# 29      weet wat         104       105
# 30       moet je         111       112
# 31      en terug          86        88
# 32     hebben ze          36        38
# 33         in de       18010     18011
# 34      moet het         176       177
# 35        ook zo         863       864
# 36        is wat         564       565
# 37      daar ook         172       174
# 38       dat het         451       453
# 39       te doen         208       210
# 40     wat beter          90        92
# 41       wat het          57        59
# 42       ook nog          23        25
# 43        van de        1899      1901
# 44       te zijn          52        54
# 45       dan ook         618       620
# 46       dus het        1874      1876
# 47         is de        1153      1154
# 48        aan de         714       716
# 49       een van          67        69
# 50        die al        3510      3511
# 51   hier gewoon         129       132
# 52      wel even        4009      4011
# 53        er aan        1081      1082
# 54      denk dat        1487      1489
# 55     zijn daar          28        30
#
#                                              sentence     video_id  \
# 0                    weet je wat lopen we daar binnen  fPzfhneNmcc
# 1   stukje belgische geschiedenis en hoe dan de ch...  Dd6N0ZdQTvc
# 2   ik ga daarop klikken en dan krijg ik de mogeli...  p4Xe249nsTU
# 3   want het is groen dat deze wijken met elkaar k...  Kh9znOzlKPw
# 4              dat is eigenlijk een levenswerk voor u  kRLm5pQi_xE
# 5   nooit in positieve zin en daarom ben ik op een...  8oxf7nVWqIE
# 6   moet ik zeggen dat als ik even voor ons beide ...  XhcjYIknnfA
# 7   als je vragen hebt of je bent een beetje bang ...  rWNpd_54cqM
# 8      ik denk daar is men dan ook wel weer mee bezig  qmqWWRrEvZk
# 9   hoe kijk jij daarnaar amber ik heb die spotjes...  Ud7n8yMn_h8
# 10  dan normaal het gaat niet goed maar de volgend...  JhxM6ufSS2k
# 11           mogelijkheden en dus wat kun je allemaal  3TI4Ce_ckO0
# 12  over het gene wat de wel goed en wat we niet g...  5OagXviiA_4
# 13  dus je moet veel meer durven te beslissen avoi...  robgEk58nx4
# 14               ja welke momenten weet je wat het is  5HW0U_THQ10
# 15  bijvoorbeeld dit is getatoeëerd en dat heb ik ...  jP8ee6ulenE
# 16  en voert uit die reeks ik zou zeggen werk geme...  71PKVXuCQj8
# 17  wat ik mee zou willen nemen naar rotterdam is ...  ybLMApgRZ5E
# 18                              deze doet het nog wel  QUTjogd2lOU
# 19  nederland is relatief een kleine markt als je ...  4Fh9KEPYaIA
# 20  de reiniger is super gemakkelijk te gebruiken ...  U9t2YcjXLr8
# 21  wil jij nog wat zeggen tot de volgende ik vond...  BqUaHXKRgJQ
# 22  frankrijk spanje duitsland servië en nu hier i...  4mRl4F7pfCk
# 23  ja we houden het praktisch zeker je weet ik be...  EiyFf3Ip18E
# 24  kookwekkers en twee daarvan waren stuk dus waa...  B7HYu_cq_P8
# 25  ho er valt een beetje in het zout maar dat maa...  ebrpR5554yM
# 26     omdat ze hebben bijgedragen aan de samenleving  nASlwkh7EGA
# 27  alleen er zijn een aantal dingen die vallen me...  VlgvYPnYjMo
# 28                    yes oh dit is echt oh mijn hart  P9u2BkJamhg
# 29  u weet wat je wel en wat je niet mag doorberek...  ypbGtkT8Jfo
# 30          dan moet je wel om de wortels heen rjiden  AOx6lBEBpWA
# 31  nieuws en op basis daarvan deel ik wat mijn me...  rMubzyzHxCU
# 32  we hebben ze op tijd er uit kunnen halen zonde...  _e0dtCyEZeM
# 33              in de portemonnee van de nederlanders  k1up2KLkuaM
# 34  dus het huidige zuidoost moet het nieuwe zuido...  ZQxGW8XGf7E
# 35  in markt het schaars dus ja als je dat dan ook...  43CNzte_Alw
# 36  denk is wat europeser ik snap dat het vraag ne...  DniD4L9cACc
# 37                 alleen zit daar ook nog compost in  SqFkqOnW5kE
# 38  kunnen we verminderen dat het overgedragen wor...  z7DjsWLAdMk
# 39  dus dat zijn vijf dingen waarvan ik dacht dat ...  Qeg9qeduuMo
# 40  zodat de aanblik in onze stad wat beter gaat w...  7iD0Zy6oCX4
# 41  wat het leuke is binnen ons team is dat wij al...  x3eXs9f3rLA
# 42                                 ja ik leef ook nog  FOO5D9kLUa0
# 43  aan het eind van de middag daar ook geweest om...  t35fwDbZyiQ
# 44  zo krijgt onze klant een machine om trots op t...  Uw5Rw3uvbsw
# 45  de mensen die het leuk vinden vinden het ook o...  boS7dcETg_4
# 46  effe terug hier mini altaar michael op ze even...  F6tNXpHHqhQ
# 47  dat het is de bedoeling dat meer mensen hierov...  Yrh7Bmlq7uA
# 48      nee mevrouw aukje de vries is nu aan de beurt  k1up2KLkuaM
# 49  zo kun je bijvoorbeeld een van onze tientallen...  rt3O1If7mYk
# 50  de vakantie te komen mezelf niet te zijn en pa...  6b2CjjmooDA
# 51  focus op de boshyacinten maar ik ga hier gewoo...  HYdl8UMx9lk
# 52  maatregelen te nemen maar dat dat zal nog wel ...  2Kc2Cz3L_Uo
# 53  er aan toe gaat ook niet na uiteindelijk wel m...  1JRauSMWBww
# 54           nog even om aan te vullen ik denk dat we  BHfZRmk3n6w
# 55  en de cliëntenraden zijn daar vaak aanwezig zi...  YsseAUPtlow
#
#                                             video_url
# 0   https://www.youtube.com/watch?v=fPzfhneNmcc&t=...
# 1   https://www.youtube.com/watch?v=Dd6N0ZdQTvc&t=...
# 2   https://www.youtube.com/watch?v=p4Xe249nsTU&t=...
# 3   https://www.youtube.com/watch?v=Kh9znOzlKPw&t=68s
# 4   https://www.youtube.com/watch?v=kRLm5pQi_xE&t=...
# 5   https://www.youtube.com/watch?v=8oxf7nVWqIE&t=68s
# 6   https://www.youtube.com/watch?v=XhcjYIknnfA&t=...
# 7   https://www.youtube.com/watch?v=rWNpd_54cqM&t=...
# 8   https://www.youtube.com/watch?v=qmqWWRrEvZk&t=...
# 9   https://www.youtube.com/watch?v=Ud7n8yMn_h8&t=...
# 10  https://www.youtube.com/watch?v=JhxM6ufSS2k&t=...
# 11  https://www.youtube.com/watch?v=3TI4Ce_ckO0&t=...
# 12  https://www.youtube.com/watch?v=5OagXviiA_4&t=...
# 13  https://www.youtube.com/watch?v=robgEk58nx4&t=...
# 14  https://www.youtube.com/watch?v=5HW0U_THQ10&t=57s
# 15  https://www.youtube.com/watch?v=jP8ee6ulenE&t=...
# 16  https://www.youtube.com/watch?v=71PKVXuCQj8&t=...
# 17  https://www.youtube.com/watch?v=ybLMApgRZ5E&t=...
# 18  https://www.youtube.com/watch?v=QUTjogd2lOU&t=...
# 19  https://www.youtube.com/watch?v=4Fh9KEPYaIA&t=...
# 20  https://www.youtube.com/watch?v=U9t2YcjXLr8&t=95s
# 21  https://www.youtube.com/watch?v=BqUaHXKRgJQ&t=...
# 22  https://www.youtube.com/watch?v=4mRl4F7pfCk&t=...
# 23  https://www.youtube.com/watch?v=EiyFf3Ip18E&t=76s
# 24  https://www.youtube.com/watch?v=B7HYu_cq_P8&t=...
# 25  https://www.youtube.com/watch?v=ebrpR5554yM&t=...
# 26  https://www.youtube.com/watch?v=nASlwkh7EGA&t=21s
# 27  https://www.youtube.com/watch?v=VlgvYPnYjMo&t=...
# 28  https://www.youtube.com/watch?v=P9u2BkJamhg&t=...
# 29  https://www.youtube.com/watch?v=ypbGtkT8Jfo&t=...
# 30  https://www.youtube.com/watch?v=AOx6lBEBpWA&t=...
# 31  https://www.youtube.com/watch?v=rMubzyzHxCU&t=86s
# 32  https://www.youtube.com/watch?v=_e0dtCyEZeM&t=36s
# 33  https://www.youtube.com/watch?v=k1up2KLkuaM&t=...
# 34  https://www.youtube.com/watch?v=ZQxGW8XGf7E&t=...
# 35  https://www.youtube.com/watch?v=43CNzte_Alw&t=...
# 36  https://www.youtube.com/watch?v=DniD4L9cACc&t=...
# 37  https://www.youtube.com/watch?v=SqFkqOnW5kE&t=...
# 38  https://www.youtube.com/watch?v=z7DjsWLAdMk&t=...
# 39  https://www.youtube.com/watch?v=Qeg9qeduuMo&t=...
# 40  https://www.youtube.com/watch?v=7iD0Zy6oCX4&t=90s
# 41  https://www.youtube.com/watch?v=x3eXs9f3rLA&t=57s
# 42  https://www.youtube.com/watch?v=FOO5D9kLUa0&t=23s
# 43  https://www.youtube.com/watch?v=t35fwDbZyiQ&t=...
# 44  https://www.youtube.com/watch?v=Uw5Rw3uvbsw&t=52s
# 45  https://www.youtube.com/watch?v=boS7dcETg_4&t=...
# 46  https://www.youtube.com/watch?v=F6tNXpHHqhQ&t=...
# 47  https://www.youtube.com/watch?v=Yrh7Bmlq7uA&t=...
# 48  https://www.youtube.com/watch?v=k1up2KLkuaM&t=...
# 49  https://www.youtube.com/watch?v=rt3O1If7mYk&t=67s
# 50  https://www.youtube.com/watch?v=6b2CjjmooDA&t=...
# 51  https://www.youtube.com/watch?v=HYdl8UMx9lk&t=...
# 52  https://www.youtube.com/watch?v=2Kc2Cz3L_Uo&t=...
# 53  https://www.youtube.com/watch?v=1JRauSMWBww&t=...
# 54  https://www.youtube.com/watch?v=BHfZRmk3n6w&t=...
# 55  https://www.youtube.com/watch?v=YsseAUPtlow&t=28s

# %%
df_threegram_link = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Talk Time/Data/3-Talk Time Data Prepare/{lang_folder.capitalize()}_Threegram_With_{word_end}_Word_{sample_num}_Youtube_{time_shift}s_Timeshift_For_Talk_Time_Result_Manuel.xlsx")
df_threegram_link
# Out:
#     search_string  start_time  end_time  \
# 0     weet je wat        4406      4408
# 1       en dat is        2593      2595
# 2     hoe dan ook        5212      5214
# 3     ik denk dat         228       230
# 4      dat is wat          61        64
# 5       ik ben ik         430       432
# 6     je weet wat         264       267
# 7   nog veel meer          15        17
# 8      wat het is        3928      3930
# 9     waar ik ben         116       118
# 10      dit is de         265       268
# 11   dus dacht ik         173       175
# 12    dat kan nog        2825      2826
# 13     het is dit        1722      1724
# 14      oh dit is        1196      1198
# 15    dus weet je         563       566
# 16   ze hebben ze        1471      1473
# 17   je kunt zien         438       440
# 18     een van de       24269     24272
# 19    dat je weet         164       166
# 20   het gaat nog        1098      1100
# 21    nu moet het        1156      1158
# 22   nog wel even         718       720
# 23     ben ik zou         424       426
# 24    als je daar          47        48
# 25    dat het een          29        31
#
#                                              sentence     video_id  \
# 0   meneer weet u dat u meneer weet u zo maar weet...  lApJy0bJNk0
# 1   van opstellen en dat is ook de reden dat wij d...  idTEcq_P1WY
# 2            en des tilleuls hoe dan ook opgenomen te  R4Q1cNbNKU0
# 3   in het onderwijs bijvoorbeeld en ik denk dat d...  S0MhQFLZGYg
# 4              intense weekenden dat is wat ik zeggen  rdLMBm1Rtcs
# 5   alleen ben ik nog wel heel lang bezig en ik be...  NxX9X3tkSXw
# 6                       je weet wat te doen dankjewel  tHFynkakpVk
# 7    wie er belt waarom diegene belt en nog veel meer  Hvc226NRmSQ
# 8   mensen willen aansluiten nou weet je wat het i...  lApJy0bJNk0
# 9   waar ik ben ik zou mijn fiets moeten en ik ga ...  BoaYsdPtJYA
# 10               dus dit is de bovenkant van de tafel  lYcOOmkhYdk
# 11  fotograferen bij zacht licht en dus dacht ik l...  5XGbMbvvfyY
# 12  we toch op een ander vlak wat kunnen gaan doen...  1JRauSMWBww
# 13  op basis van de sunshine het is dit is eigenli...  h2lcMkuZLq8
# 14  mijn de stuntman met assistent jane oh dit is ...  _lq9tjAA6hc
# 15                     het is roze dus weet je winwin  7AtG8uBhwkg
# 16  is zeker en die dollar die hebben ze toen nog ...  IAyQeJ57A0s
# 17  zoals je kunt zien is het bewolkt vanmorgen be...  aH0J3mbYpqQ
# 18                    een van de maatregelen uit stap  9uOFhXkzEQQ
# 19  alles ik vond het leuk dat je standen kan hers...  bjKUUIiC7NM
# 20  ja wat wat er gezegd wordt is we zijn er mee b...  DFHcj1NME3o
# 21  een bitcoin wisselkantoor nu moet het altijd m...  h2lcMkuZLq8
# 22  particuliere bronnen opvallend daar komen we o...  EZMgSCfbiGs
# 23  de kleinste begint ja ik ben ik zou willen dat...  Fn5erRPierY
# 24  jou kunnen behandelen in het buitenland als je...  4hMVxIPix0I
# 25                    het zou kunnen zijn dat het een  YlqkQecoiMw
#
#                                             video_url
# 0   https://www.youtube.com/watch?v=lApJy0bJNk0&t=...
# 1   https://www.youtube.com/watch?v=idTEcq_P1WY&t=...
# 2   https://www.youtube.com/watch?v=R4Q1cNbNKU0&t=...
# 3   https://www.youtube.com/watch?v=S0MhQFLZGYg&t=...
# 4   https://www.youtube.com/watch?v=rdLMBm1Rtcs&t=61s
# 5   https://www.youtube.com/watch?v=NxX9X3tkSXw&t=...
# 6   https://www.youtube.com/watch?v=tHFynkakpVk&t=...
# 7   https://www.youtube.com/watch?v=Hvc226NRmSQ&t=15s
# 8   https://www.youtube.com/watch?v=lApJy0bJNk0&t=...
# 9   https://www.youtube.com/watch?v=BoaYsdPtJYA&t=...
# 10  https://www.youtube.com/watch?v=lYcOOmkhYdk&t=...
# 11  https://www.youtube.com/watch?v=5XGbMbvvfyY&t=...
# 12  https://www.youtube.com/watch?v=1JRauSMWBww&t=...
# 13  https://www.youtube.com/watch?v=h2lcMkuZLq8&t=...
# 14  https://www.youtube.com/watch?v=_lq9tjAA6hc&t=...
# 15  https://www.youtube.com/watch?v=7AtG8uBhwkg&t=...
# 16  https://www.youtube.com/watch?v=IAyQeJ57A0s&t=...
# 17  https://www.youtube.com/watch?v=aH0J3mbYpqQ&t=...
# 18  https://www.youtube.com/watch?v=9uOFhXkzEQQ&t=...
# 19  https://www.youtube.com/watch?v=bjKUUIiC7NM&t=...
# 20  https://www.youtube.com/watch?v=DFHcj1NME3o&t=...
# 21  https://www.youtube.com/watch?v=h2lcMkuZLq8&t=...
# 22  https://www.youtube.com/watch?v=EZMgSCfbiGs&t=...
# 23  https://www.youtube.com/watch?v=Fn5erRPierY&t=...
# 24  https://www.youtube.com/watch?v=4hMVxIPix0I&t=47s
# 25  https://www.youtube.com/watch?v=YlqkQecoiMw&t=29s

# %%
df_sentence_link = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/\
Talk Time/Result/2-Adjust Word Group In Youtube Sentence Word Usage Analysis/{lang_folder.capitalize()}_{word_end}_Word_Group_In_Youtube_Sentence_Sample_Manuel.xlsx")
df_sentence_link
# Out:
#                                         search_string  start_time  end_time  \
# 0                         van wat zou dat nou voor de         141       143
# 1                           en we daar hebben wij een         167       168
# 2                          en we hebben weer een heel         332       334
# 3                     me af of dat wel goed zou komen         230       232
# 4                     dus ja er zijn veel mensen daar         480       483
# 5                          kunnen doen ja dan moet de         194       195
# 6                           we hebben hem toch in een         274       275
# 7                              maar door me in hem te         102       103
# 8                         en moeten wij hier weg zijn          65        67
# 9                 dan moeten wij hier weg zijn anders          66        68
# 10   dus hier staat er een en binnen staat er nog een         188       191
# 11                             ook nog wel eens in de         195       196
# 12                             om te weten of zij nog          94        95
# 13  nee die hebben daar niets mee van doen dat doe...         104       107
# 14                          maar dat werd hem niet en         195       198
# 15                          kom dan in een huis omdat         259       261
# 16                       staat op wat voor mij op dit         393       396
# 17                          ook hier nog even te zien         429       431
# 18                  die ons toch altijd weer weten te         639       641
#
#                                              sentence     video_id  \
# 0   maar ik heb wel beter nagedacht van wat zou da...  JUQTVKIBFns
# 1   en we daar hebben wij een efteling variant van...  JUQTVKIBFns
# 2   het staat natuurlijk gewoon in de efteling en ...  JUQTVKIBFns
# 3        dus ik vroeg me af of dat wel goed zou komen  UltPsmBVTV0
# 4   ah het is dit hele complex dus ja er zijn veel...  UltPsmBVTV0
# 5   maar je moet het snel kunnen doen ja dan moet ...  4YSldeXmuXw
# 6   we hebben hem toch in een korte deadline neerg...  KmcDJ7GyLNk
# 7   ik kende alleen maar het verhaal van max amp m...  IJ2LOTPGSvA
# 8                         en moeten wij hier weg zijn  b_HmOS8lNl4
# 9   dan moeten wij hier weg zijn anders krijgen we...  b_HmOS8lNl4
# 10   dus hier staat er een en binnen staat er nog een  b_HmOS8lNl4
# 11         en ga jij zelf ook nog wel eens in de baan  b_HmOS8lNl4
# 12  om te weten of zij nog plannen hebben met die ...  LEJ94Id9x5c
# 13  nee die hebben daar niets mee van doen dat doe...  LEJ94Id9x5c
# 14  een aantal opties onderzocht dus antikraak of ...  1g9tiRKq2dY
# 15  koud aan boord vooral als ik s ochtends uit be...  1g9tiRKq2dY
# 16  die daarbij helpen eigenlijk is dit altaartje ...  1g9tiRKq2dY
# 17                          ook hier nog even te zien  eoqpkiQbfoI
# 18        die ons toch altijd weer weten te verrassen  aWOJx8liOyU
#
#                                             video_url
# 0   https://www.youtube.com/watch?v=JUQTVKIBFns&t=...
# 1   https://www.youtube.com/watch?v=JUQTVKIBFns&t=...
# 2   https://www.youtube.com/watch?v=JUQTVKIBFns&t=...
# 3   https://www.youtube.com/watch?v=UltPsmBVTV0&t=...
# 4   https://www.youtube.com/watch?v=UltPsmBVTV0&t=...
# 5   https://www.youtube.com/watch?v=4YSldeXmuXw&t=...
# 6   https://www.youtube.com/watch?v=KmcDJ7GyLNk&t=...
# 7   https://www.youtube.com/watch?v=IJ2LOTPGSvA&t=...
# 8   https://www.youtube.com/watch?v=b_HmOS8lNl4&t=65s
# 9   https://www.youtube.com/watch?v=b_HmOS8lNl4&t=66s
# 10  https://www.youtube.com/watch?v=b_HmOS8lNl4&t=...
# 11  https://www.youtube.com/watch?v=b_HmOS8lNl4&t=...
# 12  https://www.youtube.com/watch?v=LEJ94Id9x5c&t=94s
# 13  https://www.youtube.com/watch?v=LEJ94Id9x5c&t=...
# 14  https://www.youtube.com/watch?v=1g9tiRKq2dY&t=...
# 15  https://www.youtube.com/watch?v=1g9tiRKq2dY&t=...
# 16  https://www.youtube.com/watch?v=1g9tiRKq2dY&t=...
# 17  https://www.youtube.com/watch?v=eoqpkiQbfoI&t=...
# 18  https://www.youtube.com/watch?v=aWOJx8liOyU&t=...

# %%
df_sentence_link_word_count = word_count_result(df_sentence_link, ["search_string"], set_condition=False)
df_sentence_link_word_count
# Out:
#       word  word_count
# 0      een           6
# 1       en           5
# 2       te           4
# 3       de           4
# 4     hier           4
# ..     ...         ...
# 61    zien           1
# 62    werd           1
# 63      om           1
# 64    veel           1
# 65  mensen           1
#
# [66 rows x 2 columns]

# %%
set_sent_link_word = set(df_sentence_link_word_count["word"])
set_word_list = set(word_list)

# %%
set_word_list.difference(set_sent_link_word)
# Out:
# {'aan',
#  'al',
#  'alleen',
#  'allemaal',
#  'alles',
#  'als',
#  'andere',
#  'bedankt',
#  'ben',
#  'bent',
#  'beter',
#  'bij',
#  'dacht',
#  'dag',
#  'dank',
#  'denk',
#  'deze',
#  'doe',
#  'dood',
#  'echt',
#  'erg',
#  'ga',
#  'gaan',
#  'gaat',
#  'gedaan',
#  'geef',
#  'geen',
#  'geld',
#  'genoeg',
#  'gewoon',
#  'gezien',
#  'h',
#  'haar',
#  'had',
#  'heb',
#  'hebt',
#  'heeft',
#  'helpen',
#  'het',
#  'hij',
#  'hoe',
#  'hou',
#  'hun',
#  'iedereen',
#  'iemand',
#  'iets',
#  'ik',
#  'is',
#  'jaar',
#  'je',
#  'jij',
#  'jou',
#  'jouw',
#  'jullie',
#  'kan',
#  'keer',
#  'kijk',
#  'klaar',
#  'komt',
#  'kon',
#  'kunt',
#  'laat',
#  'laten',
#  'leven',
#  'm',
#  'mag',
#  'maken',
#  'man',
#  'meer',
#  'met',
#  'mijn',
#  'misschien',
#  'moeder',
#  'mr',
#  'n',
#  'na',
#  'naar',
#  'neem',
#  'net',
#  'niemand',
#  'niks',
#  'nodig',
#  'nooit',
#  'nu',
#  'oh',
#  'ok',
#  'onze',
#  'over',
#  'praten',
#  's',
#  'spijt',
#  't',
#  'tegen',
#  'terug',
#  'tijd',
#  'toen',
#  'tot',
#  'twee',
#  'u',
#  'uit',
#  'uw',
#  'vader',
#  'vind',
#  'vinden',
#  'vrouw',
#  'waar',
#  'waarom',
#  'wacht',
#  'waren',
#  'was',
#  'weet',
#  'werk',
#  'wie',
#  'wil',
#  'wilde',
#  'willen',
#  'wilt',
#  'wist',
#  'worden',
#  'wordt',
#  'z',
#  'zal',
#  'ze',
#  'zeg',
#  'zeggen',
#  'zei',
#  'zeker',
#  'zich',
#  'zie',
#  'zit',
#  'zitten',
#  'zo',
#  'zoals',
#  'zullen'}

# %%
sent_string_list = df_sentence_link["search_string"].to_list()
sent_string_list
# Out:
# ['van wat zou dat nou voor de',
#  'en we daar hebben wij een',
#  'en we hebben weer een heel',
#  'me af of dat wel goed zou komen',
#  'dus ja er zijn veel mensen daar',
#  'kunnen doen ja dan moet de',
#  'we hebben hem toch in een',
#  'maar door me in hem te',
#  'en moeten wij hier weg zijn',
#  'dan moeten wij hier weg zijn anders',
#  'dus hier staat er een en binnen staat er nog een',
#  'ook nog wel eens in de',
#  'om te weten of zij nog',
#  'nee die hebben daar niets mee van doen dat doet de',
#  'maar dat werd hem niet en',
#  'kom dan in een huis omdat',
#  'staat op wat voor mij op dit',
#  'ook hier nog even te zien',
#  'die ons toch altijd weer weten te']

# %%
sent_string_list = df_sentence_link["search_string"][:10].to_list()
sent_string_list
# Out:
# ['van wat zou dat nou voor de',
#  'en we daar hebben wij een',
#  'en we hebben weer een heel',
#  'me af of dat wel goed zou komen',
#  'dus ja er zijn veel mensen daar',
#  'kunnen doen ja dan moet de',
#  'we hebben hem toch in een',
#  'maar door me in hem te',
#  'en moeten wij hier weg zijn',
#  'dan moeten wij hier weg zijn anders']

# %%
sent_string_list[18:25]
# Out:
# ['die ons toch altijd weer weten te']

# %%
#Rev 4
# used for multi search result and with word that repeat 4 times and 3 times different word. Output file result divide according to sentence num
#twogram_link_list = df_twogram_link["search_string"].to_list()
#threegram_link_list = df_threegram_link["search_string"].to_list()
# Parameter
part_num = 1
total_sent_num = 10 
string_step_num = 5
string_start_num = 0
string_end_num = string_step_num
for_loop_repeat = (total_sent_num/string_step_num)

for part in range(for_loop_repeat):
    df_result = pd.DataFrame()
    sent_string_list = df_sentence_link["search_string"][:total_sent_num].to_list()

    for sent in sent_string_list[string_start_num:string_end_num]:

        # words
        sent_words = word_tokenize(sent)

        # word repeat (word search result should more result each words)
        for sent_word in sent_words:
            df_word_search_repeat1 = df_word_link[df_word_link["search_string"] == sent_word].head(1)
            df_word_search_repeat2 = df_word_link[df_word_link["search_string"] == sent_word].iloc[1:,]  # will test
            for word_repeat_num in range(3):
                df_result = pd.concat([df_result,df_word_search_repeat1], axis=0)
            for word_repeat_num2 in range(len(df_word_search_repeat2)):
                df_word_search_repeat2_var = df_word_search_repeat2.iloc[[word_repeat_num2],:]
                df_result = pd.concat([df_result,df_word_search_repeat2_var], axis=0)

        # twogram
        twogram_zip = ngrams(sent.split(), 2)
        twogram_list = [" ".join(x) for x in twogram_zip]
        #df_twogram_var = pd.DataFrame(data=twogram, columns=["twogram"])

        # threegram
        threegram_zip = ngrams(sent.split(), 3)
        threegram_list = [" ".join(y) for y in threegram_zip]
        #df_threegram_var = pd.DataFrame(data=threegram, columns=["threegram"])

        # begin sent repeat 
        df_sent_search_begin = df_sentence_link[df_sentence_link["search_string"] == sent]
        for sent_repeat_num in range(3):
            df_result = pd.concat([df_result,df_sent_search_begin], axis=0)

        # word result
        for word in sent_words: 
            try:
                df_word_search_var = df_word_link[df_word_link["search_string"] == word].sample(1)
            except:
                pass
            df_word_search_var.reset_index(drop=True, inplace=True)
            for i in range(len(df_word_search_var)):
                df_link_default_var = df_link_default
                try:
                    word_time_diff_var = df_word_search_var.loc[i,"end_time"] - df_word_search_var.loc[i,"start_time"]
                    if word_time_diff_var < 4:
                        word_time_diff_var2 = 4
                    else:
                        word_time_diff_var2 = word_time_diff_var+1.0                                       
                    df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + word_time_diff_var2
                    df_result = pd.concat([df_result,df_word_search_var.iloc[[i,]]], axis=0)
                    df_result = pd.concat([df_result,df_link_default_var], axis=0)
                except:
                    pass

        # twogram result
        df_twogram_search_var = df_twogram_link[df_twogram_link["search_string"].isin(twogram_list)]
        df_twogram_search_var.reset_index(drop=True, inplace=True)
        for j in range(len(df_twogram_search_var)):
            df_link_default_var = df_link_default
            try:
                twogram_time_diff_var = df_twogram_search_var.loc[j,"end_time"] - df_twogram_search_var.loc[j,"start_time"]
                if twogram_time_diff_var < 4:
                    twogram_time_diff_var2 = 4
                else:
                    twogram_time_diff_var2 = twogram_time_diff_var+1.0 
                df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + twogram_time_diff_var2
                df_result = pd.concat([df_result,df_twogram_search_var.iloc[[j,]]], axis=0)
                df_result = pd.concat([df_result,df_link_default_var], axis=0)
            except:
                pass

        # threegram result
        df_threegram_search_var = df_threegram_link[df_threegram_link["search_string"].isin(threegram_list)]
        df_threegram_search_var.reset_index(drop=True, inplace=True)
        for k in range(len(df_threegram_search_var)):
            df_link_default_var = df_link_default
            try:
                threegram_time_diff_var = df_threegram_search_var.loc[k,"end_time"] - df_threegram_search_var.loc[k,"start_time"]
                if threegram_time_diff_var < 4:
                    threegram_time_diff_var2 = 4
                else:
                    threegram_time_diff_var2 = threegram_time_diff_var+1.0 
                df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + threegram_time_diff_var2
                df_result = pd.concat([df_result,df_threegram_search_var.iloc[[k,]]], axis=0)
                df_result = pd.concat([df_result,df_link_default_var], axis=0)
            except:
                pass

        # sentence added
        df_sent_search_var = df_sentence_link[df_sentence_link["search_string"] == sent]
        df_sent_search_var.reset_index(drop=True, inplace=True)
        for l in range(len(df_sent_search_var)):
            df_link_default_var = df_link_default
            try:
                sent_time_diff_var = df_sent_search_var.loc[l,"end_time"] - df_sent_search_var.loc[l,"start_time"]
                if sent_time_diff_var < 4:
                    sent_time_diff_var2 = 4
                else:
                    sent_time_diff_var2 = sent_time_diff_var+1.0 
                df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + sent_time_diff_var2
                df_result = pd.concat([df_result,df_sent_search_var.iloc[[l,]]], axis=0)
                df_result = pd.concat([df_result,df_link_default_var], axis=0)
            except:
                pass
            

    df_result.reset_index(drop=True, inplace=True)
    df_result_join = df_col_value_join_comma(df_result, ["video_id","start_time","end_time"])
    df_result.to_excel(f"{lang_folder.capitalize()}_{word_end}_Word_Talk_Time{part_num}.xlsx", index=False)
    df_result_join.to_excel(f"{lang_folder.capitalize()}_{word_end}_Word_Talk_Time1_Join{part_num}.xlsx", index=False)

    string_start_num += string_step_num
    string_end_num += string_step_num
    part_num += 1

# %%
#Rev 3
# used for multi search result and with word that repeat 4 times and 3 times different word
#twogram_link_list = df_twogram_link["search_string"].to_list()
#threegram_link_list = df_threegram_link["search_string"].to_list()
df_result = pd.DataFrame()
for sent in df_sentence_link["search_string"]:

    # words
    sent_words = word_tokenize(sent)

    # word repeat (word search result should more result each words)
    for sent_word in sent_words:
        df_word_search_repeat1 = df_word_link[df_word_link["search_string"] == sent_word].head(1)
        df_word_search_repeat2 = df_word_link[df_word_link["search_string"] == sent_word].iloc[1:,]  # will test
        for word_repeat_num in range(3):
            df_result = pd.concat([df_result,df_word_search_repeat1], axis=0)
        for word_repeat_num2 in range(len(df_word_search_repeat2)):
            df_word_search_repeat2_var = df_word_search_repeat2.iloc[[word_repeat_num2],:]
            df_result = pd.concat([df_result,df_word_search_repeat2_var], axis=0)

    # twogram
    twogram_zip = ngrams(sent.split(), 2)
    twogram_list = [" ".join(x) for x in twogram_zip]
    #df_twogram_var = pd.DataFrame(data=twogram, columns=["twogram"])
    
    # threegram
    threegram_zip = ngrams(sent.split(), 3)
    threegram_list = [" ".join(y) for y in threegram_zip]
    #df_threegram_var = pd.DataFrame(data=threegram, columns=["threegram"])

    # begin sent repeat 
    df_sent_search_begin = df_sentence_link[df_sentence_link["search_string"] == sent]
    for sent_repeat_num in range(3):
        df_result = pd.concat([df_result,df_sent_search_begin], axis=0)

    # word result
    for word in sent_words: 
        try:
            df_word_search_var = df_word_link[df_word_link["search_string"] == word].sample(1)
        except:
            pass
        df_word_search_var.reset_index(drop=True, inplace=True)
        for i in range(len(df_word_search_var)):
            df_link_default_var = df_link_default
            try:
                word_time_diff_var = df_word_search_var.loc[i,"end_time"] - df_word_search_var.loc[i,"start_time"]
                if word_time_diff_var < 4:
                    word_time_diff_var2 = 4
                else:
                    word_time_diff_var2 = word_time_diff_var+1.0                                       
                df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + word_time_diff_var2
                df_result = pd.concat([df_result,df_word_search_var.iloc[[i,]]], axis=0)
                df_result = pd.concat([df_result,df_link_default_var], axis=0)
            except:
                pass

    # twogram result
    df_twogram_search_var = df_twogram_link[df_twogram_link["search_string"].isin(twogram_list)]
    df_twogram_search_var.reset_index(drop=True, inplace=True)
    for j in range(len(df_twogram_search_var)):
        df_link_default_var = df_link_default
        try:
            twogram_time_diff_var = df_twogram_search_var.loc[j,"end_time"] - df_twogram_search_var.loc[j,"start_time"]
            if twogram_time_diff_var < 4:
                twogram_time_diff_var2 = 4
            else:
                twogram_time_diff_var2 = twogram_time_diff_var+1.0 
            df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + twogram_time_diff_var2
            df_result = pd.concat([df_result,df_twogram_search_var.iloc[[j,]]], axis=0)
            df_result = pd.concat([df_result,df_link_default_var], axis=0)
        except:
            pass

    # threegram result
    df_threegram_search_var = df_threegram_link[df_threegram_link["search_string"].isin(threegram_list)]
    df_threegram_search_var.reset_index(drop=True, inplace=True)
    for k in range(len(df_threegram_search_var)):
        df_link_default_var = df_link_default
        try:
            threegram_time_diff_var = df_threegram_search_var.loc[k,"end_time"] - df_threegram_search_var.loc[k,"start_time"]
            if threegram_time_diff_var < 4:
                threegram_time_diff_var2 = 4
            else:
                threegram_time_diff_var2 = threegram_time_diff_var+1.0 
            df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + threegram_time_diff_var2
            df_result = pd.concat([df_result,df_threegram_search_var.iloc[[k,]]], axis=0)
            df_result = pd.concat([df_result,df_link_default_var], axis=0)
        except:
            pass

    # sentence added
    df_sent_search_var = df_sentence_link[df_sentence_link["search_string"] == sent]
    df_sent_search_var.reset_index(drop=True, inplace=True)
    for l in range(len(df_sent_search_var)):
        df_link_default_var = df_link_default
        try:
            sent_time_diff_var = df_sent_search_var.loc[l,"end_time"] - df_sent_search_var.loc[l,"start_time"]
            if sent_time_diff_var < 4:
                sent_time_diff_var2 = 4
            else:
                sent_time_diff_var2 = sent_time_diff_var+1.0 
            df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + sent_time_diff_var2
            df_result = pd.concat([df_result,df_sent_search_var.iloc[[l,]]], axis=0)
            df_result = pd.concat([df_result,df_link_default_var], axis=0)
        except:
            pass

df_result.reset_index(drop=True, inplace=True)

# %%
##Rev 2
## used for multi search result and with word repeat that repeat 7 times same word
##twogram_link_list = df_twogram_link["search_string"].to_list()
##threegram_link_list = df_threegram_link["search_string"].to_list()
#df_result = pd.DataFrame()
#for sent in df_sentence_link["search_string"]:
#
#    # words
#    sent_words = word_tokenize(sent)
#
#    # word repeat (word search result should one result each words)
#    for sent_word in sent_words:
#        df_word_search_repeat1 = df_word_link[df_word_link["search_string"] == sent_word]
#        for word_repeat_num in range(7):
#            df_result = pd.concat([df_result,df_word_search_repeat1], axis=0)
#
#    # twogram
#    twogram_zip = ngrams(sent.split(), 2)
#    twogram_list = [" ".join(x) for x in twogram_zip]
#    #df_twogram_var = pd.DataFrame(data=twogram, columns=["twogram"])
#    
#    # threegram
#    threegram_zip = ngrams(sent.split(), 3)
#    threegram_list = [" ".join(y) for y in threegram_zip]
#    #df_threegram_var = pd.DataFrame(data=threegram, columns=["threegram"])
#
#    # begin sent repeat 
#    df_sent_search_begin = df_sentence_link[df_sentence_link["search_string"] == sent]
#    for sent_repeat_num in range(3):
#        df_result = pd.concat([df_result,df_sent_search_begin], axis=0)
#
#    # word result
#    for word in sent_words:        
#        df_word_search_var = df_word_link[df_word_link["search_string"] == word]
#        df_word_search_var.reset_index(drop=True, inplace=True)
#        for i in range(len(df_word_search_var)):
#            df_link_default_var = df_link_default
#            try:
#                word_time_diff_var = df_word_search_var.loc[i,"end_time"] - df_word_search_var.loc[i,"start_time"]
#                if word_time_diff_var < 4:
#                    word_time_diff_var2 = 4
#                else:
#                    word_time_diff_var2 = word_time_diff_var+1.0                                       
#                df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + word_time_diff_var2
#                df_result = pd.concat([df_result,df_word_search_var.iloc[[i,]]], axis=0)
#                df_result = pd.concat([df_result,df_link_default_var], axis=0)
#            except:
#                pass
#
#    # twogram result
#    df_twogram_search_var = df_twogram_link[df_twogram_link["search_string"].isin(twogram_list)]
#    df_twogram_search_var.reset_index(drop=True, inplace=True)
#    for j in range(len(df_twogram_search_var)):
#        df_link_default_var = df_link_default
#        try:
#            twogram_time_diff_var = df_twogram_search_var.loc[j,"end_time"] - df_twogram_search_var.loc[j,"start_time"]
#            if twogram_time_diff_var < 4:
#                twogram_time_diff_var2 = 4
#            else:
#                twogram_time_diff_var2 = twogram_time_diff_var+1.0 
#            df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + twogram_time_diff_var2
#            df_result = pd.concat([df_result,df_twogram_search_var.iloc[[j,]]], axis=0)
#            df_result = pd.concat([df_result,df_link_default_var], axis=0)
#        except:
#            pass
#
#    # threegram result
#    df_threegram_search_var = df_threegram_link[df_threegram_link["search_string"].isin(threegram_list)]
#    df_threegram_search_var.reset_index(drop=True, inplace=True)
#    for k in range(len(df_threegram_search_var)):
#        df_link_default_var = df_link_default
#        try:
#            threegram_time_diff_var = df_threegram_search_var.loc[k,"end_time"] - df_threegram_search_var.loc[k,"start_time"]
#            if threegram_time_diff_var < 4:
#                threegram_time_diff_var2 = 4
#            else:
#                threegram_time_diff_var2 = threegram_time_diff_var+1.0 
#            df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + threegram_time_diff_var2
#            df_result = pd.concat([df_result,df_threegram_search_var.iloc[[k,]]], axis=0)
#            df_result = pd.concat([df_result,df_link_default_var], axis=0)
#        except:
#            pass
#
#    # sentence added
#    df_sent_search_var = df_sentence_link[df_sentence_link["search_string"] == sent]
#    df_sent_search_var.reset_index(drop=True, inplace=True)
#    for l in range(len(df_sent_search_var)):
#        df_link_default_var = df_link_default
#        try:
#            sent_time_diff_var = df_sent_search_var.loc[l,"end_time"] - df_sent_search_var.loc[l,"start_time"]
#            if sent_time_diff_var < 4:
#                sent_time_diff_var2 = 4
#            else:
#                sent_time_diff_var2 = sent_time_diff_var+1.0 
#            df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + sent_time_diff_var2
#            df_result = pd.concat([df_result,df_sent_search_var.iloc[[l,]]], axis=0)
#            df_result = pd.concat([df_result,df_link_default_var], axis=0)
#        except:
#            pass
#
#df_result.reset_index(drop=True, inplace=True)

# %%
##Rev 1
## used for multi search result and without word repeat only sentence repeat
##twogram_link_list = df_twogram_link["search_string"].to_list()
##threegram_link_list = df_threegram_link["search_string"].to_list()
#df_result = pd.DataFrame()
#for sent in df_sentence_link["search_string"]:
#
#    # words
#    sent_words = word_tokenize(sent)
#
#    # twogram
#    twogram_zip = ngrams(sent.split(), 2)
#    twogram_list = [" ".join(x) for x in twogram_zip]
#    #df_twogram_var = pd.DataFrame(data=twogram, columns=["twogram"])
#    
#    # threegram
#    threegram_zip = ngrams(sent.split(), 3)
#    threegram_list = [" ".join(y) for y in threegram_zip]
#    #df_threegram_var = pd.DataFrame(data=threegram, columns=["threegram"])
#
#    # begin sent repeat 
#    df_sent_search_begin = df_sentence_link[df_sentence_link["search_string"] == sent]
#    for repeat_num in range(3):
#        df_result = pd.concat([df_result,df_sent_search_begin], axis=0)
#
#    # word result
#    for word in sent_words:        
#        df_word_search_var = df_word_link[df_word_link["search_string"] == word]
#        df_word_search_var.reset_index(drop=True, inplace=True)
#        for i in range(len(df_word_search_var)):
#            df_link_default_var = df_link_default
#            try:
#                word_time_diff_var = df_word_search_var.loc[i,"end_time"] - df_word_search_var.loc[i,"start_time"]
#                if word_time_diff_var < 4:
#                    word_time_diff_var2 = 4
#                else:
#                    word_time_diff_var2 = word_time_diff_var+1.0                                       
#                df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + word_time_diff_var2
#                df_result = pd.concat([df_result,df_word_search_var.iloc[[i,]]], axis=0)
#                df_result = pd.concat([df_result,df_link_default_var], axis=0)
#            except:
#                pass
#
#    # twogram result
#    df_twogram_search_var = df_twogram_link[df_twogram_link["search_string"].isin(twogram_list)]
#    df_twogram_search_var.reset_index(drop=True, inplace=True)
#    for j in range(len(df_twogram_search_var)):
#        df_link_default_var = df_link_default
#        try:
#            twogram_time_diff_var = df_twogram_search_var.loc[j,"end_time"] - df_twogram_search_var.loc[j,"start_time"]
#            if twogram_time_diff_var < 4:
#                twogram_time_diff_var2 = 4
#            else:
#                twogram_time_diff_var2 = twogram_time_diff_var+1.0 
#            df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + twogram_time_diff_var2
#            df_result = pd.concat([df_result,df_twogram_search_var.iloc[[j,]]], axis=0)
#            df_result = pd.concat([df_result,df_link_default_var], axis=0)
#        except:
#            pass
#
#    # threegram result
#    df_threegram_search_var = df_threegram_link[df_threegram_link["search_string"].isin(threegram_list)]
#    df_threegram_search_var.reset_index(drop=True, inplace=True)
#    for k in range(len(df_threegram_search_var)):
#        df_link_default_var = df_link_default
#        try:
#            threegram_time_diff_var = df_threegram_search_var.loc[k,"end_time"] - df_threegram_search_var.loc[k,"start_time"]
#            if threegram_time_diff_var < 4:
#                threegram_time_diff_var2 = 4
#            else:
#                threegram_time_diff_var2 = threegram_time_diff_var+1.0 
#            df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + threegram_time_diff_var2
#            df_result = pd.concat([df_result,df_threegram_search_var.iloc[[k,]]], axis=0)
#            df_result = pd.concat([df_result,df_link_default_var], axis=0)
#        except:
#            pass
#
#    # sentence added
#    df_sent_search_var = df_sentence_link[df_sentence_link["search_string"] == sent]
#    df_sent_search_var.reset_index(drop=True, inplace=True)
#    for l in range(len(df_sent_search_var)):
#        df_link_default_var = df_link_default
#        try:
#            sent_time_diff_var = df_sent_search_var.loc[l,"end_time"] - df_sent_search_var.loc[l,"start_time"]
#            if sent_time_diff_var < 4:
#                sent_time_diff_var2 = 4
#            else:
#                sent_time_diff_var2 = sent_time_diff_var+1.0 
#            df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + sent_time_diff_var2
#            df_result = pd.concat([df_result,df_sent_search_var.iloc[[l,]]], axis=0)
#            df_result = pd.concat([df_result,df_link_default_var], axis=0)
#        except:
#            pass
#
#df_result.reset_index(drop=True, inplace=True)

# %%
df_result
# Out:
#                           search_string  start_time  end_time  \
# 0                                   van         376       377
# 1                                   van         376       377
# 2                                   van         376       377
# 3                                   van          60        62
# 4                                   van         612       614
# ...                                 ...         ...       ...
# 1279                             repeat           5         9
# 1280                                 te          59        60
# 1281                             repeat           5         9
# 1282  die ons toch altijd weer weten te         639       641
# 1283                             repeat           5         9
#
#                                                sentence     video_id  \
# 0     en merk je dat je weer kunt genieten van je leven  Imj3JLDlIZE
# 1     en merk je dat je weer kunt genieten van je leven  Imj3JLDlIZE
# 2     en merk je dat je weer kunt genieten van je leven  Imj3JLDlIZE
# 3        om de kwaliteit van je producten te garanderen  mgH9ulHIsd8
# 4     ik binnen een halfjaar een woning had terwijl ...  miouy02UT58
# ...                                                 ...          ...
# 1279                                       repeat_again  Q-8I-uMUMYA
# 1280  om de berg weer af te gaan nu is het alleen ja...  SicFPD83ToU
# 1281                                       repeat_again  Q-8I-uMUMYA
# 1282        die ons toch altijd weer weten te verrassen  aWOJx8liOyU
# 1283                                       repeat_again  Q-8I-uMUMYA
#
#                                               video_url
# 0     https://www.youtube.com/watch?v=Imj3JLDlIZE&t=...
# 1     https://www.youtube.com/watch?v=Imj3JLDlIZE&t=...
# 2     https://www.youtube.com/watch?v=Imj3JLDlIZE&t=...
# 3     https://www.youtube.com/watch?v=mgH9ulHIsd8&t=60s
# 4     https://www.youtube.com/watch?v=miouy02UT58&t=...
# ...                                                 ...
# 1279   https://www.youtube.com/watch?v=Q-8I-uMUMYA&t=0s
# 1280  https://www.youtube.com/watch?v=SicFPD83ToU&t=59s
# 1281   https://www.youtube.com/watch?v=Q-8I-uMUMYA&t=0s
# 1282  https://www.youtube.com/watch?v=aWOJx8liOyU&t=...
# 1283   https://www.youtube.com/watch?v=Q-8I-uMUMYA&t=0s
#
# [1284 rows x 6 columns]

# %%
df_result[df_result["search_string"] == "repeat"]["end_time"].max()
# Out:
# 9

# %%
sample_num = df_result[df_result["search_string"] == "repeat"]["end_time"].count()
sample_num
# Out:
# 155

# %%
((df_result[df_result["search_string"] == "repeat"]["end_time"].sum()*2)-sample_num)/60
# Out:
# 43.916666666666664

# %%
df_result.to_excel(f"{lang_folder.capitalize()}_{word_end}_Word_Talk_Time_All.xlsx", index=False)

# %%
# used for divide part
from math import ceil
divide_num = 12
part_sample_num = ceil(len(df_result)/12)
sample_num_start = 0
sample_num_end = part_sample_num
for i in range(divide_num):
    df_var = df_result.iloc[sample_num_start:sample_num_end,]
    
    id_list = []
    start_list = []
    end_list = []
    for id, start, end in zip(df_var["video_id"].to_list(),df_var["start_time"].to_list(),df_var["end_time"].to_list()):
        id_list.append(str(id))
        start_list.append(str(start))
        end_list.append(str(end))

    id_join = ",".join(id_list)
    start_join = ",".join(start_list)
    end_join = ",".join(end_list)

    df_result_for_embedded = pd.DataFrame(data=[[id_join,start_join,end_join]], columns=["id","start_time","end_time"])
    df_result_for_embedded.to_excel(f"{lang_folder.capitalize()}_{word_end}_Word_Talk_Time1_Join_Sample{i+1}.xlsx", index=False)
    #df_var.to_excel(f"Turkish_200_Word_Talk_Time1_Sample{i+1}.xlsx", index=False)
    sample_num_start += part_sample_num
    sample_num_end += part_sample_num

# %% [markdown]
# #### Copy Move And Delete

# %%
output_file = glob.glob(f"{lang_folder.capitalize()}_*_Word_Talk_Time*.xlsx")
output_file

# %%
for y in output_file:
    source = y # source directory
    destination = path
    shutil.copy2(source, destination)

# %%
for z in output_file:
    try:
        os.remove(z)
    except:
        pass

# %%
# used for one search result
df_result = pd.DataFrame()
for sent in df_sentence_link["search_string"]:
    sent_words = word_tokenize(sent)
    for word in sent_words:
        df_link_default_var = df_link_default
        df_var = df_word_link[df_word_link["search_string"] == word]
        df_var.reset_index(drop=True, inplace=True)
        try:
            var_time_diff = (df_var.loc[0,"end_time"] - df_var.loc[0,"start_time"])
            df_link_default_var.loc[0,"end_time"] = df_link_default_var.loc[0,"start_time"] + var_time_diff+1.0
            df_result = pd.concat([df_result,df_var], axis=0)
            df_result = pd.concat([df_result,df_link_default_var], axis=0)
        except:
            pass
df_result.reset_index(drop=True, inplace=True)
df_result

# %%
df_result_select = df_result.head(300)
df_result_select
# Out:
#     search_string  start_time  end_time  \
# 0             van         376       377
# 1             van         376       377
# 2             van         376       377
# 3             van          60        62
# 4             van         612       614
# ..            ...         ...       ...
# 295          veel        1162      1163
# 296          veel        5099      5100
# 297          veel         286       288
# 298        mensen         108       110
# 299        mensen         108       110
#
#                                               sentence     video_id  \
# 0    en merk je dat je weer kunt genieten van je leven  Imj3JLDlIZE
# 1    en merk je dat je weer kunt genieten van je leven  Imj3JLDlIZE
# 2    en merk je dat je weer kunt genieten van je leven  Imj3JLDlIZE
# 3       om de kwaliteit van je producten te garanderen  mgH9ulHIsd8
# 4    ik binnen een halfjaar een woning had terwijl ...  miouy02UT58
# ..                                                 ...          ...
# 295  dus je krijgt eigenlijk heel veel informatie d...  pruDyt__jYs
# 296  meer kneedbaar veel meer toegankelijk en jij k...  EZMgSCfbiGs
# 297  ja heel veel eigenlijk te veel vertel eens wat...  tfzC9AvItfg
# 298  mij zeg voor mensen in een rolstoel voor ander...  1KaoCu5SII8
# 299  mij zeg voor mensen in een rolstoel voor ander...  1KaoCu5SII8
#
#                                              video_url
# 0    https://www.youtube.com/watch?v=Imj3JLDlIZE&t=...
# 1    https://www.youtube.com/watch?v=Imj3JLDlIZE&t=...
# 2    https://www.youtube.com/watch?v=Imj3JLDlIZE&t=...
# 3    https://www.youtube.com/watch?v=mgH9ulHIsd8&t=60s
# 4    https://www.youtube.com/watch?v=miouy02UT58&t=...
# ..                                                 ...
# 295  https://www.youtube.com/watch?v=pruDyt__jYs&t=...
# 296  https://www.youtube.com/watch?v=EZMgSCfbiGs&t=...
# 297  https://www.youtube.com/watch?v=tfzC9AvItfg&t=...
# 298  https://www.youtube.com/watch?v=1KaoCu5SII8&t=...
# 299  https://www.youtube.com/watch?v=1KaoCu5SII8&t=...
#
# [300 rows x 6 columns]

# %%
df_result_select.to_excel("Dutch_200_Word_Talk_Time1_Test.xlsx", index=False)

# %%
id_list = []
start_list = []
end_list = []
for id, start, end in zip(df_result_select["video_id"].to_list(),df_result_select["start_time"].to_list(),df_result_select["end_time"].to_list()):
    id_list.append(str(id))
    start_list.append(str(start))
    end_list.append(str(end))

id_join = ",".join(id_list)
start_join = ",".join(start_list)
end_join = ",".join(end_list)

df_result_for_embedded = pd.DataFrame(data=[[id_join,start_join,end_join]], columns=["id","start_time","end_time"])
df_result_for_embedded
# Out:
#                                                   id  \
# 0  Imj3JLDlIZE,Imj3JLDlIZE,Imj3JLDlIZE,mgH9ulHIsd...
#
#                                           start_time  \
# 0  376,376,376,60,612,296,9634,2970,2970,2970,813...
#
#                                             end_time
# 0  377,377,377,62,614,297,9635,2972,2972,2972,815...

# %%
df_result_for_embedded.to_excel("Dutch_200_Word_Talk_Time1_Join_Test.xlsx", index=False)

# %% [markdown]
# #### Temp

# %%
def df_col_value_join_comma(df, df_columns_list):
    '''
    df_col_value_join_comma(df_test, ["video_id","start_time","end_time"])\n
    function used for selected column value join with comma in one row
    '''
    column_value_list = []
    for column in df_columns_list:
        list_var = df[f"{column}"].to_list()
        list_var_string = [str(x) for x in list_var] 
        list_var_join = ",".join(list_var_string)
        column_value_list.append(list_var_join)

    df_result = pd.DataFrame([[column_value_list[0],column_value_list[1],column_value_list[2]]], columns=df_columns_list)

    return df_result

# %%
df_test = pd.read_excel("Dutch_200_Word_Talk_Time1_Test.xlsx")
df_test
# Out:
#             search_string  start_time  end_time  \
# 0                      en        2592      2593
# 1                      en        2592      2593
# 2                      en        2592      2593
# 3                      en        2592      2593
# 4                      en         818       820
# ..                    ...         ...       ...
# 295  hoe dan ook zo in de         557       559
# 296  hoe dan ook zo in de         557       559
# 297                   hoe        1291      1292
# 298                repeat           5         9
# 299                   dan        1770      1771
#
#                                               sentence     video_id  \
# 0    jaar en niet heel realistisch zijn geworden ov...  A0Fij7grUvs
# 1    jaar en niet heel realistisch zijn geworden ov...  A0Fij7grUvs
# 2    jaar en niet heel realistisch zijn geworden ov...  A0Fij7grUvs
# 3    jaar en niet heel realistisch zijn geworden ov...  A0Fij7grUvs
# 4    cultureel echt serieus meedeed en je ziet ook ...  AaVi4igmpYQ
# ..                                                 ...          ...
# 295                               hoe dan ook zo in de  BoaYsdPtJYA
# 296                               hoe dan ook zo in de  BoaYsdPtJYA
# 297  we nauw samenwerken met bedrijven die vanuit d...  xKNDkrAQ3iM
# 298                                       repeat_again  Q-8I-uMUMYA
# 299  de informatie over mensen en dan heb ik het ov...  gK0_yZDGIgw
#
#                                              video_url
# 0    https://www.youtube.com/watch?v=A0Fij7grUvs&t=...
# 1    https://www.youtube.com/watch?v=A0Fij7grUvs&t=...
# 2    https://www.youtube.com/watch?v=A0Fij7grUvs&t=...
# 3    https://www.youtube.com/watch?v=A0Fij7grUvs&t=...
# 4    https://www.youtube.com/watch?v=AaVi4igmpYQ&t=...
# ..                                                 ...
# 295  https://www.youtube.com/watch?v=BoaYsdPtJYA&t=...
# 296  https://www.youtube.com/watch?v=BoaYsdPtJYA&t=...
# 297  https://www.youtube.com/watch?v=xKNDkrAQ3iM&t=...
# 298   https://www.youtube.com/watch?v=Q-8I-uMUMYA&t=0s
# 299  https://www.youtube.com/watch?v=gK0_yZDGIgw&t=...
#
# [300 rows x 6 columns]

# %%
df_test_join = df_col_value_join_comma(df_test, ["video_id","start_time","end_time"])
df_test_join
# Out:
#                                             video_id  \
# 0  A0Fij7grUvs,A0Fij7grUvs,A0Fij7grUvs,A0Fij7grUv...
#
#                                           start_time  \
# 0  2592,2592,2592,2592,818,818,818,1998,1998,1998...
#
#                                             end_time
# 0  2593,2593,2593,2593,820,820,820,1999,1999,1999...

# %%
df_test_join.to_excel("Dutch_200_Word_Talk_Time1_Join_Test.xlsx", index=False)

# %%
# used for divide part will test
from math import ceil
divide_num = 12
part_sample_num = ceil(len(df_result)/12)
sample_num_start = 0
sample_num_end = part_sample_num
for i in range(divide_num):
    df_var = df_result.iloc[sample_num_start:sample_num_end,]
    
    df_result_for_embedded = df_col_value_join_comma(df_var, ["video_id","start_time","end_time"])
    df_result_for_embedded.to_excel(f"{lang_folder.capitalize()}_{word_end}_Word_Talk_Time1_Join_Sample{i+1}.xlsx", index=False)
    #df_var.to_excel(f"Turkish_200_Word_Talk_Time1_Sample{i+1}.xlsx", index=False)
    sample_num_start += part_sample_num
    sample_num_end += part_sample_num
