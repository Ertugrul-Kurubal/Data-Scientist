# %% [markdown]
# ### Word In DataFrame

# %%
import pandas as pd
import numpy as np

# %%
df_youtube_sentence = pd.read_csv("YoutubeDL_Sentence_DF.csv")
df_youtube_sentence
# Out:
#        start_time      end_time  \
# 0    00:00:01.056  00:00:04.244
# 1    00:00:04.534  00:00:06.420
# 2    00:00:06.808  00:00:08.780
# 3    00:00:10.388  00:00:12.388
# 4    00:00:17.600  00:00:18.682
# ..            ...           ...
# 468  00:03:54.800  00:03:59.300
# 469  00:03:59.300  00:04:01.940
# 470  00:04:02.840  00:04:07.560
# 471  00:04:07.560  00:04:08.960
# 472  00:04:10.320  00:04:22.780
#
#                                              sentence     video_id
# 0    bu  videoda  darıca  ve  adalar  arasında  dalış  WdX1_wNUj0E
# 1                         küçük  balıkların  değişimi  WdX1_wNUj0E
# 2                    ilk  defa  göreceğiniz  detaylar  WdX1_wNUj0E
# 3                      ve  balık  avı  izleyeceksiniz  WdX1_wNUj0E
# 4                                              darıca  WdX1_wNUj0E
# ..                                                ...          ...
# 468         hani  her  şeyindim, bensiz  sen  yoktun.  c1QvY3X64qM
# 469                                 ayrılamazdık  ya.  c1QvY3X64qM
# 470                     gül  dudaklım, sihir  gözlüm.  c1QvY3X64qM
# 471                                              dön.  c1QvY3X64qM
# 472                           bugünüm  sensiz  geçti.  c1QvY3X64qM
#
# [473 rows x 4 columns]

# %% [markdown]
# #### Word

# %%
#df_youtube_sentence.sentence.filter()

# %%
df_youtube_sentence[df_youtube_sentence.sentence.str.contains("geç", na=True)].head(5) # .sample(5, random_state=1) # replace=True
# Out:
#        start_time      end_time  \
# 27   00:03:15.640  00:03:18.320
# 53   00:07:09.449  00:07:13.562
# 83   00:13:30.709  00:13:32.903
# 91   00:14:21.197  00:14:24.785
# 289  00:11:01.910  00:11:03.910
#
#                                               sentence     video_id
# 27               farklılık  birçok  tür  için  geçerli  WdX1_wNUj0E
# 53   tekrar  saklanarak  bekliyorum  bu  kez  kefal...  WdX1_wNUj0E
# 83                 diğer  yengeçler  ısırmaya  çalışır  WdX1_wNUj0E
# 91   pendik' te  ağladığımız  balıklardan  pişirmek...  WdX1_wNUj0E
# 289                   hadi  geçmiş  olsun, güle  güle.  4CxHodWJCAc

# %%
df_youtube_sentence[df_youtube_sentence.sentence.str.contains(r'(?:\s|^)geçmiş(?:\s|$)', na=True)].head(5) # Exact match
# Out:
#        start_time      end_time  \
# 289  00:11:01.910  00:11:03.910
# 423  00:09:32.389  00:09:37.304
# 433  00:11:04.126  00:11:08.533
#
#                                               sentence     video_id
# 289                   hadi  geçmiş  olsun, güle  güle.  4CxHodWJCAc
# 423  evet  bu  harika  muayene  bitti  sona  erdi. ...  gOq59m1pUi4
# 433   evet, çok  geçmiş  olsun. çok  teşekkür  ederiz.  gOq59m1pUi4

# %%
df_youtube_sentence[df_youtube_sentence.sentence.str.contains(fr"(?:\s|^){'geçmiş'}(?:\s|$)", na=True)].head(5) # f string
# Out:
#        start_time      end_time  \
# 289  00:11:01.910  00:11:03.910
# 423  00:09:32.389  00:09:37.304
# 433  00:11:04.126  00:11:08.533
#
#                                               sentence     video_id
# 289                   hadi  geçmiş  olsun, güle  güle.  4CxHodWJCAc
# 423  evet  bu  harika  muayene  bitti  sona  erdi. ...  gOq59m1pUi4
# 433   evet, çok  geçmiş  olsun. çok  teşekkür  ederiz.  gOq59m1pUi4

# %%
word_list = ['geçmiş','yengeçler','küçük','ahmet','darıca','yüzgeçleri', 'güle', 'göreceğiniz', 'bensiz']

# %%
result_df = pd.DataFrame()
for i in word_list:
    word_in_video = df_youtube_sentence[df_youtube_sentence.sentence.str.contains(fr"(?:\s|^){i}(?:\s|$)", na=True)].head(10)
    word_in_video.insert(0,"word",i)
    result_df = pd.concat([result_df,word_in_video], axis=0)

# %%
# sample_df.drop_duplicates(subset = ['word'], keep = 'first', inplace = True)

# %%
result_df
# Out:
#             word    start_time      end_time  \
# 289       geçmiş  00:11:01.910  00:11:03.910
# 423       geçmiş  00:09:32.389  00:09:37.304
# 433       geçmiş  00:11:04.126  00:11:08.533
# 83     yengeçler  00:13:30.709  00:13:32.903
# 1          küçük  00:00:04.534  00:00:06.420
# 18         küçük  00:02:00.945  00:02:01.963
# 24         küçük  00:02:35.453  00:02:38.697
# 26         küçük  00:03:02.508  00:03:08.009
# 41         küçük  00:04:25.755  00:04:28.780
# 66         küçük  00:10:09.623  00:10:13.558
# 77         küçük  00:12:13.196  00:12:16.772
# 418        küçük  00:08:58.196  00:09:06.169
# 0         darıca  00:00:01.056  00:00:04.244
# 4         darıca  00:00:17.600  00:00:18.682
# 289         güle  00:11:01.910  00:11:03.910
# 291         güle  00:11:06.503  00:11:08.065
# 306         güle  00:11:53.433  00:11:54.943
# 2    göreceğiniz  00:00:06.808  00:00:08.780
# 438       bensiz  00:01:13.200  00:01:17.620
# 454       bensiz  00:02:56.180  00:03:00.560
# 468       bensiz  00:03:54.800  00:03:59.300
#
#                                               sentence     video_id
# 289                   hadi  geçmiş  olsun, güle  güle.  4CxHodWJCAc
# 423  evet  bu  harika  muayene  bitti  sona  erdi. ...  gOq59m1pUi4
# 433   evet, çok  geçmiş  olsun. çok  teşekkür  ederiz.  gOq59m1pUi4
# 83                 diğer  yengeçler  ısırmaya  çalışır  WdX1_wNUj0E
# 1                          küçük  balıkların  değişimi  WdX1_wNUj0E
# 18                                        küçük  pinna  WdX1_wNUj0E
# 24            bu  küçük  iki  balıkta  eşkina  yavrusu  WdX1_wNUj0E
# 26   eşkiyaların  daha  küçük  hali  ve  büyükleri ...  WdX1_wNUj0E
# 41       küçük  balık  popülasyonu  tekrar  dengelendi  WdX1_wNUj0E
# 66   kayaların  arasında  küçük  sargozlar  ve  kik...  WdX1_wNUj0E
# 77               yüzeyde  papaz  ve  küçük  karagözler  WdX1_wNUj0E
# 418  kuduz  aşısı  yasal  zorunluluk  onu  yapmak  ...  gOq59m1pUi4
# 0     bu  videoda  darıca  ve  adalar  arasında  dalış  WdX1_wNUj0E
# 4                                               darıca  WdX1_wNUj0E
# 289                   hadi  geçmiş  olsun, güle  güle.  4CxHodWJCAc
# 291     güle  güle  anneciğim. darası  alınmış  mıydı?  4CxHodWJCAc
# 306                                 haydi  güle  güle.  4CxHodWJCAc
# 2                     ilk  defa  göreceğiniz  detaylar  WdX1_wNUj0E
# 438          hani  her  şeyindim, bensiz  sen  yoktun.  c1QvY3X64qM
# 454          hani  her  şeyindim, bensiz  sen  yoktun.  c1QvY3X64qM
# 468          hani  her  şeyindim, bensiz  sen  yoktun.  c1QvY3X64qM

# %%
pd.pivot_table(result_df, index=["word"]) # ???
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/apply.py:507: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
# Empty DataFrame
# Columns: []
# Index: [bensiz, darıca, geçmiş, göreceğiniz, güle, küçük, yengeçler]

# %% [markdown]
# #### Sentence

# %%
df_youtube_sentence[df_youtube_sentence.sentence.str.contains("metrelik  kumluk", na=True)].head(5)
# Out:
#      start_time      end_time  \
# 6  00:00:27.887  00:00:30.714
#
#                                             sentence     video_id
# 6  beş  metrelik  kumluk  bir  alana  dalış  yapı...  WdX1_wNUj0E

# %%
sent_list = ["metrelik  kumluk", "hadi  geçmiş  olsun", "bu  günüm  sensiz  geçti"]

# %%
result_df = pd.DataFrame()
for i in word_list:
    word_in_video = df_youtube_sentence[df_youtube_sentence.sentence.str.contains(f"{i}", na=True)].head(10)
    word_in_video.insert(0,"word",i)
    result_df = pd.concat([result_df,word_in_video], axis=0)

# %%
ngram_list = ['diğer yengeçler', 'bir bu', 'ne dedin', 'için mi', 'o neden', 'ben de', 'çok ama', 'seni seviyorum','videoda darıca', 'hani her']

# %%
sent_list = df_youtube_sentence.sentence.tolist()

# %%
sent_list
# Out:
# ['bu  videoda  darıca  ve  adalar  arasında  dalış',
#  'küçük  balıkların  değişimi',
#  'ilk  defa  göreceğiniz  detaylar',
#  've  balık  avı  izleyeceksiniz',
#  'darıca',
#  "i̇stanbul' a  yakın  kocaeli' nin  bir  ilçesi",
#  'beş  metrelik  kumluk  bir  alana  dalış  yapıyorum',
#  'biraz  ilerlediğinde  uzun  ağzıyla  kumu  eşeleyen  büyük  bir  vatoz',
#  "marmara' da  pek  rastlanılmayan  kartal  vatozu",
#  'diğer  adıyla  fulya  balığı',
#  'uzun  kuyruk  ve  ağız  yapısı  ile  kolayca  ayırt  edilebilir',
#  "bu  tür  daha  çok  okyanuslarda  ve  akdeniz' de  görülür",
#  "marmara' ya  kadar  gelen  bu  tür  insanlar  için  zararsızdır",
#  'deniz  hıyarı',
#  "bu  ise  marmara' da  gördüğümüz  yıldızlardan  farklı",
#  'astropecten  türü  bir  denizyıldızı',
#  'dev  midiye  planın  dibindeki',
#  'genelde  gördüğümüz  denizyıldızı  türü  asterias  rubens',
#  'küçük  pinna',
#  'anemon',
#  'kestane  ve  midyeler',
#  "marmara' da ",
#  'burada  olduğu  gibi  güneş  gören  bazı  bölgelerde  de',
#  'deniz  çayırları  ile  karşılaşıyorum',
#  'bu  küçük  iki  balıkta  eşkina  yavrusu',
#  'boyutlarda  olanlar  genellikle  deniz  marulların  arasında  yaşıyor',
#  'eşkiyaların  daha  küçük  hali  ve  büyükleri  birbirinden  çok  farklı',
#  'farklılık  birçok  tür  için  geçerli',
#  'bu  yeşil  balıkta  kikla  yavrusu',
#  'yazılı  hani  yavrusu',
#  'saklandığını  sanan  lapin',
#  'gemilerin  balast  suyu  ile  sularımıza  gelen',
#  'hamsi  kırıklığına  sebep  olan  mnemiopsis  leidyi',
#  'diğer  adıyla  deniz  cevizi',
#  'yine  aynı  yollardan  sonradan  gelen',
#  'beroe  ovata  denizanası',
#  'deniz  cevizlerini  yutarak  hapsediyor',
#  'ardından  parçalayarak  sindiriyor',
#  'denizanalarının  beyni  ve  gözleri  yoktur',
#  "fakat  beroe  ovatalar  mnemiopsis' leri  bularak  dengeyi  sağlıyor",
#  'bu  ikili  arasındaki  besin  zinciri  sayesinde',
#  'küçük  balık  popülasyonu  tekrar  dengelendi',
#  'devam  eden  boru  hattını  destekleyen  bu  betonların  aralarında',
#  "kikla' lar  var",
#  'ilerledikçe  derinlik  arttığı  için',
#  "yukarı  çıkacağım  anda  iri  bir  kikla' ya  atış  yapıyorum",
#  "küçüğü  tamamen  yeşil  olan  kikla' nın  avlanabilir  boydaki  hali",
#  'pendik',
#  'aşağı  indiğimde ',
#  'sessizce  yosunların  arasında  inip  gizlenmek',
#  'balığı  ürkütmeden  atış  fırsatı  veriyor',
#  'kiloya  yakın  baltabaş  karagöz',
#  "diplodus  sargus  akdeniz  bölgesi' nde  sargoz  olarak  da  bilinir",
#  'tekrar  saklanarak  bekliyorum  bu  kez  kefaller  geçiyor',
#  'daha  derine  inip  çağrı  yapıyorum',
#  'gelen  mırmır  sürüsü',
#  'agaşonda  ses  çıkartarak  balıkları  çekmeye  çalışıyorum',
#  'bir  dakika  sonra  balık  göremeyince  ilerliyorum',
#  'yükseleceğim  anda  karagöz  sürüsü  geliyor',
#  'ıska',
#  'tekrar  beklerken  bu  kez  soldan  geldiler',
#  've  isabetli  atış',
#  'iri  bir  sivriburun  karagöz',
#  "adalar  bölgesinde  büyük  ada' nın  güneyindeki",
#  "tavşan  adası' na  dalış  yapıyoruz",
#  'adanın  güney  batısı ',
#  'kayaların  arasında  küçük  sargozlar  ve  kiklalar  var',
#  'iri  bir  kikla',
#  'en  çok  karşılaşılan  vatoz  türlerinden  dikenli  vatoz',
#  'kayaların  üzerinde  büyük  deniz  süngeri',
#  'birçok  boyutta  ve  renkte  süngerler',
#  'dişi  karabaş  balığı',
#  'burada  da  aynı  şekilde  deniz  cevizi  ve  beroe  ovatalar',
#  'yüze  yakın  bolca  bulunuyor',
#  'parıldayan  bu  canlılar  muazzam  dengenin  birer  ürünü',
#  "bu  beroe  ovata  ikinci  minemiopsis' i  yiyor",
#  'sindirimi  tamamlayan  uç  kısımdan  dışkılıyor',
#  'yüzeyde  papaz  ve  küçük  karagözler',
#  'çok  sayıda  papaz  balığı  var',
#  'buradaki  bir  oyukta  eğlenmeyi  de  ihmal  etmiyoruz',
#  'adanın  kuzey  tarafı  ise ',
#  'neandros  ve  balıkçı  adası  olarak  da  bilinen  bu  adada',
#  'bolca  deniz  örümceği  var',
#  'diğer  yengeçler  ısırmaya  çalışır',
#  'fakat  bu  tür  çok  çekingendir',
#  'bir  üzerinde  bitki  oluşmuş  bu  örümcek',
#  've  benzeri  canlıların  korunabilmesi  için',
#  'bu  ada  nisan ',
#  'cumhurbaşkanlığı  kararı  ile  kesin  korunacak  alan  ilan  edilmiştir',
#  'kuzeye  doğru  ilerlediğimizde  zeminde  sadece  midye  ve  kestaneler  var',
#  "buradan  büyükada' ya",
#  "pendik' te  ağladığımız  balıklardan  pişirmek  için  geçiyoruz",
#  'burada  bırakılan  çöplerin  dışında  temiz  ve  huzurlu  bir  yer',
#  'videoyu  faydalı  bulduysanız  beğenmeyi',
#  'sonraki  videolar  için  abone  olmayı  unutmayın.',
#  'dam  başında  sarı  çiçek  oy  oy',
#  'dam  başında  sarı  çiçek  oy  oy',
#  "burdan  kalkıp  ürgüp' e  göçek nenni  de  feride'",
#  "burdan  kalkıp  ürgüp' e  göçek nenni  de  feride'",
#  "ürgüp' e  vardığımız  gece  oy  oy",
#  "ürgüp' e  vardığımız  gece  oy  oy",
#  "hak  yoluna  kurban  kesek nenni  de  feride'",
#  "hak  yoluna  kurban  kesek nenni  de  feride'",
#  "hak  yoluna  kurban  kesek nenni  de  feride'",
#  "hak  yoluna  kurban  kesek nenni  de  feride'",
#  'gidiyorum  işte  gör  oy  oy',
#  'gidiyorum  işte  gör  oy  oy',
#  "hayalde  gör  düşte  gör nenni  de  feride'",
#  "hayalde  gör  düşte  gör nenni  de  feride'",
#  'gıymatımı  bilmedin  oy  oy',
#  'gıymatımı  bilmedin  oy  oy',
#  "bir  kötüye  düş  de  gör nenni  de  feride'",
#  "bir  kötüye  düş  de  gör nenni  de  feride'",
#  "bir  kötüye  düş  de  gör nenni  de  feride'",
#  "bir  kötüye  düş  de  gör nenni  de  feride'",
#  'percussion  emprovize',
#  "nenni  de  feride' islık.",
#  'hab  v  sbv  vsiv',
#  'buranın  ışığı  niye  yanmıyor?',
#  'tırtıl  gelmiş!',
#  'yok  şey, darası  alınmadı.',
#  'tırtıl  feci  hırçın  bir  çocuk.',
#  "aşırı  feci, hırçın, deli  çocuk, badboy' falan  yazılmış  buraya ",
#  'daha  önceden  de  zaten  videosunu  çekmiştik. şurada, yukarlarda  bir  yerde  vardır.',
#  'sana  demedim, niye  baktın  öyle?',
#  'herkes  patır  patır  geliyor. merhaba!',
#  'selam.',
#  'size  de  selam.',
#  'selam" demeyi unuttuğum  diğer  videolar  için;',
#  'selam, selam, selam, selam, selam  olsun!',
#  "ben  o  zaman  bi' lavaboya  gideyim.",
#  'yine  dejavu  oldum ',
#  'i̇şeyecekse  tırtıl  işesin. yapar  birazdan, hiç  şüphemiz  yok ',
#  'tırtıl, anneciğim. nasılsın?',
#  'özledin  mi  bizi?',
#  'biraz  keyifsiz  yine.',
#  'tırtıl  geldiğinde  birinci  karmasını mı  yapmıştık? nasıl  olmuştu?',
#  'evet, tırnak  falan bir  şey  demediler  mi?',
#  'selam.',
#  'çekiyorum  aşısını. lütfen.',
#  'tırnakları  uzamış  mıydı  ki?',
#  'merhaba!',
#  'anneciğim ',
#  "box' ı  büyümüş  bunun.",
#  'kendi  de  küçülmüş  olabilir.',
#  'hayır  box  büyümüş, evet vura  vura  büyültmüş  olabilir ',
#  'sen  mi  tutacaksın? hayır  hayır!',
#  'neyi  temizliyorsun  o  zaman?',
#  'tırnak  da  varmış  ya.',
#  'tırnak  da  mı  varmış? tamam, hazırsak  başlayalım.',
#  'tırnak  mı? ne?',
#  "ben  box' ı  alırım.",
#  'gerisi  sizin ',
#  'yerde  yapalım. daha nereye  indiriyorsun?',
#  'yer  sofrası  gibi!',
#  'arkadaşım  bir  saniye!',
#  'çok  iyi  ya!',
#  'çok  sağlam  hakikaten.',
#  'hayır  bir  de işin  ters  tarafı  şu;',
#  'ben  videoları  izlemeden  geliyordum, az  önce  videosunu  izleyip  geldim.',
#  'kaldır, gözüm  korktu  şu  an ',
#  'daha  önceden  izleyip.',
#  'fragmanını  izlemişsin.',
#  'g* te  bak  ya!',
#  'selam!',
#  'hıırğğh!',
#  'tırtıl!',
#  'tırtıl!',
#  'ya  cennetten  kovulan kedilerin  hepsi.',
#  'şimdi  de  linç  yerim, burayı  şey  yapma ',
#  'ama  gerçekten  bu sinir, bu  öfke  ne  böyle?',
#  'sakin  olur  musun?',
#  'sakin!',
#  'bir  şey  yok  ki!',
#  "hayır  o  g* t  nasıl kalkıyor, o  da  bi' garip  yani.",
#  'g* tünü  kaldırıp, bana  yapışıyor!',
#  'çalışmış  da  gelmiş.',
#  'uzun  zamandır  ilk  defa korkarak  el  atıyorum ',
#  'vallahi  ağırlaşmış da! yemin  ediyorum!',
#  'yalnız  çok  uzağa ulaşabilir, yakınlaşmayın  fazla.',
#  'bir  dakika.',
#  'yok  bir  şey, yok!',
#  'hayır.',
#  'o  benim  göbeğim.',
#  "beni  değil, gözde' yi kesiyor  galiba.",
#  'ne  oldu?',
#  'bileğimi  ısırdı.',
#  'pozitif  enerji yolluyoruz  evrene.',
#  'ben  şuradan  izleyeyim  ya  sizi.',
#  'oğlum  bilek  ısırmak  nedir? yemin  ediyorum  feci  ağrıdı  bileğim!',
#  'şu  an  çok  minnoş  duruyor  ama.',
#  "bi' kedi  bileği nasıl  ısrır  lan?",
#  'o  kadar  ağzı  açıldı  mı  yani?',
#  "şu  aşıyı  ben  bi' alayım  şuradan.",
#  'haydi.',
#  'arka  ayaklarını  tutayım  mı?',
#  "yok, arkayı  direkt gözde' ye  vermem  lazım.",
#  'sende.',
#  'sakin  olur  musun?',
#  'sakin  olur  musun? bak  çok  kötü  ısırıyorsun.',
#  'metin, kamerayı bence  oradan  al.',
#  'bitti.',
#  'bırak.',
#  'ya  biz  bunu, yeni  kesmemiş miydik  tırnaklarını? nasıl  uzayabiliyor?',
#  'olmuş.',
#  'bence  şöyle  yapıyor, böyle.',
#  'bileyliyor  mu, ne yapıyor  tırnaklarını?',
#  'ön  tırnaklar. bir  saniye  ya!',
#  'uzun  değil  ki  fazla.',
#  'oğlum! o  nasıl  bir kuvvet  gözünü  seveyim?',
#  'tırnağına  bakayım  da, belki  kesmemiz  gerekmez  ya.',
#  'evet. oha!',
#  'korkunç  olmuş!',
#  'bu  kadar  nasıl  uzuyor bu  çocuğun  tırnakları?',
#  "şunu  bi' bırakır  mısın? allah!",
#  'bu  çocuk  protein  tozu  falan mı  kullanıyor? güçlenmiş!',
#  'tamam  lan, tamam.',
#  'ya.',
#  'bir  insan  kediye karşı  guard  alır  mı  ya?',
#  "bugün  maşallah' ı  var.",
#  'nefesini  duyuyoruz! burnundan  soluyor!',
#  'terledim ',
#  'eldiven  sırtındayken  bu numarayı  yiyecek  kadar  da  aptalsın!',
#  'ayakları  tutmamı  ister  misiniz?',
#  'arka  patileri  alsana.',
#  'sende! tamam, aldım.',
#  'sıkı  tut, kaçırma. bende.',
#  'arkayı  çıkarmam  bana  dönmezse  tabii!',
#  'sende.',
#  'bırak  bırak.',
#  'kaçtı  zaten.',
#  'i̇ki  tırnağı  kaldı.',
#  'beni  unutmayın ',
#  'yok  yok, sana  ulaşamaz.',
#  'vallahi  eldiveni  parçaladı!',
#  'parçaladı  mı  harbiden? hıı.',
#  'girdi  mi?',
#  'tamam.',
#  'bırak.',
#  'hakikaten  deldi.',
#  'arka  ayakları  alayım  mı? pehlivan  gibi  ya!',
#  'sende, al! aldım.',
#  'tamam  anneciğim. tamam  bir  tanem.',
#  'bitti.',
#  'bırak. bırak. bırakıyorum.',
#  'çünkü  çok  şey  oluyor, yoruluyor  tutarken.',
#  'yoruldun  mu  anneciğim? çok  yorulmuş  gibi  durmuyor  ama.',
#  'yok, yoruldu. da  çok  yoruldu  da.',
#  'yemin  ediyorum yoruldum! şu  an  yoruldum.',
#  'hadi  devam  edelim  mi  anneciğim?',
#  'son  aşı, muayene, ateş  falan  bir  şey?',
#  'hiçbir  şeyi  adam akıllı  yaptırmayacak.',
#  'hiçbir  problem  yok, her şey  muhteşem  durumda.',
#  'okey.',
#  'ben  yine  arka ayakları  alayım  gözde.',
#  'anneciğim  bıyığın  kırılmış!',
#  'sende  ogün!',
#  'sakin  olur  musun?',
#  'bırak.',
#  'sağ  arka  patileri  al.',
#  'aldım.',
#  'orada  bir  kanama  mı  var?',
#  'sağ  tarafta.',
#  'eşek  sıpası!',
#  'kırmış! kendi  kırmış!',
#  "bakayım  bi'",
#  'kendi  kırmış. şurası, evet.',
#  'çatlatmış.',
#  'yoo, yapılacak  bir şey  yok  buna  metin.',
#  'bir  daha  bırak.',
#  'bu  öyle  bir  kanama  değil, bu kesikli  bir  şeyle  alakalı  değil. durur  o.',
#  'kanama  değil  yani.',
#  'tırnağı  yaralamış. şurayı  gördün  mü? sıyrılmış.',
#  'tamam, bırakın.',
#  'bırak. bırak  bırak.',
#  "bak, böyle  tırnağını kırıyorsun. bi' sakin  olur  musun?",
#  'atmıyorum  elimi.',
#  'sakin  ol.',
#  'bir  şey  yok. bitti  bebeğim, eve  gideceksin  işte  tamam.',
#  'anneciğim  bunu kapatmam  lazım, sakin.',
#  'sessizce  geliyorum.',
#  'gözde, biraz  havaya kaldırır  mısın  önü?',
#  'heh  tamam.',
#  'selam.',
#  'şurayı  ısırdı.',
#  'tam  olarak  şöyle  ısırabildi.',
#  'ağzı  demek  ki  bu  kadar  açılabiliyor, gördün  mü? şişmiş  mi?',
#  'yok  da, izi  bırakmış.',
#  'eldiven  olmasaydı  eğer burayı  kemiğe  saplamıştı.',
#  'hadi  geçmiş  olsun, güle  güle.',
#  'madalya  falan  vermeliyiz.',
#  'güle  güle  anneciğim. darası  alınmış  mıydı?',
#  'dara.',
#  'alamadık  tabii  ki  de.',
#  'alamadı  da, bu ',
#  'bu ',
#  'tam  kilosu  ne şeyde?',
#  'bu  box ',
#  'bu  taşıma  çantası.',
#  'evet, çocuğu  da  görmüş  oldunuz.',
#  'bu  arada  bu  kimin  üstünde?',
#  "bu  baya  sia' yı yakaladı  ya  metin.",
#  'zayıflamış  yani? zayıflamış.',
#  'o  zaman  zayıfladıysa, kas oranı  arttı  anlamına  geliyor  bu ',
#  'ben  diyorum, protein  tozu  veriyorlar  bence  buna. muhtemelen!',
#  'evde  çalışıyor!',
#  'haydi  güle  güle.',
#  'çocuk  muhtemelen',
#  'i̇lk ',
#  'var  canım.',
#  'sia  var.',
#  'sia ',
#  "sia' yı  biz  gördük  mü  ya?",
#  "hayır, görmediniz. sia' yı  getiremiyor  sahibi.",
#  'duman  var.',
#  "duman' da  çok  ciddiyim, yani  bu  muayene benimle  bulunan  herkes  şu  cümleyi  etti,",
#  'gözünde  gördüm  onu:',
#  'çıkmak  istedi muayene  salonundan.',
#  'çünkü  şey  saldırıyor, diyelim  elimden  kaçtı',
#  'ki  diyelim  değil, kaçıyor:',
#  'çok  güzel  kaçıyor.',
#  'yani  şurada  dolanıyor ya  mesela, oradan ',
#  'sana  doğru  atlama atakları  falan  yapıyor.',
#  'ya  şuradan  indirdim  ya!',
#  'bak  o, buraya  çıktı',
#  'şunun  üstüne, düşün  yani! benim  oraya kaçırabilmemi  hayal  edebiliyor  musun?',
#  'ben  atlar, yerden tutarım  bir  şekilde.',
#  'kaçırdım  ya, tutamıyorum  yani.',
#  'o  önümde  koşuyor, ben  arkasında  koşuyorum.',
#  'oraya  çıktı, bu arada  duman  geliyor.',
#  'ne  zaman?',
#  'onun  da  haberini  vermiş olayım. sahibine  ulaştım.',
#  "duman' la  alakalı bir  haber  vereceğim,",
#  'anlatırım. fotoğrafları, videoları  vesairesi  geldi.',
#  'onları  da  size  göstereceğim.',
#  'ben  izin  alayım  o  gün.',
#  've  artık  evde  yaşamıyor tabii  ki, evde  tutamamışlar.',
#  'doğasına  mı  salmışlar? bahçeye  bağlamışlar  falan?',
#  'doğaya. vallahi bahçede  yaşıyormuş.',
#  'sahibi  bahar  hanım yakalayabilirse  getirecek.',
#  "durum  öyle. duman' dan da  bilgi  vermiş  oldum.",
#  "hepimize  geçmişler  olsun. ben kıyafetimi, kendimi  bi' toparlayaym",
#  'tekrar  stüdyoya dönüyorum. görüşmek  üzere.',
#  'bu  arada  yandaki  videoları  da izleyebilirsiniz. kendinize  iyi  bakın!',
#  'i̇smi  pamuk  değil  mi? evet.',
#  "muayene  edeceğiz  ve  aşılarını  yapacağız. pamuk  beni  youtube' da  görüp  öyle  gelmiş.",
#  'bana  özel  geldin, değil  mi? merhaba! çok  iyi  yürekli, güzel  bir  kedi, bu  sefer  o  sinirlilerden  değil.',
#  'tıslaması, tırmalaması  yoktur.',
#  'pamuk  ne  kadar  zamandır  sizinle  birlikte?',
#  'merhaba. yavru  iken  mi  geldi, kaç  yaşında  şu  an?',
#  'biz ',
#  'hayır, apartmanın  önünde  bakıyorduk  yine  biz  bakıyorduk. biraz  tatsız  olaylar  yaşandığı  için  koruma  altına  aldık  artık  bizimle  uyuyor.',
#  'çok  şanslısın  ne  güzel  aile  bulmuşsun  kendine. efendim  sıcak  yuvam  ve  sevgili  ailemden  ötürü  açık  bahtıma  şükran  duymaktayım.',
#  'çıkarmayım  mı  istemiyor  musun? seni  muayene  edeceğim, kontrollerini  yapacağız  bir  tanem. elbette, elbette. i̇lginize  çok  müteşekkir  olurum  beyefendiciğim.',
#  'hep  böyle  prenses  mi  bu  kız? evet, hep  böyle  prenses, bizi  parmağında  oynatıyor.',
#  'estağfurullah  babacığım, o  nasıl  söz. tabiatım  gereği  sakin  bir  karakterim  var  diyelim.',
#  'kulakları  gayet  sağlıklı  görünüyor. yıllık  aşılarını  yaptırdınız  mı? onları  da  size  sormak  istiyorduk, ne  yaptırmamız  gerekiyor?',
#  'ağzına  da  bakayım  bırakacağım. tamam  bitti  bu  kadar. biraz  huzursuz  olmuş  bulundum, alışkın  değilim  tahmin  edersiniz  ki.',
#  'harikasın! sana  biraz  ikramda  bulunabilir  miyim?',
#  'yaş  mama  seviyor  mu? bayılır. memnuniyetle  kabul  ederim  beyfendiciğim.',
#  'bekle  orada  gitme  bir  yere, tamam  mı? dikkat  edecek  bir  tipe  benzemiyorsun. ne  münasebet, buracıktan  bir  yere  ayrılmam.',
#  'bak  sana  çok  güzel  bir  sürprizim  var  şimdi, sever  misin  bir  bak  bakalım. güzel  kokuyor  ama. i̇ştahım  kaçtı  birden.',
#  'burada  kalsın  o  zaman  o  böyle  senin  moralini  yüksek  tutalım. gerildi  tabii  biraz.',
#  'burada  geriliyorlar  ve  mama  yemiyorlar bilmem  ki  neden  oldu, gerildim  galiba.',
#  'herhangi  bir  şikayetiniz  yok  değil  mi? her  şey  yolunda. sadece  anal  kesesinin  etrafında  galiba  parazit  zamanı  geldiği  için  bir  kaç  siyah  noktalar  vardı',
#  'onlar  daha  çok  anal  kese  tam  olarak  boşalamadığı  zaman  olur  parazit  ile  alakalı  olmaz.',
#  'bazı  kedilerde  maalesef  anal  kese  yangısı  oluyor.',
#  'bu  arada  kısır  mı? evet.',
#  'öyle  yapınca  seni  çekemeyeceğimi  mi  sandın?',
#  'poposuna  en  son  bakalım  oradan  hoşlanmadı.',
#  'zaten  en  sevmediği  yer. muayene  edilmeye  alışkın  değilim  de, mazur  görünüz  efendim.',
#  'evet, ciğerimizin  muayenesi  ile  başlayalım. korkma  seviyorum  sadece.',
#  'resimlerde  çok  hoşmuş.',
#  'uzun  sessizlikler.',
#  "arabadan  hiç  hoşlanmıyor, merter' den  geliyoruz  yolda  hiç  susmadı.",
#  'arabaya  alışık  değilse  yapabilir  normal. opera  dinlemek  gibiydi.',
#  'sen  şarkılar  mı  söyledin  gelirken? dertli  şarkılardı  sanırım. araba  çok  bağırıyor, ben  dinledim  asıl  operayı.',
#  'peki  bu  çocuk  ne  yiyor? biraz  ağır. biraz  fazla  yiyor, kuru  mama  veriyoruz.',
#  'halimden  memnun  olduğumu  söyleyebilirim.',
#  'haftada ',
#  'annesi  çok  iştahlı  değil  ama  sık  yemek  yiyor. yemek  yemeyi  seviyor.',
#  'biraz  onu  düzene  sokabilirsek  iyi  olur. az  az, sık  sık  yiyin  diyor  uzmanlar.',
#  'sürekli  yiyorsa  muhtemelen ',
#  'maksimum, maksimum.',
#  'hareketli  bir  kedi  mi? yoksa  yatmayı  mı  seviyor? kendi  istediği  zaman  bayağı  hareketli daha  çok  yatmayı  seviyor.',
#  'dolapları  çok  seviyor, kutu  içleri. kediler  bayılıyor  öyle  şeylere',
#  'yatağında  yatmaz, ayakkabı  kutularının  içine  saklanır. poşet  ile  oynamıyor  mu? karton  kutu  kafidir, fazlasına  gerek  yok.',
#  'siz  var  ya  delisiniz, uzaylılar  sizi. lüks  düşkünü  insan  ırkının  aksine. biz  kediler  mütevazi  varlıklarız.',
#  'yardım  edebilirim  isterseniz. tutarsanız  çok  sevinirim.',
#  'tamam  bıraktım, bıraktım. poposu  da  gayet  sağlıklı. i̇yi  bari  ek  müdahale  gerekmeyecek.',
#  'anal  keseler, koku  üretebilmeleri  için, popo  kısmında  bulunan ',
#  'normal  şartlarda  tuvalet  yaparken  bu  anal  kese  boşalıyor  tuvalet  ile  beraber.',
#  'bazen  genetik  faktörler  nedeniyle, bazen  de  dışkının  aşırı  cıvık  olması  nedeniyle  tuvaletini  yaparken  anal  keseler  boşalmıyor  ve  boşalmadığı  zaman  içerisi  doluyor.',
#  'boşalmadıkça  içeride  enfekte  olmaya  başlıyor  ve  içeride  katılaşıyor  bu  katılaşma  ile  beraber  orada  ağrı  yapıyor.',
#  'fakat  bununki  boşalmış  kendi  kendine, düzenli  olarak  boşalmaya  devam  etmiş  o  güzel.',
#  've  oradaki  siyahlıklarda  muhtemelen  onun  kalıntıları  normaldir, dışkı  kalıntıları  da  olabilir.',
#  'parazit  ile  ilgili  değil  ama  tabii  ki  parazit  tedavilerini ',
#  'bilgilendirme  için  teşekkür  ederiz  saygıdeğer  hekim  beyefendiciğim.',
#  'kendini  biraz  daha  sık  temizlemelisiniz  dostum. bize  bırakma  o  işleri  olur  mu? sen  iyice  prenses  olmuşsun  hep  dışarıdan  bekliyorsun.',
#  'bu  konuları  kayıt  dışı  konuşmamız  daha  münasip  olabilir  beyefendiciğim.',
#  'kilosu  fazla  değil  mi? birazcık  fazla.',
#  'hap  yutmayı  seviyor  musun? yutarsan  kurtulursun, yutmazsan  iğne  yapacağım. anlaştık  mı? kurtulursam  yutup  da  kurtulayım.',
#  'yutup  demişken  abone  olmayı  unutmayın  sayın  seyirciler!',
#  'yardım  etmemi  ister  misiniz? çok  sevinirim. tamam  tamam  yutacağım  söz.',
#  'aç  bakalım  ağzını, yuttun  mu? aferin  sana! iyk  çok  iğrençmiş  bunun  tadı.',
#  'tebrik  ediyorum  seni. damlamızı  da  yapayım  sonra  seni  göndereyim, kurtul  benden. aman  yani  tadı  pek  hoş  değilmiş  demek  istedim.',
#  'ne  oldu, gidecek  misin? beni  terk  mi  ediyorsun?',
#  'korkuyor  musun  benden? bak  hiçbir  şey  yapmadım  sana.',
#  'kaçma  derdinde. çok  sıcak, güzel  bir  kedi.',
#  'evde  de  çok  uysaldır. misafirlere  karşı  nasıl? misafir  seviyor  mu?',
#  'misafir  sever  ama  daha  çok  koltukları  seviyor. misafirlerin  de  başımızın  üstünde  yeri  vardır  elbette.',
#  'çok  sıcak  kanlı  değil  kendi  ne  zaman  isterse  sevdiriyor.',
#  'hoş  geldiniz  diye  hemen  yanaşmıyor  yani. hayır  yanaşmaz, kucak  sevmez, kendi  isterse  gelip  yatıyor.',
#  'sonuçta  mesafeyi  de  korumak  gerekiyor. tam  bir  prenses.',
#  'evet, prenses  damlanı  da  yapıyoruz.',
#  'şimdi  aşı  konusuna  gelince  biz  ona  bir  tane  kimlik  çıkartalım. tamam.',
#  'aşılarına  da  parazit  tedavilerinden  sonra  başlamakta  fayda  var. kuduz  ve  karma  aşısını  muhakkak  olsun.',
#  'hayatının  belli  bir  kısmını  sokakta  yaşamış  zaten  muhtemelen  onlara  karşı  bağışıklık  kazanmıştır.',
#  'kuduz  aşısı  yasal  zorunluluk  onu  yapmak  gerekiyor  sürekli  olarak. karma  aşıyı  da  küçük  bir  önlem  olarak  yapmakta  fayda  var.',
#  'i̇çinde  herpes  virüsü  var  ve  gerçekten  pis  hastalıklar. merhabalar  efendim, merhabalar.',
#  'yani  ağız  yaralarından  solunum  problemlerine  kadar  sorunlar  çıkartıyor  önlemimizi  almış  olalım  bunun  için.',
#  'ama  bugün  yapmıyorum  çünkü  daha  iç  parazitini  yeni  yaptım. önce  parazitlerden  kurtulalım  ondan  sonra  aşılarına  başlayalım.',
#  'bugün  kimlik  çıkartalım. tamam.',
#  'evet  bu  harika  muayene  bitti  sona  erdi. geçmiş  olsun  bana.',
#  'sokaktan  sahiplenilen  kedilerin  sokağa  çıkma  isteği  olur  değil  mi? alışmış  ona  o  yüzden  çıkmak  ister.',
#  'sonuçta  ara  sıra  gezmek  istiyor  gönül.',
#  'özgür  olmak  isteyebilir  ama  biraz  dışarıda  dursun  hemen  içeriye  girmek  isteyecektir.',
#  'ne  oldu? bak  kutunu  yapıyorum. gidecek  misin? seviyor  musun  kutunu? seviyorum  tabi  ki. biraz  sallantılı  geçiyor  yolculuklar  ama  sonuçta  ayağımı  yerden  kesiyor.',
#  'buradan  kaçış  için  taşıt  o.',
#  'arabada  serbest  bıraksak  sorun  olmaz  herhalde  değil  mi? kutudan  mı  hoşlanmıyor  acaba?',
#  'araba, motor  seslerinden  hoşlanmıyor  onun  vermiş  olduğu  stres  ile  koltuğun  altına  girer  çıkartırken  yine  stres  yaşarsınız. o  yüzden  bırakmamak  daha  doğru',
#  'kutunun  rengi  çok  güzelmiş  seçimine  bayıldım. teşekkürler  çok  naziksiniz.',
#  'şunu  da  koyayım  yolda  yersin  belki. yemedin  reddettin  beni  ama. teşekkürler  beyefendiciğim.',
#  'evet, çok  geçmiş  olsun. çok  teşekkür  ederiz.',
#  'bugünüm  sensiz  geçti.',
#  'cehennemde  bir  asırdı  sanki.',
#  'gözlerim  iflas  etti.',
#  'çığrından  çıktı  gözyaşlarım.',
#  'hani  her  şeyindim, bensiz  sen  yoktun.',
#  'ayrılamazdık  ya.',
#  'gül  dudaklım, sihir  gözlüm.',
#  'dön.',
#  'hani  her  şeyindim, sensiz  ben  yoktum.',
#  'ayrılamazdık  ya.',
#  'gül  dudaklım, sihir  gözlüm.',
#  'dön.',
#  'kara  bulutları  sensizliğin.',
#  'çöküyor  üstüme, yavaş  yavaş.',
#  'çiçeğimin  renkleri  bir  bir  soluyor.',
#  'sensiz  günlerde  pembeler  nerde?',
#  'hani  her  şeyindim, sensiz  ben  yoktum.',
#  'ayrılamazdık  ya.',
#  'gül  dudaklım, sihir  gözlüm.',
#  'dön.',
#  'hani  her  şeyindim, bensiz  sen  yoktun.',
#  'ayrılamazdık  yar.',
#  'gül  dudaklım, sihir  gözlüm.',
#  'dön.',
#  'yanarım  ben  sensizliğime.',
#  'doyamam  senin  sevgine.',
#  'bağlarım  kopar, uçarım  gökyüzüne.',
#  'umutlar  gelip, geçer.',
#  'mutluluklar  bir  an  sürer.',
#  'sensizlik  canım  ölümden  beter.',
#  'hani  her  şeyindim, sensiz  ben  yoktum.',
#  'ayrılamazdık  ya.',
#  'gül  dudaklım, sihir  gözlüm.',
#  'dön.',
#  'hani  her  şeyindim, bensiz  sen  yoktun.',
#  'ayrılamazdık  ya.',
#  'gül  dudaklım, sihir  gözlüm.',
#  'dön.',
#  'bugünüm  sensiz  geçti.']

# %%
result_sent_list = []
for i in sent_list:
    for j in ngram_list:
        if j in i:
            result_sent_list.append(i)
#print(result_sent_list)

# %%
sent_list[0]
# Out:
# 'bu  videoda  darıca  ve  adalar  arasında  dalış'

# %%
"darıca ve adalar" in 'bu  videoda  darıca  ve  adalar  arasında  dalış'
# Out:
# False

# %%
.str.contains("geç", na=True)

# %%
xx = pd.Series(df_youtube_sentence.sentence)

# %%
xx.str.contains("darıca  ve  adalar")
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 468    False
# 469    False
# 470    False
# 471    False
# 472    False
# Name: sentence, Length: 473, dtype: bool

# %%
pd.DataFrame(result_sent_list)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_youtube_sentence[df_youtube_sentence.sentence.str.contains('gül du')]
# Out:
# Empty DataFrame
# Columns: [start_time, end_time, sentence, video_id]
# Index: []

# %%
df_youtube_sentence[df_youtube_sentence.sentence.str.contains('gül dudaklım')].head(5)
# Out:
# Empty DataFrame
# Columns: [start_time, end_time, sentence, video_id]
# Index: []

# %%
df_youtube_sentence[df_youtube_sentence.sentence.str.contains(r"(^.*geçmiş olsun.*)", na=True)].head(5)
# Out:
# /tmp/ipykernel_26419/4289891598.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df_youtube_sentence[df_youtube_sentence.sentence.str.contains(r"(^.*geçmiş olsun.*)", na=True)].head(5)
# Empty DataFrame
# Columns: [start_time, end_time, sentence, video_id]
# Index: []

# %%
df_youtube_sentence[df_youtube_sentence.sentence.str.match(r'([ilk defa])')==True]
# Out:
#        start_time      end_time  \
# 1    00:00:04.534  00:00:06.420
# 2    00:00:06.808  00:00:08.780
# 4    00:00:17.600  00:00:18.682
# 5    00:00:22.730  00:00:25.689
# 9    00:00:57.632  00:00:59.673
# ..            ...           ...
# 459  00:03:15.080  00:03:17.980
# 465  00:03:45.140  00:03:47.720
# 467  00:03:53.160  00:03:54.400
# 469  00:03:59.300  00:04:01.940
# 471  00:04:07.560  00:04:08.960
#
#                                            sentence     video_id
# 1                       küçük  balıkların  değişimi  WdX1_wNUj0E
# 2                  ilk  defa  göreceğiniz  detaylar  WdX1_wNUj0E
# 4                                            darıca  WdX1_wNUj0E
# 5    i̇stanbul' a  yakın  kocaeli' nin  bir  ilçesi  WdX1_wNUj0E
# 9                      diğer  adıyla  fulya  balığı  WdX1_wNUj0E
# ..                                              ...          ...
# 459                        doyamam  senin  sevgine.  c1QvY3X64qM
# 465                               ayrılamazdık  ya.  c1QvY3X64qM
# 467                                            dön.  c1QvY3X64qM
# 469                               ayrılamazdık  ya.  c1QvY3X64qM
# 471                                            dön.  c1QvY3X64qM
#
# [130 rows x 4 columns]

# %%
df_youtube_sentence[df_youtube_sentence.sentence.str.contains(r'(?:\s|^)\\geçmiş\\olsun(?:\s|$)', na=True)].head(5)
# Out:
# Empty DataFrame
# Columns: [start_time, end_time, sentence, video_id]
# Index: []

# %%
df_youtube_sentence[df_youtube_sentence.sentence.str.match("[hadi geçmiş])")]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_26419/1186812893.py in <module>
# ----> 1 df_youtube_sentence[df_youtube_sentence.sentence.str.match("[hadi geçmiş])")]
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     114                 )
#     115                 raise TypeError(msg)
# --> 116             return func(self, *args, **kwargs)
#     117
#     118         wrapper.__name__ = func_name
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/strings/accessor.py in match(self, pat, case, flags, na)
#    1191         extract : Extract matched groups.
#    1192         """
# -> 1193         result = self._data.array._str_match(pat, case=case, flags=flags, na=na)
#    1194         return self._wrap_result(result, fill_value=na, returns_string=False)
#    1195
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/strings/object_array.py in _str_match(self, pat, case, flags, na)
#     197             flags |= re.IGNORECASE
#     198
# --> 199         regex = re.compile(pat, flags=flags)
#     200
#     201         f = lambda x: regex.match(x) is not None
#
# ~/anaconda3/envs/py39/lib/python3.9/re.py in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#     253
#     254 def purge():
#
# ~/anaconda3/envs/py39/lib/python3.9/re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#     306         if len(_cache) >= _MAXCACHE:
#
# ~/anaconda3/envs/py39/lib/python3.9/sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# --> 764         p = sre_parse.parse(p, flags)
#     765     else:
#     766         pattern = None
#
# ~/anaconda3/envs/py39/lib/python3.9/sre_parse.py in parse(str, flags, state)
#     960     if source.next is not None:
#     961         assert source.next == ")"
# --> 962         raise source.error("unbalanced parenthesis")
#     963
#     964     if flags & SRE_FLAG_DEBUG:
#
# error: unbalanced parenthesis at position 13

# %%
r'(^w{5})'

# %%
sent_list = []
for i in df_youtube_sentence.sentence:
    if i.str.contains(r'([ilk defa])', na=True):
        sent_list.append(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_26419/2173374075.py in <module>
#       1 sent_list = []
#       2 for i in df_youtube_sentence.sentence:
# ----> 3     if i.str.contains(r'([ilk defa])', na=True):
#       4         sent_list.append(i)
#
# AttributeError: 'str' object has no attribute 'str'

# %%
sentence_1 = "ilk defa göreceğiniz"

# %%
sentence_1.contains(r'([ilk defa])', na=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_26419/1302926573.py in <module>
# ----> 1 sentence_1.contains(r'([ilk defa])', na=True)
#
# AttributeError: 'str' object has no attribute 'contains'

# %%
re.compile(r'''[.!?]['"]?s{1,2}(?=[A-Z])''')
