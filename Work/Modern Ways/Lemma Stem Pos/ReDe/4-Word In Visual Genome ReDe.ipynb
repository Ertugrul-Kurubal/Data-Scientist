# %% [markdown]
# ### Word In Visual Genome Process

# %%
#!pip install --upgrade pip

# %%
#!pip install --upgrade regex

# %%
#!pip install --upgrade pandas

# %%
#!pip install --upgrade yellowbrick

# %%
#!pip install --upgrade scipy

# %%
#import re
#print(re.__version__)

# %%
#import pandas
#print(pandas.__version__)

# %%
import os
import sys
import pandas as pd
import numpy as np
import re
import glob
from pathlib import Path
import shutil
from os.path import isfile, join

# %%
# language pair
lang_folder = "Turkish"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> target language for learner
#lang_pair = "English"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> native language

# %%
path = f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/\
Lemma Stem POS/Result/4-Word In Visual Genome"

Path(path).mkdir(parents=True, exist_ok=True)

# %%
def word_group_dataframe(df, search_list, target_column, sample_num):
    '''
    word_group_dataframe(df_youtube_sentence, search_list, "sentence", 6)\n
    df_youtube_sentence is dataframe and "sentence" is its column for external searching_list
    ''' 
    df_search_result = pd.DataFrame()
    for j in search_list:
        try:
            df_select = df[df[f"{target_column}"].str.contains(fr"(?:\s|^){j}(?:\s|$)", na=True)].sample(sample_num)
            #df_select = df[df[f"{target_column}"].str.contains(fr"(?:\s|^){j}(?:\s|$)", na=True)].tail(sample_num)  # will test
        except:
            df_select = df[df[f"{target_column}"].str.contains(fr"(?:\s|^){j}(?:\s|$)", na=True)].head(sample_num)
        #df_result = df[df[f"{target_column}"].str.contains(fr"(?:\s|^){j}(?:\s|$)", na=True)]  # sentence length part
        #df_result.sort_values(f"{target_column}",key=lambda x:x.str.len(), inplace=True)
        #df_select = df_result.head(sample_num)
        df_select.insert(0,"search_string",j)
        df_search_result = pd.concat([df_search_result,df_select], axis=0)
    df_search_result.reset_index(inplace=True, drop=True)
    
    return df_search_result

# %% [markdown]
# #### Visual Genome Data

# %%
df_genome_objects = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Turkish/Lemma Stem POS/Result/3-Visual Genome Process/Visual_Genome_Objects_Analysis.csv")
df_genome_objects
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-4ab8dbbace15> in <module>
# ----> 1 df_genome_objects = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Turkish/Lemma Stem POS/Result/3-Visual Genome Process/Visual_Genome_Objects_Analysis.csv")
#       2 df_genome_objects
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Turkish/Lemma Stem POS/Result/3-Visual Genome Process/Visual_Genome_Objects_Analysis.csv'

# %%
df_genome_objects["names"].nunique()
# Out:
# 82825

# %%
df_genome_attributes = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Turkish/Lemma Stem POS/Result/3-Visual Genome Process/Visual_Genome_Attributes_Analysis.csv")
df_genome_attributes
# Out:
#          object_id     names  image_id            attributes        synsets  \
# 0          1058498     clock         1          green , tall     clock.n.01
# 1             5046    street         1              sidewalk    street.n.01
# 2             5045     shade         1                   NaN     shade.n.01
# 3          1058529       man         1                   NaN       man.n.01
# 4             5048  sneakers         1                  grey  gym_shoe.n.01
# ...            ...       ...       ...                   ...            ...
# 3802369    3422177       sky   2417997  crystal clear , blue       sky.n.01
# 3802370    3103226      road   2417997                   NaN      road.n.01
# 3802371    2712437     doors   2417997                   NaN      door.n.01
# 3802372    3140197       bus   2417997                 green       bus.n.01
# 3802373    3561727      door   2417997                   NaN      door.n.01
#
#          height  width  x_koor  y_koor
# 0           339     79     421      91
# 1           262    714      77     328
# 2           192    274     119     338
# 3           262     60     238     249
# 4            26     52     243     489
# ...         ...    ...     ...     ...
# 3802369     170    497       1       2
# 3802370      83     90     312     247
# 3802371     144     50      98     127
# 3802372     155    225      29     109
# 3802373     113     50     100     130
#
# [3802374 rows x 9 columns]

# %%
df_genome_relationships = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Turkish/Lemma Stem POS/Result/3-Visual Genome Process/Visual_Genome_Relationships_Analysis.csv")
df_genome_relationships
# Out:
#          image_id obj_names  obj_object_id     obj_synsets  \
# 0               1  sidewalk        1058534   sidewalk.n.01
# 1               1     shoes        1058525       shoe.n.01
# 2               1       NaN           5050  headlight.n.01
# 3               1       NaN        1058508   building.n.01
# 4               1       NaN        1058534   sidewalk.n.01
# ...           ...       ...            ...             ...
# 2316099   2417997       NaN        3103225        bus.n.01
# 2316100   2417997       NaN        3786800     desert.n.01
# 2316101   2417997       NaN        3103226       road.n.01
# 2316102   2417997       NaN        2712437       door.n.01
# 2316103   2417997       NaN        3140197        bus.n.01
#
#         obj_merged_object_ids  obj_height  obj_width  obj_x_koor  obj_y_koor  \
# 0                        5046         290        722          78         308
# 1                        5048          28         48         388         485
# 2                         NaN          15         23         514         366
# 3                         NaN         536        218           1           2
# 4                         NaN         266        722          77         331
# ...                       ...         ...        ...         ...         ...
# 2316099                   NaN         193        289          14         110
# 2316100                   NaN         119        157         301         211
# 2316101                   NaN          83         90         312         247
# 2316102                   NaN         144         50          98         127
# 2316103                   NaN         155        225          29         109
#
#          relationships_id     synsets    sub_name  sub_object_id sub_synsets  \
# 0                   15927  along.r.01       shade           5045  shade.n.01
# 1                   15928   wear.v.01         man        1058529    man.n.01
# 2                   15929   have.v.01         car           5049    car.n.01
# 3                   15930  along.r.01        sign        1058507   sign.n.02
# 4                   15931  along.r.01  tree trunk           5055  trunk.n.01
# ...                   ...         ...         ...            ...         ...
# 2316099           4245033  along.r.01       plate        3786799  plate.n.04
# 2316100           4245034     in.r.01         NaN        3103225    bus.n.01
# 2316101           3722727  along.r.01         bus        3103225    bus.n.01
# 2316102           3880229         NaN         bus        3103225    bus.n.01
# 2316103           3722730  along.r.01        door        3561727   door.n.01
#
#          sub_height  sub_width  sub_x_koor  sub_y_koor predicate
# 0               192        274         119         338        on
# 1               262         60         238         249     wears
# 2                98         74         479         315       has
# 3               182         88         118          13        on
# 4               327         87         622         234        on
# ...             ...        ...         ...         ...       ...
# 2316099          54         89         238         233        on
# 2316100         182        287          14         110        in
# 2316101         193        289          14         110        on
# 2316102         193        289          14         110      with
# 2316103         113         50         100         130        on
#
# [2316104 rows x 19 columns]

# %% [markdown]
# #### Word Search In Genome Data

# %%
df_word_select = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Lemma Stem POS/Result/2-Word Select Process/{lang_folder.capitalize()}_45000_Lemma_Pos_Process.xlsx")
df_word_select
# Out:
#       pos.ud_imst           word  frequency lemma.spacylookup  stem  \
# 0             NUM            bir   18835735               bir   NaN
# 1             DET             bu   11062659                bu   NaN
# 2            PRON             ne    8025880                ne   NaN
# 3           CCONJ             ve    7766036                ve   NaN
# 4             ADP           için    5484109              için   NaN
# ...           ...            ...        ...               ...   ...
# 44995        NOUN        hayırbu        871           hayırbu   NaN
# 44996        NOUN   konferansına        871         konferans   NaN
# 44997        NOUN     kardeşisin        871            kardeş   NaN
# 44998        VERB  kaldırıyorsun        871            kaldır   NaN
# 44999        NOUN     kuzenlerim        871             kuzen   NaN
#
#        word_en_translate lemma_en_translate
# 0                      a                  a
# 1                   this               this
# 2                   what               what
# 3                    and                and
# 4                    for                for
# ...                  ...                ...
# 44995                 no                 no
# 44996  to the conference         conference
# 44997       your brother            brother
# 44998         you remove               lift
# 44999                NaN                NaN
#
# [45000 rows x 7 columns]

# %%
word_list = ['an','anlama','doğum','gidiyor','günün','istediğim','istediğin','istediğiniz','kutlu','olmuş','soru','söylemek','zamanki','zor','şuna']

# %%
df_word_raw = df_word_select[df_word_select["word"].isin(word_list)]
df_word_raw.reset_index(drop=True, inplace=True)
df_word_raw.drop(["frequency","stem"], inplace=True, axis=1)
df_word_raw
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    pos.ud_imst         word  ... word_en_translate lemma_en_translate
# 0         NOUN           an  ...            moment             moment
# 1          ADJ          zor  ...              hard               hard
# 2         VERB      gidiyor  ...             going                 go
# 3         VERB        olmuş  ...              dead                die
# 4         NOUN    istediğim  ...       what i want            at work
# 5         VERB     söylemek  ...            to say                say
# 6         NOUN         şuna  ...           to this               this
# 7         NOUN         soru  ...          question           question
# 8         NOUN        doğum  ...             birth              birth
# 9         NOUN    istediğin  ...          you want            at work
# 10        NOUN        günün  ...          your day                day
# 11        VERB       anlama  ...     understanding            meaning
# 12        NOUN      zamanki  ...          the time               time
# 13        VERB  istediğiniz  ...          you want            at work
# 14         ADJ        kutlu  ...           blessed            blessed
#
# [15 rows x 5 columns]

# %%
df_word_raw_lemma_trans_list = df_word_raw["lemma_en_translate"].to_list()
df_word_raw_word_trans_list = df_word_raw["word_en_translate"].to_list()

# %%
df_genome_search_result = word_group_dataframe(df_genome_objects, df_word_raw_lemma_trans_list, "names", 20)
df_genome_search_result.rename(columns={"search_string":"lemma_en_translate"}, inplace=True)
df_genome_search_result
# Out:
#     lemma_en_translate  object_id         names  ...  width x_koor y_koor
# 0               moment    2254937           NaN  ...    207      0    445
# 1               moment     994230           NaN  ...    486      6      7
# 2               moment     170579           NaN  ...     33    172    201
# 3                 hard    1089222      hard hat  ...     25      0    119
# 4                 hard    4034997  hard surface  ...    108    213    418
# ..                 ...        ...           ...  ...    ...    ...    ...
# 158            at work     994230           NaN  ...    486      6      7
# 159            at work     170579           NaN  ...     33    172    201
# 160            blessed    2254937           NaN  ...    207      0    445
# 161            blessed     994230           NaN  ...    486      6      7
# 162            blessed     170579           NaN  ...     33    172    201
#
# [163 rows x 11 columns]

# %%
df_genome_search_result["lemma_en_translate"].nunique()
# Out:
# 13

# %%
df_genome_search_result_merge = pd.merge(df_genome_search_result,df_word_raw,how="left",on="lemma_en_translate")
df_genome_search_result_merge
# Out:
#     lemma_en_translate  object_id  ... lemma.spacylookup  word_en_translate
# 0               moment    2254937  ...                an             moment
# 1               moment     994230  ...                an             moment
# 2               moment     170579  ...                an             moment
# 3                 hard    1089222  ...               zor               hard
# 4                 hard    4034997  ...               zor               hard
# ..                 ...        ...  ...               ...                ...
# 176            at work     170579  ...              iste           you want
# 177            at work     170579  ...              iste           you want
# 178            blessed    2254937  ...             kutlu            blessed
# 179            blessed     994230  ...             kutlu            blessed
# 180            blessed     170579  ...             kutlu            blessed
#
# [181 rows x 15 columns]

# %%
df_genome_search_result_merge.to_excel("test1.xlsx", index=False)

# %%
df_genome_search_result2 = word_group_dataframe(df_genome_objects, df_word_raw_word_trans_list, "names", 20)
df_genome_search_result2.rename(columns={"search_string":"word_en_translate"}, inplace=True)
df_genome_search_result2
# Out:
#     word_en_translate  object_id     names  ...  width x_koor y_koor
# 0              moment    2254937       NaN  ...    207      0    445
# 1              moment     994230       NaN  ...    486      6      7
# 2              moment     170579       NaN  ...     33    172    201
# 3                hard    2261298  hard hat  ...     15     30    225
# 4                hard    3116498  hard hat  ...     13    118    112
# ..                ...        ...       ...  ...    ...    ...    ...
# 107          you want     994230       NaN  ...    486      6      7
# 108          you want     170579       NaN  ...     33    172    201
# 109           blessed    2254937       NaN  ...    207      0    445
# 110           blessed     994230       NaN  ...    486      6      7
# 111           blessed     170579       NaN  ...     33    172    201
#
# [112 rows x 11 columns]

# %%
df_genome_search_result2["word_en_translate"].nunique()
# Out:
# 14

# %%
df_genome_search_result_merge2 = pd.merge(df_genome_search_result2,df_word_raw,how="left",on="word_en_translate")
df_genome_search_result_merge2
# Out:
#     word_en_translate  object_id  ... lemma.spacylookup  lemma_en_translate
# 0              moment    2254937  ...                an              moment
# 1              moment     994230  ...                an              moment
# 2              moment     170579  ...                an              moment
# 3                hard    2261298  ...               zor                hard
# 4                hard    3116498  ...               zor                hard
# ..                ...        ...  ...               ...                 ...
# 113          you want     170579  ...              iste             at work
# 114          you want     170579  ...              iste             at work
# 115           blessed    2254937  ...             kutlu             blessed
# 116           blessed     994230  ...             kutlu             blessed
# 117           blessed     170579  ...             kutlu             blessed
#
# [118 rows x 15 columns]

# %%
df_genome_search_result_merge2.to_excel("test2.xlsx", index=False)

# %% [markdown]
# #### Copy Move And Delete

# %%
output_file = glob.glob(f"{lang_folder.capitalize()}_45000_Lemma_Pos_Process.xlsx")
output_file

# %%
for l in output_file:
    source = l # source directory
    destination = path
    shutil.copy2(source, destination)

# %%
for j in output_file:
    try:
        os.remove(j)
    except:
        pass
