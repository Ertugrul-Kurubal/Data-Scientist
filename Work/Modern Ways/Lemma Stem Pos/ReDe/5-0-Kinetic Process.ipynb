# %% [markdown]
# ### Kinetic Process

# %%
import os
import multiprocessing
#import multiprocessing as mp
from multiprocessing import Process, Manager, Pool, Queue
from itertools import islice
from collections import Counter
import re
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize
from nltk import ngrams
from functools import reduce
from pathlib import Path
import shutil
import json

# %%
nprocs = multiprocessing.cpu_count()
print(f"Number of CPU cores: {nprocs}")
# Out:
# Number of CPU cores: 16

# %%
# language pair
lang_folder = "Turkish"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> target language for learner
#lang_pair = "English"  # Arabic, English, French, German, Turkish, Spanish, Portuguese, Dutch, Italian ==> native language

file_ext = 1000

# youtube
sample_num = 10  # 7
time_shift = 0.6

# %%
path = f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/\
Lemma Stem POS/Result/5-0-Kinetic Process"

word_lemma_data_path = f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/\
Lemma Stem POS/Result/3-2-Word In Visual Genome Merge"


#Path(path).mkdir(parents=True, exist_ok=True)

# %%
def word_group_youtube(df, search_list, target_column, sample_num):
    '''
    word_group_youtube(df_youtube_sentence, search_list, "sentence", 6)\n
    df_youtube_sentence is dataframe and "sentence" is its column for external searching_list
    ''' 
    df_search_result = pd.DataFrame()
    for j in search_list:
        try:
            df_select = df[df[f"{target_column}"].str.contains(fr"(?:\s|^){j}(?:\s|$)", na=False)].sample(sample_num)
            #df_select = df[df[f"{target_column}"].str.contains(fr"(?:\s|^){j}(?:\s|$)", na=True)].tail(sample_num)  # will test
        except:
            df_select = df[df[f"{target_column}"].str.contains(fr"(?:\s|^){j}(?:\s|$)", na=False)].head(sample_num)
        #df_result = df[df[f"{target_column}"].str.contains(fr"(?:\s|^){j}(?:\s|$)", na=True)]  # sentence length part
        #df_result.sort_values(f"{target_column}",key=lambda x:x.str.len(), inplace=True)
        #df_select = df_result.head(sample_num)
        df_select.insert(0,"search_string",j)
        df_search_result = pd.concat([df_search_result,df_select], axis=0)
    df_search_result.reset_index(inplace=True, drop=True)
    
    return df_search_result

# %%
def word_group_time_loc(df, search, start_sent, end_sent, sent, sent_video_id):
    '''
    word_group_time_loc(df_search_result, "search_string", "start_time", "end_time", "sentence", "video_id")\n
    df_search_result is dataframe and "search_string", "start_time", "end_time", "sentence", "video_id" are its columns
    '''
    df.reset_index(drop=True, inplace=True)
    word_time_loc_list = []
    for i in range(len(df)):
        word = df.loc[i,f"{search}"]
        start_time = df.loc[i,f"{start_sent}"]
        end_time = df.loc[i,f"{end_sent}"]
        sentence = df.loc[i,f"{sent}"]
        video_id = df.loc[i,f"{sent_video_id}"]
        time_length = end_time-start_time
        sentence_length = len(sentence)
        time_length_ratio = time_length/sentence_length
        loc_list = []
        for j in re.finditer(fr"(?:\s|^){word}(?:\s|$)", sentence, re.IGNORECASE|re.UNICODE):
            loc_list.append(j)
            start = loc_list[0].start()
            end = loc_list[0].end()
            start_loc = start_time+(start*time_length_ratio)
            end_loc = start_time+(end*time_length_ratio)
        word_time_loc_list.append([word,start_loc,end_loc,sentence,video_id])
    df_word_time_loc = pd.DataFrame(word_time_loc_list, columns=[f"{search}",f"{start_sent}",f"{end_sent}",f"{sent}",f"{sent_video_id}"])

    return df_word_time_loc

# %%
def word_count_result(df, column_list, set_condition=False): # df is dataframe, column_list is list value
    '''
    word_count_bool(df, column_list): df columns word count for word frequency\n
    df is dataframe, column_list is list value\n
    word_count_bool(df, ["word","twogram"]):
    '''
    list_all = []
    for i in df.loc[:,[x for x in column_list]].columns:
        if set_condition:
            var_list = set(df[f"{i}"].dropna().tolist())
        else:
            var_list = df[f"{i}"].dropna().tolist()
        for j in var_list:
            list_all.append(j)
    text = " ".join(list_all)
    word_list = re.findall(r"\w+",text, re.UNICODE)
    df_word_list = pd.DataFrame(word_list, columns=["word"])
    #df_word_list.rename(columns={0:"word"}, inplace=True)
    df_word_count = pd.DataFrame(df_word_list.value_counts())
    df_word_count.reset_index(inplace=True)
    df_word_count.rename(columns={0:"word_count"}, inplace=True)
    df_word_count.sort_values("word_count", ascending=False, inplace=True)
    df_word_count.reset_index(inplace=True, drop=True)
    
    return  df_word_count

# %%
def word_usage_result(word_list, df_target, target_column, target_opt_column, word_usage_min, word_usage_max):
    '''
    word_usage_result(word_list, df_ngram_pair, "threegram", "frequency", 1, 5) \n
    word_list is a list, df_target is a dateframe, target_column is df_target dataframe target column, \n
    target_opt_column is df_target dataframe opt_target column, \n
    word_usage_min and word_usage_max word usage condition.
    '''    
    word_num_dict = {}
    for i in word_list:
        word_num_dict[f"{i}"] = 0
    
    result_list_select = []
    var_list = []
    for i in range(len(df_target)):
        target_value = df_target.loc[i,f"{target_column}"]
        opt_value = df_target.loc[i,f"{target_opt_column}"]
        words = word_tokenize(target_value)   
        temp_list = [word for word in words]
        temp_list = temp_list + var_list
        # word count for max
        dict_list_count = Counter(temp_list)
        count_list = list(dict_list_count.values())
        # word count for min
        count_list2 = list(word_num_dict.values())
    
        if any([True if i>word_usage_max else False for i in count_list]) or not(any([True if j<word_usage_min else False for j in count_list2])):
            pass
        else:
            var_list = temp_list
            result_list_select.append([target_value,opt_value]) 
    
            for item2 in dict_list_count.items(): 
                word_num_dict[item2[0]] = item2[1]        
    df_result = pd.DataFrame(result_list_select, columns=[f"{target_column}",f"{target_opt_column}"])
    df_result.sort_values(by="frequency", ascending=False, inplace=True)
    df_result.reset_index(drop=True, inplace=True)
    
    return df_result

# %%
def lower_strip_func(x):
    try:
        var_low = str(x).lower()
        var_out = var_low.strip()
    except:
        var_out = x
    return var_out

# %%
en = re.compile(r"[abcdefghıijklmnopqrstxuvwyz]+", re.IGNORECASE|re.UNICODE) # English
def clean_text(text):
    text_clean = re.findall(en, text)
    text_result = " ".join(text_clean)
    return text_result

# %% [markdown]
# #### Kinetic Data

# %%
df_kinetic_700_csv = pd.read_csv(f"/home/kurubal/Downloads/Kinetic/kinetic 700.csv")
df_kinetic_700_csv
# Out:
#                       label   youtube_id  time_start  time_end     split
# 0                testifying  ---QUuC4vJs          84        94  validate
# 1              washing feet  --GkrdYZ9Tc           0        10  validate
# 2              air drumming  --nQbRBEz2s         104       114  validate
# 3                  pull ups  --rd8woSLiM          41        51  validate
# 4          building cabinet  --uGS0Y4D6k           9        19  validate
# ...                     ...          ...         ...       ...       ...
# 33324        trimming trees  zxdSPlGlSAQ          38        48  validate
# 33325         feeding goats  zxrvNwur1RE         194       204  validate
# 33326  country line dancing  zy7uvdwyK8k           3        13  validate
# 33327     playing paintball  zylVBFyoxZ0          94       104  validate
# 33328          washing hair  zyz4uOKGTzQ         233       243  validate
#
# [33329 rows x 5 columns]

# %%
df_kinetic_train_csv = pd.read_csv(f"/home/kurubal/Downloads/Kinetic/train.csv")
df_kinetic_train_csv
# Out:
#                         label   youtube_id  time_start  time_end  split
# 0         clay pottery making  ---0dWlqevI          19        29  train
# 1              news anchoring  ---aQ-tA5_A           9        19  train
# 2       using bagging machine  ---j12rm3WI          14        24  train
# 3               javelin throw  --07WQ2iBlw           1        11  train
# 4             climbing a rope  --0NTAs-fA0          29        39  train
# ...                       ...          ...         ...       ...    ...
# 533058         washing dishes  zzz_3yWpTXo           0        10  train
# 533059          juggling fire  zzzkS3amkWE         124       134  train
# 533060           taking photo  zzzsd1R7H0E           6        16  train
# 533061         brush painting  zzzxltuPx2Q          84        94  train
# 533062           changing oil  zzzzE0ncP1Y         232       242  train
#
# [533063 rows x 5 columns]

# %%
df_kinetic_validate_csv = pd.read_csv(f"/home/kurubal/Downloads/Kinetic/validate.csv")
df_kinetic_validate_csv
# Out:
#                       label   youtube_id  time_start  time_end     split
# 0                testifying  ---QUuC4vJs          84        94  validate
# 1              washing feet  --GkrdYZ9Tc           0        10  validate
# 2              air drumming  --nQbRBEz2s         104       114  validate
# 3                  pull ups  --rd8woSLiM          41        51  validate
# 4          building cabinet  --uGS0Y4D6k           9        19  validate
# ...                     ...          ...         ...       ...       ...
# 33324        trimming trees  zxdSPlGlSAQ          38        48  validate
# 33325         feeding goats  zxrvNwur1RE         194       204  validate
# 33326  country line dancing  zy7uvdwyK8k           3        13  validate
# 33327     playing paintball  zylVBFyoxZ0          94       104  validate
# 33328          washing hair  zyz4uOKGTzQ         233       243  validate
#
# [33329 rows x 5 columns]

# %%
df_kinetic_test_csv = pd.read_csv(f"/home/kurubal/Downloads/Kinetic/test.csv")
df_kinetic_test_csv
# Out:
#         youtube_id  time_start  time_end split
# 0      ---v8pgm1eQ           0        10  test
# 1      --0kKuQu4Gs           0        10  test
# 2      --1f2DTKcwg         111       121  test
# 3      --2V_kDPfDg         192       202  test
# 4      --3X_T3dnAE         370       380  test
# ...            ...         ...       ...   ...
# 65999  zvInmNgphQU          27        37  test
# 66000  zvifz6eL30E          38        48  test
# 66001  zvkWcTn-MX4         225       235  test
# 66002  zvwkhXw_BqM           8        18  test
# 66003  zwvRnRgzi6g          33        43  test
#
# [66004 rows x 4 columns]

# %%
df_kinetic_concat = pd.concat([df_kinetic_700_csv,df_kinetic_train_csv,df_kinetic_validate_csv], axis=0)
df_kinetic_concat = df_kinetic_concat.drop("split", axis=1)
df_kinetic_concat.drop_duplicates(inplace=True)
df_kinetic_concat
# Out:
#                    label   youtube_id  time_start  time_end
# 0             testifying  ---QUuC4vJs          84        94
# 1           washing feet  --GkrdYZ9Tc           0        10
# 2           air drumming  --nQbRBEz2s         104       114
# 3               pull ups  --rd8woSLiM          41        51
# 4       building cabinet  --uGS0Y4D6k           9        19
# ...                  ...          ...         ...       ...
# 533058    washing dishes  zzz_3yWpTXo           0        10
# 533059     juggling fire  zzzkS3amkWE         124       134
# 533060      taking photo  zzzsd1R7H0E           6        16
# 533061    brush painting  zzzxltuPx2Q          84        94
# 533062      changing oil  zzzzE0ncP1Y         232       242
#
# [566392 rows x 4 columns]

# %%
df_kinetic_concat["label"] = df_kinetic_concat["label"].apply(lambda x: lower_strip_func(x))
df_kinetic_concat["label"] = df_kinetic_concat["label"].apply(lambda x: clean_text(x))
df_kinetic_concat
# Out:
#                    label   youtube_id  time_start  time_end
# 0             testifying  ---QUuC4vJs          84        94
# 1           washing feet  --GkrdYZ9Tc           0        10
# 2           air drumming  --nQbRBEz2s         104       114
# 3               pull ups  --rd8woSLiM          41        51
# 4       building cabinet  --uGS0Y4D6k           9        19
# ...                  ...          ...         ...       ...
# 533058    washing dishes  zzz_3yWpTXo           0        10
# 533059     juggling fire  zzzkS3amkWE         124       134
# 533060      taking photo  zzzsd1R7H0E           6        16
# 533061    brush painting  zzzxltuPx2Q          84        94
# 533062      changing oil  zzzzE0ncP1Y         232       242
#
# [566392 rows x 4 columns]

# %%
Pos_Tag = "VERB" # NOUN, VERB, ADJ, ADV, NUM, PRON, CCONJ, ADP, AUX

# %%
df_genome_word_lemma_concat = pd.read_csv(f"{word_lemma_data_path}/Visual_Genome_{file_ext}_Word_Lemma_Search_Result.csv")
df_genome_word_lemma_concat
# Out:
#         POS1 POS2     word lemma.spacy stem word_en_translate  \
# 0        NUM  NaN      bir         bir  bir                 a
# 1        NUM  NaN      bir         bir  bir                 a
# 2        NUM  NaN      bir         bir  bir                 a
# 3        NUM  NaN      bir         bir  bir                 a
# 4        NUM  NaN      bir         bir  bir                 a
# ...      ...  ...      ...         ...  ...               ...
# 192717  VERB  NaN  çekilin         çek  çek          withdraw
# 192718  VERB  NaN  çekilin         çek  çek          withdraw
# 192719  VERB  NaN  çekilin         çek  çek          withdraw
# 192720  VERB  NaN  çekilin         çek  çek          withdraw
# 192721  VERB  NaN  çekilin         çek  çek          withdraw
#
#        lemma_en_translate  frequency              search_text  image_id  \
# 0                       a   18835735                        a   2390994
# 1                       a   18835735                        a   2348965
# 2                       a   18835735                        a   2348965
# 3                       a   18835735                        a   2349861
# 4                       a   18835735                        a   2349866
# ...                   ...        ...                      ...       ...
# 192717              check      69201  airport check in kiosks   2317616
# 192718              check      69201  red check of tablecloth   2400604
# 192719              check      69201  a check is on the table   2386272
# 192720              check      69201  cleats with white check   2371210
# 192721              check      69201  check number on receipt   2404231
#
#                  num
# 0         2920126305
# 1       129190150113
# 2       123317182233
# 3         4615142168
# 4           54188097
# ...              ...
# 192717     276026737
# 192718     376517459
# 192719   95132301236
# 192720    2211405194
# 192721    6140115286
#
# [192722 rows x 11 columns]

# %%
df_genome_word_lemma_concat = df_genome_word_lemma_concat[df_genome_word_lemma_concat["POS1"] == Pos_Tag]
df_genome_word_lemma_concat
# Out:
#         POS1 POS2         word lemma.spacy   stem word_en_translate  \
# 2320    VERB  NaN  gerektiğini       gerek  gerek              what
# 2321    VERB  NaN  gerektiğini       gerek  gerek              what
# 2322    VERB  NaN  gerektiğini       gerek  gerek              what
# 2323    VERB  NaN  gerektiğini       gerek  gerek              what
# 2324    VERB  NaN  gerektiğini       gerek  gerek              what
# ...      ...  ...          ...         ...    ...               ...
# 192717  VERB  NaN      çekilin         çek    çek          withdraw
# 192718  VERB  NaN      çekilin         çek    çek          withdraw
# 192719  VERB  NaN      çekilin         çek    çek          withdraw
# 192720  VERB  NaN      çekilin         çek    çek          withdraw
# 192721  VERB  NaN      çekilin         çek    çek          withdraw
#
#        lemma_en_translate  frequency              search_text  image_id  \
# 2320            necessary     120666                     what   2321637
# 2321            necessary     120666                     what   2412863
# 2322            necessary     120666             what this is   2388466
# 2323            necessary     120666      what is not allowed   2399091
# 2324            necessary     120666             what , white   2408062
# ...                   ...        ...                      ...       ...
# 192717              check      69201  airport check in kiosks   2317616
# 192718              check      69201  red check of tablecloth   2400604
# 192719              check      69201  a check is on the table   2386272
# 192720              check      69201  cleats with white check   2371210
# 192721              check      69201  check number on receipt   2404231
#
#                 num
# 2320     1308718190
# 2321     2404701598
# 2322       34576516
# 2323      553912620
# 2324      365513498
# ...             ...
# 192717    276026737
# 192718    376517459
# 192719  95132301236
# 192720   2211405194
# 192721   6140115286
#
# [50786 rows x 11 columns]

# %%
search_list = list(set(df_genome_word_lemma_concat["word"]))  # verb list
len(search_list)
# Out:
# 279

# %%
disable_video_id_list = []

# %%
df_youtube_sentence = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Youtube/Result/{lang_folder.capitalize()}/Sentence Clean Merge/Clean_Youtube_Sentence_Merge_Result.csv")
df_youtube_sentence
# Out:
#            start_time      end_time  \
# 0        00:00:00.294  00:00:03.294
# 1        00:00:03.375  00:00:06.375
# 2        00:00:06.462  00:00:09.462
# 3        00:00:10.267  00:00:11.394
# 4        00:00:11.835  00:00:14.061
# ...               ...           ...
# 3934202  00:10:00.240  00:10:07.818
# 3934203  00:10:07.994  00:10:13.534
# 3934204  00:10:14.745  00:10:17.924
# 3934205  00:10:18.047  00:10:22.398
# 3934206  00:10:22.734  00:10:23.633
#
#                                                   sentence     video_id
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                 sesli betimleme derneğine yaptırılmıştır  fI1BI4d5KFU
# 2                                            wwwsebederorg  fI1BI4d5KFU
# 3                                                     mumu  fI1BI4d5KFU
# 4                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# ...                                                    ...          ...
# 3934202  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3934203  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3934204  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
# 3934205  video hoşunuza gittiyse beğenmeyi ve kanalıma ...  dRssR_apbR0
# 3934206                                         hoşçakalın  dRssR_apbR0
#
# [3934207 rows x 4 columns]

# %%
df_youtube_sentence = df_youtube_sentence[~df_youtube_sentence["video_id"].isin(disable_video_id_list)]
df_youtube_sentence
# Out:
#            start_time      end_time  \
# 0        00:00:00.294  00:00:03.294
# 1        00:00:03.375  00:00:06.375
# 2        00:00:06.462  00:00:09.462
# 3        00:00:10.267  00:00:11.394
# 4        00:00:11.835  00:00:14.061
# ...               ...           ...
# 3934202  00:10:00.240  00:10:07.818
# 3934203  00:10:07.994  00:10:13.534
# 3934204  00:10:14.745  00:10:17.924
# 3934205  00:10:18.047  00:10:22.398
# 3934206  00:10:22.734  00:10:23.633
#
#                                                   sentence     video_id
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                 sesli betimleme derneğine yaptırılmıştır  fI1BI4d5KFU
# 2                                            wwwsebederorg  fI1BI4d5KFU
# 3                                                     mumu  fI1BI4d5KFU
# 4                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# ...                                                    ...          ...
# 3934202  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3934203  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3934204  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
# 3934205  video hoşunuza gittiyse beğenmeyi ve kanalıma ...  dRssR_apbR0
# 3934206                                         hoşçakalın  dRssR_apbR0
#
# [3934207 rows x 4 columns]

# %%
df_youtube_sentence['start_time'] = pd.to_timedelta(df_youtube_sentence['start_time']) # data type converted timedelta for second 
df_youtube_sentence['end_time'] = pd.to_timedelta(df_youtube_sentence['end_time'])

# %%
df_youtube_sentence['start_time'] = df_youtube_sentence['start_time'].apply(lambda x: x.total_seconds()) # convert seconds
df_youtube_sentence['end_time'] = df_youtube_sentence['end_time'].apply(lambda x: x.total_seconds())
df_youtube_sentence
# Out:
#          start_time  end_time  \
# 0             0.294     3.294
# 1             3.375     6.375
# 2             6.462     9.462
# 3            10.267    11.394
# 4            11.835    14.061
# ...             ...       ...
# 3934202     600.240   607.818
# 3934203     607.994   613.534
# 3934204     614.745   617.924
# 3934205     618.047   622.398
# 3934206     622.734   623.633
#
#                                                   sentence     video_id
# 0            bu dizinin betimlemesi staff fi lm tarafından  fI1BI4d5KFU
# 1                 sesli betimleme derneğine yaptırılmıştır  fI1BI4d5KFU
# 2                                            wwwsebederorg  fI1BI4d5KFU
# 3                                                     mumu  fI1BI4d5KFU
# 4                     bak şu an sinir katsayım hat safhada  fI1BI4d5KFU
# ...                                                    ...          ...
# 3934202  videoyu bitirmeden şunu da söylemek isterim ki...  dRssR_apbR0
# 3934203  bu nedenle ulaşımda insanların yarısına yakını...  dRssR_apbR0
# 3934204  danimarkayla alakalı şimdilik söyleyeceklerim ...  dRssR_apbR0
# 3934205  video hoşunuza gittiyse beğenmeyi ve kanalıma ...  dRssR_apbR0
# 3934206                                         hoşçakalın  dRssR_apbR0
#
# [3934207 rows x 4 columns]

# %%
df_word_group = word_group_youtube(df_youtube_sentence, search_list, "sentence", sample_num)
df_word_group
# Out:
#      search_string  start_time  end_time  \
# 0         ediyorum     539.200   541.200
# 1         ediyorum    2724.406  2725.930
# 2         ediyorum    3644.904  3646.840
# 3         ediyorum     242.770   248.560
# 4         ediyorum     426.210   431.760
# ...            ...         ...       ...
# 2785           dön    7361.577  7364.054
# 2786           dön    1463.866  1466.053
# 2787           dön    6173.440  6174.520
# 2788           dön    6978.008  6979.988
# 2789           dön     141.400   144.280
#
#                                                sentence     video_id
# 0                 ben onlara yardım ediyorum yüce honos  q_h9tUmdYaU
# 1                      sana ders vermeyi kabul ediyorum  UKVile_HpwQ
# 2                     ben nasıl olduğunu merak ediyorum  OPzhVWt1D9A
# 3     denemenizi tavsiye ediyorum ben hamuru bu şeki...  cVRNSvEpSIY
# 4     gerçekten çok lezzetli gönül rahatlığı ile tav...  1p2oao1tjOo
# ...                                                 ...          ...
# 2785                                     tamam sola dön  aPwTtMXPv3o
# 2786  dön bir sor istiyorsan bakalım kim mutlu ediyo...  pcAhoVDv2Gs
# 2787                                    teyze dön böyle  agAUR7SzzH0
# 2788                               ulan dön şöyle be öf  MXciFLdLVSY
# 2789                                      dön etrafinda  jAvQDHRDEn0
#
# [2790 rows x 5 columns]

# %%
df_word_group_time_loc = word_group_time_loc(df_word_group, "search_string", "start_time", "end_time", "sentence", "video_id")
df_word_group_time_loc
# Out:
#      search_string   start_time     end_time  \
# 0         ediyorum   540.118919   540.659459
# 1         ediyorum  2725.501375  2725.930000
# 2         ediyorum  3646.312000  3646.840000
# 3         ediyorum   244.025663   244.723253
# 4         ediyorum   429.960000   430.710000
# ...            ...          ...          ...
# 2785           dön  7363.346286  7364.054000
# 2786           dön  1463.866000  1464.028000
# 2787           dön  6173.800000  6174.160000
# 2788           dön  6978.404000  6978.899000
# 2789           dön   141.400000   142.286154
#
#                                                sentence     video_id
# 0                 ben onlara yardım ediyorum yüce honos  q_h9tUmdYaU
# 1                      sana ders vermeyi kabul ediyorum  UKVile_HpwQ
# 2                     ben nasıl olduğunu merak ediyorum  OPzhVWt1D9A
# 3     denemenizi tavsiye ediyorum ben hamuru bu şeki...  cVRNSvEpSIY
# 4     gerçekten çok lezzetli gönül rahatlığı ile tav...  1p2oao1tjOo
# ...                                                 ...          ...
# 2785                                     tamam sola dön  aPwTtMXPv3o
# 2786  dön bir sor istiyorsan bakalım kim mutlu ediyo...  pcAhoVDv2Gs
# 2787                                    teyze dön böyle  agAUR7SzzH0
# 2788                               ulan dön şöyle be öf  MXciFLdLVSY
# 2789                                      dön etrafinda  jAvQDHRDEn0
#
# [2790 rows x 5 columns]

# %%
df_word_group_time_loc.start_time = df_word_group_time_loc.start_time.apply(lambda x: (x-time_shift))
df_word_group_time_loc.end_time = df_word_group_time_loc.end_time.apply(lambda x: (x+time_shift))
df_word_group_time_loc
# Out:
#      search_string   start_time     end_time  \
# 0         ediyorum   539.518919   541.259459
# 1         ediyorum  2724.901375  2726.530000
# 2         ediyorum  3645.712000  3647.440000
# 3         ediyorum   243.425663   245.323253
# 4         ediyorum   429.360000   431.310000
# ...            ...          ...          ...
# 2785           dön  7362.746286  7364.654000
# 2786           dön  1463.266000  1464.628000
# 2787           dön  6173.200000  6174.760000
# 2788           dön  6977.804000  6979.499000
# 2789           dön   140.800000   142.886154
#
#                                                sentence     video_id
# 0                 ben onlara yardım ediyorum yüce honos  q_h9tUmdYaU
# 1                      sana ders vermeyi kabul ediyorum  UKVile_HpwQ
# 2                     ben nasıl olduğunu merak ediyorum  OPzhVWt1D9A
# 3     denemenizi tavsiye ediyorum ben hamuru bu şeki...  cVRNSvEpSIY
# 4     gerçekten çok lezzetli gönül rahatlığı ile tav...  1p2oao1tjOo
# ...                                                 ...          ...
# 2785                                     tamam sola dön  aPwTtMXPv3o
# 2786  dön bir sor istiyorsan bakalım kim mutlu ediyo...  pcAhoVDv2Gs
# 2787                                    teyze dön böyle  agAUR7SzzH0
# 2788                               ulan dön şöyle be öf  MXciFLdLVSY
# 2789                                      dön etrafinda  jAvQDHRDEn0
#
# [2790 rows x 5 columns]

# %%
df_word_group_time_loc.start_time = df_word_group_time_loc.start_time.apply(lambda x: round(x))
df_word_group_time_loc.end_time = df_word_group_time_loc.end_time.apply(lambda x: round(x))
df_word_group_time_loc
# Out:
#      search_string  start_time  end_time  \
# 0         ediyorum         540       541
# 1         ediyorum        2725      2727
# 2         ediyorum        3646      3647
# 3         ediyorum         243       245
# 4         ediyorum         429       431
# ...            ...         ...       ...
# 2785           dön        7363      7365
# 2786           dön        1463      1465
# 2787           dön        6173      6175
# 2788           dön        6978      6979
# 2789           dön         141       143
#
#                                                sentence     video_id
# 0                 ben onlara yardım ediyorum yüce honos  q_h9tUmdYaU
# 1                      sana ders vermeyi kabul ediyorum  UKVile_HpwQ
# 2                     ben nasıl olduğunu merak ediyorum  OPzhVWt1D9A
# 3     denemenizi tavsiye ediyorum ben hamuru bu şeki...  cVRNSvEpSIY
# 4     gerçekten çok lezzetli gönül rahatlığı ile tav...  1p2oao1tjOo
# ...                                                 ...          ...
# 2785                                     tamam sola dön  aPwTtMXPv3o
# 2786  dön bir sor istiyorsan bakalım kim mutlu ediyo...  pcAhoVDv2Gs
# 2787                                    teyze dön böyle  agAUR7SzzH0
# 2788                               ulan dön şöyle be öf  MXciFLdLVSY
# 2789                                      dön etrafinda  jAvQDHRDEn0
#
# [2790 rows x 5 columns]

# %%
df_word_group_time_loc["video_url"] = "https://www.youtube.com/watch?v="+df_word_group_time_loc['video_id'].map(str)+"&t="+df_word_group_time_loc['start_time'].map(str)+"s"
df_word_group_time_loc
# Out:
#      search_string  start_time  end_time  \
# 0         ediyorum         540       541
# 1         ediyorum        2725      2727
# 2         ediyorum        3646      3647
# 3         ediyorum         243       245
# 4         ediyorum         429       431
# ...            ...         ...       ...
# 2785           dön        7363      7365
# 2786           dön        1463      1465
# 2787           dön        6173      6175
# 2788           dön        6978      6979
# 2789           dön         141       143
#
#                                                sentence     video_id  \
# 0                 ben onlara yardım ediyorum yüce honos  q_h9tUmdYaU
# 1                      sana ders vermeyi kabul ediyorum  UKVile_HpwQ
# 2                     ben nasıl olduğunu merak ediyorum  OPzhVWt1D9A
# 3     denemenizi tavsiye ediyorum ben hamuru bu şeki...  cVRNSvEpSIY
# 4     gerçekten çok lezzetli gönül rahatlığı ile tav...  1p2oao1tjOo
# ...                                                 ...          ...
# 2785                                     tamam sola dön  aPwTtMXPv3o
# 2786  dön bir sor istiyorsan bakalım kim mutlu ediyo...  pcAhoVDv2Gs
# 2787                                    teyze dön böyle  agAUR7SzzH0
# 2788                               ulan dön şöyle be öf  MXciFLdLVSY
# 2789                                      dön etrafinda  jAvQDHRDEn0
#
#                                               video_url
# 0     https://www.youtube.com/watch?v=q_h9tUmdYaU&t=...
# 1     https://www.youtube.com/watch?v=UKVile_HpwQ&t=...
# 2     https://www.youtube.com/watch?v=OPzhVWt1D9A&t=...
# 3     https://www.youtube.com/watch?v=cVRNSvEpSIY&t=...
# 4     https://www.youtube.com/watch?v=1p2oao1tjOo&t=...
# ...                                                 ...
# 2785  https://www.youtube.com/watch?v=aPwTtMXPv3o&t=...
# 2786  https://www.youtube.com/watch?v=pcAhoVDv2Gs&t=...
# 2787  https://www.youtube.com/watch?v=agAUR7SzzH0&t=...
# 2788  https://www.youtube.com/watch?v=MXciFLdLVSY&t=...
# 2789  https://www.youtube.com/watch?v=jAvQDHRDEn0&t=...
#
# [2790 rows x 6 columns]

# %%
word_count_result(df_word_group_time_loc, ["search_string"], set_condition=True)
# Out:
#             word  word_count
# 0             al           1
# 1    bilemiyorum           1
# 2       alacağım           1
# 3           aldı           1
# 4          aldım           1
# ..           ...         ...
# 274          çık           1
# 275        çıktı           1
# 276         öldü           1
# 277     öldürmek           1
# 278        ölmüş           1
#
# [279 rows x 2 columns]

# %%
#df_word_group_time_loc.to_excel(f"{lang_folder.capitalize()}_{file_ext}_With_Verb_Youtube_Link.xlsx", index=False)  ########*****

# %%
df_kinetic_train_json = pd.read_json(f"/home/kurubal/Downloads/Kinetic/train.json")
df_kinetic_train_json
# Out:
#                                                    ---0dWlqevI  \
# annotations  {'label': 'clay pottery making', 'segment': [1...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=---0dWlqevI
#
#                                                    ---aQ-tA5_A  \
# annotations  {'label': 'news anchoring', 'segment': [9.0, 1...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=---aQ-tA5_A
#
#                                                    ---j12rm3WI  \
# annotations  {'label': 'using bagging machine', 'segment': ...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=---j12rm3WI
#
#                                                    --07WQ2iBlw  \
# annotations  {'label': 'javelin throw', 'segment': [1.0, 11...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=--07WQ2iBlw
#
#                                                    --0NTAs-fA0  \
# annotations  {'label': 'climbing a rope', 'segment': [29.0,...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=--0NTAs-fA0
#
#                                                    --0l35AkU34  \
# annotations  {'label': 'sipping cup', 'segment': [68.0, 78.0]}
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=--0l35AkU34
#
#                                                    --33Lscn6sk  \
# annotations  {'label': 'flipping pancake', 'segment': [4.0,...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=--33Lscn6sk
#
#                                                 --3OAstUWtU  \
# annotations  {'label': 'tickling', 'segment': [45.0, 55.0]}
# duration                                               10.0
# subset                                                train
# url             https://www.youtube.com/watch?v=--3OAstUWtU
#
#                                                    --3lTx87ebQ  \
# annotations  {'label': 'watering plants', 'segment': [23.0,...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=--3lTx87ebQ
#
#                                                    --3ouPhoy2A  ...  \
# annotations  {'label': 'eating spaghetti', 'segment': [20.0...  ...
# duration                                                  10.0  ...
# subset                                                   train  ...
# url                https://www.youtube.com/watch?v=--3ouPhoy2A  ...
#
#                                                   zzy_artj1B8  \
# annotations  {'label': 'gargling', 'segment': [210.0, 220.0]}
# duration                                                 10.0
# subset                                                  train
# url               https://www.youtube.com/watch?v=zzy_artj1B8
#
#                                                    zzyxMjfYpL0  \
# annotations  {'label': 'blowing glass', 'segment': [8.0, 18...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=zzyxMjfYpL0
#
#                                                    zzz0-zDYts8  \
# annotations  {'label': 'ice fishing', 'segment': [80.0, 90.0]}
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=zzz0-zDYts8
#
#                                                    zzz0X4NoFyA  \
# annotations  {'label': 'using bagging machine', 'segment': ...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=zzz0X4NoFyA
#
#                                                    zzzZycxdZHk  \
# annotations  {'label': 'making a cake', 'segment': [54.0, 6...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=zzzZycxdZHk
#
#                                                    zzz_3yWpTXo  \
# annotations  {'label': 'washing dishes', 'segment': [0.0, 1...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=zzz_3yWpTXo
#
#                                                    zzzkS3amkWE  \
# annotations  {'label': 'juggling fire', 'segment': [124.0, ...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=zzzkS3amkWE
#
#                                                    zzzsd1R7H0E  \
# annotations  {'label': 'taking photo', 'segment': [6.0, 16.0]}
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=zzzsd1R7H0E
#
#                                                    zzzxltuPx2Q  \
# annotations  {'label': 'brush painting', 'segment': [84.0, ...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=zzzxltuPx2Q
#
#                                                    zzzzE0ncP1Y
# annotations  {'label': 'changing oil', 'segment': [232.0, 2...
# duration                                                  10.0
# subset                                                   train
# url                https://www.youtube.com/watch?v=zzzzE0ncP1Y
#
# [4 rows x 530666 columns]

# %%
df_kinetic_validate_json = pd.read_json(f"/home/kurubal/Downloads/Kinetic/validate.json")
df_kinetic_validate_json
# Out:
#                                                   ---QUuC4vJs  \
# annotations  {'label': 'testifying', 'segment': [84.0, 94.0]}
# duration                                                 10.0
# subset                                               validate
# url               https://www.youtube.com/watch?v=---QUuC4vJs
#
#                                                    --GkrdYZ9Tc  \
# annotations  {'label': 'washing feet', 'segment': [0.0, 10.0]}
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=--GkrdYZ9Tc
#
#                                                    --nQbRBEz2s  \
# annotations  {'label': 'air drumming', 'segment': [104.0, 1...
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=--nQbRBEz2s
#
#                                                 --rd8woSLiM  \
# annotations  {'label': 'pull ups', 'segment': [41.0, 51.0]}
# duration                                               10.0
# subset                                             validate
# url             https://www.youtube.com/watch?v=--rd8woSLiM
#
#                                                    --uGS0Y4D6k  \
# annotations  {'label': 'building cabinet', 'segment': [9.0,...
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=--uGS0Y4D6k
#
#                                                    -07WVYMSwac  \
# annotations  {'label': 'petting cat', 'segment': [20.0, 30.0]}
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=-07WVYMSwac
#
#                                                    -08En2aQklI  \
# annotations  {'label': 'building cabinet', 'segment': [233....
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=-08En2aQklI
#
#                                                 -0IErS_cisg  \
# annotations  {'label': 'marching', 'segment': [17.0, 27.0]}
# duration                                               10.0
# subset                                             validate
# url             https://www.youtube.com/watch?v=-0IErS_cisg
#
#                                                    -0ML-FXomBw  \
# annotations  {'label': 'playing paintball', 'segment': [1.0...
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=-0ML-FXomBw
#
#                                                    -0MsYnGUrfE  ...  \
# annotations  {'label': 'playing paintball', 'segment': [22....  ...
# duration                                                  10.0  ...
# subset                                                validate  ...
# url                https://www.youtube.com/watch?v=-0MsYnGUrfE  ...
#
#                                                   zwk2hY12XAg  \
# annotations  {'label': 'lifting hat', 'segment': [7.0, 17.0]}
# duration                                                 10.0
# subset                                               validate
# url               https://www.youtube.com/watch?v=zwk2hY12XAg
#
#                                                    zwrku6rQ41s  \
# annotations  {'label': 'cleaning shoes', 'segment': [20.0, ...
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=zwrku6rQ41s
#
#                                                    zx2kZkM1LXA  \
# annotations  {'label': 'reading newspaper', 'segment': [11....
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=zx2kZkM1LXA
#
#                                                    zxYAOHRS4kI  \
# annotations  {'label': 'snowkiting', 'segment': [240.0, 250...
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=zxYAOHRS4kI
#
#                                                    zxaklajobzg  \
# annotations  {'label': 'sled dog racing', 'segment': [455.0...
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=zxaklajobzg
#
#                                                    zxdSPlGlSAQ  \
# annotations  {'label': 'trimming trees', 'segment': [38.0, ...
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=zxdSPlGlSAQ
#
#                                                    zxrvNwur1RE  \
# annotations  {'label': 'feeding goats', 'segment': [194.0, ...
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=zxrvNwur1RE
#
#                                                    zy7uvdwyK8k  \
# annotations  {'label': 'country line dancing', 'segment': [...
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=zy7uvdwyK8k
#
#                                                    zylVBFyoxZ0  \
# annotations  {'label': 'playing paintball', 'segment': [94....
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=zylVBFyoxZ0
#
#                                                    zyz4uOKGTzQ
# annotations  {'label': 'washing hair', 'segment': [233.0, 2...
# duration                                                  10.0
# subset                                                validate
# url                https://www.youtube.com/watch?v=zyz4uOKGTzQ
#
# [4 rows x 33278 columns]

# %%
df_kinetic_train_json2 = json.load(open('/home/kurubal/Downloads/Kinetic/train.json'))
df_kinetic_train_json2
# Out:
# {'---0dWlqevI': {'annotations': {'label': 'clay pottery making',
#    'segment': [19.0, 29.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=---0dWlqevI'},
#  '---aQ-tA5_A': {'annotations': {'label': 'news anchoring',
#    'segment': [9.0, 19.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=---aQ-tA5_A'},
#  '---j12rm3WI': {'annotations': {'label': 'using bagging machine',
#    'segment': [14.0, 24.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=---j12rm3WI'},
#  '--07WQ2iBlw': {'annotations': {'label': 'javelin throw',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--07WQ2iBlw'},
#  '--0NTAs-fA0': {'annotations': {'label': 'climbing a rope',
#    'segment': [29.0, 39.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--0NTAs-fA0'},
#  '--0l35AkU34': {'annotations': {'label': 'sipping cup',
#    'segment': [68.0, 78.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--0l35AkU34'},
#  '--33Lscn6sk': {'annotations': {'label': 'flipping pancake',
#    'segment': [4.0, 14.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--33Lscn6sk'},
#  '--3OAstUWtU': {'annotations': {'label': 'tickling', 'segment': [45.0, 55.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--3OAstUWtU'},
#  '--3lTx87ebQ': {'annotations': {'label': 'watering plants',
#    'segment': [23.0, 33.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--3lTx87ebQ'},
#  '--3ouPhoy2A': {'annotations': {'label': 'eating spaghetti',
#    'segment': [20.0, 30.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--3ouPhoy2A'},
#  '--4-0ihtnBU': {'annotations': {'label': 'dribbling basketball',
#    'segment': [58.0, 68.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--4-0ihtnBU'},
#  '--4NLFGNfAs': {'annotations': {'label': 'calligraphy',
#    'segment': [11.0, 21.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--4NLFGNfAs'},
#  '--56QUhyDQM': {'annotations': {'label': 'playing tennis',
#    'segment': [185.0, 195.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--56QUhyDQM'},
#  '--5Tg3gW4s4': {'annotations': {'label': 'brushing floor',
#    'segment': [8.0, 18.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--5Tg3gW4s4'},
#  '--5kVeU1uco': {'annotations': {'label': 'chiseling stone',
#    'segment': [58.0, 68.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--5kVeU1uco'},
#  '--5urtlw6gs': {'annotations': {'label': 'crossing eyes',
#    'segment': [49.0, 59.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--5urtlw6gs'},
#  '--65_UAU7ao': {'annotations': {'label': 'mountain climber (exercise)',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--65_UAU7ao'},
#  '--6q_33gNew': {'annotations': {'label': 'tap dancing',
#    'segment': [132.0, 142.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--6q_33gNew'},
#  '--6zxbYq5M4': {'annotations': {'label': 'planing wood',
#    'segment': [207.0, 217.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--6zxbYq5M4'},
#  '--71SekUwOA': {'annotations': {'label': 'using inhaler',
#    'segment': [13.0, 23.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--71SekUwOA'},
#  '--7VUM9MKg4': {'annotations': {'label': 'playing saxophone',
#    'segment': [136.0, 146.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--7VUM9MKg4'},
#  '--7goKgS4kc': {'annotations': {'label': 'slapping', 'segment': [15.0, 25.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--7goKgS4kc'},
#  '--8FQVwWH0M': {'annotations': {'label': 'shaking head',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--8FQVwWH0M'},
#  '--9s8lCov-I': {'annotations': {'label': 'driving tractor',
#    'segment': [2.0, 12.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--9s8lCov-I'},
#  '--AC9Wionlg': {'annotations': {'label': 'delivering mail',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--AC9Wionlg'},
#  '--DiygSPius': {'annotations': {'label': 'riding a bike',
#    'segment': [52.0, 62.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--DiygSPius'},
#  '--Dt5ovTecs': {'annotations': {'label': 'calligraphy',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--Dt5ovTecs'},
#  '--EZD1uEVhM': {'annotations': {'label': 'putting in contact lenses',
#    'segment': [63.0, 73.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--EZD1uEVhM'},
#  '--EaS9P7ZdQ': {'annotations': {'label': 'climbing a rope',
#    'segment': [13.0, 23.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--EaS9P7ZdQ'},
#  '--FTpoPhxcA': {'annotations': {'label': 'shaving head',
#    'segment': [570.0, 580.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--FTpoPhxcA'},
#  '--GEr5-PyTI': {'annotations': {'label': 'doing jigsaw puzzle',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--GEr5-PyTI'},
#  '--GF746y6UM': {'annotations': {'label': 'playing bass guitar',
#    'segment': [496.0, 506.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--GF746y6UM'},
#  '--GaSxELz-8': {'annotations': {'label': 'playing with trains',
#    'segment': [39.0, 49.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--GaSxELz-8'},
#  '--ILYNHl3e4': {'annotations': {'label': 'digging',
#    'segment': [541.0, 551.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--ILYNHl3e4'},
#  '--IPbe5ZMCI': {'annotations': {'label': 'brushing teeth',
#    'segment': [2.0, 12.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--IPbe5ZMCI'},
#  '--JGqNj9Bv0': {'annotations': {'label': 'washing hair',
#    'segment': [33.0, 43.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--JGqNj9Bv0'},
#  '--KkHPoWdW8': {'annotations': {'label': 'opening bottle (not wine)',
#    'segment': [25.0, 35.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--KkHPoWdW8'},
#  '--Kr1PZaPDI': {'annotations': {'label': 'finger snapping',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--Kr1PZaPDI'},
#  '--LrHkjbax8': {'annotations': {'label': 'crossing eyes',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--LrHkjbax8'},
#  '--MW2zcDiNg': {'annotations': {'label': 'doing nails',
#    'segment': [197.0, 207.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--MW2zcDiNg'},
#  '--Nixnc9DQg': {'annotations': {'label': 'making balloon shapes',
#    'segment': [17.0, 27.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--Nixnc9DQg'},
#  '--O2qCO6zBI': {'annotations': {'label': 'pouring beer',
#    'segment': [25.0, 35.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--O2qCO6zBI'},
#  '--O4p15yejk': {'annotations': {'label': 'preparing salad',
#    'segment': [351.0, 361.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--O4p15yejk'},
#  '--PwWfN1Ae4': {'annotations': {'label': 'playing violin',
#    'segment': [97.0, 107.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--PwWfN1Ae4'},
#  '--PyMoD3_eg': {'annotations': {'label': 'feeding birds',
#    'segment': [20.0, 30.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--PyMoD3_eg'},
#  '--QG-bjOFSA': {'annotations': {'label': 'wading through water',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--QG-bjOFSA'},
#  '--QfWXBoeA0': {'annotations': {'label': 'cutting watermelon',
#    'segment': [125.0, 135.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--QfWXBoeA0'},
#  '--Qq8Y0ywHA': {'annotations': {'label': 'petting cat',
#    'segment': [2.0, 12.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--Qq8Y0ywHA'},
#  '--RVKBMp_2M': {'annotations': {'label': 'playing drums',
#    'segment': [79.0, 89.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--RVKBMp_2M'},
#  '--RtHwqbEWA': {'annotations': {'label': 'doing aerobics',
#    'segment': [139.0, 149.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--RtHwqbEWA'},
#  '--RuMpNXawk': {'annotations': {'label': 'sausage making',
#    'segment': [277.0, 287.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--RuMpNXawk'},
#  '--SOz3xjWfA': {'annotations': {'label': 'playing ukulele',
#    'segment': [37.0, 47.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--SOz3xjWfA'},
#  '--SSk3r84yw': {'annotations': {'label': 'throwing knife',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--SSk3r84yw'},
#  '--SrV9bGzRA': {'annotations': {'label': 'skiing slalom',
#    'segment': [197.0, 207.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--SrV9bGzRA'},
#  '--T4dtRsSSg': {'annotations': {'label': 'knitting', 'segment': [25.0, 35.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--T4dtRsSSg'},
#  '--U3pqp_C5g': {'annotations': {'label': 'head stand',
#    'segment': [139.0, 149.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--U3pqp_C5g'},
#  '--UW3CcUqaU': {'annotations': {'label': 'dining', 'segment': [20.0, 30.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--UW3CcUqaU'},
#  '--VnA3ztuZg': {'annotations': {'label': 'hurdling', 'segment': [57.0, 67.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--VnA3ztuZg'},
#  '--VtCsmlD18': {'annotations': {'label': 'throwing water balloon',
#    'segment': [47.0, 57.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--VtCsmlD18'},
#  '--WckmtKBpc': {'annotations': {'label': 'tiptoeing',
#    'segment': [17.0, 27.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--WckmtKBpc'},
#  '--XQ47BGhdc': {'annotations': {'label': 'news anchoring',
#    'segment': [46.0, 56.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--XQ47BGhdc'},
#  '--XR9XONO2U': {'annotations': {'label': 'opening present',
#    'segment': [460.0, 470.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--XR9XONO2U'},
#  '--XWWLL8Spk': {'annotations': {'label': 'changing gear in car',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--XWWLL8Spk'},
#  '--Y25nDn2Wk': {'annotations': {'label': 'playing cymbals',
#    'segment': [60.0, 70.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--Y25nDn2Wk'},
#  '--YKMD5LYtw': {'annotations': {'label': 'chopping meat',
#    'segment': [89.0, 99.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--YKMD5LYtw'},
#  '--YXAAC0WWA': {'annotations': {'label': 'making paper aeroplanes',
#    'segment': [35.0, 45.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--YXAAC0WWA'},
#  '--ZrYtRjYfs': {'annotations': {'label': 'folding clothes',
#    'segment': [87.0, 97.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--ZrYtRjYfs'},
#  '--_3Wbv-1YY': {'annotations': {'label': 'playing pinball',
#    'segment': [319.0, 329.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--_3Wbv-1YY'},
#  '--_fOePZDoY': {'annotations': {'label': 'changing gear in car',
#    'segment': [41.0, 51.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--_fOePZDoY'},
#  '--bQb-k_Tjs': {'annotations': {'label': 'vacuuming floor',
#    'segment': [9.0, 19.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--bQb-k_Tjs'},
#  '--cIG2WqOf4': {'annotations': {'label': 'shuffling feet',
#    'segment': [20.0, 30.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--cIG2WqOf4'},
#  '--cLZr4EsEk': {'annotations': {'label': 'recording music',
#    'segment': [133.0, 143.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--cLZr4EsEk'},
#  '--cOOZbreL4': {'annotations': {'label': 'historical reenactment',
#    'segment': [129.0, 139.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--cOOZbreL4'},
#  '--coBvtS-eQ': {'annotations': {'label': 'surfing water',
#    'segment': [57.0, 67.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--coBvtS-eQ'},
#  '--d6UCSGoHg': {'annotations': {'label': 'playing drums',
#    'segment': [51.0, 61.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--d6UCSGoHg'},
#  '--dVV4_CSvw': {'annotations': {'label': 'bowling', 'segment': [33.0, 43.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--dVV4_CSvw'},
#  '--feYHvtteA': {'annotations': {'label': 'snowkiting',
#    'segment': [25.0, 35.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--feYHvtteA'},
#  '--gMWIQlLvs': {'annotations': {'label': 'lighting fire',
#    'segment': [122.0, 132.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--gMWIQlLvs'},
#  '--gtKHP3Q8E': {'annotations': {'label': 'eating cake',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--gtKHP3Q8E'},
#  '--gx7yb1-x0': {'annotations': {'label': 'inflating balloons',
#    'segment': [298.0, 308.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--gx7yb1-x0'},
#  '--h55t9J0Xo': {'annotations': {'label': 'letting go of balloon',
#    'segment': [7.0, 17.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--h55t9J0Xo'},
#  '--hZSQ7Q7qs': {'annotations': {'label': 'calligraphy',
#    'segment': [145.0, 155.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--hZSQ7Q7qs'},
#  '--iGd5Zf7-k': {'annotations': {'label': 'chopping meat',
#    'segment': [8.0, 18.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--iGd5Zf7-k'},
#  '--iIcadFu9c': {'annotations': {'label': 'bee keeping',
#    'segment': [90.0, 100.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--iIcadFu9c'},
#  '--ijHZ19K_M': {'annotations': {'label': 'cutting apple',
#    'segment': [25.0, 35.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--ijHZ19K_M'},
#  '--ixUOhZodk': {'annotations': {'label': 'drooling', 'segment': [56.0, 66.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--ixUOhZodk'},
#  '--jD1Yu5ZnQ': {'annotations': {'label': 'gymnastics tumbling',
#    'segment': [37.0, 47.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--jD1Yu5ZnQ'},
#  '--jfcGztatc': {'annotations': {'label': 'archaeological excavation',
#    'segment': [6.0, 16.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--jfcGztatc'},
#  '--jktjgj81k': {'annotations': {'label': 'clapping', 'segment': [5.0, 15.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--jktjgj81k'},
#  '--kbTDDIiP0': {'annotations': {'label': 'giving or receiving award',
#    'segment': [62.0, 72.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--kbTDDIiP0'},
#  '--kyWqclQ24': {'annotations': {'label': 'cutting cake',
#    'segment': [256.0, 266.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--kyWqclQ24'},
#  '--lmBtwsdBc': {'annotations': {'label': 'visiting the zoo',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--lmBtwsdBc'},
#  '--loSjz82iU': {'annotations': {'label': 'marriage proposal',
#    'segment': [83.0, 93.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--loSjz82iU'},
#  '--lrRHlpK68': {'annotations': {'label': 'petting animal (not cat)',
#    'segment': [218.0, 228.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--lrRHlpK68'},
#  '--lvipPLwp0': {'annotations': {'label': 'egg hunting',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--lvipPLwp0'},
#  '--mBL7P45yE': {'annotations': {'label': 'planting trees',
#    'segment': [394.0, 404.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--mBL7P45yE'},
#  '--mI_-gaZLk': {'annotations': {'label': 'biking through snow',
#    'segment': [18.0, 28.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--mI_-gaZLk'},
#  '--mLOzFpQoo': {'annotations': {'label': 'playing ping pong',
#    'segment': [7.0, 17.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--mLOzFpQoo'},
#  '--mQfG6Wu48': {'annotations': {'label': 'brushing teeth',
#    'segment': [28.0, 38.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--mQfG6Wu48'},
#  '--mTlk9ommA': {'annotations': {'label': 'dribbling basketball',
#    'segment': [48.0, 58.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--mTlk9ommA'},
#  '--o545tThdQ': {'annotations': {'label': 'capoeira', 'segment': [88.0, 98.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--o545tThdQ'},
#  '--oC9hBSmGs': {'annotations': {'label': 'cutting nails',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--oC9hBSmGs'},
#  '--oEIzy6Esc': {'annotations': {'label': 'bouncing on trampoline',
#    'segment': [45.0, 55.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--oEIzy6Esc'},
#  '--oGGqMZmAA': {'annotations': {'label': 'battle rope training',
#    'segment': [7.0, 17.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--oGGqMZmAA'},
#  '--oJV4vFNeI': {'annotations': {'label': 'triple jump',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--oJV4vFNeI'},
#  '--pe5C6kwVQ': {'annotations': {'label': 'sausage making',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--pe5C6kwVQ'},
#  '--q6ElFyVq0': {'annotations': {'label': 'stomping grapes',
#    'segment': [148.0, 158.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--q6ElFyVq0'},
#  '--qlUJAiVkg': {'annotations': {'label': 'cartwheeling',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--qlUJAiVkg'},
#  '--qyQNsbPnA': {'annotations': {'label': 'playing scrabble',
#    'segment': [164.0, 174.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--qyQNsbPnA'},
#  '--rC9Wkh6HA': {'annotations': {'label': 'changing oil',
#    'segment': [179.0, 189.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--rC9Wkh6HA'},
#  '--rSKL-i6qQ': {'annotations': {'label': 'playing gong',
#    'segment': [32.0, 42.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--rSKL-i6qQ'},
#  '--sCqFa_j-A': {'annotations': {'label': 'lock picking',
#    'segment': [197.0, 207.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--sCqFa_j-A'},
#  '--sGO9m2Was': {'annotations': {'label': 'spinning poi',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--sGO9m2Was'},
#  '--swPW3U9EE': {'annotations': {'label': 'tossing salad',
#    'segment': [255.0, 265.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--swPW3U9EE'},
#  '--uD0h1Rpvc': {'annotations': {'label': 'playing marbles',
#    'segment': [24.0, 34.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--uD0h1Rpvc'},
#  '--uqWcqI1kY': {'annotations': {'label': 'shearing sheep',
#    'segment': [126.0, 136.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--uqWcqI1kY'},
#  '--vWkSa7Po8': {'annotations': {'label': 'photocopying',
#    'segment': [67.0, 77.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--vWkSa7Po8'},
#  '--vs4LFYKc8': {'annotations': {'label': 'sword fighting',
#    'segment': [273.0, 283.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--vs4LFYKc8'},
#  '--wGzXrj0SU': {'annotations': {'label': 'making snowman',
#    'segment': [20.0, 30.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--wGzXrj0SU'},
#  '--wPB1D20NE': {'annotations': {'label': 'changing wheel (not on bike)',
#    'segment': [236.0, 246.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--wPB1D20NE'},
#  '--wYHtYMK9o': {'annotations': {'label': 'hula hooping',
#    'segment': [8.0, 18.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--wYHtYMK9o'},
#  '--xD8NX4lxQ': {'annotations': {'label': 'rock scissors paper',
#    'segment': [18.0, 28.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--xD8NX4lxQ'},
#  '--xtMMzsKgM': {'annotations': {'label': 'lock picking',
#    'segment': [34.0, 44.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--xtMMzsKgM'},
#  '--yCUKj4Oq4': {'annotations': {'label': 'clean and jerk',
#    'segment': [18.0, 28.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=--yCUKj4Oq4'},
#  '-0-s1eu4sF4': {'annotations': {'label': 'milking cow',
#    'segment': [31.0, 41.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0-s1eu4sF4'},
#  '-002n8G5Ty0': {'annotations': {'label': 'threading needle',
#    'segment': [27.0, 37.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-002n8G5Ty0'},
#  '-00fzD4K6aw': {'annotations': {'label': 'somersaulting',
#    'segment': [7.0, 17.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-00fzD4K6aw'},
#  '-00nar1nEPc': {'annotations': {'label': 'playing harmonica',
#    'segment': [33.0, 43.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-00nar1nEPc'},
#  '-01PKgtzCxc': {'annotations': {'label': 'passing American football (not in game)',
#    'segment': [34.0, 44.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-01PKgtzCxc'},
#  '-01cbva4erQ': {'annotations': {'label': 'clay pottery making',
#    'segment': [7.0, 17.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-01cbva4erQ'},
#  '-01mKR1_Yoo': {'annotations': {'label': 'entering church',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-01mKR1_Yoo'},
#  '-02UO1KSdZ0': {'annotations': {'label': 'counting money',
#    'segment': [25.0, 35.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-02UO1KSdZ0'},
#  '-02uQdK46rE': {'annotations': {'label': 'shaving legs',
#    'segment': [40.0, 50.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-02uQdK46rE'},
#  '-05APhKiIXc': {'annotations': {'label': 'golf chipping',
#    'segment': [70.0, 80.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-05APhKiIXc'},
#  '-06S_2g51gY': {'annotations': {'label': 'opening wine bottle',
#    'segment': [22.0, 32.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-06S_2g51gY'},
#  '-06VQYu3JkE': {'annotations': {'label': 'person collecting garbage',
#    'segment': [23.0, 33.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-06VQYu3JkE'},
#  '-06eY3PEL9k': {'annotations': {'label': 'massaging neck',
#    'segment': [112.0, 122.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-06eY3PEL9k'},
#  '-06mGUmXQ5M': {'annotations': {'label': 'side kick',
#    'segment': [13.0, 23.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-06mGUmXQ5M'},
#  '-081qTv9fXc': {'annotations': {'label': 'waxing chest',
#    'segment': [216.0, 226.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-081qTv9fXc'},
#  '-08KE5FkRUU': {'annotations': {'label': 'hurling (sport)',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-08KE5FkRUU'},
#  '-08O1DDPotw': {'annotations': {'label': 'grinding meat',
#    'segment': [2.0, 12.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-08O1DDPotw'},
#  '-09lBxmFoWE': {'annotations': {'label': 'front raises',
#    'segment': [30.0, 40.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-09lBxmFoWE'},
#  '-0AFA2OVzn0': {'annotations': {'label': 'breakdancing',
#    'segment': [19.0, 29.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0AFA2OVzn0'},
#  '-0CNBzthkZ4': {'annotations': {'label': 'brushing hair',
#    'segment': [4.0, 14.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0CNBzthkZ4'},
#  '-0COMyPvkHU': {'annotations': {'label': 'getting a tattoo',
#    'segment': [61.0, 71.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0COMyPvkHU'},
#  '-0DTZ_WbuEQ': {'annotations': {'label': 'fencing (sport)',
#    'segment': [13.0, 23.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0DTZ_WbuEQ'},
#  '-0EMaXGGM34': {'annotations': {'label': 'krumping', 'segment': [4.0, 14.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0EMaXGGM34'},
#  '-0ES_MVrg1A': {'annotations': {'label': 'building sandcastle',
#    'segment': [106.0, 116.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0ES_MVrg1A'},
#  '-0EXMXaj77A': {'annotations': {'label': 'feeding birds',
#    'segment': [62.0, 72.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0EXMXaj77A'},
#  '-0Eu83ggVq4': {'annotations': {'label': 'shaving head',
#    'segment': [235.0, 245.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0Eu83ggVq4'},
#  '-0EvnroWpVc': {'annotations': {'label': 'using a microscope',
#    'segment': [2.0, 12.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0EvnroWpVc'},
#  '-0FwN4ESkWY': {'annotations': {'label': 'playing pinball',
#    'segment': [123.0, 133.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0FwN4ESkWY'},
#  '-0G7LzcNhfU': {'annotations': {'label': 'driving tractor',
#    'segment': [37.0, 47.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0G7LzcNhfU'},
#  '-0H3T2B9PH4': {'annotations': {'label': 'pushing wheelchair',
#    'segment': [25.0, 35.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0H3T2B9PH4'},
#  '-0HKFF7F_BY': {'annotations': {'label': 'yawning', 'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0HKFF7F_BY'},
#  '-0HOXzejQVw': {'annotations': {'label': 'huddling', 'segment': [18.0, 28.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0HOXzejQVw'},
#  '-0HOiRx82ts': {'annotations': {'label': 'bandaging',
#    'segment': [26.0, 36.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0HOiRx82ts'},
#  '-0HRnFhCDdc': {'annotations': {'label': 'shaking hands',
#    'segment': [26.0, 36.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0HRnFhCDdc'},
#  '-0HgQ31lcNM': {'annotations': {'label': 'climbing a rope',
#    'segment': [13.0, 23.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0HgQ31lcNM'},
#  '-0IEt9-NeV4': {'annotations': {'label': 'sailing',
#    'segment': [637.0, 647.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0IEt9-NeV4'},
#  '-0IWdKhiWTs': {'annotations': {'label': 'tapping pen',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0IWdKhiWTs'},
#  '-0IoUizxRgg': {'annotations': {'label': 'playing rubiks cube',
#    'segment': [65.0, 75.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0IoUizxRgg'},
#  '-0IwCS6Gbjs': {'annotations': {'label': 'playing flute',
#    'segment': [20.0, 30.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0IwCS6Gbjs'},
#  '-0JU38ZQOlY': {'annotations': {'label': 'canoeing or kayaking',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0JU38ZQOlY'},
#  '-0KZHI6UISM': {'annotations': {'label': 'cracking knuckles',
#    'segment': [4.0, 14.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0KZHI6UISM'},
#  '-0L4fgr5GE0': {'annotations': {'label': 'motorcycling',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0L4fgr5GE0'},
#  '-0L4z8D2eGs': {'annotations': {'label': 'belly dancing',
#    'segment': [43.0, 53.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0L4z8D2eGs'},
#  '-0Li7rc78jQ': {'annotations': {'label': 'motorcycling',
#    'segment': [128.0, 138.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0Li7rc78jQ'},
#  '-0LoCy0-F9A': {'annotations': {'label': 'hula hooping',
#    'segment': [18.0, 28.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0LoCy0-F9A'},
#  '-0M6S1qBn8s': {'annotations': {'label': 'changing oil',
#    'segment': [243.0, 253.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0M6S1qBn8s'},
#  '-0MLLn0Zg1M': {'annotations': {'label': 'sailing', 'segment': [15.0, 25.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0MLLn0Zg1M'},
#  '-0Mfuocujdg': {'annotations': {'label': 'climbing tree',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0Mfuocujdg'},
#  '-0N5cgaMCfY': {'annotations': {'label': 'ice fishing',
#    'segment': [316.0, 326.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0N5cgaMCfY'},
#  '-0NIbu2PBlM': {'annotations': {'label': 'push up', 'segment': [29.0, 39.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0NIbu2PBlM'},
#  '-0NOgzGpSEY': {'annotations': {'label': 'crawling baby',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0NOgzGpSEY'},
#  '-0OK3nbLKgM': {'annotations': {'label': 'waking up',
#    'segment': [12.0, 22.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0OK3nbLKgM'},
#  '-0QQoIK10U8': {'annotations': {'label': 'shaping bread dough',
#    'segment': [22.0, 32.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0QQoIK10U8'},
#  '-0R6wpipD-c': {'annotations': {'label': 'eating spaghetti',
#    'segment': [35.0, 45.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0R6wpipD-c'},
#  '-0SUZKVInwE': {'annotations': {'label': 'tap dancing',
#    'segment': [81.0, 91.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0SUZKVInwE'},
#  '-0TewuHEBe8': {'annotations': {'label': 'training dog',
#    'segment': [38.0, 48.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0TewuHEBe8'},
#  '-0UhLeBCvHE': {'annotations': {'label': 'base jumping',
#    'segment': [36.0, 46.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0UhLeBCvHE'},
#  '-0VIriroDbc': {'annotations': {'label': 'watering plants',
#    'segment': [78.0, 88.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0VIriroDbc'},
#  '-0WBheGENmk': {'annotations': {'label': 'skipping rope',
#    'segment': [9.0, 19.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0WBheGENmk'},
#  '-0WL_HWewTE': {'annotations': {'label': 'getting a haircut',
#    'segment': [25.0, 35.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0WL_HWewTE'},
#  '-0WZKTu0xNk': {'annotations': {'label': 'wrapping present',
#    'segment': [112.0, 122.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0WZKTu0xNk'},
#  '-0YdR9X0XGw': {'annotations': {'label': 'putting in contact lenses',
#    'segment': [14.0, 24.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0YdR9X0XGw'},
#  '-0ZxijKLTgE': {'annotations': {'label': 'fixing bicycle',
#    'segment': [204.0, 214.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0ZxijKLTgE'},
#  '-0_-I3SnlOY': {'annotations': {'label': 'riding camel',
#    'segment': [65.0, 75.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0_-I3SnlOY'},
#  '-0_5tJuIrJA': {'annotations': {'label': 'zumba', 'segment': [4.0, 14.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0_5tJuIrJA'},
#  '-0_SNslrp4c': {'annotations': {'label': 'shucking oysters',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0_SNslrp4c'},
#  '-0_dVfNdhbs': {'annotations': {'label': 'playing trumpet',
#    'segment': [21.0, 31.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0_dVfNdhbs'},
#  '-0aDlftNdyw': {'annotations': {'label': 'eating watermelon',
#    'segment': [280.0, 290.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0aDlftNdyw'},
#  '-0ahlURSzu8': {'annotations': {'label': 'passing American football (in game)',
#    'segment': [53.0, 63.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0ahlURSzu8'},
#  '-0bxrYDcTiw': {'annotations': {'label': 'karaoke',
#    'segment': [162.0, 172.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0bxrYDcTiw'},
#  '-0cOo0cRVZU': {'annotations': {'label': 'shooting basketball',
#    'segment': [8.0, 18.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0cOo0cRVZU'},
#  '-0cS8MCIJZY': {'annotations': {'label': 'playing flute',
#    'segment': [6.0, 16.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0cS8MCIJZY'},
#  '-0cwhOAsODg': {'annotations': {'label': 'blowing nose',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0cwhOAsODg'},
#  '-0eFCgzIWFk': {'annotations': {'label': 'riding unicycle',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0eFCgzIWFk'},
#  '-0eNQsFHAUU': {'annotations': {'label': 'embroidering',
#    'segment': [270.0, 280.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0eNQsFHAUU'},
#  '-0eUJLYCmbs': {'annotations': {'label': 'making pizza',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0eUJLYCmbs'},
#  '-0edhdVNyYk': {'annotations': {'label': 'cooking sausages (not on barbeque)',
#    'segment': [47.0, 57.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0edhdVNyYk'},
#  '-0ejPniVcVk': {'annotations': {'label': 'grooming horse',
#    'segment': [20.0, 30.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0ejPniVcVk'},
#  '-0ew-c0w7uc': {'annotations': {'label': 'faceplanting',
#    'segment': [2.0, 12.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0ew-c0w7uc'},
#  '-0ex2By5d8A': {'annotations': {'label': 'leatherworking',
#    'segment': [373.0, 383.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0ex2By5d8A'},
#  '-0fgJPN0quo': {'annotations': {'label': 'somersaulting',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0fgJPN0quo'},
#  '-0g3eQYArEg': {'annotations': {'label': 'hugging baby',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0g3eQYArEg'},
#  '-0gO3FmnKD8': {'annotations': {'label': 'unboxing',
#    'segment': [135.0, 145.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0gO3FmnKD8'},
#  '-0iEJNyGUxg': {'annotations': {'label': 'playing trumpet',
#    'segment': [60.0, 70.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0iEJNyGUxg'},
#  '-0ip4JazGXY': {'annotations': {'label': 'getting a tattoo',
#    'segment': [18.0, 28.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0ip4JazGXY'},
#  '-0jgbzOKS6c': {'annotations': {'label': 'playing mahjong',
#    'segment': [1691.0, 1701.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0jgbzOKS6c'},
#  '-0khAHlKFlk': {'annotations': {'label': 'threading needle',
#    'segment': [56.0, 66.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0khAHlKFlk'},
#  '-0l0rX2564k': {'annotations': {'label': 'swinging on something',
#    'segment': [16.0, 26.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0l0rX2564k'},
#  '-0lfUaTIAEs': {'annotations': {'label': 'high kick', 'segment': [4.0, 14.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0lfUaTIAEs'},
#  '-0lqH3xAz6M': {'annotations': {'label': 'snowkiting',
#    'segment': [14.0, 24.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0lqH3xAz6M'},
#  '-0o2B1AEdoQ': {'annotations': {'label': 'cleaning toilet',
#    'segment': [7.0, 17.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0o2B1AEdoQ'},
#  '-0oJSXJgt7Q': {'annotations': {'label': 'assembling computer',
#    'segment': [157.0, 167.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0oJSXJgt7Q'},
#  '-0oKIpIC9Zk': {'annotations': {'label': 'tying knot (not on a tie)',
#    'segment': [19.0, 29.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0oKIpIC9Zk'},
#  '-0oMsq-9b6c': {'annotations': {'label': 'sanding floor',
#    'segment': [95.0, 105.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0oMsq-9b6c'},
#  '-0oOhwW5i8I': {'annotations': {'label': 'opening door',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0oOhwW5i8I'},
#  '-0oPhBUAr20': {'annotations': {'label': 'throwing ball (not baseball or American football)',
#    'segment': [32.0, 42.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0oPhBUAr20'},
#  '-0p4vG6a5gY': {'annotations': {'label': 'tying shoe laces',
#    'segment': [86.0, 96.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0p4vG6a5gY'},
#  '-0pMQbEe8Po': {'annotations': {'label': 'jumping bicycle',
#    'segment': [5.0, 15.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0pMQbEe8Po'},
#  '-0pgwqEYYZE': {'annotations': {'label': 'parasailing',
#    'segment': [61.0, 71.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0pgwqEYYZE'},
#  '-0qOFqf_eRk': {'annotations': {'label': 'hand washing clothes',
#    'segment': [54.0, 64.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0qOFqf_eRk'},
#  '-0qZJQXGBi4': {'annotations': {'label': 'tying knot (not on a tie)',
#    'segment': [24.0, 34.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0qZJQXGBi4'},
#  '-0r6NmrdKCU': {'annotations': {'label': 'making tea',
#    'segment': [43.0, 53.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0r6NmrdKCU'},
#  '-0sNYhpevoU': {'annotations': {'label': "massaging person's head",
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0sNYhpevoU'},
#  '-0sXtbpbKSk': {'annotations': {'label': 'winking', 'segment': [12.0, 22.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0sXtbpbKSk'},
#  '-0t56gwcfNo': {'annotations': {'label': 'eating doughnuts',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0t56gwcfNo'},
#  '-0tCqGtAVmY': {'annotations': {'label': 'playing pinball',
#    'segment': [113.0, 123.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0tCqGtAVmY'},
#  '-0tftZyvJZI': {'annotations': {'label': 'shooting goal (soccer)',
#    'segment': [98.0, 108.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0tftZyvJZI'},
#  '-0tjNvMa1V0': {'annotations': {'label': 'fly tying',
#    'segment': [74.0, 84.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0tjNvMa1V0'},
#  '-0tnFi1az8k': {'annotations': {'label': 'bench pressing',
#    'segment': [14.0, 24.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0tnFi1az8k'},
#  '-0uYwPkdl1M': {'annotations': {'label': 'preparing salad',
#    'segment': [163.0, 173.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0uYwPkdl1M'},
#  '-0wIRDnzOxs': {'annotations': {'label': 'poking bellybutton',
#    'segment': [252.0, 262.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0wIRDnzOxs'},
#  '-0yP0wBW_uQ': {'annotations': {'label': 'cartwheeling',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0yP0wBW_uQ'},
#  '-0yQNq-O7dw': {'annotations': {'label': 'longboarding',
#    'segment': [5.0, 15.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0yQNq-O7dw'},
#  '-0y_lDefNlc': {'annotations': {'label': 'cleaning pool',
#    'segment': [140.0, 150.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0y_lDefNlc'},
#  '-0zGo1-PIjs': {'annotations': {'label': 'opening bottle (not wine)',
#    'segment': [22.0, 32.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-0zGo1-PIjs'},
#  '-1-_dKO7AHo': {'annotations': {'label': 'shaving head',
#    'segment': [193.0, 203.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-1-_dKO7AHo'},
#  '-1-kRjKWOjs': {'annotations': {'label': 'crossing eyes',
#    'segment': [9.0, 19.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-1-kRjKWOjs'},
#  '-10MQYniGkQ': {'annotations': {'label': 'putting on eyeliner',
#    'segment': [79.0, 89.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-10MQYniGkQ'},
#  '-10xhPhBo0k': {'annotations': {'label': 'arm wrestling',
#    'segment': [498.0, 508.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-10xhPhBo0k'},
#  '-11PBE3gMto': {'annotations': {'label': 'snowmobiling',
#    'segment': [583.0, 593.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-11PBE3gMto'},
#  '-11n_khUXYo': {'annotations': {'label': 'twiddling fingers',
#    'segment': [13.0, 23.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-11n_khUXYo'},
#  '-12MxdP5uVo': {'annotations': {'label': 'welding', 'segment': [14.0, 24.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-12MxdP5uVo'},
#  '-12udL182q4': {'annotations': {'label': 'jumping sofa',
#    'segment': [44.0, 54.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-12udL182q4'},
#  '-12y8XXUDOA': {'annotations': {'label': 'tossing salad',
#    'segment': [164.0, 174.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-12y8XXUDOA'},
#  '-141JLtnH-c': {'annotations': {'label': 'blowing nose',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-141JLtnH-c'},
#  '-14xu6_7b68': {'annotations': {'label': 'jumping sofa',
#    'segment': [25.0, 35.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-14xu6_7b68'},
#  '-157wqwwtAo': {'annotations': {'label': 'changing oil',
#    'segment': [26.0, 36.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-157wqwwtAo'},
#  '-15OAjLm520': {'annotations': {'label': 'swimming butterfly stroke',
#    'segment': [6.0, 16.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-15OAjLm520'},
#  '-15UpGVyV4w': {'annotations': {'label': 'feeding fish',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-15UpGVyV4w'},
#  '-15bzogKBOM': {'annotations': {'label': 'ironing', 'segment': [99.0, 109.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-15bzogKBOM'},
#  '-161TxPabEQ': {'annotations': {'label': 'sanding floor',
#    'segment': [38.0, 48.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-161TxPabEQ'},
#  '-165n2L_oCY': {'annotations': {'label': 'cutting orange',
#    'segment': [65.0, 75.0]},
#   'duration': 10.0,
# ...
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6YpsicTcOs'},
#  '-6ZX7W-U-XE': {'annotations': {'label': 'opening coconuts',
#    'segment': [150.0, 160.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6ZX7W-U-XE'},
#  '-6audZPiHAE': {'annotations': {'label': 'spinning poi',
#    'segment': [232.0, 242.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6audZPiHAE'},
#  '-6d7xfYKptE': {'annotations': {'label': 'riding camel',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6d7xfYKptE'},
#  '-6dpMzaBUdM': {'annotations': {'label': 'dodgeball',
#    'segment': [59.0, 69.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6dpMzaBUdM'},
#  '-6dvnbAds1Y': {'annotations': {'label': 'snatch weight lifting',
#    'segment': [20.0, 30.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6dvnbAds1Y'},
#  '-6eJHGNWfOo': {'annotations': {'label': 'poking bellybutton',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6eJHGNWfOo'},
#  '-6ePGACa28k': {'annotations': {'label': 'front raises',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6ePGACa28k'},
#  '-6eQ36dDvg8': {'annotations': {'label': 'running on treadmill',
#    'segment': [59.0, 69.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6eQ36dDvg8'},
#  '-6ezg_-7Bck': {'annotations': {'label': 'falling off chair',
#    'segment': [10.0, 20.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6ezg_-7Bck'},
#  '-6f_erh-smY': {'annotations': {'label': 'rock scissors paper',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6f_erh-smY'},
#  '-6fbWHuoX1s': {'annotations': {'label': 'wrapping present',
#    'segment': [389.0, 399.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6fbWHuoX1s'},
#  '-6hrJT07lKk': {'annotations': {'label': 'headbanging',
#    'segment': [64.0, 74.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6hrJT07lKk'},
#  '-6hrRW9IpKA': {'annotations': {'label': 'tickling', 'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6hrRW9IpKA'},
#  '-6hsbWBHZrE': {'annotations': {'label': 'dancing macarena',
#    'segment': [13.0, 23.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6hsbWBHZrE'},
#  '-6i6pP8ImR4': {'annotations': {'label': 'playing ice hockey',
#    'segment': [18.0, 28.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6i6pP8ImR4'},
#  '-6iK0MlUtf4': {'annotations': {'label': 'needle felting',
#    'segment': [2870.0, 2880.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6iK0MlUtf4'},
#  '-6j0i3VqyiY': {'annotations': {'label': 'walking through snow',
#    'segment': [22.0, 32.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6j0i3VqyiY'},
#  '-6kJpuLAi0A': {'annotations': {'label': 'riding unicycle',
#    'segment': [113.0, 123.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6kJpuLAi0A'},
#  '-6l2F9_T5ik': {'annotations': {'label': 'playing dominoes',
#    'segment': [20.0, 30.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6l2F9_T5ik'},
#  '-6lU6QJ1twg': {'annotations': {'label': 'looking at phone',
#    'segment': [69.0, 79.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6lU6QJ1twg'},
#  '-6oPU9T5y1I': {'annotations': {'label': 'shaking head',
#    'segment': [18.0, 28.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6oPU9T5y1I'},
#  '-6ouZMNoQOY': {'annotations': {'label': 'making bubbles',
#    'segment': [2.0, 12.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6ouZMNoQOY'},
#  '-6pAm_WhJgg': {'annotations': {'label': 'playing dominoes',
#    'segment': [2.0, 12.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6pAm_WhJgg'},
#  '-6pdXuaNA88': {'annotations': {'label': 'sled dog racing',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6pdXuaNA88'},
#  '-6r1Tak9ypw': {'annotations': {'label': 'popping balloons',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6r1Tak9ypw'},
#  '-6rLmGwSr0w': {'annotations': {'label': 'pushing car',
#    'segment': [10.0, 20.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6rLmGwSr0w'},
#  '-6rd6BQQM_g': {'annotations': {'label': 'bandaging',
#    'segment': [24.0, 34.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6rd6BQQM_g'},
#  '-6rw93OApcc': {'annotations': {'label': 'presenting weather forecast',
#    'segment': [10.0, 20.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6rw93OApcc'},
#  '-6sI9s723MM': {'annotations': {'label': 'talking on cell phone',
#    'segment': [252.0, 262.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6sI9s723MM'},
#  '-6serjeIHyE': {'annotations': {'label': 'chiseling stone',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6serjeIHyE'},
#  '-6smYhRgWsw': {'annotations': {'label': 'twiddling fingers',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6smYhRgWsw'},
#  '-6tk1dzeCmA': {'annotations': {'label': 'bottling',
#    'segment': [144.0, 154.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6tk1dzeCmA'},
#  '-6u7lnRGS58': {'annotations': {'label': 'milking cow',
#    'segment': [184.0, 194.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6u7lnRGS58'},
#  '-6uDYYvaxqc': {'annotations': {'label': 'steer roping',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6uDYYvaxqc'},
#  '-6uMDIuOfGA': {'annotations': {'label': 'capsizing',
#    'segment': [58.0, 68.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6uMDIuOfGA'},
#  '-6uNJNQKvO8': {'annotations': {'label': 'hammer throw',
#    'segment': [2.0, 12.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6uNJNQKvO8'},
#  '-6u_avnE7So': {'annotations': {'label': 'riding a bike',
#    'segment': [30.0, 40.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6u_avnE7So'},
#  '-6uc4CaBkoQ': {'annotations': {'label': 'ice climbing',
#    'segment': [19.0, 29.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6uc4CaBkoQ'},
#  '-6usjfP8hys': {'annotations': {'label': 'riding camel',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6usjfP8hys'},
#  '-6wJNL8d5jA': {'annotations': {'label': 'shaking head',
#    'segment': [12.0, 22.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6wJNL8d5jA'},
#  '-6wNVod8iag': {'annotations': {'label': 'playing piano',
#    'segment': [377.0, 387.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6wNVod8iag'},
#  '-6wjzvTpF6s': {'annotations': {'label': 'waving hand',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6wjzvTpF6s'},
#  '-6wkYqjFei0': {'annotations': {'label': 'walking the dog',
#    'segment': [15.0, 25.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6wkYqjFei0'},
#  '-6xAzSJcp_A': {'annotations': {'label': 'bookbinding',
#    'segment': [41.0, 51.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6xAzSJcp_A'},
#  '-6xaLevd_z4': {'annotations': {'label': 'blowing out candles',
#    'segment': [38.0, 48.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6xaLevd_z4'},
#  '-6y3YkJOxy8': {'annotations': {'label': 'playing organ',
#    'segment': [195.0, 205.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6y3YkJOxy8'},
#  '-6y_pEz6SIo': {'annotations': {'label': 'whistling',
#    'segment': [23.0, 33.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6y_pEz6SIo'},
#  '-6yaNVdS-2E': {'annotations': {'label': 'side kick', 'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6yaNVdS-2E'},
#  '-6ykAmBXIr0': {'annotations': {'label': 'parkour', 'segment': [13.0, 23.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6ykAmBXIr0'},
#  '-6zujL8vGGg': {'annotations': {'label': 'stretching arm',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-6zujL8vGGg'},
#  '-7--fzZE2qk': {'annotations': {'label': 'peeling apples',
#    'segment': [185.0, 195.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-7--fzZE2qk'},
#  '-7-ED1IlHmw': {'annotations': {'label': 'smashing',
#    'segment': [409.0, 419.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-7-ED1IlHmw'},
#  '-70nvwi_zNw': {'annotations': {'label': 'faceplanting',
#    'segment': [34.0, 44.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-70nvwi_zNw'},
#  '-722mkcyHOQ': {'annotations': {'label': 'swinging on something',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-722mkcyHOQ'},
#  '-72xNEx6hZo': {'annotations': {'label': 'riding snow blower',
#    'segment': [214.0, 224.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-72xNEx6hZo'},
#  '-738QtnI3cY': {'annotations': {'label': 'playing ping pong',
#    'segment': [11.0, 21.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-738QtnI3cY'},
#  '-73EvXP2mqU': {'annotations': {'label': 'playing beer pong',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-73EvXP2mqU'},
#  '-73Kg-MKmwE': {'annotations': {'label': 'crying', 'segment': [10.0, 20.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-73Kg-MKmwE'},
#  '-73NGni8J7M': {'annotations': {'label': 'riding snow blower',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-73NGni8J7M'},
#  '-73SX7Svd2g': {'annotations': {'label': 'playing harp',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-73SX7Svd2g'},
#  '-73l51DVxIg': {'annotations': {'label': 'drop kicking',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-73l51DVxIg'},
#  '-74ON_5t6-k': {'annotations': {'label': 'massaging legs',
#    'segment': [294.0, 304.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-74ON_5t6-k'},
#  '-74Scce9ses': {'annotations': {'label': 'drumming fingers',
#    'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-74Scce9ses'},
#  '-74ThX0Y1X4': {'annotations': {'label': 'situp', 'segment': [38.0, 48.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-74ThX0Y1X4'},
#  '-74c73MiIes': {'annotations': {'label': 'assembling computer',
#    'segment': [1409.0, 1419.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-74c73MiIes'},
#  '-74csnCOiUs': {'annotations': {'label': 'playing keyboard',
#    'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-74csnCOiUs'},
#  '-758A62O-nE': {'annotations': {'label': 'playing pan pipes',
#    'segment': [43.0, 53.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-758A62O-nE'},
#  '-75bKju6ti0': {'annotations': {'label': 'changing gear in car',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-75bKju6ti0'},
#  '-76h3wRtvRU': {'annotations': {'label': 'clean and jerk',
#    'segment': [13.0, 23.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-76h3wRtvRU'},
#  '-76uJz2GUZE': {'annotations': {'label': 'playing volleyball',
#    'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-76uJz2GUZE'},
#  '-76vHW9l_tc': {'annotations': {'label': 'front raises',
#    'segment': [16.0, 26.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-76vHW9l_tc'},
#  '-7784_WqE1E': {'annotations': {'label': 'eating chips',
#    'segment': [16.0, 26.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-7784_WqE1E'},
#  '-77CumjuStU': {'annotations': {'label': 'bending back',
#    'segment': [63.0, 73.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-77CumjuStU'},
#  '-7883F9N6rM': {'annotations': {'label': 'smoking pipe',
#    'segment': [90.0, 100.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-7883F9N6rM'},
#  '-78VoDdVZqI': {'annotations': {'label': 'doing nails',
#    'segment': [2.0, 12.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-78VoDdVZqI'},
#  '-790qJ_J6XI': {'annotations': {'label': 'polishing metal',
#    'segment': [31.0, 41.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-790qJ_J6XI'},
#  '-79XOVmz-1g': {'annotations': {'label': 'spelunking',
#    'segment': [745.0, 755.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-79XOVmz-1g'},
#  '-79YgFexJcU': {'annotations': {'label': 'laying concrete',
#    'segment': [136.0, 146.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-79YgFexJcU'},
#  '-79hjpC_x6U': {'annotations': {'label': 'sled dog racing',
#    'segment': [20.0, 30.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-79hjpC_x6U'},
#  '-79inICxZTU': {'annotations': {'label': 'threading needle',
#    'segment': [18.0, 28.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-79inICxZTU'},
#  '-7AgKqCl6wo': {'annotations': {'label': 'catching or throwing baseball',
#    'segment': [188.0, 198.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-7AgKqCl6wo'},
#  '-7AnQEQRUjs': {'annotations': {'label': 'front raises',
#    'segment': [8.0, 18.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-7AnQEQRUjs'},
#  '-7AvWF7b0M8': {'annotations': {'label': 'cleaning shoes',
#    'segment': [562.0, 572.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-7AvWF7b0M8'},
#  '-7BVb-zigbA': {'annotations': {'label': 'feeding birds',
#    'segment': [15.0, 25.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-7BVb-zigbA'},
#  '-7BiugaROUM': {'annotations': {'label': 'push up', 'segment': [16.0, 26.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-7BiugaROUM'},
#  ...}

# %% [markdown]
# #### Copy Move And Delete

# %%
output_file = glob.glob(f"Visual_Genome_*_Analysis.csv")
output_file
# Out:
# ['Visual_Genome_Objects_Analysis.csv',
#  'Visual_Genome_Attributes_Analysis.csv',
#  'Visual_Genome_Relationships_Analysis.csv',
#  'Visual_Genome_Question_Answers_Analysis.csv',
#  'Visual_Genome_Region_Descriptions_Analysis.csv',
#  'Visual_Genome_Images_Analysis.csv']

# %%
for l in output_file:
    source = l # source directory
    destination = path
    shutil.copy2(source, destination)

# %%
for j in output_file:
    try:
        os.remove(j)
    except:
        pass
