# %% [markdown]
# ### Custom Name Entity Check Func

# %%
import pandas as pd
import numpy as np
from itertools import islice
import re

# %%
word_list = ["ramiro", "Thomas", "Peter","Arthur", "Kirkland", "Sizi","Ertugrul", "Gregor", "$ali", "20str", "evet","neden"]

# %%
# df_word = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Pyspark/Product/Sentence_Single.xlsx")
# df_word

# %%
with open("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Pyspark/ReDe/xaa.tr", "r",encoding="latin1") as file:
    text = file.read()

# %%
digit_and_not_alnum = []
string_word = []
#for i in df_word.sentence:
for i in word_list:
    i = str(i)
    if not(i[0].isalnum()) or i[0].isdigit():
        digit_and_not_alnum.append(i)
    else:
        string_word.append(i)

# %%
# # 1-Way
# special_name_list = []  
# for j in string_word:
#     var1_list = re.findall(f"(?:\s|^){j}(?:\s|$)", text, flags=re.IGNORECASE)
#     var2_list = []
#     for k in var1_list:
#         k = re.findall(r'\w+', k)
#         var2_list.append(k[0])
#     upper_list = []
#     lower_list = []
#     for m in var2_list:
#         if m[0] == m[0].upper():
#             upper_list.append(m)
#         else:
#             lower_list.append(m)
#     if round((len(upper_list))/(len(upper_list)+len(lower_list)+0.1)*100,5) >= 99:
#         special_name_list.append(j.capitalize())
#     else:
#         pass
# special_name_list

# %%
# # 2-Way
# special_name_list = []  
# for j in string_word:
#     var1_list = re.findall(f"(?:\s|^){j}(?:\s|$)", text, flags=re.IGNORECASE)
#     upper_list = []
#     lower_list = []
#     for m in var1_list:
#         if m[0] == m[0].upper():
#             upper_list.append(m)
#         else:
#             lower_list.append(m)
#     if round((len(upper_list))/(len(upper_list)+len(lower_list)+0.1)*100,5) >= 99:
#         special_name_list.append(j.capitalize())
#     else:
#         pass
# special_name_list

# %%
# 3-Way      
special_name_list = []  
for j in string_word:
    var1_list = []
    limit = 100
    for x in islice(re.finditer(f"(?:\s|^){j}(?:\s|$)", text, flags=re.IGNORECASE), limit):
        var1_list.append(x.group())
    upper_list = []
    lower_list = []
    for m in var1_list:
        if m[0] == m[0].upper():
            upper_list.append(m)
        else:
            lower_list.append(m)
    if round((len(upper_list))/(len(upper_list)+len(lower_list)+0.1)*100,5) >= 99:
        special_name_list.append(j.capitalize())
    else:
        pass
special_name_list
# Out:
# ['Thomas', 'Peter', 'Arthur', 'Kirkland', 'Sizi', 'Evet', 'Neden']

# %%
from itertools import islice
import re

limit = 100
var3_list = []
for x in islice(re.finditer(f"(?:\s|^)Arthur(?:\s|$)", text, flags=re.IGNORECASE), limit):
    var3_list.append(x.group())

# %%
len(var3_list)
# Out:
# 333

# %%
upper_list = []
        lower_list = []
        if str(m[0]) == str(m[0].upper()):
            upper_list.append(m)
        else:
            lower_list.append(m)

# %%
test_list = re.findall(f"(?:\s|^)Arthur(?:\s|$)", text, flags=re.IGNORECASE)
test_list
# Out:
# [' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ']

# %%
while len(re.findall(f"(?:\s|^)Arthur(?:\s|$)", text, flags=re.IGNORECASE)) < 11:
    var1_list = re.findall(f"(?:\s|^)Arthur(?:\s|$)", text, flags=re.IGNORECASE)

# %%
len(var1_list)
# Out:
# 14949

# %%
for k in test_list:
        k = re.findall(r'\w+', k)
        var2_list.append(k[0])

# %%
var2_list
# Out:
# ['neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'Neden',
#  'Neden',
#  'neden',
#  'neden',
#  ...]

# %%
upper_list = []
lower_list = []
for m in test_list:
    if m[0] == m[0].upper():
        upper_list.append(m)
    else:
        lower_list.append(m)

# %%
upper_list
# Out:
# [' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  '\nArthur ',
#  '\nArthur ',
#  '\nArthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ',
#  ' Arthur ']

# %%
len(upper_list)
# Out:
# 333

# %%
lower_list
# Out:
# []

# %%
len(lower_list)
# Out:
# 13568

# %%
[re.findall(r'\w+', k) for k in test_list]
# Out:
# [['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['Neden'],
#  ['Neden'],
#  ['neden'],
#  ['neden'],
#  ...]

# %%
var2_list = []
for k in word_list:
    k = re.findall(r'\w+', k)
    var2_list.append(k[0])

# %%
k[0]
# Out:
# 'zeynep'

# %%
var2_list
# Out:
# ['Ramiro',
#  'Thomas',
#  'Peter',
#  'Arthur',
#  'Kirkland',
#  'Sizi',
#  'Ertugrul',
#  'Gregor',
#  'ali',
#  '20str',
#  'zeynep']

# %%
var2_list = [re.findall(r'\w+', k) for k in test_list]
var2_list
# Out:
# [['Ramiro'], ['Ramiro'], ['Ramiro'], ['Ramiro'], ['Ramiro']]

# %%
digit_and_not_alnum
# Out:
# ['$ali', '20str']

# %%
string_word
# Out:
# ['Ramiro',
#  'Thomas',
#  'Peter',
#  'Arthur',
#  'Kirkland',
#  'Sizi',
#  'Ertugrul',
#  'Gregor']

# %%
word = "ramiro"

# %%
upper_list = []
lower_list = []
if word[0] == word[0].upper():
    upper_list.append(word)
else:
    lower_list.append(word)

# %%
upper_list
# Out:
# []

# %%
lower_list
# Out:
# ['ramiro']

# %%
num = 20

# %%
num = str(num)

# %%
num[0].isdigit()
# Out:
# True

# %%
word[0].isdigit()
# Out:
# True

# %%
not(word[0].isalnum())
# Out:
# False

# %%
str(word[0]) == str(word[0].upper())
# Out:
# True

# %%
limit = 50

# %%
var1_list_test = islice(re.finditer(f"(?:\s|^){j}(?:\s|$)", text, flags=re.IGNORECASE), limit).to_list()

# %%
special_name_list = []  
for j in string_word:
    var1_list = []
    limit = 100
    for x in islice(re.finditer(f"(?:\s|^){j}(?:\s|$)", text, flags=re.IGNORECASE), limit):
        var1_list.append(x.group())
    upper_list = []
    lower_list = []
    for m in var1_list:
        if m[0] == m[0].upper():
            upper_list.append(m)
        else:
            lower_list.append(m)
    if round((len(upper_list))/(len(upper_list)+len(lower_list)+0.1)*100,5) >= 99:
        special_name_list.append(j.capitalize())
    else:
        pass

# %%
import os
from multiprocessing import Process

# %%
digit_and_not_alnum = []
string_word = []
for i in word_list:
    i = str(i)
    if not(i[0].isalnum()) or i[0].isdigit():
        digit_and_not_alnum.append(i)
    else:
        string_word.append(i)

# %%
def find_special_name(word):
    special_name_list = [] 
    var1_list = re.findall(f"(?:\s|^){word}(?:\s|$)", text, flags=re.IGNORECASE)
    upper_list = []
    lower_list = []
    for m in var1_list:
        if m[0] == m[0].upper():
            upper_list.append(m)
        else:
            lower_list.append(m)
    if round((len(upper_list))/(len(upper_list)+len(lower_list)+0.1)*100,5) >= 98:
        special_name_list.append(word.capitalize())
    else:
        pass
    # return special_name_list

# %%
find_special_name("ramiro")
# Out:
# ['Ramiro']

# %%
df_sent = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Pyspark/Result/Clean Spark Sentence Merge/Clean_Spark_Sentence_Merge_Result.csv")
#df_sent = df_sent.sample(100)
df_sent
# Out:
#                                     sentence  frequency     ratio  cumul_ratio
# 0                                       evet    1948596  1.348816     1.348816
# 1                                      hayır    1250401  0.865526     2.214343
# 2                                      tamam     882921  0.611157     2.825500
# 3                                         ne     753105  0.521299     3.346799
# 4                                teşekkürler     343527  0.237789     3.584588
# ...                                      ...        ...       ...          ...
# 20975605      omalley bize buzsuz scotch ver          2  0.000001    99.999994
# 20975606                 omalley bu acele ne          2  0.000001    99.999996
# 20975607              omalley bu milton wing          2  0.000001    99.999997
# 20975608  omalley buna cevap verecek zamanım          2  0.000001    99.999999
# 20975609       avukat ile görüşmek istiyorum          2  0.000001   100.000000
#
# [20975610 rows x 4 columns]

# %%
df_ne = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Pyspark/Product/Special_Name.xlsx")
df_ne.rename(columns={0:"name"}, inplace=True)
df_ne
# Out:
#          name
# 0        Jack
# 1         Sam
# 2        John
# 3     Charlie
# 4     Michael
# ..        ...
# 838     Lucky
# 839       Rod
# 840     Stone
# 841  Brooklyn
# 842      Coco
#
# [843 rows x 1 columns]

# %%
ne_list = [x.lower() for x in df_ne.name]

# %%
def replace_name(x):
    for i in ne_list:
        x = re.sub(fr"(?:\s|^){i}(?:\s|$)", " ali ", x)
        x = x.strip()        
    return x

# %%
df_sent.sentence = df_sent.sentence.apply(lambda x : replace_name(x))
df_sent
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_31117/2213524524.py in <module>
# ----> 1 df_sent.sentence = df_sent.sentence.apply(lambda x : replace_name(x))
#       2 df_sent
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1097                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1098                 # "Callable[[Any], Any]"
# -> 1099                 mapped = lib.map_infer(
#    1100                     values,
#    1101                     f,  # type: ignore[arg-type]
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_31117/2213524524.py in <lambda>(x)
# ----> 1 df_sent.sentence = df_sent.sentence.apply(lambda x : replace_name(x))
#       2 df_sent
#
# /tmp/ipykernel_31117/3807371084.py in replace_name(x)
#       1 def replace_name(x):
#       2     for i in ne_list:
# ----> 3         x = re.sub(fr"(?:\s|^){i}(?:\s|$)", " ali ", x)
#       4         x = x.strip()
#       5     return x
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/re.py in sub(pattern, repl, string, count, flags)
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#     211
#     212 def subn(pattern, repl, string, count=0, flags=0):
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#     306         if len(_cache) >= _MAXCACHE:
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/sre_compile.py in compile(p, flags)
#     766         pattern = None
#     767
# --> 768     code = _code(p, flags)
#     769
#     770     if flags & SRE_FLAG_DEBUG:
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/sre_compile.py in _code(p, flags)
#     602
#     603     # compile info block
# --> 604     _compile_info(code, p, flags)
#     605
#     606     # compile the pattern
#
# KeyboardInterrupt:

# %%
df_sent.iloc[300:350,]
# Out:
#                  sentence  frequency     ratio  cumul_ratio
# 300                  amin      16381  0.011339    14.188189
# 301                  uyan      16359  0.011324    14.199513
# 302          i̇yi misiniz      16262  0.011257    14.210769
# 303         orospu çocuğu      16241  0.011242    14.222011
# 304                 nedir      16196  0.011211    14.233222
# 305  burada ne yapıyorsun      16148  0.011178    14.244400
# 306           henüz değil      16093  0.011140    14.255539
# 307           ben de öyle      16083  0.011133    14.266672
# 308             afedersin      16069  0.011123    14.277795
# 309                    üç      15953  0.011043    14.288838
# 310                 bırak      15827  0.010955    14.299793
# 311           hoşça kalın      15826  0.010955    14.310748
# 312              hayır mı      15769  0.010915    14.321663
# 313              bu kadar      15745  0.010899    14.332562
# 314          tanrı aşkına      15727  0.010886    14.343448
# 315          yemin ederim      15679  0.010853    14.354301
# 316            çık dışarı      15638  0.010825    14.365126
# 317              anlaştık      15622  0.010814    14.375939
# 318               boş ver      15619  0.010811    14.386751
# 319                    ee      15504  0.010732    14.397482
# 320             bırak onu      15450  0.010694    14.408177
# 321            evet tabii      15398  0.010658    14.418835
# 322              oh hayır      15120  0.010466    14.429302
# 323            siktir git      15021  0.010398    14.439699
# 324         öyle değil mi      15014  0.010393    14.450092
# 325           majesteleri      14956  0.010353    14.460444
# 326      bir sorun mu var      14906  0.010318    14.470762
# 327         hemen dönerim      14883  0.010302    14.481064
# 328            bir iki üç      14852  0.010281    14.491345
# 329                beyler      14835  0.010269    14.501613
# 330                 naber      14714  0.010185    14.511798
# 331        bu kadar yeter      14685  0.010165    14.521963
# 332         ben gidiyorum      14684  0.010164    14.532128
# 333               charlie      14606  0.010110    14.542238
# 334      çok özür dilerim      14578  0.010091    14.552329
# 335             ne dersin      14566  0.010083    14.562411
# 336             duydun mu      14524  0.010054    14.572465
# 337           bir şey yok      14464  0.010012    14.582477
# 338    burada ne işin var      14392  0.009962    14.592439
# 339              dinleyin      14378  0.009952    14.602391
# 340               michael      14360  0.009940    14.612331
# 341               yürüyün      14335  0.009923    14.622254
# 342            sakin olun      14308  0.009904    14.632158
# 343             kımıldama      14262  0.009872    14.642030
# 344             dur biraz      14248  0.009862    14.651893
# 345             cidden mi      14239  0.009856    14.661749
# 346                  öldü      14225  0.009847    14.671595
# 347                 aptal      14165  0.009805    14.681400
# 348               ne dedi      14160  0.009802    14.691202
# 349           benimle gel      14149  0.009794    14.700996

# %%
df_sent.to_csv("Name_Entity_Change_Sentence.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_31117/982309174.py in <module>
# ----> 1 df_sent.to_csv("Name_Entity_Change_Sentence.csv", index=False)
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     255             )
#     256
# --> 257             self._save()
#     258
#     259     def _save(self) -> None:
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save(self)
#     260         if self._need_to_save_header:
#     261             self._save_header()
# --> 262         self._save_body()
#     263
#     264     def _save_header(self) -> None:
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save_body(self)
#     298             if start_i >= end_i:
#     299                 break
# --> 300             self._save_chunk(start_i, end_i)
#     301
#     302     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     309
#     310         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 311         libwriters.write_csv_rows(
#     312             data,
#     313             ix,
#
# ~/anaconda3/envs/pyspark_env/lib/python3.9/site-packages/pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:
