# %% [markdown]
# ### Big Query Data

# %%
# pip install --upgrade google-cloud-bigquery

# %%
from google.cloud import bigquery
from google.oauth2 import service_account

# %%
# credentials = service_account.Credentials.from_service_account_file('path/to/file.json')
# 
# project_id = 'my-bq'
# client = bigquery.Client(credentials= credentials,project=project_id)

# %%
# # 1 Way
# query_job = client.query("""
#    SELECT *
#    FROM dataset.my_table
#    LIMIT 1000 """)
# 
# results = query_job.result() # Wait for the job to complete.

# %%
# # 2 Way
# # legancy_sql
# job_config.use_legacy_sql = True
# query_job = client.query("""
#    SELECT *
#    FROM dataset.my_table
#    LIMIT 1000""", job_config = job_config)
# 
# results = query_job.result() # Wait for the job to complete.

# %%
credentials = service_account.Credentials.from_service_account_file(r'C:\Users\Ertuğrul\Downloads\focal-dock-398011-3fccc3365d4c.json')

project_id = 'big query sample project'
client = bigquery.Client(credentials= credentials, project=project_id)

# %%
# 1 Way
query_job = client.query("""
   SELECT *
   FROM 'bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_20210131'
   WHERE user_pseudo_id IN (SELECT user_pseudo_id
   FROM
   (SELECT DISTINCT user_pseudo_id, count(distinct event_date) as day_count FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_*`
   group by user_pseudo_id)
   WHERE day_count > 2) """)

results = query_job.result()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# <ipython-input-13-f7f4c0409d15> in <module>
#       1 # 1 Way
# ----> 2 query_job = client.query("""
#       3    SELECT *
#       4    FROM 'bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_20210131'
#       5    WHERE user_pseudo_id IN (SELECT user_pseudo_id
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\client.py in query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method)
#    3406             )
#    3407         elif api_method == enums.QueryApiMethod.INSERT:
# -> 3408             return _job_helpers.query_jobs_insert(
#    3409                 self,
#    3410                 query,
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\_job_helpers.py in query_jobs_insert(client, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry)
#     112             return query_job
#     113
# --> 114     future = do_query()
#     115     # The future might be in a failed state now, but if it's
#     116     # unrecoverable, we'll find out when we ask for it's result, at which
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\_job_helpers.py in do_query()
#      89
#      90         try:
# ---> 91             query_job._begin(retry=retry, timeout=timeout)
#      92         except core_exceptions.Conflict as create_exc:
#      93             # The thought is if someone is providing their own job IDs and they get
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\job\query.py in _begin(self, client, retry, timeout)
#    1308
#    1309         try:
# -> 1310             super(QueryJob, self)._begin(client=client, retry=retry, timeout=timeout)
#    1311         except exceptions.GoogleAPICallError as exc:
#    1312             exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\job\base.py in _begin(self, client, retry, timeout)
#     691         # job has an ID.
#     692         span_attributes = {"path": path}
# --> 693         api_response = client._call_api(
#     694             retry,
#     695             span_name="BigQuery.job.begin",
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\client.py in _call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     814                 name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     815             ):
# --> 816                 return call()
#     817
#     818         return call()
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\api_core\retry.py in retry_wrapped_func(*args, **kwargs)
#     281                 self._initial, self._maximum, multiplier=self._multiplier
#     282             )
# --> 283             return retry_target(
#     284                 target,
#     285                 self._predicate,
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     188     for sleep in sleep_generator:
#     189         try:
# --> 190             return target()
#     191
#     192         # pylint: disable=broad-except
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\_http\__init__.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout)
#     478
#     479         if not 200 <= response.status_code < 300:
# --> 480             raise exceptions.from_http_response(response)
#     481
#     482         if expect_json and response.content:
#
# BadRequest: 400 POST https://bigquery.googleapis.com/bigquery/v2/projects/big%20query%20sample%20project/jobs?prettyPrint=false: ProjectId and DatasetId must be non-empty
#
# Location: None
# Job ID: 7c370c5a-88fb-4904-9f47-66c2155119f8

# %%
# chatgpt code block
from google.cloud import bigquery

# Kimlik doğrulama dosyasının yolunu belirtin
credentials_path = r"C:\Users\Ertuğrul\Downloads\focal-dock-398011-3fccc3365d4c.json"

# BigQuery istemcisini oluşturun
client = bigquery.Client.from_service_account_json(credentials_path)

# Veri setini ve tabloyu belirtin
project_id = "big query sample project"
dataset_id = "bigquery-public-data.ga4_obfuscated_sample_ecommerce"
table_id = "events_20210131"

# Sorguyu hazırlayın
query = f"SELECT * FROM `{project_id}.{dataset_id}.{table_id}`"

# Sorguyu çalıştırın ve sonuçları alın
query_job = client.query(query)
results = query_job.result()

# Sonuçları işleyin
for row in results:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-14-1c3e271d3655> in <module>
#      16
#      17 # Sorguyu çalıştırın ve sonuçları alın
# ---> 18 query_job = client.query(query)
#      19 results = query_job.result()
#      20
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\client.py in query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method)
#    3406             )
#    3407         elif api_method == enums.QueryApiMethod.INSERT:
# -> 3408             return _job_helpers.query_jobs_insert(
#    3409                 self,
#    3410                 query,
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\_job_helpers.py in query_jobs_insert(client, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry)
#     112             return query_job
#     113
# --> 114     future = do_query()
#     115     # The future might be in a failed state now, but if it's
#     116     # unrecoverable, we'll find out when we ask for it's result, at which
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\_job_helpers.py in do_query()
#      89
#      90         try:
# ---> 91             query_job._begin(retry=retry, timeout=timeout)
#      92         except core_exceptions.Conflict as create_exc:
#      93             # The thought is if someone is providing their own job IDs and they get
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\job\query.py in _begin(self, client, retry, timeout)
#    1308
#    1309         try:
# -> 1310             super(QueryJob, self)._begin(client=client, retry=retry, timeout=timeout)
#    1311         except exceptions.GoogleAPICallError as exc:
#    1312             exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\job\base.py in _begin(self, client, retry, timeout)
#     691         # job has an ID.
#     692         span_attributes = {"path": path}
# --> 693         api_response = client._call_api(
#     694             retry,
#     695             span_name="BigQuery.job.begin",
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\bigquery\client.py in _call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     814                 name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     815             ):
# --> 816                 return call()
#     817
#     818         return call()
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\api_core\retry.py in retry_wrapped_func(*args, **kwargs)
#     281                 self._initial, self._maximum, multiplier=self._multiplier
#     282             )
# --> 283             return retry_target(
#     284                 target,
#     285                 self._predicate,
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     188     for sleep in sleep_generator:
#     189         try:
# --> 190             return target()
#     191
#     192         # pylint: disable=broad-except
#
# c:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\_http\__init__.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout)
#     478
#     479         if not 200 <= response.status_code < 300:
# --> 480             raise exceptions.from_http_response(response)
#     481
#     482         if expect_json and response.content:
#
# Forbidden: 403 POST https://bigquery.googleapis.com/bigquery/v2/projects/focal-dock-398011/jobs?prettyPrint=false: Access Denied: Project focal-dock-398011: User does not have bigquery.jobs.create permission in project focal-dock-398011.
#
# Location: None
# Job ID: b055d321-8926-4e09-a182-7a35a8895b61

# %%
# pip install bq

# %%
import bq

# Project ID ve bölgenizi tanımlayın.
project_id = "focal-dock-398011"
region = "us-central1"

# BigQuery-public-data verilerine erişmek için bir istemci oluşturun.
client = bq.Client(project_id, region=region)

# İndirmek istediğiniz tabloyu seçin.
table_name = "bigquery-public-data.ga4_obfuscated_sample_ecommerce"

# Tabloyu Cloud Storage'a dışa aktarın.
client.extract_table(
    table_name,
    "gs://my-bucket/ga4_obfuscated_sample_ecommerce_events_20210131.csv",
    format="CSV",
    compression="GZIP",
)

# %% [markdown]
# #### Local Data Analysis

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sql = pd.read_csv(r"C:\Users\Ertuğrul\Downloads\bquxjob_7278a706_18a600fffc3.csv")
df_sql
# Out:
#      event_date   event_timestamp   event_name  \
# 0      20201103  1604383924455348    view_item
# 1      20201103  1604412531593015    view_item
# 2      20201103  1604422061072724    view_item
# 3      20201103  1604410252366614    view_item
# 4      20201103  1604372276670321    view_item
# ..          ...               ...          ...
# 935    20210122  1611358943298376    view_item
# 936    20210122  1611358988840916    view_item
# 937    20210122  1611300990568122    view_item
# 938    20210122  1611328158456229  select_item
# 939    20210122  1611327562415002    view_item
#
#                                           event_params  \
# 0    {\n  "event_params": [{\n    "key": "engagemen...
# 1    {\n  "event_params": [{\n    "key": "page_loca...
# 2    {\n  "event_params": [{\n    "key": "ga_sessio...
# 3    {\n  "event_params": [{\n    "key": "clean_eve...
# 4    {\n  "event_params": [{\n    "key": "clean_eve...
# ..                                                 ...
# 935  {\n  "event_params": [{\n    "key": "campaign"...
# 936  {\n  "event_params": [{\n    "key": "ga_sessio...
# 937  {\n  "event_params": [{\n    "key": "engaged_s...
# 938  {\n  "event_params": [{\n    "key": "session_e...
# 939  {\n  "event_params": [{\n    "key": "engagemen...
#
#      event_previous_timestamp  event_value_in_usd  event_bundle_sequence_id  \
# 0                         NaN                 NaN               -9247653259
# 1                         NaN                 NaN               -6517925002
# 2                         NaN                 NaN                3328666858
# 3                         NaN                 NaN                 941146410
# 4                         NaN                 NaN                3714819948
# ..                        ...                 ...                       ...
# 935                       NaN                 NaN               -8263767271
# 936                       NaN                 NaN               -9211643401
# 937                       NaN                 NaN               -9004921919
# 938                       NaN                 NaN                2046165995
# 939                       NaN                 NaN               -8269928213
#
#      event_server_timestamp_offset  user_id  user_pseudo_id  ...  \
# 0                              NaN      NaN    5.841763e+07  ...
# 1                              NaN      NaN    5.881750e+07  ...
# 2                              NaN      NaN    6.107577e+07  ...
# 3                              NaN      NaN    6.246598e+07  ...
# 4                              NaN      NaN    6.320507e+07  ...
# ..                             ...      ...             ...  ...
# 935                            NaN      NaN    9.133428e+06  ...
# 936                            NaN      NaN    9.133428e+06  ...
# 937                            NaN      NaN    1.114502e+07  ...
# 938                            NaN      NaN    1.229183e+07  ...
# 939                            NaN      NaN    1.229183e+07  ...
#
#                                               user_ltv  \
# 0    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 1    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 2    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 3    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 4    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# ..                                                 ...
# 935  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 936  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 937  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 938  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 939  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
#
#                                                 device  \
# 0    {\n  "device": {\n    "category": "desktop",\n...
# 1    {\n  "device": {\n    "category": "mobile",\n ...
# 2    {\n  "device": {\n    "category": "mobile",\n ...
# 3    {\n  "device": {\n    "category": "desktop",\n...
# 4    {\n  "device": {\n    "category": "desktop",\n...
# ..                                                 ...
# 935  {\n  "device": {\n    "category": "desktop",\n...
# 936  {\n  "device": {\n    "category": "desktop",\n...
# 937  {\n  "device": {\n    "category": "desktop",\n...
# 938  {\n  "device": {\n    "category": "desktop",\n...
# 939  {\n  "device": {\n    "category": "desktop",\n...
#
#                                                    geo  \
# 0    {\n  "geo": {\n    "continent": "Americas",\n ...
# 1    {\n  "geo": {\n    "continent": "Americas",\n ...
# 2    {\n  "geo": {\n    "continent": "Asia",\n    "...
# 3    {\n  "geo": {\n    "continent": "Asia",\n    "...
# 4    {\n  "geo": {\n    "continent": "Europe",\n   ...
# ..                                                 ...
# 935  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 936  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 937  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 938  {\n  "geo": {\n    "continent": "Americas",\n ...
# 939  {\n  "geo": {\n    "continent": "Americas",\n ...
#
#                      app_info  \
# 0    {\n  "app_info": null\n}
# 1    {\n  "app_info": null\n}
# 2    {\n  "app_info": null\n}
# 3    {\n  "app_info": null\n}
# 4    {\n  "app_info": null\n}
# ..                        ...
# 935  {\n  "app_info": null\n}
# 936  {\n  "app_info": null\n}
# 937  {\n  "app_info": null\n}
# 938  {\n  "app_info": null\n}
# 939  {\n  "app_info": null\n}
#
#                                         traffic_source   stream_id platform  \
# 0    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 1    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 2    {\n  "traffic_source": {\n    "medium": "\u003...  2100450278      WEB
# 3    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 4    {\n  "traffic_source": {\n    "medium": "(none...  2100450278      WEB
# ..                                                 ...         ...      ...
# 935  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 936  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 937  {\n  "traffic_source": {\n    "medium": "(data...  2100450278      WEB
# 938  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 939  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
#
#                      event_dimensions  \
# 0    {\n  "event_dimensions": null\n}
# 1    {\n  "event_dimensions": null\n}
# 2    {\n  "event_dimensions": null\n}
# 3    {\n  "event_dimensions": null\n}
# 4    {\n  "event_dimensions": null\n}
# ..                                ...
# 935  {\n  "event_dimensions": null\n}
# 936  {\n  "event_dimensions": null\n}
# 937  {\n  "event_dimensions": null\n}
# 938  {\n  "event_dimensions": null\n}
# 939  {\n  "event_dimensions": null\n}
#
#                                              ecommerce  \
# 0    {\n  "ecommerce": {\n    "total_item_quantity"...
# 1    {\n  "ecommerce": {\n    "total_item_quantity"...
# 2    {\n  "ecommerce": {\n    "total_item_quantity"...
# 3    {\n  "ecommerce": {\n    "total_item_quantity"...
# 4    {\n  "ecommerce": {\n    "total_item_quantity"...
# ..                                                 ...
# 935  {\n  "ecommerce": {\n    "total_item_quantity"...
# 936  {\n  "ecommerce": {\n    "total_item_quantity"...
# 937  {\n  "ecommerce": {\n    "total_item_quantity"...
# 938  {\n  "ecommerce": {\n    "total_item_quantity"...
# 939  {\n  "ecommerce": {\n    "total_item_quantity"...
#
#                                                  items
# 0    {\n  "items": [{\n    "item_id": "GGOEGOLA1275...
# 1    {\n  "items": [{\n    "item_id": "GGOEGDHG1622...
# 2    {\n  "items": [{\n    "item_id": "GGOEGXXX1347...
# 3    {\n  "items": [{\n    "item_id": "GGCOGXXX1569...
# 4    {\n  "items": [{\n    "item_id": "GGOEAFBH1110...
# ..                                                 ...
# 935  {\n  "items": [{\n    "item_id": "GGOEAFBA1155...
# 936  {\n  "items": [{\n    "item_id": "GGOEAOCB0927...
# 937  {\n  "items": [{\n    "item_id": "GGOEGDHR1627...
# 938  {\n  "items": [{\n    "item_id": "GGOEACBA1045...
# 939  {\n  "items": [{\n    "item_id": "GGOEGOCB1317...
#
# [940 rows x 23 columns]

# %%
df_sql.columns
# Out:
# Index(['event_date', 'event_timestamp', 'event_name', 'event_params',
#        'event_previous_timestamp', 'event_value_in_usd',
#        'event_bundle_sequence_id', 'event_server_timestamp_offset', 'user_id',
#        'user_pseudo_id', 'privacy_info', 'user_properties',
#        'user_first_touch_timestamp', 'user_ltv', 'device', 'geo', 'app_info',
#        'traffic_source', 'stream_id', 'platform', 'event_dimensions',
#        'ecommerce', 'items'],
#       dtype='object')

# %%
df_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   event_date                     940 non-null    int64
#  1   event_timestamp                940 non-null    int64
#  2   event_name                     940 non-null    object
#  3   event_params                   940 non-null    object
#  4   event_previous_timestamp       0 non-null      float64
#  5   event_value_in_usd             5 non-null      float64
#  6   event_bundle_sequence_id       940 non-null    int64
#  7   event_server_timestamp_offset  0 non-null      float64
#  8   user_id                        0 non-null      float64
#  9   user_pseudo_id                 940 non-null    float64
#  10  privacy_info                   940 non-null    object
#  11  user_properties                940 non-null    object
#  12  user_first_touch_timestamp     921 non-null    float64
#  13  user_ltv                       940 non-null    object
#  14  device                         940 non-null    object
#  15  geo                            940 non-null    object
#  16  app_info                       940 non-null    object
#  17  traffic_source                 940 non-null    object
#  18  stream_id                      940 non-null    int64
#  19  platform                       940 non-null    object
#  20  event_dimensions               940 non-null    object
#  21  ecommerce                      940 non-null    object
#  22  items                          940 non-null    object
# dtypes: float64(6), int64(4), object(13)
# memory usage: 169.0+ KB

# %%
df_sql = df_sql.drop(["event_previous_timestamp","event_value_in_usd","event_server_timestamp_offset",
                      "user_id"], axis=1)
df_sql
# Out:
#      event_date   event_timestamp   event_name  \
# 0      20201103  1604383924455348    view_item
# 1      20201103  1604412531593015    view_item
# 2      20201103  1604422061072724    view_item
# 3      20201103  1604410252366614    view_item
# 4      20201103  1604372276670321    view_item
# ..          ...               ...          ...
# 935    20210122  1611358943298376    view_item
# 936    20210122  1611358988840916    view_item
# 937    20210122  1611300990568122    view_item
# 938    20210122  1611328158456229  select_item
# 939    20210122  1611327562415002    view_item
#
#                                           event_params  \
# 0    {\n  "event_params": [{\n    "key": "engagemen...
# 1    {\n  "event_params": [{\n    "key": "page_loca...
# 2    {\n  "event_params": [{\n    "key": "ga_sessio...
# 3    {\n  "event_params": [{\n    "key": "clean_eve...
# 4    {\n  "event_params": [{\n    "key": "clean_eve...
# ..                                                 ...
# 935  {\n  "event_params": [{\n    "key": "campaign"...
# 936  {\n  "event_params": [{\n    "key": "ga_sessio...
# 937  {\n  "event_params": [{\n    "key": "engaged_s...
# 938  {\n  "event_params": [{\n    "key": "session_e...
# 939  {\n  "event_params": [{\n    "key": "engagemen...
#
#      event_bundle_sequence_id  user_pseudo_id  \
# 0                 -9247653259    5.841763e+07
# 1                 -6517925002    5.881750e+07
# 2                  3328666858    6.107577e+07
# 3                   941146410    6.246598e+07
# 4                  3714819948    6.320507e+07
# ..                        ...             ...
# 935               -8263767271    9.133428e+06
# 936               -9211643401    9.133428e+06
# 937               -9004921919    1.114502e+07
# 938                2046165995    1.229183e+07
# 939               -8269928213    1.229183e+07
#
#                                           privacy_info  \
# 0    {\n  "privacy_info": {\n    "analytics_storage...
# 1    {\n  "privacy_info": {\n    "analytics_storage...
# 2    {\n  "privacy_info": {\n    "analytics_storage...
# 3    {\n  "privacy_info": {\n    "analytics_storage...
# 4    {\n  "privacy_info": {\n    "analytics_storage...
# ..                                                 ...
# 935  {\n  "privacy_info": {\n    "analytics_storage...
# 936  {\n  "privacy_info": {\n    "analytics_storage...
# 937  {\n  "privacy_info": {\n    "analytics_storage...
# 938  {\n  "privacy_info": {\n    "analytics_storage...
# 939  {\n  "privacy_info": {\n    "analytics_storage...
#
#                    user_properties  user_first_touch_timestamp  \
# 0    {\n  "user_properties": []\n}                         NaN
# 1    {\n  "user_properties": []\n}                1.604412e+15
# 2    {\n  "user_properties": []\n}                1.604422e+15
# 3    {\n  "user_properties": []\n}                1.604410e+15
# 4    {\n  "user_properties": []\n}                1.602820e+15
# ..                             ...                         ...
# 935  {\n  "user_properties": []\n}                1.610148e+15
# 936  {\n  "user_properties": []\n}                1.610148e+15
# 937  {\n  "user_properties": []\n}                1.609933e+15
# 938  {\n  "user_properties": []\n}                1.611307e+15
# 939  {\n  "user_properties": []\n}                1.611307e+15
#
#                                               user_ltv  \
# 0    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 1    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 2    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 3    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 4    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# ..                                                 ...
# 935  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 936  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 937  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 938  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 939  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
#
#                                                 device  \
# 0    {\n  "device": {\n    "category": "desktop",\n...
# 1    {\n  "device": {\n    "category": "mobile",\n ...
# 2    {\n  "device": {\n    "category": "mobile",\n ...
# 3    {\n  "device": {\n    "category": "desktop",\n...
# 4    {\n  "device": {\n    "category": "desktop",\n...
# ..                                                 ...
# 935  {\n  "device": {\n    "category": "desktop",\n...
# 936  {\n  "device": {\n    "category": "desktop",\n...
# 937  {\n  "device": {\n    "category": "desktop",\n...
# 938  {\n  "device": {\n    "category": "desktop",\n...
# 939  {\n  "device": {\n    "category": "desktop",\n...
#
#                                                    geo  \
# 0    {\n  "geo": {\n    "continent": "Americas",\n ...
# 1    {\n  "geo": {\n    "continent": "Americas",\n ...
# 2    {\n  "geo": {\n    "continent": "Asia",\n    "...
# 3    {\n  "geo": {\n    "continent": "Asia",\n    "...
# 4    {\n  "geo": {\n    "continent": "Europe",\n   ...
# ..                                                 ...
# 935  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 936  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 937  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 938  {\n  "geo": {\n    "continent": "Americas",\n ...
# 939  {\n  "geo": {\n    "continent": "Americas",\n ...
#
#                      app_info  \
# 0    {\n  "app_info": null\n}
# 1    {\n  "app_info": null\n}
# 2    {\n  "app_info": null\n}
# 3    {\n  "app_info": null\n}
# 4    {\n  "app_info": null\n}
# ..                        ...
# 935  {\n  "app_info": null\n}
# 936  {\n  "app_info": null\n}
# 937  {\n  "app_info": null\n}
# 938  {\n  "app_info": null\n}
# 939  {\n  "app_info": null\n}
#
#                                         traffic_source   stream_id platform  \
# 0    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 1    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 2    {\n  "traffic_source": {\n    "medium": "\u003...  2100450278      WEB
# 3    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 4    {\n  "traffic_source": {\n    "medium": "(none...  2100450278      WEB
# ..                                                 ...         ...      ...
# 935  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 936  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 937  {\n  "traffic_source": {\n    "medium": "(data...  2100450278      WEB
# 938  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 939  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
#
#                      event_dimensions  \
# 0    {\n  "event_dimensions": null\n}
# 1    {\n  "event_dimensions": null\n}
# 2    {\n  "event_dimensions": null\n}
# 3    {\n  "event_dimensions": null\n}
# 4    {\n  "event_dimensions": null\n}
# ..                                ...
# 935  {\n  "event_dimensions": null\n}
# 936  {\n  "event_dimensions": null\n}
# 937  {\n  "event_dimensions": null\n}
# 938  {\n  "event_dimensions": null\n}
# 939  {\n  "event_dimensions": null\n}
#
#                                              ecommerce  \
# 0    {\n  "ecommerce": {\n    "total_item_quantity"...
# 1    {\n  "ecommerce": {\n    "total_item_quantity"...
# 2    {\n  "ecommerce": {\n    "total_item_quantity"...
# 3    {\n  "ecommerce": {\n    "total_item_quantity"...
# 4    {\n  "ecommerce": {\n    "total_item_quantity"...
# ..                                                 ...
# 935  {\n  "ecommerce": {\n    "total_item_quantity"...
# 936  {\n  "ecommerce": {\n    "total_item_quantity"...
# 937  {\n  "ecommerce": {\n    "total_item_quantity"...
# 938  {\n  "ecommerce": {\n    "total_item_quantity"...
# 939  {\n  "ecommerce": {\n    "total_item_quantity"...
#
#                                                  items
# 0    {\n  "items": [{\n    "item_id": "GGOEGOLA1275...
# 1    {\n  "items": [{\n    "item_id": "GGOEGDHG1622...
# 2    {\n  "items": [{\n    "item_id": "GGOEGXXX1347...
# 3    {\n  "items": [{\n    "item_id": "GGCOGXXX1569...
# 4    {\n  "items": [{\n    "item_id": "GGOEAFBH1110...
# ..                                                 ...
# 935  {\n  "items": [{\n    "item_id": "GGOEAFBA1155...
# 936  {\n  "items": [{\n    "item_id": "GGOEAOCB0927...
# 937  {\n  "items": [{\n    "item_id": "GGOEGDHR1627...
# 938  {\n  "items": [{\n    "item_id": "GGOEACBA1045...
# 939  {\n  "items": [{\n    "item_id": "GGOEGOCB1317...
#
# [940 rows x 19 columns]

# %%
df_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   event_date                  940 non-null    int64
#  1   event_timestamp             940 non-null    int64
#  2   event_name                  940 non-null    object
#  3   event_params                940 non-null    object
#  4   event_bundle_sequence_id    940 non-null    int64
#  5   user_pseudo_id              940 non-null    float64
#  6   privacy_info                940 non-null    object
#  7   user_properties             940 non-null    object
#  8   user_first_touch_timestamp  921 non-null    float64
#  9   user_ltv                    940 non-null    object
#  10  device                      940 non-null    object
#  11  geo                         940 non-null    object
#  12  app_info                    940 non-null    object
#  13  traffic_source              940 non-null    object
#  14  stream_id                   940 non-null    int64
#  15  platform                    940 non-null    object
#  16  event_dimensions            940 non-null    object
#  17  ecommerce                   940 non-null    object
#  18  items                       940 non-null    object
# dtypes: float64(2), int64(4), object(13)
# memory usage: 139.7+ KB

# %%
df_sql = df_sql.dropna()
df_sql.reset_index(drop=True, inplace=True)

# %%
df_sql
# Out:
#      event_date   event_timestamp   event_name  \
# 0      20201103  1604412531593015    view_item
# 1      20201103  1604422061072724    view_item
# 2      20201103  1604410252366614    view_item
# 3      20201103  1604372276670321    view_item
# 4      20201103  1604370395855534    view_item
# ..          ...               ...          ...
# 916    20210122  1611358943298376    view_item
# 917    20210122  1611358988840916    view_item
# 918    20210122  1611300990568122    view_item
# 919    20210122  1611328158456229  select_item
# 920    20210122  1611327562415002    view_item
#
#                                           event_params  \
# 0    {\n  "event_params": [{\n    "key": "page_loca...
# 1    {\n  "event_params": [{\n    "key": "ga_sessio...
# 2    {\n  "event_params": [{\n    "key": "clean_eve...
# 3    {\n  "event_params": [{\n    "key": "clean_eve...
# 4    {\n  "event_params": [{\n    "key": "session_e...
# ..                                                 ...
# 916  {\n  "event_params": [{\n    "key": "campaign"...
# 917  {\n  "event_params": [{\n    "key": "ga_sessio...
# 918  {\n  "event_params": [{\n    "key": "engaged_s...
# 919  {\n  "event_params": [{\n    "key": "session_e...
# 920  {\n  "event_params": [{\n    "key": "engagemen...
#
#      event_bundle_sequence_id  user_pseudo_id  \
# 0                 -6517925002    5.881750e+07
# 1                  3328666858    6.107577e+07
# 2                   941146410    6.246598e+07
# 3                  3714819948    6.320507e+07
# 4                  3536629074    6.320507e+07
# ..                        ...             ...
# 916               -8263767271    9.133428e+06
# 917               -9211643401    9.133428e+06
# 918               -9004921919    1.114502e+07
# 919                2046165995    1.229183e+07
# 920               -8269928213    1.229183e+07
#
#                                           privacy_info  \
# 0    {\n  "privacy_info": {\n    "analytics_storage...
# 1    {\n  "privacy_info": {\n    "analytics_storage...
# 2    {\n  "privacy_info": {\n    "analytics_storage...
# 3    {\n  "privacy_info": {\n    "analytics_storage...
# 4    {\n  "privacy_info": {\n    "analytics_storage...
# ..                                                 ...
# 916  {\n  "privacy_info": {\n    "analytics_storage...
# 917  {\n  "privacy_info": {\n    "analytics_storage...
# 918  {\n  "privacy_info": {\n    "analytics_storage...
# 919  {\n  "privacy_info": {\n    "analytics_storage...
# 920  {\n  "privacy_info": {\n    "analytics_storage...
#
#                    user_properties  user_first_touch_timestamp  \
# 0    {\n  "user_properties": []\n}                1.604412e+15
# 1    {\n  "user_properties": []\n}                1.604422e+15
# 2    {\n  "user_properties": []\n}                1.604410e+15
# 3    {\n  "user_properties": []\n}                1.602820e+15
# 4    {\n  "user_properties": []\n}                1.602820e+15
# ..                             ...                         ...
# 916  {\n  "user_properties": []\n}                1.610148e+15
# 917  {\n  "user_properties": []\n}                1.610148e+15
# 918  {\n  "user_properties": []\n}                1.609933e+15
# 919  {\n  "user_properties": []\n}                1.611307e+15
# 920  {\n  "user_properties": []\n}                1.611307e+15
#
#                                               user_ltv  \
# 0    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 1    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 2    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 3    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 4    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# ..                                                 ...
# 916  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 917  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 918  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 919  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 920  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
#
#                                                 device  \
# 0    {\n  "device": {\n    "category": "mobile",\n ...
# 1    {\n  "device": {\n    "category": "mobile",\n ...
# 2    {\n  "device": {\n    "category": "desktop",\n...
# 3    {\n  "device": {\n    "category": "desktop",\n...
# 4    {\n  "device": {\n    "category": "desktop",\n...
# ..                                                 ...
# 916  {\n  "device": {\n    "category": "desktop",\n...
# 917  {\n  "device": {\n    "category": "desktop",\n...
# 918  {\n  "device": {\n    "category": "desktop",\n...
# 919  {\n  "device": {\n    "category": "desktop",\n...
# 920  {\n  "device": {\n    "category": "desktop",\n...
#
#                                                    geo  \
# 0    {\n  "geo": {\n    "continent": "Americas",\n ...
# 1    {\n  "geo": {\n    "continent": "Asia",\n    "...
# 2    {\n  "geo": {\n    "continent": "Asia",\n    "...
# 3    {\n  "geo": {\n    "continent": "Europe",\n   ...
# 4    {\n  "geo": {\n    "continent": "Europe",\n   ...
# ..                                                 ...
# 916  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 917  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 918  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 919  {\n  "geo": {\n    "continent": "Americas",\n ...
# 920  {\n  "geo": {\n    "continent": "Americas",\n ...
#
#                      app_info  \
# 0    {\n  "app_info": null\n}
# 1    {\n  "app_info": null\n}
# 2    {\n  "app_info": null\n}
# 3    {\n  "app_info": null\n}
# 4    {\n  "app_info": null\n}
# ..                        ...
# 916  {\n  "app_info": null\n}
# 917  {\n  "app_info": null\n}
# 918  {\n  "app_info": null\n}
# 919  {\n  "app_info": null\n}
# 920  {\n  "app_info": null\n}
#
#                                         traffic_source   stream_id platform  \
# 0    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 1    {\n  "traffic_source": {\n    "medium": "\u003...  2100450278      WEB
# 2    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 3    {\n  "traffic_source": {\n    "medium": "(none...  2100450278      WEB
# 4    {\n  "traffic_source": {\n    "medium": "(none...  2100450278      WEB
# ..                                                 ...         ...      ...
# 916  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 917  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 918  {\n  "traffic_source": {\n    "medium": "(data...  2100450278      WEB
# 919  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 920  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
#
#                      event_dimensions  \
# 0    {\n  "event_dimensions": null\n}
# 1    {\n  "event_dimensions": null\n}
# 2    {\n  "event_dimensions": null\n}
# 3    {\n  "event_dimensions": null\n}
# 4    {\n  "event_dimensions": null\n}
# ..                                ...
# 916  {\n  "event_dimensions": null\n}
# 917  {\n  "event_dimensions": null\n}
# 918  {\n  "event_dimensions": null\n}
# 919  {\n  "event_dimensions": null\n}
# 920  {\n  "event_dimensions": null\n}
#
#                                              ecommerce  \
# 0    {\n  "ecommerce": {\n    "total_item_quantity"...
# 1    {\n  "ecommerce": {\n    "total_item_quantity"...
# 2    {\n  "ecommerce": {\n    "total_item_quantity"...
# 3    {\n  "ecommerce": {\n    "total_item_quantity"...
# 4    {\n  "ecommerce": {\n    "total_item_quantity"...
# ..                                                 ...
# 916  {\n  "ecommerce": {\n    "total_item_quantity"...
# 917  {\n  "ecommerce": {\n    "total_item_quantity"...
# 918  {\n  "ecommerce": {\n    "total_item_quantity"...
# 919  {\n  "ecommerce": {\n    "total_item_quantity"...
# 920  {\n  "ecommerce": {\n    "total_item_quantity"...
#
#                                                  items
# 0    {\n  "items": [{\n    "item_id": "GGOEGDHG1622...
# 1    {\n  "items": [{\n    "item_id": "GGOEGXXX1347...
# 2    {\n  "items": [{\n    "item_id": "GGCOGXXX1569...
# 3    {\n  "items": [{\n    "item_id": "GGOEAFBH1110...
# 4    {\n  "items": [{\n    "item_id": "GGOEGXXX1613...
# ..                                                 ...
# 916  {\n  "items": [{\n    "item_id": "GGOEAFBA1155...
# 917  {\n  "items": [{\n    "item_id": "GGOEAOCB0927...
# 918  {\n  "items": [{\n    "item_id": "GGOEGDHR1627...
# 919  {\n  "items": [{\n    "item_id": "GGOEACBA1045...
# 920  {\n  "items": [{\n    "item_id": "GGOEGOCB1317...
#
# [921 rows x 19 columns]

# %%
df_sql["event_name"].unique()
# Out:
# array(['view_item', 'add_to_cart', 'select_item', 'view_promotion',
#        'select_promotion', 'purchase', 'page_view', 'user_engagement',
#        'scroll', 'add_payment_info', 'session_start', 'first_visit',
#        'view_search_results'], dtype=object)

# %%
df_sql["user_pseudo_id"].nunique()
# Out:
# 532

# %%
condition_list = ["view_item","user_engagement","add_to_cart","purchase"]

# %%
df_new = df_sql.groupby(["user_pseudo_id"])["event_name"].unique()
df_new = df_new.reset_index()
df_new
# Out:
#      user_pseudo_id                                         event_name
# 0      1.065627e+06                                 [select_promotion]
# 1      1.105395e+06                                   [view_promotion]
# 2      1.308285e+06                                   [view_promotion]
# 3      1.333728e+06                                   [view_promotion]
# 4      1.388851e+06                 [view_promotion, select_promotion]
# ..              ...                                                ...
# 527    8.431846e+09                                        [view_item]
# 528    8.444872e+09                                        [view_item]
# 529    8.541380e+09                                   [view_promotion]
# 530    8.965679e+09                                  [user_engagement]
# 531    9.012970e+09  [session_start, user_engagement, view_search_r...
#
# [532 rows x 2 columns]

# %%
df_new2 = df_sql.groupby("user_pseudo_id").apply(lambda x: x[x["event_name"].isin(condition_list)]).reset_index(drop=True)
df_new2
# Out:
#      event_date   event_timestamp       event_name  \
# 0      20201121  1605953501803678        view_item
# 1      20201121  1605919563785503        view_item
# 2      20210130  1612002177248289        view_item
# 3      20201121  1605940017591938        view_item
# 4      20201211  1607664976183383        view_item
# ..          ...               ...              ...
# 611    20201112  1605210377168861        view_item
# 612    20201112  1605210678331984        view_item
# 613    20201121  1605924761081041  user_engagement
# 614    20201121  1605934964039467  user_engagement
# 615    20201121  1605934927055149  user_engagement
#
#                                           event_params  \
# 0    {\n  "event_params": [{\n    "key": "engaged_s...
# 1    {\n  "event_params": [{\n    "key": "clean_eve...
# 2    {\n  "event_params": [{\n    "key": "page_refe...
# 3    {\n  "event_params": [{\n    "key": "page_titl...
# 4    {\n  "event_params": [{\n    "key": "engaged_s...
# ..                                                 ...
# 611  {\n  "event_params": [{\n    "key": "page_refe...
# 612  {\n  "event_params": [{\n    "key": "debug_mod...
# 613  {\n  "event_params": [{\n    "key": "engagemen...
# 614  {\n  "event_params": [{\n    "key": "ga_sessio...
# 615  {\n  "event_params": [{\n    "key": "page_titl...
#
#      event_bundle_sequence_id  user_pseudo_id  \
# 0                  4848496133    1.624876e+06
# 1                 -9303579797    1.685178e+06
# 2                 -3473504933    1.924596e+06
# 3                 -1351359220    2.583761e+06
# 4                  7010500301    2.741490e+06
# ..                        ...             ...
# 611               -3473314800    8.444872e+09
# 612                9731074748    8.444872e+09
# 613               -9212279553    8.965679e+09
# 614               -6114054469    9.012970e+09
# 615                4359715382    9.012970e+09
#
#                                           privacy_info  \
# 0    {\n  "privacy_info": {\n    "analytics_storage...
# 1    {\n  "privacy_info": {\n    "analytics_storage...
# 2    {\n  "privacy_info": {\n    "analytics_storage...
# 3    {\n  "privacy_info": {\n    "analytics_storage...
# 4    {\n  "privacy_info": {\n    "analytics_storage...
# ..                                                 ...
# 611  {\n  "privacy_info": {\n    "analytics_storage...
# 612  {\n  "privacy_info": {\n    "analytics_storage...
# 613  {\n  "privacy_info": {\n    "analytics_storage...
# 614  {\n  "privacy_info": {\n    "analytics_storage...
# 615  {\n  "privacy_info": {\n    "analytics_storage...
#
#                    user_properties  user_first_touch_timestamp  \
# 0    {\n  "user_properties": []\n}                1.588418e+15
# 1    {\n  "user_properties": []\n}                1.605032e+15
# 2    {\n  "user_properties": []\n}                1.611589e+15
# 3    {\n  "user_properties": []\n}                1.605940e+15
# 4    {\n  "user_properties": []\n}                1.607665e+15
# ..                             ...                         ...
# 611  {\n  "user_properties": []\n}                1.602505e+15
# 612  {\n  "user_properties": []\n}                1.602505e+15
# 613  {\n  "user_properties": []\n}                1.604199e+15
# 614  {\n  "user_properties": []\n}                1.605534e+15
# 615  {\n  "user_properties": []\n}                1.605534e+15
#
#                                               user_ltv  \
# 0    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 1    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 2    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 3    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 4    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# ..                                                 ...
# 611  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 612  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 613  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 614  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 615  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
#
#                                                 device  \
# 0    {\n  "device": {\n    "category": "desktop",\n...
# 1    {\n  "device": {\n    "category": "mobile",\n ...
# 2    {\n  "device": {\n    "category": "desktop",\n...
# 3    {\n  "device": {\n    "category": "desktop",\n...
# 4    {\n  "device": {\n    "category": "desktop",\n...
# ..                                                 ...
# 611  {\n  "device": {\n    "category": "mobile",\n ...
# 612  {\n  "device": {\n    "category": "mobile",\n ...
# 613  {\n  "device": {\n    "category": "desktop",\n...
# 614  {\n  "device": {\n    "category": "desktop",\n...
# 615  {\n  "device": {\n    "category": "desktop",\n...
#
#                                                    geo  \
# 0    {\n  "geo": {\n    "continent": "Asia",\n    "...
# 1    {\n  "geo": {\n    "continent": "Americas",\n ...
# 2    {\n  "geo": {\n    "continent": "Americas",\n ...
# 3    {\n  "geo": {\n    "continent": "Americas",\n ...
# 4    {\n  "geo": {\n    "continent": "Europe",\n   ...
# ..                                                 ...
# 611  {\n  "geo": {\n    "continent": "Americas",\n ...
# 612  {\n  "geo": {\n    "continent": "Americas",\n ...
# 613  {\n  "geo": {\n    "continent": "Europe",\n   ...
# 614  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 615  {\n  "geo": {\n    "continent": "Asia",\n    "...
#
#                      app_info  \
# 0    {\n  "app_info": null\n}
# 1    {\n  "app_info": null\n}
# 2    {\n  "app_info": null\n}
# 3    {\n  "app_info": null\n}
# 4    {\n  "app_info": null\n}
# ..                        ...
# 611  {\n  "app_info": null\n}
# 612  {\n  "app_info": null\n}
# 613  {\n  "app_info": null\n}
# 614  {\n  "app_info": null\n}
# 615  {\n  "app_info": null\n}
#
#                                         traffic_source   stream_id platform  \
# 0    {\n  "traffic_source": {\n    "medium": "refer...  2100450278      WEB
# 1    {\n  "traffic_source": {\n    "medium": "(none...  2100450278      WEB
# 2    {\n  "traffic_source": {\n    "medium": "(none...  2100450278      WEB
# 3    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 4    {\n  "traffic_source": {\n    "medium": "\u003...  2100450278      WEB
# ..                                                 ...         ...      ...
# 611  {\n  "traffic_source": {\n    "medium": "(none...  2100450278      WEB
# 612  {\n  "traffic_source": {\n    "medium": "(none...  2100450278      WEB
# 613  {\n  "traffic_source": {\n    "medium": "refer...  2100450278      WEB
# 614  {\n  "traffic_source": {\n    "medium": "(none...  2100450278      WEB
# 615  {\n  "traffic_source": {\n    "medium": "(none...  2100450278      WEB
#
#                      event_dimensions  \
# 0    {\n  "event_dimensions": null\n}
# 1    {\n  "event_dimensions": null\n}
# 2    {\n  "event_dimensions": null\n}
# 3    {\n  "event_dimensions": null\n}
# 4    {\n  "event_dimensions": null\n}
# ..                                ...
# 611  {\n  "event_dimensions": null\n}
# 612  {\n  "event_dimensions": null\n}
# 613  {\n  "event_dimensions": null\n}
# 614  {\n  "event_dimensions": null\n}
# 615  {\n  "event_dimensions": null\n}
#
#                                              ecommerce  \
# 0    {\n  "ecommerce": {\n    "total_item_quantity"...
# 1    {\n  "ecommerce": {\n    "total_item_quantity"...
# 2    {\n  "ecommerce": {\n    "total_item_quantity"...
# 3    {\n  "ecommerce": {\n    "total_item_quantity"...
# 4    {\n  "ecommerce": {\n    "total_item_quantity"...
# ..                                                 ...
# 611  {\n  "ecommerce": {\n    "total_item_quantity"...
# 612  {\n  "ecommerce": {\n    "total_item_quantity"...
# 613  {\n  "ecommerce": {\n    "total_item_quantity"...
# 614  {\n  "ecommerce": {\n    "total_item_quantity"...
# 615  {\n  "ecommerce": {\n    "total_item_quantity"...
#
#                                                  items
# 0    {\n  "items": [{\n    "item_id": "GGOEGXXX1347...
# 1    {\n  "items": [{\n    "item_id": "GGCOGDHC1612...
# 2    {\n  "items": [{\n    "item_id": "GGOEGBRJ1285...
# 3    {\n  "items": [{\n    "item_id": "GGOEGXXX1347...
# 4    {\n  "items": [{\n    "item_id": "GGOEGXXX1346...
# ..                                                 ...
# 611  {\n  "items": [{\n    "item_id": "GGOEAFBA1154...
# 612  {\n  "items": [{\n    "item_id": "GGOEGXXX1613...
# 613                                {\n  "items": []\n}
# 614                                {\n  "items": []\n}
# 615                                {\n  "items": []\n}
#
# [616 rows x 19 columns]

# %%
df_new2.groupby("user_pseudo_id")["event_name"].nunique()
# Out:
# user_pseudo_id
# 1.624876e+06    1
# 1.685178e+06    1
# 1.924596e+06    1
# 2.583761e+06    1
# 2.741490e+06    2
#                ..
# 8.347955e+09    1
# 8.431846e+09    1
# 8.444872e+09    1
# 8.965679e+09    1
# 9.012970e+09    1
# Name: event_name, Length: 347, dtype: int64

# %%
df_new3 = df_sql.groupby(["user_pseudo_id"])["event_name"].apply(set).reset_index()
df_new3
# Out:
#      user_pseudo_id                                         event_name
# 0      1.065627e+06                                 {select_promotion}
# 1      1.105395e+06                                   {view_promotion}
# 2      1.308285e+06                                   {view_promotion}
# 3      1.333728e+06                                   {view_promotion}
# 4      1.388851e+06                 {view_promotion, select_promotion}
# ..              ...                                                ...
# 527    8.431846e+09                                        {view_item}
# 528    8.444872e+09                                        {view_item}
# 529    8.541380e+09                                   {view_promotion}
# 530    8.965679e+09                                  {user_engagement}
# 531    9.012970e+09  {user_engagement, session_start, view_search_r...
#
# [532 rows x 2 columns]

# %%
for i in df_new3.iloc[531,1]:
    print(i)
# Out:
# user_engagement
# session_start
# view_search_results

# %%
condition_list = ["session_start","user_engagement"]

# %%
def condition_check(condition_list, set_list):
    if all(condition in set_list for condition in condition_list):
        return 1
    else:
        return 0

# %%
df_new3["customer"] = df_new3["event_name"].apply(lambda x: condition_check(condition_list, x))
df_new3
# Out:
#      user_pseudo_id                                         event_name  \
# 0      1.065627e+06                                 {select_promotion}
# 1      1.105395e+06                                   {view_promotion}
# 2      1.308285e+06                                   {view_promotion}
# 3      1.333728e+06                                   {view_promotion}
# 4      1.388851e+06                 {view_promotion, select_promotion}
# ..              ...                                                ...
# 527    8.431846e+09                                        {view_item}
# 528    8.444872e+09                                        {view_item}
# 529    8.541380e+09                                   {view_promotion}
# 530    8.965679e+09                                  {user_engagement}
# 531    9.012970e+09  {user_engagement, session_start, view_search_r...
#
#      customer
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 527         0
# 528         0
# 529         0
# 530         0
# 531         1
#
# [532 rows x 3 columns]

# %%
df_new3["customer"].value_counts()
# Out:
# 0    530
# 1      2
# Name: customer, dtype: int64

# %%
df_new3["event_name"].max()
# Out:
# {'session_start', 'user_engagement', 'view_search_results'}
