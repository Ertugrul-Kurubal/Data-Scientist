# %% [markdown]
# ### Big Query Data

# %%
# pip install --upgrade google-cloud-bigquery

# %%
from google.cloud import bigquery
from google.oauth2 import service_account

# %%
# credentials = service_account.Credentials.from_service_account_file('path/to/file.json')
# 
# project_id = 'my-bq'
# client = bigquery.Client(credentials= credentials,project=project_id)

# %%
# # 1 Way
# query_job = client.query("""
#    SELECT *
#    FROM dataset.my_table
#    LIMIT 1000 """)
# 
# results = query_job.result() # Wait for the job to complete.

# %%
# # 2 Way
# # legancy_sql
# job_config.use_legacy_sql = True
# query_job = client.query("""
#    SELECT *
#    FROM dataset.my_table
#    LIMIT 1000""", job_config = job_config)
# 
# results = query_job.result() # Wait for the job to complete.

# %%
credentials = service_account.Credentials.from_service_account_file(r'C:\Users\Ertuğrul\Downloads\focal-dock-398011-3fccc3365d4c.json')

project_id = 'focal-dock-398011'
client = bigquery.Client(credentials= credentials, project=project_id)

# %%
# 1 Way
query_job = client.query("""
   SELECT *
   FROM 'bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_20210131'
   WHERE user_pseudo_id IN (SELECT user_pseudo_id
   FROM
   (SELECT DISTINCT user_pseudo_id, count(distinct event_date) as day_count FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_*`
   group by user_pseudo_id)
   WHERE day_count > 2) """)

results = query_job.result()

# %%
# chatgpt code block
from google.cloud import bigquery

# Kimlik doğrulama dosyasının yolunu belirtin
credentials_path = r"C:\Users\Ertuğrul\Downloads\focal-dock-398011-3fccc3365d4c.json"

# BigQuery istemcisini oluşturun
client = bigquery.Client.from_service_account_json(credentials_path)

# Veri setini ve tabloyu belirtin
project_id = "focal-dock-398011"
dataset_id = "bigquery-public-data.ga4_obfuscated_sample_ecommerce"
table_id = "events_20210131"

# Sorguyu hazırlayın
query = f"SELECT * FROM `{project_id}.{dataset_id}.{table_id}`"

# Sorguyu çalıştırın ve sonuçları alın
query_job = client.query(query)
results = query_job.result()

# Sonuçları işleyin
for row in results:
    print(row)

# %%
# pip install bq

# %%
import bq

# Project ID ve bölgenizi tanımlayın.
project_id = "focal-dock-398011"
region = "us-central1"

# BigQuery-public-data verilerine erişmek için bir istemci oluşturun.
client = bq.Client(project_id, region=region)

# İndirmek istediğiniz tabloyu seçin.
table_name = "bigquery-public-data.ga4_obfuscated_sample_ecommerce"

# Tabloyu Cloud Storage'a dışa aktarın.
client.extract_table(
    table_name,
    "gs://my-bucket/ga4_obfuscated_sample_ecommerce_events_20210131.csv",
    format="CSV",
    compression="GZIP",
)

# %% [markdown]
# #### Local Data Analysis

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sql = pd.read_csv(r"C:\Users\Ertuğrul\Downloads\bquxjob_7278a706_18a600fffc3.csv")  # bquxjob_7278a706_18a600fffc3
df_sql
# Out:
#      event_date   event_timestamp   event_name  \
# 0      20201103  1604383924455348    view_item
# 1      20201103  1604412531593015    view_item
# 2      20201103  1604422061072724    view_item
# 3      20201103  1604410252366614    view_item
# 4      20201103  1604372276670321    view_item
# ..          ...               ...          ...
# 935    20210122  1611358943298376    view_item
# 936    20210122  1611358988840916    view_item
# 937    20210122  1611300990568122    view_item
# 938    20210122  1611328158456229  select_item
# 939    20210122  1611327562415002    view_item
#
#                                           event_params  \
# 0    {\n  "event_params": [{\n    "key": "engagemen...
# 1    {\n  "event_params": [{\n    "key": "page_loca...
# 2    {\n  "event_params": [{\n    "key": "ga_sessio...
# 3    {\n  "event_params": [{\n    "key": "clean_eve...
# 4    {\n  "event_params": [{\n    "key": "clean_eve...
# ..                                                 ...
# 935  {\n  "event_params": [{\n    "key": "campaign"...
# 936  {\n  "event_params": [{\n    "key": "ga_sessio...
# 937  {\n  "event_params": [{\n    "key": "engaged_s...
# 938  {\n  "event_params": [{\n    "key": "session_e...
# 939  {\n  "event_params": [{\n    "key": "engagemen...
#
#      event_previous_timestamp  event_value_in_usd  event_bundle_sequence_id  \
# 0                         NaN                 NaN               -9247653259
# 1                         NaN                 NaN               -6517925002
# 2                         NaN                 NaN                3328666858
# 3                         NaN                 NaN                 941146410
# 4                         NaN                 NaN                3714819948
# ..                        ...                 ...                       ...
# 935                       NaN                 NaN               -8263767271
# 936                       NaN                 NaN               -9211643401
# 937                       NaN                 NaN               -9004921919
# 938                       NaN                 NaN                2046165995
# 939                       NaN                 NaN               -8269928213
#
#      event_server_timestamp_offset  user_id  user_pseudo_id  ...  \
# 0                              NaN      NaN    5.841763e+07  ...
# 1                              NaN      NaN    5.881750e+07  ...
# 2                              NaN      NaN    6.107577e+07  ...
# 3                              NaN      NaN    6.246598e+07  ...
# 4                              NaN      NaN    6.320507e+07  ...
# ..                             ...      ...             ...  ...
# 935                            NaN      NaN    9.133428e+06  ...
# 936                            NaN      NaN    9.133428e+06  ...
# 937                            NaN      NaN    1.114502e+07  ...
# 938                            NaN      NaN    1.229183e+07  ...
# 939                            NaN      NaN    1.229183e+07  ...
#
#                                               user_ltv  \
# 0    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 1    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 2    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 3    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 4    {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# ..                                                 ...
# 935  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 936  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 937  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 938  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
# 939  {\n  "user_ltv": {\n    "revenue": "0.0",\n   ...
#
#                                                 device  \
# 0    {\n  "device": {\n    "category": "desktop",\n...
# 1    {\n  "device": {\n    "category": "mobile",\n ...
# 2    {\n  "device": {\n    "category": "mobile",\n ...
# 3    {\n  "device": {\n    "category": "desktop",\n...
# 4    {\n  "device": {\n    "category": "desktop",\n...
# ..                                                 ...
# 935  {\n  "device": {\n    "category": "desktop",\n...
# 936  {\n  "device": {\n    "category": "desktop",\n...
# 937  {\n  "device": {\n    "category": "desktop",\n...
# 938  {\n  "device": {\n    "category": "desktop",\n...
# 939  {\n  "device": {\n    "category": "desktop",\n...
#
#                                                    geo  \
# 0    {\n  "geo": {\n    "continent": "Americas",\n ...
# 1    {\n  "geo": {\n    "continent": "Americas",\n ...
# 2    {\n  "geo": {\n    "continent": "Asia",\n    "...
# 3    {\n  "geo": {\n    "continent": "Asia",\n    "...
# 4    {\n  "geo": {\n    "continent": "Europe",\n   ...
# ..                                                 ...
# 935  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 936  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 937  {\n  "geo": {\n    "continent": "Asia",\n    "...
# 938  {\n  "geo": {\n    "continent": "Americas",\n ...
# 939  {\n  "geo": {\n    "continent": "Americas",\n ...
#
#                      app_info  \
# 0    {\n  "app_info": null\n}
# 1    {\n  "app_info": null\n}
# 2    {\n  "app_info": null\n}
# 3    {\n  "app_info": null\n}
# 4    {\n  "app_info": null\n}
# ..                        ...
# 935  {\n  "app_info": null\n}
# 936  {\n  "app_info": null\n}
# 937  {\n  "app_info": null\n}
# 938  {\n  "app_info": null\n}
# 939  {\n  "app_info": null\n}
#
#                                         traffic_source   stream_id platform  \
# 0    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 1    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 2    {\n  "traffic_source": {\n    "medium": "\u003...  2100450278      WEB
# 3    {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 4    {\n  "traffic_source": {\n    "medium": "(none...  2100450278      WEB
# ..                                                 ...         ...      ...
# 935  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 936  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 937  {\n  "traffic_source": {\n    "medium": "(data...  2100450278      WEB
# 938  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
# 939  {\n  "traffic_source": {\n    "medium": "organ...  2100450278      WEB
#
#                      event_dimensions  \
# 0    {\n  "event_dimensions": null\n}
# 1    {\n  "event_dimensions": null\n}
# 2    {\n  "event_dimensions": null\n}
# 3    {\n  "event_dimensions": null\n}
# 4    {\n  "event_dimensions": null\n}
# ..                                ...
# 935  {\n  "event_dimensions": null\n}
# 936  {\n  "event_dimensions": null\n}
# 937  {\n  "event_dimensions": null\n}
# 938  {\n  "event_dimensions": null\n}
# 939  {\n  "event_dimensions": null\n}
#
#                                              ecommerce  \
# 0    {\n  "ecommerce": {\n    "total_item_quantity"...
# 1    {\n  "ecommerce": {\n    "total_item_quantity"...
# 2    {\n  "ecommerce": {\n    "total_item_quantity"...
# 3    {\n  "ecommerce": {\n    "total_item_quantity"...
# 4    {\n  "ecommerce": {\n    "total_item_quantity"...
# ..                                                 ...
# 935  {\n  "ecommerce": {\n    "total_item_quantity"...
# 936  {\n  "ecommerce": {\n    "total_item_quantity"...
# 937  {\n  "ecommerce": {\n    "total_item_quantity"...
# 938  {\n  "ecommerce": {\n    "total_item_quantity"...
# 939  {\n  "ecommerce": {\n    "total_item_quantity"...
#
#                                                  items
# 0    {\n  "items": [{\n    "item_id": "GGOEGOLA1275...
# 1    {\n  "items": [{\n    "item_id": "GGOEGDHG1622...
# 2    {\n  "items": [{\n    "item_id": "GGOEGXXX1347...
# 3    {\n  "items": [{\n    "item_id": "GGCOGXXX1569...
# 4    {\n  "items": [{\n    "item_id": "GGOEAFBH1110...
# ..                                                 ...
# 935  {\n  "items": [{\n    "item_id": "GGOEAFBA1155...
# 936  {\n  "items": [{\n    "item_id": "GGOEAOCB0927...
# 937  {\n  "items": [{\n    "item_id": "GGOEGDHR1627...
# 938  {\n  "items": [{\n    "item_id": "GGOEACBA1045...
# 939  {\n  "items": [{\n    "item_id": "GGOEGOCB1317...
#
# [940 rows x 23 columns]

# %%
df_sql.columns
# Out:
# Index(['event_date', 'event_timestamp', 'event_name', 'user_pseudo_id',
#        'continent', 'sub_continent', 'country'],
#       dtype='object')

# %%
df_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651766 entries, 0 to 651765
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   event_date       651766 non-null  int64
#  1   event_timestamp  651766 non-null  int64
#  2   event_name       651766 non-null  object
#  3   user_pseudo_id   651766 non-null  float64
#  4   continent        651766 non-null  object
#  5   sub_continent    651766 non-null  object
#  6   country          651766 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 34.8+ MB

# %%
#df_sql = df_sql.drop(["event_previous_timestamp","event_value_in_usd","event_server_timestamp_offset",
#                      "user_id"], axis=1)
#df_sql

# %%
#df_sql.info()

# %%
df_sql = df_sql.dropna()
df_sql.reset_index(drop=True, inplace=True)
df_sql
# Out:
#         event_date   event_timestamp       event_name  user_pseudo_id  \
# 0         20201101  1604238246899973  user_engagement    1.421531e+06
# 1         20201101  1604193615737892  user_engagement    2.067846e+06
# 2         20201101  1604271841686956  user_engagement    3.336646e+06
# 3         20201101  1604271819974657  user_engagement    3.336646e+06
# 4         20201101  1604271885683174  user_engagement    3.336646e+06
# ...            ...               ...              ...             ...
# 651761    20201208  1607386382955769        view_item    7.877401e+07
# 651762    20201208  1607386364471813        view_item    7.877401e+07
# 651763    20201208  1607386419428873        view_item    7.877401e+07
# 651764    20201208  1607386408611145        view_item    7.877401e+07
# 651765    20201208  1607440568406633        view_item    8.492889e+07
#
#        continent    sub_continent         country
# 0       Americas    South America           Chile
# 1           Asia    Southern Asia      Bangladesh
# 2         Europe  Northern Europe         Denmark
# 3         Europe  Northern Europe         Denmark
# 4         Europe  Northern Europe         Denmark
# ...          ...              ...             ...
# 651761    Europe  Northern Europe  United Kingdom
# 651762    Europe  Northern Europe  United Kingdom
# 651763    Europe  Northern Europe  United Kingdom
# 651764    Europe  Northern Europe  United Kingdom
# 651765    Europe  Northern Europe  United Kingdom
#
# [651766 rows x 7 columns]

# %%
df_sql["event_name"].unique()
# Out:
# array(['user_engagement', 'view_item', 'purchase', 'add_to_cart'],
#       dtype=object)

# %%
df_sql["user_pseudo_id"].nunique()
# Out:
# 27903

# %%
condition_list = ["view_item","user_engagement","add_to_cart","purchase"]

# %%
df_new = df_sql.groupby(["user_pseudo_id"])["event_name"].unique()
df_new = df_new.reset_index()
df_new
# Out:
#        user_pseudo_id                                         event_name
# 0        1.001569e+06                                  [user_engagement]
# 1        1.002027e+06                       [user_engagement, view_item]
# 2        1.002254e+06                                  [user_engagement]
# 3        1.002420e+06                                  [user_engagement]
# 4        1.005037e+06                       [user_engagement, view_item]
# ...               ...                                                ...
# 27898    9.789701e+09                       [user_engagement, view_item]
# 27899    9.928813e+09  [user_engagement, view_item, purchase, add_to_...
# 27900    9.950140e+09                       [user_engagement, view_item]
# 27901    9.984229e+09                                  [user_engagement]
# 27902    9.985207e+09                                  [user_engagement]
#
# [27903 rows x 2 columns]

# %%
df_new2 = df_sql.groupby("user_pseudo_id").apply(lambda x: x[x["event_name"].isin(condition_list)]).reset_index(drop=True)
df_new2
# Out:
#         event_date   event_timestamp       event_name  user_pseudo_id  \
# 0         20201102  1604341115204117  user_engagement    1.001569e+06
# 1         20201209  1607518650503683  user_engagement    1.002027e+06
# 2         20201208  1607471513010844  user_engagement    1.002027e+06
# 3         20201208  1607471526715526        view_item    1.002027e+06
# 4         20201202  1606913945523218  user_engagement    1.002254e+06
# ...            ...               ...              ...             ...
# 651761    20210117  1610842734415463  user_engagement    9.984229e+09
# 651762    20210116  1610828787548368  user_engagement    9.984229e+09
# 651763    20210113  1610545531006404  user_engagement    9.985207e+09
# 651764    20201215  1608036308379854  user_engagement    9.985207e+09
# 651765    20201215  1608036336054938  user_engagement    9.985207e+09
#
#        continent     sub_continent        country
# 0       Americas  Northern America  United States
# 1       Americas   Central America      Guatemala
# 2       Americas   Central America      Guatemala
# 3       Americas   Central America      Guatemala
# 4       Americas  Northern America  United States
# ...          ...               ...            ...
# 651761  Americas  Northern America  United States
# 651762  Americas  Northern America  United States
# 651763  Americas  Northern America  United States
# 651764  Americas  Northern America  United States
# 651765  Americas  Northern America  United States
#
# [651766 rows x 7 columns]

# %%
df_new2.groupby("user_pseudo_id")["event_name"].nunique()
# Out:
# user_pseudo_id
# 1.001569e+06    1
# 1.002027e+06    2
# 1.002254e+06    1
# 1.002420e+06    1
# 1.005037e+06    2
#                ..
# 9.789701e+09    2
# 9.928813e+09    4
# 9.950140e+09    2
# 9.984229e+09    1
# 9.985207e+09    1
# Name: event_name, Length: 27903, dtype: int64

# %%
df_new3 = df_sql.groupby(["user_pseudo_id"])["event_name"].apply(set).reset_index()
df_new3
# Out:
#        user_pseudo_id                                         event_name
# 0        1.001569e+06                                  {user_engagement}
# 1        1.002027e+06                       {view_item, user_engagement}
# 2        1.002254e+06                                  {user_engagement}
# 3        1.002420e+06                                  {user_engagement}
# 4        1.005037e+06                       {view_item, user_engagement}
# ...               ...                                                ...
# 27898    9.789701e+09                       {view_item, user_engagement}
# 27899    9.928813e+09  {purchase, add_to_cart, view_item, user_engage...
# 27900    9.950140e+09                       {view_item, user_engagement}
# 27901    9.984229e+09                                  {user_engagement}
# 27902    9.985207e+09                                  {user_engagement}
#
# [27903 rows x 2 columns]

# %%
for i in df_new3.iloc[531,1]:
    print(i)
# Out:
# view_item
# user_engagement

# %%
#condition_list = ["session_start","user_engagement"]
condition_list = ["view_item","user_engagement","add_to_cart","purchase"]

# %%
def condition_check(condition_list, set_list):
    if all(condition in set_list for condition in condition_list):
        return 1
    else:
        return 0

# %%
df_new3["customer"] = df_new3["event_name"].apply(lambda x: condition_check(condition_list, x))
df_new3
# Out:
#        user_pseudo_id                                         event_name  \
# 0        1.001569e+06                                  {user_engagement}
# 1        1.002027e+06                       {view_item, user_engagement}
# 2        1.002254e+06                                  {user_engagement}
# 3        1.002420e+06                                  {user_engagement}
# 4        1.005037e+06                       {view_item, user_engagement}
# ...               ...                                                ...
# 27898    9.789701e+09                       {view_item, user_engagement}
# 27899    9.928813e+09  {purchase, add_to_cart, view_item, user_engage...
# 27900    9.950140e+09                       {view_item, user_engagement}
# 27901    9.984229e+09                                  {user_engagement}
# 27902    9.985207e+09                                  {user_engagement}
#
#        customer
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 27898         0
# 27899         1
# 27900         0
# 27901         0
# 27902         0
#
# [27903 rows x 3 columns]

# %%
df_new3["customer"].value_counts()
# Out:
# 0    25944
# 1     1959
# Name: customer, dtype: int64

# %%
df_new3["event_name"].max()
# Out:
# {'add_to_cart', 'purchase', 'user_engagement', 'view_item'}
