# %% [markdown]
# ### Morphology Root Analysis

# %% [markdown]
# This notebook was used to derive word roots from the Quran's morphology data.

# %%
import pandas as pd
import numpy as np
import re
from camel_tools.utils.charmap import CharMapper
from lang_trans.arabic import buckwalter

# %%
# buckwalter text clean for simple before transString
def clean_ex(text):
    buckwalter_out = re.sub(r'''([PJVG\.:;,!\+\^\]\[@#FNKauio`~"%-])''', "", text) # difference from clean
    return buckwalter_out

# %%
# Arabic Encoding Extended
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2uni = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "}": u"\u0626", # hamza-on-yaa'
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "F": u"\u064B", # fatHatayn
            "N": u"\u064C", # Dammatayn
            "K": u"\u064D", # kasratayn
            "a": u"\u064E", # fatHa
            "u": u"\u064F", # Damma
            "i": u"\u0650", # kasra
            "~": u"\u0651", # shaddah
            "o": u"\u0652", # sukuun
            "^": u"\u0653", # maddah
            "#": u"\u0654", # hamzaabove            
            "`": u"\u0670", # dagger 'alif
            "{": u"\u0671", # waSla
            "P": u"\u067E", # arabicletterpeh
            "J": u"\u0686", 
            "V": u"\u06A4", # arabicletterveh
            "G": u"\u06AF", # arabiclettergaf
            ":": u"\u06DC", # smallhighseen
            "@": u"\u06DF", # smallhighroundedzero
            "\"": u"\u06E0", # smallhighuprightrectangularzero
            "[": u"\u06E2", # smallhighmeemisolatedform
            ";": u"\u06E3", # smalllowseen
            ",": u"\u06E5", # smallwaw
            ".": u"\u06E6", # smallya
            "!": u"\u06E8", # smallhighnoon
            "-": u"\u06EA", # emptycentrelowstop
            "+": u"\u06EB", # emptycentrehighstop
            "%": u"\u06EC", # roundedhighstopwithfilledcentre
            "]": u"\u06ED", # smalllowmeem           
}

def transString(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2uni.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
with open("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quran/Text/Data/Quranic Corpus Morphology.txt", "r", encoding="utf8") as file:
    text_line = file.readlines()

# %%
text_line
# Out:
# ['LOCATION\tFORM\tTAG\tFEATURES\n',
#  '(1:1:1:1)\tbi\tP\tPREFIX|bi+\n',
#  '(1:1:1:2)\tsomi\tN\tSTEM|POS:N|LEM:{som|ROOT:smw|M|GEN\n',
#  '(1:1:2:1)\t{ll~ahi\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN\n',
#  '(1:1:3:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(1:1:3:2)\tr~aHoma`ni\tADJ\tSTEM|POS:ADJ|LEM:r~aHoma`n|ROOT:rHm|MS|GEN\n',
#  '(1:1:4:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(1:1:4:2)\tr~aHiymi\tADJ\tSTEM|POS:ADJ|LEM:r~aHiym|ROOT:rHm|MS|GEN\n',
#  '(1:2:1:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(1:2:1:2)\tHamodu\tN\tSTEM|POS:N|LEM:Hamod|ROOT:Hmd|M|NOM\n',
#  '(1:2:2:1)\tli\tP\tPREFIX|l:P+\n',
#  '(1:2:2:2)\tl~ahi\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN\n',
#  '(1:2:3:1)\trab~i\tN\tSTEM|POS:N|LEM:rab~|ROOT:rbb|M|GEN\n',
#  '(1:2:4:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(1:2:4:2)\tEa`lamiyna\tN\tSTEM|POS:N|LEM:Ea`lamiyn|ROOT:Elm|MP|GEN\n',
#  '(1:3:1:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(1:3:1:2)\tr~aHoma`ni\tADJ\tSTEM|POS:ADJ|LEM:r~aHoma`n|ROOT:rHm|MS|GEN\n',
#  '(1:3:2:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(1:3:2:2)\tr~aHiymi\tADJ\tSTEM|POS:ADJ|LEM:r~aHiym|ROOT:rHm|MS|GEN\n',
#  '(1:4:1:1)\tma`liki\tN\tSTEM|POS:N|ACT|PCPL|LEM:ma`lik|ROOT:mlk|M|GEN\n',
#  '(1:4:2:1)\tyawomi\tN\tSTEM|POS:N|LEM:yawom|ROOT:ywm|M|GEN\n',
#  '(1:4:3:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(1:4:3:2)\td~iyni\tN\tSTEM|POS:N|LEM:diyn|ROOT:dyn|M|GEN\n',
#  '(1:5:1:1)\t<iy~aAka\tPRON\tSTEM|POS:PRON|LEM:<iy~aA|2MS\n',
#  '(1:5:2:1)\tnaEobudu\tV\tSTEM|POS:V|IMPF|LEM:Eabada|ROOT:Ebd|1P\n',
#  '(1:5:3:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(1:5:3:2)\t<iy~aAka\tPRON\tSTEM|POS:PRON|LEM:<iy~aA|2MS\n',
#  '(1:5:4:1)\tnasotaEiynu\tV\tSTEM|POS:V|IMPF|(X)|LEM:{sotaEiynu|ROOT:Ewn|1P\n',
#  '(1:6:1:1)\t{hodi\tV\tSTEM|POS:V|IMPV|LEM:hadaY|ROOT:hdy|2MS\n',
#  '(1:6:1:2)\tnaA\tPRON\tSUFFIX|PRON:1P\n',
#  '(1:6:2:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(1:6:2:2)\tS~ira`Ta\tN\tSTEM|POS:N|LEM:Sira`T|ROOT:SrT|M|ACC\n',
#  '(1:6:3:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(1:6:3:2)\tmusotaqiyma\tADJ\tSTEM|POS:ADJ|ACT|PCPL|(X)|LEM:m~usotaqiym|ROOT:qwm|M|ACC\n',
#  '(1:7:1:1)\tSira`Ta\tN\tSTEM|POS:N|LEM:Sira`T|ROOT:SrT|M|ACC\n',
#  '(1:7:2:1)\t{l~a*iyna\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MP\n',
#  '(1:7:3:1)\t>anoEamo\tV\tSTEM|POS:V|PERF|(IV)|LEM:>anoEama|ROOT:nEm|2MS\n',
#  '(1:7:3:2)\tta\tPRON\tSUFFIX|PRON:2MS\n',
#  '(1:7:4:1)\tEalayo\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(1:7:4:2)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(1:7:5:1)\tgayori\tN\tSTEM|POS:N|LEM:gayor|ROOT:gyr|M|GEN\n',
#  '(1:7:6:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(1:7:6:2)\tmagoDuwbi\tN\tSTEM|POS:N|PASS|PCPL|LEM:magoDuwb|ROOT:gDb|M|GEN\n',
#  '(1:7:7:1)\tEalayo\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(1:7:7:2)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(1:7:8:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(1:7:8:2)\tlaA\tNEG\tSTEM|POS:NEG|LEM:laA\n',
#  '(1:7:9:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(1:7:9:2)\tD~aA^l~iyna\tN\tSTEM|POS:N|ACT|PCPL|LEM:DaA^l~|ROOT:Dll|MP|GEN\n',
#  '(2:1:1:1)\tAl^m^\tINL\tSTEM|POS:INL\n',
#  '(2:2:1:1)\t*a`lika\tDEM\tSTEM|POS:DEM|LEM:*a`lik|MS\n',
#  '(2:2:2:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:2:2:2)\tkita`bu\tN\tSTEM|POS:N|LEM:kita`b|ROOT:ktb|M|NOM\n',
#  '(2:2:3:1)\tlaA\tNEG\tSTEM|POS:NEG|LEM:laA|SP:<in~\n',
#  '(2:2:4:1)\trayoba\tN\tSTEM|POS:N|LEM:rayob|ROOT:ryb|M|ACC\n',
#  '(2:2:5:1)\tfiy\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:2:5:2)\thi\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:2:6:1)\thudFY\tN\tSTEM|POS:N|LEM:hudFY|ROOT:hdy|M|INDEF|NOM\n',
#  '(2:2:7:1)\tl~i\tP\tPREFIX|l:P+\n',
#  '(2:2:7:2)\tlo\tDET\tPREFIX|Al+\n',
#  '(2:2:7:3)\tmut~aqiyna\tN\tSTEM|POS:N|ACT|PCPL|(VIII)|LEM:mut~aqiyn|ROOT:wqy|MP|GEN\n',
#  '(2:3:1:1)\t{l~a*iyna\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MP\n',
#  "(2:3:2:1)\tyu&ominu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:'aAmana|ROOT:Amn|3MP\n",
#  '(2:3:2:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:3:3:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:3:3:2)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:3:3:3)\tgayobi\tN\tSTEM|POS:N|LEM:gayob|ROOT:gyb|M|GEN\n',
#  '(2:3:4:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:3:4:2)\tyuqiymu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:>aqaAma|ROOT:qwm|3MP\n',
#  '(2:3:4:3)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:3:5:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:3:5:2)\tS~alaw`pa\tN\tSTEM|POS:N|LEM:Salaw`p|ROOT:Slw|F|ACC\n',
#  '(2:3:6:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:3:6:2)\tmi\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:3:6:3)\tm~aA\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:3:7:1)\trazaqo\tV\tSTEM|POS:V|PERF|LEM:razaqa|ROOT:rzq|1P\n',
#  '(2:3:7:2)\tna`\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:3:7:3)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:3:8:1)\tyunfiqu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:>anfaqa|ROOT:nfq|3MP\n',
#  '(2:3:8:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:4:1:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:4:1:2)\t{l~a*iyna\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MP\n',
#  "(2:4:2:1)\tyu&ominu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:'aAmana|ROOT:Amn|3MP\n",
#  '(2:4:2:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:4:3:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:4:3:2)\tmaA^\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:4:4:1)\t>unzila\tV\tSTEM|POS:V|PERF|PASS|(IV)|LEM:>anzala|ROOT:nzl|3MS\n',
#  '(2:4:5:1)\t<ilayo\tP\tSTEM|POS:P|LEM:<ilaY`\n',
#  '(2:4:5:2)\tka\tPRON\tSUFFIX|PRON:2MS\n',
#  '(2:4:6:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:4:6:2)\tmaA^\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:4:7:1)\t>unzila\tV\tSTEM|POS:V|PERF|PASS|(IV)|LEM:>anzala|ROOT:nzl|3MS\n',
#  '(2:4:8:1)\tmin\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:4:9:1)\tqaboli\tN\tSTEM|POS:N|LEM:qabol|ROOT:qbl|GEN\n',
#  '(2:4:9:2)\tka\tPRON\tSUFFIX|PRON:2MS\n',
#  '(2:4:10:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:4:10:2)\tbi\tP\tPREFIX|bi+\n',
#  '(2:4:10:3)\t{lo\tDET\tPREFIX|Al+\n',
#  "(2:4:10:4)\t'aAxirapi\tN\tSTEM|POS:N|LEM:A^xir|ROOT:Axr|FS|GEN\n",
#  '(2:4:11:1)\thumo\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:4:12:1)\tyuwqinu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:yuwqinu|ROOT:yqn|3MP\n',
#  '(2:4:12:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:5:1:1)\t>uw@la`^}ika\tDEM\tSTEM|POS:DEM|LEM:>uwla`^}ik|P\n',
#  '(2:5:2:1)\tEalaY`\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(2:5:3:1)\thudFY\tN\tSTEM|POS:N|LEM:hudFY|ROOT:hdy|M|INDEF|GEN\n',
#  '(2:5:4:1)\tm~in\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:5:5:1)\tr~ab~i\tN\tSTEM|POS:N|LEM:rab~|ROOT:rbb|M|GEN\n',
#  '(2:5:5:2)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:5:6:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:5:6:2)\t>uw@la`^}ika\tDEM\tSTEM|POS:DEM|LEM:>uwla`^}ik|P\n',
#  '(2:5:7:1)\thumu\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:5:8:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:5:8:2)\tmufoliHuwna\tN\tSTEM|POS:N|ACT|PCPL|(IV)|LEM:mufoliHuwn|ROOT:flH|MP|NOM\n',
#  '(2:6:1:1)\t<in~a\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:6:2:1)\t{l~a*iyna\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MP\n',
#  '(2:6:3:1)\tkafaru\tV\tSTEM|POS:V|PERF|LEM:kafara|ROOT:kfr|3MP\n',
#  '(2:6:3:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  "(2:6:4:1)\tsawaA^'N\tN\tSTEM|POS:N|LEM:sawaA^'|ROOT:swy|M|INDEF|NOM\n",
#  '(2:6:5:1)\tEalayo\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(2:6:5:2)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  "(2:6:6:1)\t'a\tEQ\tPREFIX|A:EQ+\n",
#  '(2:6:6:2)\t>an*aro\tV\tSTEM|POS:V|PERF|(IV)|LEM:>an*ara|ROOT:n*r|2MS\n',
#  '(2:6:6:3)\tta\tPRON\tSUFFIX|PRON:2MS\n',
#  '(2:6:6:4)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:6:7:1)\t>amo\tCONJ\tSTEM|POS:CONJ|LEM:>am\n',
#  '(2:6:8:1)\tlamo\tNEG\tSTEM|POS:NEG|LEM:lam\n',
#  '(2:6:9:1)\ttun*iro\tV\tSTEM|POS:V|IMPF|(IV)|LEM:>an*ara|ROOT:n*r|2MS|MOOD:JUS\n',
#  '(2:6:9:2)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:6:10:1)\tlaA\tNEG\tSTEM|POS:NEG|LEM:laA\n',
#  "(2:6:11:1)\tyu&ominu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:'aAmana|ROOT:Amn|3MP\n",
#  '(2:6:11:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:7:1:1)\txatama\tV\tSTEM|POS:V|PERF|LEM:xatama|ROOT:xtm|3MS\n',
#  '(2:7:2:1)\t{ll~ahu\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|NOM\n',
#  '(2:7:3:1)\tEalaY`\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(2:7:4:1)\tquluwbi\tN\tSTEM|POS:N|LEM:qalob|ROOT:qlb|FP|GEN\n',
#  '(2:7:4:2)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:7:5:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:7:5:2)\tEalaY`\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(2:7:6:1)\tsamoEi\tN\tSTEM|POS:N|LEM:samoE|ROOT:smE|M|GEN\n',
#  '(2:7:6:2)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:7:7:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:7:7:2)\tEalaY`^\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(2:7:8:1)\t>aboSa`ri\tN\tSTEM|POS:N|LEM:baSar|ROOT:bSr|MP|GEN\n',
#  '(2:7:8:2)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:7:9:1)\tgi$a`wapN\tN\tSTEM|POS:N|LEM:gi$a`wap|ROOT:g$w|F|INDEF|NOM\n',
#  '(2:7:10:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:7:10:2)\tla\tP\tPREFIX|l:P+\n',
#  '(2:7:10:3)\thumo\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:7:11:1)\tEa*aAbN\tN\tSTEM|POS:N|LEM:Ea*aAb|ROOT:E*b|M|INDEF|NOM\n',
#  '(2:7:12:1)\tEaZiymN\tADJ\tSTEM|POS:ADJ|LEM:EaZiym|ROOT:EZm|MS|INDEF|NOM\n',
#  '(2:8:1:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:8:1:2)\tmina\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:8:2:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:8:2:2)\tn~aAsi\tN\tSTEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN\n',
#  '(2:8:3:1)\tman\tREL\tSTEM|POS:REL|LEM:man\n',
#  '(2:8:4:1)\tyaquwlu\tV\tSTEM|POS:V|IMPF|LEM:qaAla|ROOT:qwl|3MS\n',
#  "(2:8:5:1)\t'aAma\tV\tSTEM|POS:V|PERF|(IV)|LEM:'aAmana|ROOT:Amn|1P\n",
#  '(2:8:5:2)\tn~aA\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:8:6:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:8:6:2)\t{ll~ahi\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN\n',
#  '(2:8:7:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:8:7:2)\tbi\tP\tPREFIX|bi+\n',
#  '(2:8:7:3)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:8:7:4)\tyawomi\tN\tSTEM|POS:N|LEM:yawom|ROOT:ywm|M|GEN\n',
#  '(2:8:8:1)\t{lo\tDET\tPREFIX|Al+\n',
#  "(2:8:8:2)\t'aAxiri\tADJ\tSTEM|POS:ADJ|LEM:A^xir|ROOT:Axr|MS|GEN\n",
#  '(2:8:9:1)\twa\tCIRC\tPREFIX|w:CIRC+\n',
#  '(2:8:9:2)\tmaA\tNEG\tSTEM|POS:NEG|LEM:maA|SP:kaAn\n',
#  '(2:8:10:1)\thum\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:8:11:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:8:11:2)\tmu&ominiyna\tN\tSTEM|POS:N|ACT|PCPL|(IV)|LEM:mu&omin|ROOT:Amn|MP|GEN\n',
#  '(2:9:1:1)\tyuxa`diEu\tV\tSTEM|POS:V|IMPF|(III)|LEM:yuxa`diEu|ROOT:xdE|3MP\n',
#  '(2:9:1:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:9:2:1)\t{ll~aha\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|ACC\n',
#  '(2:9:3:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:9:3:2)\t{l~a*iyna\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MP\n',
#  "(2:9:4:1)\t'aAmanu\tV\tSTEM|POS:V|PERF|(IV)|LEM:'aAmana|ROOT:Amn|3MP\n",
#  '(2:9:4:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:9:5:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:9:5:2)\tmaA\tNEG\tSTEM|POS:NEG|LEM:maA\n',
#  '(2:9:6:1)\tyaxodaEu\tV\tSTEM|POS:V|IMPF|LEM:yaxodaEu|ROOT:xdE|3MP\n',
#  '(2:9:6:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:9:7:1)\t<il~aA^\tRES\tSTEM|POS:RES|LEM:<il~aA\n',
#  '(2:9:8:1)\t>anfusa\tN\tSTEM|POS:N|LEM:nafos|ROOT:nfs|FP|ACC\n',
#  '(2:9:8:2)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:9:9:1)\twa\tCIRC\tPREFIX|w:CIRC+\n',
#  '(2:9:9:2)\tmaA\tNEG\tSTEM|POS:NEG|LEM:maA\n',
#  '(2:9:10:1)\tya$oEuru\tV\tSTEM|POS:V|IMPF|LEM:ya$oEuru|ROOT:$Er|3MP\n',
#  '(2:9:10:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:10:1:1)\tfiY\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:10:2:1)\tquluwbi\tN\tSTEM|POS:N|LEM:qalob|ROOT:qlb|FP|GEN\n',
#  '(2:10:2:2)\thim\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:10:3:1)\tm~araDN\tN\tSTEM|POS:N|LEM:m~araD|ROOT:mrD|M|INDEF|NOM\n',
#  '(2:10:4:1)\tfa\tREM\tPREFIX|f:REM+\n',
#  '(2:10:4:2)\tzaAda\tV\tSTEM|POS:V|PERF|LEM:zaAda|ROOT:zyd|3MS\n',
#  '(2:10:4:3)\thumu\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:10:5:1)\t{ll~ahu\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|NOM\n',
#  '(2:10:6:1)\tmaraDFA\tN\tSTEM|POS:N|LEM:m~araD|ROOT:mrD|M|INDEF|ACC\n',
#  '(2:10:7:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:10:7:2)\tla\tP\tPREFIX|l:P+\n',
#  '(2:10:7:3)\thumo\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:10:8:1)\tEa*aAbN\tN\tSTEM|POS:N|LEM:Ea*aAb|ROOT:E*b|M|INDEF|NOM\n',
#  '(2:10:9:1)\t>aliymN[\tADJ\tSTEM|POS:ADJ|LEM:>aliym|ROOT:Alm|MS|INDEF|NOM\n',
#  '(2:10:10:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:10:10:2)\tmaA\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:10:11:1)\tkaAnu\tV\tSTEM|POS:V|PERF|LEM:kaAna|ROOT:kwn|SP:kaAn|3MP\n',
#  '(2:10:11:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:10:12:1)\tyako*ibu\tV\tSTEM|POS:V|IMPF|LEM:ka*aba|ROOT:k*b|3MP\n',
#  '(2:10:12:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:11:1:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:11:1:2)\t<i*aA\tT\tSTEM|POS:T|LEM:<i*aA\n',
#  '(2:11:2:1)\tqiyla\tV\tSTEM|POS:V|PERF|PASS|LEM:qaAla|ROOT:qwl|3MS\n',
#  '(2:11:3:1)\tla\tP\tPREFIX|l:P+\n',
#  '(2:11:3:2)\thumo\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:11:4:1)\tlaA\tPRO\tSTEM|POS:PRO|LEM:laA\n',
#  '(2:11:5:1)\ttufosidu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:>afosadu|ROOT:fsd|2MP|MOOD:JUS\n',
#  '(2:11:5:2)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:11:6:1)\tfiY\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:11:7:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:11:7:2)\t>aroDi\tN\tSTEM|POS:N|LEM:>aroD|ROOT:ArD|F|GEN\n',
#  '(2:11:8:1)\tqaAlu\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MP\n',
#  '(2:11:8:2)\tw^A@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:11:9:1)\t<in~a\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:11:9:2)\tmaA\tPREV\tSTEM|POS:PREV|LEM:maA\n',
#  '(2:11:10:1)\tnaHonu\tPRON\tSTEM|POS:PRON|1P\n',
#  '(2:11:11:1)\tmuSoliHuwna\tN\tSTEM|POS:N|ACT|PCPL|(IV)|LEM:muSoliH|ROOT:SlH|MP|NOM\n',
#  '(2:12:1:1)\t>alaA^\tINC\tSTEM|POS:INC|LEM:>alaA^\n',
#  '(2:12:2:1)\t<in~a\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:12:2:2)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:12:3:1)\thumu\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:12:4:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:12:4:2)\tmufosiduwna\tN\tSTEM|POS:N|ACT|PCPL|(IV)|LEM:mufosid|ROOT:fsd|MP|NOM\n',
#  '(2:12:5:1)\twa\tSUP\tPREFIX|w:SUP+\n',
#  '(2:12:5:2)\tla`kin\tAMD\tSTEM|POS:AMD|LEM:la`kin\n',
#  '(2:12:6:1)\tl~aA\tNEG\tSTEM|POS:NEG|LEM:laA\n',
#  '(2:12:7:1)\tya$oEuru\tV\tSTEM|POS:V|IMPF|LEM:ya$oEuru|ROOT:$Er|3MP\n',
#  '(2:12:7:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:13:1:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:13:1:2)\t<i*aA\tT\tSTEM|POS:T|LEM:<i*aA\n',
#  '(2:13:2:1)\tqiyla\tV\tSTEM|POS:V|PERF|PASS|LEM:qaAla|ROOT:qwl|3MS\n',
#  '(2:13:3:1)\tla\tP\tPREFIX|l:P+\n',
#  '(2:13:3:2)\thumo\tPRON\tSTEM|POS:PRON|3MP\n',
#  "(2:13:4:1)\t'aAminu\tV\tSTEM|POS:V|IMPV|(IV)|LEM:'aAmana|ROOT:Amn|2MP\n",
#  '(2:13:4:2)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:13:5:1)\tka\tP\tPREFIX|ka+\n',
#  '(2:13:5:2)\tmaA^\tSUB\tSTEM|POS:SUB|LEM:maA\n',
#  "(2:13:6:1)\t'aAmana\tV\tSTEM|POS:V|PERF|(IV)|LEM:'aAmana|ROOT:Amn|3MS\n",
#  '(2:13:7:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:13:7:2)\tn~aAsu\tN\tSTEM|POS:N|LEM:n~aAs|ROOT:nws|MP|NOM\n',
#  '(2:13:8:1)\tqaAlu\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MP\n',
#  '(2:13:8:2)\tw^A@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:13:9:1)\t>a\tINTG\tPREFIX|A:INTG+\n',
#  "(2:13:9:2)\tnu&ominu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:'aAmana|ROOT:Amn|1P\n",
#  '(2:13:10:1)\tka\tP\tPREFIX|ka+\n',
#  '(2:13:10:2)\tmaA^\tSUB\tSTEM|POS:SUB|LEM:maA\n',
#  "(2:13:11:1)\t'aAmana\tV\tSTEM|POS:V|PERF|(IV)|LEM:'aAmana|ROOT:Amn|3MS\n",
#  '(2:13:12:1)\t{l\tDET\tPREFIX|Al+\n',
#  "(2:13:12:2)\ts~ufahaA^'u\tN\tSTEM|POS:N|LEM:safiyh|ROOT:sfh|MP|NOM\n",
#  '(2:13:13:1)\t>alaA^\tINC\tSTEM|POS:INC|LEM:>alaA^\n',
#  '(2:13:14:1)\t<in~a\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:13:14:2)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:13:15:1)\thumu\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:13:16:1)\t{l\tDET\tPREFIX|Al+\n',
#  "(2:13:16:2)\ts~ufahaA^'u\tN\tSTEM|POS:N|LEM:safiyh|ROOT:sfh|MP|NOM\n",
#  '(2:13:17:1)\twa\tSUP\tPREFIX|w:SUP+\n',
#  '(2:13:17:2)\tla`kin\tAMD\tSTEM|POS:AMD|LEM:la`kin\n',
#  '(2:13:18:1)\tl~aA\tNEG\tSTEM|POS:NEG|LEM:laA\n',
#  '(2:13:19:1)\tyaEolamu\tV\tSTEM|POS:V|IMPF|LEM:Ealima|ROOT:Elm|3MP\n',
#  '(2:13:19:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:14:1:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:14:1:2)\t<i*aA\tT\tSTEM|POS:T|LEM:<i*aA\n',
#  '(2:14:2:1)\tlaqu\tV\tSTEM|POS:V|PERF|LEM:laqu|ROOT:lqy|3MP\n',
#  '(2:14:2:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:14:3:1)\t{l~a*iyna\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MP\n',
#  "(2:14:4:1)\t'aAmanu\tV\tSTEM|POS:V|PERF|(IV)|LEM:'aAmana|ROOT:Amn|3MP\n",
#  '(2:14:4:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:14:5:1)\tqaAlu\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MP\n',
#  '(2:14:5:2)\tw^A@\tPRON\tSUFFIX|PRON:3MP\n',
#  "(2:14:6:1)\t'aAma\tV\tSTEM|POS:V|PERF|(IV)|LEM:'aAmana|ROOT:Amn|1P\n",
#  '(2:14:6:2)\tn~aA\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:14:7:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:14:7:2)\t<i*aA\tT\tSTEM|POS:T|LEM:<i*aA\n',
#  '(2:14:8:1)\txala\tV\tSTEM|POS:V|PERF|LEM:xalaA|ROOT:xlw|3MP\n',
#  '(2:14:8:2)\twoA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:14:9:1)\t<ilaY`\tP\tSTEM|POS:P|LEM:<ilaY`\n',
#  '(2:14:10:1)\t$aya`Tiyni\tN\tSTEM|POS:N|LEM:$ayoTa`n|ROOT:$Tn|MP|GEN\n',
#  '(2:14:10:2)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:14:11:1)\tqaAlu\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MP\n',
#  '(2:14:11:2)\tw^A@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:14:12:1)\t<in~a\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:14:12:2)\tA\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:14:13:1)\tmaEa\tLOC\tSTEM|POS:LOC|LEM:maE|ACC\n',
#  '(2:14:13:2)\tkumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:14:14:1)\t<in~a\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:14:14:2)\tmaA\tPREV\tSTEM|POS:PREV|LEM:maA\n',
#  '(2:14:15:1)\tnaHonu\tPRON\tSTEM|POS:PRON|1P\n',
#  "(2:14:16:1)\tmusotahozi'uwna\tN\tSTEM|POS:N|ACT|PCPL|(X)|LEM:musotahozi'uwn|ROOT:hzA|MP|NOM\n",
#  '(2:15:1:1)\t{ll~ahu\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|NOM\n',
#  '(2:15:2:1)\tyasotahozi}u\tV\tSTEM|POS:V|IMPF|(X)|LEM:{sotuhozi}a|ROOT:hzA|3MS\n',
#  '(2:15:3:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:15:3:2)\thimo\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:15:4:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:15:4:2)\tyamud~u\tV\tSTEM|POS:V|IMPF|LEM:mad~a|ROOT:mdd|3MS\n',
#  '(2:15:4:3)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:15:5:1)\tfiY\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:15:6:1)\tTugoya`ni\tN\tSTEM|POS:N|VN|LEM:Tugoya`n|ROOT:Tgy|M|GEN\n',
#  '(2:15:6:2)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:15:7:1)\tyaEomahu\tV\tSTEM|POS:V|IMPF|LEM:yaEomahu|ROOT:Emh|3MP\n',
#  '(2:15:7:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:16:1:1)\t>uw@la`^}ika\tDEM\tSTEM|POS:DEM|LEM:>uwla`^}ik|P\n',
#  '(2:16:2:1)\t{l~a*iyna\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MP\n',
#  '(2:16:3:1)\t{$otara\tV\tSTEM|POS:V|PERF|(VIII)|LEM:{$otaraY`|ROOT:$ry|3MP\n',
#  '(2:16:3:2)\twuA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:16:4:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:16:4:2)\tD~ala`lapa\tN\tSTEM|POS:N|LEM:Dala`lap|ROOT:Dll|F|ACC\n',
#  '(2:16:5:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:16:5:2)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:16:5:3)\thudaY`\tN\tSTEM|POS:N|LEM:hudFY|ROOT:hdy|M|GEN\n',
#  '(2:16:6:1)\tfa\tREM\tPREFIX|f:REM+\n',
#  '(2:16:6:2)\tmaA\tNEG\tSTEM|POS:NEG|LEM:maA\n',
#  '(2:16:7:1)\trabiHat\tV\tSTEM|POS:V|PERF|LEM:rabiHat|ROOT:rbH|3FS\n',
#  '(2:16:8:1)\tt~ija`ratu\tN\tSTEM|POS:N|LEM:tija`rap|ROOT:tjr|F|NOM\n',
#  '(2:16:8:2)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:16:9:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:16:9:2)\tmaA\tNEG\tSTEM|POS:NEG|LEM:maA\n',
#  '(2:16:10:1)\tkaAnu\tV\tSTEM|POS:V|PERF|LEM:kaAna|ROOT:kwn|SP:kaAn|3MP\n',
#  '(2:16:10:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:16:11:1)\tmuhotadiyna\tN\tSTEM|POS:N|ACT|PCPL|(VIII)|LEM:m~uhotaduwn|ROOT:hdy|MP|ACC\n',
#  '(2:17:1:1)\tmavalu\tN\tSTEM|POS:N|LEM:maval|ROOT:mvl|M|NOM\n',
#  '(2:17:1:2)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:17:2:1)\tka\tP\tPREFIX|ka+\n',
#  '(2:17:2:2)\tmavali\tN\tSTEM|POS:N|LEM:maval|ROOT:mvl|M|GEN\n',
#  '(2:17:3:1)\t{l~a*iY\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MS\n',
#  '(2:17:4:1)\t{sotawoqada\tV\tSTEM|POS:V|PERF|(X)|LEM:{sotawoqada|ROOT:wqd|3MS\n',
#  '(2:17:5:1)\tnaArFA\tN\tSTEM|POS:N|LEM:naAr|ROOT:nwr|F|INDEF|ACC\n',
#  '(2:17:6:1)\tfa\tREM\tPREFIX|f:REM+\n',
#  '(2:17:6:2)\tlam~aA^\tT\tSTEM|POS:T|LEM:lam~aA\n',
#  "(2:17:7:1)\t>aDaA^'ato\tV\tSTEM|POS:V|PERF|(IV)|LEM:>aDaA^'a|ROOT:DwA|3FS\n",
#  '(2:17:8:1)\tmaA\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:17:9:1)\tHawola\tLOC\tSTEM|POS:LOC|LEM:Hawol|ROOT:Hwl|M|ACC\n',
#  '(2:17:9:2)\thu,\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:17:10:1)\t*ahaba\tV\tSTEM|POS:V|PERF|LEM:*ahaba|ROOT:*hb|3MS\n',
#  '(2:17:11:1)\t{ll~ahu\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|NOM\n',
#  '(2:17:12:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:17:12:2)\tnuwri\tN\tSTEM|POS:N|LEM:nuwr|ROOT:nwr|M|GEN\n',
#  '(2:17:12:3)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:17:13:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:17:13:2)\ttaraka\tV\tSTEM|POS:V|PERF|LEM:taraka|ROOT:trk|3MS\n',
#  '(2:17:13:3)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:17:14:1)\tfiY\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:17:15:1)\tZuluma`tK\tN\tSTEM|POS:N|LEM:Zuluma`t|ROOT:Zlm|FP|INDEF|GEN\n',
#  '(2:17:16:1)\tl~aA\tNEG\tSTEM|POS:NEG|LEM:laA\n',
#  '(2:17:17:1)\tyuboSiru\tV\tSTEM|POS:V|IMPF|(IV)|LEM:>aboSara|ROOT:bSr|3MP\n',
#  '(2:17:17:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:18:1:1)\tSum~N[\tN\tSTEM|POS:N|LEM:>aSam~|ROOT:Smm|P|INDEF|NOM\n',
#  '(2:18:2:1)\tbukomN\tN\tSTEM|POS:N|LEM:>abokam|ROOT:bkm|P|INDEF|NOM\n',
#  '(2:18:3:1)\tEumoYN\tN\tSTEM|POS:N|LEM:>aEomaY`|ROOT:Emy|MP|INDEF|NOM\n',
#  '(2:18:4:1)\tfa\tCONJ\tPREFIX|f:CONJ+\n',
#  '(2:18:4:2)\thumo\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:18:5:1)\tlaA\tNEG\tSTEM|POS:NEG|LEM:laA\n',
#  '(2:18:6:1)\tyarojiEu\tV\tSTEM|POS:V|IMPF|LEM:rajaEa|ROOT:rjE|3MP\n',
#  '(2:18:6:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:19:1:1)\t>awo\tCONJ\tSTEM|POS:CONJ|LEM:>aw\n',
#  '(2:19:2:1)\tka\tP\tPREFIX|ka+\n',
#  '(2:19:2:2)\tSay~ibK\tN\tSTEM|POS:N|LEM:Say~ib|ROOT:Swb|M|INDEF|GEN\n',
#  '(2:19:3:1)\tm~ina\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:19:4:1)\t{l\tDET\tPREFIX|Al+\n',
#  "(2:19:4:2)\ts~amaA^'i\tN\tSTEM|POS:N|LEM:samaA^'|ROOT:smw|F|GEN\n",
#  '(2:19:5:1)\tfiy\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:19:5:2)\thi\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:19:6:1)\tZuluma`tN\tN\tSTEM|POS:N|LEM:Zuluma`t|ROOT:Zlm|FP|INDEF|NOM\n',
#  '(2:19:7:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:19:7:2)\traEodN\tN\tSTEM|POS:N|LEM:raEod|ROOT:rEd|M|INDEF|NOM\n',
#  '(2:19:8:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:19:8:2)\tbaroqN\tN\tSTEM|POS:N|LEM:baroq|ROOT:brq|M|INDEF|NOM\n',
#  '(2:19:9:1)\tyajoEalu\tV\tSTEM|POS:V|IMPF|LEM:jaEala|ROOT:jEl|3MP\n',
#  '(2:19:9:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:19:10:1)\t>aSa`biEa\tN\tSTEM|POS:N|LEM:>aSa`biE|ROOT:SbE|MP|ACC\n',
#  '(2:19:10:2)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:19:11:1)\tfiY^\tP\tSTEM|POS:P|LEM:fiY\n',
#  "(2:19:12:1)\t'aA*aAni\tN\tSTEM|POS:N|LEM:>u*unN|ROOT:A*n|FP|GEN\n",
#  '(2:19:12:2)\thim\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:19:13:1)\tm~ina\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:19:14:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:19:14:2)\tS~awa`Eiqi\tN\tSTEM|POS:N|LEM:SaAEiqap|ROOT:SEq|FP|GEN\n',
#  '(2:19:15:1)\tHa*ara\tN\tSTEM|POS:N|VN|LEM:Ha*ar|ROOT:H*r|M|ACC\n',
#  '(2:19:16:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:19:16:2)\tmawoti\tN\tSTEM|POS:N|LEM:mawot|ROOT:mwt|M|GEN\n',
#  '(2:19:17:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:19:17:2)\t{ll~ahu\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|NOM\n',
#  '(2:19:18:1)\tmuHiyTN[\tN\tSTEM|POS:N|ACT|PCPL|(IV)|LEM:muHiyT|ROOT:HwT|M|INDEF|NOM\n',
#  '(2:19:19:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:19:19:2)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:19:19:3)\tka`firiyna\tN\tSTEM|POS:N|ACT|PCPL|LEM:ka`firuwn|ROOT:kfr|MP|GEN\n',
#  '(2:20:1:1)\tyakaAdu\tV\tSTEM|POS:V|IMPF|LEM:kaAda|ROOT:kwd|SP:kaAd|3MS\n',
#  '(2:20:2:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:20:2:2)\tbaroqu\tN\tSTEM|POS:N|LEM:baroq|ROOT:brq|M|NOM\n',
#  '(2:20:3:1)\tyaxoTafu\tV\tSTEM|POS:V|IMPF|LEM:xaTifa|ROOT:xTf|3MS\n',
#  '(2:20:4:1)\t>aboSa`ra\tN\tSTEM|POS:N|LEM:baSar|ROOT:bSr|MP|ACC\n',
#  '(2:20:4:2)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:20:5:1)\tkul~amaA^\tT\tSTEM|POS:T|LEM:kul~amaA|ROOT:kll\n',
#  "(2:20:6:1)\t>aDaA^'a\tV\tSTEM|POS:V|PERF|(IV)|LEM:>aDaA^'a|ROOT:DwA|3MS\n",
#  '(2:20:7:1)\tla\tP\tPREFIX|l:P+\n',
#  '(2:20:7:2)\thum\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:20:8:1)\tm~a$a\tV\tSTEM|POS:V|PERF|LEM:m~a$a|ROOT:m$y|3MP\n',
#  '(2:20:8:2)\twoA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:20:9:1)\tfiy\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:20:9:2)\thi\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:20:10:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:20:10:2)\t<i*aA^\tT\tSTEM|POS:T|LEM:<i*aA\n',
#  '(2:20:11:1)\t>aZolama\tV\tSTEM|POS:V|PERF|(IV)|LEM:>aZolama|ROOT:Zlm|3MS\n',
#  '(2:20:12:1)\tEalayo\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(2:20:12:2)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:20:13:1)\tqaAmu\tV\tSTEM|POS:V|PERF|LEM:qaAma|ROOT:qwm|3MP\n',
#  '(2:20:13:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:20:14:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:20:14:2)\tlawo\tCOND\tSTEM|POS:COND|LEM:law\n',
#  "(2:20:15:1)\t$aA^'a\tV\tSTEM|POS:V|PERF|LEM:$aA^'a|ROOT:$yA|3MS\n",
#  '(2:20:16:1)\t{ll~ahu\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|NOM\n',
#  '(2:20:17:1)\tla\tEMPH\tPREFIX|l:EMPH+\n',
#  '(2:20:17:2)\t*ahaba\tV\tSTEM|POS:V|PERF|LEM:*ahaba|ROOT:*hb|3MS\n',
#  '(2:20:18:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:20:18:2)\tsamoEi\tN\tSTEM|POS:N|LEM:samoE|ROOT:smE|M|GEN\n',
#  '(2:20:18:3)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:20:19:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:20:19:2)\t>aboSa`ri\tN\tSTEM|POS:N|LEM:baSar|ROOT:bSr|MP|GEN\n',
#  '(2:20:19:3)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:20:20:1)\t<in~a\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:20:21:1)\t{ll~aha\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|ACC\n',
#  '(2:20:22:1)\tEalaY`\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(2:20:23:1)\tkul~i\tN\tSTEM|POS:N|LEM:kul~|ROOT:kll|M|GEN\n',
#  "(2:20:24:1)\t$aYo'K\tN\tSTEM|POS:N|LEM:$aYo'|ROOT:$yA|M|INDEF|GEN\n",
#  '(2:20:25:1)\tqadiyrN\tN\tSTEM|POS:N|LEM:qadiyr|ROOT:qdr|M|INDEF|NOM\n',
#  '(2:21:1:1)\tya`^\tVOC\tPREFIX|ya+\n',
#  '(2:21:1:2)\t>ay~uhaA\tN\tSTEM|POS:N|LEM:>ay~uhaA|NOM\n',
#  '(2:21:2:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:21:2:2)\tn~aAsu\tN\tSTEM|POS:N|LEM:n~aAs|ROOT:nws|MP|NOM\n',
#  '(2:21:3:1)\t{Eobudu\tV\tSTEM|POS:V|IMPV|LEM:Eabada|ROOT:Ebd|2MP\n',
#  '(2:21:3:2)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:21:4:1)\trab~a\tN\tSTEM|POS:N|LEM:rab~|ROOT:rbb|M|ACC\n',
#  '(2:21:4:2)\tkumu\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:21:5:1)\t{l~a*iY\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MS\n',
#  '(2:21:6:1)\txalaqa\tV\tSTEM|POS:V|PERF|LEM:xalaqa|ROOT:xlq|3MS\n',
#  '(2:21:6:2)\tkumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:21:7:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:21:7:2)\t{l~a*iyna\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MP\n',
#  '(2:21:8:1)\tmin\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:21:9:1)\tqaboli\tN\tSTEM|POS:N|LEM:qabol|ROOT:qbl|GEN\n',
#  '(2:21:9:2)\tkumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:21:10:1)\tlaEal~a\tACC\tSTEM|POS:ACC|LEM:laEal~|SP:<in~\n',
#  '(2:21:10:2)\tkumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:21:11:1)\ttat~aqu\tV\tSTEM|POS:V|IMPF|(VIII)|LEM:{t~aqaY`|ROOT:wqy|2MP\n',
#  '(2:21:11:2)\twna\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:22:1:1)\t{l~a*iY\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MS\n',
#  '(2:22:2:1)\tjaEala\tV\tSTEM|POS:V|PERF|LEM:jaEala|ROOT:jEl|3MS\n',
#  '(2:22:3:1)\tla\tP\tPREFIX|l:P+\n',
#  '(2:22:3:2)\tkumu\tPRON\tSTEM|POS:PRON|2MP\n',
#  '(2:22:4:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:22:4:2)\t>aroDa\tN\tSTEM|POS:N|LEM:>aroD|ROOT:ArD|F|ACC\n',
#  '(2:22:5:1)\tfira`$FA\tN\tSTEM|POS:N|LEM:fira`$|ROOT:fr$|M|INDEF|ACC\n',
#  '(2:22:6:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:22:6:2)\t{l\tDET\tPREFIX|Al+\n',
#  "(2:22:6:3)\ts~amaA^'a\tN\tSTEM|POS:N|LEM:samaA^'|ROOT:smw|F|ACC\n",
#  "(2:22:7:1)\tbinaA^'F\tN\tSTEM|POS:N|LEM:binaA^'|ROOT:bny|M|INDEF|ACC\n",
#  '(2:22:8:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:22:8:2)\t>anzala\tV\tSTEM|POS:V|PERF|(IV)|LEM:>anzala|ROOT:nzl|3MS\n',
#  '(2:22:9:1)\tmina\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:22:10:1)\t{l\tDET\tPREFIX|Al+\n',
#  "(2:22:10:2)\ts~amaA^'i\tN\tSTEM|POS:N|LEM:samaA^'|ROOT:smw|F|GEN\n",
#  "(2:22:11:1)\tmaA^'F\tN\tSTEM|POS:N|LEM:maA^'|ROOT:mwh|M|INDEF|ACC\n",
#  '(2:22:12:1)\tfa\tCONJ\tPREFIX|f:CONJ+\n',
#  '(2:22:12:2)\t>axoraja\tV\tSTEM|POS:V|PERF|(IV)|LEM:>axoraja|ROOT:xrj|3MS\n',
#  '(2:22:13:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:22:13:2)\thi.\tPRON\tSTEM|POS:PRON|3MS\n',
#  '(2:22:14:1)\tmina\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:22:15:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:22:15:2)\tv~amara`ti\tN\tSTEM|POS:N|LEM:vamara`t|ROOT:vmr|FP|GEN\n',
#  '(2:22:16:1)\trizoqFA\tN\tSTEM|POS:N|LEM:rizoq|ROOT:rzq|M|INDEF|ACC\n',
#  '(2:22:17:1)\tl~a\tP\tPREFIX|l:P+\n',
#  '(2:22:17:2)\tkumo\tPRON\tSTEM|POS:PRON|2MP\n',
#  '(2:22:18:1)\tfa\tREM\tPREFIX|f:REM+\n',
#  '(2:22:18:2)\tlaA\tPRO\tSTEM|POS:PRO|LEM:laA\n',
#  '(2:22:19:1)\ttajoEalu\tV\tSTEM|POS:V|IMPF|LEM:jaEala|ROOT:jEl|2MP|MOOD:JUS\n',
#  '(2:22:19:2)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:22:20:1)\tli\tP\tPREFIX|l:P+\n',
#  '(2:22:20:2)\tl~ahi\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN\n',
#  '(2:22:21:1)\t>andaAdFA\tN\tSTEM|POS:N|LEM:>andaAd|ROOT:ndd|MP|INDEF|ACC\n',
#  '(2:22:22:1)\twa\tCIRC\tPREFIX|w:CIRC+\n',
#  '(2:22:22:2)\t>antumo\tPRON\tSTEM|POS:PRON|2MP\n',
#  '(2:22:23:1)\ttaEolamu\tV\tSTEM|POS:V|IMPF|LEM:Ealima|ROOT:Elm|2MP\n',
#  '(2:22:23:2)\twna\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:23:1:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:23:1:2)\t<in\tCOND\tSTEM|POS:COND|LEM:<in\n',
#  '(2:23:2:1)\tkun\tV\tSTEM|POS:V|PERF|LEM:kaAna|ROOT:kwn|SP:kaAn|2MP\n',
#  '(2:23:2:2)\ttumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:23:3:1)\tfiY\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:23:4:1)\trayobK\tN\tSTEM|POS:N|LEM:rayob|ROOT:ryb|M|INDEF|GEN\n',
#  '(2:23:5:1)\tm~i\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:23:5:2)\tm~aA\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:23:6:1)\tnaz~alo\tV\tSTEM|POS:V|PERF|(II)|LEM:naz~ala|ROOT:nzl|1P\n',
#  '(2:23:6:2)\tnaA\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:23:7:1)\tEalaY`\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(2:23:8:1)\tEabodi\tN\tSTEM|POS:N|LEM:Eabod|ROOT:Ebd|M|GEN\n',
#  '(2:23:8:2)\tnaA\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:23:9:1)\tfa\tRSLT\tPREFIX|f:RSLT+\n',
#  '(2:23:9:2)\t>otu\tV\tSTEM|POS:V|IMPV|LEM:>ataY|ROOT:Aty|2MP\n',
#  '(2:23:9:3)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:23:10:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:23:10:2)\tsuwrapK\tN\tSTEM|POS:N|LEM:suwrap|ROOT:swr|F|INDEF|GEN\n',
#  '(2:23:11:1)\tm~in\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:23:12:1)\tm~ivoli\tN\tSTEM|POS:N|LEM:mivol|ROOT:mvl|M|GEN\n',
#  '(2:23:12:2)\thi.\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:23:13:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:23:13:2)\t{doEu\tV\tSTEM|POS:V|IMPV|LEM:daEaA|ROOT:dEw|2MP\n',
#  '(2:23:13:3)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  "(2:23:14:1)\t$uhadaA^'a\tN\tSTEM|POS:N|LEM:$ahiyd|ROOT:$hd|MP|ACC\n",
#  '(2:23:14:2)\tkum\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:23:15:1)\tm~in\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:23:16:1)\tduwni\tN\tSTEM|POS:N|LEM:duwn|ROOT:dwn|GEN\n',
#  '(2:23:17:1)\t{ll~ahi\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN\n',
#  '(2:23:18:1)\t<in\tCOND\tSTEM|POS:COND|LEM:<in\n',
#  '(2:23:19:1)\tkun\tV\tSTEM|POS:V|PERF|LEM:kaAna|ROOT:kwn|SP:kaAn|2MP\n',
#  '(2:23:19:2)\ttumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:23:20:1)\tSa`diqiyna\tN\tSTEM|POS:N|ACT|PCPL|LEM:SaAdiq|ROOT:Sdq|MP|ACC\n',
#  '(2:24:1:1)\tfa\tREM\tPREFIX|f:REM+\n',
#  '(2:24:1:2)\t<in\tCOND\tSTEM|POS:COND|LEM:<in\n',
#  '(2:24:2:1)\tl~amo\tNEG\tSTEM|POS:NEG|LEM:lam\n',
#  '(2:24:3:1)\ttafoEalu\tV\tSTEM|POS:V|IMPF|LEM:faEala|ROOT:fEl|2MP|MOOD:JUS\n',
#  '(2:24:3:2)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:24:4:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:24:4:2)\tlan\tNEG\tSTEM|POS:NEG|LEM:lan\n',
#  '(2:24:5:1)\ttafoEalu\tV\tSTEM|POS:V|IMPF|LEM:faEala|ROOT:fEl|2MP|MOOD:SUBJ\n',
#  '(2:24:5:2)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:24:6:1)\tfa\tRSLT\tPREFIX|f:RSLT+\n',
#  '(2:24:6:2)\t{t~aqu\tV\tSTEM|POS:V|IMPV|(VIII)|LEM:{t~aqaY`|ROOT:wqy|2MP\n',
#  '(2:24:6:3)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:24:7:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:24:7:2)\tn~aAra\tN\tSTEM|POS:N|LEM:naAr|ROOT:nwr|F|ACC\n',
#  '(2:24:8:1)\t{l~atiY\tREL\tSTEM|POS:REL|LEM:{l~a*iY|FS\n',
#  '(2:24:9:1)\twaquwdu\tN\tSTEM|POS:N|LEM:waquwd|ROOT:wqd|M|NOM\n',
#  '(2:24:9:2)\thaA\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:24:10:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:24:10:2)\tn~aAsu\tN\tSTEM|POS:N|LEM:n~aAs|ROOT:nws|MP|NOM\n',
#  '(2:24:11:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:24:11:2)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:24:11:3)\tHijaArapu\tN\tSTEM|POS:N|LEM:HijaArap|ROOT:Hjr|F|NOM\n',
#  '(2:24:12:1)\t>uEid~ato\tV\tSTEM|POS:V|PERF|PASS|(IV)|LEM:>aEad~a|ROOT:Edd|3FS\n',
#  '(2:24:13:1)\tli\tP\tPREFIX|l:P+\n',
#  '(2:24:13:2)\tlo\tDET\tPREFIX|Al+\n',
#  '(2:24:13:3)\tka`firiyna\tN\tSTEM|POS:N|ACT|PCPL|LEM:ka`firuwn|ROOT:kfr|MP|GEN\n',
#  '(2:25:1:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:25:1:2)\tba$~iri\tV\tSTEM|POS:V|IMPV|(II)|LEM:bu$~ira|ROOT:b$r|2MS\n',
#  '(2:25:2:1)\t{l~a*iyna\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MP\n',
#  "(2:25:3:1)\t'aAmanu\tV\tSTEM|POS:V|PERF|(IV)|LEM:'aAmana|ROOT:Amn|3MP\n",
#  '(2:25:3:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:25:4:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:25:4:2)\tEamilu\tV\tSTEM|POS:V|PERF|LEM:Eamila|ROOT:Eml|3MP\n',
#  '(2:25:4:3)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:25:5:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:25:5:2)\tS~a`liHa`ti\tN\tSTEM|POS:N|ACT|PCPL|LEM:S~a`liHa`t|ROOT:SlH|FP|ACC\n',
#  '(2:25:6:1)\t>an~a\tACC\tSTEM|POS:ACC|LEM:>an~|SP:<in~\n',
#  '(2:25:7:1)\tla\tP\tPREFIX|l:P+\n',
#  '(2:25:7:2)\thumo\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:25:8:1)\tjan~a`tK\tN\tSTEM|POS:N|LEM:jan~ap|ROOT:jnn|FP|INDEF|ACC\n',
#  '(2:25:9:1)\ttajoriY\tV\tSTEM|POS:V|IMPF|LEM:jarayo|ROOT:jry|3FS\n',
#  '(2:25:10:1)\tmin\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:25:11:1)\ttaHoti\tN\tSTEM|POS:N|LEM:taHot|ROOT:tHt|GEN\n',
#  '(2:25:11:2)\thaA\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:25:12:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:25:12:2)\t>anoha`ru\tN\tSTEM|POS:N|LEM:nahar|ROOT:nhr|MP|NOM\n',
#  '(2:25:13:1)\tkul~amaA\tT\tSTEM|POS:T|LEM:kul~amaA|ROOT:kll\n',
#  '(2:25:14:1)\truziqu\tV\tSTEM|POS:V|PERF|PASS|LEM:razaqa|ROOT:rzq|3MP\n',
#  '(2:25:14:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:25:15:1)\tmino\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:25:15:2)\thaA\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:25:16:1)\tmin\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:25:17:1)\tvamarapK\tN\tSTEM|POS:N|LEM:vamarap|ROOT:vmr|F|INDEF|GEN\n',
#  '(2:25:18:1)\tr~izoqFA\tN\tSTEM|POS:N|LEM:rizoq|ROOT:rzq|M|INDEF|ACC\n',
#  '(2:25:19:1)\tqaAlu\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MP\n',
#  '(2:25:19:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:25:20:1)\tha`*aA\tDEM\tSTEM|POS:DEM|LEM:ha`*aA|MS\n',
#  '(2:25:21:1)\t{l~a*iY\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MS\n',
#  '(2:25:22:1)\truziqo\tV\tSTEM|POS:V|PERF|PASS|LEM:razaqa|ROOT:rzq|1P\n',
#  '(2:25:22:2)\tnaA\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:25:23:1)\tmin\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:25:24:1)\tqabolu\tN\tSTEM|POS:N|LEM:qabol|ROOT:qbl|GEN\n',
#  '(2:25:25:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:25:25:2)\t>utu\tV\tSTEM|POS:V|PERF|PASS|LEM:>ataY|ROOT:Aty|3MP\n',
#  '(2:25:25:3)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:25:26:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:25:26:2)\thi.\tPRON\tSTEM|POS:PRON|3MS\n',
#  '(2:25:27:1)\tmuta$a`bihFA\tN\tSTEM|POS:N|ACT|PCPL|(VI)|LEM:muta$a`bih|ROOT:$bh|M|INDEF|ACC\n',
#  '(2:25:28:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:25:28:2)\tla\tP\tPREFIX|l:P+\n',
#  '(2:25:28:3)\thumo\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:25:29:1)\tfiy\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:25:29:2)\thaA^\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:25:30:1)\t>azowa`jN\tN\tSTEM|POS:N|LEM:zawoj|ROOT:zwj|MP|INDEF|NOM\n',
#  '(2:25:31:1)\tm~uTah~arapN\tADJ\tSTEM|POS:ADJ|PASS|PCPL|(II)|LEM:m~uTah~arap|ROOT:Thr|FS|INDEF|NOM\n',
#  '(2:25:32:1)\twa\tCIRC\tPREFIX|w:CIRC+\n',
#  '(2:25:32:2)\thumo\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:25:33:1)\tfiy\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:25:33:2)\thaA\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:25:34:1)\txa`liduwna\tN\tSTEM|POS:N|ACT|PCPL|LEM:xa`lid|ROOT:xld|MP|NOM\n',
#  '(2:26:1:1)\t<in~a\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:26:2:1)\t{ll~aha\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|ACC\n',
#  '(2:26:3:1)\tlaA\tNEG\tSTEM|POS:NEG|LEM:laA\n',
#  '(2:26:4:1)\tyasotaHoYi.^\tV\tSTEM|POS:V|IMPF|(X)|LEM:yasotaHoYi.^|ROOT:Hyy|3MS\n',
#  '(2:26:5:1)\t>an\tSUB\tSTEM|POS:SUB|LEM:>an\n',
#  '(2:26:6:1)\tyaDoriba\tV\tSTEM|POS:V|IMPF|LEM:Daraba|ROOT:Drb|3MS|MOOD:SUBJ\n',
#  '(2:26:7:1)\tmavalFA\tN\tSTEM|POS:N|LEM:maval|ROOT:mvl|M|INDEF|ACC\n',
#  '(2:26:8:1)\tm~aA\tSUP\tSTEM|POS:SUP|LEM:maA\n',
#  '(2:26:9:1)\tbaEuwDapF\tN\tSTEM|POS:N|LEM:baEuwDap|ROOT:bED|F|INDEF|ACC\n',
#  '(2:26:10:1)\tfa\tCONJ\tPREFIX|f:CONJ+\n',
#  '(2:26:10:2)\tmaA\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:26:11:1)\tfawoqa\tLOC\tSTEM|POS:LOC|LEM:fawoq|ROOT:fwq|M|ACC\n',
#  '(2:26:11:2)\thaA\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:26:12:1)\tfa\tREM\tPREFIX|f:REM+\n',
#  '(2:26:12:2)\t>am~aA\tEXL\tSTEM|POS:EXL|LEM:>am~aA\n',
#  '(2:26:13:1)\t{l~a*iyna\tCOND\tSTEM|POS:COND|LEM:{l~a*iY|MP\n',
#  "(2:26:14:1)\t'aAmanu\tV\tSTEM|POS:V|PERF|(IV)|LEM:'aAmana|ROOT:Amn|3MP\n",
#  '(2:26:14:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:26:15:1)\tfa\tRSLT\tPREFIX|f:RSLT+\n',
#  '(2:26:15:2)\tyaEolamu\tV\tSTEM|POS:V|IMPF|LEM:Ealima|ROOT:Elm|3MP\n',
#  '(2:26:15:3)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:26:16:1)\t>an~a\tACC\tSTEM|POS:ACC|LEM:>an~|SP:<in~\n',
#  '(2:26:16:2)\thu\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:26:17:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:26:17:2)\tHaq~u\tN\tSTEM|POS:N|LEM:Haq~|ROOT:Hqq|M|NOM\n',
#  '(2:26:18:1)\tmin\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:26:19:1)\tr~ab~i\tN\tSTEM|POS:N|LEM:rab~|ROOT:rbb|M|GEN\n',
#  '(2:26:19:2)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:26:20:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:26:20:2)\t>am~aA\tEXL\tSTEM|POS:EXL|LEM:>am~aA\n',
#  '(2:26:21:1)\t{l~a*iyna\tCOND\tSTEM|POS:COND|LEM:{l~a*iY|MP\n',
#  '(2:26:22:1)\tkafaru\tV\tSTEM|POS:V|PERF|LEM:kafara|ROOT:kfr|3MP\n',
#  '(2:26:22:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:26:23:1)\tfa\tRSLT\tPREFIX|f:RSLT+\n',
#  '(2:26:23:2)\tyaquwlu\tV\tSTEM|POS:V|IMPF|LEM:qaAla|ROOT:qwl|3MP\n',
#  '(2:26:23:3)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:26:24:1)\tmaA*aA^\tINTG\tSTEM|POS:INTG|LEM:maA*aA\n',
#  '(2:26:25:1)\t>araAda\tV\tSTEM|POS:V|PERF|(IV)|LEM:>araAda|ROOT:rwd|3MS\n',
#  '(2:26:26:1)\t{ll~ahu\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|NOM\n',
#  '(2:26:27:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:26:27:2)\tha`*aA\tDEM\tSTEM|POS:DEM|LEM:ha`*aA|MS\n',
#  '(2:26:28:1)\tmavalFA\tN\tSTEM|POS:N|LEM:maval|ROOT:mvl|M|INDEF|ACC\n',
#  '(2:26:29:1)\tyuDil~u\tV\tSTEM|POS:V|IMPF|(IV)|LEM:>aDal~a|ROOT:Dll|3MS\n',
#  '(2:26:30:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:26:30:2)\thi.\tPRON\tSTEM|POS:PRON|3MS\n',
#  '(2:26:31:1)\tkaviyrFA\tN\tSTEM|POS:N|LEM:kaviyr|ROOT:kvr|MS|INDEF|ACC\n',
#  '(2:26:32:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:26:32:2)\tyahodiY\tV\tSTEM|POS:V|IMPF|LEM:hadaY|ROOT:hdy|3MS\n',
#  '(2:26:33:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:26:33:2)\thi.\tPRON\tSTEM|POS:PRON|3MS\n',
#  '(2:26:34:1)\tkaviyrFA\tN\tSTEM|POS:N|LEM:kaviyr|ROOT:kvr|MS|INDEF|ACC\n',
#  '(2:26:35:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:26:35:2)\tmaA\tNEG\tSTEM|POS:NEG|LEM:maA\n',
#  '(2:26:36:1)\tyuDil~u\tV\tSTEM|POS:V|IMPF|(IV)|LEM:>aDal~a|ROOT:Dll|3MS\n',
#  '(2:26:37:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:26:37:2)\thi.^\tPRON\tSTEM|POS:PRON|3MS\n',
#  '(2:26:38:1)\t<il~aA\tRES\tSTEM|POS:RES|LEM:<il~aA\n',
#  '(2:26:39:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:26:39:2)\tfa`siqiyna\tN\tSTEM|POS:N|ACT|PCPL|LEM:faAsiq|ROOT:fsq|MP|ACC\n',
#  '(2:27:1:1)\t{l~a*iyna\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MP\n',
#  '(2:27:2:1)\tyanquDu\tV\tSTEM|POS:V|IMPF|LEM:naqaDato|ROOT:nqD|3MP\n',
#  '(2:27:2:2)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:27:3:1)\tEahoda\tN\tSTEM|POS:N|LEM:Eahod|ROOT:Ehd|M|ACC\n',
#  '(2:27:4:1)\t{ll~ahi\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN\n',
#  '(2:27:5:1)\tmin[\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:27:6:1)\tbaEodi\tN\tSTEM|POS:N|LEM:baEod|ROOT:bEd|GEN\n',
#  '(2:27:7:1)\tmiyva`qi\tN\tSTEM|POS:N|LEM:m~iyva`q|ROOT:wvq|M|GEN\n',
#  '(2:27:7:2)\thi.\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:27:8:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:27:8:2)\tyaqoTaEu\tV\tSTEM|POS:V|IMPF|LEM:quTiEa|ROOT:qTE|3MP\n',
#  '(2:27:8:3)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:27:9:1)\tmaA^\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:27:10:1)\t>amara\tV\tSTEM|POS:V|PERF|LEM:>amara|ROOT:Amr|3MS\n',
#  '(2:27:11:1)\t{ll~ahu\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|NOM\n',
#  '(2:27:12:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:27:12:2)\thi.^\tPRON\tSTEM|POS:PRON|3MS\n',
#  '(2:27:13:1)\t>an\tSUB\tSTEM|POS:SUB|LEM:>an\n',
#  '(2:27:14:1)\tyuwSala\tV\tSTEM|POS:V|IMPF|PASS|LEM:yaSilu|ROOT:wSl|3MS|MOOD:SUBJ\n',
#  '(2:27:15:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:27:15:2)\tyufosidu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:>afosadu|ROOT:fsd|3MP\n',
#  '(2:27:15:3)\twna\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:27:16:1)\tfiY\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:27:17:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:27:17:2)\t>aroDi\tN\tSTEM|POS:N|LEM:>aroD|ROOT:ArD|F|GEN\n',
#  '(2:27:18:1)\t>uw@la`^}ika\tDEM\tSTEM|POS:DEM|LEM:>uwla`^}ik|P\n',
#  '(2:27:19:1)\thumu\tPRON\tSTEM|POS:PRON|3MP\n',
#  '(2:27:20:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:27:20:2)\txa`siruwna\tN\tSTEM|POS:N|ACT|PCPL|LEM:xa`siriyn|ROOT:xsr|MP|NOM\n',
#  '(2:28:1:1)\tkayofa\tINTG\tSTEM|POS:INTG|LEM:kayof|ROOT:kyf\n',
#  '(2:28:2:1)\ttakofuru\tV\tSTEM|POS:V|IMPF|LEM:kafara|ROOT:kfr|2MP\n',
#  '(2:28:2:2)\twna\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:28:3:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:28:3:2)\t{ll~ahi\tPN\tSTEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN\n',
#  '(2:28:4:1)\twa\tCIRC\tPREFIX|w:CIRC+\n',
#  '(2:28:4:2)\tkun\tV\tSTEM|POS:V|PERF|LEM:kaAna|ROOT:kwn|SP:kaAn|2MP\n',
#  '(2:28:4:3)\ttumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:28:5:1)\t>amowa`tFA\tN\tSTEM|POS:N|LEM:m~ay~it|ROOT:mwt|MP|INDEF|ACC\n',
#  '(2:28:6:1)\tfa\tCONJ\tPREFIX|f:CONJ+\n',
#  '(2:28:6:2)\t>aHoya`\tV\tSTEM|POS:V|PERF|(IV)|LEM:>aHoyaA|ROOT:Hyy|3MS\n',
#  '(2:28:6:3)\tkumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:28:7:1)\tvum~a\tCONJ\tSTEM|POS:CONJ|LEM:vum~\n',
#  '(2:28:8:1)\tyumiytu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:>amaAta|ROOT:mwt|3MS\n',
#  '(2:28:8:2)\tkumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:28:9:1)\tvum~a\tCONJ\tSTEM|POS:CONJ|LEM:vum~\n',
#  '(2:28:10:1)\tyuHoyiy\tV\tSTEM|POS:V|IMPF|(IV)|LEM:>aHoyaA|ROOT:Hyy|3MS\n',
#  '(2:28:10:2)\tkumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:28:11:1)\tvum~a\tCONJ\tSTEM|POS:CONJ|LEM:vum~\n',
#  '(2:28:12:1)\t<ilayo\tP\tSTEM|POS:P|LEM:<ilaY`\n',
#  '(2:28:12:2)\thi\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:28:13:1)\tturojaEu\tV\tSTEM|POS:V|IMPF|PASS|LEM:rajaEa|ROOT:rjE|2MP\n',
#  '(2:28:13:2)\twna\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:29:1:1)\thuwa\tPRON\tSTEM|POS:PRON|3MS\n',
#  '(2:29:2:1)\t{l~a*iY\tREL\tSTEM|POS:REL|LEM:{l~a*iY|MS\n',
#  '(2:29:3:1)\txalaqa\tV\tSTEM|POS:V|PERF|LEM:xalaqa|ROOT:xlq|3MS\n',
#  '(2:29:4:1)\tla\tP\tPREFIX|l:P+\n',
#  '(2:29:4:2)\tkum\tPRON\tSTEM|POS:PRON|2MP\n',
#  '(2:29:5:1)\tm~aA\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:29:6:1)\tfiY\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:29:7:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:29:7:2)\t>aroDi\tN\tSTEM|POS:N|LEM:>aroD|ROOT:ArD|F|GEN\n',
#  '(2:29:8:1)\tjamiyEFA\tN\tSTEM|POS:N|LEM:jamiyE|ROOT:jmE|M|INDEF|ACC\n',
#  '(2:29:9:1)\tvum~a\tCONJ\tSTEM|POS:CONJ|LEM:vum~\n',
#  '(2:29:10:1)\t{sotawaY`^\tV\tSTEM|POS:V|PERF|(VIII)|LEM:{sotawaY`^|ROOT:swy|3MS\n',
#  '(2:29:11:1)\t<ilaY\tP\tSTEM|POS:P|LEM:<ilaY`\n',
#  '(2:29:12:1)\t{l\tDET\tPREFIX|Al+\n',
#  "(2:29:12:2)\ts~amaA^'i\tN\tSTEM|POS:N|LEM:samaA^'|ROOT:smw|F|GEN\n",
#  '(2:29:13:1)\tfa\tCONJ\tPREFIX|f:CONJ+\n',
#  '(2:29:13:2)\tsaw~aY`\tV\tSTEM|POS:V|PERF|(II)|LEM:saw~aY`|ROOT:swy|3MS\n',
#  '(2:29:13:3)\thun~a\tPRON\tSUFFIX|PRON:3FP\n',
#  '(2:29:14:1)\tsaboEa\tN\tSTEM|POS:N|LEM:saboE|ROOT:sbE|M|ACC\n',
#  "(2:29:15:1)\tsama`wa`tK\tN\tSTEM|POS:N|LEM:samaA^'|ROOT:smw|FP|INDEF|GEN\n",
#  '(2:29:16:1)\twa\tCIRC\tPREFIX|w:CIRC+\n',
#  '(2:29:16:2)\thuwa\tPRON\tSTEM|POS:PRON|3MS\n',
#  '(2:29:17:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:29:17:2)\tkul~i\tN\tSTEM|POS:N|LEM:kul~|ROOT:kll|M|GEN\n',
#  "(2:29:18:1)\t$aYo'K\tN\tSTEM|POS:N|LEM:$aYo'|ROOT:$yA|M|INDEF|GEN\n",
#  '(2:29:19:1)\tEaliymN\tN\tSTEM|POS:N|LEM:Ealiym|ROOT:Elm|MS|INDEF|NOM\n',
#  '(2:30:1:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:30:1:2)\t<i*o\tT\tSTEM|POS:T|LEM:<i*\n',
#  '(2:30:2:1)\tqaAla\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MS\n',
#  '(2:30:3:1)\trab~u\tN\tSTEM|POS:N|LEM:rab~|ROOT:rbb|M|NOM\n',
#  '(2:30:3:2)\tka\tPRON\tSUFFIX|PRON:2MS\n',
#  '(2:30:4:1)\tli\tP\tPREFIX|l:P+\n',
#  '(2:30:4:2)\tlo\tDET\tPREFIX|Al+\n',
#  '(2:30:4:3)\tmala`^}ikapi\tN\tSTEM|POS:N|LEM:malak|ROOT:mlk|MP|GEN\n',
#  '(2:30:5:1)\t<in~i\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:30:5:2)\tY\tPRON\tSUFFIX|PRON:1S\n',
#  '(2:30:6:1)\tjaAEilN\tN\tSTEM|POS:N|ACT|PCPL|LEM:jaAEil|ROOT:jEl|M|INDEF|NOM\n',
#  '(2:30:7:1)\tfiY\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:30:8:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:30:8:2)\t>aroDi\tN\tSTEM|POS:N|LEM:>aroD|ROOT:ArD|F|GEN\n',
#  '(2:30:9:1)\txaliyfapF\tN\tSTEM|POS:N|LEM:xaliyfap|ROOT:xlf|M|INDEF|ACC\n',
#  '(2:30:10:1)\tqaAlu\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MP\n',
#  '(2:30:10:2)\tw^A@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:30:11:1)\t>a\tINTG\tPREFIX|A:INTG+\n',
#  '(2:30:11:2)\ttajoEalu\tV\tSTEM|POS:V|IMPF|LEM:jaEala|ROOT:jEl|2MS\n',
#  '(2:30:12:1)\tfiy\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:30:12:2)\thaA\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:30:13:1)\tman\tREL\tSTEM|POS:REL|LEM:man\n',
#  '(2:30:14:1)\tyufosidu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:>afosadu|ROOT:fsd|3MS\n',
#  '(2:30:15:1)\tfiy\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:30:15:2)\thaA\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:30:16:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:30:16:2)\tyasofiku\tV\tSTEM|POS:V|IMPF|LEM:yasofiku|ROOT:sfk|3MS\n',
#  '(2:30:17:1)\t{l\tDET\tPREFIX|Al+\n',
#  "(2:30:17:2)\td~imaA^'a\tN\tSTEM|POS:N|LEM:dam|ROOT:dmw|MP|ACC\n",
#  '(2:30:18:1)\twa\tCIRC\tPREFIX|w:CIRC+\n',
#  '(2:30:18:2)\tnaHonu\tPRON\tSTEM|POS:PRON|1P\n',
#  '(2:30:19:1)\tnusab~iHu\tV\tSTEM|POS:V|IMPF|(II)|LEM:sab~aHa|ROOT:sbH|1P\n',
#  '(2:30:20:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:30:20:2)\tHamodi\tN\tSTEM|POS:N|LEM:Hamod|ROOT:Hmd|M|GEN\n',
#  '(2:30:20:3)\tka\tPRON\tSUFFIX|PRON:2MS\n',
#  '(2:30:21:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:30:21:2)\tnuqad~isu\tV\tSTEM|POS:V|IMPF|(II)|LEM:nuqad~isu|ROOT:qds|1P\n',
#  '(2:30:22:1)\tla\tP\tPREFIX|l:P+\n',
#  '(2:30:22:2)\tka\tPRON\tSTEM|POS:PRON|2MS\n',
#  '(2:30:23:1)\tqaAla\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MS\n',
#  '(2:30:24:1)\t<in~i\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:30:24:2)\tY^\tPRON\tSUFFIX|PRON:1S\n',
#  '(2:30:25:1)\t>aEolamu\tV\tSTEM|POS:V|IMPF|LEM:Ealima|ROOT:Elm|1S\n',
#  '(2:30:26:1)\tmaA\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:30:27:1)\tlaA\tNEG\tSTEM|POS:NEG|LEM:laA\n',
#  '(2:30:28:1)\ttaEolamu\tV\tSTEM|POS:V|IMPF|LEM:Ealima|ROOT:Elm|2MP\n',
#  '(2:30:28:2)\twna\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:31:1:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:31:1:2)\tEal~ama\tV\tSTEM|POS:V|PERF|(II)|LEM:Eal~ama|ROOT:Elm|3MS\n',
#  "(2:31:2:1)\t'aAdama\tPN\tSTEM|POS:PN|LEM:A^dam|M|ACC\n",
#  '(2:31:3:1)\t{lo\tDET\tPREFIX|Al+\n',
#  "(2:31:3:2)\t>asomaA^'a\tN\tSTEM|POS:N|LEM:{som|ROOT:smw|MP|ACC\n",
#  '(2:31:4:1)\tkul~a\tN\tSTEM|POS:N|LEM:kul~|ROOT:kll|M|ACC\n',
#  '(2:31:4:2)\thaA\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:31:5:1)\tvum~a\tCONJ\tSTEM|POS:CONJ|LEM:vum~\n',
#  '(2:31:6:1)\tEaraDa\tV\tSTEM|POS:V|PERF|LEM:EaraDa|ROOT:ErD|3MS\n',
#  '(2:31:6:2)\thumo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:31:7:1)\tEalaY\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(2:31:8:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:31:8:2)\tmala`^}ikapi\tN\tSTEM|POS:N|LEM:malak|ROOT:mlk|MP|GEN\n',
#  '(2:31:9:1)\tfa\tCONJ\tPREFIX|f:CONJ+\n',
#  '(2:31:9:2)\tqaAla\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MS\n',
#  '(2:31:10:1)\t>an[bi_#u\tV\tSTEM|POS:V|IMPV|(IV)|LEM:>an[ba>a|ROOT:nbA|2MP\n',
#  '(2:31:10:2)\tw\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:31:10:3)\tniY\tPRON\tSUFFIX|PRON:1S\n',
#  '(2:31:11:1)\tbi\tP\tPREFIX|bi+\n',
#  "(2:31:11:2)\t>asomaA^'i\tN\tSTEM|POS:N|LEM:{som|ROOT:smw|MP|GEN\n",
#  "(2:31:12:1)\tha`^&ulaA^'i\tDEM\tSTEM|POS:DEM|LEM:ha`*aA|P\n",
#  '(2:31:13:1)\t<in\tCOND\tSTEM|POS:COND|LEM:<in\n',
#  '(2:31:14:1)\tkun\tV\tSTEM|POS:V|PERF|LEM:kaAna|ROOT:kwn|SP:kaAn|2MP\n',
#  '(2:31:14:2)\ttumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:31:15:1)\tSa`diqiyna\tN\tSTEM|POS:N|ACT|PCPL|LEM:SaAdiq|ROOT:Sdq|MP|ACC\n',
#  '(2:32:1:1)\tqaAlu\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MP\n',
#  '(2:32:1:2)\twA@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:32:2:1)\tsuboHa`na\tN\tSTEM|POS:N|LEM:suboHa`n|ROOT:sbH|M|ACC\n',
#  '(2:32:2:2)\tka\tPRON\tSUFFIX|PRON:2MS\n',
#  '(2:32:3:1)\tlaA\tNEG\tSTEM|POS:NEG|LEM:laA|SP:<in~\n',
#  '(2:32:4:1)\tEiloma\tN\tSTEM|POS:N|LEM:Eilom|ROOT:Elm|M|ACC\n',
#  '(2:32:5:1)\tla\tP\tPREFIX|l:P+\n',
#  '(2:32:5:2)\tnaA^\tPRON\tSTEM|POS:PRON|1P\n',
#  '(2:32:6:1)\t<il~aA\tEXP\tSTEM|POS:EXP|LEM:<il~aA\n',
#  '(2:32:7:1)\tmaA\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:32:8:1)\tEal~amo\tV\tSTEM|POS:V|PERF|(II)|LEM:Eal~ama|ROOT:Elm|2MS\n',
#  '(2:32:8:2)\tta\tPRON\tSUFFIX|PRON:2MS\n',
#  '(2:32:8:3)\tnaA^\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:32:9:1)\t<in~a\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:32:9:2)\tka\tPRON\tSUFFIX|PRON:2MS\n',
#  '(2:32:10:1)\t>anta\tPRON\tSTEM|POS:PRON|2MS\n',
#  '(2:32:11:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:32:11:2)\tEaliymu\tN\tSTEM|POS:N|LEM:Ealiym|ROOT:Elm|MS|NOM\n',
#  '(2:32:12:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:32:12:2)\tHakiymu\tADJ\tSTEM|POS:ADJ|LEM:Hakiym|ROOT:Hkm|MS|NOM\n',
#  '(2:33:1:1)\tqaAla\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MS\n',
#  '(2:33:2:1)\tya`^\tVOC\tPREFIX|ya+\n',
#  '(2:33:2:2)\t_#aAdamu\tPN\tSTEM|POS:PN|LEM:A^dam|M|NOM\n',
#  '(2:33:3:1)\t>an[bi}o\tV\tSTEM|POS:V|IMPV|(IV)|LEM:>an[ba>a|ROOT:nbA|2MS\n',
#  '(2:33:3:2)\thum\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:33:4:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:33:4:2)\t>asomaA^}i\tN\tSTEM|POS:N|LEM:{som|ROOT:smw|MP|GEN\n',
#  '(2:33:4:3)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:33:5:1)\tfa\tREM\tPREFIX|f:REM+\n',
#  '(2:33:5:2)\tlam~aA^\tT\tSTEM|POS:T|LEM:lam~aA\n',
#  '(2:33:6:1)\t>an[ba>a\tV\tSTEM|POS:V|PERF|(IV)|LEM:>an[ba>a|ROOT:nbA|3MS\n',
#  '(2:33:6:2)\thum\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:33:7:1)\tbi\tP\tPREFIX|bi+\n',
#  '(2:33:7:2)\t>asomaA^}i\tN\tSTEM|POS:N|LEM:{som|ROOT:smw|MP|GEN\n',
#  '(2:33:7:3)\thimo\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:33:8:1)\tqaAla\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|3MS\n',
#  '(2:33:9:1)\t>a\tINTG\tPREFIX|A:INTG+\n',
#  '(2:33:9:2)\tlamo\tNEG\tSTEM|POS:NEG|LEM:lam\n',
#  '(2:33:10:1)\t>aqul\tV\tSTEM|POS:V|IMPF|LEM:qaAla|ROOT:qwl|1S|MOOD:JUS\n',
#  '(2:33:11:1)\tl~a\tP\tPREFIX|l:P+\n',
#  '(2:33:11:2)\tkumo\tPRON\tSTEM|POS:PRON|2MP\n',
#  '(2:33:12:1)\t<in~i\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:33:12:2)\tY^\tPRON\tSUFFIX|PRON:1S\n',
#  '(2:33:13:1)\t>aEolamu\tV\tSTEM|POS:V|IMPF|LEM:Ealima|ROOT:Elm|1S\n',
#  '(2:33:14:1)\tgayoba\tN\tSTEM|POS:N|LEM:gayob|ROOT:gyb|M|ACC\n',
#  '(2:33:15:1)\t{l\tDET\tPREFIX|Al+\n',
#  "(2:33:15:2)\ts~ama`wa`ti\tN\tSTEM|POS:N|LEM:samaA^'|ROOT:smw|FP|GEN\n",
#  '(2:33:16:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:33:16:2)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:33:16:3)\t>aroDi\tN\tSTEM|POS:N|LEM:>aroD|ROOT:ArD|F|GEN\n',
#  '(2:33:17:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:33:17:2)\t>aEolamu\tV\tSTEM|POS:V|IMPF|LEM:Ealima|ROOT:Elm|1S\n',
#  '(2:33:18:1)\tmaA\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:33:19:1)\ttubodu\tV\tSTEM|POS:V|IMPF|(IV)|LEM:yubodiYa|ROOT:bdw|2MP\n',
#  '(2:33:19:2)\twna\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:33:20:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:33:20:2)\tmaA\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:33:21:1)\tkun\tV\tSTEM|POS:V|PERF|LEM:kaAna|ROOT:kwn|SP:kaAn|2MP\n',
#  '(2:33:21:2)\ttumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:33:22:1)\ttakotumu\tV\tSTEM|POS:V|IMPF|LEM:katama|ROOT:ktm|2MP\n',
#  '(2:33:22:2)\twna\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:34:1:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:34:1:2)\t<i*o\tT\tSTEM|POS:T|LEM:<i*\n',
#  '(2:34:2:1)\tqulo\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|1P\n',
#  '(2:34:2:2)\tnaA\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:34:3:1)\tli\tP\tPREFIX|l:P+\n',
#  '(2:34:3:2)\tlo\tDET\tPREFIX|Al+\n',
#  '(2:34:3:3)\tmala`^}ikapi\tN\tSTEM|POS:N|LEM:malak|ROOT:mlk|MP|GEN\n',
#  '(2:34:4:1)\t{sojudu\tV\tSTEM|POS:V|IMPV|LEM:sajada|ROOT:sjd|2MP\n',
#  '(2:34:4:2)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:34:5:1)\tli\tP\tPREFIX|l:P+\n',
#  "(2:34:5:2)\t'aAdama\tPN\tSTEM|POS:PN|LEM:A^dam|M|GEN\n",
#  '(2:34:6:1)\tfa\tRSLT\tPREFIX|f:RSLT+\n',
#  '(2:34:6:2)\tsajadu\tV\tSTEM|POS:V|PERF|LEM:sajada|ROOT:sjd|3MP\n',
#  '(2:34:6:3)\tw^A@\tPRON\tSUFFIX|PRON:3MP\n',
#  '(2:34:7:1)\t<il~aA^\tEXP\tSTEM|POS:EXP|LEM:<il~aA\n',
#  '(2:34:8:1)\t<iboliysa\tPN\tSTEM|POS:PN|LEM:<iboliys|M|ACC\n',
#  '(2:34:9:1)\t>abaY`\tV\tSTEM|POS:V|PERF|LEM:>abaY|ROOT:Aby|3MS\n',
#  '(2:34:10:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:34:10:2)\t{sotakobara\tV\tSTEM|POS:V|PERF|(X)|LEM:{sotakobara|ROOT:kbr|3MS\n',
#  '(2:34:11:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:34:11:2)\tkaAna\tV\tSTEM|POS:V|PERF|LEM:kaAna|ROOT:kwn|SP:kaAn|3MS\n',
#  '(2:34:12:1)\tmina\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:34:13:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:34:13:2)\tka`firiyna\tN\tSTEM|POS:N|ACT|PCPL|LEM:ka`firuwn|ROOT:kfr|MP|GEN\n',
#  '(2:35:1:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:35:1:2)\tqulo\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|1P\n',
#  '(2:35:1:3)\tnaA\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:35:2:1)\tya`^\tVOC\tPREFIX|ya+\n',
#  '(2:35:2:2)\t_#aAdamu\tPN\tSTEM|POS:PN|LEM:A^dam|M|NOM\n',
#  '(2:35:3:1)\t{sokuno\tV\tSTEM|POS:V|IMPV|LEM:sakana|ROOT:skn|2MS\n',
#  '(2:35:4:1)\t>anta\tPRON\tSTEM|POS:PRON|2MS\n',
#  '(2:35:5:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:35:5:2)\tzawoju\tN\tSTEM|POS:N|LEM:zawoj|ROOT:zwj|M|NOM\n',
#  '(2:35:5:3)\tka\tPRON\tSUFFIX|PRON:2MS\n',
#  '(2:35:6:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:35:6:2)\tjan~apa\tPN\tSTEM|POS:PN|LEM:jan~ap|ROOT:jnn|F|ACC\n',
#  '(2:35:7:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:35:7:2)\tkula\tV\tSTEM|POS:V|IMPV|LEM:>akala|ROOT:Akl|2D\n',
#  '(2:35:7:3)\tA\tPRON\tSUFFIX|PRON:2D\n',
#  '(2:35:8:1)\tmino\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:35:8:2)\thaA\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:35:9:1)\tragadFA\tADJ\tSTEM|POS:ADJ|LEM:ragad|ROOT:rgd|M|INDEF|ACC\n',
#  '(2:35:10:1)\tHayovu\tLOC\tSTEM|POS:LOC|LEM:Hayov|ROOT:Hyv\n',
#  "(2:35:11:1)\t$i}o\tV\tSTEM|POS:V|PERF|LEM:$aA^'a|ROOT:$yA|2D\n",
#  '(2:35:11:2)\ttumaA\tPRON\tSUFFIX|PRON:2D\n',
#  '(2:35:12:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:35:12:2)\tlaA\tPRO\tSTEM|POS:PRO|LEM:laA\n',
#  '(2:35:13:1)\ttaqoraba\tV\tSTEM|POS:V|IMPF|LEM:yaqorabu|ROOT:qrb|2D|MOOD:JUS\n',
#  '(2:35:13:2)\tA\tPRON\tSUFFIX|PRON:2D\n',
#  '(2:35:14:1)\tha`*ihi\tDEM\tSTEM|POS:DEM|LEM:ha`*aA|FS\n',
#  '(2:35:15:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:35:15:2)\t$~ajarapa\tN\tSTEM|POS:N|LEM:$ajarap|ROOT:$jr|F|ACC\n',
#  '(2:35:16:1)\tfa\tCAUS\tPREFIX|f:CAUS+\n',
#  '(2:35:16:2)\ttakuwna\tV\tSTEM|POS:V|IMPF|LEM:kaAna|ROOT:kwn|SP:kaAn|2D|MOOD:SUBJ\n',
#  '(2:35:16:3)\tA\tPRON\tSUFFIX|PRON:2D\n',
#  '(2:35:17:1)\tmina\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:35:18:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:35:18:2)\tZ~a`limiyna\tN\tSTEM|POS:N|ACT|PCPL|LEM:ZaAlim|ROOT:Zlm|MP|GEN\n',
#  '(2:36:1:1)\tfa\tREM\tPREFIX|f:REM+\n',
#  '(2:36:1:2)\t>azal~a\tV\tSTEM|POS:V|PERF|(IV)|LEM:>azal~a|ROOT:zll|3MS\n',
#  '(2:36:1:3)\thumaA\tPRON\tSUFFIX|PRON:3D\n',
#  '(2:36:2:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:36:2:2)\t$~ayoTa`nu\tPN\tSTEM|POS:PN|LEM:$ayoTa`n|ROOT:$Tn|M|NOM\n',
#  '(2:36:3:1)\tEano\tP\tSTEM|POS:P|LEM:Ean\n',
#  '(2:36:3:2)\thaA\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:36:4:1)\tfa\tCONJ\tPREFIX|f:CONJ+\n',
#  '(2:36:4:2)\t>axoraja\tV\tSTEM|POS:V|PERF|(IV)|LEM:>axoraja|ROOT:xrj|3MS\n',
#  '(2:36:4:3)\thumaA\tPRON\tSUFFIX|PRON:3D\n',
#  '(2:36:5:1)\tmi\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:36:5:2)\tm~aA\tREL\tSTEM|POS:REL|LEM:maA\n',
#  '(2:36:6:1)\tkaAna\tV\tSTEM|POS:V|PERF|LEM:kaAna|ROOT:kwn|SP:kaAn|3MD\n',
#  '(2:36:6:2)\tA\tPRON\tSUFFIX|PRON:3MD\n',
#  '(2:36:7:1)\tfiy\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:36:7:2)\thi\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:36:8:1)\twa\tREM\tPREFIX|w:REM+\n',
#  '(2:36:8:2)\tqulo\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|1P\n',
#  '(2:36:8:3)\tnaA\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:36:9:1)\t{hobiTu\tV\tSTEM|POS:V|IMPV|LEM:yahobiTu|ROOT:hbT|2MP\n',
#  '(2:36:9:2)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:36:10:1)\tbaEoDu\tN\tSTEM|POS:N|LEM:baEoD|ROOT:bED|M|NOM\n',
#  '(2:36:10:2)\tkumo\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:36:11:1)\tli\tP\tPREFIX|l:P+\n',
#  '(2:36:11:2)\tbaEoDK\tN\tSTEM|POS:N|LEM:baEoD|ROOT:bED|M|INDEF|GEN\n',
#  '(2:36:12:1)\tEaduw~N\tN\tSTEM|POS:N|LEM:Eaduw~|ROOT:Edw|M|INDEF|NOM\n',
#  '(2:36:13:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:36:13:2)\tla\tP\tPREFIX|l:P+\n',
#  '(2:36:13:3)\tkumo\tPRON\tSTEM|POS:PRON|2MP\n',
#  '(2:36:14:1)\tfiY\tP\tSTEM|POS:P|LEM:fiY\n',
#  '(2:36:15:1)\t{lo\tDET\tPREFIX|Al+\n',
#  '(2:36:15:2)\t>aroDi\tN\tSTEM|POS:N|LEM:>aroD|ROOT:ArD|F|GEN\n',
#  '(2:36:16:1)\tmusotaqar~N\tN\tSTEM|POS:N|PASS|PCPL|(X)|LEM:musotaqar~|ROOT:qrr|M|INDEF|NOM\n',
#  '(2:36:17:1)\twa\tCONJ\tPREFIX|w:CONJ+\n',
#  '(2:36:17:2)\tmata`EN\tN\tSTEM|POS:N|LEM:mata`E|ROOT:mtE|M|INDEF|NOM\n',
#  '(2:36:18:1)\t<ilaY`\tP\tSTEM|POS:P|LEM:<ilaY`\n',
#  '(2:36:19:1)\tHiynK\tN\tSTEM|POS:N|LEM:Hiyn|ROOT:Hyn|M|INDEF|GEN\n',
#  '(2:37:1:1)\tfa\tREM\tPREFIX|f:REM+\n',
#  '(2:37:1:2)\ttalaq~aY`^\tV\tSTEM|POS:V|PERF|(V)|LEM:talaq~aY`^|ROOT:lqy|3MS\n',
#  "(2:37:2:1)\t'aAdamu\tPN\tSTEM|POS:PN|LEM:A^dam|M|NOM\n",
#  '(2:37:3:1)\tmin\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:37:4:1)\tr~ab~i\tN\tSTEM|POS:N|LEM:rab~|ROOT:rbb|M|GEN\n',
#  '(2:37:4:2)\thi.\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:37:5:1)\tkalima`tK\tN\tSTEM|POS:N|LEM:kalima`t|ROOT:klm|FP|INDEF|ACC\n',
#  '(2:37:6:1)\tfa\tCONJ\tPREFIX|f:CONJ+\n',
#  '(2:37:6:2)\ttaAba\tV\tSTEM|POS:V|PERF|LEM:taAba|ROOT:twb|3MS\n',
#  '(2:37:7:1)\tEalayo\tP\tSTEM|POS:P|LEM:EalaY`\n',
#  '(2:37:7:2)\thi\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:37:8:1)\t<in~a\tACC\tSTEM|POS:ACC|LEM:<in~|SP:<in~\n',
#  '(2:37:8:2)\thu,\tPRON\tSUFFIX|PRON:3MS\n',
#  '(2:37:9:1)\thuwa\tPRON\tSTEM|POS:PRON|3MS\n',
#  '(2:37:10:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:37:10:2)\tt~aw~aAbu\tN\tSTEM|POS:N|ACT|PCPL|LEM:taw~aAb|ROOT:twb|MS|NOM\n',
#  '(2:37:11:1)\t{l\tDET\tPREFIX|Al+\n',
#  '(2:37:11:2)\tr~aHiymu\tADJ\tSTEM|POS:ADJ|LEM:r~aHiym|ROOT:rHm|MS|NOM\n',
#  '(2:38:1:1)\tqulo\tV\tSTEM|POS:V|PERF|LEM:qaAla|ROOT:qwl|1P\n',
#  '(2:38:1:2)\tnaA\tPRON\tSUFFIX|PRON:1P\n',
#  '(2:38:2:1)\t{hobiTu\tV\tSTEM|POS:V|IMPV|LEM:yahobiTu|ROOT:hbT|2MP\n',
#  '(2:38:2:2)\twA@\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:38:3:1)\tmino\tP\tSTEM|POS:P|LEM:min\n',
#  '(2:38:3:2)\thaA\tPRON\tSUFFIX|PRON:3FS\n',
#  '(2:38:4:1)\tjamiyEFA\tN\tSTEM|POS:N|LEM:jamiyE|ROOT:jmE|M|INDEF|ACC\n',
#  '(2:38:5:1)\tfa\tREM\tPREFIX|f:REM+\n',
#  '(2:38:5:2)\t<im~aA\tCOND\tSTEM|POS:COND|LEM:<im~aA\n',
#  '(2:38:6:1)\tya>otiya\tV\tSTEM|POS:V|IMPF|LEM:>ataY|ROOT:Aty|3MS\n',
#  '(2:38:6:2)\tn~a\tEMPH\tSUFFIX|+n:EMPH\n',
#  '(2:38:6:3)\tkum\tPRON\tSUFFIX|PRON:2MP\n',
#  '(2:38:7:1)\tm~in~i\tP\tSTEM|POS:P|LEM:min\n',
#  ...]

# %%
df_morp_all = pd.DataFrame(text_line)
df_morp_all
# Out:
#                                                         0
# 0                         LOCATION\tFORM\tTAG\tFEATURES\n
# 1                          (1:1:1:1)\tbi\tP\tPREFIX|bi+\n
# 2       (1:1:1:2)\tsomi\tN\tSTEM|POS:N|LEM:{som|ROOT:s...
# 3       (1:1:2:1)\t{ll~ahi\tPN\tSTEM|POS:PN|LEM:{ll~ah...
# 4                        (1:1:3:1)\t{l\tDET\tPREFIX|Al+\n
# ...                                                   ...
# 128215                (114:6:2:1)\t{lo\tDET\tPREFIX|Al+\n
# 128216  (114:6:2:2)\tjin~api\tN\tSTEM|POS:N|LEM:jin~ap...
# 128217            (114:6:3:1)\twa\tCONJ\tPREFIX|w:CONJ+\n
# 128218                 (114:6:3:2)\t{l\tDET\tPREFIX|Al+\n
# 128219  (114:6:3:3)\tn~aAsi\tN\tSTEM|POS:N|LEM:n~aAs|R...
#
# [128220 rows x 1 columns]

# %%
df_morp_all = df_morp_all[0].str.split("\t", n=-1, expand=True)
df_morp_all
# Out:
#                   0        1     2                                       3
# 0          LOCATION     FORM   TAG                              FEATURES\n
# 1         (1:1:1:1)       bi     P                            PREFIX|bi+\n
# 2         (1:1:1:2)     somi     N    STEM|POS:N|LEM:{som|ROOT:smw|M|GEN\n
# 3         (1:1:2:1)  {ll~ahi    PN   STEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN\n
# 4         (1:1:3:1)       {l   DET                            PREFIX|Al+\n
# ...             ...      ...   ...                                     ...
# 128215  (114:6:2:1)      {lo   DET                            PREFIX|Al+\n
# 128216  (114:6:2:2)  jin~api     N  STEM|POS:N|LEM:jin~ap|ROOT:jnn|F|GEN\n
# 128217  (114:6:3:1)       wa  CONJ                        PREFIX|w:CONJ+\n
# 128218  (114:6:3:2)       {l   DET                            PREFIX|Al+\n
# 128219  (114:6:3:3)   n~aAsi     N  STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN\n
#
# [128220 rows x 4 columns]

# %%
df_morp_all[3] = df_morp_all[3].apply(lambda x: x.strip("\n"))
df_morp_all
# Out:
#                   0        1     2                                     3
# 0          LOCATION     FORM   TAG                              FEATURES
# 1         (1:1:1:1)       bi     P                            PREFIX|bi+
# 2         (1:1:1:2)     somi     N    STEM|POS:N|LEM:{som|ROOT:smw|M|GEN
# 3         (1:1:2:1)  {ll~ahi    PN   STEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN
# 4         (1:1:3:1)       {l   DET                            PREFIX|Al+
# ...             ...      ...   ...                                   ...
# 128215  (114:6:2:1)      {lo   DET                            PREFIX|Al+
# 128216  (114:6:2:2)  jin~api     N  STEM|POS:N|LEM:jin~ap|ROOT:jnn|F|GEN
# 128217  (114:6:3:1)       wa  CONJ                        PREFIX|w:CONJ+
# 128218  (114:6:3:2)       {l   DET                            PREFIX|Al+
# 128219  (114:6:3:3)   n~aAsi     N  STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN
#
# [128220 rows x 4 columns]

# %%
df_morp_all.columns = df_morp_all.iloc[0]
df_morp_all.drop(df_morp_all.index[0], inplace=True)
df_morp_all.iloc[:,0] = df_morp_all.iloc[:,0].apply(lambda x: x.strip("()"))
df_morp_all
# Out:
# 0        LOCATION        FORM   TAG  \
# 1         1:1:1:1          bi     P
# 2         1:1:1:2        somi     N
# 3         1:1:2:1     {ll~ahi    PN
# 4         1:1:3:1          {l   DET
# 5         1:1:3:2  r~aHoma`ni   ADJ
# ...           ...         ...   ...
# 128215  114:6:2:1         {lo   DET
# 128216  114:6:2:2     jin~api     N
# 128217  114:6:3:1          wa  CONJ
# 128218  114:6:3:2          {l   DET
# 128219  114:6:3:3      n~aAsi     N
#
# 0                                         FEATURES
# 1                                       PREFIX|bi+
# 2               STEM|POS:N|LEM:{som|ROOT:smw|M|GEN
# 3              STEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN
# 4                                       PREFIX|Al+
# 5       STEM|POS:ADJ|LEM:r~aHoma`n|ROOT:rHm|MS|GEN
# ...                                            ...
# 128215                                  PREFIX|Al+
# 128216        STEM|POS:N|LEM:jin~ap|ROOT:jnn|F|GEN
# 128217                              PREFIX|w:CONJ+
# 128218                                  PREFIX|Al+
# 128219        STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN
#
# [128219 rows x 4 columns]

# %%
df_morp_root = df_morp_all[df_morp_all.FEATURES.str.contains("ROOT")]
df_morp_root
# Out:
# 0        LOCATION        FORM  TAG                                    FEATURES
# 2         1:1:1:2        somi    N          STEM|POS:N|LEM:{som|ROOT:smw|M|GEN
# 3         1:1:2:1     {ll~ahi   PN         STEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN
# 5         1:1:3:2  r~aHoma`ni  ADJ  STEM|POS:ADJ|LEM:r~aHoma`n|ROOT:rHm|MS|GEN
# 7         1:1:4:2    r~aHiymi  ADJ    STEM|POS:ADJ|LEM:r~aHiym|ROOT:rHm|MS|GEN
# 9         1:2:1:2      Hamodu    N         STEM|POS:N|LEM:Hamod|ROOT:Hmd|M|NOM
# ...           ...         ...  ...                                         ...
# 128209  114:5:2:1  yuwasowisu    V  STEM|POS:V|IMPF|LEM:wasowasa|ROOT:wsws|3MS
# 128211  114:5:4:1     Suduwri    N        STEM|POS:N|LEM:Sador|ROOT:Sdr|MP|GEN
# 128213  114:5:5:2      n~aAsi    N        STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN
# 128216  114:6:2:2     jin~api    N        STEM|POS:N|LEM:jin~ap|ROOT:jnn|F|GEN
# 128219  114:6:3:3      n~aAsi    N        STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN
#
# [49968 rows x 4 columns]

# %%
df_morp_root.iloc[:,3] = df_morp_root.iloc[:,3].apply(lambda x: x+"|")
df_morp_root
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# 0        LOCATION        FORM  TAG  \
# 2         1:1:1:2        somi    N
# 3         1:1:2:1     {ll~ahi   PN
# 5         1:1:3:2  r~aHoma`ni  ADJ
# 7         1:1:4:2    r~aHiymi  ADJ
# 9         1:2:1:2      Hamodu    N
# ...           ...         ...  ...
# 128209  114:5:2:1  yuwasowisu    V
# 128211  114:5:4:1     Suduwri    N
# 128213  114:5:5:2      n~aAsi    N
# 128216  114:6:2:2     jin~api    N
# 128219  114:6:3:3      n~aAsi    N
#
# 0                                          FEATURES
# 2               STEM|POS:N|LEM:{som|ROOT:smw|M|GEN|
# 3              STEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN|
# 5       STEM|POS:ADJ|LEM:r~aHoma`n|ROOT:rHm|MS|GEN|
# 7         STEM|POS:ADJ|LEM:r~aHiym|ROOT:rHm|MS|GEN|
# 9              STEM|POS:N|LEM:Hamod|ROOT:Hmd|M|NOM|
# ...                                             ...
# 128209  STEM|POS:V|IMPF|LEM:wasowasa|ROOT:wsws|3MS|
# 128211        STEM|POS:N|LEM:Sador|ROOT:Sdr|MP|GEN|
# 128213        STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN|
# 128216        STEM|POS:N|LEM:jin~ap|ROOT:jnn|F|GEN|
# 128219        STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN|
#
# [49968 rows x 4 columns]

# %%
df_morp_root["ROOT"] = df_morp_root.FEATURES.apply(lambda x: re.findall(r"\|ROOT:(.*?)\|", x))
df_morp_root
# Out:
# <ipython-input-12-77e664f7fe7c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_morp_root["ROOT"] = df_morp_root.FEATURES.apply(lambda x: re.findall(r"\|ROOT:(.*?)\|", x))
# 0        LOCATION        FORM  TAG  \
# 2         1:1:1:2        somi    N
# 3         1:1:2:1     {ll~ahi   PN
# 5         1:1:3:2  r~aHoma`ni  ADJ
# 7         1:1:4:2    r~aHiymi  ADJ
# 9         1:2:1:2      Hamodu    N
# ...           ...         ...  ...
# 128209  114:5:2:1  yuwasowisu    V
# 128211  114:5:4:1     Suduwri    N
# 128213  114:5:5:2      n~aAsi    N
# 128216  114:6:2:2     jin~api    N
# 128219  114:6:3:3      n~aAsi    N
#
# 0                                          FEATURES    ROOT
# 2               STEM|POS:N|LEM:{som|ROOT:smw|M|GEN|   [smw]
# 3              STEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN|   [Alh]
# 5       STEM|POS:ADJ|LEM:r~aHoma`n|ROOT:rHm|MS|GEN|   [rHm]
# 7         STEM|POS:ADJ|LEM:r~aHiym|ROOT:rHm|MS|GEN|   [rHm]
# 9              STEM|POS:N|LEM:Hamod|ROOT:Hmd|M|NOM|   [Hmd]
# ...                                             ...     ...
# 128209  STEM|POS:V|IMPF|LEM:wasowasa|ROOT:wsws|3MS|  [wsws]
# 128211        STEM|POS:N|LEM:Sador|ROOT:Sdr|MP|GEN|   [Sdr]
# 128213        STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN|   [nws]
# 128216        STEM|POS:N|LEM:jin~ap|ROOT:jnn|F|GEN|   [jnn]
# 128219        STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN|   [nws]
#
# [49968 rows x 5 columns]

# %%
df_morp_root.loc[:,"ROOT"] = df_morp_root.loc[:,"ROOT"].apply(lambda x: "".join(x))
df_morp_root
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 0        LOCATION        FORM  TAG  \
# 2         1:1:1:2        somi    N
# 3         1:1:2:1     {ll~ahi   PN
# 5         1:1:3:2  r~aHoma`ni  ADJ
# 7         1:1:4:2    r~aHiymi  ADJ
# 9         1:2:1:2      Hamodu    N
# ...           ...         ...  ...
# 128209  114:5:2:1  yuwasowisu    V
# 128211  114:5:4:1     Suduwri    N
# 128213  114:5:5:2      n~aAsi    N
# 128216  114:6:2:2     jin~api    N
# 128219  114:6:3:3      n~aAsi    N
#
# 0                                          FEATURES  ROOT
# 2               STEM|POS:N|LEM:{som|ROOT:smw|M|GEN|   smw
# 3              STEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN|   Alh
# 5       STEM|POS:ADJ|LEM:r~aHoma`n|ROOT:rHm|MS|GEN|   rHm
# 7         STEM|POS:ADJ|LEM:r~aHiym|ROOT:rHm|MS|GEN|   rHm
# 9              STEM|POS:N|LEM:Hamod|ROOT:Hmd|M|NOM|   Hmd
# ...                                             ...   ...
# 128209  STEM|POS:V|IMPF|LEM:wasowasa|ROOT:wsws|3MS|  wsws
# 128211        STEM|POS:N|LEM:Sador|ROOT:Sdr|MP|GEN|   Sdr
# 128213        STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN|   nws
# 128216        STEM|POS:N|LEM:jin~ap|ROOT:jnn|F|GEN|   jnn
# 128219        STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN|   nws
#
# [49968 rows x 5 columns]

# %%
df_morp_root.columns = map(str.lower,df_morp_root.columns) # OR df_morp_root.columns = [x.lower() for x in df_morp_root.columns]

# %%
df_morp_root["root_arabic"] = df_morp_root.iloc[:,4].apply(lambda x: transString(x, 1))
df_morp_root
# Out:
# <ipython-input-15-5308fbe5846e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_morp_root["root_arabic"] = df_morp_root.iloc[:,4].apply(lambda x: transString(x, 1))
#          location        form  tag  \
# 2         1:1:1:2        somi    N
# 3         1:1:2:1     {ll~ahi   PN
# 5         1:1:3:2  r~aHoma`ni  ADJ
# 7         1:1:4:2    r~aHiymi  ADJ
# 9         1:2:1:2      Hamodu    N
# ...           ...         ...  ...
# 128209  114:5:2:1  yuwasowisu    V
# 128211  114:5:4:1     Suduwri    N
# 128213  114:5:5:2      n~aAsi    N
# 128216  114:6:2:2     jin~api    N
# 128219  114:6:3:3      n~aAsi    N
#
#                                            features  root root_arabic
# 2               STEM|POS:N|LEM:{som|ROOT:smw|M|GEN|   smw         سمو
# 3              STEM|POS:PN|LEM:{ll~ah|ROOT:Alh|GEN|   Alh         اله
# 5       STEM|POS:ADJ|LEM:r~aHoma`n|ROOT:rHm|MS|GEN|   rHm         رحم
# 7         STEM|POS:ADJ|LEM:r~aHiym|ROOT:rHm|MS|GEN|   rHm         رحم
# 9              STEM|POS:N|LEM:Hamod|ROOT:Hmd|M|NOM|   Hmd         حمد
# ...                                             ...   ...         ...
# 128209  STEM|POS:V|IMPF|LEM:wasowasa|ROOT:wsws|3MS|  wsws        وسوس
# 128211        STEM|POS:N|LEM:Sador|ROOT:Sdr|MP|GEN|   Sdr         صدر
# 128213        STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN|   nws         نوس
# 128216        STEM|POS:N|LEM:jin~ap|ROOT:jnn|F|GEN|   jnn         جنن
# 128219        STEM|POS:N|LEM:n~aAs|ROOT:nws|MP|GEN|   nws         نوس
#
# [49968 rows x 6 columns]

# %%
df_morp_root_nav = df_morp_root.iloc[:,0].str.split(":", n=-1, expand=True)
df_morp_root_nav.rename(columns={0:"num_1",1:"num_2",2:"num_3",3:"num_4"}, inplace=True)
df_morp_root_nav
# Out:
#        num_1 num_2 num_3 num_4
# 2          1     1     1     2
# 3          1     1     2     1
# 5          1     1     3     2
# 7          1     1     4     2
# 9          1     2     1     2
# ...      ...   ...   ...   ...
# 128209   114     5     2     1
# 128211   114     5     4     1
# 128213   114     5     5     2
# 128216   114     6     2     2
# 128219   114     6     3     3
#
# [49968 rows x 4 columns]

# %%
df_morp_root_nav[["form","tag","root","root_arabic"]] = df_morp_root.iloc[:,[1,2,4,5]]
df_morp_root_nav
# Out:
#        num_1 num_2 num_3 num_4        form  tag  root root_arabic
# 2          1     1     1     2        somi    N   smw         سمو
# 3          1     1     2     1     {ll~ahi   PN   Alh         اله
# 5          1     1     3     2  r~aHoma`ni  ADJ   rHm         رحم
# 7          1     1     4     2    r~aHiymi  ADJ   rHm         رحم
# 9          1     2     1     2      Hamodu    N   Hmd         حمد
# ...      ...   ...   ...   ...         ...  ...   ...         ...
# 128209   114     5     2     1  yuwasowisu    V  wsws        وسوس
# 128211   114     5     4     1     Suduwri    N   Sdr         صدر
# 128213   114     5     5     2      n~aAsi    N   nws         نوس
# 128216   114     6     2     2     jin~api    N   jnn         جنن
# 128219   114     6     3     3      n~aAsi    N   nws         نوس
#
# [49968 rows x 8 columns]

# %%
df_morp_root_nav.to_excel("Arabic_Buckwalter_Form_Root_Morphology.xlsx", sheet_name="Arabic_Buckwalter_Form_Root", index=False)

# %%
df_morp_root_nav["nav"] = df_morp_root_nav["num_1"].astype("str")+":"+df_morp_root_nav["num_2"].astype("str")+":"+df_morp_root_nav["num_3"].astype("str")
df_morp_root_nav
# Out:
#        num_1 num_2 num_3 num_4        form  tag  root root_arabic      nav
# 2          1     1     1     2        somi    N   smw         سمو    1:1:1
# 3          1     1     2     1     {ll~ahi   PN   Alh         اله    1:1:2
# 5          1     1     3     2  r~aHoma`ni  ADJ   rHm         رحم    1:1:3
# 7          1     1     4     2    r~aHiymi  ADJ   rHm         رحم    1:1:4
# 9          1     2     1     2      Hamodu    N   Hmd         حمد    1:2:1
# ...      ...   ...   ...   ...         ...  ...   ...         ...      ...
# 128209   114     5     2     1  yuwasowisu    V  wsws        وسوس  114:5:2
# 128211   114     5     4     1     Suduwri    N   Sdr         صدر  114:5:4
# 128213   114     5     5     2      n~aAsi    N   nws         نوس  114:5:5
# 128216   114     6     2     2     jin~api    N   jnn         جنن  114:6:2
# 128219   114     6     3     3      n~aAsi    N   nws         نوس  114:6:3
#
# [49968 rows x 9 columns]

# %%
df_morp_root_nav = df_morp_root_nav.iloc[:,[4,5,6,7,8]]
df_morp_root_nav
# Out:
#               form  tag  root root_arabic      nav
# 2             somi    N   smw         سمو    1:1:1
# 3          {ll~ahi   PN   Alh         اله    1:1:2
# 5       r~aHoma`ni  ADJ   rHm         رحم    1:1:3
# 7         r~aHiymi  ADJ   rHm         رحم    1:1:4
# 9           Hamodu    N   Hmd         حمد    1:2:1
# ...            ...  ...   ...         ...      ...
# 128209  yuwasowisu    V  wsws        وسوس  114:5:2
# 128211     Suduwri    N   Sdr         صدر  114:5:4
# 128213      n~aAsi    N   nws         نوس  114:5:5
# 128216     jin~api    N   jnn         جنن  114:6:2
# 128219      n~aAsi    N   nws         نوس  114:6:3
#
# [49968 rows x 5 columns]

# %%
df_morp_root_nav.to_excel("Arabic_Buckwalter_Form_Root_Navigation_Morphology.xlsx", sheet_name="Arabic_Buckwalter_Form_Root_Nav", index=False)

# %%
df_morp_root_count = pd.DataFrame(df_morp_root_nav.root.value_counts(ascending=False))
df_morp_root_count.reset_index(inplace=True)
df_morp_root_count.rename(columns={"index":"root","root":"frequency"}, inplace=True)
df_morp_root_count
# Out:
#      root  frequency
# 0     Alh       2851
# 1     qwl       1722
# 2     kwn       1390
# 3     rbb        980
# 4     Amn        879
# ...   ...        ...
# 1637  h$$          1
# 1638  nEl          1
# 1639  xlE          1
# 1640  vry          1
# 1641  nfv          1
#
# [1642 rows x 2 columns]

# %%
df_morp_root_count["root_arabic"] = df_morp_root_count["root"].apply(lambda x: transString(x, 1))
df_morp_root_count = df_morp_root_count.iloc[:,[0,2,1]]
df_morp_root_count
# Out:
#      root root_arabic  frequency
# 0     Alh         اله       2851
# 1     qwl         قول       1722
# 2     kwn         كون       1390
# 3     rbb         ربب        980
# 4     Amn         امن        879
# ...   ...         ...        ...
# 1637  h$$         هشش          1
# 1638  nEl         نعل          1
# 1639  xlE         خلع          1
# 1640  vry         ثري          1
# 1641  nfv         نفث          1
#
# [1642 rows x 3 columns]

# %%
df_morp_root_count.to_excel("Arabic_Buckwalter_Root_Freq_Morphology.xlsx", sheet_name="Arabic_Buckwalter_Root_Freq", index=False)

# %%
df_morp_root_count_200 = df_morp_root_count.head(200)
df_morp_root_count_200
# Out:
#     root root_arabic  frequency
# 0    Alh         اله       2851
# 1    qwl         قول       1722
# 2    kwn         كون       1390
# 3    rbb         ربب        980
# 4    Amn         امن        879
# ..   ...         ...        ...
# 195  ndw         ندو         53
# 196  xbr         خبر         52
# 197  DEf         ضعف         52
# 198  Hll         حلل         51
# 199  tHt         تحت         51
#
# [200 rows x 3 columns]

# %%
df_morp_root_count_200.to_excel("Arabic_Buckwalter_200_Root_Freq_Morphology.xlsx", sheet_name="Arabic_Buckwalter_Root_Freq", index=False)

# %%
df_morp_root_nav_freq = pd.merge(df_morp_root_nav,df_morp_root_count,how="inner",on="root")
df_morp_root_nav_freq
# Out:
#                form tag root root_arabic_x      nav root_arabic_y  frequency
# 0              somi   N  smw           سمو    1:1:1           سمو        381
# 1         s~amaA^'i   N  smw           سمو   2:19:4           سمو        381
# 2         s~amaA^'a   N  smw           سمو   2:22:6           سمو        381
# 3         s~amaA^'i   N  smw           سمو  2:22:10           سمو        381
# 4         s~amaA^'i   N  smw           سمو  2:29:12           سمو        381
# ...             ...  ..  ...           ...      ...           ...        ...
# 49963      m~asadK]   N  msd           مسد  111:5:5           مسد          1
# 49964       S~amadu   N  Smd           صمد  112:2:2           صمد          1
# 49965       kufuwFA   N  kfA           كفا  112:4:4           كفا          1
# 49966        waqaba   V  wqb           وقب  113:3:5           وقب          1
# 49967  n~af~a`va`ti   N  nfv           نفث  113:4:3           نفث          1
#
# [49968 rows x 7 columns]

# %%
df_morp_root_freq_nav_all = df_morp_root_nav_freq.groupby(["root","root_arabic_x","frequency"])["nav"].apply(", ".join).reset_index().sort_values(by="frequency", ascending=False)
df_morp_root_freq_nav_all.rename(columns={"root_arabic_x":"root_arabic"}, inplace=True)
df_morp_root_freq_nav_all.reset_index(drop=True, inplace=True)
df_morp_root_freq_nav_all
# Out:
#       root root_arabic  frequency  \
# 0      Alh         اله       2851
# 1      qwl         قول       1722
# 2      kwn         كون       1390
# 3      rbb         ربب        980
# 4      Amn         امن        879
# ...    ...         ...        ...
# 1637  HSHS        حصحص          1
# 1638   kft         كفت          1
# 1639   rmd         رمد          1
# 1640   rmH         رمح          1
# 1641   jws         جوس          1
#
#                                                     nav
# 0     1:1:2, 1:2:2, 2:7:2, 2:8:6, 2:9:2, 2:10:5, 2:1...
# 1     2:8:4, 2:11:2, 2:11:8, 2:13:2, 2:13:8, 2:14:5,...
# 2     2:10:11, 2:16:10, 2:23:2, 2:23:19, 2:28:4, 2:3...
# 3     1:2:3, 2:5:5, 2:21:4, 2:26:19, 2:30:3, 2:37:4,...
# 4     2:3:2, 2:4:2, 2:6:11, 2:8:5, 2:8:11, 2:9:4, 2:...
# ...                                                 ...
# 1637                                           12:51:21
# 1638                                            77:25:4
# 1639                                            14:18:6
# 1640                                            5:94:11
# 1641                                            17:5:12
#
# [1642 rows x 4 columns]

# %%
df_morp_root_freq_nav_all.to_excel("Arabic_Buckwalter_Root_Freq_And_Nav_Morphology.xlsx", sheet_name="Arabic_Buckwalter_Root_Freq_Nav", index=False)
