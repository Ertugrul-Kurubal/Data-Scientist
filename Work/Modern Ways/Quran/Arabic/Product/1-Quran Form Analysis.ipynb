# %% [markdown]
# ### Quran Form Analysis

# %%
#!pip install lang-trans

# %%
import pandas as pd
import numpy as np
import re
from camel_tools.utils.charmap import CharMapper
from lang_trans.arabic import buckwalter

# %%
with open("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quran/Data/Quranic Corpus Morphology.txt", "r", encoding="utf8") as file:
    text = file.read()

# %% [markdown]
# #### Form Tag

# %%
form_tag_list = re.findall("[\(\d*:\d*:\d*:\d*\)][\t](\D*)[\t][\D*]", text)

# %%
form_tag_num = re.findall("(\d*:\d*:\d*:\d*)", text)

# %%
df_stem = pd.DataFrame(form_tag_num)
df_stem.rename(columns={0:"loc_num"}, inplace=True)
df_stem
# Out:
#           loc_num
# 0         1:1:1:1
# 1         1:1:1:2
# 2         1:1:2:1
# 3         1:1:3:1
# 4         1:1:3:2
# ...           ...
# 128214  114:6:2:1
# 128215  114:6:2:2
# 128216  114:6:3:1
# 128217  114:6:3:2
# 128218  114:6:3:3
#
# [128219 rows x 1 columns]

# %%
df_stem = df_stem["loc_num"].str.split(":", n=-1, expand=True)
df_stem.rename(columns={0:"num_1", 1:"num_2", 2:"num_3", 3:"num_4"}, inplace=True)
df_stem
# Out:
#        num_1 num_2 num_3 num_4
# 0          1     1     1     1
# 1          1     1     1     2
# 2          1     1     2     1
# 3          1     1     3     1
# 4          1     1     3     2
# ...      ...   ...   ...   ...
# 128214   114     6     2     1
# 128215   114     6     2     2
# 128216   114     6     3     1
# 128217   114     6     3     2
# 128218   114     6     3     3
#
# [128219 rows x 4 columns]

# %%
df_stem['num_1'] = df_stem['num_1'].astype(int)
df_stem['num_2'] = df_stem['num_2'].astype(int)
df_stem['num_3'] = df_stem['num_3'].astype(int)
df_stem['num_4'] = df_stem['num_4'].astype(int)

# %%
df_stem["form_tag"] = pd.DataFrame(form_tag_list)
df_stem
# Out:
#         num_1  num_2  num_3  num_4         form_tag
# 0           1      1      1      1            bi\tP
# 1           1      1      1      2          somi\tN
# 2           1      1      2      1      {ll~ahi\tPN
# 3           1      1      3      1          {l\tDET
# 4           1      1      3      2  r~aHoma`ni\tADJ
# ...       ...    ...    ...    ...              ...
# 128214    114      6      2      1         {lo\tDET
# 128215    114      6      2      2       jin~api\tN
# 128216    114      6      3      1         wa\tCONJ
# 128217    114      6      3      2          {l\tDET
# 128218    114      6      3      3        n~aAsi\tN
#
# [128219 rows x 5 columns]

# %%
df_stem[["form","tag"]] = df_stem["form_tag"].str.split("\t", n=-1, expand=True)
df_stem.drop(["form_tag"], axis=1, inplace=True)
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag
# 0           1      1      1      1          bi     P
# 1           1      1      1      2        somi     N
# 2           1      1      2      1     {ll~ahi    PN
# 3           1      1      3      1          {l   DET
# 4           1      1      3      2  r~aHoma`ni   ADJ
# ...       ...    ...    ...    ...         ...   ...
# 128214    114      6      2      1         {lo   DET
# 128215    114      6      2      2     jin~api     N
# 128216    114      6      3      1          wa  CONJ
# 128217    114      6      3      2          {l   DET
# 128218    114      6      3      3      n~aAsi     N
#
# [128219 rows x 6 columns]

# %%
df_stem.drop_duplicates(inplace=True)
df_stem.reset_index(drop=True, inplace=True)
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag
# 0           1      1      1      1          bi     P
# 1           1      1      1      2        somi     N
# 2           1      1      2      1     {ll~ahi    PN
# 3           1      1      3      1          {l   DET
# 4           1      1      3      2  r~aHoma`ni   ADJ
# ...       ...    ...    ...    ...         ...   ...
# 128214    114      6      2      1         {lo   DET
# 128215    114      6      2      2     jin~api     N
# 128216    114      6      3      1          wa  CONJ
# 128217    114      6      3      2          {l   DET
# 128218    114      6      3      3      n~aAsi     N
#
# [128219 rows x 6 columns]

# %%
#df_stem.to_excel("Buckwalter_Form_Tag_Morphology.xlsx", sheet_name="Form_Tag", index=False)

# %%
df_word = pd.DataFrame(df_stem.groupby(["num_1","num_2","num_3"])["form"].sum())
df_word.rename(columns={"form":"form_concat"}, inplace=True)
df_word.reset_index(inplace=True)
df_word
# Out:
#        num_1  num_2  num_3   form_concat
# 0          1      1      1        bisomi
# 1          1      1      2       {ll~ahi
# 2          1      1      3  {lr~aHoma`ni
# 3          1      1      4    {lr~aHiymi
# 4          1      2      1     {loHamodu
# ...      ...    ...    ...           ...
# 77424    114      5      4       Suduwri
# 77425    114      5      5      {ln~aAsi
# 77426    114      6      1          mina
# 77427    114      6      2    {lojin~api
# 77428    114      6      3    wa{ln~aAsi
#
# [77429 rows x 4 columns]

# %%
#df_word.to_excel("Buckwalter_Form_Concat_Morphology.xlsx", sheet_name="Concat_Form", index=False)

# %% [markdown]
# #### Buckwalter Text

# %%
#df_word = pd.read_excel("Buckwalter_Form_Concat_Morphology.xlsx")

# %%
df_word
# Out:
#        num_1  num_2  num_3   form_concat
# 0          1      1      1        bisomi
# 1          1      1      2       {ll~ahi
# 2          1      1      3  {lr~aHoma`ni
# 3          1      1      4    {lr~aHiymi
# 4          1      2      1     {loHamodu
# ...      ...    ...    ...           ...
# 77424    114      5      4       Suduwri
# 77425    114      5      5      {ln~aAsi
# 77426    114      6      1          mina
# 77427    114      6      2    {lojin~api
# 77428    114      6      3    wa{ln~aAsi
#
# [77429 rows x 4 columns]

# %%
concat_list = df_word.iloc[:,3].to_list()
#concat_list = df_word_concat.iloc[:,3].head(500).to_list()

# %%
buckwalter_text = " ".join(concat_list)
#buckwalter_text

# %%
#with open("Buckwalter_Form_Concat_Morphology.txt", "w", encoding="utf8") as file:
#    file.write(buckwalter_text)

# %% [markdown]
# #### Arabic Text

# %%
#with open("Buckwalter_Form_Concat_Morphology.txt", "r", encoding="utf8") as file:
#    buckwalter_text = file.read()

# %%
# buckwalter text clean for simple before transString
def clean_ex(text):
    buckwalter_out = re.sub(r'''([PJVG\.:;,!\+\^\]\[@#FNKauio`~"%-])''', "", text) # difference from clean
    return buckwalter_out

# %%
# Arabic Encoding Extended
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2uni = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "}": u"\u0626", # hamza-on-yaa'
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "F": u"\u064B", # fatHatayn
            "N": u"\u064C", # Dammatayn
            "K": u"\u064D", # kasratayn
            "a": u"\u064E", # fatHa
            "u": u"\u064F", # Damma
            "i": u"\u0650", # kasra
            "~": u"\u0651", # shaddah
            "o": u"\u0652", # sukuun
            "^": u"\u0653", # maddah
            "#": u"\u0654", # hamzaabove            
            "`": u"\u0670", # dagger 'alif
            "{": u"\u0671", # waSla
            "P": u"\u067E", # arabicletterpeh
            "J": u"\u0686", 
            "V": u"\u06A4", # arabicletterveh
            "G": u"\u06AF", # arabiclettergaf
            ":": u"\u06DC", # smallhighseen
            "@": u"\u06DF", # smallhighroundedzero
            "\"": u"\u06E0", # smallhighuprightrectangularzero
            "[": u"\u06E2", # smallhighmeemisolatedform
            ";": u"\u06E3", # smalllowseen
            ",": u"\u06E5", # smallwaw
            ".": u"\u06E6", # smallya
            "!": u"\u06E8", # smallhighnoon
            "-": u"\u06EA", # emptycentrelowstop
            "+": u"\u06EB", # emptycentrehighstop
            "%": u"\u06EC", # roundedhighstopwithfilledcentre
            "]": u"\u06ED", # smalllowmeem           
}

def transString(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2uni.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
# Simple Encoding Technique
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2unisimple = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "{": u"\u0671", # waSla         
}

def transStringSimple(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2unisimple.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
# character clean for simple after transStringSimple 
def clean(text):
    arabic_out = re.sub(r'''([PJVG\.:;,!\+\]\[@#FNKauio`~"%-])''', "", text) # .$^*+
    arabic_out2 = re.sub(r"\^", " ", arabic_out)
    return arabic_out2

# %%
arabic_func_text = transString(buckwalter_text, 1)
#arabic_func_text

# %%
#with open("Arabic_Form_Converted_Extended_Characters_Morphology.txt", "w", encoding="utf8") as file:
#    file.write(arabic_func_text)

# %% [markdown]
# ##### DF Form Word Concat Convert Arabic

# %%
#df_stem = pd.read_excel("Buckwalter_Form_Tag_Morphology.xlsx")
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag
# 0           1      1      1      1          bi     P
# 1           1      1      1      2        somi     N
# 2           1      1      2      1     {ll~ahi    PN
# 3           1      1      3      1          {l   DET
# 4           1      1      3      2  r~aHoma`ni   ADJ
# ...       ...    ...    ...    ...         ...   ...
# 128214    114      6      2      1         {lo   DET
# 128215    114      6      2      2     jin~api     N
# 128216    114      6      3      1          wa  CONJ
# 128217    114      6      3      2          {l   DET
# 128218    114      6      3      3      n~aAsi     N
#
# [128219 rows x 6 columns]

# %%
df_stem["arabic_form"] = df_stem.iloc[:,4].apply(lambda x: transString(str(x), 1))
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag arabic_form
# 0           1      1      1      1          bi     P          بِ
# 1           1      1      1      2        somi     N        سْمِ
# 2           1      1      2      1     {ll~ahi    PN     ٱللَّهِ
# 3           1      1      3      1          {l   DET          ٱل
# 4           1      1      3      2  r~aHoma`ni   ADJ  رَّحْمَٰنِ
# ...       ...    ...    ...    ...         ...   ...         ...
# 128214    114      6      2      1         {lo   DET         ٱلْ
# 128215    114      6      2      2     jin~api     N     جِنَّةِ
# 128216    114      6      3      1          wa  CONJ          وَ
# 128217    114      6      3      2          {l   DET          ٱل
# 128218    114      6      3      3      n~aAsi     N      نَّاسِ
#
# [128219 rows x 7 columns]

# %%
# 1 Way
df_stem["arabic_form_simple"] = df_stem.iloc[:,4].apply(lambda x: clean_ex(str(x)))
df_stem["arabic_form_simple"] = df_stem.iloc[:,7].apply(lambda x: transString(str(x), 1))
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag arabic_form  \
# 0           1      1      1      1          bi     P          بِ
# 1           1      1      1      2        somi     N        سْمِ
# 2           1      1      2      1     {ll~ahi    PN     ٱللَّهِ
# 3           1      1      3      1          {l   DET          ٱل
# 4           1      1      3      2  r~aHoma`ni   ADJ  رَّحْمَٰنِ
# ...       ...    ...    ...    ...         ...   ...         ...
# 128214    114      6      2      1         {lo   DET         ٱلْ
# 128215    114      6      2      2     jin~api     N     جِنَّةِ
# 128216    114      6      3      1          wa  CONJ          وَ
# 128217    114      6      3      2          {l   DET          ٱل
# 128218    114      6      3      3      n~aAsi     N      نَّاسِ
#
#        arabic_form_simple
# 0                       ب
# 1                      سم
# 2                    ٱلله
# 3                      ٱل
# 4                    رحمن
# ...                   ...
# 128214                 ٱل
# 128215                جنة
# 128216                  و
# 128217                 ٱل
# 128218                ناس
#
# [128219 rows x 8 columns]

# %%
## 2 Way
#df_stem["arabic_form_simple"] = df_stem.iloc[:,4].apply(lambda x: transStringSimple(x, 1))
#df_stem["arabic_form_simple"] = df_stem.iloc[:,7].apply(lambda x: clean(x))
#df_stem

# %%
# 1 Way
df_stem["form_simple"] = df_stem.iloc[:,4].apply(lambda x: clean_ex(str(x)))
df_stem
# Out:
#         num_1  num_2  num_3  num_4        form   tag arabic_form  \
# 0           1      1      1      1          bi     P          بِ
# 1           1      1      1      2        somi     N        سْمِ
# 2           1      1      2      1     {ll~ahi    PN     ٱللَّهِ
# 3           1      1      3      1          {l   DET          ٱل
# 4           1      1      3      2  r~aHoma`ni   ADJ  رَّحْمَٰنِ
# ...       ...    ...    ...    ...         ...   ...         ...
# 128214    114      6      2      1         {lo   DET         ٱلْ
# 128215    114      6      2      2     jin~api     N     جِنَّةِ
# 128216    114      6      3      1          wa  CONJ          وَ
# 128217    114      6      3      2          {l   DET          ٱل
# 128218    114      6      3      3      n~aAsi     N      نَّاسِ
#
#        arabic_form_simple form_simple
# 0                       ب           b
# 1                      سم          sm
# 2                    ٱلله        {llh
# 3                      ٱل          {l
# 4                    رحمن        rHmn
# ...                   ...         ...
# 128214                 ٱل          {l
# 128215                جنة         jnp
# 128216                  و           w
# 128217                 ٱل          {l
# 128218                ناس         nAs
#
# [128219 rows x 9 columns]

# %%
## 2 Way
##df_stem["form_simple"] = df_stem.iloc[:,7].apply(lambda x: transString(x, 0))
#df_stem["form_simple"] = df_stem.iloc[:,7].apply(lambda x: transStringSimple(x, 0))
#df_stem["form_simple"] = df_stem.iloc[:,8].apply(lambda x: clean(x))
#df_stem

# %%
df_stem = df_stem[["num_1","num_2","num_3","num_4","arabic_form_simple","form_simple","arabic_form","form","tag"]]
df_stem.rename(columns={"form_simple":"buckwalter_simple", "form":"buckwalter"}, inplace=True)
df_stem
# Out:
#         num_1  num_2  num_3  num_4 arabic_form_simple buckwalter_simple  \
# 0           1      1      1      1                  ب                 b
# 1           1      1      1      2                 سم                sm
# 2           1      1      2      1               ٱلله              {llh
# 3           1      1      3      1                 ٱل                {l
# 4           1      1      3      2               رحمن              rHmn
# ...       ...    ...    ...    ...                ...               ...
# 128214    114      6      2      1                 ٱل                {l
# 128215    114      6      2      2                جنة               jnp
# 128216    114      6      3      1                  و                 w
# 128217    114      6      3      2                 ٱل                {l
# 128218    114      6      3      3                ناس               nAs
#
#        arabic_form  buckwalter   tag
# 0               بِ          bi     P
# 1             سْمِ        somi     N
# 2          ٱللَّهِ     {ll~ahi    PN
# 3               ٱل          {l   DET
# 4       رَّحْمَٰنِ  r~aHoma`ni   ADJ
# ...            ...         ...   ...
# 128214         ٱلْ         {lo   DET
# 128215     جِنَّةِ     jin~api     N
# 128216          وَ          wa  CONJ
# 128217          ٱل          {l   DET
# 128218      نَّاسِ      n~aAsi     N
#
# [128219 rows x 9 columns]

# %%
#df_stem.to_excel("Arabic_Buckwalter_Form_And_Simple_Morphology.xlsx", sheet_name="Arabic_And_Simple_Form", index=False, encoding="utf-8")

# %%
#df_word = pd.read_excel("Buckwalter_Form_Concat_Morphology.xlsx")
df_word
# Out:
#        num_1  num_2  num_3   form_concat
# 0          1      1      1        bisomi
# 1          1      1      2       {ll~ahi
# 2          1      1      3  {lr~aHoma`ni
# 3          1      1      4    {lr~aHiymi
# 4          1      2      1     {loHamodu
# ...      ...    ...    ...           ...
# 77424    114      5      4       Suduwri
# 77425    114      5      5      {ln~aAsi
# 77426    114      6      1          mina
# 77427    114      6      2    {lojin~api
# 77428    114      6      3    wa{ln~aAsi
#
# [77429 rows x 4 columns]

# %%
df_word["arabic"] = df_word.iloc[:,3].apply(lambda x: transString(x, 1))
df_word
# Out:
#        num_1  num_2  num_3   form_concat        arabic
# 0          1      1      1        bisomi        بِسْمِ
# 1          1      1      2       {ll~ahi       ٱللَّهِ
# 2          1      1      3  {lr~aHoma`ni  ٱلرَّحْمَٰنِ
# 3          1      1      4    {lr~aHiymi    ٱلرَّحِيمِ
# 4          1      2      1     {loHamodu     ٱلْحَمْدُ
# ...      ...    ...    ...           ...           ...
# 77424    114      5      4       Suduwri       صُدُورِ
# 77425    114      5      5      {ln~aAsi      ٱلنَّاسِ
# 77426    114      6      1          mina          مِنَ
# 77427    114      6      2    {lojin~api    ٱلْجِنَّةِ
# 77428    114      6      3    wa{ln~aAsi    وَٱلنَّاسِ
#
# [77429 rows x 5 columns]

# %%
df_morp_word_nav = df_word.iloc[:,[0,1,2,4,3]]
df_morp_word_nav.rename(columns={"arabic":"arabic_word_morphology","form_concat":"buckwalter_word_morphology"}, inplace=True)
df_morp_word_nav
# Out:
#        num_1  num_2  num_3 arabic_word_morphology buckwalter_word_morphology
# 0          1      1      1                 بِسْمِ                     bisomi
# 1          1      1      2                ٱللَّهِ                    {ll~ahi
# 2          1      1      3           ٱلرَّحْمَٰنِ               {lr~aHoma`ni
# 3          1      1      4             ٱلرَّحِيمِ                 {lr~aHiymi
# 4          1      2      1              ٱلْحَمْدُ                  {loHamodu
# ...      ...    ...    ...                    ...                        ...
# 77424    114      5      4                صُدُورِ                    Suduwri
# 77425    114      5      5               ٱلنَّاسِ                   {ln~aAsi
# 77426    114      6      1                   مِنَ                       mina
# 77427    114      6      2             ٱلْجِنَّةِ                 {lojin~api
# 77428    114      6      3             وَٱلنَّاسِ                 wa{ln~aAsi
#
# [77429 rows x 5 columns]

# %%
#df_morp_word_nav.to_excel("Arabic_Buckwalter_Word_Morphology.xlsx", sheet_name="Arabic_And_Buckwalter", index=False, encoding="utf-8")

# %%
# 1 Way
df_word["arabic_simple"] = df_word.iloc[:,3].apply(lambda x : clean_ex(x))
df_word["arabic_simple"] = df_word.iloc[:,5].apply(lambda x : transString(x, 1))
df_word
# Out:
#        num_1  num_2  num_3   form_concat        arabic arabic_simple
# 0          1      1      1        bisomi        بِسْمِ           بسم
# 1          1      1      2       {ll~ahi       ٱللَّهِ          ٱلله
# 2          1      1      3  {lr~aHoma`ni  ٱلرَّحْمَٰنِ        ٱلرحمن
# 3          1      1      4    {lr~aHiymi    ٱلرَّحِيمِ        ٱلرحيم
# 4          1      2      1     {loHamodu     ٱلْحَمْدُ         ٱلحمد
# ...      ...    ...    ...           ...           ...           ...
# 77424    114      5      4       Suduwri       صُدُورِ          صدور
# 77425    114      5      5      {ln~aAsi      ٱلنَّاسِ         ٱلناس
# 77426    114      6      1          mina          مِنَ            من
# 77427    114      6      2    {lojin~api    ٱلْجِنَّةِ         ٱلجنة
# 77428    114      6      3    wa{ln~aAsi    وَٱلنَّاسِ        وٱلناس
#
# [77429 rows x 6 columns]

# %%
## 2 Way
#df_word["arabic_simple"] = df_word.iloc[:,3].apply(lambda x : transStringSimple(x, 1))
#df_word["arabic_simple"] = df_word.iloc[:,5].apply(lambda x : clean(x))
#df_word

# %%
# 1 Way
df_word["form_concat_simple"] = df_word.iloc[:,3].apply(lambda x: clean_ex(x))
df_word
# Out:
#        num_1  num_2  num_3   form_concat        arabic arabic_simple  \
# 0          1      1      1        bisomi        بِسْمِ           بسم
# 1          1      1      2       {ll~ahi       ٱللَّهِ          ٱلله
# 2          1      1      3  {lr~aHoma`ni  ٱلرَّحْمَٰنِ        ٱلرحمن
# 3          1      1      4    {lr~aHiymi    ٱلرَّحِيمِ        ٱلرحيم
# 4          1      2      1     {loHamodu     ٱلْحَمْدُ         ٱلحمد
# ...      ...    ...    ...           ...           ...           ...
# 77424    114      5      4       Suduwri       صُدُورِ          صدور
# 77425    114      5      5      {ln~aAsi      ٱلنَّاسِ         ٱلناس
# 77426    114      6      1          mina          مِنَ            من
# 77427    114      6      2    {lojin~api    ٱلْجِنَّةِ         ٱلجنة
# 77428    114      6      3    wa{ln~aAsi    وَٱلنَّاسِ        وٱلناس
#
#       form_concat_simple
# 0                    bsm
# 1                   {llh
# 2                 {lrHmn
# 3                 {lrHym
# 4                  {lHmd
# ...                  ...
# 77424               Sdwr
# 77425              {lnAs
# 77426                 mn
# 77427              {ljnp
# 77428             w{lnAs
#
# [77429 rows x 7 columns]

# %%
## 2 Way
##df_word["form_concat_simple"] = df_word.iloc[:,5].apply(lambda x: transString(x, 0))
#df_word["form_concat_simple"] = df_word.iloc[:,5].apply(lambda x: transStringSimple(x, 0))
#df_word["form_concat_simple"] = df_word.iloc[:,6].apply(lambda x: clean(x))
#df_word

# %%
df_word = df_word[["num_1","num_2","num_3","arabic_simple","form_concat_simple","arabic","form_concat"]]
df_word.rename(columns={"form_concat":"buckwalter","form_concat_simple":"buckwalter_simple"}, inplace=True)
df_word
# Out:
#        num_1  num_2  num_3 arabic_simple buckwalter_simple        arabic  \
# 0          1      1      1           بسم               bsm        بِسْمِ
# 1          1      1      2          ٱلله              {llh       ٱللَّهِ
# 2          1      1      3        ٱلرحمن            {lrHmn  ٱلرَّحْمَٰنِ
# 3          1      1      4        ٱلرحيم            {lrHym    ٱلرَّحِيمِ
# 4          1      2      1         ٱلحمد             {lHmd     ٱلْحَمْدُ
# ...      ...    ...    ...           ...               ...           ...
# 77424    114      5      4          صدور              Sdwr       صُدُورِ
# 77425    114      5      5         ٱلناس             {lnAs      ٱلنَّاسِ
# 77426    114      6      1            من                mn          مِنَ
# 77427    114      6      2         ٱلجنة             {ljnp    ٱلْجِنَّةِ
# 77428    114      6      3        وٱلناس            w{lnAs    وَٱلنَّاسِ
#
#          buckwalter
# 0            bisomi
# 1           {ll~ahi
# 2      {lr~aHoma`ni
# 3        {lr~aHiymi
# 4         {loHamodu
# ...             ...
# 77424       Suduwri
# 77425      {ln~aAsi
# 77426          mina
# 77427    {lojin~api
# 77428    wa{ln~aAsi
#
# [77429 rows x 7 columns]

# %%
df_word.iloc[27,:]
# Out:
# num_1                    1
# num_2                    7
# num_3                    8
# arabic_simple          ولا
# buckwalter_simple      wlA
# arabic               وَلَا
# buckwalter           walaA
# Name: 27, dtype: object

# %%
#df_word.to_excel("Arabic_Buckwalter_Word_And_Simple_Morphology.xlsx", sheet_name="Arabic_And_Simple", index=False, encoding="utf-8")

# %%
df_buckwalter = df_word.iloc[:,[0,1,2,6]]
df_buckwalter
# Out:
#        num_1  num_2  num_3    buckwalter
# 0          1      1      1        bisomi
# 1          1      1      2       {ll~ahi
# 2          1      1      3  {lr~aHoma`ni
# 3          1      1      4    {lr~aHiymi
# 4          1      2      1     {loHamodu
# ...      ...    ...    ...           ...
# 77424    114      5      4       Suduwri
# 77425    114      5      5      {ln~aAsi
# 77426    114      6      1          mina
# 77427    114      6      2    {lojin~api
# 77428    114      6      3    wa{ln~aAsi
#
# [77429 rows x 4 columns]

# %%
df_buckwalter_concat = df_buckwalter.groupby(["num_1","num_2"])["buckwalter"].apply(" ".join).reset_index()
df_buckwalter_concat
# Out:
#       num_1  num_2                                buckwalter
# 0         1      1    bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi
# 1         1      2     {loHamodu lil~ahi rab~i {loEa`lamiyna
# 2         1      3                   {lr~aHoma`ni {lr~aHiymi
# 3         1      4                   ma`liki yawomi {ld~iyni
# 4         1      5  <iy~aAka naEobudu wa<iy~aAka nasotaEiynu
# ...     ...    ...                                       ...
# 6231    114      2                           maliki {ln~aAsi
# 6232    114      3                          <ila`hi {ln~aAsi
# 6233    114      4        min $ar~i {lowasowaAsi {loxan~aAsi
# 6234    114      5   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi
# 6235    114      6                mina {lojin~api wa{ln~aAsi
#
# [6236 rows x 3 columns]

# %%
df_buckwalter_concat["arabic"] = df_buckwalter_concat.iloc[:,2].apply(lambda x: transString(x, 1)) # Convert Arabic Extended
df_buckwalter_concat
# Out:
#       num_1  num_2                                buckwalter  \
# 0         1      1    bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi
# 1         1      2     {loHamodu lil~ahi rab~i {loEa`lamiyna
# 2         1      3                   {lr~aHoma`ni {lr~aHiymi
# 3         1      4                   ma`liki yawomi {ld~iyni
# 4         1      5  <iy~aAka naEobudu wa<iy~aAka nasotaEiynu
# ...     ...    ...                                       ...
# 6231    114      2                           maliki {ln~aAsi
# 6232    114      3                          <ila`hi {ln~aAsi
# 6233    114      4        min $ar~i {lowasowaAsi {loxan~aAsi
# 6234    114      5   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi
# 6235    114      6                mina {lojin~api wa{ln~aAsi
#
#                                         arabic
# 0       بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1        ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2                      ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3                      مَٰلِكِ يَوْمِ ٱلدِّينِ
# 4     إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# ...                                        ...
# 6231                           مَلِكِ ٱلنَّاسِ
# 6232                          إِلَٰهِ ٱلنَّاسِ
# 6233        مِن شَرِّ ٱلْوَسْوَاسِ ٱلْخَنَّاسِ
# 6234   ٱلَّذِى يُوَسْوِسُ فِى صُدُورِ ٱلنَّاسِ
# 6235                مِنَ ٱلْجِنَّةِ وَٱلنَّاسِ
#
# [6236 rows x 4 columns]

# %%
df_morp_sent_nav = df_buckwalter_concat.iloc[:,[0,1,3,2]]
df_morp_sent_nav.rename(columns={"arabic":"arabic_sent_morphology", "buckwalter":"buckwalter_sent_morphology"}, inplace=True)
df_morp_sent_nav
# Out:
#       num_1  num_2                    arabic_sent_morphology  \
# 0         1      1    بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1         1      2     ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2         1      3                   ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3         1      4                   مَٰلِكِ يَوْمِ ٱلدِّينِ
# 4         1      5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# ...     ...    ...                                       ...
# 6231    114      2                           مَلِكِ ٱلنَّاسِ
# 6232    114      3                          إِلَٰهِ ٱلنَّاسِ
# 6233    114      4        مِن شَرِّ ٱلْوَسْوَاسِ ٱلْخَنَّاسِ
# 6234    114      5   ٱلَّذِى يُوَسْوِسُ فِى صُدُورِ ٱلنَّاسِ
# 6235    114      6                مِنَ ٱلْجِنَّةِ وَٱلنَّاسِ
#
#                     buckwalter_sent_morphology
# 0       bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi
# 1        {loHamodu lil~ahi rab~i {loEa`lamiyna
# 2                      {lr~aHoma`ni {lr~aHiymi
# 3                      ma`liki yawomi {ld~iyni
# 4     <iy~aAka naEobudu wa<iy~aAka nasotaEiynu
# ...                                        ...
# 6231                           maliki {ln~aAsi
# 6232                          <ila`hi {ln~aAsi
# 6233        min $ar~i {lowasowaAsi {loxan~aAsi
# 6234   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi
# 6235                mina {lojin~api wa{ln~aAsi
#
# [6236 rows x 4 columns]

# %%
#df_morp_sent_nav.to_excel("Arabic_Buckwalter_Sent_Morphology.xlsx", sheet_name="Arabic_And_Buckwalter", index=False, encoding="utf-8")

# %%
# 1 Way
df_buckwalter_concat["arabic_simple"] = df_buckwalter_concat.iloc[:,2].apply(lambda x : clean_ex(x))
df_buckwalter_concat["arabic_simple"] = df_buckwalter_concat.iloc[:,4].apply(lambda x : transString(x, 1)) # Convert Arabic Simple
df_buckwalter_concat
# Out:
#       num_1  num_2                                buckwalter  \
# 0         1      1    bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi
# 1         1      2     {loHamodu lil~ahi rab~i {loEa`lamiyna
# 2         1      3                   {lr~aHoma`ni {lr~aHiymi
# 3         1      4                   ma`liki yawomi {ld~iyni
# 4         1      5  <iy~aAka naEobudu wa<iy~aAka nasotaEiynu
# ...     ...    ...                                       ...
# 6231    114      2                           maliki {ln~aAsi
# 6232    114      3                          <ila`hi {ln~aAsi
# 6233    114      4        min $ar~i {lowasowaAsi {loxan~aAsi
# 6234    114      5   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi
# 6235    114      6                mina {lojin~api wa{ln~aAsi
#
#                                         arabic             arabic_simple
# 0       بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ    بسم ٱلله ٱلرحمن ٱلرحيم
# 1        ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ      ٱلحمد لله رب ٱلعلمين
# 2                      ٱلرَّحْمَٰنِ ٱلرَّحِيمِ             ٱلرحمن ٱلرحيم
# 3                      مَٰلِكِ يَوْمِ ٱلدِّينِ             ملك يوم ٱلدين
# 4     إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ    إياك نعبد وإياك نستعين
# ...                                        ...                       ...
# 6231                           مَلِكِ ٱلنَّاسِ                 ملك ٱلناس
# 6232                          إِلَٰهِ ٱلنَّاسِ                 إله ٱلناس
# 6233        مِن شَرِّ ٱلْوَسْوَاسِ ٱلْخَنَّاسِ      من شر ٱلوسواس ٱلخناس
# 6234   ٱلَّذِى يُوَسْوِسُ فِى صُدُورِ ٱلنَّاسِ  ٱلذى يوسوس فى صدور ٱلناس
# 6235                مِنَ ٱلْجِنَّةِ وَٱلنَّاسِ           من ٱلجنة وٱلناس
#
# [6236 rows x 5 columns]

# %%
## 2 Way
#df_buckwalter_concat["arabic_simple"] = df_buckwalter_concat.iloc[:,2].apply(lambda x : transStringSimple(x, 1)) # Convert Arabic Simple
#df_buckwalter_concat["arabic_simple"] = df_buckwalter_concat.iloc[:,4].apply(lambda x : clean(x))
#df_buckwalter_concat

# %%
df_buckwalter_concat = df_buckwalter_concat[["num_1","num_2","arabic","buckwalter","arabic_simple"]]
df_buckwalter_concat
# Out:
#       num_1  num_2                                    arabic  \
# 0         1      1    بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1         1      2     ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2         1      3                   ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3         1      4                   مَٰلِكِ يَوْمِ ٱلدِّينِ
# 4         1      5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# ...     ...    ...                                       ...
# 6231    114      2                           مَلِكِ ٱلنَّاسِ
# 6232    114      3                          إِلَٰهِ ٱلنَّاسِ
# 6233    114      4        مِن شَرِّ ٱلْوَسْوَاسِ ٱلْخَنَّاسِ
# 6234    114      5   ٱلَّذِى يُوَسْوِسُ فِى صُدُورِ ٱلنَّاسِ
# 6235    114      6                مِنَ ٱلْجِنَّةِ وَٱلنَّاسِ
#
#                                     buckwalter             arabic_simple
# 0       bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi    بسم ٱلله ٱلرحمن ٱلرحيم
# 1        {loHamodu lil~ahi rab~i {loEa`lamiyna      ٱلحمد لله رب ٱلعلمين
# 2                      {lr~aHoma`ni {lr~aHiymi             ٱلرحمن ٱلرحيم
# 3                      ma`liki yawomi {ld~iyni             ملك يوم ٱلدين
# 4     <iy~aAka naEobudu wa<iy~aAka nasotaEiynu    إياك نعبد وإياك نستعين
# ...                                        ...                       ...
# 6231                           maliki {ln~aAsi                 ملك ٱلناس
# 6232                          <ila`hi {ln~aAsi                 إله ٱلناس
# 6233        min $ar~i {lowasowaAsi {loxan~aAsi      من شر ٱلوسواس ٱلخناس
# 6234   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi  ٱلذى يوسوس فى صدور ٱلناس
# 6235                mina {lojin~api wa{ln~aAsi           من ٱلجنة وٱلناس
#
# [6236 rows x 5 columns]

# %%
# 1 Way
df_buckwalter_concat["buckwalter_simple"] = df_buckwalter_concat.iloc[:,3].apply(lambda x : clean_ex(x)) # Convert Arabic Simple
df_buckwalter_concat
# Out:
# <ipython-input-54-b8caadbd0684>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_buckwalter_concat["buckwalter_simple"] = df_buckwalter_concat.iloc[:,3].apply(lambda x : clean_ex(x)) # Convert Arabic Simple
#       num_1  num_2                                    arabic  \
# 0         1      1    بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1         1      2     ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2         1      3                   ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3         1      4                   مَٰلِكِ يَوْمِ ٱلدِّينِ
# 4         1      5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# ...     ...    ...                                       ...
# 6231    114      2                           مَلِكِ ٱلنَّاسِ
# 6232    114      3                          إِلَٰهِ ٱلنَّاسِ
# 6233    114      4        مِن شَرِّ ٱلْوَسْوَاسِ ٱلْخَنَّاسِ
# 6234    114      5   ٱلَّذِى يُوَسْوِسُ فِى صُدُورِ ٱلنَّاسِ
# 6235    114      6                مِنَ ٱلْجِنَّةِ وَٱلنَّاسِ
#
#                                     buckwalter             arabic_simple  \
# 0       bisomi {ll~ahi {lr~aHoma`ni {lr~aHiymi    بسم ٱلله ٱلرحمن ٱلرحيم
# 1        {loHamodu lil~ahi rab~i {loEa`lamiyna      ٱلحمد لله رب ٱلعلمين
# 2                      {lr~aHoma`ni {lr~aHiymi             ٱلرحمن ٱلرحيم
# 3                      ma`liki yawomi {ld~iyni             ملك يوم ٱلدين
# 4     <iy~aAka naEobudu wa<iy~aAka nasotaEiynu    إياك نعبد وإياك نستعين
# ...                                        ...                       ...
# 6231                           maliki {ln~aAsi                 ملك ٱلناس
# 6232                          <ila`hi {ln~aAsi                 إله ٱلناس
# 6233        min $ar~i {lowasowaAsi {loxan~aAsi      من شر ٱلوسواس ٱلخناس
# 6234   {l~a*iY yuwasowisu fiY Suduwri {ln~aAsi  ٱلذى يوسوس فى صدور ٱلناس
# 6235                mina {lojin~api wa{ln~aAsi           من ٱلجنة وٱلناس
#
#              buckwalter_simple
# 0       bsm {llh {lrHmn {lrHym
# 1         {lHmd llh rb {lElmyn
# 2                {lrHmn {lrHym
# 3                mlk ywm {ldyn
# 4       <yAk nEbd w<yAk nstEyn
# ...                        ...
# 6231                 mlk {lnAs
# 6232                 <lh {lnAs
# 6233      mn $r {lwswAs {lxnAs
# 6234  {l*Y ywsws fY Sdwr {lnAs
# 6235           mn {ljnp w{lnAs
#
# [6236 rows x 6 columns]

# %%
## 2 Way
##df_buckwalter_concat["buckwalter_simple"] = df_buckwalter_concat.iloc[:,4].apply(lambda x : transString(x, 0))
#df_buckwalter_concat["buckwalter_simple"] = df_buckwalter_concat.iloc[:,4].apply(lambda x : transStringSimple(x, 0)) # Convert Arabic Simple
#df_buckwalter_concat["buckwalter_simple"] = df_buckwalter_concat.iloc[:,5].apply(lambda x : clean(x))
#df_buckwalter_concat

# %%
#df_buckwalter_concat.to_excel("Arabic_Buckwalter_Sent_And_Simple_Morphology.xlsx", sheet_name="Arabic_Simple_Sentence", index=False)

# %% [markdown]
# ##### Arabic Frequency

# %%
#df_stem = pd.read_excel("Buckwalter_Form_Tag_Morphology.xlsx")

# %%
df_arabic_form_count = pd.DataFrame(df_stem.iloc[:,6].value_counts(ascending=False))
df_arabic_form_count.reset_index(inplace=True)
df_arabic_form_count.rename(columns={"index":"arabic_form","arabic_form":"frequency"}, inplace=True)
df_arabic_form_count
# Out:
#       arabic_form  frequency
# 0              وَ       9572
# 1             ٱلْ       5375
# 2              فَ       3001
# 3             وا۟       2853
# 4              ٱل       2597
# ...           ...        ...
# 12200     مُقِيمَ          1
# 12201    نُعْلِنُ          1
# 12202     نُخْفِى          1
# 12203    تَهْوِىٓ          1
# 12204  يُوَسْوِسُ          1
#
# [12205 rows x 2 columns]

# %%
#df_arabic_form_count.to_excel("Arabic_Form_Frequency_Morphology.xlsx", sheet_name="Arabic_Form_Frequency", index=False)

# %%
df_arabic_form_simple_count = pd.DataFrame(df_stem.iloc[:,4].value_counts(ascending=False))
df_arabic_form_simple_count.reset_index(inplace=True)
df_arabic_form_simple_count.rename(columns={"index":"arabic_form_simple","arabic_form_simple":"frequency"}, inplace=True)
df_arabic_form_simple_count
# Out:
#      arabic_form_simple  frequency
# 0                     و      10077
# 1                    ٱل       8046
# 2                     ل       4176
# 3                    من       3950
# 4                    هم       3901
# ...                 ...        ...
# 7420               يخيل          1
# 7421              كبائر          1
# 7422               جذوع          1
# 7423              تجتنب          1
# 7424              يوسوس          1
#
# [7425 rows x 2 columns]

# %%
#df_arabic_form_simple_count.to_excel("Arabic_Form_Simple_Frequency_Morphology.xlsx", sheet_name="Arabic_Form_Simple_Frequency", index=False)

# %%
#df_word = pd.read_excel("Arabic_Buckwalter_Word_And_Simple_Morphology.xlsx")

# %%
df_arabic_word_count = pd.DataFrame(df_word.iloc[:,5].value_counts(ascending=False))
df_arabic_word_count.reset_index(inplace=True)
df_arabic_word_count.rename(columns={"index":"arabic","arabic":"frequency"}, inplace=True)
df_arabic_word_count
# Out:
#              arabic  frequency
# 0               فِى       1098
# 1           ٱللَّهِ        828
# 2         ٱلَّذِينَ        810
# 3           ٱللَّهُ        733
# 4               مِن        728
# ...             ...        ...
# 18988       يُنكِرُ          1
# 18989      أُشْرِكَ          1
# 18990      مَـَٔابِ          1
# 18991  وَذُرِّيَّةً          1
# 18992    يُوَسْوِسُ          1
#
# [18993 rows x 2 columns]

# %%
#df_arabic_word_count.to_excel("Arabic_Word_Frequency_Morphology.xlsx", sheet_name="Arabic_Word_Frequency", index=False)

# %%
df_arabic_word_simple_count = pd.DataFrame(df_word.iloc[:,3].value_counts(ascending=False))
df_arabic_word_simple_count.reset_index(inplace=True)
df_arabic_word_simple_count.rename(columns={"index":"arabic_simple","arabic_simple":"frequency"}, inplace=True)
df_arabic_word_simple_count
# Out:
#       arabic_simple  frequency
# 0                من       2763
# 1              ٱلله       2153
# 2                فى       1185
# 3                ما       1010
# 4                إن        966
# ...             ...        ...
# 14809          فبدأ          1
# 14810      بأوعيتهم          1
# 14811      ٱستخرجها          1
# 14812          كدنا          1
# 14813         يوسوس          1
#
# [14814 rows x 2 columns]

# %%
df_arabic_word_simple_count.to_excel("Arabic_Simple_Word_Frequency_Morphology.xlsx", sheet_name="Arabic_Simple_Word_Frequency", index=False)

# %% [markdown]
# ##### Arabic Simple Frequency Nav

# %%
df_arabic_simple_select = df_arabic_word_simple_count.head(1000)
df_arabic_simple_select
# Out:
#     arabic_simple  frequency
# 0              من       2763
# 1            ٱلله       2153
# 2              فى       1185
# 3              ما       1010
# 4              إن        966
# ..            ...        ...
# 995          نفسك          9
# 996          عندك          9
# 997          يشرك          9
# 998         ٱستوى          9
# 999        يعبدون          9
#
# [1000 rows x 2 columns]

# %%
df_arabic_simple_count_merge = pd.merge(df_arabic_simple_select, df_word, how="inner", on="arabic_simple")
df_arabic_simple_count_merge
# Out:
#       arabic_simple  frequency  num_1  num_2  num_3 buckwalter_simple  \
# 0                من       2763      2      4      8                mn
# 1                من       2763      2      5      4                mn
# 2                من       2763      2      8      3                mn
# 3                من       2763      2     19      3                mn
# 4                من       2763      2     19     13                mn
# ...             ...        ...    ...    ...    ...               ...
# 51338        يعبدون          9     28     63     18            yEbdwn
# 51339        يعبدون          9     34     40     10            yEbdwn
# 51340        يعبدون          9     34     41      9            yEbdwn
# 51341        يعبدون          9     37     22      7            yEbdwn
# 51342        يعبدون          9     43     45     13            yEbdwn
#
#             arabic   buckwalter
# 0              مِن          min
# 1             مِّن         m~in
# 2              مَن          man
# 3            مِّنَ        m~ina
# 4            مِّنَ        m~ina
# ...            ...          ...
# 51338  يَعْبُدُونَ  yaEobuduwna
# 51339  يَعْبُدُونَ  yaEobuduwna
# 51340  يَعْبُدُونَ  yaEobuduwna
# 51341  يَعْبُدُونَ  yaEobuduwna
# 51342  يُعْبَدُونَ  yuEobaduwna
#
# [51343 rows x 8 columns]

# %%
df_arabic_simple_count_merge = df_arabic_simple_count_merge[["num_1","num_2","num_3","arabic_simple","buckwalter_simple","frequency","arabic","buckwalter"]]
df_arabic_simple_count_merge
# Out:
#        num_1  num_2  num_3 arabic_simple buckwalter_simple  frequency  \
# 0          2      4      8            من                mn       2763
# 1          2      5      4            من                mn       2763
# 2          2      8      3            من                mn       2763
# 3          2     19      3            من                mn       2763
# 4          2     19     13            من                mn       2763
# ...      ...    ...    ...           ...               ...        ...
# 51338     28     63     18        يعبدون            yEbdwn          9
# 51339     34     40     10        يعبدون            yEbdwn          9
# 51340     34     41      9        يعبدون            yEbdwn          9
# 51341     37     22      7        يعبدون            yEbdwn          9
# 51342     43     45     13        يعبدون            yEbdwn          9
#
#             arabic   buckwalter
# 0              مِن          min
# 1             مِّن         m~in
# 2              مَن          man
# 3            مِّنَ        m~ina
# 4            مِّنَ        m~ina
# ...            ...          ...
# 51338  يَعْبُدُونَ  yaEobuduwna
# 51339  يَعْبُدُونَ  yaEobuduwna
# 51340  يَعْبُدُونَ  yaEobuduwna
# 51341  يَعْبُدُونَ  yaEobuduwna
# 51342  يُعْبَدُونَ  yuEobaduwna
#
# [51343 rows x 8 columns]

# %%
df_arabic_simple_count_merge["nav"] = df_arabic_simple_count_merge["num_1"].astype("str")+":"+df_arabic_simple_count_merge["num_2"].astype("str")+":"+df_arabic_simple_count_merge["num_3"].astype("str")
df_arabic_simple_count_merge
# Out:
# <ipython-input-70-9577043f5c20>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_arabic_simple_count_merge["nav"] = df_arabic_simple_count_merge["num_1"].astype("str")+":"+df_arabic_simple_count_merge["num_2"].astype("str")+":"+df_arabic_simple_count_merge["num_3"].astype("str")
#        num_1  num_2  num_3 arabic_simple buckwalter_simple  frequency  \
# 0          2      4      8            من                mn       2763
# 1          2      5      4            من                mn       2763
# 2          2      8      3            من                mn       2763
# 3          2     19      3            من                mn       2763
# 4          2     19     13            من                mn       2763
# ...      ...    ...    ...           ...               ...        ...
# 51338     28     63     18        يعبدون            yEbdwn          9
# 51339     34     40     10        يعبدون            yEbdwn          9
# 51340     34     41      9        يعبدون            yEbdwn          9
# 51341     37     22      7        يعبدون            yEbdwn          9
# 51342     43     45     13        يعبدون            yEbdwn          9
#
#             arabic   buckwalter       nav
# 0              مِن          min     2:4:8
# 1             مِّن         m~in     2:5:4
# 2              مَن          man     2:8:3
# 3            مِّنَ        m~ina    2:19:3
# 4            مِّنَ        m~ina   2:19:13
# ...            ...          ...       ...
# 51338  يَعْبُدُونَ  yaEobuduwna  28:63:18
# 51339  يَعْبُدُونَ  yaEobuduwna  34:40:10
# 51340  يَعْبُدُونَ  yaEobuduwna   34:41:9
# 51341  يَعْبُدُونَ  yaEobuduwna   37:22:7
# 51342  يُعْبَدُونَ  yuEobaduwna  43:45:13
#
# [51343 rows x 9 columns]

# %%
#df_arabic_simple_count_merge.to_excel("Arabic_Buckwalter_Word_And_Simple_Navigation_Morphology.xlsx", sheet_name="Arabic_Word_Navigation", index=False)

# %%
df_arabic_simple_nav = df_arabic_simple_count_merge.groupby(["arabic_simple","buckwalter_simple","frequency"])["nav"].apply(", ".join).reset_index().sort_values(by="frequency", ascending=False)
df_arabic_simple_nav.reset_index(drop=True, inplace=True)
df_arabic_simple_nav
# Out:
#     arabic_simple buckwalter_simple  frequency  \
# 0              من                mn       2763
# 1            ٱلله              {llh       2153
# 2              فى                fY       1185
# 3              ما                mA       1010
# 4              إن                <n        966
# ..            ...               ...        ...
# 995          عندك              Endk          9
# 996          نفسك              nfsk          9
# 997        كٱلذين            k{l*yn          9
# 998         ٱستوى             {stwY          9
# 999          يشرك              y$rk          9
#
#                                                    nav
# 0    2:4:8, 2:5:4, 2:8:3, 2:19:3, 2:19:13, 2:21:8, ...
# 1    1:1:2, 2:7:2, 2:9:2, 2:10:5, 2:15:1, 2:17:11, ...
# 2    2:10:1, 2:11:6, 2:15:5, 2:17:14, 2:19:11, 2:23...
# 3    2:17:8, 2:26:8, 2:27:9, 2:29:5, 2:30:26, 2:32:...
# 4    2:6:1, 2:20:20, 2:23:18, 2:26:1, 2:31:13, 2:62...
# ..                                                 ...
# 995  4:78:24, 4:81:6, 7:134:12, 8:32:10, 17:23:11, ...
# 996  4:79:12, 4:84:8, 5:116:40, 7:205:4, 18:6:3, 18...
# 997  3:105:3, 3:156:6, 8:21:3, 8:47:3, 9:69:1, 33:6...
# 998  2:29:10, 7:54:12, 10:3:12, 13:2:9, 20:5:4, 25:...
# 999  4:48:6, 4:48:15, 4:116:6, 4:116:15, 5:72:21, 1...
#
# [1000 rows x 4 columns]

# %%
#df_arabic_simple_nav.to_excel("Arabic_Buckwalter_Simple_Freq_And_Nav_Morphology.xlsx", sheet_name="Arabic_Simple_Freq_Nav", index=False)
