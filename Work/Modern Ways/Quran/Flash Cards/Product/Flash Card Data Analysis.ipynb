# %% [markdown]
# ### Flash Cards Data Analysis

# %%
import os
import pandas as pd
import numpy as np
import re
import glob
from functools import reduce
from camel_tools.utils.charmap import CharMapper
from lang_trans.arabic import buckwalter
from pathlib import Path
import shutil

# %%
path = f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quran/Flash Cards/Result"

Path(path).mkdir(parents=True, exist_ok=True)

# %%
# buckwalter text clean for simple before transString
def clean_ex(text):
    buckwalter_out = re.sub(r'''([PJVG\.:;,!\+\^\]\[@#FNKauio`~"%-])''', "", text) # difference from clean
    return buckwalter_out

# %%
# Arabic Encoding Extended
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2uni = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "}": u"\u0626", # hamza-on-yaa'
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "F": u"\u064B", # fatHatayn
            "N": u"\u064C", # Dammatayn
            "K": u"\u064D", # kasratayn
            "a": u"\u064E", # fatHa
            "u": u"\u064F", # Damma
            "i": u"\u0650", # kasra
            "~": u"\u0651", # shaddah
            "o": u"\u0652", # sukuun
            "^": u"\u0653", # maddah
            "#": u"\u0654", # hamzaabove            
            "`": u"\u0670", # dagger 'alif
            "{": u"\u0671", # waSla
            "P": u"\u067E", # arabicletterpeh
            "J": u"\u0686", 
            "V": u"\u06A4", # arabicletterveh
            "G": u"\u06AF", # arabiclettergaf
            ":": u"\u06DC", # smallhighseen
            "@": u"\u06DF", # smallhighroundedzero
            "\"": u"\u06E0", # smallhighuprightrectangularzero
            "[": u"\u06E2", # smallhighmeemisolatedform
            ";": u"\u06E3", # smalllowseen
            ",": u"\u06E5", # smallwaw
            ".": u"\u06E6", # smallya
            "!": u"\u06E8", # smallhighnoon
            "-": u"\u06EA", # emptycentrelowstop
            "+": u"\u06EB", # emptycentrehighstop
            "%": u"\u06EC", # roundedhighstopwithfilledcentre
            "]": u"\u06ED", # smalllowmeem           
}

def transString(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2uni.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
# Simple Technique
# -*- coding: utf-8 -*-

# Arabic Transliteration based on Buckwalter
# dictionary source is buckwalter2unicode.py http://www.redhat.com/archives/fedora-extras-commits/2007-June/msg03617.html 

buck2unisimple = {"'": u"\u0621", # hamza-on-the-line
            "|": u"\u0622", # madda
            ">": u"\u0623", # hamza-on-'alif
            "&": u"\u0624", # hamza-on-waaw
            "<": u"\u0625", # hamza-under-'alif
            "A": u"\u0627", # bare 'alif
            "b": u"\u0628", # baa'
            "p": u"\u0629", # taa' marbuuTa
            "t": u"\u062A", # taa'
            "v": u"\u062B", # thaa'
            "j": u"\u062C", # jiim
            "H": u"\u062D", # Haa'
            "x": u"\u062E", # khaa'
            "d": u"\u062F", # daal
            "*": u"\u0630", # dhaal
            "r": u"\u0631", # raa'
            "z": u"\u0632", # zaay
            "s": u"\u0633", # siin
            "$": u"\u0634", # shiin
            "S": u"\u0635", # Saad
            "D": u"\u0636", # Daad
            "T": u"\u0637", # Taa'
            "Z": u"\u0638", # Zaa' (DHaa')
            "E": u"\u0639", # cayn
            "g": u"\u063A", # ghayn
            "_": u"\u0640", # taTwiil
            "f": u"\u0641", # faa'
            "q": u"\u0642", # qaaf
            "k": u"\u0643", # kaaf
            "l": u"\u0644", # laam
            "m": u"\u0645", # miim
            "n": u"\u0646", # nuun
            "h": u"\u0647", # haa'
            "w": u"\u0648", # waaw
            "Y": u"\u0649", # 'alif maqSuura
            "y": u"\u064A", # yaa'
            "{": u"\u0671", # waSla         
}

def transStringSimple(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2unisimple.items():
      if not reverse:
            string = string.replace(v, k)
      else:
            string = string.replace(k, v)

    return string

# %%
# character clean for simple after transStringSimple 
def clean(text):
    arabic_out = re.sub(r'''([PJVG\.:;,!\+\]\[@#FNKauio`~"%-])''', "", text) # .$^*+
    arabic_out2 = re.sub(r"\^", " ", arabic_out)
    return arabic_out2

# %% [markdown]
# #### Quran Word Translate Select

# %%
df_quran_master = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quran/Flash Cards/Data/Master 17052022.xlsx")
df_all_word_translate = df_quran_master.loc[:,["surah","surah latin","tanzil_clean","arabic","translate_english","translate_urdu","translate_hindi","translate_indonesian","translate_bangla","translate_turkish","translate_russian"]]
#df_all_word_translate = df_quran_master.loc[:,["surah","surah latin","tanzil_clean","tanzil_plain","arabic","translate_english","translate_urdu","translate_hindi","translate_indonesian","translate_bangla","translate_turkish","translate_russian"]]  # used for arabic plain
df_all_word_translate
# Out:
#        surah surah latin tanzil_clean        arabic       translate_english  \
# 0          1   Al-Fatiha          بسم        بِسۡمِ           In (the) name
# 1          1   Al-Fatiha         الله       ٱللَّهِ              (of) Allah
# 2          1   Al-Fatiha       الرحمن  ٱلرَّحۡمَٰنِ       the Most Gracious
# 3          1   Al-Fatiha       الرحيم    ٱلرَّحِيمِ       the Most Merciful
# 4          1   Al-Fatiha        الحمد     ٱلۡحَمۡدُ  All praises and thanks
# ...      ...         ...          ...           ...                     ...
# 78242    114      An-Nas         صدور       صُدُورِ           (the) breasts
# 78243    114      An-Nas        الناس      ٱلنَّاسِ            (of) mankind
# 78244    114      An-Nas           من          مِنَ                    From
# 78245    114      An-Nas        الجنة    ٱلۡجِنَّةِ                the jinn
# 78246    114      An-Nas       والناس    وَٱلنَّاسِ                 and men
#
#                    translate_urdu          translate_hindi  \
# 0                        ساتھ نام                 साथ नाम
# 1                         اللہ کے                अल्लाह के
# 2              جو بے حد مہربان ہے         जो बहुत मेहरबान
# 3      بار بار رحم فرمانے والا ہے  निहायत रहम करने वाला है
# 4                        سب تعریف                सब तारीफ़
# ...                           ...                      ...
# 78242                       سینوں                सीनों में
# 78243                  انسانوں کے                लोगों के
# 78244                          سے          जिन्नों में से
# 78245                    جنوں میں          जिन्नों में से
# 78246             اور انسانوں میں       और इन्सानों में से
#
#       translate_indonesian translate_bangla  translate_turkish  \
# 0              dengan nama             নামে             adıyla
# 1                    Allah       আল্লাহ (র)           Allah'ın
# 2            Maha Pengasih      পরম করুণাময়             Rahman
# 3           Maha Penyayang       অসীম দয়ালু              Rahim
# 4                   pujian      সকল প্রশংসা          hamdolsun
# ...                    ...              ...                ...
# 78242                 dada      অন্তরসমূহের        göğüslerine
# 78243              manusia          মানুষের         insanların
# 78244                 dari         মধ্য হতে          cinlerden
# 78245                  jin            জিনের          cinlerden
# 78246          dan manusia        ও মানুষের  ve insanlar(dan);
#
#          translate_russian
# 0                 С именем
# 1                  Аллаха,
# 2             Милостивого,
# 3            Милосердного!
# 4                    Хвала
# ...                    ...
# 78242               грудях
# 78243               людей,
# 78244  (будучи) из (числа)
# 78245              джиннов
# 78246            и людей».
#
# [78247 rows x 11 columns]

# %%
df_all_word_translate = df_all_word_translate[~df_all_word_translate["arabic"].isnull()]
df_all_word_translate
# Out:
#        surah surah latin tanzil_clean        arabic       translate_english  \
# 0          1   Al-Fatiha          بسم        بِسۡمِ           In (the) name
# 1          1   Al-Fatiha         الله       ٱللَّهِ              (of) Allah
# 2          1   Al-Fatiha       الرحمن  ٱلرَّحۡمَٰنِ       the Most Gracious
# 3          1   Al-Fatiha       الرحيم    ٱلرَّحِيمِ       the Most Merciful
# 4          1   Al-Fatiha        الحمد     ٱلۡحَمۡدُ  All praises and thanks
# ...      ...         ...          ...           ...                     ...
# 78242    114      An-Nas         صدور       صُدُورِ           (the) breasts
# 78243    114      An-Nas        الناس      ٱلنَّاسِ            (of) mankind
# 78244    114      An-Nas           من          مِنَ                    From
# 78245    114      An-Nas        الجنة    ٱلۡجِنَّةِ                the jinn
# 78246    114      An-Nas       والناس    وَٱلنَّاسِ                 and men
#
#                    translate_urdu          translate_hindi  \
# 0                        ساتھ نام                 साथ नाम
# 1                         اللہ کے                अल्लाह के
# 2              جو بے حد مہربان ہے         जो बहुत मेहरबान
# 3      بار بار رحم فرمانے والا ہے  निहायत रहम करने वाला है
# 4                        سب تعریف                सब तारीफ़
# ...                           ...                      ...
# 78242                       سینوں                सीनों में
# 78243                  انسانوں کے                लोगों के
# 78244                          سے          जिन्नों में से
# 78245                    جنوں میں          जिन्नों में से
# 78246             اور انسانوں میں       और इन्सानों में से
#
#       translate_indonesian translate_bangla  translate_turkish  \
# 0              dengan nama             নামে             adıyla
# 1                    Allah       আল্লাহ (র)           Allah'ın
# 2            Maha Pengasih      পরম করুণাময়             Rahman
# 3           Maha Penyayang       অসীম দয়ালু              Rahim
# 4                   pujian      সকল প্রশংসা          hamdolsun
# ...                    ...              ...                ...
# 78242                 dada      অন্তরসমূহের        göğüslerine
# 78243              manusia          মানুষের         insanların
# 78244                 dari         মধ্য হতে          cinlerden
# 78245                  jin            জিনের          cinlerden
# 78246          dan manusia        ও মানুষের  ve insanlar(dan);
#
#          translate_russian
# 0                 С именем
# 1                  Аллаха,
# 2             Милостивого,
# 3            Милосердного!
# 4                    Хвала
# ...                    ...
# 78242               грудях
# 78243               людей,
# 78244  (будучи) из (числа)
# 78245              джиннов
# 78246            и людей».
#
# [77799 rows x 11 columns]

# %%
df_all_word_translate.drop("arabic", axis=1, inplace=True)
#df_all_word_translate.rename(columns={"tanzil_plain":"arabic","tanzil_clean":"arabic_simple"}, inplace=True)  # used for arabic plain
df_all_word_translate.rename(columns={"tanzil_clean":"arabic_simple"}, inplace=True)
df_all_word_translate
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#        surah surah latin arabic_simple       translate_english  \
# 0          1   Al-Fatiha           بسم           In (the) name
# 1          1   Al-Fatiha          الله              (of) Allah
# 2          1   Al-Fatiha        الرحمن       the Most Gracious
# 3          1   Al-Fatiha        الرحيم       the Most Merciful
# 4          1   Al-Fatiha         الحمد  All praises and thanks
# ...      ...         ...           ...                     ...
# 78242    114      An-Nas          صدور           (the) breasts
# 78243    114      An-Nas         الناس            (of) mankind
# 78244    114      An-Nas            من                    From
# 78245    114      An-Nas         الجنة                the jinn
# 78246    114      An-Nas        والناس                 and men
#
#                    translate_urdu          translate_hindi  \
# 0                        ساتھ نام                 साथ नाम
# 1                         اللہ کے                अल्लाह के
# 2              جو بے حد مہربان ہے         जो बहुत मेहरबान
# 3      بار بار رحم فرمانے والا ہے  निहायत रहम करने वाला है
# 4                        سب تعریف                सब तारीफ़
# ...                           ...                      ...
# 78242                       سینوں                सीनों में
# 78243                  انسانوں کے                लोगों के
# 78244                          سے          जिन्नों में से
# 78245                    جنوں میں          जिन्नों में से
# 78246             اور انسانوں میں       और इन्सानों में से
#
#       translate_indonesian translate_bangla  translate_turkish  \
# 0              dengan nama             নামে             adıyla
# 1                    Allah       আল্লাহ (র)           Allah'ın
# 2            Maha Pengasih      পরম করুণাময়             Rahman
# 3           Maha Penyayang       অসীম দয়ালু              Rahim
# 4                   pujian      সকল প্রশংসা          hamdolsun
# ...                    ...              ...                ...
# 78242                 dada      অন্তরসমূহের        göğüslerine
# 78243              manusia          মানুষের         insanların
# 78244                 dari         মধ্য হতে          cinlerden
# 78245                  jin            জিনের          cinlerden
# 78246          dan manusia        ও মানুষের  ve insanlar(dan);
#
#          translate_russian
# 0                 С именем
# 1                  Аллаха,
# 2             Милостивого,
# 3            Милосердного!
# 4                    Хвала
# ...                    ...
# 78242               грудях
# 78243               людей,
# 78244  (будучи) из (числа)
# 78245              джиннов
# 78246            и людей».
#
# [77799 rows x 10 columns]

# %%
#df_arabic_word_count = df_all_word_translate["arabic"].value_counts(ascending=False).reset_index()  # used for arabic plain
#df_arabic_word_count.rename(columns={"index":"arabic","arabic":"arabic_frequency"}, inplace=True)  # used for arabic plain

df_arabic_word_count = df_all_word_translate["arabic_simple"].value_counts(ascending=False).reset_index()
df_arabic_word_count.rename(columns={"index":"arabic_simple","arabic_simple":"arabic_simple_frequency"}, inplace=True)
#df_arabic_word_count = df_arabic_word_count.head(300)
df_arabic_word_count
# Out:
#       arabic_simple  arabic_simple_frequency
# 0                من                     2763
# 1              الله                     2153
# 2                في                     1185
# 3                ما                     1013
# 4                إن                      966
# ...             ...                      ...
# 14862          نفقد                        1
# 14863          صواع                        1
# 14864         لنفسد                        1
# 14865        سارقين                        1
# 14866         يوسوس                        1
#
# [14867 rows x 2 columns]

# %%
#df_word_translate_select = df_all_word_translate.iloc[:,[2,3,4,5,6,7,8,9,10]]  # used for arabic plain
df_word_translate_select = df_all_word_translate.iloc[:,[2,3,4,5,6,7,8,9]]
df_word_translate_select.drop_duplicates(inplace=True)
df_word_translate_select
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#       arabic_simple       translate_english              translate_urdu  \
# 0               بسم           In (the) name                    ساتھ نام
# 1              الله              (of) Allah                     اللہ کے
# 2            الرحمن       the Most Gracious          جو بے حد مہربان ہے
# 3            الرحيم       the Most Merciful  بار بار رحم فرمانے والا ہے
# 4             الحمد  All praises and thanks                    سب تعریف
# ...             ...                     ...                         ...
# 78242          صدور           (the) breasts                       سینوں
# 78243         الناس            (of) mankind                  انسانوں کے
# 78244            من                    From                          سے
# 78245         الجنة                the jinn                    جنوں میں
# 78246        والناس                 and men             اور انسانوں میں
#
#                translate_hindi translate_indonesian translate_bangla  \
# 0                     साथ नाम           dengan nama             নামে
# 1                    अल्लाह के                Allah       আল্লাহ (র)
# 2             जो बहुत मेहरबान         Maha Pengasih      পরম করুণাময়
# 3      निहायत रहम करने वाला है       Maha Penyayang       অসীম দয়ালু
# 4                    सब तारीफ़               pujian      সকল প্রশংসা
# ...                        ...                  ...              ...
# 78242                सीनों में                 dada      অন্তরসমূহের
# 78243                लोगों के               manusia          মানুষের
# 78244          जिन्नों में से                  dari         মধ্য হতে
# 78245          जिन्नों में से                   jin            জিনের
# 78246       और इन्सानों में से          dan manusia        ও মানুষের
#
#        translate_turkish    translate_russian
# 0                 adıyla             С именем
# 1               Allah'ın              Аллаха,
# 2                 Rahman         Милостивого,
# 3                  Rahim        Милосердного!
# 4              hamdolsun                Хвала
# ...                  ...                  ...
# 78242        göğüslerine               грудях
# 78243         insanların               людей,
# 78244          cinlerden  (будучи) из (числа)
# 78245          cinlerden              джиннов
# 78246  ve insanlar(dan);            и людей».
#
# [69903 rows x 8 columns]

# %%
#df_arabic_count_translate_merge = pd.merge(df_arabic_word_count, df_word_translate_select, how="left", on="arabic")  # used for arabic plain
df_arabic_count_translate_merge = pd.merge(df_arabic_word_count, df_word_translate_select, how="left", on="arabic_simple")
df_arabic_count_translate_merge.drop_duplicates(inplace=True)
df_arabic_count_translate_merge
# Out:
#       arabic_simple  arabic_simple_frequency         translate_english  \
# 0                من                     2763                      from
# 1                من                     2763                      from
# 2                من                     2763            (are some) who
# 3                من                     2763                      from
# 4                من                     2763                      from
# ...             ...                      ...                       ...
# 69898          نفقد                        1            We are missing
# 69899          صواع                        1                 (the) cup
# 69900         لنفسد                        1  that we cause corruption
# 69901        سارقين                        1                   thieves
# 69902         يوسوس                        1                  whispers
#
#         translate_urdu      translate_hindi      translate_indonesian  \
# 0                   سے            आपसे पहले                      dari
# 1                   سے   अपने रब की तरफ़ से                      dari
# 2                   جو                   जो                orang yang
# 3                   سے             आसमान से                      dari
# 4                   سے  बिजली के कड़ाकों से                      dari
# ...                ...                  ...                       ...
# 69898   ہم گم پاتے ہیں      हम गुम पाते हैं           kami kehilangan
# 69899           پیمانہ               पैमाना                     piala
# 69900  کہ ہم فساد کریں     कि हम फ़साद करें   untuk membuat kerusakan
# 69901              چور       चोरी करने वाले  orang-orang yang mencuri
# 69902   وسوسہ ڈالتا ہے      वसवसा डालता है           membisik-bisikan
#
#                 translate_bangla        translate_turkish  \
# 0                           থেকে              senden önce
# 1                       পক্ষ হতে              Rablerinden
# 2                           যারা              öyleleri de
# 3                           থেকে                   gökten
# 4                          কারনে     yıldırım seslerinden
# ...                          ...                      ...
# 69898             "আমরা হারিয়েছি                kaybettik
# 69899                   পানপাত্র                su tasını
# 69900  জন্যে আমরা খারাপ কাজ করার  bozgunculuk yapmak için
# 69901                       চোর"                   hırsız
# 69902            কুমন্ত্রণা দেয়                 fısıldar
#
#             translate_russian
# 0                     до тебя
# 1                          от
# 2                    тот, кто
# 3                           с
# 4                          от
# ...                       ...
# 69898                «Ищем мы
# 69899                    чашу
# 69900  чтобы сеять беспорядок
# 69901                ворами».
# 69902                 наущает
#
# [69903 rows x 9 columns]

# %%
#df_select_english = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_english'].value_counts(ascending=False).index[0]))  # used for arabic plain
df_select_english = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic_simple","arabic_simple_frequency"]).apply(lambda x: x['translate_english'].value_counts(ascending=False).index[0]))
df_select_english.rename(columns={0:"translate_english"}, inplace=True)
df_select_english.reset_index(inplace=True)
#df_select_english.sort_values(by="arabic_frequency", ascending=False, inplace=True)  # used for arabic plain
df_select_english.sort_values(by="arabic_simple_frequency", ascending=False, inplace=True)
df_select_english.reset_index(drop=True, inplace=True)
df_select_english
# Out:
#       arabic_simple  arabic_simple_frequency  translate_english
# 0                من                     2763               from
# 1              الله                     2153              Allah
# 2                في                     1185                 in
# 3                ما                     1013               what
# 4                إن                      966             Indeed
# ...             ...                      ...                ...
# 14862        طردتهم                        1  I drove them away
# 14863           طرف                        1           a glance
# 14864          طرفا                        1             a part
# 14865          طرفك                        1        your glance
# 14866      فانكحوهن                        1      So marry them
#
# [14867 rows x 3 columns]

# %%
#df_select_urdu = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_urdu'].value_counts(ascending=False).index[0]))  # used for arabic plain
df_select_urdu = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic_simple","arabic_simple_frequency"]).apply(lambda x: x['translate_urdu'].value_counts(ascending=False).index[0]))
df_select_urdu.rename(columns={0:"translate_urdu"}, inplace=True)
df_select_urdu.reset_index(inplace=True)
#df_select_urdu.sort_values(by="arabic_frequency", ascending=False, inplace=True)  # used for arabic plain
df_select_urdu.sort_values(by="arabic_simple_frequency", ascending=False, inplace=True)
df_select_urdu.reset_index(drop=True, inplace=True)
df_select_urdu
# Out:
#       arabic_simple  arabic_simple_frequency              translate_urdu
# 0                من                     2763                          سے
# 1              الله                     2153                        اللہ
# 2                في                     1185                         میں
# 3                ما                     1013                          جو
# 4                إن                      966                        بیشک
# ...             ...                      ...                         ...
# 14862        طردتهم                        1  میں نے دور پھینک دیا ان کو
# 14863           طرف                        1                         نظر
# 14864          طرفا                        1     ایک گروہ کو۔ ایک حصے کو
# 14865          طرفك                        1                   نگاہ تیری
# 14866      فانكحوهن                        1          تو نکاح کرلو ان سے
#
# [14867 rows x 3 columns]

# %%
#df_select_hindi = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_hindi'].value_counts(ascending=False).index[0]))  # used for arabic plain
df_select_hindi = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic_simple","arabic_simple_frequency"]).apply(lambda x: x['translate_hindi'].value_counts(ascending=False).index[0]))
df_select_hindi.rename(columns={0:"translate_hindi"}, inplace=True)
df_select_hindi.reset_index(inplace=True)
#df_select_hindi.sort_values(by="arabic_frequency", ascending=False, inplace=True)  # used for arabic plain
df_select_hindi.sort_values(by="arabic_simple_frequency", ascending=False, inplace=True)
df_select_hindi.reset_index(drop=True, inplace=True)
df_select_hindi
# Out:
#       arabic_simple  arabic_simple_frequency           translate_hindi
# 0                من                     2763                        जो
# 1              الله                     2153                    अल्लाह
# 2                في                     1185                ज़मीन में
# 3                ما                     1013                        जो
# 4                إن                      966                      बेशक
# ...             ...                      ...                       ...
# 14862        طردتهم                        1  दूर कर दिया मैंने उन्हें
# 14863           طرف                        1                 झुकी आँख
# 14864          طرفا                        1                 एक हिस्सा
# 14865          طرفك                        1                 नज़र आपकी
# 14866      فانكحوهن                        1       तो निकाह कर लो उनसे
#
# [14867 rows x 3 columns]

# %%
#df_select_indonesian = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_indonesian'].value_counts(ascending=False).index[0]))  # used for arabic plain
df_select_indonesian = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic_simple","arabic_simple_frequency"]).apply(lambda x: x['translate_indonesian'].value_counts(ascending=False).index[0]))
df_select_indonesian.rename(columns={0:"translate_indonesian"}, inplace=True)
df_select_indonesian.reset_index(inplace=True)
#df_select_indonesian.sort_values(by="arabic_frequency", ascending=False, inplace=True)  # used for arabic plain
df_select_indonesian.sort_values(by="arabic_simple_frequency", ascending=False, inplace=True)
df_select_indonesian.reset_index(drop=True, inplace=True)
df_select_indonesian
# Out:
#       arabic_simple  arabic_simple_frequency   translate_indonesian
# 0                من                     2763                   dari
# 1              الله                     2153                  Allah
# 2                في                     1185                  dalam
# 3                ما                     1013                    apa
# 4                إن                      966           sesungguhnya
# ...             ...                      ...                    ...
# 14862        طردتهم                        1    aku mengusir mereka
# 14863           طرف                        1         pandangan mata
# 14864          طرفا                        1               golongan
# 14865          طرفك                        1                 matamu
# 14866      فانكحوهن                        1  maka nikahilah mereka
#
# [14867 rows x 3 columns]

# %%
#df_select_bangla = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_bangla'].value_counts(ascending=False).index[0]))  # used for arabic plain
df_select_bangla = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic_simple","arabic_simple_frequency"]).apply(lambda x: x['translate_bangla'].value_counts(ascending=False).index[0]))
df_select_bangla.rename(columns={0:"translate_bangla"}, inplace=True)
df_select_bangla.reset_index(inplace=True)
#df_select_bangla.sort_values(by="arabic_frequency", ascending=False, inplace=True)  # used for arabic plain
df_select_bangla.sort_values(by="arabic_simple_frequency", ascending=False, inplace=True)
df_select_bangla.reset_index(drop=True, inplace=True)
df_select_bangla
# Out:
#       arabic_simple  arabic_simple_frequency             translate_bangla
# 0                من                     2763                         থেকে
# 1              الله                     2153                       আল্লাহ
# 2                في                     1185                        মধ্যে
# 3                ما                     1013                           যা
# 4                إن                      966                     নিশ্চয়ই
# ...             ...                      ...                          ...
# 14862        طردتهم                        1       তাদেরকে আমি তাড়িয়ে দিই
# 14863           طرف                        1                       দৃষ্টি
# 14864          طرفا                        1                   একটি অংশকে
# 14865          طرفك                        1             আপনার চোখের পলক"
# 14866      فانكحوهن                        1  অতএব তাদেরকে তোমরা বিবাহ কর
#
# [14867 rows x 3 columns]

# %%
#df_select_turkish = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_turkish'].value_counts(ascending=False).index[0]))  # used for arabic plain
df_select_turkish = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic_simple","arabic_simple_frequency"]).apply(lambda x: x['translate_turkish'].value_counts(ascending=False).index[0]))
df_select_turkish.rename(columns={0:"translate_turkish"}, inplace=True)
df_select_turkish.reset_index(inplace=True)
#df_select_turkish.sort_values(by="arabic_frequency", ascending=False, inplace=True)  # used for arabic plain
df_select_turkish.sort_values(by="arabic_simple_frequency", ascending=False, inplace=True)
df_select_turkish.reset_index(drop=True, inplace=True)
df_select_turkish
# Out:
#       arabic_simple  arabic_simple_frequency         translate_turkish
# 0                من                     2763                    hiçbir
# 1              الله                     2153                     Allah
# 2                في                     1185                    içinde
# 3                ما                     1013                   şeyleri
# 4                إن                      966                  şüphesiz
# ...             ...                      ...                       ...
# 14862        طردتهم                        1             onları kovsam
# 14863           طرف                        1                göz ucuyla
# 14864          طرفا                        1               bir kısmını
# 14865          طرفك                        1                    gözünü
# 14866      فانكحوهن                        1  öyle ise onlarla evlenin
#
# [14867 rows x 3 columns]

# %%
#df_select_russian = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic","arabic_simple","arabic_frequency"]).apply(lambda x: x['translate_russian'].value_counts(ascending=False).index[0]))  # used for arabic plain
df_select_russian = pd.DataFrame(df_arabic_count_translate_merge.groupby(["arabic_simple","arabic_simple_frequency"]).apply(lambda x: x['translate_russian'].value_counts(ascending=False).index[0]))
df_select_russian.rename(columns={0:"translate_russian"}, inplace=True)
df_select_russian.reset_index(inplace=True)
#df_select_russian.sort_values(by="arabic_frequency", ascending=False, inplace=True)  # used for arabic plain
df_select_russian.sort_values(by="arabic_simple_frequency", ascending=False, inplace=True)
df_select_russian.reset_index(drop=True, inplace=True)
df_select_russian
# Out:
#       arabic_simple  arabic_simple_frequency   translate_russian
# 0                من                     2763                  из
# 1              الله                     2153               Аллах
# 2                في                     1185                   в
# 3                ما                     1013             то, что
# 4                إن                      966           Поистине,
# ...             ...                      ...                 ...
# 14862        طردتهم                        1       я прогоню их?
# 14863           طرف                        1            скрытыми
# 14864          طرفا                        1          одну часть
# 14865          طرفك                        1         твой взор».
# 14866      فانكحوهن                        1  Женитесь же на них
#
# [14867 rows x 3 columns]

# %%
dfs = [df_select_english,df_select_urdu,df_select_hindi,df_select_indonesian,df_select_bangla,df_select_turkish,df_select_russian]

# %%
#df_all_translate_merge = reduce(lambda  left,right: pd.merge(left,right, on=['arabic','arabic_simple','arabic_simple_frequency'], how='inner'), dfs)  # left,right make left to right merge, used for arabic plain
df_all_translate_merge = reduce(lambda  left,right: pd.merge(left,right, on=['arabic_simple','arabic_simple_frequency'], how='inner'), dfs)  # left,right make left to right merge
#df_all_translate_merge = reduce(lambda  right,left: pd.merge(left,right, on=['word'], how='outer'), dfs)  # right,left make right to left merge
df_all_translate_merge.drop_duplicates(inplace=True)
df_all_translate_merge
# Out:
#       arabic_simple  arabic_simple_frequency  translate_english  \
# 0                من                     2763               from
# 1              الله                     2153              Allah
# 2                في                     1185                 in
# 3                ما                     1013               what
# 4                إن                      966             Indeed
# ...             ...                      ...                ...
# 14862        طردتهم                        1  I drove them away
# 14863           طرف                        1           a glance
# 14864          طرفا                        1             a part
# 14865          طرفك                        1        your glance
# 14866      فانكحوهن                        1      So marry them
#
#                    translate_urdu           translate_hindi  \
# 0                              سے                        जो
# 1                            اللہ                    अल्लाह
# 2                             میں                ज़मीन में
# 3                              جو                        जो
# 4                            بیشک                      बेशक
# ...                           ...                       ...
# 14862  میں نے دور پھینک دیا ان کو  दूर कर दिया मैंने उन्हें
# 14863                         نظر                 झुकी आँख
# 14864     ایک گروہ کو۔ ایک حصے کو                 एक हिस्सा
# 14865                   نگاہ تیری                 नज़र आपकी
# 14866          تو نکاح کرلو ان سے       तो निकाह कर लो उनसे
#
#         translate_indonesian             translate_bangla  \
# 0                       dari                         থেকে
# 1                      Allah                       আল্লাহ
# 2                      dalam                        মধ্যে
# 3                        apa                           যা
# 4               sesungguhnya                     নিশ্চয়ই
# ...                      ...                          ...
# 14862    aku mengusir mereka       তাদেরকে আমি তাড়িয়ে দিই
# 14863         pandangan mata                       দৃষ্টি
# 14864               golongan                   একটি অংশকে
# 14865                 matamu             আপনার চোখের পলক"
# 14866  maka nikahilah mereka  অতএব তাদেরকে তোমরা বিবাহ কর
#
#               translate_turkish   translate_russian
# 0                        hiçbir                  из
# 1                         Allah               Аллах
# 2                        içinde                   в
# 3                       şeyleri             то, что
# 4                      şüphesiz           Поистине,
# ...                         ...                 ...
# 14862             onları kovsam       я прогоню их?
# 14863                göz ucuyla            скрытыми
# 14864               bir kısmını          одну часть
# 14865                    gözünü         твой взор».
# 14866  öyle ise onlarla evlenin  Женитесь же на них
#
# [14867 rows x 9 columns]

# %%
df_all_translate_merge.to_excel("Quran_Word_Translate_All.xlsx", index=False)

# %%
df_all_translate_merge_select = df_all_translate_merge.head(305)

# %%
df_all_translate_merge_select.to_excel("Quran_Word_Translate_300.xlsx", index=False)

# %% [markdown]
# #### Quran Root With Related Arabic Word Translate

# %%
df_all_translate_merge = pd.read_excel("Quran_Word_Translate_All.xlsx")  # read previous output data
df_all_translate_merge
# Out:
#       arabic_simple  arabic_simple_frequency  translate_english  \
# 0                من                     2763               from
# 1              الله                     2153              Allah
# 2                في                     1185                 in
# 3                ما                     1013               what
# 4                إن                      966             Indeed
# ...             ...                      ...                ...
# 14862        طردتهم                        1  I drove them away
# 14863           طرف                        1           a glance
# 14864          طرفا                        1             a part
# 14865          طرفك                        1        your glance
# 14866      فانكحوهن                        1      So marry them
#
#                    translate_urdu           translate_hindi  \
# 0                              سے                        जो
# 1                            اللہ                    अल्लाह
# 2                             میں                ज़मीन में
# 3                              جو                        जो
# 4                            بیشک                      बेशक
# ...                           ...                       ...
# 14862  میں نے دور پھینک دیا ان کو  दूर कर दिया मैंने उन्हें
# 14863                         نظر                 झुकी आँख
# 14864     ایک گروہ کو۔ ایک حصے کو                 एक हिस्सा
# 14865                   نگاہ تیری                 नज़र आपकी
# 14866          تو نکاح کرلو ان سے       तो निकाह कर लो उनसे
#
#         translate_indonesian             translate_bangla  \
# 0                       dari                         থেকে
# 1                      Allah                       আল্লাহ
# 2                      dalam                        মধ্যে
# 3                        apa                           যা
# 4               sesungguhnya                     নিশ্চয়ই
# ...                      ...                          ...
# 14862    aku mengusir mereka       তাদেরকে আমি তাড়িয়ে দিই
# 14863         pandangan mata                       দৃষ্টি
# 14864               golongan                   একটি অংশকে
# 14865                 matamu             আপনার চোখের পলক"
# 14866  maka nikahilah mereka  অতএব তাদেরকে তোমরা বিবাহ কর
#
#               translate_turkish   translate_russian
# 0                        hiçbir                  из
# 1                         Allah               Аллах
# 2                        içinde                   в
# 3                       şeyleri             то, что
# 4                      şüphesiz           Поистине,
# ...                         ...                 ...
# 14862             onları kovsam       я прогоню их?
# 14863                göz ucuyla            скрытыми
# 14864               bir kısmını          одну часть
# 14865                    gözünü         твой взор».
# 14866  öyle ise onlarla evlenin  Женитесь же на них
#
# [14867 rows x 9 columns]

# %%
df_quran_master = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quran/Flash Cards/Data/Master 17052022.xlsx")
df_master_root_data = df_quran_master.loc[:,["surah","ayah","word rank","surah latin","tanzil_clean","tanzil_plain","root_arabic","root"]]
df_master_root_data
# Out:
#        surah  ayah  word rank surah latin tanzil_clean  tanzil_plain  \
# 0          1     1          1   Al-Fatiha          بسم        بِسْمِ
# 1          1     1          2   Al-Fatiha         الله       اللَّهِ
# 2          1     1          3   Al-Fatiha       الرحمن  الرَّحْمَٰنِ
# 3          1     1          4   Al-Fatiha       الرحيم    الرَّحِيمِ
# 4          1     2          1   Al-Fatiha        الحمد     الْحَمْدُ
# ...      ...   ...        ...         ...          ...           ...
# 78242    114     5          4      An-Nas         صدور       صُدُورِ
# 78243    114     5          5      An-Nas        الناس      النَّاسِ
# 78244    114     6          1      An-Nas           من          مِنَ
# 78245    114     6          2      An-Nas        الجنة    الْجِنَّةِ
# 78246    114     6          3      An-Nas       والناس    وَالنَّاسِ
#
#       root_arabic root
# 0             سمو  smw
# 1             اله  Alh
# 2             رحم  rHm
# 3             رحم  rHm
# 4             حمد  Hmd
# ...           ...  ...
# 78242         صدر  Sdr
# 78243         نوس  nws
# 78244         NaN  NaN
# 78245         جنن  jnn
# 78246         نوس  nws
#
# [78247 rows x 8 columns]

# %%
df_arabic_root_count = df_master_root_data["root_arabic"].value_counts(ascending=False).reset_index()
df_arabic_root_count.rename(columns={"index":"root_arabic","root_arabic":"root_arabic_frequency"}, inplace=True)
df_arabic_root_count_select = df_arabic_root_count.iloc[1:100,]
df_arabic_root_count_select
# Out:
#    root_arabic  root_arabic_frequency
# 1          قول                   1722
# 2          كون                   1390
# 3          ربب                    980
# 4          امن                    879
# 5          علم                    854
# ..         ...                    ...
# 95         عزز                    119
# 96         امم                    119
# 97         جزي                    118
# 98         ابو                    117
# 99         نهر                    113
#
# [99 rows x 2 columns]

# %%
df_arabic_root_count_select.to_excel("Quran_Root_99.xlsx", index=False)

# %%
df_root_select_data_merge = pd.merge(df_arabic_root_count_select, df_master_root_data, how="left", on=["root_arabic"])
df_root_select_data_merge.rename(columns={"tanzil_plain":"arabic","tanzil_clean":"arabic_simple"}, inplace=True)
df_root_select_data_merge.drop_duplicates(inplace=True)
df_root_select_data_merge = df_root_select_data_merge.iloc[:,[0,8,1,2,3,4,5,6,7]]
df_root_select_data_merge
# Out:
#       root_arabic root  root_arabic_frequency  surah  ayah  word rank  \
# 0             قول  qwl                   1722      2     8          4
# 1             قول  qwl                   1722      2    11          2
# 2             قول  qwl                   1722      2    11          8
# 3             قول  qwl                   1722      2    13          2
# 4             قول  qwl                   1722      2    13          8
# ...           ...  ...                    ...    ...   ...        ...
# 27372         نهر  nhr                    113     85    11         11
# 27373         نهر  nhr                    113     91     3          1
# 27374         نهر  nhr                    113     92     2          1
# 27375         نهر  nhr                    113     93    10          4
# 27376         نهر  nhr                    113     98     8          9
#
#       surah latin arabic_simple        arabic
# 0       Al-Baqara          يقول       يَقُولُ
# 1       Al-Baqara           قيل         قِيلَ
# 2       Al-Baqara         قالوا       قَالُوا
# 3       Al-Baqara           قيل         قِيلَ
# 4       Al-Baqara         قالوا       قَالُوا
# ...           ...           ...           ...
# 27372   Al-Burooj       الأنهار  الْأَنْهَارُ
# 27373   Ash-Shams       والنهار  وَالنَّهَارِ
# 27374     Al-Lail       والنهار  وَالنَّهَارِ
# 27375    Ad-Dhuha          تنهر      تَنْهَرْ
# 27376  Al-Bayyina       الأنهار  الْأَنْهَارُ
#
# [27377 rows x 9 columns]

# %%
#df_root_select_translate_merge = pd.merge(df_root_select_data_merge, df_all_translate_merge, how="left", on=["arabic_simple","arabic"])  # used for arabic
df_root_select_translate_merge = pd.merge(df_root_select_data_merge, df_all_translate_merge, how="left", on=["arabic_simple"])
df_root_select_translate_merge.drop_duplicates(inplace=True)
df_root_select_translate_merge
# Out:
#       root_arabic root  root_arabic_frequency  surah  ayah  word rank  \
# 0             قول  qwl                   1722      2     8          4
# 1             قول  qwl                   1722      2    11          2
# 2             قول  qwl                   1722      2    11          8
# 3             قول  qwl                   1722      2    13          2
# 4             قول  qwl                   1722      2    13          8
# ...           ...  ...                    ...    ...   ...        ...
# 27372         نهر  nhr                    113     85    11         11
# 27373         نهر  nhr                    113     91     3          1
# 27374         نهر  nhr                    113     92     2          1
# 27375         نهر  nhr                    113     93    10          4
# 27376         نهر  nhr                    113     98     8          9
#
#       surah latin arabic_simple        arabic  arabic_simple_frequency  \
# 0       Al-Baqara          يقول       يَقُولُ                       39
# 1       Al-Baqara           قيل         قِيلَ                       34
# 2       Al-Baqara         قالوا       قَالُوا                      250
# 3       Al-Baqara           قيل         قِيلَ                       34
# 4       Al-Baqara         قالوا       قَالُوا                      250
# ...           ...           ...           ...                      ...
# 27372   Al-Burooj       الأنهار  الْأَنْهَارُ                       43
# 27373   Ash-Shams       والنهار  وَالنَّهَارِ                       26
# 27374     Al-Lail       والنهار  وَالنَّهَارِ                       26
# 27375    Ad-Dhuha          تنهر      تَنْهَرْ                        1
# 27376  Al-Bayyina       الأنهار  الْأَنْهَارُ                       43
#
#       translate_english translate_urdu   translate_hindi translate_indonesian  \
# 0                   say     وہ کہتا ہے        वो कहता है              berkata
# 1            it is said        کہا گیا       कहा जाता है            dikatakan
# 2             They said   انہوں نے کہا      उन्होंने कहा       mereka berkata
# 3            it is said        کہا گیا       कहा जाता है            dikatakan
# 4             They said   انہوں نے کہا      उन्होंने कहा       mereka berkata
# ...                 ...            ...               ...                  ...
# 27372        the rivers          نہریں             नहरें        sungai-sungai
# 27373       and the day      اور دن کو         और दिन को            dan siang
# 27374       and the day      اور دن کو         और दिन को            dan siang
# 27375             repel          جھڑکو  आप झिड़कये (उसे)      kamu menghardik
# 27376        the rivers          نہریں             नहरें        sungai-sungai
#
#       translate_bangla translate_turkish translate_russian
# 0                 বলেন               der          говорит:
# 1               বলা হয়           dendiği         говорится
# 2            তারা বললো           dediler      Сказали они:
# 3               বলা হয়           dendiği         говорится
# 4            তারা বললো           dediler      Сказали они:
# ...                ...               ...               ...
# 27372        ঝর্ণাসমূহ          ırmaklar             реки,
# 27373          ও দিনের        ve gündüzü           и день,
# 27374          ও দিনের        ve gündüzü           и день,
# 27375     তিরস্কার করো          azarlama          отгоняй!
# 27376        ঝর্ণাসমূহ          ırmaklar             реки,
#
# [27377 rows x 17 columns]

# %%
df_root_select_translate_merge.to_excel("Quran_Root_Word_Translate_99.xlsx", index=False)

# %%
df_root_data_merge = pd.merge(df_arabic_root_count, df_master_root_data, how="left", on=["root_arabic"])
df_root_data_merge.rename(columns={"tanzil_plain":"arabic","tanzil_clean":"arabic_simple"}, inplace=True)
df_root_data_merge.drop_duplicates(inplace=True)
df_root_data_merge = df_root_data_merge.iloc[:,[0,8,1,2,3,4,5,6,7]]
df_root_data_merge
# Out:
#       root_arabic root  root_arabic_frequency  surah  ayah  word rank  \
# 0             اله  Alh                   2851      1     1          2
# 1             اله  Alh                   2851      1     2          2
# 2             اله  Alh                   2851      2     7          2
# 3             اله  Alh                   2851      2     8          6
# 4             اله  Alh                   2851      2     9          2
# ...           ...  ...                    ...    ...   ...        ...
# 49963         هشش  h$$                      1     20    18          6
# 49964         نعل  nEl                      1     20    12          5
# 49965         خلع  xlE                      1     20    12          4
# 49966         ثري  vry                      1     20     6         12
# 49967         نفث  nfv                      1    113     4          3
#
#       surah latin arabic_simple          arabic
# 0       Al-Fatiha          الله         اللَّهِ
# 1       Al-Fatiha           لله         لِلَّهِ
# 2       Al-Baqara          الله         اللَّهُ
# 3       Al-Baqara         بالله       بِاللَّهِ
# 4       Al-Baqara          الله         اللَّهَ
# ...           ...           ...             ...
# 49963       Ta-Ha          وأهش       وَأَهُشُّ
# 49964       Ta-Ha         نعليك      نَعْلَيْكَ
# 49965       Ta-Ha         فاخلع       فَاخْلَعْ
# 49966       Ta-Ha         الثرى       الثَّرَىٰ
# 49967    Al-Falaq      النفاثات  النَّفَّاثَاتِ
#
# [49968 rows x 9 columns]

# %%
#df_root_translate_merge = pd.merge(df_root_data_merge, df_all_translate_merge, how="left", on=["arabic_simple","arabic"])  # used for arabic
df_root_translate_merge = pd.merge(df_root_data_merge, df_all_translate_merge, how="left", on=["arabic_simple"])
df_root_translate_merge.drop_duplicates(inplace=True)
df_root_translate_merge
# Out:
#       root_arabic root  root_arabic_frequency  surah  ayah  word rank  \
# 0             اله  Alh                   2851      1     1          2
# 1             اله  Alh                   2851      1     2          2
# 2             اله  Alh                   2851      2     7          2
# 3             اله  Alh                   2851      2     8          6
# 4             اله  Alh                   2851      2     9          2
# ...           ...  ...                    ...    ...   ...        ...
# 49963         هشش  h$$                      1     20    18          6
# 49964         نعل  nEl                      1     20    12          5
# 49965         خلع  xlE                      1     20    12          4
# 49966         ثري  vry                      1     20     6         12
# 49967         نفث  nfv                      1    113     4          3
#
#       surah latin arabic_simple          arabic  arabic_simple_frequency  \
# 0       Al-Fatiha          الله         اللَّهِ                     2153
# 1       Al-Fatiha           لله         لِلَّهِ                      116
# 2       Al-Baqara          الله         اللَّهُ                     2153
# 3       Al-Baqara         بالله       بِاللَّهِ                      139
# 4       Al-Baqara          الله         اللَّهَ                     2153
# ...           ...           ...             ...                      ...
# 49963       Ta-Ha          وأهش       وَأَهُشُّ                        1
# 49964       Ta-Ha         نعليك      نَعْلَيْكَ                        1
# 49965       Ta-Ha         فاخلع       فَاخْلَعْ                        1
# 49966       Ta-Ha         الثرى       الثَّرَىٰ                        1
# 49967    Al-Falaq      النفاثات  النَّفَّاثَاتِ                        1
#
#              translate_english          translate_urdu  \
# 0                        Allah                    اللہ
# 1                     to Allah             اللہ کے لیے
# 2                        Allah                    اللہ
# 3                     in Allah                 اللہ پر
# 4                        Allah                    اللہ
# ...                        ...                     ...
# 49963  and I bring down leaves  اور میں پتے جھاڑتا ہوں
# 49964               your shoes           اپنے جوتوں کو
# 49965                so remove              پس اتار دو
# 49966                 the soil         زمین کے۔ مٹی کے
# 49967         (of) the blowers       پھونکنے والیوں کے
#
#                translate_hindi    translate_indonesian  \
# 0                       अल्लाह                   Allah
# 1                अल्लाह के लिए              bagi Allah
# 2                       अल्लाह                   Allah
# 3                    अल्लाह पर            kepada Allah
# 4                       अल्लाह                   Allah
# ...                        ...                     ...
# 49963  और मैं पत्ते झाड़ता हूँ         dan aku memukul
# 49964          अपने दोनों जूते        kedua terompahmu
# 49965               पस उतार दो           maka lepaskan
# 49966           गीली मिट्टी के                   tanah
# 49967       फूँकने वालियों के   orang yang meniup-niup
#
#                   translate_bangla       translate_turkish   translate_russian
# 0                           আল্লাহ                   Allah               Аллах
# 1                    জন্যে আল্লাহর                 Allah'a             Аллаху,
# 2                           আল্লাহ                   Allah               Аллах
# 3                          আল্লাহই                 Allah'a            в Аллаха
# 4                           আল্লাহ                   Allah               Аллах
# ...                            ...                     ...                 ...
# 49963            এবং পাতা পাড়ি আমি  ve yaprak silkeliyorum     и сбиваю листья
# 49964              তোমার জুতা জোড়া             pabuçlarını      свои сандалии!
# 49965          অতএব খুলে ফেলো তুমি                   çıkar            Сними же
# 49966                  সিক্ত মাটির                toprağın             землей.
# 49967  ফুঁকদানকারীর (রাতের) অনিষ্ট            üfleyenlerin  плюющих (колдуний)
#
# [49968 rows x 17 columns]

# %%
df_root_translate_merge.to_excel("Quran_Root_Word_Translate_All.xlsx", index=False)

# %% [markdown]
# #### Quran Ayah Frequency

# %%
ar2bw = CharMapper.builtin_mapper('ar2bw')

# %%
type_file = "clean" # plain, minimal, clean

# %%
with open(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quran/Text/Data/Quran Simple {type_file.capitalize()}.txt", "r", encoding="utf8") as file: # Quran Simple Clean.txt from Tanzil website
    arabic_text_simple =file.readlines()

# %%
df_tanzil_sent = pd.DataFrame(arabic_text_simple)
df_tanzil_sent
# Out:
#                                      0
# 0         1|1|بسم الله الرحمن الرحيم\n
# 1          1|2|الحمد لله رب العالمين\n
# 2                  1|3|الرحمن الرحيم\n
# 3                 1|4|مالك يوم الدين\n
# 4         1|5|إياك نعبد وإياك نستعين\n
# ...                                ...
# 6231                 114|2|ملك الناس\n
# 6232                 114|3|إله الناس\n
# 6233      114|4|من شر الوسواس الخناس\n
# 6234  114|5|الذي يوسوس في صدور الناس\n
# 6235           114|6|من الجنة والناس\n
#
# [6236 rows x 1 columns]

# %%
df_tanzil_sent = pd.DataFrame(df_tanzil_sent.iloc[:,0].apply(lambda x: x.strip("\n")))
df_tanzil_sent
# Out:
#                                    0
# 0         1|1|بسم الله الرحمن الرحيم
# 1          1|2|الحمد لله رب العالمين
# 2                  1|3|الرحمن الرحيم
# 3                 1|4|مالك يوم الدين
# 4         1|5|إياك نعبد وإياك نستعين
# ...                              ...
# 6231                 114|2|ملك الناس
# 6232                 114|3|إله الناس
# 6233      114|4|من شر الوسواس الخناس
# 6234  114|5|الذي يوسوس في صدور الناس
# 6235           114|6|من الجنة والناس
#
# [6236 rows x 1 columns]

# %%
df_tanzil_sent_nav = df_tanzil_sent.iloc[:,0].str.split("|", n=-1, expand=True)
df_tanzil_sent_nav.rename(columns={0:"num_1",1:"num_2",2:f"arabic_sent_tanzil_{type_file.lower()}"}, inplace=True)
df_tanzil_sent_nav
# Out:
#      num_1 num_2  arabic_sent_tanzil_clean
# 0        1     1    بسم الله الرحمن الرحيم
# 1        1     2     الحمد لله رب العالمين
# 2        1     3             الرحمن الرحيم
# 3        1     4            مالك يوم الدين
# 4        1     5    إياك نعبد وإياك نستعين
# ...    ...   ...                       ...
# 6231   114     2                 ملك الناس
# 6232   114     3                 إله الناس
# 6233   114     4      من شر الوسواس الخناس
# 6234   114     5  الذي يوسوس في صدور الناس
# 6235   114     6           من الجنة والناس
#
# [6236 rows x 3 columns]

# %%
df_tanzil_sent_count = df_tanzil_sent_nav.loc[:,f"arabic_sent_tanzil_{type_file.lower()}"].value_counts(ascending=False).reset_index()
df_tanzil_sent_count.rename(columns={"index":f"arabic_sent_tanzil_{type_file.lower()}",f"arabic_sent_tanzil_{type_file.lower()}":"arabic_sent_frequency"}, inplace=True)
df_tanzil_sent_count
# Out:
#                                arabic_sent_tanzil_clean  arabic_sent_frequency
# 0                                فبأي آلاء ربكما تكذبان                     31
# 1                                    ويل يومئذ للمكذبين                     11
# 2                             وإن ربك لهو العزيز الرحيم                      8
# 3                                   فاتقوا الله وأطيعون                      8
# 4                             بسم الله الرحمن الرحيم حم                      7
# ...                                                 ...                    ...
# 6050  وكل إنسان ألزمناه طائره في عنقه ونخرج له يوم ا...                      1
# 6051  وجعلنا الليل والنهار آيتين فمحونا آية الليل وج...                      1
# 6052  ويدع الإنسان بالشر دعاءه بالخير وكان الإنسان ع...                      1
# 6053  وأن الذين لا يؤمنون بالآخرة أعتدنا لهم عذابا أ...                      1
# 6054                                    من الجنة والناس                      1
#
# [6055 rows x 2 columns]

# %%
df_tanzil_sent_count.to_excel(f"Quran_{type_file.lower().capitalize()}_Ayahs_Frequency.xlsx", index=False)

# %% [markdown]
# #### Quran Twogram Threegram Select

# %%
df_quran_master = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quran/Flash Cards/Data/Master 17052022.xlsx")
df_master_twogram_data = df_quran_master.loc[:,["twogram_string","twogram_english","twogram_turkish","twogram_urdu","twogram_hindi","twogram_indonesian","twogram_bangla","twogram_russian"]]
df_master_twogram_data
# Out:
#       twogram_string        twogram_english      twogram_turkish  \
# 0           بسم الله     In the name of God            Bismillah
# 1        الله الرحمن  God the Most Gracious  Tanrı en merhametli
# 2      الرحمن الرحيم          Most Merciful      Rahman ve Rahim
# 3                NaN                    NaN                  NaN
# 4          الحمد لله              Thank God        Allah'a şükür
# ...              ...                    ...                  ...
# 78242            NaN                    NaN                  NaN
# 78243            NaN                    NaN                  NaN
# 78244            NaN                    NaN                  NaN
# 78245            NaN                    NaN                  NaN
# 78246            NaN                    NaN                  NaN
#
#                     twogram_urdu     twogram_hindi       twogram_indonesian  \
# 0                  خدا کے نام پر   भगवान के नाम पर          Atas nama tuhan
# 1         خدا سب سے زیادہ مہربان  भगवान सबसे दयालु  Tuhan Yang Maha Pemurah
# 2      سب سے زیادہ رحم کرنے والا         परम दयालु           Maha Penyayang
# 3                            NaN               NaN                      NaN
# 4                  خدا کا شکر ہے           सुकर है       Terima kasih Tuhan
# ...                          ...               ...                      ...
# 78242                        NaN               NaN                      NaN
# 78243                        NaN               NaN                      NaN
# 78244                        NaN               NaN                      NaN
# 78245                        NaN               NaN                      NaN
# 78246                        NaN               NaN                      NaN
#
#               twogram_bangla    twogram_russian
# 0               আল্লাহর নামে        Во имя Бога
# 1         পরম করুণাময় ঈশ্বর     Бог Милостивый
# 2               পরম করুণাময়  Самый Милосердный
# 3                        NaN                NaN
# 4      সৃষ্টিকর্তাকে ধন্যবাদ         Слава Богу
# ...                      ...                ...
# 78242                    NaN                NaN
# 78243                    NaN                NaN
# 78244                    NaN                NaN
# 78245                    NaN                NaN
# 78246                    NaN                NaN
#
# [78247 rows x 8 columns]

# %%
df_master_twogram_count = df_master_twogram_data["twogram_string"].value_counts(ascending=False).reset_index()
df_master_twogram_count.rename(columns={"index":"twogram_string", "twogram_string":"twogram_string_frequency"}, inplace=True)
df_master_twogram_count
# Out:
#       twogram_string  twogram_string_frequency
# 0            إن الله                       205
# 1        الذين آمنوا                       184
# 2           في الأرض                       176
# 3        الذين كفروا                       134
# 4    السماوات والأرض                       133
# ..               ...                       ...
# 195         من بعدهم                        17
# 196          ولو شاء                        17
# 197           إن كان                        17
# 198        رسول الله                        17
# 199          من ربهم                        16
#
# [200 rows x 2 columns]

# %%
df_master_twogram_count_translate_merge = pd.merge(df_master_twogram_count, df_master_twogram_data, how="left", on="twogram_string")
df_master_twogram_count_translate_merge.drop_duplicates(inplace=True)
df_master_twogram_count_translate_merge.reset_index(drop=True, inplace=True)
df_master_twogram_count_translate_merge
# Out:
#       twogram_string  twogram_string_frequency    twogram_english  \
# 0            إن الله                       205             God is
# 1        الذين آمنوا                       184       who believed
# 2           في الأرض                       176           in Earth
# 3        الذين كفروا                       134    who disbelieved
# 4    السماوات والأرض                       133  Heavens and Earth
# ..               ...                       ...                ...
# 195         من بعدهم                        17         after them
# 196          ولو شاء                        17        if he wants
# 197           إن كان                        17                 if
# 198        رسول الله                        17   Messenger of God
# 199          من ربهم                        16    from their Lord
#
#      twogram_turkish       twogram_urdu        twogram_hindi  \
# 0              Allah             خدا ہے             भगवान है
# 1         kim inandı      جو ایمان لائے   जो विश्वास करता था
# 2           Dünya'da           زمین میں             धरती में
# 3       kim inanmadı  جنہوں نے کفر کیا۔  जिसने अविश्वास किया
# 4    Gökler ve Dünya     آسمان اور زمین     स्वर्ग और पृथ्वी
# ..               ...                ...                  ...
# 195   onlardan sonra          ان کے بعد             उनके बाद
# 196     eğer isterse    اگر وہ چاہتا ہے      यदि वह चाहता है
# 197             Eğer                اگر                  अगर
# 198       Resulullah        خدا کے رسول         भगवान के दूत
# 199      Rablerinden  اپنے رب کی طرف سے           उनके रब से
#
#             twogram_indonesian             twogram_bangla twogram_russian
# 0                 Tuhan adalah                 উপাস্য নেই         Бог это
# 1          siapa yang percaya?        যারা বিশ্বাস করেছিল       кто верил
# 2                      di Bumi                   পৃথিবীতে        на Земле
# 3    siapa yang tidak percaya?       যারা অবিশ্বাস করেছিল  кто не поверил
# 4              Langit dan Bumi              আকাশ ও পৃথিবী  Небеса и Земля
# ..                         ...                        ...             ...
# 195             setelah mereka                  তাদের পরে       после них
# 196               jika dia mau                যদি সে চায়   если он хочет
# 197                       jika                        যদি            если
# 198               Utusan Tuhan                    রসূল সা  Посланник Бога
# 199          dari Tuhan mereka  তাদের পালনকর্তার কাছ থেকে   от их Господа
#
# [200 rows x 9 columns]

# %%
df_master_twogram_count_translate_merge.to_excel(f"Quran_Twogram_Translate_Frequency.xlsx", index=False)

# %%
df_master_threegram_data = df_quran_master.loc[:,["threegram_string","threegram_english","threegram_turkish","threegram_urdu","threegram_hindi","threegram_indonesian","threegram_bangla","threegram_russian"]]
df_master_threegram_data
# Out:
#       threegram_string                         threegram_english  \
# 0      بسم الله الرحمن  in the name of ALLAH, the most mercifull
# 1                  NaN                                       NaN
# 2                  NaN                                       NaN
# 3                  NaN                                       NaN
# 4                  NaN                                       NaN
# ...                ...                                       ...
# 78242              NaN                                       NaN
# 78243              NaN                                       NaN
# 78244              NaN                                       NaN
# 78245              NaN                                       NaN
# 78246              NaN                                       NaN
#
#                   threegram_turkish  \
# 0      merhametli olan Allah adıyla
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 78242                           NaN
# 78243                           NaN
# 78244                           NaN
# 78245                           NaN
# 78246                           NaN
#
#                                         threegram_urdu  \
# 0      اللہ کے نام سے جو سب سے زیادہ رحم کرنے والا ہے۔
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 78242                                              NaN
# 78243                                              NaN
# 78244                                              NaN
# 78245                                              NaN
# 78246                                              NaN
#
#                     threegram_hindi  \
# 0      अल्लाह के नाम पर, सबसे दयालु
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 78242                           NaN
# 78243                           NaN
# 78244                           NaN
# 78245                           NaN
# 78246                           NaN
#
#                                  threegram_indonesian  \
# 0      dengan menyebut nama ALLAH yang maha penyayang
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 78242                                             NaN
# 78243                                             NaN
# 78244                                             NaN
# 78245                                             NaN
# 78246                                             NaN
#
#                 threegram_bangla          threegram_russian
# 0      পরম করুণাময় আল্লাহর নামে  во имя АЛЛАХА Милостивого
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 78242                        NaN                        NaN
# 78243                        NaN                        NaN
# 78244                        NaN                        NaN
# 78245                        NaN                        NaN
# 78246                        NaN                        NaN
#
# [78247 rows x 8 columns]

# %%
df_master_threegram_count = df_master_threegram_data["threegram_string"].value_counts(ascending=False).reset_index()
df_master_threegram_count.rename(columns={"index":"threegram_string", "threegram_string":"threegram_string_frequency"}, inplace=True)
df_master_threegram_count
# Out:
#       threegram_string  threegram_string_frequency
# 0      بسم الله الرحمن                         114
# 1        يا أيها الذين                          92
# 2     أيها الذين آمنوا                          89
# 3          من دون الله                          71
# 4           على كل شيء                          52
# ..                 ...                         ...
# 195    الأرض بعد موتها                           8
# 196        إن وعد الله                           8
# 197         إن الله هو                           8
# 198        إلا أن يشاء                           8
# 199  الذين أوتوا العلم                           7
#
# [200 rows x 2 columns]

# %%
df_master_threegram_count_translate_merge = pd.merge(df_master_threegram_count, df_master_threegram_data, how="left", on="threegram_string")
df_master_threegram_count_translate_merge.drop_duplicates(inplace=True)
df_master_threegram_count_translate_merge.reset_index(drop=True, inplace=True)
df_master_threegram_count_translate_merge
# Out:
#       threegram_string  threegram_string_frequency  \
# 0      بسم الله الرحمن                         114
# 1        يا أيها الذين                          92
# 2     أيها الذين آمنوا                          89
# 3          من دون الله                          71
# 4           على كل شيء                          52
# ..                 ...                         ...
# 195    الأرض بعد موتها                           8
# 196        إن وعد الله                           8
# 197         إن الله هو                           8
# 198        إلا أن يشاء                           8
# 199  الذين أوتوا العلم                           7
#
#                             threegram_english             threegram_turkish  \
# 0    in the name of ALLAH, the most mercifull  merhametli olan Allah adıyla
# 1                                   O you who                    Ey sen kim
# 2                           O you who believe                  Ey inananlar
# 3                                 without God                 Tanrı olmadan
# 4                              for everything                   herşey için
# ..                                        ...                           ...
# 195                         earth after death           ölümden sonra dünya
# 196                             God's promise               Tanrı'nın vaadi
# 197                                    God is                         Tanrı
# 198                      except that he wills         onun dilemesi dışında
# 199                  who were given knowledge         kimlere bilgi verildi
#
#                                       threegram_urdu  \
# 0    اللہ کے نام سے جو سب سے زیادہ رحم کرنے والا ہے۔
# 1                                              اے جو
# 2                                     اے ایمان والو!
# 3                                        خدا کے بغیر
# 4                                      ہر چیز کے لئے
# ..                                               ...
# 195                                  موت کے بعد زمین
# 196                                      خدا کا وعدہ
# 197                                           خدا ہے
# 198                           سوائے اس کے کہ وہ چاہے
# 199                           جنہیں علم دیا گیا تھا۔
#
#                   threegram_hindi  \
# 0    अल्लाह के नाम पर, सबसे दयालु
# 1                      हे तुम कौन
# 2       हे तुम जो विश्वास करते हो
# 3                   भगवान के बिना
# 4           प्रत्येक वस्तु के लिए
# ..                            ...
# 195          मृत्यु के बाद पृथ्वी
# 196                 भगवान का वादा
# 197                      भगवान है
# 198     सिवाय इसके कि वह चाहता है
# 199        जिन्हें ज्ञान दिया गया
#
#                                threegram_indonesian  \
# 0    dengan menyebut nama ALLAH yang maha penyayang
# 1                                  Wahai kamu siapa
# 2                    Wahai orang-orang yang beriman
# 3                                       tanpa Tuhan
# 4                                    untuk semuanya
# ..                                              ...
# 195                           bumi setelah kematian
# 196                                     janji tuhan
# 197                                    Tuhan adalah
# 198                         kecuali dia berkehendak
# 199                                yang diberi ilmu
#
#                threegram_bangla          threegram_russian
# 0     পরম করুণাময় আল্লাহর নামে  во имя АЛЛАХА Милостивого
# 1                  হে আপনি যারা                  О ты, кто
# 2                  হে ঈমানদারগণ            О вы, кто верит
# 3                   ঈশ্বর ছাড়া                   без Бога
# 4                 সব কিছুর জন্য                     За все
# ..                          ...                        ...
# 195          মৃত্যুর পরে পৃথিবী         земля после смерти
# 196         ঈশ্বরের প্রতিশ্রুতি              обещание Бога
# 197                  উপাস্য নেই                    Бог это
# 198      ব্যতীত যে সে ইচ্ছা করে   кроме того, что он хочет
# 199  যাদের জ্ঞান দেওয়া হয়েছিল           кому дали знания
#
# [200 rows x 9 columns]

# %%
df_master_threegram_count_translate_merge.to_excel(f"Quran_Threegram_Translate_Frequency.xlsx", index=False)

# %% [markdown]
# #### Copy Move And Delete

# %%
output_file = glob.glob(f"Quran_*.xlsx")
output_file
# Out:
# ['Quran_Word_Translate_All.xlsx',
#  'Quran_Word_Translate_300.xlsx',
#  'Quran_Root_99.xlsx',
#  'Quran_Root_Word_Translate_99.xlsx',
#  'Quran_Root_Word_Translate_All.xlsx',
#  'Quran_Clean_Ayahs_Frequency.xlsx']

# %%
for y in output_file:
    source = y # source directory
    destination = path
    shutil.copy2(source, destination)

# %%
for z in output_file:
    try:
        os.remove(z)
    except:
        pass
