# %% [markdown]
# #### Language Pair Word Equality

# %%
#!pip uninstall googletrans
#import googletrans
#from googletrans import Translator

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize
from pathlib import Path
import shutil

# %%
lang_1 = "German"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian 
lang_2 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

if lang_2 == "English":
    lang_3 = "English (eng)"
elif lang_2 == "Turkish":
    lang_3 = "Turkish (tur)"
elif lang_2 == "German":
    lang_3 = "German (deu)"
elif lang_2 == "French":
    lang_3 = "French (fra)"
elif lang_2 == "Spanish":
    lang_3 = "Spanish (spa)"
elif lang_2 == "Arabic":
    lang_3 = "Arabic (ara)"
elif lang_2 == "Russian":
    lang_3 = "Russian (rus)"
elif lang_2 == "Portuguese":
    lang_3 = "Portuguese (por)"
elif lang_2 == "Dutch":
    lang_3 = "Dutch (nld)"
elif lang_2 == "Italian":
    lang_3 = "Italian (ita)"
else:
    pass

print(f"{lang_1}\n{lang_2}\n{lang_3}")
# Out:
# French
# Turkish
# Turkish (tur)

# %%
#Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
def low_func(x):
    try:
        var_out = x.lower()
    except:
        var_out = x
    return var_out

# %%
df_lang11 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_3.capitalize()}_Etymologeek_Result5.xlsx")
df_lang11
# Out:
#    lang_master term_master    lang_sleeve term_sleeve
# 0       French     guitare        Turkish       gitar
# 1       French       sucre        Turkish       şeker
# 2       French       sucre        Turkish       şükür
# 3       French        rail        Turkish         ray
# 4       French     sourate        Turkish        sure
# ..         ...         ...            ...         ...
# 80      French        jury        Turkish        jüri
# 81      French     yatagan  Turkish (tur)     yatağan
# 82     English      sultan  Turkish (tur)      sultan
# 83      French      sultan  Turkish (tur)      sultan
# 84       Dutch      sultan  Turkish (tur)      sultan
#
# [85 rows x 4 columns]

# %%
df_lang13 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result3.xlsx")
df_lang13 = df_lang13[["lang","term","related_lang","related_term"]]
df_lang13.rename(columns={"lang":"lang_master","term":"term_master","related_lang":"lang_sleeve","related_term":"term_sleeve"}, inplace=True)
df_lang13["term_master"] = df_lang13["term_master"].apply(lambda x: low_func(x))
df_lang13["term_sleeve"] = df_lang13["term_sleeve"].apply(lambda x: low_func(x))
df_lang13
# Out:
#    lang_master term_master lang_sleeve term_sleeve
# 0       French     caracal     Turkish   karakulak
# 1       French        sofa     Turkish        sofa
# 2       French        café     Turkish       kahve
# 3       French      caviar     Turkish      havyar
# 4       French       kebab     Turkish       kebap
# 5       French     muezzin     Turkish     müezzin
# 6       French     minaret     Turkish      minare
# 7       French     houmous     Turkish       humus
# 8       French     baklava     Turkish     baklava
# 9       French        cham     Turkish         han
# 10      French      yaourt     Turkish      yoğurt
# 11      French      chacal     Turkish       çakal
# 12      French    pastrami     Turkish    pastırma
# 13      French    bouzouki     Turkish       bozuk
# 14      French     macramé     Turkish     makreme
# 15      French      laiton     Turkish       altın
# 16      French       gilet     Turkish       yelek
# 17      French      caïque     Turkish       kayık
# 18      French     yatagan     Turkish     yatağan
# 19      French      chicha     Turkish        şişe
# 20      French     loukoum     Turkish       lokum
# 21      French     yogourt     Turkish      yoğurt
# 22      French      moussa     Turkish        musa
# 23      French    narguilé     Turkish     nargile
# 24      French       douve     Turkish       duvar
# 25      French      sérail     Turkish       saray
# 26      French      mourad     Turkish       murat
# 27      French      caraco     Turkish      kerake
# 28      French      caraco     Turkish      keriki
# 29      French   chibouque     Turkish       çubuk
# 30      French       ekrem     Turkish       ekrem
# 31      French     erdogan     Turkish     erdoğan
# 32      French      koumis     Turkish       kımız
# 33      French     mahonne     Turkish      mavuna

# %%
df_lang14 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result4.xlsx")
df_lang14 = df_lang14[["lang","term","related_lang","related_term"]]
df_lang14.rename(columns={"lang":"lang_master","term":"term_master","related_lang":"lang_sleeve","related_term":"term_sleeve"}, inplace=True)
df_lang14["term_master"] = df_lang14["term_master"].apply(lambda x: low_func(x))
df_lang14["term_sleeve"] = df_lang14["term_sleeve"].apply(lambda x: low_func(x))
df_lang14
# Out:
#    lang_master    term_master lang_sleeve term_sleeve
# 0       French      cybercafé     Turkish       kahve
# 1       French        macramé     Turkish     makreme
# 2       French        chanvre     Turkish     kenevir
# 3       French        chanvre     Turkish      kendir
# 4       French         horeca     Turkish       kahve
# 5       French       cannabis     Turkish     kenevir
# 6       French       cannabis     Turkish      kendir
# 7       French            leu     Turkish      arslan
# 8       French        yatagan     Turkish      yatmak
# 9       French        yatagan     Turkish       yatak
# 10      French        yatagan     Turkish       yatay
# 11      French        yogourt     Turkish      yoğurt
# 12      French         laiton     Turkish       altın
# 13      French         bridge     Turkish         bir
# 14      French         bridge     Turkish          üç
# 15      French       kielbasa     Turkish      basmak
# 16      French         caviar     Turkish      havyar
# 17      French          gilet     Turkish       yelek
# 18      French          gilet     Turkish       yelek
# 19      French      cafetière     Turkish       kahve
# 20      French           café     Turkish       kahve
# 21      French        caféier     Turkish       kahve
# 22      French       pastrami     Turkish    pastırma
# 23      French       pastrami     Turkish    bastırma
# 24      French       pastrami     Turkish          et
# 25      French          gyros     Turkish      dönmek
# 26      French           gyro     Turkish      dönmek
# 27      French           chai     Turkish         çay
# 28      French         sérail     Turkish       saray
# 29      French         mourad     Turkish       murat
# 30      French    pousse-café     Turkish       kahve
# 31      French        bogatyr     Turkish     bahadır
# 32      French       caféisme     Turkish       kahve
# 33      French        laquais     Turkish        ulak
# 34      French        théorbe     Turkish       torba
# 35      French        douelle     Turkish       duvar
# 36      French      café-vélo     Turkish       kahve
# 37      French      vélo-café     Turkish       kahve
# 38      French          caoua     Turkish       kahve
# 39      French    chasse-café     Turkish       kahve
# 40      French  caravansérail     Turkish       saray
# 41      French      yaourtier     Turkish      yoğurt
# 42      French        archine     Turkish       arşın
# 43      French       yaourter     Turkish      yoğurt
# 44      French   caféiculture     Turkish       kahve
# 45      French         cahoua     Turkish       kahve
# 46      French         kahoua     Turkish       kahve
# 47      French         cafiot     Turkish       kahve
# 48      French          eqrem     Turkish       ekrem
# 49      French        chichon     Turkish        şişe

# %%
df_lang12 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result2.xlsx")
df_lang12 = df_lang12.loc[:,["lang","term","related_term_id"]]
df_lang12["term"] = df_lang12["term"].apply(lambda x: low_func(x))
df_lang12
# Out:
#         lang            term         related_term_id
# 0     French          parole  uXGtk5g-W8G_TlTxSHImpg
# 1     French        perruque  uXGtk5g-W8G_TlTxSHImpg
# 2     French        palabrer  uXGtk5g-W8G_TlTxSHImpg
# 3     French          parole  JHVmHqAPXEq-YaIbd0B5Jg
# 4     French          parole  JHVmHqAPXEq-YaIbd0B5Jg
# ...      ...             ...                     ...
# 2384  French            résa  7HZVkuTAUSO1BDhS0M97aw
# 2385  French  surréservation  KAz1YJD2U5uarbKRKR7ydg
# 2386  French            résa  KAz1YJD2U5uarbKRKR7ydg
# 2387  French    photopériode  zku5lNmoUeOzsvNE-uJXQw
# 2388  French      périodisme  zku5lNmoUeOzsvNE-uJXQw
#
# [2389 rows x 3 columns]

# %%
df_lang22 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_2.capitalize()}/{lang_2.capitalize()}_And_{lang_1.capitalize()}_Etymologeek_Result2.xlsx")
df_lang22 = df_lang22.loc[:,["lang","term","related_term_id"]]
df_lang22["term"] = df_lang22["term"].apply(lambda x: low_func(x))
df_lang22
# Out:
#         lang         term         related_term_id
# 0    Turkish      palavra  JHVmHqAPXEq-YaIbd0B5Jg
# 1    Turkish      parabol  JHVmHqAPXEq-YaIbd0B5Jg
# 2    Turkish   alternatif  ZSxxztTSVm6V_6rNEGaKhQ
# 3    Turkish          baz  1So0kFpyWh-G9xute2SNTg
# 4    Turkish          baz  tJZMlh3FXjinpfCxRDoq6Q
# ..       ...          ...                     ...
# 930  Turkish    beyzbolcu  tax-N0vEUdihpfdLbAjmow
# 931  Turkish      bariton  v1T5IAAcVEaBDt4h3GSrRA
# 932  Turkish  rezervasyon  7HZVkuTAUSO1BDhS0M97aw
# 933  Turkish  rezervasyon  KAz1YJD2U5uarbKRKR7ydg
# 934  Turkish      periyot  zku5lNmoUeOzsvNE-uJXQw
#
# [935 rows x 3 columns]

# %%
df_same_ety = pd.merge(df_lang12,df_lang22, how="inner", on="related_term_id", suffixes=["_master","_sleeve"])
df_same_ety = df_same_ety[["lang_master","term_master","lang_sleeve","term_sleeve"]]
df_same_ety.drop_duplicates(inplace=True)
df_same_ety
# Out:
#      lang_master       term_master lang_sleeve  term_sleeve
# 0         French            parole     Turkish      palavra
# 1         French            parole     Turkish      parabol
# 4         French            parler     Turkish      palavra
# 5         French            parler     Turkish      parabol
# 6         French          perruque     Turkish      palavra
# ...          ...               ...         ...          ...
# 2135      French        lévitation     Turkish   levitasyon
# 2136      French  mélancoliquement     Turkish   melankolik
# 2137      French  antimélancolique     Turkish   melankolik
# 2139      French    surréservation     Turkish  rezervasyon
# 2140      French              résa     Turkish  rezervasyon
#
# [1559 rows x 4 columns]

# %%
df_ety_concat = pd.concat([df_same_ety,df_lang11,df_lang13,df_lang14], axis=0)
df_ety_concat.drop_duplicates(inplace=True)
df_ety_concat.reset_index(drop=True, inplace=True)
df_ety_concat
# Out:
#      lang_master term_master lang_sleeve term_sleeve
# 0         French      parole     Turkish     palavra
# 1         French      parole     Turkish     parabol
# 2         French      parler     Turkish     palavra
# 3         French      parler     Turkish     parabol
# 4         French    perruque     Turkish     palavra
# ...          ...         ...         ...         ...
# 1688      French      cahoua     Turkish       kahve
# 1689      French      kahoua     Turkish       kahve
# 1690      French      cafiot     Turkish       kahve
# 1691      French       eqrem     Turkish       ekrem
# 1692      French     chichon     Turkish        şişe
#
# [1693 rows x 4 columns]

# %%
df_ety_concat.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_1.capitalize()}/{lang_1.capitalize()}_All_Word_From_{lang_2.capitalize()}_Etymology.xlsx", index=False)

# %%
df_master_unique = pd.DataFrame()
df_master_unique["term_master"] = df_ety_concat["term_master"].unique()
df_master_unique.rename(columns={"term_master":"term"}, inplace=True)
df_master_unique
# Out:
#               term
# 0           parole
# 1           parler
# 2         perruque
# 3              mot
# 4     porte-parole
# ...            ...
# 1363     yaourtier
# 1364       archine
# 1365      yaourter
# 1366         eqrem
# 1367       chichon
#
# [1368 rows x 1 columns]

# %%
df_master_unique.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_1.capitalize()}/{lang_1.capitalize()}_Unique_Word_From_{lang_2.capitalize()}_Etymology.xlsx", index=False)

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_1.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
##df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"term"}, inplace=True)
#df_word

# %%
#df_master_unique_word_merge = pd.merge(df_word,df_master_unique, how="inner", on="term")
#df_master_unique_word_merge.sort_values(by="frequency", inplace=True, ascending=False)
#df_master_unique_word_merge.reset_index(drop=True, inplace=True)
#df_master_unique_word_merge

# %%
#df_master_unique_word_merge = df_master_unique_word_merge.loc[:,["term"]]
#df_master_unique_word_merge.rename(columns={"term":f"{lang_1.lower()}_word"}, inplace=True)
#df_master_unique_word_merge

# %%
#df_master_unique_word_merge.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_1.capitalize()}/{lang_1.capitalize()}_Unique_Word_From_{lang_2.capitalize()}_Etymology.xlsx", index=False)

# %% [markdown]
# #### Read Translate File

# %%
df_pair_translate = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_1.capitalize()}/{lang_1.capitalize()} {lang_2.capitalize()} Language Pair Translate.xlsx")
df_pair_translate
# Out:
#        french_word turkish_word
# 0           parole       kelime
# 1           parler     konuşmak
# 2         perruque        peruk
# 3              mot       kelime
# 4     porte-parole        sözcü
# ...            ...          ...
# 1363     yaourtier        Yogrm
# 1364       archine        arşiv
# 1365      yaourter       yoğurt
# 1366         eqrem        EQREM
# 1367       chichon      chichon
#
# [1368 rows x 2 columns]

# %%
df_pair_translate[f"{lang_2.lower()}_word"] = df_pair_translate[f"{lang_2.lower()}_word"].apply(lambda x: low_func(x))
df_pair_translate
# Out:
#        french_word turkish_word
# 0           parole       kelime
# 1           parler     konuşmak
# 2         perruque        peruk
# 3              mot       kelime
# 4     porte-parole        sözcü
# ...            ...          ...
# 1363     yaourtier        yogrm
# 1364       archine        arşiv
# 1365      yaourter       yoğurt
# 1366         eqrem        eqrem
# 1367       chichon      chichon
#
# [1368 rows x 2 columns]

# %%
df_sleeve_unique = pd.DataFrame()
df_sleeve_unique["term_sleeve"] = df_ety_concat["term_sleeve"].unique()
df_sleeve_unique.rename(columns={"term_sleeve":f"{lang_2.lower()}_word"}, inplace=True)
df_sleeve_unique[f"{lang_2.lower()}_word"] = df_sleeve_unique[f"{lang_2.lower()}_word"].apply(lambda x: low_func(x))
df_sleeve_unique.drop_duplicates(inplace=True)
df_sleeve_unique.reset_index(drop=True, inplace=True)
df_sleeve_unique
# Out:
#     turkish_word
# 0        palavra
# 1        parabol
# 2     alternatif
# 3            baz
# 4            çek
# ..           ...
# 591          çay
# 592      bahadır
# 593         ulak
# 594        torba
# 595        arşın
#
# [596 rows x 1 columns]

# %%
df_translate_sleeve_merge = pd.merge(df_pair_translate,df_sleeve_unique,how="inner",on=f"{lang_2.lower()}_word")
df_translate_sleeve_merge.rename(columns={f"{lang_1.lower()}_word":"dict_entry_main"}, inplace=True)
df_translate_sleeve_merge
# Out:
#     dict_entry_main turkish_word
# 0          perruque        peruk
# 1           palabre      palavra
# 2           parloir        salon
# 3             salon        salon
# 4         paraboler      parabol
# ..              ...          ...
# 251        yaourter       yoğurt
# 252        pastrami     pastırma
# 253           ekrem        ekrem
# 254         erdogan      erdoğan
# 255         chanvre      kenevir
#
# [256 rows x 2 columns]

# %%
df_translate_sleeve_merge.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Concat_Result1.xlsx", index=False)

# %%
#df_translate_sleeve_merge.to_excel(f"{lang_1.capitalize()}_And_{lang_3.capitalize()}_Etymologeek_Result_All.xlsx", index=False)
