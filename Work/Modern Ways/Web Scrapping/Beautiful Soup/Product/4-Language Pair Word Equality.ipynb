# %% [markdown]
# #### Language Pair Word Equality

# %%
#!pip uninstall googletrans

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize
#import googletrans
#from googletrans import Translator

# %%
lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian 
lang_2 = "Italian"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

if lang_2 == "English":
    lang_3 = "English (eng)"
elif lang_2 == "Turkish":
    lang_3 = "Turkish (tur)"
elif lang_2 == "German":
    lang_3 = "German (deu)"
elif lang_2 == "French":
    lang_3 = "French (fra)"
elif lang_2 == "Spanish":
    lang_3 = "Spanish (spa)"
elif lang_2 == "Arabic":
    lang_3 = "Arabic (ara)"
elif lang_2 == "Russian":
    lang_3 = "Russian (rus)"
elif lang_2 == "Portuguese":
    lang_3 = "Portuguese (por)"
elif lang_2 == "Dutch":
    lang_3 = "Dutch (nld)"
elif lang_2 == "Italian":
    lang_3 = "Italian (ita)"
else:
    pass

print(f"{lang_1}\n{lang_2}\n{lang_3}")
# Out:
# Turkish
# Italian
# Italian (ita)

# %%
df_lang11 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_3.capitalize()}_Etymologeek_Result1.xlsx")
df_lang11 = df_lang11.loc[:,["language_main","dict_entry_main","language","dict_entry"]]
df_lang11.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master","language":"lang_sleeve","dict_entry":"term_sleeve"}, inplace=True)
df_lang11["term_master"] = df_lang11["term_master"].apply(lambda x: x.lower())
df_lang11["term_sleeve"] = df_lang11["term_sleeve"].apply(lambda x: x.lower())
df_lang11
# Out:
#    lang_master   term_master    lang_sleeve term_sleeve
# 0      Turkish         polis  Italian (ita)     polizia
# 1      Turkish        kaptan  Italian (ita)     capitan
# 2      Turkish          bira  Italian (ita)       birra
# 3      Turkish          grup  Italian (ita)      groppo
# 4      Turkish         banka  Italian (ita)       banca
# 5      Turkish         çinko  Italian (ita)       zinco
# 6      Turkish          onur  Italian (ita)       onore
# 7      Turkish         banyo  Italian (ita)       bagno
# 8      Turkish       fırtına  Italian (ita)     fortuna
# 9      Turkish         bilet  Italian (ita)   biglietto
# 10     Turkish           duş  Italian (ita)      doccia
# 11     Turkish        makine  Italian (ita)    macchina
# 12     Turkish       sigorta  Italian (ita)     sicurtà
# 13     Turkish      çikolata  Italian (ita)  cioccolata
# 14     Turkish        gazete  Italian (ita)      gazeta
# 15     Turkish          moda  Italian (ita)        moda
# 16     Turkish      politika  Italian (ita)    politica
# 17     Turkish        korsan  Italian (ita)     corsaro
# 18     Turkish          kasa  Italian (ita)       cassa
# 19     Turkish        düzine  Italian (ita)     dozzina
# 20     Turkish      pantolon  Italian (ita)   pantalone
# 21     Turkish      kamuflaj  Italian (ita)         ca-
# 22     Turkish       tiyatro  Italian (ita)      teatro
# 23     Turkish       senaryo  Italian (ita)    scenario
# 24     Turkish       palyaço  Italian (ita)      paglia
# 25     Turkish         roket  Italian (ita)        ruca
# 26     Turkish         mafya  Italian (ita)       mafia
# 27     Turkish  mafya babası  Italian (ita)       mafia
# 28     Turkish       kariyer  Italian (ita)    carriera
# 29     Turkish        antika  Italian (ita)      antico
# 30     Turkish        konser  Italian (ita)    concerto
# 31     Turkish       madalya  Italian (ita)    medaglia
# 32     Turkish        salata  Italian (ita)    insalare
# 33     Turkish        balina  Italian (ita)      balena
# 34     Turkish       fabrika  Italian (ita)    fabbrica
# 35     Turkish       makarna  Italian (ita)     maccare
# 36     Turkish         balon  Italian (ita)       balla
# 37     Turkish          kare  Italian (ita)    quadrato
# 38     Turkish      protesto  Italian (ita)  protestare
# 39     Turkish        fatura  Italian (ita)     fattura
# 40     Turkish         firma  Italian (ita)     firmare
# 41     Turkish         salon  Italian (ita)        sala
# 42     Turkish         conta  Italian (ita)      giunta
# 43     Turkish         borda  Italian (ita)       bordo
# 44     Turkish        makina  Italian (ita)    macchina
# 45     Turkish        kabine  Italian (ita)   gabinetto
# 46     Turkish          loca  Italian (ita)      loggia
# 47     Turkish          mayo  Italian (ita)      maglia
# 48     Turkish       entrika  Italian (ita)   intricare

# %%
df_lang13 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result3.xlsx")
df_lang13 = df_lang13[["lang","term","related_lang","related_term"]]
df_lang13.rename(columns={"lang":"lang_master","term":"term_master","related_lang":"lang_sleeve","related_term":"term_sleeve"}, inplace=True)
df_lang13["term_master"] = df_lang13["term_master"].apply(lambda x: x.lower())
df_lang13["term_sleeve"] = df_lang13["term_sleeve"].apply(lambda x: x.lower())
df_lang13
# Out:
#     lang_master term_master lang_sleeve term_sleeve
# 0       Turkish       zebra     Italian       zebra
# 1       Turkish        papa     Italian        papa
# 2       Turkish        lira     Italian        lira
# 3       Turkish      napoli     Italian      napoli
# 4       Turkish        tema     Italian        tema
# ..          ...         ...         ...         ...
# 132     Turkish   bocalamak     Italian      poggia
# 133     Turkish      sinyor     Italian      signor
# 134     Turkish     kasiyer     Italian    cassiere
# 135     Turkish     bilanço     Italian    bilancio
# 136     Turkish       balya     Italian       balla
#
# [137 rows x 4 columns]

# %%
df_lang14 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result4.xlsx")
df_lang14 = df_lang14[["lang","term","related_lang","related_term"]]
df_lang14.rename(columns={"lang":"lang_master","term":"term_master","related_lang":"lang_sleeve","related_term":"term_sleeve"}, inplace=True)
df_lang14["term_master"] = df_lang14["term_master"].apply(lambda x: x.lower())
df_lang14["term_sleeve"] = df_lang14["term_sleeve"].apply(lambda x: x.lower())
df_lang14
# Out:
#     lang_master term_master lang_sleeve term_sleeve
# 0       Turkish   tornavida     Italian        vite
# 1       Turkish      baston     Italian     bastone
# 2       Turkish        sone     Italian     sonetto
# 3       Turkish      kambur     Italian    cambiare
# 4       Turkish       rumen     Italian      rumeno
# ..          ...         ...         ...         ...
# 145     Turkish     bilanço     Italian    bilancio
# 146     Turkish   trambolin     Italian  trampolino
# 147     Turkish       izole     Italian     isolato
# 148     Turkish       izole     Italian     isolare
# 149     Turkish   bandıralı     Italian    bandiera
#
# [150 rows x 4 columns]

# %%
df_lang12 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result2.xlsx")
df_lang12 = df_lang12.loc[:,["lang","term","related_term_id"]]
df_lang12["term"] = df_lang12["term"].apply(lambda x: x.lower())
df_lang12
# Out:
#         lang        term         related_term_id
# 0    Turkish     palavra  JHVmHqAPXEq-YaIbd0B5Jg
# 1    Turkish     parabol  JHVmHqAPXEq-YaIbd0B5Jg
# 2    Turkish  alternatif  ZSxxztTSVm6V_6rNEGaKhQ
# 3    Turkish         çek  crVVT9teU8aDKQjnHlsDQw
# 4    Turkish         çek  aoMDbgfMWbWWazj9mWPdYw
# ..       ...         ...                     ...
# 498  Turkish     tersane  WtjxLYdoUlOdj3bGWeaQnQ
# 499  Turkish      bikini  oqwJif0MXBegenMOx5b9bw
# 500  Turkish      bikini  GNTJbzNsW_CAUT05gGD_7g
# 501  Turkish      abluka  GaufsuTTXf2knEtg2iedoA
# 502  Turkish      düzine  XmO25xwYV_-ClZwkEkE-0A
#
# [503 rows x 3 columns]

# %%
df_lang22 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_2.capitalize()}/{lang_2.capitalize()}_And_{lang_1.capitalize()}_Etymologeek_Result2.xlsx")
df_lang22 = df_lang22.loc[:,["lang","term","related_term_id"]]
df_lang22["term"] = df_lang22["term"].apply(lambda x: x.lower())
df_lang22
# Out:
#          lang         term         related_term_id
# 0     Italian   parlamento  uXGtk5g-W8G_TlTxSHImpg
# 1     Italian    parlabile  uXGtk5g-W8G_TlTxSHImpg
# 2     Italian     sparlare  uXGtk5g-W8G_TlTxSHImpg
# 3     Italian  straparlare  uXGtk5g-W8G_TlTxSHImpg
# 4     Italian   parolaccia  JHVmHqAPXEq-YaIbd0B5Jg
# ...       ...          ...                     ...
# 2160  Italian       bikini  GNTJbzNsW_CAUT05gGD_7g
# 2161  Italian    anticrisi  tteyoQ6GUpKst94SvVVRUA
# 2162  Italian     precrisi  tteyoQ6GUpKst94SvVVRUA
# 2163  Italian       civita  h8LKnZUkUkinIpCMnKKSHw
# 2164  Italian    dozzinale  XmO25xwYV_-ClZwkEkE-0A
#
# [2165 rows x 3 columns]

# %%
df_same_ety = pd.merge(df_lang12,df_lang22, how="inner", on="related_term_id", suffixes=["_master","_sleeve"])
df_same_ety.drop_duplicates(inplace=True)
df_same_ety = df_same_ety[["lang_master","term_master","lang_sleeve","term_sleeve"]]
df_same_ety
# Out:
#      lang_master term_master lang_sleeve term_sleeve
# 0        Turkish     palavra     Italian  parolaccia
# 1        Turkish     palavra     Italian    parolina
# 2        Turkish     palavra     Italian    parabola
# 3        Turkish     palavra     Italian      parola
# 4        Turkish     palavra     Italian  parlamento
# ...          ...         ...         ...         ...
# 1508     Turkish     mareşal     Italian  maniscalco
# 1509     Turkish        staj     Italian       stage
# 1510     Turkish      bikini     Italian      bikini
# 1511     Turkish      bikini     Italian      bikini
# 1512     Turkish      düzine     Italian   dozzinale
#
# [1513 rows x 4 columns]

# %%
df_ety_concat = pd.concat([df_same_ety,df_lang11,df_lang13,df_lang14], axis=0)
df_ety_concat.drop_duplicates(inplace=True)
df_ety_concat.reset_index(drop=True, inplace=True)
df_ety_concat
# Out:
#      lang_master term_master lang_sleeve  term_sleeve
# 0        Turkish     palavra     Italian   parolaccia
# 1        Turkish     palavra     Italian     parolina
# 2        Turkish     palavra     Italian     parabola
# 3        Turkish     palavra     Italian       parola
# 4        Turkish     palavra     Italian   parlamento
# ...          ...         ...         ...          ...
# 1459     Turkish     portföy     Italian  portafoglio
# 1460     Turkish       kurye     Italian     corriere
# 1461     Turkish       izole     Italian      isolato
# 1462     Turkish       izole     Italian      isolare
# 1463     Turkish   bandıralı     Italian     bandiera
#
# [1464 rows x 4 columns]

# %%
df_master_unique = pd.DataFrame()
df_master_unique["term_master"] = df_ety_concat["term_master"].unique()
df_master_unique.rename(columns={"term_master":"term"}, inplace=True)
df_master_unique
# Out:
#            term
# 0       palavra
# 1       parabol
# 2    alternatif
# 3         sıfır
# 4     sıfırıncı
# ..          ...
# 380    alabanda
# 381     portföy
# 382       kurye
# 383       izole
# 384   bandıralı
#
# [385 rows x 1 columns]

# %%
df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_1.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
df_word.rename(columns={"word":"term"}, inplace=True)
df_word
# Out:
#                term  frequency
# 0               bir   18835735
# 1            fikret   12101580
# 2                bu   11062659
# 3                ne    8025880
# 4                ve    7766036
# ...             ...        ...
# 39995    ekipmanlar        974
# 39996     şanslılar        974
# 39997     aksanıyla        974
# 39998  yargılanacak        974
# 39999     tepkisini        974
#
# [40000 rows x 2 columns]

# %%
df_master_unique_word_merge = pd.merge(df_word,df_master_unique, how="inner", on="term")
df_master_unique_word_merge.sort_values(by="frequency", inplace=True, ascending=False)
df_master_unique_word_merge.reset_index(drop=True, inplace=True)
df_master_unique_word_merge
# Out:
#           term  frequency
# 0      kontrol     272328
# 1        polis     247969
# 2      telefon     134485
# 3       milyon     118351
# 4       kaptan     112895
# ..         ...        ...
# 265    fırıncı       1058
# 266  karikatür       1021
# 267   patlıcan       1016
# 268       düet        994
# 269   versiyon        984
#
# [270 rows x 2 columns]

# %%
df_master_unique_word_merge = df_master_unique_word_merge.loc[:,["term"]]
df_master_unique_word_merge.rename(columns={"term":f"{lang_1.lower()}_word"}, inplace=True)
df_master_unique_word_merge
# Out:
#     turkish_word
# 0        kontrol
# 1          polis
# 2        telefon
# 3         milyon
# 4         kaptan
# ..           ...
# 265      fırıncı
# 266    karikatür
# 267     patlıcan
# 268         düet
# 269     versiyon
#
# [270 rows x 1 columns]

# %%
df_master_unique_word_merge.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_1.capitalize()}/{lang_1.capitalize()}_Unique_Word_From_{lang_2.capitalize()}_Etymology.xlsx", index=False)

# %% [markdown]
# #### Read Translate File

# %%
df_pair_translate = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_1.capitalize()}/{lang_1.capitalize()} {lang_2.capitalize()} Language Pair Translate.xlsx")
df_pair_translate[f"{lang_2.lower()}_word"] = df_pair_translate[f"{lang_2.lower()}_word"].apply(lambda x: x.lower())
df_pair_translate
# Out:
#     turkish_word      italian_word
# 0        kontrol         controllo
# 1          polis  polizia stradale
# 2        telefon          telefono
# 3         milyon           milione
# 4         kaptan          capitano
# ..           ...               ...
# 265      fırıncı        panettiere
# 266    karikatür   cartone animato
# 267     patlıcan         melanzana
# 268         düet            duetto
# 269     versiyon          versione
#
# [270 rows x 2 columns]

# %%
df_sleeve_unique = pd.DataFrame()
df_sleeve_unique["term_sleeve"] = df_ety_concat["term_sleeve"].unique()
df_sleeve_unique.rename(columns={"term_sleeve":f"{lang_2.lower()}_word"}, inplace=True)
df_sleeve_unique[f"{lang_2.lower()}_word"] = df_sleeve_unique[f"{lang_2.lower()}_word"].apply(lambda x: x.lower())
df_sleeve_unique.drop_duplicates(inplace=True)
df_sleeve_unique.reset_index(drop=True, inplace=True)
df_sleeve_unique
# Out:
#      italian_word
# 0      parolaccia
# 1        parolina
# 2        parabola
# 3          parola
# 4      parlamento
# ...           ...
# 1103        banda
# 1104  portafoglio
# 1105     corriere
# 1106      isolato
# 1107      isolare
#
# [1108 rows x 1 columns]

# %%
df_translate_sleeve_merge = pd.merge(df_pair_translate,df_sleeve_unique,how="inner",on=f"{lang_2.lower()}_word")
df_translate_sleeve_merge.rename(columns={f"{lang_1.lower()}_word":"dict_entry_main"})
# Out:
#     dict_entry_main italian_word
# 0           kontrol    controllo
# 1               çek    controllo
# 2           telefon     telefono
# 3            milyon      milione
# 4              ajan       agente
# ..              ...          ...
# 139         karamel    caramello
# 140         stadyum       stadio
# 141            klip         clip
# 142        patlıcan    melanzana
# 143            düet       duetto
#
# [144 rows x 2 columns]

# %%
df_translate_sleeve_merge.to_excel(f"{lang_1.capitalize()}_{lang_3.capitalize()}_Etymologeek_Result_All.xlsx", index=False)

# %%
from googletrans import Translator

# %%
translator = Translator()

# %%
result = translator.translate('Mitä sinä teet')

# %%
print(googletrans.LANGUAGES)
