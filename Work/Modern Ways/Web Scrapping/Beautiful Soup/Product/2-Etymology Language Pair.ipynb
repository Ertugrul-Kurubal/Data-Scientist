# %% [markdown]
# ### Etymology Language Pair

# %%
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### All Etymology File Concat

# %%
all_etymologeek_file = glob.glob("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/*/*_Etymologeek_Main_And_Additional_Result.xlsx")
all_etymologeek_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Turkish/Turkish_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Dutch/Dutch_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Portuguese/Portuguese_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/English/English_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/German/German_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Spanish/Spanish_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/French/French_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Italian/Italian_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Arabic/Arabic_Etymologeek_Main_And_Additional_Result.xlsx']

# %%
df_etymologeek_all = pd.DataFrame()
for i in all_etymologeek_file:
    df_var = pd.read_excel(f"{i}")
    df_etymologeek_all = pd.concat([df_etymologeek_all, df_var], axis=0)
df_etymologeek_all.drop_duplicates(inplace=True)
df_etymologeek_all.reset_index(drop=True, inplace=True)
df_etymologeek_all
# Out:
#        search_word dict_entry_main   language_main  \
# 0              bir             bir   Crimean Tatar
# 1              bir             bir   Crimean Tatar
# 2              bir             bir  Middle English
# 3              bir             bir  Middle English
# 4              bir             bir  Middle English
# ...            ...             ...             ...
# 668525        إلين           إلينا          Arabic
# 668526       مستقر           مستقر          Arabic
# 668527       مستقر           مستقر          Arabic
# 668528        صيني           صينية          Arabic
# 668529        صيني           صينية          Arabic
#
#                                           definition_main       dict_entry  \
# 0                (Numeral) (cardinal) one.(cardinal) one.             *bīr
# 1                (Numeral) (cardinal) one.(cardinal) one.              bir
# 2       (Noun) A charge on an account.. A strong or fa...           *buriz
# 3       (Noun) A charge on an account.. A strong or fa...        *bʰrewh₁-
# 4       (Noun) A charge on an account.. A strong or fa...           *buriz
# ...                                                   ...              ...
# 668525                              (Adverb) To us.To us.            إلينا
# 668526  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668528  (Noun) (usually definite) Chinese language.(us...  لُغَة صِينِيَّة
# 668529  (Noun) (usually definite) Chinese language.(us...            صينية
#
#                              language  \
# 0              Proto-Turkic (trk-pro)
# 1                 Crimean Tatar (crh)
# 2            Proto-Germanic (gem-pro)
# 3       Proto-Indo-European (ine-pro)
# 4            Proto-Germanic (gem-pro)
# ...                               ...
# 668525                   Arabic (ara)
# 668526                         Arabic
# 668527                         Arabic
# 668528                   Arabic (ara)
# 668529                   Arabic (ara)
#
#                                                definition
# 0                                                    One.
# 1                                         (cardinal) one.
# 2                                    Male offspring; son.
# 3                                                     NaN
# 4                                        Elevation; hill.
# ...                                                   ...
# 668525                                             To us.
# 668526  (Adjective) Confessing. Firm, solid, stable. F...
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...
# 668528                                                NaN
# 668529               (usually definite) Chinese language.
#
# [668530 rows x 7 columns]

# %%
#df_etymologeek_all.to_excel("All_Etymology_Language_Pair_Result.xlsx", index=False)

# %% [markdown]
# #### Read Etymologeek All Data

# %%
df_etymologeek_all = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/All_Etymology_Language_Pair_Result.xlsx")
df_etymologeek_all
# Out:
#        search_word dict_entry_main   language_main  \
# 0              bir             bir   Crimean Tatar
# 1              bir             bir   Crimean Tatar
# 2              bir             bir  Middle English
# 3              bir             bir  Middle English
# 4              bir             bir  Middle English
# ...            ...             ...             ...
# 668525        إلين           إلينا          Arabic
# 668526       مستقر           مستقر          Arabic
# 668527       مستقر           مستقر          Arabic
# 668528        صيني           صينية          Arabic
# 668529        صيني           صينية          Arabic
#
#                                           definition_main       dict_entry  \
# 0                (Numeral) (cardinal) one.(cardinal) one.             *bīr
# 1                (Numeral) (cardinal) one.(cardinal) one.              bir
# 2       (Noun) A charge on an account.. A strong or fa...           *buriz
# 3       (Noun) A charge on an account.. A strong or fa...        *bʰrewh₁-
# 4       (Noun) A charge on an account.. A strong or fa...           *buriz
# ...                                                   ...              ...
# 668525                              (Adverb) To us.To us.            إلينا
# 668526  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668528  (Noun) (usually definite) Chinese language.(us...  لُغَة صِينِيَّة
# 668529  (Noun) (usually definite) Chinese language.(us...            صينية
#
#                              language  \
# 0              Proto-Turkic (trk-pro)
# 1                 Crimean Tatar (crh)
# 2            Proto-Germanic (gem-pro)
# 3       Proto-Indo-European (ine-pro)
# 4            Proto-Germanic (gem-pro)
# ...                               ...
# 668525                   Arabic (ara)
# 668526                         Arabic
# 668527                         Arabic
# 668528                   Arabic (ara)
# 668529                   Arabic (ara)
#
#                                                definition
# 0                                                    One.
# 1                                         (cardinal) one.
# 2                                    Male offspring; son.
# 3                                                     NaN
# 4                                        Elevation; hill.
# ...                                                   ...
# 668525                                             To us.
# 668526  (Adjective) Confessing. Firm, solid, stable. F...
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...
# 668528                                                NaN
# 668529               (usually definite) Chinese language.
#
# [668530 rows x 7 columns]

# %%
#df_etymologeek_all["language_main"].unique()

# %%
#df_etymologeek_all["language"].unique()

# %%
lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Dutch (nld)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)

# %%
df_lang_pair1 = df_etymologeek_all[(df_etymologeek_all["language_main"] == f"{lang_1.capitalize()}") & (df_etymologeek_all["language"] == f"{lang_2.capitalize()}")]
df_lang_pair1
# Out:
#        search_word dict_entry_main language_main  \
# 8311          şans            şans       Turkish
# 487876        loca            loca       Turkish
#
#                                           definition_main dict_entry  \
# 8311                  (Noun) Fortune. Luck.Fortune. Luck.       dice
# 487876  (Noun) (masonic) lodge. Box (in theaters).(mas...     laubja
#
#            language definition
# 8311    Dutch (nld)        NaN
# 487876  Dutch (nld)        NaN

# %%
df_lang_pair1["dict_entry_main"] = df_lang_pair1["dict_entry_main"].apply(lambda x: x.lower())
df_lang_pair1["dict_entry"] = df_lang_pair1["dict_entry"].apply(lambda x: x.lower())
df_lang_pair1 = df_lang_pair1.drop_duplicates(subset="dict_entry_main")
df_lang_pair1.reset_index(drop=True, inplace=True)
df_lang_pair1
# Out:
# <ipython-input-10-7b683e1fb3ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair1["dict_entry_main"] = df_lang_pair1["dict_entry_main"].apply(lambda x: x.lower())
# <ipython-input-10-7b683e1fb3ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair1["dict_entry"] = df_lang_pair1["dict_entry"].apply(lambda x: x.lower())
#   search_word dict_entry_main language_main  \
# 0        şans            şans       Turkish
# 1        loca            loca       Turkish
#
#                                      definition_main dict_entry     language  \
# 0                (Noun) Fortune. Luck.Fortune. Luck.       dice  Dutch (nld)
# 1  (Noun) (masonic) lodge. Box (in theaters).(mas...     laubja  Dutch (nld)
#
#   definition
# 0        NaN
# 1        NaN

# %%
#df_lang_pair1.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result1.xlsx", index=False)  # {lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result_All.xlsx

# %% [markdown]
# #### Read Github Cross Data

# %% [markdown]
# ##### Part 1

# %%
df_github_cross = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_cross_check2.csv")
df_github_cross
# Out:
#                         term_id     lang      term                    reltype  \
# 0        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra             inherited_from
# 1        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 2        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 3        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 4        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# ...                         ...      ...       ...                        ...
# 8854119  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa             inherited_from
# 8854120  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854121  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854122  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854123  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa                 cognate_of
#
#                 related_term_id    related_lang related_term
# 0        9w90qvZDUH-2OHPVZEGJSQ  Middle english       parlai
# 1        Uy6v5wWuW6KGH4aTqGWnmA      Old french       parler
# 2        HY24XyCcUZCYSa1Q6y2kPA      Late latin     parabolō
# 3        uXGtk5g-W8G_TlTxSHImpg           Latin     parabola
# 4        JHVmHqAPXEq-YaIbd0B5Jg   Ancient greek     παραβολή
# ...                         ...             ...          ...
# 8854119  TUnsO83vXXC1Us5rJgGyUg    Vulgar latin    *pittitus
# 8854120  oUnwLLsHVymmwwiRXgrRow           Latin     pitinnus
# 8854121  IGRZaHQ-VU-vpxMjdxSTlA           Latin      pitulus
# 8854122  MDRrWciZWXGEj1KR9MUWtg           Latin     piccinus
# 8854123  SUJISOECWc6fDH00I_cTRQ          French        petit
#
# [8854124 rows x 7 columns]

# %%
lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Dutch"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang1 = df_github_cross[(df_github_cross["lang"] == f"{lang_1.capitalize()}")] 
df_lang1
# Out:
#                         term_id     lang       term  \
# 110      caAhC_cAXrKZU9rCcPAaPw  Turkish        göl
# 817      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 818      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 819      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 1345     5bVUD53NVEWYY0QAetV7iA  Turkish        net
# ...                         ...      ...        ...
# 8853155  nxRVOzFvUzS4X7r165GWcw  Turkish  ordinatör
# 8853651  pl-cU0pBVda2_BuEjBmtZw  Turkish     virman
# 8853652  pl-cU0pBVda2_BuEjBmtZw  Turkish     virman
# 8853831  fc8biERQXFicQGtfESBJQQ  Turkish   angajman
# 8853832  fc8biERQXFicQGtfESBJQQ  Turkish   angajman
#
#                            reltype         related_term_id  related_lang  \
# 110                 inherited_from  T6Wxr8YPVWK47B34DsG6KA  Proto-turkic
# 817                 inherited_from  nlVlgr5dUjas0_4GqplLJQ  Proto-turkic
# 818                 inherited_from  5g1DdR5OUPOxiQxCVcGW6A  Proto-turkic
# 819                 inherited_from  6KC332NQU7Sx9sFKEv6QdQ  Proto-turkic
# 1345                inherited_from  Ru1rzGVDWpi2rTYD9-XJWQ    Old french
# ...                            ...                     ...           ...
# 8853155  etymologically_related_to  tPEd3hNNXqeBt17YkY3I2Q        French
# 8853651       has_prefix_with_root  9CJvE6k0WJmKvcWZQmQjxw        French
# 8853652                 has_suffix  8YtrMi5VXlSpZVOupUTcWg        French
# 8853831       has_prefix_with_root  qQY-6sksXJe832mC9wIBqQ        French
# 8853832                 has_suffix  8YtrMi5VXlSpZVOupUTcWg        French
#
#         related_term
# 110             *kȫl
# 817              *ǖn
# 818              *öŋ
# 819              *oŋ
# 1345             net
# ...              ...
# 8853155  calculateur
# 8853651        virer
# 8853652         ment
# 8853831      engager
# 8853832         ment
#
# [27421 rows x 7 columns]

# %%
df_lang2 = df_github_cross[(df_github_cross["lang"] == f"{lang_2.capitalize()}")]
df_lang2["term"] = df_lang2["term"].apply(lambda x: x.lower())
df_lang2.rename(columns={"term":"word"}, inplace=True)
df_lang2
# Out:
# <ipython-input-15-7211f3bc6644>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang2["term"] = df_lang2["term"].apply(lambda x: x.lower())
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                         term_id   lang         word  \
# 1369     D3GcYQukU9m2ysG-lQAnQw  Dutch         pils
# 1370     D3GcYQukU9m2ysG-lQAnQw  Dutch         pils
# 1371     D3GcYQukU9m2ysG-lQAnQw  Dutch         pils
# 1372     D3GcYQukU9m2ysG-lQAnQw  Dutch         pils
# 1443     D3GcYQukU9m2ysG-lQAnQw  Dutch         pils
# ...                         ...    ...          ...
# 8854031  hizIVwJWWOqbH42n1yJCnQ  Dutch  aan de berg
# 8854032  hizIVwJWWOqbH42n1yJCnQ  Dutch  aan de berg
# 8854033  hizIVwJWWOqbH42n1yJCnQ  Dutch  aan de berg
# 8854034  hizIVwJWWOqbH42n1yJCnQ  Dutch  aan de berg
# 8854035  hizIVwJWWOqbH42n1yJCnQ  Dutch  aan de berg
#
#                            reltype         related_term_id  \
# 1369                   clipping_of  pmWg9nHdXkKgOGmsjGnT8w
# 1370     etymologically_related_to  RRFFFKyqWlm4FCP3v3t_aQ
# 1371     etymologically_related_to  UJtoeJ7-V8mBED0YCGXhiA
# 1372     etymologically_related_to  f2HO7kydVT2-uJaeNigWyg
# 1443                     has_affix  UJtoeJ7-V8mBED0YCGXhiA
# ...                            ...                     ...
# 8854031             inherited_from  dT27eZmEV9Sp7acanwBvVA
# 8854032             inherited_from  CqlhJ_TRXNCtZst-zyTbdg
# 8854033             inherited_from  U_l-3UJXVsune11UJv4NRA
# 8854034             inherited_from  Y_1cZjZKVC-CEk_7QNGSYg
# 8854035               derived_from  HENgvdg-Uja_oPTKv0tbWg
#
#                 related_lang related_term
# 1369                  German     Pilsener
# 1370                  German         Bier
# 1371                  German       Pilsen
# 1372                   Czech        Plzeň
# 1443                  German       Pilsen
# ...                      ...          ...
# 8854031         Middle dutch        berch
# 8854032            Old dutch         berg
# 8854033  Proto-west germanic        *berg
# 8854034       Proto-germanic      *bergaz
# 8854035  Proto-indo-european     *bʰerǵʰ-
#
# [295151 rows x 7 columns]

# %%
df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
df_word = df_word.head(40000)
df_word = df_word.loc[:,["word"]]
df_word
# Out:
#                      word
# 0                      ik
# 1                      je
# 2                     het
# 3                      de
# 4                     dat
# ...                   ...
# 39995                bois
# 39996                 ood
# 39997            melaatse
# 39998                poll
# 39999  vredesbesprekingen
#
# [40000 rows x 1 columns]

# %%
df_lang2 = pd.merge(df_lang2,df_word,how="inner",on="word")
df_lang2
# Out:
#                        term_id   lang         word                    reltype  \
# 0       D3GcYQukU9m2ysG-lQAnQw  Dutch         pils                clipping_of
# 1       D3GcYQukU9m2ysG-lQAnQw  Dutch         pils  etymologically_related_to
# 2       D3GcYQukU9m2ysG-lQAnQw  Dutch         pils  etymologically_related_to
# 3       D3GcYQukU9m2ysG-lQAnQw  Dutch         pils  etymologically_related_to
# 4       D3GcYQukU9m2ysG-lQAnQw  Dutch         pils                  has_affix
# ...                        ...    ...          ...                        ...
# 102429  y5kQzqkqX56rcOgUrBgQWw  Dutch  pinautomaat                 cognate_of
# 102430  y5kQzqkqX56rcOgUrBgQWw  Dutch  pinautomaat                 cognate_of
# 102431  y5kQzqkqX56rcOgUrBgQWw  Dutch  pinautomaat                 cognate_of
# 102432  y5kQzqkqX56rcOgUrBgQWw  Dutch  pinautomaat              borrowed_from
# 102433  y5kQzqkqX56rcOgUrBgQWw  Dutch  pinautomaat               derived_from
#
#                related_term_id   related_lang related_term
# 0       pmWg9nHdXkKgOGmsjGnT8w         German     Pilsener
# 1       RRFFFKyqWlm4FCP3v3t_aQ         German         Bier
# 2       UJtoeJ7-V8mBED0YCGXhiA         German       Pilsen
# 3       f2HO7kydVT2-uJaeNigWyg          Czech        Plzeň
# 4       UJtoeJ7-V8mBED0YCGXhiA         German       Pilsen
# ...                        ...            ...          ...
# 102429  EQsVmWjsVT6c8M4sTPdv1A      Norwegian         pinn
# 102430  Oam1tjudWNGyZmAEU5Eh0Q        Swedish        pinne
# 102431  CUnQymJqWG2GWGJmVtScnA      Icelandic        pinni
# 102432  fXZ1iW-EWKykaA1e2Yen5A  Ancient greek    αὐτόματον
# 102433  whdp0SLvVZ2cE_A4nYGntA         French     automate
#
# [102434 rows x 7 columns]

# %%
set_lang1 = set(df_lang1["related_term_id"])
set_lang2= set(df_lang2["related_term_id"])

# %%
df_pair_etymology = pd.DataFrame(set_lang1.intersection(set_lang2),columns=["related_term_id"])
df_pair_etymology
# Out:
#              related_term_id
# 0     whdp0SLvVZ2cE_A4nYGntA
# 1     N0sHMZ_AWvidnI1Dknr4uA
# 2     -Uh_s1NMVOuqQor0OyX2Gg
# 3     NNIFCv43XF23Nlh284VL9Q
# 4     5SamNZpFXS26ZWCWPW8V2Q
# ...                      ...
# 2644  AMHl5YwuXByko14m0190tg
# 2645  Lhesmnh8Uz6w2cVcj5rlBg
# 2646  GWHTSUbFXvqxnY5KHcibzw
# 2647  w47hFNyXVs-IMGTYwLLoOg
# 2648  hTwII-mKU62Pir8eFbm-jA
#
# [2649 rows x 1 columns]

# %%
df_etymology_merge = pd.merge(df_github_cross,df_pair_etymology,how="inner",on="related_term_id")
df_etymology_merge.drop_duplicates(inplace=True)
df_etymology_merge
# Out:
#                        term_id      lang           term         reltype  \
# 0       LHuH1RvcUjWNUTR6QQF8fg   Spanish        palabra    derived_from
# 1       ljccVuPLVnivw8cc3nNYlQ   Italian     parolaccia  inherited_from
# 2       FWrE64OiVqyZhvrUCjx-lw   Italian       parolina  inherited_from
# 3       nna1S--BXFqttVpHavoanQ     Scots         barley    derived_from
# 4       nEVenuUoViaCv4A9BMUvbg    French         Parole  inherited_from
# ...                        ...       ...            ...             ...
# 569398  UtyLR8iFXcKAIDHI_0xKYA    Polish   baseballówka   borrowed_from
# 569399  C77215PVXMOPtyJ1q037rA     Dutch   confederatie    derived_from
# 569400  4NbECfQmVs6GVa9sNVhg6w    Polish   konfederacja    derived_from
# 569401  8zFAy2CoX_6lw8wgfQuraQ  Romanian   confederație    derived_from
# 569402  Fq1bBqQKWM-H5qL880eaLw   Turkish  konfederasyon    derived_from
#
#                related_term_id related_lang   related_term
# 0       uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 1       uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 2       uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 3       uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 4       uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# ...                        ...          ...            ...
# 569398  tax-N0vEUdihpfdLbAjmow      English       baseball
# 569399  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
# 569400  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
# 569401  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
# 569402  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
#
# [569403 rows x 7 columns]

# %%
df_etymology_merge = df_etymology_merge[df_etymology_merge["reltype"] == "derived_from"]
df_etymology_merge
# Out:
#                        term_id      lang           term       reltype  \
# 0       LHuH1RvcUjWNUTR6QQF8fg   Spanish        palabra  derived_from
# 3       nna1S--BXFqttVpHavoanQ     Scots         barley  derived_from
# 7       gT18ll1QWImktohcA4QXGA   Quechua         parlay  derived_from
# 12      iFAzpiGXXxK_cT2ei4qrGQ   Spanish       parlante  derived_from
# 15      Mj7PEIoZX2-NWO7DWg5sFQ    French         parole  derived_from
# ...                        ...       ...            ...           ...
# 569391  dG0awV2aXHCKIvKasRTMAg    Kazakh      бейсболшы  derived_from
# 569399  C77215PVXMOPtyJ1q037rA     Dutch   confederatie  derived_from
# 569400  4NbECfQmVs6GVa9sNVhg6w    Polish   konfederacja  derived_from
# 569401  8zFAy2CoX_6lw8wgfQuraQ  Romanian   confederație  derived_from
# 569402  Fq1bBqQKWM-H5qL880eaLw   Turkish  konfederasyon  derived_from
#
#                related_term_id related_lang   related_term
# 0       uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 3       uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 7       uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 12      uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 15      uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# ...                        ...          ...            ...
# 569391  tax-N0vEUdihpfdLbAjmow      English       baseball
# 569399  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
# 569400  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
# 569401  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
# 569402  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
#
# [131560 rows x 7 columns]

# %%
df_etymology_merge = df_etymology_merge[~df_etymology_merge["related_term"].str.contains(fr"(?:\s|^)\*|\-(?:\s|$)", na=True)]
df_etymology_merge
# Out:
#                        term_id      lang           term       reltype  \
# 0       LHuH1RvcUjWNUTR6QQF8fg   Spanish        palabra  derived_from
# 3       nna1S--BXFqttVpHavoanQ     Scots         barley  derived_from
# 7       gT18ll1QWImktohcA4QXGA   Quechua         parlay  derived_from
# 12      iFAzpiGXXxK_cT2ei4qrGQ   Spanish       parlante  derived_from
# 15      Mj7PEIoZX2-NWO7DWg5sFQ    French         parole  derived_from
# ...                        ...       ...            ...           ...
# 569391  dG0awV2aXHCKIvKasRTMAg    Kazakh      бейсболшы  derived_from
# 569399  C77215PVXMOPtyJ1q037rA     Dutch   confederatie  derived_from
# 569400  4NbECfQmVs6GVa9sNVhg6w    Polish   konfederacja  derived_from
# 569401  8zFAy2CoX_6lw8wgfQuraQ  Romanian   confederație  derived_from
# 569402  Fq1bBqQKWM-H5qL880eaLw   Turkish  konfederasyon  derived_from
#
#                related_term_id related_lang   related_term
# 0       uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 3       uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 7       uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 12      uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# 15      uXGtk5g-W8G_TlTxSHImpg        Latin       parabola
# ...                        ...          ...            ...
# 569391  tax-N0vEUdihpfdLbAjmow      English       baseball
# 569399  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
# 569400  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
# 569401  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
# 569402  f04UyjpBVpyyJJsvWY-cMw   Late latin  confoederatio
#
# [71325 rows x 7 columns]

# %%
df_lang1_word = df_etymology_merge[(df_etymology_merge["lang"]==f"{lang_1.capitalize()}")]
df_lang1_word.drop_duplicates(inplace=True)
df_lang1_word
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                        term_id     lang           term       reltype  \
# 169     yglj90QEWaGcUI2-FXe41Q  Turkish        palavra  derived_from
# 282     QDVQAg50WQymOq6pxRgCYw  Turkish        parabol  derived_from
# 15107   _7Bj6HMdWbCjvChOa6fHnA  Turkish            baz  derived_from
# 15244   _7Bj6HMdWbCjvChOa6fHnA  Turkish            baz  derived_from
# 15456   _7Bj6HMdWbCjvChOa6fHnA  Turkish            baz  derived_from
# ...                        ...      ...            ...           ...
# 568825  2bMIkqQ0WXiOFsfXTpjhYA  Turkish        komando  derived_from
# 568977  PqXxLHqgWIuM95niN1tVtQ  Turkish         bikini  derived_from
# 569119  PqXxLHqgWIuM95niN1tVtQ  Turkish         bikini  derived_from
# 569382  ZND8zvDeUbmTb61x-N4BKQ  Turkish      beyzbolcu  derived_from
# 569402  Fq1bBqQKWM-H5qL880eaLw  Turkish  konfederasyon  derived_from
#
#                related_term_id   related_lang   related_term
# 169     JHVmHqAPXEq-YaIbd0B5Jg  Ancient greek       παραβολή
# 282     JHVmHqAPXEq-YaIbd0B5Jg  Ancient greek       παραβολή
# 15107   1So0kFpyWh-G9xute2SNTg     Old french           base
# 15244   tJZMlh3FXjinpfCxRDoq6Q          Latin          basis
# 15456   MVK-ls9fW8uS2jBlvBiLgA  Ancient greek          βάσις
# ...                        ...            ...            ...
# 568825  4fEwn0tDVj-q6bZYV0j6Hw     Portuguese        comando
# 568977  oqwJif0MXBegenMOx5b9bw    Marshallese        Pikinni
# 569119  GNTJbzNsW_CAUT05gGD_7g         German         Bikini
# 569382  tax-N0vEUdihpfdLbAjmow        English       baseball
# 569402  f04UyjpBVpyyJJsvWY-cMw     Late latin  confoederatio
#
# [575 rows x 7 columns]

# %%
df_lang1_word["term"] = df_lang1_word["term"].apply(lambda x: x.lower())
df_lang1_word["related_term"] = df_lang1_word["related_term"].apply(lambda x: x.lower())
df_lang1_result = df_lang1_word.drop_duplicates(subset="term")
df_lang1_result.reset_index(drop=True, inplace=True)
df_lang1_result
# Out:
# <ipython-input-24-02a36d0f2073>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_word["term"] = df_lang1_word["term"].apply(lambda x: x.lower())
# <ipython-input-24-02a36d0f2073>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_word["related_term"] = df_lang1_word["related_term"].apply(lambda x: x.lower())
#                     term_id     lang           term       reltype  \
# 0    yglj90QEWaGcUI2-FXe41Q  Turkish        palavra  derived_from
# 1    QDVQAg50WQymOq6pxRgCYw  Turkish        parabol  derived_from
# 2    _7Bj6HMdWbCjvChOa6fHnA  Turkish            baz  derived_from
# 3    7uaTXsE8Xf2lN_stc4ygFg  Turkish            çek  derived_from
# 4    v18xwBENVGyuTQtmMeP2ew  Turkish     parasızlık  derived_from
# ..                      ...      ...            ...           ...
# 372  2_7BX2vhX0OdFfWOvGY3aQ  Turkish    i̇stanbullu  derived_from
# 373  0ZMcglYQV-G-THg78ZMxkQ  Turkish       primitif  derived_from
# 374  PqXxLHqgWIuM95niN1tVtQ  Turkish         bikini  derived_from
# 375  ZND8zvDeUbmTb61x-N4BKQ  Turkish      beyzbolcu  derived_from
# 376  Fq1bBqQKWM-H5qL880eaLw  Turkish  konfederasyon  derived_from
#
#             related_term_id     related_lang   related_term
# 0    JHVmHqAPXEq-YaIbd0B5Jg    Ancient greek       παραβολή
# 1    JHVmHqAPXEq-YaIbd0B5Jg    Ancient greek       παραβολή
# 2    1So0kFpyWh-G9xute2SNTg       Old french           base
# 3    7SrzrJtdV2yhdkdGZ8hfyQ       Old french         eschek
# 4    GZt9Azt2Xjehbp6BzQhxRQ          Persian           پاره
# ..                      ...              ...            ...
# 372  LVvnOSxFUyyGr0rTBrB73w  Byzantine greek      τὴν πόλιν
# 373  G9hPkRAwXHSC1cV7AWd9Xg            Latin     primitivus
# 374  oqwJif0MXBegenMOx5b9bw      Marshallese        pikinni
# 375  tax-N0vEUdihpfdLbAjmow          English       baseball
# 376  f04UyjpBVpyyJJsvWY-cMw       Late latin  confoederatio
#
# [377 rows x 7 columns]

# %%
#df_lang1_result.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result2.xlsx", index=False)

# %% [markdown]
# ##### Part 2

# %%
df_github_clean = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_clean.csv")
df_github_clean
# Out:
#                            lang         term        reltype  \
# 0                       English    thesaurus  borrowed_from
# 1                       English    thesaurus   derived_from
# 2                       English    thesaurus   doublet_with
# 3                         Latin    thesaurus   derived_from
# 4                       English  portmanteau       has_root
# ...                         ...          ...            ...
# 3484911                 English        Boell  borrowed_from
# 3484912                 English        Boell  borrowed_from
# 3484913  South Levantine Arabic       بالمية      has_affix
# 3484914  South Levantine Arabic       بالمية      has_affix
# 3484915                 English       Cooler   derived_from
#
#                    related_lang  related_term
# 0                         Latin     thēsaurus
# 1                 Ancient Greek      θησαυρός
# 2                       English      treasure
# 3                 Ancient Greek      θησαυρός
# 4           Proto-Indo-European  *per- (fare)
# ...                         ...           ...
# 3484911                  Danish          Bøll
# 3484912                  German          Böll
# 3484913  South Levantine Arabic            بـ
# 3484914  South Levantine Arabic        الميّة
# 3484915                  German        Kühler
#
# [3484916 rows x 5 columns]

# %%
#lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
#lang_2 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang1_lang2 = df_github_clean[(df_github_clean["lang"] == f"{lang_1.capitalize()}") & (df_github_clean["related_lang"] == f"{lang_2.capitalize()}")]
df_lang1_lang2["term"] = df_lang1_lang2["term"].apply(lambda x: x.lower())
df_lang1_lang2["related_term"] = df_lang1_lang2["related_term"].apply(lambda x: x.lower())
df_lang1_lang2.reset_index(drop=True, inplace=True)
df_lang1_lang2
# Out:
# <ipython-input-28-4ffe8c9e6183>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_lang2["term"] = df_lang1_lang2["term"].apply(lambda x: x.lower())
# <ipython-input-28-4ffe8c9e6183>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_lang2["related_term"] = df_lang1_lang2["related_term"].apply(lambda x: x.lower())
#       lang    term       reltype related_lang related_term
# 0  Turkish   japon  derived_from        Dutch        japan
# 1  Turkish  manken  derived_from        Dutch     manneken

# %%
df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
df_word = df_word.head(40000)
df_word = df_word.loc[:,["word"]]
df_word.rename(columns={"word":"related_term"}, inplace=True)
df_word
# Out:
#              related_term
# 0                      ik
# 1                      je
# 2                     het
# 3                      de
# 4                     dat
# ...                   ...
# 39995                bois
# 39996                 ood
# 39997            melaatse
# 39998                poll
# 39999  vredesbesprekingen
#
# [40000 rows x 1 columns]

# %%
df_lang1_lang2 = pd.merge(df_lang1_lang2,df_word, how="inner", on="related_term")
df_lang1_lang2
# Out:
#       lang   term       reltype related_lang related_term
# 0  Turkish  japon  derived_from        Dutch        japan

# %%
#df_lang1_lang2.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result3.xlsx", index=False)

# %% [markdown]
# ##### Part 3

# %%
df_github_cross = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_cross_check2.csv")
df_github_cross
# Out:
#                         term_id     lang      term                    reltype  \
# 0        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra             inherited_from
# 1        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 2        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 3        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 4        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# ...                         ...      ...       ...                        ...
# 8854119  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa             inherited_from
# 8854120  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854121  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854122  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854123  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa                 cognate_of
#
#                 related_term_id    related_lang related_term
# 0        9w90qvZDUH-2OHPVZEGJSQ  Middle english       parlai
# 1        Uy6v5wWuW6KGH4aTqGWnmA      Old french       parler
# 2        HY24XyCcUZCYSa1Q6y2kPA      Late latin     parabolō
# 3        uXGtk5g-W8G_TlTxSHImpg           Latin     parabola
# 4        JHVmHqAPXEq-YaIbd0B5Jg   Ancient greek     παραβολή
# ...                         ...             ...          ...
# 8854119  TUnsO83vXXC1Us5rJgGyUg    Vulgar latin    *pittitus
# 8854120  oUnwLLsHVymmwwiRXgrRow           Latin     pitinnus
# 8854121  IGRZaHQ-VU-vpxMjdxSTlA           Latin      pitulus
# 8854122  MDRrWciZWXGEj1KR9MUWtg           Latin     piccinus
# 8854123  SUJISOECWc6fDH00I_cTRQ          French        petit
#
# [8854124 rows x 7 columns]

# %%
#lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
#lang_2 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang_pair2 = df_github_cross[(df_github_cross["lang"] == f"{lang_1.capitalize()}") & (df_github_cross["related_lang"] == f"{lang_2.capitalize()}")]
df_lang_pair2
# Out:
#                         term_id     lang   term                    reltype  \
# 1416     5bVUD53NVEWYY0QAetV7iA  Turkish    net                 cognate_of
# 117010   GnagvVL5UyyP2i7qDH6krQ  Turkish    hol                 cognate_of
# 132633   VaPC7LcCWLu7lVE4gMoRow  Turkish   soba                 cognate_of
# 233292   qq2kd4hTXbGWxsQa3aaR6Q  Turkish  start                 cognate_of
# 233302   qq2kd4hTXbGWxsQa3aaR6Q  Turkish  start                 cognate_of
# ...                         ...      ...    ...                        ...
# 7908810  k0RG4VlsVnOrmmXtG-KzDg  Turkish  slayt                 cognate_of
# 7908811  k0RG4VlsVnOrmmXtG-KzDg  Turkish  slayt  etymologically_related_to
# 7925999  B1Qz02lGVVqstH7bsant9w  Turkish    şık                 cognate_of
# 7926000  B1Qz02lGVVqstH7bsant9w  Turkish    şık  etymologically_related_to
# 8171139  FfzaiTXzV0OKAsE4cMT5qA  Turkish  sprey                 cognate_of
#
#                 related_term_id related_lang related_term
# 1416     8AllwxDPWd-5F5FOadvN6g        Dutch          net
# 117010   xRABeifpW22eTk3e25HBmA        Dutch          hal
# 132633   A6IWlhdlVZ-UZvqksU9aXg        Dutch        stoof
# 233292   5ykqchhZWByc9u83yzIPnA        Dutch      storten
# 233302   AaC-I38zVKqujiswsvQAxA        Dutch       staart
# ...                         ...          ...          ...
# 7908810  lgEpEcf8UV-5vvTMBeVMvg        Dutch    slijderen
# 7908811  q7GmhOidWcqDFOOhFH2LwA        Dutch      slijden
# 7925999  mOxcdg5mVfu-tIgC2VqoGA        Dutch    schielijk
# 7926000  xmoruotoVFGjfxvuyBItAA        Dutch     schikken
# 8171139  yoNMlc2kVt6ggnd41xhXvg        Dutch     sproeien
#
# [71 rows x 7 columns]

# %%
df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: x.lower())
df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: x.strip())
df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: x.lower())
df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: x.strip())
# Out:
# <ipython-input-35-1e079416b832>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: x.lower())
# <ipython-input-35-1e079416b832>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: x.strip())
# <ipython-input-35-1e079416b832>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: x.lower())
# <ipython-input-35-1e079416b832>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: x.strip())

# %%
df_lang_pair2 = df_lang_pair2.drop_duplicates(subset="term")
df_lang_pair2.reset_index(drop=True, inplace=True)
df_lang_pair2
# Out:
#                    term_id     lang          term                    reltype  \
# 0   5bVUD53NVEWYY0QAetV7iA  Turkish           net                 cognate_of
# 1   GnagvVL5UyyP2i7qDH6krQ  Turkish           hol                 cognate_of
# 2   VaPC7LcCWLu7lVE4gMoRow  Turkish          soba                 cognate_of
# 3   qq2kd4hTXbGWxsQa3aaR6Q  Turkish         start                 cognate_of
# 4   46ugIwcFXMCCguPndDYa6g  Turkish          boks                 cognate_of
# 5   j5RVDOCnWBCSBurLxpgfCw  Turkish        korvet  etymologically_related_to
# 6   WrmjvMe_XsKG56ZkabPmBg  Turkish           bit                 cognate_of
# 7   v2jBV4HTXm2KuXm2sJCGQw  Turkish         lider                 cognate_of
# 8   9CRYAyGIVE-BMqqw5S3KMg  Turkish          film                 cognate_of
# 9   h68RrckGUgGUMp2CADNhow  Turkish         trend                 cognate_of
# 10  7gpilZjWXJOsKve4GVt0JQ  Turkish          fare                 cognate_of
# 11  bgrRwtB-UWWVtKwOSBoX0g  Turkish         dolar              borrowed_from
# 12  TOGskftoXJKlGFUIf1Z6zA  Turkish        spiker                 cognate_of
# 13  icfiApR1WjiPptUiab0htA  Turkish       birader                 cognate_of
# 14  FdwzoFdmUK63zYOYFLKohQ  Turkish          park                 cognate_of
# 15  dsQ0_jAuV4iircOyeHZx-w  Turkish          pisi               derived_from
# 16  g6xdJnNmUZaeSj-7yEiQbg  Turkish        karpuz                 cognate_of
# 17  2ftpHNtyVWC5mBk14Z0rQA  Turkish         japon              borrowed_from
# 18  lzoyKM1FX4mFiDU2biUr5g  Turkish           gaz               derived_from
# 19  S4QmNyBPVDOruTR8c9_jIQ  Turkish         paket               derived_from
# 20  AOG0aJ6AVcmbRlIgldVC_Q  Turkish       japonca               derived_from
# 21  k1vtsZfpX3eveixglqP_vQ  Turkish           gri                 cognate_of
# 22  b9x1WJkWU6a0Oi0Z6NZWPQ  Turkish           dok              borrowed_from
# 23  rmEcd-cwUrOTGAWr6Q1Vyg  Turkish           gey                 cognate_of
# 24  7uaTXsE8Xf2lN_stc4ygFg  Turkish           çek                 cognate_of
# 25  33ReOcvxVb2HEUNXo55iIQ  Turkish        şablon              borrowed_from
# 26  BpB0PTOZWduxyzTZmRgu-g  Turkish          çene                 cognate_of
# 27  w0umVRLfWqqd2_MjuzhYxQ  Turkish         yarın                 cognate_of
# 28  icXF-bw0XDmPJio9KjVxkQ  Turkish       penguen              borrowed_from
# 29  r4boOTeEWf-J-q9FrtVZsw  Turkish  japon balığı               derived_from
# 30  u85ZDMy-Uce4i1VBd3OTGQ  Turkish         tröst                 cognate_of
# 31  rYOJSc4BXb-262_foaM7dQ  Turkish        manken              borrowed_from
# 32  As6zFsD8VZ-EkZiC_-PZLw  Turkish        sürücü                 cognate_of
# 33  sEy4gtuXWoO-1MYiLTSoNg  Turkish           çip                 cognate_of
# 34  3A9PKi_lWEy3Lnd5iUGxKg  Turkish         revir                 cognate_of
# 35  kLVPRTUvW-mVVMoDXojM-g  Turkish         klişe                 cognate_of
# 36  nVCqcrBJX7me3NmRAwIHiw  Turkish           yat               derived_from
# 37  AYUXPRm7UWK108a4nWJJTg  Turkish           şut                 cognate_of
# 38  iOQAbEy1XqSYOEtyqJ3SMw  Turkish           şov                 cognate_of
# 39  Ihx4oi4KU8-tEzEhAxHlzg  Turkish          burç                 cognate_of
# 40  fkNxSBywVaGKkiPFNEIvAA  Turkish          tayt                 cognate_of
# 41  7szQxpXJVAyjl3G11EYZuA  Turkish       sipariş                 cognate_of
# 42  tjQ9cJHsUTqqJg9PZp1Xhw  Turkish           vay                 cognate_of
# 43  Ar0UCkKLV0uDwIk9F5Buig  Turkish         bütçe                 cognate_of
# 44  1mJ4rTncVTyHSsvq02W7dg  Turkish         mayın                 cognate_of
# 45  mI-Uf1r5U4Cx35rfNJ_nWA  Turkish        isteka                 cognate_of
# 46  Mw1RBi4aVNuJtdy7FZhm-A  Turkish          staj                 cognate_of
# 47  vMlQ7iIFXOaJStzUvXGe0Q  Turkish          tüyo                 cognate_of
# 48  FDwZpAevVCCAoRFX4Pl3yQ  Turkish         dübel                 cognate_of
# 49  Mn8f-iTSW1mLDa8KPLhRNA  Turkish           kez               derived_from
# 50  k0RG4VlsVnOrmmXtG-KzDg  Turkish         slayt                 cognate_of
# 51  B1Qz02lGVVqstH7bsant9w  Turkish           şık                 cognate_of
# 52  FfzaiTXzV0OKAsE4cMT5qA  Turkish         sprey                 cognate_of
#
#            related_term_id related_lang related_term
# 0   8AllwxDPWd-5F5FOadvN6g        Dutch          net
# 1   xRABeifpW22eTk3e25HBmA        Dutch          hal
# 2   A6IWlhdlVZ-UZvqksU9aXg        Dutch        stoof
# 3   5ykqchhZWByc9u83yzIPnA        Dutch      storten
# 4   c3CDZzBfU9eR8ItsVx8y7w        Dutch          bos
# 5   aQZ5CoJIX5Oy0mTLNhE3XA        Dutch         korf
# 6   erSvj9rPUw2sV76iJw1TWw        Dutch          bit
# 7   PZoO_UKZX--MKfwbrKhPMA        Dutch       leider
# 8   d7VF8TQjWiabbUsasz5Y7g        Dutch          vel
# 9   C9B2w3-5XW-27dSZN9g4bA        Dutch        trent
# 10  9Xw4zfI7WPC-rpmdErQIAw        Dutch         muis
# 11  UNKCcmn-Ubu7hhxp55WKUg        Dutch        daler
# 12  jvLmy7DXXvScpjGz8OAfrw        Dutch      spreker
# 13  JEzjrpBqUviWldJocQHGqQ        Dutch      broeder
# 14  thyVPt2bVVmIC2oN7ejI6g        Dutch         perk
# 15  STRcqOVEUl-iXyXv4k2Qkg        Dutch         poes
# 16  dICTv6dQV5CFn5Lo8iraJw        Dutch       herfst
# 17  nUzqisjeUfqvn3ZK4l5hdg        Dutch        japan
# 18  UC1ZrBQOWoKgr4c2WwwTyA        Dutch          gas
# 19  pdTr8gb0WouiLXaemNSOhA        Dutch          pak
# 20  nUzqisjeUfqvn3ZK4l5hdg        Dutch        japan
# 21  co9fNuGjW9K5l_ATaYVCHg        Dutch        grijs
# 22  F_f0Zp_MWfmxKU48aqtvRw        Dutch          dok
# 23  GaIQahNsWwiGLXstPBf_Sg        Dutch         gauw
# 24  0tXQpLsFVr6nXvi4-keTGw        Dutch       schaak
# 25  lf8HpUsKWJK-9tWCyKZw2Q        Dutch   schabbelun
# 26  4HrGRxPEVCqKbHfG_fHolA        Dutch          kin
# 27  KEzHlLRsXBGysVyicZTeqw        Dutch       morgen
# 28  Kl8_gX6RUHKlL91y3mojgQ        Dutch      pinguïn
# 29  nUzqisjeUfqvn3ZK4l5hdg        Dutch        japan
# 30  uhvMQosgWbyOb6LmKBHfXw        Dutch       troost
# 31  GV-U28WjVYygiZAPrALbcw        Dutch     manneken
# 32  H8h1m1-YVdW8Kg1O5qOYjg        Dutch      drijver
# 33  -vX087v3U8OzPZouxT1_LA        Dutch          kip
# 34  lRqJh3I8UtyfqMlrERfWmQ        Dutch       rivier
# 35  2hOUf-RKUDmwArkg71j6pw        Dutch      klikken
# 36  pFKC4GXiWLafD8n4HQr_1Q        Dutch        jacht
# 37  2ksU9A89UgKgEaEjPGDTXg        Dutch     schieten
# 38  ocLnKZorUVyQHjZ_u6ledg        Dutch     schouwen
# 39  gjxLtUcqVOWh6FB9Oe0O3g        Dutch       burcht
# 40  UPjELP2CW0-_8AaxFTf64w        Dutch        dicht
# 41  Hm8X_LCkW3aErdjm17ZfSw        Dutch     spreiden
# 42  -Pk65o2DUtu5jLpyx-N9vA        Dutch          wee
# 43  fSsr0aEIUkC_0dd1BFU39g        Dutch         balg
# 44  cfHoJx_eW5OM1eCkmJGgKQ        Dutch         mijn
# 45  JtFsNIJfXpGk8j-NfGLgGw        Dutch       steken
# 46  6mXUWvWqVyiFJ8llV_JgiQ        Dutch        stage
# 47  3lsfzbJKWv-0InfJYkbLog        Dutch         tuit
# 48  YGJ-PCRfXmSi6Dq1iK9kuQ        Dutch       deuvel
# 49  fkSO1FMCVleDKGA-h_r-Vg        Dutch         giek
# 50  lgEpEcf8UV-5vvTMBeVMvg        Dutch    slijderen
# 51  mOxcdg5mVfu-tIgC2VqoGA        Dutch    schielijk
# 52  yoNMlc2kVt6ggnd41xhXvg        Dutch     sproeien

# %%
df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
df_word = df_word.head(40000)
df_word = df_word.loc[:,["word"]]
df_word.rename(columns={"word":"related_term"}, inplace=True)
df_word
# Out:
#              related_term
# 0                      ik
# 1                      je
# 2                     het
# 3                      de
# 4                     dat
# ...                   ...
# 39995                bois
# 39996                 ood
# 39997            melaatse
# 39998                poll
# 39999  vredesbesprekingen
#
# [40000 rows x 1 columns]

# %%
df_lang_pair2 = pd.merge(df_lang_pair2,df_word, how="inner", on="related_term")
df_lang_pair2 = df_lang_pair2[(df_lang_pair2["reltype"] == "cognate_of") | (df_lang_pair2["reltype"] == "etymologically_related_to") | (df_lang_pair2["reltype"] == "derived_from") | (df_lang_pair2["reltype"] == "borrowed_from")]
df_lang_pair2
# Out:
#                    term_id     lang          term                    reltype  \
# 0   5bVUD53NVEWYY0QAetV7iA  Turkish           net                 cognate_of
# 1   GnagvVL5UyyP2i7qDH6krQ  Turkish           hol                 cognate_of
# 2   qq2kd4hTXbGWxsQa3aaR6Q  Turkish         start                 cognate_of
# 3   46ugIwcFXMCCguPndDYa6g  Turkish          boks                 cognate_of
# 4   j5RVDOCnWBCSBurLxpgfCw  Turkish        korvet  etymologically_related_to
# 5   WrmjvMe_XsKG56ZkabPmBg  Turkish           bit                 cognate_of
# 6   v2jBV4HTXm2KuXm2sJCGQw  Turkish         lider                 cognate_of
# 7   9CRYAyGIVE-BMqqw5S3KMg  Turkish          film                 cognate_of
# 8   h68RrckGUgGUMp2CADNhow  Turkish         trend                 cognate_of
# 9   7gpilZjWXJOsKve4GVt0JQ  Turkish          fare                 cognate_of
# 10  TOGskftoXJKlGFUIf1Z6zA  Turkish        spiker                 cognate_of
# 11  icfiApR1WjiPptUiab0htA  Turkish       birader                 cognate_of
# 12  dsQ0_jAuV4iircOyeHZx-w  Turkish          pisi               derived_from
# 13  g6xdJnNmUZaeSj-7yEiQbg  Turkish        karpuz                 cognate_of
# 14  2ftpHNtyVWC5mBk14Z0rQA  Turkish         japon              borrowed_from
# 15  AOG0aJ6AVcmbRlIgldVC_Q  Turkish       japonca               derived_from
# 16  r4boOTeEWf-J-q9FrtVZsw  Turkish  japon balığı               derived_from
# 17  lzoyKM1FX4mFiDU2biUr5g  Turkish           gaz               derived_from
# 18  S4QmNyBPVDOruTR8c9_jIQ  Turkish         paket               derived_from
# 19  k1vtsZfpX3eveixglqP_vQ  Turkish           gri                 cognate_of
# 20  b9x1WJkWU6a0Oi0Z6NZWPQ  Turkish           dok              borrowed_from
# 21  rmEcd-cwUrOTGAWr6Q1Vyg  Turkish           gey                 cognate_of
# 22  7uaTXsE8Xf2lN_stc4ygFg  Turkish           çek                 cognate_of
# 23  BpB0PTOZWduxyzTZmRgu-g  Turkish          çene                 cognate_of
# 24  w0umVRLfWqqd2_MjuzhYxQ  Turkish         yarın                 cognate_of
# 25  u85ZDMy-Uce4i1VBd3OTGQ  Turkish         tröst                 cognate_of
# 26  As6zFsD8VZ-EkZiC_-PZLw  Turkish        sürücü                 cognate_of
# 27  sEy4gtuXWoO-1MYiLTSoNg  Turkish           çip                 cognate_of
# 28  3A9PKi_lWEy3Lnd5iUGxKg  Turkish         revir                 cognate_of
# 29  kLVPRTUvW-mVVMoDXojM-g  Turkish         klişe                 cognate_of
# 30  nVCqcrBJX7me3NmRAwIHiw  Turkish           yat               derived_from
# 31  AYUXPRm7UWK108a4nWJJTg  Turkish           şut                 cognate_of
# 32  Ihx4oi4KU8-tEzEhAxHlzg  Turkish          burç                 cognate_of
# 33  fkNxSBywVaGKkiPFNEIvAA  Turkish          tayt                 cognate_of
# 34  7szQxpXJVAyjl3G11EYZuA  Turkish       sipariş                 cognate_of
# 35  tjQ9cJHsUTqqJg9PZp1Xhw  Turkish           vay                 cognate_of
# 36  1mJ4rTncVTyHSsvq02W7dg  Turkish         mayın                 cognate_of
# 37  mI-Uf1r5U4Cx35rfNJ_nWA  Turkish        isteka                 cognate_of
# 38  Mw1RBi4aVNuJtdy7FZhm-A  Turkish          staj                 cognate_of
# 39  vMlQ7iIFXOaJStzUvXGe0Q  Turkish          tüyo                 cognate_of
# 40  FfzaiTXzV0OKAsE4cMT5qA  Turkish         sprey                 cognate_of
#
#            related_term_id related_lang related_term
# 0   8AllwxDPWd-5F5FOadvN6g        Dutch          net
# 1   xRABeifpW22eTk3e25HBmA        Dutch          hal
# 2   5ykqchhZWByc9u83yzIPnA        Dutch      storten
# 3   c3CDZzBfU9eR8ItsVx8y7w        Dutch          bos
# 4   aQZ5CoJIX5Oy0mTLNhE3XA        Dutch         korf
# 5   erSvj9rPUw2sV76iJw1TWw        Dutch          bit
# 6   PZoO_UKZX--MKfwbrKhPMA        Dutch       leider
# 7   d7VF8TQjWiabbUsasz5Y7g        Dutch          vel
# 8   C9B2w3-5XW-27dSZN9g4bA        Dutch        trent
# 9   9Xw4zfI7WPC-rpmdErQIAw        Dutch         muis
# 10  jvLmy7DXXvScpjGz8OAfrw        Dutch      spreker
# 11  JEzjrpBqUviWldJocQHGqQ        Dutch      broeder
# 12  STRcqOVEUl-iXyXv4k2Qkg        Dutch         poes
# 13  dICTv6dQV5CFn5Lo8iraJw        Dutch       herfst
# 14  nUzqisjeUfqvn3ZK4l5hdg        Dutch        japan
# 15  nUzqisjeUfqvn3ZK4l5hdg        Dutch        japan
# 16  nUzqisjeUfqvn3ZK4l5hdg        Dutch        japan
# 17  UC1ZrBQOWoKgr4c2WwwTyA        Dutch          gas
# 18  pdTr8gb0WouiLXaemNSOhA        Dutch          pak
# 19  co9fNuGjW9K5l_ATaYVCHg        Dutch        grijs
# 20  F_f0Zp_MWfmxKU48aqtvRw        Dutch          dok
# 21  GaIQahNsWwiGLXstPBf_Sg        Dutch         gauw
# 22  0tXQpLsFVr6nXvi4-keTGw        Dutch       schaak
# 23  4HrGRxPEVCqKbHfG_fHolA        Dutch          kin
# 24  KEzHlLRsXBGysVyicZTeqw        Dutch       morgen
# 25  uhvMQosgWbyOb6LmKBHfXw        Dutch       troost
# 26  H8h1m1-YVdW8Kg1O5qOYjg        Dutch      drijver
# 27  -vX087v3U8OzPZouxT1_LA        Dutch          kip
# 28  lRqJh3I8UtyfqMlrERfWmQ        Dutch       rivier
# 29  2hOUf-RKUDmwArkg71j6pw        Dutch      klikken
# 30  pFKC4GXiWLafD8n4HQr_1Q        Dutch        jacht
# 31  2ksU9A89UgKgEaEjPGDTXg        Dutch     schieten
# 32  gjxLtUcqVOWh6FB9Oe0O3g        Dutch       burcht
# 33  UPjELP2CW0-_8AaxFTf64w        Dutch        dicht
# 34  Hm8X_LCkW3aErdjm17ZfSw        Dutch     spreiden
# 35  -Pk65o2DUtu5jLpyx-N9vA        Dutch          wee
# 36  cfHoJx_eW5OM1eCkmJGgKQ        Dutch         mijn
# 37  JtFsNIJfXpGk8j-NfGLgGw        Dutch       steken
# 38  6mXUWvWqVyiFJ8llV_JgiQ        Dutch        stage
# 39  3lsfzbJKWv-0InfJYkbLog        Dutch         tuit
# 40  yoNMlc2kVt6ggnd41xhXvg        Dutch     sproeien

# %%
#df_lang_pair2.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result4.xlsx", index=False)
