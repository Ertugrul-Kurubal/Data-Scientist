# %% [markdown]
# ### Etymology Language Pair

# %%
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### Single Language Pair

# %%
lang_folder = "English"

# %%
df_result2 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_folder.capitalize()}/{lang_folder.capitalize()}_Etymologeek_Main_And_Additional_Result.xlsx")
df_result2
# Out:
#        search_word dict_entry_main language_main  \
# 0         currency        currency       English
# 1         currency        currency       English
# 2         currency        currency       English
# 3         currency        currency       English
# 4         currency        currency       English
# ...            ...             ...           ...
# 201631    superman  superman punch       English
# 201632    superman  superman punch       English
# 201633    superman    supermanship       English
# 201634    superman    supermanship       English
# 201635    superman    supermanship       English
#
#                                           definition_main      dict_entry  \
# 0       (Noun) (more, _, specifically) Paper money.. (...      crescendum
# 1       (Noun) (more, _, specifically) Paper money.. (...          *kers-
# 2       (Noun) (more, _, specifically) Paper money.. (...           *kor-
# 3       (Noun) (more, _, specifically) Paper money.. (...        sincerus
# 4       (Noun) (more, _, specifically) Paper money.. (...       currendus
# ...                                                   ...             ...
# 201631  (Noun) A technique used in Muay Thai, Sanshou,...        Superman
# 201632  (Noun) A technique used in Muay Thai, Sanshou,...  superman punch
# 201633  (Noun) The quality of being a superman.The qua...           -ship
# 201634  (Noun) The quality of being a superman.The qua...        superman
# 201635  (Noun) The quality of being a superman.The qua...    supermanship
#
#                              language  \
# 0                         Latin (lat)
# 1       Proto-Indo-European (ine-pro)
# 2       Proto-Indo-European (ine-pro)
# 3                         Latin (lat)
# 4                         Latin (lat)
# ...                               ...
# 201631                  English (eng)
# 201632                  English (eng)
# 201633                  English (eng)
# 201634                  English (eng)
# 201635                  English (eng)
#
#                                                definition
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       Clean, pure, sound.. Genuine, sincere.. Real, ...
# 4                                                     NaN
# ...                                                   ...
# 201631  (motorcycling, plural Supermans) A stunt in wh...
# 201632  A technique used in Muay Thai, Sanshou, kickbo...
# 201633  Appended to a noun to form a new noun denoting...
# 201634  (chiefly, philosophy) An imagined superior typ...
# 201635                   The quality of being a superman.
#
# [201636 rows x 7 columns]

# %%
#df_result2.language_main.unique()

# %%
#df_result2.language.unique()

# %%
lang_pair = "Turkish (tur)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), Portuguese (por), Dutch (nld), Italian (ita)

# %%
df_lang_pair = df_result2[(df_result2["language_main"] == f"{lang_folder.capitalize()}") & (df_result2["language"] == f"{lang_pair.capitalize()}")]
df_lang_pair
# Out:
#        search_word dict_entry_main language_main  \
# 30478          ray           rayah       English
# 37871       caviar          caviar       English
# 43552         arab           araba       English
# 72642         turk          turkey       English
# 122679        jack          jackal       English
# 131078      turkey          turkey       English
# 181630        done           donek       English
# 186655      sultan          sultan       English
# 186750        soft           softa       English
# 192943       marta        martagon       English
#
#                                           definition_main dict_entry  \
# 30478   (Noun) (pejorative) A member of the tax-paying...      reaya
# 37871   (Noun) Roe of the sturgeon or other large fish...     havyar
# 43552   (Noun) A horse-drawn carriage once used for tr...      araba
# 72642   (Noun) (bowling) An act of throwing three stri...   Turgutlu
# 122679  (Verb Noun) To perform menial or routine tasks...      çakal
# 131078  (Noun) (bowling) An act of throwing three stri...   Turgutlu
# 181630  (Noun) A breed of fancy pigeon.A breed of fanc...      dönek
# 186655  (Noun) (card games) A variant of solitaire, pl...     sultan
# 186750  (Noun) (Islam) A religious student, especially...      softa
# 192943            (Noun) A Eurasian lily.A Eurasian lily.   martagan
#
#              language                                         definition
# 30478   Turkish (tur)                                                NaN
# 37871   Turkish (tur)                                            Caviar.
# 43552   Turkish (tur)                               Car. Carriage. Cart.
# 72642   Turkish (tur)                                                NaN
# 122679  Turkish (tur)  (pejorative, derogatory) A detestable person, ...
# 131078  Turkish (tur)                                                NaN
# 181630  Turkish (tur)                                                NaN
# 186655  Turkish (tur)  A breed of chicken originating in Turkey, kept...
# 186750  Turkish (tur)  (Islam) A student of theology. (by extension) ...
# 192943  Turkish (tur)                                                NaN

# %%
df_lang_pair = df_lang_pair.drop_duplicates(subset="dict_entry_main")
df_lang_pair.reset_index(drop=True, inplace=True)
df_lang_pair
# Out:
#   search_word dict_entry_main language_main  \
# 0         ray           rayah       English
# 1      caviar          caviar       English
# 2        arab           araba       English
# 3        turk          turkey       English
# 4        jack          jackal       English
# 5        done           donek       English
# 6      sultan          sultan       English
# 7        soft           softa       English
# 8       marta        martagon       English
#
#                                      definition_main dict_entry  \
# 0  (Noun) (pejorative) A member of the tax-paying...      reaya
# 1  (Noun) Roe of the sturgeon or other large fish...     havyar
# 2  (Noun) A horse-drawn carriage once used for tr...      araba
# 3  (Noun) (bowling) An act of throwing three stri...   Turgutlu
# 4  (Verb Noun) To perform menial or routine tasks...      çakal
# 5  (Noun) A breed of fancy pigeon.A breed of fanc...      dönek
# 6  (Noun) (card games) A variant of solitaire, pl...     sultan
# 7  (Noun) (Islam) A religious student, especially...      softa
# 8            (Noun) A Eurasian lily.A Eurasian lily.   martagan
#
#         language                                         definition
# 0  Turkish (tur)                                                NaN
# 1  Turkish (tur)                                            Caviar.
# 2  Turkish (tur)                               Car. Carriage. Cart.
# 3  Turkish (tur)                                                NaN
# 4  Turkish (tur)  (pejorative, derogatory) A detestable person, ...
# 5  Turkish (tur)                                                NaN
# 6  Turkish (tur)  A breed of chicken originating in Turkey, kept...
# 7  Turkish (tur)  (Islam) A student of theology. (by extension) ...
# 8  Turkish (tur)                                                NaN

# %%
#df_lang_pair.to_excel(f"{lang_folder.capitalize()}_And_{lang_pair.capitalize()}_Etymologeek_Result.xlsx", index=False)

# %% [markdown]
# #### Multi File Langauge Pair

# %%
#all_etymologeek_file = glob.glob("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/*/*_Etymologeek_Main_And_Additional_Result.xlsx")
#all_etymologeek_file

# %%
#df_etymologeek_all = pd.DataFrame()
#for i in all_etymologeek_file:
#    df_var = pd.read_excel(f"{i}")
#    df_etymologeek_all = pd.concat([df_etymologeek_all, df_var], axis=0)
#df_etymologeek_all.drop_duplicates(inplace=True)
#df_etymologeek_all.reset_index(drop=True, inplace=True)
#df_etymologeek_all

# %%
#df_etymologeek_all.to_excel("All_Etymology_Language_Pair_Result.xlsx", index=False)

# %% [markdown]
# #### Read All Data

# %%
df_etymologeek_all = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/All_Etymology_Language_Pair_Result.xlsx")
df_etymologeek_all
# Out:
#        search_word dict_entry_main   language_main  \
# 0              bir             bir   Crimean Tatar
# 1              bir             bir   Crimean Tatar
# 2              bir             bir  Middle English
# 3              bir             bir  Middle English
# 4              bir             bir  Middle English
# ...            ...             ...             ...
# 668525        إلين           إلينا          Arabic
# 668526       مستقر           مستقر          Arabic
# 668527       مستقر           مستقر          Arabic
# 668528        صيني           صينية          Arabic
# 668529        صيني           صينية          Arabic
#
#                                           definition_main       dict_entry  \
# 0                (Numeral) (cardinal) one.(cardinal) one.             *bīr
# 1                (Numeral) (cardinal) one.(cardinal) one.              bir
# 2       (Noun) A charge on an account.. A strong or fa...           *buriz
# 3       (Noun) A charge on an account.. A strong or fa...        *bʰrewh₁-
# 4       (Noun) A charge on an account.. A strong or fa...           *buriz
# ...                                                   ...              ...
# 668525                              (Adverb) To us.To us.            إلينا
# 668526  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668528  (Noun) (usually definite) Chinese language.(us...  لُغَة صِينِيَّة
# 668529  (Noun) (usually definite) Chinese language.(us...            صينية
#
#                              language  \
# 0              Proto-Turkic (trk-pro)
# 1                 Crimean Tatar (crh)
# 2            Proto-Germanic (gem-pro)
# 3       Proto-Indo-European (ine-pro)
# 4            Proto-Germanic (gem-pro)
# ...                               ...
# 668525                   Arabic (ara)
# 668526                         Arabic
# 668527                         Arabic
# 668528                   Arabic (ara)
# 668529                   Arabic (ara)
#
#                                                definition
# 0                                                    One.
# 1                                         (cardinal) one.
# 2                                    Male offspring; son.
# 3                                                     NaN
# 4                                        Elevation; hill.
# ...                                                   ...
# 668525                                             To us.
# 668526  (Adjective) Confessing. Firm, solid, stable. F...
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...
# 668528                                                NaN
# 668529               (usually definite) Chinese language.
#
# [668530 rows x 7 columns]

# %%
#df_etymologeek_all["language_main"].unique()

# %%
#df_etymologeek_all["language"].unique()

# %%
lang_1 = "Spanish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "English (eng)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)

# %%
df_lang_pair_all = df_etymologeek_all[(df_etymologeek_all["language_main"] == f"{lang_1.capitalize()}") & (df_etymologeek_all["language"] == f"{lang_2.capitalize()}")]
df_lang_pair_all
# Out:
#        search_word dict_entry_main language_main  \
# 16775         lord            lord       Spanish
# 16828          hay            haya       Spanish
# 19101       futbol          futbol       Spanish
# 19102       futbol          futbol       Spanish
# 20131          rol             rol       Spanish
# ...            ...             ...           ...
# 632109       dicci         dicción       Spanish
# 639605       salti        saltillo       Spanish
# 653771     youtube        youtuber       Spanish
# 653772     youtube        youtuber       Spanish
# 653890      brunch          brunch       Spanish
#
#                                           definition_main dict_entry  \
# 16775   (Noun) Lord (British title).Lord (British title).       lord
# 16828         (Noun) Beech, beech tree.Beech, beech tree.      beech
# 19101   (Noun) (Mexico) football (soccer).(Mexico) foo...       foot
# 19102   (Noun) (Mexico) football (soccer).(Mexico) foo...   football
# 20131                                   (Noun) Role.Role.       role
# ...                                                   ...        ...
# 632109                            (Noun) Diction.Diction.     dictus
# 639605                          (Noun) Saltillo.Saltillo.  salt mine
# 653771                          (Noun) YouTuber.YouTuber.    YouTube
# 653772                          (Noun) YouTuber.YouTuber.   YouTuber
# 653890                              (Noun) Brunch.Brunch.     brunch
#
#              language                                         definition
# 16775   English (eng)  (intransitive, and, transitive) Domineer or ac...
# 16828   English (eng)  A tree of the genus Fagus having a smooth, lig...
# 19101   English (eng)  (countable) A biological structure found in ma...
# 19102   English (eng)  (Australia, Ireland, New Zealand) rugby union....
# 20131   English (eng)  (grammar) : The function of a word in a phrase...
# ...               ...                                                ...
# 632109  English (eng)                                                NaN
# 639605  English (eng)  (by extension) Any laborious work situation, e...
# 653771  English (eng)  A video-sharing website. (neologism) Any websi...
# 653772  English (eng)  (internet) A user of the video-sharing website...
# 653890  English (eng)  A meal eaten later in the day than breakfast a...
#
# [295 rows x 7 columns]

# %%
df_lang_pair_all = df_lang_pair_all.drop_duplicates(subset="dict_entry_main")
df_lang_pair_all.reset_index(drop=True, inplace=True)
df_lang_pair_all
# Out:
#     search_word dict_entry_main language_main  \
# 0          lord            lord       Spanish
# 1           hay            haya       Spanish
# 2        futbol          futbol       Spanish
# 3           rol             rol       Spanish
# 4          rock            rock       Spanish
# ..          ...             ...           ...
# 194       anime           anime       Spanish
# 195       dicci         dicción       Spanish
# 196       salti        saltillo       Spanish
# 197     youtube        youtuber       Spanish
# 198      brunch          brunch       Spanish
#
#                                        definition_main dict_entry  \
# 0    (Noun) Lord (British title).Lord (British title).       lord
# 1          (Noun) Beech, beech tree.Beech, beech tree.      beech
# 2    (Noun) (Mexico) football (soccer).(Mexico) foo...       foot
# 3                                    (Noun) Role.Role.       role
# 4        (Noun) Rock (music style).Rock (music style).       dots
# ..                                                 ...        ...
# 194                                (Noun) Anime.Anime.  animation
# 195                            (Noun) Diction.Diction.       dico
# 196                          (Noun) Saltillo.Saltillo.  salt mine
# 197                          (Noun) YouTuber.YouTuber.    YouTube
# 198                              (Noun) Brunch.Brunch.     brunch
#
#           language                                         definition
# 0    English (eng)  (intransitive, and, transitive) Domineer or ac...
# 1    English (eng)  A tree of the genus Fagus having a smooth, lig...
# 2    English (eng)  (countable) A biological structure found in ma...
# 3    English (eng)  (grammar) : The function of a word in a phrase...
# 4    English (eng)  A punctuation mark consisting of three dots, i...
# ..             ...                                                ...
# 194  English (eng)  (animation, in the sense of a cartoon) The tec...
# 195  English (eng)                                                NaN
# 196  English (eng)  (by extension) Any laborious work situation, e...
# 197  English (eng)  A video-sharing website. (neologism) Any websi...
# 198  English (eng)  A meal eaten later in the day than breakfast a...
#
# [199 rows x 7 columns]

# %%
df_lang_pair_all.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result_All.xlsx", index=False)
