# %% [markdown]
# ### Etymology Language Pair

# %%
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### Single Language Pair

# %%
lang_folder = "Turkish"

# %%
df_result2 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_folder.capitalize()}/{lang_folder.capitalize()}_Etymologeek_Main_And_Additional_Result.xlsx")
df_result2
# Out:
#       search_word dict_entry_main   language_main  \
# 0             bir             bir   Crimean Tatar
# 1             bir             bir   Crimean Tatar
# 2             bir             bir  Middle English
# 3             bir             bir  Middle English
# 4             bir             bir  Middle English
# ...           ...             ...             ...
# 54274         şah           şahin         Turkish
# 54275         şah           şahıs         Turkish
# 54276         şah           şahıs         Turkish
# 54277         şah           şahsi         Turkish
# 54278         şah           şahsi         Turkish
#
#                                          definition_main dict_entry  \
# 0               (Numeral) (cardinal) one.(cardinal) one.       *bīr
# 1               (Numeral) (cardinal) one.(cardinal) one.        bir
# 2      (Noun) A charge on an account.. A strong or fa...     *buriz
# 3      (Noun) A charge on an account.. A strong or fa...  *bʰrewh₁-
# 4      (Noun) A charge on an account.. A strong or fa...     *buriz
# ...                                                  ...        ...
# 54274                                (Noun) Buteo.Buteo.      şahin
# 54275                              (Noun) Person.Person.        شخص
# 54276                              (Noun) Person.Person.      şahıs
# 54277                     (Adjective) Personal.Personal.       شخصی
# 54278                     (Adjective) Personal.Personal.      şahsi
#
#                             language  \
# 0             Proto-Turkic (trk-pro)
# 1                Crimean Tatar (crh)
# 2           Proto-Germanic (gem-pro)
# 3      Proto-Indo-European (ine-pro)
# 4           Proto-Germanic (gem-pro)
# ...                              ...
# 54274                  Turkish (tur)
# 54275                   Arabic (ara)
# 54276                  Turkish (tur)
# 54277                  Persian (fas)
# 54278                  Turkish (tur)
#
#                                               definition
# 0                                                   One.
# 1                                        (cardinal) one.
# 2                                   Male offspring; son.
# 3                                                    NaN
# 4                                       Elevation; hill.
# ...                                                  ...
# 54274                                             Buteo.
# 54275  Figure, character. Person, individual. Someone...
# 54276                                            Person.
# 54277                                          Personal.
# 54278                                          Personal.
#
# [54279 rows x 7 columns]

# %%
#df_result2.language_main.unique()
# Out:
# array(['Crimean Tatar', 'Middle English', 'Gagauz', 'Middle High German',
#        'Indonesian', 'Old Azari', 'Javanese', 'Karakalpak', 'Maltese',
#        'Malay', 'Breton', 'Dalmatian', 'Scottish Gaelic',
#        'Westrobothnian', 'Mongghul', 'Norwegian Nynorsk',
#        'Norwegian Bokmål', 'Norwegian', 'Turkish', 'Old English',
#        'Phuthi', 'Czech', 'German', 'Middle Dutch', 'English', 'French',
#        'Danish', 'Esperanto', 'Faroese', 'Middle Low German',
#        'Old Swedish', 'Ido', 'Istro-Romanian', 'Albanian', 'Bislama',
#        'Catalan', 'Gaulish', 'Welsh', 'Proto-Finnic', 'Proto-Celtic',
#        'Cornish', 'Friulian', 'Galician', 'Aragonese', 'Asturian',
#        'Cebuano', 'Icelandic', 'Jarai', 'Latin', 'Late Latin',
#        'Old Norse', 'Azerbaijani', 'Gutnish', 'Old High German',
#        'Serbo-Croatian', 'Hungarian', 'Sãotomense', 'Northern Kurdish',
#        'Somali', 'Proto-Malayic', 'Pali', 'Abenaki', 'Finnish',
#        'Old French', 'Franco-Provençal', 'Slovenian', 'Arawak',
#        'Proto-Central Chadic', 'Occitan', 'Old Dutch', 'Old Saxon',
#        'Swedish', 'Tagalog', 'Zulu', 'Scots', 'Tocharian A', 'Estonian',
#        'Wauja', 'Spanish', 'Polish', 'Slovak', 'Chuukese', 'Dutch',
#        'Romansh', 'Italian', 'Sicilian', 'Sardinian', 'Saterland Frisian',
#        'Nias', 'Aromanian', 'Irish', 'Plains Cree', 'North Frisian',
#        'Ingrian', 'Karelian', 'Ludian', 'Livvi', 'Proto-Albanian', 'Veps',
#        'Haitian', 'Kristang', 'Mauritian Creole', 'Swahili', 'Romanian',
#        'Old Anatolian Turkish', 'Afrikaans', 'Fala', 'Eastern Cham',
#        'Korlai Creole Portuguese', 'Portuguese', 'Proto-Permic',
#        'Volapük', 'Turkmen', 'Tok Pisin', 'Kikuyu; Gikuyu', 'Nyanja',
#        'Proto-Slavic', 'Middle Irish', 'Kalasha', 'Venetian',
#        'Old Danish', 'Western Frisian', 'Proto-Balto-Slavic', 'Zazaki',
#        'Vietnamese', 'Hiligaynon', 'Tiruray', 'Dimasa', 'Balinese',
#        'Dairi Batak', 'Karo Batak', 'Makasar', 'Simeulue', 'Maranao',
#        'Lithuanian', 'Navajo, Navaho', 'Old Frisian', 'Old Turkic',
#        'Norn', 'Middle French', 'Baure', 'Kinyarwanda', 'Ojibwa',
#        'Lower Sorbian', 'Hawaiian', 'Latvian', 'Cantonese', 'Chinese',
#        'Old Irish', 'Proto-Baltic', 'Proto-Armenian', 'Interlingua',
#        'Proto-Turkic', 'Basque', 'Kurdish', 'Western Apache', 'Romani',
#        'Umbrian', 'Kashubian', 'Upper Sorbian', "Brooke's Point Palawano",
#        'Tarantino', 'Salar', 'Proto-Germanic', 'Bahnar', 'Old Cornish',
#        'Pitjantjatjara', 'Votic', "Yup'ik", 'Anglo-Norman',
#        'Extremaduran', 'Istriot', 'Mirandese', 'Old Spanish',
#        'Old Breton', 'Old Welsh', 'Middle Breton', 'Khamnigan Mongol',
#        'Old Portuguese', 'Enawené-Nawé', 'Yagnobi', 'Annobonese',
#        'Southern Sami', 'Inari Sami', 'Vilamovian', 'Talysh', 'Nobiin',
#        'Dongxiang', 'Gusii', 'Pijin', 'Kott', 'Luxembourgish',
#        'Low German', 'Filipino', 'Ladino', 'Bilba', 'Rapa Nui', 'Zhuang',
#        'Sranan Tongo', 'Maori', 'Tahitian', 'German Low German', 'Karajá',
#        'Võro', 'Jamtish', 'Indo-Portuguese', 'Aklanon', 'Bonan',
#        'Romagnol', 'Karaim', 'Yola', 'Palenquero', 'Pipil', 'Kriol',
#        'Lojban', 'Hausa', 'Nauru', 'Malayalam', 'Gamilaraay',
#        'Piedmontese', 'Walloon', 'Ilocano', 'Corsican', 'Aynu',
#        'Proto-Indo-European', 'Uzbek', 'Polabian', 'Norman', 'Manx',
#        'Novial', 'Crimean Gothic', 'Central Kurdish', 'Skolt Sami',
#        'Middle Welsh', 'Vulgar Latin', 'Dadibi', 'Classical Nahuatl',
#        'Guinea-Bissau Creole', 'Nigerian Pidgin', 'Angkorian Old Khmer',
#        'Old Khmer', 'Samoan', 'Frankish', 'Swati', 'Xhosa',
#        'Central Franconian', 'Dacian', 'Banjarese', 'Buginese',
#        'Proto-Chamic', 'Central Melanau', 'Chavacano', 'Interlingue',
#        'Old Provençal', 'Avestan', 'Proto-Samoyedic', 'Tukudede',
#        'Proto-Iranian', 'Leonese', 'Old Leonese', 'Takia', 'Michif',
#        'Chrau', 'Emilian', 'Seychellois Creole', 'Antillean Creole',
#        'Guianese Creole', 'Karipúna Creole French', 'Limburgan',
#        'Bikol Central', 'Puyuma', 'Chamorro', 'Northern Sami',
#        'Louisiana Creole French', 'Jingpho', 'Mizo', 'Buruwai',
#        'Neapolitan', 'Ter Sami', 'Modern Greek', 'Garifuna', 'Livonian',
#        'Oscan', 'Chamicuro', 'Jamaican Creole', 'Niuean', 'Translingual',
#        'Apatani', 'Demotic', 'Egyptian', 'Ligurian', 'Kangjia', "Palu'e",
#        'Kalaallisut', 'Iban', 'West Coast Bajau', 'Pareci',
#        'Proto-Brythonic', 'Shona', 'Proto-Loloish', 'Picard', 'Old Czech',
#        'Fijian', 'Alemannic German', 'Mòcheno', 'Dilling',
#        'Proto-Indo-Iranian', 'Kabuverdianu', 'Baré', 'Palikur',
#        'Ottoman Turkish', 'Old Prussian', 'Scanian', 'Kichwa',
#        'Proto-Central-Eastern Malayo-Polynesian', 'Proto-Malayo-Chamic',
#        'Proto-Malayo-Sumbawan', 'Proto-Oceanic', 'Western Arrernte',
#        'Samoan Plantation Pidgin', 'Old Uyghur', 'Moken', 'West Flemish',
#        'Dutch Low Saxon', 'Proto-Philippine', 'Tatar', 'Tat',
#        'Proto-Central New South Wales', 'Southern Sotho', 'Shawnee',
#        'Faliscan', 'Ankave', 'Champenois', 'Tarifit', 'Ladin', 'Persian',
#        'Choctaw', 'Fiji Hindi', 'Tocharian B', 'Palauan', 'Jehai',
#        'Kensiu', 'Tetum', 'Kulon-Pazeh', 'Awetí', 'Kamayurá',
#        'Sateré-Mawé', 'Tagakaulu Kalagan', 'Mussau-Emira', 'Bende',
#        'Galibi Carib', 'Halang', 'Baniwa', 'Wayuu', 'Limos Kalinga',
#        'Lubuagan Kalinga', 'Proto-Malayo-Polynesian', 'Daur', 'Lombard',
#        'Waray-Waray', 'Eman', 'Bunun', 'Bintulu', 'Old Javanese',
#        'Pite Sami', 'Lule Sami', 'Luhya', 'Ecclesiastical Latin', 'ǃXóõ',
#        'Torres Strait Creole', 'Chinook Jargon', 'Mwani', 'Haeke', 'Fwâi',
#        'Haveke', 'Jawe', 'North Ambrym', 'Kamba', 'Inupiaq', 'Nyishi',
#        'Matigsalug Manobo', 'Bambara', 'Nahuatl', 'Old Catalan',
#        'Celtiberian', 'Elfdalian', 'Papiamentu', 'Dobu', 'Numbami',
#        'Celtic', 'Arapaho', 'Venda', 'Ganda', 'Old Latin', 'Curripaco',
#        'Suevic', 'Bwatoo', 'Pangasinan', 'Wolof', 'Angevin', 'Adyghe',
#        'Kabardian', 'Rennellese', 'Nukuoro', 'Middle Cornish',
#        'Paraguayan Guaraní', 'South Marquesan', 'Rohingya', 'Toba Batak',
#        'Batad Ifugao', 'Primitive Irish', 'Aleut', 'Binukid', 'Japanese',
#        'New Latin', 'Algonquin', 'Maquiritari', 'Proto-Algonquian',
#        'Middle Persian', 'Baiso', 'Proto-Uralic', 'Wallisian',
#        'Undetermined', 'Guugu Yimidhirr', 'Megleno-Romanian', 'Mozarabic',
#        'Slovincian', 'Kavalan', 'Maguindanao', 'Tai Dam',
#        'Molise Croatian', 'Potawatomi', 'Miami', 'Muong', 'Proto-Italic',
#        'Cimbrian', 'Pumpokol', 'Angolar', 'Malagasy', 'Inuktitut',
#        'Yucatec Maya', 'Marshallese', 'Rhine Franconian', 'Kapampangan',
#        'Taos', 'Kala Lagaw Ya', 'Pre-Angkorian Old Khmer',
#        'Proto-Indo-Aryan', 'Plautdietsch', 'Atikamekw', 'Wiyot',
#        'Chuvash', 'Old Polish'], dtype=object)

# %%
#df_result2.language.unique()
# Out:
# array(['Proto-Turkic (trk-pro)', 'Crimean Tatar (crh)',
#        'Proto-Germanic (gem-pro)', 'Proto-Indo-European (ine-pro)',
#        'Old English (ang)', 'Middle English (enm)', 'Gagauz (gag)',
#        'Old High German (goh)', 'Middle High German (gmh)',
#        'Frankish (frk)', 'Old Dutch (odt)', 'Middle Dutch (dum)',
#        'Dutch (nld)', 'Indonesian (ind)', 'Old Azari (ira-azr)',
#        'Javanese (jav)', 'Karakalpak (kaa)', 'Proto-Semitic (sem-pro)',
#        'Arabic (ara)', 'Maltese (mlt)', 'English (eng)',
#        'Malay (macrolanguage) (msa)', 'Proto-Celtic (cel-pro)',
#        'Breton (bre)', 'Proto-Italic (itc-pro)', 'Latin (lat)',
#        'Dalmatian (dlm)', 'Scottish Gaelic (gla)', 'Old Norse (non)',
#        'Westrobothnian (gmq-bot)', 'Proto-Mongolic (xgn-pro)',
#        'Mongghul (mjg-huz)', 'Norwegian Nynorsk',
#        'Norwegian Bokmål (nob)', 'Norwegian (nor)',
#        'Ottoman Turkish (ota)', 'Turkish (tur)', 'Proto-Bantu (bnt-pro)',
#        'Proto-Nguni (bnt-ngu-pro)', 'Phuthi (bnt-phu)',
#        'Proto-Brythonic (cel-bry-pro)',
#        'Proto-Balto-Slavic (ine-bsl-pro)', 'Proto-Slavic (sla-pro)',
#        'Czech (ces)', 'German (deu)', 'Old Latin (itc-ola)',
#        'French (fra)', 'Danish (dan)', 'Esperanto (epo)', 'Faroese (fao)',
#        'Old Saxon (osx)', 'Middle Low German (gml)',
#        'Old Swedish (gmq-osw)', 'Ido (ido)', 'Istro-Romanian (ruo)',
#        'Albanian', 'Bislama (bis)', 'Catalan (cat)', 'Gaulish (cel-gau)',
#        'Welsh (cym)', 'Proto-Norse (gmq-pro)', 'Italian (ita)',
#        'Proto-Uralic (urj-pro)', 'Proto-Finnic (fiu-fin-pro)',
#        'Old English', 'Old Provençal (pro)', 'Old Irish (sga)',
#        'Old Cornish (oco)', 'Cornish (cor)', 'English',
#        'Proto-Baltic (bat-pro)', 'Friulian (fur)',
#        'Old Portuguese (roa-opt)', 'Galician (glg)', 'Aragonese (arg)',
#        'Asturian (ast)', 'Spanish (spa)', 'Cebuano (ceb)', 'Welsh',
#        'Albanian (sqi)', 'Old Turkic (otk)',
#        'Proto-Austronesian (map-pro)', 'Icelandic (isl)', 'Jarai (jra)',
#        'Ancient Greek (grc)', 'Late Latin (LL)', 'Azerbaijani (aze)',
#        'Gutnish (gmq-gut)', 'Serbo-Croatian (hbs)', 'Hungarian (hun)',
#        'Proto-Indo-Iranian (iir-pro)', 'Proto-Iranian (ira-pro)',
#        'Old Persian (peo)', 'Middle Persian (pal)', 'Persian (fas)',
#        'Breton', 'Portuguese (por)', 'Sãotomense (cri)', 'Akkadian (akk)',
#        'Northern Kurdish (kmr)', 'Somali (som)',
#        'Proto-Malayo-Polynesian (poz-pro)', 'Proto-Malayic (poz-mly-pro)',
#        'Proto-Indo-Aryan (inc-pro)', 'Sanskrit (san)', 'Pali (pli)',
#        'Proto-Algonquian (alg-pro)', 'Abenaki (abe)', 'Japanese (jpn)',
#        'Finnish (fin)', 'Old French (fro)', 'Franco-Provençal (frp)',
#        'Slovenian (slv)', 'Proto-Arawakan (awd-pro)',
#        'Proto-Ta-Arawakan (awd-taa-pro)', 'Arawak (arw)',
#        'Proto-Chadic (cdc-pro)', 'Proto-Central Chadic (cdc-cbm-pro)',
#        'Old High German', 'Occitan (post 1500) (oci)', 'Swedish (swe)',
#        'Tagalog (tgl)', 'Zulu (zul)', 'Hebrew (heb)', 'Yiddish (yid)',
#        'Scots (sco)', 'Tocharian A (xto)', 'Estonian (est)',
#        'Wauja (wau)', 'Polish (pol)', 'Slovak (slk)', 'Chuukese (chk)',
#        'Latin', 'Romansh (roh)', 'Sicilian (scn)', 'Sardinian (srd)',
#        'Old Frisian (ofs)', 'Saterland Frisian (stq)', 'Nias (nia)',
#        'Aromanian (rup)', 'Irish (gle)', 'Plains Cree (crk)',
#        'Old English (ca. 450-1100) (ang)',
#        'Middle English (1100-1500) (enm)', 'North Frisian (frr)',
#        'Ingrian (izh)', 'Karelian (krl)', 'Ludian (lud)', 'Livvi (olo)',
#        'Proto-Albanian (sqj-pro)', 'Veps (vep)', 'Middle French (frm)',
#        'Haitian (hat)', 'Kristang (mcm)', 'Mauritian Creole',
#        'Serbo-Croatian', 'Swahili (macrolanguage) (swa)',
#        'Romanian (ron)', 'Turkish', 'Old Anatolian Turkish (trk-oat)',
#        'Afrikaans (afr)', 'Catalan', 'Fala (fax)',
#        'Proto-Sunda-Sulawesi (poz-sus-pro)',
#        'Proto-Malayo-Sumbawan (poz-msa-pro)',
#        'Proto-Malayo-Chamic (poz-mcm-pro)', 'Eastern Cham (cjm)',
#        'Korlai Creole Portuguese (vkp)', 'Proto-Permic (urj-prm-pro)',
#        'Volapük (vol)', 'Phuthi', 'Turkmen (tuk)', 'Old Armenian (xcl)',
#        'Armenian (hye)', 'Tok Pisin (tpi)', 'Kikuyu (kik)',
#        'Nyanja (nya)', 'Anglo-Norman (xno)', 'Middle Irish (mga)',
#        'Kalasha (kls)', 'Classical Syriac (syc)', 'Venetian (vec)',
#        'Old Danish (gmq-oda)', 'Romani (rom)', 'Norwegian Nynorsk (nno)',
#        'German Low German (nds-de)', 'Western Frisian (fry)',
#        'Old Javanese (kaw)', 'Zazaki (zza)', 'Proto-Altaic (tut-pro)',
#        'Proto-Mon-Khmer (mkh-pro)', 'Vietnamese (vie)',
#        'Vulgar Latin (la-vul)', 'Undetermined (und)', 'Hiligaynon (hil)',
#        'Tiruray (tiy)', 'Proto-Sino-Tibetan (sit-pro)', 'Dimasa (dis)',
#        'Balinese (ban)', 'Dairi Batak (btd)', 'Karo Batak (btx)',
#        'Makasar (mak)', 'Simeulue (smr)', 'Maranao (mrw)',
#        'Lithuanian (lit)', 'Navajo (nav)', 'Chinese (zho)',
#        'Walloon (wln)', 'French', 'Norn (nrn)', 'Mongolian (mon)',
#        'Northern Yukaghir (ykg)', 'Old French (842-ca. 1400) (fro)',
#        'Middle French (ca. 1400-1600) (frm)', 'Baure (brg)',
#        'Kinyarwanda (kin)', 'Ojibwa (oji)', 'Lower Sorbian (dsb)',
#        'Cantonese (yue)', 'Proto-Hellenic (grk-pro)',
#        'Proto-Polynesian (poz-pol-pro)', 'Hawaiian (haw)',
#        'Latvian (lav)', 'Telugu (tel)', 'Proto-Armenian (hyx-pro)',
#        'Old Spanish (osp)',
#        'Interlingua (International Auxiliary Language Association) (ina)',
#        'Icelandic', 'Malayalam (mal)', 'Basque (eus)', 'Kurdish (kur)',
#        'Mauritian Creole (mfe)', 'Western Apache (apw)', 'Umbrian (xum)',
#        'Andalusian Arabic (xaa)', 'Kashubian (csb)',
#        'Upper Sorbian (hsb)', "Brooke's Point Palawano (plw)",
#        'Proto-Central-Eastern Malayo-Polynesian (poz-cet-pro)',
#        'Proto-Eastern Malayo-Polynesian (pqe-pro)',
#        'Proto-Oceanic (poz-oce-pro)', 'Hawaiian', 'Tarantino (roa-tar)',
#        'Hindi (hin)', 'Salar (slr)', 'Proto-Bahnaric (aav-ban-pro)',
#        'Bahnar (bdq)', 'Old Breton (obt)', 'Middle Breton (xbm)', 'Scots',
#        'Pitjantjatjara (pjt)', 'Votic (vot)', "Yup'ik (esu)",
#        'Extremaduran (ext)', 'Istriot (ist)', 'Mirandese (mwl)',
#        'Old Welsh (owl)', 'West Germanic (gmw)',
#        'Khamnigan Mongol (xgn-kha)', 'Middle English', 'Scottish Gaelic',
#        'Church Slavic (chu)', 'Enawené-Nawé (unk)',
#        'Proto-Sogdic (ira-sgc-pro)', 'Yagnobi (yai)', 'Annobonese (fab)',
#        'Proto-Samic (smi-pro)', 'Southern Sami (sma)', 'Algonquin (alq)',
#        'Inari Sami (smn)', 'Avestan (ave)', 'Vilamovian (wym)',
#        'Classical Persian (fa-cls)', 'Talysh (tly)', 'Old Nubian (onw)',
#        'Nobiin (fia)', 'Dongxiang (sce)', 'Russian (rus)', 'Gusii (guz)',
#        'Pijin (pis)', 'Middle Dutch', 'Proto-Yeniseian (qfa-yen-pro)',
#        'Kott (zko)', 'Luxembourgish (ltz)', 'Low German (nds)',
#        'Old Dutch', 'Filipino (fil)', 'Ladino (lad)', 'Bilba (bpz)',
#        'Rapa Nui (rap)', 'Proto-Tai (tai-pro)', 'Zhuang (zha)', 'Dutch',
#        'Tok Pisin', 'Ancient Hebrew (hbo)', 'Sranan Tongo (srn)',
#        'Middle High German', 'Proto-Nuclear Polynesian (poz-pnp-pro)',
#        'Maori (mri)', 'Tahitian (tah)', 'Transalpine Gaulish (xtg)',
#        'Karajá (kpj)', 'Old Northern French (fro-nor)', 'Võro (vro)',
#        'Jamtish (gmq-jmk)', 'Indo-Portuguese (idb)', 'Gagauz',
#        'Proto-Philippine (phi-pro)', 'Aklanon (akl)', 'Bonan (peh)',
#        'Romagnol (rgn)', 'Karaim (kdr)', 'Yola (yol)', 'Palenquero (pln)',
#        'Proto-Uto-Aztecan (azc-pro)', 'Pipil (ppl)', 'Kriol (rop)',
#        'Lojban (jbo)', 'Hausa (hau)', 'Old Tupi (tpw)', 'Irish',
#        'Italian', 'Nauru (nau)', 'Gamilaraay (kld)', 'Piedmontese (pms)',
#        'Ilocano (ilo)', 'Corsican (cos)', 'Manchu (mnc)', 'Aynu (aib)',
#        'Danish', 'Uzbek (uzb)', 'Polabian (pox)', 'Norman (nrf)',
#        'Manx (glv)', 'Proto-Finno-Ugric (fiu-pro)', 'Novial (nov)',
#        'Faroese', 'Proto-Afro-Asiatic (afa-pro)', 'Mandarin (cmn)',
#        'Proto-Loloish (tbq-lol-pro)', 'Old Chinese (och)',
#        'Min Nan (nan)', 'Crimean Gothic (gme-cgo)',
#        'Proto-Tibeto-Burman (tbq-pro)', 'Turkmen', 'Jamtish',
#        'Central Kurdish (ckb)', 'Crimean Tatar', 'Skolt Sami (sms)',
#        'Middle Welsh (wlm)', 'Dadibi (mps)',
#        'Samoan Plantation Pidgin (cpe-spp)', 'Chagatai (chg)',
#        'Classical Nahuatl (nci)', 'Norwegian Bokmål',
#        'Guinea-Bissau Creole (pov)', 'Tupi (tup)',
#        'Nigerian Pidgin (pcm)', 'Old East Slavic (orv)', 'Hungarian',
#        'Norman', 'Dacian (xdc)', 'Old Khmer (mkh-okm)',
#        'Angkorian Old Khmer (mkh-okm-A)', 'Samoan (smo)', 'Swati (ssw)',
#        'Xhosa (xho)', 'Central Franconian (gmw-cfr)', 'Banjarese (bjn)',
#        'Proto-South Sulawesi (poz-ssw-pro)', 'Buginese (bug)',
#        'Proto-Chamic (cmc-pro)', 'Proto-North Sarawak (poz-swa-pro)',
#        'Central Melanau (mel)', 'Chavacano (cbk)', 'German',
#        'Yucatec Maya (yua)', 'Mayan (myn)', 'Modern Greek (1453-) (ell)',
#        'Nahuatl (nah)', 'Navarro-Aragonese (roa-oan)',
#        'Old Leonese (roa-ole)', 'Interlingue (ile)', 'Tamil (tam)',
#        'Proto-Samoyedic (syd-pro)', 'Manx', 'Tukudede (tkd)',
#        'Leonese (roa-leo)', 'Bargam (mlp)', 'Takia (tbc)', 'Celtic (cel)',
#        'Kanuri (kau)', 'Michif (crg)', 'Chrau (crw)', 'Emilian (egl)',
#        'Czech', 'Late Middle Chinese (ltc)', 'Middle Chinese (ltc)',
#        'Ancient Greek (to 1453) (grc)', 'Common Turkic (trk-cmn)',
#        'Urdu (urd)', 'Seychellois Creole (crs)', 'Antillean Creole (gcf)',
#        'Guianese Creole (gcr)', 'Haitian', 'Karipúna Creole French (kmv)',
#        'Limburgan (lim)', 'Bikol Central (bcl)', 'Indonesian',
#        'Puyuma (pyu)', 'Germanic (gem)', 'Azerbaijani',
#        'Chinese (family) (zhx)', 'Cebuano', 'Chamorro (cha)',
#        'Northern Sami (sme)', 'Louisiana Creole French (lou)',
#        'Gothic (got)', 'Jingpho (kac)', 'Mizo (lus)', 'Buruwai (asi)',
#        'Neapolitan (nap)', 'Ter Sami (sjt)', 'Westrobothnian', 'Swedish',
#        'Garifuna (cab)', 'Livonian (liv)', 'Oscan (osc)',
#        'Langobardic (lng)', 'Old Italian (it-oit)', 'Chamicuro (ccc)',
#        'Jamaican Creole (jam)', 'Niuean (niu)', 'Translingual (mul)',
#        'Middle Armenian (axm)', 'Galician', 'Romansh', 'Apatani (apt)',
#        'Egyptian (egy)', 'Demotic (egx-dem)', 'Ligurian (lij)',
#        'Kangjia (kxs)', "Palu'e (ple)", 'Tocharian B (txb)',
#        'Kimbundu (kmb)', 'Kalaallisut (kal)', 'Iban (iba)',
#        'West Coast Bajau (bdr)', 'Pareci (pab)', 'New Latin (la-new)',
#        'Shona (sna)', 'Picard (pcd)', 'Old Czech (zlw-ocs)',
#        'Fijian (fij)', 'Alemannic German (gsw)', 'Parthian (xpr)',
#        'Mòcheno (mhn)', 'Proto-Nubian (nub-pro)', 'Dilling (dil)',
#        'Koine Greek (Koine)', 'Kabuverdianu (kea)', 'Portuguese',
#        'Finnish', 'Korean (kor)', 'Baré (bae)', 'Palikur (plu)', 'Polish',
#        'Old Prussian (prg)', 'Scanian (gmq-scy)', 'Quechua (que)',
#        'Kichwa (qwe-kch)', 'Ron (cla)',
#        'Proto-Eastern Polynesian (poz-pep-pro)', 'Western Arrernte (are)',
#        'Old Uyghur (oui)', 'Moken (mwt)', 'West Flemish (vls)',
#        'Tatar (tat)', 'Dutch Low Saxon (nds-nl)', 'Old Japanese (ojp)',
#        'Gujarati (guj)', 'Marathi (mar)', 'Doric Greek (grc-dor)',
#        'Sumerian (sux)', 'Ecclesiastical Latin (la-ecc)',
#        'Attic Greek (grc-att)', 'Byzantine Greek (gkm)',
#        'Proto-Basque (euq-pro)', 'Tat (ttt)',
#        'Proto-Pama-Nyungan (aus-pam-pro)',
#        'Proto-Central New South Wales (aus-cww-pro)', 'Erzya (myv)',
#        'Proto-Vietic (mkh-vie-pro)', 'Southern Sotho (sot)', 'Swati',
#        'Xhosa', 'Zulu', 'Shawnee (sjw)', 'Faliscan (xfa)',
#        'Old Polish (zlw-opl)', 'Bulgarian (bul)',
#        'Proto-Eskimo (esx-esk-pro)', 'Proto-Inuit (esx-inu-pro)', 'Kriol',
#        'Ankave (aak)', 'Mozarabic (mxi)', 'Champenois (roa-cha)',
#        'Chavacano', 'Cuvok (cuv)', 'Berber (ber)', 'Tarifit (rif)',
#        'Ladin (lld)', 'Choctaw (cho)', 'Kipchak (qwm)',
#        'Narragansett (xnt)', 'Fiji Hindi (hif)', 'Romanian',
#        'Proto-Tocharian (ine-toc-pro)', 'Afrikaans', 'Palauan (pau)',
#        'Jehai (jhi)', 'Kensiu (kns)', 'Hausa', 'Tetum (tet)', 'Friulian',
#        'Proto-Ugric (urj-ugr-pro)', 'Kulon-Pazeh (uun)',
#        'Proto-Tupian (tup-pro)', 'Awetí (awe)',
#        'Proto-Tupi-Guarani (tup-gua-pro)', 'Kamayurá (kay)',
#        'Sateré-Mawé (mav)', 'Yue Chinese (yue)',
#        'Tagakaulu Kalagan (klg)', 'Mussau-Emira (emi)',
#        'Sauraseni Prakrit (psu)', 'Sauraseni Apabhramsa (inc-sap)',
#        'Old Hindi (inc-ohi)', 'Bende (bdp)', 'Nupe (nup)',
#        'Galibi Carib (car)', 'Egyptian (Ancient) (egy)', 'Halang (hal)',
#        'Thai (tha)', 'Baniwa (bwi)', 'Wayuu (guc)', 'Bengali (ben)',
#        'Limos Kalinga (kmk)', 'Lubuagan Kalinga (knb)', 'Daur (dta)',
#        'Lombard (lmo)', 'Waray-Waray (war)', 'Eman (emn)', 'Bunun (bnn)',
#        'Bintulu (bny)', 'Lombardic (Lombardic)',
#        'Old Provençal (to 1500) (pro)', 'Pite Sami (sje)',
#        'Lule Sami (smj)', 'Luhya (luy)', 'ǃXóõ (nmn)',
#        'Proto-Athabaskan (ath-pro)', 'Torres Strait Creole (tcs)',
#        'Chinook Jargon (chn)', 'Mwani (wmw)', 'Haeke (aek)', 'Fwâi (fwa)',
#        'Middle Low German', 'Haveke (hvk)', 'Jawe (jaz)',
#        'North Ambrym (mmg)', 'Kamba (kam)', 'Inupiaq (ipk)',
#        'Nyishi (njz)', 'Proto-Tani (sit-tan-pro)', 'Inuktitut (iku)',
#        'Matigsalug Manobo (mbt)', 'Phoenician (phn)', 'Bambara (bam)',
#        'Old Catalan (roa-oca)', 'Latvian', 'Celtiberian (xce)',
#        'Elfdalian (ovd)', 'Papiamentu (pap)', 'Dobu (dob)', 'Old Norse',
#        'Numbami (sij)', 'Meriam (ulk)', 'Arapaho (arp)', 'Venda (ven)',
#        'Ganda (lug)', 'Proto-Nawiki (awd-nwk-pro)', 'Curripaco (kpc)',
#        'Old Saxon', 'Old Irish (to 900) (sga)', 'Suevic (gem-sue)',
#        'Betawi (bew)', 'Tibetan (bod)', 'Bwatoo (bwa)',
#        'Pangasinan (pag)', 'Wolof (wol)', 'Angevin (roa-ang)',
#        'Hittite (hit)', 'Adyghe (ady)', 'Kabardian (kbd)',
#        'Tokharian B (txb)', 'Rennellese (mnv)', 'Nukuoro (nkr)',
#        'Middle Cornish (cnx)', 'Paraguayan Guaraní (gug)',
#        'South Marquesan (mqm)', 'Rohingya (rhg)', 'Aramaic (arc)',
#        'Scythian (xsc)', 'Toba Batak (bbc)', 'Batad Ifugao (ifb)',
#        'German Low German', 'Primitive Irish (pgl)', 'Aleut (ale)',
#        'Tundra Nenets (yrk)', 'Binukid (bkd)', 'Aromanian', 'Old Frisian',
#        'Maquiritari (mch)', 'Proto-Algic (aql-pro)',
#        'Proto-Finno-Permic (urj-fpr-pro)', 'Old Irish', 'Sogdian (sog)',
#        'Baiso (bsw)', 'Ido', 'Wallisian (wls)', 'Guugu Yimidhirr (kky)',
#        'Megleno-Romanian (ruq)', 'Vietnamese', 'Slovincian (zlw-slv)',
#        'Javanese', 'Kirghiz (kir)', 'Swahili', 'Kavalan (ckv)',
#        'Maguindanao (mdh)', 'Early Scots (sco-osc)', 'Tai Dam (blt)',
#        'Slovak', 'Molise Croatian (svm)', 'Potawatomi (pot)',
#        'Miami (mia)', 'Muong (mtq)', 'Proto-Kartvelian (ccs-pro)',
#        'Cimbrian (cim)', 'Pumpokol (xpm)', 'Angolar (aoa)',
#        'Malagasy (mlg)', 'Marshallese (mah)',
#        'Rhine Franconian (gmw-rfr)', 'Malay', 'Kapampangan (pam)',
#        'Taos (twf)', 'Kala Lagaw Ya (mwp)', 'Shuswap (shs)',
#        'Pre-Angkorian Old Khmer (mkh-okm-P)', 'Plautdietsch (pdt)',
#        'Egyptian', 'Atikamekw (atj)', 'Wiyot (wiy)', 'Iberian (xib)',
#        'Proto-Nahuan (azc-nah-pro)', 'Chuvash (chv)'], dtype=object)

# %%
lang_pair = "French (fra)"  # English (eng), English, Turkish (tur), Turkish, German (deu), French (fra), French, Spanish (spa), Arabic (ara), Russian (rus), Portuguese (por),Portuguese

# %%
df_lang_pair = df_result2[(df_result2["language_main"] == f"{lang_folder.capitalize()}") & (df_result2["language"] == f"{lang_pair.capitalize()}")]
df_lang_pair
# Out:
#       search_word         dict_entry_main language_main  \
# 1443           şu                     şut       Turkish
# 6594          alo                     alo       Turkish
# 7506          tür                  türban       Turkish
# 7513          tür                  türban       Turkish
# 8111          çek                     çek       Turkish
# 9552         film                    film       Turkish
# 13650        test                    test       Turkish
# 13667       seksi                   seksi       Turkish
# 13668       seksi                   seksi       Turkish
# 16810        lord                    lord       Turkish
# 17809       taksi                   taksi       Turkish
# 17810       taksi                   taksi       Turkish
# 19123      futbol                  futbol       Turkish
# 19124      futbol                  futbol       Turkish
# 20871    romantik                romantik       Turkish
# 20872    romantik                romantik       Turkish
# 20873    romantik                romantik       Turkish
# 20874    romantik                romantik       Turkish
# 20918         maç                     maç       Turkish
# 23785       viski                   viski       Turkish
# 25245       radyo                   radyo       Turkish
# 26552     sandviç                 sandviç       Turkish
# 26554     sandviç                 sandviç       Turkish
# 27166        jüri                    jüri       Turkish
# 27239       lider                   lider       Turkish
# 27245       lider                   lider       Turkish
# 27619         kek                     kek       Turkish
# 29876         bağ  bağımlılık enjeksiyonu       Turkish
# 30321         şov                     şov       Turkish
# 30348         gül                     gül       Turkish
# 30900      kovboy                  kovboy       Turkish
# 30901      kovboy                  kovboy       Turkish
# 30902      kovboy                  kovboy       Turkish
# 33638     beyzbol                 beyzbol       Turkish
# 33639     beyzbol                 beyzbol       Turkish
# 34640      biftek                  biftek       Turkish
# 34641      biftek                  biftek       Turkish
# 34644      biftek               biftekkek       Turkish
# 34645      biftek               biftekkek       Turkish
# 34646      biftek               biftekkek       Turkish
# 36841        bağı  bağımlılık enjeksiyonu       Turkish
# 37487   basketbol               basketbol       Turkish
# 37488   basketbol               basketbol       Turkish
# 37489   basketbol               basketbol       Turkish
# 37490   basketbol               basketbol       Turkish
# 37491   basketbol               basketbol       Turkish
# 38884        boks                    boks       Turkish
# 39481       tenis                   tenis       Turkish
# 43928       sosis                   sosis       Turkish
# 45823         gey                     gey       Turkish
# 45824         gey                     gey       Turkish
# 45831         gey                     gey       Turkish
# 46017     bağımlı  bağımlılık enjeksiyonu       Turkish
# 46463     dijital                 dijital       Turkish
# 46465     dijital                 dijital       Turkish
# 51872    striptiz                striptiz       Turkish
# 51873    striptiz                striptiz       Turkish
#
#                                          definition_main  \
# 1443           (Noun) (football) shoot.(football) shoot.
# 6594   (Interjection) Hello (only when picking up the...
# 7506   (Noun) Turban (man’s and women’s head-dress).T...
# 7513   (Noun) Turban (man’s and women’s head-dress).T...
# 8111                 (Noun) Check, cheque.Check, cheque.
# 9552   (Noun) A medium used to capture images in a ca...
# 13650                                  (Noun) Test.Test.
# 13667                             (Adjective) Sexy.Sexy.
# 13668                             (Adjective) Sexy.Sexy.
# 16810                                  (Noun) Lord.Lord.
# 17809                                  (Noun) Taxi.Taxi.
# 17810                                  (Noun) Taxi.Taxi.
# 19123        (Noun) Football (soccer).Football (soccer).
# 19124        (Noun) Football (soccer).Football (soccer).
# 20871  (Adjective Noun) Poetical. Romanesque. Romanti...
# 20872  (Adjective Noun) Poetical. Romanesque. Romanti...
# 20873  (Adjective Noun) Poetical. Romanesque. Romanti...
# 20874  (Adjective Noun) Poetical. Romanesque. Romanti...
# 20918              (Noun) (sports) match.(sports) match.
# 23785              (Noun) Whiskey/whisky.Whiskey/whisky.
# 25245                                (Noun) Radio.Radio.
# 26552                          (Noun) Sandwich.Sandwich.
# 26554                          (Noun) Sandwich.Sandwich.
# 27166  (Noun) Jury (group in a court of law).Jury (gr...
# 27239  (Noun) Leader (of a party or organization).Lea...
# 27245  (Noun) Leader (of a party or organization).Lea...
# 27619                                  (Noun) Cake.Cake.
# 29876  (Noun) (server software) dependency injection....
# 30321                                            (Noun)
# 30348                                  (Noun) Rose.Rose.
# 30900                              (Noun) Cowboy.Cowboy.
# 30901                              (Noun) Cowboy.Cowboy.
# 30902                              (Noun) Cowboy.Cowboy.
# 33638                          (Noun) Baseball.Baseball.
# 33639                          (Noun) Baseball.Baseball.
# 34640                        (Noun) Beefsteak.Beefsteak.
# 34641                        (Noun) Beefsteak.Beefsteak.
# 34644  (Noun) (informal, rare) beefcake (such a male,...
# 34645  (Noun) (informal, rare) beefcake (such a male,...
# 34646  (Noun) (informal, rare) beefcake (such a male,...
# 36841  (Noun) (server software) dependency injection....
# 37487      (Noun) Basketball (sport).Basketball (sport).
# 37488      (Noun) Basketball (sport).Basketball (sport).
# 37489      (Noun) Basketball (sport).Basketball (sport).
# 37490      (Noun) Basketball (sport).Basketball (sport).
# 37491      (Noun) Basketball (sport).Basketball (sport).
# 38884            (Noun) (sports) boxing.(sports) boxing.
# 39481                              (Noun) Tennis.Tennis.
# 43928                            (Noun) Sausage.Sausage.
# 45823  (Noun) A gay, a homosexual male.A gay, a homos...
# 45824  (Noun) A gay, a homosexual male.A gay, a homos...
# 45831  (Noun) A gay, a homosexual male.A gay, a homos...
# 46017  (Noun) (server software) dependency injection....
# 46463                       (Adjective) Digital.Digital.
# 46465                       (Adjective) Digital.Digital.
# 51872                      (Noun) Striptease.Striptease.
# 51873                      (Noun) Striptease.Striptease.
#
#                  dict_entry       language  \
# 1443                  shoot  English (eng)
# 6594                 heaven  English (eng)
# 7506                 turban  English (eng)
# 7513                  tulip  English (eng)
# 8111                 cheque  English (eng)
# 9552                   film  English (eng)
# 13650                  test  English (eng)
# 13667                   sex  English (eng)
# 13668                  sexy  English (eng)
# 16810                  lord  English (eng)
# 17809             taximeter  English (eng)
# 17810                  taxi  English (eng)
# 19123                  foot  English (eng)
# 19124              football  English (eng)
# 20871                   -ic  English (eng)
# 20872               romance  English (eng)
# 20873                romant  English (eng)
# 20874              romantic  English (eng)
# 20918                   set  English (eng)
# 23785               whiskey  English (eng)
# 25245                 radio  English (eng)
# 26552              Sandwich  English (eng)
# 26554                 mouth  English (eng)
# 27166                  jury  English (eng)
# 27239                  lead  English (eng)
# 27245                leader  English (eng)
# 27619              nokehike  English (eng)
# 29876  dependency injection  English (eng)
# 30321                  show  English (eng)
# 30348                  goal  English (eng)
# 30900                   cow  English (eng)
# 30901                   boy  English (eng)
# 30902                cowboy  English (eng)
# 33638                  base  English (eng)
# 33639              baseball  English (eng)
# 34640                  beef  English (eng)
# 34641             beefsteak  English (eng)
# 34644                  beef  English (eng)
# 34645                  cake  English (eng)
# 34646              beefcake  English (eng)
# 36841  dependency injection  English (eng)
# 37487                basket  English (eng)
# 37488                  -ese  English (eng)
# 37489                 Sudan  English (eng)
# 37490              Sudanese  English (eng)
# 37491            basketball  English (eng)
# 38884             box seats  English (eng)
# 39481                tennis  English (eng)
# 43928             salt mine  English (eng)
# 45823                gender  English (eng)
# 45824                 queer  English (eng)
# 45831                   kay  English (eng)
# 46017  dependency injection  English (eng)
# 46463                 digit  English (eng)
# 46465               digital  English (eng)
# 51872                 strip  English (eng)
# 51873            striptease  English (eng)
#
#                                               definition
# 1443   (mining) A vein of ore running in the same gen...
# 6594   (Christianity, Islam) The afterlife of the sou...
# 7506   A man's headdress made by winding a length of ...
# 7513   A type of flowering plant, genus Tulipa.. The ...
# 8111   (Australia, Canada, India, New Zealand, UK) A ...
# 9552   (cinema, uncountable) Film or movies as a grou...
# 13650  (obsolete) A witness. (obsolete) To make a tes...
# 13667  (chiefly, US, colloquial, intransitive) To hav...
# 13668  (mathematics) Used to describe prime numbers t...
# 16810  (intransitive, and, transitive) Domineer or ac...
# 17809  A device installed in a taxicab that calculate...
# 17810  To move an aircraft on the ground under its ow...
# 19123  (countable) A biological structure found in ma...
# 19124  (Australia, Ireland, New Zealand) rugby union....
# 20871  (chemistry) Used to denote certain chemical co...
# 20872  (intransitive) To write or tell romantic stori...
# 20873                                                NaN
# 20874  (chiefly, _, historical) Of a work of literatu...
# 20918  (UK, education) To divide a class group in a s...
# 23785  (Ireland, US) A drink of whiskey.. (Ireland, U...
# 25245  (intransitive, transitive, ambitransitive) To ...
# 26552  A town in Kent, south-east England, one of the...
# 26554  (obsolete) To form or cleanse with the mouth; ...
# 27166  (nautical) For temporary use; applied to a tem...
# 27239  (acting) The actor who plays the main role; le...
# 27245  (UK) The first, or the principal, editorial ar...
# 27619                                                NaN
# 29876  (software architecture) A type-safe way of sup...
# 30321  (baseball, with "the") The major leagues.. (co...
# 30348  (Gaelic football, Australian rules) To score a...
# 30900  (biology) A female member of other large speci...
# 30901  (transitive) to act as a boy (in allusion to t...
# 30902  (intransitive) To work as a cowboy, herding ca...
# 33638  (acrobatics, cheerleading) To act as a base; t...
# 33639  A sport common in North America, the Caribbean...
# 34640  (AAVE, intransitive, slang) To feud or hold a ...
# 34641  (countable) A beefsteak mushroom.. (countable)...
# 34644  (AAVE, intransitive, slang) To feud or hold a ...
# 34645  (slang) A trivially easy task or responsibilit...
# 34646  (informal, countable) Such a male, especially ...
# 36841  (software architecture) A type-safe way of sup...
# 37487  To place in a basket or in baskets. (UK, slang...
# 37488  Used to form adjectives and nouns describing t...
# 37489  (historical) Mali (when it was under French co...
# 37490  Of, from, or pertaining to the country of Suda...
# 37491  (basketball, countable) The particular kind of...
# 38884                                                NaN
# 39481  (dated) A match in this sport.. (obsolete) An ...
# 43928  (by extension) Any laborious work situation, e...
# 45823  (grammar). (grammar) A division of nouns and p...
# 45824  (UK, dialect, dated) To puzzle.. (slang, dated...
# 45831  (colloquial) A kilometer.. The name of the Lat...
# 46017  (software architecture) A type-safe way of sup...
# 46463  (anatomy) A narrow extremity of the human hand...
# 46465  Having to do with digits (fingers or toes); pe...
# 51872  (intransitive) To fail in the thread; to lose ...
# 51873  The act of slowly taking off one's clothes to ...

# %%
df_lang_pair = df_lang_pair.drop_duplicates(subset="dict_entry_main")
df_lang_pair.reset_index(drop=True, inplace=True)
df_lang_pair
# Out:
#    search_word         dict_entry_main language_main  \
# 0           şu                     şut       Turkish
# 1          alo                     alo       Turkish
# 2          tür                  türban       Turkish
# 3          çek                     çek       Turkish
# 4         film                    film       Turkish
# 5         test                    test       Turkish
# 6        seksi                   seksi       Turkish
# 7         lord                    lord       Turkish
# 8        taksi                   taksi       Turkish
# 9       futbol                  futbol       Turkish
# 10    romantik                romantik       Turkish
# 11         maç                     maç       Turkish
# 12       viski                   viski       Turkish
# 13       radyo                   radyo       Turkish
# 14     sandviç                 sandviç       Turkish
# 15        jüri                    jüri       Turkish
# 16       lider                   lider       Turkish
# 17         kek                     kek       Turkish
# 18         bağ  bağımlılık enjeksiyonu       Turkish
# 19         şov                     şov       Turkish
# 20         gül                     gül       Turkish
# 21      kovboy                  kovboy       Turkish
# 22     beyzbol                 beyzbol       Turkish
# 23      biftek                  biftek       Turkish
# 24      biftek               biftekkek       Turkish
# 25   basketbol               basketbol       Turkish
# 26        boks                    boks       Turkish
# 27       tenis                   tenis       Turkish
# 28       sosis                   sosis       Turkish
# 29         gey                     gey       Turkish
# 30     dijital                 dijital       Turkish
# 31    striptiz                striptiz       Turkish
#
#                                       definition_main            dict_entry  \
# 0           (Noun) (football) shoot.(football) shoot.                 shoot
# 1   (Interjection) Hello (only when picking up the...                heaven
# 2   (Noun) Turban (man’s and women’s head-dress).T...                turban
# 3                 (Noun) Check, cheque.Check, cheque.                cheque
# 4   (Noun) A medium used to capture images in a ca...                  film
# 5                                   (Noun) Test.Test.                  test
# 6                              (Adjective) Sexy.Sexy.                   sex
# 7                                   (Noun) Lord.Lord.                  lord
# 8                                   (Noun) Taxi.Taxi.             taximeter
# 9         (Noun) Football (soccer).Football (soccer).                  foot
# 10  (Adjective Noun) Poetical. Romanesque. Romanti...                   -ic
# 11              (Noun) (sports) match.(sports) match.                   set
# 12              (Noun) Whiskey/whisky.Whiskey/whisky.               whiskey
# 13                                (Noun) Radio.Radio.                 radio
# 14                          (Noun) Sandwich.Sandwich.              Sandwich
# 15  (Noun) Jury (group in a court of law).Jury (gr...                  jury
# 16  (Noun) Leader (of a party or organization).Lea...                  lead
# 17                                  (Noun) Cake.Cake.              nokehike
# 18  (Noun) (server software) dependency injection....  dependency injection
# 19                                            (Noun)                   show
# 20                                  (Noun) Rose.Rose.                  goal
# 21                              (Noun) Cowboy.Cowboy.                   cow
# 22                          (Noun) Baseball.Baseball.                  base
# 23                        (Noun) Beefsteak.Beefsteak.                  beef
# 24  (Noun) (informal, rare) beefcake (such a male,...                  beef
# 25      (Noun) Basketball (sport).Basketball (sport).                basket
# 26            (Noun) (sports) boxing.(sports) boxing.             box seats
# 27                              (Noun) Tennis.Tennis.                tennis
# 28                            (Noun) Sausage.Sausage.             salt mine
# 29  (Noun) A gay, a homosexual male.A gay, a homos...                gender
# 30                       (Adjective) Digital.Digital.                 digit
# 31                      (Noun) Striptease.Striptease.                 strip
#
#          language                                         definition
# 0   English (eng)  (mining) A vein of ore running in the same gen...
# 1   English (eng)  (Christianity, Islam) The afterlife of the sou...
# 2   English (eng)  A man's headdress made by winding a length of ...
# 3   English (eng)  (Australia, Canada, India, New Zealand, UK) A ...
# 4   English (eng)  (cinema, uncountable) Film or movies as a grou...
# 5   English (eng)  (obsolete) A witness. (obsolete) To make a tes...
# 6   English (eng)  (chiefly, US, colloquial, intransitive) To hav...
# 7   English (eng)  (intransitive, and, transitive) Domineer or ac...
# 8   English (eng)  A device installed in a taxicab that calculate...
# 9   English (eng)  (countable) A biological structure found in ma...
# 10  English (eng)  (chemistry) Used to denote certain chemical co...
# 11  English (eng)  (UK, education) To divide a class group in a s...
# 12  English (eng)  (Ireland, US) A drink of whiskey.. (Ireland, U...
# 13  English (eng)  (intransitive, transitive, ambitransitive) To ...
# 14  English (eng)  A town in Kent, south-east England, one of the...
# 15  English (eng)  (nautical) For temporary use; applied to a tem...
# 16  English (eng)  (acting) The actor who plays the main role; le...
# 17  English (eng)                                                NaN
# 18  English (eng)  (software architecture) A type-safe way of sup...
# 19  English (eng)  (baseball, with "the") The major leagues.. (co...
# 20  English (eng)  (Gaelic football, Australian rules) To score a...
# 21  English (eng)  (biology) A female member of other large speci...
# 22  English (eng)  (acrobatics, cheerleading) To act as a base; t...
# 23  English (eng)  (AAVE, intransitive, slang) To feud or hold a ...
# 24  English (eng)  (AAVE, intransitive, slang) To feud or hold a ...
# 25  English (eng)  To place in a basket or in baskets. (UK, slang...
# 26  English (eng)                                                NaN
# 27  English (eng)  (dated) A match in this sport.. (obsolete) An ...
# 28  English (eng)  (by extension) Any laborious work situation, e...
# 29  English (eng)  (grammar). (grammar) A division of nouns and p...
# 30  English (eng)  (anatomy) A narrow extremity of the human hand...
# 31  English (eng)  (intransitive) To fail in the thread; to lose ...

# %%
df_lang_pair.to_excel(f"{lang_folder.capitalize()}_And_{lang_pair.capitalize()}_Etymologeek_Result.xlsx", index=False)

# %% [markdown]
# #### Multi File Langauge Pair

# %%
#all_etymologeek_file = glob.glob("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/*/*_Etymologeek_Main_And_Additional_Result.xlsx")
#all_etymologeek_file

# %%
#df_etymologeek_all = pd.DataFrame()
#for i in all_etymologeek_file:
#    df_var = pd.read_excel(f"{i}")
#    df_etymologeek_all = pd.concat([df_etymologeek_all, df_var], axis=0)
#df_etymologeek_all.drop_duplicates(inplace=True)
#df_etymologeek_all.reset_index(drop=True, inplace=True)
#df_etymologeek_all

# %%
#df_etymologeek_all.to_excel("All_Etymology_Language_Pair_Result.xlsx", index=False)

# %%
df_etymologeek_all = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/All_Etymology_Language_Pair_Result.xlsx")
df_etymologeek_all
# Out:
#        search_word dict_entry_main   language_main  \
# 0              bir             bir   Crimean Tatar
# 1              bir             bir   Crimean Tatar
# 2              bir             bir  Middle English
# 3              bir             bir  Middle English
# 4              bir             bir  Middle English
# ...            ...             ...             ...
# 668525        إلين           إلينا          Arabic
# 668526       مستقر           مستقر          Arabic
# 668527       مستقر           مستقر          Arabic
# 668528        صيني           صينية          Arabic
# 668529        صيني           صينية          Arabic
#
#                                           definition_main       dict_entry  \
# 0                (Numeral) (cardinal) one.(cardinal) one.             *bīr
# 1                (Numeral) (cardinal) one.(cardinal) one.              bir
# 2       (Noun) A charge on an account.. A strong or fa...           *buriz
# 3       (Noun) A charge on an account.. A strong or fa...        *bʰrewh₁-
# 4       (Noun) A charge on an account.. A strong or fa...           *buriz
# ...                                                   ...              ...
# 668525                              (Adverb) To us.To us.            إلينا
# 668526  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668528  (Noun) (usually definite) Chinese language.(us...  لُغَة صِينِيَّة
# 668529  (Noun) (usually definite) Chinese language.(us...            صينية
#
#                              language  \
# 0              Proto-Turkic (trk-pro)
# 1                 Crimean Tatar (crh)
# 2            Proto-Germanic (gem-pro)
# 3       Proto-Indo-European (ine-pro)
# 4            Proto-Germanic (gem-pro)
# ...                               ...
# 668525                   Arabic (ara)
# 668526                         Arabic
# 668527                         Arabic
# 668528                   Arabic (ara)
# 668529                   Arabic (ara)
#
#                                                definition
# 0                                                    One.
# 1                                         (cardinal) one.
# 2                                    Male offspring; son.
# 3                                                     NaN
# 4                                        Elevation; hill.
# ...                                                   ...
# 668525                                             To us.
# 668526  (Adjective) Confessing. Firm, solid, stable. F...
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...
# 668528                                                NaN
# 668529               (usually definite) Chinese language.
#
# [668530 rows x 7 columns]

# %%
#df_etymologeek_all["language_main"].unique()

# %%
#df_etymologeek_all["language"].unique()

# %%
lang_1 = "Turkish"
lang_2 = "English"  # English (eng), English, Turkish (tur), Turkish, German (deu), French (fra), French, Spanish (spa), Arabic (ara), Russian (rus), Portuguese (por),Portuguese

# %%
df_lang_pair_all = df_etymologeek_all[(df_etymologeek_all["language_main"] == f"{lang_1.capitalize()}") & (df_etymologeek_all["language"] == f"{lang_2.capitalize()}")]
df_lang_pair_all
# Out:
# Empty DataFrame
# Columns: [search_word, dict_entry_main, language_main, definition_main, dict_entry, language, definition]
# Index: []

# %%
df_lang_pair_all = df_lang_pair_all.drop_duplicates(subset="dict_entry_main")
df_lang_pair_all.reset_index(drop=True, inplace=True)
df_lang_pair_all
# Out:
#    search_word         dict_entry_main language_main  \
# 0           şu                     şut       Turkish
# 1          alo                     alo       Turkish
# 2          tür                  türban       Turkish
# 3          çek                     çek       Turkish
# 4         film                    film       Turkish
# 5         test                    test       Turkish
# 6        seksi                   seksi       Turkish
# 7         lord                    lord       Turkish
# 8        taksi                   taksi       Turkish
# 9       futbol                  futbol       Turkish
# 10    romantik                romantik       Turkish
# 11         maç                     maç       Turkish
# 12       viski                   viski       Turkish
# 13       radyo                   radyo       Turkish
# 14     sandviç                 sandviç       Turkish
# 15        jüri                    jüri       Turkish
# 16       lider                   lider       Turkish
# 17         kek                     kek       Turkish
# 18         bağ  bağımlılık enjeksiyonu       Turkish
# 19         şov                     şov       Turkish
# 20         gül                     gül       Turkish
# 21      kovboy                  kovboy       Turkish
# 22     beyzbol                 beyzbol       Turkish
# 23      biftek                  biftek       Turkish
# 24      biftek               biftekkek       Turkish
# 25   basketbol               basketbol       Turkish
# 26        boks                    boks       Turkish
# 27       tenis                   tenis       Turkish
# 28       sosis                   sosis       Turkish
# 29         gey                     gey       Turkish
# 30     dijital                 dijital       Turkish
# 31    striptiz                striptiz       Turkish
# 32       frans               fransiyum       Turkish
# 33         kok                     kok       Turkish
# 34        site                    site       Turkish
# 35         dok                     dok       Turkish
# 36      bikini                  bikini       Turkish
# 37      pijama                  pijama       Turkish
# 38      basket                  basket       Turkish
# 39     destroy               destroyer       Turkish
# 40         sos                     sos       Turkish
#
#                                       definition_main            dict_entry  \
# 0           (Noun) (football) shoot.(football) shoot.                 shoot
# 1   (Interjection) Hello (only when picking up the...                heaven
# 2   (Noun) Turban (man’s and women’s head-dress).T...                turban
# 3                 (Noun) Check, cheque.Check, cheque.                cheque
# 4   (Noun) A medium used to capture images in a ca...                  film
# 5                                   (Noun) Test.Test.                  test
# 6                              (Adjective) Sexy.Sexy.                   sex
# 7                                   (Noun) Lord.Lord.                  lord
# 8                                   (Noun) Taxi.Taxi.             taximeter
# 9         (Noun) Football (soccer).Football (soccer).                  foot
# 10  (Adjective Noun) Poetical. Romanesque. Romanti...                   -ic
# 11              (Noun) (sports) match.(sports) match.                   set
# 12              (Noun) Whiskey/whisky.Whiskey/whisky.               whiskey
# 13                                (Noun) Radio.Radio.                 radio
# 14                          (Noun) Sandwich.Sandwich.              Sandwich
# 15  (Noun) Jury (group in a court of law).Jury (gr...                  jury
# 16  (Noun) Leader (of a party or organization).Lea...                  lead
# 17                                  (Noun) Cake.Cake.              nokehike
# 18  (Noun) (server software) dependency injection....  dependency injection
# 19                                            (Noun)                   show
# 20                                  (Noun) Rose.Rose.                  goal
# 21                              (Noun) Cowboy.Cowboy.                   cow
# 22                          (Noun) Baseball.Baseball.                  base
# 23                        (Noun) Beefsteak.Beefsteak.                  beef
# 24  (Noun) (informal, rare) beefcake (such a male,...                  beef
# 25      (Noun) Basketball (sport).Basketball (sport).                basket
# 26            (Noun) (sports) boxing.(sports) boxing.             box seats
# 27                              (Noun) Tennis.Tennis.                tennis
# 28                            (Noun) Sausage.Sausage.             salt mine
# 29  (Noun) A gay, a homosexual male.A gay, a homos...                gender
# 30                       (Adjective) Digital.Digital.                 digit
# 31                      (Noun) Striptease.Striptease.                 strip
# 32                          (Noun) Francium.Francium.                France
# 33  (Noun Verb) Coke (coal product).Coke (coal pro...               cocaine
# 34  (Noun) (Internet) site, Web site. Buildings. C...                 civis
# 35                                  (Noun) Dock.Dock.                  dock
# 36                              (Noun) Bikini.Bikini.                Bikini
# 37                              (Noun) Pyjama.Pyjama.               pajamas
# 38  (Noun) Basket (basketball: act of putting the ...                basket
# 39                        (Noun) Destroyer.Destroyer.               destroy
# 40                                (Noun) Sauce.Sauce.                  mine
#
#          language                                         definition
# 0   English (eng)  (mining) A vein of ore running in the same gen...
# 1   English (eng)  (Christianity, Islam) The afterlife of the sou...
# 2   English (eng)  A man's headdress made by winding a length of ...
# 3   English (eng)  (Australia, Canada, India, New Zealand, UK) A ...
# 4   English (eng)  (cinema, uncountable) Film or movies as a grou...
# 5   English (eng)  (obsolete) A witness. (obsolete) To make a tes...
# 6   English (eng)  (chiefly, US, colloquial, intransitive) To hav...
# 7   English (eng)  (intransitive, and, transitive) Domineer or ac...
# 8   English (eng)  A device installed in a taxicab that calculate...
# 9   English (eng)  (countable) A biological structure found in ma...
# 10  English (eng)  (chemistry) Used to denote certain chemical co...
# 11  English (eng)  (UK, education) To divide a class group in a s...
# 12  English (eng)  (Ireland, US) A drink of whiskey.. (Ireland, U...
# 13  English (eng)  (intransitive, transitive, ambitransitive) To ...
# 14  English (eng)  A town in Kent, south-east England, one of the...
# 15  English (eng)  (nautical) For temporary use; applied to a tem...
# 16  English (eng)  (acting) The actor who plays the main role; le...
# 17  English (eng)                                                NaN
# 18  English (eng)  (software architecture) A type-safe way of sup...
# 19  English (eng)  (baseball, with "the") The major leagues.. (co...
# 20  English (eng)  (Gaelic football, Australian rules) To score a...
# 21  English (eng)  (biology) A female member of other large speci...
# 22  English (eng)  (acrobatics, cheerleading) To act as a base; t...
# 23  English (eng)  (AAVE, intransitive, slang) To feud or hold a ...
# 24  English (eng)  (AAVE, intransitive, slang) To feud or hold a ...
# 25  English (eng)  To place in a basket or in baskets. (UK, slang...
# 26  English (eng)                                                NaN
# 27  English (eng)  (dated) A match in this sport.. (obsolete) An ...
# 28  English (eng)  (by extension) Any laborious work situation, e...
# 29  English (eng)  (grammar). (grammar) A division of nouns and p...
# 30  English (eng)  (anatomy) A narrow extremity of the human hand...
# 31  English (eng)  (intransitive) To fail in the thread; to lose ...
# 32  English (eng)  A country in Western Europe which borders Belg...
# 33  English (eng)  (countable) Any derivative of cocaine.. (uncou...
# 34  English (eng)                                                NaN
# 35  English (eng)  (intransitive) To land at a harbour.. (transit...
# 36  English (eng)                                      Bikini atoll.
# 37  English (eng)  Clothes for wearing to bed and sleeping in, us...
# 38  English (eng)  To place in a basket or in baskets. (UK, slang...
# 39  English (eng)  (colloquial, transitive) To defeat soundly.. (...
# 40  English (eng)  (computing) A machine used to extract units of...

# %%
df_lang_pair_all.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result_All.xlsx", index=False)
