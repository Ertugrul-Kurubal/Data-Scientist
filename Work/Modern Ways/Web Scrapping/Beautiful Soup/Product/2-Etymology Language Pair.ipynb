# %% [markdown]
# ### Etymology Language Pair

# %%
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### Single Language Pair

# %%
lang_folder = "Turkish"  # Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_result2 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_folder.capitalize()}/{lang_folder.capitalize()}_Etymologeek_Main_And_Additional_Result.xlsx")
df_result2
# Out:
#       search_word dict_entry_main   language_main  \
# 0             bir             bir   Crimean Tatar
# 1             bir             bir   Crimean Tatar
# 2             bir             bir  Middle English
# 3             bir             bir  Middle English
# 4             bir             bir  Middle English
# ...           ...             ...             ...
# 54274         şah           şahin         Turkish
# 54275         şah           şahıs         Turkish
# 54276         şah           şahıs         Turkish
# 54277         şah           şahsi         Turkish
# 54278         şah           şahsi         Turkish
#
#                                          definition_main dict_entry  \
# 0               (Numeral) (cardinal) one.(cardinal) one.       *bīr
# 1               (Numeral) (cardinal) one.(cardinal) one.        bir
# 2      (Noun) A charge on an account.. A strong or fa...     *buriz
# 3      (Noun) A charge on an account.. A strong or fa...  *bʰrewh₁-
# 4      (Noun) A charge on an account.. A strong or fa...     *buriz
# ...                                                  ...        ...
# 54274                                (Noun) Buteo.Buteo.      şahin
# 54275                              (Noun) Person.Person.        شخص
# 54276                              (Noun) Person.Person.      şahıs
# 54277                     (Adjective) Personal.Personal.       شخصی
# 54278                     (Adjective) Personal.Personal.      şahsi
#
#                             language  \
# 0             Proto-Turkic (trk-pro)
# 1                Crimean Tatar (crh)
# 2           Proto-Germanic (gem-pro)
# 3      Proto-Indo-European (ine-pro)
# 4           Proto-Germanic (gem-pro)
# ...                              ...
# 54274                  Turkish (tur)
# 54275                   Arabic (ara)
# 54276                  Turkish (tur)
# 54277                  Persian (fas)
# 54278                  Turkish (tur)
#
#                                               definition
# 0                                                   One.
# 1                                        (cardinal) one.
# 2                                   Male offspring; son.
# 3                                                    NaN
# 4                                       Elevation; hill.
# ...                                                  ...
# 54274                                             Buteo.
# 54275  Figure, character. Person, individual. Someone...
# 54276                                            Person.
# 54277                                          Personal.
# 54278                                          Personal.
#
# [54279 rows x 7 columns]

# %%
#df_result2.language_main.unique()

# %%
#df_result2.language.unique()

# %%
lang_pair = "Turkish (tur)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), Portuguese (por), Dutch (nld), Italian (ita)

# %%
df_lang_pair = df_result2[(df_result2["language_main"] == f"{lang_folder.capitalize()}") & (df_result2["language"] == f"{lang_pair.capitalize()}")]
df_lang_pair
# Out:
#       search_word dict_entry_main language_main  \
# 99             bu              bu       Turkish
# 191          için           içine       Turkish
# 192          için           içine       Turkish
# 193          için           içine       Turkish
# 347           çok             çok       Turkish
# ...           ...             ...           ...
# 54257   saklanmak       saklanmak       Turkish
# 54266         şah             şah       Turkish
# 54274         şah           şahin       Turkish
# 54276         şah           şahıs       Turkish
# 54278         şah           şahsi       Turkish
#
#                                          definition_main dict_entry  \
# 99                                  (Pronoun) This.This.         bu
# 191                                    (Particle) In.In.        içi
# 192                                    (Particle) In.In.        -ne
# 193                                    (Particle) In.In.      içine
# 347    (Adjective) Much, many, plenty, a lot.Much, ma...        çok
# ...                                                  ...        ...
# 54257  (Verb) To hide (to put oneself in a place wher...  saklanmak
# 54266  (Noun) (chess) king. Shah, ruler.(chess) king....        şah
# 54274                                (Noun) Buteo.Buteo.      şahin
# 54276                              (Noun) Person.Person.      şahıs
# 54278                     (Adjective) Personal.Personal.      şahsi
#
#             language                                         definition
# 99     Turkish (tur)                                              This.
# 191    Turkish (tur)                                                NaN
# 192    Turkish (tur)                                                NaN
# 193    Turkish (tur)                                                In.
# 347    Turkish (tur)                         Much, many, plenty, a lot.
# ...              ...                                                ...
# 54257  Turkish (tur)  To hide (to put oneself in a place where one w...
# 54266  Turkish (tur)                         (chess) king. Shah, ruler.
# 54274  Turkish (tur)                                             Buteo.
# 54276  Turkish (tur)                                            Person.
# 54278  Turkish (tur)                                          Personal.
#
# [8647 rows x 7 columns]

# %%
df_lang_pair = df_lang_pair.drop_duplicates(subset="dict_entry_main")
df_lang_pair.reset_index(drop=True, inplace=True)
df_lang_pair
# Out:
#      search_word dict_entry_main language_main  \
# 0             bu              bu       Turkish
# 1           için           içine       Turkish
# 2            çok             çok       Turkish
# 3            çok        çokdilli       Turkish
# 4            çok     çokdillilik       Turkish
# ...          ...             ...           ...
# 3385        dadı            dadı       Turkish
# 3386    dağıtmak        dağıtmak       Turkish
# 3387         şah             şah       Turkish
# 3388         şah           şahin       Turkish
# 3389         şah           şahıs       Turkish
#
#                                         definition_main dict_entry  \
# 0                                  (Pronoun) This.This.         bu
# 1                                     (Particle) In.In.        içi
# 2     (Adjective) Much, many, plenty, a lot.Much, ma...        çok
# 3     (Adjective) Multilingual (pertaining to multip...      dilli
# 4               (Noun) Multilingualism.Multilingualism.       -lik
# ...                                                 ...        ...
# 3385                  (Noun) Nanny, nurse.Nanny, nurse.       dadı
# 3386  (Verb) (transitive) to cause (something) to br...   dağıtmak
# 3387  (Noun) (chess) king. Shah, ruler.(chess) king....        şah
# 3388                                (Noun) Buteo.Buteo.      şahin
# 3389                              (Noun) Person.Person.      şahıs
#
#            language                                         definition
# 0     Turkish (tur)                                              This.
# 1     Turkish (tur)                                                NaN
# 2     Turkish (tur)                         Much, many, plenty, a lot.
# 3     Turkish (tur)             (linguistic) lingual. Having a tongue.
# 4     Turkish (tur)                -hood. -ness. -ship. ... container.
# ...             ...                                                ...
# 3385  Turkish (tur)                                      Nanny, nurse.
# 3386  Turkish (tur)  (transitive) to cause (something) to break int...
# 3387  Turkish (tur)                         (chess) king. Shah, ruler.
# 3388  Turkish (tur)                                             Buteo.
# 3389  Turkish (tur)                                            Person.
#
# [3390 rows x 7 columns]

# %%
#df_lang_pair.to_excel(f"{lang_folder.capitalize()}_And_{lang_pair.capitalize()}_Etymologeek_Result.xlsx", index=False)

# %% [markdown]
# #### Multi File Langauge Pair

# %%
all_etymologeek_file = glob.glob("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/*/*_Etymologeek_Main_And_Additional_Result.xlsx")
all_etymologeek_file

# %%
df_etymologeek_all = pd.DataFrame()
for i in all_etymologeek_file:
    df_var = pd.read_excel(f"{i}")
    df_etymologeek_all = pd.concat([df_etymologeek_all, df_var], axis=0)
df_etymologeek_all.drop_duplicates(inplace=True)
df_etymologeek_all.reset_index(drop=True, inplace=True)
df_etymologeek_all

# %%
df_etymologeek_all.to_excel("All_Etymology_Language_Pair_Result.xlsx", index=False)

# %% [markdown]
# #### Read Etymologeek All Data

# %%
df_etymologeek_all = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/All_Etymology_Language_Pair_Result.xlsx")
df_etymologeek_all
# Out:
#        search_word dict_entry_main   language_main  \
# 0              bir             bir   Crimean Tatar
# 1              bir             bir   Crimean Tatar
# 2              bir             bir  Middle English
# 3              bir             bir  Middle English
# 4              bir             bir  Middle English
# ...            ...             ...             ...
# 668525        إلين           إلينا          Arabic
# 668526       مستقر           مستقر          Arabic
# 668527       مستقر           مستقر          Arabic
# 668528        صيني           صينية          Arabic
# 668529        صيني           صينية          Arabic
#
#                                           definition_main       dict_entry  \
# 0                (Numeral) (cardinal) one.(cardinal) one.             *bīr
# 1                (Numeral) (cardinal) one.(cardinal) one.              bir
# 2       (Noun) A charge on an account.. A strong or fa...           *buriz
# 3       (Noun) A charge on an account.. A strong or fa...        *bʰrewh₁-
# 4       (Noun) A charge on an account.. A strong or fa...           *buriz
# ...                                                   ...              ...
# 668525                              (Adverb) To us.To us.            إلينا
# 668526  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668528  (Noun) (usually definite) Chinese language.(us...  لُغَة صِينِيَّة
# 668529  (Noun) (usually definite) Chinese language.(us...            صينية
#
#                              language  \
# 0              Proto-Turkic (trk-pro)
# 1                 Crimean Tatar (crh)
# 2            Proto-Germanic (gem-pro)
# 3       Proto-Indo-European (ine-pro)
# 4            Proto-Germanic (gem-pro)
# ...                               ...
# 668525                   Arabic (ara)
# 668526                         Arabic
# 668527                         Arabic
# 668528                   Arabic (ara)
# 668529                   Arabic (ara)
#
#                                                definition
# 0                                                    One.
# 1                                         (cardinal) one.
# 2                                    Male offspring; son.
# 3                                                     NaN
# 4                                        Elevation; hill.
# ...                                                   ...
# 668525                                             To us.
# 668526  (Adjective) Confessing. Firm, solid, stable. F...
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...
# 668528                                                NaN
# 668529               (usually definite) Chinese language.
#
# [668530 rows x 7 columns]

# %%
#df_etymologeek_all["language_main"].unique()

# %%
#df_etymologeek_all["language"].unique()

# %%
lang_1 = "Italian"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Dutch (nld)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)

# %%
df_lang_pair1 = df_etymologeek_all[(df_etymologeek_all["language_main"] == f"{lang_1.capitalize()}") & (df_etymologeek_all["language"] == f"{lang_2.capitalize()}")]
df_lang_pair1
# Out:
#         search_word dict_entry_main language_main  \
# 81740           bom            boma       Italian
# 85750       collega       collegare       Italian
# 85751       collega       collegare       Italian
# 85758       collega       collegare       Italian
# 86234          boom            boom       Italian
# 142678         boss            boss       Italian
# 173138        tango         tangone       Italian
# 183968         colt           colta       Italian
# 183969         colt           colta       Italian
# 183971         colt           colta       Italian
# 187795       chance          chance       Italian
# 218276        droga           droga       Italian
# 267628   significar     significare       Italian
# 364025        yacht           yacht       Italian
# 364027        yacht           yacht       Italian
# 364031        yacht           yacht       Italian
# 394381       sketch          sketch       Italian
# 442823        trage        tragedia       Italian
# 503469     tragedia        tragedia       Italian
# 572720        pompe        pompelmo       Italian
# 584004        bilan        bilandro       Italian
# 596670        scusa           scusa       Italian
# 606408        segno           segno       Italian
# 606896      segnale         segnale       Italian
# 608571     cadavere        cadavere       Italian
# 609557       colore          colore       Italian
# 611322       cadere          cadere       Italian
# 612274       caduto          caduto       Italian
# 613728       caduta          caduta       Italian
# 615268           tè              tè       Italian
# 621280     corretto      correttore       Italian
# 623297        pacco           pacco       Italian
# 627582     politico        politico       Italian
# 627583     politico        politico       Italian
# 627675    insegnare       insegnare       Italian
# 631470      insegna       insegnare       Italian
# 636891        capra           capra       Italian
# 636936        capra     caprareccia       Italian
# 643210  significare     significare       Italian
# 647637      alloggi      alloggiare       Italian
# 649885      sigillo         sigillo       Italian
# 652262     cogliere        cogliere       Italian
# 652263     cogliere        cogliere       Italian
# 652269     cogliere        cogliere       Italian
# 654235    collegare       collegare       Italian
# 654236    collegare       collegare       Italian
# 654243    collegare       collegare       Italian
#
#                                           definition_main  dict_entry  \
# 81740             (Noun) (nautical) boom.(nautical) boom.        boom
# 85750   (Verb) (transitive) to colligate. (transitive)...      legere
# 85751   (Verb) (transitive) to colligate. (transitive)...        col-
# 85758   (Verb) (transitive) to colligate. (transitive)...   colligere
# 86234   (Noun) A boom (crane). A boom (sound). A boom,...        boom
# 142678  (Noun) Boss (leader of a business, company or ...        baas
# 173138  (Noun) (nautical) spinnaker pole.(nautical) sp...       tange
# 183968                                       (Adjective)       legere
# 183969                                       (Adjective)         col-
# 183971                                       (Adjective)    colligere
# 187795  (Noun) Chance (possibility of a certain outcom...        dice
# 218276                    (Noun) Drug. Spice.Drug. Spice.       droog
# 267628    (Verb) To mean, to signify.To mean, to signify.        sein
# 364025  (Noun) The letter Y in the Italian phonetic al...   jageschip
# 364027  (Noun) The letter Y in the Italian phonetic al...       jaght
# 364031  (Noun) The letter Y in the Italian phonetic al...      jaghte
# 394381  (Noun) Sketch, skit (short comic work).Sketch,...      schets
# 442823                            (Noun) Tragedy.Tragedy.     Dorians
# 503469                            (Noun) Tragedy.Tragedy.     Dorians
# 572720  (Noun) Grapefruit (fruit & tree).Grapefruit (f...  pompelmoes
# 584004  (Noun) (watercraft) bilander.(watercraft) bila...   bijlander
# 596670  (Noun Verb Interjection) Apology, excuse. Excu...     excuser
# 606408  (Noun) Indication. Mark, scratch. Sign. Target...        sein
# 606896                  (Noun) Signal, sign.Signal, sign.        sein
# 608571                  (Noun) Corpse, body.Corpse, body.        dice
# 609557                (Noun) Color, colour.Color, colour.       kleur
# 611322  (Verb) (intransitive) to die. (intransitive) t...        dice
# 612274  (Adjective Verb Noun) Dead. Fallen Dead soldie...        dice
# 613728  (Adjective Noun) Drop (i.e. temperature drop)....        dice
# 615268                                    (Noun) Tea.Tea.        thee
# 621280  (Noun) Concealer (cosmetic). Control. Correcti...   corrigere
# 623297  (Noun) (slang) bulge (visible protrusion of th...         pak
# 627582  (Adjective Noun) Political Politician.Politica...    politiek
# 627583  (Adjective Noun) Political Politician.Politica...       -icus
# 627675  (Verb) (intransitive, to act as a teacher) to ...        sein
# 631470  (Verb) (intransitive, to act as a teacher) to ...        sein
# 636891  (Noun) Goat (mammal). Nanny goat. Trestle.Goat...         bok
# 636936  (Noun) A shed used to keep goats indoors durin...         bok
# 643210    (Verb) To mean, to signify.To mean, to signify.        sein
# 647637  (Verb) (intransitive) To stay or lodge (at). (...      laubja
# 649885  (Noun Verb) Seal (that seals something).Seal (...        sein
# 652262  (Verb) (transitive) to grasp, seize, take. (tr...      legere
# 652263  (Verb) (transitive) to grasp, seize, take. (tr...        col-
# 652269  (Verb) (transitive) to grasp, seize, take. (tr...   colligere
# 654235  (Verb) (transitive) to colligate. (transitive)...      legere
# 654236  (Verb) (transitive) to colligate. (transitive)...        col-
# 654243  (Verb) (transitive) to colligate. (transitive)...   colligere
#
#            language                                         definition
# 81740   Dutch (nld)  Boom, as in a market explosion Any solid, pole...
# 85750   Dutch (nld)                                                NaN
# 85751   Dutch (nld)                                                NaN
# 85758   Dutch (nld)                                                NaN
# 86234   Dutch (nld)  Any solid, pole-shaped, usually wooden object....
# 142678  Dutch (nld)  (Belgium) strong or tough guy. (diminutive: ba...
# 173138  Dutch (nld)                                                NaN
# 183968  Dutch (nld)                                                NaN
# 183969  Dutch (nld)                                                NaN
# 183971  Dutch (nld)                                                NaN
# 187795  Dutch (nld)                                                NaN
# 218276  Dutch (nld)                                         Arid. Dry.
# 267628  Dutch (nld)                                            Signal.
# 364025  Dutch (nld)                                                NaN
# 364027  Dutch (nld)                                                NaN
# 364031  Dutch (nld)                                                NaN
# 394381  Dutch (nld)                                            Sketch.
# 442823  Dutch (nld)                                                NaN
# 503469  Dutch (nld)                                                NaN
# 572720  Dutch (nld)          Pomelo (fruit of the tree Citrus maxima).
# 584004  Dutch (nld)                                                NaN
# 596670  Dutch (nld)                                                NaN
# 606408  Dutch (nld)                                            Signal.
# 606896  Dutch (nld)                                            Signal.
# 608571  Dutch (nld)                                                NaN
# 609557  Dutch (nld)                    Color, colour. Suit (of cards).
# 611322  Dutch (nld)                                                NaN
# 612274  Dutch (nld)                                                NaN
# 613728  Dutch (nld)                                                NaN
# 615268  Dutch (nld)                                               Tea.
# 621280  Dutch (nld)                                                NaN
# 623297  Dutch (nld)                    Package. Suit (set of clothes).
# 627582  Dutch (nld)                                Politics Political.
# 627583  Dutch (nld)                                      -ic or ician.
# 627675  Dutch (nld)                                            Signal.
# 631470  Dutch (nld)                                            Signal.
# 636891  Dutch (nld)  (gymnastics) vaulting horse. (pejorative) chur...
# 636936  Dutch (nld)  (gymnastics) vaulting horse. (pejorative) chur...
# 643210  Dutch (nld)                                            Signal.
# 647637  Dutch (nld)                                                NaN
# 649885  Dutch (nld)                                            Signal.
# 652262  Dutch (nld)                                                NaN
# 652263  Dutch (nld)                                                NaN
# 652269  Dutch (nld)                                                NaN
# 654235  Dutch (nld)                                                NaN
# 654236  Dutch (nld)                                                NaN
# 654243  Dutch (nld)                                                NaN

# %%
df_lang_pair1 = df_lang_pair1.drop_duplicates(subset="dict_entry_main")
df_lang_pair1.reset_index(drop=True, inplace=True)
df_lang_pair1
# Out:
#    search_word dict_entry_main language_main  \
# 0          bom            boma       Italian
# 1      collega       collegare       Italian
# 2         boom            boom       Italian
# 3         boss            boss       Italian
# 4        tango         tangone       Italian
# 5         colt           colta       Italian
# 6       chance          chance       Italian
# 7        droga           droga       Italian
# 8   significar     significare       Italian
# 9        yacht           yacht       Italian
# 10      sketch          sketch       Italian
# 11       trage        tragedia       Italian
# 12       pompe        pompelmo       Italian
# 13       bilan        bilandro       Italian
# 14       scusa           scusa       Italian
# 15       segno           segno       Italian
# 16     segnale         segnale       Italian
# 17    cadavere        cadavere       Italian
# 18      colore          colore       Italian
# 19      cadere          cadere       Italian
# 20      caduto          caduto       Italian
# 21      caduta          caduta       Italian
# 22          tè              tè       Italian
# 23    corretto      correttore       Italian
# 24       pacco           pacco       Italian
# 25    politico        politico       Italian
# 26   insegnare       insegnare       Italian
# 27       capra           capra       Italian
# 28       capra     caprareccia       Italian
# 29     alloggi      alloggiare       Italian
# 30     sigillo         sigillo       Italian
# 31    cogliere        cogliere       Italian
#
#                                       definition_main  dict_entry  \
# 0             (Noun) (nautical) boom.(nautical) boom.        boom
# 1   (Verb) (transitive) to colligate. (transitive)...      legere
# 2   (Noun) A boom (crane). A boom (sound). A boom,...        boom
# 3   (Noun) Boss (leader of a business, company or ...        baas
# 4   (Noun) (nautical) spinnaker pole.(nautical) sp...       tange
# 5                                        (Adjective)       legere
# 6   (Noun) Chance (possibility of a certain outcom...        dice
# 7                     (Noun) Drug. Spice.Drug. Spice.       droog
# 8     (Verb) To mean, to signify.To mean, to signify.        sein
# 9   (Noun) The letter Y in the Italian phonetic al...   jageschip
# 10  (Noun) Sketch, skit (short comic work).Sketch,...      schets
# 11                            (Noun) Tragedy.Tragedy.     Dorians
# 12  (Noun) Grapefruit (fruit & tree).Grapefruit (f...  pompelmoes
# 13  (Noun) (watercraft) bilander.(watercraft) bila...   bijlander
# 14  (Noun Verb Interjection) Apology, excuse. Excu...     excuser
# 15  (Noun) Indication. Mark, scratch. Sign. Target...        sein
# 16                  (Noun) Signal, sign.Signal, sign.        sein
# 17                  (Noun) Corpse, body.Corpse, body.        dice
# 18                (Noun) Color, colour.Color, colour.       kleur
# 19  (Verb) (intransitive) to die. (intransitive) t...        dice
# 20  (Adjective Verb Noun) Dead. Fallen Dead soldie...        dice
# 21  (Adjective Noun) Drop (i.e. temperature drop)....        dice
# 22                                    (Noun) Tea.Tea.        thee
# 23  (Noun) Concealer (cosmetic). Control. Correcti...   corrigere
# 24  (Noun) (slang) bulge (visible protrusion of th...         pak
# 25  (Adjective Noun) Political Politician.Politica...    politiek
# 26  (Verb) (intransitive, to act as a teacher) to ...        sein
# 27  (Noun) Goat (mammal). Nanny goat. Trestle.Goat...         bok
# 28  (Noun) A shed used to keep goats indoors durin...         bok
# 29  (Verb) (intransitive) To stay or lodge (at). (...      laubja
# 30  (Noun Verb) Seal (that seals something).Seal (...        sein
# 31  (Verb) (transitive) to grasp, seize, take. (tr...      legere
#
#        language                                         definition
# 0   Dutch (nld)  Boom, as in a market explosion Any solid, pole...
# 1   Dutch (nld)                                                NaN
# 2   Dutch (nld)  Any solid, pole-shaped, usually wooden object....
# 3   Dutch (nld)  (Belgium) strong or tough guy. (diminutive: ba...
# 4   Dutch (nld)                                                NaN
# 5   Dutch (nld)                                                NaN
# 6   Dutch (nld)                                                NaN
# 7   Dutch (nld)                                         Arid. Dry.
# 8   Dutch (nld)                                            Signal.
# 9   Dutch (nld)                                                NaN
# 10  Dutch (nld)                                            Sketch.
# 11  Dutch (nld)                                                NaN
# 12  Dutch (nld)          Pomelo (fruit of the tree Citrus maxima).
# 13  Dutch (nld)                                                NaN
# 14  Dutch (nld)                                                NaN
# 15  Dutch (nld)                                            Signal.
# 16  Dutch (nld)                                            Signal.
# 17  Dutch (nld)                                                NaN
# 18  Dutch (nld)                    Color, colour. Suit (of cards).
# 19  Dutch (nld)                                                NaN
# 20  Dutch (nld)                                                NaN
# 21  Dutch (nld)                                                NaN
# 22  Dutch (nld)                                               Tea.
# 23  Dutch (nld)                                                NaN
# 24  Dutch (nld)                    Package. Suit (set of clothes).
# 25  Dutch (nld)                                Politics Political.
# 26  Dutch (nld)                                            Signal.
# 27  Dutch (nld)  (gymnastics) vaulting horse. (pejorative) chur...
# 28  Dutch (nld)  (gymnastics) vaulting horse. (pejorative) chur...
# 29  Dutch (nld)                                                NaN
# 30  Dutch (nld)                                            Signal.
# 31  Dutch (nld)                                                NaN

# %%
df_lang_pair1.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result1.xlsx", index=False)  # {lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result_All.xlsx

# %% [markdown]
# #### Read Github Cross Data

# %%
df_github_cross = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_cross_check.csv")
#df_github_cross = df_github_cross.head(150000)
df_github_cross
# Out:
#              lang         term                    reltype related_lang  \
# 0        Galician       fresco             inherited_from     Galician
# 1        Galician       fresco             inherited_from     Galician
# 2        Galician       fresco             inherited_from     Galician
# 3        Galician       fresco             inherited_from     Galician
# 4         English     ignostic  etymologically_related_to      English
# ...           ...          ...                        ...          ...
# 7799061     Dutch    landsdeel                compound_of        Dutch
# 7799062     Dutch    landsdeel                compound_of        Dutch
# 7799063     Dutch    landsdeel                compound_of        Dutch
# 7799064     Dutch    landsdeel                compound_of        Dutch
# 7799065     Dutch  ongecodeerd                 has_prefix        Dutch
#
#         related_term
# 0             fresco
# 1            friscus
# 2           *friskaz
# 3              fresh
# 4                ig-
# ...              ...
# 7799061         dêel
# 7799062          dēl
# 7799063         deil
# 7799064       *dailą
# 7799065           on
#
# [7799066 rows x 5 columns]

# %%
lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang_pair2 = df_github_cross[(df_github_cross["language_main"] == f"{lang_1.capitalize()}") & (df_github_cross["language"] == f"{lang_2.capitalize()}")]
df_lang_pair2

# %%
df_lang_pair2.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result2.xlsx", index=False)
