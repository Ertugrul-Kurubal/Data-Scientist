# %% [markdown]
# ### Etymology Language Pair

# %%
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### All Etymology File Concat

# %%
all_etymologeek_file = glob.glob("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/*/*_Etymologeek_Main_And_Additional_Result.xlsx")
all_etymologeek_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Turkish/Turkish_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Dutch/Dutch_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Portuguese/Portuguese_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/English/English_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/German/German_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Spanish/Spanish_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/French/French_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Italian/Italian_Etymologeek_Main_And_Additional_Result.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/Arabic/Arabic_Etymologeek_Main_And_Additional_Result.xlsx']

# %%
df_etymologeek_all = pd.DataFrame()
for i in all_etymologeek_file:
    df_var = pd.read_excel(f"{i}")
    df_etymologeek_all = pd.concat([df_etymologeek_all, df_var], axis=0)
df_etymologeek_all.drop_duplicates(inplace=True)
df_etymologeek_all.reset_index(drop=True, inplace=True)
df_etymologeek_all
# Out:
#        search_word dict_entry_main   language_main  \
# 0              bir             bir   Crimean Tatar
# 1              bir             bir   Crimean Tatar
# 2              bir             bir  Middle English
# 3              bir             bir  Middle English
# 4              bir             bir  Middle English
# ...            ...             ...             ...
# 668525        إلين           إلينا          Arabic
# 668526       مستقر           مستقر          Arabic
# 668527       مستقر           مستقر          Arabic
# 668528        صيني           صينية          Arabic
# 668529        صيني           صينية          Arabic
#
#                                           definition_main       dict_entry  \
# 0                (Numeral) (cardinal) one.(cardinal) one.             *bīr
# 1                (Numeral) (cardinal) one.(cardinal) one.              bir
# 2       (Noun) A charge on an account.. A strong or fa...           *buriz
# 3       (Noun) A charge on an account.. A strong or fa...        *bʰrewh₁-
# 4       (Noun) A charge on an account.. A strong or fa...           *buriz
# ...                                                   ...              ...
# 668525                              (Adverb) To us.To us.            إلينا
# 668526  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668528  (Noun) (usually definite) Chinese language.(us...  لُغَة صِينِيَّة
# 668529  (Noun) (usually definite) Chinese language.(us...            صينية
#
#                              language  \
# 0              Proto-Turkic (trk-pro)
# 1                 Crimean Tatar (crh)
# 2            Proto-Germanic (gem-pro)
# 3       Proto-Indo-European (ine-pro)
# 4            Proto-Germanic (gem-pro)
# ...                               ...
# 668525                   Arabic (ara)
# 668526                         Arabic
# 668527                         Arabic
# 668528                   Arabic (ara)
# 668529                   Arabic (ara)
#
#                                                definition
# 0                                                    One.
# 1                                         (cardinal) one.
# 2                                    Male offspring; son.
# 3                                                     NaN
# 4                                        Elevation; hill.
# ...                                                   ...
# 668525                                             To us.
# 668526  (Adjective) Confessing. Firm, solid, stable. F...
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...
# 668528                                                NaN
# 668529               (usually definite) Chinese language.
#
# [668530 rows x 7 columns]

# %%
#df_etymologeek_all.to_excel("All_Etymology_Language_Pair_Result.xlsx", index=False)

# %% [markdown]
# #### Read Etymologeek All Data

# %%
df_etymologeek_all = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/All_Etymology_Language_Pair_Result.xlsx")
df_etymologeek_all
# Out:
#        search_word dict_entry_main   language_main  \
# 0              bir             bir   Crimean Tatar
# 1              bir             bir   Crimean Tatar
# 2              bir             bir  Middle English
# 3              bir             bir  Middle English
# 4              bir             bir  Middle English
# ...            ...             ...             ...
# 668525        إلين           إلينا          Arabic
# 668526       مستقر           مستقر          Arabic
# 668527       مستقر           مستقر          Arabic
# 668528        صيني           صينية          Arabic
# 668529        صيني           صينية          Arabic
#
#                                           definition_main       dict_entry  \
# 0                (Numeral) (cardinal) one.(cardinal) one.             *bīr
# 1                (Numeral) (cardinal) one.(cardinal) one.              bir
# 2       (Noun) A charge on an account.. A strong or fa...           *buriz
# 3       (Noun) A charge on an account.. A strong or fa...        *bʰrewh₁-
# 4       (Noun) A charge on an account.. A strong or fa...           *buriz
# ...                                                   ...              ...
# 668525                              (Adverb) To us.To us.            إلينا
# 668526  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668528  (Noun) (usually definite) Chinese language.(us...  لُغَة صِينِيَّة
# 668529  (Noun) (usually definite) Chinese language.(us...            صينية
#
#                              language  \
# 0              Proto-Turkic (trk-pro)
# 1                 Crimean Tatar (crh)
# 2            Proto-Germanic (gem-pro)
# 3       Proto-Indo-European (ine-pro)
# 4            Proto-Germanic (gem-pro)
# ...                               ...
# 668525                   Arabic (ara)
# 668526                         Arabic
# 668527                         Arabic
# 668528                   Arabic (ara)
# 668529                   Arabic (ara)
#
#                                                definition
# 0                                                    One.
# 1                                         (cardinal) one.
# 2                                    Male offspring; son.
# 3                                                     NaN
# 4                                        Elevation; hill.
# ...                                                   ...
# 668525                                             To us.
# 668526  (Adjective) Confessing. Firm, solid, stable. F...
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...
# 668528                                                NaN
# 668529               (usually definite) Chinese language.
#
# [668530 rows x 7 columns]

# %%
#df_etymologeek_all["language_main"].unique()

# %%
#df_etymologeek_all["language"].unique()

# %%
lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Turkish (tur)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)

# %%
df_lang_pair1 = df_etymologeek_all[(df_etymologeek_all["language_main"] == f"{lang_1.capitalize()}") & (df_etymologeek_all["language"] == f"{lang_2.capitalize()}")]
df_lang_pair1
# Out:
#        search_word dict_entry_main language_main  \
# 6596         araba           araba       English
# 7217        beyler       beylerbey       English
# 13039          bey             bey       English
# 16978          yat        yataghan       English
# 20840        ekmek   ekmek kadayif       English
# 20841        ekmek   ekmek kadayif       English
# 25826         vali            vali       English
# 31625     kurabiye        kurabiye       English
# 38018          tuz           tuzla       English
# 38019          tuz           tuzla       English
# 68552         jack          jackal       English
# 82651          ray           rayah       English
# 200577         fez             fez       English
# 292199       abras          abrash       English
# 319018      caviar          caviar       English
# 322283        arab           araba       English
# 340181        turk          turkey       English
# 376397      turkey          turkey       English
# 407988        done           donek       English
# 411350      sultan          sultan       English
# 411445        soft           softa       English
# 415317       marta        martagon       English
# 468955        lahm        lahmacun       English
# 498514        caza            caza       English
# 509699        raya           rayah       English
# 567325     chagrin         chagrin       English
# 579360       gilet           gilet       English
# 628942        cavi          caviar       English
#
#                                           definition_main      dict_entry  \
# 6596    (Noun) A horse-drawn carriage once used for tr...           araba
# 7217    (Noun) An Ottoman administrative title.An Otto...      beylerbeyi
# 13039   (Noun) (historical) A governor of a province o...             bey
# 16978   (Noun) A type of sword used in Muslim countrie...         yatağan
# 20840   (Noun) A Turkish bread pudding dessert, also f...         kadayıf
# 20841   (Noun) A Turkish bread pudding dessert, also f...  ekmek kadayıfı
# 25826                                             (Noun)             vali
# 31625   (Noun) (rare) A cookie, particularly a sweet (...        kurabiye
# 38018   (Noun) A kind of central Anatolian rug.A kind ...             tuz
# 38019   (Noun) A kind of central Anatolian rug.A kind ...           tuzla
# 68552   (Verb Noun) To perform menial or routine tasks...           çakal
# 82651   (Noun) (pejorative) A member of the tax-paying...           reaya
# 200577  (Noun) A felt hat in the shape of a truncated ...             fes
# 292199  (Noun) A variation in color (often applied to ...           abraş
# 319018  (Noun) Roe of the sturgeon or other large fish...          havyar
# 322283  (Noun) A horse-drawn carriage once used for tr...           araba
# 340181  (Noun) (bowling) An act of throwing three stri...        Turgutlu
# 376397  (Noun) (bowling) An act of throwing three stri...        Turgutlu
# 407988  (Noun) A breed of fancy pigeon.A breed of fanc...           dönek
# 411350  (Noun) (card games) A variant of solitaire, pl...          sultan
# 411445  (Noun) (Islam) A religious student, especially...           softa
# 415317            (Noun) A Eurasian lily.A Eurasian lily.        martagan
# 468955  (Noun) A dish of Arab origin consisting of a r...        lahmacun
# 498514  (Noun) A Turkish provincial subdivision.A Turk...            kaza
# 509699  (Noun) (pejorative) A member of the tax-paying...           reaya
# 567325  (Verb Noun) (intransitive) To be vexed or anno...           sağrı
# 579360  (Noun) A sleeveless jacket similar to a waistc...           yelek
# 628942  (Noun) Roe of the sturgeon or other large fish...          havyar
#
#              language                                         definition
# 6596    Turkish (tur)                               Car. Carriage. Cart.
# 7217    Turkish (tur)                                                NaN
# 13039   Turkish (tur)          Gentleman, mister. Husband. Lord, master.
# 16978   Turkish (tur)                                          Yataghan.
# 20840   Turkish (tur)  A type of thin noodle used to make kanafeh pas...
# 20841   Turkish (tur)                                                NaN
# 25826   Turkish (tur)                                          Governor.
# 31625   Turkish (tur)                                   Cookie, biscuit.
# 38018   Turkish (tur)                                  (chemistry) salt.
# 38019   Turkish (tur)                                                NaN
# 68552   Turkish (tur)  (pejorative, derogatory) A detestable person, ...
# 82651   Turkish (tur)                                                NaN
# 200577  Turkish (tur)                                                NaN
# 292199  Turkish (tur)                                                NaN
# 319018  Turkish (tur)                                            Caviar.
# 322283  Turkish (tur)                               Car. Carriage. Cart.
# 340181  Turkish (tur)                                                NaN
# 376397  Turkish (tur)                                                NaN
# 407988  Turkish (tur)                                                NaN
# 411350  Turkish (tur)  A breed of chicken originating in Turkey, kept...
# 411445  Turkish (tur)  (Islam) A student of theology. (by extension) ...
# 415317  Turkish (tur)                                                NaN
# 468955  Turkish (tur)                                          Lahmacun.
# 498514  Turkish (tur)                                          Accident.
# 509699  Turkish (tur)                                                NaN
# 567325  Turkish (tur)  The chubby and round part of a mammal's body b...
# 579360  Turkish (tur)                           Jelick. Waistcoat, vest.
# 628942  Turkish (tur)                                            Caviar.

# %%
df_lang_pair1 = df_lang_pair1.drop_duplicates(subset="dict_entry_main")
df_lang_pair1.reset_index(drop=True, inplace=True)
df_lang_pair1
# Out:
#    search_word dict_entry_main language_main  \
# 0        araba           araba       English
# 1       beyler       beylerbey       English
# 2          bey             bey       English
# 3          yat        yataghan       English
# 4        ekmek   ekmek kadayif       English
# 5         vali            vali       English
# 6     kurabiye        kurabiye       English
# 7          tuz           tuzla       English
# 8         jack          jackal       English
# 9          ray           rayah       English
# 10         fez             fez       English
# 11       abras          abrash       English
# 12      caviar          caviar       English
# 13        turk          turkey       English
# 14        done           donek       English
# 15      sultan          sultan       English
# 16        soft           softa       English
# 17       marta        martagon       English
# 18        lahm        lahmacun       English
# 19        caza            caza       English
# 20     chagrin         chagrin       English
# 21       gilet           gilet       English
#
#                                       definition_main  dict_entry  \
# 0   (Noun) A horse-drawn carriage once used for tr...       araba
# 1   (Noun) An Ottoman administrative title.An Otto...  beylerbeyi
# 2   (Noun) (historical) A governor of a province o...         bey
# 3   (Noun) A type of sword used in Muslim countrie...     yatağan
# 4   (Noun) A Turkish bread pudding dessert, also f...     kadayıf
# 5                                             (Noun)         vali
# 6   (Noun) (rare) A cookie, particularly a sweet (...    kurabiye
# 7   (Noun) A kind of central Anatolian rug.A kind ...         tuz
# 8   (Verb Noun) To perform menial or routine tasks...       çakal
# 9   (Noun) (pejorative) A member of the tax-paying...       reaya
# 10  (Noun) A felt hat in the shape of a truncated ...         fes
# 11  (Noun) A variation in color (often applied to ...       abraş
# 12  (Noun) Roe of the sturgeon or other large fish...      havyar
# 13  (Noun) (bowling) An act of throwing three stri...    Turgutlu
# 14  (Noun) A breed of fancy pigeon.A breed of fanc...       dönek
# 15  (Noun) (card games) A variant of solitaire, pl...      sultan
# 16  (Noun) (Islam) A religious student, especially...       softa
# 17            (Noun) A Eurasian lily.A Eurasian lily.    martagan
# 18  (Noun) A dish of Arab origin consisting of a r...    lahmacun
# 19  (Noun) A Turkish provincial subdivision.A Turk...        kaza
# 20  (Verb Noun) (intransitive) To be vexed or anno...       sağrı
# 21  (Noun) A sleeveless jacket similar to a waistc...       yelek
#
#          language                                         definition
# 0   Turkish (tur)                               Car. Carriage. Cart.
# 1   Turkish (tur)                                                NaN
# 2   Turkish (tur)          Gentleman, mister. Husband. Lord, master.
# 3   Turkish (tur)                                          Yataghan.
# 4   Turkish (tur)  A type of thin noodle used to make kanafeh pas...
# 5   Turkish (tur)                                          Governor.
# 6   Turkish (tur)                                   Cookie, biscuit.
# 7   Turkish (tur)                                  (chemistry) salt.
# 8   Turkish (tur)  (pejorative, derogatory) A detestable person, ...
# 9   Turkish (tur)                                                NaN
# 10  Turkish (tur)                                                NaN
# 11  Turkish (tur)                                                NaN
# 12  Turkish (tur)                                            Caviar.
# 13  Turkish (tur)                                                NaN
# 14  Turkish (tur)                                                NaN
# 15  Turkish (tur)  A breed of chicken originating in Turkey, kept...
# 16  Turkish (tur)  (Islam) A student of theology. (by extension) ...
# 17  Turkish (tur)                                                NaN
# 18  Turkish (tur)                                          Lahmacun.
# 19  Turkish (tur)                                          Accident.
# 20  Turkish (tur)  The chubby and round part of a mammal's body b...
# 21  Turkish (tur)                           Jelick. Waistcoat, vest.

# %%
df_lang_pair1.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result1.xlsx", index=False)  # {lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result_All.xlsx

# %% [markdown]
# #### Read Github Cross Data

# %% [markdown]
# ##### Part 1

# %%
df_github_cross = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_cross_check2.csv")
df_github_cross
# Out:
#                         term_id     lang      term                    reltype  \
# 0        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra             inherited_from
# 1        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 2        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 3        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 4        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# ...                         ...      ...       ...                        ...
# 8854119  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa             inherited_from
# 8854120  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854121  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854122  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854123  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa                 cognate_of
#
#                 related_term_id    related_lang related_term
# 0        9w90qvZDUH-2OHPVZEGJSQ  Middle english       parlai
# 1        Uy6v5wWuW6KGH4aTqGWnmA      Old french       parler
# 2        HY24XyCcUZCYSa1Q6y2kPA      Late latin     parabolō
# 3        uXGtk5g-W8G_TlTxSHImpg           Latin     parabola
# 4        JHVmHqAPXEq-YaIbd0B5Jg   Ancient greek     παραβολή
# ...                         ...             ...          ...
# 8854119  TUnsO83vXXC1Us5rJgGyUg    Vulgar latin    *pittitus
# 8854120  oUnwLLsHVymmwwiRXgrRow           Latin     pitinnus
# 8854121  IGRZaHQ-VU-vpxMjdxSTlA           Latin      pitulus
# 8854122  MDRrWciZWXGEj1KR9MUWtg           Latin     piccinus
# 8854123  SUJISOECWc6fDH00I_cTRQ          French        petit
#
# [8854124 rows x 7 columns]

# %%
lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Italian"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
### ****

# %%
df_lang1 = df_github_cross[(df_github_cross["lang"] == f"{lang_1.capitalize()}")] 
df_lang1
# Out:
#                         term_id     lang          term  \
# 8        9dklyzlWU1GJG2HQTdn2Gw  English       breaker
# 9        9dklyzlWU1GJG2HQTdn2Gw  English       breaker
# 10       Sa9PLd8wVye-T_9yUc0DOw  English   unflappable
# 11       9dklyzlWU1GJG2HQTdn2Gw  English       breaker
# 12       Sa9PLd8wVye-T_9yUc0DOw  English   unflappable
# ...                         ...      ...           ...
# 8854101  X9TbD7nbViavII1VL_kMCw  English  geotechnique
# 8854102  X9TbD7nbViavII1VL_kMCw  English  geotechnique
# 8854103  X9TbD7nbViavII1VL_kMCw  English  geotechnique
# 8854104  X9TbD7nbViavII1VL_kMCw  English  geotechnique
# 8854105  X9TbD7nbViavII1VL_kMCw  English  geotechnique
#
#                            reltype         related_term_id    related_lang  \
# 8                    borrowed_from  5hrBfLYUVKCz_apIVUIeCQ         Occitan
# 9                     derived_from  7k2Vvp3nXLy5CvsTUAGhnA     Old occitan
# 10                  inherited_from  1s_U6-KHWmiJeKVbA96FWg  Middle english
# 11                    derived_from  UJle1K0PXdyx7GycKtbdvQ    Vulgar latin
# 12                  inherited_from  tiwBatmsX3aT6yV_bBj4pA     Old english
# ...                            ...                     ...             ...
# 8854101              borrowed_from  l-rKJaTcXL65SH14LLHRgA          French
# 8854102  etymologically_related_to  l-rKJaTcXL65SH14LLHRgA          French
# 8854103               derived_from  YbyR0LCGX4qfUGCtxMAlNQ   Ancient greek
# 8854104  etymologically_related_to  4bixcB-SUnyHLzonp8WarQ   Ancient greek
# 8854105  etymologically_related_to  cwWZ2hLaU1GuMpkyU45wHQ   Ancient greek
#
#         related_term
# 8           barrique
# 9            barrica
# 10               un-
# 11          *barrica
# 12               un-
# ...              ...
# 8854101    technique
# 8854102    technique
# 8854103     τεχνικός
# 8854104        τέχνη
# 8854105      τίκτειν
#
# [3656969 rows x 7 columns]

# %%
df_lang2 = df_github_cross[(df_github_cross["lang"] == f"{lang_2.capitalize()}")]
df_lang2["term"] = df_lang2["term"].apply(lambda x: x.lower())
df_lang2.rename(columns={"term":"word"}, inplace=True)
df_lang2
# Out:
# <ipython-input-182-7211f3bc6644>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang2["term"] = df_lang2["term"].apply(lambda x: x.lower())
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                         term_id     lang       word  \
# 123      sQBv_-IrX-u1XoWRYPKEjg  Italian  trasalire
# 124      sQBv_-IrX-u1XoWRYPKEjg  Italian  trasalire
# 125      sQBv_-IrX-u1XoWRYPKEjg  Italian  trasalire
# 743      pdZ0urDaXVKR4kx-gdGEjA  Italian   pedalare
# 843      pdZ0urDaXVKR4kx-gdGEjA  Italian   pedalare
# ...                         ...      ...        ...
# 8852137  GXycdh0sVwO6-sci32HR6w  Italian   setaiola
# 8852138  GXycdh0sVwO6-sci32HR6w  Italian   setaiola
# 8852139  GXycdh0sVwO6-sci32HR6w  Italian   setaiola
# 8852320  1YiNpFqLWROEOZCWBGZd_g  Italian  lo scalzo
# 8854039  PxpQA6p0WGi1aGfMsWmGHg  Italian    tomassi
#
#                            reltype         related_term_id  \
# 123                 inherited_from  F2hEQ0a_U4iwmW3KihJYkA
# 124      etymologically_related_to  mytX5yvAXFeG3OZ4QuAEag
# 125                   derived_from  POkTnl3FX-OTUKwHQQuTzQ
# 743                 inherited_from  _BLTztuoXhKR4Db8ocuOLg
# 843                 inherited_from  -Vje8yYzWgiJ6xzvN2sjHw
# ...                            ...                     ...
# 8852137  etymologically_related_to  Esf2coFGXQOeiMhHa3_K8g
# 8852138  etymologically_related_to  EH9c-R6MWnK377GwAfdydg
# 8852139                 cognate_of  vixuooLJVH6Q6AvhQJcfcA
# 8852320  etymologically_related_to  H0i3QDJRWn6_Eu71hS7J4Q
# 8854039  etymologically_related_to  ranwaQ4YXs23AiL1O7yRyg
#
#                 related_lang related_term
# 123                    Latin       salīre
# 124                    Latin        saliō
# 125      Proto-indo-european       *sl̥i-
# 743                    Latin      pedālis
# 843                    Latin         -āre
# ...                      ...          ...
# 8852137  Proto-indo-european      *sh₂ey-
# 8852138  Proto-indo-european      *seh₂i-
# 8852139           Portuguese         seda
# 8852320              Italian       scalzo
# 8854039              Italian      Tommaso
#
# [206484 rows x 7 columns]

# %%
df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
df_word = df_word.head(40000)
df_word = df_word.loc[:,["word"]]
df_word
# Out:
#                 word
# 0                  e
# 1                non
# 2                che
# 3                 di
# 4                 un
# ...              ...
# 39995  interminabili
# 39996       vendesse
# 39997      guaritori
# 39998          lives
# 39999       facetime
#
# [40000 rows x 1 columns]

# %%
df_lang2 = pd.merge(df_lang2,df_word,how="inner",on="word")
df_lang2
# Out:
#                       term_id     lang      word                    reltype  \
# 0      pdZ0urDaXVKR4kx-gdGEjA  Italian  pedalare             inherited_from
# 1      pdZ0urDaXVKR4kx-gdGEjA  Italian  pedalare             inherited_from
# 2      pdZ0urDaXVKR4kx-gdGEjA  Italian  pedalare             inherited_from
# 3      pdZ0urDaXVKR4kx-gdGEjA  Italian  pedalare  etymologically_related_to
# 4      oV2PSMfbUaek7j3TnTFh8Q  Italian  smettere             inherited_from
# ...                       ...      ...       ...                        ...
# 45913  zbcKyrS2VHSCKW_AsSsOnQ  Italian   signori             inherited_from
# 45914  zbcKyrS2VHSCKW_AsSsOnQ  Italian   signori  etymologically_related_to
# 45915  zbcKyrS2VHSCKW_AsSsOnQ  Italian   signori  etymologically_related_to
# 45916  zbcKyrS2VHSCKW_AsSsOnQ  Italian   signori               derived_from
# 45917  zbcKyrS2VHSCKW_AsSsOnQ  Italian   signori               doublet_with
#
#               related_term_id         related_lang related_term
# 0      _BLTztuoXhKR4Db8ocuOLg                Latin      pedālis
# 1      -Vje8yYzWgiJ6xzvN2sjHw                Latin         -āre
# 2      9aX5FS1YVjW8ailBEaSgtw                Latin        -ārem
# 3      iDFxE5oTXWqS5J1l42qOnw                Latin        -āris
# 4      b-nrE42UX6yGxMLSMF8YNg                Latin      mittere
# ...                       ...                  ...          ...
# 45913  mXCYRM_hV6SM3sC2mIQPLQ                Latin     seniōrem
# 45914  ykSj58GiXU2_nNRw-ocP7w                Latin       senior
# 45915  hyYJ2JPfUVqbZUklvVroaQ                Latin        senex
# 45916  2EsPA8HjUHWRaH8hudy5Qw  Proto-indo-european       *sénos
# 45917  UtxtEpPCVcCeBoewDjm2ug              Italian         sire
#
# [45918 rows x 7 columns]

# %%
set_lang1 = set(df_lang1["related_term_id"])
set_lang2= set(df_lang2["related_term_id"])

# %%
df_pair_etymology = pd.DataFrame(set_lang1.intersection(set_lang2),columns=["related_term_id"])
df_pair_etymology
# Out:
#               related_term_id
# 0      7Bnmb2YOUquDfBdL1tcdNg
# 1      _m54a6kWVkK-mxkUYcjc5A
# 2      iIXL9GG2W5aVazANKolLhg
# 3      kkN9Ya1xWEK9wWBNRvLkWw
# 4      7eDkMntNVWui1RPuAExUkA
# ...                       ...
# 17533  SYvSHBGkV0WtdgtqwFFWAg
# 17534  N1OqtTnuXDCdvRkGf-9ITQ
# 17535  _ZYwREq-V1G1s9TpImTsOw
# 17536  GEmLh3_tWxKBEXi_aBPnnQ
# 17537  IU8eqEffU0-YUPdRbzIVqg
#
# [17538 rows x 1 columns]

# %%
df_etymology_merge = pd.merge(df_github_cross,df_pair_etymology,how="inner",on="related_term_id")
df_etymology_merge.drop_duplicates(inplace=True)
df_etymology_merge
# Out:
#                         term_id            lang      term  \
# 0        LHuH1RvcUjWNUTR6QQF8fg         Spanish   palabra
# 1        nna1S--BXFqttVpHavoanQ           Scots    barley
# 2        x0csKO2pXiChaUAIWqoSEA         English    polari
# 3        i9JToR1SWwyLK5xjN7whxw  Serbo-croatian   parlati
# 4        -Dj5n6seXXC7Yxpay96yeQ          French  perruque
# ...                         ...             ...       ...
# 1997536  c6FjxMYoX_id6UW-FglbRg         English     Fauci
# 1997537  mp-iwIqxVMeMIZ3Rqj7oMQ         Italian     Fauci
# 1997538  c6FjxMYoX_id6UW-FglbRg         English     Fauci
# 1997539  mp-iwIqxVMeMIZ3Rqj7oMQ         Italian     Fauci
# 1997540  Hz7rpIR1VI-Ntcu6jogFyQ        Sicilian     Fauci
#
#                            reltype         related_term_id related_lang  \
# 0                     derived_from  HY24XyCcUZCYSa1Q6y2kPA   Late latin
# 1                     derived_from  HY24XyCcUZCYSa1Q6y2kPA   Late latin
# 2                   inherited_from  HY24XyCcUZCYSa1Q6y2kPA   Late latin
# 3                   inherited_from  HY24XyCcUZCYSa1Q6y2kPA   Late latin
# 4                   inherited_from  HY24XyCcUZCYSa1Q6y2kPA   Late latin
# ...                            ...                     ...          ...
# 1997536  etymologically_related_to  606mS6RwX2S8JE7R6qqCDA     Sicilian
# 1997537  etymologically_related_to  606mS6RwX2S8JE7R6qqCDA     Sicilian
# 1997538                 cognate_of  c_VyMU55VlSWKbKNA1ucNQ      Italian
# 1997539                 cognate_of  c_VyMU55VlSWKbKNA1ucNQ      Italian
# 1997540                 cognate_of  c_VyMU55VlSWKbKNA1ucNQ      Italian
#
#         related_term
# 0           parabolō
# 1           parabolō
# 2           parabolō
# 3           parabolō
# 4           parabolō
# ...              ...
# 1997536        fauci
# 1997537        fauci
# 1997538        falce
# 1997539        falce
# 1997540        falce
#
# [1997541 rows x 7 columns]

# %%
df_etymology_merge = df_etymology_merge[df_etymology_merge["reltype"] == "derived_from"]
df_etymology_merge
# Out:
#                         term_id     lang      term       reltype  \
# 0        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra  derived_from
# 1        nna1S--BXFqttVpHavoanQ    Scots    barley  derived_from
# 17       yq4ybfslWD60cBN7U5OHxA  English  parleyer  derived_from
# 22       LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra  derived_from
# 25       nna1S--BXFqttVpHavoanQ    Scots    barley  derived_from
# ...                         ...      ...       ...           ...
# 1997529  bBKLIDW1XRyQw2P11N_E2g  English     Buffa  derived_from
# 1997530  ag7QBfjTWv-F6b1rbNBSsw  Italian     Buffa  derived_from
# 1997533  hAVDsibPV1arEblgO9sCtA  English      Noto  derived_from
# 1997534  C8T-08TpVke6xI9DNMf6GQ  Italian      Noto  derived_from
# 1997535  BymJUkTwVvCfSNvG7_4s8Q  Italian   Di Noto  derived_from
#
#                 related_term_id   related_lang related_term
# 0        HY24XyCcUZCYSa1Q6y2kPA     Late latin     parabolō
# 1        HY24XyCcUZCYSa1Q6y2kPA     Late latin     parabolō
# 17       HY24XyCcUZCYSa1Q6y2kPA     Late latin     parabolō
# 22       uXGtk5g-W8G_TlTxSHImpg          Latin     parabola
# 25       uXGtk5g-W8G_TlTxSHImpg          Latin     parabola
# ...                         ...            ...          ...
# 1997529  qAWnKsJqWImkQCZMla0RPw          Latin         bufo
# 1997530  qAWnKsJqWImkQCZMla0RPw          Latin         bufo
# 1997533  BegI-rQLVZSWD6feGRJ9xA  Ancient greek       Νέητον
# 1997534  BegI-rQLVZSWD6feGRJ9xA  Ancient greek       Νέητον
# 1997535  BegI-rQLVZSWD6feGRJ9xA  Ancient greek       Νέητον
#
# [396180 rows x 7 columns]

# %%
df_etymology_merge = df_etymology_merge[~df_etymology_merge["related_term"].str.contains(fr"(?:\s|^)\*|\-(?:\s|$)", na=True)]
df_etymology_merge
# Out:
#                         term_id     lang      term       reltype  \
# 0        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra  derived_from
# 1        nna1S--BXFqttVpHavoanQ    Scots    barley  derived_from
# 17       yq4ybfslWD60cBN7U5OHxA  English  parleyer  derived_from
# 22       LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra  derived_from
# 25       nna1S--BXFqttVpHavoanQ    Scots    barley  derived_from
# ...                         ...      ...       ...           ...
# 1997529  bBKLIDW1XRyQw2P11N_E2g  English     Buffa  derived_from
# 1997530  ag7QBfjTWv-F6b1rbNBSsw  Italian     Buffa  derived_from
# 1997533  hAVDsibPV1arEblgO9sCtA  English      Noto  derived_from
# 1997534  C8T-08TpVke6xI9DNMf6GQ  Italian      Noto  derived_from
# 1997535  BymJUkTwVvCfSNvG7_4s8Q  Italian   Di Noto  derived_from
#
#                 related_term_id   related_lang related_term
# 0        HY24XyCcUZCYSa1Q6y2kPA     Late latin     parabolō
# 1        HY24XyCcUZCYSa1Q6y2kPA     Late latin     parabolō
# 17       HY24XyCcUZCYSa1Q6y2kPA     Late latin     parabolō
# 22       uXGtk5g-W8G_TlTxSHImpg          Latin     parabola
# 25       uXGtk5g-W8G_TlTxSHImpg          Latin     parabola
# ...                         ...            ...          ...
# 1997529  qAWnKsJqWImkQCZMla0RPw          Latin         bufo
# 1997530  qAWnKsJqWImkQCZMla0RPw          Latin         bufo
# 1997533  BegI-rQLVZSWD6feGRJ9xA  Ancient greek       Νέητον
# 1997534  BegI-rQLVZSWD6feGRJ9xA  Ancient greek       Νέητον
# 1997535  BegI-rQLVZSWD6feGRJ9xA  Ancient greek       Νέητον
#
# [218930 rows x 7 columns]

# %%
df_lang1_word = df_etymology_merge[(df_etymology_merge["lang"]==f"{lang_1.capitalize()}")]
df_lang1_word.drop_duplicates(inplace=True)
df_lang1_word
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                         term_id     lang             term       reltype  \
# 17       yq4ybfslWD60cBN7U5OHxA  English         parleyer  derived_from
# 42       x0csKO2pXiChaUAIWqoSEA  English           polari  derived_from
# 83       asg1dcSCUh-Oqlo5A5isyw  English           Polari  derived_from
# 133      yq4ybfslWD60cBN7U5OHxA  English         parleyer  derived_from
# 150      tPWnlX1EUsaKs9OSQwnCIg  English        Parlyaree  derived_from
# ...                         ...      ...              ...           ...
# 1997488  44MEisn5VMS7zws58_G7Jw  English    tragicomedian  derived_from
# 1997493  wmMV8vL8WpeU-yppBih4UA  English  tragicomedienne  derived_from
# 1997527  dk8whqIPV2KKd6OLWoXWWA  English         Sabinian  derived_from
# 1997529  bBKLIDW1XRyQw2P11N_E2g  English            Buffa  derived_from
# 1997533  hAVDsibPV1arEblgO9sCtA  English             Noto  derived_from
#
#                 related_term_id   related_lang related_term
# 17       HY24XyCcUZCYSa1Q6y2kPA     Late latin     parabolō
# 42       uXGtk5g-W8G_TlTxSHImpg          Latin     parabola
# 83       uXGtk5g-W8G_TlTxSHImpg          Latin     parabola
# 133      uXGtk5g-W8G_TlTxSHImpg          Latin     parabola
# 150      uXGtk5g-W8G_TlTxSHImpg          Latin     parabola
# ...                         ...            ...          ...
# 1997488  1XuLOqAuUqCA2tspDzb1yw          Latin     tragicus
# 1997493  1XuLOqAuUqCA2tspDzb1yw          Latin     tragicus
# 1997527  4EMVk_ZpWuWVimwWebPAuQ          Latin      Sabinus
# 1997529  qAWnKsJqWImkQCZMla0RPw          Latin         bufo
# 1997533  BegI-rQLVZSWD6feGRJ9xA  Ancient greek       Νέητον
#
# [101889 rows x 7 columns]

# %%
df_lang1_word["term"] = df_lang1_word["term"].apply(lambda x: x.lower())
df_lang1_result = df_lang1_word.drop_duplicates(subset="term")
df_lang1_result.reset_index(drop=True, inplace=True)
df_lang1_result
# Out:
# <ipython-input-191-2f7894e925bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_word["term"] = df_lang1_word["term"].apply(lambda x: x.lower())
#                       term_id     lang             term       reltype  \
# 0      yq4ybfslWD60cBN7U5OHxA  English         parleyer  derived_from
# 1      x0csKO2pXiChaUAIWqoSEA  English           polari  derived_from
# 2      tPWnlX1EUsaKs9OSQwnCIg  English        parlyaree  derived_from
# 3      VKpprkitUaijmY8EeBCvHQ  English            parle  derived_from
# 4      pC6Bp9lIXHGgnqNe3JxmFg  English           parlay  derived_from
# ...                       ...      ...              ...           ...
# 69991  44MEisn5VMS7zws58_G7Jw  English    tragicomedian  derived_from
# 69992  wmMV8vL8WpeU-yppBih4UA  English  tragicomedienne  derived_from
# 69993  dk8whqIPV2KKd6OLWoXWWA  English         sabinian  derived_from
# 69994  bBKLIDW1XRyQw2P11N_E2g  English            buffa  derived_from
# 69995  hAVDsibPV1arEblgO9sCtA  English             noto  derived_from
#
#               related_term_id   related_lang related_term
# 0      HY24XyCcUZCYSa1Q6y2kPA     Late latin     parabolō
# 1      uXGtk5g-W8G_TlTxSHImpg          Latin     parabola
# 2      uXGtk5g-W8G_TlTxSHImpg          Latin     parabola
# 3      JHVmHqAPXEq-YaIbd0B5Jg  Ancient greek     παραβολή
# 4      JHVmHqAPXEq-YaIbd0B5Jg  Ancient greek     παραβολή
# ...                       ...            ...          ...
# 69991  1XuLOqAuUqCA2tspDzb1yw          Latin     tragicus
# 69992  1XuLOqAuUqCA2tspDzb1yw          Latin     tragicus
# 69993  4EMVk_ZpWuWVimwWebPAuQ          Latin      Sabinus
# 69994  qAWnKsJqWImkQCZMla0RPw          Latin         bufo
# 69995  BegI-rQLVZSWD6feGRJ9xA  Ancient greek       Νέητον
#
# [69996 rows x 7 columns]

# %%
df_lang1_result.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result2.xlsx", index=False)

# %% [markdown]
# ##### Part 2

# %%
df_github_clean = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_clean.csv")
df_github_clean
# Out:
#                            lang         term        reltype  \
# 0                       English    thesaurus  borrowed_from
# 1                       English    thesaurus   derived_from
# 2                       English    thesaurus   doublet_with
# 3                         Latin    thesaurus   derived_from
# 4                       English  portmanteau       has_root
# ...                         ...          ...            ...
# 3484911                 English        Boell  borrowed_from
# 3484912                 English        Boell  borrowed_from
# 3484913  South Levantine Arabic       بالمية      has_affix
# 3484914  South Levantine Arabic       بالمية      has_affix
# 3484915                 English       Cooler   derived_from
#
#                    related_lang  related_term
# 0                         Latin     thēsaurus
# 1                 Ancient Greek      θησαυρός
# 2                       English      treasure
# 3                 Ancient Greek      θησαυρός
# 4           Proto-Indo-European  *per- (fare)
# ...                         ...           ...
# 3484911                  Danish          Bøll
# 3484912                  German          Böll
# 3484913  South Levantine Arabic            بـ
# 3484914  South Levantine Arabic        الميّة
# 3484915                  German        Kühler
#
# [3484916 rows x 5 columns]

# %%
lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Portuguese"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang1_lang2 = df_github_clean[(df_github_clean["lang"] == f"{lang_1.capitalize()}") & (df_github_clean["related_lang"] == f"{lang_2.capitalize()}")]
df_lang1_lang2["term"] = df_lang1_lang2["term"].apply(lambda x: x.lower())
df_lang1_lang2.reset_index(drop=True, inplace=True)
df_lang1_lang2
# Out:
# <ipython-input-52-1d0a19c05f30>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_lang2["term"] = df_lang1_lang2["term"].apply(lambda x: x.lower())
#       lang      term        reltype related_lang related_term
# 0  Turkish     kobra  borrowed_from   Portuguese        cobra
# 1  Turkish    ananas   derived_from   Portuguese       ananás
# 2  Turkish     japon   derived_from   Portuguese        Japão
# 3  Turkish  kapibara   derived_from   Portuguese     capivara

# %%
df_lang1_lang2.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result3.xlsx", index=False)

# %%
### ***
df_lang_pair2 = df_github_cross[(df_github_cross["lang"] == f"{lang_1.capitalize()}") & (df_github_cross["related_lang"] == f"{lang_2.capitalize()}")]
df_lang_pair2
# Out:
#             lang          term related_lang related_term
# 106412   Turkish        kambur   Portuguese      cambiar
# 527330   Turkish      portakal   Portuguese     Portugal
# 575020   Turkish         piyon   Portuguese         peão
# 603501   Turkish        ananas   Portuguese       ananás
# 603737   Turkish        ananas   Portuguese       ananás
# 699092   Turkish          port   Portuguese        Porto
# 1224537  Turkish         Japon   Portuguese        Japão
# 1591382  Turkish       Japonca   Portuguese        Japão
# 1594972  Turkish       bisküvi   Portuguese     biscoito
# 1595993  Turkish       Almanya   Portuguese     Alemanha
# 1690330  Turkish      şampanya   Portuguese     campanha
# 1922956  Turkish          plaj   Portuguese        praia
# 2063933  Turkish         banka   Portuguese        banco
# 2179958  Turkish         tente   Portuguese        tenda
# 2418219  Turkish         fetiş   Portuguese      feitiço
# 2706956  Turkish        tayfun   Portuguese        tufão
# 2824417  Turkish         yarın   Portuguese        manhã
# 2907872  Turkish       kaşalot   Portuguese    cachalote
# 2907874  Turkish       kaşalot   Portuguese      cachola
# 2945140  Turkish  Japon balığı   Portuguese        Japão
# 2979745  Turkish     mandalina   Portuguese     mandarim
# 3545135  Turkish      karamela   Portuguese     caramelo
# 3637779  Turkish       karamel   Portuguese     caramelo
# 3753350  Turkish      marmelat   Portuguese    marmelada
# 3755748  Turkish          şato   Portuguese      castelo
# 3982005  Turkish          jöle   Portuguese        geada
# 4220687  Turkish  akselerasyon   Portuguese   aceleração
# 4257880  Turkish      İspanyol   Portuguese     espanhol
# 4773466  Turkish       komando   Portuguese      comando
# 5648682  Turkish      kampanya   Portuguese     campanha
# 7159130  Turkish          staj   Portuguese      estágio
# 7241993  Turkish        peyzaj   Portuguese     paisagem
# 7488557  Turkish     bocalamak   Portuguese        pojar
# 7488562  Turkish     bocalamak   Portuguese       apoiar
# 8679445  Turkish       bandıra   Portuguese     bandeira

# %%
df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: x.lower())
df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: x.strip())
df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: x.lower())
df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: x.strip())
# Out:
# <ipython-input-23-1e079416b832>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: x.lower())
# <ipython-input-23-1e079416b832>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: x.strip())
# <ipython-input-23-1e079416b832>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: x.lower())
# <ipython-input-23-1e079416b832>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: x.strip())

# %%
df_lang_pair2 = df_lang_pair2.drop_duplicates(subset="term")
df_lang_pair2.reset_index(drop=True, inplace=True)
df_lang_pair2
# Out:
#        lang          term related_lang related_term
# 0   Turkish        kambur   Portuguese      cambiar
# 1   Turkish      portakal   Portuguese     portugal
# 2   Turkish         piyon   Portuguese         peão
# 3   Turkish        ananas   Portuguese       ananás
# 4   Turkish          port   Portuguese        porto
# 5   Turkish         japon   Portuguese        japão
# 6   Turkish       japonca   Portuguese        japão
# 7   Turkish       bisküvi   Portuguese     biscoito
# 8   Turkish       almanya   Portuguese     alemanha
# 9   Turkish      şampanya   Portuguese     campanha
# 10  Turkish          plaj   Portuguese        praia
# 11  Turkish         banka   Portuguese        banco
# 12  Turkish         tente   Portuguese        tenda
# 13  Turkish         fetiş   Portuguese      feitiço
# 14  Turkish        tayfun   Portuguese        tufão
# 15  Turkish         yarın   Portuguese        manhã
# 16  Turkish       kaşalot   Portuguese    cachalote
# 17  Turkish  japon balığı   Portuguese        japão
# 18  Turkish     mandalina   Portuguese     mandarim
# 19  Turkish      karamela   Portuguese     caramelo
# 20  Turkish       karamel   Portuguese     caramelo
# 21  Turkish      marmelat   Portuguese    marmelada
# 22  Turkish          şato   Portuguese      castelo
# 23  Turkish          jöle   Portuguese        geada
# 24  Turkish  akselerasyon   Portuguese   aceleração
# 25  Turkish     i̇spanyol   Portuguese     espanhol
# 26  Turkish       komando   Portuguese      comando
# 27  Turkish      kampanya   Portuguese     campanha
# 28  Turkish          staj   Portuguese      estágio
# 29  Turkish        peyzaj   Portuguese     paisagem
# 30  Turkish     bocalamak   Portuguese        pojar
# 31  Turkish       bandıra   Portuguese     bandeira

# %%
df_lang_pair2.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result2.xlsx", index=False)
