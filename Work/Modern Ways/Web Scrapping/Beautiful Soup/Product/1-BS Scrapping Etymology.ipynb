# %% [markdown]
# ### Etymology

# %%
import pandas as pd
import numpy as np
import glob
import nltk
from nltk.stem import WordNetLemmatizer
from urllib.request import urlopen
from bs4 import BeautifulSoup
from json2html import *
import re
import requests
from urllib.request import Request, urlopen
from urllib import parse
#nltk.download('wordnet')
#nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /home/kurubal/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/kurubal/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
lang_folder = "Turkish"

# %%
df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.lower().capitalize()}/Result/Word/Merge/Word_Merge2.csv")
df_word = df_word.head(10000)
df_word

# %%
#word_lemma = []
#for word in df_word["word"]:
#    word_lemma.append(WordNetLemmatizer().lemmatize(word))
#    word_unique = set(word_lemma)

# %%
#len(word_lemma)

# %%
#len(word_unique)

# %%
word_list = df_word["word"].to_list()

# %%
result_list = []
#for i in word_unique:
for i in word_list:
    try:
        response = requests.get(f"https://etymologeek.com/search/all/{i}")
        soup = BeautifulSoup(response.content, 'lxml')
        word = soup.find('tbody', attrs={"id":"tb"})
        dict_word = word.findAll('td', attrs={"data-th":"Dic. entry"})
        lang = word.findAll('td', attrs={"data-th":"Language"})
        definition = word.findAll('td', attrs={"data-th":"Definition"})
        a_href = word.findAll('td', attrs={"data-th":"Dic. entry"})
        iter_values = zip(dict_word, lang, definition, a_href)
        for a, b, c, d in iter_values:
            var1 = a.get_text()
            var2 = b.get_text()  # string
            var3 = c.get_text()  # string
            var4 = d.find('a').get('href')
            var5 = f"https://etymologeek.com{var4}"
            result_list.append([i, var1, var2, var3, var5])
    except:
        pass

df_result = pd.DataFrame(result_list)
df_result.rename(columns={0:"search_word", 1:"dict_entry", 2:"language", 3:"definition", 4:"href"}, inplace=True)
df_result

# %%
df_result.to_excel(f"{lang_folder.capitalize()}_Etymologeek_Main_Result.xlsx", index=False)

# %% [markdown]
# #### Scrapping Additional Info

# %%
df_main_word = pd.read_excel(f"{lang_folder.capitalize()}_Etymologeek_Main_Result.xlsx")
df_main_word

# %%
df_main_word.search_word.nunique()

# %%
df_main_word.language.nunique()

# %%
search_word = df_main_word["search_word"].to_list()
dict_entry_main = df_main_word["dict_entry"].to_list()
language_main = df_main_word["language"].to_list()
definition_main = df_main_word["definition"].to_list()	
href_url = df_main_word["href"].to_list()
main_iter_values = zip(search_word, dict_entry_main, language_main, definition_main, href_url)
result_list2 = []
for search, dict_ent, lang_main, def_main, href in main_iter_values:
    try:
        response = requests.get(f"{href}")
        soup = BeautifulSoup(response.content, 'lxml')
        word = soup.find('tbody', attrs={"id":"tb"})
        dict_entry = word.findAll('td', attrs={"data-th":"Dic. entry"})
        lang = word.findAll('td', attrs={"data-th":"Language"})
        definition = word.findAll('td', attrs={"data-th":"Definition"})
        iter_values = zip(dict_entry, lang, definition)
        for a, b, c in iter_values:
            var1 = a.get_text()
            var2 = b.get_text()
            var3 = c.get_text()
            result_list2.append([search, dict_ent, lang_main, def_main, var1, var2, var3])
    except:
        pass

df_result2 = pd.DataFrame(result_list2)
df_result2.rename(columns={0:"search_word", 1:"dict_entry_main", 2:"language_main", 3:"definition_main", 4:"dict_entry", 5:"language", 6:"definition"}, inplace=True)
df_result2

# %%
df_result2.language_main = df_result2.language_main.apply(lambda x: x.strip())
df_result2.language = df_result2.language.apply(lambda x: x.strip())

# %%
df_result2.to_excel(f"{lang_folder.capitalize()}_Etymologeek_Main_And_Additional_Result.xlsx", index=False)

# %% [markdown]
# #### Github Data Process

# %%
df_github = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology.csv")
df_github
# Out:
#                         term_id                    lang       term  \
# 0        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 1        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 2        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 3        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 4        iwDzanYmWxaUKbOlUy2yyQ                   Latin  thesaurus
# ...                         ...                     ...        ...
# 3884332  ttDtihHdV4aL8aDWZpIgnQ                 English      Boell
# 3884333  ttDtihHdV4aL8aDWZpIgnQ                 English      Boell
# 3884334  s0ANGE2hXn6nen8AFLynOg  South Levantine Arabic     بالمية
# 3884335  s0ANGE2hXn6nen8AFLynOg  South Levantine Arabic     بالمية
# 3884336  VtU3fy8KXDSUJkNvfVFxgQ                 English     Cooler
#
#                     reltype         related_term_id            related_lang  \
# 0        group_derived_root                     NaN                     NaN
# 1             borrowed_from  fhl-sdgwXaWvYD8CgaKXpQ                   Latin
# 2              derived_from  7Rf1835bWYmlH9VnyYVbpg           Ancient Greek
# 3              doublet_with  sqiifJX3XIOQ0vZ0trzRaA                 English
# 4              derived_from  7Rf1835bWYmlH9VnyYVbpg           Ancient Greek
# ...                     ...                     ...                     ...
# 3884332       borrowed_from  AUIYyyL0V_2rTzbDwWeVig                  Danish
# 3884333       borrowed_from  _zZUp3xTUyyi8TrPVMfOUw                  German
# 3884334           has_affix  QLqQUWCoUu6hQGr40QVQyw  South Levantine Arabic
# 3884335           has_affix  sVDOI8DxUwq2DD03Y3HGdw  South Levantine Arabic
# 3884336        derived_from  0cIktMSLVpKfszbcNudv4w                  German
#
#         related_term  position               group_tag  \
# 0                NaN         0  0IIU6TlkSA2D7dg1PfxGOw
# 1          thēsaurus         0                     NaN
# 2           θησαυρός         0                     NaN
# 3           treasure         0                     NaN
# 4           θησαυρός         0                     NaN
# ...              ...       ...                     ...
# 3884332         Bøll         0                     NaN
# 3884333         Böll         0                     NaN
# 3884334           بـ         0                     NaN
# 3884335       الميّة         1                     NaN
# 3884336       Kühler         0                     NaN
#
#                      parent_tag  parent_position
# 0                           NaN              NaN
# 1        0IIU6TlkSA2D7dg1PfxGOw              0.0
# 2        0IIU6TlkSA2D7dg1PfxGOw              1.0
# 3                           NaN              NaN
# 4                           NaN              NaN
# ...                         ...              ...
# 3884332  VfBh8FOWR_muVFpFl7EOvw              0.0
# 3884333  VfBh8FOWR_muVFpFl7EOvw              1.0
# 3884334                     NaN              NaN
# 3884335                     NaN              NaN
# 3884336                     NaN              NaN
#
# [3884337 rows x 11 columns]

# %%
df_select = df_github.loc[:,["lang","term","reltype","related_lang","related_term"]]
df_select
# Out:
#                            lang       term             reltype  \
# 0                       English  thesaurus  group_derived_root
# 1                       English  thesaurus       borrowed_from
# 2                       English  thesaurus        derived_from
# 3                       English  thesaurus        doublet_with
# 4                         Latin  thesaurus        derived_from
# ...                         ...        ...                 ...
# 3884332                 English      Boell       borrowed_from
# 3884333                 English      Boell       borrowed_from
# 3884334  South Levantine Arabic     بالمية           has_affix
# 3884335  South Levantine Arabic     بالمية           has_affix
# 3884336                 English     Cooler        derived_from
#
#                    related_lang related_term
# 0                           NaN          NaN
# 1                         Latin    thēsaurus
# 2                 Ancient Greek     θησαυρός
# 3                       English     treasure
# 4                 Ancient Greek     θησαυρός
# ...                         ...          ...
# 3884332                  Danish         Bøll
# 3884333                  German         Böll
# 3884334  South Levantine Arabic           بـ
# 3884335  South Levantine Arabic       الميّة
# 3884336                  German       Kühler
#
# [3884337 rows x 5 columns]

# %%
df_select.isnull().sum()
# Out:
# lang                 0
# term                53
# reltype              0
# related_lang    381344
# related_term    381412
# dtype: int64

# %%
df_select.drop_duplicates(inplace=True)
df_select.dropna(inplace=True)
df_select.reset_index(drop=True, inplace=True)
df_select
# Out:
#                            lang         term        reltype  \
# 0                       English    thesaurus  borrowed_from
# 1                       English    thesaurus   derived_from
# 2                       English    thesaurus   doublet_with
# 3                         Latin    thesaurus   derived_from
# 4                       English  portmanteau       has_root
# ...                         ...          ...            ...
# 3484911                 English        Boell  borrowed_from
# 3484912                 English        Boell  borrowed_from
# 3484913  South Levantine Arabic       بالمية      has_affix
# 3484914  South Levantine Arabic       بالمية      has_affix
# 3484915                 English       Cooler   derived_from
#
#                    related_lang  related_term
# 0                         Latin     thēsaurus
# 1                 Ancient Greek      θησαυρός
# 2                       English      treasure
# 3                 Ancient Greek      θησαυρός
# 4           Proto-Indo-European  *per- (fare)
# ...                         ...           ...
# 3484911                  Danish          Bøll
# 3484912                  German          Böll
# 3484913  South Levantine Arabic            بـ
# 3484914  South Levantine Arabic        الميّة
# 3484915                  German        Kühler
#
# [3484916 rows x 5 columns]

# %%
df_select.to_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_clean.csv", index=False)

# %%
df_select2 = df_github.loc[:,["term_id","lang","term","reltype","related_term_id","related_lang","related_term"]]
df_select2
# Out:
#                         term_id                    lang       term  \
# 0        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 1        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 2        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 3        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 4        iwDzanYmWxaUKbOlUy2yyQ                   Latin  thesaurus
# ...                         ...                     ...        ...
# 3884332  ttDtihHdV4aL8aDWZpIgnQ                 English      Boell
# 3884333  ttDtihHdV4aL8aDWZpIgnQ                 English      Boell
# 3884334  s0ANGE2hXn6nen8AFLynOg  South Levantine Arabic     بالمية
# 3884335  s0ANGE2hXn6nen8AFLynOg  South Levantine Arabic     بالمية
# 3884336  VtU3fy8KXDSUJkNvfVFxgQ                 English     Cooler
#
#                     reltype         related_term_id            related_lang  \
# 0        group_derived_root                     NaN                     NaN
# 1             borrowed_from  fhl-sdgwXaWvYD8CgaKXpQ                   Latin
# 2              derived_from  7Rf1835bWYmlH9VnyYVbpg           Ancient Greek
# 3              doublet_with  sqiifJX3XIOQ0vZ0trzRaA                 English
# 4              derived_from  7Rf1835bWYmlH9VnyYVbpg           Ancient Greek
# ...                     ...                     ...                     ...
# 3884332       borrowed_from  AUIYyyL0V_2rTzbDwWeVig                  Danish
# 3884333       borrowed_from  _zZUp3xTUyyi8TrPVMfOUw                  German
# 3884334           has_affix  QLqQUWCoUu6hQGr40QVQyw  South Levantine Arabic
# 3884335           has_affix  sVDOI8DxUwq2DD03Y3HGdw  South Levantine Arabic
# 3884336        derived_from  0cIktMSLVpKfszbcNudv4w                  German
#
#         related_term
# 0                NaN
# 1          thēsaurus
# 2           θησαυρός
# 3           treasure
# 4           θησαυρός
# ...              ...
# 3884332         Bøll
# 3884333         Böll
# 3884334           بـ
# 3884335       الميّة
# 3884336       Kühler
#
# [3884337 rows x 7 columns]

# %%
df_select2.isnull().sum()
# Out:
# term_id                 0
# lang                    0
# term                   53
# reltype                 0
# related_term_id    381344
# related_lang       381344
# related_term       381412
# dtype: int64

# %%
df_select2.drop_duplicates(inplace=True)
df_select2.dropna(inplace=True)
df_select2.reset_index(drop=True, inplace=True)
df_select2
# Out:
#                         term_id                    lang         term  \
# 0        8_rYLlLyVOKJlGFPZIvpVA                 English    thesaurus
# 1        8_rYLlLyVOKJlGFPZIvpVA                 English    thesaurus
# 2        8_rYLlLyVOKJlGFPZIvpVA                 English    thesaurus
# 3        iwDzanYmWxaUKbOlUy2yyQ                   Latin    thesaurus
# 4        BuO_dtS5XKenvDCLQimf5w                 English  portmanteau
# ...                         ...                     ...          ...
# 3484911  ttDtihHdV4aL8aDWZpIgnQ                 English        Boell
# 3484912  ttDtihHdV4aL8aDWZpIgnQ                 English        Boell
# 3484913  s0ANGE2hXn6nen8AFLynOg  South Levantine Arabic       بالمية
# 3484914  s0ANGE2hXn6nen8AFLynOg  South Levantine Arabic       بالمية
# 3484915  VtU3fy8KXDSUJkNvfVFxgQ                 English       Cooler
#
#                reltype         related_term_id            related_lang  \
# 0        borrowed_from  fhl-sdgwXaWvYD8CgaKXpQ                   Latin
# 1         derived_from  7Rf1835bWYmlH9VnyYVbpg           Ancient Greek
# 2         doublet_with  sqiifJX3XIOQ0vZ0trzRaA                 English
# 3         derived_from  7Rf1835bWYmlH9VnyYVbpg           Ancient Greek
# 4             has_root  FWM_rWmKWoGxUEYc9oq8JQ     Proto-Indo-European
# ...                ...                     ...                     ...
# 3484911  borrowed_from  AUIYyyL0V_2rTzbDwWeVig                  Danish
# 3484912  borrowed_from  _zZUp3xTUyyi8TrPVMfOUw                  German
# 3484913      has_affix  QLqQUWCoUu6hQGr40QVQyw  South Levantine Arabic
# 3484914      has_affix  sVDOI8DxUwq2DD03Y3HGdw  South Levantine Arabic
# 3484915   derived_from  0cIktMSLVpKfszbcNudv4w                  German
#
#          related_term
# 0           thēsaurus
# 1            θησαυρός
# 2            treasure
# 3            θησαυρός
# 4        *per- (fare)
# ...               ...
# 3484911          Bøll
# 3484912          Böll
# 3484913            بـ
# 3484914        الميّة
# 3484915        Kühler
#
# [3484916 rows x 7 columns]

# %%
df_select2.to_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_clean2.csv", index=False)

# %% [markdown]
# ##### Sample Process

# %%
df_clean = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_clean.csv")
df_clean = df_clean.head(150000)
df_clean

# %%
df_clean["lang"] = df_clean["lang"].apply(lambda x: x.capitalize())
df_clean["lang"] = df_clean["lang"].apply(lambda x: x.strip())
df_clean["term"] = df_clean["term"].apply(lambda x: x.lower())
df_clean["term"] = df_clean["term"].apply(lambda x: x.strip())
df_clean["related_lang"] = df_clean["related_lang"].apply(lambda x: x.capitalize())
df_clean["related_lang"] = df_clean["related_lang"].apply(lambda x: x.strip())
df_clean["related_term"] = df_clean["related_term"].apply(lambda x: x.lower())
df_clean["related_term"] = df_clean["related_term"].apply(lambda x: x.strip())

# %%
result_list = []
for i in range(len(df_clean)):
    lang_11 = df_clean.loc[i,"lang"]
    term_11 = df_clean.loc[i,"term"]
    reltype_11	= df_clean.loc[i,"reltype"]
    lang_12 = df_clean.loc[i,"related_lang"]
    term_12 = df_clean.loc[i,"related_term"]
    
    try:
        df_var = df_clean[(df_clean["term"] == f"{term_12}")]
        df_var.reset_index(drop=True, inplace=True)
        j = 0
        while j < len(df_var):                    
            lang_21 = df_var.loc[j,"lang"]
            term_21 = df_var.loc[j,"term"]
            #reltype_21	= df_var.loc[j,"reltype"]
            lang_22 = df_var.loc[j,"related_lang"]
            term_22 = df_var.loc[j,"related_term"]
            if ((f"{lang_21}" == f"{lang_12}") & (f"{term_21}" == f"{term_12}")):
                result_list.append([lang_11,term_11,reltype_11,lang_22,term_22])
            else:
                result_list.append([lang_11,term_11,reltype_11,lang_12,term_12])
            
            j+=1
    except:
        result_list.append([lang_11,term_11,reltype_11,lang_12,term_12])

# %%
df_result = pd.DataFrame(result_list, columns=["lang","term","reltype","related_lang","related_term"])
df_result.drop_duplicates(inplace=True)
df_result.reset_index(drop=True,inplace=True)
df_result

# %%
#df_result.to_csv("etymology_cross_check_sample.csv", index=False)

# %% [markdown]
# ##### Multi Process

# %%
import os
import multiprocessing
#import multiprocessing as mp
from multiprocessing import Process, Manager, Pool, Queue
from itertools import islice
import re
import pandas as pd
import numpy as np

# %%
nprocs = multiprocessing.cpu_count()
print(f"Number of CPU cores: {nprocs}")
# Out:
# Number of CPU cores: 16

# %%
# 1-Way
df_clean = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_clean.csv")
df_clean = df_clean.head(150000)
df_clean
# Out:
#            lang         term                    reltype         related_lang  \
# 0       English    thesaurus              borrowed_from                Latin
# 1       English    thesaurus               derived_from        Ancient Greek
# 2       English    thesaurus               doublet_with              English
# 3         Latin    thesaurus               derived_from        Ancient Greek
# 4       English  portmanteau                   has_root  Proto-Indo-European
# ...         ...          ...                        ...                  ...
# 149995  English    architect  etymologically_related_to        Ancient Greek
# 149996  English    architect  etymologically_related_to        Ancient Greek
# 149997    Dutch    architect              borrowed_from        Middle French
# 149998    Dutch    architect               derived_from                Latin
# 149999    Dutch    architect               derived_from        Ancient Greek
#
#         related_term
# 0          thēsaurus
# 1           θησαυρός
# 2           treasure
# 3           θησαυρός
# 4       *per- (fare)
# ...              ...
# 149995         ἀρχι-
# 149996        τέκτων
# 149997    architecte
# 149998   architectus
# 149999    ἀρχιτέκτων
#
# [150000 rows x 5 columns]

# %%
df_clean["lang"] = df_clean["lang"].apply(lambda x: x.capitalize())
df_clean["lang"] = df_clean["lang"].apply(lambda x: x.strip())
df_clean["term"] = df_clean["term"].apply(lambda x: x.lower())
df_clean["term"] = df_clean["term"].apply(lambda x: x.strip())
df_clean["related_lang"] = df_clean["related_lang"].apply(lambda x: x.capitalize())
df_clean["related_lang"] = df_clean["related_lang"].apply(lambda x: x.strip())
df_clean["related_term"] = df_clean["related_term"].apply(lambda x: x.lower())
df_clean["related_term"] = df_clean["related_term"].apply(lambda x: x.strip())

# %%
d_list = range(len(df_clean))

# %%
resultlist = []

# %%
#import os
#from multiprocessing import Process, Manager, Pool, Queue
manager = multiprocessing.Manager()
resultlist = manager.list()

def cross_check(i):
    lang_11 = df_clean.loc[i,"lang"]
    term_11 = df_clean.loc[i,"term"]
    reltype_11	= df_clean.loc[i,"reltype"]
    lang_12 = df_clean.loc[i,"related_lang"]
    term_12 = df_clean.loc[i,"related_term"]
    
    try:
        df_var = df_clean[(df_clean["term"] == f"{term_12}")]
        df_var.reset_index(drop=True, inplace=True)
        j = 0
        while j < len(df_var):                    
            lang_21 = df_var.loc[j,"lang"]
            term_21 = df_var.loc[j,"term"]
            reltype_21	= df_var.loc[j,"reltype"]
            lang_22 = df_var.loc[j,"related_lang"]
            term_22 = df_var.loc[j,"related_term"]
            if ((f"{lang_21}" == f"{lang_12}") & (f"{term_21}" == f"{term_12}")):
                resultlist.append([lang_11,term_11,reltype_21,lang_22,term_22])
            else:
                resultlist.append([lang_11,term_11,reltype_11,lang_12,term_12])
            
            j+=1
    except:
        resultlist.append([lang_11,term_11,reltype_11,lang_12,term_12])

if __name__ == '__main__':
    # with Pool(16) as p:
    with Pool(nprocs) as p: # Pool number CPU sayısına eşit olursa tüm CPU lar çalışır
        p.map(cross_check, d_list) # string_word liste

# %%
result_list = list(resultlist)
df_result = pd.DataFrame(result_list, columns=["lang","term","reltype","related_lang","related_term"])
df_result.drop_duplicates(inplace=True)
df_result.reset_index(drop=True,inplace=True)
df_result
# Out:
#            lang       term         reltype         related_lang related_term
# 0       English      squid        has_root  Proto-indo-european     *gʷeyh₃-
# 1       English      squid  inherited_from       Middle english         quik
# 2       English     theirs    derived_from            Old norse       þeirra
# 3       English     theirs      cognate_of          Old english        heora
# 4       English  thesaurus  inherited_from       Middle english      tresour
# ...         ...        ...             ...                  ...          ...
# 237850  English   wordbook      cognate_of     Norwegian bokmål       ordbok
# 237851  English   wordbook      cognate_of    Norwegian nynorsk       ordbok
# 237852  English   wordbook      cognate_of              Volapük      vödabuk
# 237853  English   wordbook     compound_of               Danish          ord
# 237854  English   wordbook     compound_of               Danish          bog
#
# [237855 rows x 5 columns]

# %%
#df_result.to_csv("etymology_cross_check.csv", index=False)

# %%
#df_result.to_excel("etymology_cross_check.xlsx", index=False)

# %%
# 2-Way (Master)
df_clean2 = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_clean2.csv")
df_clean2 = df_clean2.head(150000)
df_clean2
# Out:
#                        term_id     lang         term  \
# 0       8_rYLlLyVOKJlGFPZIvpVA  English    thesaurus
# 1       8_rYLlLyVOKJlGFPZIvpVA  English    thesaurus
# 2       8_rYLlLyVOKJlGFPZIvpVA  English    thesaurus
# 3       iwDzanYmWxaUKbOlUy2yyQ    Latin    thesaurus
# 4       BuO_dtS5XKenvDCLQimf5w  English  portmanteau
# ...                        ...      ...          ...
# 149995  fsUAmuRuV9OyTjbBF928Yg  English    architect
# 149996  fsUAmuRuV9OyTjbBF928Yg  English    architect
# 149997  7ZnAXsdeX3aRtVH_GgA-pw    Dutch    architect
# 149998  7ZnAXsdeX3aRtVH_GgA-pw    Dutch    architect
# 149999  7ZnAXsdeX3aRtVH_GgA-pw    Dutch    architect
#
#                           reltype         related_term_id  \
# 0                   borrowed_from  fhl-sdgwXaWvYD8CgaKXpQ
# 1                    derived_from  7Rf1835bWYmlH9VnyYVbpg
# 2                    doublet_with  sqiifJX3XIOQ0vZ0trzRaA
# 3                    derived_from  7Rf1835bWYmlH9VnyYVbpg
# 4                        has_root  FWM_rWmKWoGxUEYc9oq8JQ
# ...                           ...                     ...
# 149995  etymologically_related_to  NfL4GpkTX8uegarj6y4cig
# 149996  etymologically_related_to  UlOg8reuXuaoaYDEInocqA
# 149997              borrowed_from  EpKAbGeRVTGuIgvHK_uUwQ
# 149998               derived_from  S80mxnycUK2T-0auJJ1gSQ
# 149999               derived_from  8YcNppPpUsWf6AhERvPgyQ
#
#                related_lang  related_term
# 0                     Latin     thēsaurus
# 1             Ancient Greek      θησαυρός
# 2                   English      treasure
# 3             Ancient Greek      θησαυρός
# 4       Proto-Indo-European  *per- (fare)
# ...                     ...           ...
# 149995        Ancient Greek         ἀρχι-
# 149996        Ancient Greek        τέκτων
# 149997        Middle French    architecte
# 149998                Latin   architectus
# 149999        Ancient Greek    ἀρχιτέκτων
#
# [150000 rows x 7 columns]

# %%
df_clean2["lang"] = df_clean2["lang"].apply(lambda x: x.capitalize())
df_clean2["lang"] = df_clean2["lang"].apply(lambda x: x.strip())
df_clean2["term_id"] = df_clean2["term_id"].apply(lambda x: x.strip())
df_clean2["related_lang"] = df_clean2["related_lang"].apply(lambda x: x.capitalize())
df_clean2["related_lang"] = df_clean2["related_lang"].apply(lambda x: x.strip())
df_clean2["related_term_id"] = df_clean2["related_term_id"].apply(lambda x: x.strip())

# %%
d_list2 = range(len(df_clean2))

# %%
resultlist2 = []

# %%
#import os
#from multiprocessing import Process, Manager, Pool, Queue
manager = multiprocessing.Manager()
resultlist2 = manager.list()

def cross_check(i):
    term_id_11 = df_clean2.loc[i,"term_id"]
    lang_11 = df_clean2.loc[i,"lang"]
    term_11 = df_clean2.loc[i,"term"]
    reltype_11	= df_clean2.loc[i,"reltype"]
    term_id_12 = df_clean2.loc[i,"related_term_id"]
    lang_12 = df_clean2.loc[i,"related_lang"]
    term_12 = df_clean2.loc[i,"related_term"]
    
    try:
        df_var = df_clean2[(df_clean2["term_id"] == f"{term_id_12}")]
        df_var.reset_index(drop=True, inplace=True)
        j = 0
        while j < len(df_var):
            term_id_21 = df_var.loc[j,"term_id"]
            #lang_21 = df_var.loc[j,"lang"]
            #term_21 = df_var.loc[j,"term"]
            reltype_21	= df_var.loc[j,"reltype"]
            term_id_22 = df_var.loc[j,"related_term_id"]
            lang_22 = df_var.loc[j,"related_lang"]
            term_22 = df_var.loc[j,"related_term"]
            if (f"{term_id_21}" == f"{term_id_12}"):
                resultlist2.append([term_id_11,lang_11,term_11,reltype_21,term_id_22,lang_22,term_22])
            else:
                resultlist2.append([term_id_11,lang_11,term_11,reltype_11,term_id_12,lang_12,term_12])
            
            j+=1
    except:
        resultlist2.append([term_id_11,lang_11,term_11,reltype_11,term_id_12,lang_12,term_12])

if __name__ == '__main__':
    # with Pool(16) as p:
    with Pool(nprocs) as p: # Pool number CPU sayısına eşit olursa tüm CPU lar çalışır
        p.map(cross_check, d_list2) # string_word liste

# %%
result_list2 = list(resultlist2)
df_result2 = pd.DataFrame(result_list2, columns=["term_id","lang","term","reltype","related_term_id","related_lang","related_term"])
df_result2.drop_duplicates(inplace=True)
df_result2.reset_index(drop=True,inplace=True)
df_result2
# Out:
#                        term_id     lang      term                    reltype  \
# 0       HloBljqTXuuM6uyqXIVsfA  English    theirs               derived_from
# 1       HloBljqTXuuM6uyqXIVsfA  English    theirs                 cognate_of
# 2       KZGr0B-bUeS8B14e3Ppt_w  English     squid                   has_root
# 3       KZGr0B-bUeS8B14e3Ppt_w  English     squid             inherited_from
# 4       KZGr0B-bUeS8B14e3Ppt_w  English     squid  etymologically_related_to
# ...                        ...      ...       ...                        ...
# 206060  81Q0H906Wpajp0il1_cjoQ  English  wordbook                 cognate_of
# 206061  81Q0H906Wpajp0il1_cjoQ  English  wordbook                 cognate_of
# 206062  81Q0H906Wpajp0il1_cjoQ  English  wordbook                 cognate_of
# 206063  81Q0H906Wpajp0il1_cjoQ  English  wordbook                compound_of
# 206064  81Q0H906Wpajp0il1_cjoQ  English  wordbook                compound_of
#
#                related_term_id         related_lang related_term
# 0       GjZHhrFXV0CcXb2QVaChMA            Old norse       þeirra
# 1       uMqcCj_wXQWphv-G04dgpA          Old english        heora
# 2       p-IXotBxXjaZeDUhzoRNNg  Proto-indo-european     *gʷeyh₃-
# 3       MlbsJDjHWwiImf9DP9DZoQ       Middle english         quik
# 4       dF2TvgihUKKgSk8IyLRyUg       Middle english         quic
# ...                        ...                  ...          ...
# 206060  i_v5cwSPU8uZB32kfI0Sqg     Norwegian bokmål       ordbok
# 206061  aU3nARJ8VY6OiuXfeKcCqA    Norwegian nynorsk       ordbok
# 206062  DbPMRT9eVyeXKcF4cDh6YQ              Volapük      vödabuk
# 206063  HO_E1OrrWqmIo9ieMF-oYQ               Danish          ord
# 206064  I9RggfoOWhOTB4YIf77sdQ               Danish          bog
#
# [206065 rows x 7 columns]

# %%
df_result2.to_csv("etymology_cross_check2.csv", index=False)

# %% [markdown]
# #### Etimoloji Sözlük
