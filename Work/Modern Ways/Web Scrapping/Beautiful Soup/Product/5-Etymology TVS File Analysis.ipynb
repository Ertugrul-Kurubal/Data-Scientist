# %% [markdown]
# ### Etymology TVS File

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize
from pathlib import Path
import shutil

# %% [markdown]
# #### Read TVS And Convert

# %%
#df_tvs = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.tsv", sep="\t")
#df_tvs.rename(columns={"aaq: Pawanobskewi":"column_1","rel:etymological_origin_of":"column_2","eng: Penobscot":"column_3"}, inplace=True)
#df_tvs

# %%
#def low_func(x):
#    try:
#        var_out = x.lower()
#    except:
#        var_out = x
#    return var_out

# %%
#def strip_func(x):
#    try:
#        var_out = x.strip()
#    except:
#        var_out = x
#    return var_out

# %%
#df_col_1 = df_tvs["column_1"].str.split(":", n=-1, expand=True)
#df_col_1 = df_col_1.iloc[:,[0,1]]
#df_col_1.rename(columns={0:"lang",1:"term"}, inplace=True)
#df_col_2 = df_tvs["column_2"].str.split(":", n=-1, expand=True)
#df_col_2 = df_col_2.iloc[:,[1]]
#df_col_2.rename(columns={1:"reltype"}, inplace=True)
#df_col_3 = df_tvs["column_3"].str.split(":", n=-1, expand=True)
#df_col_3 = df_col_3.iloc[:,[0,1]]
#df_col_3.rename(columns={0:"related_lang",1:"related_term"}, inplace=True)

# %%
#df_tvs_expand =  pd.concat([df_col_1,df_col_2,df_col_3], axis=1)
#df_tvs_expand

# %%
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: low_func(x))
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: low_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: strip_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: low_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: low_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: low_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: strip_func(x))

# %%
#df_tvs_expand.to_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv", index=False)

# %% [markdown]
# #### Read CSV File

# %% [markdown]
# ##### Part 1

# %%
df_etymology = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv")
df_etymology
# Out:
#         lang      term                 reltype related_lang   related_term
# 0        aaq    senabe  etymological_origin_of          eng         sannup
# 1        abe  waniigan  etymological_origin_of          eng         wangan
# 2        abe  waniigan  etymological_origin_of          eng       wannigan
# 3        abs      beta  etymological_origin_of          zsm           beta
# 4        adt      yuru  etymological_origin_of          eng           euro
# ...      ...       ...                     ...          ...            ...
# 6031425  zul       ya-  etymological_origin_of          zul  inhlamvu yeso
# 6031426  zul       ya-  etymological_origin_of          zul  inja yasendle
# 6031427  zul       zi-         is_derived_from          zul           izi-
# 6031428  zul      zim-         is_derived_from          zul          izim-
# 6031429  zul      zin-         is_derived_from          zul          izin-
#
# [6031430 rows x 5 columns]

# %%
lang_1 = "rus"  # tur, eng, fra, deu, por, spa, ita, nld, ara, rus
lang_2 = "ara"  # tur, eng, fra, deu, por, spa, ita, nld, ara, rus

if lang_1 == "tur":
    lang_3 = "Turkish"
elif lang_1 == "eng":
    lang_3 = "English"
elif lang_1 == "fra":
    lang_3 = "French"
elif lang_1 == "deu":
    lang_3 = "German"
elif lang_1 == "por":
    lang_3 = "Portuguese"
elif lang_1 == "spa":
    lang_3 = "Spanish"
elif lang_1 == "ita":
    lang_3 = "Italian"
elif lang_1 == "nld":
    lang_3 = "Dutch"
elif lang_1 == "ara":
    lang_3 = "Arabic"
elif lang_1 == "rus":
    lang_3 = "Russian"
else:
    pass

if lang_2 == "tur":
    lang_4 = "Turkish"
elif lang_2 == "eng":
    lang_4 = "English"
elif lang_2 == "fra":
    lang_4 = "French"
elif lang_2 == "deu":
    lang_4 = "German"
elif lang_2 == "por":
    lang_4 = "Portuguese"
elif lang_2 == "spa":
    lang_4 = "Spanish"
elif lang_2 == "ita":
    lang_4 = "Italian"
elif lang_2 == "nld":
    lang_4 = "Dutch"
elif lang_2 == "ara":
    lang_4 = "Arabic"
elif lang_2 == "rus":
    lang_4 = "Russian"
else:
    pass

print(f"{lang_1}\n{lang_2}\n{lang_3}\n{lang_4}")
# Out:
# rus
# ara
# Russian
# Arabic

# %%
#Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
df_lang1 = df_etymology[df_etymology.lang == f"{lang_1.lower()}"]
df_lang1.reset_index(drop=True, inplace=True)
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_1.lower()}")]
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_2.lower()}")]
df_lang1
# Out:
#       lang       term                 reltype related_lang related_term
# 411    rus     abkhas  etymological_origin_of          eng       abkhaz
# 412    rus  cтуденкин  etymological_origin_of          eng    studenkin
# 414    rus   khristos  etymological_origin_of          jpn        ハリストス
# 418    rus     burlak  etymological_origin_of          ron       burlac
# 434    rus      kulak  etymological_origin_of          ell     κουλάκος
# ...    ...        ...                     ...          ...          ...
# 67506  rus        ярл               etymology          non         jarl
# 67509  rus    ярмарка               etymology          pol      jarmark
# 67671  rus     ятаган               etymology          tur      yatağan
# 67692  rus       ящик  etymological_origin_of          hye        յաշիկ
# 67718  rus       ётун               etymology          non       jǫtunn
#
# [2007 rows x 5 columns]

# %%
df_lang2 = df_etymology[df_etymology.lang == f"{lang_2.lower()}"]
df_lang2.reset_index(drop=True, inplace=True)
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_1.lower()}")]
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_2.lower()}")]
df_lang2
# Out:
#      lang             term                 reltype related_lang related_term
# 0     ara  '''اِرْتِداد'''  etymological_origin_of          fas       ارتداد
# 1     ara  '''اِرْتِداد'''  etymological_origin_of          urd       ارتداد
# 2     ara       '''خاصّ'''  etymological_origin_of          urd          خاص
# 3     ara      '''سلطان'''  etymological_origin_of          fas        سلطان
# 4     ara      '''نَظَر'''  etymological_origin_of          fas          نظر
# ...   ...              ...                     ...          ...          ...
# 5970  ara        ‏لُوبِيَا  etymological_origin_of          spa       alubia
# 5971  ara           ’aswad  etymological_origin_of          cat        sudan
# 5972  ara           ’aswad  etymological_origin_of          eng        sudan
# 5975  ara                ﷼  etymological_origin_of          fas            ﷼
# 5976  ara                ﷼               etymology          spa         real
#
# [3378 rows x 5 columns]

# %%
df_lang1_lang2 = pd.merge(df_lang1,df_lang2,how="inner",on=["related_lang","related_term"])
df_lang1_lang2.drop_duplicates(inplace=True)
df_lang1_lang2.reset_index(drop=True, inplace=True)
df_lang1_lang2
# Out:
#    lang_x        term_x  reltype_x related_lang  related_term lang_y  \
# 0     rus    аристотель  etymology          grc   ἀριστοτέλης    ara
# 1     rus       йоркшир  etymology          eng     yorkshire    ara
# 2     rus         конли  etymology          eng        conley    ara
# 3     rus  куала-лумпур  etymology          msa  kuala lumpur    ara
# 4     rus        авария  etymology          ita        avaria    ara
# 5     rus         аллах  etymology          tur         allah    ara
# 6     rus       аятолла  etymology          fas      آیت‌الله    ara
# 7     rus        визирь  etymology          tur         vezir    ara
# 8     rus     грейпфрут  etymology          eng    grapefruit    ara
# 9     rus        дуриан  etymology          eng        durian    ara
# 10    rus           душ  etymology          fra        douche    ara
# 11    rus        кисмет  etymology          tur        kısmet    ara
# 12    rus        макияж  etymology          fra    maquillage    ara
# 13    rus        муссон  etymology          fra       mousson    ara
# 14    rus       муэдзин  etymology          tur       müezzin    ara
# 15    rus         океан  etymology          grc       ὠκεανός    ara
# 16    rus         океан  etymology          grc       ὠκεανός    ara
# 17    rus       рамазан  etymology          tur       ramazan    ara
# 18    rus        сафари  etymology          swa        safari    ara
# 19    rus          хадж  etymology          tur           hac    ara
# 20    rus        шафран  etymology          tur        şafran    ara
# 21    rus           шах  etymology          fas           شاه    ara
# 22    rus        шербет  etymology          ota          شربت    ara
#
#          term_y               reltype_y
# 0         أرسطو               etymology
# 1      يوركشاير               etymology
# 2         كونلي               etymology
# 3   كوالا لمبور               etymology
# 4        عوارية  etymological_origin_of
# 5          الله  etymological_origin_of
# 6      آية الله  etymological_origin_of
# 7          وزير  etymological_origin_of
# 8        كريفون               etymology
# 9         دريان               etymology
# 10          دوش               etymology
# 11         قسمة  etymological_origin_of
# 12       ماكياج               etymology
# 13         موسم  etymological_origin_of
# 14         مؤذن  etymological_origin_of
# 15     أوقيانوس               etymology
# 16        قاموس               etymology
# 17        رمضان  etymological_origin_of
# 18          سفر  etymological_origin_of
# 19         حَجّ  etymological_origin_of
# 20       زعفران  etymological_origin_of
# 21          شاه               etymology
# 22         شربة  etymological_origin_of

# %%
df_lang1_lang2_result1 = df_lang1_lang2.loc[:,["term_x","term_y"]]
df_lang1_lang2_result1.rename(columns={"term_x":"dict_entry_main","term_y":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result1.reset_index(drop=True, inplace=True)
df_lang1_lang2_result1
# Out:
#    dict_entry_main  arabic_word
# 0       аристотель        أرسطو
# 1          йоркшир     يوركشاير
# 2            конли        كونلي
# 3     куала-лумпур  كوالا لمبور
# 4           авария       عوارية
# 5            аллах         الله
# 6          аятолла     آية الله
# 7           визирь         وزير
# 8        грейпфрут       كريفون
# 9           дуриан        دريان
# 10             душ          دوش
# 11          кисмет         قسمة
# 12          макияж       ماكياج
# 13          муссон         موسم
# 14         муэдзин         مؤذن
# 15           океан     أوقيانوس
# 16           океан        قاموس
# 17         рамазан        رمضان
# 18          сафари          سفر
# 19            хадж         حَجّ
# 20          шафран       زعفران
# 21             шах          شاه
# 22          шербет         شربة

# %% [markdown]
# ##### Part 2

# %%
df_lang1_lang2_result2 = df_etymology[(df_etymology["lang"] == f"{lang_1.lower()}") & (df_etymology["related_lang"] == f"{lang_2.lower()}")]
df_lang1_lang2_result2
# Out:
#         lang           term                 reltype related_lang related_term
# 5257325  rus          аббас               etymology          ara         عباس
# 5257326  rus        абдулла               etymology          ara     عبد الله
# 5257458  rus          аллах               etymology          ara         الله
# 5257463  rus    аль-джазира               etymology          ara        جزيرة
# 5258751  rus          коран               etymology          ara       القرآن
# 5260057  rus         шайтан               etymology          ara        شيطان
# 5262739  rus         бедуин               etymology          ara       بدويون
# 5272976  rus          джинн               etymology          ara           جن
# 5278424  rus           имам               etymology          ara         امام
# 5278768  rus  интеллигенция  etymological_origin_of          ara   أنتليجنسيا
# 5279504  rus           кайф               etymology          ara          كيف
# 5280120  rus        кибитка               etymology          ara          قبة
# 5286289  rus       матрёшка  etymological_origin_of          ara    ماتريوشكا
# 5287947  rus          мулла               etymology          ara          ملا
# 5288010  rus         муфтий               etymology          ara       المفتي
# 5288022  rus         мухояр               etymology          ara         مخير
# 5305108  rus        рамадан               etymology          ara        رمضان
# 5307810  rus          салят               etymology          ara         صلاة
# 5314797  rus           сура               etymology          ara         سورة
# 5320427  rus          фусха               etymology          ara         فصحى
# 5320455  rus          хадис               etymology          ara         حديث
# 5321392  rus           царь  etymological_origin_of          ara         تسار
# 5322860  rus         шаурма               etymology          ara       شاورما
# 5322958  rus           шейх               etymology          ara          شيخ

# %%
df_lang1_lang2_result2 = df_lang1_lang2_result2.loc[:,["term","related_term"]]
df_lang1_lang2_result2.rename(columns={"term":"dict_entry_main","related_term":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result2.reset_index(drop=True, inplace=True)
df_lang1_lang2_result2
# Out:
#    dict_entry_main arabic_word
# 0            аббас        عباس
# 1          абдулла    عبد الله
# 2            аллах        الله
# 3      аль-джазира       جزيرة
# 4            коран      القرآن
# 5           шайтан       شيطان
# 6           бедуин      بدويون
# 7            джинн          جن
# 8             имам        امام
# 9    интеллигенция  أنتليجنسيا
# 10            кайф         كيف
# 11         кибитка         قبة
# 12        матрёшка   ماتريوشكا
# 13           мулла         ملا
# 14          муфтий      المفتي
# 15          мухояр        مخير
# 16         рамадан       رمضان
# 17           салят        صلاة
# 18            сура        سورة
# 19           фусха        فصحى
# 20           хадис        حديث
# 21            царь        تسار
# 22          шаурма      شاورما
# 23            шейх         شيخ

# %% [markdown]
# ##### Concat Part 1 And Part 2

# %%
#df_part1_part2_concat = pd.concat([df_lang1_lang2_word_check,df_lang1_lang2_word_check2], axis=0)
df_part1_part2_concat = pd.concat([df_lang1_lang2_result1,df_lang1_lang2_result2], axis=0)
df_part1_part2_concat.drop_duplicates(inplace=True)
df_part1_part2_concat.reset_index(drop=True, inplace=True)
df_part1_part2_concat
# Out:
#    dict_entry_main  arabic_word
# 0       аристотель        أرسطو
# 1          йоркшир     يوركشاير
# 2            конли        كونلي
# 3     куала-лумпур  كوالا لمبور
# 4           авария       عوارية
# 5            аллах         الله
# 6          аятолла     آية الله
# 7           визирь         وزير
# 8        грейпфрут       كريفون
# 9           дуриан        دريان
# 10             душ          دوش
# 11          кисмет         قسمة
# 12          макияж       ماكياج
# 13          муссон         موسم
# 14         муэдзин         مؤذن
# 15           океан     أوقيانوس
# 16           океан        قاموس
# 17         рамазан        رمضان
# 18          сафари          سفر
# 19            хадж         حَجّ
# 20          шафран       زعفران
# 21             шах          شاه
# 22          шербет         شربة
# 23           аббас         عباس
# 24         абдулла     عبد الله
# 25     аль-джазира        جزيرة
# 26           коран       القرآن
# 27          шайтан        شيطان
# 28          бедуин       بدويون
# 29           джинн           جن
# 30            имам         امام
# 31   интеллигенция   أنتليجنسيا
# 32            кайф          كيف
# 33         кибитка          قبة
# 34        матрёшка    ماتريوشكا
# 35           мулла          ملا
# 36          муфтий       المفتي
# 37          мухояр         مخير
# 38         рамадан        رمضان
# 39           салят         صلاة
# 40            сура         سورة
# 41           фусха         فصحى
# 42           хадис         حديث
# 43            царь         تسار
# 44          шаурма       شاورما
# 45            шейх          شيخ

# %%
df_part1_part2_concat.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}/{lang_3.capitalize()}_And_{lang_4.capitalize()}_Etymologeek_Concat_Result2.xlsx", index=False)
