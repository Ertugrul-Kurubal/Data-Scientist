# %% [markdown]
# ### Etymology TVS File

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize
from pathlib import Path
import shutil

# %% [markdown]
# #### Read TVS And Convert

# %%
#df_tvs = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.tsv", sep="\t")
#df_tvs.rename(columns={"aaq: Pawanobskewi":"column_1","rel:etymological_origin_of":"column_2","eng: Penobscot":"column_3"}, inplace=True)
#df_tvs

# %%
#def low_func(x):
#    try:
#        var_out = x.lower()
#    except:
#        var_out = x
#    return var_out

# %%
#def strip_func(x):
#    try:
#        var_out = x.strip()
#    except:
#        var_out = x
#    return var_out

# %%
#df_col_1 = df_tvs["column_1"].str.split(":", n=-1, expand=True)
#df_col_1 = df_col_1.iloc[:,[0,1]]
#df_col_1.rename(columns={0:"lang",1:"term"}, inplace=True)
#df_col_2 = df_tvs["column_2"].str.split(":", n=-1, expand=True)
#df_col_2 = df_col_2.iloc[:,[1]]
#df_col_2.rename(columns={1:"reltype"}, inplace=True)
#df_col_3 = df_tvs["column_3"].str.split(":", n=-1, expand=True)
#df_col_3 = df_col_3.iloc[:,[0,1]]
#df_col_3.rename(columns={0:"related_lang",1:"related_term"}, inplace=True)

# %%
#df_tvs_expand =  pd.concat([df_col_1,df_col_2,df_col_3], axis=1)
#df_tvs_expand

# %%
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: low_func(x))
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: low_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: strip_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: low_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: low_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: low_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: strip_func(x))

# %%
#df_tvs_expand.to_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv", index=False)

# %% [markdown]
# #### Read CSV File

# %% [markdown]
# ##### Part 1

# %%
df_etymology = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv")
df_etymology
# Out:
#         lang      term                 reltype related_lang   related_term
# 0        aaq    senabe  etymological_origin_of          eng         sannup
# 1        abe  waniigan  etymological_origin_of          eng         wangan
# 2        abe  waniigan  etymological_origin_of          eng       wannigan
# 3        abs      beta  etymological_origin_of          zsm           beta
# 4        adt      yuru  etymological_origin_of          eng           euro
# ...      ...       ...                     ...          ...            ...
# 6031425  zul       ya-  etymological_origin_of          zul  inhlamvu yeso
# 6031426  zul       ya-  etymological_origin_of          zul  inja yasendle
# 6031427  zul       zi-         is_derived_from          zul           izi-
# 6031428  zul      zim-         is_derived_from          zul          izim-
# 6031429  zul      zin-         is_derived_from          zul          izin-
#
# [6031430 rows x 5 columns]

# %%
lang_1 = "ara"  # tur, eng, fra, deu, por, spa, ita, nld, ara, rus
lang_2 = "rus"  # tur, eng, fra, deu, por, spa, ita, nld, ara, rus

if lang_1 == "tur":
    lang_3 = "Turkish"
elif lang_1 == "eng":
    lang_3 = "English"
elif lang_1 == "fra":
    lang_3 = "French"
elif lang_1 == "deu":
    lang_3 = "German"
elif lang_1 == "por":
    lang_3 = "Portuguese"
elif lang_1 == "spa":
    lang_3 = "Spanish"
elif lang_1 == "ita":
    lang_3 = "Italian"
elif lang_1 == "nld":
    lang_3 = "Dutch"
elif lang_1 == "ara":
    lang_3 = "Arabic"
elif lang_1 == "rus":
    lang_3 = "Russian"
else:
    pass

if lang_2 == "tur":
    lang_4 = "Turkish"
elif lang_2 == "eng":
    lang_4 = "English"
elif lang_2 == "fra":
    lang_4 = "French"
elif lang_2 == "deu":
    lang_4 = "German"
elif lang_2 == "por":
    lang_4 = "Portuguese"
elif lang_2 == "spa":
    lang_4 = "Spanish"
elif lang_2 == "ita":
    lang_4 = "Italian"
elif lang_2 == "nld":
    lang_4 = "Dutch"
elif lang_2 == "ara":
    lang_4 = "Arabic"
elif lang_2 == "rus":
    lang_4 = "Russian"
else:
    pass

print(f"{lang_1}\n{lang_2}\n{lang_3}\n{lang_4}")
# Out:
# ara
# rus
# Arabic
# Russian

# %%
#Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
df_lang1 = df_etymology[df_etymology.lang == f"{lang_1.lower()}"]
df_lang1.reset_index(drop=True, inplace=True)
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_1.lower()}")]
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_2.lower()}")]
df_lang1
# Out:
#      lang             term                 reltype related_lang related_term
# 0     ara  '''اِرْتِداد'''  etymological_origin_of          fas       ارتداد
# 1     ara  '''اِرْتِداد'''  etymological_origin_of          urd       ارتداد
# 2     ara       '''خاصّ'''  etymological_origin_of          urd          خاص
# 3     ara      '''سلطان'''  etymological_origin_of          fas        سلطان
# 4     ara      '''نَظَر'''  etymological_origin_of          fas          نظر
# ...   ...              ...                     ...          ...          ...
# 5970  ara        ‏لُوبِيَا  etymological_origin_of          spa       alubia
# 5971  ara           ’aswad  etymological_origin_of          cat        sudan
# 5972  ara           ’aswad  etymological_origin_of          eng        sudan
# 5975  ara                ﷼  etymological_origin_of          fas            ﷼
# 5976  ara                ﷼               etymology          spa         real
#
# [3378 rows x 5 columns]

# %%
df_lang2 = df_etymology[df_etymology.lang == f"{lang_2.lower()}"]
df_lang2.reset_index(drop=True, inplace=True)
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_1.lower()}")]
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_2.lower()}")]
df_lang2
# Out:
#       lang       term                 reltype related_lang related_term
# 411    rus     abkhas  etymological_origin_of          eng       abkhaz
# 412    rus  cтуденкин  etymological_origin_of          eng    studenkin
# 414    rus   khristos  etymological_origin_of          jpn        ハリストス
# 418    rus     burlak  etymological_origin_of          ron       burlac
# 434    rus      kulak  etymological_origin_of          ell     κουλάκος
# ...    ...        ...                     ...          ...          ...
# 67506  rus        ярл               etymology          non         jarl
# 67509  rus    ярмарка               etymology          pol      jarmark
# 67671  rus     ятаган               etymology          tur      yatağan
# 67692  rus       ящик  etymological_origin_of          hye        յաշիկ
# 67718  rus       ётун               etymology          non       jǫtunn
#
# [2007 rows x 5 columns]

# %%
df_lang1_lang2 = pd.merge(df_lang1,df_lang2,how="inner",on=["related_lang","related_term"])
df_lang1_lang2.drop_duplicates(inplace=True)
df_lang1_lang2.reset_index(drop=True, inplace=True)
df_lang1_lang2
# Out:
#    lang_x       term_x               reltype_x related_lang  related_term  \
# 0     ara     آية الله  etymological_origin_of          fas      آیت‌الله
# 1     ara        أرسطو               etymology          grc   ἀριστοτέλης
# 2     ara     أوقيانوس               etymology          grc       ὠκεανός
# 3     ara        قاموس               etymology          grc       ὠκεανός
# 4     ara         الله  etymological_origin_of          tur         allah
# 5     ara         حَجّ  etymological_origin_of          tur           hac
# 6     ara        دريان               etymology          eng        durian
# 7     ara          دوش               etymology          fra        douche
# 8     ara        رمضان  etymological_origin_of          tur       ramazan
# 9     ara       زعفران  etymological_origin_of          tur        şafran
# 10    ara          سفر  etymological_origin_of          swa        safari
# 11    ara          شاه               etymology          fas           شاه
# 12    ara         شربة  etymological_origin_of          ota          شربت
# 13    ara       عوارية  etymological_origin_of          ita        avaria
# 14    ara         قسمة  etymological_origin_of          tur        kısmet
# 15    ara       كريفون               etymology          eng    grapefruit
# 16    ara  كوالا لمبور               etymology          msa  kuala lumpur
# 17    ara        كونلي               etymology          eng        conley
# 18    ara         مؤذن  etymological_origin_of          tur       müezzin
# 19    ara       ماكياج               etymology          fra    maquillage
# 20    ara         موسم  etymological_origin_of          fra       mousson
# 21    ara         وزير  etymological_origin_of          tur         vezir
# 22    ara     يوركشاير               etymology          eng     yorkshire
#
#    lang_y        term_y  reltype_y
# 0     rus       аятолла  etymology
# 1     rus    аристотель  etymology
# 2     rus         океан  etymology
# 3     rus         океан  etymology
# 4     rus         аллах  etymology
# 5     rus          хадж  etymology
# 6     rus        дуриан  etymology
# 7     rus           душ  etymology
# 8     rus       рамазан  etymology
# 9     rus        шафран  etymology
# 10    rus        сафари  etymology
# 11    rus           шах  etymology
# 12    rus        шербет  etymology
# 13    rus        авария  etymology
# 14    rus        кисмет  etymology
# 15    rus     грейпфрут  etymology
# 16    rus  куала-лумпур  etymology
# 17    rus         конли  etymology
# 18    rus       муэдзин  etymology
# 19    rus        макияж  etymology
# 20    rus        муссон  etymology
# 21    rus        визирь  etymology
# 22    rus       йоркшир  etymology

# %%
df_lang1_lang2_result1 = df_lang1_lang2.loc[:,["term_x","term_y"]]
df_lang1_lang2_result1.rename(columns={"term_x":"dict_entry_main","term_y":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result1.reset_index(drop=True, inplace=True)
df_lang1_lang2_result1
# Out:
#    dict_entry_main  russian_word
# 0         آية الله       аятолла
# 1            أرسطو    аристотель
# 2         أوقيانوس         океан
# 3            قاموس         океан
# 4             الله         аллах
# 5             حَجّ          хадж
# 6            دريان        дуриан
# 7              دوش           душ
# 8            رمضان       рамазан
# 9           زعفران        шафран
# 10             سفر        сафари
# 11             شاه           шах
# 12            شربة        шербет
# 13          عوارية        авария
# 14            قسمة        кисмет
# 15          كريفون     грейпфрут
# 16     كوالا لمبور  куала-лумпур
# 17           كونلي         конли
# 18            مؤذن       муэдзин
# 19          ماكياج        макияж
# 20            موسم        муссон
# 21            وزير        визирь
# 22        يوركشاير       йоркшир

# %% [markdown]
# ##### Part 2

# %%
df_lang1_lang2_result2 = df_etymology[(df_etymology["lang"] == f"{lang_1.lower()}") & (df_etymology["related_lang"] == f"{lang_2.lower()}")]
df_lang1_lang2_result2
# Out:
#       lang        term                 reltype related_lang   related_term
# 9935   ara  أنتليجنسيا               etymology          rus  интеллигенция
# 10528  ara      القرآن  etymological_origin_of          rus          коран
# 10560  ara        الله  etymological_origin_of          rus          аллах
# 10580  ara      المفتي  etymological_origin_of          rus         муфтий
# 10623  ara        امام  etymological_origin_of          rus           имам
# 10759  ara      بدويون  etymological_origin_of          rus         бедуин
# 11036  ara        تسار               etymology          rus           царь
# 11315  ara       جزيرة  etymological_origin_of          rus    аль-джазира
# 11393  ara          جن  etymological_origin_of          rus          джинн
# 11609  ara        حديث  etymological_origin_of          rus          хадис
# 12314  ara       رمضان  etymological_origin_of          rus        рамадан
# 12644  ara        سورة  etymological_origin_of          rus           сура
# 12700  ara      شاورما  etymological_origin_of          rus         шаурма
# 12863  ara         شيخ  etymological_origin_of          rus           шейх
# 12871  ara       شيطان  etymological_origin_of          rus         шайтан
# 12988  ara        صلاة  etymological_origin_of          rus          салят
# 13231  ara        عباس  etymological_origin_of          rus          аббас
# 13239  ara    عبد الله  etymological_origin_of          rus        абдулла
# 13696  ara        فصحى  etymological_origin_of          rus          фусха
# 13869  ara         قبة  etymological_origin_of          rus        кибитка
# 14391  ara         كيف  etymological_origin_of          rus           кайф
# 14539  ara   ماتريوشكا               etymology          rus       матрёшка
# 14683  ara        مخير  etymological_origin_of          rus         мухояр
# 15004  ara         ملا  etymological_origin_of          rus          мулла

# %%
df_lang1_lang2_result2 = df_lang1_lang2_result2.loc[:,["term","related_term"]]
df_lang1_lang2_result2.rename(columns={"term":"dict_entry_main","related_term":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result2.reset_index(drop=True, inplace=True)
df_lang1_lang2_result2
# Out:
#    dict_entry_main   russian_word
# 0       أنتليجنسيا  интеллигенция
# 1           القرآن          коран
# 2             الله          аллах
# 3           المفتي         муфтий
# 4             امام           имам
# 5           بدويون         бедуин
# 6             تسار           царь
# 7            جزيرة    аль-джазира
# 8               جن          джинн
# 9             حديث          хадис
# 10           رمضان        рамадан
# 11            سورة           сура
# 12          شاورما         шаурма
# 13             شيخ           шейх
# 14           شيطان         шайтан
# 15            صلاة          салят
# 16            عباس          аббас
# 17        عبد الله        абдулла
# 18            فصحى          фусха
# 19             قبة        кибитка
# 20             كيف           кайф
# 21       ماتريوشكا       матрёшка
# 22            مخير         мухояр
# 23             ملا          мулла

# %% [markdown]
# ##### Concat Part 1 And Part 2

# %%
#df_part1_part2_concat = pd.concat([df_lang1_lang2_word_check,df_lang1_lang2_word_check2], axis=0)
df_part1_part2_concat = pd.concat([df_lang1_lang2_result1,df_lang1_lang2_result2], axis=0)
df_part1_part2_concat.drop_duplicates(inplace=True)
df_part1_part2_concat.reset_index(drop=True, inplace=True)
df_part1_part2_concat
# Out:
#    dict_entry_main   russian_word
# 0         آية الله        аятолла
# 1            أرسطو     аристотель
# 2         أوقيانوس          океан
# 3            قاموس          океан
# 4             الله          аллах
# 5             حَجّ           хадж
# 6            دريان         дуриан
# 7              دوش            душ
# 8            رمضان        рамазан
# 9           زعفران         шафран
# 10             سفر         сафари
# 11             شاه            шах
# 12            شربة         шербет
# 13          عوارية         авария
# 14            قسمة         кисмет
# 15          كريفون      грейпфрут
# 16     كوالا لمبور   куала-лумпур
# 17           كونلي          конли
# 18            مؤذن        муэдзин
# 19          ماكياج         макияж
# 20            موسم         муссон
# 21            وزير         визирь
# 22        يوركشاير        йоркшир
# 23      أنتليجنسيا  интеллигенция
# 24          القرآن          коран
# 25          المفتي         муфтий
# 26            امام           имам
# 27          بدويون         бедуин
# 28            تسار           царь
# 29           جزيرة    аль-джазира
# 30              جن          джинн
# 31            حديث          хадис
# 32           رمضان        рамадан
# 33            سورة           сура
# 34          شاورما         шаурма
# 35             شيخ           шейх
# 36           شيطان         шайтан
# 37            صلاة          салят
# 38            عباس          аббас
# 39        عبد الله        абдулла
# 40            فصحى          фусха
# 41             قبة        кибитка
# 42             كيف           кайф
# 43       ماتريوشكا       матрёшка
# 44            مخير         мухояр
# 45             ملا          мулла

# %%
df_part1_part2_concat.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}/{lang_3.capitalize()}_And_{lang_4.capitalize()}_Etymologeek_Concat_Result2.xlsx", index=False)
