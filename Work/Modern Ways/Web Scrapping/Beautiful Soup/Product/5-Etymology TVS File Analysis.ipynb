# %% [markdown]
# ### Etymology TVS File

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize
from pathlib import Path
import shutil

# %% [markdown]
# #### Read TVS And Convert

# %%
#df_tvs = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.tsv", sep="\t")
#df_tvs.rename(columns={"aaq: Pawanobskewi":"column_1","rel:etymological_origin_of":"column_2","eng: Penobscot":"column_3"}, inplace=True)
#df_tvs

# %%
#def low_func(x):
#    try:
#        var_out = x.lower()
#    except:
#        var_out = x
#    return var_out

# %%
#def strip_func(x):
#    try:
#        var_out = x.strip()
#    except:
#        var_out = x
#    return var_out

# %%
#df_col_1 = df_tvs["column_1"].str.split(":", n=-1, expand=True)
#df_col_1 = df_col_1.iloc[:,[0,1]]
#df_col_1.rename(columns={0:"lang",1:"term"}, inplace=True)
#df_col_2 = df_tvs["column_2"].str.split(":", n=-1, expand=True)
#df_col_2 = df_col_2.iloc[:,[1]]
#df_col_2.rename(columns={1:"reltype"}, inplace=True)
#df_col_3 = df_tvs["column_3"].str.split(":", n=-1, expand=True)
#df_col_3 = df_col_3.iloc[:,[0,1]]
#df_col_3.rename(columns={0:"related_lang",1:"related_term"}, inplace=True)

# %%
#df_tvs_expand =  pd.concat([df_col_1,df_col_2,df_col_3], axis=1)
#df_tvs_expand

# %%
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: low_func(x))
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: low_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: strip_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: low_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: low_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: low_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: strip_func(x))

# %%
#df_tvs_expand.to_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv", index=False)

# %% [markdown]
# #### Read CSV File

# %% [markdown]
# ##### Part 1

# %%
df_etymology = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv")
df_etymology
# Out:
#         lang      term                 reltype related_lang   related_term
# 0        aaq    senabe  etymological_origin_of          eng         sannup
# 1        abe  waniigan  etymological_origin_of          eng         wangan
# 2        abe  waniigan  etymological_origin_of          eng       wannigan
# 3        abs      beta  etymological_origin_of          zsm           beta
# 4        adt      yuru  etymological_origin_of          eng           euro
# ...      ...       ...                     ...          ...            ...
# 6031425  zul       ya-  etymological_origin_of          zul  inhlamvu yeso
# 6031426  zul       ya-  etymological_origin_of          zul  inja yasendle
# 6031427  zul       zi-         is_derived_from          zul           izi-
# 6031428  zul      zim-         is_derived_from          zul          izim-
# 6031429  zul      zin-         is_derived_from          zul          izin-
#
# [6031430 rows x 5 columns]

# %%
lang_1 = "rus"  # tur, eng, fra, deu, ??prt, ??esp, ita, nld, ??arb, rus
lang_2 = "nld"  # tur, eng, fra, deu, ??prt, ??esp, ita, nld, ??arb, rus

if lang_1 == "tur":
    lang_3 = "Turkish"
elif lang_1 == "eng":
    lang_3 = "English"
elif lang_1 == "fra":
    lang_3 = "French"
elif lang_1 == "deu":
    lang_3 = "German"
elif lang_1 == "prt":
    lang_3 = "Portuguese"
elif lang_1 == "esp":
    lang_3 = "Spanish"
elif lang_1 == "ita":
    lang_3 = "Italian"
elif lang_1 == "nld":
    lang_3 = "Dutch"
elif lang_1 == "arb":
    lang_3 = "Arabic"
elif lang_1 == "rus":
    lang_3 = "Russian"
else:
    pass

if lang_2 == "tur":
    lang_4 = "Turkish"
elif lang_2 == "eng":
    lang_4 = "English"
elif lang_2 == "fra":
    lang_4 = "French"
elif lang_2 == "deu":
    lang_4 = "German"
elif lang_2 == "prt":
    lang_4 = "Portuguese"
elif lang_2 == "esp":
    lang_4 = "Spanish"
elif lang_2 == "ita":
    lang_4 = "Italian"
elif lang_2 == "nld":
    lang_4 = "Dutch"
elif lang_2 == "arb":
    lang_4 = "Arabic"
elif lang_2 == "rus":
    lang_4 = "Russian"
else:
    pass

print(f"{lang_1}\n{lang_2}\n{lang_3}\n{lang_4}")
# Out:
# rus
# nld
# Russian
# Dutch

# %%
#Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
df_lang1 = df_etymology[df_etymology.lang == f"{lang_1.lower()}"]
df_lang1.reset_index(drop=True, inplace=True)
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_1.lower()}")]
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_2.lower()}")]
df_lang1
# Out:
#       lang       term                 reltype related_lang related_term
# 411    rus     abkhas  etymological_origin_of          eng       abkhaz
# 412    rus  cтуденкин  etymological_origin_of          eng    studenkin
# 414    rus   khristos  etymological_origin_of          jpn        ハリストス
# 418    rus     burlak  etymological_origin_of          ron       burlac
# 434    rus      kulak  etymological_origin_of          ell     κουλάκος
# ...    ...        ...                     ...          ...          ...
# 67506  rus        ярл               etymology          non         jarl
# 67509  rus    ярмарка               etymology          pol      jarmark
# 67671  rus     ятаган               etymology          tur      yatağan
# 67692  rus       ящик  etymological_origin_of          hye        յաշիկ
# 67718  rus       ётун               etymology          non       jǫtunn
#
# [2011 rows x 5 columns]

# %%
df_lang2 = df_etymology[df_etymology.lang == f"{lang_2.lower()}"]
df_lang2.reset_index(drop=True, inplace=True)
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_1.lower()}")]
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_2.lower()}")]
df_lang2
# Out:
#        lang                                  term                 reltype  \
# 0       nld  ''[[alsjeblieft]], [[alstublieft]]''  etymological_origin_of
# 1       nld             ''[[spruw]], [[sprouw]]''  etymological_origin_of
# 4       nld                      's-hertogenbosch  etymological_origin_of
# 5       nld                      's-hertogenbosch  etymological_origin_of
# 56      nld                               -achtig               etymology
# ...     ...                                   ...                     ...
# 123639  nld                                zweren               etymology
# 123676  nld                                 zwerm               etymology
# 123723  nld                                zweven               etymology
# 123766  nld                               zwijgen               etymology
# 123783  nld                                 zwijn               etymology
#
#        related_lang      related_term
# 0               afr         asseblief
# 1               eng             sprue
# 4               eng  's-hertogenbosch
# 5               pol  's-hertogenbosch
# 56              dum           -achtig
# ...             ...               ...
# 123639          dum            sweren
# 123676          dum             swarm
# 123723          dum            sweven
# 123766          dum            swigen
# 123783          dum             swijn
#
# [2252 rows x 5 columns]

# %%
df_lang1_lang2 = pd.merge(df_lang1,df_lang2,how="inner",on=["related_lang","related_term"])
df_lang1_lang2.drop_duplicates(inplace=True)
df_lang1_lang2.reset_index(drop=True, inplace=True)
df_lang1_lang2
# Out:
#    lang_x      term_x               reltype_x related_lang related_term  \
# 0     rus  аристотель               etymology          grc  ἀριστοτέλης
# 1     rus   абдикация               etymology          lat    abdicatio
# 2     rus    аномалия               etymology          grc     ἀνωμαλία
# 3     rus    апартеид               etymology          afr    apartheid
# 4     rus    апартеид               etymology          afr    apartheid
# 5     rus        балл               etymology          fra        balle
# 6     rus      бамбук               etymology          eng       bamboo
# 7     rus      банкир               etymology          deu      bankier
# 8     rus     барбекю               etymology          eng     barbecue
# 9     rus     биг-мэк               etymology          eng      big mac
# 10    rus     бульвар               etymology          fra    boulevard
# 11    rus         бум               etymology          eng         boom
# 12    rus         бум               etymology          eng         boom
# 13    rus      вагина               etymology          lat       vagina
# 14    rus      вакуум               etymology          lat       vacuum
# 15    rus      визирь               etymology          tur        vezir
# 16    rus       гобой               etymology          fra     hautbois
# 17    rus         гой               etymology          yid          גוי
# 18    rus      гондон               etymology          eng       condom
# 19    rus       грипп               etymology          fra       grippe
# 20    rus        дама               etymology          fra         dame
# 21    rus    дисфория               etymology          grc     δυσφορία
# 22    rus        иена               etymology          jpn            円
# 23    rus    карамель               etymology          fra      caramel
# 24    rus    карамель               etymology          fra      caramel
# 25    rus    коктейль               etymology          eng     cocktail
# 26    rus   крашенина  etymological_origin_of          eng        crash
# 27    rus   малайский               etymology          eng        malay
# 28    rus       манго               etymology          eng        mango
# 29    rus        меню               etymology          fra         menu
# 30    rus  педерастия               etymology          grc  παιδεραστία
# 31    rus      плафон               etymology          fra      plafond
# 32    rus         поп               etymology          eng          pop
# 33    rus        саго               etymology          eng         sago
# 34    rus         суп               etymology          fra        soupe
# 35    rus     сюрприз               etymology          fra     surprise
# 36    rus        танк               etymology          eng         tank
# 37    rus     фабрика               etymology          lat      fabrica
# 38    rus        файл               etymology          eng         file
# 39    rus       фасад               etymology          fra       façade
# 40    rus      фольга               etymology          deu        folie
# 41    rus        шейх               etymology          ara          شيخ
# 42    rus    эстафета               etymology          fra    estafette
# 43    rus        этаж               etymology          fra        étage
#
#    lang_y       term_y               reltype_y
# 0     nld  aristoteles               etymology
# 1     nld    abdicatie               etymology
# 2     nld     anomalie               etymology
# 3     nld    apartheid  etymological_origin_of
# 4     nld    apartheid               etymology
# 5     nld         bale               etymology
# 6     nld       bamboe  etymological_origin_of
# 7     nld     bankiers         is_derived_from
# 8     nld     barbecue               etymology
# 9     nld      big mac               etymology
# 10    nld    boulevard               etymology
# 11    nld         boom  etymological_origin_of
# 12    nld         boom               etymology
# 13    nld       vagina               etymology
# 14    nld       vacuüm               etymology
# 15    nld       vizier               etymology
# 16    nld         hobo               etymology
# 17    nld          goj               etymology
# 18    nld      condoom               etymology
# 19    nld        griep               etymology
# 20    nld       dammen               etymology
# 21    nld     dysforie               etymology
# 22    nld          yen               etymology
# 23    nld     caramelo  etymological_origin_of
# 24    nld      karamel               etymology
# 25    nld     cocktail               etymology
# 26    nld      crashen               etymology
# 27    nld       maleis               etymology
# 28    nld        mango               etymology
# 29    nld         menu               etymology
# 30    nld   pederastie               etymology
# 31    nld      plafond               etymology
# 32    nld          pop               etymology
# 33    nld         sago  etymological_origin_of
# 34    nld         soep               etymology
# 35    nld     surprise               etymology
# 36    nld         tank               etymology
# 37    nld      fabriek               etymology
# 38    nld         file               etymology
# 39    nld       façade               etymology
# 40    nld        folie               etymology
# 41    nld        sheik               etymology
# 42    nld    estafette               etymology
# 43    nld        etage               etymology

# %%
df_lang1_lang2_result1 = df_lang1_lang2.loc[:,["term_x","term_y"]]
df_lang1_lang2_result1.rename(columns={"term_x":"dict_entry_main","term_y":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result1.reset_index(drop=True, inplace=True)
df_lang1_lang2_result1
# Out:
#    dict_entry_main   dutch_word
# 0       аристотель  aristoteles
# 1        абдикация    abdicatie
# 2         аномалия     anomalie
# 3         апартеид    apartheid
# 4         апартеид    apartheid
# 5             балл         bale
# 6           бамбук       bamboe
# 7           банкир     bankiers
# 8          барбекю     barbecue
# 9          биг-мэк      big mac
# 10         бульвар    boulevard
# 11             бум         boom
# 12             бум         boom
# 13          вагина       vagina
# 14          вакуум       vacuüm
# 15          визирь       vizier
# 16           гобой         hobo
# 17             гой          goj
# 18          гондон      condoom
# 19           грипп        griep
# 20            дама       dammen
# 21        дисфория     dysforie
# 22            иена          yen
# 23        карамель     caramelo
# 24        карамель      karamel
# 25        коктейль     cocktail
# 26       крашенина      crashen
# 27       малайский       maleis
# 28           манго        mango
# 29            меню         menu
# 30      педерастия   pederastie
# 31          плафон      plafond
# 32             поп          pop
# 33            саго         sago
# 34             суп         soep
# 35         сюрприз     surprise
# 36            танк         tank
# 37         фабрика      fabriek
# 38            файл         file
# 39           фасад       façade
# 40          фольга        folie
# 41            шейх        sheik
# 42        эстафета    estafette
# 43            этаж        etage

# %% [markdown]
# ##### Part 2

# %%
df_lang1_lang2_result2 = df_etymology[(df_etymology["lang"] == f"{lang_1.lower()}") & (df_etymology["related_lang"] == f"{lang_2.lower()}")]
df_lang1_lang2_result2
# Out:
#         lang       term                 reltype related_lang related_term
# 5260373  rus    абрикос               etymology          nld     abrikoos
# 5262531  rus       баня  etymological_origin_of          nld        banja
# 5264655  rus      брюки               etymology          nld        broek
# 5264887  rus      бухта               etymology          nld        bocht
# 5264889  rus    бушприт               etymology          nld   boegspriet
# 5265186  rus   ватерпас               etymology          nld     waterpas
# 5265675  rus      верфь               etymology          nld         werf
# 5273506  rus    домкрат               etymology          nld  dommekracht
# 5274330  rus       дюйм               etymology          nld         duim
# 5277540  rus     зонтик               etymology          nld     zonnedek
# 5280164  rus  кильватер               etymology          nld    kielwater
# 5285876  rus    макрель               etymology          nld      makreel
# 5286288  rus     матрос               etymology          nld      matroos
# 5293372  rus        ост               etymology          nld         oost
# 5306050  rus       рейс               etymology          nld         reis
# 5315211  rus    такелаж               etymology          nld     takelage
# 5318229  rus       указ  etymological_origin_of          nld       oekaze
# 5323341  rus     штопор               etymology          nld      stopper
# 5323357  rus    штурвал               etymology          nld    stuurwiel
# 5323361  rus    штурман               etymology          nld     stuurman

# %%
df_lang1_lang2_result2 = df_lang1_lang2_result2.loc[:,["term","related_term"]]
df_lang1_lang2_result2.rename(columns={"term":"dict_entry_main","related_term":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result2.reset_index(drop=True, inplace=True)
df_lang1_lang2_result2
# Out:
#    dict_entry_main   dutch_word
# 0          абрикос     abrikoos
# 1             баня        banja
# 2            брюки        broek
# 3            бухта        bocht
# 4          бушприт   boegspriet
# 5         ватерпас     waterpas
# 6            верфь         werf
# 7          домкрат  dommekracht
# 8             дюйм         duim
# 9           зонтик     zonnedek
# 10       кильватер    kielwater
# 11         макрель      makreel
# 12          матрос      matroos
# 13             ост         oost
# 14            рейс         reis
# 15         такелаж     takelage
# 16            указ       oekaze
# 17          штопор      stopper
# 18         штурвал    stuurwiel
# 19         штурман     stuurman

# %% [markdown]
# ##### Concat Part 1 And Part 2

# %%
#df_part1_part2_concat = pd.concat([df_lang1_lang2_word_check,df_lang1_lang2_word_check2], axis=0)
df_part1_part2_concat = pd.concat([df_lang1_lang2_result1,df_lang1_lang2_result2], axis=0)
df_part1_part2_concat.drop_duplicates(inplace=True)
df_part1_part2_concat.reset_index(drop=True, inplace=True)
df_part1_part2_concat
# Out:
#    dict_entry_main   dutch_word
# 0       аристотель  aristoteles
# 1        абдикация    abdicatie
# 2         аномалия     anomalie
# 3         апартеид    apartheid
# 4             балл         bale
# ..             ...          ...
# 57         такелаж     takelage
# 58            указ       oekaze
# 59          штопор      stopper
# 60         штурвал    stuurwiel
# 61         штурман     stuurman
#
# [62 rows x 2 columns]

# %%
df_part1_part2_concat.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}/{lang_3.capitalize()}_And_{lang_4.capitalize()}_Etymologeek_Concat_Result2.xlsx", index=False)
