# %% [markdown]
# ### Etymology Cross Check

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### Etymologeek Result

# %%
lang_1 = "German"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian 
lang_2 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
if lang_2 == "English":
    lang_3 = "English (eng)"
elif lang_2 == "Turkish":
    lang_3 = "Turkish (tur)"
elif lang_2 == "German":
    lang_3 = "German (deu)"
elif lang_2 == "French":
    lang_3 = "French (fra)"
elif lang_2 == "Spanish":
    lang_3 = "Spanish (spa)"
elif lang_2 == "Arabic":
    lang_3 = "Arabic (ara)"
elif lang_2 == "Russian":
    lang_3 = "Russian (rus)"
elif lang_2 == "Portuguese":
    lang_3 = "Portuguese (por)"
elif lang_2 == "Dutch":
    lang_3 = "Dutch (nld)"
elif lang_2 == "Italian":
    lang_3 = "Italian (ita)"
else:
    pass
#lang_3 = "English (eng)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)
print(f"{lang_1}\n{lang_2}\n{lang_3}")
# Out:
# English
# Italian
# Italian (ita)

# %%
lang_1_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_1.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_1_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Russian (rus)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Turkish (tur)_Etymologeek_Result1.xlsx']

# %%
df_lang_1 = pd.DataFrame()
for i in lang_1_file:
    df_var = pd.read_excel(f"{i}")
    df_lang_1 = pd.concat([df_lang_1,df_var], axis=0)
    df_lang_1.reset_index(drop=True, inplace=True)
df_lang_1
# Out:
#      search_word dict_entry_main language_main  \
# 0           aman         amanaty       English
# 1          sakin          sakina       English
# 2          cevap          cevapi       English
# 3           hale          haleem       English
# 4            dua             dua       English
# ...          ...             ...           ...
# 3033       marta        martagon       English
# 3034        lahm        lahmacun       English
# 3035        caza            caza       English
# 3036     chagrin         chagrin       English
# 3037       gilet           gilet       English
#
#                                         definition_main dict_entry  \
# 0     (Noun) (historical) Native American hostages t...   أَمَانَة
# 1     (Noun) (Islam) the divine tranquility obtained...   سَكِينَة
# 2     (Noun) A Balkan food dish of minced meat.A Bal...     كَبَاب
# 3     (Noun) A stew-like dish traditionally consisti...     حَلِيم
# 4     (Noun) (Islam) An Islamic invocation.(Islam) A...      دَعَا
# ...                                                 ...        ...
# 3033            (Noun) A Eurasian lily.A Eurasian lily.   martagan
# 3034  (Noun) A dish of Arab origin consisting of a r...   lahmacun
# 3035  (Noun) A Turkish provincial subdivision.A Turk...       kaza
# 3036  (Verb Noun) (intransitive) To be vexed or anno...      sağrı
# 3037  (Noun) A sleeveless jacket similar to a waistc...      yelek
#
#            language                                         definition
# 0      Arabic (ara)                                                NaN
# 1      Arabic (ara)                                                NaN
# 2      Arabic (ara)                                                NaN
# 3      Arabic (ara)                                                NaN
# 4      Arabic (ara)                                                NaN
# ...             ...                                                ...
# 3033  Turkish (tur)                                                NaN
# 3034  Turkish (tur)                                          Lahmacun.
# 3035  Turkish (tur)                                          Accident.
# 3036  Turkish (tur)  The chubby and round part of a mammal's body b...
# 3037  Turkish (tur)                           Jelick. Waistcoat, vest.
#
# [3038 rows x 7 columns]

# %%
lang_2_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_2.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_2_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Russian (rus)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Turkish (tur)_Etymologeek_Result1.xlsx']

# %%
df_lang_2 = pd.DataFrame()
for i in lang_2_file:
    df_var2 = pd.read_excel(f"{i}")
    df_lang_2 = pd.concat([df_lang_2,df_var2], axis=0)
    df_lang_2.reset_index(drop=True, inplace=True)
df_lang_2
# Out:
#     search_word dict_entry_main language_main  \
# 0         tarif         tariffa       Italian
# 1         nadir           nadir       Italian
# 2          atan          atanor       Italian
# 3           tuz           tuzia       Italian
# 4         burnu          burnus       Italian
# ..          ...             ...           ...
# 794        ulan           ulano       Italian
# 795         cia        ciabatta       Italian
# 796        curb       curbascio       Italian
# 797      yogurt          yogurt       Italian
# 798        scia       sciacallo       Italian
#
#                                        definition_main       dict_entry  \
# 0    (Noun Verb) Rate, tariff, price, charge, fare ...        تَعْرِفَة
# 1          (Noun) (astronomy) nadir.(astronomy) nadir.  نَظِير السَّمْت
# 2                              (Noun) Athanor.Athanor.             تنور
# 3                                  (Noun) Tutty.Tutty.        تُوتِيَاء
# 4                            (Noun) Burnoose.Burnoose.          بُرْنُس
# ..                                                 ...              ...
# 794                    (Noun) Ulan, uhlan.Ulan, uhlan.            oğlan
# 795  (Noun) (cooking) ciabatta (flat bread). Power ...           zabata
# 796                                  (Noun) Whip.Whip.           kırbaç
# 797                              (Noun) Yogurt.Yogurt.           yoğurt
# 798  (Noun) Jackal. Looter. Profiteer.Jackal. Loote...            çakal
#
#           language                                         definition
# 0     Arabic (ara)                                                NaN
# 1     Arabic (ara)                                                NaN
# 2     Arabic (ara)  Illumination, enlightenment Cook stove. Oven, ...
# 3     Arabic (ara)                                                NaN
# 4     Arabic (ara)                                                NaN
# ..             ...                                                ...
# 794  Turkish (tur)                 (slang) catamite. Boy, male child.
# 795  Turkish (tur)                                                NaN
# 796  Turkish (tur)                                        Whip, lash.
# 797  Turkish (tur)                                            Yogurt.
# 798  Turkish (tur)  (pejorative, derogatory) A detestable person, ...
#
# [799 rows x 7 columns]

# %%
set_lang_11 = set(df_lang_1["dict_entry"])

# %%
set_lang_12 = set(df_lang_2["dict_entry"])

# %%
df_cross = pd.DataFrame(set_lang_11.intersection(set_lang_12), columns=["dict_entry"])
df_cross
# Out:
#       dict_entry
# 0    reconqueste
# 1       boutique
# 2           sumo
# 3           fuck
# 4        سُمَّاق
# ..           ...
# 203          طبل
# 204          pur
# 205    prehensus
# 206      émotion
# 207         -oso
#
# [208 rows x 1 columns]

# %%
df_lang_1_cross = pd.merge(df_cross,df_lang_1,how="inner", on="dict_entry")
df_lang_1_cross.drop_duplicates(inplace=True)
df_lang_1_cross = df_lang_1_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_1_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master"}, inplace=True)
df_lang_1_cross
# Out:
#     lang_master    term_master   dict_entry
# 0       English       relevant  reconqueste
# 1       English  ramollescence  reconqueste
# 2       English     retirement  reconqueste
# 3       English        relieve  reconqueste
# 4       English         regret  reconqueste
# ..          ...            ...          ...
# 340     English           pure          pur
# 341     English           puro          pur
# 342     English          price    prehensus
# 343     English        emotion      émotion
# 344     English        vicious         -oso
#
# [345 rows x 3 columns]

# %%
df_lang_2_cross = pd.merge(df_cross,df_lang_2,how="inner", on="dict_entry")
df_lang_2_cross.drop_duplicates(inplace=True)
df_lang_2_cross = df_lang_2_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_2_cross.rename(columns={"language_main":"lang_sleeve","dict_entry_main":"term_sleeve"}, inplace=True)
df_lang_2_cross
# Out:
#     lang_sleeve term_sleeve   dict_entry
# 0       Italian   rilevante  reconqueste
# 1       Italian    boutique     boutique
# 2       Italian    assumere         sumo
# 3       Italian     fottiti         fuck
# 4       Italian    sommacco      سُمَّاق
# ..          ...         ...          ...
# 293     Italian        pure          pur
# 294     Italian        puro          pur
# 295     Italian       preso    prehensus
# 296     Italian    emozione      émotion
# 297     Italian    foglioso         -oso
#
# [298 rows x 3 columns]

# %%
df_lang_1_lang_2_cross = pd.merge(df_lang_1_cross,df_lang_2_cross, how="inner", on="dict_entry")
df_lang_1_lang_2_cross.drop_duplicates(inplace=True)
df_lang_1_lang_2_cross = df_lang_1_lang_2_cross[["lang_master","term_master","lang_sleeve","term_sleeve"]]
df_lang_1_lang_2_cross
# Out:
#     lang_master    term_master lang_sleeve term_sleeve
# 0       English       relevant     Italian   rilevante
# 1       English  ramollescence     Italian   rilevante
# 2       English     retirement     Italian   rilevante
# 3       English        relieve     Italian   rilevante
# 4       English         regret     Italian   rilevante
# ..          ...            ...         ...         ...
# 671     English           puro     Italian        pure
# 672     English           puro     Italian        puro
# 673     English          price     Italian       preso
# 674     English        emotion     Italian    emozione
# 675     English        vicious     Italian    foglioso
#
# [654 rows x 4 columns]

# %%
lang_3_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/*_And_{lang_3.capitalize()}_Etymologeek_Result1.xlsx")
lang_3_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Arabic/Arabic_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Russian/Russian_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_Italian (ita)_Etymologeek_Result1.xlsx']

# %%
df_lang_3 = pd.DataFrame()
for i in lang_3_file:
    df_var3 = pd.read_excel(f"{i}")
    df_lang_3 = pd.concat([df_lang_3,df_var3], axis=0)
    df_lang_3.reset_index(drop=True, inplace=True)
df_lang_3
# Out:
#      search_word dict_entry_main language_main  \
# 0          polis           polis       Turkish
# 1         kaptan          kaptan       Turkish
# 2           bira            bira       Turkish
# 3           grup            grup       Turkish
# 4          banka           banka       Turkish
# ...          ...             ...           ...
# 1163       sopra         sopraan         Dutch
# 1164       frega          fregat         Dutch
# 1165       provi        proviand         Dutch
# 1166    libretto        libretto         Dutch
# 1167       lotto           lotto         Dutch
#
#                                         definition_main dict_entry  \
# 0     (Noun) Police (an organisation that enforces t...    polizia
# 1                               (Noun) Captain.Captain.    capitan
# 2                                     (Noun) Beer.Beer.      birra
# 3     (Noun) (mathematics, music) grup. Group.(mathe...     groppo
# 4                                     (Noun) Bank.Bank.      banca
# ...                                                 ...        ...
# 1163  (Noun) (music) The soprano, the highest of the...      sopra
# 1164  (Noun) A frigate, type of (once sailing, small...    fregata
# 1165  (Noun) Food supplies, edible provision, in par...  provianda
# 1166          (Noun) (music) libretto.(music) libretto.      libro
# 1167                                                NaN      lotto
#
#            language                                         definition
# 0     Italian (ita)                                            Police.
# 1     Italian (ita)                                                NaN
# 2     Italian (ita)                         Beer. Beer, glass of beer.
# 3     Italian (ita)                                            Tangle.
# 4     Italian (ita)                      Bank (financial institution).
# ...             ...                                                ...
# 1163  Italian (ita)  Above. On top. Up Above. More than. On, onto. ...
# 1164  Italian (ita)                      Frigate Rip-off. Rub, polish.
# 1165  Italian (ita)                                                NaN
# 1166  Italian (ita)                     (botany) phloem. Book. Omasum.
# 1167  Italian (ita)                      Lot. Lottery. Plot (of land).
#
# [1168 rows x 7 columns]

# %%
set_lang_21 = set(df_lang_1["dict_entry_main"])

# %%
set_lang_23 = set(df_lang_3["dict_entry_main"])

# %%
df_cross_2 = pd.DataFrame(set_lang_21.intersection(set_lang_23), columns=["dict_entry_main"])
df_cross_2
# Out:
#     dict_entry_main
# 0          campaign
# 1             brave
# 2          remember
# 3                oz
# 4          milliard
# ..              ...
# 480      catenaccio
# 481          accord
# 482            vain
# 483          ultimo
# 484         brigade
#
# [485 rows x 1 columns]

# %%
df_lang_1_lang_3_cross = pd.merge(df_cross_2,df_lang_3,how="inner", on="dict_entry_main")
df_lang_1_lang_3_cross.drop_duplicates(inplace=True)
df_lang_1_lang_3_cross = df_lang_1_lang_3_cross[["language_main","dict_entry_main","language","dict_entry"]]
df_lang_1_lang_3_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master","language":"lang_sleeve","dict_entry":"term_sleeve"}, inplace=True)
df_lang_1_lang_3_cross
# Out:
#     lang_master term_master    lang_sleeve term_sleeve
# 0       English    campaign  Italian (ita)    campagna
# 1       English       brave  Italian (ita)       bravo
# 2        French       brave  Italian (ita)       bravo
# 3       English    remember  Italian (ita)   rememoror
# 4       English          oz  Italian (ita)        onza
# ..          ...         ...            ...         ...
# 611     English        vain  Italian (ita)        vano
# 612      French        vain  Italian (ita)        vano
# 613     English      ultimo  Italian (ita)      ultimo
# 614     English     brigade  Italian (ita)       briga
# 615      French     brigade  Italian (ita)       briga
#
# [616 rows x 4 columns]

# %%
df_lang_1_lang_2_lang_3 = pd.concat([df_lang_1_lang_2_cross,df_lang_1_lang_3_cross], axis=0)
df_lang_1_lang_2_lang_3.reset_index(drop=True, inplace=True)
df_lang_1_lang_2_lang_3["term_master"] = df_lang_1_lang_2_lang_3["term_master"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3["term_sleeve"] = df_lang_1_lang_2_lang_3["term_sleeve"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3
# Out:
#      lang_master    term_master    lang_sleeve term_sleeve
# 0        English       relevant        Italian   rilevante
# 1        English  ramollescence        Italian   rilevante
# 2        English     retirement        Italian   rilevante
# 3        English        relieve        Italian   rilevante
# 4        English         regret        Italian   rilevante
# ...          ...            ...            ...         ...
# 1265     English           vain  Italian (ita)        vano
# 1266      French           vain  Italian (ita)        vano
# 1267     English         ultimo  Italian (ita)      ultimo
# 1268     English        brigade  Italian (ita)       briga
# 1269      French        brigade  Italian (ita)       briga
#
# [1270 rows x 4 columns]

# %%
df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
df_word = df_word.head(40000)
df_word = df_word.loc[:,["word"]]
df_word.rename(columns={"word":"term_sleeve"}, inplace=True)
df_word
# Out:
#          term_sleeve
# 0                  e
# 1                non
# 2                che
# 3                 di
# 4                 un
# ...              ...
# 39995  interminabili
# 39996       vendesse
# 39997      guaritori
# 39998          lives
# 39999       facetime
#
# [40000 rows x 1 columns]

# %%
df_lang_1_lang_2_lang_3 = pd.merge(df_lang_1_lang_2_lang_3,df_word, how="inner", on="term_sleeve")
df_lang_1_lang_2_lang_3
# Out:
#     lang_master    term_master    lang_sleeve term_sleeve
# 0       English       relevant        Italian   rilevante
# 1       English  ramollescence        Italian   rilevante
# 2       English     retirement        Italian   rilevante
# 3       English        relieve        Italian   rilevante
# 4       English         regret        Italian   rilevante
# ..          ...            ...            ...         ...
# 962     English       corridor  Italian (ita)   corridore
# 963      French       corridor  Italian (ita)   corridore
# 964     English          fango  Italian (ita)       fango
# 965     English       contessa  Italian (ita)    contessa
# 966     English          bocca  Italian (ita)       bocca
#
# [967 rows x 4 columns]

# %%
df_lang_1_lang_2_lang_3.to_excel(f"{lang_1.capitalize()}_And_{lang_3.capitalize()}_Etymologeek_Result5.xlsx", index=False)
