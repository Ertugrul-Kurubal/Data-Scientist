# %% [markdown]
# ### Etymology Cross Check

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize

# %%
lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Portuguese"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_3 = "Portuguese (por)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)

# %%
lang_1_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_1.capitalize()}_And_*_Etymologeek_Result_All.xlsx")
lang_1_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Dutch (nld)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Arabic (ara)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_English (eng)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_French (fra)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Italian (ita)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Portuguese (por)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Spanish (spa)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_German (deu)_Etymologeek_Result_All.xlsx']

# %%
df_lang_1 = pd.DataFrame()
for i in lang_1_file:
    df_var = pd.read_excel(f"{i}")
    df_lang_1 = pd.concat([df_lang_1,df_var], axis=0)
    df_lang_1.reset_index(drop=True, inplace=True)
df_lang_1
# Out:
#      search_word dict_entry_main language_main  \
# 0           şans            şans       Turkish
# 1           loca            loca       Turkish
# 2             mı        mıknatıs       Turkish
# 3             mı          mısdak       Turkish
# 4            şey             şey       Turkish
# ..           ...             ...           ...
# 732       vermut          vermut       Turkish
# 733       panzer          panzer       Turkish
# 734  tonymayster     tonymayster       Turkish
# 735      filinta         filinta       Turkish
# 736       kuvars          kuvars       Turkish
#
#                                        definition_main   dict_entry  \
# 0                  (Noun) Fortune. Luck.Fortune. Luck.         dice
# 1    (Noun) (masonic) lodge. Box (in theaters).(mas...       laubja
# 2                                (Noun) Magnet.Magnet.  مِغْنَاطِيس
# 3    (Noun) (obsolete) criterion.(obsolete) criterion.     مِصْدَاق
# 4    (Noun Interjection) (slang) genital organ. Thi...      شَيْئاً
# ..                                                 ...          ...
# 732                                             (Noun)       wermut
# 733                                             (Noun)       panzer
# 734                                             (Noun)   tonmeister
# 735                                             (Noun)       flinte
# 736                                             (Noun)        quarz
#
#          language                                         definition
# 0     Dutch (nld)                                                NaN
# 1     Dutch (nld)                                                NaN
# 2    Arabic (ara)                                                NaN
# 3    Arabic (ara)                                                NaN
# 4    Arabic (ara)                                                NaN
# ..            ...                                                ...
# 732  German (deu)  Vermouth is an aromatized fortified wine, flav...
# 733  German (deu)  A tank is an armoured fighting vehicle intende...
# 734  German (deu)                                         Tonmeister
# 735  German (deu)                                             Flinte
# 736  German (deu)  Quartz is a hard, crystalline mineral composed...
#
# [737 rows x 7 columns]

# %%
#lang_2_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/*_And_{lang_2.capitalize()}_Etymologeek_Result_All.xlsx")
#lang_2_file

# %%
lang_2_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_2.capitalize()}_And_*_Etymologeek_Result_All.xlsx")
lang_2_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Arabic (ara)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Dutch (nld)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_English (eng)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_French (fra)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_German (deu)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Italian (ita)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Russian (rus)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Spanish (spa)_Etymologeek_Result_All.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Turkish (tur)_Etymologeek_Result_All.xlsx']

# %%
df_lang_2 = pd.DataFrame()
for i in lang_2_file:
    df_var2 = pd.read_excel(f"{i}")
    df_lang_2 = pd.concat([df_lang_2,df_var2], axis=0)
    df_lang_2.reset_index(drop=True, inplace=True)
df_lang_2
# Out:
#      search_word dict_entry_main language_main  \
# 0             aç        açacalar    Portuguese
# 1             aç         açafrão    Portuguese
# 2           emir            emir    Portuguese
# 3            saf          safado    Portuguese
# 4            saf           safar    Portuguese
# ...          ...             ...           ...
# 1057      solito          solito    Portuguese
# 1058       birra           birra    Portuguese
# 1059        cani         canibal    Portuguese
# 1060       ladri        ladrilho    Portuguese
# 1061      caviar          caviar    Portuguese
#
#                                         definition_main       dict_entry  \
# 0     (Verb) To polish; to burnish.To polish; to bur...           صَقَلَ
# 1                               (Noun) Saffron.Saffron.       زَعْفَرَان
# 2     (Noun) Emir (Islamic prince or leader).Emir (I...  أَمِير الْبَحْر
# 3     (Noun Adjective) (colloquial) rogue; trickster...          أَزَاحَ
# 4     (Verb) (colloquial) to save. (pronominal) to a...          أَزَاحَ
# ...                                                 ...              ...
# 1057  (Adjective) (Rio Grande do Sul) alone; unaccom...             solo
# 1058  (Verb Noun) (uncountable) obstinacy (state of ...           birria
# 1059                     (Adjective) Cannibal.Cannibal.          canibal
# 1060                    (Noun) Brick. Tile.Brick. Tile.         ladrillo
# 1061                              (Noun) Caviar.Caviar.           havyar
#
#            language                                         definition
# 0      Arabic (ara)                                                NaN
# 1      Arabic (ara)                                                NaN
# 2      Arabic (ara)                                                NaN
# 3      Arabic (ara)                                                NaN
# 4      Arabic (ara)                                                NaN
# ...             ...                                                ...
# 1057  Spanish (spa)  Alone, by oneself. Lonely, lonesome. Sole, onl...
# 1058  Spanish (spa)                                     Garbage, junk.
# 1059  Spanish (spa)                                                NaN
# 1060  Spanish (spa)                                             Brick.
# 1061  Turkish (tur)                                            Caviar.
#
# [1062 rows x 7 columns]

# %%
set_lang_1 = set(df_lang_1["dict_entry"])

# %%
set_lang_2 = set(df_lang_2["dict_entry"])

# %%
df_cross = pd.DataFrame(set_lang_1.intersection(set_lang_2), columns=["dict_entry"])
df_cross
# Out:
#      dict_entry
# 0   plate-forme
# 1          -age
# 2          lead
# 3        cancer
# 4        أَسَاس
# ..          ...
# 70      vampire
# 71    reportage
# 72          pur
# 73        -ance
# 74       photo-
#
# [75 rows x 1 columns]

# %%
df_lang_1_lang_2_cross = pd.merge(df_cross,df_lang_1,how="inner", on="dict_entry")
df_lang_1_lang_2_cross
# Out:
#      dict_entry search_word dict_entry_main language_main  \
# 0   plate-forme    platform        platform       Turkish
# 1          -age       masaj           masaj       Turkish
# 2          lead       lider           lider       Turkish
# 3        cancer      kanser          kanser       Turkish
# 4        أَسَاس        esas            esas       Turkish
# ..          ...         ...             ...           ...
# 77      vampire      vampir          vampir       Turkish
# 78    reportage    röportaj        röportaj       Turkish
# 79          pur        puro            puro       Turkish
# 80        -ance    ambulans        ambulans       Turkish
# 81       photo-    fotoğraf        fotoğraf       Turkish
#
#                                       definition_main       language  \
# 0   (Noun) (transport, travel) platform. Platform....   French (fra)
# 1   (Noun) Massage (rubbing, kneading, or hitting ...   French (fra)
# 2   (Noun) Leader (of a party or organization).Lea...  English (eng)
# 3   (Noun) Cancer (disease of uncontrolled cellula...   French (fra)
# 4   (Noun) Basis. Essence. Fundamental. Main. Prin...   Arabic (ara)
# ..                                                ...            ...
# 77                            (Noun) Vampire.Vampire.   French (fra)
# 78        (Noun) Interview. Report.Interview. Report.   French (fra)
# 79                                (Noun) Cigar.Cigar.   French (fra)
# 80                        (Noun) Ambulance.Ambulance.   French (fra)
# 81                                (Noun) Photo.Photo.   French (fra)
#
#                                            definition
# 0                                           Platform.
# 1   (rare) Forming collective nouns.. Forming noun...
# 2   (acting) The actor who plays the main role; le...
# 3                                             Cancer.
# 4                                                 NaN
# ..                                                ...
# 77                                           Vampire.
# 78                                         Reportage.
# 79                 Pure (undiluted). Pure (unspoilt).
# 80                 -ance (suffix used to form nouns).
# 81  Photo- (relating to to light). Photo- (relatin...
#
# [82 rows x 7 columns]

# %%
df_lang_2_lang_1_cross = pd.merge(df_cross,df_lang_2,how="inner", on="dict_entry")
df_lang_2_lang_1_cross
# Out:
#       dict_entry search_word dict_entry_main language_main  \
# 0    plate-forme  plataforma      plataforma    Portuguese
# 1           -age      salvar          salvar    Portuguese
# 2           -age     massage        massagem    Portuguese
# 3           lead       líder           líder    Portuguese
# 4         cancer      cancro          cancro    Portuguese
# ..           ...         ...             ...           ...
# 101      vampire     vampiro         vampiro    Portuguese
# 102    reportage  reportagem      reportagem    Portuguese
# 103          pur        puro            puro    Portuguese
# 104        -ance  ambulância      ambulância    Portuguese
# 105       photo-  fotografia      fotografia    Portuguese
#
#                                        definition_main       language  \
# 0    (Noun) (computing) platform (environment for r...   French (fra)
# 1    (Verb) (by extension) to greet. (computing, Br...  English (eng)
# 2                              (Noun) Massage.Massage.   French (fra)
# 3                                (Noun) Leader.Leader.  English (eng)
# 4          (Noun) (Portugal) cancer.(Portugal) cancer.   French (fra)
# ..                                                 ...            ...
# 101  (Verb Noun) Vamp (woman who uses sexual desire...   French (fra)
# 102                        (Noun) Reportage.Reportage.   French (fra)
# 103  (Adjective) Pure (free of pollutants). Pure; c...   French (fra)
# 104                        (Noun) Ambulance.Ambulance.   French (fra)
# 105  (Noun) (figurative) carbon copy (something tha...   French (fra)
#
#                                             definition
# 0                                            Platform.
# 1    Forming nouns with the sense of collection or ...
# 2    (rare) Forming collective nouns.. Forming noun...
# 3    (acting) The actor who plays the main role; le...
# 4                                              Cancer.
# ..                                                 ...
# 101                                           Vampire.
# 102                                         Reportage.
# 103                 Pure (undiluted). Pure (unspoilt).
# 104                 -ance (suffix used to form nouns).
# 105  Photo- (relating to to light). Photo- (relatin...
#
# [106 rows x 7 columns]

# %%
lang_3_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_2.capitalize()}_And_*_Etymologeek_Result_All.xlsx")
lang_3_file

# %%
df_lang_3 = pd.DataFrame()
for i in lang_3_file:
    df_var3 = pd.read_excel(f"{i}")
    df_lang_3 = pd.concat([df_lang_3,df_var3], axis=0)
    df_lang_3.reset_index(drop=True, inplace=True)
df_lang_3

# %%
set_lang_1 = set(df_lang_1["dict_entry_main"])

# %%
set_lang_3 = set(df_lang_1["dict_entry_main"])

# %%
df_cross = pd.DataFrame(set_lang_1.intersection(set_lang_3), columns=["dict_entry_main"])
df_cross

# %%
#df_cross.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result_All.xlsx")

# %% [markdown]
# #### Test Data

# %%
df = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology.csv")
df
# Out:
#                         term_id                    lang       term  \
# 0        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 1        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 2        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 3        8_rYLlLyVOKJlGFPZIvpVA                 English  thesaurus
# 4        iwDzanYmWxaUKbOlUy2yyQ                   Latin  thesaurus
# ...                         ...                     ...        ...
# 3884332  ttDtihHdV4aL8aDWZpIgnQ                 English      Boell
# 3884333  ttDtihHdV4aL8aDWZpIgnQ                 English      Boell
# 3884334  s0ANGE2hXn6nen8AFLynOg  South Levantine Arabic     بالمية
# 3884335  s0ANGE2hXn6nen8AFLynOg  South Levantine Arabic     بالمية
# 3884336  VtU3fy8KXDSUJkNvfVFxgQ                 English     Cooler
#
#                     reltype         related_term_id            related_lang  \
# 0        group_derived_root                     NaN                     NaN
# 1             borrowed_from  fhl-sdgwXaWvYD8CgaKXpQ                   Latin
# 2              derived_from  7Rf1835bWYmlH9VnyYVbpg           Ancient Greek
# 3              doublet_with  sqiifJX3XIOQ0vZ0trzRaA                 English
# 4              derived_from  7Rf1835bWYmlH9VnyYVbpg           Ancient Greek
# ...                     ...                     ...                     ...
# 3884332       borrowed_from  AUIYyyL0V_2rTzbDwWeVig                  Danish
# 3884333       borrowed_from  _zZUp3xTUyyi8TrPVMfOUw                  German
# 3884334           has_affix  QLqQUWCoUu6hQGr40QVQyw  South Levantine Arabic
# 3884335           has_affix  sVDOI8DxUwq2DD03Y3HGdw  South Levantine Arabic
# 3884336        derived_from  0cIktMSLVpKfszbcNudv4w                  German
#
#         related_term  position               group_tag  \
# 0                NaN         0  0IIU6TlkSA2D7dg1PfxGOw
# 1          thēsaurus         0                     NaN
# 2           θησαυρός         0                     NaN
# 3           treasure         0                     NaN
# 4           θησαυρός         0                     NaN
# ...              ...       ...                     ...
# 3884332         Bøll         0                     NaN
# 3884333         Böll         0                     NaN
# 3884334           بـ         0                     NaN
# 3884335       الميّة         1                     NaN
# 3884336       Kühler         0                     NaN
#
#                      parent_tag  parent_position
# 0                           NaN              NaN
# 1        0IIU6TlkSA2D7dg1PfxGOw              0.0
# 2        0IIU6TlkSA2D7dg1PfxGOw              1.0
# 3                           NaN              NaN
# 4                           NaN              NaN
# ...                         ...              ...
# 3884332  VfBh8FOWR_muVFpFl7EOvw              0.0
# 3884333  VfBh8FOWR_muVFpFl7EOvw              1.0
# 3884334                     NaN              NaN
# 3884335                     NaN              NaN
# 3884336                     NaN              NaN
#
# [3884337 rows x 11 columns]

# %%
df[(df.lang == "English") & (df.related_lang == "Portuguese")]
# Out:
#                         term_id     lang      term        reltype  \
# 161      Hwq0PRMgW6qyHkoNUIaqBA  English       cat     cognate_of
# 1985     -tan3ztNVRylENiBlHiRZw  English     abada  borrowed_from
# 2163     n_jCbAaHUjyF8lELsCvmmg  English    abacus     cognate_of
# 5447     Kft_7-1xXESIPHkBug3Oig  English    acajou   derived_from
# 7507     cxE9xVdwXHWBYOlTUck_vw  English      star     cognate_of
# ...                         ...      ...       ...            ...
# 3794806  sulo5hJ3W_SOHh7EzLojWQ  English   Cantara  borrowed_from
# 3795571  Dnwh8BbDUxmMIfMqVI3l0Q  English    Galvao  borrowed_from
# 3801681  zntGXzwzW6GMoo4atw0lDg  English  tallapoi   derived_from
# 3844658  niSy3gLOU4mVT-6qcEHiXQ  English  Quiterio  borrowed_from
# 3863593  jUi7aX-oVFCSKSBEjUoQkQ  English      Ramo  borrowed_from
#
#                 related_term_id related_lang related_term  position group_tag  \
# 161      0fQgUY6TVp60Re0rmTnZeQ   Portuguese         gato         0       NaN
# 1985     ATpkd7vPU4CjQWgtlEiR9Q   Portuguese        abada         0       NaN
# 2163     _jRZOdp7XvmMHAF-o58F9w   Portuguese        ábaco         0       NaN
# 5447     xrAgo5FxWRWpNsd5bKbBEw   Portuguese        acaju         0       NaN
# 7507     wmd-z6JAWmKOfP9-w3Rohg   Portuguese      estrela         0       NaN
# ...                         ...          ...          ...       ...       ...
# 3794806  s1Wpa2q7XhqKqYZm0mhibg   Portuguese      Cantara         0       NaN
# 3795571  4FAQ2RDbUX6Br1aY5lhVqA   Portuguese       Galvão         0       NaN
# 3801681  l8J2F2SMXjG7m3A8AvLxaQ   Portuguese      talapão         0       NaN
# 3844658  kMJU-O-TWtCJN8QOvxy2yA   Portuguese     Quitério         0       NaN
# 3863593  J3CsDNddW4O_FVLvKM6ttQ   Portuguese         Ramo         0       NaN
#
#                      parent_tag  parent_position
# 161      pGN0Jpw6RHaUmJ1jOrKfcg              9.0
# 1985     HgcLzS4ySu6J244wzTpXBA              0.0
# 2163     zbq_2ocnS02j5vSVPPk5aQ              1.0
# 5447     x7lIrlWzRG6Bd-ToaYGvug              1.0
# 7507     YgFLXIbVTMS8d1TggXy7OQ             15.0
# ...                         ...              ...
# 3794806                     NaN              NaN
# 3795571                     NaN              NaN
# 3801681  DyDfZI5kTlaNo-acbHD-bw              1.0
# 3844658                     NaN              NaN
# 3863593                     NaN              NaN
#
# [876 rows x 11 columns]

# %%
df[(df.lang == "Turkish") & (df.related_lang == "English")]
# Out:
#                         term_id     lang         term  \
# 3177     jBwnCmLZUeGQq698u7tnPA  Turkish        abide
# 9379     WrmjvMe_XsKG56ZkabPmBg  Turkish          bit
# 9380     WrmjvMe_XsKG56ZkabPmBg  Turkish          bit
# 10456    KMoSa6bHVcCO4eR3UjcCWA  Turkish         port
# 11831    W6VP6tayWCa13YOtBD9LuQ  Turkish          DVD
# ...                         ...      ...          ...
# 3841743  o4jAj92HUXiJ9sFQ4ZhY9A  Turkish        sayko
# 3841753  myarAy9HUVWjsYk4ld6-ZA  Turkish  laparoskopi
# 3844652  nDNkTSX2VmanV0vlk8vNxQ  Turkish       intörn
# 3862215  IfdNuxMaXPGPw0ZcF1g0rg  Turkish        Filiz
# 3869990  KnTkWmF1XOKYEyzQHTg8lw  Turkish      metelik
#
#                            reltype         related_term_id related_lang  \
# 3177     etymologically_related_to  8AMN4YdeW-KrfSCEgc--AQ      English
# 9379                 borrowed_from  XkDGCZgmXaKwpJN1WcAwKw      English
# 9380     etymologically_related_to  uS1RzS05UjSzbgfhibNSiw      English
# 10456                borrowed_from  1IBIa_veWwOXT25zkB55Ag      English
# 11831                 derived_from  uR9C346xUA2Qx4guNxlK4g      English
# ...                            ...                     ...          ...
# 3841743               derived_from  -NNare9ZVSSGzr6-hQDVeA      English
# 3841753               derived_from  Bh0Jy6xlV5uIoaC5VMI3Iw      English
# 3844652              borrowed_from  a06hLBO2UwasJ_EvCCNJdw      English
# 3862215                 cognate_of  VTz93kTpVJ2o3BeRO26ctg      English
# 3869990                 cognate_of  _Pa5VFsoVh6KEMEiUGRBCw      English
#
#          related_term  position group_tag parent_tag  parent_position
# 3177         monument         0       NaN        NaN              NaN
# 9379              bit         0       NaN        NaN              NaN
# 9380     binary digit         0       NaN        NaN              NaN
# 10456            port         0       NaN        NaN              NaN
# 11831             DVD         0       NaN        NaN              NaN
# ...               ...       ...       ...        ...              ...
# 3841743        psycho         0       NaN        NaN              NaN
# 3841753   laparoscopy         0       NaN        NaN              NaN
# 3844652        intern         0       NaN        NaN              NaN
# 3862215       Phyllis         0       NaN        NaN              NaN
# 3869990      metallic         0       NaN        NaN              NaN
#
# [235 rows x 11 columns]

# %%
df_select = df.loc[:,["lang","term","reltype","related_lang","related_term"]]
df_select
# Out:
#                            lang       term             reltype  \
# 0                       English  thesaurus  group_derived_root
# 1                       English  thesaurus       borrowed_from
# 2                       English  thesaurus        derived_from
# 3                       English  thesaurus        doublet_with
# 4                         Latin  thesaurus        derived_from
# ...                         ...        ...                 ...
# 3884332                 English      Boell       borrowed_from
# 3884333                 English      Boell       borrowed_from
# 3884334  South Levantine Arabic     بالمية           has_affix
# 3884335  South Levantine Arabic     بالمية           has_affix
# 3884336                 English     Cooler        derived_from
#
#                    related_lang related_term
# 0                           NaN          NaN
# 1                         Latin    thēsaurus
# 2                 Ancient Greek     θησαυρός
# 3                       English     treasure
# 4                 Ancient Greek     θησαυρός
# ...                         ...          ...
# 3884332                  Danish         Bøll
# 3884333                  German         Böll
# 3884334  South Levantine Arabic           بـ
# 3884335  South Levantine Arabic       الميّة
# 3884336                  German       Kühler
#
# [3884337 rows x 5 columns]

# %%
df_select.isnull().sum()
# Out:
# lang                 0
# term                53
# reltype              0
# related_lang    381344
# related_term    381412
# dtype: int64

# %%
df_select.drop_duplicates(inplace=True)
df_select.dropna(inplace=True)
df_select.reset_index(drop=True, inplace=True)
df_select
# Out:
#                            lang         term        reltype  \
# 0                       English    thesaurus  borrowed_from
# 1                       English    thesaurus   derived_from
# 2                       English    thesaurus   doublet_with
# 3                         Latin    thesaurus   derived_from
# 4                       English  portmanteau       has_root
# ...                         ...          ...            ...
# 3484911                 English        Boell  borrowed_from
# 3484912                 English        Boell  borrowed_from
# 3484913  South Levantine Arabic       بالمية      has_affix
# 3484914  South Levantine Arabic       بالمية      has_affix
# 3484915                 English       Cooler   derived_from
#
#                    related_lang  related_term
# 0                         Latin     thēsaurus
# 1                 Ancient Greek      θησαυρός
# 2                       English      treasure
# 3                 Ancient Greek      θησαυρός
# 4           Proto-Indo-European  *per- (fare)
# ...                         ...           ...
# 3484911                  Danish          Bøll
# 3484912                  German          Böll
# 3484913  South Levantine Arabic            بـ
# 3484914  South Levantine Arabic        الميّة
# 3484915                  German        Kühler
#
# [3484916 rows x 5 columns]

# %%
#df_select.to_csv("etymology_clean.csv", index=False)

# %%
df_clean = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_clean.csv")
df_clean
# Out:
#                            lang         term        reltype  \
# 0                       English    thesaurus  borrowed_from
# 1                       English    thesaurus   derived_from
# 2                       English    thesaurus   doublet_with
# 3                         Latin    thesaurus   derived_from
# 4                       English  portmanteau       has_root
# ...                         ...          ...            ...
# 3484911                 English        Boell  borrowed_from
# 3484912                 English        Boell  borrowed_from
# 3484913  South Levantine Arabic       بالمية      has_affix
# 3484914  South Levantine Arabic       بالمية      has_affix
# 3484915                 English       Cooler   derived_from
#
#                    related_lang  related_term
# 0                         Latin     thēsaurus
# 1                 Ancient Greek      θησαυρός
# 2                       English      treasure
# 3                 Ancient Greek      θησαυρός
# 4           Proto-Indo-European  *per- (fare)
# ...                         ...           ...
# 3484911                  Danish          Bøll
# 3484912                  German          Böll
# 3484913  South Levantine Arabic            بـ
# 3484914  South Levantine Arabic        الميّة
# 3484915                  German        Kühler
#
# [3484916 rows x 5 columns]

# %%
df_clean.iloc[0,:]
# Out:
# lang                  English
# term                thesaurus
# reltype         borrowed_from
# related_lang            Latin
# related_term        thēsaurus
# Name: 0, dtype: object

# %%
result_list = []
for i in range(len(df_clean)):
    var_list = []
    lang_1 = df_clean.loc[i,"lang"]
    term_1 = df_clean.loc[i,"term"]
    lang_2 = df_clean.loc[i,"related_lang"]
    term_2 = df_clean.loc[i,"related_term"]
    var_list.append(lang_1)
    var_list.append(term_1)
    var_list.append(lang_2)
    var_list.append(term_2)
    try:
        df_var = df_clean[(df_clean["term"] == term_2) & (df_clean["language"] == lang_2)]
        j = 0
        while j < range(len(df_var)):
            df_var2 = df_var.iloc[j:,]
            while True:
                df_var = df_clean[(df_clean["term"] == term_2) & (df_clean["language"] == lang_2)]
                lang_1 = df_var.loc[i,"lang"]
                term_1 = df_var.loc[i,"term"]
                lang_2 = df_var.loc[i,"related_lang"]
                term_2 = df_var.loc[i,"related_term"]
                var_list.append(lang_1)
                var_list.append(term_1)
                var_list.append(lang_2)
                var_list.append(term_2)
            
        j+=1


    except:
        pass
    result_list.append(var_list)

# %%
df_clean[df_clean.term == "elektrik"]
# Out:
#                lang      term                    reltype     related_lang  \
# 659619  Azerbaijani  elektrik               derived_from           French
# 659620   Indonesian  elektrik              borrowed_from            Dutch
# 659621   Indonesian  elektrik  etymologically_related_to            Dutch
# 659622   Indonesian  elektrik               derived_from           French
# 659623   Indonesian  elektrik               derived_from            Latin
# 659624   Indonesian  elektrik               derived_from    Ancient Greek
# 659625   Indonesian  elektrik               doublet_with       Indonesian
# 659626       Ladino  elektrik              borrowed_from          Turkish
# 659627       Ladino  elektrik               derived_from           French
# 659628      Turkish  elektrik             inherited_from  Ottoman Turkish
# 659629      Turkish  elektrik               derived_from           French
#
#        related_term
# 659619   électrique
# 659620    electriek
# 659621    elektriek
# 659622   électrique
# 659623   ēlectricus
# 659624     ἤλεκτρον
# 659625      listrik
# 659626     elektrik
# 659627   électrique
# 659628      الكتریق
# 659629   électrique

# %%
df_clean[df_clean.term == "électrique"]
# Out:
#           lang        term       reltype   related_lang related_term
# 774487  French  électrique  derived_from          Latin   ēlectricus
# 774488  French  électrique  derived_from  Ancient Greek     ἤλεκτρον
# 774489  Norman  électrique  derived_from          Latin   ēlectricus
# 774490  Norman  électrique  derived_from  Ancient Greek     ἤλεκτρον

# %%
df_clean[df_clean.term == "ēlectricus"]
# Out:
# Empty DataFrame
# Columns: [lang, term, reltype, related_lang, related_term]
# Index: []

# %%
df_clean[df_clean.term == "ἤλεκτρον"]
# Out:
#                  lang      term                    reltype   related_lang  \
# 953562  Ancient Greek  ἤλεκτρον                 cognate_of  Ancient Greek
# 953563  Ancient Greek  ἤλεκτρον  etymologically_related_to       Sanskrit
# 953564  Ancient Greek  ἤλεκτρον  etymologically_related_to  Ancient Greek
# 953565  Ancient Greek  ἤλεκτρον  etymologically_related_to          Latin
#
#        related_term
# 953562      ἠλέκτωρ
# 953563        उल्का
# 953564        ἥλιος
# 953565     Vulcānus

# %%
df_clean[(df_clean["term"] == "électrique") & (df_clean["lang"] == "French")]
# Out:
#           lang        term       reltype   related_lang related_term
# 774487  French  électrique  derived_from          Latin   ēlectricus
# 774488  French  électrique  derived_from  Ancient Greek     ἤλεκτρον

# %%
set_term = set(df_clean.term.unique())
set_term
# Out:
# {'medicină',
#  'hypotrophic',
#  'Мікіта',
#  'zajezdnia',
#  'lymphosuppression',
#  'niukalti',
#  'quietlike',
#  'dinsdagsochtends',
#  'логикалық',
#  'Máret',
#  'sejtközpont',
#  'nzĩa',
#  'nondiscriminating',
#  'innovational',
#  'scãntiau',
#  'अंदेशा',
#  'ꂪ',
#  'einarbeiten',
#  'Rikako',
#  'жив',
#  'karácsonyt',
#  'esmwythâd',
#  'duodecemvir',
#  'înmatriculare',
#  'pristupačnost',
#  'Belgij',
#  '両唇音',
#  'pereu',
#  'botă',
#  'apelmazamiento',
#  'jätepolttoaine',
#  'tealight',
#  'kunststroming',
#  'bombarderen',
#  'Brâncoveni',
#  'kultúrája',
#  'bútort',
#  'хорой',
#  'pysytellä',
#  'rhino-',
#  'ensearch',
#  'hirap',
#  'sannan',
#  'óclachas',
#  'Medma',
#  'rana',
#  'έχθρα',
#  'пыльник',
#  'desegregație',
#  'förnimma',
#  'attentarsi',
#  'sug-an',
#  'porcello',
#  'alamet',
#  'gaminement',
#  'gľeț',
#  'rosinback',
#  'přepěkný',
#  'meagrely',
#  'angan',
#  'κατάμαυρος',
#  'Аллаһ',
#  'ringkasan',
#  'तारउ',
#  'godronat',
#  'Molekulardynamik',
#  'थकावट',
#  'ಗವಿ',
#  'muddleheadedly',
#  'neulakinnastekniikka',
#  'collinaire',
#  'kviðlingr',
#  '所多瑪',
#  'मोडणे',
#  'appaiamento',
#  'eurythermia',
#  'peligrosu',
#  'inforcement',
#  'Tinong',
#  'maidóon',
#  'izložiti',
#  'hiustenlähtö',
#  'オーリボル',
#  'stylistka',
#  'ének',
#  'வல்லவன்',
#  'respectably',
#  'spárgák',
#  'अचंभा',
#  'pajamas',
#  'နို့လိမ်',
#  'luusarkooma',
#  'corrogatus',
#  'དཔེ་མཛོད',
#  'pensif',
#  'mirmeco-',
#  'สารสนเทศ',
#  'konkaveskar',
#  'peaceably',
#  'виріб',
#  'Namenstag',
#  'бојник',
#  'retrospicio',
#  'capoguardia',
#  'toelo',
#  'oligolécithe',
#  'padalec',
#  'Adderalled',
#  'klimaatwetenschap',
#  'pakikiapid',
#  'Bittersüß',
#  'podar',
#  'unmiserable',
#  'primavera',
#  'เวรัมภวาต',
#  'օդապարուկ',
#  'นิบาต',
#  'supracondyloid',
#  'құдай',
#  'anticâncer',
#  'ข่าว',
#  'structureless',
#  'Paragraphenreiter',
#  'любіць',
#  '𐌌𐌀𐌍(𐌏)𐌌𐌏',
#  'Breatainn',
#  'underexpress',
#  'מימון',
#  'Wieler',
#  'juntata',
#  'litu',
#  'evadir',
#  'coralligerous',
#  'ერქემი',
#  'autotrofo',
#  'loepzuiver',
#  'recíprocament',
#  'électromètre',
#  'ลิด',
#  'businesscrat',
#  'Angla-Indiach',
#  'consângean',
#  'bhikkhu',
#  'alluvionnaire',
#  'пәрваз',
#  'gălbejeală',
#  'beċċun',
#  'nonvesicular',
#  'singulier',
#  'curri',
#  'ৰান্ধা',
#  'probole',
#  'uakax',
#  'caseload',
#  'hyperreal',
#  'տձեւ',
#  'schnabbel',
#  'erótico',
#  'гөл',
#  'nonvaricose',
#  'quasetta',
#  'moniato',
#  'midperformance',
#  'ալուցք',
#  'Koper',
#  'cúter',
#  'plás',
#  'sammenlikne',
#  'toughener',
#  'bregh',
#  'stairwork',
#  'éponger',
#  'периодичный',
#  'fűtési',
#  'petu',
#  'tigrisnek',
#  'סקא',
#  'linecaster',
#  'waterval',
#  'painike',
#  'アグレッシブ',
#  'rehukasvi',
#  'davamlı',
#  'megavejiga',
#  'ligeramente',
#  'homecare',
#  'annunciare',
#  'దక్షిణ ఆఫ్రికా',
#  'obstetrical',
#  'djævelsk',
#  'താരം',
#  'D型肝炎',
#  'indisciplinable',
#  'articulément',
#  'avanzadilla',
#  'ပညာကျော်',
#  'aegocephalos',
#  'стезя',
#  'koskettimisto',
#  'yksityisomaisuus',
#  'placatus',
#  'üç',
#  'gasheer',
#  'latinità',
#  'ဆက်သွယ်ရေး',
#  'egelworm',
#  'Pietromonaco',
#  'Seljuk',
#  'schyft',
#  '西洋薄荷',
#  'Peña',
#  'airside',
#  'krantenknipsel',
#  'coenzim',
#  'gastropexy',
#  'ឯក',
#  'uilliner',
#  'mikrigar',
#  'τρέμω',
#  'rabinic',
#  'immunohistocompatibility',
#  'armboug',
#  'antimyotonic',
#  'ไซโคลน',
#  'Minaean',
#  'Abrüstung',
#  'insostituibilità',
#  'étonnamment',
#  'libhse',
#  'exorpturus',
#  'oxaphosphole',
#  'šupčina',
#  'slavenziel',
#  'Damnedeu',
#  'marginalism',
#  'oxigenació',
#  'încurcat',
#  'botifarra',
#  'erbrechen',
#  'micropilo',
#  'kúdeľ',
#  'бәден',
#  'spīdekle',
#  'dearrsaich',
#  'subestimate',
#  'angerest',
#  'osteoinduced',
#  'concusso',
#  'taxpaid',
#  'นุ่งลมห่มฟ้า',
#  'oferseon',
#  'Norseland',
#  'महसूस',
#  'December',
#  'vetrofusione',
#  'чиновница',
#  'Hyrcanian',
#  'faciality',
#  'localment',
#  'hatáskör',
#  '完全数',
#  'cerealin',
#  'overcondensation',
#  'thumbprinting',
#  'heteromorph',
#  'будалица',
#  'mucãneashti',
#  'aurinkoaika',
#  'dius',
#  'unreshaped',
#  'lampar',
#  'ຟານ',
#  'kniebroek',
#  'Simonie',
#  'figarbo',
#  'oxandrolone',
#  'bőrig',
#  'αρκετός',
#  'Kapitänskajüte',
#  'Gekkota',
#  'häpyluu',
#  'ağlatmak',
#  'Henares',
#  'arbeidsloos',
#  'Băicuș',
#  'neuharrooghid',
#  'sinipääsky',
#  'adventsstjärna',
#  'constatació',
#  'Jakobsonian',
#  'doorsturen',
#  'unleaf',
#  'շարահյուսել',
#  'biozonation',
#  'небяспечны',
#  'sorsért',
#  'Zuidervis',
#  'seleenivety',
#  'reventonazo',
#  'obliquangolo',
#  'lastulevyteollisuus',
#  'tras',
#  'musiikkielämä',
#  'chalupa',
#  'múgur',
#  'জ্বালা',
#  'donorland',
#  'chayote',
#  'cloudberry',
#  'sárgadinnye',
#  'тонафнема',
#  'cnidoblastique',
#  'جخش',
#  'ophoesten',
#  '真田紐',
#  'deracine',
#  'indoorness',
#  'ciertu',
#  'mentetek',
#  'clarified butter',
#  'büntetőbb',
#  'Pardoși',
#  'breakage',
#  'Avasiloaiei',
#  'Băbțan',
#  'ܬܘܢܝܐ',
#  'éifeachtach',
#  'physicalistic',
#  'stroef',
#  'benaid',
#  'nelimoottorinen',
#  'raddiena',
#  'lastenhuonekalu',
#  '라면 먹고 갈래',
#  'pumpattava Barbara',
#  'सीक्षते',
#  'Floridization',
#  'дангса',
#  'piézophile',
#  'abstrakcija',
#  'hiveltäminen',
#  'malaxo',
#  'britar',
#  'Matloch',
#  'victrola',
#  'svetel',
#  'steinbítur',
#  'leitura',
#  'monodigitoxoside',
#  'Kokon',
#  'liberatio',
#  'balipholite',
#  'metallization',
#  'suoneria',
#  'underinsured',
#  'vuo',
#  'hapailan',
#  'åndssvag',
#  'וואָס',
#  'tregtar',
#  'escarallado',
#  'therapese',
#  'STT',
#  'tulokertymä',
#  'reestruturar',
#  'nawijka',
#  'oligohidrosis',
#  'कैवत',
#  'sivulaiton',
#  'sœtleikr',
#  'vicecampeón',
#  'ardor',
#  'semifriend',
#  'Parcae',
#  'taxe',
#  'tisztel',
#  'градиент',
#  'उपासक',
#  'mediakulttuuri',
#  'unsuddenly',
#  'ocultație',
#  'burbur',
#  'žľaza',
#  'kabɔ',
#  'circuitousness',
#  'uliu',
#  'ысқат',
#  'proprietarily',
#  'কেওয়াড়',
#  'portacicche',
#  'tessitura',
#  'Ilergetes',
#  'epistemologist',
#  'kyllästäminen',
#  'zsírszövet',
#  'kezekben',
#  'eggburger',
#  'adiutant',
#  'korrigeren',
#  'midlifer',
#  'Saharaans',
#  'zoczyć',
#  'orak',
#  'doria',
#  'kirakatok',
#  'grootvorst',
#  'Cioroparu',
#  'trivsel',
#  'henkilökuva',
#  'extrudir',
#  'tijdvak',
#  'materi',
#  'el·lipsi',
#  'sithingly',
#  'euskara',
#  'vall',
#  'hibbant',
#  'asymptomaticity',
#  'Kowalik',
#  'เกาหลีเหนือ',
#  'desbrossar',
#  'terseuter',
#  'neapvienošana',
#  'راکٹ',
#  'Cătina',
#  'hissə',
#  'anthemau',
#  'Steadicam',
#  'pistetuomari',
#  'Kunstgeschichte',
#  'rigidize',
#  'Monolog',
#  'képzéshez',
#  'kevätilta',
#  'ideafón',
#  'imbootable',
#  'نفوذ',
#  'gasda',
#  'langteraloo',
#  'közepesen',
#  'գիտակցորեն',
#  'ruskottaminen',
#  'encís',
#  'beguda',
#  'kontoutdrag',
#  'prawda',
#  'nasalness',
#  'батыу',
#  'catequese',
#  'mollemente',
#  'ក្រវាត់ក',
#  'esta',
#  'Izard',
#  'plav',
#  'scusatore',
#  'gravabile',
#  'unhomeliness',
#  'χοριοειδής',
#  'mixtion',
#  'Paf',
#  'sconcs',
#  'hiihtokilpailu',
#  'гопкомпания',
#  'unmemorizable',
#  'ungeneralled',
#  'taipuilla',
#  'Waffel',
#  'Meibion Glyndwr',
#  'proosallisuus',
#  'pariṇāyaka',
#  'เอาผิด',
#  'somiatruites',
#  'mitraljez',
#  'смертельный',
#  'ardo zuri',
#  'pneudraulic',
#  'työntäminen',
#  'meer',
#  'κτήνος',
#  'descabello',
#  'purrer',
#  'Tabelle',
#  'Gümrü',
#  'lóng ngóng',
#  'tuuhealatvainen',
#  'бясалгал',
#  'ethylene',
#  'strongur',
#  'avant-dance',
#  'курдский',
#  'transromantic',
#  'merda',
#  'giapponesità',
#  'subvocalizer',
#  'forbled',
#  'cox box',
#  'głośno',
#  'gerundively',
#  'gahppat',
#  'inferens',
#  'lái',
#  'çhellvanee',
#  'пламеник',
#  'nieprzewidziany',
#  'pancellular',
#  'তালিব',
#  'öljyvaate',
#  'reputability',
#  'nonpolycystic',
#  'houari',
#  'charłak',
#  'kuustoist',
#  'cho biết',
#  'ompelusormus',
#  'trituratus',
#  'kšyśe',
#  'valikkokomento',
#  'átalakít',
#  'maharadja',
#  'incurvabile',
#  'скворец',
#  'frittelloso',
#  'computerist',
#  'reinfest',
#  'grasgrün',
#  'nicciano',
#  'արսեն',
#  'csirkém',
#  'kwiek',
#  'pangermano',
#  'હૂંફાળું',
#  'doscientos',
#  'apomorphe',
#  'strawboard',
#  'calcogenuro',
#  'τθούμα',
#  'neuropercolation',
#  'Spinnenwebb',
#  'патолошки',
#  'głupawka',
#  'cíall',
#  'récommencé',
#  'ráf',
#  'puoltaa',
#  'econometría',
#  'Łatacz',
#  'psychomachy',
#  'даступны',
#  'badstue',
#  'Latynos',
#  'cascón',
#  'citérieur',
#  'warped wall',
#  'Stamora Română',
#  'sacrifer',
#  'craftaholic',
#  'пение',
#  'paparchy',
#  'willowwort',
#  'અગિયાર',
#  'kruce',
#  'internalização',
#  'pangatuli',
#  'levyjarru',
#  'archangele',
#  'sexdom',
#  'kvægbestand',
#  'वेंटिलेटर',
#  'winstanleyite',
#  'コーンウォール語',
#  'csuklóm',
#  'შიმშილი',
#  'galiba',
#  'likejacking',
#  'пахарь',
#  'dorsomedially',
#  'Oceana County',
#  'havørn',
#  'brank',
#  'ceauș',
#  'αντίστοιχος',
#  'лесополоса',
#  'בינע',
#  'sökord',
#  'टेन्शन',
#  'negližé',
#  'take a dump',
#  '的士夠格',
#  'Lunchable',
#  'సుధాంశువు',
#  'bắc',
#  'いろは',
#  'immortalitat',
#  'double nelson',
#  'eklisiologija',
#  'quarter-witted',
#  'Anurogrammi',
#  'Virūpa',
#  'huijaus',
#  'doktorsexamen',
#  'vlaen',
#  'ballkicker',
#  'basare',
#  'admettre',
#  'faceless',
#  'lasinen',
#  'sarvikala',
#  'выгодный',
#  'caliph',
#  'veia',
#  'halophobic',
#  'esperancki',
#  'alley',
#  'ชลบุรี',
#  'pine',
#  'musikliv',
#  'разгильдяй',
#  'blandiciar',
#  'Курбан бајрам',
#  'macrobiotica',
#  'femtan',
#  'Rotluchs',
#  'alligate',
#  'kalkinpoltto',
#  'luvallisuus',
#  'anabiosis',
#  'nieposłuszeństwo',
#  'snøbrett',
#  'gingivolabial',
#  'self-exam',
#  'axiomatiquement',
#  'कठिनपृष्ठक',
#  'เข็ญใจ',
#  'בויכרעדער',
#  'fo-ving',
#  'clématite',
#  'mrkbt',
#  'раствориться',
#  'birsalmafája',
#  'shonichi',
#  'छाया',
#  'Badewanne',
#  "'tweenbrain",
#  'intindi',
#  'äänihuulikyhmy',
#  'leftward',
#  'digitaalikello',
#  'चुसकी',
#  'beztalencie',
#  'свороб',
#  'risquassare',
#  'crescentoid',
#  'પ્રકાશશાસ્ત્ર',
#  'Partizipialkonstruktion',
#  'psychophysics',
#  'Ronald',
#  'procerite',
#  'nanoparticle',
#  'Watroba',
#  'inspecter',
#  'Kożuch',
#  'lành',
#  'looksmatch',
#  'Perun',
#  'agħma',
#  'sgomitare',
#  'aallaarsimaarfik',
#  'valokki',
#  'Lebensgefährte',
#  'karkaisu',
#  'taplash',
#  'oceanológico',
#  'geležinis',
#  'યદુકુળમણિ',
#  'nonsens',
#  'gestern',
#  'valitusoikeus',
#  'Tegula',
#  'шос',
#  'wokkiruoka',
#  'Cecchini',
#  'amindumi',
#  'Damiani',
#  'మొద్దుగా',
#  'reticulină',
#  '블라우스',
#  'svið',
#  'tshikolo',
#  'afsky',
#  'unsymbolized',
#  'վառել',
#  'lelyń',
#  '鱘魚',
#  'bioĥemio',
#  'лѣвъ',
#  'danění',
#  'bográcsok',
#  'bayamo',
#  'vražitoŕa',
#  'térők',
#  'пробиться',
#  'прибадати',
#  'osallistumisprosentti',
#  'unpestilential',
#  'Goffman',
#  'silire',
#  'tariffa',
#  'Auriței',
#  'mummificering',
#  'longshot',
#  'fluoroprofilassi',
#  'πρωτότυπος',
#  'seuraaminen',
#  'hadâmb',
#  'ока',
#  'trường tiểu học',
#  'kapò',
#  'scandalizzamento',
#  'frakkipaita',
#  'леденица',
#  'biologo',
#  'quidam',
#  'gefeilles',
#  'hormitiili',
#  'wypracowanie',
#  'kuntuwarpu',
#  'звијезда',
#  'littery',
#  'semipredictable',
#  'Ἀλέξανδρος',
#  'koszorú',
#  'afterheat',
#  'deslucir',
#  'incenter',
#  'supralicitație',
#  'lymphlike',
#  'meatlessness',
#  'hauddum',
#  'ચાંદરણી',
#  'barnevogn',
#  'allargament',
#  'ลพบุรี',
#  'I Zingari',
#  'merőleges',
#  'shutterbug',
#  'standardless',
#  'nant',
#  'गजवदन',
#  'jeżyna',
#  'rengasnokkalokki',
#  'praedicativus',
#  'мещанин',
#  'Inspektion',
#  'fita',
#  'ideoida',
#  'baby bust',
#  'easumhal',
#  '토스터',
#  'karyawan',
#  'kalimah',
#  'disedification',
#  'fogyism',
#  'potlogărie',
#  'säpsähdys',
#  'șnur',
#  'nagykerár',
#  'rozbójnik',
#  'λευρός',
#  'prescripție',
#  'gesticulation',
#  'Potanine',
#  'norditerpene',
#  'pessimal',
#  'sodoku',
#  'soggiogare',
#  'succensendus',
#  'antaithéachtach',
#  'skjalgr',
#  'evlavios',
#  'عربون',
#  'amplasare',
#  'loază',
#  'канонерка',
#  'shouter',
#  'szil',
#  'διαφορετικός',
#  'eterologo',
#  'clapotage',
#  'foreclose',
#  'Pteridaceae',
#  'disconformitat',
#  'हंबरणे',
#  'tyrotoxism',
#  'знак',
#  'stereotomy',
#  'obiettivismo',
#  'seruntur',
#  'triciribine',
#  'solmeilutyö',
#  'намаҙлыҡ',
#  'darnic',
#  'onychoschisis',
#  'zaadoptować',
#  'بروتستانتي',
#  'チワン語',
#  'handelsafgunst',
#  'pigmentifero',
#  'Butän',
#  'ζητιανεύω',
#  'kuunsilta',
#  'moedig',
#  'captiously',
#  'Elegea',
#  'broadsheet',
#  'taurolithocholic',
#  'Twoaie Nerin',
#  'nontemplatized',
#  'refractility',
#  'vrsnoća',
#  'intrameiotic',
#  'sustentacle',
#  'शिकस्त',
#  'прдеж',
#  'intertracheid',
#  'varmuuslanka',
#  'sociotopography',
#  'swon',
#  'trayntay uno',
#  'megaschermo',
#  'aramă',
#  'свалка',
#  'անտիկ',
#  'Jahrbuch',
#  'räikeä',
#  'olympiastadion',
#  'ղոզ',
#  'incommodaturus',
#  'agrisilvofishery',
#  'turkiso',
#  'tetrabromocuprate',
#  'Zusammenhang',
#  'iutificio',
#  'cherek',
#  'misinterpretation',
#  'akālum',
#  'galactagogue',
#  'обрва',
#  'mauvaiseté',
#  'acataleptic',
#  '촌놈',
#  'sokkapultti',
#  'plaias',
#  'gruewen',
#  'มันเลือดนก',
#  'ஹ்ரஸ்வம்',
#  'seujti',
#  'foliopaperi',
#  'agressivité',
#  'unvetted',
#  'momificar',
#  'hectocotylus',
#  'övéhez',
#  'teksański',
#  'immunosénescence',
#  'lasihelmi',
#  'curling',
#  'yksijumalainen',
#  'promenad',
#  'pênis',
#  'கண்ணீர்',
#  'sivuteema',
#  'German silver',
#  'controlo remoto',
#  'veranadero',
#  'Cormany',
#  'vixenishness',
#  '虺',
#  'כוליגאַן',
#  'hebben',
#  'kertoma',
#  'friezy',
#  'haytime',
#  'kiipijäkasvi',
#  'distansi',
#  'sicera',
#  'pulmopathy',
#  'remettre',
#  'Wachtel',
#  'spermatotoxic',
#  'leister',
#  'perorate',
#  'Brauer',
#  'ἀναλίσκω',
#  'retrodict',
#  'behandla',
#  'nowator',
#  'lämpötahna',
#  'кэндо',
#  '色丹',
#  'Lăzurean',
#  'εὐρύπρωκτος',
#  'parafa',
#  'adula',
#  'حدث',
#  'パフォーマンス',
#  'Ἡρόφιλος',
#  'ymbstandend',
#  'Slavonic',
#  'tystie',
#  'πύρινος',
#  'unsoftening',
#  '樂果',
#  'θαλασσουργός',
#  'postinjakaja',
#  'kemičarka',
#  'момо',
#  'capezzo',
#  'labiale',
#  'дачник',
#  'iritație',
#  'pentrado',
#  'zingen',
#  'maize',
#  'бесвијест',
#  'nira',
#  'So',
#  'yn-cheau',
#  'Reija',
#  'sexless',
#  'cotranslator',
#  'Dobermann',
#  'küç',
#  'verurteilen',
#  'facilísimamente',
#  'مواعين',
#  'ocotochtli',
#  'inaccesso',
#  'Zayets',
#  '총알',
#  'туй',
#  'saalık',
#  'bisqueware',
#  'asocia',
#  'ntãnj',
#  'всюдисущий',
#  'uv',
#  'computação',
#  'dantay',
#  'massedness',
#  'ecolóxico',
#  'sangai',
#  'केलॖ',
#  'taideaine',
#  'infhaighteacht',
#  'tarso',
#  'many-sided',
#  'ճաշկերույթ',
#  'ainda',
#  'drikka',
#  'servotekniikka',
#  'grunnlaus',
#  'nativ',
#  'խոնչա',
#  'talbotype',
#  'organotypically',
#  'rambleu',
#  'artiċokk',
#  'salivale',
#  'singulari',
#  'Asellius',
#  'morphoclimatique',
#  'քոռ',
#  'peoncito',
#  'tuíodóireacht',
#  'нерухомість',
#  'Giordani',
#  'antialcoolismo',
#  'Rodak',
#  'स्तरी',
#  'bağana',
#  'amphictyonic',
#  'hobelfask',
#  'вмерти',
#  'cerebrito',
#  'aanzaaien',
#  'च़ॗन',
#  'Domonkos',
#  'computergesteuert',
#  'internecine',
#  'septulate',
#  'xavecar',
#  'miernik',
#  'miniräknare',
#  'hetk',
#  'forțat',
#  'conacha',
#  'गह्रुङ्गो',
#  'conselh',
#  'subreplication',
#  'otmjen',
#  ...}

# %%
set_related_term = set(df_clean["related_term"].unique())
set_related_term
# Out:
# {'pīlāre',
#  'Tuluc',
#  'medicină',
#  'End',
#  'adhikamāsa',
#  'Máret',
#  'sejtközpont',
#  'nzĩa',
#  'cyclo-',
#  'flateour',
#  'ہلسا',
#  'Branchiosaurus',
#  '*conservius',
#  'måltid',
#  'ꂪ',
#  'жив',
#  'שְׁאֵר',
#  'ჯიქი',
#  'пи̏та',
#  'sċiphlāford',
#  'adeguare',
#  'వలందేజ',
#  'classicistico',
#  'μορφώ',
#  '15 minutes of fame',
#  'automa',
#  'discoid',
#  'deb',
#  'do·aitni',
#  '*permanto',
#  'titlu',
#  'bombarderen',
#  'kupphia',
#  'betrecken',
#  'hiȝe gate',
#  'хорой',
#  'stroit',
#  'ფარსადან',
#  'prȍklēt',
#  'நுழை',
#  'פומבי',
#  '\n*𑀙𑀮',
#  'Geho-eul',
#  'lachs',
#  'rhino-',
#  'hirap',
#  'óclachas',
#  'دُرَّاج',
#  'rȇp',
#  'rana',
#  'babarira',
#  'pláchnout',
#  'Rădmănești',
#  '-나마',
#  'förnimma',
#  '*rookko',
#  'pronated',
#  'ᩈᩴ᩵ᩣᨯᩯ᩠ᨦ',
#  'лепя́',
#  'porcello',
#  'दिव्चे',
#  'poyson',
#  'gľeț',
#  'katkõ',
#  'aenweven',
#  'angan',
#  'насели',
#  'unwarm',
#  'balin',
#  'κατάμαυρος',
#  'échevelé',
#  'misspell',
#  'журавель',
#  'ætse',
#  'तारउ',
#  'ismeret',
#  'փալախ',
#  'ಗವಿ',
#  'обернуть',
#  'strȳnd',
#  '𑀤𑀼𑀤𑁆𑀥𑀺𑀅',
#  "𐬙𐬌𐬲𐬌-'''𐬛𐬄𐬯𐬙𐬭𐬀'''",
#  '*forhtu',
#  'ܠܟܝ',
#  'Church of Jesus Christ of Latter-day Saints',
#  '*ɢaːnᴬ',
#  '*Kạl(ï)-',
#  'baroun',
#  'watershipe',
#  'דְּבַשׁ',
#  'वह',
#  'Armagnac',
#  'sken',
#  'midwīf',
#  'thyro-',
#  'मोडणे',
#  'くにみつ',
#  'окно́',
#  'Ashkenazi',
#  'вла́да',
#  'start up',
#  '*tíyǫ́ ',
#  'meseraicus',
#  'naparstek',
#  'viillä',
#  'dielettrico',
#  'adicity',
#  'vīgintivirātus',
#  'tāss',
#  'acetilato',
#  'ének',
#  'жаңашыл',
#  'வல்லவன்',
#  ' περισκελῆ',
#  'maassaolo',
#  'pajamas',
#  'hätäjarru',
#  'прясна',
#  'اُرَكِرْ',
#  'კურკურება',
#  '*dus-diu-',
#  'Ὀλυμπος',
#  'pensif',
#  'отстреля́ть',
#  'hæftnian',
#  'геогра́фия',
#  'cornī',
#  '*h₁eh₁tr̥',
#  'mirmeco-',
#  'tulipalo',
#  'creindre',
#  'semmire',
#  '*toxi',
#  '-izam',
#  'święcić',
#  'حَنَك',
#  'International Standard Book Number',
#  'bèsputan',
#  'tidende',
#  'бето́нный',
#  'ovoviviparous',
#  'তুল',
#  '*ïdugan',
#  'dovetail',
#  'Արաքս',
#  'covard',
#  'aventuriini',
#  'contortio',
#  'podar',
#  '*sǣta',
#  'méarchlár',
#  '𑒣𑒮𑒰𑒩',
#  'פֿוגל',
#  'primavera',
#  'følging',
#  'häijynilkinen',
#  'inulin',
#  'ὑπαινίσσομαι',
#  'taniszra',
#  'servage',
#  'avë',
#  '*trunca',
#  'ತೋಟ',
#  'құдай',
#  'ข่าว',
#  'رنگارنگ',
#  'structureless',
#  'δημο-',
#  'Porcaro',
#  'ertļõ',
#  'vès',
#  'laikus',
#  'βότανο',
#  'indsætte',
#  'zähflüssig',
#  'juntata',
#  'мачвелӈын',
#  'děkan',
#  'tetrarchia',
#  'litu',
#  'darsa',
#  'textualized',
#  'dēstīllātiō',
#  'bydleti',
#  'evadir',
#  'قېيىن',
#  'ერქემი',
#  'ѕвѣзда',
#  'swōgan',
#  'kompaktisoida',
#  'autotrofo',
#  'πρόνοιᾰ',
#  'részegebb',
#  'ʻalima',
#  'kur̃čias',
#  'unconformity',
#  'Europe',
#  'immer noch',
#  '*𐌼𐌹𐌻𐌳𐌴𐌹𐍃',
#  'ลิด',
#  'techier',
#  'électromètre',
#  'তাম',
#  'заводской',
#  'bhikkhu',
#  'ἧπαρ συκωτόν',
#  '駆け',
#  '*m/s-k(w)a-j',
#  'sectura',
#  'alluvionnaire',
#  '*ɸare',
#  'الْقُرْآن\u200e',
#  'singulier',
#  'раздије́лити',
#  'бе̏све̄ст',
#  'మానుషము',
#  'emmer-gaas',
#  'παντόφλα',
#  'дюкэ',
#  'כ־נ־ס',
#  'rectilīneus',
#  'invertieren',
#  'žádost',
#  'lates',
#  'nieuk',
#  'stéła',
#  'bij',
#  'беззаве́тный',
#  'տձեւ',
#  '*unhtwǭ',
#  'Jeju qi: va"',
#  'erótico',
#  'esme',
#  'collapsed',
#  'гөл',
#  'ᐱᓓᐤ',
#  'grimdark',
#  'kavl',
#  'moniato',
#  'ալուցք',
#  'Koper',
#  'تېرەك',
#  'plás',
#  'sammenlikne',
#  'bregh',
#  'Florença',
#  'Peter',
#  'araw',
#  '*bow-',
#  'coltre',
#  '*dʰr̥ǵʰtós',
#  'petu',
#  'фарст',
#  'Sina',
#  'Bengali',
#  'ܪܴܚܡܘܽܬܴܐ',
#  'ziikoobiiginan',
#  '*splintō',
#  'wapi',
#  'waterval',
#  'painike',
#  'suggillō',
#  'davamlı',
#  'sróin',
#  'աւգոստոս',
#  'ordløs',
#  '*pučke',
#  'bastante',
#  'laukeava',
#  'bambocciata',
#  'šiābum',
#  'unfussy',
#  'annunciare',
#  'gutturōsus',
#  '음탕(淫蕩)',
#  'συντονία',
#  'creool',
#  'akvarelli',
#  'déserter',
#  'nivar',
#  'obstetrical',
#  'bèzbōlan',
#  '*rekǭ',
#  'tašaũ',
#  'crimped',
#  'താരം',
#  'tànyer',
#  'pripon',
#  'indisciplinable',
#  'antevolō',
#  'numerum',
#  'plungier',
#  'chamisa',
#  'fȳsan',
#  'üç',
#  'encapsidation',
#  'Hargitay',
#  'soslayar',
#  'pitjantja',
#  'synclinorium',
#  'yedinci',
#  '  wīhen nahten',
#  'virino',
#  'Seljuk',
#  'schyft',
#  'bekaaien',
#  'bucceum',
#  'знахарь',
#  'cilë',
#  'قَلَّى',
#  'Peña',
#  'ysgawd',
#  'ꍶ',
#  'མཚུལ་པ',
#  'ឯក',
#  'τρέμω',
#  'megállít',
#  'flexura',
#  '옳은',
#  'lupsahtaa',
#  'Ки́їв',
#  'ujuma',
#  'ἐξηγῶ',
#  '*s-b-(r/j)aŋ',
#  '*ɗaɰᴬ',
#  '*andar half',
#  'Abrüstung',
#  'malak',
#  'לֵילְיָא',
#  'eclog',
#  '*sъ-mǫtiti',
#  'äiditön',
#  'gihrusti',
#  'дендрарий',
#  'anî',
#  'pinkje',
#  '국가(國家)',
#  'kenspeck',
#  'kapuk',
#  't̲s̲e',
#  'Comte',
#  '*dungō',
#  'incredible',
#  'غَلِيل',
#  'botifarra',
#  'erbrechen',
#  'Kara Koyun',
#  'aflaþa',
#  'saxão',
#  '*kʷóy',
#  'Ἐπέτιον',
#  'வெடி',
#  '*poslě',
#  'կոկորդ',
#  'truquer',
#  'tous les deux',
#  'sòppan',
#  'واش',
#  '*kiljudak',
#  'rhēdo',
#  'Norseland',
#  'chemosynthetic',
#  'أَشَعَّ',
#  'ме́стен',
#  'December',
#  'شنبذ',
#  'ùrota',
#  'dyonic',
#  '*werā',
#  'อธิบ',
#  'Monterey Jack',
#  'Marina',
#  'phytographie',
#  'criticistico',
#  'دەژین',
#  '*dɔŋ',
#  'archia',
#  'klitka',
#  'hatáskör',
#  'kasaysayan',
#  'monista',
#  'slurry',
#  '*ɟu̯əiH',
#  'ampanga',
#  'épreindre',
#  'церемо́нія',
#  'य',
#  'canino',
#  'tàurs',
#  '*tьnъ',
#  'aurinkoaika',
#  'w:HASAG',
#  'enby',
#  'büyü',
#  'lampar',
#  'សប្បរស្ស',
#  'βάπτισμα',
#  'reimen',
#  'Qing',
#  'ຟານ',
#  'expetō',
#  'hīeġ',
#  'Späder',
#  'hépatiser',
#  'saag',
#  'brachialis',
#  'aditivo',
#  'exauctōrō',
#  'umirtà',
#  'опанак',
#  'onderscheid',
#  'Henares',
#  'ᒥᓯ᐀ᓰᐱ',
#  'कीर्तन',
#  '*tārō',
#  '*ʰnwɯə',
#  'ningung',
#  'имать',
#  'Ị̀gbò',
#  'Bugis',
#  'kumppi',
#  'glîden',
#  'ચા',
#  '*-hertaz',
#  'tilín',
#  'liin',
#  'շարահյուսել',
#  'fōmentō',
#  'ordforråd',
#  '*abaleggen',
#  'allau',
#  'Assebroek',
#  'tras',
#  'chalupa',
#  'টলিবা',
#  'múgur',
#  '𑀇𑀥',
#  'وَڏو\u200e',
#  'chayote',
#  'sárgadinnye',
#  'тонафнема',
#  'au petit bonheur la chance',
#  '*kūski',
#  '*ergja',
#  'kelasköynnös',
#  'чи́гав',
#  'shidoolnaʼ',
#  '-cratico',
#  'büntetőbb',
#  'frustrating',
#  'कुच',
#  'breakage',
#  'ꙗсли',
#  'Jede Sau hat ihren Martinstag',
#  'éifeachtach',
#  'ចៅហ្វា',
#  'zatylny',
#  'benaid',
#  'distīllō',
#  'stroef',
#  'Ægen',
#  'wooden spoon',
#  'physicalistic',
#  'stīgære',
#  'Präludium',
#  'ultramairín',
#  'hadern',
#  'edimo',
#  'thrombolite',
#  'סִפְרוּת',
#  'mejar',
#  'nefrite',
#  'هافَ',
#  'ねぎ巻き',
#  'vāl',
#  'malaxo',
#  'ꠙꠣꠀꠠ',
#  'britar',
#  'ihlet#Noun',
#  'kuoriutua',
#  'wërken',
#  'svetel',
#  'steinbítur',
#  'leitura',
#  'liberatio',
#  'τείνειν',
#  'miluppoq',
#  'миші́й',
#  'caricatură',
#  'tate',
#  'mâlos',
#  'vuo',
#  'וואָס',
#  'tregtar',
#  'befer',
#  'ζιβανία',
#  '*tuksne',
#  'dooyteilagh',
#  'sẽklas',
#  'sûnde',
#  'कैवत',
#  'mucus',
#  'みどり',
#  'Casuarinaceae',
#  'sœtleikr',
#  'ardor',
#  'dīmidius',
#  'Parcae',
#  'taxe',
#  'tisztel',
#  'memper-',
#  'उपासक',
#  'kermisse',
#  'amẽaça',
#  'स्नायति',
#  'дәуір',
#  'հաւանաբար',
#  '*braȷ́ai',
#  'uliu',
#  '*skorīti',
#  'road trip',
#  'dails',
#  'fiaur',
#  'steatoma',
#  'tessitura',
#  'arena',
#  'corbillard',
#  'epistemologist',
#  'óon',
#  'zsírszövet',
#  '*strēlā-',
#  'infiltrare',
#  'Turkije',
#  'adiutant',
#  'orak',
#  'doria',
#  '𒄩𒅆𒄿𒊏',
#  'labeling',
#  'oxamic',
#  'confrontari',
#  'eenzaam',
#  '*soŋɜ',
#  'trivsel',
#  'кочева́ть',
#  'kriterie',
#  'makolągwa',
#  'ուռի',
#  'ponnistus',
#  'el·lipsi',
#  'tijdvak',
#  'Пермь',
#  'napinläpi',
#  'exome',
#  'hake#Etymology 2',
#  'kutip',
#  'Finan',
#  'vall',
#  'euskara',
#  'hibbant',
#  'tunnel vision',
#  'Kowalik',
#  'confābulor',
#  'practizare',
#  '*uzbugjaną',
#  'ἴσχω',
#  'desbrossar',
#  'dentary',
#  'tönäistä',
#  'perhauriō',
#  '𑘎𑘳𑘨𑘿\u200d𑘮𑘰𑘚',
#  'Priestland',
#  'kisälli',
#  'Stano',
#  'phob',
#  'peludo',
#  'brániti',
#  'سلماني',
#  'vȑh',
#  '𐌔𐤂𐌖𐌓𐌀𐌋',
#  'Kunstgeschichte',
#  'suavísimo',
#  'גזר',
#  'præsentere',
#  'åstad',
#  'γαμῶ',
#  'lapsenhoito',
#  'cētācea',
#  'triboulet',
#  'פֿאַר־',
#  'scarved',
#  'חִירָם',
#  'نفوذ',
#  'hlas',
#  'passel',
#  'κρέμαμαι',
#  '*दौरार्घ्य',
#  '*enxitonj',
#  'Schuss',
#  'мни́мое чи́сло',
#  'oktaavi',
#  'βάβαλον',
#  'noncoincident',
#  'prawda',
#  'attuale',
#  'Vandal',
#  'cânave',
#  'ἀπονεύρωσῐς',
#  'هَرْوَلَ',
#  'desossidare',
#  'esta',
#  'Izard',
#  'plav',
#  'Tilligte',
#  'fartragan',
#  'கெடு',
#  '*biratei',
#  'vulgær',
#  'mixtion',
#  'skioldpadda',
#  'изобража́ть',
#  'live album',
#  'बान',
#  'unmagnificent',
#  'Гру́зия',
#  'Κροσσαίη',
#  'Waffel',
#  'విశ్వసనీయము',
#  'senuwee',
#  '*kulay',
#  'giratario',
#  'сліпи́й',
#  'fumeyar',
#  'मरवा',
#  'เอาผิด',
#  '*ḍamaru',
#  'plānē',
#  'ܦܪܓܝܘܢ',
#  ' fesur',
#  'Monday',
#  'غ و ر',
#  'biigá',
#  'פַּרְדֵּיסָא',
#  'jenero',
#  '*klinutor',
#  'Melphes',
#  'meer',
#  'prensión',
#  'jackal',
#  '*wildēornes',
#  'κτήνος',
#  'dynastisch',
#  'descabello',
#  'PCR',
#  'Tabelle',
#  'sorice',
#  'propreantepenultimate',
#  'hiū',
#  'promazina',
#  'stealing',
#  'ਮੁਸਲਮਾਨੀ',
#  '𐌻𐌴𐌹𐌺𐌹𐌽𐌰𐍃𐍃𐌰𐌿𐍃',
#  'жыймакъ',
#  'Flondor',
#  'gefyn',
#  '*runka',
#  'ethylene',
#  'تَعَلُّقَة',
#  '*hūʀijuling',
#  'ணு',
#  'револю́ція',
#  'útland',
#  'yere of our lord',
#  'Prus',
#  'merda',
#  'spicery',
#  'смере́ка',
#  'forbled',
#  '*puẓu',
#  'binarity',
#  'اِنْطَبَعَ',
#  'vorecoop',
#  'քանդակ',
#  'frakkr',
#  '*mьsta',
#  'voortstuwen',
#  'plāntā-',
#  'Hadaró',
#  'schod',
#  'lái',
#  'akhana',
#  'толда́',
#  'باغلامق',
#  'मसीति',
#  'Franz Liszt',
#  'ଦଣ୍ଡ',
#  'þorni',
#  'taba',
#  'friper',
#  'ب د ر',
#  'versten',
#  '回教',
#  'kœla',
#  'શેકવું',
#  'suulas',
#  'монога́мный',
#  'átalakít',
#  'σηπτικός',
#  'circulāris',
#  'вы́слать',
#  'скворец',
#  'โทรศัพท์',
#  'nicciano',
#  'dispiacevole',
#  'prendo',
#  'kwiek',
#  'изба́',
#  'ատյան',
#  'கல்லோலம்',
#  '*vьśь',
#  'qorsuk',
#  'पतिव्रता',
#  'kepfer',
#  'masalan',
#  'ბუტკო',
#  'doscientos',
#  'prem',
#  'radiculaire',
#  'тряса́вина',
#  'kaveh',
#  'تكمل',
#  '一段活用',
#  'strawboard',
#  'jūdicō',
#  'panificō',
#  'Dobroaia',
#  'cíall',
#  'autarky',
#  'ráf',
#  'exército',
#  'γόνῐμος',
#  'acrecentar',
#  'puoltaa',
#  'econometría',
#  'উলটা',
#  'nattar',
#  'ekundu',
#  'Franca',
#  'νοηματικός',
#  'Latynos',
#  'сүлде',
#  'citérieur',
#  '*laɸsketi',
#  'mortared',
#  'ၼွင်း',
#  'અગિયાર',
#  'دَحَل',
#  'naar',
#  '*gornostajь',
#  'harchi',
#  'Moigrad',
#  'rectifiable',
#  'Veit',
#  'archangele',
#  '𑜃𑜢𑜤𑜃𑜫',
#  'стакан',
#  'éphétonine',
#  'ⲙⲁⲥⲧⲓⲅⲅⲟⲓⲛ',
#  'pastūra',
#  'สะบัก',
#  'chesible',
#  'galiba',
#  'прикрепи́ть',
#  'heway',
#  'dorsomedially',
#  'Arcadie',
#  '*euþą',
#  'مدينة',
#  'bykse',
#  'brank',
#  'ceauș',
#  '흑#sob',
#  'indifférence',
#  'brilliance',
#  'misseri',
#  '-ukas',
#  'Raar',
#  'íðugr',
#  'sagus',
#  '-vaptan',
#  'bắc',
#  '*skīriz',
#  'ídolo',
#  'Dano',
#  'indret',
#  '近藤',
#  'Raimund',
#  'dēfōrmitātis',
#  'huijaus',
#  'globaliseren',
#  'vlaen',
#  'lamen',
#  'admettre',
#  'нра́вственный',
#  'իսլամացնել',
#  'faceless',
#  'үсу',
#  'caliph',
#  'veia',
#  'драгоце́нный',
#  '*ord',
#  'Sauropsida',
#  'alley',
#  'preformed',
#  'ชลบุรี',
#  'μάτσα',
#  'pine',
#  'разгильдяй',
#  'tumulātus',
#  'ло́пать',
#  'dinamómetro',
#  'susamak',
#  'Fëllement',
#  'гу̏да',
#  'τοῖς',
#  'alligate',
#  '*düĺ',
#  'skänk',
#  'три́дцять два',
#  '*tahkokivi',
#  'snøbrett',
#  'uutdreege',
#  'Capitofsky',
#  'အုပ်စု',
#  'šalko',
#  'ꠌꠣꠇ꠆ꠇꠣ',
#  'волнова́ться',
#  'clématite',
#  'یوغورت',
#  'پِلین',
#  'Νικασία',
#  'Donze',
#  'pulvīnus',
#  'espérer',
#  "d'eslais",
#  'тыл',
#  'oldal',
#  '𑘟𑘳𑘏𑘜𑘹',
#  'эртен',
#  'orcaid',
#  'छाया',
#  'pindot',
#  'rissa',
#  'δάφνη Ἀλεξανδρεία',
#  'intindi',
#  'Mrs',
#  'leftward',
#  'segenen',
#  'bebé',
#  'glyserol',
#  'echeggiare',
#  'typösen',
#  'tarreta',
#  'streynen',
#  '*pincta',
#  'hơke',
#  'threc',
#  'साँभर',
#  'Ronald',
#  'ซาว',
#  'nanoparticle',
#  'setacciare',
#  '*jaɣ',
#  '乌龙',
#  'inspecter',
#  'lành',
#  'lähetin',
#  'échantillon',
#  'polline',
#  '*gʰren-',
#  'λάχνη',
#  'Perun',
#  'agħma',
#  'κουκουμάριον',
#  'قوغو',
#  'skin and bones',
#  'lungor',
#  'Lebensgefährte',
#  'валу́н',
#  'sneewich',
#  'cosmographique',
#  'vart',
#  'pasable',
#  'ر ج ع',
#  'karkaisu',
#  'proclisi',
#  'quatiō',
#  'nonsens',
#  'timuni',
#  'iczek',
#  'rowe',
#  '*gʰur-',
#  'လူမ်ႇ',
#  'phylo-',
#  'цно́та',
#  'gestern',
#  'chứa',
#  'גָּד',
#  'Tegula',
#  'Rogojină',
#  'Cecchini',
#  'Vargatag',
#  '*klowos',
#  'amindumi',
#  'пробужде́ние',
#  'szanować',
#  'hetkua',
#  'Damiani',
#  '呂不韋',
#  'caburé',
#  'Sülye',
#  'svið',
#  'afsky',
#  '*yapïtak',
#  'oversoft',
#  'becsületes',
#  '鱘魚',
#  'վառել',
#  'лѣвъ',
#  'yel',
#  'ἀψίνθιον',
#  'tovoq',
#  'polyorchid',
#  'bayamo',
#  'обеща́ть',
#  'dēpressiō',
#  'ڇوڙڻُ',
#  'Сенега́л',
#  'demagnetizable',
#  'æst',
#  'أُتْرُجّ',
#  'Goffman',
#  'mořský',
#  'Λῠκᾱ́ων',
#  'Populinum',
#  'tariffa',
#  '*taloi',
#  'propionate',
#  '*druwa',
#  'forthfaran',
#  'πρωτότυπος',
#  'parkinsonisme',
#  'कुवड़ो',
#  '*dyxъ',
#  'fırtına',
#  'āyātl',
#  'pithinnu',
#  'κρι-κρι',
#  'Νασαύα',
#  'biologo',
#  'quidam',
#  'hellenisoida',
#  'scandalōsus',
#  'coruscāre',
#  'د ر ك',
#  'hannescht-',
#  'Ἀλέξανδρος',
#  'koszorú',
#  'afterheat',
#  'paie',
#  'ᠰᠠᠯᠬᠢᠨ ᠴᠡᠴᠡᠭ',
#  '*pešiwa',
#  'borovice',
#  'Anlage',
#  'hystéroscopie',
#  'pottaska',
#  '*ʔa-saːmʔ',
#  'stanc',
#  'trade war',
#  'Citofacta',
#  'chiosan',
#  'ลพบุรี',
#  'Mâtnic',
#  'siliște',
#  'żarna',
#  'клочка',
#  'सज्य',
#  'shutterbug',
#  'fizyczny',
#  'standardless',
#  'nant',
#  'jeżyna',
#  'мещанин',
#  'eliminaatio',
#  'Էմին',
#  'fita',
#  'ideoida',
#  'kudenn',
#  'siʼą́',
#  'બે',
#  '*ḱérh₂sō',
#  ...}

# %%
set_term.intersection(set_related_term)
# Out:
# {'medicină',
#  'End',
#  'írna',
#  'Máret',
#  'sejtközpont',
#  'nzĩa',
#  'cyclo-',
#  'flateour',
#  'ναυπηγός',
#  'måltid',
#  'ꂪ',
#  'keyll',
#  'жив',
#  'euphuism',
#  'ревень',
#  'adeguare',
#  'thyroidectomy',
#  'kazatel',
#  'chanje',
#  'hornpiper',
#  'Dumești',
#  'gemoeten',
#  'automa',
#  'discoid',
#  'bezmocný',
#  'deb',
#  'basophilia',
#  'outsourcing',
#  'titlu',
#  'bombarderen',
#  'хорой',
#  'svire',
#  'ფარსადან',
#  'kütüphane',
#  'rhino-',
#  'eolaíoch',
#  'эфир',
#  'truffa',
#  'hirap',
#  'diagonalis',
#  'óclachas',
#  'amortizable',
#  'autrui',
#  'קללה',
#  'adsorption',
#  'rana',
#  'polus',
#  'Rădmănești',
#  'förnimma',
#  'Basar',
#  'concitation',
#  'लीढ',
#  'porcello',
#  'दिव्चे',
#  'gľeț',
#  'pelaku',
#  'angan',
#  'tlalacha',
#  'unwarm',
#  'balin',
#  'κατάμαυρος',
#  'vraždit',
#  'fokka',
#  'szélhámos',
#  'misspell',
#  'Λυκαονία',
#  'usted',
#  'журавель',
#  'prosopography',
#  'ætse',
#  'तारउ',
#  'Micromonospora',
#  'infekció',
#  'ismeret',
#  'cwningar',
#  'ಗವಿ',
#  'обернуть',
#  'قائل',
#  'Mahé',
#  'baroun',
#  'वह',
#  'Armagnac',
#  'sken',
#  'thyro-',
#  'मोडणे',
#  'mutator',
#  'रामदास',
#  'Zinsser',
#  'unfair',
#  'Ashkenazi',
#  'мухар',
#  'inzeppare',
#  'naparstek',
#  'diluvium',
#  'zouten',
#  'hezký',
#  'jätkama',
#  'osunąć',
#  'adicity',
#  'tāss',
#  'bondable',
#  'ének',
#  'annuel',
#  'naš',
#  'Reigen',
#  'வல்லவன்',
#  'liempo',
#  'pajamas',
#  'hätäjarru',
#  '御霊',
#  'valli',
#  'halsztuk',
#  'enserchen',
#  'befreien',
#  'mieszkalny',
#  'şair',
#  'pensif',
#  'pensar en la inmortalidad del cangrejo',
#  'flua',
#  'mirmeco-',
#  'sluch',
#  'spico',
#  'tulipalo',
#  'qoʻriqchi',
#  'semmire',
#  '-izam',
#  'święcić',
#  'better',
#  'gassificazione',
#  'becloak',
#  'ovoviviparous',
#  'dovetail',
#  'maolagán',
#  'hirondelle',
#  'Արաքս',
#  'szczuć',
#  'podar',
#  'méarchlár',
#  'primavera',
#  'ສາມສິບສີ່',
#  'häijynilkinen',
#  'Margrieta',
#  'inulin',
#  'servage',
#  'Hegelian',
#  'tagl',
#  'avë',
#  'ailide',
#  'ordonnance',
#  'ತೋಟ',
#  'toimivalta',
#  'құдай',
#  'slach',
#  'सुप्रभात',
#  'ข่าว',
#  'structureless',
#  '𐌻𐌹𐌲𐌰𐌽',
#  'Porcaro',
#  'ciliary',
#  'muliciuni',
#  'پاساپورت',
#  'laikus',
#  'zähflüssig',
#  'juntata',
#  'disanalogous',
#  'tetrarchia',
#  'litu',
#  'darsa',
#  'emu',
#  'malingre',
#  'evadir',
#  'ერქემი',
#  'ѕвѣзда',
#  'उष्णकाल',
#  'autotrofo',
#  'recoilless',
#  'részegebb',
#  'unconformity',
#  'Europe',
#  'naționaliza',
#  'denoto',
#  'ลิด',
#  'électromètre',
#  'তাম',
#  'заводской',
#  'bhikkhu',
#  'alluvionnaire',
#  'flowmeter',
#  'singulier',
#  'παντόφλα',
#  'வேண்டிய',
#  'teileagrafaíocht',
#  'troglio',
#  'дюкэ',
#  'כ־נ־ס',
#  'žádost',
#  'lates',
#  'nieuk',
#  'stéła',
#  'bij',
#  'nykä',
#  'տձեւ',
#  'erótico',
#  'сарлаг',
#  'ถึก',
#  'гөл',
#  'interpretación',
#  'tetlatzontequiliani',
#  'देणे',
#  'φαντασία',
#  'grimdark',
#  'vico',
#  'certainement',
#  'moniato',
#  'cempa',
#  'restore',
#  'ալուցք',
#  'πλαδαρός',
#  'Koper',
#  'solutus',
#  'plás',
#  'sammenlikne',
#  'bregh',
#  'Florença',
#  'plain',
#  'Peter',
#  'araw',
#  'coltre',
#  'aquaporin',
#  'petu',
#  'Sina',
#  'Bengali',
#  'ziikoobiiginan',
#  'tenor',
#  'Małecki',
#  'waterval',
#  'malutki',
#  'painike',
#  'phím',
#  'desfăca',
#  'davamlı',
#  'geoelectrical',
#  'tālā',
#  'wrestling',
#  'bastante',
#  'bolaigh',
#  'igualdade',
#  'unfussy',
#  'transigere',
#  'annunciare',
#  'mammaire',
#  'africhten',
#  'boête',
#  'creool',
#  'hospodář',
#  'déserter',
#  'nivar',
#  'obstetrical',
#  'indiscutível',
#  'wéi',
#  'wahrscheinlich',
#  'detective',
#  'താരം',
#  'pripon',
#  'indisciplinable',
#  'Warte',
#  'cachinnus',
#  'мо̄т',
#  'streccan',
#  'üç',
#  'encapsidation',
#  'Hargitay',
#  'Euskara',
#  'soslayar',
#  'āhuṇa',
#  'távlat',
#  'virino',
#  'Seljuk',
#  'schyft',
#  'Protestant',
#  'fejléc',
#  'Peña',
#  'sopraffare',
#  'obeli',
#  'ឯក',
#  'apogāleveleve',
#  'τρέμω',
#  'megállít',
#  'ujuma',
#  '𐰾𐰚𐰔',
#  'bemitleiden',
#  'kumma',
#  'kiinteistö',
#  'San Fran',
#  'dümìnica',
#  'Abrüstung',
#  'äiditön',
#  'recoger',
#  'ישפה',
#  'Heidelbeere',
#  'curățat',
#  'kapuk',
#  'incredible',
#  'botifarra',
#  'erbrechen',
#  'meronym',
#  'Bara',
#  'saxão',
#  'севрюга',
#  'haliurunna',
#  'կոկորդ',
#  'yearbook',
#  'tembadau',
#  'amnestie',
#  'واش',
#  'protuberate',
#  'καλοήθης',
#  'Norseland',
#  'intuitiv',
#  'chemosynthetic',
#  'December',
#  'dyonic',
#  'cyclodecane',
#  'Monterey Jack',
#  'kolero',
#  'պնդակազմ',
#  'Marina',
#  'wypytać',
#  'peterolie',
#  'klitka',
#  'hatáskör',
#  'slurry',
#  'hitelesít',
#  'mandarijn',
#  'épreindre',
#  'bento',
#  'canino',
#  'préciosité',
#  'refeca',
#  'taji',
#  'aurinkoaika',
#  'enby',
#  'lépcsősor',
#  'vulpen',
#  'büyü',
#  'lampar',
#  'βάπτισμα',
#  'neni-',
#  'reimen',
#  'equiangular',
#  'ຟານ',
#  'griller',
#  'Hindu',
#  'yndig',
#  'parcourir',
#  'velttoilla',
#  'Genügsamkeit',
#  'mosca',
#  'रन्धयति',
#  '𐌰𐍂𐌺𐌰',
#  'baru',
#  'odzwierciedlić',
#  'saag',
#  'brachialis',
#  'Narbe',
#  'опанак',
#  'ménte',
#  'onderscheid',
#  'Henares',
#  'sesquiplane',
#  'कीर्तन',
#  'ningung',
#  'имать',
#  'bullo',
#  'kumppi',
#  'ચા',
#  'finnig',
#  'liin',
#  'շարահյուսել',
#  'pederasta',
#  'ordforråd',
#  'sebességváltó',
#  'athort',
#  'allau',
#  'paris',
#  'tras',
#  'aiutorio',
#  'चाँटा',
#  'chalupa',
#  'múgur',
#  '𑀇𑀥',
#  'beard',
#  'chayote',
#  'lingz',
#  'հլու',
#  'sárgadinnye',
#  'pomppia',
#  'orthoédrique',
#  'тонафнема',
#  'wytępić',
#  'epuzer',
#  'cristalin',
#  'büntetőbb',
#  'frustrating',
#  'Chabad',
#  'breakage',
#  'oikeudeton',
#  'שוויצן',
#  'ꙗсли',
#  'éifeachtach',
#  'pḏt',
#  'benaid',
#  'stroef',
#  'physicalistic',
#  'Ægen',
#  'hadern',
#  'awesomeness',
#  'बोधिसत्त्व',
#  'ઊલટો',
#  'स्थूर',
#  'ellevte',
#  'оңшыл',
#  'gridil',
#  'Parizeau',
#  'malaxo',
#  'fyzický',
#  'britar',
#  'kuoriutua',
#  'svetel',
#  'steinbítur',
#  'leitura',
#  'Wohnzimmer',
#  'liberatio',
#  'شرى',
#  'caricatură',
#  'tate',
#  'mâlos',
#  'papahostias',
#  'vuo',
#  'virsikirja',
#  'וואָס',
#  'tregtar',
#  'gondos',
#  'Wien',
#  'anthère',
#  'étreint',
#  'colloque',
#  'lobatus',
#  'कैवत',
#  'mucus',
#  'sœtleikr',
#  'Casuarinaceae',
#  'ardor',
#  'Parcae',
#  'taxe',
#  'tisztel',
#  'ustad',
#  'उपासक',
#  'кібер-',
#  'கட்டை',
#  'frenètic',
#  'Տաճկաստան',
#  'چوال',
#  'Notlandung',
#  'Bergh',
#  'дәуір',
#  'hypochondres',
#  'Βρεττανός',
#  'uliu',
#  'jumuisha',
#  'brăduț',
#  'fiaur',
#  'tidally',
#  'sciigi',
#  'tessitura',
#  'arena',
#  'karjala',
#  'epistemologist',
#  'цех',
#  'zsírszövet',
#  'થૂંક',
#  'meso',
#  'infiltrare',
#  'adiutant',
#  'Calaveras',
#  'orak',
#  'doria',
#  'De Horck',
#  'aite',
#  'schidde',
#  'eenzaam',
#  'trivsel',
#  'makolągwa',
#  'ուռի',
#  'ponnistus',
#  'meluta',
#  'abwyd',
#  'el·lipsi',
#  'tijdvak',
#  'mipela',
#  'Cheud',
#  'napinläpi',
#  'exome',
#  'jaxl',
#  'ortsa',
#  'vall',
#  'euskara',
#  'hibbant',
#  'Kowalik',
#  'stábla',
#  'کیاہ',
#  'ἴσχω',
#  'desbrossar',
#  'Termini',
#  'kantaa',
#  'dentary',
#  'tönäistä',
#  'kisälli',
#  'velmi',
#  'potentialis',
#  'Stano',
#  'walet',
#  'comprehender',
#  'peludo',
#  'asiaton',
#  'Kunstgeschichte',
#  'גזר',
#  'jawor',
#  'dieverij',
#  'præsentere',
#  'lapsenhoito',
#  'sazão',
#  'triboulet',
#  'פֿאַר־',
#  'نفوذ',
#  'medievist',
#  'samiec',
#  'hlas',
#  'passel',
#  'gamahucher',
#  'килограмм',
#  'Schuss',
#  'organe',
#  'San Pedro y San Pablo Teposcolula',
#  'tenang',
#  'miñoca',
#  'noncoincident',
#  'prawda',
#  'öv',
#  'attuale',
#  'tuonela',
#  'landa',
#  'Vandal',
#  'cânave',
#  'esta',
#  'Izard',
#  'plav',
#  'vulgær',
#  'ökologisch',
#  'mixtion',
#  'बान',
#  'katakata',
#  'ตาบอด',
#  'Waffel',
#  'విశ్వసనీయము',
#  'palvelus',
#  'grinagtig',
#  'chi',
#  'mellakoida',
#  'questa',
#  'spense',
#  'vibraphone',
#  'dagbreker',
#  'nú',
#  'เอาผิด',
#  'chaotic',
#  'Monday',
#  'szyja',
#  'xintar',
#  'シアン化',
#  'splitata',
#  'meer',
#  'A',
#  'jackal',
#  'empuje',
#  'κτήνος',
#  'descabello',
#  'Tabelle',
#  'sorice',
#  'propreantepenultimate',
#  'infarcire',
#  'серп',
#  '丼',
#  'विश्लेषण',
#  'Flaschenpost',
#  'catelectrotonus',
#  'putiri',
#  'szakadt',
#  'ethylene',
#  'grafik',
#  'বই',
#  'útland',
#  'înfrunta',
#  'Prus',
#  'торжество',
#  'merda',
#  'spicery',
#  '향고래',
#  'forbled',
#  'maldekstra',
#  'binarity',
#  'dichotomy',
#  'խուճապ',
#  'szybki',
#  'քանդակ',
#  'frakkr',
#  'خوشه',
#  'schod',
#  'lái',
#  'मसीति',
#  'wybawiać',
#  'taba',
#  'తుల',
#  'amuralhar',
#  'friper',
#  '回教',
#  'zoolatry',
#  'શેકવું',
#  'suulas',
#  'harmaalokki',
#  'ophthalmo-',
#  'átalakít',
#  'กุน',
#  'σηπτικός',
#  'nonfunctional',
#  'sepulcher',
#  'скворец',
#  'โทรศัพท์',
#  'nicciano',
#  'dispiacevole',
#  'reîmpărți',
#  'kwiek',
#  'ատյան',
#  'constituens',
#  'கல்லோலம்',
#  'gjenstand',
#  'qorsuk',
#  'dutturi',
#  'ბუტკო',
#  'doscientos',
#  'radiculaire',
#  'خربز',
#  'બાગ',
#  'kimmokerroin',
#  'jääpalakone',
#  'une',
#  'strawboard',
#  'tasa-arvo',
#  'Dobroaia',
#  'cíall',
#  'autarky',
#  'ráf',
#  'consilium',
#  'exército',
#  'мурғобӣ',
#  'puoltaa',
#  'econometría',
#  'Franca',
#  'Latynos',
#  'citérieur',
#  'undifferent',
#  'અગિયાર',
#  'naar',
#  'պիսակ',
#  'rectifiable',
#  'archangele',
#  'mononomial',
#  'стакан',
#  '-ala',
#  'chesible',
#  'galiba',
#  'disfare',
#  'ᐃᐢᑵᐤ',
#  'dorsomedially',
#  'lapangan terbang',
#  'مدينة',
#  'bykse',
#  'klepht',
#  'brank',
#  'ceauș',
#  'épistémologique',
#  'bekać',
#  'darwinistisch',
#  'definito',
#  'brilliance',
#  'snoepen',
#  'Raar',
#  'fight',
#  'كره',
#  'lithological',
#  'قورداشنی',
#  'elabora',
#  'sagus',
#  '-vaptan',
#  'diastasis',
#  'bắc',
#  'profondo',
#  'rakennustuote',
#  'risata',
#  'oženiti',
#  'ídolo',
#  'hall',
#  'indret',
#  'woofing',
#  'प्यास',
#  'Tindall',
#  'huijaus',
#  'vlaen',
#  'meti',
#  'admettre',
#  'brasileiro',
#  'faceless',
#  'incompreensível',
#  'caliph',
#  'veia',
#  'mit offenen Karten spielen',
#  'alley',
#  'ชลบุรี',
#  'pine',
#  'разгильдяй',
#  'քրքում',
#  'teamo',
#  'alligate',
#  'snøbrett',
#  'Landser',
#  '가마',
#  'newte',
#  'clématite',
#  'adjunkt',
#  'یوغورت',
#  'hylde',
#  'postic',
#  'speelvogel',
#  'Donze',
#  'espérer',
#  'эртен',
#  'тыл',
#  'oldal',
#  'rytas',
#  'orcaid',
#  'छाया',
#  'manubrium',
#  'pindot',
#  'rissa',
#  'chronological',
#  'intindi',
#  'Mrs',
#  'leftward',
#  'south',
#  'bebé',
#  'echeggiare',
#  'typösen',
#  'hionta',
#  'hryggð',
#  'hơke',
#  'Ronald',
#  'ซาว',
#  'binge-watcher',
#  'électrométallurgie',
#  'Landgraaf',
#  'nanoparticle',
#  'dövmek',
#  'setacciare',
#  'reccan',
#  'inspecter',
#  'lành',
#  'атыыһыт',
#  'lähetin',
#  'échantillon',
#  'polline',
#  'Perun',
#  'λάχνη',
#  'agħma',
#  'ded',
#  'gegužė',
#  'Lebensgefährte',
#  'civism',
#  'oxigén',
#  'vart',
#  'karkaisu',
#  'nonsens',
#  'phylo-',
#  'fejedelem',
#  'koya',
#  'gestern',
#  'symposiastic',
#  'resin',
#  'kurpa',
#  'novaculite',
#  'piederēt',
#  'supercresco',
#  'Tegula',
#  'Rogojină',
#  'dragée',
#  'Cecchini',
#  'amindumi',
#  'szanować',
#  'Damiani',
#  'svið',
#  'afsky',
#  'oversoft',
#  'becsületes',
#  '鱘魚',
#  'վառել',
#  'lazulum',
#  'Panaro',
#  'лѣвъ',
#  'effleurer',
#  'helikopter',
#  'yel',
#  'ἀψίνθιον',
#  'Athenian',
#  'flatulence',
#  'transgenetic',
#  'ghizdav',
#  'bayamo',
#  'demagnetizable',
#  'capillamentum',
#  'Goffman',
#  'mořský',
#  'tariffa',
#  'propionate',
#  'acea',
#  'kɔ̀ɔji',
#  'krafse',
#  '-овина',
#  'glapir',
#  'ohenne',
#  'πρωτότυπος',
#  'mold',
#  'vanuttaa',
#  'domestici',
#  'rautainen',
#  'fırtına',
#  'գորտն',
#  'colloïdal',
#  'гласность',
#  'complicit',
#  'հանգիստ',
#  'biologo',
#  'quidam',
#  'keino-',
#  'loha',
#  'hellenisoida',
#  'vloet',
#  'Ἀλέξανδρος',
#  'koszorú',
#  'afterheat',
#  'paie',
#  'མོ',
#  'borovice',
#  'przychodzień',
#  'Anlage',
#  'مویز',
#  'uovo',
#  'fíu',
#  'ลพบุรี',
#  'sluagh',
#  'sexta feira',
#  'Salt',
#  'φλέγμα',
#  'siliște',
#  'chemolithoautotrophic',
#  'żarna',
#  'sultana',
#  'κίδαφος',
#  'shutterbug',
#  'fizyczny',
#  'standardless',
#  'nant',
#  'jeżyna',
#  'Svondo',
#  'acan',
#  'мещанин',
#  'illuminating',
#  'Էմին',
#  'lesso',
#  'oprima',
#  'fita',
#  'ideoida',
#  'kudenn',
#  'injectable',
#  'scalpitare',
#  'baadom',
#  'easumhal',
#  'ឯករាជ',
#  'hypostome',
#  'Weissmann',
#  'dissezione',
#  'entail',
#  'skrap',
#  'șnur',
#  'rozbójnik',
#  'বহা',
#  '雌黄',
#  'формальдегид',
#  'prezo',
#  'grauweiß',
#  'gesticulation',
#  'intensité',
#  'pisāca',
#  'ulloq',
#  'pessimal',
#  'creo',
#  'kond',
#  'soggiogare',
#  'crackle',
#  'skjalgr',
#  'motiváció',
#  'skalp',
#  'mole',
#  'eise',
#  'szil',
#  'kärpänen',
#  '저',
#  'ლოცვა',
#  'vesakko',
#  'patik',
#  'Polák',
#  'ladrilho',
#  'crête',
#  'كوپری',
#  'վիճաբանել',
#  'құрғақшылық',
#  'foreclose',
#  'usinage',
#  'Holbach',
#  'Pteridaceae',
#  'unhomogeneous',
#  'chiazza',
#  'slicker',
#  'díszesebb',
#  'हंबरणे',
#  'duka',
#  'знак',
#  'Neo',
#  'stereotomy',
#  'leikillinen',
#  'աղեղն',
#  'delator',
#  'déchanter',
#  'sundrian',
#  'bejelentkezik',
#  'nyűgöz',
#  'sanctuary',
#  'collégien',
#  'moedig',
#  'genero',
#  'hupsu',
#  'Idiotikon',
#  'circuler',
#  'iklan',
#  'baklövés',
#  'schnauzer',
#  'senra',
#  'panzer',
#  'ἐπικαλέω',
#  'beodo',
#  'rekisitos',
#  'शिकस्त',
#  'reachtóir',
#  'europeizar',
#  'antineutron',
#  'swon',
#  'aramă',
#  'Jahrbuch',
#  'räikeä',
#  'imlíne',
#  'breadline',
#  'budskap',
#  'Afterwissenschaft',
#  'ancho',
#  'Zusammenhang',
#  'corupție',
#  'Աղվանք',
#  'fűnek',
#  'markswoman',
#  'contorsion',
#  'galactagogue',
#  'dlúhý',
#  'luas',
#  'tâmara',
#  'southwest',
#  'monopody',
#  'guu',
#  'spiten',
#  'Zukunft',
#  'bloemist',
#  'bronchospasm',
#  'abgeben',
#  ...}

# %%
len(set_term.intersection(set_related_term))
# Out:
# 384306

# %%
df_clean[df_clean.term == "medicină"]
# Out:
#              lang      term        reltype related_lang related_term
# 1376128  Romanian  medicină  borrowed_from       German      Medizin
# 1376129  Romanian  medicină   derived_from        Latin     medicīna

# %%
df_clean[df_clean.related_term == "medicină"] # this related_lang and related_term change with previous lang and term
# Out:
#              lang        term               reltype related_lang related_term
# 3224515  Romanian  medicinist  has_prefix_with_root     Romanian     medicină
