# %% [markdown]
# ### Etymology Cross Check

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### Etymologeek Result

# %%
lang_1 = "Italian"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian 
lang_2 = "Dutch"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
if lang_2 == "English":
    lang_3 = "English (eng)"
elif lang_2 == "Turkish":
    lang_3 = "Turkish (tur)"
elif lang_2 == "German":
    lang_3 = "German (deu)"
elif lang_2 == "French":
    lang_3 = "French (fra)"
elif lang_2 == "Spanish":
    lang_3 = "Spanish (spa)"
elif lang_2 == "Arabic":
    lang_3 = "Arabic (ara)"
elif lang_2 == "Russian":
    lang_3 = "Russian (rus)"
elif lang_2 == "Portuguese":
    lang_3 = "Portuguese (por)"
elif lang_2 == "Dutch":
    lang_3 = "Dutch (nld)"
elif lang_2 == "Italian":
    lang_3 = "Italian (ita)"
else:
    pass
#lang_3 = "English (eng)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)
print(f"{lang_1}\n{lang_2}\n{lang_3}")
# Out:
# Italian
# Dutch
# Dutch (nld)

# %%
lang_1_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_1.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_1_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Russian (rus)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Turkish (tur)_Etymologeek_Result1.xlsx']

# %%
df_lang_1 = pd.DataFrame()
for i in lang_1_file:
    df_var = pd.read_excel(f"{i}")
    df_lang_1 = pd.concat([df_lang_1,df_var], axis=0)
    df_lang_1.reset_index(drop=True, inplace=True)
df_lang_1
# Out:
#     search_word dict_entry_main language_main  \
# 0         tarif         tariffa       Italian
# 1         nadir           nadir       Italian
# 2          atan          atanor       Italian
# 3           tuz           tuzia       Italian
# 4         burnu          burnus       Italian
# ..          ...             ...           ...
# 794        ulan           ulano       Italian
# 795         cia        ciabatta       Italian
# 796        curb       curbascio       Italian
# 797      yogurt          yogurt       Italian
# 798        scia       sciacallo       Italian
#
#                                        definition_main       dict_entry  \
# 0    (Noun Verb) Rate, tariff, price, charge, fare ...        تَعْرِفَة
# 1          (Noun) (astronomy) nadir.(astronomy) nadir.  نَظِير السَّمْت
# 2                              (Noun) Athanor.Athanor.             تنور
# 3                                  (Noun) Tutty.Tutty.        تُوتِيَاء
# 4                            (Noun) Burnoose.Burnoose.          بُرْنُس
# ..                                                 ...              ...
# 794                    (Noun) Ulan, uhlan.Ulan, uhlan.            oğlan
# 795  (Noun) (cooking) ciabatta (flat bread). Power ...           zabata
# 796                                  (Noun) Whip.Whip.           kırbaç
# 797                              (Noun) Yogurt.Yogurt.           yoğurt
# 798  (Noun) Jackal. Looter. Profiteer.Jackal. Loote...            çakal
#
#           language                                         definition
# 0     Arabic (ara)                                                NaN
# 1     Arabic (ara)                                                NaN
# 2     Arabic (ara)  Illumination, enlightenment Cook stove. Oven, ...
# 3     Arabic (ara)                                                NaN
# 4     Arabic (ara)                                                NaN
# ..             ...                                                ...
# 794  Turkish (tur)                 (slang) catamite. Boy, male child.
# 795  Turkish (tur)                                                NaN
# 796  Turkish (tur)                                        Whip, lash.
# 797  Turkish (tur)                                            Yogurt.
# 798  Turkish (tur)  (pejorative, derogatory) A detestable person, ...
#
# [799 rows x 7 columns]

# %%
lang_2_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_2.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_2_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_Russian (rus)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_Turkish (tur)_Etymologeek_Result1.xlsx']

# %%
df_lang_2 = pd.DataFrame()
for i in lang_2_file:
    df_var2 = pd.read_excel(f"{i}")
    df_lang_2 = pd.concat([df_lang_2,df_var2], axis=0)
    df_lang_2.reset_index(drop=True, inplace=True)
df_lang_2
# Out:
#     search_word dict_entry_main language_main  \
# 0          emir            emir         Dutch
# 1         fakir           fakir         Dutch
# 2        koffie          koffie         Dutch
# 3         genie           genie         Dutch
# 4        suiker          suiker         Dutch
# ..          ...             ...           ...
# 897       prise           prise         Dutch
# 898        pape        papegaai         Dutch
# 899         beg             beg         Dutch
# 900      sultan          sultan         Dutch
# 901         bei             bei         Dutch
#
#                                        definition_main       dict_entry  \
# 0    (Noun) Emir (Islamic prince or leader).Emir (I...  أَمِير الْبَحْر
# 1    (Noun) (Islam, Hinduism) fakir.(Islam, Hinduis...           فَقِير
# 2                                (Noun) Coffee.Coffee.             قهوة
# 3    (Noun Noun) Genius Military engineers (unit).G...             جِنّ
# 4                                  (Noun) Sugar.Sugar.           سُكَّر
# ..                                                 ...              ...
# 897  (Noun) (Belgium) electrical plug.(Belgium) ele...        prehensus
# 898                              (Noun) Parrot.Parrot.         papagayo
# 899                (Noun) (historical) .(historical) .              beg
# 900  (Noun) A certain pastry. Sultan, a Muslim rule...           sultan
# 901  (Noun) (historical) bey, beg (historical Turki...              bey
#
#           language                                         definition
# 0     Arabic (ara)                                                NaN
# 1     Arabic (ara)                                                NaN
# 2     Arabic (ara)  (colloquial) coffee shop, café (colloquial use...
# 3     Arabic (ara)                                                NaN
# 4     Arabic (ara)                                                NaN
# ..             ...                                                ...
# 897  Spanish (spa)                                                NaN
# 898  Spanish (spa)  Any wrasse, (Labridae). Elephant ear (Caladium...
# 899  Turkish (tur)                                                NaN
# 900  Turkish (tur)  A breed of chicken originating in Turkey, kept...
# 901  Turkish (tur)          Gentleman, mister. Husband. Lord, master.
#
# [902 rows x 7 columns]

# %%
set_lang_11 = set(df_lang_1["dict_entry"])

# %%
set_lang_12 = set(df_lang_2["dict_entry"])

# %%
df_cross = pd.DataFrame(set_lang_11.intersection(set_lang_12), columns=["dict_entry"])
df_cross
# Out:
#      dict_entry
# 0         munia
# 1    maquillage
# 2         stock
# 3        rouler
# 4         trial
# ..          ...
# 145  artillerie
# 146        baie
# 147     private
# 148       coach
# 149        menu
#
# [150 rows x 1 columns]

# %%
df_lang_1_cross = pd.merge(df_cross,df_lang_1,how="inner", on="dict_entry")
df_lang_1_cross.drop_duplicates(inplace=True)
df_lang_1_cross = df_lang_1_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_1_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master"}, inplace=True)
df_lang_1_cross
# Out:
#     lang_master  term_master  dict_entry
# 0       Italian    cerimonia       munia
# 1       Italian   maquillage  maquillage
# 2       Italian        stock       stock
# 3       Italian     roulette      rouler
# 4       Italian        trial       trial
# ..          ...          ...         ...
# 192     Italian  artiglieria  artillerie
# 193     Italian         baia        baie
# 194     Italian      privacy     private
# 195     Italian        coach       coach
# 196     Italian         menu        menu
#
# [197 rows x 3 columns]

# %%
df_lang_2_cross = pd.merge(df_cross,df_lang_2,how="inner", on="dict_entry")
df_lang_2_cross.drop_duplicates(inplace=True)
df_lang_2_cross = df_lang_2_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_2_cross.rename(columns={"language_main":"lang_sleeve","dict_entry_main":"term_sleeve"}, inplace=True)
df_lang_2_cross
# Out:
#     lang_sleeve term_sleeve  dict_entry
# 0         Dutch   ceremonie       munia
# 1         Dutch  maquillage  maquillage
# 2         Dutch       stock       stock
# 3         Dutch     rollade      rouler
# 4         Dutch       trial       trial
# ..          ...         ...         ...
# 172       Dutch  artillerie  artillerie
# 173       Dutch        baai        baie
# 174       Dutch     privacy     private
# 175       Dutch       coach       coach
# 176       Dutch        menu        menu
#
# [177 rows x 3 columns]

# %%
df_lang_1_lang_2_cross = pd.merge(df_lang_1_cross,df_lang_2_cross, how="inner", on="dict_entry")
df_lang_1_lang_2_cross.drop_duplicates(inplace=True)
df_lang_1_lang_2_cross = df_lang_1_lang_2_cross[["lang_master","term_master","lang_sleeve","term_sleeve"]]
df_lang_1_lang_2_cross
# Out:
#     lang_master  term_master lang_sleeve term_sleeve
# 0       Italian    cerimonia       Dutch   ceremonie
# 1       Italian   maquillage       Dutch  maquillage
# 2       Italian        stock       Dutch       stock
# 3       Italian     roulette       Dutch     rollade
# 4       Italian        trial       Dutch       trial
# ..          ...          ...         ...         ...
# 257     Italian  artiglieria       Dutch  artillerie
# 258     Italian         baia       Dutch        baai
# 259     Italian      privacy       Dutch     privacy
# 260     Italian        coach       Dutch       coach
# 261     Italian         menu       Dutch        menu
#
# [254 rows x 4 columns]

# %%
lang_3_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/*_And_{lang_3.capitalize()}_Etymologeek_Result1.xlsx")
lang_3_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Arabic/Arabic_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Russian/Russian_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Dutch (nld)_Etymologeek_Result1.xlsx']

# %%
df_lang_3 = pd.DataFrame()
for i in lang_3_file:
    df_var3 = pd.read_excel(f"{i}")
    df_lang_3 = pd.concat([df_lang_3,df_var3], axis=0)
    df_lang_3.reset_index(drop=True, inplace=True)
df_lang_3
# Out:
#     search_word dict_entry_main language_main  \
# 0          şans            şans       Turkish
# 1          loca            loca       Turkish
# 2         porno     pornoaction       English
# 3          kast            kast       English
# 4          toen     toenadering       English
# ..          ...             ...           ...
# 272       capra           capra       Italian
# 273       capra     caprareccia       Italian
# 274     alloggi      alloggiare       Italian
# 275     sigillo         sigillo       Italian
# 276    cogliere        cogliere       Italian
#
#                                        definition_main    dict_entry  \
# 0                  (Noun) Fortune. Luck.Fortune. Luck.          dice
# 1    (Noun) (masonic) lodge. Box (in theaters).(mas...        laubja
# 2    (Noun) (Indonesia, legal) Any actions, behavio...  spiegelstraf
# 3    (Noun) A type of traditional cupboard produced...          kast
# 4    (Noun) (South Africa) A rapprochement.(South A...   toenadering
# ..                                                 ...           ...
# 272  (Noun) Goat (mammal). Nanny goat. Trestle.Goat...           bok
# 273  (Noun) A shed used to keep goats indoors durin...           bok
# 274  (Verb) (intransitive) To stay or lodge (at). (...        laubja
# 275  (Noun Verb) Seal (that seals something).Seal (...          sein
# 276  (Verb) (transitive) to grasp, seize, take. (tr...        legere
#
#         language                                         definition
# 0    Dutch (nld)                                                NaN
# 1    Dutch (nld)                                                NaN
# 2    Dutch (nld)                                                NaN
# 3    Dutch (nld)                                  Cupboard, closet.
# 4    Dutch (nld)            Approach; the process of coming closer.
# ..           ...                                                ...
# 272  Dutch (nld)  (gymnastics) vaulting horse. (pejorative) chur...
# 273  Dutch (nld)  (gymnastics) vaulting horse. (pejorative) chur...
# 274  Dutch (nld)                                                NaN
# 275  Dutch (nld)                                            Signal.
# 276  Dutch (nld)                                                NaN
#
# [277 rows x 7 columns]

# %%
set_lang_21 = set(df_lang_1["dict_entry_main"])

# %%
set_lang_23 = set(df_lang_3["dict_entry_main"])

# %%
df_cross_2 = pd.DataFrame(set_lang_21.intersection(set_lang_23), columns=["dict_entry_main"])
df_cross_2
# Out:
#    dict_entry_main
# 0            segno
# 1           salada
# 2          tangone
# 3            scusa
# 4             boom
# 5            colta
# 6            droga
# 7           caduto
# 8            yacht
# 9        collegare
# 10        pompelmo
# 11              tè
# 12          colore
# 13          caduta
# 14         sigillo
# 15            boma
# 16           capra
# 17            boss
# 18          chance
# 19         segnale
# 20        tragedia
# 21     caprareccia
# 22        bilandro
# 23        cogliere
# 24      alloggiare
# 25        cadavere
# 26           pacco
# 27          sketch
# 28      correttore
# 29          cadere
# 30        politico
# 31     significare
# 32       insegnare

# %%
df_lang_1_lang_3_cross = pd.merge(df_cross_2,df_lang_3,how="inner", on="dict_entry_main")
df_lang_1_lang_3_cross.drop_duplicates(inplace=True)
df_lang_1_lang_3_cross = df_lang_1_lang_3_cross[["language_main","dict_entry_main","language","dict_entry"]]
df_lang_1_lang_3_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master","language":"lang_sleeve","dict_entry":"term_sleeve"}, inplace=True)
df_lang_1_lang_3_cross
# Out:
#    lang_master  term_master  lang_sleeve term_sleeve
# 0      English        segno  Dutch (nld)        sein
# 1      Italian        segno  Dutch (nld)        sein
# 2   Portuguese       salada  Dutch (nld)      salade
# 3      Italian      tangone  Dutch (nld)       tange
# 4      Italian        scusa  Dutch (nld)     excuser
# 5       French         boom  Dutch (nld)        boom
# 6      Spanish         boom  Dutch (nld)        boom
# 7   Portuguese         boom  Dutch (nld)        boom
# 8      Italian         boom  Dutch (nld)        boom
# 9      Italian        colta  Dutch (nld)      legere
# 10     Italian        droga  Dutch (nld)       droog
# 11     Italian       caduto  Dutch (nld)        dice
# 12     English        yacht  Dutch (nld)  jaghtschip
# 13      French        yacht  Dutch (nld)   jageschip
# 14     Italian        yacht  Dutch (nld)   jageschip
# 15     Italian    collegare  Dutch (nld)      legere
# 16     Italian     pompelmo  Dutch (nld)  pompelmoes
# 17     Italian           tè  Dutch (nld)        thee
# 18     Italian       colore  Dutch (nld)       kleur
# 19     Italian       caduta  Dutch (nld)        dice
# 20     Italian      sigillo  Dutch (nld)        sein
# 21     Italian         boma  Dutch (nld)        boom
# 22     Italian        capra  Dutch (nld)         bok
# 23      French         boss  Dutch (nld)        baas
# 24     Italian         boss  Dutch (nld)        baas
# 25      French       chance  Dutch (nld)        dice
# 26     Spanish       chance  Dutch (nld)        dice
# 27  Portuguese       chance  Dutch (nld)        dice
# 28     Italian       chance  Dutch (nld)        dice
# 29     Italian      segnale  Dutch (nld)        sein
# 30     Italian     tragedia  Dutch (nld)     Dorians
# 31     Italian  caprareccia  Dutch (nld)         bok
# 32     Italian     bilandro  Dutch (nld)   bijlander
# 33     Italian     cogliere  Dutch (nld)      legere
# 34     Italian   alloggiare  Dutch (nld)      laubja
# 35     Italian     cadavere  Dutch (nld)        dice
# 36     Italian        pacco  Dutch (nld)         pak
# 37     English       sketch  Dutch (nld)      schets
# 38      French       sketch  Dutch (nld)      schets
# 39     Italian       sketch  Dutch (nld)      schets
# 40     Italian   correttore  Dutch (nld)   corrigere
# 41     Italian       cadere  Dutch (nld)        dice
# 42     Italian     politico  Dutch (nld)    politiek
# 43     Italian  significare  Dutch (nld)        sein
# 44     Italian    insegnare  Dutch (nld)        sein

# %%
df_lang_1_lang_2_lang_3 = pd.concat([df_lang_1_lang_2_cross,df_lang_1_lang_3_cross], axis=0)
df_lang_1_lang_2_lang_3.reset_index(drop=True, inplace=True)
df_lang_1_lang_2_lang_3["term_master"] = df_lang_1_lang_2_lang_3["term_master"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3["term_sleeve"] = df_lang_1_lang_2_lang_3["term_sleeve"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3
# Out:
#     lang_master  term_master  lang_sleeve term_sleeve
# 0       Italian    cerimonia        Dutch   ceremonie
# 1       Italian   maquillage        Dutch  maquillage
# 2       Italian        stock        Dutch       stock
# 3       Italian     roulette        Dutch     rollade
# 4       Italian        trial        Dutch       trial
# ..          ...          ...          ...         ...
# 294     Italian   correttore  Dutch (nld)   corrigere
# 295     Italian       cadere  Dutch (nld)        dice
# 296     Italian     politico  Dutch (nld)    politiek
# 297     Italian  significare  Dutch (nld)        sein
# 298     Italian    insegnare  Dutch (nld)        sein
#
# [299 rows x 4 columns]

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"term_sleeve"}, inplace=True)
#df_word
# Out:
#               term_sleeve
# 0                      ik
# 1                      je
# 2                     het
# 3                      de
# 4                     dat
# ...                   ...
# 39995                bois
# 39996                 ood
# 39997            melaatse
# 39998                poll
# 39999  vredesbesprekingen
#
# [40000 rows x 1 columns]

# %%
#df_lang_1_lang_2_lang_3 = pd.merge(df_lang_1_lang_2_lang_3,df_word, how="inner", on="term_sleeve")
#df_lang_1_lang_2_lang_3
# Out:
#     lang_master term_master  lang_sleeve term_sleeve
# 0       Italian   cerimonia        Dutch   ceremonie
# 1       Italian       stock        Dutch       stock
# 2       Italian        card        Dutch       kaart
# 3       Italian       carta        Dutch       kaart
# 4       Italian      stress        Dutch      stress
# ..          ...         ...          ...         ...
# 241     Italian       pacco  Dutch (nld)         pak
# 242     English      sketch  Dutch (nld)      schets
# 243      French      sketch  Dutch (nld)      schets
# 244     Italian      sketch  Dutch (nld)      schets
# 245     Italian    politico  Dutch (nld)    politiek
#
# [246 rows x 4 columns]

# %%
df_lang_1_lang_2_lang_3.to_excel(f"{lang_1.capitalize()}_And_{lang_3.capitalize()}_Etymologeek_Result5.xlsx", index=False)
