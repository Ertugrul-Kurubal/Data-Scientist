# %% [markdown]
# ### Etymology Cross Check

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### Etymologeek Result

# %%
lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian 
lang_2 = "Portuguese"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_3 = "Portuguese (por)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)

# %%
lang_1_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_1.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_1_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_German (deu)_Etymologeek_Result1.xlsx']

# %%
df_lang_1 = pd.DataFrame()
for i in lang_1_file:
    df_var = pd.read_excel(f"{i}")
    df_lang_1 = pd.concat([df_lang_1,df_var], axis=0)
    df_lang_1.reset_index(drop=True, inplace=True)
df_lang_1
# Out:
#      search_word dict_entry_main language_main  \
# 0           şans            şans       Turkish
# 1           loca            loca       Turkish
# 2             mı        mıknatıs       Turkish
# 3             mı          mısdak       Turkish
# 4            şey             şey       Turkish
# ..           ...             ...           ...
# 732       vermut          vermut       Turkish
# 733       panzer          panzer       Turkish
# 734  tonymayster     tonymayster       Turkish
# 735      filinta         filinta       Turkish
# 736       kuvars          kuvars       Turkish
#
#                                        definition_main   dict_entry  \
# 0                  (Noun) Fortune. Luck.Fortune. Luck.         dice
# 1    (Noun) (masonic) lodge. Box (in theaters).(mas...       laubja
# 2                                (Noun) Magnet.Magnet.  مِغْنَاطِيس
# 3    (Noun) (obsolete) criterion.(obsolete) criterion.     مِصْدَاق
# 4    (Noun Interjection) (slang) genital organ. Thi...      شَيْئاً
# ..                                                 ...          ...
# 732                                             (Noun)       wermut
# 733                                             (Noun)       panzer
# 734                                             (Noun)   tonmeister
# 735                                             (Noun)       flinte
# 736                                             (Noun)        quarz
#
#          language                                         definition
# 0     Dutch (nld)                                                NaN
# 1     Dutch (nld)                                                NaN
# 2    Arabic (ara)                                                NaN
# 3    Arabic (ara)                                                NaN
# 4    Arabic (ara)                                                NaN
# ..            ...                                                ...
# 732  German (deu)  Vermouth is an aromatized fortified wine, flav...
# 733  German (deu)  A tank is an armoured fighting vehicle intende...
# 734  German (deu)                                         Tonmeister
# 735  German (deu)                                             Flinte
# 736  German (deu)  Quartz is a hard, crystalline mineral composed...
#
# [737 rows x 7 columns]

# %%
lang_2_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_2.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_2_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Russian (rus)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Turkish (tur)_Etymologeek_Result1.xlsx']

# %%
df_lang_2 = pd.DataFrame()
for i in lang_2_file:
    df_var2 = pd.read_excel(f"{i}")
    df_lang_2 = pd.concat([df_lang_2,df_var2], axis=0)
    df_lang_2.reset_index(drop=True, inplace=True)
df_lang_2
# Out:
#      search_word dict_entry_main language_main  \
# 0             aç        açacalar    Portuguese
# 1             aç         açafrão    Portuguese
# 2           emir            emir    Portuguese
# 3            saf          safado    Portuguese
# 4            saf           safar    Portuguese
# ...          ...             ...           ...
# 1057      solito          solito    Portuguese
# 1058       birra           birra    Portuguese
# 1059        cani         canibal    Portuguese
# 1060       ladri        ladrilho    Portuguese
# 1061      caviar          caviar    Portuguese
#
#                                         definition_main       dict_entry  \
# 0     (Verb) To polish; to burnish.To polish; to bur...           صَقَلَ
# 1                               (Noun) Saffron.Saffron.       زَعْفَرَان
# 2     (Noun) Emir (Islamic prince or leader).Emir (I...  أَمِير الْبَحْر
# 3     (Noun Adjective) (colloquial) rogue; trickster...          أَزَاحَ
# 4     (Verb) (colloquial) to save. (pronominal) to a...          أَزَاحَ
# ...                                                 ...              ...
# 1057  (Adjective) (Rio Grande do Sul) alone; unaccom...             solo
# 1058  (Verb Noun) (uncountable) obstinacy (state of ...           birria
# 1059                     (Adjective) Cannibal.Cannibal.          canibal
# 1060                    (Noun) Brick. Tile.Brick. Tile.         ladrillo
# 1061                              (Noun) Caviar.Caviar.           havyar
#
#            language                                         definition
# 0      Arabic (ara)                                                NaN
# 1      Arabic (ara)                                                NaN
# 2      Arabic (ara)                                                NaN
# 3      Arabic (ara)                                                NaN
# 4      Arabic (ara)                                                NaN
# ...             ...                                                ...
# 1057  Spanish (spa)  Alone, by oneself. Lonely, lonesome. Sole, onl...
# 1058  Spanish (spa)                                     Garbage, junk.
# 1059  Spanish (spa)                                                NaN
# 1060  Spanish (spa)                                             Brick.
# 1061  Turkish (tur)                                            Caviar.
#
# [1062 rows x 7 columns]

# %%
set_lang_11 = set(df_lang_1["dict_entry"])

# %%
set_lang_12 = set(df_lang_2["dict_entry"])

# %%
df_cross = pd.DataFrame(set_lang_11.intersection(set_lang_12), columns=["dict_entry"])
df_cross
# Out:
#    dict_entry
# 0    surprise
# 1       toile
# 2       shoot
# 3      ballon
# 4        lord
# ..        ...
# 70     cancer
# 71  populaire
# 72     douche
# 73       Bank
# 74        cou
#
# [75 rows x 1 columns]

# %%
df_lang_1_lang_2_cross = pd.merge(df_cross,df_lang_1,how="inner", on="dict_entry")
df_lang_1_lang_2_cross
# Out:
#    dict_entry search_word dict_entry_main language_main  \
# 0    surprise     sürpriz         sürpriz       Turkish
# 1       toile     tuvalet         tuvalet       Turkish
# 2       shoot          şu             şut       Turkish
# 3      ballon       balon           balon       Turkish
# 4        lord        lord            lord       Turkish
# ..        ...         ...             ...           ...
# 77     cancer      kanser          kanser       Turkish
# 78  populaire     popüler         popüler       Turkish
# 79     douche         duş             duş       Turkish
# 80       Bank       banka           banka       Turkish
# 81        cou       kolye           kolye       Turkish
#
#                                       definition_main       language  \
# 0                           (Noun) Surprise.Surprise.   French (fra)
# 1   (Noun) Evening dress (ladies' long, festive dr...   French (fra)
# 2           (Noun) (football) shoot.(football) shoot.  English (eng)
# 3                             (Noun) Balloon.Balloon.   French (fra)
# 4                                   (Noun) Lord.Lord.  English (eng)
# ..                                                ...            ...
# 77  (Noun) Cancer (disease of uncontrolled cellula...   French (fra)
# 78                       (Adjective) Popular.Popular.   French (fra)
# 79                                                NaN   French (fra)
# 80                                  (Noun) Bank.Bank.   German (deu)
# 81                          (Noun) Necklace.Necklace.   French (fra)
#
#                                            definition
# 0                    Surprise (something unexpected).
# 1   (spider's) web. Fabric, cloth; canvas. Paintin...
# 2   (mining) A vein of ore running in the same gen...
# 3   (chemistry) round-bottom flask. (inflatable) b...
# 4   (intransitive, and, transitive) Domineer or ac...
# ..                                                ...
# 77                                            Cancer.
# 78  People's, as in People's Republic of China (in...
# 79                         (juggling) shower. Shower.
# 80  A facility for storage of a particular thing:....
# 81                                              Neck.
#
# [82 rows x 7 columns]

# %%
df_cross_1 = df_lang_1_lang_2_cross[["dict_entry_main"]].drop_duplicates()
df_cross_1
# Out:
#    dict_entry_main
# 0          sürpriz
# 1          tuvalet
# 2              şut
# 3            balon
# 4             lord
# ..             ...
# 76           madam
# 77          kanser
# 78         popüler
# 79             duş
# 81           kolye
#
# [70 rows x 1 columns]

# %%
#df_lang_2_lang_1_cross = pd.merge(df_cross,df_lang_2,how="inner", on="dict_entry")  # for second language (pair)
#df_lang_2_lang_1_cross

# %%
lang_3_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/*_And_{lang_3.capitalize()}_Etymologeek_Result1.xlsx")
lang_3_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Arabic/Arabic_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Russian/Russian_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Portuguese (por)_Etymologeek_Result1.xlsx']

# %%
df_lang_3 = pd.DataFrame()
for i in lang_3_file:
    df_var3 = pd.read_excel(f"{i}")
    df_lang_3 = pd.concat([df_lang_3,df_var3], axis=0)
    df_lang_3.reset_index(drop=True, inplace=True)
df_lang_3
# Out:
#     search_word dict_entry_main language_main  \
# 0       sandviç         sandviç       Turkish
# 1        harita          harita       Turkish
# 2          köri            köri       Turkish
# 3         mango           mango       Turkish
# 4            aç            açai       English
# ..          ...             ...           ...
# 187     fallire         fallire       Italian
# 188       falli       fallibile       Italian
# 189       secca         seccare       Italian
# 190       secca         seccato       Italian
# 191       cocco           cocco       Italian
#
#                                        definition_main dict_entry  \
# 0                            (Noun) Sandwich.Sandwich.       Kent
# 1    (Noun) Map (visual representation of an area)....    χαράσσω
# 2                                                  NaN       kari
# 3                                                  NaN      manga
# 4    (Noun) Any of several South American palms, of...       açaí
# ..                                                 ...        ...
# 187  (Verb) (intransitive) to fail. (intransitive) ...      fallo
# 188                     (Adjective) Fallible.Fallible.      fallo
# 189  (Verb) (transitive) To annoy or bother. (trans...     siccus
# 190  (Verb Adjective) Bothered, annoyed. Fed up. Wi...     siccus
# 191  (Noun) Coconut (fruit). Coconut palm.Coconut (...       coco
#
#              language                         definition
# 0    Portuguese (por)                                NaN
# 1    Portuguese (por)                                NaN
# 2    Portuguese (por)                    A type of spice
# 3    Portuguese (por)                            A fruit
# 4    Portuguese (por)  Açai, the fruit of the açaizeiro.
# ..                ...                                ...
# 187  Portuguese (por)                                NaN
# 188  Portuguese (por)                                NaN
# 189  Portuguese (por)                                NaN
# 190  Portuguese (por)                                NaN
# 191  Portuguese (por)      Coconut (fruit of coco palm).
#
# [192 rows x 7 columns]

# %%
set_lang_21 = set(df_lang_1["dict_entry_main"])

# %%
set_lang_23 = set(df_lang_3["dict_entry_main"])

# %%
df_cross_2 = pd.DataFrame(set_lang_21.intersection(set_lang_23), columns=["dict_entry_main"])
df_cross_2
# Out:
#   dict_entry_main
# 0            köri
# 1             ani
# 2           mango
# 3            vals
# 4         sandviç
# 5          harita

# %%
df_cross_12_word = pd.concat([df_cross_1,df_cross_2], axis=0)
df_cross_12_word.drop_duplicates(inplace=True)
df_cross_12_word
# Out:
#    dict_entry_main
# 0          sürpriz
# 1          tuvalet
# 2              şut
# 3            balon
# 4             lord
# ..             ...
# 0             köri
# 1              ani
# 2            mango
# 3             vals
# 5           harita
#
# [75 rows x 1 columns]

# %% [markdown]
# #### Github Data Result

# %% [markdown]
# ##### Part 1

# %%
df_github_cross_result = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result2.xlsx")
df_github_cross_result
# Out:
#                     term_id     lang        term       reltype  \
# 0    yglj90QEWaGcUI2-FXe41Q  Turkish     palavra  derived_from
# 1    QDVQAg50WQymOq6pxRgCYw  Turkish     parabol  derived_from
# 2    laDFbv6BUfiKYXbUNUtIUg  Turkish  alternatif  derived_from
# 3    _7Bj6HMdWbCjvChOa6fHnA  Turkish         baz  derived_from
# 4    7uaTXsE8Xf2lN_stc4ygFg  Turkish         çek  derived_from
# ..                      ...      ...         ...           ...
# 357  FfZo89O-W463MMjEwKps2A  Turkish  anormallik  derived_from
# 358  nkTw-yb0UcOdHIY-_80CuQ  Turkish    marangoz  derived_from
# 359  qbQrvqVHV5mcnnDStzwm6A  Turkish       dildo  derived_from
# 360  2_7BX2vhX0OdFfWOvGY3aQ  Turkish  İstanbullu  derived_from
# 361  DUwz2C9HVk2LmqHaBZSpXQ  Turkish        atel  derived_from
#
#             related_term_id     related_lang related_term
# 0    JHVmHqAPXEq-YaIbd0B5Jg    Ancient greek     παραβολή
# 1    JHVmHqAPXEq-YaIbd0B5Jg    Ancient greek     παραβολή
# 2    ZSxxztTSVm6V_6rNEGaKhQ            Latin        alter
# 3    tJZMlh3FXjinpfCxRDoq6Q            Latin        basis
# 4    7SrzrJtdV2yhdkdGZ8hfyQ       Old french       eschek
# ..                      ...              ...          ...
# 357  PwziQVTKXWeL5YMlK6sl4g            Latin    anōrmalus
# 358  WAc5Rd_fU7Gti7MxzD7Hgw            Latin       mergus
# 359  eYo-R3WFU6u4qX9mmJrBWw          Italian      diletto
# 360  LVvnOSxFUyyGr0rTBrB73w  Byzantine greek    τὴν Πόλιν
# 361  FXDBUkWvWPO_IojhYr24sw            Latin       assula
#
# [362 rows x 7 columns]

# %%
df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_1.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
df_word = df_word.head(40000)
df_word = df_word.loc[:,["word"]]
df_word.rename(columns={"word":"term"}, inplace=True)
df_word
# Out:
#                term
# 0               bir
# 1            fikret
# 2                bu
# 3                ne
# 4                ve
# ...             ...
# 39995    ekipmanlar
# 39996     şanslılar
# 39997     aksanıyla
# 39998  yargılanacak
# 39999     tepkisini
#
# [40000 rows x 1 columns]

# %%
df_github_cross_result = pd.merge(df_github_cross_result,df_word,how="inner",on="term")
df_github_cross_result
# Out:
#                     term_id     lang        term       reltype  \
# 0    yglj90QEWaGcUI2-FXe41Q  Turkish     palavra  derived_from
# 1    laDFbv6BUfiKYXbUNUtIUg  Turkish  alternatif  derived_from
# 2    _7Bj6HMdWbCjvChOa6fHnA  Turkish         baz  derived_from
# 3    7uaTXsE8Xf2lN_stc4ygFg  Turkish         çek  derived_from
# 4    6ApISjwlWqeRbhRl_r5DKQ  Turkish       sıfır  derived_from
# ..                      ...      ...         ...           ...
# 200  Le0BIO_0VsW9tHJk8RKcoA  Turkish       nonoş  derived_from
# 201  0EE5O8uEWbS-_xARL-vJaw  Turkish    silindir  derived_from
# 202  Pl-mdsxKXui516-CQOUd7A  Turkish     komiser  derived_from
# 203  FfZo89O-W463MMjEwKps2A  Turkish  anormallik  derived_from
# 204  nkTw-yb0UcOdHIY-_80CuQ  Turkish    marangoz  derived_from
#
#             related_term_id   related_lang related_term
# 0    JHVmHqAPXEq-YaIbd0B5Jg  Ancient greek     παραβολή
# 1    ZSxxztTSVm6V_6rNEGaKhQ          Latin        alter
# 2    tJZMlh3FXjinpfCxRDoq6Q          Latin        basis
# 3    7SrzrJtdV2yhdkdGZ8hfyQ     Old french       eschek
# 4    PzMZaVy3UqWmKxAtjw_gLg         Arabic        صِفْر
# ..                      ...            ...          ...
# 200  _TuKtJdIWwa0c66mZt_4sg     Late latin       nonnus
# 201  EuWYJQS3XUmwMvKT5rPZdw  Ancient greek    κύλινδρος
# 202  4s2VoPaFU2GF1DtlkarP2g          Latin    commissio
# 203  PwziQVTKXWeL5YMlK6sl4g          Latin    anōrmalus
# 204  WAc5Rd_fU7Gti7MxzD7Hgw          Latin       mergus
#
# [205 rows x 7 columns]

# %%
#df_github_cross_result.to_excel("Turkish_And_Portuguese_Etymologeek_Result.xlsx", index=False)

# %%
df_github_cross_term = df_github_cross_result[["term"]]
df_github_cross_term["term"] = df_github_cross_term["term"].apply(lambda x: x.lower()) 
df_github_cross_term.rename(columns={"term":"dict_entry_main"}, inplace=True)
df_github_cross_term
# Out:
# <ipython-input-6-9d4c3a2109ce>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_github_cross_term["term"] = df_github_cross_term["term"].apply(lambda x: x.lower())
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     dict_entry_main
# 0           palavra
# 1        alternatif
# 2               baz
# 3               çek
# 4             sıfır
# ..              ...
# 200           nonoş
# 201        silindir
# 202         komiser
# 203      anormallik
# 204        marangoz
#
# [205 rows x 1 columns]

# %%
df_cross_result = pd.concat([df_cross_12_word,df_github_cross_term],axis=0)
df_cross_result.drop_duplicates(inplace=True)
df_cross_result.reset_index(drop=True,inplace=True)
df_cross_result
# Out:
#     dict_entry_main
# 0           sürpriz
# 1           tuvalet
# 2               şut
# 3             balon
# 4              lord
# ..              ...
# 252           nonoş
# 253        silindir
# 254         komiser
# 255      anormallik
# 256        marangoz
#
# [257 rows x 1 columns]

# %% [markdown]
# ##### Part 2

# %%
df_github_clean_result = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result3.xlsx")
df_github_clean_result

# %%
#df_cross_result.to_excel(f"{lang_1.capitalize()}_And_{lang_3.capitalize()}_Etymologeek_Result_All.xlsx")

# %% [markdown]
# #### Test

# %%
df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_1.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = pd.read_csv(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_folder.lower().capitalize()}/Result/Word/Merge/Word_Merge2.csv")
df_word = df_word.head(40000)
df_word
# Out:
#                word  frequency
# 0               bir   18835735
# 1            fikret   12101580
# 2                bu   11062659
# 3                ne    8025880
# 4                ve    7766036
# ...             ...        ...
# 39995    ekipmanlar        974
# 39996     şanslılar        974
# 39997     aksanıyla        974
# 39998  yargılanacak        974
# 39999     tepkisini        974
#
# [40000 rows x 2 columns]

# %%
set_word = set(df_word["word"])

# %%
set_result = set(df_cross_result["dict_entry_main"])

# %%
len(set_word.intersection(set_result))
# Out:
# 800

# %%
pd.DataFrame(set_word.intersection(set_result))
# Out:
#              0
# 0       şömine
# 1        kazak
# 2    alfabetik
# 3         papa
# 4         maça
# ..         ...
# 795     reçete
# 796  karaciğer
# 797      paket
# 798        caz
# 799       boks
#
# [800 rows x 1 columns]

# %%
df_test = pd.read_excel("test.xlsx")
df_test = df_test[["term"]]
df_test["term"] = df_test["term"].apply(lambda x: x.lower())
df_test
# Out:
#             term
# 0         kambur
# 1       portakal
# 2          piyon
# 3         ananas
# 4         ananas
# 5           port
# 6          japon
# 7        japonca
# 8        bisküvi
# 9        almanya
# 10      şampanya
# 11          plaj
# 12         banka
# 13         tente
# 14         fetiş
# 15        tayfun
# 16         yarın
# 17       kaşalot
# 18       kaşalot
# 19  japon balığı
# 20     mandalina
# 21      karamela
# 22       karamel
# 23      marmelat
# 24          şato
# 25          jöle
# 26  akselerasyon
# 27     i̇spanyol
# 28       komando
# 29      kampanya
# 30          staj
# 31        peyzaj
# 32     bocalamak
# 33     bocalamak
# 34       bandıra

# %%
set_test = set(df_test["term"])

# %%
set_result = set(df_cross_result["dict_entry_main"])

# %%
set_test.difference(set_result)
# Out:
# {'ananas', 'kaşalot', 'komando', 'portakal', 'tayfun'}

# %%
df_test2 = pd.read_excel("test2.xlsx")
df_test2 = df_test2[["turkish_word"]]
df_test2["turkish_word"] = df_test2["turkish_word"].apply(lambda x: x.lower())
df_test2
# Out:
#       turkish_word
# 0             broş
# 1            posta
# 2             plan
# 3     pamuk şekeri
# 4              göt
# ...            ...
# 2770      biyoloji
# 2771    birincilik
# 2772   i̇stanbullu
# 2773     dinsizlik
# 2774      salçalık
#
# [2775 rows x 1 columns]

# %%
set_test2 = set(df_test2["turkish_word"])

# %%
set_test2.difference(set_result)
# Out:
# {'haki',
#  'topak',
#  'abonman',
#  'sinirli',
#  'topçu',
#  'muşlu',
#  'çeneli',
#  'ilkel',
#  'dert',
#  'kural',
#  'özgüven',
#  'mafya',
#  'üçlü',
#  'varsayılan',
#  'enfrastrüktür',
#  'genelde',
#  'evcil',
#  'enformasyon',
#  'işlemci',
#  'betikle',
#  'paladyum',
#  'süpürge',
#  'lastik',
#  'boyut',
#  'fransızca',
#  'su',
#  'ücretsizlik',
#  'fil',
#  'unlu',
#  'içilmek',
#  'ortalama',
#  'bilgisayarla',
#  'yönlendirmek',
#  'kötü niyetli',
#  '-t',
#  'hızlıca',
#  'dokuzgen',
#  'yemenli',
#  'gka',
#  'atatürkçü',
#  'dayılık',
#  'güncelleme',
#  'göktürkçe',
#  'coğrafya',
#  'isimli',
#  'benzinlik',
#  'zebra',
#  'haymatlos',
#  'çilli',
#  'akredite',
#  'vernikleme',
#  'anında',
#  'berk',
#  'zorlamak',
#  'bilemek',
#  'iyelik',
#  'dokunmak',
#  'alpler',
#  'sekstilyon',
#  'kamera arkası',
#  'ebedilik',
#  'ulusalcılık',
#  'ölümsüz',
#  'adlı',
#  'halk',
#  '-im',
#  'humus',
#  'seçkin',
#  'birgün',
#  'devretmek',
#  'salahiyetli',
#  'bilgisayarsa',
#  'özellikle',
#  'kaynana',
#  'cerahatlenmeme',
#  'evse',
#  'yüzlerce',
#  'krema',
#  'dişleklik',
#  'dazlak',
#  'ziyadesiyle',
#  'rövanş',
#  'bakirlik',
#  'abajursuz',
#  'nemli',
#  'ıslak',
#  'at nalı',
#  'ergenlik',
#  'tümör',
#  'turşu suyu',
#  'günlük dil',
#  'galata',
#  'totemcilik',
#  'kedi',
#  'deprenmek',
#  'analık',
#  'tezal',
#  'kokarca',
#  'erkeklik',
#  'basını',
#  'antrenman',
#  'kirlilik',
#  'hafta sonu',
#  'etkinlik',
#  'çokdilli',
#  'genelge',
#  'içlik',
#  'kimlik',
#  'panseksüellik',
#  'helak olmak',
#  'hristiyan',
#  'onlarca',
#  'islememek',
#  'kullanmak',
#  'bebeklik',
#  'önemsiz',
#  'çaydanlık',
#  'tartmak',
#  'alyuvar',
#  'evre',
#  'kaynaç',
#  'ibnelik',
#  'abacılık',
#  'genelev',
#  'amper',
#  'şemşir',
#  'platformlararası',
#  'mümessillik',
#  'sözleşmek',
#  'sağaltıcı',
#  'şaşmak',
#  'irdelemek',
#  'spam',
#  'protestocu',
#  'argo',
#  'rapçi',
#  'yükseklik',
#  'abaküs',
#  'taner',
#  'sporcu',
#  'mükemmellik',
#  'i̇srailli',
#  'oysa',
#  'evsizlik',
#  'eleştirim',
#  'aseksüellik',
#  'pisi',
#  'biberli',
#  'üçüncü',
#  'iyilik',
#  'çizgili',
#  'öngörmek',
#  'özdekçilik',
#  'laiklik',
#  'halletmek',
#  'açlık',
#  'bayrak',
#  'tabela',
#  'kahramanlık',
#  'buzsa',
#  'banliyö',
#  'protesto',
#  'yemlik',
#  'kırım',
#  'alan',
#  'rumence',
#  'ananas',
#  'provokasyon',
#  'lezzetlilik',
#  'işlem',
#  'bandıralı',
#  'nikotin',
#  'cenk',
#  'paylaşmak',
#  'okçuluk',
#  'ilgili',
#  'hastalanmak',
#  'nargile',
#  'çöpçü',
#  'değer',
#  'alp',
#  'ay çöreği',
#  'düşünce',
#  'samur',
#  'arayüz',
#  'gen',
#  'hititçe',
#  'engin',
#  'yaylak',
#  'kan bilimi',
#  'evcikli',
#  'isteksizlik',
#  'kuran',
#  'ada',
#  'yapmamak',
#  'diş eti',
#  'erimek',
#  'kapsamsa',
#  'üretim',
#  'kuruşla',
#  'mikrofon',
#  'terli',
#  'mesuliyetli',
#  'devir',
#  'bel',
#  'bombalanmak',
#  'ayılmak',
#  'riskli',
#  'savunmak',
#  'siklamen',
#  'yazım',
#  'baldırıkara',
#  'bakım',
#  'inkılaptan',
#  'imek',
#  'gelinlik',
#  'realite',
#  'akbaba',
#  'piyade',
#  'şişlik',
#  'lubunyaca',
#  'kaskatı',
#  'arabaysa',
#  'analı',
#  'bilgisayarsız',
#  'burada',
#  'torba',
#  'şort',
#  'gün boyu',
#  'arzulamak',
#  'omniseksüellik',
#  'kanar',
#  'şaşırttırma',
#  'ikna olmak',
#  'hamol',
#  'sihirli',
#  'donmak',
#  'altdil',
#  'sorun',
#  'acentelik',
#  'politika',
#  'rezervuar',
#  'birkaç',
#  'elastik',
#  'lehçe',
#  'oynanmak',
#  'sonuncu',
#  'dikişli',
#  'telesmek',
#  'sapmak',
#  'hürriyet',
#  'yardımseverlik',
#  'hiçbir',
#  'dübel',
#  'yudum',
#  'eleman',
#  'kederli',
#  'meşem',
#  'koşullu',
#  'ak',
#  'kolay',
#  'kullanıcı adı',
#  'kırımı',
#  'varsıl',
#  'bakımsız',
#  'lakros',
#  'dans',
#  'sizce',
#  'sanık',
#  'hızla',
#  'poliseksüellik',
#  'tuvalet kapağı',
#  'anasız',
#  'en',
#  'alla',
#  'hastaneler',
#  'katmer',
#  'dikkatlice',
#  'bugün',
#  'konu',
#  'eril',
#  'iş adamlığı',
#  'devrim',
#  'aletli',
#  'kim',
#  'konuşma dili',
#  'kefaletle',
#  'kakırca',
#  'solcu',
#  'kadırga balığı',
#  'şeyle',
#  'ölümlü',
#  'orgeneral',
#  'genel',
#  'babasız',
#  'sözel',
#  'aparmak',
#  'özerk',
#  'adaylık',
#  'ağlatmak',
#  'çinko',
#  'benimsemek',
#  'bej',
#  'latince',
#  'yüzbinlerce',
#  'enfeksiyon',
#  'olmak',
#  'çimdiklemek',
#  'yay',
#  'eylemcilik',
#  'havaalanı',
#  'terminatör',
#  'bellemek',
#  'altyapısal',
#  'fahişelik',
#  'norveçli',
#  'aday',
#  'permütasyonla',
#  'büyükelçi',
#  'aylık',
#  'buji',
#  'kesinlikle',
#  'il',
#  'hanımeli',
#  'sulu',
#  'çöp arabası',
#  'totem',
#  'annelik',
#  'yaptırmamak',
#  'yazıt',
#  'kıyın',
#  'dertli',
#  'temel reis',
#  'dedelik',
#  'beşer',
#  'akrabayla',
#  'madenci',
#  'anasızlık',
#  'onay',
#  'prehistorik',
#  'evropiyum',
#  'değerli',
#  'önemlilik',
#  'kalsiyumlu',
#  'bilge',
#  'eğitmenlik',
#  'germek',
#  'varoş',
#  'önad',
#  'kulaklı',
#  'başla',
#  'karaçam',
#  'sahip olmak',
#  'ölümcül',
#  'sonnur',
#  'meşen',
#  'katsayı',
#  'sarmal',
#  'ölü',
#  'zilyon',
#  'parisli',
#  'olay',
#  'zehirli',
#  'kahraman',
#  'ben',
#  'adalı',
#  'ideal',
#  'onbinlerce',
#  'gramer',
#  'portakal',
#  'sevilay',
#  'kulak memesi',
#  'önemli',
#  'kilolu',
#  'öptürmek',
#  'göt',
#  'şaşırtma',
#  'evli',
#  'psikozla',
#  'kolaylık',
#  'dün',
#  'verimlilik',
#  'dinsizlik',
#  'delikanlı',
#  'abece',
#  'yazın',
#  'belarusça',
#  'dil bilgisi',
#  'fazlasıyla',
#  'bay',
#  'düzenli',
#  'doğukan',
#  'babaanne',
#  'türkçe',
#  'ata',
#  'çayhane',
#  'el kremi',
#  'erdemlilik',
#  'tirbuşon',
#  'aplikasyon',
#  'ay tutulması',
#  'süreklilik',
#  'karakulak',
#  'ağ',
#  'yedincilik',
#  'bombardıman',
#  'arkabahçe',
#  'arkadaş',
#  'matematikle',
#  'aletsel',
#  'tehlikeli',
#  'tasarım',
#  'elektrikli',
#  'ay ışığı',
#  'prensip',
#  'ant',
#  'norveççe',
#  'asteroitle',
#  'temizlik',
#  'seri',
#  'begüm',
#  'flöre',
#  'yamaner',
#  'seçmeli',
#  'final',
#  'yöneltmek',
#  'lektör',
#  'kuru',
#  'dinlilik',
#  'hastalıklı',
#  'smiley',
#  'esneklik',
#  'babamla',
#  'sosyoloji',
#  'erte',
#  'hidrat',
#  'adacık',
#  'er',
#  'etçil',
#  'boyacı',
#  'boksörlük',
#  'programsa',
#  'kürtçe',
#  'eyerletmek',
#  'eksiklik',
#  'karanlık',
#  'sürekli',
#  'böcekli',
#  'albüm',
#  "boole'ca",
#  'boya',
#  'çekimserlik',
#  'tarayıcı',
#  'sucu',
#  'kokteyl',
#  'talebelik',
#  'hür',
#  'kartaca',
#  'hatalı',
#  'olarak',
#  'profesyonel',
#  'yatay',
#  'biberlik',
#  'katkı',
#  'değişiklik',
#  'tabiyetli',
#  'öbür',
#  'basiretli',
#  'çimdikleme',
#  'kamus',
#  'konser',
#  'dilsizlik',
#  'fidan',
#  'şu',
#  'kötü',
#  'ilçe',
#  'taksi',
#  'portekizli',
#  'abajurcu',
#  'genellik',
#  'türkmence',
#  'üstünlük',
#  'lavaş',
#  'ağrıtmak',
#  'tepkili',
#  'homoseksüellik',
#  'eğlenmek',
#  'yönelimli',
#  'endişeli',
#  'akdoğu',
#  'hiçlik',
#  'kurtulmak',
#  'kask',
#  'kışlık',
#  'benzin',
#  'ankaralı',
#  'sertlik',
#  'koreli',
#  'silisyum',
#  'helsinki',
#  'angolalı',
#  'dulluk',
#  'aksiseda',
#  'tepki',
#  'araç',
#  'borçlu',
#  'sevgili',
#  'gürcüce',
#  'liseli',
#  'paha',
#  'azerice',
#  'i̇lker',
#  'hamburglu',
#  'gergin',
#  'enfrastrüktürel',
#  'varlık',
#  'antilop',
#  'dokunca',
#  'verimsizlik',
#  'plasman',
#  'musevilik',
#  'dikey',
#  'cibiliyetli',
#  'maceracı',
#  'uygulamak',
#  'korkusuz',
#  'yüzey',
#  'hastalık',
#  'deneyim',
#  'kansız',
#  'köz',
#  'emoji',
#  'ayakkabıcı',
#  'pist',
#  'profesyonellik',
#  'adsız',
#  'öne sürmek',
#  'dil bilimi',
#  'önbilgi',
#  'çilekli',
#  'atmak',
#  'kanserli',
#  'birlik',
#  'on',
#  'işlememek',
#  'evcik',
#  'aralık',
#  'kuvvetlilik',
#  'letonca',
#  'birliktelik',
#  'sen',
#  'imparatoriçe',
#  'aktif',
#  'sinagog',
#  'kıskanç',
#  'ilke',
#  'güvenli',
#  'elle',
#  'süperiletkenlik',
#  'benzerlik',
#  'hatasız',
#  'üçüz',
#  'duvar',
#  'kitapla',
#  'flu',
#  'it',
#  'kirli',
#  'yedigen',
#  'zorla',
#  'alabanda',
#  'altıgen',
#  'dikkatli',
#  'kibirli',
#  'kaşalot',
#  'judocu',
#  'i̇ngilizce',
#  'dansçı',
#  'gerçeklik',
#  'binlerce',
#  'mozambikli',
#  'düşünceli',
#  'berber',
#  'lügatçe',
#  'uyumak',
#  'ada balığı',
#  'araç hâli',
#  'ulusalcı',
#  'ninelik',
#  'bura',
#  'gerilmek',
#  'parti',
#  'sikiş',
#  'dolap',
#  'yerinde',
#  'yoksul',
#  'körce',
#  'şişmek',
#  'ayrıca',
#  'kesinlik',
#  'ehemmiyetsizlik',
#  'lirayla',
#  'bazalt',
#  'denizatı',
#  'taşıt',
#  'endeksli',
#  'atasözü',
#  'bilgisayarlı',
#  'bağlam',
#  'hekimlik',
#  'hazcı',
#  'basketçilik',
#  'olmazsa',
#  'kaybolmak',
#  'puding',
#  'olmamak',
#  'erdoğan',
#  'başka',
#  'entelektüel',
#  'verimli',
#  'farsça',
#  'adal',
#  'köşe vuruşu',
#  'cansızlık',
#  'dinçlik',
#  'elvermek',
#  'sayko',
#  'galeri',
#  'bilmek',
#  'telli',
#  'ara bulucu',
#  'bakirelik',
#  'adıyla',
#  'astroloji',
#  'kulaklık',
#  'önem',
#  'ege',
#  'arubalı',
#  'karadul',
#  'psikozsa',
#  'susuzluk',
#  'daktiloysa',
#  'dılak',
#  'minibüs',
#  'bitirtmek',
#  'sağaltmak',
#  'ut',
#  'at',
#  'koma',
#  'düzensiz',
#  'koşul',
#  'süre',
#  'fildişi',
#  'uzatmak',
#  'koz',
#  'işlemek',
#  'alakarga',
#  'zagrepli',
#  'web',
#  'falez',
#  'kansızlık',
#  'sosisli',
#  'desibel',
#  'giyinmek',
#  'sineklik',
#  'el gün',
#  'çarmıha germek',
#  'nazır',
#  'kanlılık',
#  'ateş',
#  'avcı',
#  'şaşırma',
#  'varyant',
#  'kabadayı',
#  'santimantal',
#  'venedikli',
#  'cd',
#  'elçilik',
#  'sinem',
#  'eritmek',
#  'kor',
#  'kaptan',
#  'mafya babası',
#  'kangren',
#  'istekli',
#  'kısır',
#  'işle',
#  'evle',
#  'kaptanlık',
#  'partisyon',
#  'spor',
#  'sonsuz',
#  'karamsar',
#  'dilsiz',
#  'hamilelik',
#  'güvensizlik',
#  'dönercilik',
#  'duşanbeli',
#  'omlet',
#  'osmanlılık',
#  'avlamak',
#  'haince',
#  'zehir',
#  'resmî dil',
#  'at hırsızı',
#  'rimelli',
#  'sahipli',
#  'şırınga',
#  'abu dabili',
#  'aikido',
#  'alabalık',
#  'bencillik',
#  'sierra leoneli',
#  'çirkinlik',
#  'yönelmek',
#  'dikkatsizce',
#  'karadeniz',
#  'tabansızsa',
#  'devralmak',
#  'böyle',
#  'oyuncak',
#  'babalı',
#  'eşlik',
#  'fince',
#  'dilimin',
#  '-len',
#  'çalkantılı',
#  'goril',
#  'hamak',
#  'ay',
#  'megapol',
#  'pasta',
#  'bilardo',
#  'sululuk',
#  'birleşmeli',
#  'başbakan',
#  'kara sinek',
#  'dam',
#  'cinsellik',
#  'çotra',
#  'kaprisli',
#  'karadon',
#  'belaruslu',
#  'pus',
#  'osmanlıcılık',
#  'yetenekli',
#  'ten',
#  'bürokrasi',
#  'astronot',
#  'saplı',
#  'üstdil',
#  'golfçü',
#  'kötü amaçlı',
#  'seçicilik',
#  'ovmak',
#  'paşa',
#  'yapım',
#  'osmanlıcı',
#  'bellek',
#  'argon',
#  'sırasıyla',
#  'ıslaklık',
#  'bütünsellik',
#  'kânunuevel',
#  'gerekli',
#  'kavuşum',
#  'kemikli',
#  'eşit',
#  'abalı',
#  'baba',
#  'özenli',
#  'sekizincilik',
#  'komando',
#  'indiyum',
#  'sikmek',
#  'i̇branice',
#  'bakanlık',
#  'karabağ',
#  'mayın gemisi',
#  'kiriş',
#  'enternasyonal',
#  'bencil',
#  'düzenlenebilir',
#  'i̇zmirli',
#  'elemli',
#  'bazlı',
#  'ulusal',
#  'travesti',
#  'halk dili',
#  'teşrinievvel',
#  'iz',
#  'andorralı',
#  'hevesli',
#  'ait',
#  'memnuniyetle',
#  'akdoğan',
#  'eyercilik',
#  'ajan',
#  'canlılık',
#  'kuzu',
#  'sümerce',
#  'kaliteli',
#  'bilgisayar',
#  'kafesli',
#  'bileşik',
#  'korku',
#  'sanmak',
#  'özverili',
#  'ora',
#  'sekizgen',
#  'uygun',
#  'tören',
#  'yermeli',
#  'varlıklı',
#  'kapsamla',
#  'çokgen',
#  'aral',
#  'sözleşme',
#  'yama',
#  'el',
#  'ulu',
#  'ikincilik',
#  'demlemek',
#  'marketing',
#  'kuvvetsizlik',
#  'enstrümantal',
#  'start',
#  'beşincilik',
#  'slovakça',
#  'torbalı',
#  'birer',
#  'dilbilim',
#  'jorjet',
#  'götürmek',
#  'salata',
#  'i̇sveççe',
#  'tabansızla',
#  'londra',
#  'amerikan',
#  'gerginlik',
#  'öncelik',
#  'ayvaz',
#  'izlek',
#  'birleşik kelimenin',
#  'baskça',
#  'beşlik',
#  'demirli',
#  'düzenlenebilirlik',
#  'yanıtlamak',
#  'oluşmak',
#  'teslim etmek',
#  'kaçırmak',
#  'kontekst',
#  'istemek',
#  'psikoterapi',
#  'kötümser',
#  'abacı',
#  'mikroskop',
#  'kanaat',
#  'kontuar',
#  'uysal',
#  'art',
#  'asrilik',
#  'krallık',
#  'biber',
#  'kestane',
#  'dondurma',
#  'yastık',
#  'berlinli',
#  'çaycı',
#  'ganalı',
#  'özlü',
#  'politikacı',
#  'bahriyeli',
#  'beşgen',
#  'eyerli',
#  'yetişkinlik',
#  'yakalamak',
#  'arabayla',
#  'renkli',
#  'bakan',
#  'meşenin',
#  'kulakçık',
#  'eğlenceli',
#  'kötülük',
#  'birol',
#  'beylik',
#  'soner',
#  'brokoli',
#  'afyonkarahisar',
#  'katar',
#  'göker',
#  'pelin',
#  'düzey',
#  'disko',
#  'benim',
#  'leh',
#  'sempati',
#  'bu',
#  'evrim',
#  'ayrancılık',
#  'performans',
#  'çözelti',
#  'çimmek',
#  'karagöz',
#  'kırbaçlamak',
#  'ateşçi',
#  'özbekçe',
#  'yanında',
#  'soğutmak',
#  'daktiloyla',
#  'i̇sveçli',
#  'hakim',
#  'milyarlarca',
#  'karakol',
#  'üstünlükçü',
#  'tuğçe',
#  'osmanlı',
#  'inovasyon',
#  'bitirttirmek',
#  'tarak',
#  'kara tahta',
#  'dondurmak',
#  'tokalp',
#  'izleyici',
#  'peki',
#  'başsa',
#  'bayağı',
#  'ölçü',
#  'hapsolmak',
#  'sağlıcak',
#  'kapat',
#  'tavukgötü',
#  'sırayla',
#  'nikel',
#  'oba',
#  'sekmek',
#  'arka',
#  'akarsu',
#  'uluslararası',
#  'soykırım',
#  'venezuelalı',
#  'anacık',
#  'yakalanmak',
#  'ayyıldız',
#  'prematüre',
#  'yetkili',
#  'allık',
#  'kalsiyum',
#  'gebelik',
#  'rutubetli',
#  'sürtmek',
#  'arpej',
#  'kült',
#  'tepmemek',
#  'kaynak',
#  'modernlik',
#  'yansıma',
#  'kürek',
#  'hatırlatmak',
#  'san',
#  'fresk',
#  'fırkateyn',
#  'sap',
#  'eyerlemek',
#  'bomba',
#  'vantilatör',
#  'normatiflik',
#  'evsiz',
#  'estelik',
#  'gevşemek',
#  'evlilik',
#  'özet',
#  'korece',
#  'düzen',
#  'portekizce',
#  'kasiyer',
#  'katmak',
#  'erol',
#  'opsiyonel',
#  'taklitle',
#  'kaynata',
#  'önemsizlik',
#  'pelte',
#  'absorpsiyon spektrumu',
#  'şifalı',
#  'malumat',
#  'güncellemek',
#  'kapı',
#  'kalyon',
#  'uydu',
#  'sonsuzluk',
#  'çekçe',
#  'karadağ',
#  'ölüm',
#  'kalorifer',
#  'radar',
#  'judo',
#  'karantina',
#  'genellikle',
#  'dabak',
#  ...}
