# %% [markdown]
# ### Etymology Language Pair

# %%
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### All Etymology File Concat

# %%
#all_etymologeek_file = glob.glob("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/*/*_Etymologeek_Main_And_Additional_Result.xlsx")
#all_etymologeek_file

# %%
#df_etymologeek_all = pd.DataFrame()
#for i in all_etymologeek_file:
#    df_var = pd.read_excel(f"{i}")
#    df_etymologeek_all = pd.concat([df_etymologeek_all, df_var], axis=0)
#df_etymologeek_all.drop_duplicates(inplace=True)
#df_etymologeek_all.reset_index(drop=True, inplace=True)
#df_etymologeek_all

# %%
#df_etymologeek_all.to_excel("All_Etymology_Language_Pair_Result.xlsx", index=False)

# %% [markdown]
# #### Read Etymologeek All Data

# %%
df_etymologeek_all = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/All_Etymology_Language_Pair_Result.xlsx")
df_etymologeek_all
# Out:
#        search_word dict_entry_main   language_main  \
# 0              bir             bir   Crimean Tatar
# 1              bir             bir   Crimean Tatar
# 2              bir             bir  Middle English
# 3              bir             bir  Middle English
# 4              bir             bir  Middle English
# ...            ...             ...             ...
# 668525        إلين           إلينا          Arabic
# 668526       مستقر           مستقر          Arabic
# 668527       مستقر           مستقر          Arabic
# 668528        صيني           صينية          Arabic
# 668529        صيني           صينية          Arabic
#
#                                           definition_main       dict_entry  \
# 0                (Numeral) (cardinal) one.(cardinal) one.             *bīr
# 1                (Numeral) (cardinal) one.(cardinal) one.              bir
# 2       (Noun) A charge on an account.. A strong or fa...           *buriz
# 3       (Noun) A charge on an account.. A strong or fa...        *bʰrewh₁-
# 4       (Noun) A charge on an account.. A strong or fa...           *buriz
# ...                                                   ...              ...
# 668525                              (Adverb) To us.To us.            إلينا
# 668526  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668528  (Noun) (usually definite) Chinese language.(us...  لُغَة صِينِيَّة
# 668529  (Noun) (usually definite) Chinese language.(us...            صينية
#
#                              language  \
# 0              Proto-Turkic (trk-pro)
# 1                 Crimean Tatar (crh)
# 2            Proto-Germanic (gem-pro)
# 3       Proto-Indo-European (ine-pro)
# 4            Proto-Germanic (gem-pro)
# ...                               ...
# 668525                   Arabic (ara)
# 668526                         Arabic
# 668527                         Arabic
# 668528                   Arabic (ara)
# 668529                   Arabic (ara)
#
#                                                definition
# 0                                                    One.
# 1                                         (cardinal) one.
# 2                                    Male offspring; son.
# 3                                                     NaN
# 4                                        Elevation; hill.
# ...                                                   ...
# 668525                                             To us.
# 668526  (Adjective) Confessing. Firm, solid, stable. F...
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...
# 668528                                                NaN
# 668529               (usually definite) Chinese language.
#
# [668530 rows x 7 columns]

# %%
#df_etymologeek_all["language_main"].unique()

# %%
#df_etymologeek_all["language"].unique()

# %%
lang_1 = "Arabic"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Turkish (tur)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)

# %%
df_lang_pair1 = df_etymologeek_all[(df_etymologeek_all["language_main"] == f"{lang_1.capitalize()}") & (df_etymologeek_all["language"] == f"{lang_2.capitalize()}")]
df_lang_pair1
# Out:
#        search_word dict_entry_main language_main  \
# 658125        الأن        الأناضول        Arabic
# 658241         دون            دونم        Arabic
# 660426         شعر             شعر        Arabic
# 663017        كافي          كافيار        Arabic
# 667049         كاف          كافيار        Arabic
#
#                                           definition_main dict_entry  \
# 658125                   (Proper noun) Anatolia.Anatolia.    Anadolu
# 658241                                (Noun) Dunam.Dunam.     dönmek
# 660426  (Noun Noun Noun Verb) Knowing, knowledge. Noti...       شعار
# 663017                              (Noun) Caviar.Caviar.     havyar
# 667049                              (Noun) Caviar.Caviar.     havyar
#
#              language                                         definition
# 658125  Turkish (tur)                                          Anatolia.
# 658241  Turkish (tur)  To be converted to another religion. To return...
# 660426  Turkish (tur)                                                NaN
# 663017  Turkish (tur)                                            Caviar.
# 667049  Turkish (tur)                                            Caviar.

# %%
df_lang_pair1["dict_entry_main"] = df_lang_pair1["dict_entry_main"].apply(lambda x: x.lower())
df_lang_pair1["dict_entry"] = df_lang_pair1["dict_entry"].apply(lambda x: x.lower())
df_lang_pair1 = df_lang_pair1.drop_duplicates(subset="dict_entry_main")
df_lang_pair1.reset_index(drop=True, inplace=True)
df_lang_pair1
# Out:
# <ipython-input-77-7b683e1fb3ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair1["dict_entry_main"] = df_lang_pair1["dict_entry_main"].apply(lambda x: x.lower())
# <ipython-input-77-7b683e1fb3ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair1["dict_entry"] = df_lang_pair1["dict_entry"].apply(lambda x: x.lower())
#   search_word dict_entry_main language_main  \
# 0        الأن        الأناضول        Arabic
# 1         دون            دونم        Arabic
# 2         شعر             شعر        Arabic
# 3        كافي          كافيار        Arabic
#
#                                      definition_main dict_entry  \
# 0                   (Proper noun) Anatolia.Anatolia.    anadolu
# 1                                (Noun) Dunam.Dunam.     dönmek
# 2  (Noun Noun Noun Verb) Knowing, knowledge. Noti...       شعار
# 3                              (Noun) Caviar.Caviar.     havyar
#
#         language                                         definition
# 0  Turkish (tur)                                          Anatolia.
# 1  Turkish (tur)  To be converted to another religion. To return...
# 2  Turkish (tur)                                                NaN
# 3  Turkish (tur)                                            Caviar.

# %%
df_lang_pair1.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result1.xlsx", index=False)  # {lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result_All.xlsx

# %% [markdown]
# #### Read Github Cross Data

# %% [markdown]
# ##### Part 1

# %%
df_github_cross = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_cross_check2.csv")
df_github_cross
# Out:
#                         term_id     lang      term                    reltype  \
# 0        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra             inherited_from
# 1        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 2        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 3        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 4        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# ...                         ...      ...       ...                        ...
# 8854119  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa             inherited_from
# 8854120  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854121  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854122  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854123  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa                 cognate_of
#
#                 related_term_id    related_lang related_term
# 0        9w90qvZDUH-2OHPVZEGJSQ  Middle english       parlai
# 1        Uy6v5wWuW6KGH4aTqGWnmA      Old french       parler
# 2        HY24XyCcUZCYSa1Q6y2kPA      Late latin     parabolō
# 3        uXGtk5g-W8G_TlTxSHImpg           Latin     parabola
# 4        JHVmHqAPXEq-YaIbd0B5Jg   Ancient greek     παραβολή
# ...                         ...             ...          ...
# 8854119  TUnsO83vXXC1Us5rJgGyUg    Vulgar latin    *pittitus
# 8854120  oUnwLLsHVymmwwiRXgrRow           Latin     pitinnus
# 8854121  IGRZaHQ-VU-vpxMjdxSTlA           Latin      pitulus
# 8854122  MDRrWciZWXGEj1KR9MUWtg           Latin     piccinus
# 8854123  SUJISOECWc6fDH00I_cTRQ          French        petit
#
# [8854124 rows x 7 columns]

# %%
lang_1 = "Arabic"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang1 = df_github_cross[(df_github_cross["lang"] == f"{lang_1.capitalize()}")] 
df_lang1
# Out:
#                         term_id    lang   term                    reltype  \
# 1376     wkvXK0XUXv-l0ADRAfplvw  Arabic  صابون              borrowed_from
# 1377     wkvXK0XUXv-l0ADRAfplvw  Arabic  صابون               derived_from
# 1378     wkvXK0XUXv-l0ADRAfplvw  Arabic  صابون               derived_from
# 1379     wkvXK0XUXv-l0ADRAfplvw  Arabic  صابون                 cognate_of
# 1380     wkvXK0XUXv-l0ADRAfplvw  Arabic  صابون  etymologically_related_to
# ...                         ...     ...    ...                        ...
# 8835212  mHFIj8G0Vc26MiQ-k0C1rg  Arabic  سروال  etymologically_related_to
# 8835213  mHFIj8G0Vc26MiQ-k0C1rg  Arabic  سروال  etymologically_related_to
# 8835214  mHFIj8G0Vc26MiQ-k0C1rg  Arabic  سروال  etymologically_related_to
# 8849626  LFpwYYVPW82jVY27YP-eTw  Arabic  باستا             inherited_from
# 8849627  LFpwYYVPW82jVY27YP-eTw  Arabic  باستا               derived_from
#
#                 related_term_id    related_lang related_term
# 1376     GDbh1rwvWwG4hHsO9CtaHQ   Ancient greek        σάπων
# 1377     pJcF6yFLWjKzwkSh2o8C9A           Latin         sāpō
# 1378     5o_N9d5MUgGbaN1hoc6abA  Proto-germanic       *saipǭ
# 1379     Naffm4scXmuKs81zPKkSTg         Aramaic      צַפּוֹן
# 1380     1A1-C2MtUNuyEn4WZ9a62w         Aramaic      סַפּוֹן
# ...                         ...             ...          ...
# 8835212  rGe4se1sVquQb7w6P_AgNA          Arabic     شَرْوَال
# 8835213  RcY8asd_W-C00hsrgOOIcA          Arabic      سِرْوَل
# 8835214  nVrhifUoVWq635_i9a7B6A          Arabic     سِرْوِيل
# 8849626  43A0voe4VvyMDUtG8Rlxww      Late latin        pasta
# 8849627  MKsGCYe8X9KiPQQtuR3ucg   Ancient greek        πάστα
#
# [9295 rows x 7 columns]

# %%
df_lang2 = df_github_cross[(df_github_cross["lang"] == f"{lang_2.capitalize()}")]
df_lang2["term"] = df_lang2["term"].apply(lambda x: x.lower())
#df_lang2.rename(columns={"term":"word"}, inplace=True)
df_lang2
# Out:
# <ipython-input-82-74392beaa152>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang2["term"] = df_lang2["term"].apply(lambda x: x.lower())
#                         term_id     lang       term  \
# 110      caAhC_cAXrKZU9rCcPAaPw  Turkish        göl
# 817      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 818      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 819      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 1345     5bVUD53NVEWYY0QAetV7iA  Turkish        net
# ...                         ...      ...        ...
# 8853155  nxRVOzFvUzS4X7r165GWcw  Turkish  ordinatör
# 8853651  pl-cU0pBVda2_BuEjBmtZw  Turkish     virman
# 8853652  pl-cU0pBVda2_BuEjBmtZw  Turkish     virman
# 8853831  fc8biERQXFicQGtfESBJQQ  Turkish   angajman
# 8853832  fc8biERQXFicQGtfESBJQQ  Turkish   angajman
#
#                            reltype         related_term_id  related_lang  \
# 110                 inherited_from  T6Wxr8YPVWK47B34DsG6KA  Proto-turkic
# 817                 inherited_from  nlVlgr5dUjas0_4GqplLJQ  Proto-turkic
# 818                 inherited_from  5g1DdR5OUPOxiQxCVcGW6A  Proto-turkic
# 819                 inherited_from  6KC332NQU7Sx9sFKEv6QdQ  Proto-turkic
# 1345                inherited_from  Ru1rzGVDWpi2rTYD9-XJWQ    Old french
# ...                            ...                     ...           ...
# 8853155  etymologically_related_to  tPEd3hNNXqeBt17YkY3I2Q        French
# 8853651       has_prefix_with_root  9CJvE6k0WJmKvcWZQmQjxw        French
# 8853652                 has_suffix  8YtrMi5VXlSpZVOupUTcWg        French
# 8853831       has_prefix_with_root  qQY-6sksXJe832mC9wIBqQ        French
# 8853832                 has_suffix  8YtrMi5VXlSpZVOupUTcWg        French
#
#         related_term
# 110             *kȫl
# 817              *ǖn
# 818              *öŋ
# 819              *oŋ
# 1345             net
# ...              ...
# 8853155  calculateur
# 8853651        virer
# 8853652         ment
# 8853831      engager
# 8853832         ment
#
# [27421 rows x 7 columns]

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word

# %%
#df_lang2 = pd.merge(df_lang2,df_word,how="inner",on="word")
#df_lang2

# %%
set_lang1 = set(df_lang1["related_term_id"])
set_lang2= set(df_lang2["related_term_id"])

# %%
df_pair_etymology = pd.DataFrame(set_lang1.intersection(set_lang2),columns=["related_term_id"])
df_pair_etymology
# Out:
#              related_term_id
# 0     NxY1OUoyWYCGRLRVxM4NkQ
# 1     wkNmCebqVh6E4cqmpTUXrQ
# 2     te2N0PjrVe2LDqiV2qdo4g
# 3     OTsN0VgrUri9KCZCRBscTg
# 4     wraXgyXoXsSLW_0Zb-_gvA
# ...                      ...
# 1551  Socpy9A-WQutM1otxNsgKw
# 1552  NA9r9rxsWX-TLlJDCWKg4A
# 1553  7AB70dqvUQu3ENbI_EG8ZQ
# 1554  gT2XbB3OW3i3gFOrisIQlA
# 1555  Zu-JGbMmW8iQo7dQ2Sz7-A
#
# [1556 rows x 1 columns]

# %%
df_etymology_merge = pd.merge(df_github_cross,df_pair_etymology,how="inner",on="related_term_id")
df_etymology_merge.drop_duplicates(inplace=True)
df_etymology_merge
# Out:
#                        term_id             lang          term        reltype  \
# 0       Sa9PLd8wVye-T_9yUc0DOw          English   unflappable     cognate_of
# 1       nFXAVxL6VNq-21U7oEJWsA          English  unacquainted     cognate_of
# 2       M8zwjHLNWTKJPvER9iEqLQ          English      acentric     cognate_of
# 3       f-6H0YHIV3yXEDrMC4MjIw          English       acephal     cognate_of
# 4       Vjv-9CLGXRutFlCYSi_bvg          English   investigate      has_affix
# ...                        ...              ...           ...            ...
# 269177  3rcFo3thXU-PyV6Y-dnx4w       Macedonian      харзувал  borrowed_from
# 269178  SX6bd02eXnGUVWh97X1zWg   Serbo-croatian       arzuhal  borrowed_from
# 269179  YudyjNxkUUGBcOH_L8D0OA  Ottoman turkish      عرضحالجی  borrowed_from
# 269180  -I_duEN_ViCEKj0ChcWDBQ           Arabic        عرضحال  borrowed_from
# 269181  aupigRMpXIel5oNQ-cfw5Q   Serbo-croatian       арзухал  borrowed_from
#
#                related_term_id related_lang related_term
# 0       J5FnlsOjVgWaY5_YXTRlOg        Latin          in-
# 1       J5FnlsOjVgWaY5_YXTRlOg        Latin          in-
# 2       J5FnlsOjVgWaY5_YXTRlOg        Latin          in-
# 3       J5FnlsOjVgWaY5_YXTRlOg        Latin          in-
# 4       J5FnlsOjVgWaY5_YXTRlOg        Latin          in-
# ...                        ...          ...          ...
# 269177  1c-7-hajVDOFTo6DK64Y-g      Persian       عرضحال
# 269178  1c-7-hajVDOFTo6DK64Y-g      Persian       عرضحال
# 269179  1c-7-hajVDOFTo6DK64Y-g      Persian       عرضحال
# 269180  1c-7-hajVDOFTo6DK64Y-g      Persian       عرضحال
# 269181  1c-7-hajVDOFTo6DK64Y-g      Persian       عرضحال
#
# [269182 rows x 7 columns]

# %%
df_etymology_merge = df_etymology_merge[df_etymology_merge["reltype"] == "derived_from"]
df_etymology_merge
# Out:
#                        term_id         lang        term       reltype  \
# 5       t7OyFm0yX0GAYfsAUUJDVg      English   immutable  derived_from
# 19      c2ve4L9sU4iSWc8nWr2Vyw      Italian    inesatto  derived_from
# 22      tovl3aGUWYKxh1319QAMCA      Italian   impreciso  derived_from
# 29      USKChRNJUK6zbCsYUlZkZg      Italian  imprudente  derived_from
# 43      etgy0jdvXzKT9N_C6exvmg      English  in-between  derived_from
# ...                        ...          ...         ...           ...
# 269165  gcOJoQTpUdS5qBTMhnU8dQ       Kazakh      құндақ  derived_from
# 269170  clelB-JGW-GCNXOR9tpB1w      Turkish      matbaa  derived_from
# 269172  3HRYEB5fWFeJr-68kljWDw  Azerbaijani      mətbəə  derived_from
# 269173  _BZNyhVHWHS9agkDreT1wg  Azerbaijani    mətbəəçi  derived_from
# 269174  njGmmg6qXLalRZqYMHryxQ       Arabic       مطبعة  derived_from
#
#                related_term_id     related_lang related_term
# 5       J5FnlsOjVgWaY5_YXTRlOg            Latin          in-
# 19      J5FnlsOjVgWaY5_YXTRlOg            Latin          in-
# 22      J5FnlsOjVgWaY5_YXTRlOg            Latin          in-
# 29      J5FnlsOjVgWaY5_YXTRlOg            Latin          in-
# 43      J5FnlsOjVgWaY5_YXTRlOg            Latin          in-
# ...                        ...              ...          ...
# 269165  RWjEqB6MUsiEYLubTibIrQ  Byzantine greek       κόνταξ
# 269170  168DPoisUEGN8i1Nq8RYxA           Arabic       طَبَعَ
# 269172  168DPoisUEGN8i1Nq8RYxA           Arabic       طَبَعَ
# 269173  168DPoisUEGN8i1Nq8RYxA           Arabic       طَبَعَ
# 269174  168DPoisUEGN8i1Nq8RYxA           Arabic       طَبَعَ
#
# [56081 rows x 7 columns]

# %%
df_etymology_merge = df_etymology_merge[~df_etymology_merge["related_term"].str.contains(fr"(?:\s|^)\*|\-(?:\s|$)", na=True)]
df_etymology_merge
# Out:
#                        term_id         lang      term       reltype  \
# 8325    1yENNvQwWv2Ls2MuYLt32A      English     union  derived_from
# 8326    38zyxl14XQ2SqTE5_NsxvA       French     union  derived_from
# 8333    9clM4h8YXdawt-8UPOUZ1A      English      -ary  derived_from
# 8337    z2MdW2haU12rrnLOjsxbHw       French     Union  derived_from
# 8338    Ew_D07cxUmes02_ekhfM9w       German     Union  derived_from
# ...                        ...          ...       ...           ...
# 269165  gcOJoQTpUdS5qBTMhnU8dQ       Kazakh    құндақ  derived_from
# 269170  clelB-JGW-GCNXOR9tpB1w      Turkish    matbaa  derived_from
# 269172  3HRYEB5fWFeJr-68kljWDw  Azerbaijani    mətbəə  derived_from
# 269173  _BZNyhVHWHS9agkDreT1wg  Azerbaijani  mətbəəçi  derived_from
# 269174  njGmmg6qXLalRZqYMHryxQ       Arabic     مطبعة  derived_from
#
#                related_term_id     related_lang related_term
# 8325    H-2YVn9qXryY0R5E5yibQw            Latin         ūnus
# 8326    H-2YVn9qXryY0R5E5yibQw            Latin         ūnus
# 8333    H-2YVn9qXryY0R5E5yibQw            Latin         ūnus
# 8337    H-2YVn9qXryY0R5E5yibQw            Latin         ūnus
# 8338    H-2YVn9qXryY0R5E5yibQw            Latin         ūnus
# ...                        ...              ...          ...
# 269165  RWjEqB6MUsiEYLubTibIrQ  Byzantine greek       κόνταξ
# 269170  168DPoisUEGN8i1Nq8RYxA           Arabic       طَبَعَ
# 269172  168DPoisUEGN8i1Nq8RYxA           Arabic       طَبَعَ
# 269173  168DPoisUEGN8i1Nq8RYxA           Arabic       طَبَعَ
# 269174  168DPoisUEGN8i1Nq8RYxA           Arabic       طَبَعَ
#
# [20160 rows x 7 columns]

# %%
df_lang1_result = df_etymology_merge[(df_etymology_merge["lang"]==f"{lang_1.capitalize()}")]
df_lang1_result.drop_duplicates(inplace=True)
df_lang1_result.reset_index(drop=True, inplace=True)
df_lang1_result
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                     term_id    lang     term       reltype  \
# 0    u4UxBwwIVPGvHKsxKByg6w  Arabic     سفود  derived_from
# 1    u4UxBwwIVPGvHKsxKByg6w  Arabic     سفود  derived_from
# 2    dF4cHMxgUPGvuXUPmMWq4Q  Arabic    علجوم  derived_from
# 3    b4vY8qXaUuO4W-CtBaS-hQ  Arabic  شمبانيا  derived_from
# 4    jiFlFcMqWVi5OxzHAIr9sw  Arabic   عسقلان  derived_from
# ..                      ...     ...      ...           ...
# 190  aBJx8eKAV_u1sj84GKI5qQ  Arabic    دزينة  derived_from
# 191  wXUkUjnIVKO2dL07d0EtGA  Arabic    عفارم  derived_from
# 192  N0Qx0s93VyS2gTJsnq6TUQ  Arabic   ترسانة  derived_from
# 193  X_RAaLMNUnS3zjo_QaXXag  Arabic    قنداق  derived_from
# 194  njGmmg6qXLalRZqYMHryxQ  Arabic    مطبعة  derived_from
#
#             related_term_id      related_lang related_term
# 0    Qy6xCGslU2GAzKoFUR28CQ        Old french       broche
# 1    rbP28JLEXQ2oIHJ16jGjGQ             Latin      broccus
# 2    Ux17bOrCXpCVmK6FdnPEUg             Latin        bulla
# 3    uSgMF5cQU1yZU9QlNGKk-w             Latin       campus
# 4    vyBt0TY5Vk-iRHQrbVxguQ             Latin
# ..                      ...               ...          ...
# 190  XmO25xwYV_-ClZwkEkE-0A       Old occitan      dotzena
# 191  C6qiuPhgWeOWFPLXr_ABkQ  Northern kurdish       aferim
# 192  e9R-HUTqV8OL51-OoFf7ow          Ligurian      tersaná
# 193  RWjEqB6MUsiEYLubTibIrQ   Byzantine greek       κόνταξ
# 194  168DPoisUEGN8i1Nq8RYxA            Arabic       طَبَعَ
#
# [195 rows x 7 columns]

# %%
df_lang1_result["term"] = df_lang1_result["term"].apply(lambda x: x.lower())
df_lang1_result["related_term"] = df_lang1_result["related_term"].apply(lambda x: x.lower())
# Out:
# <ipython-input-91-975ea63e0cd5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_result["term"] = df_lang1_result["term"].apply(lambda x: x.lower())
# <ipython-input-91-975ea63e0cd5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_result["related_term"] = df_lang1_result["related_term"].apply(lambda x: x.lower())

# %%
df_lang1_result
# Out:
#                     term_id    lang     term       reltype  \
# 0    u4UxBwwIVPGvHKsxKByg6w  Arabic     سفود  derived_from
# 1    u4UxBwwIVPGvHKsxKByg6w  Arabic     سفود  derived_from
# 2    dF4cHMxgUPGvuXUPmMWq4Q  Arabic    علجوم  derived_from
# 3    b4vY8qXaUuO4W-CtBaS-hQ  Arabic  شمبانيا  derived_from
# 4    jiFlFcMqWVi5OxzHAIr9sw  Arabic   عسقلان  derived_from
# ..                      ...     ...      ...           ...
# 190  aBJx8eKAV_u1sj84GKI5qQ  Arabic    دزينة  derived_from
# 191  wXUkUjnIVKO2dL07d0EtGA  Arabic    عفارم  derived_from
# 192  N0Qx0s93VyS2gTJsnq6TUQ  Arabic   ترسانة  derived_from
# 193  X_RAaLMNUnS3zjo_QaXXag  Arabic    قنداق  derived_from
# 194  njGmmg6qXLalRZqYMHryxQ  Arabic    مطبعة  derived_from
#
#             related_term_id      related_lang related_term
# 0    Qy6xCGslU2GAzKoFUR28CQ        Old french       broche
# 1    rbP28JLEXQ2oIHJ16jGjGQ             Latin      broccus
# 2    Ux17bOrCXpCVmK6FdnPEUg             Latin        bulla
# 3    uSgMF5cQU1yZU9QlNGKk-w             Latin       campus
# 4    vyBt0TY5Vk-iRHQrbVxguQ             Latin
# ..                      ...               ...          ...
# 190  XmO25xwYV_-ClZwkEkE-0A       Old occitan      dotzena
# 191  C6qiuPhgWeOWFPLXr_ABkQ  Northern kurdish       aferim
# 192  e9R-HUTqV8OL51-OoFf7ow          Ligurian      tersaná
# 193  RWjEqB6MUsiEYLubTibIrQ   Byzantine greek       κόνταξ
# 194  168DPoisUEGN8i1Nq8RYxA            Arabic       طَبَعَ
#
# [195 rows x 7 columns]

# %%
df_lang1_result["term"].nunique()
# Out:
# 141

# %%
df_lang1_result.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result2.xlsx", index=False)

# %% [markdown]
# ##### Part 2

# %%
df_github_clean = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_clean.csv")
df_github_clean
# Out:
#                            lang         term        reltype  \
# 0                       English    thesaurus  borrowed_from
# 1                       English    thesaurus   derived_from
# 2                       English    thesaurus   doublet_with
# 3                         Latin    thesaurus   derived_from
# 4                       English  portmanteau       has_root
# ...                         ...          ...            ...
# 3484911                 English        Boell  borrowed_from
# 3484912                 English        Boell  borrowed_from
# 3484913  South Levantine Arabic       بالمية      has_affix
# 3484914  South Levantine Arabic       بالمية      has_affix
# 3484915                 English       Cooler   derived_from
#
#                    related_lang  related_term
# 0                         Latin     thēsaurus
# 1                 Ancient Greek      θησαυρός
# 2                       English      treasure
# 3                 Ancient Greek      θησαυρός
# 4           Proto-Indo-European  *per- (fare)
# ...                         ...           ...
# 3484911                  Danish          Bøll
# 3484912                  German          Böll
# 3484913  South Levantine Arabic            بـ
# 3484914  South Levantine Arabic        الميّة
# 3484915                  German        Kühler
#
# [3484916 rows x 5 columns]

# %%
#lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
#lang_2 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang1_lang2 = df_github_clean[(df_github_clean["lang"] == f"{lang_1.capitalize()}") & (df_github_clean["related_lang"] == f"{lang_2.capitalize()}")]
df_lang1_lang2["term"] = df_lang1_lang2["term"].apply(lambda x: x.lower())
df_lang1_lang2["related_term"] = df_lang1_lang2["related_term"].apply(lambda x: x.lower())
df_lang1_lang2.reset_index(drop=True, inplace=True)
df_lang1_lang2
# Out:
# <ipython-input-97-4ffe8c9e6183>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_lang2["term"] = df_lang1_lang2["term"].apply(lambda x: x.lower())
# <ipython-input-97-4ffe8c9e6183>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_lang2["related_term"] = df_lang1_lang2["related_term"].apply(lambda x: x.lower())
#       lang           term                    reltype related_lang  \
# 0   Arabic           عربة                 cognate_of      Turkish
# 1   Arabic          فرملة  etymologically_related_to      Turkish
# 2   Arabic            قرش                 cognate_of      Turkish
# 3   Arabic             جي                 cognate_of      Turkish
# 4   Arabic             جي  etymologically_related_to      Turkish
# 5   Arabic            بيه                 cognate_of      Turkish
# 6   Arabic        سالونيك                 cognate_of      Turkish
# 7   Arabic           بلوط                 cognate_of      Turkish
# 8   Arabic           بلوط  etymologically_related_to      Turkish
# 9   Arabic           بلوط  etymologically_related_to      Turkish
# 10  Arabic           بلوط  etymologically_related_to      Turkish
# 11  Arabic           بلوط  etymologically_related_to      Turkish
# 12  Arabic           بلوط  etymologically_related_to      Turkish
# 13  Arabic           بلوط                 cognate_of      Turkish
# 14  Arabic           بلوط  etymologically_related_to      Turkish
# 15  Arabic         شاورما  etymologically_related_to      Turkish
# 16  Arabic          حزنبل                 cognate_of      Turkish
# 17  Arabic          حزنبل  etymologically_related_to      Turkish
# 18  Arabic           قندس                 cognate_of      Turkish
# 19  Arabic           سميذ                 cognate_of      Turkish
# 20  Arabic           قفيز                 cognate_of      Turkish
# 21  Arabic           قفيز  etymologically_related_to      Turkish
# 22  Arabic           قفيز  etymologically_related_to      Turkish
# 23  Arabic           قفيز  etymologically_related_to      Turkish
# 24  Arabic           قفيز  etymologically_related_to      Turkish
# 25  Arabic           قفيز  etymologically_related_to      Turkish
# 26  Arabic           قفيز  etymologically_related_to      Turkish
# 27  Arabic           قفيز  etymologically_related_to      Turkish
# 28  Arabic           كسبة                 cognate_of      Turkish
# 29  Arabic  مقدونس إفرنجي                 cognate_of      Turkish
# 30  Arabic        مازريون                 cognate_of      Turkish
# 31  Arabic           برغي                 cognate_of      Turkish
# 32  Arabic           برغي                 cognate_of      Turkish
# 33  Arabic           بلية                 cognate_of      Turkish
# 34  Arabic        إسكدنيا  etymologically_related_to      Turkish
# 35  Arabic        إسكدنيا  etymologically_related_to      Turkish
# 36  Arabic        إسكدنيا  etymologically_related_to      Turkish
# 37  Arabic        إسكدنيا  etymologically_related_to      Turkish
# 38  Arabic          ح ب ن  etymologically_related_to      Turkish
# 39  Arabic          ح ب ن  etymologically_related_to      Turkish
# 40  Arabic          ح ب ن  etymologically_related_to      Turkish
#
#        related_term
# 0             araba
# 1         frenlemek
# 2             kuruş
# 3               -ci
# 4               -çi
# 5               bey
# 6           selanik
# 7             bolut
# 8             pelüt
# 9             palıt
# 10            pölüt
# 11            pelit
# 12            pilit
# 13          palamut
# 14            pelid
# 15      döner kebap
# 16         hazanbel
# 17         hazambel
# 18           kunduz
# 19            simit
# 20            gebiç
# 21            kapis
# 22            kebiç
# 23            kepiç
# 24           kepinç
# 25            kepis
# 26            gabiz
# 27            kepiz
# 28            küspe
# 29  frenk maydanozu
# 30         mezeryon
# 31            burgu
# 32           burmak
# 33            bilye
# 34       yeni dünya
# 35            ezgil
# 36            dünya
# 37           dönmek
# 38           zakkum
# 39        ağı ağacı
# 40           zıkkım

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"related_term"}, inplace=True)
#df_word

# %%
#df_lang1_lang2 = pd.merge(df_lang1_lang2,df_word, how="inner", on="related_term")
#df_lang1_lang2

# %%
df_lang1_lang2["term"].nunique()
# Out:
# 19

# %%
df_lang1_lang2.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result3.xlsx", index=False)

# %% [markdown]
# ##### Part 3

# %%
df_github_cross = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_cross_check2.csv")
df_github_cross
# Out:
#                         term_id     lang      term                    reltype  \
# 0        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra             inherited_from
# 1        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 2        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 3        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 4        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# ...                         ...      ...       ...                        ...
# 8854119  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa             inherited_from
# 8854120  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854121  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854122  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854123  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa                 cognate_of
#
#                 related_term_id    related_lang related_term
# 0        9w90qvZDUH-2OHPVZEGJSQ  Middle english       parlai
# 1        Uy6v5wWuW6KGH4aTqGWnmA      Old french       parler
# 2        HY24XyCcUZCYSa1Q6y2kPA      Late latin     parabolō
# 3        uXGtk5g-W8G_TlTxSHImpg           Latin     parabola
# 4        JHVmHqAPXEq-YaIbd0B5Jg   Ancient greek     παραβολή
# ...                         ...             ...          ...
# 8854119  TUnsO83vXXC1Us5rJgGyUg    Vulgar latin    *pittitus
# 8854120  oUnwLLsHVymmwwiRXgrRow           Latin     pitinnus
# 8854121  IGRZaHQ-VU-vpxMjdxSTlA           Latin      pitulus
# 8854122  MDRrWciZWXGEj1KR9MUWtg           Latin     piccinus
# 8854123  SUJISOECWc6fDH00I_cTRQ          French        petit
#
# [8854124 rows x 7 columns]

# %%
#lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
#lang_2 = "Portuguese"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang_pair2 = df_github_cross[(df_github_cross["lang"] == f"{lang_1.capitalize()}") & (df_github_cross["related_lang"] == f"{lang_2.capitalize()}")]
df_lang_pair2.drop_duplicates(inplace=True)
df_lang_pair2.reset_index(drop=True, inplace=True)
df_lang_pair2
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                    term_id    lang     term                    reltype  \
# 0   Z5y1SZ_LW3aNkk6cq3CEAg  Arabic      طبل                 cognate_of
# 1   RKJ4VbmrW3ynYlVCFAixKg  Arabic      قوش                 cognate_of
# 2   mCJ6FYnAWlytWiCDu3T05A  Arabic    نعناع                 cognate_of
# 3   X1y38liNUO6orIPx-PFI_A  Arabic   كافيار                 cognate_of
# 4   ZSTCANmkWZuwQZYWUqPagA  Arabic      خان                 cognate_of
# 5   ZSTCANmkWZuwQZYWUqPagA  Arabic      خان                 cognate_of
# 6   vv2NTf0LW0-Fv_gfgqIMrQ  Arabic     كوسا  etymologically_related_to
# 7   8-c7j96jXVqNlmqzYM2FeA  Arabic     بلوط                 cognate_of
# 8   8-c7j96jXVqNlmqzYM2FeA  Arabic     بلوط                 cognate_of
# 9   ugX1u647XHilEzf0FweekA  Arabic   شاورما                  calque_of
# 10  ugX1u647XHilEzf0FweekA  Arabic   شاورما  etymologically_related_to
# 11  Ab_z-twlXu2U9qZi7e0b1Q  Arabic     عجور                 cognate_of
# 12  i10FH5AEUgG-HdGOvhsCZQ  Arabic      بيه                 cognate_of
# 13  i10FH5AEUgG-HdGOvhsCZQ  Arabic      بيه                 cognate_of
# 14  i10FH5AEUgG-HdGOvhsCZQ  Arabic      بيه  etymologically_related_to
# 15  8iJFYXHYUquZgjxU2Fru-A  Arabic      خوخ                 cognate_of
# 16  4Nc5YCOcW_eKH1CZ_lyLHg  Arabic     يارا                 cognate_of
# 17  AJHSEp14Uc2j6LYAlqIrgw  Arabic    خاتون              borrowed_from
# 18  AJHSEp14Uc2j6LYAlqIrgw  Arabic    خاتون              borrowed_from
# 19  sqtaJgENUkST-hnuCQyyXQ  Arabic     تليس                 cognate_of
# 20  8P8DvTwXVJuxt9wtsD55OQ  Arabic      قنب                 cognate_of
# 21  8P8DvTwXVJuxt9wtsD55OQ  Arabic      قنب  etymologically_related_to
# 22  N0Qx0s93VyS2gTJsnq6TUQ  Arabic   ترسانة                 cognate_of
# 23  SpxDfP7GXEqnvUIi9g0etA  Arabic     برغي                 cognate_of
# 24  iEMqzY17XSGsLn1x7n7Abw  Arabic     سنجق  etymologically_related_to
# 25  HlWFrbgTUEWARzdP18MshA  Arabic     قندس                 cognate_of
# 26  F5GKUJojUNWIJWBo3Q1dDQ  Arabic  سكنجبين                 cognate_of
# 27  R5dmKYh5XgKOxJmoQ3woBw  Arabic      ساج                 cognate_of
#
#            related_term_id related_lang related_term
# 0   m9yfdkYfVJ-zJQk8jPX1Lw      Turkish        davul
# 1   VVccjbk7WkSX1whwvZVeLg      Turkish       kuskun
# 2   OHXPjnXmVKCirlio4EF62g      Turkish         nane
# 3   -tjcLj35UXG7y0BYEyqjhQ      Turkish       havyar
# 4   1rcRTekMV9CNYvRvFKezcQ      Turkish        kağan
# 5   YHnth_XSWAeg-5wcKlmMKw      Turkish        hakan
# 6   AvYJY1j2WsCbJFF6r4vNWw      Turkish       dikeni
# 7   Vn8A16vXXM-uCt6TS9H0Rg      Turkish        pelit
# 8   _Q1xkvqaUDKuJ129ZDWW9Q      Turkish        palıt
# 9   jRv7ceGiVHa9phsKhvv6BA      Turkish        döner
# 10  9tbgYlSOXGmtQ3Vi_qMDFA      Turkish       dönmek
# 11  4GYazp5YVz6CMCRwVqv8Mw      Turkish        incir
# 12  pwrimp7EVGu3_qHtEPyiTQ      Turkish          bey
# 13  PehjSTIZUA-AxIkBcXMN4g      Turkish          ben
# 14  XXQSX1HVUpS4ZFix0h92hQ      Turkish          bay
# 15  P3q0BMhpXMqfNzxwLusZYQ      Turkish        güvem
# 16  aUMhciD-VWKCcSv4mccNxQ      Turkish         yara
# 17  ltrktuVdXm6KyvAuAIOslA      Turkish        kadın
# 18  LKdz9-vPX1GwteyU-76ttA      Turkish        hatun
# 19  eX_nbunCX_6GFgXZ9WuS0Q      Turkish        telis
# 20  GdGLICiSXVurRuHVxOTlBQ      Turkish      kenevir
# 21  qb8lHFV2WQ2DqcVl09gDZQ      Turkish       kendir
# 22  ZmAjiw8JUaezZF4CmOgD0A      Turkish      tersane
# 23  rOqoIhGxXIq-OnqcTO7yfw      Turkish        burgu
# 24  6mRHuoMbWZCnmW8qFyQUHA      Turkish       sancak
# 25  NrKOd1FPVuWKMhW8HoQ-Sg      Turkish       kunduz
# 26  u5IG05lJV-WAk6wm9eeU1Q      Turkish        sirke
# 27  lcgeIRlyXNyNx3KLGI701Q      Turkish          sac

# %%
df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: x.lower())
df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: x.lower())
# Out:
# <ipython-input-105-23b9c833e872>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: x.lower())
# <ipython-input-105-23b9c833e872>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: x.lower())

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"related_term"}, inplace=True)
#df_word

# %%
#df_lang_pair2 = pd.merge(df_lang_pair2,df_word, how="inner", on="related_term")
#df_lang_pair2

# %%
df_lang_pair2 = df_lang_pair2[(df_lang_pair2["reltype"] == "cognate_of") | (df_lang_pair2["reltype"] == "etymologically_related_to") | (df_lang_pair2["reltype"] == "derived_from") | (df_lang_pair2["reltype"] == "borrowed_from")]
df_lang_pair2 = df_lang_pair2.loc[:,["lang","term","reltype","related_lang","related_term"]]
df_lang_pair2.reset_index(drop=True, inplace=True)
df_lang_pair2
# Out:
#       lang     term                    reltype related_lang related_term
# 0   Arabic      طبل                 cognate_of      Turkish        davul
# 1   Arabic      قوش                 cognate_of      Turkish       kuskun
# 2   Arabic    نعناع                 cognate_of      Turkish         nane
# 3   Arabic   كافيار                 cognate_of      Turkish       havyar
# 4   Arabic      خان                 cognate_of      Turkish        kağan
# 5   Arabic      خان                 cognate_of      Turkish        hakan
# 6   Arabic     كوسا  etymologically_related_to      Turkish       dikeni
# 7   Arabic     بلوط                 cognate_of      Turkish        pelit
# 8   Arabic     بلوط                 cognate_of      Turkish        palıt
# 9   Arabic   شاورما  etymologically_related_to      Turkish       dönmek
# 10  Arabic     عجور                 cognate_of      Turkish        incir
# 11  Arabic      بيه                 cognate_of      Turkish          bey
# 12  Arabic      بيه                 cognate_of      Turkish          ben
# 13  Arabic      بيه  etymologically_related_to      Turkish          bay
# 14  Arabic      خوخ                 cognate_of      Turkish        güvem
# 15  Arabic     يارا                 cognate_of      Turkish         yara
# 16  Arabic    خاتون              borrowed_from      Turkish        kadın
# 17  Arabic    خاتون              borrowed_from      Turkish        hatun
# 18  Arabic     تليس                 cognate_of      Turkish        telis
# 19  Arabic      قنب                 cognate_of      Turkish      kenevir
# 20  Arabic      قنب  etymologically_related_to      Turkish       kendir
# 21  Arabic   ترسانة                 cognate_of      Turkish      tersane
# 22  Arabic     برغي                 cognate_of      Turkish        burgu
# 23  Arabic     سنجق  etymologically_related_to      Turkish       sancak
# 24  Arabic     قندس                 cognate_of      Turkish       kunduz
# 25  Arabic  سكنجبين                 cognate_of      Turkish        sirke
# 26  Arabic      ساج                 cognate_of      Turkish          sac

# %%
df_lang_pair2["term"].nunique()
# Out:
# 21

# %%
df_lang_pair2.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result4.xlsx", index=False)
