# %% [markdown]
# ### Etymology Language Pair

# %%
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### All Etymology File Concat

# %%
#all_etymologeek_file = glob.glob("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/*/*_Etymologeek_Main_And_Additional_Result.xlsx")
#all_etymologeek_file

# %%
#df_etymologeek_all = pd.DataFrame()
#for i in all_etymologeek_file:
#    df_var = pd.read_excel(f"{i}")
#    df_etymologeek_all = pd.concat([df_etymologeek_all, df_var], axis=0)
#df_etymologeek_all.drop_duplicates(inplace=True)
#df_etymologeek_all.reset_index(drop=True, inplace=True)
#df_etymologeek_all

# %%
#df_etymologeek_all.to_excel("All_Etymology_Language_Pair_Result.xlsx", index=False)

# %% [markdown]
# #### Read Etymologeek All Data

# %%
df_etymologeek_all = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/All_Etymology_Language_Pair_Result.xlsx")
df_etymologeek_all
# Out:
#        search_word dict_entry_main   language_main  \
# 0              bir             bir   Crimean Tatar
# 1              bir             bir   Crimean Tatar
# 2              bir             bir  Middle English
# 3              bir             bir  Middle English
# 4              bir             bir  Middle English
# ...            ...             ...             ...
# 668525        إلين           إلينا          Arabic
# 668526       مستقر           مستقر          Arabic
# 668527       مستقر           مستقر          Arabic
# 668528        صيني           صينية          Arabic
# 668529        صيني           صينية          Arabic
#
#                                           definition_main       dict_entry  \
# 0                (Numeral) (cardinal) one.(cardinal) one.             *bīr
# 1                (Numeral) (cardinal) one.(cardinal) one.              bir
# 2       (Noun) A charge on an account.. A strong or fa...           *buriz
# 3       (Noun) A charge on an account.. A strong or fa...        *bʰrewh₁-
# 4       (Noun) A charge on an account.. A strong or fa...           *buriz
# ...                                                   ...              ...
# 668525                              (Adverb) To us.To us.            إلينا
# 668526  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668528  (Noun) (usually definite) Chinese language.(us...  لُغَة صِينِيَّة
# 668529  (Noun) (usually definite) Chinese language.(us...            صينية
#
#                              language  \
# 0              Proto-Turkic (trk-pro)
# 1                 Crimean Tatar (crh)
# 2            Proto-Germanic (gem-pro)
# 3       Proto-Indo-European (ine-pro)
# 4            Proto-Germanic (gem-pro)
# ...                               ...
# 668525                   Arabic (ara)
# 668526                         Arabic
# 668527                         Arabic
# 668528                   Arabic (ara)
# 668529                   Arabic (ara)
#
#                                                definition
# 0                                                    One.
# 1                                         (cardinal) one.
# 2                                    Male offspring; son.
# 3                                                     NaN
# 4                                        Elevation; hill.
# ...                                                   ...
# 668525                                             To us.
# 668526  (Adjective) Confessing. Firm, solid, stable. F...
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...
# 668528                                                NaN
# 668529               (usually definite) Chinese language.
#
# [668530 rows x 7 columns]

# %%
#df_etymologeek_all["language_main"].unique()

# %%
#df_etymologeek_all["language"].unique()

# %%
lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Turkish (tur)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)

# %%
df_lang_pair1 = df_etymologeek_all[(df_etymologeek_all["language_main"] == f"{lang_1.capitalize()}") & (df_etymologeek_all["language"] == f"{lang_2.capitalize()}")]
df_lang_pair1
# Out:
#        search_word dict_entry_main language_main  \
# 6596         araba           araba       English
# 7217        beyler       beylerbey       English
# 13039          bey             bey       English
# 16978          yat        yataghan       English
# 20840        ekmek   ekmek kadayif       English
# 20841        ekmek   ekmek kadayif       English
# 25826         vali            vali       English
# 31625     kurabiye        kurabiye       English
# 38018          tuz           tuzla       English
# 38019          tuz           tuzla       English
# 68552         jack          jackal       English
# 82651          ray           rayah       English
# 200577         fez             fez       English
# 292199       abras          abrash       English
# 319018      caviar          caviar       English
# 322283        arab           araba       English
# 340181        turk          turkey       English
# 376397      turkey          turkey       English
# 407988        done           donek       English
# 411350      sultan          sultan       English
# 411445        soft           softa       English
# 415317       marta        martagon       English
# 468955        lahm        lahmacun       English
# 498514        caza            caza       English
# 509699        raya           rayah       English
# 567325     chagrin         chagrin       English
# 579360       gilet           gilet       English
# 628942        cavi          caviar       English
#
#                                           definition_main      dict_entry  \
# 6596    (Noun) A horse-drawn carriage once used for tr...           araba
# 7217    (Noun) An Ottoman administrative title.An Otto...      beylerbeyi
# 13039   (Noun) (historical) A governor of a province o...             bey
# 16978   (Noun) A type of sword used in Muslim countrie...         yatağan
# 20840   (Noun) A Turkish bread pudding dessert, also f...         kadayıf
# 20841   (Noun) A Turkish bread pudding dessert, also f...  ekmek kadayıfı
# 25826                                             (Noun)             vali
# 31625   (Noun) (rare) A cookie, particularly a sweet (...        kurabiye
# 38018   (Noun) A kind of central Anatolian rug.A kind ...             tuz
# 38019   (Noun) A kind of central Anatolian rug.A kind ...           tuzla
# 68552   (Verb Noun) To perform menial or routine tasks...           çakal
# 82651   (Noun) (pejorative) A member of the tax-paying...           reaya
# 200577  (Noun) A felt hat in the shape of a truncated ...             fes
# 292199  (Noun) A variation in color (often applied to ...           abraş
# 319018  (Noun) Roe of the sturgeon or other large fish...          havyar
# 322283  (Noun) A horse-drawn carriage once used for tr...           araba
# 340181  (Noun) (bowling) An act of throwing three stri...        Turgutlu
# 376397  (Noun) (bowling) An act of throwing three stri...        Turgutlu
# 407988  (Noun) A breed of fancy pigeon.A breed of fanc...           dönek
# 411350  (Noun) (card games) A variant of solitaire, pl...          sultan
# 411445  (Noun) (Islam) A religious student, especially...           softa
# 415317            (Noun) A Eurasian lily.A Eurasian lily.        martagan
# 468955  (Noun) A dish of Arab origin consisting of a r...        lahmacun
# 498514  (Noun) A Turkish provincial subdivision.A Turk...            kaza
# 509699  (Noun) (pejorative) A member of the tax-paying...           reaya
# 567325  (Verb Noun) (intransitive) To be vexed or anno...           sağrı
# 579360  (Noun) A sleeveless jacket similar to a waistc...           yelek
# 628942  (Noun) Roe of the sturgeon or other large fish...          havyar
#
#              language                                         definition
# 6596    Turkish (tur)                               Car. Carriage. Cart.
# 7217    Turkish (tur)                                                NaN
# 13039   Turkish (tur)          Gentleman, mister. Husband. Lord, master.
# 16978   Turkish (tur)                                          Yataghan.
# 20840   Turkish (tur)  A type of thin noodle used to make kanafeh pas...
# 20841   Turkish (tur)                                                NaN
# 25826   Turkish (tur)                                          Governor.
# 31625   Turkish (tur)                                   Cookie, biscuit.
# 38018   Turkish (tur)                                  (chemistry) salt.
# 38019   Turkish (tur)                                                NaN
# 68552   Turkish (tur)  (pejorative, derogatory) A detestable person, ...
# 82651   Turkish (tur)                                                NaN
# 200577  Turkish (tur)                                                NaN
# 292199  Turkish (tur)                                                NaN
# 319018  Turkish (tur)                                            Caviar.
# 322283  Turkish (tur)                               Car. Carriage. Cart.
# 340181  Turkish (tur)                                                NaN
# 376397  Turkish (tur)                                                NaN
# 407988  Turkish (tur)                                                NaN
# 411350  Turkish (tur)  A breed of chicken originating in Turkey, kept...
# 411445  Turkish (tur)  (Islam) A student of theology. (by extension) ...
# 415317  Turkish (tur)                                                NaN
# 468955  Turkish (tur)                                          Lahmacun.
# 498514  Turkish (tur)                                          Accident.
# 509699  Turkish (tur)                                                NaN
# 567325  Turkish (tur)  The chubby and round part of a mammal's body b...
# 579360  Turkish (tur)                           Jelick. Waistcoat, vest.
# 628942  Turkish (tur)                                            Caviar.

# %%
df_lang_pair1["dict_entry_main"] = df_lang_pair1["dict_entry_main"].apply(lambda x: x.lower())
df_lang_pair1["dict_entry"] = df_lang_pair1["dict_entry"].apply(lambda x: x.lower())
df_lang_pair1 = df_lang_pair1.drop_duplicates(subset="dict_entry_main")
df_lang_pair1.reset_index(drop=True, inplace=True)
df_lang_pair1
# Out:
# <ipython-input-63-7b683e1fb3ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair1["dict_entry_main"] = df_lang_pair1["dict_entry_main"].apply(lambda x: x.lower())
# <ipython-input-63-7b683e1fb3ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair1["dict_entry"] = df_lang_pair1["dict_entry"].apply(lambda x: x.lower())
#    search_word dict_entry_main language_main  \
# 0        araba           araba       English
# 1       beyler       beylerbey       English
# 2          bey             bey       English
# 3          yat        yataghan       English
# 4        ekmek   ekmek kadayif       English
# 5         vali            vali       English
# 6     kurabiye        kurabiye       English
# 7          tuz           tuzla       English
# 8         jack          jackal       English
# 9          ray           rayah       English
# 10         fez             fez       English
# 11       abras          abrash       English
# 12      caviar          caviar       English
# 13        turk          turkey       English
# 14        done           donek       English
# 15      sultan          sultan       English
# 16        soft           softa       English
# 17       marta        martagon       English
# 18        lahm        lahmacun       English
# 19        caza            caza       English
# 20     chagrin         chagrin       English
# 21       gilet           gilet       English
#
#                                       definition_main  dict_entry  \
# 0   (Noun) A horse-drawn carriage once used for tr...       araba
# 1   (Noun) An Ottoman administrative title.An Otto...  beylerbeyi
# 2   (Noun) (historical) A governor of a province o...         bey
# 3   (Noun) A type of sword used in Muslim countrie...     yatağan
# 4   (Noun) A Turkish bread pudding dessert, also f...     kadayıf
# 5                                             (Noun)         vali
# 6   (Noun) (rare) A cookie, particularly a sweet (...    kurabiye
# 7   (Noun) A kind of central Anatolian rug.A kind ...         tuz
# 8   (Verb Noun) To perform menial or routine tasks...       çakal
# 9   (Noun) (pejorative) A member of the tax-paying...       reaya
# 10  (Noun) A felt hat in the shape of a truncated ...         fes
# 11  (Noun) A variation in color (often applied to ...       abraş
# 12  (Noun) Roe of the sturgeon or other large fish...      havyar
# 13  (Noun) (bowling) An act of throwing three stri...    turgutlu
# 14  (Noun) A breed of fancy pigeon.A breed of fanc...       dönek
# 15  (Noun) (card games) A variant of solitaire, pl...      sultan
# 16  (Noun) (Islam) A religious student, especially...       softa
# 17            (Noun) A Eurasian lily.A Eurasian lily.    martagan
# 18  (Noun) A dish of Arab origin consisting of a r...    lahmacun
# 19  (Noun) A Turkish provincial subdivision.A Turk...        kaza
# 20  (Verb Noun) (intransitive) To be vexed or anno...       sağrı
# 21  (Noun) A sleeveless jacket similar to a waistc...       yelek
#
#          language                                         definition
# 0   Turkish (tur)                               Car. Carriage. Cart.
# 1   Turkish (tur)                                                NaN
# 2   Turkish (tur)          Gentleman, mister. Husband. Lord, master.
# 3   Turkish (tur)                                          Yataghan.
# 4   Turkish (tur)  A type of thin noodle used to make kanafeh pas...
# 5   Turkish (tur)                                          Governor.
# 6   Turkish (tur)                                   Cookie, biscuit.
# 7   Turkish (tur)                                  (chemistry) salt.
# 8   Turkish (tur)  (pejorative, derogatory) A detestable person, ...
# 9   Turkish (tur)                                                NaN
# 10  Turkish (tur)                                                NaN
# 11  Turkish (tur)                                                NaN
# 12  Turkish (tur)                                            Caviar.
# 13  Turkish (tur)                                                NaN
# 14  Turkish (tur)                                                NaN
# 15  Turkish (tur)  A breed of chicken originating in Turkey, kept...
# 16  Turkish (tur)  (Islam) A student of theology. (by extension) ...
# 17  Turkish (tur)                                                NaN
# 18  Turkish (tur)                                          Lahmacun.
# 19  Turkish (tur)                                          Accident.
# 20  Turkish (tur)  The chubby and round part of a mammal's body b...
# 21  Turkish (tur)                           Jelick. Waistcoat, vest.

# %%
df_lang_pair1.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result1.xlsx", index=False)  # {lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result_All.xlsx

# %% [markdown]
# #### Read Github Cross Data

# %% [markdown]
# ##### Part 1

# %%
df_github_cross = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_cross_check2.csv")
df_github_cross
# Out:
#                         term_id     lang      term                    reltype  \
# 0        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra             inherited_from
# 1        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 2        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 3        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 4        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# ...                         ...      ...       ...                        ...
# 8854119  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa             inherited_from
# 8854120  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854121  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854122  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854123  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa                 cognate_of
#
#                 related_term_id    related_lang related_term
# 0        9w90qvZDUH-2OHPVZEGJSQ  Middle english       parlai
# 1        Uy6v5wWuW6KGH4aTqGWnmA      Old french       parler
# 2        HY24XyCcUZCYSa1Q6y2kPA      Late latin     parabolō
# 3        uXGtk5g-W8G_TlTxSHImpg           Latin     parabola
# 4        JHVmHqAPXEq-YaIbd0B5Jg   Ancient greek     παραβολή
# ...                         ...             ...          ...
# 8854119  TUnsO83vXXC1Us5rJgGyUg    Vulgar latin    *pittitus
# 8854120  oUnwLLsHVymmwwiRXgrRow           Latin     pitinnus
# 8854121  IGRZaHQ-VU-vpxMjdxSTlA           Latin      pitulus
# 8854122  MDRrWciZWXGEj1KR9MUWtg           Latin     piccinus
# 8854123  SUJISOECWc6fDH00I_cTRQ          French        petit
#
# [8854124 rows x 7 columns]

# %%
df_github_cross[df_github_cross["term"] == "nasıl"]
# Out:
#                        term_id     lang   term         reltype  \
# 799419  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl  inherited_from
# 799421  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl  inherited_from
# 799423  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799425  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799426  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799427  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799428  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799429  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799430  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799431  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799433  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799435  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799437  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799439  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799440  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799441  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799442  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl    derived_from
# 799443  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl      cognate_of
# 799507  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl  inherited_from
# 799508  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl    derived_from
# 799509  jWxCi4i7UIG_3G-ADIczWQ  Turkish  nasıl        has_root
#
#                related_term_id     related_lang related_term
# 799419  mfOkpjKIWhWZd7h-C25r7A  Ottoman turkish           نه
# 799421  9mJl5yn_UF-pRtDYx1C8pQ     Proto-turkic         *nē-
# 799423  L4XKLlfmUzy34V1Yj7aPXw       Old turkic           𐰤𐰀
# 799425  QN5eFeZGVHKBLki6kuNg1Q      Azerbaijani           nə
# 799426  PR7uFJDUVj-I4_Mj88QnMw            Salar          neñ
# 799427  -FVaztfkXs-rjEaavLTGew          Bashkir           ни
# 799428  jWpLaj3_XAerlg8zd7PT9Q          Chuvash          мӗн
# 799429  GTcDKQhLXqumrhrXfD3wbg           Kazakh           не
# 799430  jCEyGVnMX_O5hb5DEO7jaw           Khakas         ниме
# 799431  V8nypnBnVCWIB4SZvrThtw           Kyrgyz           не
# 799433  epOJ1IBSXoSM0VwfGQMmag            Tatar           ни
# 799435  IHptT4G0XUuYPE1CMptTSQ          Turkmen         näme
# 799437  6PzsUWjBV9-tw9NrZZd4iQ            Tuvan          чүү
# 799439  l6q35QLvWgqYihx6KF8TMA           Uyghur         نېمە
# 799440  b2ePIjIaUF2gwfpJGWQuZg            Uzbek           na
# 799441  4VTVAOZlW-iovPvX5MuifA            Yakut         туох
# 799442  Qt1QIXbQW12SBuJc2kMl4g          Persian           نه
# 799443  KodMXVMtUxq5RQ7E3dFj5g      Old english           ne
# 799507  4UeKKFWuWk-4DB4LltiSew  Ottoman turkish          آصل
# 799508  ZrXgaj4DVKS-qhyZciiyHA           Arabic        أَصْل
# 799509  L-hq_UC9UHikAZitIiXgJA           Arabic        ء ص ل

# %%
df_github_cross[df_github_cross["related_term_id"] == "ZrXgaj4DVKS-qhyZciiyHA"]
# Out:
#                         term_id          lang         term        reltype  \
# 713537   q02u8LSFUz-yO03PVynOAw          Urdu          اصل  borrowed_from
# 714130   3I4yadKiXZm8UI6O7uRYyQ          Urdu      اصل میں   derived_from
# 714732   YC-1cjC-VuOrLmq7dYUWVg         Hindi      असल में  borrowed_from
# 799508   jWxCi4i7UIG_3G-ADIczWQ       Turkish        nasıl   derived_from
# 2017170  EKzj78yMWOCMi6NaBA5wrg       English        asili   derived_from
# 2061439  MpgtDFcqVm-G_ABnBuL3MQ    Indonesian         asal  borrowed_from
# 2062365  Ad_znb6NWOOCVhANFyo8fQ       Ternate         asal  borrowed_from
# 4875536  4oGFboG0XIaICiPDjJ-neQ        Hebrew          גזע      calque_of
# 4995445  zi_EoooQVcKg1bltrjDuvw    Indonesian      berasal   derived_from
# 4995525  stoC1SCnXl2Fx2GUCodsag         Malay      berasal  borrowed_from
# 5715465  S-1S5pkrW-6_JOq7rYaQ8Q       Turkish         asıl  borrowed_from
# 6270986  PiypSdOmUT2nYVg-MisM0w        Arabic          جذع      calque_of
# 6615768  q_iipOtIVaW2trdZpO-XsQ         Hindi        दरअसल  borrowed_from
# 6754723  WJORWa8-Vj29b_eiLjN6Cg         Hindi       असलियत  borrowed_from
# 6763159  uH8FzuhEXh-_gzx6BMwK_Q       Swahili     asilimia   derived_from
# 6899436  uzjunLWfWIarbWVPX79aLA        Telugu         అసలు  borrowed_from
# 6944152  pUdjKKe3XmCcb1eoGfbfHg        Kazakh      Асылбек  borrowed_from
# 7184383  aJKyoHhrUFmOyXa2kqsCWQ      Assamese          আচল  borrowed_from
# 7719279  29P0TNPBWOK-Yk4_ONoMzg    Indonesian        askot   derived_from
# 7862827  jL2_FQkMWBidQHEDlhWDRA  Translingual  Asilisaurus   derived_from
# 7892464  SfrYrWw3VSaxwV5ho7FyVg        Kazakh  Асылмұратов  borrowed_from
# 8162395  HxAzqkaGUl6VQ1ZUhxZsgQ       Swahili      kiasili   derived_from
# 8500649  dmbyU5FiUwe72LFBk92rBg    Indonesian        asbun   derived_from
# 8567689  A6v3PpuHXbyscDCvChKEUg        Uyghur         ئەسل   derived_from
#
#                 related_term_id related_lang related_term
# 713537   ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 714130   ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 714732   ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 799508   ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 2017170  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 2061439  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 2062365  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 4875536  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 4995445  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 4995525  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 5715465  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 6270986  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 6615768  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 6754723  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 6763159  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 6899436  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 6944152  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 7184383  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 7719279  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 7862827  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 7892464  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 8162395  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 8500649  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل
# 8567689  ZrXgaj4DVKS-qhyZciiyHA       Arabic        أَصْل

# %%
lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
def low_func(x):
    try:
        var_out = x.lower()
    except:
        var_out = x
    return var_out

# %%
df_lang1 = df_github_cross[(df_github_cross["lang"] == f"{lang_1.capitalize()}")] 
df_lang1
# Out:
#                         term_id     lang       term  \
# 110      caAhC_cAXrKZU9rCcPAaPw  Turkish        göl
# 817      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 818      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 819      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 1345     5bVUD53NVEWYY0QAetV7iA  Turkish        net
# ...                         ...      ...        ...
# 8853155  nxRVOzFvUzS4X7r165GWcw  Turkish  ordinatör
# 8853651  pl-cU0pBVda2_BuEjBmtZw  Turkish     virman
# 8853652  pl-cU0pBVda2_BuEjBmtZw  Turkish     virman
# 8853831  fc8biERQXFicQGtfESBJQQ  Turkish   angajman
# 8853832  fc8biERQXFicQGtfESBJQQ  Turkish   angajman
#
#                            reltype         related_term_id  related_lang  \
# 110                 inherited_from  T6Wxr8YPVWK47B34DsG6KA  Proto-turkic
# 817                 inherited_from  nlVlgr5dUjas0_4GqplLJQ  Proto-turkic
# 818                 inherited_from  5g1DdR5OUPOxiQxCVcGW6A  Proto-turkic
# 819                 inherited_from  6KC332NQU7Sx9sFKEv6QdQ  Proto-turkic
# 1345                inherited_from  Ru1rzGVDWpi2rTYD9-XJWQ    Old french
# ...                            ...                     ...           ...
# 8853155  etymologically_related_to  tPEd3hNNXqeBt17YkY3I2Q        French
# 8853651       has_prefix_with_root  9CJvE6k0WJmKvcWZQmQjxw        French
# 8853652                 has_suffix  8YtrMi5VXlSpZVOupUTcWg        French
# 8853831       has_prefix_with_root  qQY-6sksXJe832mC9wIBqQ        French
# 8853832                 has_suffix  8YtrMi5VXlSpZVOupUTcWg        French
#
#         related_term
# 110             *kȫl
# 817              *ǖn
# 818              *öŋ
# 819              *oŋ
# 1345             net
# ...              ...
# 8853155  calculateur
# 8853651        virer
# 8853652         ment
# 8853831      engager
# 8853832         ment
#
# [27421 rows x 7 columns]

# %%
df_lang2 = df_github_cross[(df_github_cross["lang"] == f"{lang_2.capitalize()}")]
df_lang2["term"] = df_lang2["term"].apply(lambda x: low_func(x))
#df_lang2.rename(columns={"term":"word"}, inplace=True)
df_lang2
# Out:
# <ipython-input-52-5d67f43db184>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang2["term"] = df_lang2["term"].apply(lambda x: low_func(x))
#                         term_id     lang          term  \
# 8        9dklyzlWU1GJG2HQTdn2Gw  English       breaker
# 9        9dklyzlWU1GJG2HQTdn2Gw  English       breaker
# 10       Sa9PLd8wVye-T_9yUc0DOw  English   unflappable
# 11       9dklyzlWU1GJG2HQTdn2Gw  English       breaker
# 12       Sa9PLd8wVye-T_9yUc0DOw  English   unflappable
# ...                         ...      ...           ...
# 8854101  X9TbD7nbViavII1VL_kMCw  English  geotechnique
# 8854102  X9TbD7nbViavII1VL_kMCw  English  geotechnique
# 8854103  X9TbD7nbViavII1VL_kMCw  English  geotechnique
# 8854104  X9TbD7nbViavII1VL_kMCw  English  geotechnique
# 8854105  X9TbD7nbViavII1VL_kMCw  English  geotechnique
#
#                            reltype         related_term_id    related_lang  \
# 8                    borrowed_from  5hrBfLYUVKCz_apIVUIeCQ         Occitan
# 9                     derived_from  7k2Vvp3nXLy5CvsTUAGhnA     Old occitan
# 10                  inherited_from  1s_U6-KHWmiJeKVbA96FWg  Middle english
# 11                    derived_from  UJle1K0PXdyx7GycKtbdvQ    Vulgar latin
# 12                  inherited_from  tiwBatmsX3aT6yV_bBj4pA     Old english
# ...                            ...                     ...             ...
# 8854101              borrowed_from  l-rKJaTcXL65SH14LLHRgA          French
# 8854102  etymologically_related_to  l-rKJaTcXL65SH14LLHRgA          French
# 8854103               derived_from  YbyR0LCGX4qfUGCtxMAlNQ   Ancient greek
# 8854104  etymologically_related_to  4bixcB-SUnyHLzonp8WarQ   Ancient greek
# 8854105  etymologically_related_to  cwWZ2hLaU1GuMpkyU45wHQ   Ancient greek
#
#         related_term
# 8           barrique
# 9            barrica
# 10               un-
# 11          *barrica
# 12               un-
# ...              ...
# 8854101    technique
# 8854102    technique
# 8854103     τεχνικός
# 8854104        τέχνη
# 8854105      τίκτειν
#
# [3656969 rows x 7 columns]

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word

# %%
#df_lang2 = pd.merge(df_lang2,df_word,how="inner",on="word")
#df_lang2

# %%
set_lang1 = set(df_lang1["related_term_id"])
set_lang2= set(df_lang2["related_term_id"])

# %%
df_pair_etymology = pd.DataFrame(set_lang1.intersection(set_lang2),columns=["related_term_id"])
df_pair_etymology
# Out:
#              related_term_id
# 0     D1eta8DOVOSQT-7B8tveRA
# 1     iXz9xjjvX46SBU6sbBmNyA
# 2     v_ANCPMtXRuPFFJfQ9HZfg
# 3     s8JXc7yrXSihqxbqOBV-WQ
# 4     NCZap6k6ViS9q83UhM77WQ
# ...                      ...
# 6573  hDUF6DLgVcin8mFoT0T87Q
# 6574  GmLlmSa0U5-3f-bkinwJxA
# 6575  EZF5hZJ9UiSDvbXrzeaDqw
# 6576  NyXGnwE0WeKc_Fu5JeK4RA
# 6577  bS1UaBkzWRi8u9YYTd-8xw
#
# [6578 rows x 1 columns]

# %%
df_etymology_merge = pd.merge(df_github_cross,df_pair_etymology,how="inner",on="related_term_id")
df_etymology_merge.drop_duplicates(inplace=True)
df_etymology_merge
# Out:
#                        term_id     lang          term         reltype  \
# 0       LHuH1RvcUjWNUTR6QQF8fg  Spanish       palabra    derived_from
# 1       ljccVuPLVnivw8cc3nNYlQ  Italian    parolaccia  inherited_from
# 2       FWrE64OiVqyZhvrUCjx-lw  Italian      parolina  inherited_from
# 3       nna1S--BXFqttVpHavoanQ    Scots        barley    derived_from
# 4       nEVenuUoViaCv4A9BMUvbg   French        Parole  inherited_from
# ...                        ...      ...           ...             ...
# 776499  cq1pMSwQXLiG-BfsI9kSYQ  English  cyberarsenal    derived_from
# 776500  ZmAjiw8JUaezZF4CmOgD0A  Turkish       tersane    derived_from
# 776501  cq1pMSwQXLiG-BfsI9kSYQ  English  cyberarsenal    derived_from
# 776502  Z0yiLTJHUD2HHKu-RAxbXg  Turkish       kaşıkçı       has_affix
# 776503  yviZV8jXWnSHcUvqUkGGRg  English     Khashoggi       has_affix
#
#                related_term_id     related_lang      related_term
# 0       uXGtk5g-W8G_TlTxSHImpg            Latin          parabola
# 1       uXGtk5g-W8G_TlTxSHImpg            Latin          parabola
# 2       uXGtk5g-W8G_TlTxSHImpg            Latin          parabola
# 3       uXGtk5g-W8G_TlTxSHImpg            Latin          parabola
# 4       uXGtk5g-W8G_TlTxSHImpg            Latin          parabola
# ...                        ...              ...               ...
# 776499  8sAvMylPV06vp_knMpEaQA           French           arsenal
# 776500  uunt-HERUyi9KbO__wGPZg           Arabic  دَار الصِّنَاعَة
# 776501  uunt-HERUyi9KbO__wGPZg           Arabic  دَار الصِّنَاعَة
# 776502  U9sgqrd8XCyr4zQERX_6Eg  Ottoman turkish              قاشق
# 776503  U9sgqrd8XCyr4zQERX_6Eg  Ottoman turkish              قاشق
#
# [776504 rows x 7 columns]

# %%
df_etymology_merge = df_etymology_merge[(df_etymology_merge["reltype"] == "inherited_from") | (df_etymology_merge["reltype"] == "etymologically_related_to") | (df_etymology_merge["reltype"] == "derived_from") | (df_etymology_merge["reltype"] == "borrowed_from")]
df_etymology_merge
# Out:
#                        term_id     lang          term         reltype  \
# 0       LHuH1RvcUjWNUTR6QQF8fg  Spanish       palabra    derived_from
# 1       ljccVuPLVnivw8cc3nNYlQ  Italian    parolaccia  inherited_from
# 2       FWrE64OiVqyZhvrUCjx-lw  Italian      parolina  inherited_from
# 3       nna1S--BXFqttVpHavoanQ    Scots        barley    derived_from
# 4       nEVenuUoViaCv4A9BMUvbg   French        Parole  inherited_from
# ...                        ...      ...           ...             ...
# 776497  ZmAjiw8JUaezZF4CmOgD0A  Turkish       tersane    derived_from
# 776498  Yyd9trhXVwaQEwbQRXkvEA   Polish    arsenałowy   borrowed_from
# 776499  cq1pMSwQXLiG-BfsI9kSYQ  English  cyberarsenal    derived_from
# 776500  ZmAjiw8JUaezZF4CmOgD0A  Turkish       tersane    derived_from
# 776501  cq1pMSwQXLiG-BfsI9kSYQ  English  cyberarsenal    derived_from
#
#                related_term_id related_lang      related_term
# 0       uXGtk5g-W8G_TlTxSHImpg        Latin          parabola
# 1       uXGtk5g-W8G_TlTxSHImpg        Latin          parabola
# 2       uXGtk5g-W8G_TlTxSHImpg        Latin          parabola
# 3       uXGtk5g-W8G_TlTxSHImpg        Latin          parabola
# 4       uXGtk5g-W8G_TlTxSHImpg        Latin          parabola
# ...                        ...          ...               ...
# 776497  8sAvMylPV06vp_knMpEaQA       French           arsenal
# 776498  8sAvMylPV06vp_knMpEaQA       French           arsenal
# 776499  8sAvMylPV06vp_knMpEaQA       French           arsenal
# 776500  uunt-HERUyi9KbO__wGPZg       Arabic  دَار الصِّنَاعَة
# 776501  uunt-HERUyi9KbO__wGPZg       Arabic  دَار الصِّنَاعَة
#
# [483743 rows x 7 columns]

# %%
df_etymology_merge = df_etymology_merge[~df_etymology_merge["related_term"].str.contains(fr"(?:\s|^)\*|\-(?:\s|$)", na=True)]
df_etymology_merge
# Out:
#                        term_id     lang          term         reltype  \
# 0       LHuH1RvcUjWNUTR6QQF8fg  Spanish       palabra    derived_from
# 1       ljccVuPLVnivw8cc3nNYlQ  Italian    parolaccia  inherited_from
# 2       FWrE64OiVqyZhvrUCjx-lw  Italian      parolina  inherited_from
# 3       nna1S--BXFqttVpHavoanQ    Scots        barley    derived_from
# 4       nEVenuUoViaCv4A9BMUvbg   French        Parole  inherited_from
# ...                        ...      ...           ...             ...
# 776497  ZmAjiw8JUaezZF4CmOgD0A  Turkish       tersane    derived_from
# 776498  Yyd9trhXVwaQEwbQRXkvEA   Polish    arsenałowy   borrowed_from
# 776499  cq1pMSwQXLiG-BfsI9kSYQ  English  cyberarsenal    derived_from
# 776500  ZmAjiw8JUaezZF4CmOgD0A  Turkish       tersane    derived_from
# 776501  cq1pMSwQXLiG-BfsI9kSYQ  English  cyberarsenal    derived_from
#
#                related_term_id related_lang      related_term
# 0       uXGtk5g-W8G_TlTxSHImpg        Latin          parabola
# 1       uXGtk5g-W8G_TlTxSHImpg        Latin          parabola
# 2       uXGtk5g-W8G_TlTxSHImpg        Latin          parabola
# 3       uXGtk5g-W8G_TlTxSHImpg        Latin          parabola
# 4       uXGtk5g-W8G_TlTxSHImpg        Latin          parabola
# ...                        ...          ...               ...
# 776497  8sAvMylPV06vp_knMpEaQA       French           arsenal
# 776498  8sAvMylPV06vp_knMpEaQA       French           arsenal
# 776499  8sAvMylPV06vp_knMpEaQA       French           arsenal
# 776500  uunt-HERUyi9KbO__wGPZg       Arabic  دَار الصِّنَاعَة
# 776501  uunt-HERUyi9KbO__wGPZg       Arabic  دَار الصِّنَاعَة
#
# [323426 rows x 7 columns]

# %%
df_lang1_result = df_etymology_merge[(df_etymology_merge["lang"]==f"{lang_1.capitalize()}")]
df_lang1_result.drop_duplicates(inplace=True)
df_lang1_result.reset_index(drop=True, inplace=True)
df_lang1_result
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                      term_id     lang       term                    reltype  \
# 0     yglj90QEWaGcUI2-FXe41Q  Turkish    palavra             inherited_from
# 1     yglj90QEWaGcUI2-FXe41Q  Turkish    palavra               derived_from
# 2     QDVQAg50WQymOq6pxRgCYw  Turkish    parabol               derived_from
# 3     yglj90QEWaGcUI2-FXe41Q  Turkish    palavra  etymologically_related_to
# 4     ps8w0BEzV2iu0c_dmeDBHg  Turkish        inç  etymologically_related_to
# ...                      ...      ...        ...                        ...
# 5061  -1OcugzGVym4hDHToaGC5A  Turkish     mersin              borrowed_from
# 5062  SJq-RrN9Wvq5ET1k8n7xrw  Turkish  sanayisiz  etymologically_related_to
# 5063  ZmAjiw8JUaezZF4CmOgD0A  Turkish    tersane  etymologically_related_to
# 5064  ZmAjiw8JUaezZF4CmOgD0A  Turkish    tersane               derived_from
# 5065  ZmAjiw8JUaezZF4CmOgD0A  Turkish    tersane               derived_from
#
#              related_term_id   related_lang      related_term
# 0     uXGtk5g-W8G_TlTxSHImpg          Latin          parabola
# 1     JHVmHqAPXEq-YaIbd0B5Jg  Ancient greek          παραβολή
# 2     JHVmHqAPXEq-YaIbd0B5Jg  Ancient greek          παραβολή
# 3     r3NclALnW1ioq3gnbe1R5g        English           palaver
# 4     H-2YVn9qXryY0R5E5yibQw          Latin              ūnus
# ...                      ...            ...               ...
# 5061  nkekVjAuXMCqs70-yhzAHw         Arabic          مَرْسِين
# 5062  lOJgZfZpVs2j5mhShOkXFg         Arabic          صِنَاعَة
# 5063  lOJgZfZpVs2j5mhShOkXFg         Arabic          صِنَاعَة
# 5064  8sAvMylPV06vp_knMpEaQA         French           arsenal
# 5065  uunt-HERUyi9KbO__wGPZg         Arabic  دَار الصِّنَاعَة
#
# [5066 rows x 7 columns]

# %%
df_lang1_result["term"] = df_lang1_result["term"].apply(lambda x: low_func(x))
df_lang1_result["related_term"] = df_lang1_result["related_term"].apply(lambda x: low_func(x))
df_lang1_result = df_lang1_result.loc[:,["lang","term","related_term_id"]]
df_lang1_result
# Out:
# <ipython-input-61-e326500b988f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_result["term"] = df_lang1_result["term"].apply(lambda x: low_func(x))
# <ipython-input-61-e326500b988f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_result["related_term"] = df_lang1_result["related_term"].apply(lambda x: low_func(x))
#          lang       term         related_term_id
# 0     Turkish    palavra  uXGtk5g-W8G_TlTxSHImpg
# 1     Turkish    palavra  JHVmHqAPXEq-YaIbd0B5Jg
# 2     Turkish    parabol  JHVmHqAPXEq-YaIbd0B5Jg
# 3     Turkish    palavra  r3NclALnW1ioq3gnbe1R5g
# 4     Turkish        inç  H-2YVn9qXryY0R5E5yibQw
# ...       ...        ...                     ...
# 5061  Turkish     mersin  nkekVjAuXMCqs70-yhzAHw
# 5062  Turkish  sanayisiz  lOJgZfZpVs2j5mhShOkXFg
# 5063  Turkish    tersane  lOJgZfZpVs2j5mhShOkXFg
# 5064  Turkish    tersane  8sAvMylPV06vp_knMpEaQA
# 5065  Turkish    tersane  uunt-HERUyi9KbO__wGPZg
#
# [5066 rows x 3 columns]

# %%
df_lang2_result = df_etymology_merge[(df_etymology_merge["lang"]==f"{lang_2.capitalize()}")]
df_lang2_result.drop_duplicates(inplace=True)
df_lang2_result.reset_index(drop=True, inplace=True)
df_lang2_result
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                        term_id     lang          term  \
# 0       VKpprkitUaijmY8EeBCvHQ  English         parle
# 1       pC6Bp9lIXHGgnqNe3JxmFg  English        parlay
# 2       pa1DyTEyVOaIVZQPA8Hzjg  English        parlor
# 3       WB7OVE01XeSxWXeHsxGrxQ  English        parole
# 4       x0csKO2pXiChaUAIWqoSEA  English        polari
# ...                        ...      ...           ...
# 136618  tS1sREhuWbCr2UScFIzW8A  English        Mersin
# 136619  cq1pMSwQXLiG-BfsI9kSYQ  English  cyberarsenal
# 136620  YoaH-eGUVTq4sX_3kPDdQA  English     ispaghula
# 136621  cq1pMSwQXLiG-BfsI9kSYQ  English  cyberarsenal
# 136622  cq1pMSwQXLiG-BfsI9kSYQ  English  cyberarsenal
#
#                           reltype         related_term_id related_lang  \
# 0                  inherited_from  uXGtk5g-W8G_TlTxSHImpg        Latin
# 1                  inherited_from  uXGtk5g-W8G_TlTxSHImpg        Latin
# 2                  inherited_from  uXGtk5g-W8G_TlTxSHImpg        Latin
# 3                  inherited_from  uXGtk5g-W8G_TlTxSHImpg        Latin
# 4                    derived_from  uXGtk5g-W8G_TlTxSHImpg        Latin
# ...                           ...                     ...          ...
# 136618              borrowed_from  nkekVjAuXMCqs70-yhzAHw       Arabic
# 136619  etymologically_related_to  lOJgZfZpVs2j5mhShOkXFg       Arabic
# 136620  etymologically_related_to  Prp1DBBWUTaz2Byw6yggQA      Persian
# 136621               derived_from  8sAvMylPV06vp_knMpEaQA       French
# 136622               derived_from  uunt-HERUyi9KbO__wGPZg       Arabic
#
#             related_term
# 0               parabola
# 1               parabola
# 2               parabola
# 3               parabola
# 4               parabola
# ...                  ...
# 136618          مَرْسِين
# 136619          صِنَاعَة
# 136620               غوش
# 136621           arsenal
# 136622  دَار الصِّنَاعَة
#
# [136623 rows x 7 columns]

# %%
df_lang2_result["term"] = df_lang2_result["term"].apply(lambda x: low_func(x))
df_lang2_result["related_term"] = df_lang2_result["related_term"].apply(lambda x: low_func(x))
df_lang2_result = df_lang2_result.loc[:,["lang","term","related_term_id"]]
df_lang2_result
# Out:
# <ipython-input-64-2be3fed2343d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang2_result["term"] = df_lang2_result["term"].apply(lambda x: x.lower())
# <ipython-input-64-2be3fed2343d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang2_result["related_term"] = df_lang2_result["related_term"].apply(lambda x: x.lower())
#            lang          term         related_term_id
# 0       English         parle  uXGtk5g-W8G_TlTxSHImpg
# 1       English        parlay  uXGtk5g-W8G_TlTxSHImpg
# 2       English        parlor  uXGtk5g-W8G_TlTxSHImpg
# 3       English        parole  uXGtk5g-W8G_TlTxSHImpg
# 4       English        polari  uXGtk5g-W8G_TlTxSHImpg
# ...         ...           ...                     ...
# 136618  English        mersin  nkekVjAuXMCqs70-yhzAHw
# 136619  English  cyberarsenal  lOJgZfZpVs2j5mhShOkXFg
# 136620  English     ispaghula  Prp1DBBWUTaz2Byw6yggQA
# 136621  English  cyberarsenal  8sAvMylPV06vp_knMpEaQA
# 136622  English  cyberarsenal  uunt-HERUyi9KbO__wGPZg
#
# [136623 rows x 3 columns]

# %%
df_same_ety = pd.merge(df_lang1_result,df_lang2_result, how="inner", on="related_term_id", suffixes=["_master","_sleeve"])
df_same_ety = df_same_ety[["lang_master","term_master","lang_sleeve","term_sleeve"]]
df_same_ety.drop_duplicates(inplace=True)
df_same_ety
# Out:
#        lang_master  term_master lang_sleeve       term_sleeve
# 0          Turkish      palavra     English             parle
# 1          Turkish      palavra     English            parlay
# 2          Turkish      palavra     English            parlor
# 3          Turkish      palavra     English            parole
# 4          Turkish      palavra     English            polari
# ...            ...          ...         ...               ...
# 141255     Turkish  laparoskopi     English     laparoscopist
# 141256     Turkish  laparoskopi     English  hydrolaparoscopy
# 141257     Turkish  laparoskopi     English     relaparoscopy
# 141258     Turkish  laparoskopi     English  videolaparoscopy
# 141260     Turkish    sanayisiz     English      cyberarsenal
#
# [93313 rows x 4 columns]

# %%
df_same_ety.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result2.xlsx", index=False)

# %% [markdown]
# ##### Part 2

# %%
df_github_clean = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_clean.csv")
df_github_clean
# Out:
#                            lang         term        reltype  \
# 0                       English    thesaurus  borrowed_from
# 1                       English    thesaurus   derived_from
# 2                       English    thesaurus   doublet_with
# 3                         Latin    thesaurus   derived_from
# 4                       English  portmanteau       has_root
# ...                         ...          ...            ...
# 3484911                 English        Boell  borrowed_from
# 3484912                 English        Boell  borrowed_from
# 3484913  South Levantine Arabic       بالمية      has_affix
# 3484914  South Levantine Arabic       بالمية      has_affix
# 3484915                 English       Cooler   derived_from
#
#                    related_lang  related_term
# 0                         Latin     thēsaurus
# 1                 Ancient Greek      θησαυρός
# 2                       English      treasure
# 3                 Ancient Greek      θησαυρός
# 4           Proto-Indo-European  *per- (fare)
# ...                         ...           ...
# 3484911                  Danish          Bøll
# 3484912                  German          Böll
# 3484913  South Levantine Arabic            بـ
# 3484914  South Levantine Arabic        الميّة
# 3484915                  German        Kühler
#
# [3484916 rows x 5 columns]

# %%
#lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
#lang_2 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang1_lang2 = df_github_clean[(df_github_clean["lang"] == f"{lang_1.capitalize()}") & (df_github_clean["related_lang"] == f"{lang_2.capitalize()}")]
df_lang1_lang2["term"] = df_lang1_lang2["term"].apply(lambda x: low_func(x))
df_lang1_lang2["related_term"] = df_lang1_lang2["related_term"].apply(lambda x: low_func(x))
df_lang1_lang2.reset_index(drop=True, inplace=True)
df_lang1_lang2
# Out:
# <ipython-input-150-4ffe8c9e6183>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_lang2["term"] = df_lang1_lang2["term"].apply(lambda x: x.lower())
# <ipython-input-150-4ffe8c9e6183>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_lang2["related_term"] = df_lang1_lang2["related_term"].apply(lambda x: x.lower())
#         lang         term                    reltype related_lang  \
# 0    Turkish        abide  etymologically_related_to      English
# 1    Turkish          bit              borrowed_from      English
# 2    Turkish          bit  etymologically_related_to      English
# 3    Turkish         port              borrowed_from      English
# 4    Turkish          dvd               derived_from      English
# ..       ...          ...                        ...          ...
# 230  Turkish        sayko               derived_from      English
# 231  Turkish  laparoskopi               derived_from      English
# 232  Turkish       intörn              borrowed_from      English
# 233  Turkish        filiz                 cognate_of      English
# 234  Turkish      metelik                 cognate_of      English
#
#      related_term
# 0        monument
# 1             bit
# 2    binary digit
# 3            port
# 4             dvd
# ..            ...
# 230        psycho
# 231   laparoscopy
# 232        intern
# 233       phyllis
# 234      metallic
#
# [235 rows x 5 columns]

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"related_term"}, inplace=True)
#df_word

# %%
#df_lang1_lang2 = pd.merge(df_lang1_lang2,df_word, how="inner", on="related_term")
#df_lang1_lang2

# %%
df_lang1_lang2["term"].nunique()
# Out:
# 228

# %%
df_lang1_lang2.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result3.xlsx", index=False)

# %% [markdown]
# ##### Part 3

# %%
df_github_cross = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_cross_check2.csv")
df_github_cross
# Out:
#                         term_id     lang      term                    reltype  \
# 0        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra             inherited_from
# 1        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 2        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 3        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 4        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# ...                         ...      ...       ...                        ...
# 8854119  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa             inherited_from
# 8854120  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854121  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854122  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854123  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa                 cognate_of
#
#                 related_term_id    related_lang related_term
# 0        9w90qvZDUH-2OHPVZEGJSQ  Middle english       parlai
# 1        Uy6v5wWuW6KGH4aTqGWnmA      Old french       parler
# 2        HY24XyCcUZCYSa1Q6y2kPA      Late latin     parabolō
# 3        uXGtk5g-W8G_TlTxSHImpg           Latin     parabola
# 4        JHVmHqAPXEq-YaIbd0B5Jg   Ancient greek     παραβολή
# ...                         ...             ...          ...
# 8854119  TUnsO83vXXC1Us5rJgGyUg    Vulgar latin    *pittitus
# 8854120  oUnwLLsHVymmwwiRXgrRow           Latin     pitinnus
# 8854121  IGRZaHQ-VU-vpxMjdxSTlA           Latin      pitulus
# 8854122  MDRrWciZWXGEj1KR9MUWtg           Latin     piccinus
# 8854123  SUJISOECWc6fDH00I_cTRQ          French        petit
#
# [8854124 rows x 7 columns]

# %%
#lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
#lang_2 = "Portuguese"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang_pair2 = df_github_cross[(df_github_cross["lang"] == f"{lang_1.capitalize()}") & (df_github_cross["related_lang"] == f"{lang_2.capitalize()}")]
df_lang_pair2.drop_duplicates(inplace=True)
df_lang_pair2.reset_index(drop=True, inplace=True)
df_lang_pair2
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                     term_id     lang           term  \
# 0    5bVUD53NVEWYY0QAetV7iA  Turkish            net
# 1    5bVUD53NVEWYY0QAetV7iA  Turkish            net
# 2    ZZOXAtMCUAOdIhVk2GVPBQ  Turkish         beygir
# 3    zsF2dCDXX6KSQ9g8AMUvag  Turkish           spor
# 4    xLZa_YWsVeKC5MhzBBk_9w  Turkish         kokain
# ..                      ...      ...            ...
# 518  iA4F_qb-Xki4qznAYuk4Xg  Turkish      centilmen
# 519  iA4F_qb-Xki4qznAYuk4Xg  Turkish      centilmen
# 520  vGZ-kjFgW9CHWeNEKFVSiA  Turkish  haber spikeri
# 521  vw44cjfCVtmYWrwH05qbGQ  Turkish  radyo spikeri
# 522  vw44cjfCVtmYWrwH05qbGQ  Turkish  radyo spikeri
#
#                        reltype         related_term_id related_lang  \
# 0    etymologically_related_to  I8ZPn9fJXNKweD-cX1O0xg      English
# 1    etymologically_related_to  GRMNBzJoUrS1D5tF0_FCIg      English
# 2                borrowed_from  BCJ2Aan0W4qdgexddz6FWw      English
# 3                borrowed_from  -k3OXSrGV5CeduqN0Ho1iQ      English
# 4         has_prefix_with_root  fu_Xx5uiU5WYWyTb0KHWWQ      English
# ..                         ...                     ...          ...
# 518                compound_of  -G1a431-Uk-h6aAMTueLUA      English
# 519                compound_of  7iNxSR4wXuKM7buAqExYqg      English
# 520              borrowed_from  WVJfkWdhXFKG3yQdn2uhAQ      English
# 521               derived_from  -UAbZ0GkUDSPBZR9I8xm9A      English
# 522              borrowed_from  WVJfkWdhXFKG3yQdn2uhAQ      English
#
#     related_term
# 0          nitid
# 1           neat
# 2            bar
# 3          sport
# 4           coca
# ..           ...
# 518       gentle
# 519          man
# 520      speaker
# 521        radio
# 522      speaker
#
# [523 rows x 7 columns]

# %%
df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: low_func(x))
df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: low_func(x))
# Out:
# <ipython-input-158-23b9c833e872>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: x.lower())
# <ipython-input-158-23b9c833e872>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: x.lower())

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"related_term"}, inplace=True)
#df_word

# %%
#df_lang_pair2 = pd.merge(df_lang_pair2,df_word, how="inner", on="related_term")
#df_lang_pair2

# %%
df_lang_pair2 = df_lang_pair2[(df_lang_pair2["reltype"] == "cognate_of") | (df_lang_pair2["reltype"] == "etymologically_related_to") | (df_lang_pair2["reltype"] == "derived_from") | (df_lang_pair2["reltype"] == "borrowed_from")]
df_lang_pair2 = df_lang_pair2.loc[:,["lang","term","reltype","related_lang","related_term"]]
df_lang_pair2.reset_index(drop=True, inplace=True)
df_lang_pair2
# Out:
#         lang           term                    reltype related_lang  \
# 0    Turkish            net  etymologically_related_to      English
# 1    Turkish            net  etymologically_related_to      English
# 2    Turkish         beygir              borrowed_from      English
# 3    Turkish           spor              borrowed_from      English
# 4    Turkish           blok  etymologically_related_to      English
# ..       ...            ...                        ...          ...
# 347  Turkish          poşet                 cognate_of      English
# 348  Turkish    materyalizm               derived_from      English
# 349  Turkish  haber spikeri              borrowed_from      English
# 350  Turkish  radyo spikeri               derived_from      English
# 351  Turkish  radyo spikeri              borrowed_from      English
#
#     related_term
# 0          nitid
# 1           neat
# 2            bar
# 3          sport
# 4           balk
# ..           ...
# 347       pocket
# 348  materialism
# 349      speaker
# 350        radio
# 351      speaker
#
# [352 rows x 5 columns]

# %%
df_lang_pair2["term"].nunique()
# Out:
# 247

# %%
df_lang_pair2.to_excel(f"{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result4.xlsx", index=False)
