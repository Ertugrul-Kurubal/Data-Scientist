# %% [markdown]
# ### Web Scrapping

# %%
# !pip install --upgrade pip
# !pip install beautifulsoup4 --upgrade
# pip install lxml
# pip install html5lib

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
from json2html import *
import re
import requests
from urllib.request import Request, urlopen
from urllib import parse

# %% [markdown]
# #### Amazon

# %%
response = requests.get("https://www.amazon.com.tr/gp/bestsellers/electronics/13709880031/ref=zg_bs_nav_electronics_1")
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="tr-tr">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:aui-assets -->
# ...

# %%
products = soup.find_all('div', attrs={'class':'zg-grid-general-faceout'})

# %%
products
# Out:
# [<div class="zg-grid-general-faceout"><div><a class="a-link-normal" href="/TTEC-2Dk7508B-Iphone-Kablosu-Beyaz/dp/B07B9WHNLR/ref=zg_bs_13709880031_1/000-0000000-0000000?pd_rd_i=B07B9WHNLR&amp;psc=1" role="link" tabindex="-1"><div class="a-section a-spacing-mini _p13n-zg-list-grid-desktop_maskStyle_noop__3Xbw5"><img alt="ttec iPh. Şarj Kablosu- Beyaz" class="a-dynamic-image p13n-sc-dynamic-image p13n-product-image" data-a-dynamic-image='{"https://images-eu.ssl-images-amazon.com/images/I/31f2da-n1cL._AC_UL302_SR302,200_.jpg":[302,200],"https://images-eu.ssl-images-amazon.com/images/I/31f2da-n1cL._AC_UL604_SR604,400_.jpg":[604,400],"https://images-eu.ssl-images-amazon.com/images/I/31f2da-n1cL._AC_UL906_SR906,600_.jpg":[906,600]}' height="200px" src="https://images-eu.ssl-images-amazon.com/images/I/31f2da-n1cL._AC_UL302_SR302,200_.jpg" style="max-width:302px;max-height:200px"/></div></a><a class="a-link-normal" href="/TTEC-2Dk7508B-Iphone-Kablosu-Beyaz/dp/B07B9WHNLR/ref=zg_bs_13709880031_
# ...

# %%
link_list = []
for i in products:
    link_parse = i.find('a', attrs={'class':'a-link-normal'})
    link = link_parse.get("href")
    link_list.append('https://www.amazon.com.tr'+f'{link}')
    print(link)
# Out:
# /TTEC-2Dk7508B-Iphone-Kablosu-Beyaz/dp/B07B9WHNLR/ref=zg_bs_13709880031_1/000-0000000-0000000?pd_rd_i=B07B9WHNLR&psc=1
# /Apple-AirPods-Bluetooth-Kulakl%C4%B1k-Garantili/dp/B07QB4FG6B/ref=zg_bs_13709880031_2/000-0000000-0000000?pd_rd_i=B07QB4FG6B&psc=1
# /General-Mobile-Turbo-Adapt%C3%B6r%C3%BC-Adapt%C3%B6r/dp/B07NW73HCM/ref=zg_bs_13709880031_3/000-0000000-0000000?pd_rd_i=B07NW73HCM&psc=1
# /ttec-Micro-Usb-Kablosu-2DK7530B/dp/B081S8GJVQ/ref=zg_bs_13709880031_4/000-0000000-0000000?pd_rd_i=B081S8GJVQ&psc=1
# /Kioxia-Exceria-Class-MicroSD-Haf%C4%B1za/dp/B088X252DK/ref=zg_bs_13709880031_5/000-0000000-0000000?pd_rd_i=B088X252DK&psc=1
# /Apple-MMTN2TU-Lightning-Konnekt%C3%B6rl%C3%BC-Kulakl%C4%B1k/dp/B07B9WNSSF/ref=zg_bs_13709880031_6/000-0000000-0000000?pd_rd_i=B07B9WNSSF&psc=1
# /Apple-MME73TU-A-AirPods-3-nesil/dp/B09JR8K6HJ/ref=zg_bs_13709880031_7/000-0000000-0000000?pd_rd_i=B09JR8K6HJ&psc=1
# ...

# %%
link_list
# Out:
# ['https://www.amazon.com.tr/TTEC-2Dk7508B-Iphone-Kablosu-Beyaz/dp/B07B9WHNLR/ref=zg_bs_13709880031_1/000-0000000-0000000?pd_rd_i=B07B9WHNLR&psc=1',
#  'https://www.amazon.com.tr/Apple-AirPods-Bluetooth-Kulakl%C4%B1k-Garantili/dp/B07QB4FG6B/ref=zg_bs_13709880031_2/000-0000000-0000000?pd_rd_i=B07QB4FG6B&psc=1',
#  'https://www.amazon.com.tr/General-Mobile-Turbo-Adapt%C3%B6r%C3%BC-Adapt%C3%B6r/dp/B07NW73HCM/ref=zg_bs_13709880031_3/000-0000000-0000000?pd_rd_i=B07NW73HCM&psc=1',
#  'https://www.amazon.com.tr/ttec-Micro-Usb-Kablosu-2DK7530B/dp/B081S8GJVQ/ref=zg_bs_13709880031_4/000-0000000-0000000?pd_rd_i=B081S8GJVQ&psc=1',
#  'https://www.amazon.com.tr/Kioxia-Exceria-Class-MicroSD-Haf%C4%B1za/dp/B088X252DK/ref=zg_bs_13709880031_5/000-0000000-0000000?pd_rd_i=B088X252DK&psc=1',
#  'https://www.amazon.com.tr/Apple-MMTN2TU-Lightning-Konnekt%C3%B6rl%C3%BC-Kulakl%C4%B1k/dp/B07B9WNSSF/ref=zg_bs_13709880031_6/000-0000000-0000000?pd_rd_i=B07B9WNSSF&psc=1',
# ...

# %%
df_link = pd.DataFrame(link_list)
df_link
# Out:
#                                                     0
# 0   https://www.amazon.com.tr/TTEC-2Dk7508B-Iphone...
# 1   https://www.amazon.com.tr/Apple-AirPods-Blueto...
# 2   https://www.amazon.com.tr/General-Mobile-Turbo...
# 3   https://www.amazon.com.tr/ttec-Micro-Usb-Kablo...
# 4   https://www.amazon.com.tr/Kioxia-Exceria-Class...
# 5   https://www.amazon.com.tr/Apple-MMTN2TU-Lightn...
# 6   https://www.amazon.com.tr/Apple-MME73TU-A-AirP...
# 7   https://www.amazon.com.tr/Samsung-SM-M127F-Gal...
# 8   https://www.amazon.com.tr/JBL-510BT-Connect-Wi...
# 9   https://www.amazon.com.tr/Kioxia-Exceria-Micro...
# 10  https://www.amazon.com.tr/Baseus-Speed-Cihaz%C...
# 11  https://www.amazon.com.tr/Spigen-F210-Cihaz%C4...
# 12  https://www.amazon.com.tr/Hypergear-15101-Tekl...
# 13  https://www.amazon.com.tr/Anker-PowerCore-2000...
# 14  https://www.amazon.com.tr/Telefon-Numaras%C4%B...
# 15  https://www.amazon.com.tr/JBL-T110-Kulak-Kulak...
# ...

# %%
result_title = soup.title
result_title
# Out:
# <title>Amazon.com.tr Çok Satanlar: Cep Telefonları ve Aksesuarlar adlı listedeki en popüler ürünler</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# 'Amazon.com.tr Çok Satanlar: Cep Telefonları ve Aksesuarlar adlı listedeki en popüler ürünler'

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.get_text()
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAmazon.com.tr Çok Satanlar: Cep Telefonları ve Aksesuarlar adlı listedeki en popüler ürünler\n\n\n\n\n\n\n\n\n\nÇerez Tercihlerinizi SeçinÇerez Bildirimimizde ayrıntılı şekilde açıklandığı üzere alışveriş yapmanızı sağlamak, alışveriş deneyiminizi iyileştirmek ve hizmetlerimizi sunmak için gerekli olan çerezleri ve benzer araçları kullanırız. Ayrıca, bu çerezleri müşterilerin hizmetlerimizi nasıl kullandıklarını anlamak (örneğin, site ziyaretlerini ölçerek) ve böylece iyileştirmeler yapabilmek için kullanıyoruz.\nKabul ederseniz, Çerez Bildirimimizde açıklandığı üzere, Amazon mağazalarındaki alışveriş deneyiminizin tamamlayıcısı olarak da çerezleri kullanacağız. Buna, benzersiz tanımlayıcı gibi standart cihaz bilgilerini depolayan veya bunlara erişen birinci ve üçüncü taraf çerezlerinin kullanılması dahildir. Üçüncü taraflar, kişiselleştirilmiş reklamları görüntülemek ve ölçmek, hedef kitle içgörüleri oluşturmak ve ürünleri geliş
# ...

# %%
soup.get_attribute_list('div')
# Out:
# [None]

# %% [markdown]
# #### Quaran

# %%
url = "https://quranwbw.com/35"
headers = {'User-Agent':'Chrome/98.0.4758.102'}

# %%
response = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(response.content, 'html.parser')
#soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script type="text/javascript">
#    var url_split = window.location.pathname.split('/'); var surah_number = url_split[url_split.length - 1]; if(surah_number.match(/^-{0,1}\d+$/)) { surah_number = parseInt(surah_number); if(surah_number < 1 || surah_number > 114) window.location = "./"; } else window.location = "./";
#   </script>
#   <title>
#    Quran WBW - Word By Word Translation And Transliteration In English, Urdu, Hindi, Indonesian, Bangla, Turkish, Russian, German And Ingush
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="Read The Holy Quran Through Word By Word Translation And Transliteration In English, Urdu, Hindi, Indonesian, Bangla, Turkish, Russian, German And Ingush" name="description"/>
# ...

# %%
ayah_word = soup.findAll('div', attrs={"class":"ayahs-block"})
ayah_word
# Out:
# [<div class="ayahs-block"></div>]

# %% [markdown]
# #### External HTML File From Browser Element Section

# %%
# !pip install --upgrade pip
# !pip install beautifulsoup4 --upgrade
# pip install lxml
# pip install html5lib

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
from json2html import *
import re
import requests
from urllib.request import Request, urlopen
from urllib import parse

# %%
file = "faatir"

# %%
HTMLFile = open(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Arabic/Quaran/Web Scrapping/Data/{file.lower()}.html", "r") # ayahs-block

# %%
content = HTMLFile.read()

# %%
soup = BeautifulSoup(content, 'lxml')

# %%
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <div class="ayahs-block">
#    <div class="ayah-1 ayah-single 35" id="1">
#     <div class="row ayah-row">
#      <div class="col-1 ayah-buttons">
#       <span class="ayah-block-buttons ayah-number-button">
#        Ayah 1
#       </span>
#       <span class="ayah-block-buttons play-ayah-button">
#        Play Ayah
#       </span>
#       <span class="ayah-block-buttons stop-recitation-button" style="display: none;">
#        Stop Recitation
#       </span>
#      </div>
#      <div class="col-10 single-ayah 1">
#       <span class="single-word" data-ts="" id="35-1-1">
#        <span class="word-arabic word-arabic-uthmani-hafs" style="display: inline-block;">
#         ٱلۡحَمۡدُ
#        </span>
#        <span class="word-transliteration">
#         al-hamdu
#        </span>
#        <span class="word-translation">
#         hamd olsun
#        </span>
#       </span>
#       <span class="single-word" data-ts="" id="35-1-2">
# ...

# %%
ayah_word = soup.findAll('span', attrs={"class":"single-word"})
ayah_word
# Out:
# [<span class="single-word" data-ts="" id="35-1-1"><span class="word-arabic word-arabic-uthmani-hafs" style="display: inline-block;">ٱلۡحَمۡدُ</span> <span class="word-transliteration">al-hamdu</span><span class="word-translation">hamd olsun</span></span>,
#  <span class="single-word" data-ts="" id="35-1-2"><span class="word-arabic word-arabic-uthmani-hafs" style="display: inline-block;">لِلَّهِ</span> <span class="word-transliteration">lillahi</span><span class="word-translation">Allah'a</span></span>,
#  <span class="single-word" data-ts="" id="35-1-3"><span class="word-arabic word-arabic-uthmani-hafs" style="display: inline-block;">فَاطِرِ</span> <span class="word-transliteration">fatiri</span><span class="word-translation">yoktan var eden</span></span>,
# ...

# %%
word_list = []
for word in ayah_word:
    var1 = word.find('span', attrs={"class":"word-arabic word-arabic-uthmani-hafs"})
    #try:
    #    var1_list = re.findall(r'''(?<=>)(.*)(?=</span>)''', var1)
    #    arabic=" ".join(var1_list)
    #except:
    #    pass
    #arabic = var1.get_text()
    arabic = var1.string
    var2 = word.find('span', attrs={"class":"word-transliteration"})
    transliterate = var2.string
    var3 = word.find('span', attrs={"class":"word-translation"})
    translate = var3.string
    word_list.append((arabic, transliterate, translate))

# %%
word_list
# Out:
# [('ٱلۡحَمۡدُ', 'al-hamdu', 'hamd olsun'),
#  ('لِلَّهِ', 'lillahi', "Allah'a"),
#  ('فَاطِرِ', 'fatiri', 'yoktan var eden'),
#  ('ٱلسَّمَٰوَٰتِ', 'al-samawati', 'gökleri'),
#  ('وَٱلۡأَرۡضِ', 'wal-ardi', 've yeri'),
#  ('جَاعِلِ', "ja'ili", 'yapan'),
#  ('ٱلۡمَلَـٰٓئِكَةِ', 'al-malaikati', 'melekleri'),
#  ('رُسُلًا', 'rusulan', 'elçiler'),
#  ('أُوْلِيٓ', 'uli', 'sahibi'),
#  ('أَجۡنِحَةٖ', 'ajnihatin', 'kanatlar'),
#  ('مَّثۡنَىٰ', 'mathna', 'ikişer'),
#  ('وَثُلَٰثَ', 'wathulatha', 've üçer'),
#  ('وَرُبَٰعَۚ', "waruba'a", 've dörder'),
#  ('يَزِيدُ', 'yazidu', 'artırır'),
#  ('فِي', 'fi', 'yaratmada'),
#  ('ٱلۡخَلۡقِ', 'al-khalqi', '*'),
#  ('مَا', 'ma', 'ne kadar'),
#  ('يَشَآءُۚ', 'yashau', 'dilerse'),
#  ('إِنَّ', 'inna', 'şüphesiz'),
#  ('ٱللَّهَ', 'al-laha', 'Allah'),
#  ('عَلَىٰ', 'ala', 'her'),
#  ('كُلِّ', 'kulli', '*'),
#  ('شَيۡءٖ', 'shayin', 'şeyi'),
#  ('قَدِيرٞ', 'qadirun', 'yapabilendir'),
#  ('مَّا', 'ma', 'ne ki'),
#  ('يَفۡتَحِ', 'yaftahi', '(Allah) açar'),
# ...

# %%
df_word_list = pd.DataFrame(word_list)
df_word_list.rename(columns={0:"arabic", 1:"transliterate", 2:"translate"}, inplace=True)
# df_word_list = df_word_list.iloc[3:,] for all body element
df_word_list
# Out:
#             arabic transliterate        translate
# 0        ٱلۡحَمۡدُ      al-hamdu       hamd olsun
# 1          لِلَّهِ       lillahi          Allah'a
# 2          فَاطِرِ        fatiri  yoktan var eden
# 3    ٱلسَّمَٰوَٰتِ   al-samawati          gökleri
# 4      وَٱلۡأَرۡضِ      wal-ardi          ve yeri
# ..             ...           ...              ...
# 770        فَإِنَّ       fa-inna         kuşkusuz
# 771        ٱللَّهَ       al-laha            Allah
# 772          كَانَ          kana        kullarını
# 773   بِعِبَادِهِۦ    bi'ibadihi                *
# 774      بَصِيرَۢا       basiran      görmektedir
#
# [775 rows x 3 columns]

# %%
df_word_list.to_excel(f"{file.lower().capitalize()}_Arabic_Transliterate_Translate_Words.xlsx", index=False)

# %%
var = re.findall(r'''(?<=>)(.*)(?=</span>)''', test_text)
var
# Out:
# ['يَبُورُ يَبُورُ']

# %%
" ".join(var)
# Out:
# 'يَبُورُ يَبُورُ'

# %%
find_text(test_text)
# Out:
# 'يَبُورُ يَبُورُ'

# %%
df = pd.read_excel("Faatir_Yaseen_Saaffaat_Saad_Zumar_Surah_Translate_Concat.xlsx")
df
# Out:
#       surah surah latin         arabic transliterate    translate_english  \
# 0        35       Fatir      ٱلۡحَمۡدُ      al-hamdu          All praises
# 1        35       Fatir        لِلَّهِ       lillahi        (be) to Allah
# 2        35       Fatir        فَاطِرِ        fatiri              Creator
# 3        35       Fatir  ٱلسَّمَٰوَٰتِ   al-samawati     (of) the heavens
# 4        35       Fatir    وَٱلۡأَرۡضِ      wal-ardi        and the earth
# ...     ...         ...            ...           ...                  ...
# 4260     39    Az-Zumar        وَقِيلَ        waqila  and it will be said
# 4261     39    Az-Zumar      ٱلۡحَمۡدُ      al-hamdu        All praise be
# 4262     39    Az-Zumar        لِلَّهِ       lillahi             to Allah
# 4263     39    Az-Zumar          رَبِّ         rabbi           (the) Lord
# 4264     39    Az-Zumar  ٱلۡعَٰلَمِينَ   al-'alamina      (of) the worlds
#
#            translate_urdu    translate_hindi translate_indonesian  \
# ...

# %%
df["translate_turkish"]
# Out:
# 0               All praises
# 1             (be) to Allah
# 2                   Creator
# 3          (of) the heavens
# 4             and the earth
#                ...
# 4260    and it will be said
# 4261          All praise be
# 4262               to Allah
# 4263             (the) Lord
# 4264        (of) the worlds
# Name: translate_english, Length: 4265, dtype: object

# %%
df[df["translate_turkish"] == "&"]
# Out:
#       surah surah latin       arabic transliterate   translate_english  \
# 15       35       Fatir    ٱلۡخَلۡقِ     al-khalqi        the creation
# 21       35       Fatir        كُلِّ         kulli               every
# 29       35       Fatir    رَّحۡمَةٖ      rahmatin               Mercy
# 39       35       Fatir   بَعۡدِهِۦۚ       ba'dihi          thereafter
# 53       35       Fatir      ٱللَّهِ       al-lahi  other (than) Allah
# ...     ...         ...          ...           ...                 ...
# 4168     39    Az-Zumar  يَفۡعَلُونَ    yaf 'aluna             they do
# 4173     39    Az-Zumar    جَهَنَّمَ     jahannama                Hell
# 4184     39    Az-Zumar   يَأۡتِكُمۡ       yatikum         come to you
# 4217     39    Az-Zumar   ٱلۡجَنَّةِ     al-janati            Paradise
# 4252     39    Az-Zumar       حَوۡلِ         hawli              around
#
#           translate_urdu     translate_hindi translate_indonesian  \
# ...

# %%
df["translate_turkish"] = df["translate_turkish"].apply(lambda x: x.replace("*", "&"))
df
# Out:
#       surah surah latin         arabic transliterate    translate_english  \
# 0        35       Fatir      ٱلۡحَمۡدُ      al-hamdu          All praises
# 1        35       Fatir        لِلَّهِ       lillahi        (be) to Allah
# 2        35       Fatir        فَاطِرِ        fatiri              Creator
# 3        35       Fatir  ٱلسَّمَٰوَٰتِ   al-samawati     (of) the heavens
# 4        35       Fatir    وَٱلۡأَرۡضِ      wal-ardi        and the earth
# ...     ...         ...            ...           ...                  ...
# 4260     39    Az-Zumar        وَقِيلَ        waqila  and it will be said
# 4261     39    Az-Zumar      ٱلۡحَمۡدُ      al-hamdu        All praise be
# 4262     39    Az-Zumar        لِلَّهِ       lillahi             to Allah
# 4263     39    Az-Zumar          رَبِّ         rabbi           (the) Lord
# 4264     39    Az-Zumar  ٱلۡعَٰلَمِينَ   al-'alamina      (of) the worlds
#
#            translate_urdu    translate_hindi translate_indonesian  \
# ...

# %%
df["translate_hindi"] = df["translate_hindi"].apply(lambda x: x.replace("*", "&"))
df
# Out:
#       surah surah latin         arabic transliterate    translate_english  \
# 0        35       Fatir      ٱلۡحَمۡدُ      al-hamdu          All praises
# 1        35       Fatir        لِلَّهِ       lillahi        (be) to Allah
# 2        35       Fatir        فَاطِرِ        fatiri              Creator
# 3        35       Fatir  ٱلسَّمَٰوَٰتِ   al-samawati     (of) the heavens
# 4        35       Fatir    وَٱلۡأَرۡضِ      wal-ardi        and the earth
# ...     ...         ...            ...           ...                  ...
# 4260     39    Az-Zumar        وَقِيلَ        waqila  and it will be said
# 4261     39    Az-Zumar      ٱلۡحَمۡدُ      al-hamdu        All praise be
# 4262     39    Az-Zumar        لِلَّهِ       lillahi             to Allah
# 4263     39    Az-Zumar          رَبِّ         rabbi           (the) Lord
# 4264     39    Az-Zumar  ٱلۡعَٰلَمِينَ   al-'alamina      (of) the worlds
#
#            translate_urdu    translate_hindi translate_indonesian  \
# ...

# %%
df["translate_russian"] = df["translate_russian"].apply(lambda x: x.replace("*", "&"))
df
# Out:
#       surah surah latin         arabic transliterate    translate_english  \
# 0        35       Fatir      ٱلۡحَمۡدُ      al-hamdu          All praises
# 1        35       Fatir        لِلَّهِ       lillahi        (be) to Allah
# 2        35       Fatir        فَاطِرِ        fatiri              Creator
# 3        35       Fatir  ٱلسَّمَٰوَٰتِ   al-samawati     (of) the heavens
# 4        35       Fatir    وَٱلۡأَرۡضِ      wal-ardi        and the earth
# ...     ...         ...            ...           ...                  ...
# 4260     39    Az-Zumar        وَقِيلَ        waqila  and it will be said
# 4261     39    Az-Zumar      ٱلۡحَمۡدُ      al-hamdu        All praise be
# 4262     39    Az-Zumar        لِلَّهِ       lillahi             to Allah
# 4263     39    Az-Zumar          رَبِّ         rabbi           (the) Lord
# 4264     39    Az-Zumar  ٱلۡعَٰلَمِينَ   al-'alamina      (of) the worlds
#
#            translate_urdu    translate_hindi translate_indonesian  \
# ...

# %%
df.to_excel("Faatir_Yaseen_Saaffaat_Saad_Zumar_Surah_Translate_Concat2.xlsx", index=False)

# %%
a = "ali ata"

# %%
a.replace("ata", "at")
# Out:
# 'ali at'

# %% [markdown]
# #### Etimology
