# %% [markdown]
# ### Etymology Cross Check

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### Etymologeek Result

# %%
lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian 
lang_2 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
if lang_2 == "English":
    lang_3 = "English (eng)"
elif lang_2 == "Turkish":
    lang_3 = "Turkish (tur)"
elif lang_2 == "German":
    lang_3 = "German (deu)"
elif lang_2 == "French":
    lang_3 = "French (fra)"
elif lang_2 == "Spanish":
    lang_3 = "Spanish (spa)"
elif lang_2 == "Arabic":
    lang_3 = "Arabic (ara)"
elif lang_2 == "Russian":
    lang_3 = "Russian (rus)"
elif lang_2 == "Portuguese":
    lang_3 = "Portuguese (por)"
elif lang_2 == "Dutch":
    lang_3 = "Dutch (nld)"
elif lang_2 == "Italian":
    lang_3 = "Italian (ita)"
else:
    pass
#lang_3 = "English (eng)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)
print(f"{lang_1}\n{lang_2}\n{lang_3}")
# Out:
# English
# Turkish
# Turkish (tur)

# %%
lang_1_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_1.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_1_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Russian (rus)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Turkish (tur)_Etymologeek_Result1.xlsx']

# %%
df_lang_1 = pd.DataFrame()
for i in lang_1_file:
    df_var = pd.read_excel(f"{i}")
    df_lang_1 = pd.concat([df_lang_1,df_var], axis=0)
    df_lang_1.reset_index(drop=True, inplace=True)
df_lang_1
# Out:
#      search_word dict_entry_main language_main  \
# 0           aman         amanaty       English
# 1          sakin          sakina       English
# 2          cevap          cevapi       English
# 3           hale          haleem       English
# 4            dua             dua       English
# ...          ...             ...           ...
# 3033       marta        martagon       English
# 3034        lahm        lahmacun       English
# 3035        caza            caza       English
# 3036     chagrin         chagrin       English
# 3037       gilet           gilet       English
#
#                                         definition_main dict_entry  \
# 0     (Noun) (historical) Native American hostages t...   أَمَانَة
# 1     (Noun) (Islam) the divine tranquility obtained...   سَكِينَة
# 2     (Noun) A Balkan food dish of minced meat.A Bal...     كَبَاب
# 3     (Noun) A stew-like dish traditionally consisti...     حَلِيم
# 4     (Noun) (Islam) An Islamic invocation.(Islam) A...      دَعَا
# ...                                                 ...        ...
# 3033            (Noun) A Eurasian lily.A Eurasian lily.   martagan
# 3034  (Noun) A dish of Arab origin consisting of a r...   lahmacun
# 3035  (Noun) A Turkish provincial subdivision.A Turk...       kaza
# 3036  (Verb Noun) (intransitive) To be vexed or anno...      sağrı
# 3037  (Noun) A sleeveless jacket similar to a waistc...      yelek
#
#            language                                         definition
# 0      Arabic (ara)                                                NaN
# 1      Arabic (ara)                                                NaN
# 2      Arabic (ara)                                                NaN
# 3      Arabic (ara)                                                NaN
# 4      Arabic (ara)                                                NaN
# ...             ...                                                ...
# 3033  Turkish (tur)                                                NaN
# 3034  Turkish (tur)                                          Lahmacun.
# 3035  Turkish (tur)                                          Accident.
# 3036  Turkish (tur)  The chubby and round part of a mammal's body b...
# 3037  Turkish (tur)                           Jelick. Waistcoat, vest.
#
# [3038 rows x 7 columns]

# %%
lang_2_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_2.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_2_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_German (deu)_Etymologeek_Result1.xlsx']

# %%
df_lang_2 = pd.DataFrame()
for i in lang_2_file:
    df_var2 = pd.read_excel(f"{i}")
    df_lang_2 = pd.concat([df_lang_2,df_var2], axis=0)
    df_lang_2.reset_index(drop=True, inplace=True)
df_lang_2
# Out:
#      search_word dict_entry_main language_main  \
# 0           şans            şans       Turkish
# 1           loca            loca       Turkish
# 2             mı        mıknatıs       Turkish
# 3             mı          mısdak       Turkish
# 4            şey             şey       Turkish
# ..           ...             ...           ...
# 732       vermut          vermut       Turkish
# 733       panzer          panzer       Turkish
# 734  tonymayster     tonymayster       Turkish
# 735      filinta         filinta       Turkish
# 736       kuvars          kuvars       Turkish
#
#                                        definition_main   dict_entry  \
# 0                  (Noun) Fortune. Luck.Fortune. Luck.         dice
# 1    (Noun) (masonic) lodge. Box (in theaters).(mas...       laubja
# 2                                (Noun) Magnet.Magnet.  مِغْنَاطِيس
# 3    (Noun) (obsolete) criterion.(obsolete) criterion.     مِصْدَاق
# 4    (Noun Interjection) (slang) genital organ. Thi...      شَيْئاً
# ..                                                 ...          ...
# 732                                             (Noun)       wermut
# 733                                             (Noun)       panzer
# 734                                             (Noun)   tonmeister
# 735                                             (Noun)       flinte
# 736                                             (Noun)        quarz
#
#          language                                         definition
# 0     Dutch (nld)                                                NaN
# 1     Dutch (nld)                                                NaN
# 2    Arabic (ara)                                                NaN
# 3    Arabic (ara)                                                NaN
# 4    Arabic (ara)                                                NaN
# ..            ...                                                ...
# 732  German (deu)  Vermouth is an aromatized fortified wine, flav...
# 733  German (deu)  A tank is an armoured fighting vehicle intende...
# 734  German (deu)                                         Tonmeister
# 735  German (deu)                                             Flinte
# 736  German (deu)  Quartz is a hard, crystalline mineral composed...
#
# [737 rows x 7 columns]

# %%
set_lang_11 = set(df_lang_1["dict_entry"])

# %%
set_lang_12 = set(df_lang_2["dict_entry"])

# %%
df_cross = pd.DataFrame(set_lang_11.intersection(set_lang_12), columns=["dict_entry"])
df_cross
# Out:
#      dict_entry
# 0        vision
# 1           pur
# 2    téléphoner
# 3         lycée
# 4       million
# ..          ...
# 114      مُدِير
# 115        شَاه
# 116     قَانُون
# 117        sala
# 118     campaña
#
# [119 rows x 1 columns]

# %%
df_lang_1_cross = pd.merge(df_cross,df_lang_1,how="inner", on="dict_entry")
df_lang_1_cross.drop_duplicates(inplace=True)
df_lang_1_cross = df_lang_1_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_1_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master"}, inplace=True)
df_lang_1_cross
# Out:
#     lang_master     term_master dict_entry
# 0       English  midnight movie     vision
# 1       English    talking head     vision
# 2       English      television     vision
# 3       English            pure        pur
# 4       English            puro        pur
# ..          ...             ...        ...
# 172     English           kanun    قَانُون
# 173     English           salon       sala
# 174     English       champagne    campaña
# 175     English        campaign    campaña
# 176     English        campagna    campaña
#
# [177 rows x 3 columns]

# %%
df_lang_2_cross = pd.merge(df_cross,df_lang_2,how="inner", on="dict_entry")
df_lang_2_cross.drop_duplicates(inplace=True)
df_lang_2_cross = df_lang_2_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_2_cross.rename(columns={"language_main":"lang_sleeve","dict_entry_main":"term_sleeve"}, inplace=True)
df_lang_2_cross
# Out:
#     lang_sleeve term_sleeve  dict_entry
# 0       Turkish  televizyon      vision
# 1       Turkish        puro         pur
# 2       Turkish     telefon  téléphoner
# 3       Turkish        lise       lycée
# 4       Turkish    milyoner     million
# ..          ...         ...         ...
# 123     Turkish       müdür      مُدِير
# 124     Turkish         çek        شَاه
# 125     Turkish       kanun     قَانُون
# 126     Turkish       salon        sala
# 127     Turkish    şampanya     campaña
#
# [128 rows x 3 columns]

# %%
df_lang_1_lang_2_cross = pd.merge(df_lang_1_cross,df_lang_2_cross, how="inner", on="dict_entry")
df_lang_1_lang_2_cross.drop_duplicates(inplace=True)
df_lang_1_lang_2_cross = df_lang_1_lang_2_cross[["lang_master","term_master","lang_sleeve","term_sleeve"]]
df_lang_1_lang_2_cross
# Out:
#     lang_master     term_master lang_sleeve term_sleeve
# 0       English  midnight movie     Turkish  televizyon
# 1       English    talking head     Turkish  televizyon
# 2       English      television     Turkish  televizyon
# 3       English            pure     Turkish        puro
# 4       English            puro     Turkish        puro
# ..          ...             ...         ...         ...
# 189     English           kanun     Turkish       kanun
# 190     English           salon     Turkish       salon
# 191     English       champagne     Turkish    şampanya
# 192     English        campaign     Turkish    şampanya
# 193     English        campagna     Turkish    şampanya
#
# [189 rows x 4 columns]

# %%
lang_3_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/*_And_{lang_3.capitalize()}_Etymologeek_Result1.xlsx")
lang_3_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Turkish (tur)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Turkish (tur)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Turkish (tur)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_Turkish (tur)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Arabic/Arabic_And_Turkish (tur)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Russian/Russian_And_Turkish (tur)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Turkish (tur)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_Turkish (tur)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Turkish (tur)_Etymologeek_Result1.xlsx']

# %%
df_lang_3 = pd.DataFrame()
for i in lang_3_file:
    df_var3 = pd.read_excel(f"{i}")
    df_lang_3 = pd.concat([df_lang_3,df_var3], axis=0)
    df_lang_3.reset_index(drop=True, inplace=True)
df_lang_3
# Out:
#    search_word dict_entry_main language_main  \
# 0        araba           araba       English
# 1       beyler       beylerbey       English
# 2          bey             bey       English
# 3          yat        yataghan       English
# 4        ekmek   ekmek kadayif       English
# 5         vali            vali       English
# 6     kurabiye        kurabiye       English
# 7          tuz           tuzla       English
# 8         jack          jackal       English
# 9          ray           rayah       English
# 10         fez             fez       English
# 11       abras          abrash       English
# 12      caviar          caviar       English
# 13        turk          turkey       English
# 14        done           donek       English
# 15      sultan          sultan       English
# 16        soft           softa       English
# 17       marta        martagon       English
# 18        lahm        lahmacun       English
# 19        caza            caza       English
# 20     chagrin         chagrin       English
# 21       gilet           gilet       English
# 22      tschüs        tschüsch        German
# 23       anges    angeschlagen        German
# 24         yat         yatagan        French
# 25      sultan          sultan        French
# 26         bey             bey       Spanish
# 27     chaleco         chaleco       Spanish
# 28        الأن        الأناضول        Arabic
# 29         دون            دونم        Arabic
# 30         شعر             شعر        Arabic
# 31        كافي          كافيار        Arabic
# 32      caviar          caviar    Portuguese
# 33         beg             beg         Dutch
# 34      sultan          sultan         Dutch
# 35         bei             bei         Dutch
# 36        ulan           ulano       Italian
# 37         cia        ciabatta       Italian
# 38        curb       curbascio       Italian
# 39      yogurt          yogurt       Italian
# 40        scia       sciacallo       Italian
#
#                                       definition_main  dict_entry  \
# 0   (Noun) A horse-drawn carriage once used for tr...       araba
# 1   (Noun) An Ottoman administrative title.An Otto...  beylerbeyi
# 2   (Noun) (historical) A governor of a province o...         bey
# 3   (Noun) A type of sword used in Muslim countrie...     yatağan
# 4   (Noun) A Turkish bread pudding dessert, also f...     kadayıf
# 5                                             (Noun)         vali
# 6   (Noun) (rare) A cookie, particularly a sweet (...    kurabiye
# 7   (Noun) A kind of central Anatolian rug.A kind ...         tuz
# 8   (Verb Noun) To perform menial or routine tasks...       çakal
# 9   (Noun) (pejorative) A member of the tax-paying...       reaya
# 10  (Noun) A felt hat in the shape of a truncated ...         fes
# 11  (Noun) A variation in color (often applied to ...       abraş
# 12  (Noun) Roe of the sturgeon or other large fish...      havyar
# 13  (Noun) (bowling) An act of throwing three stri...    Turgutlu
# 14  (Noun) A breed of fancy pigeon.A breed of fanc...       dönek
# 15  (Noun) (card games) A variant of solitaire, pl...      sultan
# 16  (Noun) (Islam) A religious student, especially...       softa
# 17            (Noun) A Eurasian lily.A Eurasian lily.    martagan
# 18  (Noun) A dish of Arab origin consisting of a r...    lahmacun
# 19  (Noun) A Turkish provincial subdivision.A Turk...        kaza
# 20  (Verb Noun) (intransitive) To be vexed or anno...       sağrı
# 21  (Noun) A sleeveless jacket similar to a waistc...       yelek
# 22  (Interjection) (immigrant or youth, _, slang, ...         çüş
# 23          (Verb Adjective) Beleaguered.Beleaguered.  anschlagen
# 24                          (Noun) Yataghan.Yataghan.     yatağan
# 25  (Noun) A perfume sachet to put in a linen coff...      sultan
# 26                                    (Noun) Bey.Bey.         bey
# 27  (Noun) Sweater, jumper. Vest, waistcoat.Sweate...       yelek
# 28                   (Proper noun) Anatolia.Anatolia.     Anadolu
# 29                                (Noun) Dunam.Dunam.      dönmek
# 30  (Noun Noun Noun Verb) Knowing, knowledge. Noti...        شعار
# 31                              (Noun) Caviar.Caviar.      havyar
# 32                              (Noun) Caviar.Caviar.      havyar
# 33                (Noun) (historical) .(historical) .         beg
# 34  (Noun) A certain pastry. Sultan, a Muslim rule...      sultan
# 35  (Noun) (historical) bey, beg (historical Turki...         bey
# 36                    (Noun) Ulan, uhlan.Ulan, uhlan.       oğlan
# 37  (Noun) (cooking) ciabatta (flat bread). Power ...      zabata
# 38                                  (Noun) Whip.Whip.      kırbaç
# 39                              (Noun) Yogurt.Yogurt.      yoğurt
# 40  (Noun) Jackal. Looter. Profiteer.Jackal. Loote...       çakal
#
#          language                                         definition
# 0   Turkish (tur)                               Car. Carriage. Cart.
# 1   Turkish (tur)                                                NaN
# 2   Turkish (tur)          Gentleman, mister. Husband. Lord, master.
# 3   Turkish (tur)                                          Yataghan.
# 4   Turkish (tur)  A type of thin noodle used to make kanafeh pas...
# 5   Turkish (tur)                                          Governor.
# 6   Turkish (tur)                                   Cookie, biscuit.
# 7   Turkish (tur)                                  (chemistry) salt.
# 8   Turkish (tur)  (pejorative, derogatory) A detestable person, ...
# 9   Turkish (tur)                                                NaN
# 10  Turkish (tur)                                                NaN
# 11  Turkish (tur)                                                NaN
# 12  Turkish (tur)                                            Caviar.
# 13  Turkish (tur)                                                NaN
# 14  Turkish (tur)                                                NaN
# 15  Turkish (tur)  A breed of chicken originating in Turkey, kept...
# 16  Turkish (tur)  (Islam) A student of theology. (by extension) ...
# 17  Turkish (tur)                                                NaN
# 18  Turkish (tur)                                          Lahmacun.
# 19  Turkish (tur)                                          Accident.
# 20  Turkish (tur)  The chubby and round part of a mammal's body b...
# 21  Turkish (tur)                           Jelick. Waistcoat, vest.
# 22  Turkish (tur)                                                NaN
# 23  Turkish (tur)                                                NaN
# 24  Turkish (tur)                                          Yataghan.
# 25  Turkish (tur)  A breed of chicken originating in Turkey, kept...
# 26  Turkish (tur)          Gentleman, mister. Husband. Lord, master.
# 27  Turkish (tur)                           Jelick. Waistcoat, vest.
# 28  Turkish (tur)                                          Anatolia.
# 29  Turkish (tur)  To be converted to another religion. To return...
# 30  Turkish (tur)                                                NaN
# 31  Turkish (tur)                                            Caviar.
# 32  Turkish (tur)                                            Caviar.
# 33  Turkish (tur)                                                NaN
# 34  Turkish (tur)  A breed of chicken originating in Turkey, kept...
# 35  Turkish (tur)          Gentleman, mister. Husband. Lord, master.
# 36  Turkish (tur)                 (slang) catamite. Boy, male child.
# 37  Turkish (tur)                                                NaN
# 38  Turkish (tur)                                        Whip, lash.
# 39  Turkish (tur)                                            Yogurt.
# 40  Turkish (tur)  (pejorative, derogatory) A detestable person, ...

# %%
set_lang_21 = set(df_lang_1["dict_entry_main"])

# %%
set_lang_23 = set(df_lang_3["dict_entry_main"])

# %%
df_cross_2 = pd.DataFrame(set_lang_21.intersection(set_lang_23), columns=["dict_entry_main"])
df_cross_2
# Out:
#    dict_entry_main
# 0             caza
# 1              fez
# 2           turkey
# 3           caviar
# 4          chagrin
# 5            araba
# 6         yataghan
# 7            softa
# 8        beylerbey
# 9            rayah
# 10             bey
# 11        kurabiye
# 12          jackal
# 13        martagon
# 14          sultan
# 15        ciabatta
# 16          abrash
# 17            vali
# 18        lahmacun
# 19           tuzla
# 20           donek
# 21           gilet
# 22   ekmek kadayif

# %%
df_lang_1_lang_3_cross = pd.merge(df_cross_2,df_lang_3,how="inner", on="dict_entry_main")
df_lang_1_lang_3_cross.drop_duplicates(inplace=True)
df_lang_1_lang_3_cross = df_lang_1_lang_3_cross[["language_main","dict_entry_main","language","dict_entry"]]
df_lang_1_lang_3_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master","language":"lang_sleeve","dict_entry":"term_sleeve"}, inplace=True)
df_lang_1_lang_3_cross
# Out:
#    lang_master    term_master    lang_sleeve term_sleeve
# 0      English           caza  Turkish (tur)        kaza
# 1      English            fez  Turkish (tur)         fes
# 2      English         turkey  Turkish (tur)    Turgutlu
# 3      English         caviar  Turkish (tur)      havyar
# 4   Portuguese         caviar  Turkish (tur)      havyar
# 5      English        chagrin  Turkish (tur)       sağrı
# 6      English          araba  Turkish (tur)       araba
# 7      English       yataghan  Turkish (tur)     yatağan
# 8      English          softa  Turkish (tur)       softa
# 9      English      beylerbey  Turkish (tur)  beylerbeyi
# 10     English          rayah  Turkish (tur)       reaya
# 11     English            bey  Turkish (tur)         bey
# 12     Spanish            bey  Turkish (tur)         bey
# 13     English       kurabiye  Turkish (tur)    kurabiye
# 14     English         jackal  Turkish (tur)       çakal
# 15     English       martagon  Turkish (tur)    martagan
# 16     English         sultan  Turkish (tur)      sultan
# 17      French         sultan  Turkish (tur)      sultan
# 18       Dutch         sultan  Turkish (tur)      sultan
# 19     Italian       ciabatta  Turkish (tur)      zabata
# 20     English         abrash  Turkish (tur)       abraş
# 21     English           vali  Turkish (tur)        vali
# 22     English       lahmacun  Turkish (tur)    lahmacun
# 23     English          tuzla  Turkish (tur)         tuz
# 24     English          donek  Turkish (tur)       dönek
# 25     English          gilet  Turkish (tur)       yelek
# 26     English  ekmek kadayif  Turkish (tur)     kadayıf

# %%
df_lang_1_lang_2_lang_3 = pd.concat([df_lang_1_lang_2_cross,df_lang_1_lang_3_cross], axis=0)
df_lang_1_lang_2_lang_3.reset_index(drop=True, inplace=True)
df_lang_1_lang_2_lang_3["term_master"] = df_lang_1_lang_2_lang_3["term_master"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3["term_sleeve"] = df_lang_1_lang_2_lang_3["term_sleeve"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3
# Out:
#     lang_master     term_master    lang_sleeve term_sleeve
# 0       English  midnight movie        Turkish  televizyon
# 1       English    talking head        Turkish  televizyon
# 2       English      television        Turkish  televizyon
# 3       English            pure        Turkish        puro
# 4       English            puro        Turkish        puro
# ..          ...             ...            ...         ...
# 211     English        lahmacun  Turkish (tur)    lahmacun
# 212     English           tuzla  Turkish (tur)         tuz
# 213     English           donek  Turkish (tur)       dönek
# 214     English           gilet  Turkish (tur)       yelek
# 215     English   ekmek kadayif  Turkish (tur)     kadayıf
#
# [216 rows x 4 columns]

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"term_sleeve"}, inplace=True)
#df_word

# %%
#df_lang_1_lang_2_lang_3 = pd.merge(df_lang_1_lang_2_lang_3,df_word, how="inner", on="term_sleeve")
#df_lang_1_lang_2_lang_3

# %%
df_lang_1_lang_2_lang_3.to_excel(f"{lang_1.capitalize()}_And_{lang_3.capitalize()}_Etymologeek_Result5.xlsx", index=False)
