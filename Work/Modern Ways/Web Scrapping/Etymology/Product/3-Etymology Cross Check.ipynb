# %% [markdown]
# ### Etymology Cross Check

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### Etymologeek Result

# %%
lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian 
lang_2 = "Spanish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

if lang_2 == "English":
    lang_3 = "English (eng)"
elif lang_2 == "Turkish":
    lang_3 = "Turkish (tur)"
elif lang_2 == "German":
    lang_3 = "German (deu)"
elif lang_2 == "French":
    lang_3 = "French (fra)"
elif lang_2 == "Spanish":
    lang_3 = "Spanish (spa)"
elif lang_2 == "Arabic":
    lang_3 = "Arabic (ara)"
elif lang_2 == "Russian":
    lang_3 = "Russian (rus)"
elif lang_2 == "Portuguese":
    lang_3 = "Portuguese (por)"
elif lang_2 == "Dutch":
    lang_3 = "Dutch (nld)"
elif lang_2 == "Italian":
    lang_3 = "Italian (ita)"
else:
    pass
#lang_3 = "English (eng)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)
print(f"{lang_1}\n{lang_2}\n{lang_3}")
# Out:
# Turkish
# Spanish
# Spanish (spa)

# %%
#Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
lang_1_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_1.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_1_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_German (deu)_Etymologeek_Result1.xlsx']

# %%
df_lang_1 = pd.DataFrame()
for i in lang_1_file:
    df_var = pd.read_excel(f"{i}")
    df_lang_1 = pd.concat([df_lang_1,df_var], axis=0)
    df_lang_1.reset_index(drop=True, inplace=True)
df_lang_1
# Out:
#      search_word dict_entry_main language_main  \
# 0           şans            şans       Turkish
# 1           loca            loca       Turkish
# 2             mı        mıknatıs       Turkish
# 3             mı          mısdak       Turkish
# 4            şey             şey       Turkish
# ..           ...             ...           ...
# 732       vermut          vermut       Turkish
# 733       panzer          panzer       Turkish
# 734  tonymayster     tonymayster       Turkish
# 735      filinta         filinta       Turkish
# 736       kuvars          kuvars       Turkish
#
#                                        definition_main   dict_entry  \
# 0                  (Noun) Fortune. Luck.Fortune. Luck.         dice
# 1    (Noun) (masonic) lodge. Box (in theaters).(mas...       laubja
# 2                                (Noun) Magnet.Magnet.  مِغْنَاطِيس
# 3    (Noun) (obsolete) criterion.(obsolete) criterion.     مِصْدَاق
# 4    (Noun Interjection) (slang) genital organ. Thi...      شَيْئاً
# ..                                                 ...          ...
# 732                                             (Noun)       wermut
# 733                                             (Noun)       panzer
# 734                                             (Noun)   tonmeister
# 735                                             (Noun)       flinte
# 736                                             (Noun)        quarz
#
#          language                                         definition
# 0     Dutch (nld)                                                NaN
# 1     Dutch (nld)                                                NaN
# 2    Arabic (ara)                                                NaN
# 3    Arabic (ara)                                                NaN
# 4    Arabic (ara)                                                NaN
# ..            ...                                                ...
# 732  German (deu)  Vermouth is an aromatized fortified wine, flav...
# 733  German (deu)  A tank is an armoured fighting vehicle intende...
# 734  German (deu)                                         Tonmeister
# 735  German (deu)                                             Flinte
# 736  German (deu)  Quartz is a hard, crystalline mineral composed...
#
# [737 rows x 7 columns]

# %%
lang_2_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_2.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_2_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_Russian (rus)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_Turkish (tur)_Etymologeek_Result1.xlsx']

# %%
df_lang_2 = pd.DataFrame()
for i in lang_2_file:
    df_var2 = pd.read_excel(f"{i}")
    df_lang_2 = pd.concat([df_lang_2,df_var2], axis=0)
    df_lang_2.reset_index(drop=True, inplace=True)
df_lang_2
# Out:
#     search_word dict_entry_main language_main  \
# 0         hasta           hasta       Spanish
# 1          emir            emir       Spanish
# 2         almaz        almazara       Spanish
# 3          arar            arar       Spanish
# 4          atan          atanor       Spanish
# ..          ...             ...           ...
# 761       corna         cornaca       Spanish
# 762       chamá          chamán       Spanish
# 763    ensalada   ensalada rusa       Spanish
# 764         bey             bey       Spanish
# 765     chaleco         chaleco       Spanish
#
#                                        definition_main       dict_entry  \
# 0    (Preposition) Even. Until. Up to, to the point...           حَتَّى
# 1                                    (Noun) Emir.Emir.  أَمِير الْبَحْر
# 2                (Noun) Olive oil mill.Olive oil mill.        مَعْصَرَة
# 3    (Noun) Common juniper, Juniperus communis.. Sa...          عَرْعَر
# 4                        (Noun) Water pipe.Water pipe.             تنور
# ..                                                 ...              ...
# 761  (Noun) Elephant guide, elephant trainer, mahou...          cornaca
# 762        (Noun) (religion) shaman.(religion) shaman.           шама́н
# 763  (Noun) (usually, _, uncountable) Olivier salad...         шкатулка
# 764                                    (Noun) Bey.Bey.              bey
# 765  (Noun) Sweater, jumper. Vest, waistcoat.Sweate...            yelek
#
#              language                                         definition
# 0        Arabic (ara)                                                NaN
# 1        Arabic (ara)                                                NaN
# 2        Arabic (ara)                                                NaN
# 3        Arabic (ara)                                                NaN
# 4        Arabic (ara)  Illumination, enlightenment Cook stove. Oven, ...
# ..                ...                                                ...
# 761  Portuguese (por)               Mahout (elephant driver and keeper).
# 762     Russian (rus)                                                NaN
# 763     Russian (rus)              Casket, (small) box, case, jewel-box.
# 764     Turkish (tur)          Gentleman, mister. Husband. Lord, master.
# 765     Turkish (tur)                           Jelick. Waistcoat, vest.
#
# [766 rows x 7 columns]

# %%
set_lang_11 = set(df_lang_1["dict_entry"])

# %%
set_lang_12 = set(df_lang_2["dict_entry"])

# %%
df_cross = pd.DataFrame(set_lang_11.intersection(set_lang_12), columns=["dict_entry"])
df_cross
# Out:
#      dict_entry
# 0          film
# 1        paglia
# 2        groppo
# 3          -age
# 4       oxygène
# 5          chef
# 6    bicyclette
# 7         jambe
# 8        doccia
# 9         shoot
# 10        -ence
# 11         lead
# 12       chance
# 13    box seats
# 14        balla
# 15       Bikini
# 16      cocaine
# 17     jaquette
# 18       gender
# 19        birra
# 20       صَفِرَ
# 21    قِيثَارَة
# 22       douche
# 23    salt mine
# 24       Pilsen
# 25     quadrato
# 26        panda
# 27       basket
# 28         lord
# 29         base
# 30      chanter
# 31      χαράσσω
# 32     réclamer
# 33         mine
# 34        civis
# 35  plate-forme
# 36       madame
# 37          dos
# 38         شَاه
# 39    populaire
# 40        champ
# 41          كحل
# 42         dice
# 43      héroïne
# 44      autobus
# 45       cheque
# 46      Reklame
# 47          pur
# 48         foot
# 49       cancer

# %%
df_lang_1_cross = pd.merge(df_cross,df_lang_1,how="inner", on="dict_entry")
df_lang_1_cross.drop_duplicates(inplace=True)
df_lang_1_cross = df_lang_1_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_1_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master"}, inplace=True)
df_lang_1_cross
# Out:
#    lang_master term_master   dict_entry
# 0      Turkish        film         film
# 1      Turkish        film         film
# 2      Turkish     palyaço       paglia
# 3      Turkish        grup       groppo
# 4      Turkish       masaj         -age
# 5      Turkish     oksijen      oxygène
# 6      Turkish         şef         chef
# 7      Turkish    bisiklet   bicyclette
# 8      Turkish      jambon        jambe
# 9      Turkish         duş       doccia
# 10     Turkish         şut        shoot
# 11     Turkish   konferans        -ence
# 12     Turkish    referans        -ence
# 13     Turkish       lider         lead
# 14     Turkish        şans       chance
# 15     Turkish        boks    box seats
# 16     Turkish       balon        balla
# 17     Turkish      bikini       Bikini
# 18     Turkish      bikini       Bikini
# 19     Turkish      bikini       Bikini
# 20     Turkish         kok      cocaine
# 21     Turkish       ceket     jaquette
# 22     Turkish         gey       gender
# 23     Turkish        bira        birra
# 24     Turkish       sıfır       صَفِرَ
# 25     Turkish       safer       صَفِرَ
# 26     Turkish       gitar    قِيثَارَة
# 27     Turkish         duş       douche
# 28     Turkish       sosis    salt mine
# 29     Turkish        bira       Pilsen
# 30     Turkish        kare     quadrato
# 31     Turkish       panda        panda
# 32     Turkish   basketbol       basket
# 33     Turkish      basket       basket
# 34     Turkish        lord         lord
# 35     Turkish     beyzbol         base
# 36     Turkish      şantaj      chanter
# 37     Turkish      harita      χαράσσω
# 38     Turkish      reklam     réclamer
# 39     Turkish         sos         mine
# 40     Turkish        site        civis
# 41     Turkish    platform  plate-forme
# 42     Turkish       madam       madame
# 43     Turkish       dosya          dos
# 44     Turkish         çek         شَاه
# 45     Turkish     popüler    populaire
# 46     Turkish    şampanya        champ
# 47     Turkish       alkol          كحل
# 48     Turkish        şans         dice
# 49     Turkish       eroin      héroïne
# 50     Turkish      otobüs      autobus
# 51     Turkish         çek       cheque
# 52     Turkish      reklam      Reklame
# 53     Turkish        puro          pur
# 54     Turkish      futbol         foot
# 55     Turkish      kanser       cancer

# %%
df_lang_2_cross = pd.merge(df_cross,df_lang_2,how="inner", on="dict_entry")
df_lang_2_cross.drop_duplicates(inplace=True)
df_lang_2_cross = df_lang_2_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_2_cross.rename(columns={"language_main":"lang_sleeve","dict_entry_main":"term_sleeve"}, inplace=True)
df_lang_2_cross
# Out:
#    lang_sleeve term_sleeve dict_entry
# 0      Spanish       filme       film
# 1      Spanish      payaso     paglia
# 2      Spanish       grupo     groppo
# 3      Spanish      masaje       -age
# 4      Spanish     oxígeno    oxygène
# ..         ...         ...        ...
# 69     Spanish      fútbol       foot
# 70     Spanish    cancelar     cancer
# 71     Spanish      cancel     cancer
# 72     Spanish      cáncer     cancer
# 73     Spanish   canciller     cancer
#
# [74 rows x 3 columns]

# %%
df_lang_1_lang_2_cross = pd.merge(df_lang_1_cross,df_lang_2_cross, how="inner", on="dict_entry")
df_lang_1_lang_2_cross.drop_duplicates(inplace=True)
df_lang_1_lang_2_cross = df_lang_1_lang_2_cross[["lang_master","term_master","lang_sleeve","term_sleeve"]]
df_lang_1_lang_2_cross
# Out:
#    lang_master term_master lang_sleeve term_sleeve
# 0      Turkish        film     Spanish       filme
# 2      Turkish     palyaço     Spanish      payaso
# 3      Turkish        grup     Spanish       grupo
# 4      Turkish       masaj     Spanish      masaje
# 5      Turkish     oksijen     Spanish     oxígeno
# ..         ...         ...         ...         ...
# 79     Turkish      futbol     Spanish      fútbol
# 80     Turkish      kanser     Spanish    cancelar
# 81     Turkish      kanser     Spanish      cancel
# 82     Turkish      kanser     Spanish      cáncer
# 83     Turkish      kanser     Spanish   canciller
#
# [75 rows x 4 columns]

# %%
lang_3_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/*_And_{lang_3.capitalize()}_Etymologeek_Result1.xlsx")
lang_3_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Arabic/Arabic_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Russian/Russian_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_Spanish (spa)_Etymologeek_Result1.xlsx']

# %%
df_lang_3 = pd.DataFrame()
for i in lang_3_file:
    df_var3 = pd.read_excel(f"{i}")
    df_lang_3 = pd.concat([df_lang_3,df_var3], axis=0)
    df_lang_3.reset_index(drop=True, inplace=True)
df_lang_3
# Out:
#     search_word dict_entry_main language_main  \
# 0        sigara          sigara       Turkish
# 1       avokado         avokado       Turkish
# 2         sıfır           sıfır       Turkish
# 3      çikolata        çikolata       Turkish
# 4      şampanya        şampanya       Turkish
# ..          ...             ...           ...
# 705       legna           legna       Italian
# 706   vigliacco       vigliacco       Italian
# 707    cogliere        cogliere       Italian
# 708      mosche         moschea       Italian
# 709      patata          patata       Italian
#
#                                        definition_main dict_entry  \
# 0                          (Noun) Cigarette.Cigarette.    cigarro
# 1    (Noun) Advocate. Attorney. Lawyer (professiona...    avocado
# 2           (Numeral) (cardinal) zero.(cardinal) zero.       zero
# 3                          (Noun) Chocolate.Chocolate.  chocolate
# 4                          (Noun) Champagne.Champagne.    campaña
# ..                                                 ...        ...
# 705                          (Noun) Firewood.Firewood.     lignum
# 706  (Adjective Noun) Contemptible. Cowardly Coward...    bellaco
# 707  (Verb) (transitive) to grasp, seize, take. (tr...    colligo
# 708                              (Noun) Mosque.Mosque.   mezquita
# 709  (Noun) (slang) pussy (vagina). Potato.(slang) ...     patata
#
#           language                                         definition
# 0    Spanish (spa)                                  Cigar. Cigarette.
# 1    Spanish (spa)                                           Avocado.
# 2    Spanish (spa)                                                NaN
# 3    Spanish (spa)  (slang) hashish (the leaves of the Indian hemp...
# 4    Spanish (spa)      (heraldiccharge) base. Campaign. Countryside.
# ..             ...                                                ...
# 705  Spanish (spa)                                                NaN
# 706  Spanish (spa)       (Peru) plantain (banana). Scoundrel, rascal.
# 707  Spanish (spa)                                                NaN
# 708  Spanish (spa)             Mosque (place of worship for Muslims).
# 709  Spanish (spa)  (Spain, Philippines) potato. (colloquial) piec...
#
# [710 rows x 7 columns]

# %%
set_lang_21 = set(df_lang_1["dict_entry_main"])

# %%
set_lang_23 = set(df_lang_3["dict_entry_main"])

# %%
df_cross_2 = pd.DataFrame(set_lang_21.intersection(set_lang_23), columns=["dict_entry_main"])
df_cross_2
# Out:
#    dict_entry_main
# 0             feci
# 1            cunta
# 2            papel
# 3             fare
# 4           sigara
# 5            amigo
# 6            boyoz
# 7        mandalina
# 8             site
# 9          kanarya
# 10        tortilla
# 11         domates
# 12         tornado
# 13           gitar
# 14           tabak
# 15        çikolata
# 16           sıfır
# 17           riyal
# 18            oley
# 19            taco
# 20         patates
# 21        flamenko
# 22          fatura
# 23           plaza
# 24            puro
# 25        şampanya
# 26         palavra
# 27         avokado

# %%
df_lang_1_lang_3_cross = pd.merge(df_cross_2,df_lang_3,how="inner", on="dict_entry_main")
df_lang_1_lang_3_cross.drop_duplicates(inplace=True)
df_lang_1_lang_3_cross = df_lang_1_lang_3_cross[["language_main","dict_entry_main","language","dict_entry"]]
df_lang_1_lang_3_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master","language":"lang_sleeve","dict_entry":"term_sleeve"}, inplace=True)
df_lang_1_lang_3_cross
# Out:
#    lang_master term_master    lang_sleeve term_sleeve
# 0      Italian        feci  Spanish (spa)      faecem
# 1      Turkish       cunta  Spanish (spa)       cunta
# 2      Turkish       papel  Spanish (spa)       papel
# 3      Italian        fare  Spanish (spa)       hacer
# 4      Turkish      sigara  Spanish (spa)     cigarro
# 5      Turkish       amigo  Spanish (spa)       amigo
# 6      Turkish       boyoz  Spanish (spa)       boyoz
# 7      Turkish   mandalina  Spanish (spa)    mandarin
# 8      English        site  Spanish (spa)      sitiar
# 9       French        site  Spanish (spa)      sitiar
# 10  Portuguese        site  Spanish (spa)      sitiar
# 11     Turkish     kanarya  Spanish (spa)     canario
# 12     Turkish    tortilla  Spanish (spa)    tortilla
# 13     Turkish     domates  Spanish (spa)     tomates
# 14     Turkish     tornado  Spanish (spa)     tornado
# 15     English     tornado  Spanish (spa)      tronar
# 16     Turkish       gitar  Spanish (spa)    guitarra
# 17       Dutch       tabak  Spanish (spa)      tabaco
# 18     Turkish    çikolata  Spanish (spa)   chocolate
# 19     Turkish       sıfır  Spanish (spa)        zero
# 20     Turkish       riyal  Spanish (spa)       riyal
# 21     Turkish        oley  Spanish (spa)         ole
# 22     Turkish        taco  Spanish (spa)        taco
# 23     English        taco  Spanish (spa)        taco
# 24  Portuguese        taco  Spanish (spa)        taco
# 25     Turkish     patates  Spanish (spa)     patatas
# 26     Turkish    flamenko  Spanish (spa)    flamenko
# 27     Turkish      fatura  Spanish (spa)       hacer
# 28     Turkish       plaza  Spanish (spa)       plaza
# 29     English       plaza  Spanish (spa)       plaza
# 30     Turkish        puro  Spanish (spa)        puro
# 31     English        puro  Spanish (spa)        puro
# 32     Turkish    şampanya  Spanish (spa)     campaña
# 33     Turkish     palavra  Spanish (spa)     palabra
# 34     Turkish     avokado  Spanish (spa)     avocado

# %%
df_lang_1_lang_2_lang_3 = pd.concat([df_lang_1_lang_2_cross,df_lang_1_lang_3_cross], axis=0)
df_lang_1_lang_2_lang_3.reset_index(drop=True, inplace=True)
df_lang_1_lang_2_lang_3["term_master"] = df_lang_1_lang_2_lang_3["term_master"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3["term_sleeve"] = df_lang_1_lang_2_lang_3["term_sleeve"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3
# Out:
#     lang_master term_master    lang_sleeve term_sleeve
# 0       Turkish        film        Spanish       filme
# 1       Turkish     palyaço        Spanish      payaso
# 2       Turkish        grup        Spanish       grupo
# 3       Turkish       masaj        Spanish      masaje
# 4       Turkish     oksijen        Spanish     oxígeno
# ..          ...         ...            ...         ...
# 105     Turkish        puro  Spanish (spa)        puro
# 106     English        puro  Spanish (spa)        puro
# 107     Turkish    şampanya  Spanish (spa)     campaña
# 108     Turkish     palavra  Spanish (spa)     palabra
# 109     Turkish     avokado  Spanish (spa)     avocado
#
# [110 rows x 4 columns]

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"term_sleeve"}, inplace=True)
#df_word

# %%
#df_lang_1_lang_2_lang_3 = pd.merge(df_lang_1_lang_2_lang_3,df_word, how="inner", on="term_sleeve")
#df_lang_1_lang_2_lang_3

# %%
df_lang_1_lang_2_lang_3.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()} {lang_2.capitalize()}/{lang_1.capitalize()}_And_{lang_3.capitalize()}_Etymologeek_Result5.xlsx", index=False)
