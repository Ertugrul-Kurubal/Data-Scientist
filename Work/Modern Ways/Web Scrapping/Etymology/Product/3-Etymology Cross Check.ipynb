# %% [markdown]
# ### Etymology Cross Check

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### Etymologeek Result

# %%
lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian 
lang_2 = "French"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

if lang_2 == "English":
    lang_3 = "English (eng)"
elif lang_2 == "Turkish":
    lang_3 = "Turkish (tur)"
elif lang_2 == "German":
    lang_3 = "German (deu)"
elif lang_2 == "French":
    lang_3 = "French (fra)"
elif lang_2 == "Spanish":
    lang_3 = "Spanish (spa)"
elif lang_2 == "Arabic":
    lang_3 = "Arabic (ara)"
elif lang_2 == "Russian":
    lang_3 = "Russian (rus)"
elif lang_2 == "Portuguese":
    lang_3 = "Portuguese (por)"
elif lang_2 == "Dutch":
    lang_3 = "Dutch (nld)"
elif lang_2 == "Italian":
    lang_3 = "Italian (ita)"
else:
    pass
#lang_3 = "English (eng)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)
print(f"{lang_1}\n{lang_2}\n{lang_3}")
# Out:
# Turkish
# French
# French (fra)

# %%
#Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
lang_1_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_1.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_1_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_German (deu)_Etymologeek_Result1.xlsx']

# %%
df_lang_1 = pd.DataFrame()
for i in lang_1_file:
    df_var = pd.read_excel(f"{i}")
    df_lang_1 = pd.concat([df_lang_1,df_var], axis=0)
    df_lang_1.reset_index(drop=True, inplace=True)
df_lang_1
# Out:
#      search_word dict_entry_main language_main  \
# 0           şans            şans       Turkish
# 1           loca            loca       Turkish
# 2             mı        mıknatıs       Turkish
# 3             mı          mısdak       Turkish
# 4            şey             şey       Turkish
# ..           ...             ...           ...
# 732       vermut          vermut       Turkish
# 733       panzer          panzer       Turkish
# 734  tonymayster     tonymayster       Turkish
# 735      filinta         filinta       Turkish
# 736       kuvars          kuvars       Turkish
#
#                                        definition_main   dict_entry  \
# 0                  (Noun) Fortune. Luck.Fortune. Luck.         dice
# 1    (Noun) (masonic) lodge. Box (in theaters).(mas...       laubja
# 2                                (Noun) Magnet.Magnet.  مِغْنَاطِيس
# 3    (Noun) (obsolete) criterion.(obsolete) criterion.     مِصْدَاق
# 4    (Noun Interjection) (slang) genital organ. Thi...      شَيْئاً
# ..                                                 ...          ...
# 732                                             (Noun)       wermut
# 733                                             (Noun)       panzer
# 734                                             (Noun)   tonmeister
# 735                                             (Noun)       flinte
# 736                                             (Noun)        quarz
#
#          language                                         definition
# 0     Dutch (nld)                                                NaN
# 1     Dutch (nld)                                                NaN
# 2    Arabic (ara)                                                NaN
# 3    Arabic (ara)                                                NaN
# 4    Arabic (ara)                                                NaN
# ..            ...                                                ...
# 732  German (deu)  Vermouth is an aromatized fortified wine, flav...
# 733  German (deu)  A tank is an armoured fighting vehicle intende...
# 734  German (deu)                                         Tonmeister
# 735  German (deu)                                             Flinte
# 736  German (deu)  Quartz is a hard, crystalline mineral composed...
#
# [737 rows x 7 columns]

# %%
lang_2_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_2.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_2_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Russian (rus)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_Turkish (tur)_Etymologeek_Result1.xlsx']

# %%
df_lang_2 = pd.DataFrame()
for i in lang_2_file:
    df_var2 = pd.read_excel(f"{i}")
    df_lang_2 = pd.concat([df_lang_2,df_var2], axis=0)
    df_lang_2.reset_index(drop=True, inplace=True)
df_lang_2
# Out:
#     search_word dict_entry_main language_main  \
# 0         hasar          hasard        French
# 1         barda        bardache        French
# 2         tarif           tarif        French
# 3        amiral          amiral        French
# 4         fakir           fakir        French
# ..          ...             ...           ...
# 933     évanoui        évanouir        French
# 934      cuivre          cuivre        French
# 935      patate          patate        French
# 936         yat         yatagan        French
# 937      sultan          sultan        French
#
#                                        definition_main        dict_entry  \
# 0    (Noun) (golf) hazard. (usually, in the singula...               زهر
# 1    (Noun) (dated) a berdache; a third-gender Nati...           بَرْدَج
# 2                                  (Noun) Price.Price.         تَعْرِفَة
# 3    (Adjective Noun) Of or belonging to an admiral...  أَمِير اَلْبَحْر
# 4    (Noun) Fakir (all meanings).Fakir (all meanings).            فَقِير
# ..                                                 ...               ...
# 933  (Verb) (pronominal) to lose consciousness; to ...         desvariar
# 934  (Verb Noun) (arts) copperplate. (music) brass....            Cyprus
# 935  (Noun) (chiefly, Canada, Louisiana French) pot...            patata
# 936                          (Noun) Yataghan.Yataghan.           yatağan
# 937  (Noun) A perfume sachet to put in a linen coff...            sultan
#
#           language                                         definition
# 0     Arabic (ara)  die, dice. Blossoms. Cast iron. Flowers To shi...
# 1     Arabic (ara)                                                NaN
# 2     Arabic (ara)                                                NaN
# 3     Arabic (ara)                                                NaN
# 4     Arabic (ara)                                                NaN
# ..             ...                                                ...
# 933  Spanish (spa)          To become delusional, to lose one's mind.
# 934  Spanish (spa)                                                NaN
# 935  Spanish (spa)  (Spain, Philippines) potato. (colloquial) piec...
# 936  Turkish (tur)                                          Yataghan.
# 937  Turkish (tur)  A breed of chicken originating in Turkey, kept...
#
# [938 rows x 7 columns]

# %%
set_lang_11 = set(df_lang_1["dict_entry"])

# %%
set_lang_12 = set(df_lang_2["dict_entry"])

# %%
df_cross = pd.DataFrame(set_lang_11.intersection(set_lang_12), columns=["dict_entry"])
df_cross
# Out:
#           dict_entry
# 0           medaglia
# 1              banca
# 2            whiskey
# 3              shoot
# 4             عَجِين
# 5           Sandwich
# 6                كحل
# 7            cigarro
# 8               foot
# 9               base
# 10           Hamburg
# 11          scenario
# 12          concerto
# 13              jury
# 14            Bikini
# 15         box seats
# 16              Kent
# 17             hacer
# 18             balla
# 19              Bank
# 20          nokehike
# 21              جِنّ
# 22              sala
# 23               sex
# 24  أَمِير اَلْبَحْر
# 25            heaven
# 26            شَرَبَ
# 27               شكر
# 28              lord
# 29           firmare
# 30          guitarra
# 31           destroy
# 32              -age
# 33           corsaro
# 34         salt mine
# 35              lead
# 36            tennis
# 37               set
# 38           سَوَّرَ
# 39              zero
# 40            groppo
# 41           χαράσσω
# 42         gabinetto
# 43            Vampir
# 44             civis
# 45         قِيثَارَة
# 46              dice
# 47              rail
# 48           tornado
# 49              film
# 50            فَقِير
# 51          quadrato
# 52              mine
# 53         chocolate
# 54              goal
# 55            doccia

# %%
df_lang_1_cross = pd.merge(df_cross,df_lang_1,how="inner", on="dict_entry")
df_lang_1_cross.drop_duplicates(inplace=True)
df_lang_1_cross = df_lang_1_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_1_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master"}, inplace=True)
df_lang_1_cross
# Out:
#    lang_master term_master dict_entry
# 0      Turkish     madalya   medaglia
# 1      Turkish       banka      banca
# 2      Turkish       viski    whiskey
# 3      Turkish         şut      shoot
# 4      Turkish    lahmacun     عَجِين
# ..         ...         ...        ...
# 57     Turkish        kare   quadrato
# 58     Turkish         sos       mine
# 59     Turkish    çikolata  chocolate
# 60     Turkish         gül       goal
# 61     Turkish         duş     doccia
#
# [62 rows x 3 columns]

# %%
df_lang_2_cross = pd.merge(df_cross,df_lang_2,how="inner", on="dict_entry")
df_lang_2_cross.drop_duplicates(inplace=True)
df_lang_2_cross = df_lang_2_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_2_cross.rename(columns={"language_main":"lang_sleeve","dict_entry_main":"term_sleeve"}, inplace=True)
df_lang_2_cross
# Out:
#    lang_sleeve term_sleeve dict_entry
# 0       French    médaille   medaglia
# 1       French     banquet      banca
# 2       French      banque      banca
# 3       French      whisky    whiskey
# 4       French     shooter      shoot
# ..         ...         ...        ...
# 76      French        saut       mine
# 77      French         sel       mine
# 78      French    chocolat  chocolate
# 79      French        goal       goal
# 80      French      douche     doccia
#
# [81 rows x 3 columns]

# %%
df_lang_1_lang_2_cross = pd.merge(df_lang_1_cross,df_lang_2_cross, how="inner", on="dict_entry")
df_lang_1_lang_2_cross.drop_duplicates(inplace=True)
df_lang_1_lang_2_cross = df_lang_1_lang_2_cross[["lang_master","term_master","lang_sleeve","term_sleeve"]]
df_lang_1_lang_2_cross
# Out:
#    lang_master term_master lang_sleeve term_sleeve
# 0      Turkish     madalya      French    médaille
# 1      Turkish       banka      French     banquet
# 2      Turkish       banka      French      banque
# 3      Turkish       viski      French      whisky
# 4      Turkish         şut      French     shooter
# ..         ...         ...         ...         ...
# 84     Turkish         sos      French        saut
# 85     Turkish         sos      French         sel
# 86     Turkish    çikolata      French    chocolat
# 87     Turkish         gül      French        goal
# 88     Turkish         duş      French      douche
#
# [81 rows x 4 columns]

# %%
lang_3_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/*_And_{lang_3.capitalize()}_Etymologeek_Result1.xlsx")
lang_3_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Arabic/Arabic_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Russian/Russian_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_French (fra)_Etymologeek_Result1.xlsx']

# %%
df_lang_3 = pd.DataFrame()
for i in lang_3_file:
    df_var3 = pd.read_excel(f"{i}")
    df_lang_3 = pd.concat([df_lang_3,df_var3], axis=0)
    df_lang_3.reset_index(drop=True, inplace=True)
df_lang_3
# Out:
#       search_word dict_entry_main language_main  \
# 0           polis           polis       Turkish
# 1             dün           dünit       Turkish
# 2             alo             alo       Turkish
# 3           komik           komik       Turkish
# 4         telefon         telefon       Turkish
# ...           ...             ...           ...
# 3184      incendi      incendiare       Italian
# 3185      allegro         allegro       Italian
# 3186      plotone         plotone       Italian
# 3187   confidenza      confidenza       Italian
# 3188  trasmettere     trasmettere       Italian
#
#                                         definition_main  dict_entry  \
# 0     (Noun) Police (an organisation that enforces t...      police
# 1       (Noun) (mineralogy) dunite.(mineralogy) dunite.      dunite
# 2     (Interjection) Hello (only when picking up the...        allo
# 3                              (Adjective) Funny.Funny.     comique
# 4                           (Noun) Telephone.Telephone.  téléphoner
# ...                                                 ...         ...
# 3184  (Verb) (transitive) to set fire to, ignite, in...    incendie
# 3185  (Adjective) Cheerful. Mirthful.Cheerful. Mirth...      alègre
# 3186  (Noun) (cycle racing) peloton, group. (militar...     peloton
# 3187  (Noun) Confidence. Intimacy, familiarity.Confi...      fiance
# 3188  (Verb) (transitive) to broadcast, transmit, ai...      mettre
#
#           language                                         definition
# 0     French (fra)  (Quebec) cop (police officer). (typography) fo...
# 1     French (fra)                                                NaN
# 2     French (fra)                                                NaN
# 3     French (fra)       Comic Clown (person who acts silly). Comedy.
# 4     French (fra)     (intransitive) To call, to ring, to telephone.
# ...            ...                                                ...
# 3184  French (fra)  Fire (something on fire which is out of control).
# 3185  French (fra)                                                NaN
# 3186  French (fra)  (military) platoon. Pack, bunch (of cyclists e...
# 3187  French (fra)                      (obsolete) faith; confidence.
# 3188  French (fra)  (pronominal) to start (+ à) (something / doing...
#
# [3189 rows x 7 columns]

# %%
set_lang_21 = set(df_lang_1["dict_entry_main"])

# %%
set_lang_23 = set(df_lang_3["dict_entry_main"])

# %%
df_cross_2 = pd.DataFrame(set_lang_21.intersection(set_lang_23), columns=["dict_entry_main"])
df_cross_2
# Out:
#     dict_entry_main
# 0               şok
# 1        enfeksiyon
# 2             dünit
# 3          alkolizm
# 4             sosis
# ..              ...
# 206          sosyal
# 207         oksijen
# 208         andaval
# 209          volkan
# 210       fransiyum
#
# [211 rows x 1 columns]

# %%
df_lang_1_lang_3_cross = pd.merge(df_cross_2,df_lang_3,how="inner", on="dict_entry_main")
df_lang_1_lang_3_cross.drop_duplicates(inplace=True)
df_lang_1_lang_3_cross = df_lang_1_lang_3_cross[["language_main","dict_entry_main","language","dict_entry"]]
df_lang_1_lang_3_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master","language":"lang_sleeve","dict_entry":"term_sleeve"}, inplace=True)
df_lang_1_lang_3_cross
# Out:
#     lang_master term_master   lang_sleeve term_sleeve
# 0       Turkish         şok  French (fra)        choc
# 1       Turkish  enfeksiyon  French (fra)   infection
# 2       Turkish       dünit  French (fra)      dunite
# 3       Turkish    alkolizm  French (fra)      alcool
# 4       Turkish       sosis  French (fra)    saucisse
# ..          ...         ...           ...         ...
# 225     Turkish      sosyal  French (fra)      social
# 226     Turkish     oksijen  French (fra)     oxygène
# 227     Turkish     andaval  French (fra)   andouille
# 228     Turkish      volkan  French (fra)      volcan
# 229     Turkish   fransiyum  French (fra)    francium
#
# [230 rows x 4 columns]

# %%
df_lang_1_lang_2_lang_3 = pd.concat([df_lang_1_lang_2_cross,df_lang_1_lang_3_cross], axis=0)
df_lang_1_lang_2_lang_3.reset_index(drop=True, inplace=True)
df_lang_1_lang_2_lang_3["term_master"] = df_lang_1_lang_2_lang_3["term_master"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3["term_sleeve"] = df_lang_1_lang_2_lang_3["term_sleeve"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3
# Out:
#     lang_master term_master   lang_sleeve term_sleeve
# 0       Turkish     madalya        French    médaille
# 1       Turkish       banka        French     banquet
# 2       Turkish       banka        French      banque
# 3       Turkish       viski        French      whisky
# 4       Turkish         şut        French     shooter
# ..          ...         ...           ...         ...
# 306     Turkish      sosyal  French (fra)      social
# 307     Turkish     oksijen  French (fra)     oxygène
# 308     Turkish     andaval  French (fra)   andouille
# 309     Turkish      volkan  French (fra)      volcan
# 310     Turkish   fransiyum  French (fra)    francium
#
# [311 rows x 4 columns]

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"term_sleeve"}, inplace=True)
#df_word

# %%
#df_lang_1_lang_2_lang_3 = pd.merge(df_lang_1_lang_2_lang_3,df_word, how="inner", on="term_sleeve")
#df_lang_1_lang_2_lang_3

# %%
df_lang_1_lang_2_lang_3.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()} {lang_2.capitalize()}/{lang_1.capitalize()}_And_{lang_3.capitalize()}_Etymologeek_Result5.xlsx", index=False)
