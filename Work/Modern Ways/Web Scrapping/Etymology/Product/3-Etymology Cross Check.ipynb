# %% [markdown]
# ### Etymology Cross Check

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize

# %% [markdown]
# #### Etymologeek Result

# %%
lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian 
lang_2 = "German"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

if lang_2 == "English":
    lang_3 = "English (eng)"
elif lang_2 == "Turkish":
    lang_3 = "Turkish (tur)"
elif lang_2 == "German":
    lang_3 = "German (deu)"
elif lang_2 == "French":
    lang_3 = "French (fra)"
elif lang_2 == "Spanish":
    lang_3 = "Spanish (spa)"
elif lang_2 == "Arabic":
    lang_3 = "Arabic (ara)"
elif lang_2 == "Russian":
    lang_3 = "Russian (rus)"
elif lang_2 == "Portuguese":
    lang_3 = "Portuguese (por)"
elif lang_2 == "Dutch":
    lang_3 = "Dutch (nld)"
elif lang_2 == "Italian":
    lang_3 = "Italian (ita)"
else:
    pass
#lang_3 = "English (eng)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)
print(f"{lang_1}\n{lang_2}\n{lang_3}")
# Out:
# Turkish
# German
# German (deu)

# %%
#Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
lang_1_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_1.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_1_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_German (deu)_Etymologeek_Result1.xlsx']

# %%
df_lang_1 = pd.DataFrame()
for i in lang_1_file:
    df_var = pd.read_excel(f"{i}")
    df_lang_1 = pd.concat([df_lang_1,df_var], axis=0)
    df_lang_1.reset_index(drop=True, inplace=True)
df_lang_1
# Out:
#      search_word dict_entry_main language_main  \
# 0           şans            şans       Turkish
# 1           loca            loca       Turkish
# 2             mı        mıknatıs       Turkish
# 3             mı          mısdak       Turkish
# 4            şey             şey       Turkish
# ..           ...             ...           ...
# 732       vermut          vermut       Turkish
# 733       panzer          panzer       Turkish
# 734  tonymayster     tonymayster       Turkish
# 735      filinta         filinta       Turkish
# 736       kuvars          kuvars       Turkish
#
#                                        definition_main   dict_entry  \
# 0                  (Noun) Fortune. Luck.Fortune. Luck.         dice
# 1    (Noun) (masonic) lodge. Box (in theaters).(mas...       laubja
# 2                                (Noun) Magnet.Magnet.  مِغْنَاطِيس
# 3    (Noun) (obsolete) criterion.(obsolete) criterion.     مِصْدَاق
# 4    (Noun Interjection) (slang) genital organ. Thi...      شَيْئاً
# ..                                                 ...          ...
# 732                                             (Noun)       wermut
# 733                                             (Noun)       panzer
# 734                                             (Noun)   tonmeister
# 735                                             (Noun)       flinte
# 736                                             (Noun)        quarz
#
#          language                                         definition
# 0     Dutch (nld)                                                NaN
# 1     Dutch (nld)                                                NaN
# 2    Arabic (ara)                                                NaN
# 3    Arabic (ara)                                                NaN
# 4    Arabic (ara)                                                NaN
# ..            ...                                                ...
# 732  German (deu)  Vermouth is an aromatized fortified wine, flav...
# 733  German (deu)  A tank is an armoured fighting vehicle intende...
# 734  German (deu)                                         Tonmeister
# 735  German (deu)                                             Flinte
# 736  German (deu)  Quartz is a hard, crystalline mineral composed...
#
# [737 rows x 7 columns]

# %%
lang_2_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/{lang_2.capitalize()}_And_*_Etymologeek_Result1.xlsx")
lang_2_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Arabic (ara)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Dutch (nld)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_English (eng)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_French (fra)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Italian (ita)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Portuguese (por)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Russian (rus)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Spanish (spa)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/German/German_And_Turkish (tur)_Etymologeek_Result1.xlsx']

# %%
df_lang_2 = pd.DataFrame()
for i in lang_2_file:
    df_var2 = pd.read_excel(f"{i}")
    df_lang_2 = pd.concat([df_lang_2,df_var2], axis=0)
    df_lang_2.reset_index(drop=True, inplace=True)
df_lang_2
# Out:
#     search_word dict_entry_main language_main  \
# 0        genial          genial        German
# 1      beginnen        beginnen        German
# 2        kappen          kappen        German
# 3         haben    haben können        German
# 4       tschüss         tschüss        German
# ..          ...             ...           ...
# 177      tanken          tanken        German
# 178      falsch          falsch        German
# 179      fehlen          fehlen        German
# 180      tschüs        tschüsch        German
# 181       anges    angeschlagen        German
#
#                                        definition_main     dict_entry  \
# 0    (Adjective) Genius, ingenious, genial (in the ...           جِنّ
# 1    (Verb) (chiefly, literary, transitive, _, or w...      ontginnen
# 2    (Verb) To cut down so as to make unusable; to ...         kappen
# 3    (Verb) (idiomatic) to be able to stand or endu...  kunnen hebben
# 4    (Interjection) (informal) bye, cheers, ciao.(i...      adjuusjes
# ..                                                 ...            ...
# 177  (Verb) (transitive, or, intransitive) to fuel,...         tanque
# 178  (Adjective) (chiefly, predicative) wrong (immo...          fallo
# 179  (Verb) (dated) to fail. To be absent. To lack....          fallo
# 180  (Interjection) (immigrant or youth, _, slang, ...            çüş
# 181          (Verb Adjective) Beleaguered.Beleaguered.     anschlagen
#
#              language                                         definition
# 0        Arabic (ara)                                                NaN
# 1         Dutch (nld)                                        To develop.
# 2         Dutch (nld)  (transitive) to young, notably have piglets (c...
# 3         Dutch (nld)                                                NaN
# 4         Dutch (nld)                                                NaN
# ..                ...                                                ...
# 177  Portuguese (por)            A sink used for laundry. Cistern. Tank.
# 178  Portuguese (por)                                                NaN
# 179  Portuguese (por)                                                NaN
# 180     Turkish (tur)                                                NaN
# 181     Turkish (tur)                                                NaN
#
# [182 rows x 7 columns]

# %%
set_lang_11 = set(df_lang_1["dict_entry"])

# %%
set_lang_12 = set(df_lang_2["dict_entry"])

# %%
df_cross = pd.DataFrame(set_lang_11.intersection(set_lang_12), columns=["dict_entry"])
df_cross
# Out:
#    dict_entry
# 0     intérêt
# 1       train
# 2         sex
# 3        جِنّ
# 4       super
# 5   box seats
# 6      cheque
# 7        test
# 8     comique
# 9         pur
# 10      actif

# %%
df_lang_1_cross = pd.merge(df_cross,df_lang_1,how="inner", on="dict_entry")
df_lang_1_cross.drop_duplicates(inplace=True)
df_lang_1_cross = df_lang_1_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_1_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master"}, inplace=True)
df_lang_1_cross
# Out:
#    lang_master term_master dict_entry
# 0      Turkish   enteresan    intérêt
# 1      Turkish        tren      train
# 2      Turkish       seksi        sex
# 3      Turkish         cin       جِنّ
# 4      Turkish       süper      super
# 5      Turkish        boks  box seats
# 6      Turkish         çek     cheque
# 7      Turkish        test       test
# 8      Turkish       komik    comique
# 9      Turkish        puro        pur
# 10     Turkish       aktif      actif

# %%
df_lang_2_cross = pd.merge(df_cross,df_lang_2,how="inner", on="dict_entry")
df_lang_2_cross.drop_duplicates(inplace=True)
df_lang_2_cross = df_lang_2_cross[["language_main","dict_entry_main","dict_entry"]]
df_lang_2_cross.rename(columns={"language_main":"lang_sleeve","dict_entry_main":"term_sleeve"}, inplace=True)
df_lang_2_cross
# Out:
#    lang_sleeve    term_sleeve dict_entry
# 0       German    interessant    intérêt
# 1       German  interessieren    intérêt
# 2       German     trainieren      train
# 3       German           sexy        sex
# 4       German         genial       جِنّ
# 5       German          super      super
# 6       German          boxen  box seats
# 7       German        checken     cheque
# 8       German         testen       test
# 9       German        komisch    comique
# 10      German            pur        pur
# 11      German          aktiv      actif

# %%
df_lang_1_lang_2_cross = pd.merge(df_lang_1_cross,df_lang_2_cross, how="inner", on="dict_entry")
df_lang_1_lang_2_cross.drop_duplicates(inplace=True)
df_lang_1_lang_2_cross = df_lang_1_lang_2_cross[["lang_master","term_master","lang_sleeve","term_sleeve"]]
df_lang_1_lang_2_cross
# Out:
#    lang_master term_master lang_sleeve    term_sleeve
# 0      Turkish   enteresan      German    interessant
# 1      Turkish   enteresan      German  interessieren
# 2      Turkish        tren      German     trainieren
# 3      Turkish       seksi      German           sexy
# 4      Turkish         cin      German         genial
# 5      Turkish       süper      German          super
# 6      Turkish        boks      German          boxen
# 7      Turkish         çek      German        checken
# 8      Turkish        test      German         testen
# 9      Turkish       komik      German        komisch
# 10     Turkish        puro      German            pur
# 11     Turkish       aktif      German          aktiv

# %%
lang_3_file = glob.glob(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/*/*_And_{lang_3.capitalize()}_Etymologeek_Result1.xlsx")
lang_3_file
# Out:
# ['/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Turkish/Turkish_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/English/English_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/French/French_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Spanish/Spanish_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Arabic/Arabic_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Russian/Russian_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Portuguese/Portuguese_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Dutch/Dutch_And_German (deu)_Etymologeek_Result1.xlsx',
#  '/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/Italian/Italian_And_German (deu)_Etymologeek_Result1.xlsx']

# %%
df_lang_3 = pd.DataFrame()
for i in lang_3_file:
    df_var3 = pd.read_excel(f"{i}")
    df_lang_3 = pd.concat([df_lang_3,df_var3], axis=0)
    df_lang_3.reset_index(drop=True, inplace=True)
df_lang_3
# Out:
#     search_word dict_entry_main language_main  \
# 0          bira            bira       Turkish
# 1         banka           banka       Turkish
# 2        vampir          vampir       Turkish
# 3        reklam          reklam       Turkish
# 4         kuruş           kuruş       Turkish
# ..          ...             ...           ...
# 536    bloccata        bloccata       Italian
# 537      mobili         mobilia       Italian
# 538    assoluto        assoluto       Italian
# 539      banche       banchetto       Italian
# 540       salti     saltimbanco       Italian
#
#                                        definition_main   dict_entry  \
# 0                                    (Noun) Beer.Beer.       Pilsen
# 1                                    (Noun) Bank.Bank.         Bank
# 2                              (Noun) Vampire.Vampire.       Vampir
# 3                  (Noun) Advertisement.Advertisement.      Reklame
# 4    (Noun) A subdivision of currency, equal to one...     Groschen
# ..                                                 ...          ...
# 536                                                NaN        Block
# 537                   (Verb Noun) Furniture.Furniture.        Möbel
# 538  (Adjective) Absolute. Complete, total.Absolute...  absolvieren
# 539         (Noun Verb) Feast, banquet.Feast, banquet.         Bank
# 540  (Noun) (figuratively, pejorative) a charlatan....         Bank
#
#          language                                         definition
# 0    German (deu)                Pilsen, city in the Czech Republic.
# 1    German (deu)  A facility for storage of a particular thing:....
# 2    German (deu)                                           Vampire.
# 3    German (deu)                                     Advertisement.
# 4    German (deu)  (colloquial, Germany) a 10-cent coin (since th...
# ..            ...                                                ...
# 536  German (deu)  Bloc. Block (large building or group of such)....
# 537  German (deu)                     Furniture. Piece of furniture.
# 538  German (deu)  (theology) to absolve (pronounce free or give ...
# 539  German (deu)  A facility for storage of a particular thing:....
# 540  German (deu)  A facility for storage of a particular thing:....
#
# [541 rows x 7 columns]

# %%
set_lang_21 = set(df_lang_1["dict_entry_main"])

# %%
set_lang_23 = set(df_lang_3["dict_entry_main"])

# %%
df_cross_2 = pd.DataFrame(set_lang_21.intersection(set_lang_23), columns=["dict_entry_main"])
df_cross_2
# Out:
#    dict_entry_main
# 0           şalter
# 1      tonymayster
# 2           vampir
# 3             vals
# 4         tekniker
# 5            kuruş
# 6          genetik
# 7          protein
# 8           panzer
# 9           vermut
# 10        laborant
# 11       hamburger
# 12           dizel
# 13        şinitzel
# 14       germanyum
# 15           baron
# 16         general
# 17      fahrenhayt
# 18           banka
# 19          reklam
# 20          otoban
# 21           dikta
# 22      akupunktur
# 23         element
# 24          zeplin
# 25           vokal
# 26           revir
# 27         snorkel
# 28           panda
# 29          doçent
# 30           şilep
# 31         gestapo
# 32         vazelin
# 33          bitter
# 34           dekan
# 35           beher
# 36          kuvars
# 37           drama
# 38             kek
# 39         filinta
# 40         röntgen
# 41          bikini
# 42            bira

# %%
df_lang_1_lang_3_cross = pd.merge(df_cross_2,df_lang_3,how="inner", on="dict_entry_main")
df_lang_1_lang_3_cross.drop_duplicates(inplace=True)
df_lang_1_lang_3_cross = df_lang_1_lang_3_cross[["language_main","dict_entry_main","language","dict_entry"]]
df_lang_1_lang_3_cross.rename(columns={"language_main":"lang_master","dict_entry_main":"term_master","language":"lang_sleeve","dict_entry":"term_sleeve"}, inplace=True)
df_lang_1_lang_3_cross
# Out:
#    lang_master  term_master   lang_sleeve    term_sleeve
# 0      Turkish       şalter  German (deu)       schalter
# 1      Turkish  tonymayster  German (deu)     tonmeister
# 2      Turkish       vampir  German (deu)         Vampir
# 3      Turkish         vals  German (deu)         walzer
# 4      Turkish     tekniker  German (deu)      techniker
# 5      Turkish        kuruş  German (deu)       Groschen
# 6      Turkish      genetik  German (deu)        genetik
# 7      English      protein  German (deu)        Protein
# 8      Turkish       panzer  German (deu)         panzer
# 9      English       panzer  German (deu)         Panzer
# 10     Turkish       vermut  German (deu)         wermut
# 11     Turkish     laborant  German (deu)       laborant
# 12     Turkish    hamburger  German (deu)        Hamburg
# 13      French    hamburger  German (deu)        Hamburg
# 14  Portuguese    hamburger  German (deu)        Hamburg
# 15       Dutch    hamburger  German (deu)        Hamburg
# 16     Turkish        dizel  German (deu)         diesel
# 17     Turkish     şinitzel  German (deu)      schnitzel
# 18     Turkish    germanyum  German (deu)      Germanium
# 19     Turkish        baron  German (deu)          baron
# 20     Turkish      general  German (deu)        general
# 21     Turkish   fahrenhayt  German (deu)     fahrenheit
# 22     Turkish        banka  German (deu)           Bank
# 23     Turkish       reklam  German (deu)        Reklame
# 24     Turkish       otoban  German (deu)       autobahn
# 25     Turkish        dikta  German (deu)          dikta
# 26     Turkish   akupunktur  German (deu)     akupunktur
# 27     Turkish      element  German (deu)        Element
# 28     Turkish      element  German (deu)        element
# 29     Turkish       zeplin  German (deu)       zeppelin
# 30     Turkish        vokal  German (deu)          vokal
# 31     Turkish        revir  German (deu)         revier
# 32     Turkish      snorkel  German (deu)     schnorchel
# 33     Turkish        panda  German (deu)          panda
# 34     Turkish       doçent  German (deu)         dozent
# 35     Turkish        şilep  German (deu)  schleppschiff
# 36     Turkish      gestapo  German (deu)        gestapo
# 37     Turkish      vazelin  German (deu)        vaselin
# 38     Turkish       bitter  German (deu)         bitter
# 39     Turkish        dekan  German (deu)          dekan
# 40     Turkish        beher  German (deu)         becher
# 41     Turkish       kuvars  German (deu)          quarz
# 42     Turkish        drama  German (deu)          drama
# 43       Dutch          kek  German (deu)           keck
# 44     Turkish      filinta  German (deu)         flinte
# 45     Turkish      röntgen  German (deu)        röntgen
# 46     Turkish       bikini  German (deu)         Bikini
# 47     English       bikini  German (deu)         Bikini
# 48      French       bikini  German (deu)         Bikini
# 49     Spanish       bikini  German (deu)         Bikini
# 50       Dutch       bikini  German (deu)         Bikini
# 51     Turkish         bira  German (deu)         Pilsen

# %%
df_lang_1_lang_2_lang_3 = pd.concat([df_lang_1_lang_2_cross,df_lang_1_lang_3_cross], axis=0)
df_lang_1_lang_2_lang_3.reset_index(drop=True, inplace=True)
df_lang_1_lang_2_lang_3["term_master"] = df_lang_1_lang_2_lang_3["term_master"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3["term_sleeve"] = df_lang_1_lang_2_lang_3["term_sleeve"].apply(lambda x: x.lower())
df_lang_1_lang_2_lang_3
# Out:
#    lang_master term_master   lang_sleeve    term_sleeve
# 0      Turkish   enteresan        German    interessant
# 1      Turkish   enteresan        German  interessieren
# 2      Turkish        tren        German     trainieren
# 3      Turkish       seksi        German           sexy
# 4      Turkish         cin        German         genial
# ..         ...         ...           ...            ...
# 59     English      bikini  German (deu)         bikini
# 60      French      bikini  German (deu)         bikini
# 61     Spanish      bikini  German (deu)         bikini
# 62       Dutch      bikini  German (deu)         bikini
# 63     Turkish        bira  German (deu)         pilsen
#
# [64 rows x 4 columns]

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"term_sleeve"}, inplace=True)
#df_word

# %%
#df_lang_1_lang_2_lang_3 = pd.merge(df_lang_1_lang_2_lang_3,df_word, how="inner", on="term_sleeve")
#df_lang_1_lang_2_lang_3

# %%
df_lang_1_lang_2_lang_3.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()} {lang_2.capitalize()}/{lang_1.capitalize()}_And_{lang_3.capitalize()}_Etymologeek_Result5.xlsx", index=False)
