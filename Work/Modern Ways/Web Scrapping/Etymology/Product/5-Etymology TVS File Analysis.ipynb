# %% [markdown]
# ### Etymology TVS File

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize
from pathlib import Path
import shutil

# %% [markdown]
# #### Read TVS And Convert CSV

# %%
#df_tvs = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.tsv", sep="\t")
#df_tvs.rename(columns={"aaq: Pawanobskewi":"column_1","rel:etymological_origin_of":"column_2","eng: Penobscot":"column_3"}, inplace=True)
#df_tvs

# %%
#def low_func(x):
#    try:
#        var_out = x.lower()
#    except:
#        var_out = x
#    return var_out

# %%
#def strip_func(x):
#    try:
#        var_out = x.strip()
#    except:
#        var_out = x
#    return var_out

# %%
#df_col_1 = df_tvs["column_1"].str.split(":", n=-1, expand=True)
#df_col_1 = df_col_1.iloc[:,[0,1]]
#df_col_1.rename(columns={0:"lang",1:"term"}, inplace=True)
#df_col_2 = df_tvs["column_2"].str.split(":", n=-1, expand=True)
#df_col_2 = df_col_2.iloc[:,[1]]
#df_col_2.rename(columns={1:"reltype"}, inplace=True)
#df_col_3 = df_tvs["column_3"].str.split(":", n=-1, expand=True)
#df_col_3 = df_col_3.iloc[:,[0,1]]
#df_col_3.rename(columns={0:"related_lang",1:"related_term"}, inplace=True)

# %%
#df_tvs_expand =  pd.concat([df_col_1,df_col_2,df_col_3], axis=1)
#df_tvs_expand

# %%
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: low_func(x))
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: low_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: strip_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: low_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: low_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: low_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: strip_func(x))

# %%
#df_tvs_expand.to_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv", index=False)

# %% [markdown]
# #### Read CSV File

# %% [markdown]
# ##### Part 1

# %%
df_etymology = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv")
df_etymology
# Out:
#         lang      term                 reltype related_lang   related_term
# 0        aaq    senabe  etymological_origin_of          eng         sannup
# 1        abe  waniigan  etymological_origin_of          eng         wangan
# 2        abe  waniigan  etymological_origin_of          eng       wannigan
# 3        abs      beta  etymological_origin_of          zsm           beta
# 4        adt      yuru  etymological_origin_of          eng           euro
# ...      ...       ...                     ...          ...            ...
# 6031425  zul       ya-  etymological_origin_of          zul  inhlamvu yeso
# 6031426  zul       ya-  etymological_origin_of          zul  inja yasendle
# 6031427  zul       zi-         is_derived_from          zul           izi-
# 6031428  zul      zim-         is_derived_from          zul          izim-
# 6031429  zul      zin-         is_derived_from          zul          izin-
#
# [6031430 rows x 5 columns]

# %%
lang_1 = "tur"  # tur, eng, fra, deu, por, spa, ita, nld, ara, rus
lang_2 = "por"  # tur, eng, fra, deu, por, spa, ita, nld, ara, rus

if lang_1 == "tur":
    lang_3 = "Turkish"
elif lang_1 == "eng":
    lang_3 = "English"
elif lang_1 == "fra":
    lang_3 = "French"
elif lang_1 == "deu":
    lang_3 = "German"
elif lang_1 == "por":
    lang_3 = "Portuguese"
elif lang_1 == "spa":
    lang_3 = "Spanish"
elif lang_1 == "ita":
    lang_3 = "Italian"
elif lang_1 == "nld":
    lang_3 = "Dutch"
elif lang_1 == "ara":
    lang_3 = "Arabic"
elif lang_1 == "rus":
    lang_3 = "Russian"
else:
    pass

if lang_2 == "tur":
    lang_4 = "Turkish"
elif lang_2 == "eng":
    lang_4 = "English"
elif lang_2 == "fra":
    lang_4 = "French"
elif lang_2 == "deu":
    lang_4 = "German"
elif lang_2 == "por":
    lang_4 = "Portuguese"
elif lang_2 == "spa":
    lang_4 = "Spanish"
elif lang_2 == "ita":
    lang_4 = "Italian"
elif lang_2 == "nld":
    lang_4 = "Dutch"
elif lang_2 == "ara":
    lang_4 = "Arabic"
elif lang_2 == "rus":
    lang_4 = "Russian"
else:
    pass

print(f"{lang_1}\n{lang_2}\n{lang_3}\n{lang_4}")
# Out:
# tur
# por
# Turkish
# Portuguese

# %%
#Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
df_lang1 = df_etymology[df_etymology.lang == f"{lang_1.lower()}"]
df_lang1.reset_index(drop=True, inplace=True)
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_1.lower()}")]
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_2.lower()}")]
df_lang1
# Out:
#       lang            term                 reltype related_lang  \
# 118    tur             -cı  etymological_origin_of          lad
# 457    tur            -luk  etymological_origin_of          hbs
# 996    tur             -çi  etymological_origin_of          hye
# 1053   tur  afyonkarahisar  etymological_origin_of          eng
# 1066   tur           allah  etymological_origin_of          rus
# ...    ...             ...                     ...          ...
# 22642  tur            نجار  etymological_origin_of          hye
# 22643  tur            نجار  etymological_origin_of          hye
# 22644  tur          ‏پاشا‎  etymological_origin_of          hun
# 22645  tur            ﮔﺎﻭﺭ  etymological_origin_of          hun
# 22646  tur            ﮔﺎﻭﺭ               etymology          fas
#
#          related_term
# 118              -djí
# 457              -luk
# 996               -չի
# 1053   afyonkarahisar
# 1066            аллах
# ...               ...
# 22642        նաջարյան
# 22643           նաջար
# 22644            pasa
# 22645           gyaur
# 22646             گبر
#
# [2433 rows x 5 columns]

# %%
df_lang2 = df_etymology[df_etymology.lang == f"{lang_2.lower()}"]
df_lang2.reset_index(drop=True, inplace=True)
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_1.lower()}")]
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_2.lower()}")]
df_lang2
# Out:
#       lang    term          reltype related_lang related_term
# 37     por   -agem        etymology          fra         -age
# 46     por   -alha        etymology          ita       -aglia
# 55     por    -ano        etymology          lat        -anus
# 115    por     -ar        etymology          lat         -āre
# 130    por   -dade        etymology          lat       -tatem
# ...    ...     ...              ...          ...          ...
# 27437  por  último        etymology          lat      ultimus
# 27445  por   úmero        etymology          lat       umerus
# 27446  por   úmido        etymology          lat      humidus
# 27450  por   único        etymology          lat       unicus
# 27453  por  únicos  is_derived_from          spa        único
#
# [2704 rows x 5 columns]

# %%
df_lang1_lang2 = pd.merge(df_lang1,df_lang2,how="inner",on=["related_lang","related_term"])
df_lang1_lang2.drop_duplicates(inplace=True)
df_lang1_lang2.reset_index(drop=True, inplace=True)
df_lang1_lang2
# Out:
#    lang_x      term_x               reltype_x related_lang related_term  \
# 0     tur      aristo               etymology          grc  ἀριστοτέλης
# 1     tur     pandora               etymology          grc      πανδώρα
# 2     tur      abajur               etymology          fra    abat-jour
# 3     tur      alyans               etymology          fra     alliance
# 4     tur       amber               etymology          ara         عنبر
# 5     tur       ambi-               etymology          lat        ambi-
# 6     tur      ananas               etymology          fra       ananas
# 7     tur     ağustos               etymology          lat     augustus
# 8     tur   basketbol               etymology          eng   basketball
# 9     tur     biberon               etymology          fra      biberon
# 10    tur    bisiklet               etymology          fra   bicyclette
# 11    tur       bomba               etymology          ita        bomba
# 12    tur      durian               etymology          eng       durian
# 13    tur      durian               etymology          eng       durian
# 14    tur       ekran               etymology          fra        écran
# 15    tur       fetiş               etymology          fra      fétiche
# 16    tur       fetiş               etymology          fra      fétiche
# 17    tur      futbol               etymology          eng     football
# 18    tur       galon               etymology          eng       gallon
# 19    tur      garson               etymology          fra       garçon
# 20    tur         gol               etymology          eng         goal
# 21    tur         gol               etymology          eng         goal
# 22    tur  helikopter               etymology          fra  hélicoptère
# 23    tur      jargon               etymology          fra       jargon
# 24    tur     jelatin               etymology          fra     gélatine
# 25    tur       kazak               etymology          fra      casaque
# 26    tur      korvet               etymology          fra     corvette
# 27    tur      kravat               etymology          fra      cravate
# 28    tur     madalya               etymology          ita     medaglia
# 29    tur    marmelat               etymology          fra    marmelade
# 30    tur        masa               etymology          lat        mensa
# 31    tur     mayonez               etymology          fra   mayonnaise
# 32    tur      mevsim               etymology          ara         موسم
# 33    tur    platform               etymology          fra  plate-forme
# 34    tur    saksafon               etymology          fra    saxophone
# 35    tur     sandviç               etymology          eng     sandwich
# 36    tur      sigara               etymology          spa      cigarro
# 37    tur      sinema               etymology          fra       cinéma
# 38    tur   sosyoloji               etymology          fra   sociologie
# 39    tur     sürpriz               etymology          fra     surprise
# 40    tur     tülbent  etymological_origin_of          ita     turbante
# 41    tur      vajina               etymology          lat       vagina
# 42    tur      vajina               etymology          lat       vagina
# 43    tur      vajina               etymology          lat       vagina
# 44    tur    voleybol               etymology          eng   volleyball
# 45    tur      yoğurt               etymology          ota       یوغورت
#
#    lang_y       term_y               reltype_y
# 0     por  aristóteles               etymology
# 1     por      pandora               etymology
# 2     por       abajur               etymology
# 3     por      aliança               etymology
# 4     por        âmbar               etymology
# 5     por        ambi-               etymology
# 6     por       ananás  etymological_origin_of
# 7     por       agosto               etymology
# 8     por  basquetebol               etymology
# 9     por      biberão               etymology
# 10    por    bicicleta               etymology
# 11    por        bomba               etymology
# 12    por        durio               etymology
# 13    por       durião               etymology
# 14    por         ecrã               etymology
# 15    por      feitiço  etymological_origin_of
# 16    por      fetiche               etymology
# 17    por      futebol               etymology
# 18    por        galão               etymology
# 19    por       garçom               etymology
# 20    por          gol               etymology
# 21    por         golo               etymology
# 22    por  helicóptero               etymology
# 23    por       jargão               etymology
# 24    por     gelatina               etymology
# 25    por       casaca               etymology
# 26    por      corveta               etymology
# 27    por      gravata               etymology
# 28    por      medalha               etymology
# 29    por    marmelada  etymological_origin_of
# 30    por         mesa               etymology
# 31    por     maionese               etymology
# 32    por       monção               etymology
# 33    por   plataforma               etymology
# 34    por     saxofone               etymology
# 35    por    sanduíche               etymology
# 36    por      cigarro               etymology
# 37    por       cinema               etymology
# 38    por   sociologia               etymology
# 39    por     surpresa               etymology
# 40    por     turbante               etymology
# 41    por       bainha               etymology
# 42    por        vagem               etymology
# 43    por       vagina               etymology
# 44    por     voleibol               etymology
# 45    por      iogurte               etymology

# %%
df_lang1_lang2_result1 = df_lang1_lang2.loc[:,["term_x","term_y"]]
df_lang1_lang2_result1.rename(columns={"term_x":"dict_entry_main","term_y":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result1.reset_index(drop=True, inplace=True)
df_lang1_lang2_result1
# Out:
#    dict_entry_main portuguese_word
# 0           aristo     aristóteles
# 1          pandora         pandora
# 2           abajur          abajur
# 3           alyans         aliança
# 4            amber           âmbar
# 5            ambi-           ambi-
# 6           ananas          ananás
# 7          ağustos          agosto
# 8        basketbol     basquetebol
# 9          biberon         biberão
# 10        bisiklet       bicicleta
# 11           bomba           bomba
# 12          durian           durio
# 13          durian          durião
# 14           ekran            ecrã
# 15           fetiş         feitiço
# 16           fetiş         fetiche
# 17          futbol         futebol
# 18           galon           galão
# 19          garson          garçom
# 20             gol             gol
# 21             gol            golo
# 22      helikopter     helicóptero
# 23          jargon          jargão
# 24         jelatin        gelatina
# 25           kazak          casaca
# 26          korvet         corveta
# 27          kravat         gravata
# 28         madalya         medalha
# 29        marmelat       marmelada
# 30            masa            mesa
# 31         mayonez        maionese
# 32          mevsim          monção
# 33        platform      plataforma
# 34        saksafon        saxofone
# 35         sandviç       sanduíche
# 36          sigara         cigarro
# 37          sinema          cinema
# 38       sosyoloji      sociologia
# 39         sürpriz        surpresa
# 40         tülbent        turbante
# 41          vajina          bainha
# 42          vajina           vagem
# 43          vajina          vagina
# 44        voleybol        voleibol
# 45          yoğurt         iogurte

# %% [markdown]
# ##### Part 2

# %%
df_lang1_lang2_result2 = df_etymology[(df_etymology["lang"] == f"{lang_1.lower()}") & (df_etymology["related_lang"] == f"{lang_2.lower()}")]
df_lang1_lang2_result2
# Out:
#         lang       term                 reltype related_lang related_term
# 5906625  tur  karakulak  etymological_origin_of          por      caracal

# %%
df_lang1_lang2_result2 = df_lang1_lang2_result2.loc[:,["term","related_term"]]
df_lang1_lang2_result2.rename(columns={"term":"dict_entry_main","related_term":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result2.reset_index(drop=True, inplace=True)
df_lang1_lang2_result2
# Out:
#   dict_entry_main portuguese_word
# 0       karakulak         caracal

# %% [markdown]
# ##### Concat Part 1 And Part 2

# %%
#df_part1_part2_concat = pd.concat([df_lang1_lang2_word_check,df_lang1_lang2_word_check2], axis=0)
df_part1_part2_concat = pd.concat([df_lang1_lang2_result1,df_lang1_lang2_result2], axis=0)
df_part1_part2_concat.drop_duplicates(inplace=True)
df_part1_part2_concat.reset_index(drop=True, inplace=True)
df_part1_part2_concat
# Out:
#    dict_entry_main portuguese_word
# 0           aristo     aristóteles
# 1          pandora         pandora
# 2           abajur          abajur
# 3           alyans         aliança
# 4            amber           âmbar
# 5            ambi-           ambi-
# 6           ananas          ananás
# 7          ağustos          agosto
# 8        basketbol     basquetebol
# 9          biberon         biberão
# 10        bisiklet       bicicleta
# 11           bomba           bomba
# 12          durian           durio
# 13          durian          durião
# 14           ekran            ecrã
# 15           fetiş         feitiço
# 16           fetiş         fetiche
# 17          futbol         futebol
# 18           galon           galão
# 19          garson          garçom
# 20             gol             gol
# 21             gol            golo
# 22      helikopter     helicóptero
# 23          jargon          jargão
# 24         jelatin        gelatina
# 25           kazak          casaca
# 26          korvet         corveta
# 27          kravat         gravata
# 28         madalya         medalha
# 29        marmelat       marmelada
# 30            masa            mesa
# 31         mayonez        maionese
# 32          mevsim          monção
# 33        platform      plataforma
# 34        saksafon        saxofone
# 35         sandviç       sanduíche
# 36          sigara         cigarro
# 37          sinema          cinema
# 38       sosyoloji      sociologia
# 39         sürpriz        surpresa
# 40         tülbent        turbante
# 41          vajina          bainha
# 42          vajina           vagem
# 43          vajina          vagina
# 44        voleybol        voleibol
# 45          yoğurt         iogurte
# 46       karakulak         caracal

# %%
df_part1_part2_concat.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}/{lang_3.capitalize()} {lang_4.capitalize()}/{lang_3.capitalize()}_And_{lang_4.capitalize()}_Etymologeek_Concat_Result2.xlsx", index=False)
