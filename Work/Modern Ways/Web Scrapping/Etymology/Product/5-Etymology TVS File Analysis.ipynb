# %% [markdown]
# ### Etymology TVS File

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize
from pathlib import Path
import shutil

# %% [markdown]
# #### Read TVS And Convert CSV

# %%
#df_tvs = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.tsv", sep="\t")
#df_tvs.rename(columns={"aaq: Pawanobskewi":"column_1","rel:etymological_origin_of":"column_2","eng: Penobscot":"column_3"}, inplace=True)
#df_tvs

# %%
#def low_func(x):
#    try:
#        var_out = x.lower()
#    except:
#        var_out = x
#    return var_out

# %%
#def strip_func(x):
#    try:
#        var_out = x.strip()
#    except:
#        var_out = x
#    return var_out

# %%
#df_col_1 = df_tvs["column_1"].str.split(":", n=-1, expand=True)
#df_col_1 = df_col_1.iloc[:,[0,1]]
#df_col_1.rename(columns={0:"lang",1:"term"}, inplace=True)
#df_col_2 = df_tvs["column_2"].str.split(":", n=-1, expand=True)
#df_col_2 = df_col_2.iloc[:,[1]]
#df_col_2.rename(columns={1:"reltype"}, inplace=True)
#df_col_3 = df_tvs["column_3"].str.split(":", n=-1, expand=True)
#df_col_3 = df_col_3.iloc[:,[0,1]]
#df_col_3.rename(columns={0:"related_lang",1:"related_term"}, inplace=True)

# %%
#df_tvs_expand =  pd.concat([df_col_1,df_col_2,df_col_3], axis=1)
#df_tvs_expand

# %%
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: low_func(x))
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: low_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: strip_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: low_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: low_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: low_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: strip_func(x))

# %%
#df_tvs_expand.to_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv", index=False)

# %% [markdown]
# #### Read CSV File

# %% [markdown]
# ##### Part 1

# %%
df_etymology = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv")
df_etymology
# Out:
#         lang      term                 reltype related_lang   related_term
# 0        aaq    senabe  etymological_origin_of          eng         sannup
# 1        abe  waniigan  etymological_origin_of          eng         wangan
# 2        abe  waniigan  etymological_origin_of          eng       wannigan
# 3        abs      beta  etymological_origin_of          zsm           beta
# 4        adt      yuru  etymological_origin_of          eng           euro
# ...      ...       ...                     ...          ...            ...
# 6031425  zul       ya-  etymological_origin_of          zul  inhlamvu yeso
# 6031426  zul       ya-  etymological_origin_of          zul  inja yasendle
# 6031427  zul       zi-         is_derived_from          zul           izi-
# 6031428  zul      zim-         is_derived_from          zul          izim-
# 6031429  zul      zin-         is_derived_from          zul          izin-
#
# [6031430 rows x 5 columns]

# %%
lang_1 = "tur"  # tur, eng, fra, deu, por, spa, ita, nld, ara, rus
lang_2 = "ita"  # tur, eng, fra, deu, por, spa, ita, nld, ara, rus

if lang_1 == "tur":
    lang_3 = "Turkish"
elif lang_1 == "eng":
    lang_3 = "English"
elif lang_1 == "fra":
    lang_3 = "French"
elif lang_1 == "deu":
    lang_3 = "German"
elif lang_1 == "por":
    lang_3 = "Portuguese"
elif lang_1 == "spa":
    lang_3 = "Spanish"
elif lang_1 == "ita":
    lang_3 = "Italian"
elif lang_1 == "nld":
    lang_3 = "Dutch"
elif lang_1 == "ara":
    lang_3 = "Arabic"
elif lang_1 == "rus":
    lang_3 = "Russian"
else:
    pass

if lang_2 == "tur":
    lang_4 = "Turkish"
elif lang_2 == "eng":
    lang_4 = "English"
elif lang_2 == "fra":
    lang_4 = "French"
elif lang_2 == "deu":
    lang_4 = "German"
elif lang_2 == "por":
    lang_4 = "Portuguese"
elif lang_2 == "spa":
    lang_4 = "Spanish"
elif lang_2 == "ita":
    lang_4 = "Italian"
elif lang_2 == "nld":
    lang_4 = "Dutch"
elif lang_2 == "ara":
    lang_4 = "Arabic"
elif lang_2 == "rus":
    lang_4 = "Russian"
else:
    pass

print(f"{lang_1}\n{lang_2}\n{lang_3}\n{lang_4}")
# Out:
# tur
# ita
# Turkish
# Italian

# %%
#Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
df_lang1 = df_etymology[df_etymology.lang == f"{lang_1.lower()}"]
df_lang1.reset_index(drop=True, inplace=True)
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_1.lower()}")]
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_2.lower()}")]
df_lang1
# Out:
#       lang            term                 reltype related_lang  \
# 118    tur             -cı  etymological_origin_of          lad
# 457    tur            -luk  etymological_origin_of          hbs
# 996    tur             -çi  etymological_origin_of          hye
# 1053   tur  afyonkarahisar  etymological_origin_of          eng
# 1066   tur           allah  etymological_origin_of          rus
# ...    ...             ...                     ...          ...
# 22642  tur            نجار  etymological_origin_of          hye
# 22643  tur            نجار  etymological_origin_of          hye
# 22644  tur          ‏پاشا‎  etymological_origin_of          hun
# 22645  tur            ﮔﺎﻭﺭ  etymological_origin_of          hun
# 22646  tur            ﮔﺎﻭﺭ               etymology          fas
#
#          related_term
# 118              -djí
# 457              -luk
# 996               -չի
# 1053   afyonkarahisar
# 1066            аллах
# ...               ...
# 22642        նաջարյան
# 22643           նաջար
# 22644            pasa
# 22645           gyaur
# 22646             گبر
#
# [2363 rows x 5 columns]

# %%
df_lang2 = df_etymology[df_etymology.lang == f"{lang_2.lower()}"]
df_lang2.reset_index(drop=True, inplace=True)
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_1.lower()}")]
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_2.lower()}")]
df_lang2
# Out:
#        lang                       term                 reltype related_lang  \
# 1       ita  ''[[angelic]] [[woman]]''  etymological_origin_of          eng
# 2       ita   ''[[golden]] [[bread]]''  etymological_origin_of          eng
# 3       ita  ''[[straw]] and [[hay]]''  etymological_origin_of          eng
# 4       ita   ''[[strong]] [[bread]]''  etymological_origin_of          eng
# 7       ita                     'nduja  etymological_origin_of          eng
# ...     ...                        ...                     ...          ...
# 976972  ita                   zucchini  etymological_origin_of          rus
# 976974  ita                   zucchino  etymological_origin_of          dan
# 977284  ita                          è               etymology          lat
# 977285  ita                    μοῦστος  etymological_origin_of          ell
# 977286  ita                    μοῦστος               etymology          lat
#
#           related_term
# 1       donna angelica
# 2              pandoro
# 3       paglia e fieno
# 4             panforte
# 7                nduja
# ...                ...
# 976972         цуккини
# 976974        zucchini
# 977284             est
# 977285         μούστος
# 977286          mustum
#
# [5533 rows x 5 columns]

# %%
df_lang1_lang2 = pd.merge(df_lang1,df_lang2,how="inner",on=["related_lang","related_term"])
df_lang1_lang2.drop_duplicates(inplace=True)
df_lang1_lang2.reset_index(drop=True, inplace=True)
df_lang1_lang2
# Out:
#    lang_x    term_x               reltype_x related_lang related_term lang_y  \
# 0     tur    aristo               etymology          grc  ἀριστοτέλης    ita
# 1     tur     japon               etymology          fra        japon    ita
# 2     tur   pandora               etymology          grc      πανδώρα    ita
# 3     tur     ambi-               etymology          lat        ambi-    ita
# 4     tur   ağustos               etymology          lat     augustus    ita
# 5     tur      bale               etymology          fra       ballet    ita
# 6     tur     beton               etymology          fra        béton    ita
# 7     tur      büst               etymology          fra        buste    ita
# 8     tur    durian               etymology          eng       durian    ita
# 9     tur      grup               etymology          fra       groupe    ita
# 10    tur    jargon               etymology          fra       jargon    ita
# 11    tur   jelatin               etymology          fra     gélatine    ita
# 12    tur    kabine               etymology          fra      cabinet    ita
# 13    tur    kantin               etymology          fra      cantine    ita
# 14    tur   kapüşon               etymology          fra     capuchon    ita
# 15    tur     kayık  etymological_origin_of          ell        καΐκι    ita
# 16    tur    konser               etymology          fra      concert    ita
# 17    tur   koridor               etymology          fra     corridor    ita
# 18    tur  lacivert               etymology          fas       لاجورد    ita
# 19    tur  manganez               etymology          fra    manganèse    ita
# 20    tur      masa               etymology          lat        mensa    ita
# 21    tur    metres               etymology          fra    maîtresse    ita
# 22    tur    misket               etymology          fra     mousquet    ita
# 23    tur    miskin               etymology          ara        مسكين    ita
# 24    tur      okka  etymological_origin_of          fra         oque    ita
# 25    tur  pantalon               etymology          fra     pantalon    ita
# 26    tur  pantalon               etymology          fra     pantalon    ita
# 27    tur  pantolon               etymology          fra     pantalon    ita
# 28    tur  pantolon               etymology          fra     pantalon    ita
# 29    tur      reis               etymology          ara         رئيس    ita
# 30    tur  sardalya               etymology          ell      σαρδέλα    ita
# 31    tur    sigara               etymology          spa      cigarro    ita
# 32    tur    sinema               etymology          fra       cinéma    ita
# 33    tur    vajina               etymology          lat       vagina    ita
# 34    tur    zürafa               etymology          ara        زرافة    ita
#
#         term_y               reltype_y
# 0   aristotele               etymology
# 1     giappone               etymology
# 2      pandora               etymology
# 3        ambi-               etymology
# 4       agosto               etymology
# 5     balletto  etymological_origin_of
# 6        beton               etymology
# 7        busto  etymological_origin_of
# 8       durian               etymology
# 9       gruppo  etymological_origin_of
# 10    giargone  etymological_origin_of
# 11    gelatina  etymological_origin_of
# 12   gabinetto  etymological_origin_of
# 13     cantina  etymological_origin_of
# 14   cappuccio  etymological_origin_of
# 15      caicco               etymology
# 16    concerto  etymological_origin_of
# 17   corridore  etymological_origin_of
# 18     azzurro               etymology
# 19   manganese  etymological_origin_of
# 20       mensa               etymology
# 21   maitresse               etymology
# 22   moschetto  etymological_origin_of
# 23    meschino               etymology
# 24         oca               etymology
# 25  pantaleone  etymological_origin_of
# 26   pantalone  etymological_origin_of
# 27  pantaleone  etymological_origin_of
# 28   pantalone  etymological_origin_of
# 29        rais               etymology
# 30    sardella  etymological_origin_of
# 31      sigaro               etymology
# 32      cinema               etymology
# 33      vagina               etymology
# 34     giraffa               etymology

# %%
df_lang1_lang2_result1 = df_lang1_lang2.loc[:,["term_x","term_y"]]
df_lang1_lang2_result1.rename(columns={"term_x":"dict_entry_main","term_y":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result1.reset_index(drop=True, inplace=True)
df_lang1_lang2_result1
# Out:
#    dict_entry_main italian_word
# 0           aristo   aristotele
# 1            japon     giappone
# 2          pandora      pandora
# 3            ambi-        ambi-
# 4          ağustos       agosto
# 5             bale     balletto
# 6            beton        beton
# 7             büst        busto
# 8           durian       durian
# 9             grup       gruppo
# 10          jargon     giargone
# 11         jelatin     gelatina
# 12          kabine    gabinetto
# 13          kantin      cantina
# 14         kapüşon    cappuccio
# 15           kayık       caicco
# 16          konser     concerto
# 17         koridor    corridore
# 18        lacivert      azzurro
# 19        manganez    manganese
# 20            masa        mensa
# 21          metres    maitresse
# 22          misket    moschetto
# 23          miskin     meschino
# 24            okka          oca
# 25        pantalon   pantaleone
# 26        pantalon    pantalone
# 27        pantolon   pantaleone
# 28        pantolon    pantalone
# 29            reis         rais
# 30        sardalya     sardella
# 31          sigara       sigaro
# 32          sinema       cinema
# 33          vajina       vagina
# 34          zürafa      giraffa

# %% [markdown]
# ##### Part 2

# %%
df_lang1_lang2_result2 = df_etymology[(df_etymology["lang"] == f"{lang_1.lower()}") & (df_etymology["related_lang"] == f"{lang_2.lower()}")]
df_lang1_lang2_result2
# Out:
#         lang      term    reltype related_lang related_term
# 5897525  tur     abosa  etymology          ita      abbozza
# 5897565  tur    acente  etymology          ita       agente
# 5898522  tur    antika  etymology          ita       antico
# 5899544  tur    balina  etymology          ita       balena
# 5899593  tur     banka  etymology          ita        banca
# ...      ...       ...        ...          ...          ...
# 5916111  tur  çikolata  etymology          ita   cioccolata
# 5916178  tur   çimento  etymology          ita      cemento
# 5916179  tur     çinko  etymology          ita        zinco
# 5917191  tur  i̇ngiliz  etymology          ita      inglese
# 5917753  tur   şırınga  etymology          ita      siringa
#
# [71 rows x 5 columns]

# %%
df_lang1_lang2_result2 = df_lang1_lang2_result2.loc[:,["term","related_term"]]
df_lang1_lang2_result2.rename(columns={"term":"dict_entry_main","related_term":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result2.reset_index(drop=True, inplace=True)
df_lang1_lang2_result2
# Out:
#    dict_entry_main italian_word
# 0            abosa      abbozza
# 1           acente       agente
# 2           antika       antico
# 3           balina       balena
# 4            banka        banca
# ..             ...          ...
# 66        çikolata   cioccolata
# 67         çimento      cemento
# 68           çinko        zinco
# 69        i̇ngiliz      inglese
# 70         şırınga      siringa
#
# [71 rows x 2 columns]

# %% [markdown]
# ##### Concat Part 1 And Part 2

# %%
#df_part1_part2_concat = pd.concat([df_lang1_lang2_word_check,df_lang1_lang2_word_check2], axis=0)
df_part1_part2_concat = pd.concat([df_lang1_lang2_result1,df_lang1_lang2_result2], axis=0)
df_part1_part2_concat.drop_duplicates(inplace=True)
df_part1_part2_concat.reset_index(drop=True, inplace=True)
df_part1_part2_concat
# Out:
#     dict_entry_main italian_word
# 0            aristo   aristotele
# 1             japon     giappone
# 2           pandora      pandora
# 3             ambi-        ambi-
# 4           ağustos       agosto
# ..              ...          ...
# 100        çikolata   cioccolata
# 101         çimento      cemento
# 102           çinko        zinco
# 103        i̇ngiliz      inglese
# 104         şırınga      siringa
#
# [105 rows x 2 columns]

# %%
df_part1_part2_concat.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}/{lang_3.capitalize()} {lang_4.capitalize()}/{lang_3.capitalize()}_And_{lang_4.capitalize()}_Etymologeek_Concat_Result2.xlsx", index=False)
