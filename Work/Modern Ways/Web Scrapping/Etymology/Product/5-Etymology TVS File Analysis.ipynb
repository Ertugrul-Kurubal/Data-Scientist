# %% [markdown]
# ### Etymology TVS File

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize
from pathlib import Path
import shutil

# %% [markdown]
# #### Read TVS And Convert CSV

# %%
#df_tvs = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.tsv", sep="\t")
#df_tvs.rename(columns={"aaq: Pawanobskewi":"column_1","rel:etymological_origin_of":"column_2","eng: Penobscot":"column_3"}, inplace=True)
#df_tvs

# %%
#def low_func(x):
#    try:
#        var_out = x.lower()
#    except:
#        var_out = x
#    return var_out

# %%
#def strip_func(x):
#    try:
#        var_out = x.strip()
#    except:
#        var_out = x
#    return var_out

# %%
#df_col_1 = df_tvs["column_1"].str.split(":", n=-1, expand=True)
#df_col_1 = df_col_1.iloc[:,[0,1]]
#df_col_1.rename(columns={0:"lang",1:"term"}, inplace=True)
#df_col_2 = df_tvs["column_2"].str.split(":", n=-1, expand=True)
#df_col_2 = df_col_2.iloc[:,[1]]
#df_col_2.rename(columns={1:"reltype"}, inplace=True)
#df_col_3 = df_tvs["column_3"].str.split(":", n=-1, expand=True)
#df_col_3 = df_col_3.iloc[:,[0,1]]
#df_col_3.rename(columns={0:"related_lang",1:"related_term"}, inplace=True)

# %%
#df_tvs_expand =  pd.concat([df_col_1,df_col_2,df_col_3], axis=1)
#df_tvs_expand

# %%
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: low_func(x))
#df_tvs_expand["lang"] = df_tvs_expand["lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: low_func(x))
#df_tvs_expand["term"] = df_tvs_expand["term"].apply(lambda x: strip_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: low_func(x))
#df_tvs_expand["reltype"] = df_tvs_expand["reltype"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: low_func(x))
#df_tvs_expand["related_lang"] = df_tvs_expand["related_lang"].apply(lambda x: strip_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: low_func(x))
#df_tvs_expand["related_term"] = df_tvs_expand["related_term"].apply(lambda x: strip_func(x))

# %%
#df_tvs_expand.to_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv", index=False)

# %% [markdown]
# #### Read CSV File

# %% [markdown]
# ##### Part 1

# %%
df_etymology = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymwn.csv")
df_etymology
# Out:
#         lang      term                 reltype related_lang   related_term
# 0        aaq    senabe  etymological_origin_of          eng         sannup
# 1        abe  waniigan  etymological_origin_of          eng         wangan
# 2        abe  waniigan  etymological_origin_of          eng       wannigan
# 3        abs      beta  etymological_origin_of          zsm           beta
# 4        adt      yuru  etymological_origin_of          eng           euro
# ...      ...       ...                     ...          ...            ...
# 6031425  zul       ya-  etymological_origin_of          zul  inhlamvu yeso
# 6031426  zul       ya-  etymological_origin_of          zul  inja yasendle
# 6031427  zul       zi-         is_derived_from          zul           izi-
# 6031428  zul      zim-         is_derived_from          zul          izim-
# 6031429  zul      zin-         is_derived_from          zul          izin-
#
# [6031430 rows x 5 columns]

# %%
lang_1 = "tur"  # tur, eng, fra, deu, por, spa, ita, nld, ara, rus
lang_2 = "nld"  # tur, eng, fra, deu, por, spa, ita, nld, ara, rus

if lang_1 == "tur":
    lang_3 = "Turkish"
elif lang_1 == "eng":
    lang_3 = "English"
elif lang_1 == "fra":
    lang_3 = "French"
elif lang_1 == "deu":
    lang_3 = "German"
elif lang_1 == "por":
    lang_3 = "Portuguese"
elif lang_1 == "spa":
    lang_3 = "Spanish"
elif lang_1 == "ita":
    lang_3 = "Italian"
elif lang_1 == "nld":
    lang_3 = "Dutch"
elif lang_1 == "ara":
    lang_3 = "Arabic"
elif lang_1 == "rus":
    lang_3 = "Russian"
else:
    pass

if lang_2 == "tur":
    lang_4 = "Turkish"
elif lang_2 == "eng":
    lang_4 = "English"
elif lang_2 == "fra":
    lang_4 = "French"
elif lang_2 == "deu":
    lang_4 = "German"
elif lang_2 == "por":
    lang_4 = "Portuguese"
elif lang_2 == "spa":
    lang_4 = "Spanish"
elif lang_2 == "ita":
    lang_4 = "Italian"
elif lang_2 == "nld":
    lang_4 = "Dutch"
elif lang_2 == "ara":
    lang_4 = "Arabic"
elif lang_2 == "rus":
    lang_4 = "Russian"
else:
    pass

print(f"{lang_1}\n{lang_2}\n{lang_3}\n{lang_4}")
# Out:
# tur
# nld
# Turkish
# Dutch

# %%
#Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
df_lang1 = df_etymology[df_etymology.lang == f"{lang_1.lower()}"]
df_lang1.reset_index(drop=True, inplace=True)
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_1.lower()}")]
df_lang1 = df_lang1[~(df_lang1["related_lang"] == f"{lang_2.lower()}")]
df_lang1
# Out:
#       lang            term                 reltype related_lang  \
# 118    tur             -cı  etymological_origin_of          lad
# 457    tur            -luk  etymological_origin_of          hbs
# 996    tur             -çi  etymological_origin_of          hye
# 1053   tur  afyonkarahisar  etymological_origin_of          eng
# 1066   tur           allah  etymological_origin_of          rus
# ...    ...             ...                     ...          ...
# 22642  tur            نجار  etymological_origin_of          hye
# 22643  tur            نجار  etymological_origin_of          hye
# 22644  tur          ‏پاشا‎  etymological_origin_of          hun
# 22645  tur            ﮔﺎﻭﺭ  etymological_origin_of          hun
# 22646  tur            ﮔﺎﻭﺭ               etymology          fas
#
#          related_term
# 118              -djí
# 457              -luk
# 996               -չի
# 1053   afyonkarahisar
# 1066            аллах
# ...               ...
# 22642        նաջարյան
# 22643           նաջար
# 22644            pasa
# 22645           gyaur
# 22646             گبر
#
# [2429 rows x 5 columns]

# %%
df_lang2 = df_etymology[df_etymology.lang == f"{lang_2.lower()}"]
df_lang2.reset_index(drop=True, inplace=True)
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_1.lower()}")]
df_lang2 = df_lang2[~(df_lang2["related_lang"] == f"{lang_2.lower()}")]
df_lang2
# Out:
#        lang                                  term                 reltype  \
# 0       nld  ''[[alsjeblieft]], [[alstublieft]]''  etymological_origin_of
# 1       nld             ''[[spruw]], [[sprouw]]''  etymological_origin_of
# 4       nld                      's-hertogenbosch  etymological_origin_of
# 5       nld                      's-hertogenbosch  etymological_origin_of
# 56      nld                               -achtig               etymology
# ...     ...                                   ...                     ...
# 123639  nld                                zweren               etymology
# 123676  nld                                 zwerm               etymology
# 123723  nld                                zweven               etymology
# 123766  nld                               zwijgen               etymology
# 123783  nld                                 zwijn               etymology
#
#        related_lang      related_term
# 0               afr         asseblief
# 1               eng             sprue
# 4               eng  's-hertogenbosch
# 5               pol  's-hertogenbosch
# 56              dum           -achtig
# ...             ...               ...
# 123639          dum            sweren
# 123676          dum             swarm
# 123723          dum            sweven
# 123766          dum            swigen
# 123783          dum             swijn
#
# [2267 rows x 5 columns]

# %%
df_lang1_lang2 = pd.merge(df_lang1,df_lang2,how="inner",on=["related_lang","related_term"])
df_lang1_lang2.drop_duplicates(inplace=True)
df_lang1_lang2.reset_index(drop=True, inplace=True)
df_lang1_lang2
# Out:
#    lang_x     term_x  reltype_x related_lang related_term lang_y       term_y  \
# 0     tur     aristo  etymology          grc  ἀριστοτέλης    nld  aristoteles
# 1     tur    pandora  etymology          grc      πανδώρα    nld      pandora
# 2     tur     aktris  etymology          fra      actrice    nld      actrice
# 3     tur      anemi  etymology          fra       anémie    nld       anemie
# 4     tur    ağustos  etymology          lat     augustus    nld        oogst
# 5     tur  basketbol  etymology          eng   basketball    nld    basketbal
# 6     tur    bisküvi  etymology          fra      biscuit    nld     beschuit
# 7     tur  enteresan  etymology          fra  intéressant    nld  interessant
# 8     tur    garanti  etymology          fra     garantie    nld     garantie
# 9     tur       grip  etymology          fra       grippe    nld        griep
# 10    tur    kapüşon  etymology          fra     capuchon    nld     capuchon
# 11    tur    karamel  etymology          fra      caramel    nld     caramelo
# 12    tur    karamel  etymology          fra      caramel    nld      karamel
# 13    tur        kek  etymology          eng         cake    nld         kaak
# 14    tur     ketçap  etymology          eng      ketchup    nld      ketchup
# 15    tur   komünizm  etymology          fra   communisme    nld   communisme
# 16    tur      korse  etymology          fra       corset    nld       korset
# 17    tur    mayonez  etymology          fra   mayonnaise    nld    mayonaise
# 18    tur   pasaport  etymology          fra    passeport    nld     paspoort
# 19    tur     poliçe  etymology          ita      polizza    nld        polis
# 20    tur   sekreter  etymology          fra   secrétaire    nld   secretaire
# 21    tur     sembol  etymology          fra      symbole    nld      symbool
# 22    tur       spam  etymology          eng         spam    nld      spammen
# 23    tur    sürpriz  etymology          fra     surprise    nld     surprise
# 24    tur    telefon  etymology          fra    téléphone    nld     telefoon
# 25    tur     vajina  etymology          lat       vagina    nld       vagina
# 26    tur        şef  etymology          fra         chef    nld         chef
#
#                  reltype_y
# 0                etymology
# 1                etymology
# 2                etymology
# 3                etymology
# 4                etymology
# 5                etymology
# 6                etymology
# 7                etymology
# 8                etymology
# 9                etymology
# 10               etymology
# 11  etymological_origin_of
# 12               etymology
# 13               etymology
# 14               etymology
# 15               etymology
# 16               etymology
# 17               etymology
# 18               etymology
# 19               etymology
# 20               etymology
# 21               etymology
# 22               etymology
# 23               etymology
# 24               etymology
# 25               etymology
# 26               etymology

# %%
df_lang1_lang2_result1 = df_lang1_lang2.loc[:,["term_x","term_y"]]
df_lang1_lang2_result1.rename(columns={"term_x":"dict_entry_main","term_y":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result1.reset_index(drop=True, inplace=True)
df_lang1_lang2_result1
# Out:
#    dict_entry_main   dutch_word
# 0           aristo  aristoteles
# 1          pandora      pandora
# 2           aktris      actrice
# 3            anemi       anemie
# 4          ağustos        oogst
# 5        basketbol    basketbal
# 6          bisküvi     beschuit
# 7        enteresan  interessant
# 8          garanti     garantie
# 9             grip        griep
# 10         kapüşon     capuchon
# 11         karamel     caramelo
# 12         karamel      karamel
# 13             kek         kaak
# 14          ketçap      ketchup
# 15        komünizm   communisme
# 16           korse       korset
# 17         mayonez    mayonaise
# 18        pasaport     paspoort
# 19          poliçe        polis
# 20        sekreter   secretaire
# 21          sembol      symbool
# 22            spam      spammen
# 23         sürpriz     surprise
# 24         telefon     telefoon
# 25          vajina       vagina
# 26             şef         chef

# %% [markdown]
# ##### Part 2

# %%
df_lang1_lang2_result2 = df_etymology[(df_etymology["lang"] == f"{lang_1.lower()}") & (df_etymology["related_lang"] == f"{lang_2.lower()}")]
df_lang1_lang2_result2
# Out:
#         lang     term                 reltype related_lang related_term
# 5909345  tur   minare  etymological_origin_of          nld      minaret
# 5909918  tur   odalık  etymological_origin_of          nld      odalisk
# 5913941  tur  tülbent  etymological_origin_of          nld      tulband
# 5913942  tur  tülbent  etymological_origin_of          nld         tulp
# 5914475  tur    vezir  etymological_origin_of          nld       vizier

# %%
df_lang1_lang2_result2 = df_lang1_lang2_result2.loc[:,["term","related_term"]]
df_lang1_lang2_result2.rename(columns={"term":"dict_entry_main","related_term":f"{lang_4.lower()}_word"}, inplace=True)
df_lang1_lang2_result2.reset_index(drop=True, inplace=True)
df_lang1_lang2_result2
# Out:
#   dict_entry_main dutch_word
# 0          minare    minaret
# 1          odalık    odalisk
# 2         tülbent    tulband
# 3         tülbent       tulp
# 4           vezir     vizier

# %% [markdown]
# ##### Concat Part 1 And Part 2

# %%
#df_part1_part2_concat = pd.concat([df_lang1_lang2_word_check,df_lang1_lang2_word_check2], axis=0)
df_part1_part2_concat = pd.concat([df_lang1_lang2_result1,df_lang1_lang2_result2], axis=0)
df_part1_part2_concat.drop_duplicates(inplace=True)
df_part1_part2_concat.reset_index(drop=True, inplace=True)
df_part1_part2_concat
# Out:
#    dict_entry_main   dutch_word
# 0           aristo  aristoteles
# 1          pandora      pandora
# 2           aktris      actrice
# 3            anemi       anemie
# 4          ağustos        oogst
# 5        basketbol    basketbal
# 6          bisküvi     beschuit
# 7        enteresan  interessant
# 8          garanti     garantie
# 9             grip        griep
# 10         kapüşon     capuchon
# 11         karamel     caramelo
# 12         karamel      karamel
# 13             kek         kaak
# 14          ketçap      ketchup
# 15        komünizm   communisme
# 16           korse       korset
# 17         mayonez    mayonaise
# 18        pasaport     paspoort
# 19          poliçe        polis
# 20        sekreter   secretaire
# 21          sembol      symbool
# 22            spam      spammen
# 23         sürpriz     surprise
# 24         telefon     telefoon
# 25          vajina       vagina
# 26             şef         chef
# 27          minare      minaret
# 28          odalık      odalisk
# 29         tülbent      tulband
# 30         tülbent         tulp
# 31           vezir       vizier

# %%
df_part1_part2_concat.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_3.capitalize()}/{lang_3.capitalize()} {lang_4.capitalize()}/{lang_3.capitalize()}_And_{lang_4.capitalize()}_Etymologeek_Concat_Result2.xlsx", index=False)
