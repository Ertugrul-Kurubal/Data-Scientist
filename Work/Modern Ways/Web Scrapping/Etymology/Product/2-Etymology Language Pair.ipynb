# %% [markdown]
# ### Etymology Language Pair

# %%
import pandas as pd
import numpy as np
import glob
import nltk
from nltk import word_tokenize
from pathlib import Path
import shutil

# %% [markdown]
# #### All Etymology File Concat

# %%
#all_etymologeek_file = glob.glob("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/*/*_Etymologeek_Main_And_Additional_Result.xlsx")
#all_etymologeek_file

# %%
#df_etymologeek_all = pd.DataFrame()
#for i in all_etymologeek_file:
#    df_var = pd.read_excel(f"{i}")
#    df_etymologeek_all = pd.concat([df_etymologeek_all, df_var], axis=0)
#df_etymologeek_all.drop_duplicates(inplace=True)
#df_etymologeek_all.reset_index(drop=True, inplace=True)
#df_etymologeek_all

# %%
#df_etymologeek_all.to_excel("All_Etymology_Language_Pair_Result.xlsx", index=False)

# %% [markdown]
# #### Read Etymologeek All Data

# %%
df_etymologeek_all = pd.read_excel("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/All_Etymology_Language_Pair_Result.xlsx")
df_etymologeek_all
# Out:
#        search_word dict_entry_main   language_main  \
# 0              bir             bir   Crimean Tatar
# 1              bir             bir   Crimean Tatar
# 2              bir             bir  Middle English
# 3              bir             bir  Middle English
# 4              bir             bir  Middle English
# ...            ...             ...             ...
# 668525        إلين           إلينا          Arabic
# 668526       مستقر           مستقر          Arabic
# 668527       مستقر           مستقر          Arabic
# 668528        صيني           صينية          Arabic
# 668529        صيني           صينية          Arabic
#
#                                           definition_main       dict_entry  \
# 0                (Numeral) (cardinal) one.(cardinal) one.             *bīr
# 1                (Numeral) (cardinal) one.(cardinal) one.              bir
# 2       (Noun) A charge on an account.. A strong or fa...           *buriz
# 3       (Noun) A charge on an account.. A strong or fa...        *bʰrewh₁-
# 4       (Noun) A charge on an account.. A strong or fa...           *buriz
# ...                                                   ...              ...
# 668525                              (Adverb) To us.To us.            إلينا
# 668526  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...            مستقر
# 668528  (Noun) (usually definite) Chinese language.(us...  لُغَة صِينِيَّة
# 668529  (Noun) (usually definite) Chinese language.(us...            صينية
#
#                              language  \
# 0              Proto-Turkic (trk-pro)
# 1                 Crimean Tatar (crh)
# 2            Proto-Germanic (gem-pro)
# 3       Proto-Indo-European (ine-pro)
# 4            Proto-Germanic (gem-pro)
# ...                               ...
# 668525                   Arabic (ara)
# 668526                         Arabic
# 668527                         Arabic
# 668528                   Arabic (ara)
# 668529                   Arabic (ara)
#
#                                                definition
# 0                                                    One.
# 1                                         (cardinal) one.
# 2                                    Male offspring; son.
# 3                                                     NaN
# 4                                        Elevation; hill.
# ...                                                   ...
# 668525                                             To us.
# 668526  (Adjective) Confessing. Firm, solid, stable. F...
# 668527  (Noun) Fixed domicile, fixed residence, fixed ...
# 668528                                                NaN
# 668529               (usually definite) Chinese language.
#
# [668530 rows x 7 columns]

# %%
#df_etymologeek_all["language_main"].unique()

# %%
#df_etymologeek_all["language"].unique()

# %%
lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "Turkish (tur)"  # English (eng), Turkish (tur), German (deu), French (fra), Spanish (spa), Arabic (ara), Russian (rus), 
                          # Portuguese (por), Dutch (nld), Italian (ita)

# %%
Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
df_lang_pair1 = df_etymologeek_all[(df_etymologeek_all["language_main"] == f"{lang_1.capitalize()}") & (df_etymologeek_all["language"] == f"{lang_2.capitalize()}")]
df_lang_pair1

# %%
df_lang_pair1["dict_entry_main"] = df_lang_pair1["dict_entry_main"].apply(lambda x: x.lower())
df_lang_pair1["dict_entry"] = df_lang_pair1["dict_entry"].apply(lambda x: x.lower())
df_lang_pair1 = df_lang_pair1.drop_duplicates(subset="dict_entry_main")
df_lang_pair1.reset_index(drop=True, inplace=True)
df_lang_pair1

# %%
#df_lang_pair1.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result1.xlsx", index=False)

# %% [markdown]
# #### Read Github Cross Data

# %% [markdown]
# ##### Part 1

# %%
df_github_cross = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_cross_check2.csv")
df_github_cross
# Out:
#                         term_id     lang      term                    reltype  \
# 0        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra             inherited_from
# 1        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 2        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 3        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# 4        LHuH1RvcUjWNUTR6QQF8fg  Spanish   palabra               derived_from
# ...                         ...      ...       ...                        ...
# 8854119  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa             inherited_from
# 8854120  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854121  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854122  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa  etymologically_related_to
# 8854123  3q28WGgPWs2K_SSglCAWvQ  Catalan  petitesa                 cognate_of
#
#                 related_term_id    related_lang related_term
# 0        9w90qvZDUH-2OHPVZEGJSQ  Middle english       parlai
# 1        Uy6v5wWuW6KGH4aTqGWnmA      Old french       parler
# 2        HY24XyCcUZCYSa1Q6y2kPA      Late latin     parabolō
# 3        uXGtk5g-W8G_TlTxSHImpg           Latin     parabola
# 4        JHVmHqAPXEq-YaIbd0B5Jg   Ancient greek     παραβολή
# ...                         ...             ...          ...
# 8854119  TUnsO83vXXC1Us5rJgGyUg    Vulgar latin    *pittitus
# 8854120  oUnwLLsHVymmwwiRXgrRow           Latin     pitinnus
# 8854121  IGRZaHQ-VU-vpxMjdxSTlA           Latin      pitulus
# 8854122  MDRrWciZWXGEj1KR9MUWtg           Latin     piccinus
# 8854123  SUJISOECWc6fDH00I_cTRQ          French        petit
#
# [8854124 rows x 7 columns]

# %%
lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
lang_2 = "German"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_1.capitalize()}/{lang_1.capitalize()} {lang_2.capitalize()}").mkdir(parents=True, exist_ok=True)
Path(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()} {lang_2.capitalize()}").mkdir(parents=True, exist_ok=True)

# %%
def low_func(x):
    try:
        var_out = x.lower()
    except:
        var_out = x
    return var_out

# %%
df_lang1 = df_github_cross[(df_github_cross["lang"] == f"{lang_1.capitalize()}")] 
df_lang1
# Out:
#                         term_id     lang       term  \
# 110      caAhC_cAXrKZU9rCcPAaPw  Turkish        göl
# 817      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 818      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 819      SC0fKM3-VcGTWvelEkpEXw  Turkish         ön
# 1345     5bVUD53NVEWYY0QAetV7iA  Turkish        net
# ...                         ...      ...        ...
# 8853155  nxRVOzFvUzS4X7r165GWcw  Turkish  ordinatör
# 8853651  pl-cU0pBVda2_BuEjBmtZw  Turkish     virman
# 8853652  pl-cU0pBVda2_BuEjBmtZw  Turkish     virman
# 8853831  fc8biERQXFicQGtfESBJQQ  Turkish   angajman
# 8853832  fc8biERQXFicQGtfESBJQQ  Turkish   angajman
#
#                            reltype         related_term_id  related_lang  \
# 110                 inherited_from  T6Wxr8YPVWK47B34DsG6KA  Proto-turkic
# 817                 inherited_from  nlVlgr5dUjas0_4GqplLJQ  Proto-turkic
# 818                 inherited_from  5g1DdR5OUPOxiQxCVcGW6A  Proto-turkic
# 819                 inherited_from  6KC332NQU7Sx9sFKEv6QdQ  Proto-turkic
# 1345                inherited_from  Ru1rzGVDWpi2rTYD9-XJWQ    Old french
# ...                            ...                     ...           ...
# 8853155  etymologically_related_to  tPEd3hNNXqeBt17YkY3I2Q        French
# 8853651       has_prefix_with_root  9CJvE6k0WJmKvcWZQmQjxw        French
# 8853652                 has_suffix  8YtrMi5VXlSpZVOupUTcWg        French
# 8853831       has_prefix_with_root  qQY-6sksXJe832mC9wIBqQ        French
# 8853832                 has_suffix  8YtrMi5VXlSpZVOupUTcWg        French
#
#         related_term
# 110             *kȫl
# 817              *ǖn
# 818              *öŋ
# 819              *oŋ
# 1345             net
# ...              ...
# 8853155  calculateur
# 8853651        virer
# 8853652         ment
# 8853831      engager
# 8853832         ment
#
# [27421 rows x 7 columns]

# %%
#df_lang1.to_excel("Turkish_Word_From_Other_Language.xlsx", index=False)

# %%
df_lang2 = df_github_cross[(df_github_cross["lang"] == f"{lang_2.capitalize()}")]
df_lang2["term"] = df_lang2["term"].apply(lambda x: x.lower())
#df_lang2.rename(columns={"term":"word"}, inplace=True)
df_lang2
# Out:
# <ipython-input-11-74392beaa152>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang2["term"] = df_lang2["term"].apply(lambda x: x.lower())
#                         term_id    lang             term  \
# 262      VJCmKVj1UVWabrwADX_pXg  German  glaubwürdigkeit
# 263      VJCmKVj1UVWabrwADX_pXg  German  glaubwürdigkeit
# 359      VJCmKVj1UVWabrwADX_pXg  German  glaubwürdigkeit
# 360      VJCmKVj1UVWabrwADX_pXg  German  glaubwürdigkeit
# 362      VJCmKVj1UVWabrwADX_pXg  German  glaubwürdigkeit
# ...                         ...     ...              ...
# 8854110  r_86_CzTUmiwftlGf3Raow  German        vordertür
# 8854111  r_86_CzTUmiwftlGf3Raow  German        vordertür
# 8854112  r_86_CzTUmiwftlGf3Raow  German        vordertür
# 8854113  r_86_CzTUmiwftlGf3Raow  German        vordertür
# 8854114  r_86_CzTUmiwftlGf3Raow  German        vordertür
#
#                            reltype         related_term_id  \
# 262           has_prefix_with_root  uY3srVpwXpeZz9yoQCMJ0Q
# 263                     has_suffix  u0cxLIEBUgCaPeIzJ3KBTA
# 359      etymologically_related_to  0iJmkQEIUyuluDZUqxbIZA
# 360      etymologically_related_to  _rM8NkgIUkaIu3XC1uJOxA
# 362      etymologically_related_to  -eYSAXKzUFCZ1aIP7II3EA
# ...                            ...                     ...
# 8854110                   has_root  m3x2SwwSVTqo0z7BYCuvog
# 8854111             inherited_from  VVztb_yGWTGW48g315-kFw
# 8854112               derived_from  jHu4wk_dUomgDTuM9lsHRg
# 8854113               derived_from  m3x2SwwSVTqo0z7BYCuvog
# 8854114                 cognate_of  3V6Kju5-UsuoXD_jCoQO9w
#
#                 related_lang related_term
# 262                   German      glauben
# 263                   German       würdig
# 359       Middle high german          -ec
# 360                   German          -ig
# 362                   German        -heit
# ...                      ...          ...
# 8854110  Proto-indo-european      *dʰwer-
# 8854111      Old high german         turi
# 8854112       Proto-germanic        *durz
# 8854113  Proto-indo-european      *dʰwer-
# 8854114              English         door
#
# [377295 rows x 7 columns]

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word

# %%
#df_lang2 = pd.merge(df_lang2,df_word,how="inner",on="word")
#df_lang2

# %%
set_lang1 = set(df_lang1["related_term_id"])
set_lang2= set(df_lang2["related_term_id"])

# %%
df_pair_etymology = pd.DataFrame(set_lang1.intersection(set_lang2),columns=["related_term_id"])
df_pair_etymology
# Out:
#              related_term_id
# 0     1cWo7W-AVfy4UdztSrE4JA
# 1     LQ0ji49CUfeW2lHsmcakOA
# 2     PJW0liLoVAG_K4fM2upifg
# 3     Vp7ixNnEUrGG7rSTBTLlug
# 4     kKQX6nPBUteEKpyEijHuLA
# ...                      ...
# 3283  54tJQ8guU--CitIpqts3sA
# 3284  YZB_2zN8XNmmHTTgkQJWQQ
# 3285  Tt9L1vKqXkmBQdjff7dGnA
# 3286  kYs_cEs_XJGCIbiu9fNbeg
# 3287  RyvIosX7XSmWqPIPLe11nw
#
# [3288 rows x 1 columns]

# %%
df_etymology_merge = pd.merge(df_github_cross,df_pair_etymology,how="inner",on="related_term_id")
df_etymology_merge.drop_duplicates(inplace=True)
df_etymology_merge
# Out:
#                        term_id     lang          term  \
# 0       Sa9PLd8wVye-T_9yUc0DOw  English   unflappable
# 1       nFXAVxL6VNq-21U7oEJWsA  English  unacquainted
# 2       M8zwjHLNWTKJPvER9iEqLQ  English      acentric
# 3       f-6H0YHIV3yXEDrMC4MjIw  English       acephal
# 4       Vjv-9CLGXRutFlCYSi_bvg  English   investigate
# ...                        ...      ...           ...
# 633839  V9z1h5PSXI-yWTzu4cvGZg  Turkish  Dağ Türkleri
# 633840  -HGzC0v1UzeYXLss27-oLw   German    Bergtürken
# 633841  V9z1h5PSXI-yWTzu4cvGZg  Turkish  Dağ Türkleri
# 633842  -HGzC0v1UzeYXLss27-oLw   German    Bergtürken
# 633843  V9z1h5PSXI-yWTzu4cvGZg  Turkish  Dağ Türkleri
#
#                           reltype         related_term_id related_lang  \
# 0                      cognate_of  J5FnlsOjVgWaY5_YXTRlOg        Latin
# 1                      cognate_of  J5FnlsOjVgWaY5_YXTRlOg        Latin
# 2                      cognate_of  J5FnlsOjVgWaY5_YXTRlOg        Latin
# 3                      cognate_of  J5FnlsOjVgWaY5_YXTRlOg        Latin
# 4                       has_affix  J5FnlsOjVgWaY5_YXTRlOg        Latin
# ...                           ...                     ...          ...
# 633839  etymologically_related_to  YIdyTNbrWJexvLhvJGbtnw       German
# 633840  etymologically_related_to  q3-B4Yc8XVaaNMUAnjvcHA       German
# 633841  etymologically_related_to  q3-B4Yc8XVaaNMUAnjvcHA       German
# 633842  etymologically_related_to  OuxWlSLLWc2k4mV4T_XOwg       German
# 633843  etymologically_related_to  OuxWlSLLWc2k4mV4T_XOwg       German
#
#        related_term
# 0               in-
# 1               in-
# 2               in-
# 3               in-
# 4               in-
# ...             ...
# 633839       Türken
# 633840      Osmanen
# 633841      Osmanen
# 633842  Turkalbaner
# 633843  Turkalbaner
#
# [633844 rows x 7 columns]

# %%
df_etymology_merge = df_etymology_merge[(df_etymology_merge["reltype"] == "inherited_from") | (df_etymology_merge["reltype"] == "etymologically_related_to") | (df_etymology_merge["reltype"] == "derived_from") | (df_etymology_merge["reltype"] == "borrowed_from")]
df_etymology_merge
# Out:
#                        term_id     lang          term  \
# 5       t7OyFm0yX0GAYfsAUUJDVg  English     immutable
# 7       x4GxbqEbVPaSnq787vZTpw  English   irrefutably
# 8       0PnroPxZVsi9oNfDcSnv1w  English   irregularly
# 9       3c-cgHzfVOiSsJColbZdiA  English   irremovable
# 10      driFreohUxitXzgvlgQo0A  English    iniquitous
# ...                        ...      ...           ...
# 633839  V9z1h5PSXI-yWTzu4cvGZg  Turkish  Dağ Türkleri
# 633840  -HGzC0v1UzeYXLss27-oLw   German    Bergtürken
# 633841  V9z1h5PSXI-yWTzu4cvGZg  Turkish  Dağ Türkleri
# 633842  -HGzC0v1UzeYXLss27-oLw   German    Bergtürken
# 633843  V9z1h5PSXI-yWTzu4cvGZg  Turkish  Dağ Türkleri
#
#                           reltype         related_term_id related_lang  \
# 5                    derived_from  J5FnlsOjVgWaY5_YXTRlOg        Latin
# 7       etymologically_related_to  J5FnlsOjVgWaY5_YXTRlOg        Latin
# 8       etymologically_related_to  J5FnlsOjVgWaY5_YXTRlOg        Latin
# 9       etymologically_related_to  J5FnlsOjVgWaY5_YXTRlOg        Latin
# 10      etymologically_related_to  J5FnlsOjVgWaY5_YXTRlOg        Latin
# ...                           ...                     ...          ...
# 633839  etymologically_related_to  YIdyTNbrWJexvLhvJGbtnw       German
# 633840  etymologically_related_to  q3-B4Yc8XVaaNMUAnjvcHA       German
# 633841  etymologically_related_to  q3-B4Yc8XVaaNMUAnjvcHA       German
# 633842  etymologically_related_to  OuxWlSLLWc2k4mV4T_XOwg       German
# 633843  etymologically_related_to  OuxWlSLLWc2k4mV4T_XOwg       German
#
#        related_term
# 5               in-
# 7               in-
# 8               in-
# 9               in-
# 10              in-
# ...             ...
# 633839       Türken
# 633840      Osmanen
# 633841      Osmanen
# 633842  Turkalbaner
# 633843  Turkalbaner
#
# [388028 rows x 7 columns]

# %%
df_etymology_merge = df_etymology_merge[~df_etymology_merge["related_term"].str.contains(fr"(?:\s|^)\*|\-(?:\s|$)", na=True)]
df_etymology_merge
# Out:
#                        term_id              lang          term  \
# 10886   Sa9PLd8wVye-T_9yUc0DOw           English   unflappable
# 10887   nFXAVxL6VNq-21U7oEJWsA           English  unacquainted
# 10888   PkGNd3GKX4GltfR8xYhcag           English         ounce
# 10890   _b7Fi6LGWp26DvbLPhRDog    Middle english         ounce
# 10891   J682Gr_pWyqab5AR1FYjVA  Norwegian bokmål         ounce
# ...                        ...               ...           ...
# 633839  V9z1h5PSXI-yWTzu4cvGZg           Turkish  Dağ Türkleri
# 633840  -HGzC0v1UzeYXLss27-oLw            German    Bergtürken
# 633841  V9z1h5PSXI-yWTzu4cvGZg           Turkish  Dağ Türkleri
# 633842  -HGzC0v1UzeYXLss27-oLw            German    Bergtürken
# 633843  V9z1h5PSXI-yWTzu4cvGZg           Turkish  Dağ Türkleri
#
#                           reltype         related_term_id related_lang  \
# 10886               borrowed_from  H-2YVn9qXryY0R5E5yibQw        Latin
# 10887               borrowed_from  H-2YVn9qXryY0R5E5yibQw        Latin
# 10888   etymologically_related_to  H-2YVn9qXryY0R5E5yibQw        Latin
# 10890   etymologically_related_to  H-2YVn9qXryY0R5E5yibQw        Latin
# 10891   etymologically_related_to  H-2YVn9qXryY0R5E5yibQw        Latin
# ...                           ...                     ...          ...
# 633839  etymologically_related_to  YIdyTNbrWJexvLhvJGbtnw       German
# 633840  etymologically_related_to  q3-B4Yc8XVaaNMUAnjvcHA       German
# 633841  etymologically_related_to  q3-B4Yc8XVaaNMUAnjvcHA       German
# 633842  etymologically_related_to  OuxWlSLLWc2k4mV4T_XOwg       German
# 633843  etymologically_related_to  OuxWlSLLWc2k4mV4T_XOwg       German
#
#        related_term
# 10886          ūnus
# 10887          ūnus
# 10888          ūnus
# 10890          ūnus
# 10891          ūnus
# ...             ...
# 633839       Türken
# 633840      Osmanen
# 633841      Osmanen
# 633842  Turkalbaner
# 633843  Turkalbaner
#
# [243274 rows x 7 columns]

# %%
df_lang1_result = df_etymology_merge[(df_etymology_merge["lang"]==f"{lang_1.capitalize()}")]
df_lang1_result.drop_duplicates(inplace=True)
df_lang1_result.reset_index(drop=True, inplace=True)
df_lang1_result
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                      term_id     lang          term  \
# 0     ps8w0BEzV2iu0c_dmeDBHg  Turkish           inç
# 1     mEUGVqfcUN23TCses5HH0w  Turkish           sos
# 2     rfNVjePlV46YQPsn7C4k_w  Turkish         salça
# 3     QDVQAg50WQymOq6pxRgCYw  Turkish       parabol
# 4     yglj90QEWaGcUI2-FXe41Q  Turkish       palavra
# ...                      ...      ...           ...
# 2151  V9z1h5PSXI-yWTzu4cvGZg  Turkish  Dağ Türkleri
# 2152  V9z1h5PSXI-yWTzu4cvGZg  Turkish  Dağ Türkleri
# 2153  V9z1h5PSXI-yWTzu4cvGZg  Turkish  Dağ Türkleri
# 2154  V9z1h5PSXI-yWTzu4cvGZg  Turkish  Dağ Türkleri
# 2155  V9z1h5PSXI-yWTzu4cvGZg  Turkish  Dağ Türkleri
#
#                         reltype         related_term_id related_lang  \
# 0     etymologically_related_to  H-2YVn9qXryY0R5E5yibQw        Latin
# 1     etymologically_related_to  mytX5yvAXFeG3OZ4QuAEag        Latin
# 2     etymologically_related_to  mytX5yvAXFeG3OZ4QuAEag        Latin
# 3                 borrowed_from  rTuNNlxpW-K1LOPUlrghlw   Late latin
# 4     etymologically_related_to  fS3-uXGaUqmu9O5GHb3cLg      English
# ...                         ...                     ...          ...
# 2151  etymologically_related_to  V9z1h5PSXI-yWTzu4cvGZg      Turkish
# 2152  etymologically_related_to  -HGzC0v1UzeYXLss27-oLw       German
# 2153  etymologically_related_to  YIdyTNbrWJexvLhvJGbtnw       German
# 2154  etymologically_related_to  q3-B4Yc8XVaaNMUAnjvcHA       German
# 2155  etymologically_related_to  OuxWlSLLWc2k4mV4T_XOwg       German
#
#       related_term
# 0             ūnus
# 1            saliō
# 2            saliō
# 3         parabola
# 4          parable
# ...            ...
# 2151  Dağ Türkleri
# 2152    Bergtürken
# 2153        Türken
# 2154       Osmanen
# 2155   Turkalbaner
#
# [2156 rows x 7 columns]

# %%
df_lang1_result["term"] = df_lang1_result["term"].apply(lambda x: low_func(x))
df_lang1_result["related_term"] = df_lang1_result["related_term"].apply(lambda x: low_func(x))
df_lang1_result = df_lang1_result.loc[:,["lang","term","related_term_id"]]
df_lang1_result
# Out:
# <ipython-input-20-e326500b988f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_result["term"] = df_lang1_result["term"].apply(lambda x: low_func(x))
# <ipython-input-20-e326500b988f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_result["related_term"] = df_lang1_result["related_term"].apply(lambda x: low_func(x))
#          lang          term         related_term_id
# 0     Turkish           inç  H-2YVn9qXryY0R5E5yibQw
# 1     Turkish           sos  mytX5yvAXFeG3OZ4QuAEag
# 2     Turkish         salça  mytX5yvAXFeG3OZ4QuAEag
# 3     Turkish       parabol  rTuNNlxpW-K1LOPUlrghlw
# 4     Turkish       palavra  fS3-uXGaUqmu9O5GHb3cLg
# ...       ...           ...                     ...
# 2151  Turkish  dağ türkleri  V9z1h5PSXI-yWTzu4cvGZg
# 2152  Turkish  dağ türkleri  -HGzC0v1UzeYXLss27-oLw
# 2153  Turkish  dağ türkleri  YIdyTNbrWJexvLhvJGbtnw
# 2154  Turkish  dağ türkleri  q3-B4Yc8XVaaNMUAnjvcHA
# 2155  Turkish  dağ türkleri  OuxWlSLLWc2k4mV4T_XOwg
#
# [2156 rows x 3 columns]

# %%
df_lang2_result = df_etymology_merge[(df_etymology_merge["lang"]==f"{lang_2.capitalize()}")]
df_lang2_result.drop_duplicates(inplace=True)
df_lang2_result.reset_index(drop=True, inplace=True)
df_lang2_result
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                      term_id    lang           term  \
# 0     Ew_D07cxUmes02_ekhfM9w  German          Union
# 1     GPblIyqWWrua1abEagXoeQ  German     nonchalant
# 2     CA-fyH-BUy2akJtkgrAe9g  German           ent-
# 3     DA3j3wIIW1ylp_bxqYMMtw  German      Münzunion
# 4     WZ-XND_VWJ-I1ShBZMfZlg  German  Währungsunion
# ...                      ...     ...            ...
# 7130  -HGzC0v1UzeYXLss27-oLw  German     Bergtürken
# 7131  -HGzC0v1UzeYXLss27-oLw  German     Bergtürken
# 7132  -HGzC0v1UzeYXLss27-oLw  German     Bergtürken
# 7133  -HGzC0v1UzeYXLss27-oLw  German     Bergtürken
# 7134  -HGzC0v1UzeYXLss27-oLw  German     Bergtürken
#
#                         reltype         related_term_id related_lang  \
# 0                  derived_from  H-2YVn9qXryY0R5E5yibQw        Latin
# 1     etymologically_related_to  H-2YVn9qXryY0R5E5yibQw        Latin
# 2                 borrowed_from  H-2YVn9qXryY0R5E5yibQw        Latin
# 3                  derived_from  H-2YVn9qXryY0R5E5yibQw        Latin
# 4                  derived_from  H-2YVn9qXryY0R5E5yibQw        Latin
# ...                         ...                     ...          ...
# 7130  etymologically_related_to  V9z1h5PSXI-yWTzu4cvGZg      Turkish
# 7131  etymologically_related_to  -HGzC0v1UzeYXLss27-oLw       German
# 7132  etymologically_related_to  YIdyTNbrWJexvLhvJGbtnw       German
# 7133  etymologically_related_to  q3-B4Yc8XVaaNMUAnjvcHA       German
# 7134  etymologically_related_to  OuxWlSLLWc2k4mV4T_XOwg       German
#
#       related_term
# 0             ūnus
# 1             ūnus
# 2             ūnus
# 3             ūnus
# 4             ūnus
# ...            ...
# 7130  Dağ Türkleri
# 7131    Bergtürken
# 7132        Türken
# 7133       Osmanen
# 7134   Turkalbaner
#
# [7135 rows x 7 columns]

# %%
df_lang2_result["term"] = df_lang2_result["term"].apply(lambda x: low_func(x))
df_lang2_result["related_term"] = df_lang2_result["related_term"].apply(lambda x: low_func(x))
df_lang2_result = df_lang2_result.loc[:,["lang","term","related_term_id"]]
df_lang2_result
# Out:
# <ipython-input-22-808639a87f81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang2_result["term"] = df_lang2_result["term"].apply(lambda x: low_func(x))
# <ipython-input-22-808639a87f81>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang2_result["related_term"] = df_lang2_result["related_term"].apply(lambda x: low_func(x))
#         lang           term         related_term_id
# 0     German          union  H-2YVn9qXryY0R5E5yibQw
# 1     German     nonchalant  H-2YVn9qXryY0R5E5yibQw
# 2     German           ent-  H-2YVn9qXryY0R5E5yibQw
# 3     German      münzunion  H-2YVn9qXryY0R5E5yibQw
# 4     German  währungsunion  H-2YVn9qXryY0R5E5yibQw
# ...      ...            ...                     ...
# 7130  German     bergtürken  V9z1h5PSXI-yWTzu4cvGZg
# 7131  German     bergtürken  -HGzC0v1UzeYXLss27-oLw
# 7132  German     bergtürken  YIdyTNbrWJexvLhvJGbtnw
# 7133  German     bergtürken  q3-B4Yc8XVaaNMUAnjvcHA
# 7134  German     bergtürken  OuxWlSLLWc2k4mV4T_XOwg
#
# [7135 rows x 3 columns]

# %%
df_same_ety = pd.merge(df_lang1_result,df_lang2_result, how="inner", on="related_term_id", suffixes=["_master","_sleeve"])
df_same_ety = df_same_ety[["lang_master","term_master","lang_sleeve","term_sleeve"]]
df_same_ety.drop_duplicates(inplace=True)
df_same_ety
# Out:
#      lang_master term_master lang_sleeve     term_sleeve
# 0        Turkish         inç      German           union
# 1        Turkish         inç      German      nonchalant
# 2        Turkish         inç      German            ent-
# 3        Turkish         inç      German       münzunion
# 4        Turkish         inç      German   währungsunion
# ...          ...         ...         ...             ...
# 7982     Turkish      berber      German      berberaffe
# 7984     Turkish     emirlik      German          emirat
# 7985     Turkish    emretmek      German          emirat
# 7987     Turkish     bilanço      German      bilanziell
# 7988     Turkish     bilanço      German  zwischenbilanz
#
# [5269 rows x 4 columns]

# %%
df_same_ety.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()} {lang_2.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result2.xlsx", index=False)

# %% [markdown]
# ##### Part 2

# %%
df_github_clean = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_clean.csv")
df_github_clean
# Out:
#                            lang         term        reltype  \
# 0                       English    thesaurus  borrowed_from
# 1                       English    thesaurus   derived_from
# 2                       English    thesaurus   doublet_with
# 3                         Latin    thesaurus   derived_from
# 4                       English  portmanteau       has_root
# ...                         ...          ...            ...
# 3484911                 English        Boell  borrowed_from
# 3484912                 English        Boell  borrowed_from
# 3484913  South Levantine Arabic       بالمية      has_affix
# 3484914  South Levantine Arabic       بالمية      has_affix
# 3484915                 English       Cooler   derived_from
#
#                    related_lang  related_term
# 0                         Latin     thēsaurus
# 1                 Ancient Greek      θησαυρός
# 2                       English      treasure
# 3                 Ancient Greek      θησαυρός
# 4           Proto-Indo-European  *per- (fare)
# ...                         ...           ...
# 3484911                  Danish          Bøll
# 3484912                  German          Böll
# 3484913  South Levantine Arabic            بـ
# 3484914  South Levantine Arabic        الميّة
# 3484915                  German        Kühler
#
# [3484916 rows x 5 columns]

# %%
#lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
#lang_2 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang1_lang2 = df_github_clean[(df_github_clean["lang"] == f"{lang_1.capitalize()}") & (df_github_clean["related_lang"] == f"{lang_2.capitalize()}")]
df_lang1_lang2["term"] = df_lang1_lang2["term"].apply(lambda x: low_func(x))
df_lang1_lang2["related_term"] = df_lang1_lang2["related_term"].apply(lambda x: low_func(x))
df_lang1_lang2.reset_index(drop=True, inplace=True)
df_lang1_lang2
# Out:
# <ipython-input-27-b67a13c1e2b0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_lang2["term"] = df_lang1_lang2["term"].apply(lambda x: low_func(x))
# <ipython-input-27-b67a13c1e2b0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang1_lang2["related_term"] = df_lang1_lang2["related_term"].apply(lambda x: low_func(x))
#        lang          term                    reltype related_lang  \
# 0   Turkish       şibidak              borrowed_from       German
# 1   Turkish       hamburg              borrowed_from       German
# 2   Turkish       element               derived_from       German
# 3   Turkish     hamburger               derived_from       German
# 4   Turkish       volfram              borrowed_from       German
# 5   Turkish        bizmut               derived_from       German
# 6   Turkish        şablon              borrowed_from       German
# 7   Turkish         kuruş               derived_from       German
# 8   Turkish        kuvars              borrowed_from       German
# 9   Turkish         enzim               derived_from       German
# 10  Turkish   lihtenştayn              borrowed_from       German
# 11  Turkish         revir              borrowed_from       German
# 12  Turkish    hinterlant              borrowed_from       German
# 13  Turkish     haymatlos               derived_from       German
# 14  Turkish   sözdizimsel  etymologically_related_to       German
# 15  Turkish        dilmaç                 cognate_of       German
# 16  Turkish         dübel              borrowed_from       German
# 17  Turkish  dağ türkleri  etymologically_related_to       German
# 18  Turkish        şalter              borrowed_from       German
# 19  Turkish        doçent              borrowed_from       German
# 20  Turkish         şilep               derived_from       German
#
#      related_term
# 0     schiebedach
# 1         hamburg
# 2         element
# 3       hamburger
# 4         wolfram
# 5          wismut
# 6       schablone
# 7        groschen
# 8           quarz
# 9           enzym
# 10  liechtenstein
# 11         revier
# 12     hinterland
# 13      heimatlos
# 14      sözdizimi
# 15    dolmetscher
# 16          dübel
# 17     bergtürken
# 18       schalter
# 19         dozent
# 20       schleppe

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"related_term"}, inplace=True)
#df_word

# %%
#df_lang1_lang2 = pd.merge(df_lang1_lang2,df_word, how="inner", on="related_term")
#df_lang1_lang2

# %%
df_lang1_lang2.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()} {lang_2.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result3.xlsx", index=False)

# %% [markdown]
# ##### Part 3

# %%
df_github_cross = pd.read_csv("/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/All/etymology_cross_check2.csv")
df_github_cross

# %%
#lang_1 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian
#lang_2 = "Portuguese"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

# %%
df_lang_pair2 = df_github_cross[(df_github_cross["lang"] == f"{lang_1.capitalize()}") & (df_github_cross["related_lang"] == f"{lang_2.capitalize()}")]
df_lang_pair2.drop_duplicates(inplace=True)
df_lang_pair2.reset_index(drop=True, inplace=True)
df_lang_pair2
# Out:
# /home/kurubal/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                    term_id     lang          term                    reltype  \
# 0   6w-klkZFXAyAzKSyLHQmbQ  Turkish        kambur                 cognate_of
# 1   J43uukryXfOQpVmu3Mclsw  Turkish      portakal  etymologically_related_to
# 2   nKtdn0o-VCSEinitYJNNjg  Turkish         piyon                 cognate_of
# 3   D6Qd-awbUrGtU8oEnPkQZg  Turkish        ananas               derived_from
# 4   D6Qd-awbUrGtU8oEnPkQZg  Turkish        ananas              borrowed_from
# 5   KMoSa6bHVcCO4eR3UjcCWA  Turkish          port               derived_from
# 6   2ftpHNtyVWC5mBk14Z0rQA  Turkish         Japon               derived_from
# 7   AOG0aJ6AVcmbRlIgldVC_Q  Turkish       Japonca               derived_from
# 8   qPjbBcFkUSmZY8FOXLB1_w  Turkish       bisküvi                 cognate_of
# 9   r_3y4CJPWQCBH_b4BGrPNQ  Turkish       Almanya                 cognate_of
# 10  6BfKYSjyX_KQa6O76ODjJA  Turkish      şampanya                 cognate_of
# 11  jeI0lYIpWGu77hbh8DGrpg  Turkish          plaj                 cognate_of
# 12  JyYxz7irVoyqUWYLZhLhTA  Turkish         banka                 cognate_of
# 13  8Ep6TbuVWlmFWfRH6mQYKw  Turkish         tente                 cognate_of
# 14  kwjxLIXiVEiy9eIL9L38bg  Turkish         fetiş              borrowed_from
# 15  eETePepRXbS0ZI2GwflirQ  Turkish        tayfun  etymologically_related_to
# 16  w0umVRLfWqqd2_MjuzhYxQ  Turkish         yarın                 cognate_of
# 17  4Bt61e-TWTCstf3ch07qSw  Turkish       kaşalot              borrowed_from
# 18  4Bt61e-TWTCstf3ch07qSw  Turkish       kaşalot  etymologically_related_to
# 19  r4boOTeEWf-J-q9FrtVZsw  Turkish  Japon balığı               derived_from
# 20  kz1DVnl0USu0VY_KWkQ5lw  Turkish     mandalina              borrowed_from
# 21  vWZNR7waVS615uTLYo8KgA  Turkish      karamela               derived_from
# 22  Qy9sROryXN-_5FX-XFQ5oQ  Turkish       karamel               derived_from
# 23  sMbssQ6OW7eNvg9PpAVlCQ  Turkish      marmelat               derived_from
# 24  Vgy7m0w8VeyR1tD4sfuHsg  Turkish          şato                 cognate_of
# 25  42V7R3YLUTCo65hOMNF8Hg  Turkish          jöle                 cognate_of
# 26  s2YIZzs_WZy_xp2pQMlhOw  Turkish  akselerasyon                 cognate_of
# 27  gyONY4q5VR2YmvoDEs3hEg  Turkish      İspanyol                 cognate_of
# 28  2bMIkqQ0WXiOFsfXTpjhYA  Turkish       komando               derived_from
# 29  ynZFsn7bUhKGlETSI-J8Pg  Turkish      kampanya                 cognate_of
# 30  Mw1RBi4aVNuJtdy7FZhm-A  Turkish          staj                 cognate_of
# 31  9fwr5fGQXd6EO85NBDuUuw  Turkish        peyzaj                 cognate_of
# 32  VwyeQ2JlVNe4cDMsedjm_A  Turkish     bocalamak                 cognate_of
# 33  VwyeQ2JlVNe4cDMsedjm_A  Turkish     bocalamak                 cognate_of
# 34  xjb75pjCUgOHa9gchR-Tcw  Turkish       bandıra                 cognate_of
#
#            related_term_id related_lang related_term
# 0   eTA9UZP2XyakahRkcOBP5w   Portuguese      cambiar
# 1   aU-MkKELV9WJX7MbJA-mcg   Portuguese     Portugal
# 2   bBL_Ezf3Whu5VwOFu1UEgg   Portuguese         peão
# 3   9PGP0CqcWQWJSkPOgrQH2w   Portuguese       ananás
# 4   9PGP0CqcWQWJSkPOgrQH2w   Portuguese       ananás
# 5   G3OXgqFtX_CcH1cCat23CQ   Portuguese        Porto
# 6   Ekv4ESQeXC2YaP_Jczt9fw   Portuguese        Japão
# 7   Ekv4ESQeXC2YaP_Jczt9fw   Portuguese        Japão
# 8   IcMHBj5rUhi1bPWWEArQaQ   Portuguese     biscoito
# 9   k9vrGopkXkWal_yobAYCgA   Portuguese     Alemanha
# 10  qWtefDSEU8CPKM02Ch4L0Q   Portuguese     campanha
# 11  -6_YtLYsUxaqIZDLC1sfIw   Portuguese        praia
# 12  v_ANCPMtXRuPFFJfQ9HZfg   Portuguese        banco
# 13  epRcNvDBVFOIxBmyU3ZnDg   Portuguese        tenda
# 14  Da1PowNbXrye6t80ufsDMg   Portuguese      feitiço
# 15  mumzPUEcV2S7MXcewQM5aw   Portuguese        tufão
# 16  FPcaEETqWlyYXTkHWGTJXw   Portuguese        manhã
# 17  zT2UwZuKWFa-pBmf6-vBjw   Portuguese    cachalote
# 18  om63uYCfWVmpKb50zUrBFA   Portuguese      cachola
# 19  Ekv4ESQeXC2YaP_Jczt9fw   Portuguese        Japão
# 20  v3yr9dzXWfCDOh1xJmqvDw   Portuguese     mandarim
# 21  bkXaKl56VcW3tCW9EkKuuA   Portuguese     caramelo
# 22  bkXaKl56VcW3tCW9EkKuuA   Portuguese     caramelo
# 23  fOFOq2lFX_6hTJxCC1KMoA   Portuguese    marmelada
# 24  MGhvFlPhVn-LAXoK1FRpoQ   Portuguese      castelo
# 25  MrRMzx6OVvCuDZsWXpaP9Q   Portuguese        geada
# 26  ZdkVOzckUGe-G0epe9VQMQ   Portuguese   aceleração
# 27  2vfCMhmuViiLVN3FkpiUFQ   Portuguese     espanhol
# 28  4fEwn0tDVj-q6bZYV0j6Hw   Portuguese      comando
# 29  qWtefDSEU8CPKM02Ch4L0Q   Portuguese     campanha
# 30  5o-BksKwUSmrrTe4S-GtfA   Portuguese      estágio
# 31  W5xys8xrVMe_--0ITmjqZg   Portuguese     paisagem
# 32  rf-e6xznVKm9_Kg5ySW2Qw   Portuguese        pojar
# 33  lSXPAhanVQmP7KbGvp-kEA   Portuguese       apoiar
# 34  DKJlmxfwWba22obgV0xAzw   Portuguese     bandeira

# %%
df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: low_func(x))
df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: low_func(x))
# Out:
# <ipython-input-34-d80e4b8b2bc1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["term"] = df_lang_pair2["term"].apply(lambda x: low_func(x))
# <ipython-input-34-d80e4b8b2bc1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lang_pair2["related_term"] = df_lang_pair2["related_term"].apply(lambda x: low_func(x))

# %%
#df_word = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/{lang_2.capitalize()}/Result/Word/Merge/Word_Merge2.xlsx")
#df_word = df_word.head(40000)
#df_word = df_word.loc[:,["word"]]
#df_word.rename(columns={"word":"related_term"}, inplace=True)
#df_word

# %%
#df_lang_pair2 = pd.merge(df_lang_pair2,df_word, how="inner", on="related_term")
#df_lang_pair2

# %%
df_lang_pair2 = df_lang_pair2[(df_lang_pair2["reltype"] == "cognate_of") | (df_lang_pair2["reltype"] == "etymologically_related_to") | (df_lang_pair2["reltype"] == "derived_from") | (df_lang_pair2["reltype"] == "borrowed_from")]
df_lang_pair2 = df_lang_pair2.loc[:,["lang","term","reltype","related_lang","related_term"]]
df_lang_pair2.reset_index(drop=True, inplace=True)
df_lang_pair2
# Out:
#        lang          term                    reltype related_lang related_term
# 0   Turkish        kambur                 cognate_of   Portuguese      cambiar
# 1   Turkish      portakal  etymologically_related_to   Portuguese     portugal
# 2   Turkish         piyon                 cognate_of   Portuguese         peão
# 3   Turkish        ananas               derived_from   Portuguese       ananás
# 4   Turkish        ananas              borrowed_from   Portuguese       ananás
# 5   Turkish          port               derived_from   Portuguese        porto
# 6   Turkish         japon               derived_from   Portuguese        japão
# 7   Turkish       japonca               derived_from   Portuguese        japão
# 8   Turkish       bisküvi                 cognate_of   Portuguese     biscoito
# 9   Turkish       almanya                 cognate_of   Portuguese     alemanha
# 10  Turkish      şampanya                 cognate_of   Portuguese     campanha
# 11  Turkish          plaj                 cognate_of   Portuguese        praia
# 12  Turkish         banka                 cognate_of   Portuguese        banco
# 13  Turkish         tente                 cognate_of   Portuguese        tenda
# 14  Turkish         fetiş              borrowed_from   Portuguese      feitiço
# 15  Turkish        tayfun  etymologically_related_to   Portuguese        tufão
# 16  Turkish         yarın                 cognate_of   Portuguese        manhã
# 17  Turkish       kaşalot              borrowed_from   Portuguese    cachalote
# 18  Turkish       kaşalot  etymologically_related_to   Portuguese      cachola
# 19  Turkish  japon balığı               derived_from   Portuguese        japão
# 20  Turkish     mandalina              borrowed_from   Portuguese     mandarim
# 21  Turkish      karamela               derived_from   Portuguese     caramelo
# 22  Turkish       karamel               derived_from   Portuguese     caramelo
# 23  Turkish      marmelat               derived_from   Portuguese    marmelada
# 24  Turkish          şato                 cognate_of   Portuguese      castelo
# 25  Turkish          jöle                 cognate_of   Portuguese        geada
# 26  Turkish  akselerasyon                 cognate_of   Portuguese   aceleração
# 27  Turkish     i̇spanyol                 cognate_of   Portuguese     espanhol
# 28  Turkish       komando               derived_from   Portuguese      comando
# 29  Turkish      kampanya                 cognate_of   Portuguese     campanha
# 30  Turkish          staj                 cognate_of   Portuguese      estágio
# 31  Turkish        peyzaj                 cognate_of   Portuguese     paisagem
# 32  Turkish     bocalamak                 cognate_of   Portuguese        pojar
# 33  Turkish     bocalamak                 cognate_of   Portuguese       apoiar
# 34  Turkish       bandıra                 cognate_of   Portuguese     bandeira

# %%
df_lang_pair2.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()} {lang_2.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Result4.xlsx", index=False)
