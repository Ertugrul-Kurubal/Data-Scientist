# %% [markdown]
# ### Etymology Concat Result Merge

# %%
import pandas as pd
import numpy as np
import glob
import re
import nltk
from nltk import word_tokenize
from pathlib import Path
import shutil

# %%
lang_1 = "English"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian 
lang_2 = "Turkish"  # English, Turkish, German, French, Spanish, Arabic, Russian, Portuguese, Dutch, Italian

if lang_2 == "English":
    lang_3 = "English (eng)"
elif lang_2 == "Turkish":
    lang_3 = "Turkish (tur)"
elif lang_2 == "German":
    lang_3 = "German (deu)"
elif lang_2 == "French":
    lang_3 = "French (fra)"
elif lang_2 == "Spanish":
    lang_3 = "Spanish (spa)"
elif lang_2 == "Arabic":
    lang_3 = "Arabic (ara)"
elif lang_2 == "Russian":
    lang_3 = "Russian (rus)"
elif lang_2 == "Portuguese":
    lang_3 = "Portuguese (por)"
elif lang_2 == "Dutch":
    lang_3 = "Dutch (nld)"
elif lang_2 == "Italian":
    lang_3 = "Italian (ita)"
else:
    pass

print(f"{lang_1}\n{lang_2}\n{lang_3}")
# Out:
# English
# Turkish
# Turkish (tur)

# %%
df_concat1 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Concat_Result1.xlsx")
df_concat1
# Out:
#      dict_entry_main turkish_word
# 0               taco         taco
# 1             bikini       bikini
# 2             factor       faktör
# 3          factorage       faktör
# 4          factoress       faktör
# ...              ...          ...
# 3475           lavta        lavta
# 3476           cizye        cizye
# 3477           abaza        abaza
# 3478         persian       farsça
# 3479            orda         ordu
#
# [3480 rows x 2 columns]

# %%
df_concat2 = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Concat_Result2.xlsx")
df_concat2
# Out:
#     dict_entry_main turkish_word
# 0        al jazeera       cezire
# 1           algiedi        ciddi
# 2             allah        allah
# 3         aristotle       aristo
# 4          augustus      ağustos
# ..              ...          ...
# 396           yuruk        yürük
# 397            zarf         zarf
# 398          ziamet       zeamet
# 399            zill          zil
# 400           zurna        zurna
#
# [401 rows x 2 columns]

# %%
df_merge_result = pd.concat([df_concat1,df_concat2], axis=0)
df_merge_result.drop_duplicates(inplace=True)
df_merge_result.reset_index(drop=True, inplace=True)
df_merge_result
# Out:
#      dict_entry_main turkish_word
# 0               taco         taco
# 1             bikini       bikini
# 2             factor       faktör
# 3          factorage       faktör
# 4          factoress       faktör
# ...              ...          ...
# 3759         yardang      yardang
# 3760         yashmak       yaşmak
# 3761           yuruk        yürük
# 3762            zarf         zarf
# 3763          ziamet       zeamet
#
# [3764 rows x 2 columns]

# %%
df_merge_result.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_3.capitalize()}_Etymologeek_Result_All.xlsx", index=False)

# %% [markdown]
# #### Compare All Cross Word With Result

# %%
df_all_cross = pd.read_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web Scrapping/Data/{lang_1.capitalize()}/{lang_1.capitalize()}_All_Word_From_{lang_2.capitalize()}_Etymology.xlsx")
df_all_cross
# Out:
#       lang_master   term_master lang_sleeve term_sleeve
# 0         English          taco     Turkish        taco
# 1         English        bikini     Turkish      bikini
# 2         English        factor     Turkish      fatura
# 3         English        façade     Turkish      fatura
# 4         English         facto     Turkish      fatura
# ...           ...           ...         ...         ...
# 94066     English  uzbekization     Turkish          öz
# 94067     English  balkanistics     Turkish      balkan
# 94068     English     demirjian     Turkish     demirci
# 94069     English       alikhan     Turkish       kağan
# 94070     English      elchibey     Turkish         bey
#
# [94071 rows x 4 columns]

# %%
df_all_cross.rename(columns={"term_master":"dict_entry_main", "term_sleeve":f"{lang_2.lower()}_word"}, inplace=True)
df_all_cross
# Out:
#       lang_master dict_entry_main lang_sleeve turkish_word
# 0         English            taco     Turkish         taco
# 1         English          bikini     Turkish       bikini
# 2         English          factor     Turkish       fatura
# 3         English          façade     Turkish       fatura
# 4         English           facto     Turkish       fatura
# ...           ...             ...         ...          ...
# 94066     English    uzbekization     Turkish           öz
# 94067     English    balkanistics     Turkish       balkan
# 94068     English       demirjian     Turkish      demirci
# 94069     English         alikhan     Turkish        kağan
# 94070     English        elchibey     Turkish          bey
#
# [94071 rows x 4 columns]

# %%
df_merge_result
# Out:
#      dict_entry_main turkish_word
# 0               taco         taco
# 1             bikini       bikini
# 2             factor       faktör
# 3          factorage       faktör
# 4          factoress       faktör
# ...              ...          ...
# 3759         yardang      yardang
# 3760         yashmak       yaşmak
# 3761           yuruk        yürük
# 3762            zarf         zarf
# 3763          ziamet       zeamet
#
# [3764 rows x 2 columns]

# %%
df_collective = pd.merge(df_all_cross,df_merge_result, how="inner", on="dict_entry_main")
df_collective = df_collective.loc[:,["lang_master","dict_entry_main","lang_sleeve",f"{lang_2.lower()}_word_x"]]
df_collective.rename(columns={f"{lang_2.lower()}_word_x":f"{lang_2.lower()}_word"}, inplace=True)
df_collective
# Out:
#      lang_master dict_entry_main lang_sleeve turkish_word
# 0        English            taco     Turkish         taco
# 1        English          bikini     Turkish       bikini
# 2        English          factor     Turkish       fatura
# 3        English          factor     Turkish        efekt
# 4        English         fashion     Turkish       fatura
# ...          ...             ...         ...          ...
# 5715     English           yasak     Turkish        yasak
# 5716     English        balkano-     Turkish       balkan
# 5717     English       uzbekness     Turkish           öz
# 5718     English     pistachioed     Turkish       fıstık
# 5719     English      haremesque     Turkish        harem
#
# [5720 rows x 4 columns]

# %%
df_not_collective = pd.concat([df_all_cross,df_collective]).drop_duplicates(keep=False)
df_not_collective.reset_index(drop=True, inplace=True)
df_not_collective
# Out:
#       lang_master dict_entry_main lang_sleeve turkish_word
# 0         English          façade     Turkish       fatura
# 1         English           facto     Turkish       fatura
# 2         English          facade     Turkish       fatura
# 3         English        artefact     Turkish       fatura
# 4         English         fazenda     Turkish       fatura
# ...           ...             ...         ...          ...
# 88378     English    uzbekization     Turkish           öz
# 88379     English    balkanistics     Turkish       balkan
# 88380     English       demirjian     Turkish      demirci
# 88381     English         alikhan     Turkish        kağan
# 88382     English        elchibey     Turkish          bey
#
# [88383 rows x 4 columns]

# %%
df_not_collective.to_excel(f"/media/kurubal/SSD/Data Scientist/Work/Modern Ways/Project/Web \
Scrapping/Result/{lang_1.capitalize()}/{lang_1.capitalize()}_And_{lang_2.capitalize()}_Etymologeek_Additional_Result.xlsx", index=False)
