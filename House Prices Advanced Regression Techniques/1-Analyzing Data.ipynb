# %% [markdown]
# ## House Price Prediction

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
df_sub = pd.read_csv("sample_submission.csv")
df_test = pd.read_csv("test.csv")
df_train = pd.read_csv("train.csv")

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
# 2       Norm     1Fam     2Story            5            5       1997
# 3       Norm     1Fam     2Story            6            6       1998
# 4       Norm   TwnhsE     1Story            8            5       1992
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 2          1998     Gable  CompShg     VinylSd     VinylSd       None
# 3          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       TA       TA           No
# 1       108.0        TA        TA     CBlock       TA       TA           No
# 2         0.0        TA        TA      PConc       Gd       TA           No
# 3        20.0        TA        TA      PConc       TA       TA           No
# 4         0.0        Gd        TA      PConc       Gd       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          Rec       468.0          LwQ       144.0      270.0        882.0
# 1          ALQ       923.0          Unf         0.0      406.0       1329.0
# 2          GLQ       791.0          Unf         0.0      137.0        928.0
# 3          GLQ       602.0          Unf         0.0      324.0        926.0
# 4          ALQ       263.0          Unf         0.0     1017.0       1280.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr       896         0             0
# 1    GasA        TA          Y      SBrkr      1329         0             0
# 2    GasA        Gd          Y      SBrkr       928       701             0
# 3    GasA        Ex          Y      SBrkr       926       678             0
# 4    GasA        Ex          Y      SBrkr      1280         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        896           0.0           0.0         1         0             2
# 1       1329           0.0           0.0         1         1             3
# 2       1629           0.0           0.0         2         1             3
# 3       1604           0.0           0.0         2         1             3
# 4       1280           0.0           0.0         2         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             5        Typ           0         NaN
# 1             1          Gd             6        Typ           0         NaN
# 2             1          TA             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             5        Typ           0         NaN
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       1961.0          Unf         1.0       730.0         TA
# 1     Attchd       1958.0          Unf         1.0       312.0         TA
# 2     Attchd       1997.0          Fin         2.0       482.0         TA
# 3     Attchd       1998.0          Fin         2.0       470.0         TA
# 4     Attchd       1992.0          RFn         2.0       506.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y         140            0              0          0
# 1         TA          Y         393           36              0          0
# 2         TA          Y         212           34              0          0
# 3         TA          Y         360           36              0          0
# 4         TA          Y           0           82              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0          120         0    NaN  MnPrv         NaN        0       6    2010
# 1            0         0    NaN    NaN        Gar2    12500       6    2010
# 2            0         0    NaN  MnPrv         NaN        0       3    2010
# 3            0         0    NaN    NaN         NaN        0       6    2010
# 4          144         0    NaN    NaN         NaN        0       1    2010
#
#   SaleType SaleCondition
# 0       WD        Normal
# 1       WD        Normal
# 2       WD        Normal
# 3       WD        Normal
# 4       WD        Normal

# %%
df_test.shape
# Out:
# (1459, 80)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df_train.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# dtype: int64

# %% [markdown]
# ### Analyzing NaN Values

# %% [markdown]
# #### LotFrontage

# %%
df_train.LotFrontage.value_counts()
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 90.0      23
# 21.0      23
# 64.0      19
# 68.0      19
# 24.0      19
# 73.0      18
# 79.0      17
# 55.0      17
# 72.0      17
# 63.0      17
# 100.0     16
# 74.0      15
# 66.0      15
# 51.0      15
# 52.0      14
# 59.0      13
# 82.0      12
# 43.0      12
# 40.0      12
# 71.0      12
# 67.0      12
# 57.0      12
# 76.0      11
# 69.0      11
# 92.0      10
# 53.0      10
# 88.0      10
# 34.0      10
# 86.0      10
# 84.0       9
# 77.0       9
# 35.0       9
# 44.0       9
# 62.0       9
# 61.0       8
# 98.0       8
# 96.0       8
# 93.0       8
# 58.0       7
# 120.0      7
# 95.0       7
# 107.0      7
# 91.0       6
# 110.0      6
# 41.0       6
# 81.0       6
# 89.0       6
# 30.0       6
# 105.0      6
# 36.0       6
# 94.0       6
# 54.0       6
# 48.0       6
# 87.0       5
# 56.0       5
# 83.0       5
# 37.0       5
# 32.0       5
# 47.0       5
# 102.0      4
# 42.0       4
# 49.0       4
# 103.0      3
# 104.0      3
# 130.0      3
# 99.0       3
# 108.0      3
# 45.0       3
# 97.0       2
# 129.0      2
# 115.0      2
# 313.0      2
# 109.0      2
# 174.0      2
# 114.0      2
# 101.0      2
# 121.0      2
# 124.0      2
# 116.0      2
# 134.0      2
# 122.0      2
# 118.0      2
# 106.0      1
# 46.0       1
# 150.0      1
# 137.0      1
# 153.0      1
# 168.0      1
# 182.0      1
# 39.0       1
# 144.0      1
# 140.0      1
# 160.0      1
# 141.0      1
# 128.0      1
# 33.0       1
# 152.0      1
# 112.0      1
# 138.0      1
# 149.0      1
# 38.0       1
# 111.0      1
# Name: LotFrontage, dtype: int64

# %%
df_train.LotFrontage.describe().T
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
df_test.LotFrontage.describe().T
# Out:
# count    1232.000000
# mean       68.580357
# std        22.376841
# min        21.000000
# 25%        58.000000
# 50%        67.000000
# 75%        80.000000
# max       200.000000
# Name: LotFrontage, dtype: float64

# %%
plt.figure(figsize=(9,7))
sns.histplot(x="LotFrontage", data=df_train, kde=True);

# %%
plt.figure(figsize=(9,7))
sns.histplot(x="LotFrontage", data=df_test, kde=True);

# %%
df_train.LotFrontage.fillna(df_train.LotFrontage.mean(), inplace=True)

# %%
df_test.LotFrontage.fillna(df_test.LotFrontage.mean(), inplace=True)

# %%
df_train.LotFrontage.isnull().sum()
# Out:
# 0

# %%
df_test.LotFrontage.isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Alley

# %%
df_train.Alley.value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
df_test.Alley.value_counts()
# Out:
# Grvl    70
# Pave    37
# Name: Alley, dtype: int64

# %%
df_train.Alley.sample(10)
# Out:
# 1300    NaN
# 332     NaN
# 1142    NaN
# 1436    NaN
# 524     NaN
# 185     NaN
# 1067    NaN
# 304     NaN
# 658     NaN
# 1225    NaN
# Name: Alley, dtype: object

# %%
df_train.Alley.fillna("NoAccess", inplace=True)

# %%
df_test.Alley.fillna("NoAccess", inplace=True)

# %%
# def fill_value(data, col, old, new):
#     for i in data[col]:
#         if i == old:
#             i == new
#         else:
#             i == i

# %%
df_train.Alley.value_counts()
# Out:
# NoAccess    1369
# Grvl          50
# Pave          41
# Name: Alley, dtype: int64

# %%
df_test.Alley.value_counts() # Apply LabelEncoder or get_dummies
# Out:
# NoAccess    1352
# Grvl          70
# Pave          37
# Name: Alley, dtype: int64

# %% [markdown]
# #### BsmtQual

# %%
df_train.BsmtQual
# Out:
# 0       Gd
# 1       Gd
# 2       Gd
# 3       TA
# 4       Gd
#         ..
# 1455    Gd
# 1456    Gd
# 1457    TA
# 1458    TA
# 1459    TA
# Name: BsmtQual, Length: 1460, dtype: object

# %%
df_train.BsmtQual.value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
df_train.BsmtQual.fillna("NoBsmnt", inplace=True)

# %%
df_test.BsmtQual.fillna("NoBsmnt", inplace=True)

# %%
df_train.BsmtQual.value_counts()
# Out:
# TA         649
# Gd         618
# Ex         121
# NoBsmnt     37
# Fa          35
# Name: BsmtQual, dtype: int64

# %%
df_test.BsmtQual.value_counts() # Apply OrdinalEncoder
# Out:
# TA         634
# Gd         591
# Ex         137
# Fa          53
# NoBsmnt     44
# Name: BsmtQual, dtype: int64

# %% [markdown]
# #### BsmtCond

# %%
df_train.BsmtCond.sample(10)
# Out:
# 524      TA
# 137      TA
# 1041     TA
# 431      TA
# 1229     TA
# 466      Gd
# 1011    NaN
# 611      TA
# 715      TA
# 651      TA
# Name: BsmtCond, dtype: object

# %%
df_train.BsmtCond.fillna("NoBsmnt", inplace=True)

# %%
df_test.BsmtCond.fillna("NoBsmnt", inplace=True)

# %%
df_train.BsmtCond.value_counts()
# Out:
# TA         1311
# Gd           65
# Fa           45
# NoBsmnt      37
# Po            2
# Name: BsmtCond, dtype: int64

# %%
df_test.BsmtCond.value_counts()
# Out:
# TA         1295
# Fa           59
# Gd           57
# NoBsmnt      45
# Po            3
# Name: BsmtCond, dtype: int64

# %%
df_train.loc[df_train.BsmtCond == "Po"]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street     Alley LotShape  \
# 375  376          30       RL    70.049958    10020   Pave  NoAccess      IR1
# 398  399          30       RM    60.000000     8967   Pave  NoAccess      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 375         Low    AllPub    Inside       Sev      Edwards       Norm
# 398         Lvl    AllPub    Corner       Gtl       IDOTRR       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 375       Norm     1Fam     1Story            1            1       1922
# 398       Norm     1Fam     1Story            5            2       1920
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 375          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 398          1950     Gable  CompShg     MetalSd     MetalSd       None
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 375         0.0        Fa        Fa     BrkTil       Fa       Po           Gd
# 398         0.0        TA        Fa     BrkTil       Fa       Po           No
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 375          BLQ         350          Unf           0        333          683
# 398          Unf           0          Unf           0        961          961
#
#     Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 375    GasA        Gd          N      FuseA       904         0             0
# 398    GasA        Gd          Y        Mix      1077         0             0
#
#      GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 375        904             1             0         0         1             1
# 398       1077             0             0         1         0             2
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 375             1          Fa             4       Maj1           0
# 398             1          TA             6       Maj2           0
#
#     FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 375         NaN        NaN          NaN          NaN           0           0
# 398         NaN     Detchd       1920.0          Unf           1         338
#
#     GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 375        NaN        NaN          Y           0            0              0
# 398         Po         Po          N           0            0              0
#
#      3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 375          0            0         0    NaN   NaN         NaN        0
# 398          0            0         0    NaN   NaN         NaN        0
#
#      MoSold  YrSold SaleType SaleCondition  SalePrice
# 375       3    2009       WD        Normal      61000
# 398      11    2007       WD       Abnorml      67000

# %%
df_train.loc[df_train.BsmtCond == "Po"].index
# Out:
# Int64Index([375, 398], dtype='int64')

# %%
df_train.drop(index=[375, 398], inplace=True)

# %%
df_train.BsmtCond.value_counts()
# Out:
# TA         1311
# Gd           65
# Fa           45
# NoBsmnt      37
# Name: BsmtCond, dtype: int64

# %%
df_test.loc[df_test.BsmtCond == "Po"]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street     Alley  \
# 42    1503          20       FV         57.0    12853   Pave      Pave
# 350   1811         190       RM         63.0     7627   Pave  NoAccess
# 1115  2576          50       RM         50.0     7288   Pave  NoAccess
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 42        IR1         Lvl    AllPub    Inside       Gtl      Somerst
# 350       Reg         Lvl    AllPub    Corner       Gtl      OldTown
# 1115      Reg         Lvl    AllPub    Inside       Gtl       IDOTRR
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 42         Norm       Norm     1Fam     1Story            8            5
# 350      Artery       Norm   2fmCon     2Story            4            6
# 1115     Artery       Norm     1Fam     1.5Fin            5            7
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 42         2010          2010     Gable  CompShg     CemntBd     CmentBd
# 350        1920          1950     Gable  CompShg     AsbShng     AsbShng
# 1115       1925          2003     Gable  CompShg     VinylSd     VinylSd
#
#      MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 42         None         0.0        Gd        TA      PConc       Ex       Po
# 350        None         0.0        Fa        TA     BrkTil       Fa       Po
# 1115       None         0.0        Gd        Gd     BrkTil       TA       Po
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 42             No          GLQ      1032.0          Unf         0.0
# 350            No          Unf         0.0          Unf         0.0
# 1115           No          Unf         0.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 42        610.0       1642.0    GasA        Ex          Y      SBrkr
# 350       600.0        600.0    GasA        Gd          N      SBrkr
# 1115      936.0        936.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 42        1418         0             0       1418           1.0           0.0
# 350       1101       600             0       1701           0.0           0.0
# 1115       936       665             0       1601           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 42           1         1             1             1          Gd
# 350          2         0             4             2          Fa
# 1115         2         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 42               6        Typ           1          Gd     Attchd       2010.0
# 350              8        Typ           0         NaN        NaN          NaN
# 1115             6        Typ           0         NaN        NaN          NaN
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 42            RFn         3.0       852.0         TA         TA          Y
# 350           NaN         0.0         0.0        NaN        NaN          N
# 1115          NaN         0.0         0.0        NaN        NaN          N
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 42           160          192              0        224            0
# 350            0            0            148          0            0
# 1115           0            0              0        176            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 42           0    NaN   NaN         NaN        0       4    2010      New
# 350          0    NaN   NaN         NaN        0      10    2009       WD
# 1115         0    NaN   NaN         NaN        0       9    2007       WD
#
#      SaleCondition
# 42         Partial
# 350         Normal
# 1115        Normal

# %%
df_test.loc[df_test.BsmtCond == "Po"].index
# Out:
# Int64Index([42, 350, 1115], dtype='int64')

# %%
df_test.drop(index=[42, 350, 1115], inplace=True)

# %%
df_test.BsmtCond.value_counts()
# Out:
# TA         1295
# Fa           59
# Gd           57
# NoBsmnt      45
# Name: BsmtCond, dtype: int64

# %% [markdown]
# #### BsmtExposure

# %%
df_train.BsmtExposure.value_counts()
# Out:
# No    952
# Av    221
# Gd    133
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
df_train.BsmtExposure.fillna("NoBsmnt", inplace=True)

# %%
df_test.BsmtExposure.fillna("NoBsmnt", inplace=True)

# %%
df_train.BsmtExposure.value_counts()
# Out:
# No         952
# Av         221
# Gd         133
# Mn         114
# NoBsmnt     38
# Name: BsmtExposure, dtype: int64

# %%
df_test.BsmtExposure.value_counts()
# Out:
# No         948
# Av         197
# Gd         142
# Mn         125
# NoBsmnt     44
# Name: BsmtExposure, dtype: int64

# %% [markdown]
# #### BsmtFinType1

# %%
df_train.BsmtFinType1.value_counts()
# Out:
# Unf    429
# GLQ    418
# ALQ    220
# BLQ    147
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
df_train.BsmtFinType1.fillna("NoBsmnt", inplace=True)

# %%
df_test.BsmtFinType1.fillna("NoBsmnt", inplace=True)

# %%
df_train.BsmtFinType1.value_counts() # Apply OrdinalEncoder
# Out:
# Unf        429
# GLQ        418
# ALQ        220
# BLQ        147
# Rec        133
# LwQ         74
# NoBsmnt     37
# Name: BsmtFinType1, dtype: int64

# %% [markdown]
# #### BsmtFinType2

# %%
df_train.BsmtFinType2.value_counts()
# Out:
# Unf    1254
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64

# %%
df_test.BsmtFinType2.value_counts()
# Out:
# Unf    1234
# Rec      51
# LwQ      41
# BLQ      35
# ALQ      33
# GLQ      20
# Name: BsmtFinType2, dtype: int64

# %%
df_train.BsmtFinType2.fillna("NoBsmnt", inplace=True)

# %%
df_test.BsmtFinType2.fillna("NoBsmnt", inplace=True)

# %%
df_train.BsmtFinType2.value_counts() # Apply OrdinalEncoder
# Out:
# Unf        1254
# Rec          54
# LwQ          46
# NoBsmnt      38
# BLQ          33
# ALQ          19
# GLQ          14
# Name: BsmtFinType2, dtype: int64

# %% [markdown]
# #### FireplaceQu

# %%
df_train.FireplaceQu
# Out:
# 0       NaN
# 1        TA
# 2        TA
# 3        Gd
# 4        TA
#        ...
# 1455     TA
# 1456     TA
# 1457     Gd
# 1458    NaN
# 1459    NaN
# Name: FireplaceQu, Length: 1458, dtype: object

# %%
df_train.FireplaceQu.fillna("NoFirePlace", inplace=True)

# %%
df_test.FireplaceQu.fillna("NoFirePlace", inplace=True)

# %%
df_train.FireplaceQu.value_counts() # Apply OrdinalEncoder
# Out:
# NoFirePlace    688
# Gd             380
# TA             313
# Fa              33
# Ex              24
# Po              20
# Name: FireplaceQu, dtype: int64

# %%
df_test.FireplaceQu.value_counts()
# Out:
# NoFirePlace    728
# Gd             363
# TA             279
# Fa              41
# Po              26
# Ex              19
# Name: FireplaceQu, dtype: int64

# %% [markdown]
# #### GarageType

# %%
df_train.GarageType.value_counts()
# Out:
# Attchd     870
# Detchd     386
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
df_test.GarageType.value_counts()
# Out:
# Attchd     852
# Detchd     392
# BuiltIn     98
# Basment     17
# 2Types      17
# CarPort      6
# Name: GarageType, dtype: int64

# %%
df_train.GarageType.fillna("NoGarage", inplace=True)

# %%
df_test.GarageType.fillna("NoGarage", inplace=True)

# %%
df_train.GarageType.value_counts() # Apply OneHotEncoder or get_dummies, drop Carport
# Out:
# Attchd      870
# Detchd      386
# BuiltIn      88
# NoGarage     80
# Basment      19
# CarPort       9
# 2Types        6
# Name: GarageType, dtype: int64

# %%
df_test.GarageType.value_counts()
# Out:
# Attchd      852
# Detchd      392
# BuiltIn      98
# NoGarage     74
# Basment      17
# 2Types       17
# CarPort       6
# Name: GarageType, dtype: int64

# %% [markdown]
# #### GarageYrBlt

# %%
df_train.GarageYrBlt.value_counts()
# Out:
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
# 1977.0    35
# 1998.0    31
# 1999.0    30
# 2008.0    29
# 1976.0    29
# 2000.0    27
# 2002.0    26
# 1968.0    26
# 1950.0    24
# 1993.0    22
# 2009.0    21
# 1965.0    21
# 1962.0    21
# 1958.0    21
# 1966.0    21
# 2001.0    20
# 1970.0    20
# 1996.0    20
# 1957.0    20
# 1997.0    19
# 1960.0    19
# 1978.0    19
# 1954.0    19
# 1974.0    18
# 1964.0    18
# 1995.0    18
# 1994.0    18
# 1959.0    17
# 1990.0    16
# 1963.0    16
# 1956.0    16
# 1980.0    15
# 1967.0    15
# 1979.0    15
# 1969.0    15
# 1988.0    14
# 1973.0    14
# 1940.0    14
# 1972.0    14
# 1961.0    13
# 1920.0    13
# 1992.0    13
# 1971.0    13
# 1955.0    13
# 1953.0    12
# 1948.0    11
# 1987.0    11
# 1989.0    10
# 1981.0    10
# 1925.0    10
# 1985.0    10
# 1941.0    10
# 1939.0     9
# 1975.0     9
# 1991.0     9
# 1984.0     8
# 1949.0     8
# 1930.0     8
# 1983.0     7
# 1951.0     6
# 1986.0     6
# 1926.0     6
# 1922.0     5
# 1916.0     5
# 1936.0     5
# 1945.0     4
# 1931.0     4
# 1982.0     4
# 1928.0     4
# 1935.0     4
# 1946.0     4
# 1921.0     3
# 2010.0     3
# 1952.0     3
# 1923.0     3
# 1910.0     3
# 1932.0     3
# 1924.0     3
# 1938.0     3
# 1937.0     2
# 1915.0     2
# 1942.0     2
# 1934.0     2
# 1914.0     2
# 1929.0     2
# 1947.0     2
# 1918.0     2
# 1906.0     1
# 1908.0     1
# 1933.0     1
# 1900.0     1
# 1927.0     1
# Name: GarageYrBlt, dtype: int64

# %%
df_train.GarageYrBlt.sample(20)
# Out:
# 839     1946.0
# 1297    2005.0
# 1039    1970.0
# 372     1984.0
# 1361    2005.0
# 1081    1963.0
# 1215    1966.0
# 325     1941.0
# 422     1954.0
# 970        NaN
# 916     1958.0
# 307        NaN
# 50      1997.0
# 373     1953.0
# 1109    2004.0
# 968        NaN
# 1023    2005.0
# 763     1999.0
# 1391    1967.0
# 820     2003.0
# Name: GarageYrBlt, dtype: float64

# %%
df_train.dropna(subset=["GarageYrBlt"], inplace=True, axis=0) # Nan Year dropped

# %%
df_test.dropna(subset=["GarageYrBlt"], inplace=True, axis=0) # # Nan Year dropped

# %%
df_train.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage         0
# LotArea             0
# Street              0
# Alley               0
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtCond            0
# BsmtExposure        0
# BsmtFinType1        0
# BsmtFinSF1          0
# BsmtFinType2        0
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu         0
# GarageType          0
# GarageYrBlt         0
# GarageFinish        0
# GarageCars          0
# GarageArea          0
# GarageQual          0
# GarageCond          0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1371
# Fence            1113
# MiscFeature      1327
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# dtype: int64

# %% [markdown]
# #### PoolQC

# %%
df_train.PoolQC
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1455    NaN
# 1456    NaN
# 1457    NaN
# 1458    NaN
# 1459    NaN
# Name: PoolQC, Length: 1378, dtype: object

# %%
df_train.PoolQC.fillna("NoPool", inplace=True)

# %%
df_test.PoolQC.fillna("NoPool", inplace=True)

# %%
df_train.PoolQC.value_counts()
# Out:
# NoPool    1371
# Gd           3
# Ex           2
# Fa           2
# Name: PoolQC, dtype: int64

# %%
df_test.PoolQC.value_counts() # Apply OrdinalEncoder or drop
# Out:
# NoPool    1377
# Ex           2
# Gd           1
# Name: PoolQC, dtype: int64

# %% [markdown]
# #### Fence

# %%
df_train.Fence.fillna("NoFence", inplace=True)

# %%
df_test.Fence.fillna("NoFence", inplace=True)

# %%
df_train.Fence.value_counts()
# Out:
# NoFence    1113
# MnPrv       146
# GdPrv        58
# GdWo         50
# MnWw         11
# Name: Fence, dtype: int64

# %%
df_test.Fence.value_counts() # Apply OrdinalEncoder
# Out:
# NoFence    1103
# MnPrv       164
# GdPrv        58
# GdWo         54
# MnWw          1
# Name: Fence, dtype: int64

# %% [markdown]
# #### MiscFeature

# %%
df_train.MiscFeature.value_counts()
# Out:
# Shed    47
# Gar2     2
# TenC     1
# Othr     1
# Name: MiscFeature, dtype: int64

# %%
df_test.MiscFeature.value_counts()
# Out:
# Shed    41
# Gar2     3
# Othr     2
# Name: MiscFeature, dtype: int64

# %%
df_train.drop("MiscFeature", axis=1, inplace=True)

# %%
df_test.drop("MiscFeature", axis=1, inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       8
# MasVnrArea       8
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       1
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# PoolQC           0
# Fence            0
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          4
# LotFrontage       0
# LotArea           0
# Street            0
# Alley             0
# LotShape          0
# LandContour       0
# Utilities         2
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrType       15
# MasVnrArea       14
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual          0
# BsmtCond          0
# BsmtExposure      0
# BsmtFinType1      0
# BsmtFinSF1        1
# BsmtFinType2      0
# BsmtFinSF2        1
# BsmtUnfSF         1
# TotalBsmtSF       1
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        0
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# GrLivArea         0
# BsmtFullBath      2
# BsmtHalfBath      2
# FullBath          0
# HalfBath          0
# BedroomAbvGr      0
# KitchenAbvGr      0
# KitchenQual       1
# TotRmsAbvGrd      0
# Functional        2
# Fireplaces        0
# FireplaceQu       0
# GarageType        0
# GarageYrBlt       0
# GarageFinish      0
# GarageCars        0
# GarageArea        0
# GarageQual        0
# GarageCond        0
# PavedDrive        0
# WoodDeckSF        0
# OpenPorchSF       0
# EnclosedPorch     0
# 3SsnPorch         0
# ScreenPorch       0
# PoolArea          0
# PoolQC            0
# Fence             0
# MiscVal           0
# MoSold            0
# YrSold            0
# SaleType          1
# SaleCondition     0
# dtype: int64

# %%
df_train.dropna(inplace=True, axis=0)

# %%
df_test.dropna(inplace=True, axis=0)

# %%
df_train.shape
# Out:
# (1369, 80)

# %%
df_test.shape
# Out:
# (1355, 79)

# %%
df_train.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# PoolQC           0
# Fence            0
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# PoolQC           0
# Fence            0
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
df_train.reset_index(inplace=True)

# %%
df_test.reset_index(inplace=True)

# %%
df_train
# Out:
#       index    Id  MSSubClass MSZoning  LotFrontage  LotArea Street     Alley  \
# 0         0     1          60       RL         65.0     8450   Pave  NoAccess
# 1         1     2          20       RL         80.0     9600   Pave  NoAccess
# 2         2     3          60       RL         68.0    11250   Pave  NoAccess
# 3         3     4          70       RL         60.0     9550   Pave  NoAccess
# 4         4     5          60       RL         84.0    14260   Pave  NoAccess
# ...     ...   ...         ...      ...          ...      ...    ...       ...
# 1364   1455  1456          60       RL         62.0     7917   Pave  NoAccess
# 1365   1456  1457          20       RL         85.0    13175   Pave  NoAccess
# 1366   1457  1458          70       RL         66.0     9042   Pave  NoAccess
# 1367   1458  1459          20       RL         68.0     9717   Pave  NoAccess
# 1368   1459  1460          20       RL         75.0     9937   Pave  NoAccess
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0         Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1         Reg         Lvl    AllPub       FR2       Gtl      Veenker
# 2         IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 3         IR1         Lvl    AllPub    Corner       Gtl      Crawfor
# 4         IR1         Lvl    AllPub       FR2       Gtl      NoRidge
# ...       ...         ...       ...       ...       ...          ...
# 1364      Reg         Lvl    AllPub    Inside       Gtl      Gilbert
# 1365      Reg         Lvl    AllPub    Inside       Gtl       NWAmes
# 1366      Reg         Lvl    AllPub    Inside       Gtl      Crawfor
# 1367      Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 1368      Reg         Lvl    AllPub    Inside       Gtl      Edwards
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 0          Norm       Norm     1Fam     2Story            7            5
# 1         Feedr       Norm     1Fam     1Story            6            8
# 2          Norm       Norm     1Fam     2Story            7            5
# 3          Norm       Norm     1Fam     2Story            7            5
# 4          Norm       Norm     1Fam     2Story            8            5
# ...         ...        ...      ...        ...          ...          ...
# 1364       Norm       Norm     1Fam     2Story            6            5
# 1365       Norm       Norm     1Fam     1Story            6            6
# 1366       Norm       Norm     1Fam     2Story            7            9
# 1367       Norm       Norm     1Fam     1Story            5            6
# 1368       Norm       Norm     1Fam     1Story            5            6
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 0          2003          2003     Gable  CompShg     VinylSd     VinylSd
# 1          1976          1976     Gable  CompShg     MetalSd     MetalSd
# 2          2001          2002     Gable  CompShg     VinylSd     VinylSd
# 3          1915          1970     Gable  CompShg     Wd Sdng     Wd Shng
# 4          2000          2000     Gable  CompShg     VinylSd     VinylSd
# ...         ...           ...       ...      ...         ...         ...
# 1364       1999          2000     Gable  CompShg     VinylSd     VinylSd
# 1365       1978          1988     Gable  CompShg     Plywood     Plywood
# 1366       1941          2006     Gable  CompShg     CemntBd     CmentBd
# 1367       1950          1996       Hip  CompShg     MetalSd     MetalSd
# 1368       1965          1965     Gable  CompShg     HdBoard     HdBoard
#
#      MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0       BrkFace       196.0        Gd        TA      PConc       Gd       TA
# 1          None         0.0        TA        TA     CBlock       Gd       TA
# 2       BrkFace       162.0        Gd        TA      PConc       Gd       TA
# 3          None         0.0        TA        TA     BrkTil       TA       Gd
# 4       BrkFace       350.0        Gd        TA      PConc       Gd       TA
# ...         ...         ...       ...       ...        ...      ...      ...
# 1364       None         0.0        TA        TA      PConc       Gd       TA
# 1365      Stone       119.0        TA        TA     CBlock       Gd       TA
# 1366       None         0.0        Ex        Gd      Stone       TA       Gd
# 1367       None         0.0        TA        TA     CBlock       TA       TA
# 1368       None         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1364           No          Unf           0          Unf           0
# 1365           No          ALQ         790          Rec         163
# 1366           No          GLQ         275          Unf           0
# 1367           Mn          GLQ          49          Rec        1029
# 1368           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1364        953          953    GasA        Ex          Y      SBrkr
# 1365        589         1542    GasA        TA          Y      SBrkr
# 1366        877         1152    GasA        Ex          Y      SBrkr
# 1367          0         1078    GasA        Gd          Y      FuseA
# 1368        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1364       953       694             0       1647             0             0
# 1365      2073         0             0       2073             1             0
# 1366      1188      1152             0       2340             0             0
# 1367      1078         0             0       1078             1             0
# 1368      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1364         2         1             3             1          TA
# 1365         2         0             3             1          TA
# 1366         2         0             4             1          Gd
# 1367         1         0             2             1          Gd
# 1368         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# 0                8        Typ           0  NoFirePlace     Attchd
# 1                6        Typ           1           TA     Attchd
# 2                6        Typ           1           TA     Attchd
# 3                7        Typ           1           Gd     Detchd
# 4                9        Typ           1           TA     Attchd
# ...            ...        ...         ...          ...        ...
# 1364             7        Typ           1           TA     Attchd
# 1365             7       Min1           2           TA     Attchd
# 1366             9        Typ           2           Gd     Attchd
# 1367             5        Typ           0  NoFirePlace     Attchd
# 1368             6        Typ           0  NoFirePlace     Attchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 0          2003.0          RFn           2         548         TA         TA
# 1          1976.0          RFn           2         460         TA         TA
# 2          2001.0          RFn           2         608         TA         TA
# 3          1998.0          Unf           3         642         TA         TA
# 4          2000.0          RFn           3         836         TA         TA
# ...           ...          ...         ...         ...        ...        ...
# 1364       1999.0          RFn           2         460         TA         TA
# 1365       1978.0          Unf           2         500         TA         TA
# 1366       1941.0          RFn           1         252         TA         TA
# 1367       1950.0          Unf           1         240         TA         TA
# 1368       1965.0          Fin           1         276         TA         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0             Y           0           61              0          0
# 1             Y         298            0              0          0
# 2             Y           0           42              0          0
# 3             Y           0           35            272          0
# 4             Y         192           84              0          0
# ...         ...         ...          ...            ...        ...
# 1364          Y           0           40              0          0
# 1365          Y         349            0              0          0
# 1366          Y           0           60              0          0
# 1367          Y         366            0            112          0
# 1368          Y         736           68              0          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence  MiscVal  MoSold  YrSold  \
# 0               0         0  NoPool  NoFence        0       2    2008
# 1               0         0  NoPool  NoFence        0       5    2007
# 2               0         0  NoPool  NoFence        0       9    2008
# 3               0         0  NoPool  NoFence        0       2    2006
# 4               0         0  NoPool  NoFence        0      12    2008
# ...           ...       ...     ...      ...      ...     ...     ...
# 1364            0         0  NoPool  NoFence        0       8    2007
# 1365            0         0  NoPool    MnPrv        0       2    2010
# 1366            0         0  NoPool    GdPrv     2500       5    2010
# 1367            0         0  NoPool  NoFence        0       4    2010
# 1368            0         0  NoPool  NoFence        0       6    2008
#
#      SaleType SaleCondition  SalePrice
# 0          WD        Normal     208500
# 1          WD        Normal     181500
# 2          WD        Normal     223500
# 3          WD       Abnorml     140000
# 4          WD        Normal     250000
# ...       ...           ...        ...
# 1364       WD        Normal     175000
# 1365       WD        Normal     210000
# 1366       WD        Normal     266500
# 1367       WD        Normal     142125
# 1368       WD        Normal     147500
#
# [1369 rows x 81 columns]

# %%
df_test
# Out:
#       index    Id  MSSubClass MSZoning  LotFrontage  LotArea Street     Alley  \
# 0         0  1461          20       RH         80.0    11622   Pave  NoAccess
# 1         1  1462          20       RL         81.0    14267   Pave  NoAccess
# 2         2  1463          60       RL         74.0    13830   Pave  NoAccess
# 3         3  1464          60       RL         78.0     9978   Pave  NoAccess
# 4         4  1465         120       RL         43.0     5005   Pave  NoAccess
# ...     ...   ...         ...      ...          ...      ...    ...       ...
# 1350   1451  2912          20       RL         80.0    13384   Pave  NoAccess
# 1351   1452  2913         160       RM         21.0     1533   Pave  NoAccess
# 1352   1455  2916         160       RM         21.0     1894   Pave  NoAccess
# 1353   1456  2917          20       RL        160.0    20000   Pave  NoAccess
# 1354   1458  2919          60       RL         74.0     9627   Pave  NoAccess
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0         Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 1         IR1         Lvl    AllPub    Corner       Gtl        NAmes
# 2         IR1         Lvl    AllPub    Inside       Gtl      Gilbert
# 3         IR1         Lvl    AllPub    Inside       Gtl      Gilbert
# 4         IR1         HLS    AllPub    Inside       Gtl      StoneBr
# ...       ...         ...       ...       ...       ...          ...
# 1350      Reg         Lvl    AllPub    Inside       Mod      Mitchel
# 1351      Reg         Lvl    AllPub    Inside       Gtl      MeadowV
# 1352      Reg         Lvl    AllPub    Inside       Gtl      MeadowV
# 1353      Reg         Lvl    AllPub    Inside       Gtl      Mitchel
# 1354      Reg         Lvl    AllPub    Inside       Mod      Mitchel
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 0         Feedr       Norm     1Fam     1Story            5            6
# 1          Norm       Norm     1Fam     1Story            6            6
# 2          Norm       Norm     1Fam     2Story            5            5
# 3          Norm       Norm     1Fam     2Story            6            6
# 4          Norm       Norm   TwnhsE     1Story            8            5
# ...         ...        ...      ...        ...          ...          ...
# 1350       Norm       Norm     1Fam     1Story            5            5
# 1351       Norm       Norm    Twnhs     2Story            4            5
# 1352       Norm       Norm   TwnhsE     2Story            4            5
# 1353       Norm       Norm     1Fam     1Story            5            7
# 1354       Norm       Norm     1Fam     2Story            7            5
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 0          1961          1961     Gable  CompShg     VinylSd     VinylSd
# 1          1958          1958       Hip  CompShg     Wd Sdng     Wd Sdng
# 2          1997          1998     Gable  CompShg     VinylSd     VinylSd
# 3          1998          1998     Gable  CompShg     VinylSd     VinylSd
# 4          1992          1992     Gable  CompShg     HdBoard     HdBoard
# ...         ...           ...       ...      ...         ...         ...
# 1350       1969          1979     Gable  CompShg     Plywood     Plywood
# 1351       1970          1970     Gable  CompShg     CemntBd     CmentBd
# 1352       1970          1970     Gable  CompShg     CemntBd     CmentBd
# 1353       1960          1996     Gable  CompShg     VinylSd     VinylSd
# 1354       1993          1994     Gable  CompShg     HdBoard     HdBoard
#
#      MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          None         0.0        TA        TA     CBlock       TA       TA
# 1       BrkFace       108.0        TA        TA     CBlock       TA       TA
# 2          None         0.0        TA        TA      PConc       Gd       TA
# 3       BrkFace        20.0        TA        TA      PConc       TA       TA
# 4          None         0.0        Gd        TA      PConc       Gd       TA
# ...         ...         ...       ...       ...        ...      ...      ...
# 1350    BrkFace       194.0        TA        TA      PConc       TA       TA
# 1351       None         0.0        TA        TA     CBlock       TA       TA
# 1352       None         0.0        TA        TA     CBlock       TA       TA
# 1353       None         0.0        TA        TA     CBlock       TA       TA
# 1354    BrkFace        94.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          Rec       468.0          LwQ       144.0
# 1              No          ALQ       923.0          Unf         0.0
# 2              No          GLQ       791.0          Unf         0.0
# 3              No          GLQ       602.0          Unf         0.0
# 4              No          ALQ       263.0          Unf         0.0
# ...           ...          ...         ...          ...         ...
# 1350           Av          Rec       119.0          BLQ       344.0
# 1351           No          Rec       408.0          Unf         0.0
# 1352           No          Rec       252.0          Unf         0.0
# 1353           No          ALQ      1224.0          Unf         0.0
# 1354           Av          LwQ       758.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0         270.0        882.0    GasA        TA          Y      SBrkr
# 1         406.0       1329.0    GasA        TA          Y      SBrkr
# 2         137.0        928.0    GasA        Gd          Y      SBrkr
# 3         324.0        926.0    GasA        Ex          Y      SBrkr
# 4        1017.0       1280.0    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1350      641.0       1104.0    GasA        Fa          Y      SBrkr
# 1351      138.0        546.0    GasA        TA          Y      SBrkr
# 1352      294.0        546.0    GasA        TA          Y      SBrkr
# 1353        0.0       1224.0    GasA        Ex          Y      SBrkr
# 1354      238.0        996.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          896         0             0        896           0.0           0.0
# 1         1329         0             0       1329           0.0           0.0
# 2          928       701             0       1629           0.0           0.0
# 3          926       678             0       1604           0.0           0.0
# 4         1280         0             0       1280           0.0           0.0
# ...        ...       ...           ...        ...           ...           ...
# 1350      1360         0             0       1360           1.0           0.0
# 1351       546       546             0       1092           0.0           0.0
# 1352       546       546             0       1092           0.0           0.0
# 1353      1224         0             0       1224           1.0           0.0
# 1354       996      1004             0       2000           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            1         0             2             1          TA
# 1            1         1             3             1          Gd
# 2            2         1             3             1          TA
# 3            2         1             3             1          Gd
# 4            2         0             2             1          Gd
# ...        ...       ...           ...           ...         ...
# 1350         1         0             3             1          TA
# 1351         1         1             3             1          TA
# 1352         1         1             3             1          TA
# 1353         1         0             4             1          TA
# 1354         2         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# 0                5        Typ           0  NoFirePlace     Attchd
# 1                6        Typ           0  NoFirePlace     Attchd
# 2                6        Typ           1           TA     Attchd
# 3                7        Typ           1           Gd     Attchd
# 4                5        Typ           0  NoFirePlace     Attchd
# ...            ...        ...         ...          ...        ...
# 1350             8        Typ           1           TA     Attchd
# 1351             5        Typ           0  NoFirePlace    CarPort
# 1352             6        Typ           0  NoFirePlace    CarPort
# 1353             7        Typ           1           TA     Detchd
# 1354             9        Typ           1           TA     Attchd
#
#       GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 0          1961.0          Unf         1.0       730.0         TA         TA
# 1          1958.0          Unf         1.0       312.0         TA         TA
# 2          1997.0          Fin         2.0       482.0         TA         TA
# 3          1998.0          Fin         2.0       470.0         TA         TA
# 4          1992.0          RFn         2.0       506.0         TA         TA
# ...           ...          ...         ...         ...        ...        ...
# 1350       1969.0          RFn         1.0       336.0         TA         TA
# 1351       1970.0          Unf         1.0       286.0         TA         TA
# 1352       1970.0          Unf         1.0       286.0         TA         TA
# 1353       1960.0          Unf         2.0       576.0         TA         TA
# 1354       1993.0          Fin         3.0       650.0         TA         TA
#
#      PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0             Y         140            0              0          0
# 1             Y         393           36              0          0
# 2             Y         212           34              0          0
# 3             Y         360           36              0          0
# 4             Y           0           82              0          0
# ...         ...         ...          ...            ...        ...
# 1350          Y         160            0              0          0
# 1351          Y           0            0              0          0
# 1352          Y           0           24              0          0
# 1353          Y         474            0              0          0
# 1354          Y         190           48              0          0
#
#       ScreenPorch  PoolArea  PoolQC    Fence  MiscVal  MoSold  YrSold  \
# 0             120         0  NoPool    MnPrv        0       6    2010
# 1               0         0  NoPool  NoFence    12500       6    2010
# 2               0         0  NoPool    MnPrv        0       3    2010
# 3               0         0  NoPool  NoFence        0       6    2010
# 4             144         0  NoPool  NoFence        0       1    2010
# ...           ...       ...     ...      ...      ...     ...     ...
# 1350            0         0  NoPool  NoFence        0       5    2006
# 1351            0         0  NoPool  NoFence        0      12    2006
# 1352            0         0  NoPool  NoFence        0       4    2006
# 1353            0         0  NoPool  NoFence        0       9    2006
# 1354            0         0  NoPool  NoFence        0      11    2006
#
#      SaleType SaleCondition
# 0          WD        Normal
# 1          WD        Normal
# 2          WD        Normal
# 3          WD        Normal
# 4          WD        Normal
# ...       ...           ...
# 1350       WD        Normal
# 1351       WD       Abnorml
# 1352       WD       Abnorml
# 1353       WD       Abnorml
# 1354       WD        Normal
#
# [1355 rows x 80 columns]

# %% [markdown]
# ### Outliers

# %%
df_train.select_dtypes(include = "object")
# Out:
#      MSZoning Street     Alley LotShape LandContour Utilities LotConfig  \
# 0          RL   Pave  NoAccess      Reg         Lvl    AllPub    Inside
# 1          RL   Pave  NoAccess      Reg         Lvl    AllPub       FR2
# 2          RL   Pave  NoAccess      IR1         Lvl    AllPub    Inside
# 3          RL   Pave  NoAccess      IR1         Lvl    AllPub    Corner
# 4          RL   Pave  NoAccess      IR1         Lvl    AllPub       FR2
# ...       ...    ...       ...      ...         ...       ...       ...
# 1364       RL   Pave  NoAccess      Reg         Lvl    AllPub    Inside
# 1365       RL   Pave  NoAccess      Reg         Lvl    AllPub    Inside
# 1366       RL   Pave  NoAccess      Reg         Lvl    AllPub    Inside
# 1367       RL   Pave  NoAccess      Reg         Lvl    AllPub    Inside
# 1368       RL   Pave  NoAccess      Reg         Lvl    AllPub    Inside
#
#      LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0          Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1          Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2          Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3          Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4          Gtl      NoRidge       Norm       Norm     1Fam     2Story
# ...        ...          ...        ...        ...      ...        ...
# 1364       Gtl      Gilbert       Norm       Norm     1Fam     2Story
# 1365       Gtl       NWAmes       Norm       Norm     1Fam     1Story
# 1366       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 1367       Gtl        NAmes       Norm       Norm     1Fam     1Story
# 1368       Gtl      Edwards       Norm       Norm     1Fam     1Story
#
#      RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# 0        Gable  CompShg     VinylSd     VinylSd    BrkFace        Gd
# 1        Gable  CompShg     MetalSd     MetalSd       None        TA
# 2        Gable  CompShg     VinylSd     VinylSd    BrkFace        Gd
# 3        Gable  CompShg     Wd Sdng     Wd Shng       None        TA
# 4        Gable  CompShg     VinylSd     VinylSd    BrkFace        Gd
# ...        ...      ...         ...         ...        ...       ...
# 1364     Gable  CompShg     VinylSd     VinylSd       None        TA
# 1365     Gable  CompShg     Plywood     Plywood      Stone        TA
# 1366     Gable  CompShg     CemntBd     CmentBd       None        Ex
# 1367       Hip  CompShg     MetalSd     MetalSd       None        TA
# 1368     Gable  CompShg     HdBoard     HdBoard       None        Gd
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0           TA      PConc       Gd       TA           No          GLQ
# 1           TA     CBlock       Gd       TA           Gd          ALQ
# 2           TA      PConc       Gd       TA           Mn          GLQ
# 3           TA     BrkTil       TA       Gd           No          ALQ
# 4           TA      PConc       Gd       TA           Av          GLQ
# ...        ...        ...      ...      ...          ...          ...
# 1364        TA      PConc       Gd       TA           No          Unf
# 1365        TA     CBlock       Gd       TA           No          ALQ
# 1366        Gd      Stone       TA       Gd           No          GLQ
# 1367        TA     CBlock       TA       TA           Mn          GLQ
# 1368        TA     CBlock       TA       TA           No          BLQ
#
#      BsmtFinType2 Heating HeatingQC CentralAir Electrical KitchenQual  \
# 0             Unf    GasA        Ex          Y      SBrkr          Gd
# 1             Unf    GasA        Ex          Y      SBrkr          TA
# 2             Unf    GasA        Ex          Y      SBrkr          Gd
# 3             Unf    GasA        Gd          Y      SBrkr          Gd
# 4             Unf    GasA        Ex          Y      SBrkr          Gd
# ...           ...     ...       ...        ...        ...         ...
# 1364          Unf    GasA        Ex          Y      SBrkr          TA
# 1365          Rec    GasA        TA          Y      SBrkr          TA
# 1366          Unf    GasA        Ex          Y      SBrkr          Gd
# 1367          Rec    GasA        Gd          Y      FuseA          Gd
# 1368          LwQ    GasA        Gd          Y      SBrkr          TA
#
#      Functional  FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# 0           Typ  NoFirePlace     Attchd          RFn         TA         TA
# 1           Typ           TA     Attchd          RFn         TA         TA
# 2           Typ           TA     Attchd          RFn         TA         TA
# 3           Typ           Gd     Detchd          Unf         TA         TA
# 4           Typ           TA     Attchd          RFn         TA         TA
# ...         ...          ...        ...          ...        ...        ...
# 1364        Typ           TA     Attchd          RFn         TA         TA
# 1365       Min1           TA     Attchd          Unf         TA         TA
# 1366        Typ           Gd     Attchd          RFn         TA         TA
# 1367        Typ  NoFirePlace     Attchd          Unf         TA         TA
# 1368        Typ  NoFirePlace     Attchd          Fin         TA         TA
#
#      PavedDrive  PoolQC    Fence SaleType SaleCondition
# 0             Y  NoPool  NoFence       WD        Normal
# 1             Y  NoPool  NoFence       WD        Normal
# 2             Y  NoPool  NoFence       WD        Normal
# 3             Y  NoPool  NoFence       WD       Abnorml
# 4             Y  NoPool  NoFence       WD        Normal
# ...         ...     ...      ...      ...           ...
# 1364          Y  NoPool  NoFence       WD        Normal
# 1365          Y  NoPool    MnPrv       WD        Normal
# 1366          Y  NoPool    GdPrv       WD        Normal
# 1367          Y  NoPool  NoFence       WD        Normal
# 1368          Y  NoPool  NoFence       WD        Normal
#
# [1369 rows x 42 columns]

# %%
df_train.MSZoning.nunique()
# Out:
# 5

# %%
for i in df_train.select_dtypes(include = "object"):
    print(f"{i} has {df_train[i].nunique()} unique values")
# Out:
# MSZoning has 5 unique values
# Street has 2 unique values
# Alley has 3 unique values
# LotShape has 4 unique values
# LandContour has 4 unique values
# Utilities has 2 unique values
# LotConfig has 5 unique values
# LandSlope has 3 unique values
# Neighborhood has 25 unique values
# Condition1 has 9 unique values
# Condition2 has 8 unique values
# BldgType has 5 unique values
# HouseStyle has 8 unique values
# RoofStyle has 6 unique values
# RoofMatl has 8 unique values
# Exterior1st has 14 unique values
# Exterior2nd has 16 unique values
# MasVnrType has 4 unique values
# ExterQual has 4 unique values
# ExterCond has 4 unique values
# Foundation has 6 unique values
# BsmtQual has 5 unique values
# BsmtCond has 4 unique values
# BsmtExposure has 5 unique values
# BsmtFinType1 has 7 unique values
# BsmtFinType2 has 7 unique values
# Heating has 6 unique values
# HeatingQC has 5 unique values
# CentralAir has 2 unique values
# Electrical has 4 unique values
# KitchenQual has 4 unique values
# Functional has 7 unique values
# FireplaceQu has 6 unique values
# GarageType has 6 unique values
# GarageFinish has 3 unique values
# GarageQual has 5 unique values
# GarageCond has 5 unique values
# PavedDrive has 3 unique values
# PoolQC has 4 unique values
# Fence has 5 unique values
# SaleType has 9 unique values
# SaleCondition has 6 unique values

# %%
df_train.select_dtypes(exclude = "object")
# Out:
#       index    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0         0     1          60         65.0     8450            7            5
# 1         1     2          20         80.0     9600            6            8
# 2         2     3          60         68.0    11250            7            5
# 3         3     4          70         60.0     9550            7            5
# 4         4     5          60         84.0    14260            8            5
# ...     ...   ...         ...          ...      ...          ...          ...
# 1364   1455  1456          60         62.0     7917            6            5
# 1365   1456  1457          20         85.0    13175            6            6
# 1366   1457  1458          70         66.0     9042            7            9
# 1367   1458  1459          20         68.0     9717            5            6
# 1368   1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0          2003          2003       196.0         706           0        150
# 1          1976          1976         0.0         978           0        284
# 2          2001          2002       162.0         486           0        434
# 3          1915          1970         0.0         216           0        540
# 4          2000          2000       350.0         655           0        490
# ...         ...           ...         ...         ...         ...        ...
# 1364       1999          2000         0.0           0           0        953
# 1365       1978          1988       119.0         790         163        589
# 1366       1941          2006         0.0         275           0        877
# 1367       1950          1996         0.0          49        1029          0
# 1368       1965          1965         0.0         830         290        136
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 0             856       856       854             0       1710             1
# 1            1262      1262         0             0       1262             0
# 2             920       920       866             0       1786             1
# 3             756       961       756             0       1717             1
# 4            1145      1145      1053             0       2198             1
# ...           ...       ...       ...           ...        ...           ...
# 1364          953       953       694             0       1647             0
# 1365         1542      2073         0             0       2073             1
# 1366         1152      1188      1152             0       2340             0
# 1367         1078      1078         0             0       1078             1
# 1368         1256      1256         0             0       1256             1
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0                0         2         1             3             1
# 1                1         2         0             3             1
# 2                0         2         1             3             1
# 3                0         1         0             3             1
# 4                0         2         1             4             1
# ...            ...       ...       ...           ...           ...
# 1364             0         2         1             3             1
# 1365             0         2         0             3             1
# 1366             0         2         0             4             1
# 1367             0         1         0             2             1
# 1368             0         1         1             3             1
#
#       TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# 0                8           0       2003.0           2         548
# 1                6           1       1976.0           2         460
# 2                6           1       2001.0           2         608
# 3                7           1       1998.0           3         642
# 4                9           1       2000.0           3         836
# ...            ...         ...          ...         ...         ...
# 1364             7           1       1999.0           2         460
# 1365             7           2       1978.0           2         500
# 1366             9           2       1941.0           1         252
# 1367             5           0       1950.0           1         240
# 1368             6           0       1965.0           1         276
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1364           0           40              0          0            0
# 1365         349            0              0          0            0
# 1366           0           60              0          0            0
# 1367         366            0            112          0            0
# 1368         736           68              0          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold  SalePrice
# 0            0        0       2    2008     208500
# 1            0        0       5    2007     181500
# 2            0        0       9    2008     223500
# 3            0        0       2    2006     140000
# 4            0        0      12    2008     250000
# ...        ...      ...     ...     ...        ...
# 1364         0        0       8    2007     175000
# 1365         0        0       2    2010     210000
# 1366         0     2500       5    2010     266500
# 1367         0        0       4    2010     142125
# 1368         0        0       6    2008     147500
#
# [1369 rows x 39 columns]

# %%
a_1 = 1
plt.figure(figsize=(30,60))
for i in df_train.select_dtypes(exclude = "object"):    
    plt.subplot(10,4,a_1)
    sns.boxplot(df_train[i])
    plt.title(i);
    a_1 +=1
# Out:
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
a_2 = 1
plt.figure(figsize=(30,60))
for i in df_test.select_dtypes(exclude = "object"):    
    plt.subplot(10,4,a_2)
    sns.boxplot(df_test[i])
    plt.title(i);
    a_2 +=1
# Out:
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,10), dpi=200)
sns.heatmap(df_train.corr(), annot=True);
