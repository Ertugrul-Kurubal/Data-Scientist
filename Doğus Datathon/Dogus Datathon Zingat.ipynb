# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("max_columns", 1000)
pd.set_option("max_rows", 20)

# %%
df = pd.read_csv("zingat_usecase_trainset.csv")
df
# Out:
#             tarih                               path güncel_fiyat odasayısı  \
# 0      2019-01-01  İstanbul/Beylikdüzü/Adnan Kahveci  1050000 TRY       5+2
# 1      2019-01-01           İstanbul/Kadıköy/Erenköy   547500 TRY       2+1
# 2      2019-01-01  İstanbul/Beylikdüzü/Adnan Kahveci   440000 TRY       3+1
# 3      2019-01-01        İstanbul/Beşiktaş/Nisbetiye  1450000 TRY       3+1
# 4      2019-01-01     İstanbul/Beylikdüzü/Cumhuriyet   169000 TRY       2+1
# ...           ...                                ...          ...       ...
# 64568  2020-04-19         İzmir/Seferihisar/Bengiler   790000 TRY       3+1
# 64569  2020-04-19             İzmir/Karabağlar/Vatan   340000 TRY       3+1
# 64570  2020-04-19         İzmir/Seferihisar/Bengiler   620000 TRY       3+1
# 64571  2020-04-19          İzmir/Karşıyaka/Donanmacı   750000 TRY       3+1
# 64572  2020-04-19           İzmir/Narlıdere/2. İnönü   250000 TRY       2+1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64573 entries, 0 to 64572
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tarih                     64573 non-null  object
#  1   path                      64573 non-null  object
#  2   güncel_fiyat              64573 non-null  object
#  3   odasayısı                 64573 non-null  object
#  4   brütm²                    64573 non-null  float64
#  5   netm²                     64573 non-null  float64
#  6   emlaktipi                 64573 non-null  object
#  7   binayaşı                  64573 non-null  object
#  8   bulunduğukat              64573 non-null  object
#  9   binadakikatsayısı         64573 non-null  object
#  10  isıtmatipi                64573 non-null  object
#  11  banyosayisi               64573 non-null  object
#  12  manzara                   64573 non-null  object
# ...

# %%
df.describe()
# Out:
#               brütm²          netm²       Ilan_ID
# count   64573.000000   64573.000000  64573.000000
# mean      185.902328     127.894027  32287.000000
# std      2671.847842     765.582879  18640.763803
# min         1.000000       1.000000      1.000000
# 25%       100.000000      90.000000  16144.000000
# 50%       125.000000     110.000000  32287.000000
# 75%       155.000000     135.000000  48430.000000
# max    370000.000000  145000.000000  64573.000000

# %%
df.isnull().any()
# Out:
# tarih                       False
# path                        False
# güncel_fiyat                False
# odasayısı                   False
# brütm²                      False
# netm²                       False
# emlaktipi                   False
# binayaşı                    False
# bulunduğukat                False
# binadakikatsayısı           False
# isıtmatipi                  False
# banyosayisi                 False
# manzara                     False
# otopark                     False
# İnterkom                    False
# depremyönetmeliğineuygun    False
# asansör                     False
# Çocukoyunalanı              False
# giyinmeodası                False
# ebeveynbanyosu              False
# Ilan_ID                     False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# tarih                       0
# path                        0
# güncel_fiyat                0
# odasayısı                   0
# brütm²                      0
# netm²                       0
# emlaktipi                   0
# binayaşı                    0
# bulunduğukat                0
# binadakikatsayısı           0
# isıtmatipi                  0
# banyosayisi                 0
# manzara                     0
# otopark                     0
# İnterkom                    0
# depremyönetmeliğineuygun    0
# asansör                     0
# Çocukoyunalanı              0
# giyinmeodası                0
# ebeveynbanyosu              0
# Ilan_ID                     0
# dtype: int64

# %%
df.path.apply(lambda x : x.split("/")).tolist()
# Out:
# [['İstanbul', 'Beylikdüzü', 'Adnan Kahveci'],
#  ['İstanbul', 'Kadıköy', 'Erenköy'],
#  ['İstanbul', 'Beylikdüzü', 'Adnan Kahveci'],
#  ['İstanbul', 'Beşiktaş', 'Nisbetiye'],
#  ['İstanbul', 'Beylikdüzü', 'Cumhuriyet'],
#  ['İstanbul', 'Beylikdüzü', 'Cumhuriyet'],
#  ['İzmir', 'Güzelbahçe', 'Mustafa Kemal Paşa'],
#  ['İzmir', 'Buca', 'Güven'],
#  ['İzmir', 'Karşıyaka', 'Örnekköy'],
#  ['İzmir', 'Torbalı', 'Dirmil'],
#  ['İzmir', 'Menemen', 'Ulus'],
#  ['İstanbul', 'Kadıköy', 'Caddebostan'],
#  ['İstanbul', 'Beylikdüzü', 'Beylikdüzü OSB'],
#  ['İstanbul', 'Beylikdüzü', 'Büyükşehir'],
#  ['İstanbul', 'Beylikdüzü', 'Cumhuriyet'],
#  ['İstanbul', 'Beylikdüzü', 'Cumhuriyet'],
#  ['İzmir', 'Dikili', 'Gazipaşa'],
#  ['İstanbul', 'Beylikdüzü', 'Cumhuriyet'],
#  ['İzmir', 'Bergama', 'Ertuğrul'],
#  ['İzmir', 'Bergama', 'Maltepe'],
#  ['İzmir', 'Bergama', 'Maltepe'],
#  ['İstanbul', 'Beylikdüzü', 'Cumhuriyet'],
#  ['İstanbul', 'Bağcılar', 'Göztepe'],
#  ['İzmir', 'Çeşme', 'Sakarya'],
# ...

# %%
df_path = pd.DataFrame(df.path.apply(lambda x : x.split("/")).tolist())
df_path
# Out:
#               0            1              2
# 0      İstanbul   Beylikdüzü  Adnan Kahveci
# 1      İstanbul      Kadıköy        Erenköy
# 2      İstanbul   Beylikdüzü  Adnan Kahveci
# 3      İstanbul     Beşiktaş      Nisbetiye
# 4      İstanbul   Beylikdüzü     Cumhuriyet
# ...         ...          ...            ...
# 64568     İzmir  Seferihisar       Bengiler
# 64569     İzmir   Karabağlar          Vatan
# 64570     İzmir  Seferihisar       Bengiler
# 64571     İzmir    Karşıyaka      Donanmacı
# 64572     İzmir    Narlıdere       2. İnönü
#
# [64573 rows x 3 columns]

# %%
df_path.rename(columns={0:"il",1:"ilçe",2:"mahalle"}, inplace=True)

# %%
df_path
# Out:
#              il         ilçe        mahalle
# 0      İstanbul   Beylikdüzü  Adnan Kahveci
# 1      İstanbul      Kadıköy        Erenköy
# 2      İstanbul   Beylikdüzü  Adnan Kahveci
# 3      İstanbul     Beşiktaş      Nisbetiye
# 4      İstanbul   Beylikdüzü     Cumhuriyet
# ...         ...          ...            ...
# 64568     İzmir  Seferihisar       Bengiler
# 64569     İzmir   Karabağlar          Vatan
# 64570     İzmir  Seferihisar       Bengiler
# 64571     İzmir    Karşıyaka      Donanmacı
# 64572     İzmir    Narlıdere       2. İnönü
#
# [64573 rows x 3 columns]

# %%
pd.concat([df,df_path],axis=1)
# Out:
#             tarih                               path güncel_fiyat odasayısı  \
# 0      2019-01-01  İstanbul/Beylikdüzü/Adnan Kahveci  1050000 TRY       5+2
# 1      2019-01-01           İstanbul/Kadıköy/Erenköy   547500 TRY       2+1
# 2      2019-01-01  İstanbul/Beylikdüzü/Adnan Kahveci   440000 TRY       3+1
# 3      2019-01-01        İstanbul/Beşiktaş/Nisbetiye  1450000 TRY       3+1
# 4      2019-01-01     İstanbul/Beylikdüzü/Cumhuriyet   169000 TRY       2+1
# ...           ...                                ...          ...       ...
# 64568  2020-04-19         İzmir/Seferihisar/Bengiler   790000 TRY       3+1
# 64569  2020-04-19             İzmir/Karabağlar/Vatan   340000 TRY       3+1
# 64570  2020-04-19         İzmir/Seferihisar/Bengiler   620000 TRY       3+1
# 64571  2020-04-19          İzmir/Karşıyaka/Donanmacı   750000 TRY       3+1
# 64572  2020-04-19           İzmir/Narlıdere/2. İnönü   250000 TRY       2+1
#
# ...

# %%
df_path.il.unique()
# Out:
# array(['İstanbul', 'İzmir'], dtype=object)

# %%
df_path.ilçe.unique()
# Out:
# array(['Beylikdüzü', 'Kadıköy', 'Beşiktaş', 'Güzelbahçe', 'Buca',
#        'Karşıyaka', 'Torbalı', 'Menemen', 'Dikili', 'Bergama', 'Bağcılar',
#        'Çeşme', 'Bayraklı', 'Menderes', 'Çiğli', 'Gaziemir', 'Urla',
#        'Bornova', 'Balçova', 'Pendik', 'Seferihisar', 'Konak',
#        'Kemalpaşa', 'Karabağlar', 'Narlıdere', 'Tire', 'Selçuk', 'Foça',
#        'Aliağa', 'Ödemiş', 'Karaburun', 'Bayındır', 'Beydağ', 'Kınık',
#        None], dtype=object)

# %%
df_path.mahalle.unique()
# Out:
# array(['Adnan Kahveci', 'Erenköy', 'Nisbetiye', 'Cumhuriyet',
#        'Mustafa Kemal Paşa', 'Güven', 'Örnekköy', 'Dirmil', 'Ulus',
#        'Caddebostan', 'Beylikdüzü OSB', 'Büyükşehir', 'Gazipaşa',
#        'Ertuğrul', 'Maltepe', 'Göztepe', 'Sakarya', 'Onur', 'Talatpaşa',
#        'Dereağzı', 'Kemalpaşa', 'Yakuplu', 'Balatçık', 'Kabakum',
#        'Dalyan', 'Kasımpaşa', 'Merdivenköy', 'Fırat', 'Demirkapı',
#        'Etiler', 'Barış', 'Gazi', 'Yıldız', 'Gazikent', 'Çukuraltı',
#        'Kavaklı', 'Ataşehir', 'İnönü', 'Yeni Mahalle', 'Demirköprü',
#        'Üniversite', 'Kozyatağı', 'Zeytinalanı', 'Suadiye', 'Atatürk',
#        'Barbaros', 'Marmara', 'Fevzi Çakmak', 'Çetin Emeç', 'Gürpınar',
#        'Mahmutbey', 'Alaçatı', 'Ilıca', 'Bahriye Üçok', 'Yenişehir',
#        'Küçük Çiğli', 'Nergiz', 'Vişnezade', 'Teleferik', 'Aksoy',
#        'Caferağa', 'Zübeyde Hanım', 'Sahrayı Cedit', 'Kemal Atatürk',
#        'Ortaköy', 'Tepecik', 'Mevlana', 'Bostancı', 'Mavişehir',
# ...

# %% [markdown]
# #### Path

# %%
df.path.value_counts()
# Out:
# İstanbul/Beylikdüzü/Cumhuriyet        5715
# İstanbul/Beylikdüzü/Yakuplu           2220
# İstanbul/Kadıköy/Suadiye              1879
# İstanbul/Beylikdüzü/Adnan Kahveci     1829
# İstanbul/Beylikdüzü/Beylikdüzü OSB    1497
#                                       ...
# İzmir/Tire/Yeniçiftlik                   1
# İzmir/Torbalı/Çaybaşı                    1
# İzmir/Bergama/Gültepe                    1
# İzmir/Bayındır/Cumhuriyet                1
# İzmir/Tire/Dağdere                       1
# Name: path, Length: 828, dtype: int64

# %%
df.path.value_counts()[df.path.value_counts()<20]
# Out:
# İzmir/Kemalpaşa/Aşağıkızılca    19
# İzmir/Güzelbahçe/Atatürk        19
# İzmir/Çiğli/Çağdaş              19
# İstanbul/Beşiktaş/Sinanpaşa     19
# İzmir/Tire/Kurtuluş             19
#                                 ..
# İzmir/Kınık/Sucahlı              1
# İzmir/Tire/Yenioba               1
# İzmir/Bayındır/Mektep            1
# İzmir/Konak/Faik Paşa            1
# İzmir/Aliağa/Mimar Sinan         1
# Name: path, Length: 408, dtype: int64

# %%
df = df.groupby('path').filter(lambda x : len(x)>=20)
df
# Out:
#             tarih                               path güncel_fiyat odasayısı  \
# 0      2019-01-01  İstanbul/Beylikdüzü/Adnan Kahveci  1050000 TRY       5+2
# 1      2019-01-01           İstanbul/Kadıköy/Erenköy   547500 TRY       2+1
# 2      2019-01-01  İstanbul/Beylikdüzü/Adnan Kahveci   440000 TRY       3+1
# 3      2019-01-01        İstanbul/Beşiktaş/Nisbetiye  1450000 TRY       3+1
# 4      2019-01-01     İstanbul/Beylikdüzü/Cumhuriyet   169000 TRY       2+1
# ...           ...                                ...          ...       ...
# 64568  2020-04-19         İzmir/Seferihisar/Bengiler   790000 TRY       3+1
# 64569  2020-04-19             İzmir/Karabağlar/Vatan   340000 TRY       3+1
# 64570  2020-04-19         İzmir/Seferihisar/Bengiler   620000 TRY       3+1
# 64571  2020-04-19          İzmir/Karşıyaka/Donanmacı   750000 TRY       3+1
# 64572  2020-04-19           İzmir/Narlıdere/2. İnönü   250000 TRY       2+1
#
# ...

# %%
df.path.value_counts() # get_dummies
# Out:
# İstanbul/Beylikdüzü/Cumhuriyet        5715
# İstanbul/Beylikdüzü/Yakuplu           2220
# İstanbul/Kadıköy/Suadiye              1879
# İstanbul/Beylikdüzü/Adnan Kahveci     1829
# İstanbul/Beylikdüzü/Beylikdüzü OSB    1497
#                                       ...
# İzmir/Konak/Mimar Sinan                 21
# İzmir/Bornova/Rafet Paşa                21
# İzmir/Selçuk/Cumhuriyet                 21
# İstanbul/Pendik/Yeşilbağlar             21
# İzmir/Çiğli/Cumhuriyet                  21
# Name: path, Length: 412, dtype: int64

# %% [markdown]
# #### Emlak Tipi

# %%
df.emlaktipi.value_counts() # get_dummies
# Out:
# Daire                  55098
# Villa                   4053
# Rezidans                1096
# Yazlık                   996
# Müstakil Ev              878
# Prefabrik Ev             139
# Yalı Dairesi              70
# Köşk / Konak / Yalı       40
# Çiftlik Evi               21
# Name: emlaktipi, dtype: int64

# %% [markdown]
# #### Bina Yaşı

# %%
df.binayaşı.value_counts() # tekrar bakılacak
# Out:
# 0              27542
# 6-10 arası      5513
# 16-20 arası     3600
# 1               3467
# 21-25 arası     3099
# 11-15 arası     3024
# 26-30 arası     2997
# 2               2728
# 4               2534
# 3               2346
# -               2181
# 31-35 arası     1635
# 5               1264
# 36-40 arası      274
# 40 ve üzeri      187
# Name: binayaşı, dtype: int64

# %% [markdown]
# #### Bulunduğu Kat

# %%
df.bulunduğukat.value_counts()
# Out:
# 2               10328
# 3                8409
# 1                5926
# 4                5764
# -                3943
# 5                3746
# Bahçe katı       3404
# Müstakil         3342
# Yüksek Giriş     3264
# 6                2022
# 7                1717
# Giriş Katı       1686
# 8                1373
# 9                1124
# 10                877
# Komple            662
# 11                652
# Kot 1             584
# Zemin Kat         537
# Kot 2             463
# 12                423
# Çatı Katı         344
# 13                335
# Kot 3             268
# 14                266
# 20 ve üzeri       211
# Kot 4             168
# 15                134
# En Üst Kat         94
# 16                 87
# 17                 83
# Teras Kat          46
# 18                 46
# Bodrum Kat         40
# 19                 23
# Name: bulunduğukat, dtype: int64

# %% [markdown]
# #### Binadaki Katsayısı

# %%
df.binadakikatsayısı.value_counts()
# Out:
# 5              13177
# 4              12674
# 3               7559
# 10-20 arası     5365
# 6               4912
# 2               3362
# 7               3259
# 8               2902
# 9               2724
# -               2720
# 10              2245
# 20 ve üzeri     1063
# 1                429
# Name: binadakikatsayısı, dtype: int64

# %% [markdown]
# #### Isıtma Tipi

# %%
df.isıtmatipi.unique()
# Out:
# array(['Kombi (Doğalgaz)', 'Merkezi Sistem (Isı Payı Ölçer)',
#        'Kat Kaloriferi', '-', 'Yok', 'Klima', 'Kalorifer (Doğalgaz)',
#        'Merkezi Sistem', 'Yerden Isıtma', 'Soba (Doğalgaz)', 'Jeotermal',
#        'Soba (Kömür)', 'Kombi (Elektrikli)', 'Kalorifer (Kömür)',
#        'Fancoil', 'Kalorifer (Akaryakıt)', 'Güneş Enerjisi'], dtype=object)

# %%
df.isıtmatipi.value_counts()
# Out:
# Kombi (Doğalgaz)                   36067
# Klima                              10391
# Merkezi Sistem (Isı Payı Ölçer)     5104
# -                                   2740
# Merkezi Sistem                      2469
# Yok                                 1559
# Kalorifer (Doğalgaz)                1539
# Yerden Isıtma                       1249
# Soba (Kömür)                         878
# Kat Kaloriferi                       837
# Jeotermal                            625
# Kombi (Elektrikli)                   397
# Soba (Doğalgaz)                      274
# Fancoil                              266
# Kalorifer (Kömür)                     84
# Güneş Enerjisi                        57
# Kalorifer (Akaryakıt)                 37
# Name: isıtmatipi, dtype: int64

# %%
df.isıtmatipi = df.isıtmatipi.apply(lambda x: x.replace("-","Yok"))

# %%
df.isıtmatipi.value_counts()
# Out:
# Kombi (Doğalgaz)                   36067
# Klima                              10391
# Merkezi Sistem (Isı Payı Ölçer)     5104
# Yok                                 4299
# Merkezi Sistem                      2469
# Kalorifer (Doğalgaz)                1539
# Yerden Isıtma                       1249
# Soba (Kömür)                         878
# Kat Kaloriferi                       837
# Jeotermal                            625
# Kombi (Elektrikli)                   397
# Soba (Doğalgaz)                      274
# Fancoil                              266
# Kalorifer (Kömür)                     84
# Güneş Enerjisi                        57
# Kalorifer (Akaryakıt)                 37
# Name: isıtmatipi, dtype: int64

# %% [markdown]
# #### Banyo Sayısı

# %%
df.banyosayisi.value_counts()
# Out:
# 1             34164
# 2             22477
# 3              3774
# 4              1051
# 5               314
# 0               307
# 6 ve üzeri      192
# -               112
# Name: banyosayisi, dtype: int64

# %% [markdown]
# #### Manzara

# %%
df.manzara.value_counts()
# Out:
# _                                                                        39596
# Şehir                                                                     7613
# Doğa,Şehir                                                                2087
# Cadde,Şehir                                                               1017
# Boğaz,Cadde,Deniz,Havuz,Park,Şehir,Yeşil Alan,Göl,Nehir,Vadi,Dağ,Doğa      960
#                                                                          ...
# Cadde,Havuz,Park,Şehir,Doğa                                                  1
# Boğaz,Cadde,Deniz,Havuz,Park,Şehir,Vadi,Yeşil Alan                           1
# Cadde,Deniz,Havuz,Park,Şehir,Vadi,Yeşil Alan                                 1
# Cadde,Doğa,Vadi,Yeşil Alan                                                   1
# Cadde,Deniz,Şehir,Yeşil Alan,Göl,Doğa                                        1
# Name: manzara, Length: 917, dtype: int64

# %%
df = df.groupby('manzara').filter(lambda x : len(x)>=20)
df
# Out:
#             tarih                                 path güncel_fiyat odasayısı  \
# 1      2019-01-01             İstanbul/Kadıköy/Erenköy   547500 TRY       2+1
# 2      2019-01-01    İstanbul/Beylikdüzü/Adnan Kahveci   440000 TRY       3+1
# 3      2019-01-01          İstanbul/Beşiktaş/Nisbetiye  1450000 TRY       3+1
# 5      2019-01-01       İstanbul/Beylikdüzü/Cumhuriyet   180000 TRY       2+1
# 6      2019-01-01  İzmir/Güzelbahçe/Mustafa Kemal Paşa   695000 TRY       2+1
# ...           ...                                  ...          ...       ...
# 64568  2020-04-19           İzmir/Seferihisar/Bengiler   790000 TRY       3+1
# 64569  2020-04-19               İzmir/Karabağlar/Vatan   340000 TRY       3+1
# 64570  2020-04-19           İzmir/Seferihisar/Bengiler   620000 TRY       3+1
# 64571  2020-04-19            İzmir/Karşıyaka/Donanmacı   750000 TRY       3+1
# 64572  2020-04-19             İzmir/Narlıdere/2. İnönü   250000 TRY       2+1
#
# ...

# %%
df.manzara.value_counts()
# Out:
# _                                                                        39596
# Şehir                                                                     7613
# Doğa,Şehir                                                                2087
# Cadde,Şehir                                                               1017
# Boğaz,Cadde,Deniz,Havuz,Park,Şehir,Yeşil Alan,Göl,Nehir,Vadi,Dağ,Doğa      960
#                                                                          ...
# Şehir,Şehir                                                                 20
# Cadde,Deniz,Şehir,Yeşil Alan,Doğa                                           20
# Boğaz,Şehir,Deniz                                                           20
# Cadde,Doğa,Havuz,Park,Şehir,Yeşil Alan                                      20
# Boğaz,Cadde,Deniz,Havuz,Park,Şehir,Yeşil Alan,Göl,Nehir,Vadi,Doğa           20
# Name: manzara, Length: 77, dtype: int64

# %% [markdown]
# #### Otopark

# %%
df.columns
# Out:
# Index(['tarih', 'path', 'güncel_fiyat', 'odasayısı', 'brütm²', 'netm²',
#        'emlaktipi', 'binayaşı', 'bulunduğukat', 'binadakikatsayısı',
#        'isıtmatipi', 'banyosayisi', 'manzara', 'otopark', 'İnterkom',
#        'depremyönetmeliğineuygun', 'asansör', 'Çocukoyunalanı', 'giyinmeodası',
#        'ebeveynbanyosu', 'Ilan_ID'],
#       dtype='object')

# %%
df.otopark.value_counts() # tekrar bakılacak
# Out:
# -                         32816
# Var                       13050
# Var (Ücretsiz, Kapalı)     9331
# Var (Ücretsiz, Açık)       3343
# Var (Açık,Kapalı)          1091
# Yok                         731
# Var (Ücretli, Açık)          22
# Var (Ücretli, Kapalı)        10
# Name: otopark, dtype: int64

# %% [markdown]
# #### Interkom

# %%
df.İnterkom.value_counts()
# Out:
# YOK    34480
# VAR    25914
# Name: İnterkom, dtype: int64

# %% [markdown]
# #### Deprem Yönetmeliği

# %%
df.depremyönetmeliğineuygun.value_counts()
# Out:
# YOK    48253
# VAR    12141
# Name: depremyönetmeliğineuygun, dtype: int64
