# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("max_columns", 1000)
pd.set_option("max_rows", 20)

# %%
# df_test = pd.read_csv("zingat_usecase_testset_null.csv")
# df_test

# %%
# df = pd.read_csv("zingat_usecase_trainset.csv")
# df

# %%
# df_dolar = pd.read_excel("EVDS.xlsx")
# df_dolar = df_dolar[["tarih","dolar"]]
# df_dolar

# %%
# df.tarih = pd.to_datetime(df.tarih)

# %%
# df_test.tarih = pd.to_datetime(df_test.tarih)

# %%
# df_dolar.tarih = pd.to_datetime(df_dolar.tarih)

# %%
# df = pd.merge(df, df_dolar,how="left", on="tarih")
# df

# %%
# df.to_csv("zingat_usecase_trainset2.csv", index=False)

# %%
# df_test = pd.merge(df_test, df_dolar,how="left", on="tarih")
# df_test

# %%
# df_test.to_csv("zingat_usecase_testset_null2.csv", index=False)

# %%
df_test = pd.read_csv("zingat_usecase_testset_null2.csv")
df_test
# Out:
#             tarih                            path odasayısı  brütm²  netm²  \
# 0      2020-04-20           İzmir/Konak/Güzelyalı       4+1   165.0  155.0
# 1      2020-04-20              İzmir/Ödemiş/İnönü       2+1   130.0  120.0
# 2      2020-04-20        İzmir/Karşıyaka/Örnekköy       3+1   182.0  153.0
# 3      2020-04-20              İzmir/Ödemiş/İnönü       2+1   130.0  120.0
# 4      2020-04-20     İstanbul/Beylikdüzü/Kavaklı       3+1   125.0  120.0
# ...           ...                             ...       ...     ...    ...
# 35122  2020-12-31              İzmir/Urla/İçmeler       4+1   200.0  180.0
# 35123  2020-12-31  İstanbul/Bağcılar/Fevzi Çakmak       2+1    85.0   65.0
# 35124  2020-12-31      İzmir/Seferihisar/Turabiye       3+1   125.0  120.0
# 35125  2020-12-31            İzmir/Foça/Fevzipaşa       7+1   427.0  245.0
# 35126  2020-12-31  İstanbul/Bağcılar/Fevzi Çakmak       2+1    85.0   65.0
#
#          emlaktipi     binayaşı  bulunduğukat binadakikatsayısı  \
# ...

# %%
df = pd.read_csv("zingat_usecase_trainset2.csv")
df
# Out:
#             tarih                               path güncel_fiyat odasayısı  \
# 0      2019-01-01  İstanbul/Beylikdüzü/Adnan Kahveci  1050000 TRY       5+2
# 1      2019-01-01           İstanbul/Kadıköy/Erenköy   547500 TRY       2+1
# 2      2019-01-01  İstanbul/Beylikdüzü/Adnan Kahveci   440000 TRY       3+1
# 3      2019-01-01        İstanbul/Beşiktaş/Nisbetiye  1450000 TRY       3+1
# 4      2019-01-01     İstanbul/Beylikdüzü/Cumhuriyet   169000 TRY       2+1
# ...           ...                                ...          ...       ...
# 64568  2020-04-19         İzmir/Seferihisar/Bengiler   790000 TRY       3+1
# 64569  2020-04-19             İzmir/Karabağlar/Vatan   340000 TRY       3+1
# 64570  2020-04-19         İzmir/Seferihisar/Bengiler   620000 TRY       3+1
# 64571  2020-04-19          İzmir/Karşıyaka/Donanmacı   750000 TRY       3+1
# 64572  2020-04-19           İzmir/Narlıdere/2. İnönü   250000 TRY       2+1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64573 entries, 0 to 64572
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tarih                     64573 non-null  object
#  1   path                      64573 non-null  object
#  2   güncel_fiyat              64573 non-null  object
#  3   odasayısı                 64573 non-null  object
#  4   brütm²                    64573 non-null  float64
#  5   netm²                     64573 non-null  float64
#  6   emlaktipi                 64573 non-null  object
#  7   binayaşı                  64573 non-null  object
#  8   bulunduğukat              64573 non-null  object
#  9   binadakikatsayısı         64573 non-null  object
#  10  isıtmatipi                64573 non-null  object
#  11  banyosayisi               64573 non-null  object
#  12  manzara                   64573 non-null  object
# ...

# %%
df.describe()
# Out:
#               brütm²          netm²       Ilan_ID         dolar
# count   64573.000000   64573.000000  64573.000000  64573.000000
# mean      185.902328     127.894027  32287.000000      5.866832
# std      2671.847842     765.582879  18640.763803      0.486061
# min         1.000000       1.000000      1.000000      5.194500
# 25%       100.000000      90.000000  16144.000000      5.656400
# 50%       125.000000     110.000000  32287.000000      5.758400
# 75%       155.000000     135.000000  48430.000000      5.957100
# max    370000.000000  145000.000000  64573.000000      8.454600

# %%
df.isnull().any()
# Out:
# tarih             False
# path              False
# güncel_fiyat      False
# odasayısı         False
# brütm²            False
#                   ...
# Çocukoyunalanı    False
# giyinmeodası      False
# ebeveynbanyosu    False
# Ilan_ID           False
# dolar             False
# Length: 22, dtype: bool

# %%
df.isnull().sum()
# Out:
# tarih             0
# path              0
# güncel_fiyat      0
# odasayısı         0
# brütm²            0
#                  ..
# Çocukoyunalanı    0
# giyinmeodası      0
# ebeveynbanyosu    0
# Ilan_ID           0
# dolar             0
# Length: 22, dtype: int64

# %%
#df.path.apply(lambda x : x.split("/")).tolist()

# %%
# df_path = pd.DataFrame(df.path.apply(lambda x : x.split("/")).tolist())
# df_path

# %%
# df_path.rename(columns={0:"il",1:"ilçe",2:"mahalle"}, inplace=True)
# df_path

# %%
# pd.concat([df,df_path],axis=1)

# %%
# df_path.il.unique()

# %%
# df_path.ilçe.unique()

# %%
# df_path.ilçe.nunique()

# %%
# df_path.mahalle.unique()

# %%
# df_path.mahalle.nunique()

# %%
# df.tarih = pd.to_datetime(df.tarih)

# %%
# df_test.tarih = pd.to_datetime(df_test.tarih)

# %%
# def get_date_int(df, column):
#     year_1 = df[column].dt.year
#     month_1 = df[column].dt.month
#     day_1 = df[column].dt.day
#     return year_1, month_1, day_1

# %%
# df["yıl"], df["ay"], df["gün"] = get_date_int(df, "tarih")

# %%
# df_test["yıl"], df_test["ay"], df_test["gün"] = get_date_int(df_test, "tarih")

# %%
df.drop(["tarih","Ilan_ID"],axis=1, inplace=True)

# %%
df_test.drop(["tarih","Ilan_ID","güncel_fiyat"],axis=1, inplace=True)

# %%
df
# Out:
#                                     path güncel_fiyat odasayısı  brütm²  \
# 0      İstanbul/Beylikdüzü/Adnan Kahveci  1050000 TRY       5+2   380.0
# 1               İstanbul/Kadıköy/Erenköy   547500 TRY       2+1    65.0
# 2      İstanbul/Beylikdüzü/Adnan Kahveci   440000 TRY       3+1   205.0
# 3            İstanbul/Beşiktaş/Nisbetiye  1450000 TRY       3+1   150.0
# 4         İstanbul/Beylikdüzü/Cumhuriyet   169000 TRY       2+1    70.0
# ...                                  ...          ...       ...     ...
# 64568         İzmir/Seferihisar/Bengiler   790000 TRY       3+1   180.0
# 64569             İzmir/Karabağlar/Vatan   340000 TRY       3+1   130.0
# 64570         İzmir/Seferihisar/Bengiler   620000 TRY       3+1   180.0
# 64571          İzmir/Karşıyaka/Donanmacı   750000 TRY       3+1   125.0
# 64572           İzmir/Narlıdere/2. İnönü   250000 TRY       2+1   100.0
#
#        netm² emlaktipi     binayaşı bulunduğukat binadakikatsayısı  \
# ...

# %%
df.shape
# Out:
# (64573, 20)

# %%
df_test.shape
# Out:
# (35127, 19)

# %% [markdown]
# #### Path

# %%
df.path.value_counts()
# Out:
# İstanbul/Beylikdüzü/Cumhuriyet         5715
# İstanbul/Beylikdüzü/Yakuplu            2220
# İstanbul/Kadıköy/Suadiye               1879
# İstanbul/Beylikdüzü/Adnan Kahveci      1829
# İstanbul/Beylikdüzü/Beylikdüzü OSB     1497
#                                        ...
# İzmir/Menderes/Değirmendere Atatürk       1
# İzmir/Karabağlar/Cennetçeşme              1
# İzmir/Bayındır/Cumhuriyet                 1
# İzmir/Tire/Dağdere                        1
# İzmir/Tire/Duatepe                        1
# Name: path, Length: 828, dtype: int64

# %%
df.path.value_counts()[df.path.value_counts()>=20]
# Out:
# İstanbul/Beylikdüzü/Cumhuriyet        5715
# İstanbul/Beylikdüzü/Yakuplu           2220
# İstanbul/Kadıköy/Suadiye              1879
# İstanbul/Beylikdüzü/Adnan Kahveci     1829
# İstanbul/Beylikdüzü/Beylikdüzü OSB    1497
#                                       ...
# İzmir/Narlıdere/Sahilevleri             20
# İzmir/Kemalpaşa/85. Yıl Cumhuriyet      20
# İzmir/Ödemiş/Üç Eylül                   20
# İstanbul/Beşiktaş/Kültür                20
# İzmir/Bornova/Yakaköy                   20
# Name: path, Length: 420, dtype: int64

# %%
df = df.groupby('path').filter(lambda x : len(x)>=20)
df
# Out:
#                                     path güncel_fiyat odasayısı  brütm²  \
# 0      İstanbul/Beylikdüzü/Adnan Kahveci  1050000 TRY       5+2   380.0
# 1               İstanbul/Kadıköy/Erenköy   547500 TRY       2+1    65.0
# 2      İstanbul/Beylikdüzü/Adnan Kahveci   440000 TRY       3+1   205.0
# 3            İstanbul/Beşiktaş/Nisbetiye  1450000 TRY       3+1   150.0
# 4         İstanbul/Beylikdüzü/Cumhuriyet   169000 TRY       2+1    70.0
# ...                                  ...          ...       ...     ...
# 64568         İzmir/Seferihisar/Bengiler   790000 TRY       3+1   180.0
# 64569             İzmir/Karabağlar/Vatan   340000 TRY       3+1   130.0
# 64570         İzmir/Seferihisar/Bengiler   620000 TRY       3+1   180.0
# 64571          İzmir/Karşıyaka/Donanmacı   750000 TRY       3+1   125.0
# 64572           İzmir/Narlıdere/2. İnönü   250000 TRY       2+1   100.0
#
#        netm² emlaktipi     binayaşı bulunduğukat binadakikatsayısı  \
# ...

# %%
df.path.value_counts() # get_dummies
# Out:
# İstanbul/Beylikdüzü/Cumhuriyet        5715
# İstanbul/Beylikdüzü/Yakuplu           2220
# İstanbul/Kadıköy/Suadiye              1879
# İstanbul/Beylikdüzü/Adnan Kahveci     1829
# İstanbul/Beylikdüzü/Beylikdüzü OSB    1497
#                                       ...
# İzmir/Ödemiş/Üç Eylül                   20
# İzmir/Çiğli/Uğur Mumcu                  20
# İzmir/Bergama/Bahçelievler              20
# İzmir/Narlıdere/Sahilevleri             20
# İzmir/Kemalpaşa/85. Yıl Cumhuriyet      20
# Name: path, Length: 420, dtype: int64

# %% [markdown]
# #### Oda Sayısı

# %%
df.odasayısı.value_counts()
# Out:
# 3+1     24370
# 2+1     23025
# 1+1      4899
# 4+1      4803
# 4+2      1264
#         ...
# 19+4        2
# 4+4         2
# 10+1        2
# 10+4        1
# 19+6        1
# Name: odasayısı, Length: 38, dtype: int64

# %%
# df['odasayısı'] = df['odasayısı'].replace("-","0+0")

# %%
# df["odasayısı"] = df.odasayısı.str.split('+', expand=True)[0].astype("int64") + df.odasayısı.str.split('+', expand=True)[1].astype("int64")

# %%
df = df.groupby('odasayısı').filter(lambda x : len(x)>=20)
df
# Out:
#                                     path güncel_fiyat odasayısı  brütm²  \
# 0      İstanbul/Beylikdüzü/Adnan Kahveci  1050000 TRY       5+2   380.0
# 1               İstanbul/Kadıköy/Erenköy   547500 TRY       2+1    65.0
# 2      İstanbul/Beylikdüzü/Adnan Kahveci   440000 TRY       3+1   205.0
# 3            İstanbul/Beşiktaş/Nisbetiye  1450000 TRY       3+1   150.0
# 4         İstanbul/Beylikdüzü/Cumhuriyet   169000 TRY       2+1    70.0
# ...                                  ...          ...       ...     ...
# 64568         İzmir/Seferihisar/Bengiler   790000 TRY       3+1   180.0
# 64569             İzmir/Karabağlar/Vatan   340000 TRY       3+1   130.0
# 64570         İzmir/Seferihisar/Bengiler   620000 TRY       3+1   180.0
# 64571          İzmir/Karşıyaka/Donanmacı   750000 TRY       3+1   125.0
# 64572           İzmir/Narlıdere/2. İnönü   250000 TRY       2+1   100.0
#
#        netm² emlaktipi     binayaşı bulunduğukat binadakikatsayısı  \
# ...

# %%
df.odasayısı.value_counts()
# Out:
# 3+1     24370
# 2+1     23025
# 1+1      4899
# 4+1      4803
# 4+2      1264
# 5+1      1247
# 5+2       748
# 3+2       735
# 6+2       283
# 6+1       272
# 1+0       269
# 2+2       134
# 7+2       100
# 7+1        83
# 8+2        49
# 10+0       39
# -          36
# 4+3        30
# 8+1        26
# 5+3        25
# Name: odasayısı, dtype: int64

# %% [markdown]
# #### Emlak Tipi

# %%
df.emlaktipi.value_counts() # get_dummies
# Out:
# Daire                  55156
# Villa                   4045
# Rezidans                1089
# Yazlık                   996
# Müstakil Ev              890
# Prefabrik Ev             140
# Yalı Dairesi              70
# Köşk / Konak / Yalı       29
# Çiftlik Evi               22
# Name: emlaktipi, dtype: int64

# %% [markdown]
# #### Bina Yaşı

# %%
df.binayaşı.value_counts() # Değerlendirilecek (Regex)
# Out:
# 0              27588
# 6-10 arası      5514
# 16-20 arası     3600
# 1               3469
# 21-25 arası     3106
# 11-15 arası     3017
# 26-30 arası     2999
# 2               2728
# 4               2528
# 3               2340
# -               2197
# 31-35 arası     1633
# 5               1265
# 36-40 arası      274
# 40 ve üzeri      179
# Name: binayaşı, dtype: int64

# %% [markdown]
# #### Bulunduğu Kat

# %%
df.bulunduğukat.value_counts() # Değerlendirilecek
# Out:
# 2             10339
# 3              8420
# 1              5921
# 4              5774
# -              3936
#               ...
# 17               83
# 18               47
# Teras Kat        47
# Bodrum Kat       40
# 19               23
# Name: bulunduğukat, Length: 35, dtype: int64

# %% [markdown]
# #### Binadaki Katsayısı

# %%
df.binadakikatsayısı.value_counts() # Değerlendirilecek
# Out:
# 5              13192
# 4              12669
# 3               7561
# 10-20 arası     5359
# 6               4919
# 2               3365
# 7               3267
# 8               2901
# -               2731
# 9               2723
# 10              2244
# 20 ve üzeri     1062
# 1                444
# Name: binadakikatsayısı, dtype: int64

# %% [markdown]
# #### Isıtma Tipi

# %%
df.isıtmatipi.value_counts()
# Out:
# Kombi (Doğalgaz)                   35497
# Klima                               9932
# Merkezi Sistem (Isı Payı Ölçer)     5029
# -                                   2460
# Merkezi Sistem                      2429
# Kalorifer (Doğalgaz)                1508
# Yok                                 1404
# Yerden Isıtma                       1200
# Kat Kaloriferi                       768
# Jeotermal                            623
# Soba (Kömür)                         575
# Kombi (Elektrikli)                   379
# Fancoil                              251
# Soba (Doğalgaz)                      230
# Kalorifer (Kömür)                     73
# Güneş Enerjisi                        47
# Kalorifer (Akaryakıt)                 32
# Name: isıtmatipi, dtype: int64

# %%
#df.isıtmatipi = df.isıtmatipi.apply(lambda x: x.replace("-","Yok")) # ?????

# %%
df.isıtmatipi.value_counts()
# Out:
# Kombi (Doğalgaz)                   35497
# Klima                               9932
# Merkezi Sistem (Isı Payı Ölçer)     5029
# -                                   2460
# Merkezi Sistem                      2429
# Kalorifer (Doğalgaz)                1508
# Yok                                 1404
# Yerden Isıtma                       1200
# Kat Kaloriferi                       768
# Jeotermal                            623
# Soba (Kömür)                         575
# Kombi (Elektrikli)                   379
# Fancoil                              251
# Soba (Doğalgaz)                      230
# Kalorifer (Kömür)                     73
# Güneş Enerjisi                        47
# Kalorifer (Akaryakıt)                 32
# Name: isıtmatipi, dtype: int64

# %% [markdown]
# #### Banyo Sayısı

# %%
df.banyosayisi.value_counts()
# Out:
# 1             34222
# 2             22516
# 3              3769
# 4              1036
# 5               309
# 0               306
# 6 ve üzeri      167
# -               112
# Name: banyosayisi, dtype: int64

# %% [markdown]
# #### Manzara

# %%
df.manzara.value_counts()
# Out:
# _                                                                        39665
# Şehir                                                                     7609
# Doğa,Şehir                                                                2085
# Cadde,Şehir                                                               1017
# Boğaz,Cadde,Deniz,Havuz,Park,Şehir,Yeşil Alan,Göl,Nehir,Vadi,Dağ,Doğa      960
#                                                                          ...
# Vadi                                                                         1
# Göl,Doğa,Şehir,Deniz                                                         1
# Boğaz,Dağ,Deniz,Doğa,Göl,Havuz,Nehir,Vadi                                    1
# Göl,Deniz,Şehir                                                              1
# Deniz,Yeşil Alan,Havuz,Doğa,Park                                             1
# Name: manzara, Length: 916, dtype: int64

# %%
df = df.groupby('manzara').filter(lambda x : len(x)>=20)
df
# Out:
#                                       path güncel_fiyat odasayısı  brütm²  \
# 1                 İstanbul/Kadıköy/Erenköy   547500 TRY       2+1    65.0
# 2        İstanbul/Beylikdüzü/Adnan Kahveci   440000 TRY       3+1   205.0
# 3              İstanbul/Beşiktaş/Nisbetiye  1450000 TRY       3+1   150.0
# 5           İstanbul/Beylikdüzü/Cumhuriyet   180000 TRY       2+1   110.0
# 6      İzmir/Güzelbahçe/Mustafa Kemal Paşa   695000 TRY       2+1   123.0
# ...                                    ...          ...       ...     ...
# 64568           İzmir/Seferihisar/Bengiler   790000 TRY       3+1   180.0
# 64569               İzmir/Karabağlar/Vatan   340000 TRY       3+1   130.0
# 64570           İzmir/Seferihisar/Bengiler   620000 TRY       3+1   180.0
# 64571            İzmir/Karşıyaka/Donanmacı   750000 TRY       3+1   125.0
# 64572             İzmir/Narlıdere/2. İnönü   250000 TRY       2+1   100.0
#
#        netm² emlaktipi     binayaşı bulunduğukat binadakikatsayısı  \
# ...

# %%
df.manzara.value_counts()
# Out:
# _                                                                        39665
# Şehir                                                                     7609
# Doğa,Şehir                                                                2085
# Cadde,Şehir                                                               1017
# Boğaz,Cadde,Deniz,Havuz,Park,Şehir,Yeşil Alan,Göl,Nehir,Vadi,Dağ,Doğa      960
#                                                                          ...
# Boğaz,Şehir,Deniz                                                           21
# Cadde,Deniz,Doğa,Şehir,Yeşil Alan                                           21
# Cadde,Deniz,Şehir,Yeşil Alan,Doğa                                           20
# Boğaz,Cadde,Deniz,Havuz,Park,Şehir,Yeşil Alan,Göl,Nehir,Vadi,Doğa           20
# Cadde,Doğa,Havuz,Park,Şehir,Yeşil Alan                                      20
# Name: manzara, Length: 76, dtype: int64

# %% [markdown]
# #### Otopark

# %%
df.otopark.value_counts() # tekrar bakılacak
# Out:
# -                         32867
# Var                       13042
# Var (Ücretsiz, Kapalı)     9316
# Var (Ücretsiz, Açık)       3344
# Var (Açık,Kapalı)          1090
# Yok                         731
# Var (Ücretli, Açık)          22
# Var (Ücretli, Kapalı)        10
# Name: otopark, dtype: int64

# %% [markdown]
# #### Interkom

# %%
df.İnterkom.value_counts()
# Out:
# YOK    34512
# VAR    25910
# Name: İnterkom, dtype: int64

# %%
df.İnterkom = df.İnterkom.map({"YOK":0, "VAR":1})

# %%
df_test.İnterkom = df_test.İnterkom.map({"YOK":0, "VAR":1})

# %%
df.İnterkom.value_counts()
# Out:
# 0    34512
# 1    25910
# Name: İnterkom, dtype: int64

# %% [markdown]
# #### Deprem Yönetmeliği

# %%
df.depremyönetmeliğineuygun.value_counts()
# Out:
# YOK    48282
# VAR    12140
# Name: depremyönetmeliğineuygun, dtype: int64

# %%
df.depremyönetmeliğineuygun = df.depremyönetmeliğineuygun.map({"YOK":0, "VAR":1})

# %%
df_test.depremyönetmeliğineuygun = df_test.depremyönetmeliğineuygun.map({"YOK":0, "VAR":1})

# %%
df.depremyönetmeliğineuygun.value_counts()
# Out:
# 0    48282
# 1    12140
# Name: depremyönetmeliğineuygun, dtype: int64

# %% [markdown]
# #### Asansör

# %%
df.asansör.value_counts()
# Out:
# VAR    30544
# YOK    29878
# Name: asansör, dtype: int64

# %%
df.asansör = df.asansör.map({"YOK":0, "VAR":1})

# %%
df_test.asansör = df_test.asansör.map({"YOK":0, "VAR":1})

# %%
df.asansör.value_counts()
# Out:
# 1    30544
# 0    29878
# Name: asansör, dtype: int64

# %% [markdown]
# #### Çocuk Oyun Alanı

# %%
df.Çocukoyunalanı.value_counts()
# Out:
# YOK    53098
# VAR     7324
# Name: Çocukoyunalanı, dtype: int64

# %%
df.Çocukoyunalanı = df.Çocukoyunalanı.map({"YOK":0, "VAR":1})

# %%
df_test.Çocukoyunalanı = df_test.Çocukoyunalanı.map({"YOK":0, "VAR":1})

# %%
df.Çocukoyunalanı.value_counts()
# Out:
# 0    53098
# 1     7324
# Name: Çocukoyunalanı, dtype: int64

# %% [markdown]
# #### Giyinme Odası

# %%
df.giyinmeodası.value_counts()
# Out:
# YOK    52902
# VAR     7520
# Name: giyinmeodası, dtype: int64

# %%
df.giyinmeodası = df.giyinmeodası.map({"YOK":0, "VAR":1})

# %%
df_test.giyinmeodası = df_test.giyinmeodası.map({"YOK":0, "VAR":1})

# %%
df.giyinmeodası.value_counts()
# Out:
# 0    52902
# 1     7520
# Name: giyinmeodası, dtype: int64

# %% [markdown]
# #### Ebevyen Banyosu

# %%
df.ebeveynbanyosu.value_counts()
# Out:
# YOK    41422
# VAR    19000
# Name: ebeveynbanyosu, dtype: int64

# %%
df.ebeveynbanyosu = df.ebeveynbanyosu.map({"YOK":0, "VAR":1})

# %%
df_test.ebeveynbanyosu = df_test.ebeveynbanyosu.map({"YOK":0, "VAR":1})

# %%
df.ebeveynbanyosu.value_counts()
# Out:
# 0    41422
# 1    19000
# Name: ebeveynbanyosu, dtype: int64

# %%
df
# Out:
#                                       path güncel_fiyat odasayısı  brütm²  \
# 1                 İstanbul/Kadıköy/Erenköy   547500 TRY       2+1    65.0
# 2        İstanbul/Beylikdüzü/Adnan Kahveci   440000 TRY       3+1   205.0
# 3              İstanbul/Beşiktaş/Nisbetiye  1450000 TRY       3+1   150.0
# 5           İstanbul/Beylikdüzü/Cumhuriyet   180000 TRY       2+1   110.0
# 6      İzmir/Güzelbahçe/Mustafa Kemal Paşa   695000 TRY       2+1   123.0
# ...                                    ...          ...       ...     ...
# 64568           İzmir/Seferihisar/Bengiler   790000 TRY       3+1   180.0
# 64569               İzmir/Karabağlar/Vatan   340000 TRY       3+1   130.0
# 64570           İzmir/Seferihisar/Bengiler   620000 TRY       3+1   180.0
# 64571            İzmir/Karşıyaka/Donanmacı   750000 TRY       3+1   125.0
# 64572             İzmir/Narlıdere/2. İnönü   250000 TRY       2+1   100.0
#
#        netm² emlaktipi     binayaşı bulunduğukat binadakikatsayısı  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60422 entries, 1 to 64572
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   path                      60422 non-null  object
#  1   güncel_fiyat              60422 non-null  object
#  2   odasayısı                 60422 non-null  object
#  3   brütm²                    60422 non-null  float64
#  4   netm²                     60422 non-null  float64
#  5   emlaktipi                 60422 non-null  object
#  6   binayaşı                  60422 non-null  object
#  7   bulunduğukat              60422 non-null  object
#  8   binadakikatsayısı         60422 non-null  object
#  9   isıtmatipi                60422 non-null  object
#  10  banyosayisi               60422 non-null  object
#  11  manzara                   60422 non-null  object
#  12  otopark                   60422 non-null  object
# ...

# %%
import re
def num_value(x):
    var1 = re.findall('[0-9]+', x)
    var2 = int(var1[0])
    return var2

# %%
df.güncel_fiyat = df.güncel_fiyat.apply(lambda x : num_value(x))

# %%
df
# Out:
#                                       path  güncel_fiyat odasayısı  brütm²  \
# 1                 İstanbul/Kadıköy/Erenköy        547500       2+1    65.0
# 2        İstanbul/Beylikdüzü/Adnan Kahveci        440000       3+1   205.0
# 3              İstanbul/Beşiktaş/Nisbetiye       1450000       3+1   150.0
# 5           İstanbul/Beylikdüzü/Cumhuriyet        180000       2+1   110.0
# 6      İzmir/Güzelbahçe/Mustafa Kemal Paşa        695000       2+1   123.0
# ...                                    ...           ...       ...     ...
# 64568           İzmir/Seferihisar/Bengiler        790000       3+1   180.0
# 64569               İzmir/Karabağlar/Vatan        340000       3+1   130.0
# 64570           İzmir/Seferihisar/Bengiler        620000       3+1   180.0
# 64571            İzmir/Karşıyaka/Donanmacı        750000       3+1   125.0
# 64572             İzmir/Narlıdere/2. İnönü        250000       2+1   100.0
#
# ...

# %%
df[df["brütm²"]<df["netm²"]]
# Out:
#                            path  güncel_fiyat odasayısı  brütm²  netm²  \
# 5294    İstanbul/Beşiktaş/Bebek      45000000       7+2     1.0  950.0
# 6491         İzmir/Çeşme/Dalyan       1250000       3+1   120.0  300.0
# 8902     İstanbul/Beşiktaş/Ulus      27000000       5+1     1.0  309.0
# 13020         İzmir/Çeşme/Ardıç      17000000       5+1     1.0  300.0
# 13029         İzmir/Çeşme/Ilıca       3900000       6+1     1.0  350.0
# ...                         ...           ...       ...     ...    ...
# 59788     İzmir/Foça/Cumhuriyet        400000       2+1    60.0   90.0
# 60218  İstanbul/Beşiktaş/Levent      25000000         -   553.0  656.0
# 60442       İzmir/Çeşme/Alaçatı      12000000       6+1   145.0  290.0
# 63206       İzmir/Konak/Çankaya       2450000       7+2   200.0  250.0
# 63830       İzmir/Çeşme/Alaçatı       3950000       5+1   170.0  200.0
#
#                  emlaktipi     binayaşı bulunduğukat binadakikatsayısı  \
# ...

# %%
df = df[~(df["brütm²"]<df["netm²"])]
df
# Out:
#                                       path  güncel_fiyat odasayısı  brütm²  \
# 1                 İstanbul/Kadıköy/Erenköy        547500       2+1    65.0
# 2        İstanbul/Beylikdüzü/Adnan Kahveci        440000       3+1   205.0
# 3              İstanbul/Beşiktaş/Nisbetiye       1450000       3+1   150.0
# 5           İstanbul/Beylikdüzü/Cumhuriyet        180000       2+1   110.0
# 6      İzmir/Güzelbahçe/Mustafa Kemal Paşa        695000       2+1   123.0
# ...                                    ...           ...       ...     ...
# 64568           İzmir/Seferihisar/Bengiler        790000       3+1   180.0
# 64569               İzmir/Karabağlar/Vatan        340000       3+1   130.0
# 64570           İzmir/Seferihisar/Bengiler        620000       3+1   180.0
# 64571            İzmir/Karşıyaka/Donanmacı        750000       3+1   125.0
# 64572             İzmir/Narlıdere/2. İnönü        250000       2+1   100.0
#
# ...

# %%
df = df[~(df["brütm²"]<=20)]
df
# Out:
#                                       path  güncel_fiyat odasayısı  brütm²  \
# 1                 İstanbul/Kadıköy/Erenköy        547500       2+1    65.0
# 2        İstanbul/Beylikdüzü/Adnan Kahveci        440000       3+1   205.0
# 3              İstanbul/Beşiktaş/Nisbetiye       1450000       3+1   150.0
# 5           İstanbul/Beylikdüzü/Cumhuriyet        180000       2+1   110.0
# 6      İzmir/Güzelbahçe/Mustafa Kemal Paşa        695000       2+1   123.0
# ...                                    ...           ...       ...     ...
# 64568           İzmir/Seferihisar/Bengiler        790000       3+1   180.0
# 64569               İzmir/Karabağlar/Vatan        340000       3+1   130.0
# 64570           İzmir/Seferihisar/Bengiler        620000       3+1   180.0
# 64571            İzmir/Karşıyaka/Donanmacı        750000       3+1   125.0
# 64572             İzmir/Narlıdere/2. İnönü        250000       2+1   100.0
#
# ...

# %%
df[(df["brütm²"] > 10000) & (df.emlaktipi != "Çiftlik Evi")]
# Out:
#                                     path  güncel_fiyat odasayısı    brütm²  \
# 4043      İstanbul/Beylikdüzü/Cumhuriyet        209000       2+1   10090.0
# 5799                  İzmir/Urla/Yelaltı        750000       2+1   17000.0
# 6334           İstanbul/Kadıköy/Bostancı       1250000       3+1   15011.0
# 9528                  İzmir/Buca/Yenigün        232500       3+1   12011.0
# 9931                  İzmir/Buca/İnkılap        350000       3+1  125120.0
# 13157             İzmir/Torbalı/Muratbey        220000       3+1  145000.0
# 26265           İzmir/Torbalı/Ayrancılar        235000       3+1  145000.0
# 31045           İzmir/Karşıyaka/Bostanlı        600000       3+1  120110.0
# 37515         İstanbul/Bağcılar/Barbaros        800000       6+2  350350.0
# 40757            İstanbul/Pendik/Kurtköy        260000       2+1   11010.0
# 42195        İstanbul/Beylikdüzü/Marmara        325000       3+1  145135.0
# ...

# %%
df = df[~(df["brütm²"] > 10000) & (df.emlaktipi != "Çiftlik Evi")]
df
# Out:
#                                       path  güncel_fiyat odasayısı  brütm²  \
# 1                 İstanbul/Kadıköy/Erenköy        547500       2+1    65.0
# 2        İstanbul/Beylikdüzü/Adnan Kahveci        440000       3+1   205.0
# 3              İstanbul/Beşiktaş/Nisbetiye       1450000       3+1   150.0
# 5           İstanbul/Beylikdüzü/Cumhuriyet        180000       2+1   110.0
# 6      İzmir/Güzelbahçe/Mustafa Kemal Paşa        695000       2+1   123.0
# ...                                    ...           ...       ...     ...
# 64568           İzmir/Seferihisar/Bengiler        790000       3+1   180.0
# 64569               İzmir/Karabağlar/Vatan        340000       3+1   130.0
# 64570           İzmir/Seferihisar/Bengiler        620000       3+1   180.0
# 64571            İzmir/Karşıyaka/Donanmacı        750000       3+1   125.0
# 64572             İzmir/Narlıdere/2. İnönü        250000       2+1   100.0
#
# ...

# %%
df = df[~(df["brütm²"] > 50000)] 
df
# Out:
#                                       path  güncel_fiyat odasayısı  brütm²  \
# 1                 İstanbul/Kadıköy/Erenköy        547500       2+1    65.0
# 2        İstanbul/Beylikdüzü/Adnan Kahveci        440000       3+1   205.0
# 3              İstanbul/Beşiktaş/Nisbetiye       1450000       3+1   150.0
# 5           İstanbul/Beylikdüzü/Cumhuriyet        180000       2+1   110.0
# 6      İzmir/Güzelbahçe/Mustafa Kemal Paşa        695000       2+1   123.0
# ...                                    ...           ...       ...     ...
# 64568           İzmir/Seferihisar/Bengiler        790000       3+1   180.0
# 64569               İzmir/Karabağlar/Vatan        340000       3+1   130.0
# 64570           İzmir/Seferihisar/Bengiler        620000       3+1   180.0
# 64571            İzmir/Karşıyaka/Donanmacı        750000       3+1   125.0
# 64572             İzmir/Narlıdere/2. İnönü        250000       2+1   100.0
#
# ...

# %%
df[~((df["netm²"] < 20) & (df.emlaktipi != "Prefabrik Ev"))]
# Out:
#                                       path  güncel_fiyat odasayısı  brütm²  \
# 1                 İstanbul/Kadıköy/Erenköy        547500       2+1    65.0
# 2        İstanbul/Beylikdüzü/Adnan Kahveci        440000       3+1   205.0
# 3              İstanbul/Beşiktaş/Nisbetiye       1450000       3+1   150.0
# 5           İstanbul/Beylikdüzü/Cumhuriyet        180000       2+1   110.0
# 6      İzmir/Güzelbahçe/Mustafa Kemal Paşa        695000       2+1   123.0
# ...                                    ...           ...       ...     ...
# 64568           İzmir/Seferihisar/Bengiler        790000       3+1   180.0
# 64569               İzmir/Karabağlar/Vatan        340000       3+1   130.0
# 64570           İzmir/Seferihisar/Bengiler        620000       3+1   180.0
# 64571            İzmir/Karşıyaka/Donanmacı        750000       3+1   125.0
# 64572             İzmir/Narlıdere/2. İnönü        250000       2+1   100.0
#
# ...

# %%
df = df[~((df["netm²"] < 20) & (df.emlaktipi != "Prefabrik Ev"))]
df
# Out:
#                                       path  güncel_fiyat odasayısı  brütm²  \
# 1                 İstanbul/Kadıköy/Erenköy        547500       2+1    65.0
# 2        İstanbul/Beylikdüzü/Adnan Kahveci        440000       3+1   205.0
# 3              İstanbul/Beşiktaş/Nisbetiye       1450000       3+1   150.0
# 5           İstanbul/Beylikdüzü/Cumhuriyet        180000       2+1   110.0
# 6      İzmir/Güzelbahçe/Mustafa Kemal Paşa        695000       2+1   123.0
# ...                                    ...           ...       ...     ...
# 64568           İzmir/Seferihisar/Bengiler        790000       3+1   180.0
# 64569               İzmir/Karabağlar/Vatan        340000       3+1   130.0
# 64570           İzmir/Seferihisar/Bengiler        620000       3+1   180.0
# 64571            İzmir/Karşıyaka/Donanmacı        750000       3+1   125.0
# 64572             İzmir/Narlıdere/2. İnönü        250000       2+1   100.0
#
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df[(df["netm²"] > 2500)]
# Out:
#                                        path  güncel_fiyat odasayısı  brütm²  \
# 13804                    İzmir/Çeşme/Ovacık       6000000       8+1  6000.0
# 40082  İzmir/Kemalpaşa/Yukarıkızılca Merkez       3000000       3+1  9100.0
# 49848                    İzmir/Urla/Denizli      15800000       7+1  3793.0
# 51188                    İzmir/Urla/Yelaltı       3500000       4+1  2700.0
#
#         netm²    emlaktipi binayaşı bulunduğukat binadakikatsayısı isıtmatipi  \
# 13804  5999.0  Müstakil Ev        -            -                 -          -
# 40082  9000.0        Daire        -            -                 -          -
# 49848  3790.0        Villa        -            -                 -          -
# 51188  2600.0        Villa        4     Müstakil                 1      Klima
#
#       banyosayisi manzara otopark  İnterkom  depremyönetmeliğineuygun  \
# 13804           1       _       -         0                         0
# ...

# %%
df.drop(40082, inplace=True)
# Out:
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df[(df["netm²"] > 2500)]
# Out:
#                      path  güncel_fiyat odasayısı  brütm²   netm²  \
# 13804  İzmir/Çeşme/Ovacık       6000000       8+1  6000.0  5999.0
# 49848  İzmir/Urla/Denizli      15800000       7+1  3793.0  3790.0
# 51188  İzmir/Urla/Yelaltı       3500000       4+1  2700.0  2600.0
#
#          emlaktipi binayaşı bulunduğukat binadakikatsayısı isıtmatipi  \
# 13804  Müstakil Ev        -            -                 -          -
# 49848        Villa        -            -                 -          -
# 51188        Villa        4     Müstakil                 1      Klima
#
#       banyosayisi manzara otopark  İnterkom  depremyönetmeliğineuygun  \
# 13804           1       _       -         0                         0
# 49848           5       _       -         0                         0
# 51188           3       _       -         0                         0
#
#        asansör  Çocukoyunalanı  giyinmeodası  ebeveynbanyosu   dolar
# ...

# %%
df[((df["güncel_fiyat"] < 10000) & (df.emlaktipi != "Prefabrik Ev"))]
# Out:
#                                  path  güncel_fiyat odasayısı  brütm²  netm²  \
# 24           İzmir/Menderes/Kemalpaşa           900       2+1    85.0   80.0
# 126    İstanbul/Beylikdüzü/Cumhuriyet          1300       2+1   110.0  100.0
# 130         İstanbul/Kadıköy/Bostancı          2800       3+1   145.0  110.0
# 2802     İstanbul/Beylikdüzü/Gürpınar          2100       2+1   175.0  160.0
# 2938            İzmir/Karşıyaka/Aksoy          2200       2+1    90.0   85.0
# ...                               ...           ...       ...     ...    ...
# 57916     İstanbul/Kadıköy/Dumlupınar          2500       2+1    90.0   80.0
# 57919     İstanbul/Kadıköy/Dumlupınar          2500       2+1    90.0   80.0
# 59564      İstanbul/Kadıköy/Rasimpaşa          2750       2+1    90.0   75.0
# 60079        İstanbul/Kadıköy/Suadiye          7000       5+1   240.0  200.0
# 60248            İzmir/Bornova/Erzene          4000       3+1   145.0  135.0
#
# ...

# %%
df = df[~((df["güncel_fiyat"] < 10000) & (df.emlaktipi != "Prefabrik Ev"))]
df
# Out:
#                                       path  güncel_fiyat odasayısı  brütm²  \
# 0                 İstanbul/Kadıköy/Erenköy        547500       2+1    65.0
# 1        İstanbul/Beylikdüzü/Adnan Kahveci        440000       3+1   205.0
# 2              İstanbul/Beşiktaş/Nisbetiye       1450000       3+1   150.0
# 3           İstanbul/Beylikdüzü/Cumhuriyet        180000       2+1   110.0
# 4      İzmir/Güzelbahçe/Mustafa Kemal Paşa        695000       2+1   123.0
# ...                                    ...           ...       ...     ...
# 60304           İzmir/Seferihisar/Bengiler        790000       3+1   180.0
# 60305               İzmir/Karabağlar/Vatan        340000       3+1   130.0
# 60306           İzmir/Seferihisar/Bengiler        620000       3+1   180.0
# 60307            İzmir/Karşıyaka/Donanmacı        750000       3+1   125.0
# 60308             İzmir/Narlıdere/2. İnönü        250000       2+1   100.0
#
# ...

# %%
df[((df["güncel_fiyat"] > 30000000) & (df.emlaktipi == "Daire") & (df["netm²"] < 200))]
# Out:
#                                 path  güncel_fiyat odasayısı  brütm²  netm²  \
# 2426        İstanbul/Bağcılar/Merkez     510000000       3+1   180.0  170.0
# 3080        İstanbul/Bağcılar/Merkez     300000000       3+1   140.0  130.0
# 58805  İstanbul/Bağcılar/Yavuz Selim     110000000       2+1   100.0   90.0
#
#       emlaktipi     binayaşı bulunduğukat binadakikatsayısı  \
# 2426      Daire  16-20 arası            2                 5
# 3080      Daire            -            2                 5
# 58805     Daire  16-20 arası    Çatı Katı                 6
#
#                  isıtmatipi banyosayisi manzara otopark  İnterkom  \
# 2426   Kalorifer (Doğalgaz)           1       _       -         0
# 3080   Kalorifer (Doğalgaz)           2       _       -         0
# 58805          Soba (Kömür)           1       _       -         0
#
#        depremyönetmeliğineuygun  asansör  Çocukoyunalanı  giyinmeodası  \
# 2426                          0        0               0             0
# ...

# %%
df = df[~((df["güncel_fiyat"] > 30000000) & (df.emlaktipi == "Daire") & (df["netm²"] < 200))]
df
# Out:
#                                       path  güncel_fiyat odasayısı  brütm²  \
# 0                 İstanbul/Kadıköy/Erenköy        547500       2+1    65.0
# 1        İstanbul/Beylikdüzü/Adnan Kahveci        440000       3+1   205.0
# 2              İstanbul/Beşiktaş/Nisbetiye       1450000       3+1   150.0
# 3           İstanbul/Beylikdüzü/Cumhuriyet        180000       2+1   110.0
# 4      İzmir/Güzelbahçe/Mustafa Kemal Paşa        695000       2+1   123.0
# ...                                    ...           ...       ...     ...
# 60304           İzmir/Seferihisar/Bengiler        790000       3+1   180.0
# 60305               İzmir/Karabağlar/Vatan        340000       3+1   130.0
# 60306           İzmir/Seferihisar/Bengiler        620000       3+1   180.0
# 60307            İzmir/Karşıyaka/Donanmacı        750000       3+1   125.0
# 60308             İzmir/Narlıdere/2. İnönü        250000       2+1   100.0
#
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60249 entries, 0 to 60248
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   path                      60249 non-null  object
#  1   güncel_fiyat              60249 non-null  int64
#  2   odasayısı                 60249 non-null  object
#  3   brütm²                    60249 non-null  float64
#  4   netm²                     60249 non-null  float64
#  5   emlaktipi                 60249 non-null  object
#  6   binayaşı                  60249 non-null  object
#  7   bulunduğukat              60249 non-null  object
#  8   binadakikatsayısı         60249 non-null  object
#  9   isıtmatipi                60249 non-null  object
#  10  banyosayisi               60249 non-null  object
#  11  manzara                   60249 non-null  object
#  12  otopark                   60249 non-null  object
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35127 entries, 0 to 35126
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   path                      35127 non-null  object
#  1   odasayısı                 35127 non-null  object
#  2   brütm²                    35127 non-null  float64
#  3   netm²                     35127 non-null  float64
#  4   emlaktipi                 35127 non-null  object
#  5   binayaşı                  35127 non-null  object
#  6   bulunduğukat              35127 non-null  object
#  7   binadakikatsayısı         35127 non-null  object
#  8   isıtmatipi                35127 non-null  object
#  9   banyosayisi               35127 non-null  object
#  10  manzara                   35127 non-null  object
#  11  otopark                   35127 non-null  object
#  12  İnterkom                  35127 non-null  int64
# ...

# %% [markdown]
# ### Model Train

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.shape
# Out:
# (60249, 620)

# %%
df.columns
# Out:
# Index(['güncel_fiyat', 'brütm²', 'netm²', 'İnterkom',
#        'depremyönetmeliğineuygun', 'asansör', 'Çocukoyunalanı', 'giyinmeodası',
#        'ebeveynbanyosu', 'dolar',
#        ...
#        'manzara_Şehir,Doğa', 'manzara_Şehir,Doğa,Deniz',
#        'manzara_Şehir,Yeşil Alan', 'otopark_Var', 'otopark_Var (Açık,Kapalı)',
#        'otopark_Var (Ücretli, Açık)', 'otopark_Var (Ücretli, Kapalı)',
#        'otopark_Var (Ücretsiz, Açık)', 'otopark_Var (Ücretsiz, Kapalı)',
#        'otopark_Yok'],
#       dtype='object', length=620)

# %%
# df.to_csv("train_data_cleaned.csv",index=False)

# %%
df = pd.read_csv("train_data_cleaned.csv")
df
# Out:
#        güncel_fiyat  brütm²  netm²  İnterkom  depremyönetmeliğineuygun  \
# 0            547500    65.0   55.0         1                         0
# 1            440000   205.0  197.0         1                         1
# 2           1450000   150.0  130.0         0                         0
# 3            180000   110.0   95.0         0                         1
# 4            695000   123.0  101.0         1                         1
# ...             ...     ...    ...       ...                       ...
# 60244        790000   180.0  174.0         0                         1
# 60245        340000   130.0  125.0         0                         1
# 60246        620000   180.0  175.0         0                         1
# 60247        750000   125.0  115.0         0                         1
# 60248        250000   100.0   90.0         0                         0
#
#        asansör  Çocukoyunalanı  giyinmeodası  ebeveynbanyosu   dolar  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
X = df.drop("güncel_fiyat", axis=1)
y = df.güncel_fiyat

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = MinMaxScaler()

# %%
X_train_scale = scaler.fit_transform(X_train)
X_test_scale = scaler.transform(X_test)

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    score = r2_score(actual, pred)
    return print("r2_score:", score, "\n","mae:", mae, "\n","mse:",mse, "\n","rmse:",rmse)

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
log_model = LogisticRegression()
log_model.fit(X_train_scale, y_train)
# Out:
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = log_model.predict(X_test_scale)
eval_metrics(y_test, y_pred)
# Out:
# r2_score: 0.4435041635488244
#  mae: 385371.97316735826
#  mse: 3647968358272.7026
#  rmse: 1909965.538503955

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor()
rf_model.fit(X_train_scale, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf_model.predict(X_test_scale)
eval_metrics(y_test, y_pred)
# Out:
# r2_score: 0.8318549734744578
#  mae: 247777.43354882736
#  mse: 1102232390951.4429
#  rmse: 1049872.5593858727

# %% [markdown]
# #### Gradient Boosting

# %% [markdown]
# #### XGBoost

# %% [markdown]
# #### Final Model

# %%
X = df.drop("güncel_fiyat", axis=1)
y = df.güncel_fiyat

# %%
scaler = MinMaxScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor()
rf_model.fit(X_scaled, y)
# Out:
# RandomForestRegressor()

# %% [markdown]
# #### Test Data

# %%
X_columms = X_train.columns

# %%
df_test = pd.get_dummies(df_test).reindex(columns=X_columms, fill_value=0)

# %%
df_test
# Out:
#        brütm²  netm²  İnterkom  depremyönetmeliğineuygun  asansör  \
# 0       165.0  155.0         0                         0        0
# 1       130.0  120.0         0                         0        0
# 2       182.0  153.0         0                         0        0
# 3       130.0  120.0         0                         0        0
# 4       125.0  120.0         1                         1        1
# ...       ...    ...       ...                       ...      ...
# 35122   200.0  180.0         0                         0        0
# 35123    85.0   65.0         0                         0        0
# 35124   125.0  120.0         0                         0        1
# 35125   427.0  245.0         0                         0        0
# 35126    85.0   65.0         0                         0        0
#
#        Çocukoyunalanı  giyinmeodası  ebeveynbanyosu   dolar  \
# 0                   0             1               0  6.9130
# ...

# %%
# df_test.to_csv("test_data_dummies.csv",index=False)

# %%
df_test = pd.read_csv("test_data_dummies.csv")
df_test
# Out:
#        brütm²  netm²  İnterkom  depremyönetmeliğineuygun  asansör  \
# 0       165.0  155.0         0                         0        0
# 1       130.0  120.0         0                         0        0
# 2       182.0  153.0         0                         0        0
# 3       130.0  120.0         0                         0        0
# 4       125.0  120.0         1                         1        1
# ...       ...    ...       ...                       ...      ...
# 35122   200.0  180.0         0                         0        0
# 35123    85.0   65.0         0                         0        0
# 35124   125.0  120.0         0                         0        1
# 35125   427.0  245.0         0                         0        0
# 35126    85.0   65.0         0                         0        0
#
#        Çocukoyunalanı  giyinmeodası  ebeveynbanyosu   dolar  \
# 0                   0             1               0  6.9130
# ...

# %%
df_test = scaler.transform(df_test)

# %%
final_pred = rf_model.predict(df_test)

# %%
submission = pd.read_csv("sample_submission_zingat.csv")

# %%
submission.head()
# Out:
#       Id  Expected
# 0  64650         0
# 1  64651         0
# 2  64652         0
# 3  64653         0
# 4  64654         0

# %%
submission["Expected"] = final_pred

# %%
submission.head()
# Out:
#       Id     Expected
# 0  64650   942610.000
# 1  64651   405914.000
# 2  64652  1001120.000
# 3  64653   405914.000
# 4  64654   328917.275

# %%
submission.to_csv("Submission_V3.csv", index=False)
